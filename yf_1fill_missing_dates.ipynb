# %%
def compare_lists(list_a, list_b):
  """Compares two lists and returns a list of values that are in list A but not in list B.

  Args:
    list_a: A list of objects.
    list_b: A list of objects.

  Returns:
    A list of values that are in list_a but not in list_b.
  """

  list_difference = []

  for item in list_a:
    if item not in list_b:
      list_difference.append(item)

  return list_difference

# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.width', 900)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_picks  = f'df_picks'
fp_df_model_top_picks = f'df_model_top_picks'

# %%
df_picks = pickle_load(path_data_dump, fp_df_picks)
# drop duplicates
df_picks = df_picks.drop_duplicates(subset=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], keep='last')
# sort, most recent date is first
df_picks = df_picks.sort_values(by=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], ascending=False)
# re-index
df_picks = df_picks.reset_index(drop=True)
# save results
pickle_dump(df_picks, path_data_dump, fp_df_picks)
print(f'df_picks, len({len(df_picks)}):\n{df_picks}')
# Out:
# df_picks, len(274):
#     date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13      sym_freq_12              sym_freq_11       sym_freq_10               sym_freq_9               sym_freq_8                     sym_freq_7                     sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0          2023-11-03                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                  ['ANF']                             []         ['EDU', 'GPS', 'ICPT']  ['GBTC', 'HRB', 'LRN', 'NR...                       ['CBOE']  ['AGYS', 'BTC-USD', 'CLS',...         []
# 1          2023-11-03                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                       []           ['ANF', 'LRN']               ['GBTC', 'ICPT']  ['BTC-USD', 'EDU', 'GPS', ...  ['AGYS', 'HRB', 'NRG', 'SP...                       ['CBOE']                        ['AES']         []
# 2          2023-11-02                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                  ['ANF']                        ['NRG']                ['GPS', 'ICPT']  ['GBTC', 'LRN', 'SPLK', 'U...                             []  ['AGYS', 'BTC-USD', 'CBOE'...         []
# 3          2023-11-02                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']                []                 ['FTSM']                  ['ANF']  ['GBTC', 'GPS', 'ICPT', 'L...  ['AGYS', 'BTC-USD', 'SPR',...   ['SPLK', 'TNK', 'USAC', 'X']                             []  ['AES', 'CBOE', 'CLS', 'EDU']         []
# 4          2023-11-01                 120      [30, 60, 120]          []          []          []               []                       []                []                 ['FTSM']                  ['ANF']                             []  ['EDU', 'ICPT', 'LRN', 'NR...  ['CBOE', 'GBTC', 'GPS', 'S...                             []  ['AGYS', 'BTC-USD', 'CLS',...         []
# 5          2023-11-01                 120  [15, 30, 60, 120]          []          []          []               []                       []          ['FTSM']                  ['LRN']                  ['ANF']                       ['GBTC']  ['AGYS', 'BTC-USD', 'EDU',...  ['CBOE', 'GPS', 'QNST', 'S...                             []                        ['AES']         []
# 6          2023-10-31                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']          ['ANF', 'SPLK']                             []  ['EDU', 'FTSM', 'ICPT', 'L...  ['CBOE', 'GBTC', 'USAC', 'X']                        ['PGR']  ['AGYS', 'BTC-USD', 'CLS',...         []
# 7          2023-10-31                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                       []                []                  ['LRN']          ['ANF', 'SPLK']                       ['GBTC']  ['BTC-USD', 'EDU', 'FTSM',...  ['AGYS', 'CBOE', 'TNK', 'U...                ['PGR', 'QNST']                        ['AES']         []
# 8          2023-10-30                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                 ['SPLK']                        ['ANF']        ['ICPT', 'LRN', 'USAC']                  ['CBOE', 'X']  ['EDU', 'GBTC', 'NGS', 'PG...  ['AGYS', 'BTC-USD', 'CLS',...         []
# 9          2023-10-30                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']                       []                []                  ['LRN']                 ['SPLK']                        ['ANF']  ['BTC-USD', 'GBTC', 'ICPT'...  ['AGYS', 'CBOE', 'GPS', 'P...          ['EDU', 'FCN', 'FTI']                             []         []
# 10         2023-10-27                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                 ['SPLK']                        ['ANF']   ['ICPT', 'LRN', 'USAC', 'X']                       ['CBOE']                 ['NGS', 'PGR']  ['AEO', 'BTC-USD', 'CHE', ...         []
# 11         2023-10-27                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                 ['FTSM']                []                  ['LRN']                 ['SPLK']                        ['ANF']  ['BTC-USD', 'ICPT', 'SPR',...  ['CBOE', 'GBTC', 'GPS', 'T...  ['CHE', 'FCN', 'FTI', 'GEL...                             []         []
# 12         2023-10-26                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                 ['SPLK']                             []  ['ANF', 'CBOE', 'ICPT', 'L...                        ['PGR']                          ['X']  ['BTC-USD', 'CLS', 'CNX', ...         []
# 13         2023-10-26                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                       []          ['LRN', 'SPLK']                             []  ['ANF', 'CBOE', 'GBTC', 'I...  ['BTC-USD', 'GEL', 'PGR', ...           ['FTI', 'SWBI', 'X']                        ['AES']         []
# 14         2023-10-25                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']          ['ANF', 'SPLK']                             []        ['CBOE', 'ICPT', 'TDS']         ['LRN', 'PGR', 'USAC']           ['GBTC', 'NGS', 'X']  ['AEO', 'AKAM', 'BTC-USD',...         []
# 15         2023-10-25                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                       []          ['ANF', 'SPLK']                             []  ['CBOE', 'GBTC', 'ICPT', '...  ['BTC-USD', 'PGR', 'SPR', ...           ['NGS', 'SGEN', 'X']                 ['AEO', 'AES']         []
# 16         2023-10-24                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                  ['ANF']                       ['SPLK']                ['ICPT', 'PGR']        ['CBOE', 'CLS', 'USAC']   ['ARLP', 'GBTC', 'NGS', 'X']  ['AEO', 'AKAM', 'BTC-USD',...         []
# 17         2023-10-24                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                       []                  ['ANF']                       ['SPLK']        ['GBTC', 'ICPT', 'PGR']  ['BTC-USD', 'CBOE', 'CLS',...  ['ARLP', 'NGS', 'SGEN', 'T...                 ['AEM', 'AEO']         []
# 18         2023-10-23                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                 ['SPLK']                        ['ANF']                ['ICPT', 'PGR']                       ['USAC']  ['ARLP', 'CBOE', 'JBL', 'M...  ['AKAM', 'BTC-USD', 'CLS',...         []
# 19         2023-10-23                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                       []                 ['SPLK']                        ['ANF']         ['ICPT', 'PGR', 'TGH']        ['GBTC', 'SPR', 'USAC']  ['ARLP', 'BTC-USD', 'CBOE'...                             []         []
# 20         2023-10-20                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                             []  ['ANF', 'ICPT', 'MMYT', 'P...        ['ARLP', 'CLS', 'USAC']                 ['JBL', 'NGS']  ['AKAM', 'CBOE', 'CNX', 'C...         []
# 21         2023-10-20                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                       []          ['PGR', 'USAC']                             []  ['ANF', 'ICPT', 'MMYT', 'S...          ['ARLP', 'CLS', 'FL']  ['GBTC', 'JBL', 'NGS', 'SG...  ['AEM', 'AKAM', 'AR', 'CBOE']         []
# 22         2023-10-19                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                             []  ['ANF', 'CLS', 'ICPT', 'MM...                 ['CNX', 'JBL']        ['ARLP', 'NGS', 'TWNK']  ['AKAM', 'CBOE', 'CPRI', '...         []
# 23         2023-10-19                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                       []          ['FTSM']          ['PGR', 'USAC']                       []                             []  ['ANF', 'CLS', 'ICPT', 'MM...    ['ALL', 'CNX', 'FL', 'JBL']  ['ARLP', 'CI', 'HUM', 'NGS...                             []         []
# 24         2023-10-17                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                             []  ['ANF', 'CLS', 'ICPT', 'MM...                        ['CNX']  ['ARLP', 'JBL', 'LRN', 'NG...  ['AIZ', 'CPRI', 'DELL', 'H...         []
# 25         2023-10-17                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                       []           ['CLS', 'PGR']                        ['JBL']  ['ANF', 'ICPT', 'MMYT', 'S...                ['CNX', 'SWBI']  ['ARLP', 'LRN', 'NGS', 'TW...  ['AEO', 'AIZ', 'BAH', 'CPRI']         []
# 26         2023-10-12                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                             []  ['ANF', 'CLS', 'DELL', 'IC...        ['CNX', 'SPLK', 'USAC']  ['AKAM', 'LRN', 'MLKN', 'N...   ['HRB', 'JBL', 'LII', 'LLY']         []
# 27         2023-10-12                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                 ['ICPT']           ['ANF', 'CLS']                       ['MLKN']  ['DELL', 'JBL', 'MMYT', 'N...        ['CNX', 'SPLK', 'USAC']  ['AKAM', 'BAH', 'CME', 'LR...                             []         []
# 28         2023-10-06                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                        ['CLS']                ['ANF', 'USAC']        ['ICPT', 'LRN', 'MMYT']  ['CNX', 'DELL', 'MLKN', 'N...  ['ARCH', 'CCJ', 'CNK', 'HR...         []
# 29         2023-10-06                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                 ['FTSM']           ['CLS']                       []                 ['ICPT']       ['MLKN', 'SPLK', 'USAC']  ['ANF', 'CNK', 'JBL', 'SBL...         ['LRN', 'MMYT', 'NGS']  ['CNX', 'DELL', 'HOLI', 'H...                             []         []
# 30         2023-10-05                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                             []          ['ANF', 'CLS', 'LRN']  ['DELL', 'ICPT', 'MMYT', '...                 ['NGS', 'VST']  ['ARCH', 'CBOE', 'DBI', 'H...         []
# 31         2023-10-05                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']                       []                []                  ['CLS']         ['ICPT', 'SPLK']                             []  ['ANF', 'CBOE', 'JBL', 'LR...  ['CNK', 'DELL', 'MMYT', 'N...               ['HOLI', 'HZNP']                             []         []
# 32         2023-10-04                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                       ['SPLK']  ['ANF', 'BBW', 'ICPT', 'LRN']  ['CLS', 'DELL', 'MLKN', 'M...                             []  ['AKAM', 'ARLP', 'CBOE', '...         []
# 33         2023-10-04                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']                       []          ['SPLK']                 ['ICPT']                 ['MLKN']                             []  ['ANF', 'BBW', 'CBOE', 'HZ...  ['CLS', 'DELL', 'MMYT', 'T...  ['HOLI', 'HRB', 'NGS', 'WSM']                       ['AKAM']         []
# 34         2023-10-02                 120      [30, 60, 120]          []          []          []               []                       []                []                 ['FTSM']                  ['ANF']                             []                ['DELL', 'LRN']  ['ARCH', 'BBW', 'CLS', 'IC...  ['HRB', 'MMYT', 'SHV', 'SP...  ['CELH', 'DBI', 'HZNP', 'I...         []
# 35         2023-10-02                 120  [15, 30, 60, 120]          []          []          []         ['FTSM']                       []                []                  ['ANF']                 ['ICPT']         ['HRB', 'NGS', 'SPLK']        ['DELL', 'LRN', 'MLKN']  ['ARCH', 'BBW', 'CLS', 'JB...  ['ARLP', 'HZNP', 'MMYT', '...                             []         []
# 36         2023-09-29                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                ['ANF', 'DELL']                ['ARCH', 'CCJ']  ['CLS', 'ICPT', 'LRN', 'NGS']                       ['MMYT']  ['BBW', 'CELH', 'HRB', 'HZ...         []
# 37         2023-09-29                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                       []          ['FTSM']                 ['ARCH']          ['ICPT', 'NGS']                ['ANF', 'DELL']        ['CCJ', 'MLKN', 'SPLK']          ['CLS', 'HRB', 'LRN']       ['HZNP', 'MMYT', 'RCKT']  ['ARLP', 'BBW', 'CASY', 'C...         []
# 38         2023-09-28                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                  ['CCJ']                        ['ANF']               ['ARCH', 'DELL']                       ['USAC']  ['APO', 'CLS', 'ICPT', 'LR...  ['CELH', 'HRB', 'LII', 'SB...         []
# 39         2023-09-28                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                       []          ['FTSM']                 ['ARCH']          ['CCJ', 'USAC']         ['ANF', 'ICPT', 'NGS']       ['DELL', 'SPLK', 'TWNK']                             []  ['APO', 'CLS', 'HRB', 'LRN...                       ['ARLP']         []
# 40         2023-09-25                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                        ['CCJ']                ['DELL', 'HRB']  ['ARCH', 'CLS', 'LRN', 'VST']         ['APO', 'MMYT', 'PBR']  ['BBW', 'CELH', 'CLMT', 'C...         []
# 41         2023-09-25                 120  [15, 30, 60, 120]          []          []          []               []          ['FTSM', 'SHV']                []                       []          ['ARCH', 'CCJ']                        ['HRB']  ['DELL', 'NGS', 'TWNK', 'YY']          ['CLS', 'LRN', 'VST']  ['APO', 'CASY', 'CRS', 'MM...                       ['ARLP']         []
# 42         2023-09-22                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                       ['DELL']                 ['CCJ', 'HRB']          ['CLS', 'LRN', 'VST']  ['AKAM', 'APO', 'ARCH', 'M...  ['BBW', 'BX', 'CELH', 'CLM...         []
# 43         2023-09-22                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']                       []                []                       []                       []               ['ARCH', 'DELL']  ['CCJ', 'HRB', 'SPLK', 'TW...   ['CLS', 'LRN', 'NGS', 'VST']  ['AKAM', 'APO', 'CASY', 'M...                       ['ARLP']         []
# 44         2023-09-21                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                       ['DELL']                        ['HRB']                        ['CCJ']  ['APO', 'ARCH', 'CLS', 'HE...  ['BBW', 'CELH', 'CLMT', 'C...         []
# 45         2023-09-21                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']                       []          ['DELL']                       []                       []                       ['ARCH']  ['HRB', 'SPLK', 'TWNK', 'YY']                 ['CCJ', 'NGS']  ['APO', 'CASY', 'CLS', 'HE...                             []         []
# 46         2023-09-20                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                        ['CCJ']                ['DELL', 'HRB']                       ['CPRI']  ['APO', 'CLS', 'LRN', 'MMY...  ['ARCH', 'BBW', 'CELH', 'C...         []
# 47         2023-09-20                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                 ['FTSM']                []                 ['DELL']                       []                        ['CCJ']  ['ARCH', 'HRB', 'TWNK', 'YY']  ['APO', 'CPRI', 'NGS', 'USO']  ['BX', 'CLS', 'GEL', 'HMC'...                             []         []
# 48         2023-09-18                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['FTSM']                             []        ['CELH', 'DELL', 'LLY']          ['CCJ', 'FTI', 'VST']  ['ANF', 'ARCH', 'CLS', 'CP...       ['CLMT', 'HZNP', 'SKYW']         []
# 49         2023-09-18                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['FTSM']                 ['DELL']                       []                ['ARCH', 'CCJ']  ['CELH', 'FTI', 'LLY', 'TW...                       ['RCKT']  ['ANF', 'CLS', 'CPRI', 'HA...                             []         []
# 50         2023-09-15                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                       ['DELL']         ['ANF', 'CELH', 'LLY']                ['CCJ', 'MMYT']  ['ARCH', 'CLS', 'CPRI', 'P...  ['CLMT', 'HRB', 'HZNP', 'O...         []
# 51         2023-09-15                 120  [15, 30, 60, 120]          []          []          []               []          ['FTSM', 'SHV']          ['DELL']                       []                       []                       ['ARCH']  ['ANF', 'CCJ', 'CELH', 'LL...               ['HZNP', 'MMYT']  ['CLS', 'CPRI', 'HMC', 'PB...                 ['BX', 'CLMT']         []
# 52         2023-09-14                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']         ['DELL', 'FTSM']                             []         ['CELH', 'LLY', 'TDS']         ['ANF', 'CCJ', 'CPRI']         ['CLS', 'HEP', 'MMYT']  ['ARCH', 'BBW', 'BR', 'CLM...         []
# 53         2023-09-14                 120  [15, 30, 60, 120]          []          []          []               []          ['DELL', 'SHV']                []                       []                 ['FTSM']                             []  ['ARCH', 'CELH', 'LLY', 'T...  ['ANF', 'CCJ', 'CPRI', 'HZ...  ['CLS', 'FTI', 'HEP', 'HMC...          ['BBW', 'BR', 'CLMT']         []
# 54         2023-09-13                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                 ['DELL']                       ['MMYT']         ['CELH', 'LLY', 'TDS']               ['CORT', 'CPRI']          ['CCJ', 'CLS', 'VST']  ['ANF', 'BBW', 'CNX', 'FTI...         []
# 55         2023-09-13                 120  [15, 30, 60, 120]          []          []          []               []          ['DELL', 'SHV']                []                 ['FTSM']                       []                ['LLY', 'MMYT']        ['CELH', 'TDS', 'TWNK']  ['BBW', 'CORT', 'CPRI', 'H...   ['CCJ', 'CLS', 'FTI', 'VST']          ['ANF', 'ARCH', 'BX']         []
# 56         2023-09-12                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']         ['DELL', 'MMYT']                             []  ['ANF', 'CELH', 'FTI', 'LL...        ['CORT', 'STRL', 'VST']                ['CLS', 'CPRI']  ['BBW', 'BCC', 'CNX', 'HZN...         []
# 57         2023-09-12                 120  [15, 30, 60, 120]          []          []          []               []          ['DELL', 'SHV']                []          ['ANF', 'FTSM']          ['FTI', 'MMYT']                             []  ['CELH', 'LLY', 'TDS', 'TW...  ['CORT', 'HZNP', 'STRL', '...         ['CLS', 'CPRI', 'SLG']                 ['BBW', 'BCC']         []
# 58         2023-09-11                 120      [30, 60, 120]          []          []          []               []                       []                []  ['DELL', 'FTSM', 'SHV']                       []                       ['MMYT']  ['ANF', 'CELH', 'LLY', 'ST...        ['CORT', 'CPRI', 'VST']                 ['CLS', 'XPO']  ['BBW', 'BR', 'CNX', 'FTI'...         []
# 59         2023-09-11                 120  [15, 30, 60, 120]          []          []          []         ['DELL']                  ['SHV']                []          ['ANF', 'FTSM']                       []                       ['MMYT']  ['CELH', 'CLS', 'LLY', 'ST...  ['CORT', 'CPRI', 'HZNP', '...                 ['SLG', 'XPO']                  ['BBW', 'BR']         []
# 60         2023-09-08                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']         ['DELL', 'STRL']                             []  ['ANF', 'CELH', 'LLY', 'MM...                        ['VST']        ['CLS', 'CORT', 'CPRI']  ['AEO', 'CNX', 'FTI', 'HZN...         []
# 61         2023-09-08                 120  [15, 30, 60, 120]          []          []          []               []          ['DELL', 'SHV']                []          ['ANF', 'FTSM']         ['CELH', 'STRL']                        ['VST']         ['LLY', 'MMYT', 'TDS']         ['FTI', 'HZNP', 'VNO']  ['CLS', 'CORT', 'CPRI', 'S...         ['AEO', 'CLMT', 'CNX']         []
# 62         2023-09-05                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['FTSM']        ['ANF', 'DELL', 'STRL']  ['AEO', 'CELH', 'CLS', 'SM...  ['CNX', 'LLY', 'MMYT', 'XPO']  ['BCC', 'CORT', 'CPRI', 'U...                ['CDW', 'FFWM']         []
# 63         2023-09-05                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']   ['ANF', 'DELL']                 ['FTSM']                       []                ['STRL', 'UBS']  ['AEO', 'CELH', 'CLS', 'PA...  ['CNX', 'HZNP', 'LLY', 'MM...        ['BCC', 'CORT', 'CPRI']                             []         []
# 64         2023-09-01                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']         ['FTSM', 'STRL']                             []  ['AEO', 'ANF', 'CELH', 'CL...  ['BCC', 'CNX', 'LLY', 'MMY...                       ['CPRI']  ['BKI', 'CDW', 'CORT', 'HRB']         []
# 65         2023-09-01                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']                []  ['ANF', 'DELL', 'FTSM']          ['STRL', 'TDS']                             []  ['AEO', 'CELH', 'CLS', 'HR...  ['BCC', 'CNX', 'HZNP', 'LL...                       ['CPRI']                             []         []
# 66         2023-08-25                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['STRL']                       ['FTSM']    ['AEO', 'ANF', 'SM', 'TDS']          ['CLS', 'CNX', 'LLY']  ['BCC', 'CPRI', 'MMYT', 'X...  ['CELH', 'CORT', 'DELL', '...         []
# 67         2023-08-25                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                       []          ['STRL']           ['ANF', 'TDS']          ['FTSM', 'LLY']                       ['CPRI']  ['AEO', 'CELH', 'HRB', 'MM...     ['CLS', 'CNX', 'UBS', 'X']                 ['BCC', 'XPO']               ['CCOI', 'CCRN']         []
# 68         2023-08-18                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['FTSM']                       ['STRL']                 ['CNX', 'TDS']                 ['CLS', 'XPO']          ['BKI', 'HRB', 'LLY']  ['ADBE', 'AEO', 'BCC', 'BL...         []
# 69         2023-08-18                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                       []          ['FTSM']   ['CNX', 'STRL', 'TDS']                       []                 ['HRB', 'LLY']  ['AEO', 'BKI', 'CELH', 'CO...         ['CLS', 'CPRI', 'XPO']         ['MMYT', 'REGN', 'SM']        ['ADBE', 'AZTA', 'BCC']         []
# 70         2023-08-17                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['FTSM']                       ['STRL']          ['CLS', 'CNX', 'TDS']                        ['XPO']          ['BKI', 'HRB', 'LLY']  ['ADBE', 'AEO', 'ANF', 'BC...         []
# 71         2023-08-17                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                       []  ['FTSM', 'STRL']           ['CNX', 'TDS']                       []                 ['HRB', 'LLY']  ['AEO', 'BKI', 'CLS', 'COR...                ['LAUR', 'XPO']                         ['SM']  ['ADBE', 'ANF', 'BCC', 'BL...         []
# 72         2023-08-15                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['STRL']                             []                ['FTSM', 'TDS']                 ['CLS', 'XPO']  ['BKI', 'CNX', 'ELF', 'EME...  ['AEO', 'ANF', 'BCC', 'BZH...         []
# 73         2023-08-15                 120  [15, 30, 60, 120]          []          []          []          ['SHV']                 ['STRL']                []                  ['TDS']                       []          ['CLS', 'CNX', 'EME']  ['AEO', 'CORT', 'ELF', 'EX...  ['BKI', 'CELH', 'CPRI', 'F...               ['MMYT', 'SAIA']                             []         []
# 74         2023-08-14                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []                       ['STRL']  ['CLS', 'FTSM', 'LOB', 'TDS']                 ['EME', 'XPO']                ['BKI', 'SATS']  ['AEO', 'ANF', 'BCC', 'BZH...         []
# 75         2023-08-14                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']          ['STRL']                  ['TDS']           ['CLS', 'EME']                       ['SATS']  ['AEO', 'CORT', 'FTSM', 'L...  ['BKI', 'CELH', 'DINO', 'E...  ['CNX', 'CPRI', 'CSL', 'FF...                             []         []
# 76         2023-08-11                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'STRL']                             []                ['FTSM', 'TDS']          ['CLS', 'LOB', 'XPO']  ['BCC', 'DINO', 'EME', 'SA...  ['AEO', 'BKI', 'BZH', 'CEL...         []
# 77         2023-08-11                 120  [15, 30, 60, 120]          []          []          []               []                 ['STRL']           ['SHV']                  ['TDS']                       []         ['CLS', 'DINO', 'EME']         ['AEO', 'FTSM', 'MPC']  ['CNX', 'CORT', 'CPRI', 'C...                        ['BCC']                             []         []
# 78         2023-08-10                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'STRL']                             []         ['FTSM', 'LOB', 'TDS']                 ['CLS', 'XPO']  ['BCC', 'DINO', 'SATS', 'S...  ['AEO', 'BZH', 'CELH', 'CO...         []
# 79         2023-08-10                 120  [15, 30, 60, 120]          []          []          []               []                 ['STRL']           ['SHV']           ['LOB', 'TDS']                       []                ['CLS', 'DINO']  ['AEO', 'CORT', 'FTSM', 'S...  ['CPRI', 'CVBF', 'FFWM', '...  ['BCC', 'EME', 'LAUR', 'SM...                       ['ATSG']         []
# 80         2023-08-09                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'STRL']                             []         ['FTSM', 'LOB', 'TDS']                 ['CLS', 'GBX']  ['BCC', 'DINO', 'SATS', 'S...  ['BKI', 'BKU', 'BZH', 'CEL...         []
# 81         2023-08-09                 120  [15, 30, 60, 120]          []          []          []               []                 ['STRL']           ['SHV']           ['LOB', 'TDS']                       []                ['CLS', 'DINO']               ['FTSM', 'SATS']         ['CORT', 'GBX', 'OVV']  ['BCC', 'CNX', 'CVBF', 'EM...                             []         []
# 82         2023-08-08                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'STRL']                       ['SMCI']          ['BCC', 'LOB', 'TDS']        ['CLS', 'FTSM', 'SKYW']  ['BKU', 'EME', 'GBX', 'KDN...  ['AMPH', 'BZH', 'CVBF', 'E...         []
# 83         2023-08-08                 120  [15, 30, 60, 120]          []          []          []               []                 ['STRL']           ['SHV']                  ['TDS']                       []  ['CLS', 'LOB', 'SATS', 'SM...                 ['BCC', 'EME']  ['CORT', 'FFWM', 'FTSM', '...  ['BKU', 'DINO', 'GBX', 'KD...                ['AMPH', 'BZH']         []
# 84         2023-08-07                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['SMCI']                        ['LOB']  ['BCC', 'CLS', 'EME', 'FTS...         ['GBX', 'SATS', 'VNO']  ['AVGO', 'BKU', 'BLDR', 'B...         []
# 85         2023-08-07                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []                  ['LOB']                ['CLS', 'SMCI']         ['EME', 'SATS', 'TDS']  ['BCC', 'CORT', 'CVBF', 'F...  ['DINO', 'EDU', 'FFWM', 'G...                       ['AVGO']         []
# 86         2023-08-04                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['SMCI']                        ['LOB']  ['BCC', 'CLS', 'FTSM', 'GB...          ['EME', 'TDS', 'VNO']  ['AMPH', 'AVGO', 'BKU', 'B...         []
# 87         2023-08-04                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []                  ['LOB']         ['CLS', 'SMCI', 'TDS']                             []  ['BCC', 'CORT', 'CVBF', 'E...         ['BKU', 'EDU', 'FFWM']                       ['AMPH']         []
# 88         2023-08-03                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                             []         ['BCC', 'LOB', 'SMCI']        ['FTSM', 'GBX', 'SKYW']  ['AMPH', 'BZH', 'CLS', 'SL...  ['AVGO', 'CVBF', 'ELF', 'G...         []
# 89         2023-08-03                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []                  ['LOB']                             []  ['BCC', 'CLS', 'SMCI', 'WAL']  ['CORT', 'CVBF', 'FTSM', '...  ['AMPH', 'BZH', 'MATX', 'P...               ['AVGO', 'CADE']         []
# 90         2023-08-02                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['SMCI']          ['BZH', 'GBX', 'LOB']  ['BCC', 'CLS', 'FTSM', 'SK...         ['AMPH', 'EME', 'JOE']  ['AVGO', 'CHTR', 'CSL', 'E...         []
# 91         2023-08-02                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                  ['LOB']                       []                ['CLS', 'SMCI']          ['BZH', 'EME', 'GBX']  ['BCC', 'FTSM', 'HP', 'JOE...  ['AMPH', 'CVBF', 'PKX', 'V...  ['ASTE', 'AVGO', 'BKI', 'B...         []
# 92         2023-08-01                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                       []                ['BZH', 'SMCI']                 ['GBX', 'LOB']         ['BCC', 'CLS', 'FTSM']         ['AMPH', 'JOE', 'PKX']  ['AVGO', 'BAH', 'EME', 'GE...         []
# 93         2023-08-01                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['LOB']                 ['SMCI']                 ['BZH', 'CLS']                 ['GBX', 'PKX']         ['BCC', 'FTSM', 'JOE']                ['AMPH', 'EME']  ['AVGO', 'BAH', 'BKI', 'ED...         []
# 94         2023-07-27                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                             []                        ['JOE']  ['BCC', 'CLS', 'FTSM', 'GBX']  ['AMPH', 'KDNY', 'PKX', 'X...  ['AVGO', 'BLDR', 'BZH', 'C...         []
# 95         2023-07-27                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                  ['JOE']                       []                             []                        ['PKX']  ['BCC', 'CLS', 'FTSM', 'GB...        ['AMPH', 'KDNY', 'XPO']  ['AVGO', 'BKI', 'BLDR', 'B...         []
# 96         2023-07-26                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                        ['PKX']         ['FTSM', 'GBX', 'XPO']                ['BCC', 'STRL']                       ['AMPH']  ['AAPL', 'AVGO', 'BKI', 'B...         []
# 97         2023-07-26                 120  [15, 30, 60, 120]          []          []          []               []                       []    ['PKX', 'SHV']                       []                       []                             []         ['FTSM', 'GBX', 'XPO']  ['BCC', 'LOB', 'PRG', 'STRL']                ['AMPH', 'BKI']  ['AAPL', 'AVGO', 'BLDR', '...         []
# 98         2023-07-25                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                        ['PKX']                ['FTSM', 'GBX']        ['AMPH', 'BCC', 'NVDA']                ['STRL', 'XPO']  ['AAPL', 'AVGO', 'BKI', 'B...         []
# 99         2023-07-25                 120  [15, 30, 60, 120]          []          []          []               []                       []    ['PKX', 'SHV']                       []                       []                             []                ['FTSM', 'GBX']  ['AMPH', 'BCC', 'MLKN', 'N...  ['BKI', 'PTEN', 'STRL', 'X...  ['AAPL', 'AVGO', 'BLDR', '...         []
# 100        2023-07-21                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                             []         ['BCC', 'SIRI', 'XPO']        ['FTSM', 'GBX', 'KDNY']  ['AMPH', 'HELE', 'SKYW', '...  ['AAPL', 'AVGO', 'BECN', '...         []
# 101        2023-07-21                 120  [15, 30, 60, 120]          []          []          []               []                       []                []          ['SHV', 'SIRI']                       []                             []          ['BCC', 'PKX', 'XPO']        ['FTSM', 'GBX', 'KDNY']  ['AMPH', 'BKI', 'HELE', 'S...  ['AAPL', 'AVGO', 'BECN', '...         []
# 102        2023-07-20                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                             []  ['BCC', 'NVDA', 'SIRI', 'X...        ['AMPH', 'FTSM', 'GBX']  ['DAL', 'KDNY', 'SKYW', 'S...  ['AN', 'AVGO', 'BKI', 'BLD...         []
# 103        2023-07-20                 120  [15, 30, 60, 120]          []          []          []               []                       []                []          ['SHV', 'SIRI']                       []                             []         ['BCC', 'NVDA', 'XPO']  ['AMPH', 'FTSM', 'GBX', 'P...  ['BKI', 'DAL', 'KDNY', 'PK...  ['AN', 'AVGO', 'BLDR', 'BO...         []
# 104        2023-07-18                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                             []        ['BCC', 'FTSM', 'NVDA']               ['BECN', 'BLDR']       ['META', 'SKYW', 'STRL']  ['AN', 'AVGO', 'BOOT', 'BZ...         []
# 105        2023-07-18                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                  ['BCC']                             []        ['FTSM', 'GBX', 'NVDA']  ['BECN', 'BLDR', 'EXTR', '...  ['META', 'OSTK', 'SIRI', '...  ['AN', 'AVGO', 'BKI', 'BOO...         []
# 106        2023-07-14                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                             []         ['BCC', 'BZH', 'NVDA']  ['BECN', 'FTSM', 'META', '...  ['BLDR', 'KDNY', 'SKYW', 'W']  ['AAPL', 'AN', 'AVGO', 'BO...         []
# 107        2023-07-14                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                  ['BCC']                        ['BZH']                ['GBX', 'NVDA']  ['BECN', 'FTSM', 'META', '...  ['BLDR', 'KDNY', 'MARA', '...  ['AAPL', 'AN', 'AVGO', 'BO...         []
# 108        2023-07-13                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'SKYW']                             []                ['BCC', 'NVDA']  ['BECN', 'BZH', 'FTSM', 'M...   ['CCL', 'KDNY', 'NCLH', 'W']  ['AVGO', 'BLDR', 'CAR', 'C...         []
# 109        2023-07-13                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']          ['BCC', 'SKYW']                             []         ['BZH', 'GBX', 'NVDA']  ['AN', 'BECN', 'FTSM', 'ME...  ['CCL', 'COMM', 'HELE', 'K...               ['AVGO', 'BLDR']         []
# 110        2023-07-12                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'SKYW']                             []        ['BZH', 'FTSM', 'NVDA']               ['KDNY', 'NCLH']  ['BLDR', 'CCL', 'STRL', 'T...  ['AAPL', 'AVGO', 'BCC', 'C...         []
# 111        2023-07-12                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']          ['BZH', 'SKYW']                             []        ['FTSM', 'GBX', 'NVDA']  ['HELE', 'KDNY', 'NCLH', 'W']  ['BLDR', 'CCL', 'COMM', 'M...                 ['AAPL', 'AN']         []
# 112        2023-07-11                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'SKYW']                             []               ['FTSM', 'KDNY']  ['CCL', 'NCLH', 'NVDA', 'R...     ['BCC', 'BZH', 'DAL', 'W']  ['AAL', 'AAPL', 'BECN', 'B...         []
# 113        2023-07-11                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []                 ['SKYW']                             []  ['BZH', 'FTSM', 'GBX', 'KD...  ['BCC', 'CCL', 'MARA', 'NC...  ['AAL', 'DAL', 'HELE', 'OS...                             []         []
# 114        2023-07-10                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'SKYW']                             []               ['FTSM', 'NVDA']  ['CCL', 'ISEE', 'KDNY', 'N...  ['BCC', 'BECN', 'BLDR', 'B...  ['AAPL', 'CAR', 'CELH', 'C...         []
# 115        2023-07-10                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []                 ['SKYW']         ['BCC', 'CCL', 'FTSM']  ['BZH', 'GBX', 'KDNY', 'NC...  ['CAR', 'COMM', 'DAL', 'HA...               ['BECN', 'BLDR']                             []         []
# 116        2023-07-07                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'SKYW']                             []  ['CCL', 'FTSM', 'KDNY', 'N...               ['ISEE', 'NCLH']  ['AAPL', 'BZH', 'DAL', 'EL...  ['AAL', 'BCC', 'BECN', 'BL...         []
# 117        2023-07-07                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []                 ['SKYW']               ['FTSM', 'KDNY']  ['BZH', 'CCL', 'DAL', 'GBX...  ['BCC', 'CAR', 'COMM', 'IS...  ['AAPL', 'DLR', 'ELF', 'OS...                             []         []
# 118        2023-07-06                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'SKYW']                             []  ['CCL', 'FTSM', 'ISEE', 'K...                       ['NCLH']  ['AAPL', 'BCC', 'BZH', 'DA...         ['AMPH', 'ANF', 'CAR']         []
# 119        2023-07-06                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []          ['CCL', 'SKYW']               ['FTSM', 'KDNY']  ['BCC', 'BZH', 'DAL', 'GBX...  ['AMPH', 'COMM', 'MARA', '...  ['AAPL', 'CAR', 'ELF', 'OS...                             []         []
# 120        2023-07-05                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['SKYW']                ['CCL', 'STRL']  ['BZH', 'ISEE', 'KDNY', 'N...  ['AAPL', 'BCC', 'BLDR', 'D...                 ['ANF', 'CAR']         []
# 121        2023-07-05                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []                  ['CCL']  ['BZH', 'DAL', 'MARA', 'SK...  ['BCC', 'CAR', 'GBX', 'JBL...  ['EXP', 'ISEE', 'KDNY', 'N...                       ['AAPL']                             []         []
# 122        2023-07-03                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['SKYW']                        ['CCL']  ['BZH', 'FTSM', 'ISEE', 'N...  ['BLDR', 'KDNY', 'NVDA', '...  ['AAPL', 'ANF', 'BCC', 'CA...         []
# 123        2023-07-03                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []     ['CCL', 'SKYW', 'W']                        ['BZH']                 ['DAL', 'GBX']  ['EXP', 'FTSM', 'ISEE', 'M...  ['BLDR', 'CAR', 'KDNY', 'N...                             []         []
# 124        2023-06-30                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['SKYW']                        ['CCL']        ['ISEE', 'NCLH', 'RCL']  ['BLDR', 'BZH', 'FTSM', 'K...  ['AAPL', 'ANF', 'BCC', 'BMA']         []
# 125        2023-06-30                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                 ['SKYW']                  ['CCL']               ['KDNY', 'NCLH']  ['BZH', 'DAL', 'GBX', 'OST...  ['CAR', 'EXP', 'ISEE', 'MA...       ['BLDR', 'FTSM', 'NVDA']                             []         []
# 126        2023-06-29                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['SHV', 'SKYW']                             []                       ['FTSM']        ['CCL', 'ISEE', 'NCLH']  ['BECN', 'BLDR', 'BZH', 'K...  ['AAPL', 'ANF', 'BCC', 'BM...         []
# ...
# 232        2023-04-13                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['FTSM']                        ['ELF']  ['META', 'NVDA', 'NVO', 'P...  ['AU', 'COTY', 'GBTC', 'SG...  ['ACLS', 'AMPH', 'ANET', '...         []
# 233        2023-04-13                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []                       ['FTSM']                  ['AU', 'ELF']  ['META', 'NVDA', 'NVO', 'N...  ['AZN', 'COTY', 'GBTC', 'M...  ['ACLS', 'AMPH', 'ANET', '...         []
# 234        2023-04-12                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['FTSM']                        ['ELF']       ['META', 'NVDA', 'PDFS']  ['ACLS', 'AU', 'COTY', 'NV...  ['AMPH', 'ANET', 'AZN', 'C...         []
# 235        2023-04-12                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []                 ['AU', 'FTSM']                        ['ELF']  ['META', 'NVDA', 'NVS', 'P...  ['ACLS', 'AZN', 'CNK', 'CO...       ['AMPH', 'ANET', 'CPRT']         []
# 236        2023-04-11                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['FTSM']                ['AMPH', 'ELF']       ['META', 'NVDA', 'PDFS']  ['ACLS', 'AU', 'MLR', 'NVO...  ['ANET', 'AQN', 'BTC-USD',...         []
# 237        2023-04-11                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []                 ['AU', 'FTSM']                ['AMPH', 'ELF']       ['META', 'NVDA', 'PDFS']  ['ACLS', 'CNK', 'MLR', 'NV...         ['ANET', 'AQN', 'AZN']         []
# 238        2023-04-10                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['FTSM']                ['AMPH', 'ELF']       ['META', 'NVDA', 'PDFS']  ['ACLS', 'AU', 'GBTC', 'HY...  ['AJRD', 'ANET', 'BTC-USD'...         []
# 239        2023-04-10                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []                 ['AU', 'FTSM']                ['AMPH', 'ELF']  ['META', 'NVDA', 'NVO', 'P...  ['ACLS', 'CNK', 'GBTC', 'H...                       ['AJRD']         []
# 240        2023-04-06                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                       ['FTSM']                ['ELF', 'SGEN']       ['META', 'NVDA', 'PDFS']  ['ACLS', 'AMPH', 'AU', 'GB...    ['AJRD', 'ANET', 'BTC-USD']         []
# 241        2023-04-06                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                       []                  ['SHV']                 ['AU', 'FTSM']  ['ELF', 'NVO', 'SGEN', 'SNY']       ['META', 'NVDA', 'PDFS']  ['ACLS', 'AMPH', 'CNK', 'G...                       ['AJRD']         []
# 242        2023-04-05                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []                       ['FTSM']  ['ANET', 'ELF', 'GE', 'SGEN']  ['ACLS', 'AMPH', 'HY', 'ME...  ['AU', 'GBTC', 'LNTH', 'ML...                             []         []
# 243        2023-04-05                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []          ['AU', 'FTSM', 'NVO']  ['ANET', 'ELF', 'GE', 'OR'...  ['ACLS', 'AMPH', 'HY', 'ME...  ['GBTC', 'LNTH', 'MLR', 'R...                             []         []
# 244        2023-04-04                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['NVDA', 'SHV']                             []  ['ANET', 'ELF', 'FTSM', 'G...  ['ACLS', 'HY', 'META', 'PD...    ['AU', 'FCN', 'GBTC', 'TA']               ['AMPH', 'AVGO']         []
# 245        2023-04-04                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                       []          ['NVDA', 'SHV']                 ['AU', 'PERI']  ['ANET', 'ELF', 'FTSM', 'G...  ['ACLS', 'HY', 'META', 'OR...  ['FCN', 'GBTC', 'RELX', 'TA']                             []         []
# 246        2023-04-03                 120      [30, 60, 120]          []          []          []               []                       []                []                       []           ['GE', 'NVDA']                             []  ['ACLS', 'ANET', 'FTSM', '...       ['META', 'OLED', 'SGEN']  ['CRUS', 'FCN', 'GBTC', 'P...    ['AMPH', 'AVGO', 'BTC-USD']         []
# 247        2023-04-03                 120  [15, 30, 60, 120]          []          []          []               []                       []          ['NVDA']                       []           ['GE', 'PERI']                             []  ['ACLS', 'ANET', 'FTSM', '...  ['AU', 'ELF', 'META', 'OLE...  ['CRUS', 'FCN', 'GBTC', 'O...                             []         []
# 248        2023-03-31                 120      [30, 60, 120]          []          []          []               []                       []                []                       []                 ['NVDA']          ['FTSM', 'HY', 'SHV']  ['ACLS', 'ANET', 'GE', 'LN...               ['META', 'SGEN']  ['AMD', 'CRUS', 'FCN', 'GB...                ['CNK', 'COTY']         []
# 249        2023-03-31                 120  [15, 30, 60, 120]          []          []          []               []                       []          ['NVDA']                       []                       []          ['FTSM', 'HY', 'SHV']  ['ACLS', 'ANET', 'GBTC', '...  ['AMD', 'AU', 'ELF', 'META...  ['CRUS', 'FCN', 'MLR', 'NVO']                             []         []
# 250        2023-03-30                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['NVDA']                 ['FTSM', 'HY']         ['GE', 'LNTH', 'PDFS']  ['ACLS', 'META', 'NVO', 'S...  ['AMD', 'AMPH', 'CRUS', 'F...                       ['AJRD']         []
# 251        2023-03-30                 120  [15, 30, 60, 120]          []          []          []               []                       []          ['NVDA']                  ['SHV']                       []         ['FTSM', 'HY', 'SGEN']  ['GBTC', 'GE', 'LNTH', 'PD...  ['ACLS', 'AU', 'BTC-USD', ...  ['AMD', 'AMPH', 'CRUS', 'F...                             []         []
# 252        2023-03-29                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []                 ['FTSM', 'HY']  ['GE', 'LNTH', 'NVDA', 'PD...  ['ACLS', 'GBTC', 'PERI', '...  ['FCN', 'META', 'MLR', 'NT...                       ['AJRD']         []
# 253        2023-03-29                 120  [15, 30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['SGEN']         ['FTSM', 'GBTC', 'HY']  ['GE', 'LNTH', 'NVDA', 'PD...  ['ACLS', 'BTC-USD', 'OR', ...          ['AU', 'FCN', 'MARA']                             []         []
# 254        2023-03-28                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []                 ['FTSM', 'HY']  ['GE', 'LNTH', 'PDFS', 'SG...  ['GBTC', 'MLR', 'NVDA', 'P...  ['ACLS', 'AMPH', 'COTY', '...                 ['CNK', 'ELF']         []
# 255        2023-03-28                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []                 ['SGEN']    ['FTSM', 'HY', 'MLR', 'TA']  ['GE', 'LNTH', 'PDFS', 'SNY']  ['GBTC', 'NVDA', 'OR', 'PE...  ['ACLS', 'AMPH', 'BTC-USD'...                             []         []
# 256        2023-03-27                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                   ['GE']         ['FTSM', 'HY', 'NVDA']  ['LNTH', 'PDFS', 'PERI', '...        ['ACLS', 'GBTC', 'WST']  ['AMPH', 'COTY', 'FCN', 'N...    ['AJRD', 'ATCO', 'BTC-USD']         []
# 257        2023-03-27                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                       []   ['GE', 'NVDA', 'SGEN']           ['FTSM', 'HY', 'TA']       ['LNTH', 'PDFS', 'PERI']  ['ACLS', 'ANET', 'BTC-USD'...               ['AMPH', 'COTY']                             []         []
# 258        2023-03-24                 120      [30, 60, 120]          []          []          []               []                       []                []                       []          ['NVDA', 'SHV']                 ['FTSM', 'HY']  ['GE', 'LNTH', 'PDFS', 'PE...        ['ACLS', 'GBTC', 'WST']         ['FCN', 'MLR', 'NTRA']  ['AJRD', 'AMPH', 'BTC-USD'...         []
# 259        2023-03-24                 120  [15, 30, 60, 120]          []          []          []               []                       []          ['NVDA']                  ['SHV']                 ['SGEN']   ['FTSM', 'GBTC', 'HY', 'TA']  ['GE', 'LNTH', 'MLR', 'PDF...  ['ACLS', 'AMD', 'ANET', 'B...                ['FCN', 'MARA']                             []         []
# 260        2023-03-23                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                       []   ['FTSM', 'GE', 'HY', 'NVDA']  ['LNTH', 'PDFS', 'PERI', '...        ['ACLS', 'GBTC', 'WST']        ['FCN', 'MARA', 'NTRA']  ['AJRD', 'AMPH', 'ANET', '...         []
# 261        2023-03-23                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']                []                 ['NVDA']           ['FTSM', 'GE']   ['GBTC', 'HY', 'SGEN', 'TA']  ['ANET', 'BTC-USD', 'LNTH'...         ['ACLS', 'AMD', 'WST']         ['FCN', 'MLR', 'NTRA']                             []         []
# 262        2023-03-22                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                 ['FTSM']                       ['NVDA']  ['GE', 'HY', 'LNTH', 'PDFS...                ['ACLS', 'WST']  ['AMPH', 'COTY', 'FCN', 'G...       ['AJRD', 'ANET', 'BURL']         []
# 263        2023-03-22                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']                []         ['FTSM', 'NVDA']                 ['SGEN']                             []  ['ANET', 'GBTC', 'GE', 'HY...                ['ACLS', 'WST']  ['AMD', 'AMPH', 'COTY', 'F...                             []         []
# 264        2023-03-21                 120      [30, 60, 120]          []          []          []               []                       []                []                  ['SHV']                   ['GE']                       ['FTSM']  ['HY', 'LNTH', 'PDFS', 'SG...                ['ACLS', 'WST']  ['AMPH', 'AXON', 'FCN', 'G...  ['AJRD', 'ATCO', 'BURL', '...         []
# 265        2023-03-21                 120  [15, 30, 60, 120]          []          []          []               []                       []           ['SHV']                   ['GE']                       []               ['FTSM', 'SGEN']  ['GBTC', 'HY', 'LNTH', 'NV...        ['ACLS', 'ANET', 'WST']  ['AMPH', 'ATCO', 'AXON', '...                             []         []
# 266        2023-03-20                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                             []  ['GE', 'LNTH', 'SGEN', 'TA...        ['ACLS', 'FCN', 'NVDA']         ['AMPH', 'GBTC', 'HY']  ['AJRD', 'ANET', 'ATCO', '...         []
# 267        2023-03-20                 120  [15, 30, 60, 120]          []          []          []               []                       []   ['FTSM', 'SHV']                       []                       []                       ['SGEN']  ['AMPH', 'ANET', 'FCN', 'G...  ['ACLS', 'FSLR', 'MLR', 'N...                 ['HY', 'MYGN']                ['AJRD', 'AMD']         []
# 268        2023-03-17                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                   ['GE']                       ['NVDA']          ['SGEN', 'TA', 'WST']        ['ACLS', 'FCN', 'LNTH']               ['ATCO', 'GBTC']  ['AJRD', 'AMPH', 'ANET', '...         []
# 269        2023-03-17                 120  [15, 30, 60, 120]          []          []          []               []                  ['SHV']                []           ['FTSM', 'GE']                       []               ['NVDA', 'SGEN']  ['ANET', 'FCN', 'GBTC', 'T...  ['ACLS', 'FSLR', 'HY', 'LN...         ['AMD', 'ATCO', 'MLR']                       ['AJRD']         []
# 270        2023-03-16                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                             []        ['LNTH', 'SGEN', 'WST']  ['ACLS', 'AMPH', 'CTLT', '...           ['HY', 'MLR', 'OEC']  ['ANET', 'ATCO', 'ATKR', '...         []
# 271        2023-03-16                 120  [15, 30, 60, 120]          []          []          []               []                       []   ['FTSM', 'SHV']                 ['SGEN']                       []                        ['MLR']  ['ANET', 'FCN', 'FSLR', 'G...  ['ACLS', 'AMPH', 'CTLT', '...                             []                             []         []
# 272        2023-03-15                 120      [30, 60, 120]          []          []          []               []                       []                []          ['FTSM', 'SHV']                       []                             []  ['CTLT', 'ELF', 'SGEN', 'T...  ['ACLS', 'AMPH', 'FCN', 'GE']  ['ATCO', 'HY', 'LNTH', 'ME...  ['ATKR', 'BURL', 'FIZZ', '...         []
# 273        2023-03-15                 120  [15, 30, 60, 120]          []          []          []               []          ['FTSM', 'SHV']                []                 ['SGEN']          ['AMPH', 'FCN']           ['GE', 'HY', 'META']  ['CTLT', 'ELF', 'FIZZ', 'M...       ['ACLS', 'ANET', 'SRPT']               ['ATCO', 'LNTH']                             []         []

# %%
start_date = df_picks.date_end_df_train.min()
end_date = df_picks.date_end_df_train.max()
print(f'df_picks start date: {start_date}')
print(f'df_picks end date: {end_date}')
# Out:
# df_picks start date: 2023-03-15
# df_picks end date: 2023-11-03

# %%
l_dates_df_picks = df_picks.date_end_df_train.unique().tolist()  # unique dates in df_picks
print(f'l_dates_df_picks, len({len(l_dates_df_picks)}):\n{l_dates_df_picks}')
# Out:
# l_dates_df_picks, len(137):
# ['2023-11-03', '2023-11-02', '2023-11-01', '2023-10-31', '2023-10-30', '2023-10-27', '2023-10-26', '2023-10-25', '2023-10-24', '2023-10-23', '2023-10-20', '2023-10-19', '2023-10-17', '2023-10-12', '2023-10-06', '2023-10-05', '2023-10-04', '2023-10-02', '2023-09-29', '2023-09-28', '2023-09-25', '2023-09-22', '2023-09-21', '2023-09-20', '2023-09-18', '2023-09-15', '2023-09-14', '2023-09-13', '2023-09-12', '2023-09-11', '2023-09-08', '2023-09-05', '2023-09-01', '2023-08-25', '2023-08-18', '2023-08-17', '2023-08-15', '2023-08-14', '2023-08-11', '2023-08-10', '2023-08-09', '2023-08-08', '2023-08-07', '2023-08-04', '2023-08-03', '2023-08-02', '2023-08-01', '2023-07-27', '2023-07-26', '2023-07-25', '2023-07-21', '2023-07-20', '2023-07-18', '2023-07-14', '2023-07-13', '2023-07-12', '2023-07-11', '2023-07-10', '2023-07-07', '2023-07-06', '2023-07-05', '2023-07-03', '2023-06-30', '2023-06-29', '2023-06-28', '2023-06-27', '2023-06-26', '2023-06-23', '2023-06-22', '2023-06-21', '2023-06-20', '2023-06-16', '2023-06-15', '2023-06-14', '2023-06-13', '2023-06-12', '2023-06-09', '2023-06-08', '2023-06-07', '2023-06-06', '2023-06-05', '2023-06-02', '2023-06-01', '2023-05-31', '2023-05-30', '2023-05-26', '2023-05-25', '2023-05-24', '2023-05-23', '2023-05-22', '2023-05-19', '2023-05-18', '2023-05-17', '2023-05-16', '2023-05-15', '2023-05-12', '2023-05-11', '2023-05-10', '2023-05-09', '2023-05-08', '2023-05-05', '2023-05-04', '2023-05-03', '2023-05-02', '2023-05-01', '2023-04-28', '2023-04-27', '2023-04-26', '2023-04-25', '2023-04-24', '2023-04-21', '2023-04-20', '2023-04-19', '2023-04-18', '2023-04-17', '2023-04-14', '2023-04-13', '2023-04-12', '2023-04-11', '2023-04-10', '2023-04-06', '2023-04-05', '2023-04-04', '2023-04-03', '2023-03-31', '2023-03-30', '2023-03-29', '2023-03-28', '2023-03-27', '2023-03-24', '2023-03-23', '2023-03-22', '2023-03-21', '2023-03-20', '2023-03-17', '2023-03-16', '2023-03-15']

# %%
import pandas_market_calendars as mcal
nyse = mcal.get_calendar('NYSE')
# NYSE dates from df_picks start date to end date
dates_NYSE = nyse.valid_days(start_date=start_date, end_date=end_date).strftime('%Y-%m-%d')
# print(f'len(dates_NYSE): {len(dates_NYSE)}')
dates_NYSE_reversed_sorted = dates_NYSE.sort_values(ascending=False)
print('NYSE dates from df_picks start date to end date')
print(f'dates_NYSE_reversed_sorted, len({len(dates_NYSE)}):\n{dates_NYSE_reversed_sorted}')
# Out:
# NYSE dates from df_picks start date to end date
# dates_NYSE_reversed_sorted, len(163):
# Index(['2023-11-03', '2023-11-02', '2023-11-01', '2023-10-31', '2023-10-30', '2023-10-27', '2023-10-26', '2023-10-25', '2023-10-24', '2023-10-23',
#        ...
#        '2023-03-28', '2023-03-27', '2023-03-24', '2023-03-23', '2023-03-22', '2023-03-21', '2023-03-20', '2023-03-17', '2023-03-16', '2023-03-15'], dtype='object', length=163)

# %%
NYSE_dates_missing_in_df_picks  = compare_lists(dates_NYSE_reversed_sorted, l_dates_df_picks)
NYSE_dates_missing_in_df_picks .sort(reverse=True)  # sorted inplace, newest first
print(f'NYSE_dates_missing_in_df_picks, (len={len(NYSE_dates_missing_in_df_picks )}):\n{NYSE_dates_missing_in_df_picks }')
# Out:
# NYSE_dates_missing_in_df_picks, (len=26):
# ['2023-10-18', '2023-10-16', '2023-10-13', '2023-10-11', '2023-10-10', '2023-10-09', '2023-10-03', '2023-09-27', '2023-09-26', '2023-09-19', '2023-09-07', '2023-09-06', '2023-08-31', '2023-08-30', '2023-08-29', '2023-08-28', '2023-08-24', '2023-08-23', '2023-08-22', '2023-08-21', '2023-08-16', '2023-07-31', '2023-07-28', '2023-07-24', '2023-07-19', '2023-07-17']

# %% [markdown]
# ## Add picks from missing dates to df_picks

# %%
df_model_picks_results = pickle_load(path_data_dump, 'df_model_picks_results')
print(f'df_model_picks_results, len({len(df_model_picks_results)}):\n{df_model_picks_results}\n')
# Out:
# df_model_picks_results, len(125):
#            date      days_lookback    syms_freq                  symbols    date_buy     sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell    sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 4    2023-09-01      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-09-05            [9.0]   990.629997      [2.0]  898.479980  2023-09-08            [9.0]    991.440033     0.081770       [2.0]  891.039978  -0.828065   0.909835    1
# 5    2023-09-01      [30, 60, 120]   sym_freq_8         ['FTSM', 'STRL']  2023-09-05       [8.0, 6.0]   959.080002      [2.0]  898.479980  2023-09-08       [8.0, 6.0]    947.040024    -1.255367       [2.0]  891.039978  -0.828065  -0.427302    0
# 6    2023-08-25      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-08-28            [9.0]   989.454735      [2.0]  885.520020  2023-08-31            [9.0]    990.350945     0.090576       [2.0]  900.700012   1.714246  -1.623670    0
# 7    2023-08-25      [30, 60, 120]   sym_freq_8                 ['STRL']  2023-08-28           [12.0]   949.920044      [2.0]  885.520020  2023-08-31           [12.0]    993.120026     4.547749       [2.0]  900.700012   1.714246   2.833503    1
# 8    2023-08-25  [15, 30, 60, 120]  sym_freq_12                  ['SHV']  2023-08-28            [9.0]   989.454735      [2.0]  885.520020  2023-08-31            [9.0]    990.350945     0.090576       [2.0]  900.700012   1.714246  -1.623670    0
# 9    2023-08-18      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-08-21            [9.0]   988.558525      [2.0]  878.679993  2023-08-24            [9.0]    989.365128     0.081594       [2.0]  873.780029  -0.557651   0.639244    1
# 10   2023-08-18      [30, 60, 120]   sym_freq_8                 ['FTSM']  2023-08-21           [16.0]   949.653931      [2.0]  878.679993  2023-08-24           [16.0]    950.450684     0.083899       [2.0]  873.780029  -0.557651   0.641550    1
# 11   2023-08-18  [15, 30, 60, 120]  sym_freq_12                  ['SHV']  2023-08-21            [9.0]   988.558525      [2.0]  878.679993  2023-08-24            [9.0]    989.365128     0.081594       [2.0]  873.780029  -0.557651   0.639244    1
# 12   2023-08-17      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-08-18            [9.0]   988.468849      [2.0]  873.000000  2023-08-23            [9.0]    988.916954     0.045333       [2.0]  886.059998   1.495991  -1.450657    0
# 13   2023-08-17      [30, 60, 120]   sym_freq_8                 ['FTSM']  2023-08-18           [16.0]   949.494629      [2.0]  873.000000  2023-08-23           [16.0]    950.131958     0.067123       [2.0]  886.059998   1.495991  -1.428868    0
# 14   2023-08-17  [15, 30, 60, 120]  sym_freq_12                  ['SHV']  2023-08-18            [9.0]   988.468849      [2.0]  873.000000  2023-08-23            [9.0]    988.916954     0.045333       [2.0]  886.059998   1.495991  -1.450657    0
# 15   2023-08-15      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-08-16            [9.0]   987.931137      [2.0]  879.280029  2023-08-21            [9.0]    988.558525     0.063505       [2.0]  878.679993  -0.068242   0.131747    1
# 16   2023-08-15      [30, 60, 120]   sym_freq_8                 ['STRL']  2023-08-16           [12.0]   965.879974      [2.0]  879.280029  2023-08-21           [12.0]    928.920044    -3.826555       [2.0]  878.679993  -0.068242  -3.758313    0
# 17   2023-08-15  [15, 30, 60, 120]  sym_freq_12                  ['SHV']  2023-08-16            [9.0]   987.931137      [2.0]  879.280029  2023-08-21            [9.0]    988.558525     0.063505       [2.0]  878.679993  -0.068242   0.131747    1
# 18   2023-08-14      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-08-15            [9.0]   987.841530      [2.0]  885.780029  2023-08-18            [9.0]    988.468849     0.063504       [2.0]  873.000000  -1.442799   1.506303    1
# 19   2023-08-11      [30, 60, 120]   sym_freq_8          ['SHV', 'STRL']  2023-08-14       [4.0, 6.0]   919.800995      [2.0]  896.219971  2023-08-17       [4.0, 6.0]    890.719650    -3.161700       [2.0]  872.580017  -2.637740  -0.523960    0
# 20   2023-08-10      [30, 60, 120]   sym_freq_8          ['SHV', 'STRL']  2023-08-11       [4.0, 6.0]   923.621323      [2.0]  891.299988  2023-08-16       [4.0, 6.0]    922.020493    -0.173321       [2.0]  879.280029  -1.348587   1.175266    1
# 21   2023-08-09      [30, 60, 120]   sym_freq_8          ['SHV', 'STRL']  2023-08-10       [4.0, 6.0]   918.141663      [2.0]  891.820007  2023-08-15       [4.0, 6.0]    932.780685     1.594419       [2.0]  885.780029  -0.677264   2.271683    1
# 22   2023-08-08      [30, 60, 120]   sym_freq_8          ['SHV', 'STRL']  2023-08-09       [4.0, 6.0]   908.702499      [2.0]  891.500000  2023-08-14       [4.0, 6.0]    919.800995     1.221356       [2.0]  896.219971   0.529441   0.691915    1
# 23   2023-08-07      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-08-08            [9.0]   986.765968      [2.0]  897.500000  2023-08-11            [9.0]    987.482964     0.072661       [2.0]  891.299988  -0.690809   0.763470    1
# 24   2023-08-04      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-08-07            [9.0]   986.586754      [2.0]  901.419983  2023-08-10            [9.0]    987.303749     0.072674       [2.0]  891.820007  -1.064984   1.137658    1
# 25   2023-08-03      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-08-04            [9.0]   986.586754      [2.0]  893.619995  2023-08-09            [9.0]    986.855644     0.027255       [2.0]  891.500000  -0.237237   0.264491    1
# 26   2023-08-02      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-08-03            [9.0]   986.317932      [2.0]  897.679993  2023-08-08            [9.0]    986.765968     0.045425       [2.0]  897.500000  -0.020051   0.065476    1
# 27   2023-07-27      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-28            [9.0]   985.449326      [2.0]  913.840027  2023-08-02            [9.0]    985.959366     0.051757       [2.0]  900.260010  -1.486039   1.537796    1
# 28   2023-07-26      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-27            [9.0]   985.181534      [2.0]  904.979980  2023-08-01            [9.0]    985.780083     0.060755       [2.0]  912.960022   0.881792  -0.821037    0
# 29   2023-07-25      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-26            [9.0]   984.824547      [2.0]  911.020020  2023-07-31            [9.0]    985.627785     0.081562       [2.0]  915.580017   0.500538  -0.418976    0
# 30   2023-07-21      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-24            [9.0]   984.556824      [2.0]  908.400024  2023-07-27            [9.0]    985.181534     0.063451       [2.0]  904.979980  -0.376491   0.439942    1
# 31   2023-07-20      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-21            [9.0]   984.467560      [2.0]  904.359985  2023-07-26            [9.0]    984.824547     0.036262       [2.0]  911.020020   0.736436  -0.700174    0
# 32   2023-07-18      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-19            [9.0]   983.932114      [2.0]  910.400024  2023-07-24            [9.0]    984.556824     0.063491       [2.0]  908.400024  -0.219684   0.283175    1
# 33   2023-07-14      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-17            [9.0]   983.664322      [2.0]  901.679993  2023-07-20            [9.0]    984.378365     0.072590       [2.0]  904.359985   0.297222  -0.224632    0
# 34   2023-07-13      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-07-14      [4.0, 12.0]   922.304504      [2.0]  898.559998  2023-07-19      [4.0, 12.0]    945.743149     2.541313       [2.0]  910.400024   1.317667   1.223646    1
# 35   2023-07-12      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-07-13      [4.0, 12.0]   934.744843      [2.0]  899.119995  2023-07-18      [4.0, 12.0]    939.663834     0.526239       [2.0]  908.380005   1.029897  -0.503658    0
# 36   2023-07-11      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-07-12      [4.0, 12.0]   930.306839      [2.0]  892.039978  2023-07-17      [4.0, 12.0]    922.584152    -0.830123       [2.0]  901.679993   1.080671  -1.910793    0
# 37   2023-07-10      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-07-11      [4.0, 11.0]   895.997833      [2.0]  884.919983  2023-07-14      [4.0, 11.0]    881.874504    -1.576268       [2.0]  898.559998   1.541384  -3.117652    0
# 38   2023-07-07      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-07-10      [4.0, 11.0]   900.837818      [2.0]  879.320007  2023-07-13      [4.0, 11.0]    893.274841    -0.839549       [2.0]  899.119995   2.251739  -3.091288    0
# 39   2023-07-06      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-07-07      [4.0, 12.0]   926.988495      [2.0]  877.099976  2023-07-12      [4.0, 12.0]    930.306839     0.357970       [2.0]  892.039978   1.703341  -1.345371    0
# 40   2023-07-05      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-06            [9.0]   982.504097      [2.0]  879.320007  2023-07-11            [9.0]    982.682625     0.018171       [2.0]  884.919983   0.636853  -0.618682    0
# 41   2023-07-03      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-05            [9.0]   981.968719      [2.0]  886.260010  2023-07-10            [9.0]    982.682625     0.072701       [2.0]  879.320007  -0.783066   0.855768    1
# 42   2023-06-30      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-07-03            [9.0]   981.790260      [2.0]  887.580017  2023-07-07            [9.0]    982.504097     0.072708       [2.0]  877.099976  -1.180743   1.253451    1
# 43   2023-06-29      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-06-30      [4.0, 12.0]   925.022919      [2.0]  886.559998  2023-07-06      [4.0, 12.0]    912.588486    -1.344230       [2.0]  879.320007  -0.816638  -0.527591    0
# 44   2023-06-28      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-06-29      [4.0, 12.0]   920.705917      [2.0]  876.219971  2023-07-05      [4.0, 12.0]    918.350540    -0.255823       [2.0]  886.260010   1.145835  -1.401658    0
# 45   2023-06-27      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-06-28      [4.0, 12.0]   911.866913      [2.0]  872.780029  2023-07-03      [4.0, 12.0]    926.911240     1.649838       [2.0]  887.580017   1.695729  -0.045891    0
# 46   2023-06-26      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-06-27      [4.0, 12.0]   906.067322      [2.0]  872.340027  2023-06-30      [4.0, 12.0]    925.022919     2.092074       [2.0]  886.559998   1.630095   0.461979    1
# 47   2023-06-23      [30, 60, 120]   sym_freq_9                 ['NVDA']  2023-06-26            [2.0]   812.573059      [2.0]  862.880005  2023-06-29            [2.0]    816.372742     0.467611       [2.0]  876.219971   1.545982  -1.078370    0
# 48   2023-06-23      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-06-26      [4.0, 12.0]   902.868332      [2.0]  862.880005  2023-06-29      [4.0, 12.0]    920.705917     1.975657       [2.0]  876.219971   1.545982   0.429676    1
# 49   2023-06-22      [30, 60, 120]   sym_freq_9                 ['NVDA']  2023-06-23            [2.0]   844.110474      [2.0]  866.419983  2023-06-28            [2.0]    822.272278    -2.587125       [2.0]  872.780029   0.734060  -3.321186    0
# 50   2023-06-22      [30, 60, 120]   sym_freq_8          ['SHV', 'SKYW']  2023-06-23      [4.0, 12.0]   910.709320      [2.0]  866.419983  2023-06-28      [4.0, 12.0]    911.866913     0.127109       [2.0]  872.780029   0.734060  -0.606952    0
# 51   2023-06-21      [30, 60, 120]   sym_freq_9                 ['NVDA']  2023-06-22            [2.0]   860.429138      [2.0]  873.020020  2023-06-27            [2.0]    837.451050    -2.670538       [2.0]  872.340027  -0.077890  -2.592648    0
# 52   2023-06-21      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-06-22            [9.0]   980.617058      [2.0]  873.020020  2023-06-27            [9.0]    981.061523     0.045325       [2.0]  872.340027  -0.077890   0.123215    1
# 53   2023-06-20      [30, 60, 120]   sym_freq_9                 ['NVDA']  2023-06-21            [2.0]   860.829102      [2.0]  869.880005  2023-06-26            [2.0]    812.573059    -5.605763       [2.0]  862.880005  -0.804709  -4.801055    0
# 54   2023-06-20      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-06-21            [9.0]   980.261444      [2.0]  869.880005  2023-06-26            [9.0]    980.883751     0.063484       [2.0]  862.880005  -0.804709   0.868192    1
# 55   2023-06-16      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-06-20       [1.0, 4.0]   873.676208      [2.0]  874.359985  2023-06-23       [1.0, 4.0]    857.924561    -1.802916       [2.0]  866.419983  -0.908093  -0.894823    0
# 56   2023-06-15      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-06-16       [1.0, 4.0]   862.517151      [2.0]  878.919983  2023-06-22       [1.0, 4.0]    866.044373     0.408945       [2.0]  873.020020  -0.671274   1.080219    1
# 57   2023-06-14      [30, 60, 120]   sym_freq_8  ['AVGO', 'NVDA', 'SHV']  2023-06-15  [0.0, 0.0, 3.0]   326.694580      [2.0]  881.924011  2023-06-21  [0.0, 0.0, 3.0]    326.753815     0.018131       [2.0]  869.880005  -1.365651   1.383783    1
# 58   2023-06-13      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-06-14            [9.0]   979.372513      [2.0]  871.124084  2023-06-20            [9.0]    980.172661     0.081700       [2.0]  874.359985   0.371463  -0.289763    0
# 59   2023-06-12      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-06-13            [9.0]   979.283661      [2.0]  870.087952  2023-06-16            [9.0]    980.172661     0.090781       [2.0]  878.919983   1.015073  -0.924293    0
# 60   2023-06-09      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-06-12       [1.0, 4.0]   829.945648      [2.0]  864.389099  2023-06-15       [1.0, 4.0]    862.087646     3.872784       [2.0]  881.924011   2.028590   1.844193    1
# 61   2023-06-08      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-06-09       [1.0, 4.0]   822.747223      [2.0]  856.617981  2023-06-14       [1.0, 4.0]    865.211243     5.161247       [2.0]  871.124084   1.693416   3.467832    1
# 62   2023-06-07      [30, 60, 120]   sym_freq_8                 ['EXAS']  2023-06-08           [11.0]   997.150017      [2.0]  855.083740  2023-06-13           [11.0]   1029.269997     3.221178       [2.0]  870.087952   1.754707   1.466472    1
# 63   2023-06-07      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-06-08            [9.0]   978.928047      [2.0]  855.083740  2023-06-13            [9.0]    979.283661     0.036327       [2.0]  870.087952   1.754707  -1.718380    0
# 64   2023-06-06      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-06-07       [1.0, 4.0]   809.521667      [2.0]  849.942749  2023-06-12       [1.0, 4.0]    829.945648     2.522969       [2.0]  864.389099   1.699685   0.823284    1
# 65   2023-06-05      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-06-06       [1.0, 4.0]   821.191681      [2.0]  852.891846  2023-06-09       [1.0, 4.0]    822.747223     0.189425       [2.0]  856.617981   0.436883  -0.247458    0
# 66   2023-06-02      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-06-05       [1.0, 4.0]   826.281738      [2.0]  851.038757  2023-06-08       [1.0, 4.0]    820.147430    -0.742399       [2.0]  855.083740   0.475299  -1.217699    0
# 67   2023-06-01      [30, 60, 120]   sym_freq_8         ['META', 'NVDA']  2023-06-02       [1.0, 1.0]   665.806915      [2.0]  852.672668  2023-06-07       [1.0, 1.0]    638.319122    -4.128493       [2.0]  849.942749  -0.320160  -3.808333    0
# 68   2023-05-31      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-06-01            [9.0]   977.861343      [2.0]  840.517822  2023-06-06            [9.0]    978.127899     0.027259       [2.0]  852.891846   1.472190  -1.444931    0
# 69   2023-05-31      [30, 60, 120]   sym_freq_8         ['AVGO', 'NVDA']  2023-06-01       [0.0, 1.0]   397.626129      [2.0]  840.517822  2023-06-06       [0.0, 1.0]    386.468170    -2.806143       [2.0]  852.891846   1.472190  -4.278334    0
# 70   2023-05-30      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-05-31            [9.0]   977.221321      [2.0]  832.607239  2023-06-05            [9.0]    977.950195     0.074586       [2.0]  851.038757   2.213711  -2.139125    0
# 71   2023-05-30      [30, 60, 120]   sym_freq_8         ['AVGO', 'NVDA']  2023-05-31       [0.0, 1.0]   378.269684      [2.0]  832.607239  2023-06-05       [0.0, 1.0]    391.637207     3.533861       [2.0]  851.038757   2.213711   1.320150    1
# 72   2023-05-26      [30, 60, 120]   sym_freq_9          ['AVGO', 'SHV']  2023-05-30       [0.0, 4.0]   434.241852      [2.0]  837.249939  2023-06-02       [0.0, 4.0]    434.644531     0.092732       [2.0]  852.672668   1.842070  -1.749338    0
# 73   2023-05-26      [30, 60, 120]   sym_freq_8                 ['NVDA']  2023-05-30            [2.0]   802.070862      [2.0]  837.249939  2023-06-02            [2.0]    786.393860    -1.954566       [2.0]  852.672668   1.842070  -3.796636    0
# 74   2023-05-26  [15, 30, 60, 120]  sym_freq_12                 ['AVGO']  2023-05-30            [1.0]   799.082886      [2.0]  837.249939  2023-06-02            [1.0]    807.696960     1.077995       [2.0]  852.672668   1.842070  -0.764075    0
# 75   2023-05-25      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-05-26            [9.0]   976.955658      [2.0]  836.931091  2023-06-01            [9.0]    977.861343     0.092705       [2.0]  840.517822   0.428557  -0.335853    0
# 76   2023-05-25      [30, 60, 120]   sym_freq_8         ['FTSM', 'NVDA']  2023-05-26       [8.0, 1.0]   859.075592      [2.0]  836.931091  2023-06-01       [8.0, 1.0]    868.095673     1.049975       [2.0]  840.517822   0.428557   0.621418    1
# 77   2023-05-24      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-05-25            [9.0]   976.778709      [2.0]  826.230896  2023-05-31            [9.0]    977.221321     0.045313       [2.0]  832.607239   0.771739  -0.726425    0
# 78   2023-05-23      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-05-24            [9.0]   976.336166      [2.0]  819.137207  2023-05-30            [9.0]    977.044167     0.072516       [2.0]  837.249939   2.211196  -2.138680    0
# 79   2023-05-22      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-05-23            [9.0]   976.336166      [2.0]  825.115051  2023-05-26            [9.0]    976.955658     0.063451       [2.0]  836.931091   1.432048  -1.368597    0
# 80   2023-05-19      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-05-22            [9.0]   976.159149      [2.0]  834.480286  2023-05-25            [9.0]    976.778709     0.063469       [2.0]  826.230896  -0.988566   1.052035    1
# 81   2023-05-18      [30, 60, 120]   sym_freq_8          ['SHV', 'TMHC']  2023-05-19      [4.0, 11.0]   920.598511      [2.0]  834.141479  2023-05-24      [4.0, 11.0]    904.837200    -1.712072       [2.0]  819.137207  -1.798768   0.086696    1
# 82   2023-05-17      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-05-18            [9.0]   976.159149      [2.0]  835.356995  2023-05-23            [9.0]    976.336166     0.018134       [2.0]  825.115051  -1.226056   1.244190    1
# 83   2023-05-16      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-05-17            [9.0]   975.893623      [2.0]  827.386597  2023-05-22            [9.0]    976.159149     0.027208       [2.0]  834.480286   0.857361  -0.830152    0
# 84   2023-05-15      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-05-16            [9.0]   975.716469      [2.0]  817.463440  2023-05-19            [9.0]    976.159149     0.045370       [2.0]  834.141479   2.040218  -1.994849    0
# 85   2023-05-12      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-05-15            [9.0]   975.716469      [2.0]  822.963013  2023-05-18            [9.0]    976.159149     0.045370       [2.0]  835.356995   1.506019  -1.460650    0
# 86   2023-05-11      [30, 60, 120]   sym_freq_8          ['ISEE', 'SHV']  2023-05-12      [13.0, 4.0]   922.412498      [2.0]  820.133545  2023-05-17      [13.0, 4.0]    914.210487    -0.889191       [2.0]  827.386597   0.884374  -1.773566    0
# 87   2023-05-10      [30, 60, 120]   sym_freq_8          ['ISEE', 'SHV']  2023-05-11      [13.0, 4.0]   919.292526      [2.0]  821.209534  2023-05-16      [13.0, 4.0]    915.301754    -0.434113       [2.0]  817.463440  -0.456168   0.022054    1
# 88   2023-05-09      [30, 60, 120]   sym_freq_8          ['ISEE', 'SHV']  2023-05-10      [13.0, 4.0]   917.055119      [2.0]  822.644226  2023-05-15      [13.0, 4.0]    922.581772     0.602652       [2.0]  822.963013   0.038751   0.563901    1
# 89   2023-05-08      [30, 60, 120]   sym_freq_8          ['ISEE', 'SHV']  2023-05-09      [13.0, 4.0]   918.847740      [2.0]  818.818420  2023-05-12      [13.0, 4.0]    922.412498     0.387960       [2.0]  820.133545   0.160612   0.227347    1
# 90   2023-05-05      [30, 60, 120]   sym_freq_8          ['ISEE', 'SHV']  2023-05-08      [13.0, 4.0]   923.267742      [2.0]  822.424988  2023-05-11      [13.0, 4.0]    919.292526    -0.430559       [2.0]  821.209534  -0.147789  -0.282770    0
# 91   2023-05-04      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-05-05            [9.0]   974.831520      [2.0]  822.205872  2023-05-10            [9.0]    975.273994     0.045390       [2.0]  822.644226   0.053314  -0.007925    0
# 92   2023-05-03      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-05-04            [9.0]   974.919960      [2.0]  807.261353  2023-05-09            [9.0]    974.919960     0.000000       [2.0]  818.818420   1.431639  -1.431639    0
# 93   2023-05-02      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-05-03            [9.0]   974.388840      [2.0]  813.019958  2023-05-08            [9.0]    974.919960     0.054508       [2.0]  822.424988   1.156802  -1.102294    0
# 94   2023-04-26      [30, 60, 120]   sym_freq_8                  ['ELF']  2023-04-27           [10.0]   928.499985      [2.0]  821.767456  2023-05-02           [10.0]    917.399979    -1.195477       [2.0]  818.639099  -0.380686  -0.814791    0
# 95   2023-04-25      [30, 60, 120]   sym_freq_8           ['ELF', 'SHV']  2023-04-26       [5.0, 4.0]   902.044670      [2.0]  805.726990  2023-05-01       [5.0, 4.0]    896.465088    -0.618548       [2.0]  827.944519   2.757451  -3.376000    0
# 96   2023-04-24      [30, 60, 120]   sym_freq_8                  ['ELF']  2023-04-25           [10.0]   923.899994      [2.0]  809.154297  2023-04-28           [10.0]    927.600021     0.400479       [2.0]  828.781372   2.425628  -2.025149    0
# 97   2023-04-21      [30, 60, 120]   sym_freq_8                  ['ELF']  2023-04-24           [10.0]   948.399963      [2.0]  822.205872  2023-04-27           [10.0]    928.499985    -2.098269       [2.0]  821.767456  -0.053322  -2.044947    0
# 98   2023-04-20      [30, 60, 120]   sym_freq_8                  ['ELF']  2023-04-21           [10.0]   966.800003      [2.0]  821.349060  2023-04-26           [10.0]    938.499985    -2.927184       [2.0]  805.726990  -1.902001  -1.025183    0
# 99   2023-04-19      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-04-20            [9.0]   973.258896      [2.0]  820.711426  2023-04-25            [9.0]    973.699860     0.045308       [2.0]  809.154297  -1.408184   1.453492    1
# 100  2023-04-18      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-04-19            [9.0]   972.729767      [2.0]  825.214661  2023-04-24            [9.0]    973.435295     0.072531       [2.0]  822.205872  -0.364607   0.437138    1
# 101  2023-04-17      [30, 60, 120]   sym_freq_8           ['ELF', 'SHV']  2023-04-18       [5.0, 4.0]   895.185165      [2.0]  825.354126  2023-04-21       [5.0, 4.0]    915.998695     2.325053       [2.0]  821.349060  -0.485254   2.810307    1
# 102  2023-04-14      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-04-17            [9.0]   972.465134      [2.0]  824.816162  2023-04-20            [9.0]    973.258896     0.081624       [2.0]  820.711426  -0.497655   0.579278    1
# 103  2023-04-13      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-04-14            [9.0]   972.376968      [2.0]  821.867065  2023-04-19            [9.0]    972.729767     0.036282       [2.0]  825.214661   0.407316  -0.371034    0
# 104  2023-04-12      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-04-13            [9.0]   972.553299      [2.0]  823.879639  2023-04-18            [9.0]    972.641602     0.009079       [2.0]  825.354126   0.178969  -0.169889    0
# 105  2023-04-11      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-04-12            [9.0]   972.024239      [2.0]  813.079712  2023-04-17            [9.0]    972.465134     0.045358       [2.0]  824.816162   1.443456  -1.398098    0
# 106  2023-04-10      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-04-11            [9.0]   971.936073      [2.0]  816.407349  2023-04-14            [9.0]    972.376968     0.045363       [2.0]  821.867065   0.668749  -0.623387    0
# 107  2023-04-06      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-04-10            [9.0]   971.759743      [2.0]  816.188171  2023-04-13            [9.0]    972.553299     0.081662       [2.0]  823.879639   0.942364  -0.860703    0
# 108  2023-04-05      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-04-06            [9.0]   971.847771      [2.0]  815.351318  2023-04-12            [9.0]    972.024239     0.018158       [2.0]  813.079712  -0.278605   0.296763    1
# 109  2023-04-04      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-04-05       [1.0, 4.0]   700.692383      [2.0]  812.183105  2023-04-11       [1.0, 4.0]    703.611115     0.416550       [2.0]  816.407349   0.520110  -0.103560    0
# 110  2023-04-03      [30, 60, 120]   sym_freq_8           ['GE', 'NVDA']  2023-04-04       [5.0, 1.0]   749.377808      [2.0]  814.315186  2023-04-10       [5.0, 1.0]    747.190147    -0.291930       [2.0]  816.188171   0.230007  -0.521938    0
# 111  2023-03-31      [30, 60, 120]   sym_freq_8                 ['NVDA']  2023-04-03            [3.0]   838.794067      [2.0]  818.858276  2023-04-06            [3.0]    810.959198    -3.318439       [2.0]  815.351318  -0.428274  -2.890165    0
# 112  2023-03-30      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-03-31            [9.0]   971.045219      [2.0]  815.749817  2023-04-05            [9.0]    971.847771     0.082648       [2.0]  812.183105  -0.437231   0.519879    1
# 113  2023-03-30      [30, 60, 120]   sym_freq_8                 ['NVDA']  2023-03-31            [3.0]   833.155060      [2.0]  815.749817  2023-04-05            [3.0]    806.280121    -3.225683       [2.0]  812.183105  -0.437231  -2.788452    0
# 114  2023-03-29      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-03-30            [9.0]   970.957466      [2.0]  804.411926  2023-04-04            [9.0]    971.318779     0.037212       [2.0]  814.315186   1.231118  -1.193906    0
# 115  2023-03-28      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-03-29            [9.0]   970.781548      [2.0]  799.729309  2023-04-03            [9.0]    970.965843     0.018984       [2.0]  818.858276   2.391930  -2.372946    0
# 116  2023-03-27      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-03-28            [9.0]   970.693794      [2.0]  788.271912  2023-03-31            [9.0]    971.045219     0.036204       [2.0]  815.749817   3.485841  -3.449637    0
# 117  2023-03-27      [30, 60, 120]   sym_freq_8                   ['GE']  2023-03-28           [10.0]   930.711746      [2.0]  788.271912  2023-03-31           [10.0]    955.293579     2.641186       [2.0]  815.749817   3.485841  -0.844654    0
# 118  2023-03-24      [30, 60, 120]   sym_freq_8          ['NVDA', 'SHV']  2023-03-27       [1.0, 4.0]   696.641083      [2.0]  790.045288  2023-03-30       [1.0, 4.0]    705.315765     1.245215       [2.0]  804.411926   1.818458  -0.573242    0
# 119  2023-03-23      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-03-24            [9.0]   970.605904      [2.0]  788.570801  2023-03-29            [9.0]    970.781548     0.018096       [2.0]  799.729309   1.415029  -1.396933    0
# 120  2023-03-22      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-03-23            [9.0]   970.518013      [2.0]  783.429871  2023-03-28            [9.0]    970.693794     0.018112       [2.0]  788.271912   0.618057  -0.599945    0
# 121  2023-03-22      [30, 60, 120]   sym_freq_8                 ['FTSM']  2023-03-23           [17.0]   991.377739      [2.0]  783.429871  2023-03-28           [17.0]    991.045383    -0.033525       [2.0]  788.271912   0.618057  -0.651581    0
# 122  2023-03-21      [30, 60, 120]   sym_freq_9                  ['SHV']  2023-03-22            [9.0]   969.902916      [2.0]  781.317688  2023-03-27            [9.0]    970.605904     0.072480       [2.0]  790.045288   1.117036  -1.044556    0
# 123  2023-03-21      [30, 60, 120]   sym_freq_8                   ['GE']  2023-03-22           [11.0]   984.761757      [2.0]  781.317688  2023-03-27           [11.0]   1025.651558     4.152253       [2.0]  790.045288   1.117036   3.035217    1
# 124  2023-03-20      [30, 60, 120]   sym_freq_9          ['FTSM', 'SHV']  2023-03-21       [8.0, 4.0]   896.895111      [2.0]  794.867371  2023-03-24       [8.0, 4.0]    898.145630     0.139428       [2.0]  788.570801  -0.792154   0.931581    1
# 125  2023-03-17      [30, 60, 120]   sym_freq_9          ['FTSM', 'SHV']  2023-03-20       [8.0, 4.0]   897.481384      [2.0]  784.565613  2023-03-23       [8.0, 4.0]    897.872040     0.043528       [2.0]  783.429871  -0.144761   0.188289    1
# 126  2023-03-17      [30, 60, 120]   sym_freq_8                   ['GE']  2023-03-20           [11.0]   988.389091      [2.0]  784.565613  2023-03-23           [11.0]   1006.745476     1.857202       [2.0]  783.429871  -0.144761   2.001963    1
# 127  2023-03-16      [30, 60, 120]   sym_freq_9          ['FTSM', 'SHV']  2023-03-17       [8.0, 4.0]   896.855835      [2.0]  777.093384  2023-03-22       [8.0, 4.0]    897.520447     0.074105       [2.0]  781.317688   0.543603  -0.469499    0
# 128  2023-03-15      [30, 60, 120]   sym_freq_9          ['FTSM', 'SHV']  2023-03-16       [8.0, 4.0]   896.621613      [2.0]  786.287231  2023-03-21       [8.0, 4.0]    896.895111     0.030503       [2.0]  794.867371   1.091222  -1.060719    0

# %%
df_model_picks = pickle_load(path_data_dump, 'df_model_picks')
print(f'df_model_picks, len({len(df_model_picks)}):\n{df_model_picks}')
# Out:
# df_model_picks, len(4):
#          date  days_lookback   syms_freq           symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0  2023-09-08  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 1  2023-09-08  [30, 60, 120]  sym_freq_8  ['DELL', 'STRL']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 2  2023-09-05  [30, 60, 120]  sym_freq_9           ['SHV']  2023-09-06        [9.0]   990.809967      [2.0]  892.440002      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 3  2023-09-05  [30, 60, 120]  sym_freq_8          ['FTSM']  2023-09-06       [16.0]   951.840027      [2.0]  892.440002      None          None           NaN          NaN        None         NaN        NaN        NaN    0
