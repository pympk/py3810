# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump, delete_all_rows
from yf_utils import split_train_val_test, random_slices, lookback_slices
from yf_utils import top_set_sym_freq_cnt, get_grp_top_syms_n_freq
from yf_utils import eval_grp_top_syms_n_freq


pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.width", 500)  # code-runner format

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"

path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = "df_close_clean"

# %% [markdown]
# ### Run below cell for Colab

# %%
#######################################################################
## SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# select run type
run_type = "train"
# run_type = 'validate'
# run_type = "test"

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms
# n_samples = 400
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
# days_lookbacks = [15, 30, 60]
# days_lookbacks = [30, 60, 120]
days_lookbacks = [15, 30, 60, 120]
days_lookbacks.sort()

# number of days in dataframe to evaluate effectiveness of the training, days_eval = len(df_eval)
#  days_eval = 4 means buy at close on 1st day after the signal, hold for 2nd and 3rd day, sell at close on 4th day
days_eval = 4
# days_eval = 5

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20
# n_top_syms = 5

# slice starts and ends for selecting the best performing symbols
syms_start = 0
syms_end = 10


##########################################################
# fp_df_eval_results = f"df_eval_results_{run_type}"
fp_df_eval_results = "test_df_eval"
##########################################################

#### Delete all rows in df_eval_results ##################
delete_all_rows(path_data_dump, fp_df_eval_results)
##########################################################

# %%
path_data_dump
# Out:
# 'C:/Users/ping/MyDrive/stocks/yfinance/VSCode_dump/'

# %%
print(f"verbose : {verbose }")
print(f"store_results: {store_results}")
print(f"run_type: {run_type}")
print(f"n_samples: {n_samples}")
print(f"days_lookbacks: {days_lookbacks}")
print(f"days_eval: {days_eval}")
print(f"n_top_syms: {n_top_syms}")
print(f"syms_start: {syms_start}")
print(f"syms_end: {syms_end}")
print(f"fp_df_eval_results: {fp_df_eval_results}")

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = split_train_val_test(df_close_clean)
# Out:
# verbose : True
# store_results: True
# run_type: train
# n_samples: 2
# days_lookbacks: [15, 30, 60, 120]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10
# fp_df_eval_results: test_df_eval

# %%
# max_days_lookbacks = max(days_lookbacks)
# print(f"max_days_lookbacks: {max_days_lookbacks}")

# Load df according to run_type
if run_type == "train":
    df = df_train.copy()
elif run_type == "validate":
    df = df_val.copy()
elif run_type == "test":
    df = df_test.copy()
else:
    msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop)

# Print dataframe for the run, and lengths of other dataframes
print(f"run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n")
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f"run_type: {run_type}, len(df): {len(df)}")
print(
    f"len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}"
)

# return n_samples slices
max_lookback_slices = random_slices(
    len_df,
    n_samples=n_samples,
    days_lookback=max(days_lookbacks),
    days_eval=days_eval,
    verbose=False,
)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = lookback_slices(
    max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False
)
# Out:
# run_type: train, df.tail(3):
#                      A         AA        AAL         AAP        AAPL         AB        ABB        ABBV         ABC        ABM        ABR         ABT       ACGL       ACHC       ACIW  ...        XRX         XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA          ZD          ZG       ZION        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                                   ...
# 2021-07-06  147.387589  36.058010  21.010000  197.164200  140.569183  41.311390  32.729343  106.834770  112.808167  42.026814  15.067636  114.871323  38.799999  62.580002  37.310001  ...  21.389660  118.042938  39.580002  112.666039  65.499908  56.030933  155.889175  544.349976  122.278259  120.370003  49.311123  28.451982  191.272812  49.270000  49.729626
# 2021-07-07  147.892136  35.820732  20.309999  197.863297  143.093140  40.027229  33.240738  107.776360  112.436760  41.542629  14.982608  115.886429  39.020000  63.369999  37.580002  ...  21.750668  118.248718  38.279999  114.187622  65.509743  54.880238  154.280304  546.650024  123.982613  119.040001  48.920223  28.031702  194.604935  47.599998  50.391369
# 2021-07-08  147.239197  34.960560  20.350000  196.039978  141.776718  39.206070  33.307030  107.407112  111.850349  41.223064  14.838054  115.296707  37.619999  62.360001  36.730000  ...  21.497965  116.798424  38.000000  113.703041  64.329208  52.823471  152.518188  539.840027  123.452171  114.580002  47.518684  27.718935  194.171158  47.230000  49.502457
#
# [3 rows x 1310 columns]
#
# run_type: train, len(df): 1050
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %% [markdown]
# ### Run below cell to use test data to debug code, results should match yf_test.ipynb

# %%
# ####### RUN THIS CELL TO USE TEST DATA TO DEBUG CODE, RESULTS SHOULD MATCH yf_test.ipynb ################# 

# # load test data to debug code if needed
# test_dic = pickle_load(path_data_dump, 'yf_test_dic')
# for i, key in enumerate(test_dic.keys()):
#   print(f'{i}: {key}')

# # convert dictionary entries into variables
# locals().update(test_dic)
# del df_eval_results  # delete df_eval_results loaded from locals().update(test_dic)

# # Delete all rows in df_eval_results
# delete_all_rows(path_data_dump, fp_df_eval_results)

# %%
max_days_lookbacks = max(days_lookbacks)
print(f"max_days_lookbacks: {max_days_lookbacks}")

if verbose:
    print(f"number of max_lookback_slices is equal to n_samples = {n_samples}")
    print(f"max_lookback_slices:\n{max_lookback_slices}\n")
    print(f"number of sets in sets_lookback_slices is equal to n_samples = {n_samples}")
    print(f"sets_lookback_slices:\n{sets_lookback_slices}\n")
    print(f"days_lookbacks: {days_lookbacks}")
    print(
        f'number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): {len(days_lookbacks)}'
    )

# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the max_lookback_slices. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in max_lookback_slices. There are as many sub-lists as there are tuples in max_lookback_slices.
grp_top_set_syms_n_freq, grp_top_set_syms, dates_end_df_train = get_grp_top_syms_n_freq(
    df, sets_lookback_slices, days_lookbacks, n_top_syms, syms_start, syms_end, verbose
)

# #### print the best performing symbols for each set in sets_lookback_slices
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
    l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
    if verbose:
        print(f"max_lookback_slices:             {max_lookback_slices}")
        # print(f'set_lookback_slices: {sets_lookback_slices[i]}\n')
        print(
            f"set_lookback_slices {i + 1} of {len(sets_lookback_slices):>3}:    {sets_lookback_slices[i]}\n"
        )
        print(f"max_days_lookbacks:              {max_days_lookbacks}")
        print(f"df end date for days_lookbacks:  {dates_end_df_train[i]}")
        print(f"days_lookbacks:                  {days_lookbacks}")
        print(f"sym_freq_15:                     {l_sym_freq_cnt[0]}")
        print(f"sym_freq_14:                     {l_sym_freq_cnt[1]}")
        print(f"sym_freq_13:                     {l_sym_freq_cnt[2]}")
        print(f"sym_freq_12:                     {l_sym_freq_cnt[3]}")
        print(f"sym_freq_11:                     {l_sym_freq_cnt[4]}")
        print(f"sym_freq_10:                     {l_sym_freq_cnt[5]}")
        print(f"sym_freq_9:                      {l_sym_freq_cnt[6]}")
        print(f"sym_freq_8:                      {l_sym_freq_cnt[7]}")
        print(f"sym_freq_7:                      {l_sym_freq_cnt[8]}")
        print(f"sym_freq_6:                      {l_sym_freq_cnt[9]}")
        print(f"sym_freq_5:                      {l_sym_freq_cnt[10]}")
        print(f"sym_freq_4:                      {l_sym_freq_cnt[11]}")
        print(f"sym_freq_3:                      {l_sym_freq_cnt[12]}")
        print(f"sym_freq_2:                      {l_sym_freq_cnt[13]}\n")


# #### Evaluate performance of symbols in set_lookback_slices versus SPY
l_row_add_total = eval_grp_top_syms_n_freq(
    df, max_lookback_slices, sets_lookback_slices, grp_top_set_syms_n_freq, days_lookbacks, days_eval, n_samples, n_top_syms, syms_start, syms_end, verbose
)

for row_add_total in l_row_add_total:
    print(f"row_add_total: {row_add_total}")

if store_results:  # record results to df
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results BEFORW store results:\n{df_eval_results}\n")

    for row_add_total in l_row_add_total:
        # print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f"appended row_add_total to df_eval_results:\n{row_add_total}\n")

    pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
    print(f"Save results to: {fp_df_eval_results}")
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results AFTER store results:\n{df_eval_results}\n")
# Out:
# max_days_lookbacks: 120
# number of max_lookback_slices is equal to n_samples = 2
# max_lookback_slices:
# [(805, 925, 929), (325, 445, 449)]
#
# number of sets in sets_lookback_slices is equal to n_samples = 2
# sets_lookback_slices:
# [[(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)], [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]]
#
# days_lookbacks: [15, 30, 60, 120]
# number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): 4
#
# ########## 1 of 2 lb_slices: [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)] in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)]
# lb_slice:            (910, 925, 929)
# days eval:           4
# iloc_start_train:    910
# iloc_end_train:      925
# date_start_df_train: 2020-12-16
# date_end_df_train:   2021-01-07
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['MARA', 'BTC-USD', 'GBTC', 'IPI', 'PLUG', 'RUN', 'ALB', 'ROCK',
#        'ORA', 'SM', 'CELH', 'GPRE', 'BEP', 'VCEL', 'VSTO', 'SSYS', 'NTLA',
#        'MYGN', 'FCX', 'NOAH'], dtype=object), 'r_CAGR/retnStd': array(['MARA', 'BTC-USD', 'GBTC', 'PLUG', 'IPI', 'RUN', 'SM', 'NTLA',
#        'CELH', 'ORA', 'VSTO', 'SSYS', 'GPRE', 'ALB', 'DQ', 'MYGN', 'ROCK',
#        'CSIQ', 'TSLA', 'VCEL'], dtype=object), 'r_retnStd/UI': array(['AJRD', 'BCPC', 'BTC-USD', 'BEP', 'SCHW', 'ROCK', 'MOH', 'IPI',
#        'GVA', 'ON', 'VCEL', 'ETN', 'LPLA', 'AMPH', 'ZION', 'NOAH', 'MS',
#        'APTV', 'HBAN', 'TSM'], dtype=object)}}
# most_freq_syms: [('BTC-USD', 3), ('IPI', 3), ('ROCK', 3), ('VCEL', 3), ('MARA', 2), ('GBTC', 2), ('PLUG', 2), ('RUN', 2), ('ALB', 2), ('ORA', 2), ('SM', 2), ('CELH', 2), ('GPRE', 2), ('BEP', 2), ('VSTO', 2), ('SSYS', 2), ('NTLA', 2), ('MYGN', 2), ('NOAH', 2), ('FCX', 1), ('DQ', 1), ('CSIQ', 1), ('TSLA', 1), ('AJRD', 1), ('BCPC', 1), ('SCHW', 1), ('MOH', 1), ('GVA', 1), ('ON', 1), ('ETN', 1), ('LPLA', 1), ('AMPH', 1), ('ZION', 1), ('MS', 1), ('APTV', 1), ('HBAN', 1), ('TSM', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)]
# lb_slice:            (895, 925, 929)
# days eval:           4
# iloc_start_train:    895
# iloc_end_train:      925
# date_start_df_train: 2020-11-24
# date_end_df_train:   2021-01-07
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['MARA', 'NTLA', 'BTC-USD', 'FATE', 'RCKT', 'CELH', 'GBTC', 'SSYS',
#        'IPI', 'PERI', 'CTRN', 'ACRS', 'CRSP', 'DQ', 'CLF', 'BIDU', 'PLUG',
#        'SM', 'VCEL', 'RAMP'], dtype=object), 'r_CAGR/retnStd': array(['MARA', 'NTLA', 'BTC-USD', 'FATE', 'GBTC', 'ACRS', 'PERI', 'DQ',
#        'SSYS', 'CELH', 'SM', 'CRSP', 'IPI', 'RCKT', 'CTRN', 'PLUG', 'CLF',
#        'BCRX', 'ENPH', 'BIDU'], dtype=object), 'r_retnStd/UI': array(['RCKT', 'AJRD', 'BCPC', 'MT', 'PNC', 'CTRN', 'BIDU', 'IPI', 'IAC',
#        'NATI', 'RAMP', 'PTC', 'VCEL', 'DAR', 'SWBI', 'SCHW', 'GPK',
#        'CELH', 'DIS', 'APTV'], dtype=object)}}
# most_freq_syms: [('RCKT', 3), ('CELH', 3), ('IPI', 3), ('CTRN', 3), ('BIDU', 3), ('MARA', 2), ('NTLA', 2), ('BTC-USD', 2), ('FATE', 2), ('GBTC', 2), ('SSYS', 2), ('PERI', 2), ('ACRS', 2), ('CRSP', 2), ('DQ', 2), ('CLF', 2), ('PLUG', 2), ('SM', 2), ('VCEL', 2), ('RAMP', 2), ('BCRX', 1), ('ENPH', 1), ('AJRD', 1), ('BCPC', 1), ('MT', 1), ('PNC', 1), ('IAC', 1), ('NATI', 1), ('PTC', 1), ('DAR', 1), ('SWBI', 1), ('SCHW', 1), ('GPK', 1), ('DIS', 1), ('APTV', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)]
# lb_slice:            (865, 925, 929)
# days eval:           4
# iloc_start_train:    865
# iloc_end_train:      925
# date_start_df_train: 2020-10-13
# date_end_df_train:   2021-01-07
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['CHRD', 'MARA', 'SM', 'BTC-USD', 'GBTC', 'NTLA', 'CPE', 'CLF',
#        'CPRI', 'PLUG', 'CELH', 'IPI', 'FATE', 'CTRN', 'JWN', 'ALB',
#        'TCBI', 'X', 'TPR', 'COHR'], dtype=object), 'r_CAGR/retnStd': array(['CHRD', 'MARA', 'SM', 'BTC-USD', 'GBTC', 'NTLA', 'CPE', 'CLF',
#        'PLUG', 'IPI', 'JWN', 'CPRI', 'X', 'CELH', 'PTEN', 'CTRN', 'FATE',
#        'ALB', 'TPR', 'MT'], dtype=object), 'r_retnStd/UI': array(['CHRD', 'RCKT', 'TCBI', 'BTC-USD', 'WAL', 'COHR', 'OMCL', 'AIR',
#        'RLJ', 'FHB', 'MEOH', 'ALB', 'SCHW', 'FATE', 'PNFP', 'CPRI',
#        'APTV', 'CTRN', 'FBP', 'C'], dtype=object)}}
# most_freq_syms: [('CHRD', 3), ('BTC-USD', 3), ('CPRI', 3), ('FATE', 3), ('CTRN', 3), ('ALB', 3), ('MARA', 2), ('SM', 2), ('GBTC', 2), ('NTLA', 2), ('CPE', 2), ('CLF', 2), ('PLUG', 2), ('CELH', 2), ('IPI', 2), ('JWN', 2), ('TCBI', 2), ('X', 2), ('TPR', 2), ('COHR', 2), ('PTEN', 1), ('MT', 1), ('RCKT', 1), ('WAL', 1), ('OMCL', 1), ('AIR', 1), ('RLJ', 1), ('FHB', 1), ('MEOH', 1), ('SCHW', 1), ('PNFP', 1), ('APTV', 1), ('FBP', 1), ('C', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)]
# lb_slice:            (805, 925, 929)
# days eval:           4
# iloc_start_train:    805
# iloc_end_train:      925
# date_start_df_train: 2020-07-20
# date_end_df_train:   2021-01-07
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['CHRD', 'MARA', 'PLUG', 'CTRN', 'SPWR', 'BTC-USD', 'LOB', 'FATE',
#        'GBTC', 'DAR', 'GME', 'CLF', 'ENPH', 'MEOH', 'APPS', 'DBRG',
#        'NTLA', 'TPR', 'BYD', 'TX'], dtype=object), 'r_CAGR/retnStd': array(['MARA', 'PLUG', 'BTC-USD', 'GBTC', 'SPWR', 'CTRN', 'LOB', 'GME',
#        'CELH', 'APPS', 'ENPH', 'CHRD', 'CLF', 'NTLA', 'TPR', 'DQ', 'DBRG',
#        'SIG', 'CPRI', 'FATE'], dtype=object), 'r_retnStd/UI': array(['CHRD', 'BBWI', 'FATE', 'DAR', 'QNST', 'SCHW', 'MEOH', 'CTRN',
#        'GIL', 'RCKT', 'SLM', 'AES', 'ALGN', 'CROX', 'RHP', 'XYL', 'SNV',
#        'BFAM', 'BYD', 'LOB'], dtype=object)}}
# most_freq_syms: [('CHRD', 3), ('CTRN', 3), ('LOB', 3), ('FATE', 3), ('MARA', 2), ('PLUG', 2), ('SPWR', 2), ('BTC-USD', 2), ('GBTC', 2), ('DAR', 2), ('GME', 2), ('CLF', 2), ('ENPH', 2), ('MEOH', 2), ('APPS', 2), ('DBRG', 2), ('NTLA', 2), ('TPR', 2), ('BYD', 2), ('TX', 1), ('CELH', 1), ('DQ', 1), ('SIG', 1), ('CPRI', 1), ('BBWI', 1), ('QNST', 1), ('SCHW', 1), ('GIL', 1), ('RCKT', 1), ('SLM', 1), ('AES', 1), ('ALGN', 1), ('CROX', 1), ('RHP', 1), ('XYL', 1), ('SNV', 1), ('BFAM', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('BTC-USD', 3), ('IPI', 3), ('ROCK', 3), ('VCEL', 3), ('MARA', 2), ('GBTC', 2), ('PLUG', 2), ('RUN', 2), ('ALB', 2), ('ORA', 2), ('SM', 2), ('CELH', 2), ('GPRE', 2), ('BEP', 2), ('VSTO', 2), ('SSYS', 2), ('NTLA', 2), ('MYGN', 2), ('NOAH', 2), ('FCX', 1), ('DQ', 1), ('CSIQ', 1), ('TSLA', 1), ('AJRD', 1), ('BCPC', 1), ('SCHW', 1), ('MOH', 1), ('GVA', 1), ('ON', 1), ('ETN', 1), ('LPLA', 1), ('AMPH', 1), ('ZION', 1), ('MS', 1), ('APTV', 1), ('HBAN', 1), ('TSM', 1)], [('RCKT', 3), ('CELH', 3), ('IPI', 3), ('CTRN', 3), ('BIDU', 3), ('MARA', 2), ('NTLA', 2), ('BTC-USD', 2), ('FATE', 2), ('GBTC', 2), ('SSYS', 2), ('PERI', 2), ('ACRS', 2), ('CRSP', 2), ('DQ', 2), ('CLF', 2), ('PLUG', 2), ('SM', 2), ('VCEL', 2), ('RAMP', 2), ('BCRX', 1), ('ENPH', 1), ('AJRD', 1), ('BCPC', 1), ('MT', 1), ('PNC', 1), ('IAC', 1), ('NATI', 1), ('PTC', 1), ('DAR', 1), ('SWBI', 1), ('SCHW', 1), ('GPK', 1), ('DIS', 1), ('APTV', 1)], [('CHRD', 3), ('BTC-USD', 3), ('CPRI', 3), ('FATE', 3), ('CTRN', 3), ('ALB', 3), ('MARA', 2), ('SM', 2), ('GBTC', 2), ('NTLA', 2), ('CPE', 2), ('CLF', 2), ('PLUG', 2), ('CELH', 2), ('IPI', 2), ('JWN', 2), ('TCBI', 2), ('X', 2), ('TPR', 2), ('COHR', 2), ('PTEN', 1), ('MT', 1), ('RCKT', 1), ('WAL', 1), ('OMCL', 1), ('AIR', 1), ('RLJ', 1), ('FHB', 1), ('MEOH', 1), ('SCHW', 1), ('PNFP', 1), ('APTV', 1), ('FBP', 1), ('C', 1)], [('CHRD', 3), ('CTRN', 3), ('LOB', 3), ('FATE', 3), ('MARA', 2), ('PLUG', 2), ('SPWR', 2), ('BTC-USD', 2), ('GBTC', 2), ('DAR', 2), ('GME', 2), ('CLF', 2), ('ENPH', 2), ('MEOH', 2), ('APPS', 2), ('DBRG', 2), ('NTLA', 2), ('TPR', 2), ('BYD', 2), ('TX', 1), ('CELH', 1), ('DQ', 1), ('SIG', 1), ('CPRI', 1), ('BBWI', 1), ('QNST', 1), ('SCHW', 1), ('GIL', 1), ('RCKT', 1), ('SLM', 1), ('AES', 1), ('ALGN', 1), ('CROX', 1), ('RHP', 1), ('XYL', 1), ('SNV', 1), ('BFAM', 1)]]
# **** finish lookback slices [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)] ****
#
# top 20 ranked symbols and frequency from set [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)]:
# [('BTC-USD', 10), ('CTRN', 9), ('CELH', 8), ('FATE', 8), ('GBTC', 8), ('IPI', 8), ('MARA', 8), ('NTLA', 8), ('PLUG', 8), ('CHRD', 6), ('CLF', 6), ('SM', 6), ('ALB', 5), ('RCKT', 5), ('VCEL', 5), ('CPRI', 4), ('DQ', 4), ('SCHW', 4), ('SSYS', 4), ('TPR', 4)]
# top 20 ranked symbols from set [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)]:
# ['BTC-USD', 'CTRN', 'CELH', 'FATE', 'GBTC', 'IPI', 'MARA', 'NTLA', 'PLUG', 'CHRD']
# ===== finish top 20 ranked symbols from days_lookback set [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)] =====
#
#
#
# ########## 2 of 2 lb_slices: [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)] in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]
# lb_slice:            (430, 445, 449)
# days eval:           4
# iloc_start_train:    430
# iloc_end_train:      445
# date_start_df_train: 2019-01-23
# date_end_df_train:   2019-02-12
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['PCG', 'RUN', 'ALLE', 'AGYS', 'MRCY', 'COTY', 'VECO', 'AVXL',
#        'MAT', 'UCTT', 'LRCX', 'OLED', 'IRBT', 'XRX', 'NYT', 'PGR', 'PCTY',
#        'MAS', 'CLF', 'BWXT'], dtype=object), 'r_CAGR/retnStd': array(['PCG', 'COTY', 'AVXL', 'UCTT', 'VECO', 'MAT', 'IRBT', 'AGYS',
#        'SSYS', 'KDNY', 'APPS', 'ARWR', 'MRCY', 'W', 'CLF', 'ON', 'RUN',
#        'PCTY', 'AMKR', 'OLED'], dtype=object), 'r_retnStd/UI': array(['RUN', 'ALLE', 'PGR', 'ALL', 'MRCY', 'MAS', 'BWXT', 'AGYS', 'LRCX',
#        'RNR', 'CTLT', 'COLM', 'LADR', 'OLED', 'MSI', 'IIM', 'COMM', 'CDW',
#        'ACGL', 'SKX'], dtype=object)}}
# most_freq_syms: [('RUN', 3), ('AGYS', 3), ('MRCY', 3), ('OLED', 3), ('PCG', 2), ('ALLE', 2), ('COTY', 2), ('VECO', 2), ('AVXL', 2), ('MAT', 2), ('UCTT', 2), ('LRCX', 2), ('IRBT', 2), ('PGR', 2), ('PCTY', 2), ('MAS', 2), ('CLF', 2), ('BWXT', 2), ('XRX', 1), ('NYT', 1), ('SSYS', 1), ('KDNY', 1), ('APPS', 1), ('ARWR', 1), ('W', 1), ('ON', 1), ('AMKR', 1), ('ALL', 1), ('RNR', 1), ('CTLT', 1), ('COLM', 1), ('LADR', 1), ('MSI', 1), ('IIM', 1), ('COMM', 1), ('CDW', 1), ('ACGL', 1), ('SKX', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]
# lb_slice:            (415, 445, 449)
# days eval:           4
# iloc_start_train:    415
# iloc_end_train:      445
# date_start_df_train: 2018-12-31
# date_end_df_train:   2019-02-12
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['AXSM', 'XRX', 'ENPH', 'BOOT', 'MAT', 'SSYS', 'VECO', 'NVCR',
#        'HBI', 'CCRN', 'NYCB', 'COTY', 'SYF', 'HRI', 'PPC', 'CLF', 'CCK',
#        'PCTY', 'NYT', 'GLPI'], dtype=object), 'r_CAGR/retnStd': array(['AXSM', 'ENPH', 'XRX', 'HRI', 'APPS', 'BOOT', 'NVCR', 'MAT',
#        'SSYS', 'VECO', 'AVXL', 'COTY', 'EVRI', 'CSIQ', 'NSTG', 'CCRN',
#        'UCTT', 'CLF', 'PAYC', 'CCS'], dtype=object), 'r_retnStd/UI': array(['SYF', 'XRX', 'NYCB', 'AXSM', 'IIM', 'IBM', 'GLPI', 'HBI', 'PPC',
#        'FCF', 'FDUS', 'SANM', 'CPF', 'UE', 'CCK', 'CSGS', 'NMZ', 'CNO',
#        'RDN', 'SHV'], dtype=object)}}
# most_freq_syms: [('AXSM', 3), ('XRX', 3), ('ENPH', 2), ('BOOT', 2), ('MAT', 2), ('SSYS', 2), ('VECO', 2), ('NVCR', 2), ('HBI', 2), ('CCRN', 2), ('NYCB', 2), ('COTY', 2), ('SYF', 2), ('HRI', 2), ('PPC', 2), ('CLF', 2), ('CCK', 2), ('GLPI', 2), ('PCTY', 1), ('NYT', 1), ('APPS', 1), ('AVXL', 1), ('EVRI', 1), ('CSIQ', 1), ('NSTG', 1), ('UCTT', 1), ('PAYC', 1), ('CCS', 1), ('IIM', 1), ('IBM', 1), ('FCF', 1), ('FDUS', 1), ('SANM', 1), ('CPF', 1), ('UE', 1), ('CSGS', 1), ('NMZ', 1), ('CNO', 1), ('RDN', 1), ('SHV', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]
# lb_slice:            (385, 445, 449)
# days eval:           4
# iloc_start_train:    385
# iloc_end_train:      445
# date_start_df_train: 2018-11-14
# date_end_df_train:   2019-02-12
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['AXSM', 'SHV', 'NVCR', 'PAR', 'APPS', 'MTCH', 'OR', 'LRN', 'LSCC',
#        'CHGG', 'AU', 'BNDX', 'QURE', 'LQD', 'WPM', 'KEYS', 'TEAM', 'GLD',
#        'LGIH', 'SBS'], dtype=object), 'r_CAGR/retnStd': array(['AXSM', 'NVCR', 'APPS', 'SHV', 'PAR', 'CSIQ', 'QURE', 'MTCH', 'AU',
#        'CHGG', 'DQ', 'TEAM', 'OR', 'LGIH', 'KEYS', 'LSCC', 'LRN', 'WDAY',
#        'PAYC', 'EBAY'], dtype=object), 'r_retnStd/UI': array(['SHV', 'AXSM', 'RCII', 'GLD', 'WPM', 'LQD', 'BNDX', 'LRN', 'RGLD',
#        'AMX', 'BKT', 'LSCC', 'ASA', 'MTCH', 'PAR', 'NLY', 'OR', 'PKE',
#        'CVLT', 'OSIS'], dtype=object)}}
# most_freq_syms: [('AXSM', 3), ('SHV', 3), ('PAR', 3), ('MTCH', 3), ('OR', 3), ('LRN', 3), ('LSCC', 3), ('NVCR', 2), ('APPS', 2), ('CHGG', 2), ('AU', 2), ('BNDX', 2), ('QURE', 2), ('LQD', 2), ('WPM', 2), ('KEYS', 2), ('TEAM', 2), ('GLD', 2), ('LGIH', 2), ('SBS', 1), ('CSIQ', 1), ('DQ', 1), ('WDAY', 1), ('PAYC', 1), ('EBAY', 1), ('RCII', 1), ('RGLD', 1), ('AMX', 1), ('BKT', 1), ('ASA', 1), ('NLY', 1), ('PKE', 1), ('CVLT', 1), ('OSIS', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]
# lb_slice:            (325, 445, 449)
# days eval:           4
# iloc_start_train:    325
# iloc_end_train:      445
# date_start_df_train: 2018-08-21
# date_end_df_train:   2019-02-12
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['SHV', 'AXSM', 'LRN', 'FTSM', 'AU', 'SBS', 'APPS', 'SSRM', 'CSIQ',
#        'GLD', 'CIEN', 'SBUX', 'MPW', 'O', 'RCII', 'BALL', 'EXAS', 'GKOS',
#        'PBR', 'AVGO'], dtype=object), 'r_CAGR/retnStd': array(['SHV', 'AXSM', 'AU', 'LRN', 'FTSM', 'APPS', 'SBS', 'SSRM', 'CSIQ',
#        'BALL', 'PBR', 'EXAS', 'BNDX', 'SBUX', 'GKOS', 'CIEN', 'NSTG',
#        'NVAX', 'KDP', 'O'], dtype=object), 'r_retnStd/UI': array(['SHV', 'FTSM', 'AXSM', 'LRN', 'RCII', 'GLD', 'AU', 'SBS', 'SSRM',
#        'VCEL', 'TDS', 'MPW', 'VIRT', 'O', 'TWLO', 'RGLD', 'NEM', 'YUM',
#        'CIEN', 'OMC'], dtype=object)}}
# most_freq_syms: [('SHV', 3), ('AXSM', 3), ('LRN', 3), ('FTSM', 3), ('AU', 3), ('SBS', 3), ('SSRM', 3), ('CIEN', 3), ('O', 3), ('APPS', 2), ('CSIQ', 2), ('GLD', 2), ('SBUX', 2), ('MPW', 2), ('RCII', 2), ('BALL', 2), ('EXAS', 2), ('GKOS', 2), ('PBR', 2), ('AVGO', 1), ('BNDX', 1), ('NSTG', 1), ('NVAX', 1), ('KDP', 1), ('VCEL', 1), ('TDS', 1), ('VIRT', 1), ('TWLO', 1), ('RGLD', 1), ('NEM', 1), ('YUM', 1), ('OMC', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('RUN', 3), ('AGYS', 3), ('MRCY', 3), ('OLED', 3), ('PCG', 2), ('ALLE', 2), ('COTY', 2), ('VECO', 2), ('AVXL', 2), ('MAT', 2), ('UCTT', 2), ('LRCX', 2), ('IRBT', 2), ('PGR', 2), ('PCTY', 2), ('MAS', 2), ('CLF', 2), ('BWXT', 2), ('XRX', 1), ('NYT', 1), ('SSYS', 1), ('KDNY', 1), ('APPS', 1), ('ARWR', 1), ('W', 1), ('ON', 1), ('AMKR', 1), ('ALL', 1), ('RNR', 1), ('CTLT', 1), ('COLM', 1), ('LADR', 1), ('MSI', 1), ('IIM', 1), ('COMM', 1), ('CDW', 1), ('ACGL', 1), ('SKX', 1)], [('AXSM', 3), ('XRX', 3), ('ENPH', 2), ('BOOT', 2), ('MAT', 2), ('SSYS', 2), ('VECO', 2), ('NVCR', 2), ('HBI', 2), ('CCRN', 2), ('NYCB', 2), ('COTY', 2), ('SYF', 2), ('HRI', 2), ('PPC', 2), ('CLF', 2), ('CCK', 2), ('GLPI', 2), ('PCTY', 1), ('NYT', 1), ('APPS', 1), ('AVXL', 1), ('EVRI', 1), ('CSIQ', 1), ('NSTG', 1), ('UCTT', 1), ('PAYC', 1), ('CCS', 1), ('IIM', 1), ('IBM', 1), ('FCF', 1), ('FDUS', 1), ('SANM', 1), ('CPF', 1), ('UE', 1), ('CSGS', 1), ('NMZ', 1), ('CNO', 1), ('RDN', 1), ('SHV', 1)], [('AXSM', 3), ('SHV', 3), ('PAR', 3), ('MTCH', 3), ('OR', 3), ('LRN', 3), ('LSCC', 3), ('NVCR', 2), ('APPS', 2), ('CHGG', 2), ('AU', 2), ('BNDX', 2), ('QURE', 2), ('LQD', 2), ('WPM', 2), ('KEYS', 2), ('TEAM', 2), ('GLD', 2), ('LGIH', 2), ('SBS', 1), ('CSIQ', 1), ('DQ', 1), ('WDAY', 1), ('PAYC', 1), ('EBAY', 1), ('RCII', 1), ('RGLD', 1), ('AMX', 1), ('BKT', 1), ('ASA', 1), ('NLY', 1), ('PKE', 1), ('CVLT', 1), ('OSIS', 1)], [('SHV', 3), ('AXSM', 3), ('LRN', 3), ('FTSM', 3), ('AU', 3), ('SBS', 3), ('SSRM', 3), ('CIEN', 3), ('O', 3), ('APPS', 2), ('CSIQ', 2), ('GLD', 2), ('SBUX', 2), ('MPW', 2), ('RCII', 2), ('BALL', 2), ('EXAS', 2), ('GKOS', 2), ('PBR', 2), ('AVGO', 1), ('BNDX', 1), ('NSTG', 1), ('NVAX', 1), ('KDP', 1), ('VCEL', 1), ('TDS', 1), ('VIRT', 1), ('TWLO', 1), ('RGLD', 1), ('NEM', 1), ('YUM', 1), ('OMC', 1)]]
# **** finish lookback slices [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)] ****
#
# top 20 ranked symbols and frequency from set [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]:
# [('AXSM', 9), ('SHV', 7), ('APPS', 6), ('LRN', 6), ('AU', 5), ('CLF', 4), ('COTY', 4), ('CSIQ', 4), ('GLD', 4), ('MAT', 4), ('NVCR', 4), ('SBS', 4), ('VECO', 4), ('XRX', 4), ('AGYS', 3), ('AVXL', 3), ('BNDX', 3), ('CIEN', 3), ('FTSM', 3), ('LSCC', 3)]
# top 20 ranked symbols from set [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]:
# ['AXSM', 'SHV', 'APPS', 'LRN', 'AU', 'CLF', 'COTY', 'CSIQ', 'GLD', 'MAT']
# ===== finish top 20 ranked symbols from days_lookback set [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)] =====
#
#
# max_lookback_slices:             [(805, 925, 929), (325, 445, 449)]
# set_lookback_slices 1 of   2:    [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)]
#
# max_days_lookbacks:              120
# df end date for days_lookbacks:  2021-01-07
# days_lookbacks:                  [15, 30, 60, 120]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     ['BTC-USD']
# sym_freq_9:                      ['CTRN']
# sym_freq_8:                      ['CELH', 'FATE', 'GBTC', 'IPI', 'MARA', 'NTLA', 'PLUG']
# sym_freq_7:                      []
# sym_freq_6:                      ['CHRD', 'CLF', 'SM']
# sym_freq_5:                      ['ALB', 'RCKT', 'VCEL']
# sym_freq_4:                      ['CPRI', 'DQ', 'SCHW', 'SSYS', 'TPR']
# sym_freq_3:                      []
# sym_freq_2:                      []
#
# max_lookback_slices:             [(805, 925, 929), (325, 445, 449)]
# set_lookback_slices 2 of   2:    [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]
#
# max_days_lookbacks:              120
# df end date for days_lookbacks:  2019-02-12
# days_lookbacks:                  [15, 30, 60, 120]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     []
# sym_freq_9:                      ['AXSM']
# sym_freq_8:                      []
# sym_freq_7:                      ['SHV']
# sym_freq_6:                      ['APPS', 'LRN']
# sym_freq_5:                      ['AU']
# sym_freq_4:                      ['CLF', 'COTY', 'CSIQ', 'GLD', 'MAT', 'NVCR', 'SBS', 'VECO', 'XRX']
# sym_freq_3:                      ['AGYS', 'AVXL', 'BNDX', 'CIEN', 'FTSM', 'LSCC']
# sym_freq_2:                      []
#
# z_grp_top_set_syms_n_freq:
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
#
#
# 1 of 2 max_lookback_slice: (805, 925, 929)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2020-07-20', '2020-07-21', '2020-07-22', '2020-07-23', '2020-07-24', '2020-07-27', '2020-07-28', '2020-07-29', '2020-07-30', '2020-07-31',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-28', '2020-12-29', '2020-12-30', '2020-12-31', '2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2020-07-20 - 2021-01-07
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2021-01-08 - 2021-01-13
#
# top_set_syms_n_freq: [('BTC-USD', 10), ('CTRN', 9), ('CELH', 8), ('FATE', 8), ('GBTC', 8), ('IPI', 8), ('MARA', 8), ('NTLA', 8), ('PLUG', 8), ('CHRD', 6), ('CLF', 6), ('SM', 6), ('ALB', 5), ('RCKT', 5), ('VCEL', 5), ('CPRI', 4), ('DQ', 4), ('SCHW', 4), ('SSYS', 4), ('TPR', 4)]
#
# set_lookback_slices: [(910, 925, 929), (895, 925, 929), (865, 925, 929), (805, 925, 929)]
# max_lookback_slice:  (805, 925, 929)
# days_lookbacks:      [15, 30, 60, 120]
# date_end_df_train:   2021-01-07
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         ['BTC-USD']
# sym_freq_9:          ['CTRN']
# sym_freq_8:          ['CELH', 'FATE', 'GBTC', 'IPI', 'MARA', 'NTLA', 'PLUG']
# sym_freq_7:          []
# sym_freq_6:          ['CHRD', 'CLF', 'SM']
# sym_freq_5:          ['ALB', 'RCKT', 'VCEL']
# sym_freq_4:          ['CPRI', 'DQ', 'SCHW', 'SSYS', 'TPR']
# sym_freq_3:          []
# sym_freq_2:          []
#
# iloc_start_eval:    925,  df_eval first date: 2021-01-08
# iloc_end_eval:      929,  df_eval last date:  2021-01-13
# frequency count of symbol(s): 10
#
# df_eval_n_SPY:
#                  BTC-USD         SPY
# Date
# 2021-01-08  40797.609375  368.830597
# 2021-01-11  35566.656250  366.344360
# 2021-01-12  33922.960938  366.421814
# 2021-01-13  37316.359375  367.408508
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.9994
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                          -8.7560
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -10.5868
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        0.8271
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                   -0.2771
# SPY_CAGR/UI                               -54.6207
# SPY_CAGR/retnStd                          -69.4024
# SPY_retnStd/UI                              0.7870
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# iloc_start_eval:    925,  df_eval first date: 2021-01-08
# iloc_end_eval:      929,  df_eval last date:  2021-01-13
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#                  CTRN         SPY
# Date
# 2021-01-08  53.869999  368.830597
# 2021-01-11  55.959999  366.344360
# 2021-01-12  60.680000  366.421814
# 2021-01-13  59.599998  367.408508
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                          4,869.1200
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                             inf
# grp(CAGR/UI)_mean                     547,143.8920
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                          inf
# grp(CAGR/retnStd)_mean                116,537.8625
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                     inf
# grp(retnStd/UI)_mean                        4.6950
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                   -0.2771
# SPY_CAGR/UI                               -54.6207
# SPY_CAGR/retnStd                          -69.4024
# SPY_retnStd/UI                              0.7870
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# iloc_start_eval:    925,  df_eval first date: 2021-01-08
# iloc_end_eval:      929,  df_eval last date:  2021-01-13
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#                  CELH        FATE       GBTC        IPI       MARA       NTLA       PLUG         SPY
# Date
# 2021-01-08  58.540001  116.309998  44.419998  23.620001  26.389999  78.360001  53.779999  368.830597
# 2021-01-11  57.110001  112.010002  37.400002  25.190001  23.360001  72.779999  53.970001  366.344360
# 2021-01-12  59.310001  112.050003  38.919998  27.990000  26.150000  75.690002  66.019997  366.421814
# 2021-01-13  59.599998  113.290001  40.349998  26.799999  23.000000  76.010002  69.500000  367.408508
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                    323,211,742.9559
# grp(CAGR)_std                     791,687,302.2207
# grp(CAGR)_mean/std                          0.4083
# grp(CAGR/UI)_mean             646,411,905,682,327.3750
# grp(CAGR/UI)_std              1,583,379,331,803,290.0000
# grp(CAGR/UI)_mean/std                       0.4082
# grp(CAGR/retnStd)_mean          3,432,612,163.2569
# grp(CAGR/retnStd)_std           8,407,891,880.8928
# grp(CAGR/retnStd)_mean/std                  0.4083
# grp(retnStd/UI)_mean                   26,904.1249
# grp(retnStd/UI)_std                    65,897.6694
# grp(retnStd/UI)_mean/std                    0.4083
# SPY_CAGR                                   -0.2771
# SPY_CAGR/UI                               -54.6207
# SPY_CAGR/retnStd                          -69.4024
# SPY_retnStd/UI                              0.7870
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, 323211742.95589834, 791687302.2207226, 0.4082568231791431, 646411905682327.4, 1583379331803290.0, 0.4082482906645859, 3432612163.256907, 8407891880.892803, 0.4082607402525745, 26904.124869256804, 65897.66939763329, 0.40827126536015346, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# iloc_start_eval:    925,  df_eval first date: 2021-01-08
# iloc_end_eval:      929,  df_eval last date:  2021-01-13
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  CHRD        CLF         SM         SPY
# Date
# 2021-01-08  31.139992  18.040001   8.300544  368.830597
# 2021-01-11  31.243204  18.110001   9.108912  366.344360
# 2021-01-12  33.042007  18.559999  10.222880  366.421814
# 2021-01-13  32.717636  17.780001   9.256783  367.408508
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                          3,186.7608
# grp(CAGR)_std                           4,463.1231
# grp(CAGR)_mean/std                          0.7140
# grp(CAGR/UI)_mean                      71,240.8780
# grp(CAGR/UI)_std                       91,914.6217
# grp(CAGR/UI)_mean/std                       0.7751
# grp(CAGR/retnStd)_mean                 33,392.6526
# grp(CAGR/retnStd)_std                  45,735.1636
# grp(CAGR/retnStd)_mean/std                  0.7301
# grp(retnStd/UI)_mean                        3.1073
# grp(retnStd/UI)_std                         2.0265
# grp(retnStd/UI)_mean/std                    1.5333
# SPY_CAGR                                   -0.2771
# SPY_CAGR/UI                               -54.6207
# SPY_CAGR/retnStd                          -69.4024
# SPY_retnStd/UI                              0.7870
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, 323211742.95589834, 791687302.2207226, 0.4082568231791431, 646411905682327.4, 1583379331803290.0, 0.4082482906645859, 3432612163.256907, 8407891880.892803, 0.4082607402525745, 26904.124869256804, 65897.66939763329, 0.40827126536015346, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3186.760783431062, 4463.123105065582, 0.7140203638600363, 71240.87804949754, 91914.62174715575, 0.7750766602235628, 33392.65261770969, 45735.163648779984, 0.7301308217490211, 3.107275008406722, 2.0265321634818076, 1.5332966653083255, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# iloc_start_eval:    925,  df_eval first date: 2021-01-08
# iloc_end_eval:      929,  df_eval last date:  2021-01-13
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                    ALB       RCKT       VCEL         SPY
# Date
# 2021-01-08  181.091827  56.919998  36.169998  368.830597
# 2021-01-11  174.393097  55.240002  34.889999  366.344360
# 2021-01-12  179.517990  55.619999  37.400002  366.421814
# 2021-01-13  176.980133  55.490002  36.919998  367.408508
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              0.9566
# grp(CAGR)_std                               2.5810
# grp(CAGR)_mean/std                          0.3706
# grp(CAGR/UI)_mean                          55.6403
# grp(CAGR/UI)_std                          133.7223
# grp(CAGR/UI)_mean/std                       0.4161
# grp(CAGR/retnStd)_mean                      3.8544
# grp(CAGR/retnStd)_std                      68.6017
# grp(CAGR/retnStd)_mean/std                  0.0562
# grp(retnStd/UI)_mean                        1.4619
# grp(retnStd/UI)_std                         0.7381
# grp(retnStd/UI)_mean/std                    1.9807
# SPY_CAGR                                   -0.2771
# SPY_CAGR/UI                               -54.6207
# SPY_CAGR/retnStd                          -69.4024
# SPY_retnStd/UI                              0.7870
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, 323211742.95589834, 791687302.2207226, 0.4082568231791431, 646411905682327.4, 1583379331803290.0, 0.4082482906645859, 3432612163.256907, 8407891880.892803, 0.4082607402525745, 26904.124869256804, 65897.66939763329, 0.40827126536015346, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3186.760783431062, 4463.123105065582, 0.7140203638600363, 71240.87804949754, 91914.62174715575, 0.7750766602235628, 33392.65261770969, 45735.163648779984, 0.7301308217490211, 3.107275008406722, 2.0265321634818076, 1.5332966653083255, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 0.956646555362337, 2.581002868797216, 0.3706491639074186, 55.64034547789182, 133.7222876988038, 0.4160887944365429, 3.8544483108791874, 68.60172957126913, 0.056185876580194215, 1.4619121045053707, 0.7380791441228879, 1.98069829793479, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# iloc_start_eval:    925,  df_eval first date: 2021-01-08
# iloc_end_eval:      929,  df_eval last date:  2021-01-13
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  CPRI         DQ       SCHW       SSYS        TPR         SPY
# Date
# 2021-01-08  45.090000  77.110001  57.540947  28.129999  32.562080  368.830597
# 2021-01-11  45.529999  76.529999  58.779961  29.500000  32.876007  366.344360
# 2021-01-12  46.540001  85.300003  59.706772  27.330000  33.617996  366.421814
# 2021-01-13  45.560001  77.410004  58.058014  28.170000  32.371830  367.408508
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              0.5266
# grp(CAGR)_std                               0.6503
# grp(CAGR)_mean/std                          0.8099
# grp(CAGR/UI)_mean                          40.6735
# grp(CAGR/UI)_std                           56.9954
# grp(CAGR/UI)_mean/std                       0.7136
# grp(CAGR/retnStd)_mean                     23.8427
# grp(CAGR/retnStd)_std                      34.2465
# grp(CAGR/retnStd)_mean/std                  0.6962
# grp(retnStd/UI)_mean                        1.5557
# grp(retnStd/UI)_std                         0.2147
# grp(retnStd/UI)_mean/std                    7.2476
# SPY_CAGR                                   -0.2771
# SPY_CAGR/UI                               -54.6207
# SPY_CAGR/retnStd                          -69.4024
# SPY_retnStd/UI                              0.7870
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, 323211742.95589834, 791687302.2207226, 0.4082568231791431, 646411905682327.4, 1583379331803290.0, 0.4082482906645859, 3432612163.256907, 8407891880.892803, 0.4082607402525745, 26904.124869256804, 65897.66939763329, 0.40827126536015346, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3186.760783431062, 4463.123105065582, 0.7140203638600363, 71240.87804949754, 91914.62174715575, 0.7750766602235628, 33392.65261770969, 45735.163648779984, 0.7301308217490211, 3.107275008406722, 2.0265321634818076, 1.5332966653083255, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 0.956646555362337, 2.581002868797216, 0.3706491639074186, 55.64034547789182, 133.7222876988038, 0.4160887944365429, 3.8544483108791874, 68.60172957126913, 0.056185876580194215, 1.4619121045053707, 0.7380791441228879, 1.98069829793479, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.5266431766821689, 0.650270306538634, 0.8098834767428824, 40.673483018689744, 56.995387266636065, 0.7136276279413785, 23.842714380906216, 34.246467012694595, 0.6962094621926437, 1.5557161219150877, 0.21465119233435395, 7.247647241072895, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# ================================================================================
#
#
#
# 2 of 2 max_lookback_slice: (325, 445, 449)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2018-08-21', '2018-08-22', '2018-08-23', '2018-08-24', '2018-08-27', '2018-08-28', '2018-08-29', '2018-08-30', '2018-08-31', '2018-09-04',
#                ...
#                '2019-01-30', '2019-01-31', '2019-02-01', '2019-02-04', '2019-02-05', '2019-02-06', '2019-02-07', '2019-02-08', '2019-02-11', '2019-02-12'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2018-08-21 - 2019-02-12
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2019-02-13', '2019-02-14', '2019-02-15', '2019-02-19'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2019-02-13 - 2019-02-19
#
# top_set_syms_n_freq: [('AXSM', 9), ('SHV', 7), ('APPS', 6), ('LRN', 6), ('AU', 5), ('CLF', 4), ('COTY', 4), ('CSIQ', 4), ('GLD', 4), ('MAT', 4), ('NVCR', 4), ('SBS', 4), ('VECO', 4), ('XRX', 4), ('AGYS', 3), ('AVXL', 3), ('BNDX', 3), ('CIEN', 3), ('FTSM', 3), ('LSCC', 3)]
#
# set_lookback_slices: [(430, 445, 449), (415, 445, 449), (385, 445, 449), (325, 445, 449)]
# max_lookback_slice:  (325, 445, 449)
# days_lookbacks:      [15, 30, 60, 120]
# date_end_df_train:   2019-02-12
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          ['AXSM']
# sym_freq_8:          []
# sym_freq_7:          ['SHV']
# sym_freq_6:          ['APPS', 'LRN']
# sym_freq_5:          ['AU']
# sym_freq_4:          ['CLF', 'COTY', 'CSIQ', 'GLD', 'MAT', 'NVCR', 'SBS', 'VECO', 'XRX']
# sym_freq_3:          ['AGYS', 'AVXL', 'BNDX', 'CIEN', 'FTSM', 'LSCC']
# sym_freq_2:          []
#
# iloc_start_eval:    445,  df_eval first date: 2019-02-13
# iloc_end_eval:      449,  df_eval last date:  2019-02-19
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#             AXSM         SPY
# Date
# 2019-02-13  9.14  256.295044
# 2019-02-14  9.17  255.726547
# 2019-02-15  9.33  258.513245
# 2019-02-19  8.59  258.960693
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.9946
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                         -25.0789
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -23.3087
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        1.0759
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    1.3849
# SPY_CAGR/UI                             1,248.6859
# SPY_CAGR/retnStd                          252.0841
# SPY_retnStd/UI                              4.9534
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, 323211742.95589834, 791687302.2207226, 0.4082568231791431, 646411905682327.4, 1583379331803290.0, 0.4082482906645859, 3432612163.256907, 8407891880.892803, 0.4082607402525745, 26904.124869256804, 65897.66939763329, 0.40827126536015346, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3186.760783431062, 4463.123105065582, 0.7140203638600363, 71240.87804949754, 91914.62174715575, 0.7750766602235628, 33392.65261770969, 45735.163648779984, 0.7301308217490211, 3.107275008406722, 2.0265321634818076, 1.5332966653083255, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 0.956646555362337, 2.581002868797216, 0.3706491639074186, 55.64034547789182, 133.7222876988038, 0.4160887944365429, 3.8544483108791874, 68.60172957126913, 0.056185876580194215, 1.4619121045053707, 0.7380791441228879, 1.98069829793479, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.5266431766821689, 0.650270306538634, 0.8098834767428824, 40.673483018689744, 56.995387266636065, 0.7136276279413785, 23.842714380906216, 34.246467012694595, 0.6962094621926437, 1.5557161219150877, 0.21465119233435395, 7.247647241072895, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.994555668038787, 0.0, -inf, -25.078938316162233, 0.0, -inf, -23.30866082036371, 0.0, -inf, 1.0759493438701513, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
# iloc_start_eval:    445,  df_eval first date: 2019-02-13
# iloc_end_eval:      449,  df_eval last date:  2019-02-19
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                    SHV         SPY
# Date
# 2019-02-13  104.951965  256.295044
# 2019-02-14  104.980484  255.726547
# 2019-02-15  104.999474  258.513245
# 2019-02-19  105.009018  258.960693
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              0.0467
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                             inf
# grp(CAGR/UI)_mean                      93,417.1967
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                          inf
# grp(CAGR/retnStd)_mean                    632.6984
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                     inf
# grp(retnStd/UI)_mean                      147.6489
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    1.3849
# SPY_CAGR/UI                             1,248.6859
# SPY_CAGR/retnStd                          252.0841
# SPY_retnStd/UI                              4.9534
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, 323211742.95589834, 791687302.2207226, 0.4082568231791431, 646411905682327.4, 1583379331803290.0, 0.4082482906645859, 3432612163.256907, 8407891880.892803, 0.4082607402525745, 26904.124869256804, 65897.66939763329, 0.40827126536015346, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3186.760783431062, 4463.123105065582, 0.7140203638600363, 71240.87804949754, 91914.62174715575, 0.7750766602235628, 33392.65261770969, 45735.163648779984, 0.7301308217490211, 3.107275008406722, 2.0265321634818076, 1.5332966653083255, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 0.956646555362337, 2.581002868797216, 0.3706491639074186, 55.64034547789182, 133.7222876988038, 0.4160887944365429, 3.8544483108791874, 68.60172957126913, 0.056185876580194215, 1.4619121045053707, 0.7380791441228879, 1.98069829793479, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.5266431766821689, 0.650270306538634, 0.8098834767428824, 40.673483018689744, 56.995387266636065, 0.7136276279413785, 23.842714380906216, 34.246467012694595, 0.6962094621926437, 1.5557161219150877, 0.21465119233435395, 7.247647241072895, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.994555668038787, 0.0, -inf, -25.078938316162233, 0.0, -inf, -23.30866082036371, 0.0, -inf, 1.0759493438701513, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 0.046708598348548014, 0.0, inf, 93417.19669709603, 0.0, inf, 632.6983759953511, 0.0, inf, 147.64886435836598, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
# iloc_start_eval:    445,  df_eval first date: 2019-02-13
# iloc_end_eval:      449,  df_eval last date:  2019-02-19
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#             APPS        LRN         SPY
# Date
# 2019-02-13  2.89  32.160000  256.295044
# 2019-02-14  2.99  31.980000  255.726547
# 2019-02-15  3.05  32.060001  258.513245
# 2019-02-19  2.88  32.230000  258.960693
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.0261
# grp(CAGR)_std                               0.2265
# grp(CAGR)_mean/std                         -0.1153
# grp(CAGR/UI)_mean                          26.7636
# grp(CAGR/UI)_std                           35.8277
# grp(CAGR/UI)_mean/std                       0.7470
# grp(CAGR/retnStd)_mean                     18.4896
# grp(CAGR/retnStd)_std                      24.8672
# grp(CAGR/retnStd)_mean/std                  0.7435
# grp(retnStd/UI)_mean                        1.4324
# grp(retnStd/UI)_std                         0.0112
# grp(retnStd/UI)_mean/std                  127.8010
# SPY_CAGR                                    1.3849
# SPY_CAGR/UI                             1,248.6859
# SPY_CAGR/retnStd                          252.0841
# SPY_retnStd/UI                              4.9534
#
# type(l_row_add_total): <class 'list'>
# ...
#
#
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, 323211742.95589834, 791687302.2207226, 0.4082568231791431, 646411905682327.4, 1583379331803290.0, 0.4082482906645859, 3432612163.256907, 8407891880.892803, 0.4082607402525745, 26904.124869256804, 65897.66939763329, 0.40827126536015346, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3186.760783431062, 4463.123105065582, 0.7140203638600363, 71240.87804949754, 91914.62174715575, 0.7750766602235628, 33392.65261770969, 45735.163648779984, 0.7301308217490211, 3.107275008406722, 2.0265321634818076, 1.5332966653083255, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 0.956646555362337, 2.581002868797216, 0.3706491639074186, 55.64034547789182, 133.7222876988038, 0.4160887944365429, 3.8544483108791874, 68.60172957126913, 0.056185876580194215, 1.4619121045053707, 0.7380791441228879, 1.98069829793479, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.5266431766821689, 0.650270306538634, 0.8098834767428824, 40.673483018689744, 56.995387266636065, 0.7136276279413785, 23.842714380906216, 34.246467012694595, 0.6962094621926437, 1.5557161219150877, 0.21465119233435395, 7.247647241072895, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.994555668038787, 0.0, -inf, -25.078938316162233, 0.0, -inf, -23.30866082036371, 0.0, -inf, 1.0759493438701513, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 0.046708598348548014, 0.0, inf, 93417.19669709603, 0.0, inf, 632.6983759953511, 0.0, inf, 147.64886435836598, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, -0.02611350351893693, 0.22649129428925685, -0.11529583775342296, 26.763598166335267, 35.82766117838001, 0.7470093577441109, 18.489561081826285, 24.867246223627593, 0.7435307036232441, 1.4324234217719285, 0.011208229971992667, 127.80103775094682, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 9650.8033475796, 0.0, inf, 2640491.127943074, 0.0, inf, 204738.1466865813, 0.0, inf, 12.896918188798537, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 16.088783401959372, 30.031898332902795, 0.5357231575445427, 4974308.772900225, 9675400.122441834, 0.5141191795636904, 819.8864017969271, 894.9790644696225, 0.9160956209437185, 2440.1701719962452, 4663.017492696469, 0.5233028132144483, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 3, 76.04810132698482, 96.97701805841159, 0.7841868398261042, 110125742.47588761, 194731965.48832884, 0.5655247313902757, 5489.106369871329, 7911.231353552404, 0.6938371695332282, 6976.647953626376, 9964.097866421904, 0.7001785858744964, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
# df_eval_results BEFORW store results:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9994425289417938, 0.0, -inf, -8.75600317637996, 0.0, -inf, -10.586768580999713, 0.0, -inf, 0.8270704237452148, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, 4869.1199919585615, 0.0, inf, 547143.8919866481, 0.0, inf, 116537.86252242918, 0.0, inf, 4.694988222229864, 0.0, inf, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, 323211742.95589834, 791687302.2207226, 0.4082568231791431, 646411905682327.4, 1583379331803290.0, 0.4082482906645859, 3432612163.256907, 8407891880.892803, 0.4082607402525745, 26904.124869256804, 65897.66939763329, 0.40827126536015346, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3186.760783431062, 4463.123105065582, 0.7140203638600363, 71240.87804949754, 91914.62174715575, 0.7750766602235628, 33392.65261770969, 45735.163648779984, 0.7301308217490211, 3.107275008406722, 2.0265321634818076, 1.5332966653083255, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 0.956646555362337, 2.581002868797216, 0.3706491639074186, 55.64034547789182, 133.7222876988038, 0.4160887944365429, 3.8544483108791874, 68.60172957126913, 0.056185876580194215, 1.4619121045053707, 0.7380791441228879, 1.98069829793479, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.5266431766821689, 0.650270306538634, 0.8098834767428824, 40.673483018689744, 56.995387266636065, 0.7136276279413785, 23.842714380906216, 34.246467012694595, 0.6962094621926437, 1.5557161219150877, 0.21465119233435395, 7.247647241072895, -0.27711285955117504, -54.620721059345485, -69.40240624229087, 0.787014802752789]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.994555668038787, 0.0, -inf, -25.078938316162233, 0.0, -inf, -23.30866082036371, 0.0, -inf, 1.0759493438701513, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 0.046708598348548014, 0.0, inf, 93417.19669709603, 0.0, inf, 632.6983759953511, 0.0, inf, 147.64886435836598, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, -0.02611350351893693, 0.22649129428925685, -0.11529583775342296, 26.763598166335267, 35.82766117838001, 0.7470093577441109, 18.489561081826285, 24.867246223627593, 0.7435307036232441, 1.4324234217719285, 0.011208229971992667, 127.80103775094682, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 9650.8033475796, 0.0, inf, 2640491.127943074, 0.0, inf, 204738.1466865813, 0.0, inf, 12.896918188798537, 0.0, inf, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 16.088783401959372, 30.031898332902795, 0.5357231575445427, 4974308.772900225, 9675400.122441834, 0.5141191795636904, 819.8864017969271, 894.9790644696225, 0.9160956209437185, 2440.1701719962452, 4663.017492696469, 0.5233028132144483, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 3, 76.04810132698482, 96.97701805841159, 0.7841868398261042, 110125742.47588761, 194731965.48832884, 0.5655247313902757, 5489.106369871329, 7911.231353552404, 0.6938371695332282, 6976.647953626376, 9964.097866421904, 0.7001785858744964, 1.3848762357908626, 1248.685922539445, 252.08411023104293, 4.953449550608269]
#
# Save results to: test_df_eval
# df_eval_results AFTER store results:
#     n_samples     days_lookbacks  days_eval  n_top_syms  syms_start  syms_end  sym_freq_cnt  grp(CAGR)_mean  grp(CAGR)_std  grp(CAGR)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  grp(CAGR/retnStd)_mean  grp(CAGR/retnStd)_std  grp(CAGR/retnStd)_mean/std  grp(retnStd/UI)_mean  grp(retnStd/UI)_std  grp(retnStd/UI)_mean/std  SPY_CAGR  SPY_CAGR/UI  SPY_CAGR/retnStd  SPY_retnStd/UI
# 0           2  [15, 30, 60, 120]          4          20           0        10            10   -9.994425e-01   0.000000e+00                -inf      -8.756003e+00      0.000000e+00                 -inf          -1.058677e+01            0.000000e+00                   -inf                    0.827070              0.000000                  inf      -0.277113   -54.620721        -69.402406        0.787015
# 1           2  [15, 30, 60, 120]          4          20           0        10             9    4.869120e+03   0.000000e+00                 inf       5.471439e+05      0.000000e+00                  inf           1.165379e+05            0.000000e+00                    inf                    4.694988              0.000000                  inf      -0.277113   -54.620721        -69.402406        0.787015
# 2           2  [15, 30, 60, 120]          4          20           0        10             8    3.232117e+08   7.916873e+08            0.408257       6.464119e+14      1.583379e+15             0.408248           3.432612e+09            8.407892e+09               0.408261                26904.124869          65897.669398             0.408271      -0.277113   -54.620721        -69.402406        0.787015
# 3           2  [15, 30, 60, 120]          4          20           0        10             6    3.186761e+03   4.463123e+03            0.714020       7.124088e+04      9.191462e+04             0.775077           3.339265e+04            4.573516e+04               0.730131                    3.107275              2.026532             1.533297      -0.277113   -54.620721        -69.402406        0.787015
# 4           2  [15, 30, 60, 120]          4          20           0        10             5    9.566466e-01   2.581003e+00            0.370649       5.564035e+01      1.337223e+02             0.416089           3.854448e+00            6.860173e+01               0.056186                    1.461912              0.738079             1.980698      -0.277113   -54.620721        -69.402406        0.787015
# ..        ...                ...        ...         ...         ...       ...           ...             ...            ...                 ...                ...               ...                  ...                    ...                     ...                    ...                         ...                   ...                  ...            ...          ...               ...             ...
# 7           2  [15, 30, 60, 120]          4          20           0        10             7    4.670860e-02   0.000000e+00                 inf       9.341720e+04      0.000000e+00                  inf           6.326984e+02            0.000000e+00                    inf                  147.648864              0.000000                  inf       1.384876  1248.685923        252.084110        4.953450
# 8           2  [15, 30, 60, 120]          4          20           0        10             6   -2.611350e-02   2.264913e-01           -0.115296       2.676360e+01      3.582766e+01             0.747009           1.848956e+01            2.486725e+01               0.743531                    1.432423              0.011208           127.801038       1.384876  1248.685923        252.084110        4.953450
# 9           2  [15, 30, 60, 120]          4          20           0        10             5    9.650803e+03   0.000000e+00                 inf       2.640491e+06      0.000000e+00                  inf           2.047381e+05            0.000000e+00                    inf                   12.896918              0.000000                  inf       1.384876  1248.685923        252.084110        4.953450
# 10          2  [15, 30, 60, 120]          4          20           0        10             4    1.608878e+01   3.003190e+01            0.535723       4.974309e+06      9.675400e+06             0.514119           8.198864e+02            8.949791e+02               0.916096                 2440.170172           4663.017493             0.523303       1.384876  1248.685923        252.084110        4.953450
# 11          2  [15, 30, 60, 120]          4          20           0        10             3    7.604810e+01   9.697702e+01            0.784187       1.101257e+08      1.947320e+08             0.565525           5.489106e+03            7.911231e+03               0.693837                 6976.647954           9964.097866             0.700179       1.384876  1248.685923        252.084110        4.953450
#
# [12 rows x 23 columns]
