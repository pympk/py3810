# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump, delete_all_rows
from yf_utils import split_train_val_test, random_slices, lookback_slices
from yf_utils import top_set_sym_freq_cnt, get_grp_top_syms_n_freq
from yf_utils import eval_grp_top_syms_n_freq


pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.width", 500)  # code-runner format

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = "df_close_clean"

# %% [markdown]
# ### Run below cell for Colab

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/py_files/python/py3810

newpath = r'/content/colab_dump/'
if not os.path.exists(newpath):
    os.makedirs(newpath)

path_data_dump = '/content/colab_dump/'

# %%
#######################################################################
## SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# select run type
run_type = "train"
# run_type = 'validate'
# run_type = "test"

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms
# n_samples = 400
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
# days_lookbacks = [15, 30, 60]
# days_lookbacks = [30, 60, 120]
days_lookbacks = [15, 30, 60, 120]
days_lookbacks.sort()

# number of days in dataframe to evaluate effectiveness of the training, days_eval = len(df_eval)
#  days_eval = 4 means buy at close on 1st day after the signal, hold for 2nd and 3rd day, sell at close on 4th day
days_eval = 4
# days_eval = 5

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20
# n_top_syms = 5

# slice starts and ends for selecting the best performing symbols
syms_start = 0
syms_end = 10


##########################################################
# fp_df_eval_results = f"df_eval_results_{run_type}"
fp_df_eval_results = "test_df_eval"
##########################################################

#### Delete all rows in df_eval_results ##################
delete_all_rows(path_data_dump, fp_df_eval_results)
##########################################################

# %%
print(f"verbose : {verbose }")
print(f"store_results: {store_results}")
print(f"run_type: {run_type}")
print(f"n_samples: {n_samples}")
print(f"days_lookbacks: {days_lookbacks}")
print(f"days_eval: {days_eval}")
print(f"n_top_syms: {n_top_syms}")
print(f"syms_start: {syms_start}")
print(f"syms_end: {syms_end}")
print(f"fp_df_eval_results: {fp_df_eval_results}")

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = split_train_val_test(df_close_clean)
# Out:
# verbose : True
# store_results: True
# run_type: train
# n_samples: 2
# days_lookbacks: [15, 30, 60, 120]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10
# fp_df_eval_results: test_df_eval

# %%
# max_days_lookbacks = max(days_lookbacks)
# print(f"max_days_lookbacks: {max_days_lookbacks}")

# Load df according to run_type
if run_type == "train":
    df = df_train.copy()
elif run_type == "validate":
    df = df_val.copy()
elif run_type == "test":
    df = df_test.copy()
else:
    msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop)

# Print dataframe for the run, and lengths of other dataframes
print(f"run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n")
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f"run_type: {run_type}, len(df): {len(df)}")
print(
    f"len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}"
)

# return n_samples slices
max_lookback_slices = random_slices(
    len_df,
    n_samples=n_samples,
    days_lookback=max(days_lookbacks),
    days_eval=days_eval,
    verbose=False,
)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = lookback_slices(
    max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False
)
# Out:
# run_type: train, df.tail(3):
#                      A         AA        AAL         AAP        AAPL         AB        ABB        ABBV         ABC        ABM        ABR         ABT       ACGL       ACHC       ACIW  ...       XRAY        XRX         XYL       YELP       YUMC         YY         ZBH        ZBRA          ZD          ZG       ZION        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                                   ...
# 2021-06-15  143.119141  35.880051  22.790001  190.966675  128.315643  39.616646  32.975571  107.910744  116.336479  46.516220  15.713879  107.274254  39.529999  65.709999  39.029999  ...  64.357971  21.924356  115.720497  39.900002  66.946068  65.857132  151.415741  506.100006  113.278259  111.209999  51.980713  30.783392  183.434143  45.570000  50.638290
# 2021-06-16  142.099838  34.960552  22.830000  187.407349  128.820404  39.607910  32.255829  107.631256  115.681633  45.304855  15.526809  106.934189  39.389999  64.290001  38.700001  ...  63.996552  22.013657  113.172661  41.320000  65.913101  65.371948  151.119308  506.700012  115.939133  108.839996  52.562302  30.199211  181.892929  45.959999  51.023483
# 2021-06-17  145.395294  33.200668  22.230000  185.943817  130.443665  39.005150  31.678141  107.044327  115.437302  44.190407  15.441776  108.459602  38.509998  63.130001  38.669998  ...  63.596107  21.102751  111.653778  40.880001  64.752243  64.062668  153.376129  502.089996  116.165215  113.660004  49.215782  29.733847  184.194870  44.130001  48.998741
#
# [3 rows x 1320 columns]
#
# run_type: train, len(df): 1050
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %% [markdown]
# ### Run below cell to use test data to debug code, results should match yf_test.ipynb

# %%
# ####### RUN THIS CELL TO USE TEST DATA TO DEBUG CODE, RESULTS SHOULD MATCH yf_test.ipynb ################# 

# # load test data to debug code if needed
# test_dic = pickle_load(path_data_dump, 'yf_test_dic')
# for i, key in enumerate(test_dic.keys()):
#   print(f'{i}: {key}')

# # convert dictionary entries into variables
# locals().update(test_dic)
# del df_eval_results  # delete df_eval_results loaded from locals().update(test_dic)

# # Delete all rows in df_eval_results
# delete_all_rows(path_data_dump, fp_df_eval_results)
# Out:
# 0: df_eval_results
# 1: df
# 2: max_lookback_slices
# 3: sets_lookback_slices
# 4: grp_top_set_syms_n_freq
# 5: days_lookbacks
# 6: days_eval
# 7: n_samples
# 8: n_top_syms
# 9: syms_start
# 10: syms_end
# 11: verbose

# %%
max_days_lookbacks = max(days_lookbacks)
print(f"max_days_lookbacks: {max_days_lookbacks}")

if verbose:
    print(f"number of max_lookback_slices is equal to n_samples = {n_samples}")
    print(f"max_lookback_slices:\n{max_lookback_slices}\n")
    print(f"number of sets in sets_lookback_slices is equal to n_samples = {n_samples}")
    print(f"sets_lookback_slices:\n{sets_lookback_slices}\n")
    print(f"days_lookbacks: {days_lookbacks}")
    print(
        f'number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): {len(days_lookbacks)}'
    )

# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the max_lookback_slices. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in max_lookback_slices. There are as many sub-lists as there are tuples in max_lookback_slices.
grp_top_set_syms_n_freq, grp_top_set_syms, dates_end_df_train = get_grp_top_syms_n_freq(
    df, sets_lookback_slices, days_lookbacks, n_top_syms, syms_start, syms_end, verbose
)

# #### print the best performing symbols for each set in sets_lookback_slices
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
    l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
    if verbose:
        print(f"max_lookback_slices:             {max_lookback_slices}")
        # print(f'set_lookback_slices: {sets_lookback_slices[i]}\n')
        print(
            f"set_lookback_slices {i + 1} of {len(sets_lookback_slices):>3}:    {sets_lookback_slices[i]}\n"
        )
        print(f"max_days_lookbacks:              {max_days_lookbacks}")
        print(f"df end date for days_lookbacks:  {dates_end_df_train[i]}")
        print(f"days_lookbacks:                  {days_lookbacks}")
        print(f"sym_freq_15:                     {l_sym_freq_cnt[0]}")
        print(f"sym_freq_14:                     {l_sym_freq_cnt[1]}")
        print(f"sym_freq_13:                     {l_sym_freq_cnt[2]}")
        print(f"sym_freq_12:                     {l_sym_freq_cnt[3]}")
        print(f"sym_freq_11:                     {l_sym_freq_cnt[4]}")
        print(f"sym_freq_10:                     {l_sym_freq_cnt[5]}")
        print(f"sym_freq_9:                      {l_sym_freq_cnt[6]}")
        print(f"sym_freq_8:                      {l_sym_freq_cnt[7]}")
        print(f"sym_freq_7:                      {l_sym_freq_cnt[8]}")
        print(f"sym_freq_6:                      {l_sym_freq_cnt[9]}")
        print(f"sym_freq_5:                      {l_sym_freq_cnt[10]}")
        print(f"sym_freq_4:                      {l_sym_freq_cnt[11]}")
        print(f"sym_freq_3:                      {l_sym_freq_cnt[12]}")
        print(f"sym_freq_2:                      {l_sym_freq_cnt[13]}\n")


# #### Evaluate performance of symbols in set_lookback_slices versus SPY
l_row_add_total = eval_grp_top_syms_n_freq(
    df, max_lookback_slices, sets_lookback_slices, grp_top_set_syms_n_freq, days_lookbacks, days_eval, n_samples, n_top_syms, syms_start, syms_end, verbose
)

for row_add_total in l_row_add_total:
    print(f"row_add_total: {row_add_total}")

if store_results:  # record results to df
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results BEFORW store results:\n{df_eval_results}\n")

    for row_add_total in l_row_add_total:
        # print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f"appended row_add_total to df_eval_results:\n{row_add_total}\n")

    pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
    print(f"Save results to: {fp_df_eval_results}")
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results AFTER store results:\n{df_eval_results}\n")
# Out:
# max_days_lookbacks: 120
# number of max_lookback_slices is equal to n_samples = 2
# max_lookback_slices:
# [(108, 228, 232), (772, 892, 896)]
#
# number of sets in sets_lookback_slices is equal to n_samples = 2
# sets_lookback_slices:
# [[(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)], [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]]
#
# days_lookbacks: [15, 30, 60, 120]
# number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): 4
#
# ########## 1 of 2 lb_slices: [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)] in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)]
# lb_slice:            (213, 228, 232)
# days eval:           4
# iloc_start_train:    213
# iloc_end_train:      228
# date_start_df_train: 2018-02-21
# date_end_df_train:   2018-03-13
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['PEN', 'NTNX', 'VCEL', 'ENPH', 'AXON', 'KDNY', 'MU', 'ARWR', 'RCM',
#        'CRSP', 'HLF', 'ETSY', 'VEEV', 'LITE', 'HHC', 'MED', 'CYRX',
#        'SRPT', 'PRFT', 'MMYT'], dtype=object), 'r_CAGR/retnStd': array(['NTNX', 'VCEL', 'ENPH', 'KDNY', 'RCM', 'ARWR', 'CRSP', 'MU',
#        'AXON', 'PEN', 'SRPT', 'MED', 'ETSY', 'LITE', 'VEEV', 'PLAB',
#        'CYRX', 'SWN', 'ZG', 'NTLA'], dtype=object), 'r_retnStd/UI': array(['PEN', 'HHC', 'HLF', 'VEEV', 'ETSY', 'NTNX', 'AXON', 'FSS', 'LITE',
#        'PLNT', 'MMYT', 'ADSK', 'MU', 'STX', 'PAYC', 'PRFT', 'DENN',
#        'CYRX', 'SCL', 'ARWR'], dtype=object)}}
# most_freq_syms: [('PEN', 3), ('NTNX', 3), ('AXON', 3), ('MU', 3), ('ARWR', 3), ('ETSY', 3), ('VEEV', 3), ('LITE', 3), ('CYRX', 3), ('VCEL', 2), ('ENPH', 2), ('KDNY', 2), ('RCM', 2), ('CRSP', 2), ('HLF', 2), ('HHC', 2), ('MED', 2), ('SRPT', 2), ('PRFT', 2), ('MMYT', 2), ('PLAB', 1), ('SWN', 1), ('ZG', 1), ('NTLA', 1), ('FSS', 1), ('PLNT', 1), ('ADSK', 1), ('STX', 1), ('PAYC', 1), ('DENN', 1), ('SCL', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)]
# lb_slice:            (198, 228, 232)
# days eval:           4
# iloc_start_train:    198
# iloc_end_train:      228
# date_start_df_train: 2018-01-30
# date_end_df_train:   2018-03-13
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['ENPH', 'VIRT', 'NTNX', 'LITE', 'ETSY', 'TWLO', 'XENE', 'WIX',
#        'CIEN', 'MU', 'AXON', 'ITCI', 'VCEL', 'ZG', 'RCM', 'QNST', 'MTCH',
#        'SPSC', 'QURE', 'FTNT'], dtype=object), 'r_CAGR/retnStd': array(['ENPH', 'NTNX', 'VIRT', 'LITE', 'TWLO', 'ETSY', 'XENE', 'MU',
#        'VCEL', 'WIX', 'RCM', 'AXON', 'ITCI', 'ZG', 'CIEN', 'MTCH', 'AX',
#        'VNDA', 'KDNY', 'QNST'], dtype=object), 'r_retnStd/UI': array(['VIRT', 'CIEN', 'ETSY', 'LITE', 'NTNX', 'XENE', 'SPSC', 'VIAV',
#        'HAE', 'AXON', 'MODN', 'QNST', 'FTNT', 'ITCI', 'BL', 'WIX', 'QURE',
#        'SWKS', 'FTSM', 'ENPH'], dtype=object)}}
# most_freq_syms: [('ENPH', 3), ('VIRT', 3), ('NTNX', 3), ('LITE', 3), ('ETSY', 3), ('XENE', 3), ('WIX', 3), ('CIEN', 3), ('AXON', 3), ('ITCI', 3), ('QNST', 3), ('TWLO', 2), ('MU', 2), ('VCEL', 2), ('ZG', 2), ('RCM', 2), ('MTCH', 2), ('SPSC', 2), ('QURE', 2), ('FTNT', 2), ('AX', 1), ('VNDA', 1), ('KDNY', 1), ('VIAV', 1), ('HAE', 1), ('MODN', 1), ('BL', 1), ('SWKS', 1), ('FTSM', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)]
# lb_slice:            (168, 228, 232)
# days eval:           4
# iloc_start_train:    168
# iloc_end_train:      228
# date_start_df_train: 2017-12-14
# date_end_df_train:   2018-03-13
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['CRSP', 'FATE', 'VIRT', 'VCEL', 'ARWR', 'XENE', 'MTCH', 'AX',
#        'PTCT', 'NTLA', 'RCKT', 'HLF', 'NFLX', 'SGRY', 'RCM', 'BGNE',
#        'TWLO', 'SPSC', 'NOW', 'AXON'], dtype=object), 'r_CAGR/retnStd': array(['CRSP', 'FATE', 'ARWR', 'VCEL', 'PTCT', 'XENE', 'NFLX', 'RCKT',
#        'NTLA', 'VIRT', 'AX', 'RCM', 'MTCH', 'SGRY', 'BGNE', 'PBR', 'HLF',
#        'TWLO', 'STX', 'ZG'], dtype=object), 'r_retnStd/UI': array(['VIRT', 'SPSC', 'XENE', 'KDP', 'QNST', 'HAE', 'AXON', 'FTSM',
#        'MTCH', 'CHGG', 'FTNT', 'CME', 'EVTC', 'TPR', 'DECK', 'IAC',
#        'COLM', 'HLF', 'NYT', 'NOW'], dtype=object)}}
# most_freq_syms: [('VIRT', 3), ('XENE', 3), ('MTCH', 3), ('HLF', 3), ('CRSP', 2), ('FATE', 2), ('VCEL', 2), ('ARWR', 2), ('AX', 2), ('PTCT', 2), ('NTLA', 2), ('RCKT', 2), ('NFLX', 2), ('SGRY', 2), ('RCM', 2), ('BGNE', 2), ('TWLO', 2), ('SPSC', 2), ('NOW', 2), ('AXON', 2), ('PBR', 1), ('STX', 1), ('ZG', 1), ('KDP', 1), ('QNST', 1), ('HAE', 1), ('FTSM', 1), ('CHGG', 1), ('FTNT', 1), ('CME', 1), ('EVTC', 1), ('TPR', 1), ('DECK', 1), ('IAC', 1), ('COLM', 1), ('NYT', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)]
# lb_slice:            (108, 228, 232)
# days eval:           4
# iloc_start_train:    108
# iloc_end_train:      228
# date_start_df_train: 2017-09-20
# date_end_df_train:   2018-03-13
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['HAE', 'CRSP', 'COLL', 'MTCH', 'FATE', 'RCM', 'SAGE', 'AMZN',
#        'NSP', 'RCKT', 'FTSM', 'GMED', 'QURE', 'AKAM', 'SHV', 'NTNX',
#        'STX', 'GDS', 'XPO', 'WWE'], dtype=object), 'r_CAGR/retnStd': array(['CRSP', 'FATE', 'RCKT', 'COLL', 'NTNX', 'RCM', 'GDS', 'STX',
#        'BOOT', 'HAE', 'GMED', 'MTCH', 'QURE', 'NSP', 'ENPH', 'AMZN', 'BR',
#        'WWE', 'NFLX', 'AXGN'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'SKX', 'SAGE', 'HAE', 'SHV', 'AKAM', 'AMZN', 'CME', 'MTCH',
#        'FTNT', 'TPR', 'PRAA', 'NSP', 'HI', 'MED', 'XPO', 'CMA', 'RF',
#        'RDWR', 'PODD'], dtype=object)}}
# most_freq_syms: [('HAE', 3), ('MTCH', 3), ('AMZN', 3), ('NSP', 3), ('CRSP', 2), ('COLL', 2), ('FATE', 2), ('RCM', 2), ('SAGE', 2), ('RCKT', 2), ('FTSM', 2), ('GMED', 2), ('QURE', 2), ('AKAM', 2), ('SHV', 2), ('NTNX', 2), ('STX', 2), ('GDS', 2), ('XPO', 2), ('WWE', 2), ('BOOT', 1), ('ENPH', 1), ('BR', 1), ('NFLX', 1), ('AXGN', 1), ('SKX', 1), ('CME', 1), ('FTNT', 1), ('TPR', 1), ('PRAA', 1), ('HI', 1), ('MED', 1), ('CMA', 1), ('RF', 1), ('RDWR', 1), ('PODD', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('PEN', 3), ('NTNX', 3), ('AXON', 3), ('MU', 3), ('ARWR', 3), ('ETSY', 3), ('VEEV', 3), ('LITE', 3), ('CYRX', 3), ('VCEL', 2), ('ENPH', 2), ('KDNY', 2), ('RCM', 2), ('CRSP', 2), ('HLF', 2), ('HHC', 2), ('MED', 2), ('SRPT', 2), ('PRFT', 2), ('MMYT', 2), ('PLAB', 1), ('SWN', 1), ('ZG', 1), ('NTLA', 1), ('FSS', 1), ('PLNT', 1), ('ADSK', 1), ('STX', 1), ('PAYC', 1), ('DENN', 1), ('SCL', 1)], [('ENPH', 3), ('VIRT', 3), ('NTNX', 3), ('LITE', 3), ('ETSY', 3), ('XENE', 3), ('WIX', 3), ('CIEN', 3), ('AXON', 3), ('ITCI', 3), ('QNST', 3), ('TWLO', 2), ('MU', 2), ('VCEL', 2), ('ZG', 2), ('RCM', 2), ('MTCH', 2), ('SPSC', 2), ('QURE', 2), ('FTNT', 2), ('AX', 1), ('VNDA', 1), ('KDNY', 1), ('VIAV', 1), ('HAE', 1), ('MODN', 1), ('BL', 1), ('SWKS', 1), ('FTSM', 1)], [('VIRT', 3), ('XENE', 3), ('MTCH', 3), ('HLF', 3), ('CRSP', 2), ('FATE', 2), ('VCEL', 2), ('ARWR', 2), ('AX', 2), ('PTCT', 2), ('NTLA', 2), ('RCKT', 2), ('NFLX', 2), ('SGRY', 2), ('RCM', 2), ('BGNE', 2), ('TWLO', 2), ('SPSC', 2), ('NOW', 2), ('AXON', 2), ('PBR', 1), ('STX', 1), ('ZG', 1), ('KDP', 1), ('QNST', 1), ('HAE', 1), ('FTSM', 1), ('CHGG', 1), ('FTNT', 1), ('CME', 1), ('EVTC', 1), ('TPR', 1), ('DECK', 1), ('IAC', 1), ('COLM', 1), ('NYT', 1)], [('HAE', 3), ('MTCH', 3), ('AMZN', 3), ('NSP', 3), ('CRSP', 2), ('COLL', 2), ('FATE', 2), ('RCM', 2), ('SAGE', 2), ('RCKT', 2), ('FTSM', 2), ('GMED', 2), ('QURE', 2), ('AKAM', 2), ('SHV', 2), ('NTNX', 2), ('STX', 2), ('GDS', 2), ('XPO', 2), ('WWE', 2), ('BOOT', 1), ('ENPH', 1), ('BR', 1), ('NFLX', 1), ('AXGN', 1), ('SKX', 1), ('CME', 1), ('FTNT', 1), ('TPR', 1), ('PRAA', 1), ('HI', 1), ('MED', 1), ('CMA', 1), ('RF', 1), ('RDWR', 1), ('PODD', 1)]]
# **** finish lookback slices [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)] ****
#
# top 20 ranked symbols and frequency from set [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)]:
# [('AXON', 8), ('MTCH', 8), ('NTNX', 8), ('RCM', 8), ('CRSP', 6), ('ENPH', 6), ('ETSY', 6), ('LITE', 6), ('VCEL', 6), ('VIRT', 6), ('XENE', 6), ('ARWR', 5), ('HAE', 5), ('HLF', 5), ('MU', 5), ('FATE', 4), ('FTNT', 4), ('FTSM', 4), ('QNST', 4), ('QURE', 4)]
# top 20 ranked symbols from set [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)]:
# ['AXON', 'MTCH', 'NTNX', 'RCM', 'CRSP', 'ENPH', 'ETSY', 'LITE', 'VCEL', 'VIRT']
# ===== finish top 20 ranked symbols from days_lookback set [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)] =====
#
#
#
# ########## 2 of 2 lb_slices: [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)] in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]
# lb_slice:            (877, 892, 896)
# days eval:           4
# iloc_start_train:    877
# iloc_end_train:      892
# date_start_df_train: 2020-10-09
# date_end_df_train:   2020-10-29
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['AVXL', 'MGI', 'ALGN', 'GBTC', 'STAA', 'ARWR', 'BTC-USD', 'FOLD',
#        'LOB', 'TPR', 'TCBI', 'PEN', 'HOG', 'PNM', 'RAMP', 'CROX', 'GTLS',
#        'X', 'DBRG', 'MDRX'], dtype=object), 'r_CAGR/retnStd': array(['AVXL', 'MGI', 'GBTC', 'STAA', 'ALGN', 'ARWR', 'FOLD', 'BTC-USD',
#        'TPR', 'TCBI', 'LOB', 'PEN', 'RAMP', 'GTLS', 'DBRG', 'X', 'HOG',
#        'CROX', 'SIG', 'ARLP'], dtype=object), 'r_retnStd/UI': array(['PNM', 'ALGN', 'AVXL', 'HOG', 'CROX', 'MAT', 'BTC-USD', 'LOB',
#        'STAA', 'PEN', 'WD', 'TPR', 'FSLR', 'TCBI', 'GBTC', 'ARWR', 'GTLS',
#        'SHOO', 'EXAS', 'IDXX'], dtype=object)}}
# most_freq_syms: [('AVXL', 3), ('ALGN', 3), ('GBTC', 3), ('STAA', 3), ('ARWR', 3), ('BTC-USD', 3), ('LOB', 3), ('TPR', 3), ('TCBI', 3), ('PEN', 3), ('HOG', 3), ('CROX', 3), ('GTLS', 3), ('MGI', 2), ('FOLD', 2), ('PNM', 2), ('RAMP', 2), ('X', 2), ('DBRG', 2), ('MDRX', 1), ('SIG', 1), ('ARLP', 1), ('MAT', 1), ('WD', 1), ('FSLR', 1), ('SHOO', 1), ('EXAS', 1), ('IDXX', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]
# lb_slice:            (862, 892, 896)
# days eval:           4
# iloc_start_train:    862
# iloc_end_train:      892
# date_start_df_train: 2020-09-18
# date_end_df_train:   2020-10-29
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['SPWR', 'EXAS', 'FSLR', 'BPMC', 'PAYC', 'DQ', 'PNM', 'STAA',
#        'TCBI', 'MGI', 'RAMP', 'PCTY', 'ENPH', 'ALGN', 'CROX', 'LOB',
#        'TTD', 'ARWR', 'IDXX', 'MELI'], dtype=object), 'r_CAGR/retnStd': array(['DQ', 'SPWR', 'ENPH', 'PAYC', 'TTD', 'EXAS', 'TCBI', 'ACRS', 'LOB',
#        'FSLR', 'MGI', 'PCTY', 'BPMC', 'CROX', 'DBRG', 'MELI', 'HRB',
#        'STAA', 'RAMP', 'ARWR'], dtype=object), 'r_retnStd/UI': array(['PNM', 'ALGN', 'BPMC', 'FSLR', 'EXAS', 'STAA', 'RAMP', 'IDXX',
#        'DUK', 'MAT', 'PKX', 'PEG', 'HAE', 'GNRC', 'MDRX', 'MPWR', 'LSCC',
#        'BABA', 'ARWR', 'SHOO'], dtype=object)}}
# most_freq_syms: [('EXAS', 3), ('FSLR', 3), ('BPMC', 3), ('STAA', 3), ('RAMP', 3), ('ARWR', 3), ('SPWR', 2), ('PAYC', 2), ('DQ', 2), ('PNM', 2), ('TCBI', 2), ('MGI', 2), ('PCTY', 2), ('ENPH', 2), ('ALGN', 2), ('CROX', 2), ('LOB', 2), ('TTD', 2), ('IDXX', 2), ('MELI', 2), ('ACRS', 1), ('DBRG', 1), ('HRB', 1), ('DUK', 1), ('MAT', 1), ('PKX', 1), ('PEG', 1), ('HAE', 1), ('GNRC', 1), ('MDRX', 1), ('MPWR', 1), ('LSCC', 1), ('BABA', 1), ('SHOO', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]
# lb_slice:            (832, 892, 896)
# days eval:           4
# iloc_start_train:    832
# iloc_end_train:      892
# date_start_df_train: 2020-08-06
# date_end_df_train:   2020-10-29
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['GOGO', 'GME', 'LOB', 'SPWR', 'SIG', 'FDX', 'DBRG', 'DAR', 'MEOH',
#        'TGH', 'ACRS', 'CROX', 'SLM', 'PWR', 'DDS', 'R', 'BFAM', 'NVCR',
#        'TPR', 'CTRN'], dtype=object), 'r_CAGR/retnStd': array(['GOGO', 'GME', 'LOB', 'SPWR', 'SIG', 'DBRG', 'ACRS', 'FDX', 'TPR',
#        'NVCR', 'MEOH', 'DDS', 'DAR', 'TGH', 'R', 'BOOT', 'PWR', 'SLM',
#        'HIBB', 'EAT'], dtype=object), 'r_retnStd/UI': array(['ALGN', 'GME', 'FDX', 'LOB', 'BFAM', 'BKE', 'QNST', 'GOGO', 'CROX',
#        'CLAR', 'NKE', 'AQN', 'SCHW', 'AZPN', 'TGH', 'DAR', 'SIG', 'RC',
#        'CORT', 'PERI'], dtype=object)}}
# most_freq_syms: [('GOGO', 3), ('GME', 3), ('LOB', 3), ('SIG', 3), ('FDX', 3), ('DAR', 3), ('TGH', 3), ('SPWR', 2), ('DBRG', 2), ('MEOH', 2), ('ACRS', 2), ('CROX', 2), ('SLM', 2), ('PWR', 2), ('DDS', 2), ('R', 2), ('BFAM', 2), ('NVCR', 2), ('TPR', 2), ('CTRN', 1), ('BOOT', 1), ('HIBB', 1), ('EAT', 1), ('ALGN', 1), ('BKE', 1), ('QNST', 1), ('CLAR', 1), ('NKE', 1), ('AQN', 1), ('SCHW', 1), ('AZPN', 1), ('RC', 1), ('CORT', 1), ('PERI', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]
# lb_slice:            (772, 892, 896)
# days eval:           4
# iloc_start_train:    772
# iloc_end_train:      892
# date_start_df_train: 2020-05-12
# date_end_df_train:   2020-10-29
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['APPS', 'GOGO', 'RUN', 'SPWR', 'FDX', 'PLUG', 'DQ', 'CROX', 'CELH',
#        'VSTO', 'LOB', 'COOP', 'GNRC', 'HIBB', 'UPS', 'DAR', 'BBWI',
#        'GTLS', 'FCX', 'GPS'], dtype=object), 'r_CAGR/retnStd': array(['APPS', 'GOGO', 'RUN', 'LOB', 'CELH', 'SPWR', 'DQ', 'VSTO', 'PLUG',
#        'FDX', 'OSTK', 'BBWI', 'GNRC', 'CROX', 'HIBB', 'CAR', 'DAR',
#        'TRUP', 'GTLS', 'PWR'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'UPS', 'ALGN', 'CROX', 'FCX', 'HZNP', 'CCS', 'GOGO',
#        'SAGE', 'APPS', 'FDX', 'ON', 'TMO', 'STKL', 'BSIG', 'QCOM', 'COOP',
#        'TSM', 'DG', 'AVGO'], dtype=object)}}
# most_freq_syms: [('APPS', 3), ('GOGO', 3), ('FDX', 3), ('CROX', 3), ('RUN', 2), ('SPWR', 2), ('PLUG', 2), ('DQ', 2), ('CELH', 2), ('VSTO', 2), ('LOB', 2), ('COOP', 2), ('GNRC', 2), ('HIBB', 2), ('UPS', 2), ('DAR', 2), ('BBWI', 2), ('GTLS', 2), ('FCX', 2), ('GPS', 1), ('OSTK', 1), ('CAR', 1), ('TRUP', 1), ('PWR', 1), ('FTSM', 1), ('ALGN', 1), ('HZNP', 1), ('CCS', 1), ('SAGE', 1), ('ON', 1), ('TMO', 1), ('STKL', 1), ('BSIG', 1), ('QCOM', 1), ('TSM', 1), ('DG', 1), ('AVGO', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('AVXL', 3), ('ALGN', 3), ('GBTC', 3), ('STAA', 3), ('ARWR', 3), ('BTC-USD', 3), ('LOB', 3), ('TPR', 3), ('TCBI', 3), ('PEN', 3), ('HOG', 3), ('CROX', 3), ('GTLS', 3), ('MGI', 2), ('FOLD', 2), ('PNM', 2), ('RAMP', 2), ('X', 2), ('DBRG', 2), ('MDRX', 1), ('SIG', 1), ('ARLP', 1), ('MAT', 1), ('WD', 1), ('FSLR', 1), ('SHOO', 1), ('EXAS', 1), ('IDXX', 1)], [('EXAS', 3), ('FSLR', 3), ('BPMC', 3), ('STAA', 3), ('RAMP', 3), ('ARWR', 3), ('SPWR', 2), ('PAYC', 2), ('DQ', 2), ('PNM', 2), ('TCBI', 2), ('MGI', 2), ('PCTY', 2), ('ENPH', 2), ('ALGN', 2), ('CROX', 2), ('LOB', 2), ('TTD', 2), ('IDXX', 2), ('MELI', 2), ('ACRS', 1), ('DBRG', 1), ('HRB', 1), ('DUK', 1), ('MAT', 1), ('PKX', 1), ('PEG', 1), ('HAE', 1), ('GNRC', 1), ('MDRX', 1), ('MPWR', 1), ('LSCC', 1), ('BABA', 1), ('SHOO', 1)], [('GOGO', 3), ('GME', 3), ('LOB', 3), ('SIG', 3), ('FDX', 3), ('DAR', 3), ('TGH', 3), ('SPWR', 2), ('DBRG', 2), ('MEOH', 2), ('ACRS', 2), ('CROX', 2), ('SLM', 2), ('PWR', 2), ('DDS', 2), ('R', 2), ('BFAM', 2), ('NVCR', 2), ('TPR', 2), ('CTRN', 1), ('BOOT', 1), ('HIBB', 1), ('EAT', 1), ('ALGN', 1), ('BKE', 1), ('QNST', 1), ('CLAR', 1), ('NKE', 1), ('AQN', 1), ('SCHW', 1), ('AZPN', 1), ('RC', 1), ('CORT', 1), ('PERI', 1)], [('APPS', 3), ('GOGO', 3), ('FDX', 3), ('CROX', 3), ('RUN', 2), ('SPWR', 2), ('PLUG', 2), ('DQ', 2), ('CELH', 2), ('VSTO', 2), ('LOB', 2), ('COOP', 2), ('GNRC', 2), ('HIBB', 2), ('UPS', 2), ('DAR', 2), ('BBWI', 2), ('GTLS', 2), ('FCX', 2), ('GPS', 1), ('OSTK', 1), ('CAR', 1), ('TRUP', 1), ('PWR', 1), ('FTSM', 1), ('ALGN', 1), ('HZNP', 1), ('CCS', 1), ('SAGE', 1), ('ON', 1), ('TMO', 1), ('STKL', 1), ('BSIG', 1), ('QCOM', 1), ('TSM', 1), ('DG', 1), ('AVGO', 1)]]
# **** finish lookback slices [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)] ****
#
# top 20 ranked symbols and frequency from set [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]:
# [('CROX', 10), ('LOB', 10), ('ALGN', 7), ('ARWR', 6), ('FDX', 6), ('GOGO', 6), ('SPWR', 6), ('STAA', 6), ('DAR', 5), ('DBRG', 5), ('GTLS', 5), ('RAMP', 5), ('TCBI', 5), ('TPR', 5), ('DQ', 4), ('EXAS', 4), ('FSLR', 4), ('MGI', 4), ('PNM', 4), ('SIG', 4)]
# top 20 ranked symbols from set [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]:
# ['CROX', 'LOB', 'ALGN', 'ARWR', 'FDX', 'GOGO', 'SPWR', 'STAA', 'DAR', 'DBRG']
# ===== finish top 20 ranked symbols from days_lookback set [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)] =====
#
#
# max_lookback_slices:             [(108, 228, 232), (772, 892, 896)]
# set_lookback_slices 1 of   2:    [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)]
#
# max_days_lookbacks:              120
# df end date for days_lookbacks:  2018-03-13
# days_lookbacks:                  [15, 30, 60, 120]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     []
# sym_freq_9:                      []
# sym_freq_8:                      ['AXON', 'MTCH', 'NTNX', 'RCM']
# sym_freq_7:                      []
# sym_freq_6:                      ['CRSP', 'ENPH', 'ETSY', 'LITE', 'VCEL', 'VIRT', 'XENE']
# sym_freq_5:                      ['ARWR', 'HAE', 'HLF', 'MU']
# sym_freq_4:                      ['FATE', 'FTNT', 'FTSM', 'QNST', 'QURE']
# sym_freq_3:                      []
# sym_freq_2:                      []
#
# max_lookback_slices:             [(108, 228, 232), (772, 892, 896)]
# set_lookback_slices 2 of   2:    [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]
#
# max_days_lookbacks:              120
# df end date for days_lookbacks:  2020-10-29
# days_lookbacks:                  [15, 30, 60, 120]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     ['CROX', 'LOB']
# sym_freq_9:                      []
# sym_freq_8:                      []
# sym_freq_7:                      ['ALGN']
# sym_freq_6:                      ['ARWR', 'FDX', 'GOGO', 'SPWR', 'STAA']
# sym_freq_5:                      ['DAR', 'DBRG', 'GTLS', 'RAMP', 'TCBI', 'TPR']
# sym_freq_4:                      ['DQ', 'EXAS', 'FSLR', 'MGI', 'PNM', 'SIG']
# sym_freq_3:                      []
# sym_freq_2:                      []
#
# z_grp_top_set_syms_n_freq:
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
#
#
# 1 of 2 max_lookback_slice: (108, 228, 232)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2017-09-20', '2017-09-21', '2017-09-22', '2017-09-25', '2017-09-26', '2017-09-27', '2017-09-28', '2017-09-29', '2017-10-02', '2017-10-03',
#                ...
#                '2018-02-28', '2018-03-01', '2018-03-02', '2018-03-05', '2018-03-06', '2018-03-07', '2018-03-08', '2018-03-09', '2018-03-12', '2018-03-13'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2017-09-20 - 2018-03-13
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2018-03-14', '2018-03-15', '2018-03-16', '2018-03-19'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2018-03-14 - 2018-03-19
#
# top_set_syms_n_freq: [('AXON', 8), ('MTCH', 8), ('NTNX', 8), ('RCM', 8), ('CRSP', 6), ('ENPH', 6), ('ETSY', 6), ('LITE', 6), ('VCEL', 6), ('VIRT', 6), ('XENE', 6), ('ARWR', 5), ('HAE', 5), ('HLF', 5), ('MU', 5), ('FATE', 4), ('FTNT', 4), ('FTSM', 4), ('QNST', 4), ('QURE', 4)]
#
# set_lookback_slices: [(213, 228, 232), (198, 228, 232), (168, 228, 232), (108, 228, 232)]
# max_lookback_slice:  (108, 228, 232)
# days_lookbacks:      [15, 30, 60, 120]
# date_end_df_train:   2018-03-13
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['AXON', 'MTCH', 'NTNX', 'RCM']
# sym_freq_7:          []
# sym_freq_6:          ['CRSP', 'ENPH', 'ETSY', 'LITE', 'VCEL', 'VIRT', 'XENE']
# sym_freq_5:          ['ARWR', 'HAE', 'HLF', 'MU']
# sym_freq_4:          ['FATE', 'FTNT', 'FTSM', 'QNST', 'QURE']
# sym_freq_3:          []
# sym_freq_2:          []
#
# iloc_start_eval:    228,  df_eval first date: 2018-03-14
# iloc_end_eval:      232,  df_eval last date:  2018-03-19
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#                  AXON       MTCH       NTNX   RCM         SPY
# Date
# 2018-03-14  39.009998  44.532883  54.660000  7.66  251.801041
# 2018-03-15  38.619999  44.456741  54.410000  7.74  251.526718
# 2018-03-16  37.970001  44.228321  53.740002  7.77  251.799393
# 2018-03-19  37.400002  43.447876  53.000000  7.75  248.392441
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.2756
# grp(CAGR)_std                               1.1225
# grp(CAGR)_mean/std                         -0.2455
# grp(CAGR/UI)_mean                         283.8193
# grp(CAGR/UI)_std                          584.3401
# grp(CAGR/UI)_mean/std                       0.4857
# grp(CAGR/retnStd)_mean                    -94.7676
# grp(CAGR/retnStd)_std                     247.1221
# grp(CAGR/retnStd)_mean/std                 -0.3835
# grp(retnStd/UI)_mean                        1.2538
# grp(retnStd/UI)_std                         1.6675
# grp(retnStd/UI)_mean/std                    0.7519
# SPY_CAGR                                   -0.6817
# SPY_CAGR/UI                              -100.3977
# SPY_CAGR/retnStd                         -105.8842
# SPY_retnStd/UI                              0.9482
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
# iloc_start_eval:    228,  df_eval first date: 2018-03-14
# iloc_end_eval:      232,  df_eval last date:  2018-03-19
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  CRSP  ENPH       ETSY       LITE   VCEL       VIRT   XENE         SPY
# Date
# 2018-03-14  58.169998  4.25  28.370001  73.199997  11.65  27.261696  4.625  251.801041
# 2018-03-15  52.599998  4.41  28.379999  71.199997  11.25  26.894949  4.700  251.526718
# 2018-03-16  51.770000  4.72  28.299999  69.949997  11.60  26.446699  4.600  251.799393
# 2018-03-19  51.520000  4.74  27.830000  69.050003  11.25  26.813452  4.650  248.392441
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                          1,365.8008
# grp(CAGR)_std                           3,347.1152
# grp(CAGR)_mean/std                          0.4081
# grp(CAGR/UI)_mean               2,732,721,430.7014
# grp(CAGR/UI)_std                6,693,773,175.6424
# grp(CAGR/UI)_mean/std                       0.4082
# grp(CAGR/retnStd)_mean                 50,615.1152
# grp(CAGR/retnStd)_std                 124,124.1945
# grp(CAGR/retnStd)_mean/std                  0.4078
# grp(retnStd/UI)_mean                    7,705.9462
# grp(retnStd/UI)_std                    18,873.7122
# grp(retnStd/UI)_mean/std                    0.4083
# SPY_CAGR                                   -0.6817
# SPY_CAGR/UI                              -100.3977
# SPY_CAGR/retnStd                         -105.8842
# SPY_retnStd/UI                              0.9482
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
# iloc_start_eval:    228,  df_eval first date: 2018-03-14
# iloc_end_eval:      232,  df_eval last date:  2018-03-19
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#             ARWR        HAE        HLF         MU         SPY
# Date
# 2018-03-14  7.37  74.279999  49.349998  59.175426  251.801041
# 2018-03-15  7.57  73.180000  48.775002  58.244930  251.526718
# 2018-03-16  7.53  73.580002  48.560001  59.967327  251.799393
# 2018-03-19  7.17  72.980003  47.889999  59.531780  248.392441
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.4844
# grp(CAGR)_std                               0.6608
# grp(CAGR)_mean/std                         -0.7331
# grp(CAGR/UI)_mean                         -18.0612
# grp(CAGR/UI)_std                           55.0971
# grp(CAGR/UI)_mean/std                      -0.3278
# grp(CAGR/retnStd)_mean                    -79.1431
# grp(CAGR/retnStd)_std                      97.1274
# grp(CAGR/retnStd)_mean/std                 -0.8148
# grp(retnStd/UI)_mean                        1.0832
# grp(retnStd/UI)_std                         0.7603
# grp(retnStd/UI)_mean/std                    1.4247
# SPY_CAGR                                   -0.6817
# SPY_CAGR/UI                              -100.3977
# SPY_CAGR/retnStd                         -105.8842
# SPY_retnStd/UI                              0.9482
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
# iloc_start_eval:    228,  df_eval first date: 2018-03-14
# iloc_end_eval:      232,  df_eval last date:  2018-03-19
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#              FATE    FTNT       FTSM   QNST       QURE         SPY
# Date
# 2018-03-14  11.73  10.908  55.126564  13.86  22.360001  251.801041
# 2018-03-15  11.87  10.836  55.140347  13.68  21.719999  251.526718
# 2018-03-16  11.83  10.800  55.135754  13.80  21.590000  251.799393
# 2018-03-19  11.72  10.670  55.126564  13.76  20.780001  248.392441
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.4732
# grp(CAGR)_std                               0.3999
# grp(CAGR)_mean/std                         -1.1832
# grp(CAGR/UI)_mean                         -32.2370
# grp(CAGR/UI)_std                           26.6779
# grp(CAGR/UI)_mean/std                      -1.2084
# grp(CAGR/retnStd)_mean                    -73.7570
# grp(CAGR/retnStd)_std                      85.0738
# grp(CAGR/retnStd)_mean/std                 -0.8670
# grp(retnStd/UI)_mean                        0.8981
# grp(retnStd/UI)_std                         0.4922
# grp(retnStd/UI)_mean/std                    1.8246
# SPY_CAGR                                   -0.6817
# SPY_CAGR/UI                              -100.3977
# SPY_CAGR/retnStd                         -105.8842
# SPY_retnStd/UI                              0.9482
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, -0.47319090872977065, 0.3999293996026231, -1.1831861053474475, -32.237029005261, 26.677902866760565, -1.2083794279582167, -73.75696713331193, 85.0738498985509, -0.8669757771778971, 0.8980578061175631, 0.4922010712017256, 1.824575074420144, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
# ================================================================================
#
#
#
# 2 of 2 max_lookback_slice: (772, 892, 896)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15', '2020-05-18', '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22', '2020-05-26',
#                ...
#                '2020-10-16', '2020-10-19', '2020-10-20', '2020-10-21', '2020-10-22', '2020-10-23', '2020-10-26', '2020-10-27', '2020-10-28', '2020-10-29'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2020-05-12 - 2020-10-29
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2020-10-30', '2020-11-02', '2020-11-03', '2020-11-04'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2020-10-30 - 2020-11-04
#
# top_set_syms_n_freq: [('CROX', 10), ('LOB', 10), ('ALGN', 7), ('ARWR', 6), ('FDX', 6), ('GOGO', 6), ('SPWR', 6), ('STAA', 6), ('DAR', 5), ('DBRG', 5), ('GTLS', 5), ('RAMP', 5), ('TCBI', 5), ('TPR', 5), ('DQ', 4), ('EXAS', 4), ('FSLR', 4), ('MGI', 4), ('PNM', 4), ('SIG', 4)]
#
# set_lookback_slices: [(877, 892, 896), (862, 892, 896), (832, 892, 896), (772, 892, 896)]
# max_lookback_slice:  (772, 892, 896)
# days_lookbacks:      [15, 30, 60, 120]
# date_end_df_train:   2020-10-29
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         ['CROX', 'LOB']
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['ALGN']
# sym_freq_6:          ['ARWR', 'FDX', 'GOGO', 'SPWR', 'STAA']
# sym_freq_5:          ['DAR', 'DBRG', 'GTLS', 'RAMP', 'TCBI', 'TPR']
# sym_freq_4:          ['DQ', 'EXAS', 'FSLR', 'MGI', 'PNM', 'SIG']
# sym_freq_3:          []
# sym_freq_2:          []
#
# iloc_start_eval:    892,  df_eval first date: 2020-10-30
# iloc_end_eval:      896,  df_eval last date:  2020-11-04
# frequency count of symbol(s): 10
#
# df_eval_n_SPY:
#                  CROX        LOB         SPY
# Date
# 2020-10-30  52.330002  37.040283  314.553650
# 2020-11-02  53.810001  37.745720  318.079346
# 2020-11-03  55.150002  39.156586  323.695312
# 2020-11-04  56.040001  37.874889  330.929657
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                            159.9201
# grp(CAGR)_std                             154.4207
# grp(CAGR)_mean/std                          1.0356
# grp(CAGR/UI)_mean                 314,341,020.1897
# grp(CAGR/UI)_std                  314,340,684.1689
# grp(CAGR/UI)_mean/std                       1.0000
# grp(CAGR/retnStd)_mean                 30,803.3803
# grp(CAGR/retnStd)_std                  30,618.1418
# grp(CAGR/retnStd)_mean/std                  1.0060
# grp(retnStd/UI)_mean                    5,118.6710
# grp(retnStd/UI)_std                     5,116.8570
# grp(retnStd/UI)_mean/std                    1.0004
# SPY_CAGR                                   70.0298
# SPY_CAGR/UI                       140,059,623.8102
# SPY_CAGR/retnStd                       15,334.1770
# SPY_retnStd/UI                          9,133.8208
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, -0.47319090872977065, 0.3999293996026231, -1.1831861053474475, -32.237029005261, 26.677902866760565, -1.2083794279582167, -73.75696713331193, 85.0738498985509, -0.8669757771778971, 0.8980578061175631, 0.4922010712017256, 1.824575074420144, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, 159.92013348249, 154.42071869679515, 1.035613192530809, 314341020.18968123, 314340684.1688891, 1.0000010689700984, 30803.38033120863, 30618.14179265971, 1.0060499601773132, 5118.670952960623, 5116.856963308083, 1.0003545124801314, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# iloc_start_eval:    892,  df_eval first date: 2020-10-30
# iloc_end_eval:      896,  df_eval last date:  2020-11-04
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                   ALGN         SPY
# Date
# 2020-10-30  426.079987  314.553650
# 2020-11-02  458.440002  318.079346
# 2020-11-03  465.010010  323.695312
# 2020-11-04  483.459991  330.929657
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                         40,646.1396
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                             inf
# grp(CAGR/UI)_mean              81,292,279,106.1256
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                          inf
# grp(CAGR/retnStd)_mean              1,607,423.1151
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                     inf
# grp(retnStd/UI)_mean                   50,573.0435
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                   70.0298
# SPY_CAGR/UI                       140,059,623.8102
# SPY_CAGR/retnStd                       15,334.1770
# SPY_retnStd/UI                          9,133.8208
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, -0.47319090872977065, 0.3999293996026231, -1.1831861053474475, -32.237029005261, 26.677902866760565, -1.2083794279582167, -73.75696713331193, 85.0738498985509, -0.8669757771778971, 0.8980578061175631, 0.4922010712017256, 1.824575074420144, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, 159.92013348249, 154.42071869679515, 1.035613192530809, 314341020.18968123, 314340684.1688891, 1.0000010689700984, 30803.38033120863, 30618.14179265971, 1.0060499601773132, 5118.670952960623, 5116.856963308083, 1.0003545124801314, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 40646.13955306278, 0.0, inf, 81292279106.12556, 0.0, inf, 1607423.115101168, 0.0, inf, 50573.04348955389, 0.0, inf, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# iloc_start_eval:    892,  df_eval first date: 2020-10-30
# iloc_end_eval:      896,  df_eval last date:  2020-11-04
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  ARWR         FDX   GOGO       SPWR       STAA         SPY
# Date
# 2020-10-30  57.299999  249.451599  8.040  15.990000  72.500000  314.553650
# 2020-11-02  58.220001  256.671631  8.315  16.850000  71.760002  318.079346
# 2020-11-03  59.470001  263.882080  8.640  17.049999  70.440002  323.695312
# 2020-11-04  64.339996  258.709808  8.480  16.570000  73.190002  330.929657
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                          3,401.6337
# grp(CAGR)_std                           6,739.6496
# grp(CAGR)_mean/std                          0.5047
# grp(CAGR/UI)_mean               6,752,325,138.3088
# grp(CAGR/UI)_std               13,504,643,835.2283
# grp(CAGR/UI)_mean/std                       0.5000
# grp(CAGR/retnStd)_mean                114,109.3915
# grp(CAGR/retnStd)_std                 225,800.9027
# grp(CAGR/retnStd)_mean/std                  0.5054
# grp(retnStd/UI)_mean                   11,937.9454
# grp(retnStd/UI)_std                    23,871.2966
# grp(retnStd/UI)_mean/std                    0.5001
# SPY_CAGR                                   70.0298
# SPY_CAGR/UI                       140,059,623.8102
# SPY_CAGR/retnStd                       15,334.1770
# SPY_retnStd/UI                          9,133.8208
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, -0.47319090872977065, 0.3999293996026231, -1.1831861053474475, -32.237029005261, 26.677902866760565, -1.2083794279582167, -73.75696713331193, 85.0738498985509, -0.8669757771778971, 0.8980578061175631, 0.4922010712017256, 1.824575074420144, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, 159.92013348249, 154.42071869679515, 1.035613192530809, 314341020.18968123, 314340684.1688891, 1.0000010689700984, 30803.38033120863, 30618.14179265971, 1.0060499601773132, 5118.670952960623, 5116.856963308083, 1.0003545124801314, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 40646.13955306278, 0.0, inf, 81292279106.12556, 0.0, inf, 1607423.115101168, 0.0, inf, 50573.04348955389, 0.0, inf, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3401.633691570337, 6739.649597516396, 0.504719665666871, 6752325138.308827, 13504643835.228329, 0.5000002384879381, 114109.39151313997, 225800.90273944652, 0.5053540093451784, 11937.945389314584, 23871.29655165039, 0.5000962291044568, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# iloc_start_eval:    892,  df_eval first date: 2020-10-30
# iloc_end_eval:      896,  df_eval last date:  2020-11-04
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   DAR       DBRG       GTLS       RAMP       TCBI        TPR         SPY
# Date
# 2020-10-30  43.000000  14.203535  84.449997  66.089996  45.000000  21.146803  314.553650
# 2020-11-02  43.840000  14.642408  86.519997  63.950001  45.009998  22.478584  318.079346
# 2020-11-03  45.419998  14.602510  86.230003  66.730003  45.290001  22.887636  323.695312
# 2020-11-04  43.720001  14.682306  85.989998  70.010002  43.970001  22.678352  330.929657
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             83.4833
# grp(CAGR)_std                             128.9940
# grp(CAGR)_mean/std                          0.6472
# grp(CAGR/UI)_mean                      16,260.1492
# grp(CAGR/UI)_std                       27,720.1164
# grp(CAGR/UI)_mean/std                       0.5866
# grp(CAGR/retnStd)_mean                  2,779.3573
# grp(CAGR/retnStd)_std                   4,251.1472
# grp(CAGR/retnStd)_mean/std                  0.6538
# grp(retnStd/UI)_mean                        4.2954
# grp(retnStd/UI)_std                         3.2936
# grp(retnStd/UI)_mean/std                    1.3042
# SPY_CAGR                                   70.0298
# SPY_CAGR/UI                       140,059,623.8102
# SPY_CAGR/retnStd                       15,334.1770
# SPY_retnStd/UI                          9,133.8208
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, -0.47319090872977065, 0.3999293996026231, -1.1831861053474475, -32.237029005261, 26.677902866760565, -1.2083794279582167, -73.75696713331193, 85.0738498985509, -0.8669757771778971, 0.8980578061175631, 0.4922010712017256, 1.824575074420144, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, 159.92013348249, 154.42071869679515, 1.035613192530809, 314341020.18968123, 314340684.1688891, 1.0000010689700984, 30803.38033120863, 30618.14179265971, 1.0060499601773132, 5118.670952960623, 5116.856963308083, 1.0003545124801314, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 40646.13955306278, 0.0, inf, 81292279106.12556, 0.0, inf, 1607423.115101168, 0.0, inf, 50573.04348955389, 0.0, inf, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3401.633691570337, 6739.649597516396, 0.504719665666871, 6752325138.308827, 13504643835.228329, 0.5000002384879381, 114109.39151313997, 225800.90273944652, 0.5053540093451784, 11937.945389314584, 23871.29655165039, 0.5000962291044568, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]]
# type(row_add_total): <class 'list'>
# ...
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.31793279282177966, 2.316051483014527, 0.1372736293443549, 2.5474221167362443, 72.33594106190257, 0.03521654767104294, -11.947158635293066, 44.66762849686599, -0.26746794126604045, 1.176603981405654, 0.5083201164927338, 2.3146909658502035, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# ================================================================================
#
#
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, -0.47319090872977065, 0.3999293996026231, -1.1831861053474475, -32.237029005261, 26.677902866760565, -1.2083794279582167, -73.75696713331193, 85.0738498985509, -0.8669757771778971, 0.8980578061175631, 0.4922010712017256, 1.824575074420144, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, 159.92013348249, 154.42071869679515, 1.035613192530809, 314341020.18968123, 314340684.1688891, 1.0000010689700984, 30803.38033120863, 30618.14179265971, 1.0060499601773132, 5118.670952960623, 5116.856963308083, 1.0003545124801314, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 40646.13955306278, 0.0, inf, 81292279106.12556, 0.0, inf, 1607423.115101168, 0.0, inf, 50573.04348955389, 0.0, inf, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3401.633691570337, 6739.649597516396, 0.504719665666871, 6752325138.308827, 13504643835.228329, 0.5000002384879381, 114109.39151313997, 225800.90273944652, 0.5053540093451784, 11937.945389314584, 23871.29655165039, 0.5000962291044568, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 83.48325162674625, 128.9940108828155, 0.6471870364786667, 16260.149223025952, 27720.116387330425, 0.5865830069334669, 2779.357311198339, 4251.147193161334, 0.6537899500796844, 4.295425772794341, 3.293588706235661, 1.3041779517466556, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.31793279282177966, 2.316051483014527, 0.1372736293443549, 2.5474221167362443, 72.33594106190257, 0.03521654767104294, -11.947158635293066, 44.66762849686599, -0.26746794126604045, 1.176603981405654, 0.5083201164927338, 2.3146909658502035, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]]
#
#
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, -0.47319090872977065, 0.3999293996026231, -1.1831861053474475, -32.237029005261, 26.677902866760565, -1.2083794279582167, -73.75696713331193, 85.0738498985509, -0.8669757771778971, 0.8980578061175631, 0.4922010712017256, 1.824575074420144, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, 159.92013348249, 154.42071869679515, 1.035613192530809, 314341020.18968123, 314340684.1688891, 1.0000010689700984, 30803.38033120863, 30618.14179265971, 1.0060499601773132, 5118.670952960623, 5116.856963308083, 1.0003545124801314, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 40646.13955306278, 0.0, inf, 81292279106.12556, 0.0, inf, 1607423.115101168, 0.0, inf, 50573.04348955389, 0.0, inf, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3401.633691570337, 6739.649597516396, 0.504719665666871, 6752325138.308827, 13504643835.228329, 0.5000002384879381, 114109.39151313997, 225800.90273944652, 0.5053540093451784, 11937.945389314584, 23871.29655165039, 0.5000962291044568, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 83.48325162674625, 128.9940108828155, 0.6471870364786667, 16260.149223025952, 27720.116387330425, 0.5865830069334669, 2779.357311198339, 4251.147193161334, 0.6537899500796844, 4.295425772794341, 3.293588706235661, 1.3041779517466556, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.31793279282177966, 2.316051483014527, 0.1372736293443549, 2.5474221167362443, 72.33594106190257, 0.03521654767104294, -11.947158635293066, 44.66762849686599, -0.26746794126604045, 1.176603981405654, 0.5083201164927338, 2.3146909658502035, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
# df_eval_results BEFORW store results:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 8, -0.27560996716614283, 1.1224592550347376, -0.2455411774903253, 283.819318543447, 584.3400660881404, 0.4857091529654522, -94.76763932589179, 247.12213513165958, -0.38348502968138537, 1.2538086540192481, 1.6674976139762547, 0.7519103137002164, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1365.8008433417276, 3347.115194222597, 0.40805313354593087, 2732721430.7014394, 6693773175.642403, 0.40824828672793795, 50615.11517605523, 124124.1944551442, 0.40777799524287295, 7705.946154663457, 18873.71222239064, 0.40828990417272465, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, -0.4844463673662893, 0.6607782473384467, -0.7331451501583084, -18.061187191229703, 55.09707277766772, -0.32780665615597593, -79.14309066183016, 97.12736819669338, -0.8148382081305536, 1.0832418081298387, 0.760323629270261, 1.424711486567248, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, -0.47319090872977065, 0.3999293996026231, -1.1831861053474475, -32.237029005261, 26.677902866760565, -1.2083794279582167, -73.75696713331193, 85.0738498985509, -0.8669757771778971, 0.8980578061175631, 0.4922010712017256, 1.824575074420144, -0.6817328834714468, -100.39770145526072, -105.88420029322543, 0.9481839705756767]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, 159.92013348249, 154.42071869679515, 1.035613192530809, 314341020.18968123, 314340684.1688891, 1.0000010689700984, 30803.38033120863, 30618.14179265971, 1.0060499601773132, 5118.670952960623, 5116.856963308083, 1.0003545124801314, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 40646.13955306278, 0.0, inf, 81292279106.12556, 0.0, inf, 1607423.115101168, 0.0, inf, 50573.04348955389, 0.0, inf, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 3401.633691570337, 6739.649597516396, 0.504719665666871, 6752325138.308827, 13504643835.228329, 0.5000002384879381, 114109.39151313997, 225800.90273944652, 0.5053540093451784, 11937.945389314584, 23871.29655165039, 0.5000962291044568, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 83.48325162674625, 128.9940108828155, 0.6471870364786667, 16260.149223025952, 27720.116387330425, 0.5865830069334669, 2779.357311198339, 4251.147193161334, 0.6537899500796844, 4.295425772794341, 3.293588706235661, 1.3041779517466556, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 0.31793279282177966, 2.316051483014527, 0.1372736293443549, 2.5474221167362443, 72.33594106190257, 0.03521654767104294, -11.947158635293066, 44.66762849686599, -0.26746794126604045, 1.176603981405654, 0.5083201164927338, 2.3146909658502035, 70.02981190508693, 140059623.81017387, 15334.17696340347, 9133.820755064977]
#
# Save results to: test_df_eval
# df_eval_results AFTER store results:
#    n_samples     days_lookbacks  days_eval  n_top_syms  syms_start  syms_end  sym_freq_cnt  grp(CAGR)_mean  grp(CAGR)_std  grp(CAGR)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  grp(CAGR/retnStd)_mean  grp(CAGR/retnStd)_std  grp(CAGR/retnStd)_mean/std  grp(retnStd/UI)_mean  grp(retnStd/UI)_std  grp(retnStd/UI)_mean/std   SPY_CAGR   SPY_CAGR/UI  SPY_CAGR/retnStd  SPY_retnStd/UI
# 0          2  [15, 30, 60, 120]          4          20           0        10             8       -0.275610       1.122459           -0.245541       2.838193e+02      5.843401e+02             0.485709          -9.476764e+01              247.122135              -0.383485                    1.253809              1.667498             0.751910       -0.681733 -1.003977e+02       -105.884200        0.948184
# 1          2  [15, 30, 60, 120]          4          20           0        10             6     1365.800843    3347.115194            0.408053       2.732721e+09      6.693773e+09             0.408248           5.061512e+04           124124.194455               0.407778                 7705.946155          18873.712222             0.408290       -0.681733 -1.003977e+02       -105.884200        0.948184
# 2          2  [15, 30, 60, 120]          4          20           0        10             5       -0.484446       0.660778           -0.733145      -1.806119e+01      5.509707e+01            -0.327807          -7.914309e+01               97.127368              -0.814838                    1.083242              0.760324             1.424711       -0.681733 -1.003977e+02       -105.884200        0.948184
# 3          2  [15, 30, 60, 120]          4          20           0        10             4       -0.473191       0.399929           -1.183186      -3.223703e+01      2.667790e+01            -1.208379          -7.375697e+01               85.073850              -0.866976                    0.898058              0.492201             1.824575       -0.681733 -1.003977e+02       -105.884200        0.948184
# 4          2  [15, 30, 60, 120]          4          20           0        10            10      159.920133     154.420719            1.035613       3.143410e+08      3.143407e+08             1.000001           3.080338e+04            30618.141793               1.006050                 5118.670953           5116.856963             1.000355       70.029812  1.400596e+08      15334.176963     9133.820755
# 5          2  [15, 30, 60, 120]          4          20           0        10             7    40646.139553       0.000000                 inf       8.129228e+10      0.000000e+00                  inf           1.607423e+06                0.000000                    inf                50573.043490              0.000000                  inf       70.029812  1.400596e+08      15334.176963     9133.820755
# 6          2  [15, 30, 60, 120]          4          20           0        10             6     3401.633692    6739.649598            0.504720       6.752325e+09      1.350464e+10             0.500000           1.141094e+05           225800.902739               0.505354                11937.945389          23871.296552             0.500096       70.029812  1.400596e+08      15334.176963     9133.820755
# 7          2  [15, 30, 60, 120]          4          20           0        10             5       83.483252     128.994011            0.647187       1.626015e+04      2.772012e+04             0.586583           2.779357e+03             4251.147193               0.653790                    4.295426              3.293589             1.304178       70.029812  1.400596e+08      15334.176963     9133.820755
# 8          2  [15, 30, 60, 120]          4          20           0        10             4        0.317933       2.316051            0.137274       2.547422e+00      7.233594e+01             0.035217          -1.194716e+01               44.667628              -0.267468                    1.176604              0.508320             2.314691       70.029812  1.400596e+08      15334.176963     9133.820755
