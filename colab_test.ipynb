# %%
import pandas as pd
import numpy as np
import datetime
# from IPython.display import display, HTML
from yf_utils import eval_grp_top_syms_n_freq
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 16)
pd.set_option('display.width', 790)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_trash = 'trash'

# %%
# create a range of dates
dates = pd.date_range(start='2022-01-01', end='2022-01-10')

# create a DataFrame with dates as the index
df = pd.DataFrame(index=dates)

# add a column of integers to the DataFrame
df['col'] = np.arange(1, 11, 1, dtype=int)
df
# Out:
#             col
# 2022-01-01    1
# 2022-01-02    2
# 2022-01-03    3
# 2022-01-04    4
# 2022-01-05    5
# 2022-01-06    6
# 2022-01-07    7
# 2022-01-08    8
# 2022-01-09    9
# 2022-01-10   10

# %%
pickle_dump(df, path_data_dump, fp_trash)
my_trash = pickle_load(path_data_dump, fp_trash)
my_trash
# Out:
#             col
# 2022-01-01    1
# 2022-01-02    2
# 2022-01-03    3
# 2022-01-04    4
# 2022-01-05    5
# 2022-01-06    6
# 2022-01-07    7
# 2022-01-08    8
# 2022-01-09    9
# 2022-01-10   10
