# %%
def top_set_sym_freq_cnt(top_set_syms_n_freq):
    # accommodate upto 5 periods of days_lookbacks(i.e. days_lookbacks = [5, 10, 15, 20, 25])
    sym_freq_cnt_15 = []
    sym_freq_cnt_14 = []
    sym_freq_cnt_13 = []
    sym_freq_cnt_12 = []
    sym_freq_cnt_11 = []
    sym_freq_cnt_10 = []
    sym_freq_cnt_9 = []
    sym_freq_cnt_8 = []
    sym_freq_cnt_7 = []
    sym_freq_cnt_6 = []
    sym_freq_cnt_5 = []
    sym_freq_cnt_4 = []
    sym_freq_cnt_3 = []
    sym_freq_cnt_2 = []

    for sym_n_freq in top_set_syms_n_freq:
        _sym = sym_n_freq[0]
        _freq = sym_n_freq[1]
        if _freq == 15:
            sym_freq_cnt_15.append(_sym)
        elif _freq == 14:
            sym_freq_cnt_14.append(_sym)
        elif _freq == 13:
            sym_freq_cnt_13.append(_sym)
        elif _freq == 12:
            sym_freq_cnt_12.append(_sym)                        
        elif _freq == 11:
            sym_freq_cnt_11.append(_sym)
        elif _freq == 10:
            sym_freq_cnt_10.append(_sym)            
        elif _freq == 9:
            sym_freq_cnt_9.append(_sym)
        elif _freq == 8:
            sym_freq_cnt_8.append(_sym)
        elif _freq == 7:
            sym_freq_cnt_7.append(_sym)  
        elif _freq == 6:
            sym_freq_cnt_6.append(_sym)
        elif _freq == 5:
            sym_freq_cnt_5.append(_sym)
        elif _freq == 4:
            sym_freq_cnt_4.append(_sym)
        elif _freq == 3:
            sym_freq_cnt_3.append(_sym)          
        else:
            sym_freq_cnt_2.append(_sym)

    l_sym_freq_cnt = []

    l_sym_freq_cnt.append(sym_freq_cnt_15)
    l_sym_freq_cnt.append(sym_freq_cnt_14)
    l_sym_freq_cnt.append(sym_freq_cnt_13)
    l_sym_freq_cnt.append(sym_freq_cnt_12)    
    l_sym_freq_cnt.append(sym_freq_cnt_11)   
    l_sym_freq_cnt.append(sym_freq_cnt_10)
    l_sym_freq_cnt.append(sym_freq_cnt_9)
    l_sym_freq_cnt.append(sym_freq_cnt_8)
    l_sym_freq_cnt.append(sym_freq_cnt_7)    
    l_sym_freq_cnt.append(sym_freq_cnt_6)
    l_sym_freq_cnt.append(sym_freq_cnt_5)
    l_sym_freq_cnt.append(sym_freq_cnt_4)
    l_sym_freq_cnt.append(sym_freq_cnt_3)    
    l_sym_freq_cnt.append(sym_freq_cnt_2)    

    return l_sym_freq_cnt

# %%
import pandas as pd
# import numpy as np
import datetime
# from IPython.display import display, HTML
from yf_utils import _2_split_train_val_test, _3_random_slices, _4_lookback_slices
from yf_utils import _5_perf_ranks, _6_grp_tuples_sort_sum
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 16)
pd.set_option('display.width', 790)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = 'df_close_clean'


###########################################################################################################
str_today = datetime.date.today().strftime('%Y-%m-%d')
# str_today = '2023-03-08'
fp_df_eval_sym_freq_results_train    = f'df_eval_sym_freq_results_train_{str_today}'
fp_df_eval_sym_freq_results_validate = f'df_eval_sym_freq_results_validate_{str_today}'
fp_df_eval_sym_freq_results_test     = f'df_eval_sym_freq_results_test_{str_today}'
fp_df_eval_sym_freq_results_current  = f'df_eval_sym_freq_results_current_{str_today}'

# fp_df_eval_sym_freq_results_train    = f'df_eval_sym_freq_results_train'
# fp_df_eval_sym_freq_results_validate = f'df_eval_sym_freq_results_validate'
# fp_df_eval_sym_freq_results_test     = f'df_eval_sym_freq_results_test'
# fp_df_eval_sym_freq_results_current  = f'df_eval_sym_freq_results_current'
###########################################################################################################

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# %% [markdown]
# #### Check run results

# %%
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_train)
# df
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_validate)
# df
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_test)
# df
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_current)
# df

# %% [markdown]
# #### Create column names

# %%
col_add0 = ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'sym_freq_cnt']
col_add1 = ['grp(CAGR)_mean',         'grp(CAGR)_std',         'grp(CAGR)_mean/std']
col_add2 = ['grp(CAGR/UI)_mean',      'grp(CAGR/UI)_std',      'grp(CAGR/UI)_mean/std']
col_add3 = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
col_add4 = ['grp(retnStd/UI)_mean',   'grp(retnStd/UI)_std',   'grp(retnStd/UI)_mean/std']
col_add5 = ['SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI']

col_add_total = col_add0 + col_add1 + col_add2 + col_add3 + col_add4 + col_add5
print(f'col_add_total:\n{col_add_total}, total columns: {len(col_add_total)}')
# Out:
# col_add_total:
# ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'sym_freq_cnt', 'grp(CAGR)_mean', 'grp(CAGR)_std', 'grp(CAGR)_mean/std', 'grp(CAGR/UI)_mean', 'grp(CAGR/UI)_std', 'grp(CAGR/UI)_mean/std', 'grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std', 'grp(retnStd/UI)_mean', 'grp(retnStd/UI)_std', 'grp(retnStd/UI)_mean/std', 'SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI'], total columns: 23

# %% [markdown]
# #### DANGER: Create a new Dataframe to store run results. Previous data will be destroyed. To create a new dataframe, uncomment one choice from below.

# %%
# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_train)
# df

# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_validate)
# df

# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_test)
# df

# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_current)
# df

# %% [markdown]
# #### Select run parameters. Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb

# %%
# SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# select run type
run_type = 'train'
# run_type = 'validate'
# run_type = 'test'
# run_type = 'current'

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms 
# n_samples = 400  
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
# days_lookbacks = [7, 15, 30, 60, 120]
# days_lookbacks = [30, 60, 120]
days_lookbacks = [2]
days_lookbacks.sort()

# number of days from iloc_end_train are used to evaluate effectiveness of the training
days_eval = 4

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20  

syms_start = 0  #  start index of n_top_syms for evaluation
syms_end = 10  #  end index of n_top_syms for evaluation

# over-ride parameters for run_type 'current'
if run_type == 'current':
  days_eval = 0  # no need to eval, df_eval will be empty
  n_samples = 1  # no need to repeat sample the current result, repeat sample will yield the same tuple

print(f'verbose : {verbose }')
print(f'store_results: {store_results}')
print(f'run_type: {run_type}')
print(f'n_samples: {n_samples}')
print(f'days_lookbacks: {days_lookbacks}')
print(f'days_eval: {days_eval}')
print(f'n_top_syms: {n_top_syms}')
print(f'syms_start: {syms_start}')
print(f'syms_end: {syms_end}')
# Out:
# verbose : True
# store_results: True
# run_type: train
# n_samples: 2
# days_lookbacks: [2]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10

# %%
# Parameters
verbose = True
store_results = True
n_top_syms = 20
syms_start = 0
syms_end = 10
run_type = "test"
n_samples = 57
days_eval = 6
days_lookbacks = [15, 30, 60, 120]

# %% [markdown]
# #### Split dataframe into Train, Validate and Test

# %%
# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = _2_split_train_val_test(df_close_clean)

# %% [markdown]
# #### Create df_current, a df with the latest data

# %%
max_days_lookbacks = max(days_lookbacks)
print(f'max_days_lookbacks: {max_days_lookbacks}')
df_current = df_test.tail(max_days_lookbacks)  
df_current.tail(3)
# Out:
# max_days_lookbacks: 120
#                      A         AA    AAL         AAP        AAPL       AAWW         AB        ABB        ABBV         ABC        ABM    ABR        ABT       ACGL       ACHC  ...       XRAY    XRX        XYL       YELP       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION        ZTO         ZTS   ZUMZ        ZWS
# Date                                                                                                                                                                          ...
# 2023-03-10  135.720001  44.910000  15.46  128.039993  148.500000  99.930000  36.869999  33.139999  149.710007  149.600006  44.750000  13.15  96.959999  66.610001  68.980003  ...  36.930000  15.58  98.980003  28.570000  58.759998  28.440001  123.529999  288.190002  73.809998  38.650002  40.349998  25.740000  161.529999  21.65  21.309999
# 2023-03-13  136.690002  44.709999  14.85  124.360001  150.470001  99.519997  36.009998  32.919998  151.949997  148.369995  44.220001  12.99  98.190002  65.180000  68.349998  ...  37.549999  14.96  97.900002  28.360001  59.139999  27.620001  124.250000  284.920013  73.239998  39.459999  29.969999  25.709999  163.410004  20.66  21.070000
# 2023-03-14  138.399994  44.590000  14.66  121.699997  152.589996  99.300003  35.709999  33.759998  153.850006  149.289993  44.570000  12.12  98.550003  67.339996  69.160004  ...  38.130001  15.14  99.900002  29.260000  60.680000  27.469999  126.629997  292.459991  74.370003  39.610001  31.309999  26.270000  164.559998  20.43  21.379999
#
# [3 rows x 1292 columns]

# %% [markdown]
# #### Load previous data according to run_type

# %%
if run_type == 'train':
  df_eval_sym_freq_results_train = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_train)
  df = df_train.copy()    
elif run_type == 'validate':
  df_eval_sym_freq_results_validate = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_validate)
  df = df_val.copy()
elif run_type == 'test':
  df_eval_sym_freq_results_test = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_test)
  df = df_test.copy()
elif run_type == 'current':  # get the current results
  df = df_current.copy()
else:
  msg_stop = f"ERROR run_type must be 'train', 'validate', 'test' or 'current', run_type is: {run_type}"
  raise SystemExit(msg_stop )

# %% [markdown]
# #### Print dataframe for the run, and lengths of other dataframes

# %%
print(f'run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n')
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
len_df_current = len(df_current)
print(f'run_type: {run_type}, len(df): {len(df)}')
print(f'len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}, len_df_current: {len_df_current} ')
# Out:
# run_type: test, df.tail(3):
#                      A         AA    AAL         AAP        AAPL       AAWW         AB        ABB        ABBV         ABC        ABM    ABR        ABT       ACGL       ACHC  ...       XRAY    XRX        XYL       YELP       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION        ZTO         ZTS   ZUMZ        ZWS
# Date                                                                                                                                                                          ...
# 2023-03-10  135.720001  44.910000  15.46  128.039993  148.500000  99.930000  36.869999  33.139999  149.710007  149.600006  44.750000  13.15  96.959999  66.610001  68.980003  ...  36.930000  15.58  98.980003  28.570000  58.759998  28.440001  123.529999  288.190002  73.809998  38.650002  40.349998  25.740000  161.529999  21.65  21.309999
# 2023-03-13  136.690002  44.709999  14.85  124.360001  150.470001  99.519997  36.009998  32.919998  151.949997  148.369995  44.220001  12.99  98.190002  65.180000  68.349998  ...  37.549999  14.96  97.900002  28.360001  59.139999  27.620001  124.250000  284.920013  73.239998  39.459999  29.969999  25.709999  163.410004  20.66  21.070000
# 2023-03-14  138.399994  44.590000  14.66  121.699997  152.589996  99.300003  35.709999  33.759998  153.850006  149.289993  44.570000  12.12  98.550003  67.339996  69.160004  ...  38.130001  15.14  99.900002  29.260000  60.680000  27.469999  126.629997  292.459991  74.370003  39.610001  31.309999  26.270000  164.559998  20.43  21.379999
#
# [3 rows x 1292 columns]
#
# run_type: test, len(df): 150
# len_df_train: 1050, len_df_val: 300, len_df_test: 150, len_df_current: 120

# %% [markdown]
# #### Create a sets of iloc lookback slices (iloc_start_train:iloc_end_train:iloc_end_eval), where:
# * iloc_end_train - iloc_start_train = days_lookback
# * iloc_end_eval - iloc_end_train = days_eval
# #### for example, if given:
# * n_samples = 2
# * days_lookbacks = [10, 20, 30]
# * days_eval = 5
# #### a possible result is:
#   - max_lookback_slices: [(417, 447, 452), (265, 295, 300)], where:
#     - len(max_lookback_slices) = n_samples = 2
#     - middle number in the tuples, 447 and 295, is the iloc of the "pivot day" for the days in "days_lookbacks" to lookback
#     - 447 - 417 = middle number - first number = max(days_lookbacks) = 30
#     - 295 - 265 = middle number - first number = max(days_lookbacks) = 30
#     - 452 - 447 = last number - middle number = days_eval = 5
#     - 300 - 295 = last number - middle number = days_eval = 5
#   - sets_lookback_slices: [[(437, 447, 452), (427, 447, 452), (417, 447, 452)], [(285, 295, 300), (275, 295, 300), (265, 295, 300)]], where:
#     - len(sets_lookback_slices) = n_samples = 2
#     - last tuple in each list, i.e. (417, 447, 452) and (265, 295, 300), is a tuple from max_lookback_slices
#     - where a set, e.g. [(437, 447, 452), (427, 447, 452), (417, 447, 452)]:
#       - middle number, 447, iloc of the "pivot day" is constant for that set
#       - middle number - first number, is the training period specified in days_lookbacks
#         - 447 - 437 = middle number - first number = days_lookbacks[0] = 10
#         - 447 - 427 = middle number - first number = days_lookbacks[1] = 20
#         - 447 - 417 = middle number - first number = days_lookbacks[2] = 30
#       - last number, 452, iloc of the end of the evaluation period is constant
#         - 452 - 447 = last number - middle number = days_eval = 5

# %%
# return n_samples slices
max_lookback_slices = _3_random_slices(len_df, n_samples=n_samples, days_lookback=max(days_lookbacks), days_eval=days_eval, verbose=False)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = _4_lookback_slices(max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False)

if verbose:
  print(f'number of max_lookback_slices is equal to n_samples = {n_samples}')
  print(f'max_lookback_slices:\n{max_lookback_slices}\n')
  print(f'number of sets in sets_lookback_slices is equal to n_samples = {n_samples}')
  print(f'days_lookbacks: {days_lookbacks}')  
  print(f'sets_lookback_slices:\n{sets_lookback_slices}\n')
  print(f'number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): len({days_lookbacks})')
# Out:
# number of max_lookback_slices is equal to n_samples = 57
# max_lookback_slices:
# [(19, 139, 145), (15, 135, 141), (8, 128, 134), (18, 138, 144), (4, 124, 130), (12, 132, 138), (6, 126, 132), (16, 136, 142), (2, 122, 128), (1, 121, 127), (1, 121, 127), (0, 120, 126), (17, 137, 143), (2, 122, 128), (19, 139, 145), (18, 138, 144), (12, 132, 138), (24, 144, 150), (21, 141, 147), (18, 138, 144), (14, 134, 140), (17, 137, 143), (17, 137, 143), (2, 122, 128), (0, 120, 126), (21, 141, 147), (19, 139, 145), (6, 126, 132), (6, 126, 132), (5, 125, 131), (11, 131, 137), (4, 124, 130), (3, 123, 129), (24, 144, 150), (2, 122, 128), (14, 134, 140), (15, 135, 141), (13, 133, 139), (9, 129, 135), (7, 127, 133), (22, 142, 148), (7, 127, 133), (4, 124, 130), (17, 137, 143), (18, 138, 144), (13, 133, 139), (0, 120, 126), (7, 127, 133), (23, 143, 149), (10, 130, 136), (0, 120, 126), (11, 131, 137), (5, 125, 131), (21, 141, 147), (21, 141, 147), (5, 125, 131), (13, 133, 139)]
#
# number of sets in sets_lookback_slices is equal to n_samples = 57
# days_lookbacks: [15, 30, 60, 120]
# sets_lookback_slices:
# [[(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)], [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)], [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)], [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)], [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)], [(117, 132, 138), (102, 132, 138), (72, 132, 138), (12, 132, 138)], [(111, 126, 132), (96, 126, 132), (66, 126, 132), (6, 126, 132)], [(121, 136, 142), (106, 136, 142), (76, 136, 142), (16, 136, 142)], [(107, 122, 128), (92, 122, 128), (62, 122, 128), (2, 122, 128)], [(106, 121, 127), (91, 121, 127), (61, 121, 127), (1, 121, 127)], [(106, 121, 127), (91, 121, 127), (61, 121, 127), (1, 121, 127)], [(105, 120, 126), (90, 120, 126), (60, 120, 126), (0, 120, 126)], [(122, 137, 143), (107, 137, 143), (77, 137, 143), (17, 137, 143)], [(107, 122, 128), (92, 122, 128), (62, 122, 128), (2, 122, 128)], [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)], [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)], [(117, 132, 138), (102, 132, 138), (72, 132, 138), (12, 132, 138)], [(129, 144, 150), (114, 144, 150), (84, 144, 150), (24, 144, 150)], [(126, 141, 147), (111, 141, 147), (81, 141, 147), (21, 141, 147)], [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)], [(119, 134, 140), (104, 134, 140), (74, 134, 140), (14, 134, 140)], [(122, 137, 143), (107, 137, 143), (77, 137, 143), (17, 137, 143)], [(122, 137, 143), (107, 137, 143), (77, 137, 143), (17, 137, 143)], [(107, 122, 128), (92, 122, 128), (62, 122, 128), (2, 122, 128)], [(105, 120, 126), (90, 120, 126), (60, 120, 126), (0, 120, 126)], [(126, 141, 147), (111, 141, 147), (81, 141, 147), (21, 141, 147)], [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)], [(111, 126, 132), (96, 126, 132), (66, 126, 132), (6, 126, 132)], [(111, 126, 132), (96, 126, 132), (66, 126, 132), (6, 126, 132)], [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)], [(116, 131, 137), (101, 131, 137), (71, 131, 137), (11, 131, 137)], [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)], [(108, 123, 129), (93, 123, 129), (63, 123, 129), (3, 123, 129)], [(129, 144, 150), (114, 144, 150), (84, 144, 150), (24, 144, 150)], [(107, 122, 128), (92, 122, 128), (62, 122, 128), (2, 122, 128)], [(119, 134, 140), (104, 134, 140), (74, 134, 140), (14, 134, 140)], [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)], [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)], [(114, 129, 135), (99, 129, 135), (69, 129, 135), (9, 129, 135)], [(112, 127, 133), (97, 127, 133), (67, 127, 133), (7, 127, 133)], [(127, 142, 148), (112, 142, 148), (82, 142, 148), (22, 142, 148)], [(112, 127, 133), (97, 127, 133), (67, 127, 133), (7, 127, 133)], [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)], [(122, 137, 143), (107, 137, 143), (77, 137, 143), (17, 137, 143)], [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)], [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)], [(105, 120, 126), (90, 120, 126), (60, 120, 126), (0, 120, 126)], [(112, 127, 133), (97, 127, 133), (67, 127, 133), (7, 127, 133)], [(128, 143, 149), (113, 143, 149), (83, 143, 149), (23, 143, 149)], [(115, 130, 136), (100, 130, 136), (70, 130, 136), (10, 130, 136)], [(105, 120, 126), (90, 120, 126), (60, 120, 126), (0, 120, 126)], [(116, 131, 137), (101, 131, 137), (71, 131, 137), (11, 131, 137)], [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)], [(126, 141, 147), (111, 141, 147), (81, 141, 147), (21, 141, 147)], [(126, 141, 147), (111, 141, 147), (81, 141, 147), (21, 141, 147)], [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)], [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]]
#
# number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): len([15, 30, 60, 120])

# %% [markdown]
# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the max_lookback_slices. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in max_lookback_slices. There are as many sub-lists as there are tuples in max_lookback_slices.

# %%
# grp_top_set_syms_n_freq is a list of lists of top_set_syms_n_freq, e.g.
#   [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)],
#    [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
#   where each list is the best performing symbols from a lb_slices, e.g.
#     [(483, 513, 523), (453, 513, 523), (393, 513, 523)]  
grp_top_set_syms_n_freq = []  # list of lists of top_set_symbols_n_freq, there are n_samples lists in list
grp_top_set_syms = []  # grp_top_set_syms_n_freq without the frequency count

# lb_slices, e.g  [(483, 513, 523), (453, 513, 523), (393, 513, 523)],
#  is one max_lookback_slice, e.g. (393, 513, 523), along with
#  the remaining slices of the days_lookbacks, e.g. (483, 513, 523), (453, 513, 523)  
for i, lb_slices in enumerate(sets_lookback_slices):
  print(f'\n########## {i + 1} of {len(sets_lookback_slices)} lb_slices in sets_lookcak_slices ##########')
  # unsorted list of the most frequent symbols in performance metrics of the lb_slices  
  grp_most_freq_syms = []
  for j, lb_slice in enumerate(lb_slices):  # lb_slice, e.g. (246, 276, 286)
    iloc_start_train = lb_slice[0]     # iloc of start of training period
    iloc_end_train   = lb_slice[1]     # iloc of end of training period
    iloc_start_eval  = iloc_end_train  # iloc of start of evaluation period
    iloc_end_eval    = lb_slice[2]     # iloc of end of evaluation period
    lookback         = iloc_end_train - iloc_start_train
    d_eval           = iloc_end_eval - iloc_start_eval

    _df = df.iloc[iloc_start_train:iloc_end_train]
    date_start_df_train = _df.index[0].strftime('%Y-%m-%d')
    date_end_df_train = _df.index[-1].strftime('%Y-%m-%d')

    if verbose:
      print(f'days lookback:       {lookback},  {j + 1} of {len(days_lookbacks)} days_lookbacks: {days_lookbacks}')
      print(f'lb_slices:           {lb_slices}')
      print(f'lb_slice:            {lb_slice}')
      print(f'days eval:           {d_eval}')    
      print(f'iloc_start_train:    {iloc_start_train}')
      print(f'iloc_end_train:      {iloc_end_train}')
      print(f'date_start_df_train: {date_start_df_train}')
      print(f'date_end_df_train:   {date_end_df_train}')


    perf_ranks, most_freq_syms = _5_perf_ranks(_df, n_top_syms=n_top_syms)
    # unsorted list of the most frequent symbols in performance metrics of the lb_slices  
    grp_most_freq_syms.append(most_freq_syms)  
    if verbose:    
      # 1 lookback of r_CAGR/UI, r_CAGR/retnStd, r_retnStd/UI
      print(f'perf_ranks: {perf_ranks}')  
      # most common symbols of perf_ranks 
      print(f'most_freq_syms: {most_freq_syms}')     
      # grp_perf_ranks[lookback] = perf_ranks
      print(f'+++ finish lookback slice {lookback} +++\n')

  if verbose:
    print(f'grp_most_freq_syms: {grp_most_freq_syms}')
    # grp_most_freq_syms a is list of lists of tuples of 
    #  the most-common-symbols symbol:frequency cumulated from
    #  each days_lookback  
    print(f'**** finish lookback slices {lb_slices} ****\n')

  # flatten list of lists of (symbol:frequency)
  flat_grp_most_freq_syms = [val for sublist in grp_most_freq_syms for val in sublist]
  # return "symbol, frequency" pairs of the most frequent symbols, i.e. best performing symbols,
  #  in flat_grp_most_freq_syms. The paris are sorted in descending frequency.   
  set_most_freq_syms = _6_grp_tuples_sort_sum(flat_grp_most_freq_syms, reverse=True)
  # get the top n_top_syms of the most frequent "symbol, frequency" pairs
  top_set_syms_n_freq = set_most_freq_syms[0:n_top_syms]
  # get symbols from top_set_syms_n_freq, i[0] = symbol, i[1]=symbol's frequency count
  top_set_syms = [i[0] for i in top_set_syms_n_freq[syms_start:syms_end]]  

  # grp_top_set_syms_n_freq is a list of lists of top_set_syms_n_freq, e.g.
  #   [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)],
  #    [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
  #   where each list is the best performing symbols from a lb_slices, e.g.
  #     [(483, 513, 523), (453, 513, 523), (393, 513, 523)]    
  grp_top_set_syms_n_freq.append(top_set_syms_n_freq)
  grp_top_set_syms.append(top_set_syms)

  if verbose:  
    print(f'top {n_top_syms} ranked symbols and frequency from set {lb_slices}:\n{top_set_syms_n_freq}')
    print(f'top {n_top_syms} ranked symbols from set {lb_slices}:\n{top_set_syms}')  
    print(f'===== finish top {n_top_syms} ranked symbols from days_lookback set {lb_slices} =====\n\n')
# Out:
# ########## 1 of 57 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]
# lb_slice:            (124, 139, 145)
# days eval:           6
# iloc_start_train:    124
# iloc_end_train:      139
# date_start_df_train: 2023-02-06
# date_end_df_train:   2023-02-27
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TA', 'SGEN', 'TNP', 'TNK', 'OEC', 'ACGL', 'LNTH', 'FTI', 'ASC',
#        'STNG', 'BP', 'WST', 'PBF', 'CNA', 'AMCX', 'EME', 'NVGS', 'MSGS',
#        'PDFS', 'FTSM'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'TNP', 'SGEN', 'TNK', 'STNG', 'ASC', 'FTI', 'OEC', 'ACGL',
#        'BP', 'LNTH', 'AMCX', 'PBF', 'WST', 'IRTC', 'HLF', 'FTNT', 'XPRO',
#        'NSP', 'HZO'], dtype=object), 'r_retnStd/UI': array(['TA', 'SGEN', 'CNA', 'LAUR', 'OEC', 'KBR', 'TNK', 'LNTH', 'MSGS',
#        'FTSM', 'ACGL', 'TWNK', 'QNST', 'EME', 'MMS', 'NVGS', 'TNP', 'FDP',
#        'PDFS', 'RELX'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('SGEN', 3), ('TNP', 3), ('TNK', 3), ('OEC', 3), ('ACGL', 3), ('LNTH', 3), ('FTI', 2), ('ASC', 2), ('STNG', 2), ('BP', 2), ('WST', 2), ('PBF', 2), ('CNA', 2), ('AMCX', 2), ('EME', 2), ('NVGS', 2), ('MSGS', 2), ('PDFS', 2), ('FTSM', 2), ('IRTC', 1), ('HLF', 1), ('FTNT', 1), ('XPRO', 1), ('NSP', 1), ('HZO', 1), ('LAUR', 1), ('KBR', 1), ('TWNK', 1), ('QNST', 1), ('MMS', 1), ('FDP', 1), ('RELX', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]
# lb_slice:            (109, 139, 145)
# days eval:           6
# iloc_start_train:    109
# iloc_end_train:      139
# date_start_df_train: 2023-01-13
# date_end_df_train:   2023-02-27
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TA', 'TSLA', 'ELF', 'TNK', 'OEC', 'SGEN', 'LNTH', 'CTLT', 'FTSM',
#        'NVDA', 'SMG', 'NVGS', 'LRN', 'ASC', 'PDFS', 'TNP', 'WIRE', 'EURN',
#        'THR', 'ACLS'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'TA', 'TNK', 'ELF', 'TNP', 'NVDA', 'SGEN', 'SMG', 'LNTH',
#        'OEC', 'CTLT', 'ASC', 'CNK', 'WIRE', 'ACLS', 'PAG', 'RVNC', 'EURN',
#        'AN', 'THR'], dtype=object), 'r_retnStd/UI': array(['TA', 'ELF', 'OEC', 'FTSM', 'LRN', 'SGEN', 'NVGS', 'LNTH', 'PDFS',
#        'TNK', 'AQN', 'MMS', 'CTLT', 'CME', 'KEX', 'STLA', 'EURN', 'FISV',
#        'TSLA', 'QNST'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('TSLA', 3), ('ELF', 3), ('TNK', 3), ('OEC', 3), ('SGEN', 3), ('LNTH', 3), ('CTLT', 3), ('EURN', 3), ('FTSM', 2), ('NVDA', 2), ('SMG', 2), ('NVGS', 2), ('LRN', 2), ('ASC', 2), ('PDFS', 2), ('TNP', 2), ('WIRE', 2), ('THR', 2), ('ACLS', 2), ('CNK', 1), ('PAG', 1), ('RVNC', 1), ('AN', 1), ('AQN', 1), ('MMS', 1), ('CME', 1), ('KEX', 1), ('STLA', 1), ('FISV', 1), ('QNST', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]
# lb_slice:            (79, 139, 145)
# days eval:           6
# iloc_start_train:    79
# iloc_end_train:      139
# date_start_df_train: 2022-11-30
# date_end_df_train:   2023-02-27
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['FTSM', 'BVH', 'SGEN', 'ACLS', 'MCFT', 'URI', 'HSBC', 'CRUS',
#        'ALGN', 'HEES', 'RVNC', 'CCU', 'THR', 'ATI', 'IPGP', 'TPX', 'TA',
#        'PEN', 'IBP', 'TX'], dtype=object), 'r_CAGR/retnStd': array(['BVH', 'ACLS', 'FTSM', 'CRUS', 'SGEN', 'TPX', 'ALGN', 'BMA', 'SMG',
#        'TX', 'HSBC', 'OEC', 'THR', 'CCU', 'IPGP', 'IBP', 'MCFT', 'URI',
#        'SBH', 'ATI'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'MCFT', 'SGEN', 'LW', 'TA', 'AJRD', 'RVNC', 'HEES', 'MMS',
#        'OTTR', 'PEN', 'URI', 'VRNS', 'ACGL', 'WYNN', 'ATI', 'PNM', 'BVH',
#        'MBI', 'NVO'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('BVH', 3), ('SGEN', 3), ('MCFT', 3), ('URI', 3), ('ATI', 3), ('ACLS', 2), ('HSBC', 2), ('CRUS', 2), ('ALGN', 2), ('HEES', 2), ('RVNC', 2), ('CCU', 2), ('THR', 2), ('IPGP', 2), ('TPX', 2), ('TA', 2), ('PEN', 2), ('IBP', 2), ('TX', 2), ('BMA', 1), ('SMG', 1), ('OEC', 1), ('SBH', 1), ('LW', 1), ('AJRD', 1), ('MMS', 1), ('OTTR', 1), ('VRNS', 1), ('ACGL', 1), ('WYNN', 1), ('PNM', 1), ('MBI', 1), ('NVO', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]
# lb_slice:            (19, 139, 145)
# days eval:           6
# iloc_start_train:    19
# iloc_end_train:      139
# date_start_df_train: 2022-09-06
# date_end_df_train:   2023-02-27
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['FTSM', 'ELF', 'HZNP', 'RMBS', 'ACGL', 'ANF', 'FTI', 'AGYS', 'TPX',
#        'OI', 'LOCO', 'ACLS', 'FIVE', 'HEES', 'CNO', 'LW', 'ASC', 'ATKR',
#        'TMHC', 'TEX'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'RMBS', 'ACLS', 'ELF', 'FTI', 'TEX', 'HEES', 'ASC', 'TPX',
#        'THR', 'ACGL', 'HZNP', 'AXON', 'WYNN', 'ANF', 'LOCO', 'OI', 'FMX',
#        'PERI', 'URI'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'ELF', 'LW', 'ANF', 'AGYS', 'ACGL', 'QNST', 'TMHC',
#        'FIVE', 'BIIB', 'REGN', 'ORI', 'OI', 'CNO', 'IRDM', 'LOCO', 'DHI',
#        'MMS', 'RMBS'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('RMBS', 3), ('ACGL', 3), ('ANF', 3), ('OI', 3), ('LOCO', 3), ('FTI', 2), ('AGYS', 2), ('TPX', 2), ('ACLS', 2), ('FIVE', 2), ('HEES', 2), ('CNO', 2), ('LW', 2), ('ASC', 2), ('TMHC', 2), ('TEX', 2), ('ATKR', 1), ('THR', 1), ('AXON', 1), ('WYNN', 1), ('FMX', 1), ('PERI', 1), ('URI', 1), ('QNST', 1), ('BIIB', 1), ('REGN', 1), ('ORI', 1), ('IRDM', 1), ('DHI', 1), ('MMS', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('TA', 3), ('SGEN', 3), ('TNP', 3), ('TNK', 3), ('OEC', 3), ('ACGL', 3), ('LNTH', 3), ('FTI', 2), ('ASC', 2), ('STNG', 2), ('BP', 2), ('WST', 2), ('PBF', 2), ('CNA', 2), ('AMCX', 2), ('EME', 2), ('NVGS', 2), ('MSGS', 2), ('PDFS', 2), ('FTSM', 2), ('IRTC', 1), ('HLF', 1), ('FTNT', 1), ('XPRO', 1), ('NSP', 1), ('HZO', 1), ('LAUR', 1), ('KBR', 1), ('TWNK', 1), ('QNST', 1), ('MMS', 1), ('FDP', 1), ('RELX', 1)], [('TA', 3), ('TSLA', 3), ('ELF', 3), ('TNK', 3), ('OEC', 3), ('SGEN', 3), ('LNTH', 3), ('CTLT', 3), ('EURN', 3), ('FTSM', 2), ('NVDA', 2), ('SMG', 2), ('NVGS', 2), ('LRN', 2), ('ASC', 2), ('PDFS', 2), ('TNP', 2), ('WIRE', 2), ('THR', 2), ('ACLS', 2), ('CNK', 1), ('PAG', 1), ('RVNC', 1), ('AN', 1), ('AQN', 1), ('MMS', 1), ('CME', 1), ('KEX', 1), ('STLA', 1), ('FISV', 1), ('QNST', 1)], [('FTSM', 3), ('BVH', 3), ('SGEN', 3), ('MCFT', 3), ('URI', 3), ('ATI', 3), ('ACLS', 2), ('HSBC', 2), ('CRUS', 2), ('ALGN', 2), ('HEES', 2), ('RVNC', 2), ('CCU', 2), ('THR', 2), ('IPGP', 2), ('TPX', 2), ('TA', 2), ('PEN', 2), ('IBP', 2), ('TX', 2), ('BMA', 1), ('SMG', 1), ('OEC', 1), ('SBH', 1), ('LW', 1), ('AJRD', 1), ('MMS', 1), ('OTTR', 1), ('VRNS', 1), ('ACGL', 1), ('WYNN', 1), ('PNM', 1), ('MBI', 1), ('NVO', 1)], [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('RMBS', 3), ('ACGL', 3), ('ANF', 3), ('OI', 3), ('LOCO', 3), ('FTI', 2), ('AGYS', 2), ('TPX', 2), ('ACLS', 2), ('FIVE', 2), ('HEES', 2), ('CNO', 2), ('LW', 2), ('ASC', 2), ('TMHC', 2), ('TEX', 2), ('ATKR', 1), ('THR', 1), ('AXON', 1), ('WYNN', 1), ('FMX', 1), ('PERI', 1), ('URI', 1), ('QNST', 1), ('BIIB', 1), ('REGN', 1), ('ORI', 1), ('IRDM', 1), ('DHI', 1), ('MMS', 1)]]
# **** finish lookback slices [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)] ****
#
# top 20 ranked symbols and frequency from set [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]:
# [('FTSM', 10), ('SGEN', 9), ('TA', 8), ('ACGL', 7), ('OEC', 7), ('ACLS', 6), ('ASC', 6), ('ELF', 6), ('LNTH', 6), ('TNK', 6), ('THR', 5), ('TNP', 5), ('FTI', 4), ('HEES', 4), ('MMS', 4), ('NVGS', 4), ('PDFS', 4), ('TPX', 4), ('URI', 4), ('ANF', 3)]
# top 20 ranked symbols from set [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]:
# ['FTSM', 'SGEN', 'TA', 'ACGL', 'OEC', 'ACLS', 'ASC', 'ELF', 'LNTH', 'TNK']
# ===== finish top 20 ranked symbols from days_lookback set [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)] =====
#
#
#
# ########## 2 of 57 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]
# lb_slice:            (120, 135, 141)
# days eval:           6
# iloc_start_train:    120
# iloc_end_train:      135
# date_start_df_train: 2023-01-31
# date_end_df_train:   2023-02-21
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TA', 'ELF', 'STNG', 'CTLT', 'TNK', 'TNP', 'ASC', 'CLMT', 'AMCX',
#        'PDFS', 'WIRE', 'OEC', 'FCF', 'MMS', 'NSP', 'FTSM', 'ATCO', 'SFBS',
#        'PKE', 'THR'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'STNG', 'ELF', 'CTLT', 'TNK', 'TNP', 'ASC', 'AMCX', 'CLMT',
#        'PDFS', 'WIRE', 'OEC', 'NSP', 'MCFT', 'FCF', 'PKE', 'THR', 'NYT',
#        'PAG', 'ATI'], dtype=object), 'r_retnStd/UI': array(['TA', 'ELF', 'MMS', 'ATCO', 'FTSM', 'SFBS', 'CTLT', 'KBR', 'CINF',
#        'FCF', 'OEC', 'PRGS', 'ALSN', 'NSP', 'PDFS', 'WIRE', 'SGEN', 'TNK',
#        'PRMW', 'MWA'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('ELF', 3), ('CTLT', 3), ('TNK', 3), ('PDFS', 3), ('WIRE', 3), ('OEC', 3), ('FCF', 3), ('NSP', 3), ('STNG', 2), ('TNP', 2), ('ASC', 2), ('CLMT', 2), ('AMCX', 2), ('MMS', 2), ('FTSM', 2), ('ATCO', 2), ('SFBS', 2), ('PKE', 2), ('THR', 2), ('MCFT', 1), ('NYT', 1), ('PAG', 1), ('ATI', 1), ('KBR', 1), ('CINF', 1), ('PRGS', 1), ('ALSN', 1), ('SGEN', 1), ('PRMW', 1), ('MWA', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]
# lb_slice:            (105, 135, 141)
# days eval:           6
# iloc_start_train:    105
# iloc_end_train:      135
# date_start_df_train: 2023-01-09
# date_end_df_train:   2023-02-21
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TA', 'TSLA', 'WIRE', 'CTLT', 'TNK', 'OEC', 'NATI', 'PDFS', 'EVRI',
#        'FTSM', 'SMG', 'CNK', 'CRUS', 'LRN', 'ASC', 'NVGS', 'ACLS', 'CAR',
#        'THR', 'CIGI'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'TA', 'TNK', 'WIRE', 'CNK', 'CTLT', 'SMG', 'NATI', 'PAR',
#        'ACLS', 'ASC', 'TNP', 'OEC', 'PDFS', 'EVRI', 'CAR', 'HUBS', 'CRUS',
#        'TEX', 'ATI'], dtype=object), 'r_retnStd/UI': array(['TA', 'FTSM', 'OEC', 'LRN', 'CTLT', 'NATI', 'WIRE', 'PDFS', 'NVGS',
#        'EVRI', 'CIGI', 'FISV', 'SGEN', 'RACE', 'MMS', 'WYNN', 'TSLA',
#        'CRUS', 'BYD', 'URI'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('TSLA', 3), ('WIRE', 3), ('CTLT', 3), ('OEC', 3), ('NATI', 3), ('PDFS', 3), ('EVRI', 3), ('CRUS', 3), ('TNK', 2), ('FTSM', 2), ('SMG', 2), ('CNK', 2), ('LRN', 2), ('ASC', 2), ('NVGS', 2), ('ACLS', 2), ('CAR', 2), ('CIGI', 2), ('THR', 1), ('PAR', 1), ('TNP', 1), ('HUBS', 1), ('TEX', 1), ('ATI', 1), ('FISV', 1), ('SGEN', 1), ('RACE', 1), ('MMS', 1), ('WYNN', 1), ('BYD', 1), ('URI', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]
# lb_slice:            (75, 135, 141)
# days eval:           6
# iloc_start_train:    75
# iloc_end_train:      135
# date_start_df_train: 2022-11-23
# date_end_df_train:   2023-02-21
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['FTSM', 'HSBC', 'BVH', 'WYNN', 'ACLS', 'MCFT', 'HTHT', 'HZNP',
#        'META', 'ALGN', 'ATI', 'PEN', 'CCU', 'BMA', 'IPGP', 'LVS', 'WB',
#        'GDS', 'EDU', 'CTLT'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'ACLS', 'HSBC', 'CTLT', 'BVH', 'BMA', 'WYNN', 'GDS', 'CCU',
#        'HTHT', 'META', 'ALGN', 'EDU', 'PAR', 'ATI', 'IPGP', 'SMG', 'PEN',
#        'MCFT', 'LVS'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'AJRD', 'MCFT', 'LW', 'URI', 'TA', 'PEN', 'VRNS',
#        'EXAS', 'MMS', 'SGEN', 'WYNN', 'HSBC', 'HEES', 'ALGN', 'BVH',
#        'ATI', 'OTTR', 'META'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('HSBC', 3), ('BVH', 3), ('WYNN', 3), ('MCFT', 3), ('META', 3), ('ALGN', 3), ('ATI', 3), ('PEN', 3), ('ACLS', 2), ('HTHT', 2), ('HZNP', 2), ('CCU', 2), ('BMA', 2), ('IPGP', 2), ('LVS', 2), ('GDS', 2), ('EDU', 2), ('CTLT', 2), ('WB', 1), ('PAR', 1), ('SMG', 1), ('AJRD', 1), ('LW', 1), ('URI', 1), ('TA', 1), ('VRNS', 1), ('EXAS', 1), ('MMS', 1), ('SGEN', 1), ('HEES', 1), ('OTTR', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]
# lb_slice:            (15, 135, 141)
# days eval:           6
# iloc_start_train:    15
# iloc_end_train:      135
# date_start_df_train: 2022-08-30
# date_end_df_train:   2023-02-21
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['FTSM', 'ELF', 'HZNP', 'ANF', 'RMBS', 'ACGL', 'FIVE', 'AGYS',
#        'ASC', 'FTI', 'OI', 'TPX', 'RNR', 'TTC', 'LOCO', 'PERI', 'LW',
#        'ATKR', 'IRDM', 'FMX'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'ELF', 'RMBS', 'ASC', 'ANF', 'HZNP', 'ACLS', 'TEX', 'WYNN',
#        'AXON', 'FMX', 'RNR', 'ACGL', 'FTI', 'PERI', 'THR', 'HEES', 'URI',
#        'PEN', 'TPX'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'ELF', 'ANF', 'LW', 'ACGL', 'FIVE', 'BIIB', 'AGYS',
#        'DHI', 'ISEE', 'TMHC', 'REGN', 'IRDM', 'LOCO', 'OI', 'ORI', 'NFLX',
#        'CNO', 'RMBS'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('ANF', 3), ('RMBS', 3), ('ACGL', 3), ('FIVE', 2), ('AGYS', 2), ('ASC', 2), ('FTI', 2), ('OI', 2), ('TPX', 2), ('RNR', 2), ('LOCO', 2), ('PERI', 2), ('LW', 2), ('IRDM', 2), ('FMX', 2), ('TTC', 1), ('ATKR', 1), ('ACLS', 1), ('TEX', 1), ('WYNN', 1), ('AXON', 1), ('THR', 1), ('HEES', 1), ('URI', 1), ('PEN', 1), ('BIIB', 1), ('DHI', 1), ('ISEE', 1), ('TMHC', 1), ('REGN', 1), ('ORI', 1), ('NFLX', 1), ('CNO', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('TA', 3), ('ELF', 3), ('CTLT', 3), ('TNK', 3), ('PDFS', 3), ('WIRE', 3), ('OEC', 3), ('FCF', 3), ('NSP', 3), ('STNG', 2), ('TNP', 2), ('ASC', 2), ('CLMT', 2), ('AMCX', 2), ('MMS', 2), ('FTSM', 2), ('ATCO', 2), ('SFBS', 2), ('PKE', 2), ('THR', 2), ('MCFT', 1), ('NYT', 1), ('PAG', 1), ('ATI', 1), ('KBR', 1), ('CINF', 1), ('PRGS', 1), ('ALSN', 1), ('SGEN', 1), ('PRMW', 1), ('MWA', 1)], [('TA', 3), ('TSLA', 3), ('WIRE', 3), ('CTLT', 3), ('OEC', 3), ('NATI', 3), ('PDFS', 3), ('EVRI', 3), ('CRUS', 3), ('TNK', 2), ('FTSM', 2), ('SMG', 2), ('CNK', 2), ('LRN', 2), ('ASC', 2), ('NVGS', 2), ('ACLS', 2), ('CAR', 2), ('CIGI', 2), ('THR', 1), ('PAR', 1), ('TNP', 1), ('HUBS', 1), ('TEX', 1), ('ATI', 1), ('FISV', 1), ('SGEN', 1), ('RACE', 1), ('MMS', 1), ('WYNN', 1), ('BYD', 1), ('URI', 1)], [('FTSM', 3), ('HSBC', 3), ('BVH', 3), ('WYNN', 3), ('MCFT', 3), ('META', 3), ('ALGN', 3), ('ATI', 3), ('PEN', 3), ('ACLS', 2), ('HTHT', 2), ('HZNP', 2), ('CCU', 2), ('BMA', 2), ('IPGP', 2), ('LVS', 2), ('GDS', 2), ('EDU', 2), ('CTLT', 2), ('WB', 1), ('PAR', 1), ('SMG', 1), ('AJRD', 1), ('LW', 1), ('URI', 1), ('TA', 1), ('VRNS', 1), ('EXAS', 1), ('MMS', 1), ('SGEN', 1), ('HEES', 1), ('OTTR', 1)], [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('ANF', 3), ('RMBS', 3), ('ACGL', 3), ('FIVE', 2), ('AGYS', 2), ('ASC', 2), ('FTI', 2), ('OI', 2), ('TPX', 2), ('RNR', 2), ('LOCO', 2), ('PERI', 2), ('LW', 2), ('IRDM', 2), ('FMX', 2), ('TTC', 1), ('ATKR', 1), ('ACLS', 1), ('TEX', 1), ('WYNN', 1), ('AXON', 1), ('THR', 1), ('HEES', 1), ('URI', 1), ('PEN', 1), ('BIIB', 1), ('DHI', 1), ('ISEE', 1), ('TMHC', 1), ('REGN', 1), ('ORI', 1), ('NFLX', 1), ('CNO', 1)]]
# **** finish lookback slices [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)] ****
#
# top 20 ranked symbols and frequency from set [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]:
# [('FTSM', 10), ('CTLT', 8), ('TA', 7), ('ASC', 6), ('ELF', 6), ('OEC', 6), ('PDFS', 6), ('WIRE', 6), ('ACLS', 5), ('ATI', 5), ('HZNP', 5), ('TNK', 5), ('WYNN', 5), ('MCFT', 4), ('MMS', 4), ('PEN', 4), ('THR', 4), ('ACGL', 3), ('ALGN', 3), ('ANF', 3)]
# top 20 ranked symbols from set [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]:
# ['FTSM', 'CTLT', 'TA', 'ASC', 'ELF', 'OEC', 'PDFS', 'WIRE', 'ACLS', 'ATI']
# ===== finish top 20 ranked symbols from days_lookback set [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)] =====
#
#
#
# ########## 3 of 57 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)]
# lb_slice:            (113, 128, 134)
# days eval:           6
# iloc_start_train:    113
# iloc_end_train:      128
# date_start_df_train: 2023-01-20
# date_end_df_train:   2023-02-09
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TSLA', 'CTLT', 'ELF', 'CINF', 'THR', 'ON', 'ICPT', 'CRUS', 'PH',
#        'LRN', 'AXP', 'ALGN', 'MPWR', 'NYT', 'META', 'URI', 'PSTG', 'NVDA',
#        'PAG', 'FORM'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'CTLT', 'ELF', 'ON', 'THR', 'ICPT', 'ALGN', 'MPWR', 'NVDA',
#        'FORM', 'PSTG', 'CRUS', 'LRN', 'CINF', 'SMG', 'META', 'ACLS',
#        'JWN', 'ANET', 'PAG'], dtype=object), 'r_retnStd/UI': array(['CINF', 'AXP', 'ELF', 'URI', 'NYT', 'PH', 'THR', 'STBA', 'CRUS',
#        'RCL', 'PRMW', 'LRN', 'MMS', 'WBS', 'FISV', 'CTLT', 'KEX', 'META',
#        'MWA', 'DNOW'], dtype=object)}}
# most_freq_syms: [('CTLT', 3), ('ELF', 3), ('CINF', 3), ('THR', 3), ('CRUS', 3), ('LRN', 3), ('META', 3), ('TSLA', 2), ('ON', 2), ('ICPT', 2), ('PH', 2), ('AXP', 2), ('ALGN', 2), ('MPWR', 2), ('NYT', 2), ('URI', 2), ('PSTG', 2), ('NVDA', 2), ('PAG', 2), ('FORM', 2), ('SMG', 1), ('ACLS', 1), ('JWN', 1), ('ANET', 1), ('STBA', 1), ('RCL', 1), ('PRMW', 1), ('MMS', 1), ('WBS', 1), ('FISV', 1), ('KEX', 1), ('MWA', 1), ('DNOW', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)]
# lb_slice:            (98, 128, 134)
# days eval:           6
# iloc_start_train:    98
# iloc_end_train:      128
# date_start_df_train: 2022-12-28
# date_end_df_train:   2023-02-09
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['ICPT', 'CTLT', 'TSLA', 'ACLS', 'SMG', 'RVNC', 'CRUS', 'W', 'RCL',
#        'NVDA', 'TRIP', 'NATI', 'META', 'NSTG', 'WBD', 'ALGN', 'MARA',
#        'EVRI', 'FORM', 'EXPE'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'ICPT', 'W', 'ACLS', 'MARA', 'SMG', 'CTLT', 'WBD', 'NVDA',
#        'TRIP', 'RVNC', 'RCL', 'CRUS', 'NSTG', 'ALGN', 'FORM', 'STAA',
#        'MPWR', 'SHOP', 'EXPE'], dtype=object), 'r_retnStd/UI': array(['DCP', 'NATI', 'CRUS', 'FTSM', 'CTLT', 'META', 'EVRI', 'SWKS',
#        'LRN', 'RACE', 'RVNC', 'MEOH', 'BYD', 'HLT', 'FISV', 'IGT', 'URI',
#        'EFR', 'JOE', 'CIGI'], dtype=object)}}
# most_freq_syms: [('CTLT', 3), ('RVNC', 3), ('CRUS', 3), ('ICPT', 2), ('TSLA', 2), ('ACLS', 2), ('SMG', 2), ('W', 2), ('RCL', 2), ('NVDA', 2), ('TRIP', 2), ('NATI', 2), ('META', 2), ('NSTG', 2), ('WBD', 2), ('ALGN', 2), ('MARA', 2), ('EVRI', 2), ('FORM', 2), ('EXPE', 2), ('STAA', 1), ('MPWR', 1), ('SHOP', 1), ('DCP', 1), ('FTSM', 1), ('SWKS', 1), ('LRN', 1), ('RACE', 1), ('MEOH', 1), ('BYD', 1), ('HLT', 1), ('FISV', 1), ('IGT', 1), ('URI', 1), ('EFR', 1), ('JOE', 1), ('CIGI', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)]
# lb_slice:            (68, 128, 134)
# days eval:           6
# iloc_start_train:    68
# iloc_end_train:      128
# date_start_df_train: 2022-11-14
# date_end_df_train:   2023-02-09
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['FTSM', 'BVH', 'ACLS', 'HSBC', 'BIDU', 'BURL', 'WB', 'HZNP',
#        'META', 'ANF', 'MTH', 'MCFT', 'ZTO', 'PEN', 'LVS', 'WYNN', 'MMS',
#        'TMHC', 'EDU', 'TOL'], dtype=object), 'r_CAGR/retnStd': array(['ACLS', 'BVH', 'FTSM', 'HSBC', 'WB', 'ANF', 'GDS', 'BIDU', 'EDU',
#        'THR', 'FORM', 'META', 'MTH', 'BMA', 'CRUS', 'WYNN', 'PEN', 'CCU',
#        'BABA', 'ELF'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'MMS', 'BVH', 'BURL', 'AJRD', 'MCFT', 'PNM', 'LW',
#        'TMHC', 'EXAS', 'TOL', 'META', 'ZTO', 'BIDU', 'COLL', 'MTH', 'RNR',
#        'LVS', 'BBWI'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('BVH', 3), ('BIDU', 3), ('META', 3), ('MTH', 3), ('ACLS', 2), ('HSBC', 2), ('BURL', 2), ('WB', 2), ('HZNP', 2), ('ANF', 2), ('MCFT', 2), ('ZTO', 2), ('PEN', 2), ('LVS', 2), ('WYNN', 2), ('MMS', 2), ('TMHC', 2), ('EDU', 2), ('TOL', 2), ('GDS', 1), ('THR', 1), ('FORM', 1), ('BMA', 1), ('CRUS', 1), ('CCU', 1), ('BABA', 1), ('ELF', 1), ('AJRD', 1), ('PNM', 1), ('LW', 1), ('EXAS', 1), ('COLL', 1), ('RNR', 1), ('BBWI', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)]
# lb_slice:            (8, 128, 134)
# days eval:           6
# iloc_start_train:    8
# iloc_end_train:      128
# date_start_df_train: 2022-08-19
# date_end_df_train:   2023-02-09
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['FTSM', 'ELF', 'HZNP', 'FTI', 'RNR', 'AGYS', 'ACGL', 'OI', 'RMBS',
#        'RCL', 'FIVE', 'COLL', 'LOCO', 'TPX', 'ASC', 'GILD', 'NFLX',
#        'WYNN', 'SLB', 'CCU'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'ELF', 'RMBS', 'HZNP', 'RCL', 'RNR', 'WYNN', 'FTI', 'PEN',
#        'ASC', 'ACLS', 'THR', 'EXAS', 'NVO', 'OI', 'BMA', 'AGYS', 'CCU',
#        'LVS', 'ATKR'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'ELF', 'FIVE', 'BIIB', 'ACGL', 'AGYS', 'REGN',
#        'ISEE', 'IRDM', 'OI', 'COLL', 'LOCO', 'NFLX', 'MODN', 'MGI', 'PCG',
#        'FTI', 'TPX', 'TS'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('FTI', 3), ('AGYS', 3), ('OI', 3), ('RNR', 2), ('ACGL', 2), ('RMBS', 2), ('RCL', 2), ('FIVE', 2), ('COLL', 2), ('LOCO', 2), ('TPX', 2), ('ASC', 2), ('NFLX', 2), ('WYNN', 2), ('CCU', 2), ('GILD', 1), ('SLB', 1), ('PEN', 1), ('ACLS', 1), ('THR', 1), ('EXAS', 1), ('NVO', 1), ('BMA', 1), ('LVS', 1), ('ATKR', 1), ('BIIB', 1), ('REGN', 1), ('ISEE', 1), ('IRDM', 1), ('MODN', 1), ('MGI', 1), ('PCG', 1), ('TS', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('CTLT', 3), ('ELF', 3), ('CINF', 3), ('THR', 3), ('CRUS', 3), ('LRN', 3), ('META', 3), ('TSLA', 2), ('ON', 2), ('ICPT', 2), ('PH', 2), ('AXP', 2), ('ALGN', 2), ('MPWR', 2), ('NYT', 2), ('URI', 2), ('PSTG', 2), ('NVDA', 2), ('PAG', 2), ('FORM', 2), ('SMG', 1), ('ACLS', 1), ('JWN', 1), ('ANET', 1), ('STBA', 1), ('RCL', 1), ('PRMW', 1), ('MMS', 1), ('WBS', 1), ('FISV', 1), ('KEX', 1), ('MWA', 1), ('DNOW', 1)], [('CTLT', 3), ('RVNC', 3), ('CRUS', 3), ('ICPT', 2), ('TSLA', 2), ('ACLS', 2), ('SMG', 2), ('W', 2), ('RCL', 2), ('NVDA', 2), ('TRIP', 2), ('NATI', 2), ('META', 2), ('NSTG', 2), ('WBD', 2), ('ALGN', 2), ('MARA', 2), ('EVRI', 2), ('FORM', 2), ('EXPE', 2), ('STAA', 1), ('MPWR', 1), ('SHOP', 1), ('DCP', 1), ('FTSM', 1), ('SWKS', 1), ('LRN', 1), ('RACE', 1), ('MEOH', 1), ('BYD', 1), ('HLT', 1), ('FISV', 1), ('IGT', 1), ('URI', 1), ('EFR', 1), ('JOE', 1), ('CIGI', 1)], [('FTSM', 3), ('BVH', 3), ('BIDU', 3), ('META', 3), ('MTH', 3), ('ACLS', 2), ('HSBC', 2), ('BURL', 2), ('WB', 2), ('HZNP', 2), ('ANF', 2), ('MCFT', 2), ('ZTO', 2), ('PEN', 2), ('LVS', 2), ('WYNN', 2), ('MMS', 2), ('TMHC', 2), ('EDU', 2), ('TOL', 2), ('GDS', 1), ('THR', 1), ('FORM', 1), ('BMA', 1), ('CRUS', 1), ('CCU', 1), ('BABA', 1), ('ELF', 1), ('AJRD', 1), ('PNM', 1), ('LW', 1), ('EXAS', 1), ('COLL', 1), ('RNR', 1), ('BBWI', 1)], [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('FTI', 3), ('AGYS', 3), ('OI', 3), ('RNR', 2), ('ACGL', 2), ('RMBS', 2), ('RCL', 2), ('FIVE', 2), ('COLL', 2), ('LOCO', 2), ('TPX', 2), ('ASC', 2), ('NFLX', 2), ('WYNN', 2), ('CCU', 2), ('GILD', 1), ('SLB', 1), ('PEN', 1), ('ACLS', 1), ('THR', 1), ('EXAS', 1), ('NVO', 1), ('BMA', 1), ('LVS', 1), ('ATKR', 1), ('BIIB', 1), ('REGN', 1), ('ISEE', 1), ('IRDM', 1), ('MODN', 1), ('MGI', 1), ('PCG', 1), ('TS', 1)]]
# **** finish lookback slices [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)] ****
#
# top 20 ranked symbols and frequency from set [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)]:
# [('META', 8), ('CRUS', 7), ('ELF', 7), ('FTSM', 7), ('ACLS', 6), ('CTLT', 6), ('FORM', 5), ('HZNP', 5), ('RCL', 5), ('THR', 5), ('ALGN', 4), ('ICPT', 4), ('LRN', 4), ('NVDA', 4), ('TSLA', 4), ('WYNN', 4), ('AGYS', 3), ('BIDU', 3), ('BVH', 3), ('CCU', 3)]
# top 20 ranked symbols from set [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)]:
# ['META', 'CRUS', 'ELF', 'FTSM', 'ACLS', 'CTLT', 'FORM', 'HZNP', 'RCL', 'THR']
# ===== finish top 20 ranked symbols from days_lookback set [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)] =====
#
#
#
# ########## 4 of 57 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# lb_slice:            (123, 138, 144)
# days eval:           6
# iloc_start_train:    123
# iloc_end_train:      138
# date_start_df_train: 2023-02-03
# date_end_df_train:   2023-02-24
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TA', 'TNK', 'TNP', 'ACGL', 'CNA', 'STNG', 'SGEN', 'OEC', 'ASC',
#        'CTLT', 'PDFS', 'LNTH', 'AMCX', 'FTI', 'HZO', 'MMS', 'KBR', 'EURN',
#        'BP', 'NOC'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'TNK', 'TNP', 'STNG', 'ASC', 'ACGL', 'CTLT', 'AMCX', 'OEC',
#        'SGEN', 'FTI', 'LNTH', 'RRC', 'CNA', 'PDFS', 'XPRO', 'BP', 'EURN',
#        'HZO', 'CLMT'], dtype=object), 'r_retnStd/UI': array(['TA', 'CNA', 'ATCO', 'MSGS', 'KBR', 'TNK', 'SGEN', 'MMS', 'FTSM',
#        'ACGL', 'OEC', 'TWNK', 'EME', 'PDFS', 'NVGS', 'FDP', 'PGR', 'FCN',
#        'HUM', 'HZO'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('TNK', 3), ('ACGL', 3), ('CNA', 3), ('SGEN', 3), ('OEC', 3), ('PDFS', 3), ('HZO', 3), ('TNP', 2), ('STNG', 2), ('ASC', 2), ('CTLT', 2), ('LNTH', 2), ('AMCX', 2), ('FTI', 2), ('MMS', 2), ('KBR', 2), ('EURN', 2), ('BP', 2), ('NOC', 1), ('RRC', 1), ('XPRO', 1), ('CLMT', 1), ('ATCO', 1), ('MSGS', 1), ('FTSM', 1), ('TWNK', 1), ('EME', 1), ('NVGS', 1), ('FDP', 1), ('PGR', 1), ('FCN', 1), ('HUM', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# lb_slice:            (108, 138, 144)
# days eval:           6
# iloc_start_train:    108
# iloc_end_train:      138
# date_start_df_train: 2023-01-12
# date_end_df_train:   2023-02-24
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TA', 'ELF', 'TNK', 'TSLA', 'OEC', 'LNTH', 'CTLT', 'SMG', 'NVDA',
#        'FTSM', 'LRN', 'NVGS', 'EURN', 'PDFS', 'ASC', 'TEX', 'SGEN',
#        'WIRE', 'ACLS', 'THR'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'TNK', 'TA', 'ELF', 'LNTH', 'SMG', 'NVDA', 'OEC', 'CTLT',
#        'ASC', 'EURN', 'TEX', 'RVNC', 'ACLS', 'TNP', 'XPRO', 'THR', 'CNK',
#        'WIRE', 'CRUS'], dtype=object), 'r_retnStd/UI': array(['TA', 'ELF', 'OEC', 'FTSM', 'LRN', 'NVGS', 'LNTH', 'PDFS', 'SGEN',
#        'TNK', 'CTLT', 'MMS', 'FISV', 'NATI', 'AQN', 'EURN', 'CME', 'TSLA',
#        'WIRE', 'CIGI'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('ELF', 3), ('TNK', 3), ('TSLA', 3), ('OEC', 3), ('LNTH', 3), ('CTLT', 3), ('EURN', 3), ('WIRE', 3), ('SMG', 2), ('NVDA', 2), ('FTSM', 2), ('LRN', 2), ('NVGS', 2), ('PDFS', 2), ('ASC', 2), ('TEX', 2), ('SGEN', 2), ('ACLS', 2), ('THR', 2), ('RVNC', 1), ('TNP', 1), ('XPRO', 1), ('CNK', 1), ('CRUS', 1), ('MMS', 1), ('FISV', 1), ('NATI', 1), ('AQN', 1), ('CME', 1), ('CIGI', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# lb_slice:            (78, 138, 144)
# days eval:           6
# iloc_start_train:    78
# iloc_end_train:      138
# date_start_df_train: 2022-11-29
# date_end_df_train:   2023-02-24
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['FTSM', 'BVH', 'ACLS', 'MCFT', 'CRUS', 'PEN', 'META', 'HZNP',
#        'HEES', 'ALGN', 'ATI', 'IPGP', 'SGEN', 'HSBC', 'AJRD', 'TPX',
#        'CCU', 'PAR', 'URI', 'WYNN'], dtype=object), 'r_CAGR/retnStd': array(['ACLS', 'BVH', 'FTSM', 'CRUS', 'PAR', 'SMG', 'TPX', 'ALGN', 'META',
#        'BMA', 'IPGP', 'CCU', 'HSBC', 'OEC', 'PEN', 'ATI', 'MCFT', 'THR',
#        'TX', 'HEES'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'AJRD', 'MCFT', 'LW', 'TA', 'SGEN', 'HEES', 'RVNC',
#        'PEN', 'MMS', 'OTTR', 'VRNS', 'URI', 'ATI', 'WYNN', 'PNM', 'ACGL',
#        'EXAS', 'BVH'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('BVH', 3), ('MCFT', 3), ('PEN', 3), ('HEES', 3), ('ATI', 3), ('ACLS', 2), ('CRUS', 2), ('META', 2), ('HZNP', 2), ('ALGN', 2), ('IPGP', 2), ('SGEN', 2), ('HSBC', 2), ('AJRD', 2), ('TPX', 2), ('CCU', 2), ('PAR', 2), ('URI', 2), ('WYNN', 2), ('SMG', 1), ('BMA', 1), ('OEC', 1), ('THR', 1), ('TX', 1), ('LW', 1), ('TA', 1), ('RVNC', 1), ('MMS', 1), ('OTTR', 1), ('VRNS', 1), ('PNM', 1), ('ACGL', 1), ('EXAS', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# lb_slice:            (18, 138, 144)
# days eval:           6
# iloc_start_train:    18
# iloc_end_train:      138
# date_start_df_train: 2022-09-02
# date_end_df_train:   2023-02-24
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['FTSM', 'ELF', 'HZNP', 'RMBS', 'ANF', 'ACGL', 'FTI', 'AGYS', 'TPX',
#        'OI', 'FIVE', 'HEES', 'ACLS', 'CNO', 'ISEE', 'TEX', 'LOCO', 'ATKR',
#        'LW', 'ASC'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'RMBS', 'ACLS', 'ELF', 'TEX', 'FTI', 'HEES', 'AXON', 'TPX',
#        'HZNP', 'ANF', 'ASC', 'THR', 'ACGL', 'WYNN', 'OI', 'PERI', 'GE',
#        'ATKR', 'FMX'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'ELF', 'LW', 'ANF', 'AGYS', 'ACGL', 'TMHC', 'FIVE',
#        'BIIB', 'QNST', 'ISEE', 'IRDM', 'REGN', 'LOCO', 'ORI', 'DHI', 'OI',
#        'CNO', 'MMS'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('ANF', 3), ('ACGL', 3), ('OI', 3), ('RMBS', 2), ('FTI', 2), ('AGYS', 2), ('TPX', 2), ('FIVE', 2), ('HEES', 2), ('ACLS', 2), ('CNO', 2), ('ISEE', 2), ('TEX', 2), ('LOCO', 2), ('ATKR', 2), ('LW', 2), ('ASC', 2), ('AXON', 1), ('THR', 1), ('WYNN', 1), ('PERI', 1), ('GE', 1), ('FMX', 1), ('TMHC', 1), ('BIIB', 1), ('QNST', 1), ('IRDM', 1), ('REGN', 1), ('ORI', 1), ('DHI', 1), ('MMS', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('TA', 3), ('TNK', 3), ('ACGL', 3), ('CNA', 3), ('SGEN', 3), ('OEC', 3), ('PDFS', 3), ('HZO', 3), ('TNP', 2), ('STNG', 2), ('ASC', 2), ('CTLT', 2), ('LNTH', 2), ('AMCX', 2), ('FTI', 2), ('MMS', 2), ('KBR', 2), ('EURN', 2), ('BP', 2), ('NOC', 1), ('RRC', 1), ('XPRO', 1), ('CLMT', 1), ('ATCO', 1), ('MSGS', 1), ('FTSM', 1), ('TWNK', 1), ('EME', 1), ('NVGS', 1), ('FDP', 1), ('PGR', 1), ('FCN', 1), ('HUM', 1)], [('TA', 3), ('ELF', 3), ('TNK', 3), ('TSLA', 3), ('OEC', 3), ('LNTH', 3), ('CTLT', 3), ('EURN', 3), ('WIRE', 3), ('SMG', 2), ('NVDA', 2), ('FTSM', 2), ('LRN', 2), ('NVGS', 2), ('PDFS', 2), ('ASC', 2), ('TEX', 2), ('SGEN', 2), ('ACLS', 2), ('THR', 2), ('RVNC', 1), ('TNP', 1), ('XPRO', 1), ('CNK', 1), ('CRUS', 1), ('MMS', 1), ('FISV', 1), ('NATI', 1), ('AQN', 1), ('CME', 1), ('CIGI', 1)], [('FTSM', 3), ('BVH', 3), ('MCFT', 3), ('PEN', 3), ('HEES', 3), ('ATI', 3), ('ACLS', 2), ('CRUS', 2), ('META', 2), ('HZNP', 2), ('ALGN', 2), ('IPGP', 2), ('SGEN', 2), ('HSBC', 2), ('AJRD', 2), ('TPX', 2), ('CCU', 2), ('PAR', 2), ('URI', 2), ('WYNN', 2), ('SMG', 1), ('BMA', 1), ('OEC', 1), ('THR', 1), ('TX', 1), ('LW', 1), ('TA', 1), ('RVNC', 1), ('MMS', 1), ('OTTR', 1), ('VRNS', 1), ('PNM', 1), ('ACGL', 1), ('EXAS', 1)], [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('ANF', 3), ('ACGL', 3), ('OI', 3), ('RMBS', 2), ('FTI', 2), ('AGYS', 2), ('TPX', 2), ('FIVE', 2), ('HEES', 2), ('ACLS', 2), ('CNO', 2), ('ISEE', 2), ('TEX', 2), ('LOCO', 2), ('ATKR', 2), ('LW', 2), ('ASC', 2), ('AXON', 1), ('THR', 1), ('WYNN', 1), ('PERI', 1), ('GE', 1), ('FMX', 1), ('TMHC', 1), ('BIIB', 1), ('QNST', 1), ('IRDM', 1), ('REGN', 1), ('ORI', 1), ('DHI', 1), ('MMS', 1)]]
# **** finish lookback slices [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)] ****
#
# top 20 ranked symbols and frequency from set [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]:
# [('FTSM', 9), ('ACGL', 7), ('OEC', 7), ('SGEN', 7), ('TA', 7), ('ACLS', 6), ('ASC', 6), ('ELF', 6), ('TNK', 6), ('CTLT', 5), ('EURN', 5), ('HEES', 5), ('HZNP', 5), ('LNTH', 5), ('MMS', 5), ('PDFS', 5), ('FTI', 4), ('TEX', 4), ('THR', 4), ('TPX', 4)]
# top 20 ranked symbols from set [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]:
# ['FTSM', 'ACGL', 'OEC', 'SGEN', 'TA', 'ACLS', 'ASC', 'ELF', 'TNK', 'CTLT']
# ===== finish top 20 ranked symbols from days_lookback set [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)] =====
#
#
#
# ########## 5 of 57 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]
# lb_slice:            (109, 124, 130)
# days eval:           6
# iloc_start_train:    109
# iloc_end_train:      124
# date_start_df_train: 2023-01-13
# date_end_df_train:   2023-02-03
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TSLA', 'JWN', 'W', 'ALGN', 'META', 'ELF', 'AN', 'SHOP', 'SMG',
#        'PEB', 'ALLY', 'CRUS', 'BVH', 'DBRG', 'LRN', 'STX', 'SITE', 'SQM',
#        'RVNC', 'RAMP'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'W', 'JWN', 'ALGN', 'SHOP', 'SMG', 'META', 'ELF', 'DBRG',
#        'AN', 'BVH', 'PEB', 'ALLY', 'CACC', 'FATE', 'RVNC', 'LRN', 'ON',
#        'BSIG', 'NVDA'], dtype=object), 'r_retnStd/UI': array(['JWN', 'PEB', 'AN', 'CRUS', 'ELF', 'META', 'NATI', 'ALGN', 'SQM',
#        'RC', 'RAMP', 'JOE', 'ALLY', 'BYD', 'SBH', 'LRN', 'LAUR', 'PHM',
#        'MRCY', 'EVRI'], dtype=object)}}
# most_freq_syms: [('JWN', 3), ('ALGN', 3), ('META', 3), ('ELF', 3), ('AN', 3), ('PEB', 3), ('ALLY', 3), ('LRN', 3), ('TSLA', 2), ('W', 2), ('SHOP', 2), ('SMG', 2), ('CRUS', 2), ('BVH', 2), ('DBRG', 2), ('SQM', 2), ('RVNC', 2), ('RAMP', 2), ('STX', 1), ('SITE', 1), ('CACC', 1), ('FATE', 1), ('ON', 1), ('BSIG', 1), ('NVDA', 1), ('NATI', 1), ('RC', 1), ('JOE', 1), ('BYD', 1), ('SBH', 1), ('LAUR', 1), ('PHM', 1), ('MRCY', 1), ('EVRI', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]
# lb_slice:            (94, 124, 130)
# days eval:           6
# iloc_start_train:    94
# iloc_end_train:      124
# date_start_df_train: 2022-12-21
# date_end_df_train:   2023-02-03
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['ALGN', 'WBD', 'SMG', 'PAR', 'META', 'RVNC', 'BVH', 'MARA', 'W',
#        'SBH', 'ALLY', 'JWN', 'SBGI', 'EVRI', 'STX', 'NSTG', 'PARA',
#        'EXPE', 'BOOT', 'STAA'], dtype=object), 'r_CAGR/retnStd': array(['WBD', 'MARA', 'PAR', 'SMG', 'W', 'RVNC', 'ALGN', 'BVH', 'STAA',
#        'JWN', 'META', 'PARA', 'EVRI', 'ZUMZ', 'SBGI', 'NSTG', 'ACLS',
#        'SBH', 'CLAR', 'DENN'], dtype=object), 'r_retnStd/UI': array(['DCP', 'ALGN', 'META', 'SBH', 'ALLY', 'PHM', 'LRN', 'DLB', 'STX',
#        'BVH', 'IHG', 'EVTC', 'NATI', 'SJR', 'PNR', 'TROX', 'OEC', 'SUN',
#        'COF', 'EXPE'], dtype=object)}}
# most_freq_syms: [('ALGN', 3), ('META', 3), ('BVH', 3), ('SBH', 3), ('WBD', 2), ('SMG', 2), ('PAR', 2), ('RVNC', 2), ('MARA', 2), ('W', 2), ('ALLY', 2), ('JWN', 2), ('SBGI', 2), ('EVRI', 2), ('STX', 2), ('NSTG', 2), ('PARA', 2), ('EXPE', 2), ('STAA', 2), ('BOOT', 1), ('ZUMZ', 1), ('ACLS', 1), ('CLAR', 1), ('DENN', 1), ('DCP', 1), ('PHM', 1), ('LRN', 1), ('DLB', 1), ('IHG', 1), ('EVTC', 1), ('NATI', 1), ('SJR', 1), ('PNR', 1), ('TROX', 1), ('OEC', 1), ('SUN', 1), ('COF', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]
# lb_slice:            (64, 124, 130)
# days eval:           6
# iloc_start_train:    64
# iloc_end_train:      124
# date_start_df_train: 2022-11-08
# date_end_df_train:   2023-02-03
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['BVH', 'FTSM', 'BURL', 'META', 'RAMP', 'ZTO', 'MTH', 'GDS', 'ENV',
#        'PHM', 'PUK', 'WB', 'TOL', 'ACLS', 'BIDU', 'PEN', 'ALGN', 'TPX',
#        'ANF', 'TMHC'], dtype=object), 'r_CAGR/retnStd': array(['GDS', 'META', 'BVH', 'RAMP', 'ALGN', 'ACLS', 'BURL', 'W', 'WB',
#        'NSTG', 'MTH', 'PUK', 'PERI', 'ANF', 'AMBA', 'PEN', 'TPX', 'BIDU',
#        'ENV', 'FTSM'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'BVH', 'ZTO', 'HZNP', 'BURL', 'TOL', 'COLL', 'MTH', 'TMHC',
#        'PHM', 'MMS', 'DHI', 'ENV', 'PNM', 'NKE', 'MKSI', 'RAMP', 'AJRD',
#        'META', 'MCFT'], dtype=object)}}
# most_freq_syms: [('BVH', 3), ('FTSM', 3), ('BURL', 3), ('META', 3), ('RAMP', 3), ('MTH', 3), ('ENV', 3), ('ZTO', 2), ('GDS', 2), ('PHM', 2), ('PUK', 2), ('WB', 2), ('TOL', 2), ('ACLS', 2), ('BIDU', 2), ('PEN', 2), ('ALGN', 2), ('TPX', 2), ('ANF', 2), ('TMHC', 2), ('W', 1), ('NSTG', 1), ('PERI', 1), ('AMBA', 1), ('HZNP', 1), ('COLL', 1), ('MMS', 1), ('DHI', 1), ('PNM', 1), ('NKE', 1), ('MKSI', 1), ('AJRD', 1), ('MCFT', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]
# lb_slice:            (4, 124, 130)
# days eval:           6
# iloc_start_train:    4
# iloc_end_train:      124
# date_start_df_train: 2022-08-15
# date_end_df_train:   2023-02-03
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['FTSM', 'ELF', 'HZNP', 'BKE', 'OI', 'RNR', 'FTI', 'LOCO', 'SLB',
#        'ACGL', 'RMBS', 'AGYS', 'COLL', 'PERI', 'DCP', 'CCU', 'GILD',
#        'STLD', 'XPRO', 'LVS'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'ELF', 'RMBS', 'BKE', 'OI', 'RNR', 'HZNP', 'AXON', 'STLD',
#        'PERI', 'COLL', 'ATKR', 'AJRD', 'CCU', 'LOCO', 'FTI', 'BMA', 'TPX',
#        'ASC', 'AGYS'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'ELF', 'DCP', 'IRDM', 'ACGL', 'BIIB', 'MGI',
#        'ISEE', 'PCG', 'TS', 'FTI', 'REGN', 'OI', 'VALE', 'SLB', 'NFLX',
#        'GILD', 'AGYS', 'FIVE'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('OI', 3), ('FTI', 3), ('AGYS', 3), ('BKE', 2), ('RNR', 2), ('LOCO', 2), ('SLB', 2), ('ACGL', 2), ('RMBS', 2), ('COLL', 2), ('PERI', 2), ('DCP', 2), ('CCU', 2), ('GILD', 2), ('STLD', 2), ('XPRO', 1), ('LVS', 1), ('AXON', 1), ('ATKR', 1), ('AJRD', 1), ('BMA', 1), ('TPX', 1), ('ASC', 1), ('IRDM', 1), ('BIIB', 1), ('MGI', 1), ('ISEE', 1), ('PCG', 1), ('TS', 1), ('REGN', 1), ('VALE', 1), ('NFLX', 1), ('FIVE', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('JWN', 3), ('ALGN', 3), ('META', 3), ('ELF', 3), ('AN', 3), ('PEB', 3), ('ALLY', 3), ('LRN', 3), ('TSLA', 2), ('W', 2), ('SHOP', 2), ('SMG', 2), ('CRUS', 2), ('BVH', 2), ('DBRG', 2), ('SQM', 2), ('RVNC', 2), ('RAMP', 2), ('STX', 1), ('SITE', 1), ('CACC', 1), ('FATE', 1), ('ON', 1), ('BSIG', 1), ('NVDA', 1), ('NATI', 1), ('RC', 1), ('JOE', 1), ('BYD', 1), ('SBH', 1), ('LAUR', 1), ('PHM', 1), ('MRCY', 1), ('EVRI', 1)], [('ALGN', 3), ('META', 3), ('BVH', 3), ('SBH', 3), ('WBD', 2), ('SMG', 2), ('PAR', 2), ('RVNC', 2), ('MARA', 2), ('W', 2), ('ALLY', 2), ('JWN', 2), ('SBGI', 2), ('EVRI', 2), ('STX', 2), ('NSTG', 2), ('PARA', 2), ('EXPE', 2), ('STAA', 2), ('BOOT', 1), ('ZUMZ', 1), ('ACLS', 1), ('CLAR', 1), ('DENN', 1), ('DCP', 1), ('PHM', 1), ('LRN', 1), ('DLB', 1), ('IHG', 1), ('EVTC', 1), ('NATI', 1), ('SJR', 1), ('PNR', 1), ('TROX', 1), ('OEC', 1), ('SUN', 1), ('COF', 1)], [('BVH', 3), ('FTSM', 3), ('BURL', 3), ('META', 3), ('RAMP', 3), ('MTH', 3), ('ENV', 3), ('ZTO', 2), ('GDS', 2), ('PHM', 2), ('PUK', 2), ('WB', 2), ('TOL', 2), ('ACLS', 2), ('BIDU', 2), ('PEN', 2), ('ALGN', 2), ('TPX', 2), ('ANF', 2), ('TMHC', 2), ('W', 1), ('NSTG', 1), ('PERI', 1), ('AMBA', 1), ('HZNP', 1), ('COLL', 1), ('MMS', 1), ('DHI', 1), ('PNM', 1), ('NKE', 1), ('MKSI', 1), ('AJRD', 1), ('MCFT', 1)], [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('OI', 3), ('FTI', 3), ('AGYS', 3), ('BKE', 2), ('RNR', 2), ('LOCO', 2), ('SLB', 2), ('ACGL', 2), ('RMBS', 2), ('COLL', 2), ('PERI', 2), ('DCP', 2), ('CCU', 2), ('GILD', 2), ('STLD', 2), ('XPRO', 1), ('LVS', 1), ('AXON', 1), ('ATKR', 1), ('AJRD', 1), ('BMA', 1), ('TPX', 1), ('ASC', 1), ('IRDM', 1), ('BIIB', 1), ('MGI', 1), ('ISEE', 1), ('PCG', 1), ('TS', 1), ('REGN', 1), ('VALE', 1), ('NFLX', 1), ('FIVE', 1)]]
# **** finish lookback slices [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)] ****
#
# top 20 ranked symbols and frequency from set [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]:
# [('META', 9), ('ALGN', 8), ('BVH', 8), ('ELF', 6), ('FTSM', 6), ('ALLY', 5), ('JWN', 5), ('RAMP', 5), ('W', 5), ('HZNP', 4), ('LRN', 4), ('PHM', 4), ('RVNC', 4), ('SBH', 4), ('SMG', 4), ('ACLS', 3), ('AGYS', 3), ('AN', 3), ('BURL', 3), ('COLL', 3)]
# top 20 ranked symbols from set [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]:
# ['META', 'ALGN', 'BVH', 'ELF', 'FTSM', 'ALLY', 'JWN', 'RAMP', 'W', 'HZNP']
# ===== finish top 20 ranked symbols from days_lookback set [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)] =====
#
#
#
# ########## 6 of 57 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(117, 132, 138), (102, 132, 138), (72, 132, 138), (12, 132, 138)]
# lb_slice:            (117, 132, 138)
# days eval:           6
# iloc_start_train:    117
# iloc_end_train:      132
# date_start_df_train: 2023-01-26
# date_end_df_train:   2023-02-15
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['DCP', 'ASC', 'STNG', 'TNK', 'ELF', 'CTLT', 'TSLA', 'SMG', 'TNP',
#        'FCF', 'THR', 'CAR', 'WIRE', 'PH', 'CINF', 'PAG', 'MMS', 'AXP',
#        'SFBS', 'MCFT'], dtype=object), 'r_CAGR/retnStd': array(['ASC', 'STNG', 'TNK', 'SMG', 'TSLA', 'CTLT', 'CAR', 'TNP', 'ELF',
#        'TTD', 'WIRE', 'FCF', 'PAG', 'THR', 'MCFT', 'RNG', 'ALGN', 'AN',
#        'MPWR', 'HLF'], dtype=object), 'r_retnStd/UI': array(['DCP', 'AXP', 'MMS', 'PH', 'SFBS', 'ELF', 'CINF', 'FCF', 'DXCM',
#        'CTLT', 'FISV', 'ENS', 'THR', 'STBA', 'FTSM', 'ADI', 'STNG',
#        'CRUS', 'TNK', 'GM'], dtype=object)}}
# most_freq_syms: [('STNG', 3), ('TNK', 3), ('ELF', 3), ('CTLT', 3), ('FCF', 3), ('THR', 3), ('DCP', 2), ('ASC', 2), ('TSLA', 2), ('SMG', 2), ('TNP', 2), ('CAR', 2), ('WIRE', 2), ('PH', 2), ('CINF', 2), ('PAG', 2), ('MMS', 2), ('AXP', 2), ('SFBS', 2), ('MCFT', 2), ('TTD', 1), ('RNG', 1), ('ALGN', 1), ('AN', 1), ('MPWR', 1), ('HLF', 1), ('DXCM', 1), ('FISV', 1), ('ENS', 1), ('STBA', 1), ('FTSM', 1), ('ADI', 1), ('CRUS', 1), ('GM', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(117, 132, 138), (102, 132, 138), (72, 132, 138), (12, 132, 138)]
# lb_slice:            (102, 132, 138)
# days eval:           6
# iloc_start_train:    102
# iloc_end_train:      132
# date_start_df_train: 2023-01-04
# date_end_df_train:   2023-02-15
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TSLA', 'ACLS', 'CRUS', 'ICPT', 'RVNC', 'NVDA', 'DCP', 'CTLT',
#        'RCL', 'WIRE', 'MARA', 'EVRI', 'MPWR', 'FORM', 'NATI', 'LSCC',
#        'CAR', 'TNK', 'ON', 'CRS'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'ACLS', 'MARA', 'ICPT', 'RVNC', 'NVDA', 'RCL', 'CRUS',
#        'SMG', 'WBD', 'TNK', 'MPWR', 'TEAM', 'NCLH', 'FORM', 'WIRE', 'CAR',
#        'CRS', 'CTLT', 'LSCC'], dtype=object), 'r_retnStd/UI': array(['DCP', 'CRUS', 'FTSM', 'NATI', 'CTLT', 'LRN', 'FISV', 'EVRI',
#        'NVGS', 'SWKS', 'WIRE', 'BYD', 'ON', 'URI', 'TSLA', 'STX', 'RVNC',
#        'CIGI', 'EFR', 'HLT'], dtype=object)}}
# most_freq_syms: [('TSLA', 3), ('CRUS', 3), ('RVNC', 3), ('CTLT', 3), ('WIRE', 3), ('ACLS', 2), ('ICPT', 2), ('NVDA', 2), ('DCP', 2), ('RCL', 2), ('MARA', 2), ('EVRI', 2), ('MPWR', 2), ('FORM', 2), ('NATI', 2), ('LSCC', 2), ('CAR', 2), ('TNK', 2), ('ON', 2), ('CRS', 2), ('SMG', 1), ('WBD', 1), ('TEAM', 1), ('NCLH', 1), ('FTSM', 1), ('LRN', 1), ('FISV', 1), ('NVGS', 1), ('SWKS', 1), ('BYD', 1), ('URI', 1), ('STX', 1), ('CIGI', 1), ('EFR', 1), ('HLT', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(117, 132, 138), (102, 132, 138), (72, 132, 138), (12, 132, 138)]
# lb_slice:            (72, 132, 138)
# days eval:           6
# iloc_start_train:    72
# iloc_end_train:      132
# date_start_df_train: 2022-11-18
# date_end_df_train:   2023-02-15
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['FTSM', 'BVH', 'ALGN', 'ACLS', 'BMA', 'BURL', 'META', 'ANF', 'MTH',
#        'WYNN', 'MMS', 'PEN', 'MCFT', 'HSBC', 'NSTG', 'BIDU', 'HZNP',
#        'CCU', 'IPGP', 'URI'], dtype=object), 'r_CAGR/retnStd': array(['ACLS', 'BMA', 'BVH', 'ALGN', 'FTSM', 'ANF', 'CCU', 'HSBC', 'CTLT',
#        'IBP', 'WYNN', 'THR', 'IPGP', 'MTH', 'META', 'NSTG', 'TEAM', 'PEN',
#        'BIDU', 'TPX'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'MMS', 'BURL', 'AJRD', 'MCFT', 'ALGN', 'BVH', 'LW',
#        'EXAS', 'META', 'WB', 'TMHC', 'VRNS', 'URI', 'MTH', 'SPR', 'PEN',
#        'LVS', 'PNM'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('BVH', 3), ('ALGN', 3), ('META', 3), ('MTH', 3), ('PEN', 3), ('ACLS', 2), ('BMA', 2), ('BURL', 2), ('ANF', 2), ('WYNN', 2), ('MMS', 2), ('MCFT', 2), ('HSBC', 2), ('NSTG', 2), ('BIDU', 2), ('HZNP', 2), ('CCU', 2), ('IPGP', 2), ('URI', 2), ('CTLT', 1), ('IBP', 1), ('THR', 1), ('TEAM', 1), ('TPX', 1), ('AJRD', 1), ('LW', 1), ('EXAS', 1), ('WB', 1), ('TMHC', 1), ('VRNS', 1), ('SPR', 1), ('LVS', 1), ('PNM', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(117, 132, 138), (102, 132, 138), (72, 132, 138), (12, 132, 138)]
# lb_slice:            (12, 132, 138)
# days eval:           6
# iloc_start_train:    12
# iloc_end_train:      132
# date_start_df_train: 2022-08-25
# date_end_df_train:   2023-02-15
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['FTSM', 'ELF', 'HZNP', 'ACGL', 'ASC', 'FIVE', 'AGYS', 'FTI', 'RNR',
#        'ANF', 'TPX', 'OI', 'ISEE', 'RMBS', 'LOCO', 'PERI', 'GILD', 'NFLX',
#        'COLL', 'TTC'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'ELF', 'ASC', 'RMBS', 'RNR', 'HZNP', 'FTI', 'AXON', 'ANF',
#        'ACGL', 'PERI', 'TEX', 'THR', 'WYNN', 'RCL', 'TPX', 'ATKR', 'OMC',
#        'PEN', 'AGYS'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'ELF', 'BIIB', 'FIVE', 'ACGL', 'ISEE', 'REGN',
#        'AGYS', 'NFLX', 'LOCO', 'OI', 'IRDM', 'COLL', 'TPX', 'CNO', 'ANF',
#        'FTI', 'GILD', 'LW'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('ACGL', 3), ('AGYS', 3), ('FTI', 3), ('ANF', 3), ('TPX', 3), ('ASC', 2), ('FIVE', 2), ('RNR', 2), ('OI', 2), ('ISEE', 2), ('RMBS', 2), ('LOCO', 2), ('PERI', 2), ('GILD', 2), ('NFLX', 2), ('COLL', 2), ('TTC', 1), ('AXON', 1), ('TEX', 1), ('THR', 1), ('WYNN', 1), ('RCL', 1), ('ATKR', 1), ('OMC', 1), ('PEN', 1), ('BIIB', 1), ('REGN', 1), ('IRDM', 1), ('CNO', 1), ('LW', 1)]
# +++ finish lookback slice 120 +++
#
# ...
#        'AN', 'CRUS', 'PAG', 'SMG', 'SHOP', 'CACC', 'SAIA', 'DBRG', 'ALLY',
#        'PACW', 'AX'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'W', 'CTLT', 'ALGN', 'META', 'JWN', 'SMG', 'ICPT', 'ELF',
#        'SHOP', 'AN', 'CACC', 'LRN', 'DBRG', 'SAIA', 'PACW', 'RVNC', 'PRG',
#        'PAG', 'CRUS'], dtype=object), 'r_retnStd/UI': array(['LRN', 'META', 'CRUS', 'PAG', 'ELF', 'SUN', 'ALGN', 'OI', 'AX',
#        'CUBE', 'ICPT', 'ALLY', 'JWN', 'ST', 'AN', 'OEC', 'JOE', 'BYD',
#        'CTLT', 'MRCY'], dtype=object)}}
# most_freq_syms: [('META', 3), ('CTLT', 3), ('ALGN', 3), ('JWN', 3), ('LRN', 3), ('ELF', 3), ('ICPT', 3), ('AN', 3), ('CRUS', 3), ('PAG', 3), ('TSLA', 2), ('W', 2), ('SMG', 2), ('SHOP', 2), ('CACC', 2), ('SAIA', 2), ('DBRG', 2), ('ALLY', 2), ('PACW', 2), ('AX', 2), ('RVNC', 1), ('PRG', 1), ('SUN', 1), ('OI', 1), ('CUBE', 1), ('ST', 1), ('OEC', 1), ('JOE', 1), ('BYD', 1), ('MRCY', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)]
# lb_slice:            (95, 125, 131)
# days eval:           6
# iloc_start_train:    95
# iloc_end_train:      125
# date_start_df_train: 2022-12-22
# date_end_df_train:   2023-02-06
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['ALGN', 'W', 'META', 'SMG', 'WBD', 'CTLT', 'MARA', 'PAR', 'NATI',
#        'RVNC', 'EXPE', 'SBH', 'NSTG', 'MEOH', 'ALLY', 'KSS', 'STX',
#        'ACLS', 'SHOP', 'PERI'], dtype=object), 'r_CAGR/retnStd': array(['W', 'MARA', 'SMG', 'WBD', 'ALGN', 'PAR', 'META', 'RVNC', 'CTLT',
#        'NSTG', 'EXPE', 'ACLS', 'ICPT', 'TSLA', 'KSS', 'ANF', 'TRIP',
#        'SHOP', 'DENN', 'PARA'], dtype=object), 'r_retnStd/UI': array(['DCP', 'META', 'NATI', 'ALGN', 'ALLY', 'SBH', 'LRN', 'CTLT', 'SJR',
#        'ST', 'MEOH', 'OEC', 'STX', 'SUN', 'ALV', 'IGT', 'RACE', 'SMG',
#        'EXPE', 'AX'], dtype=object)}}
# most_freq_syms: [('ALGN', 3), ('META', 3), ('SMG', 3), ('CTLT', 3), ('EXPE', 3), ('W', 2), ('WBD', 2), ('MARA', 2), ('PAR', 2), ('NATI', 2), ('RVNC', 2), ('SBH', 2), ('NSTG', 2), ('MEOH', 2), ('ALLY', 2), ('KSS', 2), ('STX', 2), ('ACLS', 2), ('SHOP', 2), ('PERI', 1), ('ICPT', 1), ('TSLA', 1), ('ANF', 1), ('TRIP', 1), ('DENN', 1), ('PARA', 1), ('DCP', 1), ('LRN', 1), ('SJR', 1), ('ST', 1), ('OEC', 1), ('SUN', 1), ('ALV', 1), ('IGT', 1), ('RACE', 1), ('AX', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)]
# lb_slice:            (65, 125, 131)
# days eval:           6
# iloc_start_train:    65
# iloc_end_train:      125
# date_start_df_train: 2022-11-09
# date_end_df_train:   2023-02-06
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['FTSM', 'BVH', 'BURL', 'GDS', 'ZTO', 'META', 'BIDU', 'WB', 'MTH',
#        'ANF', 'W', 'ENV', 'PHM', 'ALGN', 'PUK', 'TOL', 'PEN', 'LVS',
#        'ACLS', 'NSTG'], dtype=object), 'r_CAGR/retnStd': array(['GDS', 'W', 'ALGN', 'META', 'NSTG', 'WB', 'ACLS', 'BIDU', 'BURL',
#        'ANF', 'BVH', 'PAR', 'ZTO', 'AMBA', 'CTRN', 'PUK', 'FTSM', 'PEN',
#        'HSBC', 'WYNN'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'BVH', 'HZNP', 'ZTO', 'BURL', 'TOL', 'TMHC', 'MTH', 'COLL',
#        'MMS', 'PHM', 'ENV', 'DHI', 'PNM', 'NKE', 'META', 'AJRD', 'MKSI',
#        'MCFT', 'HHC'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('BVH', 3), ('BURL', 3), ('ZTO', 3), ('META', 3), ('GDS', 2), ('BIDU', 2), ('WB', 2), ('MTH', 2), ('ANF', 2), ('W', 2), ('ENV', 2), ('PHM', 2), ('ALGN', 2), ('PUK', 2), ('TOL', 2), ('PEN', 2), ('ACLS', 2), ('NSTG', 2), ('LVS', 1), ('PAR', 1), ('AMBA', 1), ('CTRN', 1), ('HSBC', 1), ('WYNN', 1), ('HZNP', 1), ('TMHC', 1), ('COLL', 1), ('MMS', 1), ('DHI', 1), ('PNM', 1), ('NKE', 1), ('AJRD', 1), ('MKSI', 1), ('MCFT', 1), ('HHC', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)]
# lb_slice:            (5, 125, 131)
# days eval:           6
# iloc_start_train:    5
# iloc_end_train:      125
# date_start_df_train: 2022-08-16
# date_end_df_train:   2023-02-06
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['FTSM', 'ELF', 'HZNP', 'COLL', 'RNR', 'AGYS', 'FTI', 'OI', 'SLB',
#        'PERI', 'ACGL', 'LOCO', 'XPRO', 'BKE', 'RMBS', 'GILD', 'ASC',
#        'LVS', 'NFLX', 'ATKR'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'ELF', 'RMBS', 'RNR', 'HZNP', 'XPRO', 'PERI', 'FTI',
#        'COLL', 'ASC', 'OI', 'AGYS', 'BMA', 'ATKR', 'PEN', 'ACLS', 'AXON',
#        'BKE', 'SLB', 'LOCO'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'ELF', 'DCP', 'BIIB', 'IRDM', 'ACGL', 'COLL',
#        'ISEE', 'AGYS', 'MGI', 'PCG', 'TS', 'NFLX', 'FTI', 'REGN', 'OI',
#        'LW', 'VALE', 'SLB'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('COLL', 3), ('AGYS', 3), ('FTI', 3), ('OI', 3), ('SLB', 3), ('RNR', 2), ('PERI', 2), ('ACGL', 2), ('LOCO', 2), ('XPRO', 2), ('BKE', 2), ('RMBS', 2), ('ASC', 2), ('NFLX', 2), ('ATKR', 2), ('GILD', 1), ('LVS', 1), ('BMA', 1), ('PEN', 1), ('ACLS', 1), ('AXON', 1), ('DCP', 1), ('BIIB', 1), ('IRDM', 1), ('ISEE', 1), ('MGI', 1), ('PCG', 1), ('TS', 1), ('REGN', 1), ('LW', 1), ('VALE', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('META', 3), ('CTLT', 3), ('ALGN', 3), ('JWN', 3), ('LRN', 3), ('ELF', 3), ('ICPT', 3), ('AN', 3), ('CRUS', 3), ('PAG', 3), ('TSLA', 2), ('W', 2), ('SMG', 2), ('SHOP', 2), ('CACC', 2), ('SAIA', 2), ('DBRG', 2), ('ALLY', 2), ('PACW', 2), ('AX', 2), ('RVNC', 1), ('PRG', 1), ('SUN', 1), ('OI', 1), ('CUBE', 1), ('ST', 1), ('OEC', 1), ('JOE', 1), ('BYD', 1), ('MRCY', 1)], [('ALGN', 3), ('META', 3), ('SMG', 3), ('CTLT', 3), ('EXPE', 3), ('W', 2), ('WBD', 2), ('MARA', 2), ('PAR', 2), ('NATI', 2), ('RVNC', 2), ('SBH', 2), ('NSTG', 2), ('MEOH', 2), ('ALLY', 2), ('KSS', 2), ('STX', 2), ('ACLS', 2), ('SHOP', 2), ('PERI', 1), ('ICPT', 1), ('TSLA', 1), ('ANF', 1), ('TRIP', 1), ('DENN', 1), ('PARA', 1), ('DCP', 1), ('LRN', 1), ('SJR', 1), ('ST', 1), ('OEC', 1), ('SUN', 1), ('ALV', 1), ('IGT', 1), ('RACE', 1), ('AX', 1)], [('FTSM', 3), ('BVH', 3), ('BURL', 3), ('ZTO', 3), ('META', 3), ('GDS', 2), ('BIDU', 2), ('WB', 2), ('MTH', 2), ('ANF', 2), ('W', 2), ('ENV', 2), ('PHM', 2), ('ALGN', 2), ('PUK', 2), ('TOL', 2), ('PEN', 2), ('ACLS', 2), ('NSTG', 2), ('LVS', 1), ('PAR', 1), ('AMBA', 1), ('CTRN', 1), ('HSBC', 1), ('WYNN', 1), ('HZNP', 1), ('TMHC', 1), ('COLL', 1), ('MMS', 1), ('DHI', 1), ('PNM', 1), ('NKE', 1), ('AJRD', 1), ('MKSI', 1), ('MCFT', 1), ('HHC', 1)], [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('COLL', 3), ('AGYS', 3), ('FTI', 3), ('OI', 3), ('SLB', 3), ('RNR', 2), ('PERI', 2), ('ACGL', 2), ('LOCO', 2), ('XPRO', 2), ('BKE', 2), ('RMBS', 2), ('ASC', 2), ('NFLX', 2), ('ATKR', 2), ('GILD', 1), ('LVS', 1), ('BMA', 1), ('PEN', 1), ('ACLS', 1), ('AXON', 1), ('DCP', 1), ('BIIB', 1), ('IRDM', 1), ('ISEE', 1), ('MGI', 1), ('PCG', 1), ('TS', 1), ('REGN', 1), ('LW', 1), ('VALE', 1)]]
# **** finish lookback slices [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)] ****
#
# top 20 ranked symbols and frequency from set [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)]:
# [('META', 9), ('ALGN', 8), ('CTLT', 6), ('ELF', 6), ('FTSM', 6), ('W', 6), ('ACLS', 5), ('SMG', 5), ('ALLY', 4), ('COLL', 4), ('HZNP', 4), ('ICPT', 4), ('LRN', 4), ('NSTG', 4), ('OI', 4), ('SHOP', 4), ('AGYS', 3), ('AN', 3), ('ANF', 3), ('AX', 3)]
# top 20 ranked symbols from set [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)]:
# ['META', 'ALGN', 'CTLT', 'ELF', 'FTSM', 'W', 'ACLS', 'SMG', 'ALLY', 'COLL']
# ===== finish top 20 ranked symbols from days_lookback set [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)] =====
#
#
#
# ########## 57 of 57 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]
# lb_slice:            (118, 133, 139)
# days eval:           6
# iloc_start_train:    118
# iloc_end_train:      133
# date_start_df_train: 2023-01-27
# date_end_df_train:   2023-02-16
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TA', 'STNG', 'ELF', 'CTLT', 'TNK', 'ASC', 'TNP', 'MMS', 'WIRE',
#        'THR', 'SMG', 'CINF', 'FCF', 'PAG', 'CAR', 'MCFT', 'CLMT', 'XPRO',
#        'CRUS', 'SFBS'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'STNG', 'ASC', 'TNK', 'CTLT', 'SMG', 'ELF', 'TNP', 'CAR',
#        'WIRE', 'MCFT', 'THR', 'PAG', 'TWLO', 'CLMT', 'XPRO', 'MMS',
#        'CINF', 'FCF', 'IPGP'], dtype=object), 'r_retnStd/UI': array(['TA', 'ELF', 'ATCO', 'MMS', 'CINF', 'SFBS', 'CTLT', 'FCF', 'ALSN',
#        'KBR', 'FISV', 'ENS', 'THR', 'DXCM', 'DCP', 'PH', 'STNG', 'TNK',
#        'ADI', 'STBA'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('STNG', 3), ('ELF', 3), ('CTLT', 3), ('TNK', 3), ('MMS', 3), ('THR', 3), ('CINF', 3), ('FCF', 3), ('ASC', 2), ('TNP', 2), ('WIRE', 2), ('SMG', 2), ('PAG', 2), ('CAR', 2), ('MCFT', 2), ('CLMT', 2), ('XPRO', 2), ('SFBS', 2), ('CRUS', 1), ('TWLO', 1), ('IPGP', 1), ('ATCO', 1), ('ALSN', 1), ('KBR', 1), ('FISV', 1), ('ENS', 1), ('DXCM', 1), ('DCP', 1), ('PH', 1), ('ADI', 1), ('STBA', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]
# lb_slice:            (103, 133, 139)
# days eval:           6
# iloc_start_train:    103
# iloc_end_train:      133
# date_start_df_train: 2023-01-05
# date_end_df_train:   2023-02-16
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TSLA', 'TA', 'ACLS', 'CTLT', 'RVNC', 'CRUS', 'NVDA', 'WIRE',
#        'SMG', 'NATI', 'MPWR', 'ON', 'MARA', 'CAR', 'EVRI', 'DCP', 'THR',
#        'RCL', 'TWLO', 'FORM'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'TA', 'MARA', 'ACLS', 'SMG', 'RVNC', 'NVDA', 'CTLT',
#        'TWLO', 'WIRE', 'CRUS', 'MPWR', 'CAR', 'TEAM', 'TNK', 'RCL', 'THR',
#        'ON', 'NATI', 'DBRG'], dtype=object), 'r_retnStd/UI': array(['DCP', 'TA', 'CRUS', 'FTSM', 'FISV', 'NATI', 'CTLT', 'LRN', 'EVRI',
#        'NVGS', 'CIGI', 'ON', 'WIRE', 'URI', 'BYD', 'SWKS', 'STX', 'TSLA',
#        'OEC', 'RVNC'], dtype=object)}}
# most_freq_syms: [('TSLA', 3), ('TA', 3), ('CTLT', 3), ('RVNC', 3), ('CRUS', 3), ('WIRE', 3), ('NATI', 3), ('ON', 3), ('ACLS', 2), ('NVDA', 2), ('SMG', 2), ('MPWR', 2), ('MARA', 2), ('CAR', 2), ('EVRI', 2), ('DCP', 2), ('THR', 2), ('RCL', 2), ('TWLO', 2), ('FORM', 1), ('TEAM', 1), ('TNK', 1), ('DBRG', 1), ('FTSM', 1), ('FISV', 1), ('LRN', 1), ('NVGS', 1), ('CIGI', 1), ('URI', 1), ('BYD', 1), ('SWKS', 1), ('STX', 1), ('OEC', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]
# lb_slice:            (73, 133, 139)
# days eval:           6
# iloc_start_train:    73
# iloc_end_train:      133
# date_start_df_train: 2022-11-21
# date_end_df_train:   2023-02-16
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['FTSM', 'BVH', 'ALGN', 'ACLS', 'WYNN', 'BMA', 'IPGP', 'MMS',
#        'MCFT', 'BURL', 'WB', 'PEN', 'META', 'CCU', 'ANF', 'TWLO', 'HSBC',
#        'BIDU', 'MTH', 'HZNP'], dtype=object), 'r_CAGR/retnStd': array(['ACLS', 'BMA', 'BVH', 'CTLT', 'FTSM', 'TWLO', 'ALGN', 'IPGP',
#        'CCU', 'WYNN', 'ANF', 'BLDR', 'HSBC', 'CRUS', 'PEN', 'IBP', 'WB',
#        'FIVN', 'META', 'BIDU'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'MMS', 'BURL', 'AJRD', 'MCFT', 'ALGN', 'LW', 'BVH',
#        'EXAS', 'WB', 'TMHC', 'VRNS', 'URI', 'META', 'TA', 'PEN', 'SPR',
#        'MTH', 'LVS'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('BVH', 3), ('ALGN', 3), ('WB', 3), ('PEN', 3), ('META', 3), ('ACLS', 2), ('WYNN', 2), ('BMA', 2), ('IPGP', 2), ('MMS', 2), ('MCFT', 2), ('BURL', 2), ('CCU', 2), ('ANF', 2), ('TWLO', 2), ('HSBC', 2), ('BIDU', 2), ('MTH', 2), ('HZNP', 2), ('CTLT', 1), ('BLDR', 1), ('CRUS', 1), ('IBP', 1), ('FIVN', 1), ('AJRD', 1), ('LW', 1), ('EXAS', 1), ('TMHC', 1), ('VRNS', 1), ('URI', 1), ('TA', 1), ('SPR', 1), ('LVS', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]
# lb_slice:            (13, 133, 139)
# days eval:           6
# iloc_start_train:    13
# iloc_end_train:      133
# date_start_df_train: 2022-08-26
# date_end_df_train:   2023-02-16
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['FTSM', 'ELF', 'HZNP', 'ANF', 'RMBS', 'FIVE', 'AGYS', 'ACGL', 'OI',
#        'TPX', 'ASC', 'FTI', 'TTC', 'RNR', 'FMX', 'LOCO', 'ISEE', 'ATKR',
#        'PERI', 'NFLX'], dtype=object), 'r_CAGR/retnStd': array(['FTSM', 'ELF', 'RMBS', 'ASC', 'ANF', 'ACLS', 'FMX', 'HZNP', 'AXON',
#        'RNR', 'TEX', 'WYNN', 'TPX', 'PERI', 'THR', 'AGYS', 'FTI', 'OI',
#        'TTC', 'FIVE'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'HZNP', 'ELF', 'ANF', 'BIIB', 'FIVE', 'ACGL', 'DHI', 'LW',
#        'AGYS', 'ISEE', 'REGN', 'OI', 'LOCO', 'NFLX', 'CNO', 'IRDM', 'MMS',
#        'TMHC', 'LEN'], dtype=object)}}
# most_freq_syms: [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('ANF', 3), ('FIVE', 3), ('AGYS', 3), ('OI', 3), ('RMBS', 2), ('ACGL', 2), ('TPX', 2), ('ASC', 2), ('FTI', 2), ('TTC', 2), ('RNR', 2), ('FMX', 2), ('LOCO', 2), ('ISEE', 2), ('PERI', 2), ('NFLX', 2), ('ATKR', 1), ('ACLS', 1), ('AXON', 1), ('TEX', 1), ('WYNN', 1), ('THR', 1), ('BIIB', 1), ('DHI', 1), ('LW', 1), ('REGN', 1), ('CNO', 1), ('IRDM', 1), ('MMS', 1), ('TMHC', 1), ('LEN', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('TA', 3), ('STNG', 3), ('ELF', 3), ('CTLT', 3), ('TNK', 3), ('MMS', 3), ('THR', 3), ('CINF', 3), ('FCF', 3), ('ASC', 2), ('TNP', 2), ('WIRE', 2), ('SMG', 2), ('PAG', 2), ('CAR', 2), ('MCFT', 2), ('CLMT', 2), ('XPRO', 2), ('SFBS', 2), ('CRUS', 1), ('TWLO', 1), ('IPGP', 1), ('ATCO', 1), ('ALSN', 1), ('KBR', 1), ('FISV', 1), ('ENS', 1), ('DXCM', 1), ('DCP', 1), ('PH', 1), ('ADI', 1), ('STBA', 1)], [('TSLA', 3), ('TA', 3), ('CTLT', 3), ('RVNC', 3), ('CRUS', 3), ('WIRE', 3), ('NATI', 3), ('ON', 3), ('ACLS', 2), ('NVDA', 2), ('SMG', 2), ('MPWR', 2), ('MARA', 2), ('CAR', 2), ('EVRI', 2), ('DCP', 2), ('THR', 2), ('RCL', 2), ('TWLO', 2), ('FORM', 1), ('TEAM', 1), ('TNK', 1), ('DBRG', 1), ('FTSM', 1), ('FISV', 1), ('LRN', 1), ('NVGS', 1), ('CIGI', 1), ('URI', 1), ('BYD', 1), ('SWKS', 1), ('STX', 1), ('OEC', 1)], [('FTSM', 3), ('BVH', 3), ('ALGN', 3), ('WB', 3), ('PEN', 3), ('META', 3), ('ACLS', 2), ('WYNN', 2), ('BMA', 2), ('IPGP', 2), ('MMS', 2), ('MCFT', 2), ('BURL', 2), ('CCU', 2), ('ANF', 2), ('TWLO', 2), ('HSBC', 2), ('BIDU', 2), ('MTH', 2), ('HZNP', 2), ('CTLT', 1), ('BLDR', 1), ('CRUS', 1), ('IBP', 1), ('FIVN', 1), ('AJRD', 1), ('LW', 1), ('EXAS', 1), ('TMHC', 1), ('VRNS', 1), ('URI', 1), ('TA', 1), ('SPR', 1), ('LVS', 1)], [('FTSM', 3), ('ELF', 3), ('HZNP', 3), ('ANF', 3), ('FIVE', 3), ('AGYS', 3), ('OI', 3), ('RMBS', 2), ('ACGL', 2), ('TPX', 2), ('ASC', 2), ('FTI', 2), ('TTC', 2), ('RNR', 2), ('FMX', 2), ('LOCO', 2), ('ISEE', 2), ('PERI', 2), ('NFLX', 2), ('ATKR', 1), ('ACLS', 1), ('AXON', 1), ('TEX', 1), ('WYNN', 1), ('THR', 1), ('BIIB', 1), ('DHI', 1), ('LW', 1), ('REGN', 1), ('CNO', 1), ('IRDM', 1), ('MMS', 1), ('TMHC', 1), ('LEN', 1)]]
# **** finish lookback slices [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)] ****
#
# top 20 ranked symbols and frequency from set [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]:
# [('CTLT', 7), ('FTSM', 7), ('TA', 7), ('ELF', 6), ('MMS', 6), ('THR', 6), ('ACLS', 5), ('ANF', 5), ('CRUS', 5), ('HZNP', 5), ('TWLO', 5), ('WIRE', 5), ('ASC', 4), ('CAR', 4), ('MCFT', 4), ('SMG', 4), ('TNK', 4), ('AGYS', 3), ('ALGN', 3), ('BVH', 3)]
# top 20 ranked symbols from set [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]:
# ['CTLT', 'FTSM', 'TA', 'ELF', 'MMS', 'THR', 'ACLS', 'ANF', 'CRUS', 'HZNP']
# ===== finish top 20 ranked symbols from days_lookback set [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)] =====

# %% [markdown]
# #### Output the best performing symbols for each set in sets_lookback_slices

# %%
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
  l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
  if verbose:
    print(f'set_lookback_slices: {sets_lookback_slices[i]}')
    print(f'days_lookbacks:      {days_lookbacks}')
    print(f'sym_freq_15:         {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14:         {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13:         {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12:         {l_sym_freq_cnt[3]}')
    print(f'sym_freq_11:         {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10:         {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9:          {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8:          {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7:          {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6:          {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5:          {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4:          {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3:          {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2:          {l_sym_freq_cnt[13]}\n')
# Out:
# set_lookback_slices: [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          ['SGEN']
# sym_freq_8:          ['TA']
# sym_freq_7:          ['ACGL', 'OEC']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'LNTH', 'TNK']
# sym_freq_5:          ['THR', 'TNP']
# sym_freq_4:          ['FTI', 'HEES', 'MMS', 'NVGS', 'PDFS', 'TPX', 'URI']
# sym_freq_3:          ['ANF']
# sym_freq_2:          []
#
# set_lookback_slices: [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          []
# sym_freq_8:          ['CTLT']
# sym_freq_7:          ['TA']
# sym_freq_6:          ['ASC', 'ELF', 'OEC', 'PDFS', 'WIRE']
# sym_freq_5:          ['ACLS', 'ATI', 'HZNP', 'TNK', 'WYNN']
# sym_freq_4:          ['MCFT', 'MMS', 'PEN', 'THR']
# sym_freq_3:          ['ACGL', 'ALGN', 'ANF']
# sym_freq_2:          []
#
# set_lookback_slices: [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['META']
# sym_freq_7:          ['CRUS', 'ELF', 'FTSM']
# sym_freq_6:          ['ACLS', 'CTLT']
# sym_freq_5:          ['FORM', 'HZNP', 'RCL', 'THR']
# sym_freq_4:          ['ALGN', 'ICPT', 'LRN', 'NVDA', 'TSLA', 'WYNN']
# sym_freq_3:          ['AGYS', 'BIDU', 'BVH', 'CCU']
# sym_freq_2:          []
#
# set_lookback_slices: [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM']
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'OEC', 'SGEN', 'TA']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'TNK']
# sym_freq_5:          ['CTLT', 'EURN', 'HEES', 'HZNP', 'LNTH', 'MMS', 'PDFS']
# sym_freq_4:          ['FTI', 'TEX', 'THR', 'TPX']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          ['ALGN', 'BVH']
# sym_freq_7:          []
# sym_freq_6:          ['ELF', 'FTSM']
# sym_freq_5:          ['ALLY', 'JWN', 'RAMP', 'W']
# sym_freq_4:          ['HZNP', 'LRN', 'PHM', 'RVNC', 'SBH', 'SMG']
# sym_freq_3:          ['ACLS', 'AGYS', 'AN', 'BURL', 'COLL']
# sym_freq_2:          []
#
# set_lookback_slices: [(117, 132, 138), (102, 132, 138), (72, 132, 138), (12, 132, 138)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['FTSM']
# sym_freq_7:          ['CTLT']
# sym_freq_6:          ['ELF']
# sym_freq_5:          ['ANF', 'HZNP', 'THR', 'TNK', 'TSLA', 'WIRE']
# sym_freq_4:          ['ACLS', 'ALGN', 'ASC', 'CAR', 'CRUS', 'DCP', 'MCFT', 'MMS', 'PEN', 'TPX']
# sym_freq_3:          ['ACGL']
# sym_freq_2:          []
#
# set_lookback_slices: [(111, 126, 132), (96, 126, 132), (66, 126, 132), (6, 126, 132)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          []
# sym_freq_7:          ['CRUS', 'FTSM']
# sym_freq_6:          ['ALGN', 'ELF']
# sym_freq_5:          ['ACLS', 'COLL', 'CTLT', 'HZNP', 'ICPT']
# sym_freq_4:          ['LOCO', 'LRN', 'LVS', 'RCL', 'SHOP', 'SMG', 'THR', 'W']
# sym_freq_3:          ['AGYS', 'ALLY']
# sym_freq_2:          []
#
# set_lookback_slices: [(121, 136, 142), (106, 136, 142), (76, 136, 142), (16, 136, 142)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          ['ELF']
# sym_freq_8:          []
# sym_freq_7:          ['CTLT', 'TA']
# sym_freq_6:          ['ACLS', 'OEC']
# sym_freq_5:          ['HZNP', 'PDFS', 'SGEN', 'THR', 'WYNN']
# sym_freq_4:          ['ACGL', 'ASC', 'CRUS', 'MCFT', 'MMS', 'TNK']
# sym_freq_3:          ['ANF', 'ATI', 'EVRI']
# sym_freq_2:          []
#
# set_lookback_slices: [(107, 122, 128), (92, 122, 128), (62, 122, 128), (2, 122, 128)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH']
# sym_freq_6:          []
# sym_freq_5:          ['FTSM', 'NATI', 'PHM', 'SBGI', 'W']
# sym_freq_4:          ['CLF', 'HZNP', 'LRN', 'MARA', 'NEOG', 'RVNC', 'SMG']
# sym_freq_3:          ['ACGL', 'ACLS', 'AGYS', 'ALLY', 'BMA', 'BURL', 'ELF']
# sym_freq_2:          []
#
# set_lookback_slices: [(106, 121, 127), (91, 121, 127), (61, 121, 127), (1, 121, 127)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH', 'NEOG']
# sym_freq_6:          ['FTSM', 'HSBC']
# sym_freq_5:          ['NATI']
# sym_freq_4:          ['CCU', 'LRN', 'LVS', 'TX', 'W']
# sym_freq_3:          ['ACGL', 'AGYS', 'ALGN', 'AX', 'BKE', 'BMA', 'BURL', 'CLF', 'DCP', 'ELF']
# sym_freq_2:          []
#
# set_lookback_slices: [(106, 121, 127), (91, 121, 127), (61, 121, 127), (1, 121, 127)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH', 'NEOG']
# sym_freq_6:          ['FTSM', 'HSBC']
# sym_freq_5:          ['NATI']
# sym_freq_4:          ['CCU', 'LRN', 'LVS', 'TX', 'W']
# sym_freq_3:          ['ACGL', 'AGYS', 'ALGN', 'AX', 'BKE', 'BMA', 'BURL', 'CLF', 'DCP', 'ELF']
# sym_freq_2:          []
#
# set_lookback_slices: [(105, 120, 126), (90, 120, 126), (60, 120, 126), (0, 120, 126)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH', 'FTSM']
# sym_freq_6:          ['HSBC']
# sym_freq_5:          ['PUK', 'TX']
# sym_freq_4:          ['CLF', 'HZNP', 'NATI', 'NEOG']
# sym_freq_3:          ['ACGL', 'AGYS', 'ALGN', 'BKE', 'BMA', 'BOOT', 'BURL', 'CCU', 'COLL', 'CROX', 'DCP']
# sym_freq_2:          []
#
# set_lookback_slices: [(122, 137, 143), (107, 137, 143), (77, 137, 143), (17, 137, 143)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'TA', 'TNK']
# sym_freq_6:          ['ACLS', 'ASC', 'CTLT', 'ELF', 'OEC']
# sym_freq_5:          ['HZNP', 'PDFS', 'SGEN', 'THR']
# sym_freq_4:          ['LNTH', 'MMS', 'TPX', 'WYNN']
# sym_freq_3:          ['AMCX', 'ANF', 'ATI']
# sym_freq_2:          []
#
# set_lookback_slices: [(107, 122, 128), (92, 122, 128), (62, 122, 128), (2, 122, 128)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH']
# sym_freq_6:          []
# sym_freq_5:          ['FTSM', 'NATI', 'PHM', 'SBGI', 'W']
# sym_freq_4:          ['CLF', 'HZNP', 'LRN', 'MARA', 'NEOG', 'RVNC', 'SMG']
# sym_freq_3:          ['ACGL', 'ACLS', 'AGYS', 'ALLY', 'BMA', 'BURL', 'ELF']
# sym_freq_2:          []
#
# set_lookback_slices: [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          ['SGEN']
# sym_freq_8:          ['TA']
# sym_freq_7:          ['ACGL', 'OEC']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'LNTH', 'TNK']
# sym_freq_5:          ['THR', 'TNP']
# sym_freq_4:          ['FTI', 'HEES', 'MMS', 'NVGS', 'PDFS', 'TPX', 'URI']
# sym_freq_3:          ['ANF']
# sym_freq_2:          []
#
# set_lookback_slices: [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM']
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'OEC', 'SGEN', 'TA']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'TNK']
# sym_freq_5:          ['CTLT', 'EURN', 'HEES', 'HZNP', 'LNTH', 'MMS', 'PDFS']
# sym_freq_4:          ['FTI', 'TEX', 'THR', 'TPX']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(117, 132, 138), (102, 132, 138), (72, 132, 138), (12, 132, 138)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['FTSM']
# sym_freq_7:          ['CTLT']
# sym_freq_6:          ['ELF']
# sym_freq_5:          ['ANF', 'HZNP', 'THR', 'TNK', 'TSLA', 'WIRE']
# sym_freq_4:          ['ACLS', 'ALGN', 'ASC', 'CAR', 'CRUS', 'DCP', 'MCFT', 'MMS', 'PEN', 'TPX']
# sym_freq_3:          ['ACGL']
# sym_freq_2:          []
#
# set_lookback_slices: [(129, 144, 150), (114, 144, 150), (84, 144, 150), (24, 144, 150)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM', 'SGEN']
# sym_freq_8:          ['OEC', 'TA']
# sym_freq_7:          ['TNK']
# sym_freq_6:          ['ACGL', 'ELF', 'HY', 'LNTH', 'PDFS']
# sym_freq_5:          ['CCU', 'THR']
# sym_freq_4:          ['ACLS', 'ATKR', 'AXON', 'HEES', 'PRG', 'STRL', 'TEX', 'TX']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(126, 141, 147), (111, 141, 147), (81, 141, 147), (21, 141, 147)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM', 'SGEN']
# sym_freq_8:          ['OEC', 'TA']
# sym_freq_7:          ['ACGL']
# sym_freq_6:          ['ACLS', 'AMPH', 'ASC', 'ELF', 'LNTH', 'TEX', 'TNK']
# sym_freq_5:          ['THR']
# sym_freq_4:          ['AXON', 'HEES', 'HY', 'MCFT', 'PKE', 'STRL', 'WYNN']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM']
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'OEC', 'SGEN', 'TA']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'TNK']
# sym_freq_5:          ['CTLT', 'EURN', 'HEES', 'HZNP', 'LNTH', 'MMS', 'PDFS']
# sym_freq_4:          ['FTI', 'TEX', 'THR', 'TPX']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(119, 134, 140), (104, 134, 140), (74, 134, 140), (14, 134, 140)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['CTLT']
# sym_freq_7:          ['FTSM', 'TA']
# sym_freq_6:          ['ELF', 'THR']
# sym_freq_5:          ['ACLS', 'HZNP', 'OEC', 'SMG', 'TSLA', 'WIRE']
# sym_freq_4:          ['AMCX', 'AN', 'ASC', 'CAR', 'MCFT', 'MMS', 'PEN', 'TNK', 'WYNN']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(122, 137, 143), (107, 137, 143), (77, 137, 143), (17, 137, 143)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'TA', 'TNK']
# sym_freq_6:          ['ACLS', 'ASC', 'CTLT', 'ELF', 'OEC']
# sym_freq_5:          ['HZNP', 'PDFS', 'SGEN', 'THR']
# sym_freq_4:          ['LNTH', 'MMS', 'TPX', 'WYNN']
# sym_freq_3:          ['AMCX', 'ANF', 'ATI']
# sym_freq_2:          []
#
# set_lookback_slices: [(122, 137, 143), (107, 137, 143), (77, 137, 143), (17, 137, 143)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'TA', 'TNK']
# sym_freq_6:          ['ACLS', 'ASC', 'CTLT', 'ELF', 'OEC']
# sym_freq_5:          ['HZNP', 'PDFS', 'SGEN', 'THR']
# sym_freq_4:          ['LNTH', 'MMS', 'TPX', 'WYNN']
# sym_freq_3:          ['AMCX', 'ANF', 'ATI']
# sym_freq_2:          []
#
# set_lookback_slices: [(107, 122, 128), (92, 122, 128), (62, 122, 128), (2, 122, 128)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH']
# sym_freq_6:          []
# sym_freq_5:          ['FTSM', 'NATI', 'PHM', 'SBGI', 'W']
# sym_freq_4:          ['CLF', 'HZNP', 'LRN', 'MARA', 'NEOG', 'RVNC', 'SMG']
# sym_freq_3:          ['ACGL', 'ACLS', 'AGYS', 'ALLY', 'BMA', 'BURL', 'ELF']
# sym_freq_2:          []
#
# set_lookback_slices: [(105, 120, 126), (90, 120, 126), (60, 120, 126), (0, 120, 126)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH', 'FTSM']
# sym_freq_6:          ['HSBC']
# sym_freq_5:          ['PUK', 'TX']
# sym_freq_4:          ['CLF', 'HZNP', 'NATI', 'NEOG']
# sym_freq_3:          ['ACGL', 'AGYS', 'ALGN', 'BKE', 'BMA', 'BOOT', 'BURL', 'CCU', 'COLL', 'CROX', 'DCP']
# sym_freq_2:          []
#
# set_lookback_slices: [(126, 141, 147), (111, 141, 147), (81, 141, 147), (21, 141, 147)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM', 'SGEN']
# sym_freq_8:          ['OEC', 'TA']
# sym_freq_7:          ['ACGL']
# sym_freq_6:          ['ACLS', 'AMPH', 'ASC', 'ELF', 'LNTH', 'TEX', 'TNK']
# sym_freq_5:          ['THR']
# sym_freq_4:          ['AXON', 'HEES', 'HY', 'MCFT', 'PKE', 'STRL', 'WYNN']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          ['SGEN']
# sym_freq_8:          ['TA']
# sym_freq_7:          ['ACGL', 'OEC']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'LNTH', 'TNK']
# sym_freq_5:          ['THR', 'TNP']
# sym_freq_4:          ['FTI', 'HEES', 'MMS', 'NVGS', 'PDFS', 'TPX', 'URI']
# sym_freq_3:          ['ANF']
# sym_freq_2:          []
#
# set_lookback_slices: [(111, 126, 132), (96, 126, 132), (66, 126, 132), (6, 126, 132)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          []
# sym_freq_7:          ['CRUS', 'FTSM']
# sym_freq_6:          ['ALGN', 'ELF']
# sym_freq_5:          ['ACLS', 'COLL', 'CTLT', 'HZNP', 'ICPT']
# sym_freq_4:          ['LOCO', 'LRN', 'LVS', 'RCL', 'SHOP', 'SMG', 'THR', 'W']
# sym_freq_3:          ['AGYS', 'ALLY']
# sym_freq_2:          []
#
# set_lookback_slices: [(111, 126, 132), (96, 126, 132), (66, 126, 132), (6, 126, 132)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          []
# sym_freq_7:          ['CRUS', 'FTSM']
# sym_freq_6:          ['ALGN', 'ELF']
# sym_freq_5:          ['ACLS', 'COLL', 'CTLT', 'HZNP', 'ICPT']
# sym_freq_4:          ['LOCO', 'LRN', 'LVS', 'RCL', 'SHOP', 'SMG', 'THR', 'W']
# sym_freq_3:          ['AGYS', 'ALLY']
# sym_freq_2:          []
#
# set_lookback_slices: [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          ['ALGN']
# sym_freq_7:          []
# sym_freq_6:          ['CTLT', 'ELF', 'FTSM', 'W']
# sym_freq_5:          ['ACLS', 'SMG']
# sym_freq_4:          ['ALLY', 'COLL', 'HZNP', 'ICPT', 'LRN', 'NSTG', 'OI', 'SHOP']
# sym_freq_3:          ['AGYS', 'AN', 'ANF', 'AX']
# sym_freq_2:          []
#
# set_lookback_slices: [(116, 131, 137), (101, 131, 137), (71, 131, 137), (11, 131, 137)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['FTSM']
# sym_freq_7:          ['CRUS', 'CTLT']
# sym_freq_6:          ['ALGN', 'ELF']
# sym_freq_5:          ['ACLS', 'HZNP', 'TSLA']
# sym_freq_4:          ['ASC', 'CAR', 'META', 'MMS', 'ON', 'PEN', 'RCL', 'THR', 'URI', 'WYNN']
# sym_freq_3:          ['ACGL', 'AGYS']
# sym_freq_2:          []
#
# set_lookback_slices: [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          ['ALGN', 'BVH']
# sym_freq_7:          []
# sym_freq_6:          ['ELF', 'FTSM']
# sym_freq_5:          ['ALLY', 'JWN', 'RAMP', 'W']
# sym_freq_4:          ['HZNP', 'LRN', 'PHM', 'RVNC', 'SBH', 'SMG']
# sym_freq_3:          ['ACLS', 'AGYS', 'AN', 'BURL', 'COLL']
# sym_freq_2:          []
#
# set_lookback_slices: [(108, 123, 129), (93, 123, 129), (63, 123, 129), (3, 123, 129)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          ['ALGN']
# sym_freq_7:          ['BVH']
# sym_freq_6:          ['ELF', 'PHM', 'W']
# sym_freq_5:          ['ALLY', 'FTSM']
# sym_freq_4:          ['HZNP', 'NATI', 'RVNC', 'SBGI', 'SBH', 'SMG']
# sym_freq_3:          ['ACLS', 'AGYS', 'BURL', 'COLL', 'DCP', 'MTH']
# sym_freq_2:          []
#
# set_lookback_slices: [(129, 144, 150), (114, 144, 150), (84, 144, 150), (24, 144, 150)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM', 'SGEN']
# sym_freq_8:          ['OEC', 'TA']
# sym_freq_7:          ['TNK']
# sym_freq_6:          ['ACGL', 'ELF', 'HY', 'LNTH', 'PDFS']
# sym_freq_5:          ['CCU', 'THR']
# sym_freq_4:          ['ACLS', 'ATKR', 'AXON', 'HEES', 'PRG', 'STRL', 'TEX', 'TX']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(107, 122, 128), (92, 122, 128), (62, 122, 128), (2, 122, 128)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH']
# sym_freq_6:          []
# sym_freq_5:          ['FTSM', 'NATI', 'PHM', 'SBGI', 'W']
# sym_freq_4:          ['CLF', 'HZNP', 'LRN', 'MARA', 'NEOG', 'RVNC', 'SMG']
# sym_freq_3:          ['ACGL', 'ACLS', 'AGYS', 'ALLY', 'BMA', 'BURL', 'ELF']
# sym_freq_2:          []
#
# set_lookback_slices: [(119, 134, 140), (104, 134, 140), (74, 134, 140), (14, 134, 140)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['CTLT']
# sym_freq_7:          ['FTSM', 'TA']
# sym_freq_6:          ['ELF', 'THR']
# sym_freq_5:          ['ACLS', 'HZNP', 'OEC', 'SMG', 'TSLA', 'WIRE']
# sym_freq_4:          ['AMCX', 'AN', 'ASC', 'CAR', 'MCFT', 'MMS', 'PEN', 'TNK', 'WYNN']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          []
# sym_freq_8:          ['CTLT']
# sym_freq_7:          ['TA']
# sym_freq_6:          ['ASC', 'ELF', 'OEC', 'PDFS', 'WIRE']
# sym_freq_5:          ['ACLS', 'ATI', 'HZNP', 'TNK', 'WYNN']
# sym_freq_4:          ['MCFT', 'MMS', 'PEN', 'THR']
# sym_freq_3:          ['ACGL', 'ALGN', 'ANF']
# sym_freq_2:          []
#
# set_lookback_slices: [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['CTLT', 'FTSM', 'TA']
# sym_freq_6:          ['ELF', 'MMS', 'THR']
# sym_freq_5:          ['ACLS', 'ANF', 'CRUS', 'HZNP', 'TWLO', 'WIRE']
# sym_freq_4:          ['ASC', 'CAR', 'MCFT', 'SMG', 'TNK']
# sym_freq_3:          ['AGYS', 'ALGN', 'BVH']
# sym_freq_2:          []
#
# set_lookback_slices: [(114, 129, 135), (99, 129, 135), (69, 129, 135), (9, 129, 135)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['THR']
# sym_freq_7:          ['CRUS', 'FTSM']
# sym_freq_6:          ['CTLT', 'ELF', 'WYNN']
# sym_freq_5:          ['ACLS', 'HZNP', 'META']
# sym_freq_4:          ['ICPT', 'LRN', 'MMS', 'RCL', 'TSLA', 'URI']
# sym_freq_3:          ['AGYS', 'ALGN', 'BURL', 'BVH', 'CINF']
# sym_freq_2:          []
#
# set_lookback_slices: [(112, 127, 133), (97, 127, 133), (67, 127, 133), (7, 127, 133)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          []
# sym_freq_7:          ['CRUS', 'ELF', 'FTSM']
# sym_freq_6:          ['RCL', 'THR']
# sym_freq_5:          ['ALGN', 'CTLT', 'HZNP']
# sym_freq_4:          ['ACLS', 'CCU', 'ICPT', 'LVS', 'NVDA', 'OI', 'SMG', 'TSLA', 'W']
# sym_freq_3:          ['AGYS', 'BIDU']
# sym_freq_2:          []
#
# set_lookback_slices: [(127, 142, 148), (112, 142, 148), (82, 142, 148), (22, 142, 148)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['SGEN']
# sym_freq_8:          ['FTSM', 'OEC', 'TA']
# sym_freq_7:          []
# sym_freq_6:          ['ELF', 'LNTH', 'TNK']
# sym_freq_5:          ['ACGL', 'ACLS', 'AMPH', 'OI', 'THR']
# sym_freq_4:          ['ASC', 'FTI', 'HEES', 'HY', 'MCFT', 'NTRA', 'PKE', 'TEX']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(112, 127, 133), (97, 127, 133), (67, 127, 133), (7, 127, 133)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          []
# sym_freq_7:          ['CRUS', 'ELF', 'FTSM']
# sym_freq_6:          ['RCL', 'THR']
# sym_freq_5:          ['ALGN', 'CTLT', 'HZNP']
# sym_freq_4:          ['ACLS', 'CCU', 'ICPT', 'LVS', 'NVDA', 'OI', 'SMG', 'TSLA', 'W']
# sym_freq_3:          ['AGYS', 'BIDU']
# sym_freq_2:          []
#
# set_lookback_slices: [(109, 124, 130), (94, 124, 130), (64, 124, 130), (4, 124, 130)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          ['ALGN', 'BVH']
# sym_freq_7:          []
# sym_freq_6:          ['ELF', 'FTSM']
# sym_freq_5:          ['ALLY', 'JWN', 'RAMP', 'W']
# sym_freq_4:          ['HZNP', 'LRN', 'PHM', 'RVNC', 'SBH', 'SMG']
# sym_freq_3:          ['ACLS', 'AGYS', 'AN', 'BURL', 'COLL']
# sym_freq_2:          []
#
# set_lookback_slices: [(122, 137, 143), (107, 137, 143), (77, 137, 143), (17, 137, 143)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'TA', 'TNK']
# sym_freq_6:          ['ACLS', 'ASC', 'CTLT', 'ELF', 'OEC']
# sym_freq_5:          ['HZNP', 'PDFS', 'SGEN', 'THR']
# sym_freq_4:          ['LNTH', 'MMS', 'TPX', 'WYNN']
# sym_freq_3:          ['AMCX', 'ANF', 'ATI']
# sym_freq_2:          []
#
# set_lookback_slices: [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM']
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'OEC', 'SGEN', 'TA']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'TNK']
# sym_freq_5:          ['CTLT', 'EURN', 'HEES', 'HZNP', 'LNTH', 'MMS', 'PDFS']
# sym_freq_4:          ['FTI', 'TEX', 'THR', 'TPX']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['CTLT', 'FTSM', 'TA']
# sym_freq_6:          ['ELF', 'MMS', 'THR']
# sym_freq_5:          ['ACLS', 'ANF', 'CRUS', 'HZNP', 'TWLO', 'WIRE']
# sym_freq_4:          ['ASC', 'CAR', 'MCFT', 'SMG', 'TNK']
# sym_freq_3:          ['AGYS', 'ALGN', 'BVH']
# sym_freq_2:          []
#
# set_lookback_slices: [(105, 120, 126), (90, 120, 126), (60, 120, 126), (0, 120, 126)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH', 'FTSM']
# sym_freq_6:          ['HSBC']
# sym_freq_5:          ['PUK', 'TX']
# sym_freq_4:          ['CLF', 'HZNP', 'NATI', 'NEOG']
# sym_freq_3:          ['ACGL', 'AGYS', 'ALGN', 'BKE', 'BMA', 'BOOT', 'BURL', 'CCU', 'COLL', 'CROX', 'DCP']
# sym_freq_2:          []
#
# set_lookback_slices: [(112, 127, 133), (97, 127, 133), (67, 127, 133), (7, 127, 133)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          []
# sym_freq_7:          ['CRUS', 'ELF', 'FTSM']
# sym_freq_6:          ['RCL', 'THR']
# sym_freq_5:          ['ALGN', 'CTLT', 'HZNP']
# sym_freq_4:          ['ACLS', 'CCU', 'ICPT', 'LVS', 'NVDA', 'OI', 'SMG', 'TSLA', 'W']
# sym_freq_3:          ['AGYS', 'BIDU']
# sym_freq_2:          []
#
# set_lookback_slices: [(128, 143, 149), (113, 143, 149), (83, 143, 149), (23, 143, 149)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM', 'SGEN']
# sym_freq_8:          ['OEC', 'TA']
# sym_freq_7:          []
# sym_freq_6:          ['ELF', 'HY', 'LNTH', 'TNK']
# sym_freq_5:          ['ACGL', 'THR']
# sym_freq_4:          ['ACLS', 'AMPH', 'ASC', 'FTI', 'MCFT', 'NTRA', 'OI', 'PDFS', 'TEX', 'TX']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(115, 130, 136), (100, 130, 136), (70, 130, 136), (10, 130, 136)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['FTSM']
# sym_freq_7:          ['CRUS', 'CTLT', 'THR']
# sym_freq_6:          ['ALGN', 'ELF', 'META', 'WYNN']
# sym_freq_5:          ['ACLS', 'HZNP', 'URI']
# sym_freq_4:          ['BSIG', 'ICPT', 'LRN', 'MMS', 'RCL', 'SMG', 'TSLA']
# sym_freq_3:          ['AGYS', 'BURL']
# sym_freq_2:          []
#
# set_lookback_slices: [(105, 120, 126), (90, 120, 126), (60, 120, 126), (0, 120, 126)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['BVH', 'FTSM']
# sym_freq_6:          ['HSBC']
# sym_freq_5:          ['PUK', 'TX']
# sym_freq_4:          ['CLF', 'HZNP', 'NATI', 'NEOG']
# sym_freq_3:          ['ACGL', 'AGYS', 'ALGN', 'BKE', 'BMA', 'BOOT', 'BURL', 'CCU', 'COLL', 'CROX', 'DCP']
# sym_freq_2:          []
#
# set_lookback_slices: [(116, 131, 137), (101, 131, 137), (71, 131, 137), (11, 131, 137)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['FTSM']
# sym_freq_7:          ['CRUS', 'CTLT']
# sym_freq_6:          ['ALGN', 'ELF']
# sym_freq_5:          ['ACLS', 'HZNP', 'TSLA']
# sym_freq_4:          ['ASC', 'CAR', 'META', 'MMS', 'ON', 'PEN', 'RCL', 'THR', 'URI', 'WYNN']
# sym_freq_3:          ['ACGL', 'AGYS']
# sym_freq_2:          []
#
# set_lookback_slices: [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          ['ALGN']
# sym_freq_7:          []
# sym_freq_6:          ['CTLT', 'ELF', 'FTSM', 'W']
# sym_freq_5:          ['ACLS', 'SMG']
# sym_freq_4:          ['ALLY', 'COLL', 'HZNP', 'ICPT', 'LRN', 'NSTG', 'OI', 'SHOP']
# sym_freq_3:          ['AGYS', 'AN', 'ANF', 'AX']
# sym_freq_2:          []
#
# set_lookback_slices: [(126, 141, 147), (111, 141, 147), (81, 141, 147), (21, 141, 147)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM', 'SGEN']
# sym_freq_8:          ['OEC', 'TA']
# sym_freq_7:          ['ACGL']
# sym_freq_6:          ['ACLS', 'AMPH', 'ASC', 'ELF', 'LNTH', 'TEX', 'TNK']
# sym_freq_5:          ['THR']
# sym_freq_4:          ['AXON', 'HEES', 'HY', 'MCFT', 'PKE', 'STRL', 'WYNN']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(126, 141, 147), (111, 141, 147), (81, 141, 147), (21, 141, 147)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM', 'SGEN']
# sym_freq_8:          ['OEC', 'TA']
# sym_freq_7:          ['ACGL']
# sym_freq_6:          ['ACLS', 'AMPH', 'ASC', 'ELF', 'LNTH', 'TEX', 'TNK']
# sym_freq_5:          ['THR']
# sym_freq_4:          ['AXON', 'HEES', 'HY', 'MCFT', 'PKE', 'STRL', 'WYNN']
# sym_freq_3:          []
# sym_freq_2:          []
#
# set_lookback_slices: [(110, 125, 131), (95, 125, 131), (65, 125, 131), (5, 125, 131)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          ['META']
# sym_freq_8:          ['ALGN']
# sym_freq_7:          []
# sym_freq_6:          ['CTLT', 'ELF', 'FTSM', 'W']
# sym_freq_5:          ['ACLS', 'SMG']
# sym_freq_4:          ['ALLY', 'COLL', 'HZNP', 'ICPT', 'LRN', 'NSTG', 'OI', 'SHOP']
# sym_freq_3:          ['AGYS', 'AN', 'ANF', 'AX']
# sym_freq_2:          []
#
# set_lookback_slices: [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['CTLT', 'FTSM', 'TA']
# sym_freq_6:          ['ELF', 'MMS', 'THR']
# sym_freq_5:          ['ACLS', 'ANF', 'CRUS', 'HZNP', 'TWLO', 'WIRE']
# sym_freq_4:          ['ASC', 'CAR', 'MCFT', 'SMG', 'TNK']
# sym_freq_3:          ['AGYS', 'ALGN', 'BVH']
# sym_freq_2:          []

# %% [markdown]
# #### Compare performance of symbols in set_lookback_slices versus SPY

# %%
from myUtils import symb_perf_stats_vectorized_v8

print('z_grp_top_set_syms_n_freq:')
# zip max_lookback_slices with top performing symbols:freq pairs
z_grp_top_set_syms_n_freq = zip(max_lookback_slices, grp_top_set_syms_n_freq)

idx_train = pd.Index([])
idx_eval = pd.Index([])
for i, (_lookback_slice, _top_set_syms_n_freq) in enumerate(z_grp_top_set_syms_n_freq):
  iloc_start_train = _lookback_slice[0]
  iloc_end_train = _lookback_slice[1]
  iloc_start_eval = iloc_end_train
  iloc_end_eval = _lookback_slice[2]

  print(f'{i + 1 } of {n_samples} max_lookback_slice: {_lookback_slice}\n')
  # print(f'max_lookback_slice: {_lookback_slice}\n')
  # dates correspond to max_lookback_slice
  idx_train = df.index[iloc_start_train:iloc_end_train]
  date_start_df_train = idx_train[0].strftime('%Y-%m-%d')
  date_end_df_train = idx_train[-1].strftime('%Y-%m-%d')
  print(f'len(idx_train): {len(idx_train)}')
  print(f'idx_train: {idx_train}')
  print(f'df_train_dates (inclusive): {date_start_df_train} - {date_end_df_train}\n')     

  if run_type != 'current':
    idx_eval = df.index[iloc_start_eval:iloc_end_eval]
    date_start_df_eval = idx_eval[0].strftime('%Y-%m-%d')
    date_end_df_eval = idx_eval[-1].strftime('%Y-%m-%d')
    print(f'len(idx_eval): {len(idx_eval)}')
    print(f'idx_eval: {idx_eval}')
    print(f'df_eval dates (inclusive): {date_start_df_eval} - {date_end_df_eval}\n')
  else: # run_type == "current'
    print(f'run_type: {run_type}, idx_eval is empty: {idx_eval.empty}')

  print(f'top_set_syms_n_freq: {_top_set_syms_n_freq}\n')   

  l_sym_freq_cnt = top_set_sym_freq_cnt(_top_set_syms_n_freq)
  if verbose:
    print(f'max_lookback_slice:  {_lookback_slice}')
    print(f'set_lookback_slices: {sets_lookback_slices[i]}')    
    print(f'days_lookbacks:      {days_lookbacks}')
    print(f'sym_freq_15:         {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14:         {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13:         {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12:         {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10:         {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9:          {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8:          {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7:          {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6:          {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5:          {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4:          {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3:          {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2:          {l_sym_freq_cnt[13]}\n') 

  if idx_eval.empty:
    if run_type == 'current':
      msg_stop = f'\n\n**** STOPPED df_eval is empty and run_type is "{run_type}" ****'
      raise SystemExit(msg_stop)
    else:
      msg_stop = f'\n\n**** STOPPED df_eval is empty but run_type != "current", the run_type is "{run_type}" ****'
      raise SystemExit(msg_stop)    

  _sym_idx = ['SPY']
  df_SPY = df[iloc_start_eval:iloc_end_eval][_sym_idx]

  (
    _symbols,
    _period_yr,
    _retn,
    _DD,
    _UI,
    _MDD,
    _retnMean,
    _retnStd,
    _retnStd_div_UI,
    _CAGR,
    _CAGR_div_retnStd,
    _CAGR_div_UI,
    SPY_retnStd_d_UI,     
    SPY_CAGR,
    SPY_CAGR_d_retnStd,
    SPY_CAGR_d_UI,
  ) = symb_perf_stats_vectorized_v8(df_SPY)  

  print(f'\nSPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR: {SPY_retnStd_d_UI[0]:>17,.1f}, {SPY_CAGR_d_retnStd[0]:>17,.1f}, {SPY_CAGR_d_UI[0]:>17.1f}, {SPY_CAGR[0]:>17.1f}')

  # drop list with frequency count 2 or less, in l_sym_freq_cnt from zip
  zip_cnt_n_syms = zip([15,14,13,12,11,10,9,8,7,6,5,4,3], l_sym_freq_cnt[:-1])
  for item in zip_cnt_n_syms:
    sym_freq_cnt = item[0]
    syms = item[1]
    if syms:  # iterate ONLY if there are symbols in syms
      df_eval = df[iloc_start_eval:iloc_end_eval][syms]      

      if verbose:
        print(f'iloc_start_eval: {iloc_start_eval:>6},  df_eval first date: {date_start_df_eval:>10}') 
        print(f'iloc_end_eval:   {iloc_end_eval:>6},  df_eval last date:  {date_end_df_eval:>10}')        
        print(f'frequency count of symbol(s): {sym_freq_cnt}')      

        syms_n_SPY = syms + ['SPY']
        df_eval_n_SPY = df[iloc_start_eval:iloc_end_eval][syms_n_SPY]   
        print(f'\ndf_eval_n_SPY:\n{df_eval_n_SPY}\n')

      (
        _symbols,
        _period_yr,
        _retn,
        _DD,
        _UI,
        _MDD,
        _retnMean,
        _retnStd,
        _retnStd_div_UI,
        _CAGR,
        _CAGR_div_retnStd,
        _CAGR_div_UI,
        grp_retnStd_d_UI,     
        grp_CAGR,
        grp_CAGR_d_retnStd,
        grp_CAGR_d_UI,
      ) = symb_perf_stats_vectorized_v8(df_eval)  
      print(f'grp(retnStd/UI):   mean, std, mean/std: {grp_retnStd_d_UI[0]  :>17,.1f}, {grp_retnStd_d_UI[1]  :>17,.1f}, {grp_retnStd_d_UI[2]  :>17,.1f}')
      print(f'grp(CAGR/retnStd): mean, std, mean/std: {grp_CAGR_d_retnStd[0]:>17,.1f}, {grp_CAGR_d_retnStd[1]:>17,.1f}, {grp_CAGR_d_retnStd[2]:>17,.1f}')
      print(f'grp(CAGR/UI):      mean, std, mean/std: {grp_CAGR_d_UI[0]     :>17,.1f}, {grp_CAGR_d_UI[1]     :>17,.1f}, {grp_CAGR_d_UI[2]     :>17,.1f}')
      print(f'grp(CAGR):         mean, std, mean/std: {grp_CAGR[0]          :>17,.1f}, {grp_CAGR[1]          :>17,.1f}, {grp_CAGR[2]          :>17,.1f}\n')

      if store_results:  # record results to df
        row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt]
        row_add1      = [grp_CAGR[0],           grp_CAGR[1],           grp_CAGR[2]]
        row_add2      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
        row_add3      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
        row_add4      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
        row_add5      = [SPY_CAGR[0], SPY_CAGR_d_UI[0], SPY_CAGR_d_retnStd[0], SPY_retnStd_d_UI[0]]
        row_add_total = row_add0 + row_add1 + row_add2 + row_add3 + row_add4 + row_add5
        print(f'row_add_total: {row_add_total}')

        if run_type == 'train':
          df_eval_sym_freq_results_train.loc[len(df_eval_sym_freq_results_train)] = row_add_total
          print(f'appended row_add to df_eval_sym_freq_results_train:\n{row_add_total}\n')
        elif run_type == 'validate':
          df_eval_sym_freq_results_validate.loc[len(df_eval_sym_freq_results_validate)] = row_add_total       
          print(f'appended row_add to df_eval_sym_freq_results_validate:\n{row_add_total}\n')
        elif run_type == 'test':
          df_eval_sym_freq_results_test.loc[len(df_eval_sym_freq_results_test)] = row_add_total       
          print(f'appended row_add to df_eval_sym_freq_results_test:\n{row_add_total}\n')
        else:
          msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
          raise SystemExit(msg_stop )                             
  
  print('='*50, '\n')
# Out:
# z_grp_top_set_syms_n_freq:
# 1 of 57 max_lookback_slice: (19, 139, 145)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2022-09-06', '2022-09-07', '2022-09-08', '2022-09-09', '2022-09-12', '2022-09-13', '2022-09-14', '2022-09-15', '2022-09-16', '2022-09-19',
#                ...
#                '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2022-09-06 - 2023-02-27
#
# len(idx_eval): 6
# idx_eval: DatetimeIndex(['2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03', '2023-03-06', '2023-03-07'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-02-28 - 2023-03-07
#
# top_set_syms_n_freq: [('FTSM', 10), ('SGEN', 9), ('TA', 8), ('ACGL', 7), ('OEC', 7), ('ACLS', 6), ('ASC', 6), ('ELF', 6), ('LNTH', 6), ('TNK', 6), ('THR', 5), ('TNP', 5), ('FTI', 4), ('HEES', 4), ('MMS', 4), ('NVGS', 4), ('PDFS', 4), ('TPX', 4), ('URI', 4), ('ANF', 3)]
#
# max_lookback_slice:  (19, 139, 145)
# set_lookback_slices: [(124, 139, 145), (109, 139, 145), (79, 139, 145), (19, 139, 145)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          ['SGEN']
# sym_freq_8:          ['TA']
# sym_freq_7:          ['ACGL', 'OEC']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'LNTH', 'TNK']
# sym_freq_5:          ['THR', 'TNP']
# sym_freq_4:          ['FTI', 'HEES', 'MMS', 'NVGS', 'PDFS', 'TPX', 'URI']
# sym_freq_3:          ['ANF']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.6,              27.4,              45.0,               0.3
# iloc_start_eval:    139,  df_eval first date: 2023-02-28
# iloc_end_eval:      145,  df_eval last date:  2023-03-07
# frequency count of symbol(s): 10
#
# df_eval_n_SPY:
#                  FTSM         SPY
# Date
# 2023-02-28  59.450001  396.260010
# 2023-03-01  59.439999  394.739990
# 2023-03-02  59.459999  397.809998
# 2023-03-03  59.480000  404.190002
# 2023-03-06  59.480000  404.470001
# 2023-03-07  59.470001  398.269989
#
# grp(retnStd/UI):   mean, std, mean/std:               2.3,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:              74.9,               0.0,               inf
# grp(CAGR/UI):      mean, std, mean/std:             176.1,               0.0,               inf
# grp(CAGR):         mean, std, mean/std:               0.0,               0.0,               inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 10, 0.017097478001636635, 0.0, inf, 176.093803530989, 0.0, inf, 74.93735494325601, 0.0, inf, 2.3498801587583467, 0.0, inf, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 10, 0.017097478001636635, 0.0, inf, 176.093803530989, 0.0, inf, 74.93735494325601, 0.0, inf, 2.3498801587583467, 0.0, inf, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
#
# iloc_start_eval:    139,  df_eval first date: 2023-02-28
# iloc_end_eval:      145,  df_eval last date:  2023-03-07
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#                   SGEN         SPY
# Date
# 2023-02-28  179.690002  396.260010
# 2023-03-01  178.229996  394.739990
# 2023-03-02  178.669998  397.809998
# 2023-03-03  181.289993  404.190002
# 2023-03-06  177.350006  404.470001
# 2023-03-07  177.500000  398.269989
#
# grp(retnStd/UI):   mean, std, mean/std:               0.9,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -38.1,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -35.6,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.5,               0.0,              -inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 9, -0.4609960878449404, 0.0, -inf, -35.57342538404883, 0.0, -inf, -38.10126614265908, 0.0, -inf, 0.9336546783210438, 0.0, inf, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 9, -0.4609960878449404, 0.0, -inf, -35.57342538404883, 0.0, -inf, -38.10126614265908, 0.0, -inf, 0.9336546783210438, 0.0, inf, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
#
# iloc_start_eval:    139,  df_eval first date: 2023-02-28
# iloc_end_eval:      145,  df_eval last date:  2023-03-07
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#                    TA         SPY
# Date
# 2023-02-28  84.349998  396.260010
# 2023-03-01  84.260002  394.739990
# 2023-03-02  84.550003  397.809998
# 2023-03-03  84.769997  404.190002
# 2023-03-06  84.629997  404.470001
# 2023-03-07  84.510002  398.269989
#
# grp(retnStd/UI):   mean, std, mean/std:               1.5,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:              46.0,               0.0,               inf
# grp(CAGR/UI):      mean, std, mean/std:              67.4,               0.0,               inf
# grp(CAGR):         mean, std, mean/std:               0.1,               0.0,               inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 8, 0.1002234423420143, 0.0, inf, 67.38525673895782, 0.0, inf, 45.97182484327917, 0.0, inf, 1.465794689870989, 0.0, inf, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 8, 0.1002234423420143, 0.0, inf, 67.38525673895782, 0.0, inf, 45.97182484327917, 0.0, inf, 1.465794689870989, 0.0, inf, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
#
# iloc_start_eval:    139,  df_eval first date: 2023-02-28
# iloc_end_eval:      145,  df_eval last date:  2023-03-07
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                  ACGL        OEC         SPY
# Date
# 2023-02-28  70.000000  25.500000  396.260010
# 2023-03-01  70.970001  26.059999  394.739990
# 2023-03-02  70.900002  26.410000  397.809998
# 2023-03-03  71.300003  26.690001  404.190002
# 2023-03-06  71.699997  26.309999  404.470001
# 2023-03-07  70.989998  26.010000  398.269989
#
# grp(retnStd/UI):   mean, std, mean/std:               1.6,               0.4,               4.2
# grp(CAGR/retnStd): mean, std, mean/std:             124.8,               5.1,              24.3
# grp(CAGR/UI):      mean, std, mean/std:             198.6,              54.8,               3.6
# grp(CAGR):         mean, std, mean/std:               1.4,               0.3,               4.0
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, 1.3712628178483817, 0.341731282898845, 4.012693266522765, 198.59077253177168, 54.82455392062524, 3.6222961853787368, 124.78929780961784, 5.14466788123886, 24.256045422230056, 1.5759748216257732, 0.3743645304057911, 4.2097332776625525, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, 1.3712628178483817, 0.341731282898845, 4.012693266522765, 198.59077253177168, 54.82455392062524, 3.6222961853787368, 124.78929780961784, 5.14466788123886, 24.256045422230056, 1.5759748216257732, 0.3743645304057911, 4.2097332776625525, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
#
# iloc_start_eval:    139,  df_eval first date: 2023-02-28
# iloc_end_eval:      145,  df_eval last date:  2023-03-07
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   ACLS        ASC        ELF       LNTH        TNK         SPY
# Date
# 2023-02-28  128.539993  18.150000  74.750000  73.959999  45.150002  396.260010
# 2023-03-01  132.240005  18.530001  74.190002  73.080002  46.570000  394.739990
# 2023-03-02  129.169998  18.590000  75.220001  73.349998  47.610001  397.809998
# 2023-03-03  129.910004  18.180000  75.190002  72.940002  47.549999  404.190002
# 2023-03-06  128.850006  17.910000  72.080002  73.000000  45.910000  404.470001
# 2023-03-07  128.000000  18.240000  73.699997  72.370003  47.290001  398.269989
#
# grp(retnStd/UI):   mean, std, mean/std:               1.0,               0.4,               2.5
# grp(CAGR/retnStd): mean, std, mean/std:              48.1,             168.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:             111.2,             259.2,               0.4
# grp(CAGR):         mean, std, mean/std:               1.6,               3.8,               0.4
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, 1.64703991391493, 3.8494901449259924, 0.42785923639417317, 111.20720596634945, 259.21112780706096, 0.42902172799126315, 48.12133673385615, 168.32662592168197, 0.2858807183377261, 1.0052090525541615, 0.4080153818691896, 2.463654796417536, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, 1.64703991391493, 3.8494901449259924, 0.42785923639417317, 111.20720596634945, 259.21112780706096, 0.42902172799126315, 48.12133673385615, 168.32662592168197, 0.2858807183377261, 1.0052090525541615, 0.4080153818691896, 2.463654796417536, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
#
# iloc_start_eval:    139,  df_eval first date: 2023-02-28
# iloc_end_eval:      145,  df_eval last date:  2023-03-07
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   THR        TNP         SPY
# Date
# 2023-02-28  26.450001  23.780001  396.260010
# 2023-03-01  27.070000  23.790001  394.739990
# 2023-03-02  27.559999  23.770000  397.809998
# 2023-03-03  27.510000  24.510000  404.190002
# 2023-03-06  27.059999  23.580000  404.470001
# 2023-03-07  27.010000  23.850000  398.269989
#
# grp(retnStd/UI):   mean, std, mean/std:               1.3,               0.1,              18.8
# grp(CAGR/retnStd): mean, std, mean/std:              68.0,              60.9,               1.1
# grp(CAGR/UI):      mean, std, mean/std:              89.1,              80.7,               1.1
# grp(CAGR):         mean, std, mean/std:               1.0,               0.9,               1.2
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, 1.0171618767985073, 0.8574850312966295, 1.1862153153395876, 89.13971847357615, 80.7347756960363, 1.1041056063521397, 67.957809934142, 60.869586491921446, 1.1164493444219685, 1.2521912097004413, 0.0664296650690549, 18.849879920345295, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, 1.0171618767985073, 0.8574850312966295, 1.1862153153395876, 89.13971847357615, 80.7347756960363, 1.1041056063521397, 67.957809934142, 60.869586491921446, 1.1164493444219685, 1.2521912097004413, 0.0664296650690549, 18.849879920345295, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
#
# iloc_start_eval:    139,  df_eval first date: 2023-02-28
# iloc_end_eval:      145,  df_eval last date:  2023-03-07
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#               FTI       HEES        MMS   NVGS       PDFS        TPX         URI         SPY
# Date
# 2023-02-28  15.29  55.500000  82.080002  13.89  37.439999  42.740002  468.529999  396.260010
# 2023-03-01  15.42  54.490002  81.989998  13.77  37.220001  42.770000  467.799988  394.739990
# 2023-03-02  15.36  55.189999  82.309998  13.95  37.470001  42.959999  470.600006  397.809998
# 2023-03-03  15.34  55.799999  82.580002  14.04  38.380001  42.779999  479.570007  404.190002
# 2023-03-06  15.19  55.419998  82.269997  13.46  38.080002  42.080002  475.019989  404.470001
# 2023-03-07  15.17  55.310001  80.540001  13.43  38.340000  41.580002  475.760010  398.269989
#
# grp(retnStd/UI):   mean, std, mean/std:               1.3,               0.8,               1.6
# grp(CAGR/retnStd): mean, std, mean/std:               6.7,             103.1,               0.1
# grp(CAGR/UI):      mean, std, mean/std:              87.2,             220.0,               0.4
# grp(CAGR):         mean, std, mean/std:               0.1,               1.1,               0.1
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, 0.1151493959034021, 1.0916648318372715, 0.10548053994705107, 87.18763387560271, 220.02046457958875, 0.3962705652958206, 6.713697632701785, 103.13249276416036, 0.06509779268163744, 1.2540401039623306, 0.7828832678626152, 1.601822590213279, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, 0.1151493959034021, 1.0916648318372715, 0.10548053994705107, 87.18763387560271, 220.02046457958875, 0.3962705652958206, 6.713697632701785, 103.13249276416036, 0.06509779268163744, 1.2540401039623306, 0.7828832678626152, 1.601822590213279, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
#
# iloc_start_eval:    139,  df_eval first date: 2023-02-28
# iloc_end_eval:      145,  df_eval last date:  2023-03-07
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   ANF         SPY
# Date
# 2023-02-28  29.410000  396.260010
# 2023-03-01  29.230000  394.739990
# 2023-03-02  28.340000  397.809998
# 2023-03-03  28.520000  404.190002
# 2023-03-06  27.730000  404.470001
# 2023-03-07  28.360001  398.269989
#
# grp(retnStd/UI):   mean, std, mean/std:               0.6,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -41.6,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -24.9,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.8,               0.0,              -inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, -0.8399538742380432, 0.0, -inf, -24.923558427435285, 0.0, -inf, -41.5782641724131, 0.0, -inf, 0.5994372041142569, 0.0, inf, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, -0.8399538742380432, 0.0, -inf, -24.923558427435285, 0.0, -inf, -41.5782641724131, 0.0, -inf, 0.5994372041142569, 0.0, inf, 0.2904635548283454, 45.02686281133569, 27.393639837558815, 1.6436977005735598]
#
# ==================================================
#
# 2 of 57 max_lookback_slice: (15, 135, 141)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2022-08-30', '2022-08-31', '2022-09-01', '2022-09-02', '2022-09-06', '2022-09-07', '2022-09-08', '2022-09-09', '2022-09-12', '2022-09-13',
#                ...
#                '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2022-08-30 - 2023-02-21
#
# len(idx_eval): 6
# idx_eval: DatetimeIndex(['2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28', '2023-03-01'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-02-22 - 2023-03-01
#
# top_set_syms_n_freq: [('FTSM', 10), ('CTLT', 8), ('TA', 7), ('ASC', 6), ('ELF', 6), ('OEC', 6), ('PDFS', 6), ('WIRE', 6), ('ACLS', 5), ('ATI', 5), ('HZNP', 5), ('TNK', 5), ('WYNN', 5), ('MCFT', 4), ('MMS', 4), ('PEN', 4), ('THR', 4), ('ACGL', 3), ('ALGN', 3), ('ANF', 3)]
#
# max_lookback_slice:  (15, 135, 141)
# set_lookback_slices: [(120, 135, 141), (105, 135, 141), (75, 135, 141), (15, 135, 141)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         ['FTSM']
# sym_freq_9:          []
# sym_freq_8:          ['CTLT']
# sym_freq_7:          ['TA']
# sym_freq_6:          ['ASC', 'ELF', 'OEC', 'PDFS', 'WIRE']
# sym_freq_5:          ['ACLS', 'ATI', 'HZNP', 'TNK', 'WYNN']
# sym_freq_4:          ['MCFT', 'MMS', 'PEN', 'THR']
# sym_freq_3:          ['ACGL', 'ALGN', 'ANF']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.6,             -66.8,             -41.7,              -0.4
# iloc_start_eval:    135,  df_eval first date: 2023-02-22
# iloc_end_eval:      141,  df_eval last date:  2023-03-01
# frequency count of symbol(s): 10
#
# df_eval_n_SPY:
#                  FTSM         SPY
# Date
# 2023-02-22  59.409100  398.540009
# 2023-02-23  59.429035  400.660004
# 2023-02-24  59.419067  396.380005
# 2023-02-27  59.438999  397.730011
# 2023-02-28  59.450001  396.260010
# 2023-03-01  59.439999  394.739990
#
# grp(retnStd/UI):   mean, std, mean/std:               2.4,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             116.1,               0.0,               inf
# grp(CAGR/UI):      mean, std, mean/std:             273.8,               0.0,               inf
# grp(CAGR):         mean, std, mean/std:               0.0,               0.0,               inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 10, 0.026552954691140496, 0.0, inf, 273.77992078888184, 0.0, inf, 116.0599006493213, 0.0, inf, 2.3589536028995632, 0.0, inf, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 10, 0.026552954691140496, 0.0, inf, 273.77992078888184, 0.0, inf, 116.0599006493213, 0.0, inf, 2.3589536028995632, 0.0, inf, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
#
# iloc_start_eval:    135,  df_eval first date: 2023-02-22
# iloc_end_eval:      141,  df_eval last date:  2023-03-01
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#                  CTLT         SPY
# Date
# 2023-02-22  67.660004  398.540009
# 2023-02-23  67.650002  400.660004
# 2023-02-24  67.980003  396.380005
# 2023-02-27  67.239998  397.730011
# 2023-02-28  68.220001  396.260010
# 2023-03-01  69.010002  394.739990
#
# grp(retnStd/UI):   mean, std, mean/std:               2.0,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             188.7,               0.0,               inf
# grp(CAGR/UI):      mean, std, mean/std:             384.0,               0.0,               inf
# grp(CAGR):         mean, std, mean/std:               1.7,               0.0,               inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 8, 1.7066568795023058, 0.0, inf, 383.99718077062874, 0.0, inf, 188.7355721453457, 0.0, inf, 2.0345776707896466, 0.0, inf, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 8, 1.7066568795023058, 0.0, inf, 383.99718077062874, 0.0, inf, 188.7355721453457, 0.0, inf, 2.0345776707896466, 0.0, inf, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
#
# iloc_start_eval:    135,  df_eval first date: 2023-02-22
# iloc_end_eval:      141,  df_eval last date:  2023-03-01
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                    TA         SPY
# Date
# 2023-02-22  84.300003  398.540009
# 2023-02-23  84.279999  400.660004
# 2023-02-24  84.370003  396.380005
# 2023-02-27  84.349998  397.730011
# 2023-02-28  84.349998  396.260010
# 2023-03-01  84.260002  394.739990
#
# grp(retnStd/UI):   mean, std, mean/std:               1.2,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -34.5,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -42.4,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.0,               0.0,              -inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, -0.023636978029893507, 0.0, -inf, -42.35536236925606, 0.0, -inf, -34.50373310002088, 0.0, -inf, 1.227558833894134, 0.0, inf, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, -0.023636978029893507, 0.0, -inf, -42.35536236925606, 0.0, -inf, -34.50373310002088, 0.0, -inf, 1.227558833894134, 0.0, inf, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
#
# iloc_start_eval:    135,  df_eval first date: 2023-02-22
# iloc_end_eval:      141,  df_eval last date:  2023-03-01
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   ASC        ELF        OEC       PDFS        WIRE         SPY
# Date
# 2023-02-22  17.295204  73.120003  24.870001  36.490002  188.080002  398.540009
# 2023-02-23  17.812208  73.750000  24.790001  36.930000  188.419998  400.660004
# 2023-02-24  17.900002  73.339996  25.299999  37.139999  188.479996  396.380005
# 2023-02-27  18.370001  74.070000  25.260000  37.099998  190.720001  397.730011
# 2023-02-28  18.150000  74.750000  25.500000  37.439999  193.009995  396.260010
# 2023-03-01  18.530001  74.190002  26.059999  37.220001  195.210007  394.739990
#
# grp(retnStd/UI):   mean, std, mean/std:           2,583.4,           5,159.2,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:             872.5,             670.9,               1.3
# grp(CAGR/UI):      mean, std, mean/std:       2,708,410.0,       5,409,863.0,               0.5
# grp(CAGR):         mean, std, mean/std:               9.8,              11.2,               0.9
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, 9.836185756196485, 11.16137988741295, 0.8812696866710066, 2708409.9778236076, 5409863.0423540175, 0.5006429842344189, 872.4596370162502, 670.8989418261925, 1.3004337652425084, 2583.3776034070147, 5159.169830752667, 0.5007351353328348, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, 9.836185756196485, 11.16137988741295, 0.8812696866710066, 2708409.9778236076, 5409863.0423540175, 0.5006429842344189, 872.4596370162502, 670.8989418261925, 1.3004337652425084, 2583.3776034070147, 5159.169830752667, 0.5007351353328348, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
#
# iloc_start_eval:    135,  df_eval first date: 2023-02-22
# iloc_end_eval:      141,  df_eval last date:  2023-03-01
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   ACLS        ATI        HZNP        TNK        WYNN         SPY
# Date
# 2023-02-22  122.279999  40.360001  110.760002  37.360001  107.669998  398.540009
# 2023-02-23  124.709999  40.439999  110.699997  42.320000  105.839996  400.660004
# 2023-02-24  123.470001  39.509998  110.500000  43.320000  105.529999  396.380005
# 2023-02-27  125.290001  40.290001  109.839996  43.950001  105.139999  397.730011
# 2023-02-28  128.539993  40.650002  109.489998  45.150002  108.370003  396.260010
# 2023-03-01  132.240005  41.770000  110.339996  46.570000  112.220001  394.739990
#
# grp(retnStd/UI):   mean, std, mean/std:          21,444.1,          42,884.5,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:         305,007.1,         607,891.8,               0.5
# grp(CAGR/UI):      mean, std, mean/std:  32,609,707,112.5,  65,219,407,497.3,               0.5
# grp(CAGR):         mean, std, mean/std:          13,325.3,          26,619.5,               0.5
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, 13325.312315470355, 26619.490352205234, 0.5005848023069476, 32609707112.50177, 65219407497.34585, 0.5000000515771145, 305007.14772790583, 607891.8273136743, 0.5017457613729706, 21444.12714988778, 42884.535959915185, 0.5000433529217134, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, 13325.312315470355, 26619.490352205234, 0.5005848023069476, 32609707112.50177, 65219407497.34585, 0.5000000515771145, 305007.14772790583, 607891.8273136743, 0.5017457613729706, 21444.12714988778, 42884.535959915185, 0.5000433529217134, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
#
# iloc_start_eval:    135,  df_eval first date: 2023-02-22
# iloc_end_eval:      141,  df_eval last date:  2023-03-01
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  MCFT        MMS         PEN        THR         SPY
# Date
# 2023-02-22  33.750000  83.040001  261.350006  26.480000  398.540009
# 2023-02-23  34.009998  82.510002  261.720001  26.490000  400.660004
# 2023-02-24  34.320000  82.830002  267.380005  26.440001  396.380005
# 2023-02-27  33.919998  82.230003  264.820007  26.480000  397.730011
# 2023-02-28  33.770000  82.080002  259.989990  26.450001  396.260010
# 2023-03-01  34.279999  81.989998  258.380005  27.070000  394.739990
#
# grp(retnStd/UI):   mean, std, mean/std:               3.0,               3.8,               0.8
# grp(CAGR/retnStd): mean, std, mean/std:              46.2,             129.1,               0.4
# grp(CAGR/UI):      mean, std, mean/std:             526.6,             876.5,               0.6
# grp(CAGR):         mean, std, mean/std:               0.6,               1.1,               0.5
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, 0.5795216011221216, 1.077311296862082, 0.5379332815037883, 526.6115842800623, 876.476038085057, 0.6008282729903424, 46.232251382179484, 129.13729299633937, 0.3580085218565796, 2.9973600967329173, 3.8061132627097862, 0.7875120601636872, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, 0.5795216011221216, 1.077311296862082, 0.5379332815037883, 526.6115842800623, 876.476038085057, 0.6008282729903424, 46.232251382179484, 129.13729299633937, 0.3580085218565796, 2.9973600967329173, 3.8061132627097862, 0.7875120601636872, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
#
# iloc_start_eval:    135,  df_eval first date: 2023-02-22
# iloc_end_eval:      141,  df_eval last date:  2023-03-01
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ACGL        ALGN        ANF         SPY
# Date
# 2023-02-22  67.940002  302.720001  29.309999  398.540009
# 2023-02-23  68.379997  305.459991  28.959999  400.660004
# 2023-02-24  69.169998  306.279999  28.990000  396.380005
# 2023-02-27  69.209999  304.640015  28.730000  397.730011
# 2023-02-28  70.000000  309.500000  29.410000  396.260010
# 2023-03-01  70.970001  308.529999  29.230000  394.739990
#
# grp(retnStd/UI):   mean, std, mean/std:           3,882.7,           5,488.0,               0.7
# grp(CAGR/retnStd): mean, std, mean/std:             627.0,             754.2,               0.8
# grp(CAGR/UI):      mean, std, mean/std:       6,545,727.6,       9,256,616.7,               0.7
# grp(CAGR):         mean, std, mean/std:               3.2,               3.5,               0.9
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, 3.164920057140747, 3.5030525259920067, 0.9034749075720736, 6545727.619006194, 9256616.674817262, 0.7071404001003871, 626.9932373309413, 754.2387645526455, 0.8312927772982125, 3882.731663690313, 5487.97507590621, 0.70749804982472, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, 3.164920057140747, 3.5030525259920067, 0.9034749075720736, 6545727.619006194, 9256616.674817262, 0.7071404001003871, 626.9932373309413, 754.2387645526455, 0.8312927772982125, 3882.731663690313, 5487.97507590621, 0.70749804982472, -0.3829850412878617, -41.68330147499401, -66.79576129399236, 0.6240411167937842]
#
# ==================================================
#
# 3 of 57 max_lookback_slice: (8, 128, 134)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2022-08-19', '2022-08-22', '2022-08-23', '2022-08-24', '2022-08-25', '2022-08-26', '2022-08-29', '2022-08-30', '2022-08-31', '2022-09-01',
#                ...
#                '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2022-08-19 - 2023-02-09
#
# len(idx_eval): 6
# idx_eval: DatetimeIndex(['2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-02-10 - 2023-02-17
#
# top_set_syms_n_freq: [('META', 8), ('CRUS', 7), ('ELF', 7), ('FTSM', 7), ('ACLS', 6), ('CTLT', 6), ('FORM', 5), ('HZNP', 5), ('RCL', 5), ('THR', 5), ('ALGN', 4), ('ICPT', 4), ('LRN', 4), ('NVDA', 4), ('TSLA', 4), ('WYNN', 4), ('AGYS', 3), ('BIDU', 3), ('BVH', 3), ('CCU', 3)]
#
# max_lookback_slice:  (8, 128, 134)
# set_lookback_slices: [(113, 128, 134), (98, 128, 134), (68, 128, 134), (8, 128, 134)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['META']
# sym_freq_7:          ['CRUS', 'ELF', 'FTSM']
# sym_freq_6:          ['ACLS', 'CTLT']
# sym_freq_5:          ['FORM', 'HZNP', 'RCL', 'THR']
# sym_freq_4:          ['ALGN', 'ICPT', 'LRN', 'NVDA', 'TSLA', 'WYNN']
# sym_freq_3:          ['AGYS', 'BIDU', 'BVH', 'CCU']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.0,             -11.1,             -10.6,              -0.1
# iloc_start_eval:    128,  df_eval first date: 2023-02-10
# iloc_end_eval:      134,  df_eval last date:  2023-02-17
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#                   META         SPY
# Date
# 2023-02-10  174.149994  408.040009
# 2023-02-13  179.429993  412.829987
# 2023-02-14  179.479996  412.640015
# 2023-02-15  177.160004  413.980011
# 2023-02-16  172.440002  408.279999
# 2023-02-17  172.880005  407.260010
#
# grp(retnStd/UI):   mean, std, mean/std:               0.8,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -16.3,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -13.7,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.3,               0.0,              -inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 8, -0.3084976673938694, 0.0, -inf, -13.665237467547009, 0.0, -inf, -16.2842327956351, 0.0, -inf, 0.8391698668917276, 0.0, inf, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 8, -0.3084976673938694, 0.0, -inf, -13.665237467547009, 0.0, -inf, -16.2842327956351, 0.0, -inf, 0.8391698668917276, 0.0, inf, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
#
# iloc_start_eval:    128,  df_eval first date: 2023-02-10
# iloc_end_eval:      134,  df_eval last date:  2023-02-17
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                   CRUS        ELF       FTSM         SPY
# Date
# 2023-02-10  104.500000  71.320000  59.329369  408.040009
# 2023-02-13  106.139999  73.440002  59.349304  412.829987
# 2023-02-14  105.849998  73.769997  59.349304  412.640015
# 2023-02-15  106.010002  74.629997  59.349304  413.980011
# 2023-02-16  104.769997  74.000000  59.369236  408.279999
# 2023-02-17  103.529999  73.650002  59.384186  407.260010
#
# grp(retnStd/UI):   mean, std, mean/std:             126.7,             177.0,               0.7
# grp(CAGR/retnStd): mean, std, mean/std:             190.5,             160.9,               1.2
# grp(CAGR/UI):      mean, std, mean/std:          39,103.6,          54,875.0,               0.7
# grp(CAGR):         mean, std, mean/std:               1.2,               2.0,               0.6
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, 1.242293583906577, 1.9958197743822663, 0.6224477780269934, 39103.62348703706, 54874.97850966495, 0.7125947845273392, 190.53841886396197, 160.8778506398372, 1.1843670095427052, 126.68922032291094, 177.03155364847183, 0.7156307319907236, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, 1.242293583906577, 1.9958197743822663, 0.6224477780269934, 39103.62348703706, 54874.97850966495, 0.7125947845273392, 190.53841886396197, 160.8778506398372, 1.1843670095427052, 126.68922032291094, 177.03155364847183, 0.7156307319907236, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
#
# iloc_start_eval:    128,  df_eval first date: 2023-02-10
# iloc_end_eval:      134,  df_eval last date:  2023-02-17
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   ACLS       CTLT         SPY
# Date
# 2023-02-10  123.360001  70.459999  408.040009
# 2023-02-13  128.330002  70.550003  412.829987
# 2023-02-14  127.470001  70.349998  412.640015
# 2023-02-15  128.850006  69.089996  413.980011
# 2023-02-16  127.300003  71.889999  408.279999
# 2023-02-17  121.930000  71.370003  407.260010
#
# grp(retnStd/UI):   mean, std, mean/std:               1.7,               0.5,               3.4
# grp(CAGR/retnStd): mean, std, mean/std:              14.6,              31.0,               0.5
# grp(CAGR/UI):      mean, std, mean/std:              40.6,              60.2,               0.7
# grp(CAGR):         mean, std, mean/std:               0.2,               0.7,               0.3
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, 0.2324845602068802, 0.6768553278539498, 0.34347747685461844, 40.56683484671176, 60.19922637335775, 0.6738763484287124, 14.629432273857605, 30.986364488901437, 0.4721248366873601, 1.704632897859896, 0.5043838983201376, 3.3796338533748114, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, 0.2324845602068802, 0.6768553278539498, 0.34347747685461844, 40.56683484671176, 60.19922637335775, 0.6738763484287124, 14.629432273857605, 30.986364488901437, 0.4721248366873601, 1.704632897859896, 0.5043838983201376, 3.3796338533748114, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
#
# iloc_start_eval:    128,  df_eval first date: 2023-02-10
# iloc_end_eval:      134,  df_eval last date:  2023-02-17
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  FORM        HZNP        RCL        THR         SPY
# Date
# 2023-02-10  31.480000  109.419998  71.639999  27.010000  408.040009
# 2023-02-13  31.900000  109.510002  73.989998  27.180000  412.829987
# 2023-02-14  32.270000  109.550003  75.370003  26.700001  412.640015
# 2023-02-15  32.590000  109.680000  75.750000  27.309999  413.980011
# 2023-02-16  32.369999  109.620003  73.900002  27.030001  408.279999
# 2023-02-17  31.570000  109.930000  73.029999  26.930000  407.260010
#
# grp(retnStd/UI):   mean, std, mean/std:               2.2,               1.6,               1.3
# grp(CAGR/retnStd): mean, std, mean/std:              79.5,              97.1,               0.8
# grp(CAGR/UI):      mean, std, mean/std:             318.2,             500.6,               0.6
# grp(CAGR):         mean, std, mean/std:               0.5,               0.7,               0.7
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, 0.47851275120352266, 0.6832295758844403, 0.7003689068701222, 318.219933274035, 500.5983450661899, 0.6356791555752336, 79.49884284386698, 97.10163231673239, 0.8187178829759783, 2.161725598436064, 1.6296450635282997, 1.326500872377554, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, 0.47851275120352266, 0.6832295758844403, 0.7003689068701222, 318.219933274035, 500.5983450661899, 0.6356791555752336, 79.49884284386698, 97.10163231673239, 0.8187178829759783, 2.161725598436064, 1.6296450635282997, 1.326500872377554, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
#
# iloc_start_eval:    128,  df_eval first date: 2023-02-10
# iloc_end_eval:      134,  df_eval last date:  2023-02-17
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   ALGN       ICPT        LRN        NVDA        TSLA        WYNN         SPY
# Date
# 2023-02-10  315.809998  20.860001  41.599998  212.613876  196.889999  108.639999  408.040009
# 2023-02-13  325.260010  20.629999  42.660000  217.843002  194.639999  109.279999  412.829987
# 2023-02-14  331.519989  21.209999  42.860001  229.671005  209.250000  109.080002  412.640015
# 2023-02-15  338.390015  20.870001  43.400002  227.601349  214.240005  108.459999  413.980011
# 2023-02-16  326.170013  19.680000  43.820000  219.982635  202.039993  108.470001  408.279999
# 2023-02-17  316.709991  20.030001  43.889999  213.843689  208.309998  109.010002  407.260010
#
# grp(retnStd/UI):   mean, std, mean/std:           3,377.6,           7,550.1,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:             345.7,             610.9,               0.6
# grp(CAGR/UI):      mean, std, mean/std:       5,671,057.8,      12,680,580.6,               0.4
# grp(CAGR):         mean, std, mean/std:               5.0,               7.1,               0.7
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, 4.973804573718582, 7.142500069652413, 0.6963674519026825, 5671057.767334192, 12680580.561436811, 0.4472238270052531, 345.7254709912943, 610.9343579233674, 0.5658962644799564, 3377.594473824601, 7550.137432196876, 0.4473553632840054, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, 4.973804573718582, 7.142500069652413, 0.6963674519026825, 5671057.767334192, 12680580.561436811, 0.4472238270052531, 345.7254709912943, 610.9343579233674, 0.5658962644799564, 3377.594473824601, 7550.137432196876, 0.4473553632840054, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
#
# iloc_start_eval:    128,  df_eval first date: 2023-02-10
# iloc_end_eval:      134,  df_eval last date:  2023-02-17
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AGYS        BIDU        BVH    CCU         SPY
# Date
# 2023-02-10  80.779999  138.990005  32.014729  15.04  408.040009
# 2023-02-13  81.230003  146.860001  32.720421  15.31  412.829987
# 2023-02-14  81.690002  149.070007  32.690605  15.52  412.640015
# 2023-02-15  83.260002  152.039993  33.118000  15.52  413.980011
# 2023-02-16  83.330002  149.009995  32.859577  15.77  408.279999
# 2023-02-17  82.860001  141.710007  32.173756  15.76  407.260010
#
# grp(retnStd/UI):   mean, std, mean/std:               9.3,              12.7,               0.7
# grp(CAGR/retnStd): mean, std, mean/std:             391.8,             472.1,               0.8
# grp(CAGR/UI):      mean, std, mean/std:           9,531.8,          15,816.9,               0.6
# grp(CAGR):         mean, std, mean/std:               3.5,               3.6,               1.0
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, 3.5245107651295657, 3.5790462409139026, 0.9847625674234343, 9531.774797137921, 15816.871889076152, 0.6026333692265028, 391.769379113547, 472.149599300703, 0.8297568814922082, 9.308061153842267, 12.663266609463154, 0.7350442378656413, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, 3.5245107651295657, 3.5790462409139026, 0.9847625674234343, 9531.774797137921, 15816.871889076152, 0.6026333692265028, 391.769379113547, 472.149599300703, 0.8297568814922082, 9.308061153842267, 12.663266609463154, 0.7350442378656413, -0.09193157399702889, -10.57673291343087, -11.086939152840857, 0.9539813259208467]
#
# ==================================================
#
# 4 of 57 max_lookback_slice: (18, 138, 144)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2022-09-02', '2022-09-06', '2022-09-07', '2022-09-08', '2022-09-09', '2022-09-12', '2022-09-13', '2022-09-14', '2022-09-15', '2022-09-16',
#                ...
#                '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2022-09-02 - 2023-02-24
#
# len(idx_eval): 6
# idx_eval: DatetimeIndex(['2023-02-27', '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03', '2023-03-06'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-02-27 - 2023-03-06
#
# top_set_syms_n_freq: [('FTSM', 9), ('ACGL', 7), ('OEC', 7), ('SGEN', 7), ('TA', 7), ('ACLS', 6), ('ASC', 6), ('ELF', 6), ('TNK', 6), ('CTLT', 5), ('EURN', 5), ('HEES', 5), ('HZNP', 5), ('LNTH', 5), ('MMS', 5), ('PDFS', 5), ('FTI', 4), ('TEX', 4), ('THR', 4), ('TPX', 4)]
#
# max_lookback_slice:  (18, 138, 144)
# set_lookback_slices: [(123, 138, 144), (108, 138, 144), (78, 138, 144), (18, 138, 144)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          ['FTSM']
# sym_freq_8:          []
# sym_freq_7:          ['ACGL', 'OEC', 'SGEN', 'TA']
# sym_freq_6:          ['ACLS', 'ASC', 'ELF', 'TNK']
# sym_freq_5:          ['CTLT', 'EURN', 'HEES', 'HZNP', 'LNTH', 'MMS', 'PDFS']
# sym_freq_4:          ['FTI', 'TEX', 'THR', 'TPX']
# sym_freq_3:          []
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               2.2,             175.3,             389.6,               1.3
# iloc_start_eval:    138,  df_eval first date: 2023-02-27
# iloc_end_eval:      144,  df_eval last date:  2023-03-06
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#                  FTSM         SPY
# Date
# 2023-02-27  59.438999  397.730011
# 2023-02-28  59.450001  396.260010
# 2023-03-01  59.439999  394.739990
# 2023-03-02  59.459999  397.809998
# 2023-03-03  59.480000  404.190002
# 2023-03-06  59.480000  404.470001
#
# grp(retnStd/UI):   mean, std, mean/std:               2.9,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             179.6,               0.0,               inf
# grp(CAGR/UI):      mean, std, mean/std:             514.9,               0.0,               inf
# grp(CAGR):         mean, std, mean/std:               0.0,               0.0,               inf
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 9, 0.03536433511535941, 0.0, inf, 514.8731229093765, 0.0, inf, 179.63150921042958, 0.0, inf, 2.8662739915313393, 0.0, inf, 1.332474412927949, 389.6182726311638, 175.29048936700116, 2.222700581407073]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 9, 0.03536433511535941, 0.0, inf, 514.8731229093765, 0.0, inf, 179.63150921042958, 0.0, inf, 2.8662739915313393, 0.0, inf, 1.332474412927949, 389.6182726311638, 175.29048936700116, 2.222700581407073]
#
# iloc_start_eval:    138,  df_eval first date: 2023-02-27
# iloc_end_eval:      144,  df_eval last date:  2023-03-06
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                  ACGL        OEC        SGEN         TA         SPY
# Date
# 2023-02-27  69.209999  25.260000  178.160004  84.349998  397.730011
# 2023-02-28  70.000000  25.500000  179.690002  84.349998  396.260010
# 2023-03-01  70.970001  26.059999  178.229996  84.260002  394.739990
# 2023-03-02  70.900002  26.410000  178.669998  84.550003  397.809998
# 2023-03-03  71.300003  26.690001  181.289993  84.769997  404.190002
# 2023-03-06  71.699997  26.309999  177.350006  84.629997  404.470001
#
# grp(retnStd/UI):   mean, std, mean/std:               4.7,               4.7,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:             397.7,             388.0,               1.0
# grp(CAGR/UI):      mean, std, mean/std:           3,409.3,           5,131.3,               0.7
# grp(CAGR):         mean, std, mean/std:               2.9,               3.0,               1.0
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, 2.925801444131645, 3.0125728254283146, 0.9711969182738901, 3409.2681438775116, 5131.340588835303, 0.6644010633976135, 397.73836734295554, 387.9904982948056, 1.0251239890950712, 4.690445340439969, 4.734022777929803, 0.9907948399207133, 1.332474412927949, 389.6182726311638, 175.29048936700116, 2.222700581407073]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, 2.925801444131645, 3.0125728254283146, 0.9711969182738901, 3409.2681438775116, 5131.340588835303, 0.6644010633976135, 397.73836734295554, 387.9904982948056, 1.0251239890950712, 4.690445340439969, 4.734022777929803, 0.9907948399207133, 1.332474412927949, 389.6182726311638, 175.29048936700116, 2.222700581407073]
#
# iloc_start_eval:    138,  df_eval first date: 2023-02-27
# iloc_end_eval:      144,  df_eval last date:  2023-03-06
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   ACLS        ASC        ELF        TNK         SPY
# Date
# 2023-02-27  125.290001  18.370001  74.070000  43.950001  397.730011
# 2023-02-28  128.539993  18.150000  74.750000  45.150002  396.260010
# 2023-03-01  132.240005  18.530001  74.190002  46.570000  394.739990
# 2023-03-02  129.169998  18.590000  75.220001  47.610001  397.809998
# 2023-03-03  129.910004  18.180000  75.190002  47.549999  404.190002
# 2023-03-06  128.850006  17.910000  72.080002  45.910000  404.470001
#
# grp(retnStd/UI):   mean, std, mean/std:               1.2,               0.3,               4.1
# grp(CAGR/retnStd): mean, std, mean/std:              99.4,             154.3,               0.6
# grp(CAGR/UI):      mean, std, mean/std:             165.6,             241.9,               0.7
# grp(CAGR):         mean, std, mean/std:               2.4,               3.6,               0.7
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, 2.4130724901164173, 3.59430279238278, 0.6713603804416024, 165.62652640528182, 241.91554762759662, 0.6846460594597513, 99.41068202817202, 154.27665390381526, 0.6443663348451297, 1.2277623541025147, 0.30112231584975047, 4.07728783115206, 1.332474412927949, 389.6182726311638, 175.29048936700116, 2.222700581407073]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, 2.4130724901164173, 3.59430279238278, 0.6713603804416024, 165.62652640528182, 241.91554762759662, 0.6846460594597513, 99.41068202817202, 154.27665390381526, 0.6443663348451297, 1.2277623541025147, 0.30112231584975047, 4.07728783115206, 1.332474412927949, 389.6182726311638, 175.29048936700116, 2.222700581407073]
#
# iloc_start_eval:    138,  df_eval first date: 2023-02-27
# iloc_end_eval:      144,  df_eval last date:  2023-03-06
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  CTLT       EURN       HEES        HZNP       LNTH        MMS       PDFS         SPY
# ...
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, 17.10884079633222, 17.759765179656764, 0.9633483676873072, 2923.8891223689698, 2947.713400315449, 0.9919177088437671, 589.3617137889013, 622.7887943650849, 0.9463267790322697, 2.778339434026425, 2.0656155725399024, 1.345041870792129, -0.2669182252361104, -22.207606297708196, -32.80539496317362, 0.6769498225105295]
#
# iloc_start_eval:    125,  df_eval first date: 2023-02-07
# iloc_end_eval:      131,  df_eval last date:  2023-02-14
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  ALLY       COLL        HZNP       ICPT        LRN   NSTG         OI       SHOP         SPY
# Date
# 2023-02-07  34.560001  28.120001  109.800003  21.709999  41.799999  12.18  22.299999  51.349998  415.190002
# 2023-02-08  33.639999  26.820000  109.599998  20.750000  40.740002  11.99  22.209999  49.799999  410.649994
# 2023-02-09  32.689999  26.709999  109.150002  20.840000  41.389999  11.29  22.040001  49.639999  407.089996
# 2023-02-10  32.540001  26.750000  109.419998  20.860001  41.599998  10.93  21.750000  48.299999  408.040009
# 2023-02-13  33.209999  26.950001  109.510002  20.629999  42.660000  11.27  21.870001  48.700001  412.829987
# 2023-02-14  32.610001  26.850000  109.550003  21.209999  42.860001  11.36  21.910000  50.110001  412.640015
#
# grp(retnStd/UI):   mean, std, mean/std:               0.7,               0.3,               1.9
# grp(CAGR/retnStd): mean, std, mean/std:             -22.5,              67.0,              -0.3
# grp(CAGR/UI):      mean, std, mean/std:               7.3,              82.5,               0.1
# grp(CAGR):         mean, std, mean/std:              -0.3,               1.1,              -0.3
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, -0.29788441245212016, 1.100902917950879, -0.2705819083544399, 7.304343125835739, 82.52427773527417, 0.08851144567744058, -22.53832612636408, 66.95424437808592, -0.3366228136201752, 0.6501304179365531, 0.3428059348457072, 1.896496973511176, -0.2669182252361104, -22.207606297708196, -32.80539496317362, 0.6769498225105295]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, -0.29788441245212016, 1.100902917950879, -0.2705819083544399, 7.304343125835739, 82.52427773527417, 0.08851144567744058, -22.53832612636408, 66.95424437808592, -0.3366228136201752, 0.6501304179365531, 0.3428059348457072, 1.896496973511176, -0.2669182252361104, -22.207606297708196, -32.80539496317362, 0.6769498225105295]
#
# iloc_start_eval:    125,  df_eval first date: 2023-02-07
# iloc_end_eval:      131,  df_eval last date:  2023-02-14
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AGYS          AN        ANF         AX         SPY
# Date
# 2023-02-07  83.949997  133.160004  31.250000  50.689999  415.190002
# 2023-02-08  81.660004  133.089996  30.100000  49.119999  410.649994
# 2023-02-09  80.959999  133.679993  30.410000  48.520000  407.089996
# 2023-02-10  80.779999  133.850006  30.490000  48.720001  408.040009
# 2023-02-13  81.230003  135.600006  31.049999  49.630001  412.829987
# 2023-02-14  81.690002  140.070007  31.010000  49.770000  412.640015
#
# grp(retnStd/UI):   mean, std, mean/std:              14.8,              24.5,               0.6
# grp(CAGR/retnStd): mean, std, mean/std:             211.7,             432.9,               0.5
# grp(CAGR/UI):      mean, std, mean/std:          13,734.2,          23,823.6,               0.6
# grp(CAGR):         mean, std, mean/std:               2.5,               5.4,               0.5
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, 2.5330868758262213, 5.354926987618395, 0.4730385459378247, 13734.219830671971, 23823.630219042177, 0.576495676955825, 211.71071795969704, 432.8571425874189, 0.4891006688585262, 14.777224934548771, 24.512555754222358, 0.6028430932585784, -0.2669182252361104, -22.207606297708196, -32.80539496317362, 0.6769498225105295]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, 2.5330868758262213, 5.354926987618395, 0.4730385459378247, 13734.219830671971, 23823.630219042177, 0.576495676955825, 211.71071795969704, 432.8571425874189, 0.4891006688585262, 14.777224934548771, 24.512555754222358, 0.6028430932585784, -0.2669182252361104, -22.207606297708196, -32.80539496317362, 0.6769498225105295]
#
# ==================================================
#
# 57 of 57 max_lookback_slice: (13, 133, 139)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2022-08-26', '2022-08-29', '2022-08-30', '2022-08-31', '2022-09-01', '2022-09-02', '2022-09-06', '2022-09-07', '2022-09-08', '2022-09-09',
#                ...
#                '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2022-08-26 - 2023-02-16
#
# len(idx_eval): 6
# idx_eval: DatetimeIndex(['2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-02-17 - 2023-02-27
#
# top_set_syms_n_freq: [('CTLT', 7), ('FTSM', 7), ('TA', 7), ('ELF', 6), ('MMS', 6), ('THR', 6), ('ACLS', 5), ('ANF', 5), ('CRUS', 5), ('HZNP', 5), ('TWLO', 5), ('WIRE', 5), ('ASC', 4), ('CAR', 4), ('MCFT', 4), ('SMG', 4), ('TNK', 4), ('AGYS', 3), ('ALGN', 3), ('BVH', 3)]
#
# max_lookback_slice:  (13, 133, 139)
# set_lookback_slices: [(118, 133, 139), (103, 133, 139), (73, 133, 139), (13, 133, 139)]
# days_lookbacks:      [15, 30, 60, 120]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['CTLT', 'FTSM', 'TA']
# sym_freq_6:          ['ELF', 'MMS', 'THR']
# sym_freq_5:          ['ACLS', 'ANF', 'CRUS', 'HZNP', 'TWLO', 'WIRE']
# sym_freq_4:          ['ASC', 'CAR', 'MCFT', 'SMG', 'TNK']
# sym_freq_3:          ['AGYS', 'ALGN', 'BVH']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.5,             -73.5,             -35.0,              -0.7
# iloc_start_eval:    133,  df_eval first date: 2023-02-17
# iloc_end_eval:      139,  df_eval last date:  2023-02-27
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                  CTLT       FTSM         TA         SPY
# Date
# 2023-02-17  71.370003  59.384186  84.220001  407.260010
# 2023-02-21  68.660004  59.419067  84.099998  399.089996
# 2023-02-22  67.660004  59.409100  84.300003  398.540009
# 2023-02-23  67.650002  59.429035  84.279999  400.660004
# 2023-02-24  67.980003  59.419067  84.370003  396.380005
# 2023-02-27  67.239998  59.438999  84.349998  397.730011
#
# grp(retnStd/UI):   mean, std, mean/std:               1.9,               1.2,               1.6
# grp(CAGR/retnStd): mean, std, mean/std:              52.0,              90.7,               0.6
# grp(CAGR/UI):      mean, std, mean/std:             202.0,             214.4,               0.9
# grp(CAGR):         mean, std, mean/std:              -0.3,               0.5,              -0.6
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, -0.273998027498982, 0.47850008247745984, -0.5726185585597865, 201.96486408083288, 214.40986047129942, 0.9419569773371854, 51.958543287123526, 90.69863014170974, 0.5728702099022028, 1.8739146757291927, 1.1597903415676276, 1.6157357140914976, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 7, -0.273998027498982, 0.47850008247745984, -0.5726185585597865, 201.96486408083288, 214.40986047129942, 0.9419569773371854, 51.958543287123526, 90.69863014170974, 0.5728702099022028, 1.8739146757291927, 1.1597903415676276, 1.6157357140914976, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
#
# iloc_start_eval:    133,  df_eval first date: 2023-02-17
# iloc_end_eval:      139,  df_eval last date:  2023-02-27
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   ELF        MMS        THR         SPY
# Date
# 2023-02-17  73.650002  84.000000  26.930000  407.260010
# 2023-02-21  73.190002  83.269997  26.200001  399.089996
# 2023-02-22  73.120003  83.040001  26.480000  398.540009
# 2023-02-23  73.750000  82.510002  26.490000  400.660004
# 2023-02-24  73.339996  82.830002  26.440001  396.380005
# 2023-02-27  74.070000  82.230003  26.480000  397.730011
#
# grp(retnStd/UI):   mean, std, mean/std:               0.9,               0.5,               1.7
# grp(CAGR/retnStd): mean, std, mean/std:             -47.7,              79.3,              -0.6
# grp(CAGR/UI):      mean, std, mean/std:              -2.0,              53.9,              -0.0
# grp(CAGR):         mean, std, mean/std:              -0.3,               0.4,              -0.7
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, -0.29951260188067996, 0.4478396365110469, -0.6687943126563606, -1.9666856215844344, 53.85350825458151, -0.03651917368664875, -47.70361156572753, 79.31381392761043, -0.6014540116462754, 0.8557090701026687, 0.5024817404120969, 1.7029655035840345, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 6, -0.29951260188067996, 0.4478396365110469, -0.6687943126563606, -1.9666856215844344, 53.85350825458151, -0.03651917368664875, -47.70361156572753, 79.31381392761043, -0.6014540116462754, 0.8557090701026687, 0.5024817404120969, 1.7029655035840345, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
#
# iloc_start_eval:    133,  df_eval first date: 2023-02-17
# iloc_end_eval:      139,  df_eval last date:  2023-02-27
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   ACLS        ANF        CRUS        HZNP       TWLO        WIRE         SPY
# Date
# 2023-02-17  121.930000  31.190001  103.529999  109.930000  70.669998  199.610001  407.260010
# 2023-02-21  120.849998  28.900000  101.660004  109.879997  66.489998  192.350006  399.089996
# 2023-02-22  122.279999  29.309999  101.790001  110.760002  65.930000  188.080002  398.540009
# 2023-02-23  124.709999  28.959999  102.769997  110.699997  64.889999  188.419998  400.660004
# 2023-02-24  123.470001  28.990000  102.080002  110.500000  64.099998  188.479996  396.380005
# 2023-02-27  125.290001  28.730000  102.190002  109.839996  63.770000  190.720001  397.730011
#
# grp(retnStd/UI):   mean, std, mean/std:               0.9,               0.7,               1.3
# grp(CAGR/retnStd): mean, std, mean/std:               6.9,             103.4,               0.1
# grp(CAGR/UI):      mean, std, mean/std:              74.0,             208.6,               0.4
# grp(CAGR):         mean, std, mean/std:              -0.1,               1.4,              -0.1
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, -0.07733325563815935, 1.3893300433986449, -0.05566226398515293, 73.9629727207119, 208.5879216431946, 0.35458895288880227, 6.901171396716823, 103.3635296924144, 0.06676601909061242, 0.9009975158047768, 0.7049422804318554, 1.278115302224199, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 5, -0.07733325563815935, 1.3893300433986449, -0.05566226398515293, 73.9629727207119, 208.5879216431946, 0.35458895288880227, 6.901171396716823, 103.3635296924144, 0.06676601909061242, 0.9009975158047768, 0.7049422804318554, 1.278115302224199, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
#
# iloc_start_eval:    133,  df_eval first date: 2023-02-17
# iloc_end_eval:      139,  df_eval last date:  2023-02-27
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   ASC         CAR       MCFT        SMG        TNK         SPY
# Date
# 2023-02-17  17.558584  240.839996  33.990002  85.275063  37.599998  407.260010
# 2023-02-21  17.656132  225.240005  33.240002  81.118446  37.669998  399.089996
# 2023-02-22  17.295204  223.529999  33.750000  82.169998  37.360001  398.540009
# 2023-02-23  17.812208  220.130005  34.009998  82.959999  42.320000  400.660004
# 2023-02-24  17.900002  218.210007  34.320000  82.849998  43.320000  396.380005
# 2023-02-27  18.370001  221.169998  33.919998  82.720001  43.950001  397.730011
#
# grp(retnStd/UI):   mean, std, mean/std:               4.0,               5.7,               0.7
# grp(CAGR/retnStd): mean, std, mean/std:          10,271.4,          20,341.6,               0.5
# grp(CAGR/UI):      mean, std, mean/std:         155,166.5,         309,833.0,               0.5
# grp(CAGR):         mean, std, mean/std:             522.0,           1,040.6,               0.5
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, 521.9998804355516, 1040.5676669859201, 0.5016491449783004, 155166.54896249349, 309833.0034867424, 0.500807038683124, 10271.413648855252, 20341.64448507547, 0.5049450970589581, 3.950963665727027, 5.661618092897672, 0.6978506145943315, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 4, 521.9998804355516, 1040.5676669859201, 0.5016491449783004, 155166.54896249349, 309833.0034867424, 0.500807038683124, 10271.413648855252, 20341.64448507547, 0.5049450970589581, 3.950963665727027, 5.661618092897672, 0.6978506145943315, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
#
# iloc_start_eval:    133,  df_eval first date: 2023-02-17
# iloc_end_eval:      139,  df_eval last date:  2023-02-27
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AGYS        ALGN        BVH         SPY
# Date
# 2023-02-17  82.860001  316.709991  32.173756  407.260010
# 2023-02-21  81.190002  304.000000  31.338852  399.089996
# 2023-02-22  79.959999  302.720001  31.716547  398.540009
# 2023-02-23  80.459999  305.459991  32.700546  400.660004
# 2023-02-24  79.910004  306.279999  32.740303  396.380005
# 2023-02-27  79.449997  304.640015  33.485756  397.730011
#
# grp(retnStd/UI):   mean, std, mean/std:               0.8,               0.6,               1.4
# grp(CAGR/retnStd): mean, std, mean/std:              60.1,             190.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:             161.4,             266.2,               0.6
# grp(CAGR):         mean, std, mean/std:               1.6,               3.5,               0.5
#
# row_add_total: [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, 1.5859664936622053, 3.472308861332564, 0.4567469533956034, 161.3662201597019, 266.2292439155916, 0.6061175616412121, 60.05452628592327, 190.34827879019522, 0.3154981314651985, 0.8093929314455357, 0.5926158205479192, 1.3657970364294179, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60, 120]', 6, 20, 0, 10, 3, 1.5859664936622053, 3.472308861332564, 0.4567469533956034, 161.3662201597019, 266.2292439155916, 0.6061175616412121, 60.05452628592327, 190.34827879019522, 0.3154981314651985, 0.8093929314455357, 0.5926158205479192, 1.3657970364294179, -0.6968089470664469, -34.951374301004456, -73.54228274716586, 0.4752554992230153]
#
# ==================================================

# %%
if store_results:  # record results to df
  if run_type == 'train':
    pickle_dump(df_eval_sym_freq_results_train, path_data_dump, fp_df_eval_sym_freq_results_train)
    print(f'Save results to: {fp_df_eval_sym_freq_results_train}')
  elif run_type == 'validate':
    pickle_dump(df_eval_sym_freq_results_validate, path_data_dump, fp_df_eval_sym_freq_results_validate)   
    print(f'Save results to: {fp_df_eval_sym_freq_results_validate}')
  elif run_type == 'test':
    pickle_dump(df_eval_sym_freq_results_test, path_data_dump, fp_df_eval_sym_freq_results_test)   
    print(f'Save results to: {fp_df_eval_sym_freq_results_test}')
  else:
    msg_stop = f"ERROR: Result was not saved. run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop )
# Out:
# Save results to: df_eval_sym_freq_results_test_2023-03-14
