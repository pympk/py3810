# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
from yf_utils import _2_split_train_val_test, _3_random_slices, _4_lookback_slices
from yf_utils import _5_perf_ranks, _6_grp_tuples_sort_sum
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 14)
pd.set_option('display.max_colwidth', 16)
pd.set_option('display.width', 800)

verbose = False  # True prints more output
# verbose = True  # True prints more output

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"
fp_df_close_clean = 'df_close_clean'
fp_df_eval_results = 'df_eval_results'

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# %%
# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.

###################################
# df_train, df_val, df_test = _2_split_train_val_test(df_close_clean, s_train=1, s_val=0, s_test=0)
df_train, df_val, df_test = _2_split_train_val_test(df_close_clean)
###################################

len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f'len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test} ')
# Out:
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %%
# if store_results:  # record results to df
# my_cols = ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'grp(CAGR/UI)_mean', 'grp(CAGR/UI)_std', 'grp(CAGR/UI)_mean/std', 'SPY_CAGR/UI']
df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)

# %%
# write run results to df_eval_results
# store_results = False
store_results = True

# number of max lookback tuples to create for iloc start_train:end_train:end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms 
n_samples = 400  
# n_samples = 2

# for training, the number of days to lookback from iloc max-lookback end_train
days_lookbacks = [15, 30, 60, 120]
days_lookbacks = [30, 60, 120]
days_lookbacks = [60, 120]
days_lookbacks = [120]
days_lookbacks = [60]
days_lookbacks = [30]
days_lookbacks = [15]
days_lookbacks = [15, 30]
# days_lookbacks = [15, 29]
# days_lookbacks = [15, 31]
# days_lookbacks = [14, 30]
# days_lookbacks = [16, 32]
# days_lookbacks = [14, 28]

days_lookbacks.sort()

# number of days from end_train are used to evaluate effectiveness of the training
# days_eval = 10
days_eval = 5
# days_eval = 4
# days_eval = 3
# days_eval = 2  


# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20  

syms_start = 0  #  start index of n_top_syms for evaluation
# syms_start = 1  #  start index of n_top_syms for evaluation

# syms_end = n_top_syms  #  end index of n_top_syms for evaluation
# syms_end = 1  #  end index of n_top_syms for evaluation
# syms_end = 2  #  end index of n_top_syms for evaluation
# syms_end = 3  #  end index of n_top_syms for evaluation
# syms_end = 4  #  end index of n_top_syms for evaluation
# syms_end = 5  #  end index of n_top_syms for evaluation
# syms_end = 6  #  end index of n_top_syms for evaluation
syms_end = 10  #  end index of n_top_syms for evaluation

# %% [markdown]
# create a sets of iloc lookback slices (start_train:end_train:end_eval), where
# end_train - start_train = days_lookback
# end_eval - end_train = days_eval
# for example,
# if given:
#  n_samples = 2
#  days_lookbacks = [30, 60, 120]
#  days_eval = 10
# a possible result is:
#  max_lookback_slices:
#  [(150, 270, 280), (5, 125, 135)]
#  where 270-150=125-5=max(days_lookbacks), 280-270=135-125=days_eval
#  sets_lookback_slices:
#  [[(240, 270, 280), (210, 270, 280), (150, 270, 280)], [(95, 125, 135), (65, 125, 135), (5, 125, 135)]]
#   where in a set, 270-240=days_lookbacks[0], 270-210=days_lookbacks[1], 270-150=days_lookbacks[2]
#   and 270, i.e. end_train, is constant for the set

# %%
# return n_samples slices
max_lookback_slices = _3_random_slices(len_df_train, n_samples=n_samples, days_lookback=max(days_lookbacks), days_eval=days_eval)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = _4_lookback_slices(max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False)

if verbose:
  print(f'max_lookback_slices:\n{max_lookback_slices}')
  print(f'sets_lookback_slices:\n{sets_lookback_slices}')

# %% [markdown]
# Generate lists, n_samples long, of the highest performance ranked symbols. The performance metrics are: CAGR/UI, CAGR/retnStd, retnStd/UI. n_top_syms of the best performing symbols from each metric are combined. The symbols are sorted by their number of appearances in the combined pool, and are placed in a list. A slice of the best performing symbols is selected by syms_start:syms_end, i.e. top_set_syms_n_freq[syms_start:syms_end].
#
# The performance metrics are calculated based on slices in sets_lookback_slices.  The first two numbers are ilocs for training. The last two numbers are ilocs for evaluation.

# %%
grp_top_set_syms_n_freq = []  # list of lists of top_set_symbols_n_freq, there are n_samples lists in list
grp_top_set_syms = []  # list of lists of top_set_symbols, there are n_samples lists in list
# loop thru lists of tuples of start_train:end_train:end_eval, i.e.
#  [[(887, 917, 927), (857, 917, 927), (797, 917, 927)],
#  [(483, 513, 523), (453, 513, 523), (393, 513, 523)]]
for lb_slices in sets_lookback_slices:
  grp_most_common_syms = []  
  for lb_slice in lb_slices:  # lb_slice, e.g. (246, 276, 286)
    start_train = lb_slice[0]
    end_train = lb_slice[1]
    start_eval = end_train
    end_eval = lb_slice[2]
    lookback = end_train - start_train
    d_eval = end_eval - start_eval

    if verbose:
      print(f'days lookback: {lookback}')
      print(f'lb_slices:     {lb_slices}')
      print(f'lb_slice:      {lb_slice}')
      print(f'days eval:     {d_eval}')    
      print(f'start_train:   {start_train}')
      print(f'end_train:     {end_train}')
      # print(f'start_eval:    {start_eval}')
      # print(f'end_eval:      {end_eval}')`

    _df = df_train.iloc[start_train:end_train]
    perf_ranks, most_common_syms = _5_perf_ranks(_df, n_top_syms=n_top_syms)
    grp_most_common_syms.append(most_common_syms)
    
    if verbose:    
      # 1 lookback of r_CAGR/UI, r_CAGR/retnStd, r_retnStd/UI
      print(f'perf_ranks: {perf_ranks}')  
      # most common symbols of perf_ranks 
      print(f'most_common_syms: {most_common_syms}')     
      # grp_perf_ranks[lookback] = perf_ranks
      print(f'+++ finish lookback slice {lookback} +++\n')

  if verbose:
    print(f'grp_most_common_syms: {grp_most_common_syms}')
    # grp_most_common_syms a is list of lists of tuples of 
    #  the most-common-symbols symbol:frequency cumulated from
    #  each days_lookback  
    print(f'**** finish lookback slices {lb_slices} ****\n')

  # flatten list of lists of (symbol:frequency)
  flat_grp_most_common_syms = [val for sublist in grp_most_common_syms for val in sublist]
  # group symbols from set of days_lookbacks (i.e. lb_slices) and sum frequency of the symbols
  set_most_common_syms = _6_grp_tuples_sort_sum(flat_grp_most_common_syms, reverse=True)
  # get the top few most-frequent symbol:frequency pairs
  top_set_syms_n_freq = set_most_common_syms[0:n_top_syms]
  # get symbols from top_set_syms_n_freq

###################################  
  # top_set_syms = [i[0] for i in top_set_syms_n_freq]
  top_set_syms = [i[0] for i in top_set_syms_n_freq[syms_start:syms_end]]  
###################################  
  
  grp_top_set_syms_n_freq.append(top_set_syms_n_freq)
  grp_top_set_syms.append(top_set_syms)

  if verbose:  
    print(f'top {n_top_syms} ranked symbols and frequency from set {lb_slices}:\n{top_set_syms_n_freq}')
    print(f'top {n_top_syms} ranked symbols from set {lb_slices}:\n{top_set_syms}')  
    print(f'===== finish top {n_top_syms} ranked symbols from days_lookback set {lb_slices} =====\n\n')

# %%
print('z_grp_top_set_syms:')
z_grp_top_set_syms = zip(max_lookback_slices, grp_top_set_syms)
for item in z_grp_top_set_syms:
  print(item)
# Out:
# z_grp_top_set_syms:
# ((292, 322, 327), ['SIG', 'CATO', 'TNDM', 'AVXL', 'CYRX', 'W', 'ALGN', 'DDS', 'MED', 'PLAY'])
# ((474, 504, 509), ['JYNT', 'LSCC', 'NXST', 'OLED', 'W', 'CAR', 'GRMN', 'QURE', 'AGYS', 'LNTH'])
# ((136, 166, 171), ['MERC', 'SHYF', 'OSTK', 'QURE', 'ACLS', 'AMP', 'DHI', 'ETR', 'MKSI', 'NNI'])
# ((294, 324, 329), ['AVXL', 'SIG', 'TNDM', 'CYRX', 'RARE', 'ALGN', 'ETSY', 'MED', 'PI', 'PLAY'])
# ((365, 395, 400), ['DCI', 'MCFT', 'SBH', 'CLF', 'EW', 'TFX', 'NVAX', 'AMD', 'AU', 'CARA'])
# ((314, 344, 349), ['CARA', 'RAMP', 'KDP', 'NTRA', 'RDWR', 'RPM', 'ARWR', 'BLFS', 'MKC', 'XENE'])
# ((793, 823, 828), ['CHRD', 'CPE', 'ENLC', 'MGI', 'ROCC', 'CELH', 'CWH', 'STKL', 'TA', 'TRGP'])
# ((248, 278, 283), ['CATO', 'TNDM', 'GES', 'MOV', 'ANF', 'NSTG', 'RCII', 'AMBC', 'ANGO', 'AXON'])
# ((923, 953, 958), ['FATE', 'BCRX', 'NTLA', 'PERI', 'BPT', 'CPE', 'JWN', 'NOG', 'NSTG', 'OXY'])
# ((576, 606, 611), ['AMKR', 'PERI', 'CSTM', 'FCN', 'NVCR', 'OSTK', 'SSRM', 'ENTG', 'MAT', 'MU'])
# ((194, 224, 229), ['STX', 'CORT', 'FLR', 'STLA', 'ARWR', 'ATHM', 'CRSP', 'ARES', 'FATE', 'LOW'])
# ((887, 917, 922), ['GME', 'STAA', 'ACRS', 'CLMT', 'MGI', 'OLN', 'AR', 'ARWR', 'BPMC', 'DQ'])
# ((374, 404, 409), ['PBR', 'LLY', 'SUN', 'NVAX', 'VST', 'BPT', 'CCJ', 'CCK', 'CI', 'DCI'])
# ((959, 989, 994), ['ACRS', 'AVXL', 'NVAX', 'YY', 'HY', 'SSYS', 'BSM', 'IAC', 'IRDM', 'JYNT'])
# ((524, 554, 559), ['ENPH', 'PI', 'SBGI', 'TSN', 'AIG', 'AXSM', 'CYRX', 'GOGO', 'TNK', 'FTSM'])
# ((809, 839, 844), ['APPS', 'SQ', 'STAA', 'TRUP', 'CYRX', 'ETSY', 'MED', 'PLUG', 'VSTO', 'OSTK'])
# ((645, 675, 680), ['ISEE', 'BGNE', 'LEG', 'SGEN', 'UCTT', 'UFPI', 'ALGN', 'AMKR', 'CC', 'MHK'])
# ((358, 388, 393), ['MCFT', 'SWBI', 'AMD', 'SEAS', 'DCI', 'GKOS', 'BRC', 'EXAS', 'NVCR', 'PCTY'])
# ((516, 546, 551), ['PI', 'QCOM', 'AZTA', 'ENPH', 'HAS', 'MGI', 'PPC', 'SMG', 'CYRX', 'F'])
# ((465, 495, 500), ['LSCC', 'PCTY', 'RUN', 'CTLT', 'BWXT', 'GRMN', 'NYT', 'PGR', 'VECO', 'XRX'])
# ((247, 277, 282), ['CATO', 'CTRN', 'CVLT', 'DINO', 'GES', 'MOV', 'TNDM', 'ANF', 'BLFS', 'JYNT'])
# ((393, 423, 428), ['LOCO', 'KDP', 'LRN', 'PLCE', 'ACHC', 'DECK', 'ENSG', 'QNST', 'SBUX', 'CBRL'])
# ((225, 255, 260), ['AXON', 'ETSY', 'BL', 'ENPH', 'TWLO', 'COUP', 'FATE', 'VCEL', 'VEEV', 'CHGG'])
# ((956, 986, 991), ['ACRS', 'GME', 'HY', 'NVAX', 'PLCE', 'SSYS', 'DDS', 'SGRY', 'SPWR', 'STKL'])
# ((195, 225, 230), ['STX', 'ARES', 'CORT', 'FLR', 'STLA', 'ARWR', 'COLL', 'CRSP', 'FATE', 'NFLX'])
# ((67, 97, 102), ['BGNE', 'NVAX', 'OEC', 'FOLD', 'NRG', 'CAR', 'QURE', 'ASML', 'CC', 'CM'])
# ((116, 146, 151), ['HALO', 'PTEN', 'QNST', 'RCKT', 'ANF', 'ARWR', 'BPMC', 'CVE', 'NEX', 'OSBC'])
# ((434, 464, 469), ['OR', 'PKE', 'SBS', 'WPM', 'ATSG', 'MTLS', 'PTMN', 'GME', 'ABM', 'AU'])
# ((711, 741, 746), ['RNG', 'AGYS', 'CCS', 'PCG', 'AJG', 'AVXL', 'BRO', 'ENPH', 'KDNY', 'RUN'])
# ((75, 105, 110), ['TECK', 'BIDU', 'DDS', 'AVA', 'AX', 'BA', 'CYRX', 'FSLR', 'HAIN', 'HTHT'])
# ((377, 407, 412), ['FTSM', 'PBR', 'SBS', 'SUN', 'AU', 'BPT', 'GOLD', 'NG', 'NVAX', 'PZZA'])
# ((1005, 1035, 1040), ['CARA', 'WCN', 'LPX', 'MOV', 'ANF', 'AZO', 'FCN', 'GMED', 'MRCY', 'NOMD'])
# ((677, 707, 712), ['AXSM', 'ISEE', 'LLY', 'AIR', 'ATCO', 'BMA', 'DAR', 'FATE', 'MRK', 'NSP'])
# ((33, 63, 68), ['G', 'BRKR', 'TRUP', 'TTD', 'ATHM', 'CHGG', 'IAC', 'NEE', 'PETS', 'PM'])
# ((11, 41, 46), ['EXAS', 'IRBT', 'PAR', 'PTCT', 'AXGN', 'CNMD', 'EVBG', 'EVRI', 'IAC', 'ISRG'])
# ((630, 660, 665), ['EURN', 'STRL', 'TNK', 'ASC', 'BBW', 'CROX', 'TSM', 'STNG', 'DDS', 'HIBB'])
# ((117, 147, 152), ['HALO', 'PTEN', 'RCKT', 'VCEL', 'BGNE', 'BPMC', 'QNST', 'ANF', 'MNRO', 'MYGN'])
# ((631, 661, 666), ['STRL', 'TNK', 'ASC', 'CROX', 'EURN', 'LEN', 'ACRS', 'BBW', 'TNP', 'ALGN'])
# ((885, 915, 920), ['DQ', 'ENPH', 'FLEX', 'PAYC', 'ACRS', 'DAR', 'MGI', 'OLN', 'PCTY', 'SPWR'])
# ((206, 236, 241), ['DECK', 'EVTC', 'WING', 'KDP', 'NVGS', 'QNST', 'COUP', 'CRSP', 'NFLX', 'PTCT'])
# ((576, 606, 611), ['AMKR', 'PERI', 'CSTM', 'FCN', 'NVCR', 'OSTK', 'SSRM', 'ENTG', 'MAT', 'MU'])
# ((530, 560, 565), ['AXSM', 'QNST', 'FTSM', 'RNR', 'TSN', 'AIG', 'ARES', 'ARWR', 'CCEP', 'CINF'])
# ((333, 363, 368), ['LLY', 'FCN', 'HCA', 'HZNP', 'MBI', 'PCRX', 'RHI', 'SPSC', 'IBN', 'FLS'])
# ((69, 99, 104), ['NVAX', 'BGNE', 'FOLD', 'NRG', 'QURE', 'TROX', 'ASML', 'AZTA', 'ENTG', 'EXEL'])
# ((928, 958, 963), ['FATE', 'BCRX', 'CPE', 'GPRK', 'NOG', 'NSTG', 'RCKT', 'ATKR', 'BIDU', 'CHRD'])
# ((329, 359, 364), ['CACC', 'DNOW', 'FCN', 'MED', 'HCA', 'PBR', 'PCRX', 'BRKR', 'DLR', 'FLR'])
# ((54, 84, 89), ['RUN', 'STRL', 'AXSM', 'CPRX', 'FDX', 'AXP', 'COLL', 'HRB', 'LGIH', 'NVCR'])
# ((104, 134, 139), ['CELH', 'ITCI', 'ABBV', 'ANF', 'ARWR', 'FATE', 'CORT', 'CUTR', 'JYNT', 'MYGN'])
# ((208, 238, 243), ['QNST', 'VIRT', 'WING', 'DECK', 'KDP', 'PRO', 'COUP', 'HLF', 'NVGS', 'NYT'])
# ((935, 965, 970), ['ALRM', 'BIDU', 'NOAH', 'ACRS', 'IAC', 'MARA', 'CHRD', 'CTRN', 'FATE', 'GME'])
# ((596, 626, 631), ['SHAK', 'MGI', 'NVRO', 'APPS', 'PERI', 'AEM', 'BFZ', 'DXCM', 'ENPH', 'FIVN'])
# ((341, 371, 376), ['ALRM', 'FLS', 'AIN', 'DXCM', 'FIVN', 'GOGO', 'HCA', 'IRBT', 'LLY', 'MODG'])
# ((354, 384, 389), ['MCFT', 'SEAS', 'SWBI', 'AMD', 'SFM', 'STAA', 'TNDM', 'XENE', 'ARWR', 'DXCM'])
# ((598, 628, 633), ['MGI', 'SHAK', 'CNMD', 'CPRX', 'PERI', 'SUI', 'ADC', 'APPS', 'BURL', 'CATO'])
# ((827, 857, 862), ['CINF', 'EVH', 'GTLS', 'NVAX', 'RUN', 'LRN', 'MARA', 'OSTK', 'SOHU', 'AMN'])
# ((32, 62, 67), ['G', 'VOD', 'PRO', 'TRUP', 'TTD', 'ATSG', 'CHGG', 'IAC', 'LAUR', 'NEE'])
# ((668, 698, 703), ['SGRY', 'XENE', 'PCG', 'PDCO', 'RCKT', 'ALNY', 'ARWR', 'AXSM', 'ICPT', 'ISEE'])
# ((622, 652, 657), ['FTSM', 'HIBB', 'BEP', 'GME', 'AMH', 'DLTR', 'JACK', 'LEN', 'LW', 'MYI'])
# ((47, 77, 82), ['CYRX', 'PTCT', 'ALNY', 'FOLD', 'MAA', 'NVCR', 'COLL', 'CPRX', 'HALO', 'JNJ'])
# ((105, 135, 140), ['CELH', 'ITCI', 'OSTK', 'ABBV', 'ANF', 'ARWR', 'FATE', 'VCEL', 'BL', 'CUTR'])
# ((440, 470, 475), ['AXSM', 'PKE', 'SBS', 'NSTG', 'NVCR', 'AMX', 'ATSG', 'AU', 'LSCC', 'MAG'])
# ((489, 519, 524), ['CPRX', 'EVRI', 'IONS', 'AXSM', 'FTSM', 'IRDM', 'MAG', 'PLUG', 'BEP', 'CDNS'])
# ((222, 252, 257), ['AXON', 'BL', 'ENPH', 'QURE', 'TWLO', 'CRSP', 'FATE', 'PEN', 'CHGG', 'COOP'])
# ((378, 408, 413), ['BPT', 'FTSM', 'GOLD', 'MUR', 'PBR', 'PZZA', 'SBS', 'SSRM', 'AES', 'AU'])
# ((255, 285, 290), ['CVLT', 'DINO', 'TNDM', 'NSTG', 'AA', 'GPRK', 'OXY', 'BVH', 'CATO', 'CELH'])
# ((376, 406, 411), ['BPT', 'LLY', 'PBR', 'PZZA', 'SUN', 'NVAX', 'SBS', 'FTSM', 'LW', 'MKC'])
# ((883, 913, 918), ['PCTY', 'DQ', 'ENPH', 'ACRS', 'LOB', 'OLN', 'PAYC', 'PLUG', 'APPS', 'DAR'])
# ((880, 910, 915), ['EXAS', 'TRUP', 'DQ', 'ACRS', 'DDS', 'HIBB', 'AGO', 'GME', 'IBP', 'ILMN'])
# ((596, 626, 631), ['SHAK', 'MGI', 'NVRO', 'APPS', 'PERI', 'AEM', 'BFZ', 'DXCM', 'ENPH', 'FIVN'])
# ((129, 159, 164), ['SHYF', 'VSH', 'ICHR', 'LGIH', 'TROW', 'ACLS', 'MCFT', 'NOAH', 'NVDA', 'PTC'])
# ((10, 40, 45), ['EXAS', 'EVRI', 'PPC', 'ALGN', 'PAR', 'PI', 'PTCT', 'UTF', 'CMG', 'CYTK'])
# ((196, 226, 231), ['ARES', 'NFLX', 'STLA', 'STX', 'CORT', 'CRSP', 'FLR', 'ARWR', 'FATE', 'IHG'])
# ((206, 236, 241), ['DECK', 'EVTC', 'WING', 'KDP', 'NVGS', 'QNST', 'COUP', 'CRSP', 'NFLX', 'PTCT'])
# ((958, 988, 993), ['ACRS', 'NVAX', 'SSYS', 'GME', 'HY', 'IAC', 'STKL', 'DBI', 'DQ', 'IRDM'])
# ((451, 481, 486), ['TA', 'DQ', 'OZK', 'SANM', 'XRX', 'ATSG', 'AXSM', 'FBP', 'HEES', 'LGIH'])
# ((22, 52, 57), ['MELI', 'MOH', 'PETS', 'WB', 'ATSG', 'IAC', 'IRBT', 'ALNY', 'CSGP', 'CYRX'])
# ((904, 934, 939), ['CNK', 'MGI', 'CPRI', 'FORM', 'NTLA', 'PLUG', 'SPR', 'ACHC', 'AGYS', 'AZTA'])
# ((795, 825, 830), ['SWBI', 'APPS', 'MGI', 'CELH', 'CHRD', 'CPE', 'CWH', 'EBAY', 'GLW', 'MELI'])
# ((717, 747, 752), ['ENPH', 'ZG', 'CCS', 'KDNY', 'AVXL', 'CAR', 'RUN', 'ADNT', 'AY', 'BEP'])
# ((332, 362, 367), ['PFE', 'FCN', 'HCA', 'LLY', 'PCRX', 'RHI', 'SPSC', 'HCKT', 'IBN', 'ICPT'])
# ((299, 329, 334), ['ETSY', 'SRPT', 'AVXL', 'SIG', 'TNDM', 'RCII', 'TRUP', 'CATO', 'EAT', 'LC'])
# ((34, 64, 69), ['AON', 'COO', 'G', 'TRUP', 'CHGG', 'CTLT', 'IAC', 'PETS', 'PM', 'REXR'])
# ((590, 620, 625), ['CPRX', 'MODN', 'SAIA', 'SHAK', 'CUTR', 'ENPH', 'NEA', 'PERI', 'PODD', 'AGYS'])
# ((460, 490, 495), ['COUP', 'MAT', 'PCTY', 'VECO', 'XRX', 'AGYS', 'AVXL', 'AXSM', 'CCRN', 'CLF'])
# ((125, 155, 160), ['GM', 'AGYS', 'GTLS', 'RCKT', 'APPS', 'ASIX', 'MCFT', 'NOAH', 'BGNE', 'DHI'])
# ((231, 261, 266), ['AXON', 'ETSY', 'NTNX', 'ENPH', 'KDNY', 'LITE', 'MED', 'MU', 'ZG', 'ITCI'])
# ((601, 631, 636), ['AMT', 'MGI', 'NSA', 'SHAK', 'WEC', 'BOX', 'EXR', 'HGV', 'LOW', 'MODN'])
# ((585, 615, 620), ['CUTR', 'ENPH', 'MODN', 'MYGN', 'SHAK', 'AGYS', 'MUC', 'NEA', 'SAIA', 'CHE'])
# ((428, 458, 463), ['AEM', 'AU', 'MTLS', 'OR', 'RGLD', 'WPM', 'BNDX', 'RCII', 'SSRM', 'ATSG'])
# ((491, 521, 526), ['CPRX', 'EVRI', 'CMG', 'NVS', 'AXSM', 'FTSM', 'BEP', 'CAG', 'CATO', 'CDNS'])
# ((97, 127, 132), ['STLA', 'QNST', 'ARWR', 'CLMT', 'ITCI', 'MARA', 'MED', 'MYGN', 'WB', 'ANF'])
# ((412, 442, 447), ['NWL', 'BXP', 'LNTH', 'PHM', 'BECN', 'CLW', 'COLL', 'CROX', 'EXEL', 'HELE'])
# ((1000, 1030, 1035), ['FCN', 'WSM', 'HIG', 'NUE', 'CARA', 'MARA', 'BRKR', 'CCOI', 'CLMT', 'EIG'])
# ((521, 551, 556), ['PI', 'PRO', 'SBGI', 'AXSM', 'AZTA', 'ENPH', 'AJRD', 'BLDR', 'F', 'OSIS'])
# ((864, 894, 899), ['ARCH', 'GOGO', 'ANF', 'FIVE', 'GLNG', 'HIBB', 'LOB', 'BBW', 'CORT', 'GME'])
# ((713, 743, 748), ['RNG', 'AGYS', 'AVXL', 'CYTK', 'KDNY', 'RUN', 'TSLA', 'ADNT', 'AEE', 'AON'])
# ((153, 183, 188), ['BOOT', 'DINO', 'RFP', 'ENPH', 'GDS', 'HIBB', 'NTAP', 'OLED', 'RRR', 'ALGN'])
# ((944, 974, 979), ['CELH', 'GME', 'IPI', 'MARA', 'PLUG', 'ROCK', 'SM', 'AR', 'CTRN', 'DNOW'])
# ((323, 353, 358), ['KDP', 'AIZ', 'ARWR', 'BLFS', 'CHRW', 'DLR', 'FAST', 'GLW', 'HCA', 'HEP'])
# ((902, 932, 937), ['DBRG', 'LOB', 'TCBI', 'IMO', 'MGI', 'OLN', 'PLUG', 'CPRI', 'ICPT', 'JYNT'])
# ((537, 567, 572), ['ARWR', 'FTSM', 'MOH', 'SEAS', 'QURE', 'RNR', 'AIG', 'AU', 'BAH', 'BMA'])
# ((65, 95, 100), ['BGNE', 'FOLD', 'NVAX', 'OEC', 'BLFS', 'CAR', 'CYRX', 'NRG', 'NVGS', 'QURE'])
# ((488, 518, 523), ['EVRI', 'AXSM', 'CPRX', 'HAIN', 'IRDM', 'FTSM', 'JYNT', 'MAG', 'AMT', 'BEP'])
# ((465, 495, 500), ['LSCC', 'PCTY', 'RUN', 'CTLT', 'BWXT', 'GRMN', 'NYT', 'PGR', 'VECO', 'XRX'])
# ((433, 463, 468), ['MTLS', 'OR', 'PKE', 'SBS', 'WPM', 'AU', 'PTMN', 'RCII', 'RGLD', 'AEM'])
# ((788, 818, 823), ['CWH', 'MGI', 'CZR', 'ENLC', 'ROCC', 'TRGP', 'BIG', 'CCS', 'MCFT', 'STKL'])
# ((151, 181, 186), ['DINO', 'RFP', 'BOOT', 'ENPH', 'GDS', 'H', 'JLL', 'OLED', 'WMT', 'ALGN'])
# ((641, 671, 676), ['ALGN', 'AMKR', 'ISEE', 'SGEN', 'CROX', 'LEG', 'BRX', 'FELE', 'ICPT', 'PDFS'])
# ((951, 981, 986), ['ACRS', 'AMCX', 'GME', 'HY', 'SSYS', 'BGNE', 'DDS', 'IRBT', 'PLUG', 'SPWR'])
# ((942, 972, 977), ['IPI', 'AJRD', 'CELH', 'CLF', 'MARA', 'PLUG', 'SM', 'BIDU', 'CTRN', 'SSYS'])
# ((275, 305, 310), ['ROCC', 'STAA', 'TNDM', 'NOG', 'TTD', 'WWE', 'ARWR', 'AXON', 'CHRD', 'CRSP'])
# ((58, 88, 93), ['BGNE', 'EBF', 'KDNY', 'NVCR', 'EXEL', 'AXSM', 'BPMC', 'CPRX', 'LGIH', 'BLFS'])
# ((190, 220, 225), ['ARES', 'STX', 'ATHM', 'BA', 'ARWR', 'FLR', 'NOG', 'PRGS', 'AA', 'IPGP'])
# ((838, 868, 873), ['COOP', 'APPS', 'EVH', 'ROCK', 'UPS', 'BBWI', 'GPRE', 'MARA', 'OSTK', 'SOHU'])
# ((344, 374, 379), ['FLS', 'IRBT', 'ZUMZ', 'ALRM', 'AMD', 'EVBG', 'FIVN', 'INCY', 'LLY', 'NUVA'])
# ((158, 188, 193), ['RRR', 'MARA', 'BKE', 'BOOT', 'DQ', 'ENPH', 'OSTK', 'URBN', 'ANF', 'CRI'])
# ((333, 363, 368), ['LLY', 'FCN', 'HCA', 'HZNP', 'MBI', 'PCRX', 'RHI', 'SPSC', 'IBN', 'FLS'])
# ((172, 202, 207), ['SAGE', 'WWE', 'AKAM', 'LULU', 'MARA', 'PETS', 'ANF', 'CACC', 'CAR', 'CLX'])
# ((894, 924, 929), ['DBRG', 'LOB', 'MGI', 'RAMP', 'STAA', 'TCBI', 'TPR', 'ALGN', 'ARWR', 'AVXL'])
# ((736, 766, 771), ['CCOI', 'CLX', 'CTRA', 'DLR', 'EQT', 'GIS', 'FDP', 'KR', 'REGN', 'UNFI'])
# ((1006, 1036, 1041), ['CARA', 'LPX', 'ANF', 'AZO', 'ETR', 'FNV', 'GMED', 'HD', 'KBR', 'LOW'])
# ((885, 915, 920), ['DQ', 'ENPH', 'FLEX', 'PAYC', 'ACRS', 'DAR', 'MGI', 'OLN', 'PCTY', 'SPWR'])
# ((811, 841, 846), ['APPS', 'CYRX', 'DQ', 'ETSY', 'IAC', 'MED', 'OSTK', 'PLUG', 'SQ', 'TSLA'])
# ((555, 585, 590), ['NG', 'AU', 'BMA', 'RGLD', 'AJRD', 'ARWR', 'CASY', 'CMC', 'CTLT', 'DECK'])
# ((501, 531, 536), ['CPRX', 'MKC', 'PRGS', 'XPO', 'ADNT', 'AZO', 'BSIG', 'CAG', 'CCOI', 'CMG'])
# ((20, 50, 55), ['IAC', 'IRBT', 'MELI', 'MOH', 'PETS', 'ATSG', 'JD', 'MTLS', 'SSYS', 'CSGP'])
# ((323, 353, 358), ['KDP', 'AIZ', 'ARWR', 'BLFS', 'CHRW', 'DLR', 'FAST', 'GLW', 'HCA', 'HEP'])
# ((729, 759, 764), ['BNDX', 'CCOI', 'CLX', 'DPZ', 'ETSY', 'EVBG', 'GILD', 'REGN', 'TDOC', 'VIRT'])
# ((455, 485, 490), ['XRX', 'AXSM', 'BLFS', 'COUP', 'MTCH', 'UCTT', 'EDU', 'PCTY', 'SSYS', 'SYF'])
# ((95, 125, 130), ['STLA', 'ARWR', 'PAR', 'TVTX', 'BLFS', 'BMA', 'CLMT', 'MED', 'QNST', 'AEM'])
# ((375, 405, 410), ['PBR', 'PZZA', 'SUN', 'LLY', 'SBS', 'EOG', 'LW', 'MCS', 'NVAX', 'AON'])
# ((107, 137, 142), ['RGNX', 'ADNT', 'ENPH', 'ITCI', 'VCEL', 'AXGN', 'CORT', 'CUTR', 'CYRX', 'FATE'])
# ((281, 311, 316), ['TNDM', 'WWE', 'AXON', 'TTD', 'GDS', 'NOG', 'PERI', 'ROCC', 'SCVL', 'STAA'])
# ((468, 498, 503), ['LSCC', 'OLED', 'CTLT', 'LNTH', 'MARA', 'QURE', 'W', 'BOOT', 'BWXT', 'JYNT'])
# ((989, 1019, 1024), ['SFBS', 'EIG', 'HE', 'HIG', 'PARA', 'SJR', 'CPE', 'GME', 'WBD', 'LC'])
# ((723, 753, 758), ['BNDX', 'ENPH', 'EVBG', 'FATE', 'FTSM', 'TDOC', 'VIRT', 'DPZ', 'DXCM', 'ETSY'])
# ((924, 954, 959), ['FATE', 'NSTG', 'BCRX', 'PERI', 'BPT', 'CPE', 'CRSP', 'NOG', 'NTLA', 'SM'])
# ((324, 354, 359), ['KDP', 'ACGL', 'NTRA', 'AIZ', 'ARWR', 'ATKR', 'CHRW', 'CLF', 'DLR', 'FAST'])
# ((301, 331, 336), ['FIZZ', 'NTRA', 'TNDM', 'ETSY', 'RCII', 'SEAS', 'SIG', 'CYRX', 'PETS', 'SRPT'])
# ((628, 658, 663), ['EURN', 'STRL', 'TNK', 'BBW', 'TSM', 'CROX', 'STNG', 'ASC', 'BRX', 'DDS'])
# ((570, 600, 605), ['HLIT', 'RGLD', 'SKX', 'OSTK', 'SBLK', 'CUTR', 'DDS', 'FTSM', 'PAAS', 'PSX'])
# ((282, 312, 317), ['WWE', 'AXON', 'SCVL', 'STAA', 'TNDM', 'TTD', 'ARWR', 'CATO', 'GDS', 'NOG'])
# ((117, 147, 152), ['HALO', 'PTEN', 'RCKT', 'VCEL', 'BGNE', 'BPMC', 'QNST', 'ANF', 'MNRO', 'MYGN'])
# ((126, 156, 161), ['SHYF', 'AGYS', 'RCKT', 'APPS', 'GTLS', 'NOAH', 'SITE', 'ACLS', 'ASIX', 'GM'])
# ((186, 216, 221), ['DVA', 'HAL', 'CMC', 'FATE', 'NOG', 'CAT', 'FDX', 'IPGP', 'PTCT', 'ROCC'])
# ((976, 1006, 1011), ['GT', 'GME', 'SEAS', 'TRIP', 'CAR', 'PBF', 'WBD', 'XPRO', 'AMCX', 'BBW'])
# ((585, 615, 620), ['CUTR', 'ENPH', 'MODN', 'MYGN', 'SHAK', 'AGYS', 'MUC', 'NEA', 'SAIA', 'CHE'])
# ((580, 610, 615), ['CPRX', 'EXTR', 'MYGN', 'NEA', 'ENPH', 'MTSI', 'NVCR', 'SAIA', 'LSCC', 'OSTK'])
# ((68, 98, 103), ['BGNE', 'FOLD', 'NRG', 'NVAX', 'BLFS', 'QURE', 'TROX', 'ASML', 'AZTA', 'ENTG'])
# ((123, 153, 158), ['ASIX', 'GM', 'RCKT', 'ARWR', 'BGNE', 'THR', 'AGYS', 'ALNY', 'CNOB', 'GTLS'])
# ((731, 761, 766), ['BNDX', 'CCOI', 'CLX', 'EVBG', 'GILD', 'KR', 'REGN', 'TDOC', 'VIRT', 'ZTO'])
# ((841, 871, 876), ['APPS', 'BBWI', 'CELH', 'STRL', 'MARA', 'OSTK', 'ROCK', 'UPS', 'AGYS', 'EAT'])
# ((304, 334, 339), ['RCII', 'TNDM', 'WWE', 'ETSY', 'NTRA', 'CARA', 'DRI', 'RGNX', 'AMH', 'CATO'])
# ((392, 422, 427), ['LRN', 'ACHC', 'DENN', 'DECK', 'FTSM', 'KDP', 'QNST', 'AXSM', 'CBRL', 'GOLD'])
# ((113, 143, 148), ['HALO', 'RCKT', 'CVE', 'QNST', 'ZUMZ', 'ADNT', 'ANF', 'ASIX', 'CYRX', 'ENPH'])
# ((903, 933, 938), ['LOB', 'JYNT', 'COHR', 'DBRG', 'MGI', 'PLUG', 'TCBI', 'TPR', 'AZTA', 'CPRI'])
# ((577, 607, 612), ['EXTR', 'PERI', 'CPRX', 'ENPH', 'FCN', 'MTSI', 'NEA', 'NVCR', 'OSTK', 'AMKR'])
# ((388, 418, 423), ['AU', 'GOLD', 'LRN', 'PLCE', 'SSRM', 'FTSM', 'AXSM', 'GOGO', 'BFZ', 'BNDX'])
# ((22, 52, 57), ['MELI', 'MOH', 'PETS', 'WB', 'ATSG', 'IAC', 'IRBT', 'ALNY', 'CSGP', 'CYRX'])
# ((900, 930, 935), ['TCBI', 'NSP', 'SHOO', 'WAL', 'ALGN', 'BOOT', 'LOB', 'TPR', 'CPE', 'DBRG'])
# ((345, 375, 380), ['IRBT', 'MOH', 'TNDM', 'AMD', 'FLS', 'TTD', 'EXAS', 'IAC', 'INCY', 'NSTG'])
# ((622, 652, 657), ['FTSM', 'HIBB', 'BEP', 'GME', 'AMH', 'DLTR', 'JACK', 'LEN', 'LW', 'MYI'])
# ((14, 44, 49), ['ATSG', 'CHGG', 'IAC', 'IRBT', 'MOH', 'EXAS', 'CSGP', 'FSS', 'SSYS', 'TEAM'])
# ((657, 687, 692), ['EVRI', 'TRUP', 'CI', 'SGRY', 'AXSM', 'COLL', 'HUM', 'SEM', 'ALNY', 'AXON'])
# ((889, 919, 924), ['STAA', 'ALGN', 'GME', 'MGI', 'SIG', 'ARWR', 'BPMC', 'CHGG', 'OLN', 'PAYC'])
# ((278, 308, 313), ['STAA', 'TNDM', 'WWE', 'AXON', 'LPLA', 'ROCC', 'TTD', 'NOG', 'NSTG', 'CHRD'])
# ((471, 501, 506), ['OLED', 'JYNT', 'LSCC', 'W', 'GRMN', 'MSI', 'QURE', 'AGYS', 'ANET', 'APPS'])
# ((197, 227, 232), ['NFLX', 'ARES', 'NOW', 'CRSP', 'FLR', 'LOW', 'STX', 'ARWR', 'ATHM', 'CORT'])
# ((1012, 1042, 1047), ['EFX', 'IQV', 'STAA', 'RFP', 'WSO', 'ATO', 'CARA', 'GMED', 'HD', 'MAN'])
# ((241, 271, 276), ['CATO', 'CTRN', 'DXCM', 'CPE', 'RUN', 'TNDM', 'BNDX', 'ENPH', 'GPRK', 'JYNT'])
# ((139, 169, 174), ['CCS', 'INTC', 'LGIH', 'SHYF', 'ALGN', 'DHI', 'FCN', 'OSTK', 'QURE', 'TER'])
# ((705, 735, 740), ['PCG', 'TSLA', 'AGYS', 'AQN', 'BFZ', 'KDNY', 'NOW', 'NVAX', 'WTRG', 'AEP'])
# ((96, 126, 131), ['STLA', 'TVTX', 'ARWR', 'BLFS', 'CLMT', 'ITCI', 'MED', 'MYGN', 'QNST', 'TTWO'])
# ((1000, 1030, 1035), ['FCN', 'WSM', 'HIG', 'NUE', 'CARA', 'MARA', 'BRKR', 'CCOI', 'CLMT', 'EIG'])
# ((196, 226, 231), ['ARES', 'NFLX', 'STLA', 'STX', 'CORT', 'CRSP', 'FLR', 'ARWR', 'FATE', 'IHG'])
# ((677, 707, 712), ['AXSM', 'ISEE', 'LLY', 'AIR', 'ATCO', 'BMA', 'DAR', 'FATE', 'MRK', 'NSP'])
# ((110, 140, 145), ['ADNT', 'RCKT', 'CYRX', 'ENPH', 'QNST', 'AXGN', 'HALO', 'NOV', 'OSTK', 'PRGS'])
# ((592, 622, 627), ['CPRX', 'MODN', 'CORT', 'PERI', 'SHAK', 'APPS', 'CUTR', 'MGI', 'NEA', 'PODD'])
# ((16, 46, 51), ['ATSG', 'IAC', 'IRBT', 'MOH', 'PETS', 'CHGG', 'EXAS', 'MELI', 'ZG', 'APPS'])
# ((554, 584, 589), ['AU', 'BMA', 'NG', 'CTLT', 'GNRC', 'AEM', 'ARWR', 'CASY', 'CMC', 'DECK'])
# ((291, 321, 326), ['RARE', 'CATO', 'SCVL', 'SIG', 'TNDM', 'AVXL', 'CYRX', 'ALGN', 'BRX', 'FL'])
# ((63, 93, 98), ['BGNE', 'BLFS', 'NVGS', 'OEC', 'NRG', 'CAR', 'EXEL', 'FOLD', 'HAIN', 'LGIH'])
# ((342, 372, 377), ['FLS', 'ALRM', 'ZUMZ', 'AIN', 'FIVN', 'GOGO', 'HCA', 'IRBT', 'LLY', 'MED'])
# ((343, 373, 378), ['ZUMZ', 'FLS', 'ALRM', 'EVBG', 'FIVN', 'IRBT', 'NUVA', 'QURE', 'RDN', 'SEAS'])
# ((469, 499, 504), ['LSCC', 'OLED', 'W', 'GRMN', 'LNTH', 'PCG', 'QURE', 'AGYS', 'ANET', 'APPS'])
# ((544, 574, 579), ['BMA', 'AU', 'IIM', 'AEM', 'PRO', 'ARWR', 'BNDX', 'CSIQ', 'DXCM', 'MODG'])
# ((814, 844, 849), ['RUN', 'TSLA', 'ETSY', 'MED', 'NVAX', 'OSTK', 'PLUG', 'SQ', 'DQ', 'WIX'])
# ((629, 659, 664), ['EURN', 'STRL', 'TNK', 'TSM', 'ASC', 'BBW', 'CROX', 'TNP', 'STNG', 'DDS'])
# ((702, 732, 737), ['AGYS', 'BBW', 'NVAX', 'PCG', 'RVNC', 'AORT', 'ATRC', 'BFZ', 'CLW', 'CTLT'])
# ((659, 689, 694), ['TRUP', 'DXCM', 'EVRI', 'ICPT', 'ARWR', 'AXSM', 'CI', 'COLL', 'CRSP', 'HUM'])
# ((166, 196, 201), ['SAGE', 'MARA', 'NOG', 'CPRI', 'CPRT', 'CPRX', 'CTRN', 'CZR', 'DVA', 'RFP'])
# ((413, 443, 448), ['EXEL', 'NWL', 'VNDA', 'BXP', 'LNTH', 'ACLS', 'BECN', 'BERY', 'BGNE', 'CROX'])
# ((863, 893, 898), ['ARCH', 'GOGO', 'SCVL', 'ANF', 'GLNG', 'HIBB', 'CTRN', 'GME', 'ITCI', 'NVCR'])
# ((836, 866, 871), ['GTLS', 'MARA', 'BBWI', 'IRTC', 'UPS', 'AMD', 'APPS', 'CELH', 'OSTK', 'SGRY'])
# ((957, 987, 992), ['ACRS', 'NVAX', 'SSYS', 'GME', 'HY', 'STKL', 'DBI', 'DQ', 'PLCE', 'SPWR'])
# ((972, 1002, 1007), ['CUTR', 'TRIP', 'WAL', 'CPE', 'PBF', 'VNDA', 'ACRS', 'CTRN', 'HAFC', 'LOB'])
# ((73, 103, 108), ['NRG', 'HAIN', 'TECK', 'BA', 'BIDU', 'CYRX', 'DDS', 'SPWR', 'AMCX', 'AVA'])
# ((660, 690, 695), ['ICPT', 'ALNY', 'ARWR', 'AXSM', 'COLL', 'CRSP', 'NVRO', 'AXON', 'BGNE', 'CELH'])
# ((53, 83, 88), ['RUN', 'AXSM', 'CARA', 'GDEN', 'ATRC', 'BNS', 'ENSG', 'HRB', 'LGIH', 'NTLA'])
# ((79, 109, 114), ['BIDU', 'SQM', 'TECK', 'AJRD', 'DQ', 'HII', 'SPR', 'YELP', 'BSAC', 'BZH'])
# ((830, 860, 865), ['BBWI', 'EVH', 'GTLS', 'MARA', 'OSTK', 'ASA', 'NVAX', 'SOHU', 'AEM', 'AMD'])
# ((282, 312, 317), ['WWE', 'AXON', 'SCVL', 'STAA', 'TNDM', 'TTD', 'ARWR', 'CATO', 'GDS', 'NOG'])
# ((252, 282, 287), ['CVLT', 'TNDM', 'MOV', 'NSTG', 'ANGO', 'DINO', 'PAR', 'CATO', 'CELH', 'COP'])
# ((193, 223, 228), ['STX', 'FLR', 'STLA', 'ARWR', 'ATHM', 'CORT', 'CRSP', 'IPGP', 'NOG', 'ON'])
# ((401, 431, 436), ['BBWI', 'CROX', 'LOCO', 'DECK', 'SBUX', 'APPS', 'CBRL', 'CCEP', 'DENN', 'DORM'])
# ((295, 325, 330), ['AVXL', 'TNDM', 'BLFS', 'PI', 'SIG', 'TRUP', 'ALGN', 'CATO', 'ETSY', 'FIVE'])
# ((180, 210, 215), ['FCX', 'GLNG', 'NEX', 'SGRY', 'AA', 'BBY', 'FATE', 'FL', 'IPI', 'MEOH'])
# ((583, 613, 618), ['CPRX', 'MODN', 'MYGN', 'SAIA', 'AGYS', 'ENPH', 'NEA', 'PERI', 'CHE', 'MUC'])
# ((771, 801, 806), ['W', 'AR', 'SM', 'AEM', 'CVE', 'OSTK', 'WING', 'BCRX', 'BIG', 'CCJ'])
# ((865, 895, 900), ['ARCH', 'GOGO', 'ITCI', 'HIBB', 'NVCR', 'BBW', 'CORT', 'CUTR', 'FIVE', 'GME'])
# ((763, 793, 798), ['AXSM', 'BCRX', 'EXEL', 'W', 'OSTK', 'RRC', 'SGRY', 'SHOP', 'BOX', 'EXAS'])
# ((892, 922, 927), ['FSLR', 'PNM', 'STAA', 'ALGN', 'CROX', 'EXAS', 'LOB', 'TCBI', 'FOLD', 'AVXL'])
# ((175, 205, 210), ['SAGE', 'ETSY', 'LULU', 'AEO', 'AKAM', 'CYRX', 'ANF', 'CROX', 'FCX', 'FL'])
# ((510, 540, 545), ['QCOM', 'PPC', 'STNG', 'ADNT', 'BURL', 'MRVL', 'APO', 'ATCO', 'AXSM', 'BX'])
# ((992, 1022, 1027), ['FCN', 'HE', 'HIG', 'SJR', 'EIG', 'MBI', 'CLMT', 'LOB', 'WSM', 'AEE'])
# ((556, 586, 591), ['BFAM', 'NG', 'SPWR', 'AU', 'BMA', 'CMC', 'CTLT', 'DECK', 'DVA', 'ILMN'])
# ((832, 862, 867), ['GTLS', 'AMD', 'ASA', 'BBWI', 'EVH', 'MARA', 'NVAX', 'OSTK', 'GNRC', 'SOHU'])
# ((278, 308, 313), ['STAA', 'TNDM', 'WWE', 'AXON', 'LPLA', 'ROCC', 'TTD', 'NOG', 'NSTG', 'CHRD'])
# ((77, 107, 112), ['BIDU', 'IPI', 'SQM', 'TECK', 'HII', 'SPR', 'AAWW', 'AVA', 'CLMT', 'CYRX'])
# ((948, 978, 983), ['ACRS', 'SSYS', 'BGNE', 'CELH', 'GME', 'IPI', 'MARA', 'NTLA', 'PLUG', 'SPWR'])
# ((403, 433, 438), ['CROX', 'DORM', 'SBUX', 'APPS', 'CBRL', 'DELL', 'HRL', 'IBN', 'KDP', 'LOCO'])
# ((125, 155, 160), ['GM', 'AGYS', 'GTLS', 'RCKT', 'APPS', 'ASIX', 'MCFT', 'NOAH', 'BGNE', 'DHI'])
# ((744, 774, 779), ['CALM', 'EURN', 'NVAX', 'TNK', 'UNFI', 'TNP', 'CCOI', 'COUP', 'CTRA', 'CVBF'])
# ((256, 286, 291), ['DINO', 'TNDM', 'AA', 'E', 'NSTG', 'OXY', 'SPWR', 'BVH', 'CATO', 'COP'])
# ((668, 698, 703), ['SGRY', 'XENE', 'PCG', 'PDCO', 'RCKT', 'ALNY', 'ARWR', 'AXSM', 'ICPT', 'ISEE'])
# ((403, 433, 438), ['CROX', 'DORM', 'SBUX', 'APPS', 'CBRL', 'DELL', 'HRL', 'IBN', 'KDP', 'LOCO'])
# ((201, 231, 236), ['AMZN', 'IDXX', 'NFLX', 'STX', 'ARWR', 'BGNE', 'CRSP', 'FATE', 'NYT', 'PBR'])
# ((74, 104, 109), ['BIDU', 'NRG', 'HAIN', 'PKX', 'TECK', 'BA', 'CYRX', 'AVA', 'BGNE', 'DDS'])
# ((971, 1001, 1006), ['CTRN', 'CUTR', 'AVXL', 'CPE', 'DINO', 'PBF', 'SKYW', 'ACRS', 'HAFC', 'NVAX'])
# ((441, 471, 476), ['AXSM', 'SBS', 'NFLX', 'NVCR', 'AMX', 'ATSG', 'AU', 'GME', 'LSCC', 'MAG'])
# ((689, 719, 724), ['ITCI', 'TSLA', 'MED', 'PERI', 'WDC', 'APA', 'AXSM', 'BIG', 'DQ', 'ENPH'])
# ((291, 321, 326), ['RARE', 'CATO', 'SCVL', 'SIG', 'TNDM', 'AVXL', 'CYRX', 'ALGN', 'BRX', 'FL'])
# ((57, 87, 92), ['BGNE', 'EBF', 'KDNY', 'NVCR', 'BPMC', 'BLFS', 'BNS', 'COLL', 'CPRX', 'EXEL'])
# ((653, 683, 688), ['BGNE', 'EVRI', 'QRVO', 'SEM', 'TRUP', 'VSTO', 'ISEE', 'SGRY', 'STKL', 'TROX'])
# ((885, 915, 920), ['DQ', 'ENPH', 'FLEX', 'PAYC', 'ACRS', 'DAR', 'MGI', 'OLN', 'PCTY', 'SPWR'])
# ((302, 332, 337), ['ETSY', 'NTRA', 'RCII', 'TNDM', 'PETS', 'CATO', 'CPB', 'CYRX', 'DRI', 'KR'])
# ((143, 173, 178), ['STM', 'ALGN', 'INTC', 'ANSS', 'GDS', 'RFP', 'TEAM', 'CDNS', 'DHI', 'DQ'])
# ((963, 993, 998), ['AVXL', 'NVAX', 'SBNY', 'YY', 'MARA', 'OSTK', 'SSYS', 'STAA', 'BSM', 'CPE'])
# ((489, 519, 524), ['CPRX', 'EVRI', 'IONS', 'AXSM', 'FTSM', 'IRDM', 'MAG', 'PLUG', 'BEP', 'CDNS'])
# ((362, 392, 397), ['DCI', 'SWBI', 'AMD', 'MCFT', 'SBH', 'TA', 'ALB', 'ALSN', 'CAT', 'CSGS'])
# ((42, 72, 77), ['CYRX', 'PTCT', 'GDEN', 'ABT', 'AON', 'BLK', 'CTLT', 'GIL', 'LAUR', 'LGIH'])
# ((857, 887, 892), ['GME', 'GOGO', 'SPWR', 'ANF', 'BBW', 'CYRX', 'HIBB', 'ITCI', 'CAKE', 'CORT'])
# ((984, 1014, 1019), ['CPE', 'PARA', 'PDCE', 'CAR', 'HEP', 'SM', 'GME', 'HAFC', 'HFWA', 'HOPE'])
# ((384, 414, 419), ['GOLD', 'SSRM', 'NYT', 'PBR', 'SBS', 'AU', 'CNK', 'LW', 'NG', 'AES'])
# ((891, 921, 926), ['STAA', 'ALGN', 'IDXX', 'AVXL', 'FOLD', 'MGI', 'PNM', 'SIG', 'BPMC', 'CLMT'])
# ((7, 37, 42), ['YUMC', 'EVRI', 'PI', 'MCD', 'PAR', 'PLUG', 'PPC', 'QNST', 'SUN', 'UTF'])
# ((853, 883, 888), ['GOGO', 'EAT', 'GME', 'CYRX', 'DY', 'NVDA', 'RFP', 'SPWR', 'BBWI', 'BLFS'])
# ((240, 270, 275), ['CATO', 'DXCM', 'CTRN', 'JYNT', 'KDNY', 'RUN', 'BNDX', 'ENPH', 'MED', 'TNDM'])
# ((342, 372, 377), ['FLS', 'ALRM', 'ZUMZ', 'AIN', 'FIVN', 'GOGO', 'HCA', 'IRBT', 'LLY', 'MED'])
# ((823, 853, 858), ['CELH', 'RUN', 'INFY', 'NVAX', 'TSLA', 'CWH', 'EVH', 'LRN', 'MED', 'OSTK'])
# ((468, 498, 503), ['LSCC', 'OLED', 'CTLT', 'LNTH', 'MARA', 'QURE', 'W', 'BOOT', 'BWXT', 'JYNT'])
# ((439, 469, 474), ['AXSM', 'PKE', 'SBS', 'NVCR', 'AMX', 'AU', 'LSCC', 'MAG', 'MTLS', 'OR'])
# ((18, 48, 53), ['ATSG', 'IAC', 'IRBT', 'MOH', 'PETS', 'TEAM', 'EXAS', 'MELI', 'W', 'APPS'])
# ((854, 884, 889), ['EAT', 'GME', 'GOGO', 'CYRX', 'IRTC', 'SPWR', 'LOB', 'RFP', 'TA', 'BOOT'])
# ((28, 58, 63), ['CYRX', 'PETS', 'WB', 'ALNY', 'NVDA', 'OLED', 'W', 'ADSK', 'ATHM', 'ATSG'])
# ((506, 536, 541), ['QCOM', 'XPO', 'ADNT', 'MSCI', 'ELF', 'MRVL', 'WOLF', 'CAG', 'CPRX', 'JBL'])
# ((440, 470, 475), ['AXSM', 'PKE', 'SBS', 'NSTG', 'NVCR', 'AMX', 'ATSG', 'AU', 'LSCC', 'MAG'])
# ((411, 441, 446), ['NWL', 'ALK', 'BXP', 'HDB', 'BECN', 'BZH', 'CBRL', 'CLW', 'COLL', 'CROX'])
# ((859, 889, 894), ['GOGO', 'HIBB', 'SCVL', 'ANF', 'CYRX', 'MTLS', 'SIG', 'SPWR', 'AEO', 'ARCH'])
# ((546, 576, 581), ['AU', 'BMA', 'INVH', 'NEM', 'PEN', 'QURE', 'WING', 'AEM', 'ARWR', 'BBW'])
# ((869, 899, 904), ['BGNE', 'BLFS', 'GME', 'ITCI', 'NVCR', 'RUN', 'ZG', 'APPS', 'CZR', 'DQ'])
# ((392, 422, 427), ['LRN', 'ACHC', 'DENN', 'DECK', 'FTSM', 'KDP', 'QNST', 'AXSM', 'CBRL', 'GOLD'])
# ((3, 33, 38), ['MPW', 'YUMC', 'PLUG', 'EVRI', 'FMC', 'NVCR', 'SUN', 'AMT', 'CCU', 'CUBE'])
# ((0, 30, 35), ['YUMC', 'FMC', 'PLUG', 'VRTX', 'APO', 'CCU', 'EVRI', 'FIZZ', 'GPRK', 'HASI'])
# ((873, 903, 908), ['GME', 'RUN', 'ZG', 'BEP', 'BFAM', 'BLFS', 'BPMC', 'COOP', 'CSIQ', 'DRI'])
# ((480, 510, 515), ['NXST', 'OLED', 'QURE', 'W', 'CDNS', 'JYNT', 'PLUG', 'IONS', 'MELI', 'TNDM'])
# ((263, 293, 298), ['JYNT', 'LULU', 'CHRD', 'ROCC', 'ATCO', 'CMG', 'FCN', 'SM', 'UGI', 'AES'])
# ((979, 1009, 1014), ['CPE', 'GEL', 'GME', 'GT', 'MRO', 'PBF', 'ROCC', 'SEAS', 'TRIP', 'TS'])
# ((339, 369, 374), ['PAYC', 'ALRM', 'LLY', 'MOH', 'CLAR', 'DXCM', 'FAST', 'FIVN', 'FLS', 'GOGO'])
# ((432, 462, 467), ['MTLS', 'OR', 'SBS', 'WPM', 'AU', 'PTMN', 'AEM', 'ATSG', 'HDB', 'RCII'])
# ((71, 101, 106), ['NRG', 'BA', 'CHGG', 'CYRX', 'QURE', 'AMCX', 'BGNE', 'CLMT', 'EXEL', 'FOLD'])
# ((332, 362, 367), ['PFE', 'FCN', 'HCA', 'LLY', 'PCRX', 'RHI', 'SPSC', 'HCKT', 'IBN', 'ICPT'])
# ((14, 44, 49), ['ATSG', 'CHGG', 'IAC', 'IRBT', 'MOH', 'EXAS', 'CSGP', 'FSS', 'SSYS', 'TEAM'])
# ((262, 292, 297), ['JYNT', 'LULU', 'CHRD', 'SM', 'EOG', 'FCN', 'ROCC', 'AXSM', 'CMG', 'COP'])
# ((570, 600, 605), ['HLIT', 'RGLD', 'SKX', 'OSTK', 'SBLK', 'CUTR', 'DDS', 'FTSM', 'PAAS', 'PSX'])
# ((417, 447, 452), ['APPS', 'EXEL', 'VNDA', 'AZO', 'BNDX', 'FATE', 'HE', 'MUC', 'NWL', 'O'])
# ((444, 474, 479), ['AXSM', 'OZK', 'PKE', 'NVCR', 'SBS', 'ATSG', 'GTLS', 'HEES', 'LGIH', 'OR'])
# ((995, 1025, 1030), ['FCN', 'HE', 'SJR', 'CLMT', 'EIG', 'HIG', 'WSM', 'CAH', 'NUE', 'SFM'])
# ((216, 246, 251), ['VIRT', 'MTCH', 'QURE', 'FIVN', 'PAR', 'VSTO', 'XENE', 'BBW', 'BL', 'COOP'])
# ((65, 95, 100), ['BGNE', 'FOLD', 'NVAX', 'OEC', 'BLFS', 'CAR', 'CYRX', 'NRG', 'NVGS', 'QURE'])
# ((513, 543, 548), ['QCOM', 'MGI', 'PI', 'PPC', 'ADNT', 'STNG', 'STZ', 'CAG', 'CPRX', 'F'])
# ((22, 52, 57), ['MELI', 'MOH', 'PETS', 'WB', 'ATSG', 'IAC', 'IRBT', 'ALNY', 'CSGP', 'CYRX'])
# ((393, 423, 428), ['LOCO', 'KDP', 'LRN', 'PLCE', 'ACHC', 'DECK', 'ENSG', 'QNST', 'SBUX', 'CBRL'])
# ((263, 293, 298), ['JYNT', 'LULU', 'CHRD', 'ROCC', 'ATCO', 'CMG', 'FCN', 'SM', 'UGI', 'AES'])
# ((839, 869, 874), ['ROCK', 'APPS', 'CELH', 'COOP', 'EVH', 'UPS', 'GPRE', 'MARA', 'OSTK', 'SOHU'])
# ((465, 495, 500), ['LSCC', 'PCTY', 'RUN', 'CTLT', 'BWXT', 'GRMN', 'NYT', 'PGR', 'VECO', 'XRX'])
# ((969, 999, 1004), ['AVXL', 'CUTR', 'MARA', 'PBF', 'ACRS', 'APPS', 'BIDU', 'HUBS', 'HY', 'NVAX'])
# ((471, 501, 506), ['OLED', 'JYNT', 'LSCC', 'W', 'GRMN', 'MSI', 'QURE', 'AGYS', 'ANET', 'APPS'])
# ((650, 680, 685), ['BGNE', 'VSTO', 'EVRI', 'COLL', 'ISEE', 'QRVO', 'SGRY', 'SWKS', 'TROX', 'UCTT'])
# ((96, 126, 131), ['STLA', 'TVTX', 'ARWR', 'BLFS', 'CLMT', 'ITCI', 'MED', 'MYGN', 'QNST', 'TTWO'])
# ((803, 833, 838), ['PMT', 'SWBI', 'CELH', 'ISEE', 'STAA', 'VSTO', 'YY', 'CHRD', 'NVAX', 'TA'])
# ((650, 680, 685), ['BGNE', 'VSTO', 'EVRI', 'COLL', 'ISEE', 'QRVO', 'SGRY', 'SWKS', 'TROX', 'UCTT'])
# ((218, 248, 253), ['VIRT', 'CNK', 'FATE', 'QURE', 'TWLO', 'CRSP', 'NYT', 'PAR', 'AIR', 'BL'])
# ((991, 1021, 1026), ['FCN', 'HE', 'HIG', 'SJR', 'WSM', 'EIG', 'GME', 'PARA', 'CLMT', 'MBI'])
# ((903, 933, 938), ['LOB', 'JYNT', 'COHR', 'DBRG', 'MGI', 'PLUG', 'TCBI', 'TPR', 'AZTA', 'CPRI'])
# ((40, 70, 75), ['CYRX', 'GDEN', 'AON', 'BCC', 'CHGG', 'CTLT', 'GIL', 'MODN', 'MOH', 'MRTN'])
# ((130, 160, 165), ['SHYF', 'VSH', 'NOAH', 'ACLS', 'ALNY', 'CGNX', 'ICHR', 'LGIH', 'MCFT', 'NVDA'])
# ((931, 961, 966), ['FATE', 'JOE', 'PERI', 'ACRS', 'MARA', 'NTLA', 'RCKT', 'AJRD', 'ARWR', 'ATRC'])
# ((569, 599, 604), ['HLIT', 'RGLD', 'DDS', 'ELF', 'OSTK', 'PI', 'AU', 'FTNT', 'MU', 'OLED'])
# ((215, 245, 250), ['MTCH', 'QNST', 'VIRT', 'NVAX', 'QURE', 'VSTO', 'WIX', 'APPS', 'BL', 'COUP'])
# ((872, 902, 907), ['GME', 'ANGO', 'NVCR', 'RUN', 'BGNE', 'ALNY', 'BEP', 'BFAM', 'BLFS', 'BPMC'])
# ((328, 358, 363), ['MOH', 'HWM', 'MRCY', 'CACC', 'CMA', 'DLR', 'DNOW', 'FCN', 'HCA', 'NUVA'])
# ((550, 580, 585), ['GOLD', 'IQV', 'AEM', 'ARWR', 'AU', 'BMA', 'EXAS', 'HAE', 'HGV', 'NEM'])
# ((963, 993, 998), ['AVXL', 'NVAX', 'SBNY', 'YY', 'MARA', 'OSTK', 'SSYS', 'STAA', 'BSM', 'CPE'])
# ((991, 1021, 1026), ['FCN', 'HE', 'HIG', 'SJR', 'WSM', 'EIG', 'GME', 'PARA', 'CLMT', 'MBI'])
# ((494, 524, 529), ['CMG', 'CPRX', 'EVRI', 'MKC', 'AXSM', 'FTSM', 'HIBB', 'CAG', 'CATO', 'ELF'])
# ((71, 101, 106), ['NRG', 'BA', 'CHGG', 'CYRX', 'QURE', 'AMCX', 'BGNE', 'CLMT', 'EXEL', 'FOLD'])
# ((8, 38, 43), ['YUMC', 'EVRI', 'MTLS', 'TNL', 'FIVE', 'PI', 'PPC', 'SSYS', 'SUN', 'CMG'])
# ((196, 226, 231), ['ARES', 'NFLX', 'STLA', 'STX', 'CORT', 'CRSP', 'FLR', 'ARWR', 'FATE', 'IHG'])
# ((53, 83, 88), ['RUN', 'AXSM', 'CARA', 'GDEN', 'ATRC', 'BNS', 'ENSG', 'HRB', 'LGIH', 'NTLA'])
# ((965, 995, 1000), ['NVAX', 'SBNY', 'ACRS', 'AVXL', 'MARA', 'OSTK', 'STAA', 'YY', 'CPE', 'GPRE'])
# ((142, 172, 177), ['STM', 'ALGN', 'INTC', 'AXGN', 'OSTK', 'TEAM', 'ANSS', 'CDNS', 'DHI', 'DQ'])
# ((80, 110, 115), ['BIDU', 'TECK', 'YELP', 'AJRD', 'LGIH', 'AVA', 'BSAC', 'CSTM', 'SPR', 'SQM'])
# ((126, 156, 161), ['SHYF', 'AGYS', 'RCKT', 'APPS', 'GTLS', 'NOAH', 'SITE', 'ACLS', 'ASIX', 'GM'])
# ((242, 272, 277), ['CTRN', 'DXCM', 'CATO', 'RUN', 'TNDM', 'BNDX', 'GES', 'GPRK', 'MOV', 'PAR'])
# ((719, 749, 754), ['ENPH', 'KDNY', 'SBAC', 'AVXL', 'AY', 'CCS', 'DPZ', 'RUN', 'ZG', 'DXCM'])
# ((323, 353, 358), ['KDP', 'AIZ', 'ARWR', 'BLFS', 'CHRW', 'DLR', 'FAST', 'GLW', 'HCA', 'HEP'])
# ((75, 105, 110), ['TECK', 'BIDU', 'DDS', 'AVA', 'AX', 'BA', 'CYRX', 'FSLR', 'HAIN', 'HTHT'])
# ((977, 1007, 1012), ['GT', 'JYNT', 'SEAS', 'GME', 'TRIP', 'AMCX', 'CAR', 'CPE', 'PBF', 'WBD'])
# ((497, 527, 532), ['NVRO', 'CPRX', 'CAG', 'MKC', 'SRCL', 'AXSM', 'CMG', 'ELF', 'EVRI', 'FTSM'])
# ((51, 81, 86), ['RUN', 'HRB', 'NVCR', 'CARA', 'AXSM', 'ENSG', 'GDEN', 'GIL', 'IART', 'NTLA'])
# ((377, 407, 412), ['FTSM', 'PBR', 'SBS', 'SUN', 'AU', 'BPT', 'GOLD', 'NG', 'NVAX', 'PZZA'])
# ((819, 849, 854), ['RUN', 'TSLA', 'MED', 'NVAX', 'CWH', 'LRN', 'OSTK', 'APD', 'BBWI', 'BGNE'])
# ((442, 472, 477), ['AXSM', 'PKE', 'SBS', 'FMX', 'NFLX', 'NVCR', 'AMX', 'ATSG', 'GME', 'LGIH'])
# ((391, 421, 426), ['DENN', 'LRN', 'KDP', 'PLCE', 'MCD', 'MKC', 'WBA', 'ACHC', 'CBRL', 'FTSM'])
# ((455, 485, 490), ['XRX', 'AXSM', 'BLFS', 'COUP', 'MTCH', 'UCTT', 'EDU', 'PCTY', 'SSYS', 'SYF'])
# ((493, 523, 528), ['CMG', 'CPRX', 'EVRI', 'AXSM', 'FTSM', 'HTHT', 'MKC', 'CAG', 'CATO', 'CDNS'])
# ((688, 718, 723), ['ITCI', 'MED', 'OI', 'TSLA', 'PERI', 'WDC', 'APA', 'AXSM', 'BPT', 'BTI'])
# ((665, 695, 700), ['ICPT', 'XENE', 'AXSM', 'ARWR', 'CRSP', 'ISEE', 'NTLA', 'SGRY', 'ALNY', 'BCRX'])
# ((192, 222, 227), ['FLR', 'STX', 'STLA', 'ARES', 'ARWR', 'ATHM', 'CORT', 'CRSP', 'IPGP', 'SGRY'])
# ((889, 919, 924), ['STAA', 'ALGN', 'GME', 'MGI', 'SIG', 'ARWR', 'BPMC', 'CHGG', 'OLN', 'PAYC'])
# ((905, 935, 940), ['CNK', 'MGI', 'CELH', 'SM', 'SPR', 'BRX', 'CPRI', 'DBRG', 'FORM', 'GE'])
# ((770, 800, 805), ['W', 'AR', 'BCRX', 'CHGG', 'SM', 'APA', 'OSTK', 'WING', 'CCJ', 'CHRD'])
# ((517, 547, 552), ['AZTA', 'PI', 'QCOM', 'SBGI', 'ENPH', 'PPC', 'HAS', 'MGI', 'SMG', 'F'])
# ((879, 909, 914), ['EXAS', 'TRUP', 'DQ', 'HIBB', 'NVCR', 'SPWR', 'ACRS', 'AGO', 'COOP', 'ENPH'])
# ((167, 197, 202), ['SAGE', 'CPRX', 'MARA', 'NOG', 'RRR', 'BOOT', 'CPRT', 'CTRN', 'CZR', 'DVA'])
# ((872, 902, 907), ['GME', 'ANGO', 'NVCR', 'RUN', 'BGNE', 'ALNY', 'BEP', 'BFAM', 'BLFS', 'BPMC'])
# ((865, 895, 900), ['ARCH', 'GOGO', 'ITCI', 'HIBB', 'NVCR', 'BBW', 'CORT', 'CUTR', 'FIVE', 'GME'])
# ((55, 85, 90), ['BGNE', 'RUN', 'STRL', 'AXP', 'COLL', 'MARA', 'SCHN', 'BNS', 'CPRX', 'FDX'])
# ((213, 243, 248), ['MTCH', 'QNST', 'VIRT', 'IPG', 'VSTO', 'QTWO', 'RNG', 'APPS', 'AX', 'BL'])
# ((385, 415, 420), ['AU', 'GOLD', 'SSRM', 'LW', 'NYT', 'PBR', 'SBS', 'FTSM', 'NG', 'PM'])
# ((221, 251, 256), ['AXON', 'ENPH', 'TWLO', 'XENE', 'BL', 'FATE', 'PEN', 'QURE', 'WIX', 'COOP'])
# ((502, 532, 537), ['KMX', 'PRGS', 'XPO', 'MSCI', 'ADNT', 'CAG', 'CCOI', 'CPRX', 'ELF', 'LOB'])
# ((592, 622, 627), ['CPRX', 'MODN', 'CORT', 'PERI', 'SHAK', 'APPS', 'CUTR', 'MGI', 'NEA', 'PODD'])
# ((55, 85, 90), ['BGNE', 'RUN', 'STRL', 'AXP', 'COLL', 'MARA', 'SCHN', 'BNS', 'CPRX', 'FDX'])
# ((678, 708, 713), ['AXSM', 'ITCI', 'ISEE', 'TA', 'APA', 'ATCO', 'BMA', 'DAR', 'MMSI', 'MRK'])
# ((520, 550, 555), ['PI', 'PRO', 'SBGI', 'AXSM', 'ENPH', 'AZTA', 'AJRD', 'AXON', 'F', 'FTSM'])
# ((66, 96, 101), ['BGNE', 'FOLD', 'OEC', 'NRG', 'BLFS', 'CAR', 'QURE', 'SBS', 'BWA', 'EXEL'])
# ((223, 253, 258), ['AXON', 'COUP', 'CHGG', 'TWLO', 'BL', 'CRSP', 'ENPH', 'FATE', 'VCEL', 'VEEV'])
# ((549, 579, 584), ['AU', 'DXCM', 'IRT', 'SPWR', 'AEM', 'ARWR', 'BMA', 'HAE', 'NEM', 'NG'])
# ((92, 122, 127), ['ATHM', 'CUTR', 'MED', 'PAR', 'ARWR', 'CLMT', 'PPC', 'TVTX', 'WB', 'AJRD'])
# ((364, 394, 399), ['DCI', 'MCFT', 'CARA', 'PH', 'SBH', 'ALSN', 'AMD', 'AU', 'CCK', 'CLF'])
# ((693, 723, 728), ['APA', 'OI', 'OXY', 'BPT', 'PERI', 'BBW', 'BTI', 'CYTK', 'EFR', 'FATE'])
# ((116, 146, 151), ['HALO', 'PTEN', 'QNST', 'RCKT', 'ANF', 'ARWR', 'BPMC', 'CVE', 'NEX', 'OSBC'])
# ((664, 694, 699), ['ICPT', 'AXSM', 'XENE', 'ALNY', 'ARWR', 'CRSP', 'ISEE', 'NTLA', 'PAYC', 'SGRY'])
# ((547, 577, 582), ['IRT', 'AU', 'DXCM', 'INVH', 'BMA', 'VEEV', 'ARWR', 'BNDX', 'GOLD', 'HGV'])
# ((117, 147, 152), ['HALO', 'PTEN', 'RCKT', 'VCEL', 'BGNE', 'BPMC', 'QNST', 'ANF', 'MNRO', 'MYGN'])
# ((438, 468, 473), ['AXSM', 'PKE', 'SBS', 'MAG', 'ATSG', 'AMX', 'AU', 'GPRK', 'LGIH', 'LSCC'])
# ((74, 104, 109), ['BIDU', 'NRG', 'HAIN', 'PKX', 'TECK', 'BA', 'CYRX', 'AVA', 'BGNE', 'DDS'])
# ((1014, 1044, 1049), ['EFX', 'IQV', 'NVCR', 'SKM', 'STAA', 'STE', 'CSL', 'GMED', 'RFP', 'STX'])
# ((146, 176, 181), ['ALGN', 'SAGE', 'ANSS', 'INTC', 'PEN', 'RFP', 'OLED', 'OSTK', 'AXGN', 'DHI'])
# ((549, 579, 584), ['AU', 'DXCM', 'IRT', 'SPWR', 'AEM', 'ARWR', 'BMA', 'HAE', 'NEM', 'NG'])
# ((936, 966, 971), ['IPI', 'ALRM', 'BIDU', 'IAC', 'NOAH', 'ACRS', 'MARA', 'XENE', 'APPS', 'CELH'])
# ((760, 790, 795), ['CNX', 'RRC', 'W', 'AR', 'EQT', 'NG', 'OSTK', 'AAWW', 'ALNY', 'BCRX'])
# ((779, 809, 814), ['TWLO', 'NVAX', 'BCRX', 'CELH', 'CWH', 'ENPH', 'HZNP', 'OSTK', 'STKL', 'TRGP'])
# ((773, 803, 808), ['W', 'BCRX', 'CWH', 'OSTK', 'ROCC', 'SM', 'TRGP', 'AR', 'CCS', 'CHGG'])
# ((530, 560, 565), ['AXSM', 'QNST', 'FTSM', 'RNR', 'TSN', 'AIG', 'ARES', 'ARWR', 'CCEP', 'CINF'])
# ((886, 916, 921), ['DQ', 'ENPH', 'FLEX', 'PAYC', 'ACRS', 'CLMT', 'MGI', 'OLN', 'STAA', 'TPR'])
# ((120, 150, 155), ['RCKT', 'VCEL', 'ARWR', 'BGNE', 'SITE', 'SKYW', 'SRI', 'ALNY', 'ANF', 'ASIX'])
# ((549, 579, 584), ['AU', 'DXCM', 'IRT', 'SPWR', 'AEM', 'ARWR', 'BMA', 'HAE', 'NEM', 'NG'])
# ((80, 110, 115), ['BIDU', 'TECK', 'YELP', 'AJRD', 'LGIH', 'AVA', 'BSAC', 'CSTM', 'SPR', 'SQM'])
# ((754, 784, 789), ['CNX', 'EQT', 'W', 'CAG', 'TDOC', 'VEEV', 'VSTO', 'ABM', 'ACHC', 'AMZN'])
# ((839, 869, 874), ['ROCK', 'APPS', 'CELH', 'COOP', 'EVH', 'UPS', 'GPRE', 'MARA', 'OSTK', 'SOHU'])
# ((597, 627, 632), ['MGI', 'SHAK', 'NVRO', 'APPS', 'CPRX', 'FTSM', 'AEM', 'BFZ', 'CATO', 'DXCM'])
# ((661, 691, 696), ['ICPT', 'ARWR', 'AXON', 'AXSM', 'CRSP', 'ALNY', 'BGNE', 'EVRI', 'JAZZ', 'LITE'])
# ((937, 967, 972), ['BIDU', 'IPI', 'IAC', 'ACRS', 'AJRD', 'ALRM', 'MARA', 'CHRD', 'CTRN', 'DQ'])
# ((908, 938, 943), ['CPRI', 'AGYS', 'CELH', 'CNK', 'COHR', 'SM', 'SPR', 'YELP', 'JWN', 'LOB'])
# ((97, 127, 132), ['STLA', 'QNST', 'ARWR', 'CLMT', 'ITCI', 'MARA', 'MED', 'MYGN', 'WB', 'ANF'])
# ((288, 318, 323), ['MED', 'WWE', 'AMD', 'TNDM', 'CYRX', 'SCVL', 'UVV', 'AXON', 'CATO', 'HUBS'])
# ((896, 926, 931), ['LOB', 'TCBI', 'ALGN', 'DBRG', 'TPR', 'AVXL', 'FLR', 'MATX', 'NSP', 'PNFP'])
# ((362, 392, 397), ['DCI', 'SWBI', 'AMD', 'MCFT', 'SBH', 'TA', 'ALB', 'ALSN', 'CAT', 'CSGS'])
# ((301, 331, 336), ['FIZZ', 'NTRA', 'TNDM', 'ETSY', 'RCII', 'SEAS', 'SIG', 'CYRX', 'PETS', 'SRPT'])
# ((49, 79, 84), ['RUN', 'ALNY', 'PTCT', 'ARMK', 'CYRX', 'FOLD', 'COLL', 'ETSY', 'GDEN', 'HALO'])
# ((976, 1006, 1011), ['GT', 'GME', 'SEAS', 'TRIP', 'CAR', 'PBF', 'WBD', 'XPRO', 'AMCX', 'BBW'])
# ((40, 70, 75), ['CYRX', 'GDEN', 'AON', 'BCC', 'CHGG', 'CTLT', 'GIL', 'MODN', 'MOH', 'MRTN'])
# ((352, 382, 387), ['AMD', 'GKOS', 'SEAS', 'SWBI', 'MRCY', 'RFP', 'SFM', 'TNDM', 'ARWR', 'BL'])
# ((253, 283, 288), ['CVLT', 'TNDM', 'NSTG', 'ANF', 'ANGO', 'DINO', 'MOV', 'RCII', 'AA', 'BLFS'])
# ((515, 545, 550), ['QCOM', 'HAS', 'PI', 'PPC', 'ADNT', 'MGI', 'RCII', 'STNG', 'APO', 'AZTA'])
# ((354, 384, 389), ['MCFT', 'SEAS', 'SWBI', 'AMD', 'SFM', 'STAA', 'TNDM', 'XENE', 'ARWR', 'DXCM'])
# ((405, 435, 440), ['SBUX', 'CBRL', 'APPS', 'LOCO', 'BCRX', 'BKH', 'CROX', 'DORM', 'HELE', 'HRL'])
# ((449, 479, 484), ['OZK', 'ATSG', 'AXSM', 'BOOT', 'DQ', 'EDU', 'HEES', 'LGIH', 'LRN', 'NVCR'])
# ((438, 468, 473), ['AXSM', 'PKE', 'SBS', 'MAG', 'ATSG', 'AMX', 'AU', 'GPRK', 'LGIH', 'LSCC'])
# ((214, 244, 249), ['MTCH', 'QNST', 'VIRT', 'NVAX', 'VSTO', 'XENE', 'QURE', 'RNG', 'APPS', 'BL'])
# ((319, 349, 354), ['RAMP', 'BLFS', 'KDP', 'MELI', 'NTRA', 'TRUP', 'ARWR', 'FAST', 'GDEN', 'GTLS'])
# ((648, 678, 683), ['BGNE', 'EVRI', 'ISEE', 'QRVO', 'VSTO', 'COLL', 'GPRE', 'UCTT', 'SGRY', 'ACRS'])
# ((297, 327, 332), ['AVXL', 'SRPT', 'SIG', 'TNDM', 'RCII', 'TRUP', 'ALGN', 'ARWR', 'BLFS', 'CATO'])
# ((915, 945, 950), ['CHRD', 'X', 'LC', 'SM', 'AA', 'ATKR', 'JWN', 'MARA', 'BAP', 'COHR'])
# ((899, 929, 934), ['DBRG', 'LOB', 'ALGN', 'RAMP', 'TPR', 'ARWR', 'NSP', 'TTD', 'CROX', 'DLB'])
# ((37, 67, 72), ['SQ', 'COO', 'ALV', 'CHGG', 'CYRX', 'EXTR', 'LITE', 'MCHP', 'MU', 'OLED'])
# ((224, 254, 259), ['AXON', 'BL', 'TWLO', 'COUP', 'ENPH', 'ETSY', 'FATE', 'HLF', 'VCEL', 'VEEV'])

# %%
col_add0 = ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end']
col_add1 = ['grp(retnStd/UI)_mean',   'grp(retnStd/UI)_std',   'grp(retnStd/UI)_mean/std']
col_add2 = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
col_add3 = ['grp(CAGR/UI)_mean',      'grp(CAGR/UI)_std',      'grp(CAGR/UI)_mean/std']
col_add4 = ['SPY_retnStd/UI', 'SPY_CAGR/retnStd', 'SPY_CAGR/UI']
col_add_total = col_add0 + col_add1 + col_add2 + col_add3 + col_add4
print(f'col_add_total: {col_add_total}')
# Out:
# col_add_total: ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'grp(retnStd/UI)_mean', 'grp(retnStd/UI)_std', 'grp(retnStd/UI)_mean/std', 'grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std', 'grp(CAGR/UI)_mean', 'grp(CAGR/UI)_std', 'grp(CAGR/UI)_mean/std', 'SPY_retnStd/UI', 'SPY_CAGR/retnStd', 'SPY_CAGR/UI']

# %%
from yf_utils import _7_perf_eval

print('z_grp_top_set_syms:')
z_grp_top_set_syms = zip(max_lookback_slices, grp_top_set_syms)
# z_grp_top_set_syms = zip(max_lookback_slices, grp_top_set_syms[26:29])

for i, (_lookback_slice, _top_set_syms) in enumerate(z_grp_top_set_syms):
# for i, (_lookback_slice, _top_set_syms) in enumerate(z_grp_top_set_syms[26:29]):

  start_train = _lookback_slice[0]
  end_train = _lookback_slice[1]
  start_eval = end_train
  end_eval = _lookback_slice[2]

  print(f'{i + 1 } of {n_samples} max_lookback_slice')
  print(f'max_lookback_slice: {_lookback_slice}')
  # dates correspond to max_lookback_slice
  d_start_train = df_train.index[start_train].strftime('%Y-%m-%d')
  d_end_train = df_train.index[end_train].strftime('%Y-%m-%d')
  d_start_eval = d_end_train
  d_end_eval = df_train.index[end_eval].strftime('%Y-%m-%d')
  d_df_eval_start = d_end_train
  d_df_eval_end = df_train.index[end_eval - 1].strftime('%Y-%m-%d')  
  print(f'max lookback dates: {d_start_train}, {d_end_train}, {d_end_eval}')
  print(f'df_eval dates (inclusive): {d_df_eval_start} - {d_df_eval_end}')    
  print(f'top_set_syms: {_top_set_syms}\n')

  # df_eval to show _top_set_syms along with SPY 
  symbols_eval = _top_set_syms.copy()
  symbols_eval.append('SPY')
  print(f'symbols_eval: {symbols_eval}, _top_set_syms: {_top_set_syms}')
  df_eval = df_train[start_eval:end_eval][symbols_eval]

  if verbose:
    # print(f'start_eval: {start_eval}')
    # print(f'end_eval:   {end_eval}')  
    print(f'start_eval: {start_eval},  date: {d_end_train}')
    print(f'end_eval:   {end_eval},  date: {d_end_eval},  df_eval last date: {d_df_eval_end}')      
    print(f'\ndf_eval:\n{df_eval}\n')


  _, grp_retnStd_d_UI, grp_CAGR_d_retnStd, grp_CAGR_d_UI = _7_perf_eval(df_eval)
  print(f'grp(retnStd/UI):   mean, std, mean/std: {grp_retnStd_d_UI[0]  :>13,.3f}, {grp_retnStd_d_UI[1]  :>13,.3f}, {grp_retnStd_d_UI[2]  :>13,.3f}')
  print(f'grp(CAGR/retnStd): mean, std, mean/std: {grp_CAGR_d_retnStd[0]:>13,.3f}, {grp_CAGR_d_retnStd[1]:>13,.3f}, {grp_CAGR_d_retnStd[2]:>13,.3f}')
  print(f'grp(CAGR/UI):      mean, std, mean/std: {grp_CAGR_d_UI[0]     :>13,.3f}, {grp_CAGR_d_UI[1]     :>13,.3f}, {grp_CAGR_d_UI[2]     :>13,.3f}')

  _sym_idx = ['SPY']
  df_SPY = df_train[start_eval:end_eval][_sym_idx]
  _, SPY_retnStd_d_UI, SPY_CAGR_d_retnStd, SPY_CAGR_d_UI = _7_perf_eval(df_SPY)
  print(f'\nSPY: retnStd/UI, CAGR/retnStd, CAGR/UI: {SPY_retnStd_d_UI[0]:>13,.3f}, {SPY_CAGR_d_retnStd[0]:>13,.3f}, {SPY_CAGR_d_UI[0]:>13,.3f}')

  if store_results:  # record results to df
    # row_add = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, grp_CAGR_d_UI[0], grp_CAGR_d_UI[1], grp_CAGR_d_UI[2], SPY_CAGR_d_UI[0]]
    # df_eval_results.loc[len(df_eval_results)] = row_add
    row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end]
    row_add1      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
    row_add2      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
    row_add3      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
    row_add4      = [SPY_retnStd_d_UI[0],   SPY_CAGR_d_retnStd[0], SPY_CAGR_d_UI[0]]
    row_add_total = row_add0 + row_add1 + row_add2 + row_add3 + row_add4
    print(f'row_add_total: {row_add_total}')
    df_eval_results.loc[len(df_eval_results)] = row_add_total
    # print(f'appended row_add to df_eval_results:\n{row_add}\n')
    print(f'appended row_add to df_eval_results:\n{row_add_total}\n')
  print('='*50, '\n')
# Out:
# z_grp_top_set_syms:
# 1 of 400 max_lookback_slice
# max_lookback_slice: (292, 322, 327)
# max lookback dates: 2018-05-01, 2018-06-13, 2018-06-20
# df_eval dates (inclusive): 2018-06-13 - 2018-06-19
# top_set_syms: ['SIG', 'CATO', 'TNDM', 'AVXL', 'CYRX', 'W', 'ALGN', 'DDS', 'MED', 'PLAY']
#
# symbols_eval: ['SIG', 'CATO', 'TNDM', 'AVXL', 'CYRX', 'W', 'ALGN', 'DDS', 'MED', 'PLAY', 'SPY'], _top_set_syms: ['SIG', 'CATO', 'TNDM', 'AVXL', 'CYRX', 'W', 'ALGN', 'DDS', 'MED', 'PLAY']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:     1,018.394,     1,934.363,         0.526
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.749,       -78.225,       -58.593
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 1018.394078045316, 1934.3626014629738, 0.5264752726686798, inf, nan, nan, 0.749028221164424, -78.2250634591159, -58.592780133255765]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 1018.394078045316, 1934.3626014629738, 0.5264752726686798, inf, nan, nan, 0.749028221164424, -78.2250634591159, -58.592780133255765]
#
# ==================================================
#
# 2 of 400 max_lookback_slice
# max_lookback_slice: (474, 504, 509)
# max lookback dates: 2019-01-22, 2019-03-06, 2019-03-13
# df_eval dates (inclusive): 2019-03-06 - 2019-03-12
# top_set_syms: ['JYNT', 'LSCC', 'NXST', 'OLED', 'W', 'CAR', 'GRMN', 'QURE', 'AGYS', 'LNTH']
#
# symbols_eval: ['JYNT', 'LSCC', 'NXST', 'OLED', 'W', 'CAR', 'GRMN', 'QURE', 'AGYS', 'LNTH', 'SPY'], _top_set_syms: ['JYNT', 'LSCC', 'NXST', 'OLED', 'W', 'CAR', 'GRMN', 'QURE', 'AGYS', 'LNTH']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:    27,726.474,    76,301.792,         0.363
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.632,        49.279,        80.406
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 27726.473843338645, 76301.7919734701, 0.3633790652384554, inf, nan, nan, 1.6316589313140182, 49.27860027003924, 80.40586825326292]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 27726.473843338645, 76301.7919734701, 0.3633790652384554, inf, nan, nan, 1.6316589313140182, 49.27860027003924, 80.40586825326292]
#
# ==================================================
#
# 3 of 400 max_lookback_slice
# max_lookback_slice: (136, 166, 171)
# max lookback dates: 2017-09-15, 2017-10-27, 2017-11-03
# df_eval dates (inclusive): 2017-10-27 - 2017-11-02
# top_set_syms: ['MERC', 'SHYF', 'OSTK', 'QURE', 'ACLS', 'AMP', 'DHI', 'ETR', 'MKSI', 'NNI']
#
# symbols_eval: ['MERC', 'SHYF', 'OSTK', 'QURE', 'ACLS', 'AMP', 'DHI', 'ETR', 'MKSI', 'NNI', 'SPY'], _top_set_syms: ['MERC', 'SHYF', 'OSTK', 'QURE', 'ACLS', 'AMP', 'DHI', 'ETR', 'MKSI', 'NNI']
# grp(retnStd/UI):   mean, std, mean/std:         1.566,         1.211,         1.294
# grp(CAGR/retnStd): mean, std, mean/std:        88.545,       326.869,         0.271
# grp(CAGR/UI):      mean, std, mean/std:       273.674,       830.461,         0.330
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.244,        -9.431,       -11.733
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.5661999263655273, 1.2105770310158974, 1.293763128027629, 88.54461550061131, 326.86877313582903, 0.27088734922934027, 273.67416484162845, 830.4613610327185, 0.32954472981295785, 1.244094717179469, -9.4306216073401, -11.732586521410372]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.5661999263655273, 1.2105770310158974, 1.293763128027629, 88.54461550061131, 326.86877313582903, 0.27088734922934027, 273.67416484162845, 830.4613610327185, 0.32954472981295785, 1.244094717179469, -9.4306216073401, -11.732586521410372]
#
# ==================================================
#
# 4 of 400 max_lookback_slice
# max_lookback_slice: (294, 324, 329)
# max lookback dates: 2018-05-03, 2018-06-15, 2018-06-22
# df_eval dates (inclusive): 2018-06-15 - 2018-06-21
# top_set_syms: ['AVXL', 'SIG', 'TNDM', 'CYRX', 'RARE', 'ALGN', 'ETSY', 'MED', 'PI', 'PLAY']
#
# symbols_eval: ['AVXL', 'SIG', 'TNDM', 'CYRX', 'RARE', 'ALGN', 'ETSY', 'MED', 'PI', 'PLAY', 'SPY'], _top_set_syms: ['AVXL', 'SIG', 'TNDM', 'CYRX', 'RARE', 'ALGN', 'ETSY', 'MED', 'PI', 'PLAY']
# grp(retnStd/UI):   mean, std, mean/std:         1.805,         0.917,         1.968
# grp(CAGR/retnStd): mean, std, mean/std:        20.980,       102.361,         0.205
# grp(CAGR/UI):      mean, std, mean/std:       113.370,       290.140,         0.391
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.584,      -122.238,       -71.425
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.8053050995258573, 0.917130733567034, 1.9684272192083352, 20.979751214744848, 102.36051790384936, 0.2049594086115491, 113.36993140571771, 290.1404519351142, 0.39074155516608655, 0.5843123365233308, -122.2378998733923, -71.42511288672681]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.8053050995258573, 0.917130733567034, 1.9684272192083352, 20.979751214744848, 102.36051790384936, 0.2049594086115491, 113.36993140571771, 290.1404519351142, 0.39074155516608655, 0.5843123365233308, -122.2378998733923, -71.42511288672681]
#
# ==================================================
#
# 5 of 400 max_lookback_slice
# max_lookback_slice: (365, 395, 400)
# max lookback dates: 2018-08-14, 2018-09-26, 2018-10-03
# df_eval dates (inclusive): 2018-09-26 - 2018-10-02
# top_set_syms: ['DCI', 'MCFT', 'SBH', 'CLF', 'EW', 'TFX', 'NVAX', 'AMD', 'AU', 'CARA']
#
# symbols_eval: ['DCI', 'MCFT', 'SBH', 'CLF', 'EW', 'TFX', 'NVAX', 'AMD', 'AU', 'CARA', 'SPY'], _top_set_syms: ['DCI', 'MCFT', 'SBH', 'CLF', 'EW', 'TFX', 'NVAX', 'AMD', 'AU', 'CARA']
# grp(retnStd/UI):   mean, std, mean/std:         1.656,         2.029,         0.817
# grp(CAGR/retnStd): mean, std, mean/std:       -11.355,        78.084,        -0.145
# grp(CAGR/UI):      mean, std, mean/std:       106.774,       398.067,         0.268
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         7.623,       170.092,     1,296.537
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.6564867179256182, 2.0287045789520692, 0.8165243649133376, -11.355056930141457, 78.08433876162964, -0.14542041477491888, 106.77373793747506, 398.067025659898, 0.2682305517782345, 7.6225862734349406, 170.0915240314406, 1296.5373163096885]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.6564867179256182, 2.0287045789520692, 0.8165243649133376, -11.355056930141457, 78.08433876162964, -0.14542041477491888, 106.77373793747506, 398.067025659898, 0.2682305517782345, 7.6225862734349406, 170.0915240314406, 1296.5373163096885]
#
# ==================================================
#
# 6 of 400 max_lookback_slice
# max_lookback_slice: (314, 344, 349)
# max lookback dates: 2018-06-01, 2018-07-16, 2018-07-23
# df_eval dates (inclusive): 2018-07-16 - 2018-07-20
# top_set_syms: ['CARA', 'RAMP', 'KDP', 'NTRA', 'RDWR', 'RPM', 'ARWR', 'BLFS', 'MKC', 'XENE']
#
# symbols_eval: ['CARA', 'RAMP', 'KDP', 'NTRA', 'RDWR', 'RPM', 'ARWR', 'BLFS', 'MKC', 'XENE', 'SPY'], _top_set_syms: ['CARA', 'RAMP', 'KDP', 'NTRA', 'RDWR', 'RPM', 'ARWR', 'BLFS', 'MKC', 'XENE']
# grp(retnStd/UI):   mean, std, mean/std:         1.796,         0.973,         1.847
# grp(CAGR/retnStd): mean, std, mean/std:        61.962,       105.936,         0.585
# grp(CAGR/UI):      mean, std, mean/std:       176.780,       289.171,         0.611
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.250,        18.262,        22.827
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.7964699818181806, 0.9727779059660856, 1.8467421708494394, 61.962411337708474, 105.93576751060546, 0.5849054837074295, 176.77959033647423, 289.1707405315142, 0.6113329101400167, 1.2499707990029272, 18.262126273088736, 22.827124569065074]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.7964699818181806, 0.9727779059660856, 1.8467421708494394, 61.962411337708474, 105.93576751060546, 0.5849054837074295, 176.77959033647423, 289.1707405315142, 0.6113329101400167, 1.2499707990029272, 18.262126273088736, 22.827124569065074]
#
# ==================================================
#
# 7 of 400 max_lookback_slice
# max_lookback_slice: (793, 823, 828)
# max lookback dates: 2020-04-28, 2020-06-10, 2020-06-17
# df_eval dates (inclusive): 2020-06-10 - 2020-06-16
# top_set_syms: ['CHRD', 'CPE', 'ENLC', 'MGI', 'ROCC', 'CELH', 'CWH', 'STKL', 'TA', 'TRGP']
#
# symbols_eval: ['CHRD', 'CPE', 'ENLC', 'MGI', 'ROCC', 'CELH', 'CWH', 'STKL', 'TA', 'TRGP', 'SPY'], _top_set_syms: ['CHRD', 'CPE', 'ENLC', 'MGI', 'ROCC', 'CELH', 'CWH', 'STKL', 'TA', 'TRGP']
# grp(retnStd/UI):   mean, std, mean/std:         1.509,         0.444,         3.395
# grp(CAGR/retnStd): mean, std, mean/std:       704.385,     1,944.190,         0.362
# grp(CAGR/UI):      mean, std, mean/std:     1,454.352,     3,979.359,         0.365
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.942,       -17.260,       -16.258
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.509068816428283, 0.4444716248107887, 3.3951972008802422, 704.3851639500094, 1944.1901444132518, 0.3623026101506084, 1454.3522078980336, 3979.3589837365694, 0.36547399062057345, 0.9419361671208994, -17.25970556347736, -16.25754090409713]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.509068816428283, 0.4444716248107887, 3.3951972008802422, 704.3851639500094, 1944.1901444132518, 0.3623026101506084, 1454.3522078980336, 3979.3589837365694, 0.36547399062057345, 0.9419361671208994, -17.25970556347736, -16.25754090409713]
#
# ==================================================
#
# 8 of 400 max_lookback_slice
# max_lookback_slice: (248, 278, 283)
# max lookback dates: 2018-02-27, 2018-04-11, 2018-04-18
# df_eval dates (inclusive): 2018-04-11 - 2018-04-17
# top_set_syms: ['CATO', 'TNDM', 'GES', 'MOV', 'ANF', 'NSTG', 'RCII', 'AMBC', 'ANGO', 'AXON']
#
# symbols_eval: ['CATO', 'TNDM', 'GES', 'MOV', 'ANF', 'NSTG', 'RCII', 'AMBC', 'ANGO', 'AXON', 'SPY'], _top_set_syms: ['CATO', 'TNDM', 'GES', 'MOV', 'ANF', 'NSTG', 'RCII', 'AMBC', 'ANGO', 'AXON']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:       618.851,     1,013.781,         0.610
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         4.653,       387.747,     1,804.176
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 618.8506628947925, 1013.7811388476772, 0.6104381302637119, inf, nan, nan, 4.65297617202855, 387.74658766906344, 1804.1756332095315]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 618.8506628947925, 1013.7811388476772, 0.6104381302637119, inf, nan, nan, 4.65297617202855, 387.74658766906344, 1804.1756332095315]
#
# ==================================================
#
# 9 of 400 max_lookback_slice
# max_lookback_slice: (923, 953, 958)
# max lookback dates: 2020-10-30, 2020-12-14, 2020-12-21
# df_eval dates (inclusive): 2020-12-14 - 2020-12-18
# top_set_syms: ['FATE', 'BCRX', 'NTLA', 'PERI', 'BPT', 'CPE', 'JWN', 'NOG', 'NSTG', 'OXY']
#
# symbols_eval: ['FATE', 'BCRX', 'NTLA', 'PERI', 'BPT', 'CPE', 'JWN', 'NOG', 'NSTG', 'OXY', 'SPY'], _top_set_syms: ['FATE', 'BCRX', 'NTLA', 'PERI', 'BPT', 'CPE', 'JWN', 'NOG', 'NSTG', 'OXY']
# grp(retnStd/UI):   mean, std, mean/std:         2.646,         2.547,         1.039
# grp(CAGR/retnStd): mean, std, mean/std:     1,326.407,     3,862.262,         0.343
# grp(CAGR/UI):      mean, std, mean/std:    10,337.458,    30,848.076,         0.335
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         4.126,       177.190,       731.053
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 2.6455799435655534, 2.547403265458704, 1.0385399043167085, 1326.406817409495, 3862.2623776707087, 0.34342742354273653, 10337.45801138343, 30848.076336142374, 0.33510867578059667, 4.125811023764424, 177.19020190406172, 731.0532883188218]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 2.6455799435655534, 2.547403265458704, 1.0385399043167085, 1326.406817409495, 3862.2623776707087, 0.34342742354273653, 10337.45801138343, 30848.076336142374, 0.33510867578059667, 4.125811023764424, 177.19020190406172, 731.0532883188218]
#
# ==================================================
#
# 10 of 400 max_lookback_slice
# max_lookback_slice: (576, 606, 611)
# max lookback dates: 2019-06-18, 2019-07-31, 2019-08-07
# df_eval dates (inclusive): 2019-07-31 - 2019-08-06
# top_set_syms: ['AMKR', 'PERI', 'CSTM', 'FCN', 'NVCR', 'OSTK', 'SSRM', 'ENTG', 'MAT', 'MU']
#
# symbols_eval: ['AMKR', 'PERI', 'CSTM', 'FCN', 'NVCR', 'OSTK', 'SSRM', 'ENTG', 'MAT', 'MU', 'SPY'], _top_set_syms: ['AMKR', 'PERI', 'CSTM', 'FCN', 'NVCR', 'OSTK', 'SSRM', 'ENTG', 'MAT', 'MU']
# grp(retnStd/UI):   mean, std, mean/std:         1.562,         2.864,         0.545
# grp(CAGR/retnStd): mean, std, mean/std:       164.062,       663.486,         0.247
# grp(CAGR/UI):      mean, std, mean/std:     1,979.479,     6,634.832,         0.298
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.683,       -44.958,       -30.691
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.5615210331187002, 2.863944157412194, 0.545234455454488, 164.06247766955732, 663.4864952724562, 0.24727327359117715, 1979.4785922693568, 6634.831848410712, 0.29834645963838785, 0.682669327420898, -44.95777491912315, -30.69129396637792]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.5615210331187002, 2.863944157412194, 0.545234455454488, 164.06247766955732, 663.4864952724562, 0.24727327359117715, 1979.4785922693568, 6634.831848410712, 0.29834645963838785, 0.682669327420898, -44.95777491912315, -30.69129396637792]
#
# ==================================================
#
# 11 of 400 max_lookback_slice
# max_lookback_slice: (194, 224, 229)
# max lookback dates: 2017-12-07, 2018-01-23, 2018-01-30
# df_eval dates (inclusive): 2018-01-23 - 2018-01-29
# top_set_syms: ['STX', 'CORT', 'FLR', 'STLA', 'ARWR', 'ATHM', 'CRSP', 'ARES', 'FATE', 'LOW']
#
# symbols_eval: ['STX', 'CORT', 'FLR', 'STLA', 'ARWR', 'ATHM', 'CRSP', 'ARES', 'FATE', 'LOW', 'SPY'], _top_set_syms: ['STX', 'CORT', 'FLR', 'STLA', 'ARWR', 'ATHM', 'CRSP', 'ARES', 'FATE', 'LOW']
# grp(retnStd/UI):   mean, std, mean/std:         1.920,         0.895,         2.144
# grp(CAGR/retnStd): mean, std, mean/std:     1,082.706,     3,468.385,         0.312
# grp(CAGR/UI):      mean, std, mean/std:     4,448.930,    14,486.714,         0.307
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.550,        36.934,        94.194
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.919963438494226, 0.895318972639829, 2.144446277993255, 1082.7057774643845, 3468.3851549622764, 0.3121642289107769, 4448.929592627419, 14486.713817375485, 0.3071041264921887, 2.5503189951504543, 36.93426397057699, 94.19415497606354]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.919963438494226, 0.895318972639829, 2.144446277993255, 1082.7057774643845, 3468.3851549622764, 0.3121642289107769, 4448.929592627419, 14486.713817375485, 0.3071041264921887, 2.5503189951504543, 36.93426397057699, 94.19415497606354]
#
# ==================================================
#
# 12 of 400 max_lookback_slice
# max_lookback_slice: (887, 917, 922)
# max lookback dates: 2020-09-10, 2020-10-22, 2020-10-29
# df_eval dates (inclusive): 2020-10-22 - 2020-10-28
# top_set_syms: ['GME', 'STAA', 'ACRS', 'CLMT', 'MGI', 'OLN', 'AR', 'ARWR', 'BPMC', 'DQ']
#
# symbols_eval: ['GME', 'STAA', 'ACRS', 'CLMT', 'MGI', 'OLN', 'AR', 'ARWR', 'BPMC', 'DQ', 'SPY'], _top_set_syms: ['GME', 'STAA', 'ACRS', 'CLMT', 'MGI', 'OLN', 'AR', 'ARWR', 'BPMC', 'DQ']
# grp(retnStd/UI):   mean, std, mean/std:         1.043,         0.709,         1.472
# grp(CAGR/retnStd): mean, std, mean/std:       -13.729,        39.877,        -0.344
# grp(CAGR/UI):      mean, std, mean/std:         7.811,        72.771,         0.107
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.600,       -55.779,       -33.488
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.0433041843130655, 0.7086535447008748, 1.4722344820182165, -13.729091662042526, 39.87650246959049, -0.3442902664924594, 7.811081544136656, 72.77080154463694, 0.1073381270830913, 0.6003782989568125, -55.77886557124574, -33.48842042940523]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.0433041843130655, 0.7086535447008748, 1.4722344820182165, -13.729091662042526, 39.87650246959049, -0.3442902664924594, 7.811081544136656, 72.77080154463694, 0.1073381270830913, 0.6003782989568125, -55.77886557124574, -33.48842042940523]
#
# ==================================================
#
# 13 of 400 max_lookback_slice
# max_lookback_slice: (374, 404, 409)
# max lookback dates: 2018-08-27, 2018-10-09, 2018-10-16
# df_eval dates (inclusive): 2018-10-09 - 2018-10-15
# top_set_syms: ['PBR', 'LLY', 'SUN', 'NVAX', 'VST', 'BPT', 'CCJ', 'CCK', 'CI', 'DCI']
#
# symbols_eval: ['PBR', 'LLY', 'SUN', 'NVAX', 'VST', 'BPT', 'CCJ', 'CCK', 'CI', 'DCI', 'SPY'], _top_set_syms: ['PBR', 'LLY', 'SUN', 'NVAX', 'VST', 'BPT', 'CCJ', 'CCK', 'CI', 'DCI']
# grp(retnStd/UI):   mean, std, mean/std:         0.567,         0.270,         2.099
# grp(CAGR/retnStd): mean, std, mean/std:       -52.675,        36.246,        -1.453
# grp(CAGR/UI):      mean, std, mean/std:       -22.944,         4.563,        -5.028
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.518,       -45.216,       -23.403
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 0.5667731469107395, 0.2700433200869974, 2.098823058197283, -52.67474843679225, 36.245783676628776, -1.4532655413588655, -22.943807812988634, 4.563120381947203, -5.028096103657451, 0.5175710422141969, -45.2162842422511, -23.40263936031527]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 0.5667731469107395, 0.2700433200869974, 2.098823058197283, -52.67474843679225, 36.245783676628776, -1.4532655413588655, -22.943807812988634, 4.563120381947203, -5.028096103657451, 0.5175710422141969, -45.2162842422511, -23.40263936031527]
#
# ==================================================
#
# 14 of 400 max_lookback_slice
# max_lookback_slice: (959, 989, 994)
# max lookback dates: 2020-12-22, 2021-02-05, 2021-02-12
# df_eval dates (inclusive): 2021-02-05 - 2021-02-11
# top_set_syms: ['ACRS', 'AVXL', 'NVAX', 'YY', 'HY', 'SSYS', 'BSM', 'IAC', 'IRDM', 'JYNT']
#
# symbols_eval: ['ACRS', 'AVXL', 'NVAX', 'YY', 'HY', 'SSYS', 'BSM', 'IAC', 'IRDM', 'JYNT', 'SPY'], _top_set_syms: ['ACRS', 'AVXL', 'NVAX', 'YY', 'HY', 'SSYS', 'BSM', 'IAC', 'IRDM', 'JYNT']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:   159,265.272,   523,851.441,         0.304
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         6.380,       129.306,       824.925
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 159265.2715053425, 523851.4406709932, 0.304027552737742, inf, nan, nan, 6.379656555558521, 129.30558740574818, 824.9252383634266]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 159265.2715053425, 523851.4406709932, 0.304027552737742, inf, nan, nan, 6.379656555558521, 129.30558740574818, 824.9252383634266]
#
# ==================================================
#
# 15 of 400 max_lookback_slice
# max_lookback_slice: (524, 554, 559)
# max lookback dates: 2019-04-03, 2019-05-16, 2019-05-23
# df_eval dates (inclusive): 2019-05-16 - 2019-05-22
# top_set_syms: ['ENPH', 'PI', 'SBGI', 'TSN', 'AIG', 'AXSM', 'CYRX', 'GOGO', 'TNK', 'FTSM']
#
# symbols_eval: ['ENPH', 'PI', 'SBGI', 'TSN', 'AIG', 'AXSM', 'CYRX', 'GOGO', 'TNK', 'FTSM', 'SPY'], _top_set_syms: ['ENPH', 'PI', 'SBGI', 'TSN', 'AIG', 'AXSM', 'CYRX', 'GOGO', 'TNK', 'FTSM']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:       124.834,       282.855,         0.441
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.986,       -41.322,       -40.725
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 124.8341932450737, 282.8552548759476, 0.44133595219866956, inf, nan, nan, 0.9855397547499467, -41.32249329157012, -40.72495990423033]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 124.8341932450737, 282.8552548759476, 0.44133595219866956, inf, nan, nan, 0.9855397547499467, -41.32249329157012, -40.72495990423033]
#
# ==================================================
#
# 16 of 400 max_lookback_slice
# max_lookback_slice: (809, 839, 844)
# max lookback dates: 2020-05-20, 2020-07-02, 2020-07-10
# df_eval dates (inclusive): 2020-07-02 - 2020-07-09
# top_set_syms: ['APPS', 'SQ', 'STAA', 'TRUP', 'CYRX', 'ETSY', 'MED', 'PLUG', 'VSTO', 'OSTK']
#
# symbols_eval: ['APPS', 'SQ', 'STAA', 'TRUP', 'CYRX', 'ETSY', 'MED', 'PLUG', 'VSTO', 'OSTK', 'SPY'], _top_set_syms: ['APPS', 'SQ', 'STAA', 'TRUP', 'CYRX', 'ETSY', 'MED', 'PLUG', 'VSTO', 'OSTK']
# grp(retnStd/UI):   mean, std, mean/std:         2.597,         1.621,         1.602
# grp(CAGR/retnStd): mean, std, mean/std: 3,561,791.948, 11,806,714.113,         0.302
# grp(CAGR/UI):      mean, std, mean/std: 18,762,025.603, 62,205,518.718,         0.302
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.953,        34.796,        67.963
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 2.5969414718219466, 1.6212398647273112, 1.6018243372387997, 3561791.947830157, 11806714.11334064, 0.30167512430961785, 18762025.60263394, 62205518.717987366, 0.301613522229318, 1.9532167474059257, 34.795673317328315, 67.96349186067117]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 2.5969414718219466, 1.6212398647273112, 1.6018243372387997, 3561791.947830157, 11806714.11334064, 0.30167512430961785, 18762025.60263394, 62205518.717987366, 0.301613522229318, 1.9532167474059257, 34.795673317328315, 67.96349186067117]
#
# ==================================================
#
# 17 of 400 max_lookback_slice
# max_lookback_slice: (645, 675, 680)
# max lookback dates: 2019-09-25, 2019-11-06, 2019-11-13
# df_eval dates (inclusive): 2019-11-06 - 2019-11-12
# top_set_syms: ['ISEE', 'BGNE', 'LEG', 'SGEN', 'UCTT', 'UFPI', 'ALGN', 'AMKR', 'CC', 'MHK']
#
# symbols_eval: ['ISEE', 'BGNE', 'LEG', 'SGEN', 'UCTT', 'UFPI', 'ALGN', 'AMKR', 'CC', 'MHK', 'SPY'], _top_set_syms: ['ISEE', 'BGNE', 'LEG', 'SGEN', 'UCTT', 'UFPI', 'ALGN', 'AMKR', 'CC', 'MHK']
# grp(retnStd/UI):   mean, std, mean/std:         1.640,         1.185,         1.384
# grp(CAGR/retnStd): mean, std, mean/std:        63.851,       137.783,         0.463
# grp(CAGR/UI):      mean, std, mean/std:       247.744,       533.248,         0.465
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.786,       153.199,       426.817
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.639934886159906, 1.1850072435235772, 1.3839028369848756, 63.850777570404574, 137.7825075534746, 0.4634171543555594, 247.74395967899883, 533.2483096653503, 0.46459398968273347, 2.7860413594058984, 153.19854665247263, 426.81748717466274]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.639934886159906, 1.1850072435235772, 1.3839028369848756, 63.850777570404574, 137.7825075534746, 0.4634171543555594, 247.74395967899883, 533.2483096653503, 0.46459398968273347, 2.7860413594058984, 153.19854665247263, 426.81748717466274]
#
# ==================================================
#
# 18 of 400 max_lookback_slice
# max_lookback_slice: (358, 388, 393)
# max lookback dates: 2018-08-03, 2018-09-17, 2018-09-24
# df_eval dates (inclusive): 2018-09-17 - 2018-09-21
# top_set_syms: ['MCFT', 'SWBI', 'AMD', 'SEAS', 'DCI', 'GKOS', 'BRC', 'EXAS', 'NVCR', 'PCTY']
#
# symbols_eval: ['MCFT', 'SWBI', 'AMD', 'SEAS', 'DCI', 'GKOS', 'BRC', 'EXAS', 'NVCR', 'PCTY', 'SPY'], _top_set_syms: ['MCFT', 'SWBI', 'AMD', 'SEAS', 'DCI', 'GKOS', 'BRC', 'EXAS', 'NVCR', 'PCTY']
# grp(retnStd/UI):   mean, std, mean/std:         2.412,         2.733,         0.882
# grp(CAGR/retnStd): mean, std, mean/std:        83.538,       179.287,         0.466
# grp(CAGR/UI):      mean, std, mean/std:       454.920,       847.948,         0.536
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:        10.019,       241.319,     2,417.832
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 2.4121523208212454, 2.7334002513849383, 0.8824731466235414, 83.53789044896922, 179.28722259809828, 0.46594447299924496, 454.92005881176624, 847.9475150747128, 0.5364955386085224, 10.019254724790555, 241.31858903237674, 2417.8324133424303]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 2.4121523208212454, 2.7334002513849383, 0.8824731466235414, 83.53789044896922, 179.28722259809828, 0.46594447299924496, 454.92005881176624, 847.9475150747128, 0.5364955386085224, 10.019254724790555, 241.31858903237674, 2417.8324133424303]
#
# ==================================================
#
# 19 of 400 max_lookback_slice
# max_lookback_slice: (516, 546, 551)
# max lookback dates: 2019-03-22, 2019-05-06, 2019-05-13
# df_eval dates (inclusive): 2019-05-06 - 2019-05-10
# top_set_syms: ['PI', 'QCOM', 'AZTA', 'ENPH', 'HAS', 'MGI', 'PPC', 'SMG', 'CYRX', 'F']
#
# symbols_eval: ['PI', 'QCOM', 'AZTA', 'ENPH', 'HAS', 'MGI', 'PPC', 'SMG', 'CYRX', 'F', 'SPY'], _top_set_syms: ['PI', 'QCOM', 'AZTA', 'ENPH', 'HAS', 'MGI', 'PPC', 'SMG', 'CYRX', 'F']
# grp(retnStd/UI):   mean, std, mean/std:         0.916,         0.415,         2.205
# grp(CAGR/retnStd): mean, std, mean/std:       -20.140,        34.874,        -0.578
# grp(CAGR/UI):      mean, std, mean/std:        -7.905,        31.299,        -0.253
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.565,       -61.193,       -34.575
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 0.915958902594927, 0.4154730858149852, 2.204616698090556, -20.139855623396244, 34.87394726966223, -0.5775043320351761, -7.9050075091994385, 31.298811703216938, -0.2525657390496697, 0.565016489787887, -61.19292999496037, -34.575014505588406]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 0.915958902594927, 0.4154730858149852, 2.204616698090556, -20.139855623396244, 34.87394726966223, -0.5775043320351761, -7.9050075091994385, 31.298811703216938, -0.2525657390496697, 0.565016489787887, -61.19292999496037, -34.575014505588406]
#
# ==================================================
#
# 20 of 400 max_lookback_slice
# max_lookback_slice: (465, 495, 500)
# max lookback dates: 2019-01-08, 2019-02-21, 2019-02-28
# df_eval dates (inclusive): 2019-02-21 - 2019-02-27
# top_set_syms: ['LSCC', 'PCTY', 'RUN', 'CTLT', 'BWXT', 'GRMN', 'NYT', 'PGR', 'VECO', 'XRX']
#
# symbols_eval: ['LSCC', 'PCTY', 'RUN', 'CTLT', 'BWXT', 'GRMN', 'NYT', 'PGR', 'VECO', 'XRX', 'SPY'], _top_set_syms: ['LSCC', 'PCTY', 'RUN', 'CTLT', 'BWXT', 'GRMN', 'NYT', 'PGR', 'VECO', 'XRX']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:       150.491,       202.924,         0.742
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         5.298,       118.897,       629.859
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 150.4906226903885, 202.9239921887495, 0.7416107926282558, inf, nan, nan, 5.297515741589351, 118.8970607315339, 629.8590508540059]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 150.4906226903885, 202.9239921887495, 0.7416107926282558, inf, nan, nan, 5.297515741589351, 118.8970607315339, 629.8590508540059]
#
# ==================================================
#
# 21 of 400 max_lookback_slice
# max_lookback_slice: (247, 277, 282)
# max lookback dates: 2018-02-26, 2018-04-10, 2018-04-17
# df_eval dates (inclusive): 2018-04-10 - 2018-04-16
# top_set_syms: ['CATO', 'CTRN', 'CVLT', 'DINO', 'GES', 'MOV', 'TNDM', 'ANF', 'BLFS', 'JYNT']
#
# symbols_eval: ['CATO', 'CTRN', 'CVLT', 'DINO', 'GES', 'MOV', 'TNDM', 'ANF', 'BLFS', 'JYNT', 'SPY'], _top_set_syms: ['CATO', 'CTRN', 'CVLT', 'DINO', 'GES', 'MOV', 'TNDM', 'ANF', 'BLFS', 'JYNT']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:       283.623,       454.006,         0.625
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.669,        71.246,       190.175
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 283.6230580122959, 454.00582073652566, 0.6247123826566348, inf, nan, nan, 2.6692652483876977, 71.24620148805995, 190.1750097117063]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 283.6230580122959, 454.00582073652566, 0.6247123826566348, inf, nan, nan, 2.6692652483876977, 71.24620148805995, 190.1750097117063]
#
# ==================================================
#
# 22 of 400 max_lookback_slice
# max_lookback_slice: (393, 423, 428)
# max lookback dates: 2018-09-24, 2018-11-05, 2018-11-12
# df_eval dates (inclusive): 2018-11-05 - 2018-11-09
# top_set_syms: ['LOCO', 'KDP', 'LRN', 'PLCE', 'ACHC', 'DECK', 'ENSG', 'QNST', 'SBUX', 'CBRL']
#
# symbols_eval: ['LOCO', 'KDP', 'LRN', 'PLCE', 'ACHC', 'DECK', 'ENSG', 'QNST', 'SBUX', 'CBRL', 'SPY'], _top_set_syms: ['LOCO', 'KDP', 'LRN', 'PLCE', 'ACHC', 'DECK', 'ENSG', 'QNST', 'SBUX', 'CBRL']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:       595.106,       763.835,         0.779
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.543,        91.917,       233.763
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 595.1061388881989, 763.8345173913978, 0.7791034907934902, inf, nan, nan, 2.543193648491081, 91.91716372529241, 233.76314697347843]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 595.1061388881989, 763.8345173913978, 0.7791034907934902, inf, nan, nan, 2.543193648491081, 91.91716372529241, 233.76314697347843]
#
# ==================================================
#
# 23 of 400 max_lookback_slice
# max_lookback_slice: (225, 255, 260)
# max lookback dates: 2018-01-24, 2018-03-08, 2018-03-15
# df_eval dates (inclusive): 2018-03-08 - 2018-03-14
# top_set_syms: ['AXON', 'ETSY', 'BL', 'ENPH', 'TWLO', 'COUP', 'FATE', 'VCEL', 'VEEV', 'CHGG']
#
# symbols_eval: ['AXON', 'ETSY', 'BL', 'ENPH', 'TWLO', 'COUP', 'FATE', 'VCEL', 'VEEV', 'CHGG', 'SPY'], _top_set_syms: ['AXON', 'ETSY', 'BL', 'ENPH', 'TWLO', 'COUP', 'FATE', 'VCEL', 'VEEV', 'CHGG']
# grp(retnStd/UI):   mean, std, mean/std:        17.136,        51.982,         0.330
# grp(CAGR/retnStd): mean, std, mean/std:       933.272,     2,630.000,         0.355
# grp(CAGR/UI):      mean, std, mean/std:    25,439.676,    71,508.525,         0.356
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.650,        22.256,        36.721
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 17.136400781904115, 51.981545267826476, 0.3296631659103551, 933.2719643284679, 2630.0003417766275, 0.3548562140862767, 25439.67556089333, 71508.52535617755, 0.3557572392128154, 1.6499095902451986, 22.25619139275215, 36.72070362123442]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 17.136400781904115, 51.981545267826476, 0.3296631659103551, 933.2719643284679, 2630.0003417766275, 0.3548562140862767, 25439.67556089333, 71508.52535617755, 0.3557572392128154, 1.6499095902451986, 22.25619139275215, 36.72070362123442]
#
# ==================================================
#
# 24 of 400 max_lookback_slice
# max_lookback_slice: (956, 986, 991)
# max lookback dates: 2020-12-17, 2021-02-02, 2021-02-09
# df_eval dates (inclusive): 2021-02-02 - 2021-02-08
# top_set_syms: ['ACRS', 'GME', 'HY', 'NVAX', 'PLCE', 'SSYS', 'DDS', 'SGRY', 'SPWR', 'STKL']
#
# symbols_eval: ['ACRS', 'GME', 'HY', 'NVAX', 'PLCE', 'SSYS', 'DDS', 'SGRY', 'SPWR', 'STKL', 'SPY'], _top_set_syms: ['ACRS', 'GME', 'HY', 'NVAX', 'PLCE', 'SSYS', 'DDS', 'SGRY', 'SPWR', 'STKL']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:    35,279.251,    89,697.228,         0.393
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:           inf,       490.236,           inf
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 35279.251427611984, 89697.2284365828, 0.3933148441989477, inf, nan, nan, inf, 490.2359031414973, inf]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 35279.251427611984, 89697.2284365828, 0.3933148441989477, inf, nan, nan, inf, 490.2359031414973, inf]
#
# ==================================================
#
# 25 of 400 max_lookback_slice
# max_lookback_slice: (195, 225, 230)
# max lookback dates: 2017-12-08, 2018-01-24, 2018-01-31
# df_eval dates (inclusive): 2018-01-24 - 2018-01-30
# top_set_syms: ['STX', 'ARES', 'CORT', 'FLR', 'STLA', 'ARWR', 'COLL', 'CRSP', 'FATE', 'NFLX']
#
# symbols_eval: ['STX', 'ARES', 'CORT', 'FLR', 'STLA', 'ARWR', 'COLL', 'CRSP', 'FATE', 'NFLX', 'SPY'], _top_set_syms: ['STX', 'ARES', 'CORT', 'FLR', 'STLA', 'ARWR', 'COLL', 'CRSP', 'FATE', 'NFLX']
# grp(retnStd/UI):   mean, std, mean/std:         4.449,         6.709,         0.663
# grp(CAGR/retnStd): mean, std, mean/std:     1,525.613,     3,910.042,         0.390
# grp(CAGR/UI):      mean, std, mean/std:    25,423.579,    79,241.474,         0.321
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.189,       -23.274,       -27.682
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 4.449089964161718, 6.708922071313254, 0.6631601793655684, 1525.6134804924382, 3910.042001134817, 0.3901782845426359, 25423.578615169445, 79241.4735944336, 0.3208367722348282, 1.1894113034142755, -23.2740133445709, -27.682374547847317]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 4.449089964161718, 6.708922071313254, 0.6631601793655684, 1525.6134804924382, 3910.042001134817, 0.3901782845426359, 25423.578615169445, 79241.4735944336, 0.3208367722348282, 1.1894113034142755, -23.2740133445709, -27.682374547847317]
#
# ==================================================
#
# 26 of 400 max_lookback_slice
# max_lookback_slice: (67, 97, 102)
# max lookback dates: 2017-06-08, 2017-07-21, 2017-07-28
# df_eval dates (inclusive): 2017-07-21 - 2017-07-27
# top_set_syms: ['BGNE', 'NVAX', 'OEC', 'FOLD', 'NRG', 'CAR', 'QURE', 'ASML', 'CC', 'CM']
#
# symbols_eval: ['BGNE', 'NVAX', 'OEC', 'FOLD', 'NRG', 'CAR', 'QURE', 'ASML', 'CC', 'CM', 'SPY'], _top_set_syms: ['BGNE', 'NVAX', 'OEC', 'FOLD', 'NRG', 'CAR', 'QURE', 'ASML', 'CC', 'CM']
# grp(retnStd/UI):   mean, std, mean/std:         1.527,         0.974,         1.567
# grp(CAGR/retnStd): mean, std, mean/std:        32.936,       133.289,         0.247
# grp(CAGR/UI):      mean, std, mean/std:       122.415,       320.867,         0.382
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         3.402,        46.142,       156.974
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.5267048471770372, 0.9743403859014445, 1.5669111834716303, 32.936360068503696, 133.28862224807813, 0.2471055631980516, 122.41467645671965, 320.86678180098494, 0.3815124637384445, 3.401992331815888, 46.14188845889645, 156.97435071266975]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.5267048471770372, 0.9743403859014445, 1.5669111834716303, 32.936360068503696, 133.28862224807813, 0.2471055631980516, 122.41467645671965, 320.86678180098494, 0.3815124637384445, 3.401992331815888, 46.14188845889645, 156.97435071266975]
#
# ==================================================
#
# 27 of 400 max_lookback_slice
# max_lookback_slice: (116, 146, 151)
# max lookback dates: 2017-08-17, 2017-09-29, 2017-10-06
# df_eval dates (inclusive): 2017-09-29 - 2017-10-05
# top_set_syms: ['HALO', 'PTEN', 'QNST', 'RCKT', 'ANF', 'ARWR', 'BPMC', 'CVE', 'NEX', 'OSBC']
#
# symbols_eval: ['HALO', 'PTEN', 'QNST', 'RCKT', 'ANF', 'ARWR', 'BPMC', 'CVE', 'NEX', 'OSBC', 'SPY'], _top_set_syms: ['HALO', 'PTEN', 'QNST', 'RCKT', 'ANF', 'ARWR', 'BPMC', 'CVE', 'NEX', 'OSBC']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std: 180,095,970,150.256, 597,310,758,006.667,         0.302
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:           inf,       458.195,           inf
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 180095970150.25592, 597310758006.667, 0.3015113452020661, inf, nan, nan, inf, 458.19517809836645, inf]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 180095970150.25592, 597310758006.667, 0.3015113452020661, inf, nan, nan, inf, 458.19517809836645, inf]
#
# ==================================================
#
# 28 of 400 max_lookback_slice
# max_lookback_slice: (434, 464, 469)
# max lookback dates: 2018-11-20, 2019-01-07, 2019-01-14
# df_eval dates (inclusive): 2019-01-07 - 2019-01-11
# top_set_syms: ['OR', 'PKE', 'SBS', 'WPM', 'ATSG', 'MTLS', 'PTMN', 'GME', 'ABM', 'AU']
#
# symbols_eval: ['OR', 'PKE', 'SBS', 'WPM', 'ATSG', 'MTLS', 'PTMN', 'GME', 'ABM', 'AU', 'SPY'], _top_set_syms: ['OR', 'PKE', 'SBS', 'WPM', 'ATSG', 'MTLS', 'PTMN', 'GME', 'ABM', 'AU']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:       363.336,       874.354,         0.416
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:           inf,       392.873,           inf
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 363.33647432779077, 874.3539873756465, 0.4155484844511739, inf, nan, nan, inf, 392.8730889209687, inf]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 363.33647432779077, 874.3539873756465, 0.4155484844511739, inf, nan, nan, inf, 392.8730889209687, inf]
#
# ==================================================
#
# 29 of 400 max_lookback_slice
# max_lookback_slice: (711, 741, 746)
# max lookback dates: 2019-12-30, 2020-02-12, 2020-02-20
# df_eval dates (inclusive): 2020-02-12 - 2020-02-19
# top_set_syms: ['RNG', 'AGYS', 'CCS', 'PCG', 'AJG', 'AVXL', 'BRO', 'ENPH', 'KDNY', 'RUN']
#
# symbols_eval: ['RNG', 'AGYS', 'CCS', 'PCG', 'AJG', 'AVXL', 'BRO', 'ENPH', 'KDNY', 'RUN', 'SPY'], _top_set_syms: ['RNG', 'AGYS', 'CCS', 'PCG', 'AJG', 'AVXL', 'BRO', 'ENPH', 'KDNY', 'RUN']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std: 4,518,467.838, 14,851,259.602,         0.304
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.591,        45.517,       117.923
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 4518467.838460416, 14851259.60166404, 0.30424812168485255, inf, nan, nan, 2.5907570524700474, 45.516699346063575, 117.922709835973]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 4518467.838460416, 14851259.60166404, 0.30424812168485255, inf, nan, nan, 2.5907570524700474, 45.516699346063575, 117.922709835973]
#
# ==================================================
#
# 30 of 400 max_lookback_slice
# max_lookback_slice: (75, 105, 110)
# max lookback dates: 2017-06-20, 2017-08-02, 2017-08-09
# df_eval dates (inclusive): 2017-08-02 - 2017-08-08
# top_set_syms: ['TECK', 'BIDU', 'DDS', 'AVA', 'AX', 'BA', 'CYRX', 'FSLR', 'HAIN', 'HTHT']
#
# symbols_eval: ['TECK', 'BIDU', 'DDS', 'AVA', 'AX', 'BA', 'CYRX', 'FSLR', 'HAIN', 'HTHT', 'SPY'], _top_set_syms: ['TECK', 'BIDU', 'DDS', 'AVA', 'AX', 'BA', 'CYRX', 'FSLR', 'HAIN', 'HTHT']
# grp(retnStd/UI):   mean, std, mean/std:         4.610,         6.496,         0.710
# grp(CAGR/retnStd): mean, std, mean/std:       197.687,       394.514,         0.501
# grp(CAGR/UI):      mean, std, mean/std:     3,109.218,     8,990.441,         0.346
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.671,       -15.373,       -25.682
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 4.609537869383268, 6.496325473095613, 0.709560795325537, 197.6872253878343, 394.5136113326737, 0.5010910136155847, 3109.218056846672, 8990.440753754667, 0.3458359987020851, 1.6705526790959155, -15.373413488815416, -25.682097090589878]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 4.609537869383268, 6.496325473095613, 0.709560795325537, 197.6872253878343, 394.5136113326737, 0.5010910136155847, 3109.218056846672, 8990.440753754667, 0.3458359987020851, 1.6705526790959155, -15.373413488815416, -25.682097090589878]
#
# ==================================================
#
# 31 of 400 max_lookback_slice
# max_lookback_slice: (377, 407, 412)
# max lookback dates: 2018-08-30, 2018-10-12, 2018-10-19
# df_eval dates (inclusive): 2018-10-12 - 2018-10-18
# top_set_syms: ['FTSM', 'PBR', 'SBS', 'SUN', 'AU', 'BPT', 'GOLD', 'NG', 'NVAX', 'PZZA']
#
# symbols_eval: ['FTSM', 'PBR', 'SBS', 'SUN', 'AU', 'BPT', 'GOLD', 'NG', 'NVAX', 'PZZA', 'SPY'], _top_set_syms: ['FTSM', 'PBR', 'SBS', 'SUN', 'AU', 'BPT', 'GOLD', 'NG', 'NVAX', 'PZZA']
# grp(retnStd/UI):   mean, std, mean/std:         3.119,         4.159,         0.750
# grp(CAGR/retnStd): mean, std, mean/std:        93.603,       254.264,         0.368
# grp(CAGR/UI):      mean, std, mean/std:     1,249.862,     4,028.406,         0.310
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.231,         5.534,        12.349
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 3.1193166422775205, 4.159454600507194, 0.7499340519060259, 93.60259108061827, 254.2638687268858, 0.3681317032942666, 1249.8624658205663, 4028.4057776794834, 0.31026230593397053, 2.2313462074481625, 5.5344955005560275, 12.34937554530461]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 3.1193166422775205, 4.159454600507194, 0.7499340519060259, 93.60259108061827, 254.2638687268858, 0.3681317032942666, 1249.8624658205663, 4028.4057776794834, 0.31026230593397053, 2.2313462074481625, 5.5344955005560275, 12.34937554530461]
#
# ==================================================
#
# 32 of 400 max_lookback_slice
# max_lookback_slice: (1005, 1035, 1040)
# max lookback dates: 2021-03-02, 2021-04-14, 2021-04-21
# df_eval dates (inclusive): 2021-04-14 - 2021-04-20
# top_set_syms: ['CARA', 'WCN', 'LPX', 'MOV', 'ANF', 'AZO', 'FCN', 'GMED', 'MRCY', 'NOMD']
#
# symbols_eval: ['CARA', 'WCN', 'LPX', 'MOV', 'ANF', 'AZO', 'FCN', 'GMED', 'MRCY', 'NOMD', 'SPY'], _top_set_syms: ['CARA', 'WCN', 'LPX', 'MOV', 'ANF', 'AZO', 'FCN', 'GMED', 'MRCY', 'NOMD']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:       157.993,       402.095,         0.393
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.400,        11.186,        15.663
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 157.99323418313625, 402.09457165106494, 0.39292555861769196, inf, nan, nan, 1.4002649572102182, 11.185687445162802, 15.662926151767767]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 157.99323418313625, 402.09457165106494, 0.39292555861769196, inf, nan, nan, 1.4002649572102182, 11.185687445162802, 15.662926151767767]
#
# ==================================================
#
# 33 of 400 max_lookback_slice
# max_lookback_slice: (677, 707, 712)
# max lookback dates: 2019-11-08, 2019-12-23, 2019-12-31
# df_eval dates (inclusive): 2019-12-23 - 2019-12-30
# top_set_syms: ['AXSM', 'ISEE', 'LLY', 'AIR', 'ATCO', 'BMA', 'DAR', 'FATE', 'MRK', 'NSP']
#
# symbols_eval: ['AXSM', 'ISEE', 'LLY', 'AIR', 'ATCO', 'BMA', 'DAR', 'FATE', 'MRK', 'NSP', 'SPY'], _top_set_syms: ['AXSM', 'ISEE', 'LLY', 'AIR', 'ATCO', 'BMA', 'DAR', 'FATE', 'MRK', 'NSP']
# grp(retnStd/UI):   mean, std, mean/std:         1.389,         1.023,         1.358
# grp(CAGR/retnStd): mean, std, mean/std:        -1.301,       123.377,        -0.011
# grp(CAGR/UI):      mean, std, mean/std:        61.426,       182.387,         0.337
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.717,        -4.910,        -8.429
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.3893593280161982, 1.0230767934096683, 1.3580205679241326, -1.3010110463718763, 123.37740111437375, -0.010544970429112933, 61.42618955684085, 182.3870133000645, 0.3367903692560721, 1.7165605124144283, -4.910482595781642, -8.429140520817068]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.3893593280161982, 1.0230767934096683, 1.3580205679241326, -1.3010110463718763, 123.37740111437375, -0.010544970429112933, 61.42618955684085, 182.3870133000645, 0.3367903692560721, 1.7165605124144283, -4.910482595781642, -8.429140520817068]
#
# ==================================================
#
# 34 of 400 max_lookback_slice
# max_lookback_slice: (33, 63, 68)
# max lookback dates: 2017-04-20, 2017-06-02, 2017-06-09
# df_eval dates (inclusive): 2017-06-02 - 2017-06-08
# top_set_syms: ['G', 'BRKR', 'TRUP', 'TTD', 'ATHM', 'CHGG', 'IAC', 'NEE', 'PETS', 'PM']
#
# symbols_eval: ['G', 'BRKR', 'TRUP', 'TTD', 'ATHM', 'CHGG', 'IAC', 'NEE', 'PETS', 'PM', 'SPY'], _top_set_syms: ['G', 'BRKR', 'TRUP', 'TTD', 'ATHM', 'CHGG', 'IAC', 'NEE', 'PETS', 'PM']
# grp(retnStd/UI):   mean, std, mean/std:         1.564,         0.927,         1.688
# grp(CAGR/retnStd): mean, std, mean/std:        59.581,       174.209,         0.342
# grp(CAGR/UI):      mean, std, mean/std:       234.846,       511.345,         0.459
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.002,       -36.096,       -36.158
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.5635786437600396, 0.9265525985757135, 1.687522808919381, 59.58079016268178, 174.20945535150085, 0.3420066381728027, 234.8456649386625, 511.3449885849089, 0.4592704928791267, 1.001730591790048, -36.09582999809562, -36.1582971451453]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.5635786437600396, 0.9265525985757135, 1.687522808919381, 59.58079016268178, 174.20945535150085, 0.3420066381728027, 234.8456649386625, 511.3449885849089, 0.4592704928791267, 1.001730591790048, -36.09582999809562, -36.1582971451453]
#
# ==================================================
#
# 35 of 400 max_lookback_slice
# max_lookback_slice: (11, 41, 46)
# max lookback dates: 2017-03-20, 2017-05-02, 2017-05-09
# df_eval dates (inclusive): 2017-05-02 - 2017-05-08
# top_set_syms: ['EXAS', 'IRBT', 'PAR', 'PTCT', 'AXGN', 'CNMD', 'EVBG', 'EVRI', 'IAC', 'ISRG']
#
# symbols_eval: ['EXAS', 'IRBT', 'PAR', 'PTCT', 'AXGN', 'CNMD', 'EVBG', 'EVRI', 'IAC', 'ISRG', 'SPY'], _top_set_syms: ['EXAS', 'IRBT', 'PAR', 'PTCT', 'AXGN', 'CNMD', 'EVBG', 'EVRI', 'IAC', 'ISRG']
# grp(retnStd/UI):   mean, std, mean/std:         3.143,         3.730,         0.843
# grp(CAGR/retnStd): mean, std, mean/std:       321.123,       858.818,         0.374
# grp(CAGR/UI):      mean, std, mean/std:     1,852.745,     4,029.946,         0.460
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         4.063,        92.524,       375.926
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 3.1434740265201437, 3.7302038355287674, 0.8427083787163998, 321.12268504818326, 858.8182380794276, 0.3739122794670836, 1852.7446104920828, 4029.9463878289403, 0.4597442328482724, 4.062997666748587, 92.52432112926772, 375.92610086571176]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 3.1434740265201437, 3.7302038355287674, 0.8427083787163998, 321.12268504818326, 858.8182380794276, 0.3739122794670836, 1852.7446104920828, 4029.9463878289403, 0.4597442328482724, 4.062997666748587, 92.52432112926772, 375.92610086571176]
#
# ==================================================
#
# 36 of 400 max_lookback_slice
# max_lookback_slice: (630, 660, 665)
# max lookback dates: 2019-09-04, 2019-10-16, 2019-10-23
# df_eval dates (inclusive): 2019-10-16 - 2019-10-22
# top_set_syms: ['EURN', 'STRL', 'TNK', 'ASC', 'BBW', 'CROX', 'TSM', 'STNG', 'DDS', 'HIBB']
#
# ...
# max lookback dates: 2018-07-30, 2018-09-11, 2018-09-18
# df_eval dates (inclusive): 2018-09-11 - 2018-09-17
# top_set_syms: ['MCFT', 'SEAS', 'SWBI', 'AMD', 'SFM', 'STAA', 'TNDM', 'XENE', 'ARWR', 'DXCM']
#
# symbols_eval: ['MCFT', 'SEAS', 'SWBI', 'AMD', 'SFM', 'STAA', 'TNDM', 'XENE', 'ARWR', 'DXCM', 'SPY'], _top_set_syms: ['MCFT', 'SEAS', 'SWBI', 'AMD', 'SFM', 'STAA', 'TNDM', 'XENE', 'ARWR', 'DXCM']
# grp(retnStd/UI):   mean, std, mean/std:         1.400,         1.032,         1.356
# grp(CAGR/retnStd): mean, std, mean/std:        95.437,       267.171,         0.357
# grp(CAGR/UI):      mean, std, mean/std:       350.985,       823.017,         0.426
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.933,        11.325,        21.889
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.4000793766386819, 1.0323735631118993, 1.3561751546779262, 95.43680072513938, 267.17075101906926, 0.35721275761330473, 350.9846441698141, 823.0174298157776, 0.4264607667523854, 1.932844842294337, 11.325005525537685, 21.889478518990384]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.4000793766386819, 1.0323735631118993, 1.3561751546779262, 95.43680072513938, 267.17075101906926, 0.35721275761330473, 350.9846441698141, 823.0174298157776, 0.4264607667523854, 1.932844842294337, 11.325005525537685, 21.889478518990384]
#
# ==================================================
#
# 390 of 400 max_lookback_slice
# max_lookback_slice: (405, 435, 440)
# max lookback dates: 2018-10-10, 2018-11-21, 2018-11-29
# df_eval dates (inclusive): 2018-11-21 - 2018-11-28
# top_set_syms: ['SBUX', 'CBRL', 'APPS', 'LOCO', 'BCRX', 'BKH', 'CROX', 'DORM', 'HELE', 'HRL']
#
# symbols_eval: ['SBUX', 'CBRL', 'APPS', 'LOCO', 'BCRX', 'BKH', 'CROX', 'DORM', 'HELE', 'HRL', 'SPY'], _top_set_syms: ['SBUX', 'CBRL', 'APPS', 'LOCO', 'BCRX', 'BKH', 'CROX', 'DORM', 'HELE', 'HRL']
# grp(retnStd/UI):   mean, std, mean/std:         5.596,         8.817,         0.635
# grp(CAGR/retnStd): mean, std, mean/std:       487.285,       692.754,         0.703
# grp(CAGR/UI):      mean, std, mean/std:     7,955.848,    22,476.694,         0.354
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         4.430,       375.262,     1,662.573
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 5.5956568347045845, 8.817417752020319, 0.6346140096880929, 487.28466506886326, 692.7537302441024, 0.7034024412934753, 7955.8475096390475, 22476.694468572794, 0.35395985476258607, 4.430430903066749, 375.262146621443, 1662.5730111428063]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 5.5956568347045845, 8.817417752020319, 0.6346140096880929, 487.28466506886326, 692.7537302441024, 0.7034024412934753, 7955.8475096390475, 22476.694468572794, 0.35395985476258607, 4.430430903066749, 375.262146621443, 1662.5730111428063]
#
# ==================================================
#
# 391 of 400 max_lookback_slice
# max_lookback_slice: (449, 479, 484)
# max lookback dates: 2018-12-13, 2019-01-29, 2019-02-05
# df_eval dates (inclusive): 2019-01-29 - 2019-02-04
# top_set_syms: ['OZK', 'ATSG', 'AXSM', 'BOOT', 'DQ', 'EDU', 'HEES', 'LGIH', 'LRN', 'NVCR']
#
# symbols_eval: ['OZK', 'ATSG', 'AXSM', 'BOOT', 'DQ', 'EDU', 'HEES', 'LGIH', 'LRN', 'NVCR', 'SPY'], _top_set_syms: ['OZK', 'ATSG', 'AXSM', 'BOOT', 'DQ', 'EDU', 'HEES', 'LGIH', 'LRN', 'NVCR']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:    55,555.421,   182,481.764,         0.304
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:           inf,       634.471,           inf
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 55555.421240946715, 182481.76425084818, 0.3044436876694022, inf, nan, nan, inf, 634.4714053546562, inf]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 55555.421240946715, 182481.76425084818, 0.3044436876694022, inf, nan, nan, inf, 634.4714053546562, inf]
#
# ==================================================
#
# 392 of 400 max_lookback_slice
# max_lookback_slice: (438, 468, 473)
# max lookback dates: 2018-11-27, 2019-01-11, 2019-01-18
# df_eval dates (inclusive): 2019-01-11 - 2019-01-17
# top_set_syms: ['AXSM', 'PKE', 'SBS', 'MAG', 'ATSG', 'AMX', 'AU', 'GPRK', 'LGIH', 'LSCC']
#
# symbols_eval: ['AXSM', 'PKE', 'SBS', 'MAG', 'ATSG', 'AMX', 'AU', 'GPRK', 'LGIH', 'LSCC', 'SPY'], _top_set_syms: ['AXSM', 'PKE', 'SBS', 'MAG', 'ATSG', 'AMX', 'AU', 'GPRK', 'LGIH', 'LSCC']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:     3,625.080,    11,910.592,         0.304
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.783,       152.364,       424.018
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 3625.080034823368, 11910.592084661546, 0.30435766828852645, inf, nan, nan, 2.782921424269155, 152.3642617228029, 424.0177682413409]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 3625.080034823368, 11910.592084661546, 0.30435766828852645, inf, nan, nan, 2.782921424269155, 152.3642617228029, 424.0177682413409]
#
# ==================================================
#
# 393 of 400 max_lookback_slice
# max_lookback_slice: (214, 244, 249)
# max lookback dates: 2018-01-08, 2018-02-21, 2018-02-28
# df_eval dates (inclusive): 2018-02-21 - 2018-02-27
# top_set_syms: ['MTCH', 'QNST', 'VIRT', 'NVAX', 'VSTO', 'XENE', 'QURE', 'RNG', 'APPS', 'BL']
#
# symbols_eval: ['MTCH', 'QNST', 'VIRT', 'NVAX', 'VSTO', 'XENE', 'QURE', 'RNG', 'APPS', 'BL', 'SPY'], _top_set_syms: ['MTCH', 'QNST', 'VIRT', 'NVAX', 'VSTO', 'XENE', 'QURE', 'RNG', 'APPS', 'BL']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:       159.761,       436.846,         0.366
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.264,        98.857,       223.829
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 159.76064719287453, 436.8464829062695, 0.3657134793211853, inf, nan, nan, 2.2641772392402064, 98.85651490373156, 223.8286709956393]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 159.76064719287453, 436.8464829062695, 0.3657134793211853, inf, nan, nan, 2.2641772392402064, 98.85651490373156, 223.8286709956393]
#
# ==================================================
#
# 394 of 400 max_lookback_slice
# max_lookback_slice: (319, 349, 354)
# max lookback dates: 2018-06-08, 2018-07-23, 2018-07-30
# df_eval dates (inclusive): 2018-07-23 - 2018-07-27
# top_set_syms: ['RAMP', 'BLFS', 'KDP', 'MELI', 'NTRA', 'TRUP', 'ARWR', 'FAST', 'GDEN', 'GTLS']
#
# symbols_eval: ['RAMP', 'BLFS', 'KDP', 'MELI', 'NTRA', 'TRUP', 'ARWR', 'FAST', 'GDEN', 'GTLS', 'SPY'], _top_set_syms: ['RAMP', 'BLFS', 'KDP', 'MELI', 'NTRA', 'TRUP', 'ARWR', 'FAST', 'GDEN', 'GTLS']
# grp(retnStd/UI):   mean, std, mean/std:         1.074,         0.418,         2.572
# grp(CAGR/retnStd): mean, std, mean/std:       -28.013,        25.409,        -1.103
# grp(CAGR/UI):      mean, std, mean/std:       -23.029,        28.753,        -0.801
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         1.648,        35.264,        58.108
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.074122587172962, 0.4176057823988415, 2.572097016959174, -28.013477463051064, 25.408590740615633, -1.1025199212749537, -23.029137340466853, 28.752623188000467, -0.8009403938517082, 1.6478031128199293, 35.263865870393005, 58.10790795129806]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.074122587172962, 0.4176057823988415, 2.572097016959174, -28.013477463051064, 25.408590740615633, -1.1025199212749537, -23.029137340466853, 28.752623188000467, -0.8009403938517082, 1.6478031128199293, 35.263865870393005, 58.10790795129806]
#
# ==================================================
#
# 395 of 400 max_lookback_slice
# max_lookback_slice: (648, 678, 683)
# max lookback dates: 2019-09-30, 2019-11-11, 2019-11-18
# df_eval dates (inclusive): 2019-11-11 - 2019-11-15
# top_set_syms: ['BGNE', 'EVRI', 'ISEE', 'QRVO', 'VSTO', 'COLL', 'GPRE', 'UCTT', 'SGRY', 'ACRS']
#
# symbols_eval: ['BGNE', 'EVRI', 'ISEE', 'QRVO', 'VSTO', 'COLL', 'GPRE', 'UCTT', 'SGRY', 'ACRS', 'SPY'], _top_set_syms: ['BGNE', 'EVRI', 'ISEE', 'QRVO', 'VSTO', 'COLL', 'GPRE', 'UCTT', 'SGRY', 'ACRS']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:        46.078,       145.656,         0.316
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:           inf,       244.804,           inf
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 46.077624643462386, 145.65578850916856, 0.31634599019428566, inf, nan, nan, inf, 244.80374801361313, inf]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 46.077624643462386, 145.65578850916856, 0.31634599019428566, inf, nan, nan, inf, 244.80374801361313, inf]
#
# ==================================================
#
# 396 of 400 max_lookback_slice
# max_lookback_slice: (297, 327, 332)
# max lookback dates: 2018-05-08, 2018-06-20, 2018-06-27
# df_eval dates (inclusive): 2018-06-20 - 2018-06-26
# top_set_syms: ['AVXL', 'SRPT', 'SIG', 'TNDM', 'RCII', 'TRUP', 'ALGN', 'ARWR', 'BLFS', 'CATO']
#
# symbols_eval: ['AVXL', 'SRPT', 'SIG', 'TNDM', 'RCII', 'TRUP', 'ALGN', 'ARWR', 'BLFS', 'CATO', 'SPY'], _top_set_syms: ['AVXL', 'SRPT', 'SIG', 'TNDM', 'RCII', 'TRUP', 'ALGN', 'ARWR', 'BLFS', 'CATO']
# grp(retnStd/UI):   mean, std, mean/std:         1.840,         2.512,         0.732
# grp(CAGR/retnStd): mean, std, mean/std:     1,087.888,     3,602.339,         0.302
# grp(CAGR/UI):      mean, std, mean/std:     9,694.942,    31,868.875,         0.304
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         0.669,       -73.402,       -49.071
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.8398715559805578, 2.5120459307092244, 0.7324195523212857, 1087.8875219105523, 3602.3393999997643, 0.30199473206511956, 9694.941617402224, 31868.87511944345, 0.30421348670343445, 0.6685254617919207, -73.40190114763391, -49.07103986112687]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.8398715559805578, 2.5120459307092244, 0.7324195523212857, 1087.8875219105523, 3602.3393999997643, 0.30199473206511956, 9694.941617402224, 31868.87511944345, 0.30421348670343445, 0.6685254617919207, -73.40190114763391, -49.07103986112687]
#
# ==================================================
#
# 397 of 400 max_lookback_slice
# max_lookback_slice: (915, 945, 950)
# max lookback dates: 2020-10-20, 2020-12-02, 2020-12-09
# df_eval dates (inclusive): 2020-12-02 - 2020-12-08
# top_set_syms: ['CHRD', 'X', 'LC', 'SM', 'AA', 'ATKR', 'JWN', 'MARA', 'BAP', 'COHR']
#
# symbols_eval: ['CHRD', 'X', 'LC', 'SM', 'AA', 'ATKR', 'JWN', 'MARA', 'BAP', 'COHR', 'SPY'], _top_set_syms: ['CHRD', 'X', 'LC', 'SM', 'AA', 'ATKR', 'JWN', 'MARA', 'BAP', 'COHR']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:   284,453.766,   656,369.649,         0.433
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         5.055,       125.413,       633.976
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 284453.7657831665, 656369.6493336951, 0.43337434336265546, inf, nan, nan, 5.0550898616865325, 125.41342459444982, 633.9761311867918]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 284453.7657831665, 656369.6493336951, 0.43337434336265546, inf, nan, nan, 5.0550898616865325, 125.41342459444982, 633.9761311867918]
#
# ==================================================
#
# 398 of 400 max_lookback_slice
# max_lookback_slice: (899, 929, 934)
# max lookback dates: 2020-09-28, 2020-11-09, 2020-11-16
# df_eval dates (inclusive): 2020-11-09 - 2020-11-13
# top_set_syms: ['DBRG', 'LOB', 'ALGN', 'RAMP', 'TPR', 'ARWR', 'NSP', 'TTD', 'CROX', 'DLB']
#
# symbols_eval: ['DBRG', 'LOB', 'ALGN', 'RAMP', 'TPR', 'ARWR', 'NSP', 'TTD', 'CROX', 'DLB', 'SPY'], _top_set_syms: ['DBRG', 'LOB', 'ALGN', 'RAMP', 'TPR', 'ARWR', 'NSP', 'TTD', 'CROX', 'DLB']
# grp(retnStd/UI):   mean, std, mean/std:         1.663,         0.867,         1.918
# grp(CAGR/retnStd): mean, std, mean/std:       148.349,       233.746,         0.635
# grp(CAGR/UI):      mean, std, mean/std:       394.955,       591.880,         0.667
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.345,        63.165,       148.118
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 1.6632791592234484, 0.8670515252218007, 1.91831639855309, 148.34948198081997, 233.74608205655653, 0.6346608280044914, 394.95479212838563, 591.8800717161383, 0.6672885454366223, 2.34493936130558, 63.165099671061576, 148.1183284794624]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 1.6632791592234484, 0.8670515252218007, 1.91831639855309, 148.34948198081997, 233.74608205655653, 0.6346608280044914, 394.95479212838563, 591.8800717161383, 0.6672885454366223, 2.34493936130558, 63.165099671061576, 148.1183284794624]
#
# ==================================================
#
# 399 of 400 max_lookback_slice
# max_lookback_slice: (37, 67, 72)
# max lookback dates: 2017-04-26, 2017-06-08, 2017-06-15
# df_eval dates (inclusive): 2017-06-08 - 2017-06-14
# top_set_syms: ['SQ', 'COO', 'ALV', 'CHGG', 'CYRX', 'EXTR', 'LITE', 'MCHP', 'MU', 'OLED']
#
# symbols_eval: ['SQ', 'COO', 'ALV', 'CHGG', 'CYRX', 'EXTR', 'LITE', 'MCHP', 'MU', 'OLED', 'SPY'], _top_set_syms: ['SQ', 'COO', 'ALV', 'CHGG', 'CYRX', 'EXTR', 'LITE', 'MCHP', 'MU', 'OLED']
# grp(retnStd/UI):   mean, std, mean/std:           inf,           nan,           nan
# grp(CAGR/retnStd): mean, std, mean/std:     1,185.001,     4,037.482,         0.293
# grp(CAGR/UI):      mean, std, mean/std:           inf,           nan,           nan
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.556,        33.250,        84.987
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 1185.0006291292775, 4037.482123583225, 0.29349990733274167, inf, nan, nan, 2.5560201355804306, 33.24972100884504, 84.9869564010396]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, inf, nan, nan, 1185.0006291292775, 4037.482123583225, 0.29349990733274167, inf, nan, nan, 2.5560201355804306, 33.24972100884504, 84.9869564010396]
#
# ==================================================
#
# 400 of 400 max_lookback_slice
# max_lookback_slice: (224, 254, 259)
# max lookback dates: 2018-01-23, 2018-03-07, 2018-03-14
# df_eval dates (inclusive): 2018-03-07 - 2018-03-13
# top_set_syms: ['AXON', 'BL', 'TWLO', 'COUP', 'ENPH', 'ETSY', 'FATE', 'HLF', 'VCEL', 'VEEV']
#
# symbols_eval: ['AXON', 'BL', 'TWLO', 'COUP', 'ENPH', 'ETSY', 'FATE', 'HLF', 'VCEL', 'VEEV', 'SPY'], _top_set_syms: ['AXON', 'BL', 'TWLO', 'COUP', 'ENPH', 'ETSY', 'FATE', 'HLF', 'VCEL', 'VEEV']
# grp(retnStd/UI):   mean, std, mean/std:        17.356,        52.445,         0.331
# grp(CAGR/retnStd): mean, std, mean/std:       103.337,       322.096,         0.321
# grp(CAGR/UI):      mean, std, mean/std:    16,798.623,    55,465.703,         0.303
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI:         2.942,       103.151,       303.471
# row_add_total: [400, '[15, 30]', 5, 20, 0, 10, 17.355506740832848, 52.44450247929926, 0.33093090639354167, 103.33695518137439, 322.09581589971435, 0.32082675427720775, 16798.62260414985, 55465.70303206483, 0.30286504426777994, 2.942010314625767, 103.15096708056367, 303.4712091146413]
# appended row_add to df_eval_results:
# [400, '[15, 30]', 5, 20, 0, 10, 17.355506740832848, 52.44450247929926, 0.33093090639354167, 103.33695518137439, 322.09581589971435, 0.32082675427720775, 16798.62260414985, 55465.70303206483, 0.30286504426777994, 2.942010314625767, 103.15096708056367, 303.4712091146413]
#
# ==================================================

# %%
# # Creating Empty DataFrame and Storing it in variable df
# df_eval_results = pd.DataFrame(columns=col_add_total)
pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
df = pickle_load(path_data_dump, fp_df_eval_results)
df
# Out:
#       n_samples   days_lookbacks days_eval n_top_syms syms_start syms_end  grp(retnStd/UI)_mean  ...  grp(CAGR/retnStd)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  SPY_retnStd/UI  SPY_CAGR/retnStd  SPY_CAGR/UI
# 0           400  [15, 30, 60,...        10         20          0       20         1.108222       ...         0.278516                1.233041e+03        4819.519128          0.255843              1.237703        52.961179     65.550204
# 1           400  [15, 30, 60,...        10         20          0       20         2.548395       ...         0.256072                5.087090e+04      155754.011507          0.326611              1.008170        19.357624     19.515773
# 2           400  [15, 30, 60,...        10         20          0       20         0.635840       ...        -0.570477               -3.047098e+00          52.327578         -0.058231              0.766355       -57.849946    -44.333608
# 3           400  [15, 30, 60,...        10         20          0       20         1.278825       ...         0.364307                1.155709e+03        3027.321602          0.381760              2.549837       158.783768    404.872663
# 4           400  [15, 30, 60,...        10         20          0       20         0.614480       ...        -0.259152                6.407780e+00          71.436772          0.089699              0.515219       -39.893368    -20.553813
# ...         ...              ...       ...        ...        ...      ...              ...       ...              ...                         ...                ...               ...                   ...              ...           ...
# 20395       400         [15, 30]         5         20          0       10         1.839872       ...         0.301995                9.694942e+03       31868.875119          0.304213              0.668525       -73.401901    -49.071040
# 20396       400         [15, 30]         5         20          0       10              inf       ...         0.433374                         inf                NaN               NaN              5.055090       125.413425    633.976131
# 20397       400         [15, 30]         5         20          0       10         1.663279       ...         0.634661                3.949548e+02         591.880072          0.667289              2.344939        63.165100    148.118328
# 20398       400         [15, 30]         5         20          0       10              inf       ...         0.293500                         inf                NaN               NaN              2.556020        33.249721     84.986956
# 20399       400         [15, 30]         5         20          0       10        17.355507       ...         0.320827                1.679862e+04       55465.703032          0.302865              2.942010       103.150967    303.471209
#
# [20400 rows x 18 columns]

# %%
# https://towardsdatascience.com/pandas-groupby-a-simple-but-detailed-tutorial-314b8f37005d
# https://towardsdatascience.com/accessing-data-in-a-multiindex-dataframe-in-pandas-569e8767201d
# https://towardsdatascience.com/summarizing-data-with-pandas-crosstab-efc8b9abecf
# https://towardsdatascience.com/how-to-flatten-multiindex-columns-and-rows-in-pandas-f5406c50e569
# https://datascientyst.com/list-aggregation-functions-aggfunc-groupby-pandas/

# %%
print(f'len(df.columns): {len(df.columns)}')
print(f'df.columns: {df.columns}')
# Out:
# len(df.columns): 18
# df.columns: Index(['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'grp(retnStd/UI)_mean', 'grp(retnStd/UI)_std', 'grp(retnStd/UI)_mean/std', 'grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std', 'grp(CAGR/UI)_mean', 'grp(CAGR/UI)_std', 'grp(CAGR/UI)_mean/std', 'SPY_retnStd/UI', 'SPY_CAGR/retnStd', 'SPY_CAGR/UI'], dtype='object')

# %%
# pd.crosstab(df['days_lookbacks'], df['grp(CAGR/UI)_mean'])
tbl = df.groupby(['days_lookbacks', 'days_eval', 'syms_start', 'syms_end'])\
        .agg({'grp(CAGR/retnStd)_mean':     ['mean', 'std'],
              'grp(CAGR/retnStd)_mean/std': ['mean', 'std'],
              'SPY_CAGR/retnStd':           ['mean', 'std']})

# %%
tbl
# Out:
#                                                grp(CAGR/retnStd)_mean               grp(CAGR/retnStd)_mean/std             SPY_CAGR/retnStd
#                                                                  mean           std                       mean         std             mean          std
# days_lookbacks   days_eval syms_start syms_end
# [120]            5         0          5            5.001869e+05        4.229700e+06         0.329713              0.785886       123.411555   281.441718
#                                       10           2.147785e+12        4.104217e+13         0.289564              0.604811       178.953439   758.264793
#                                       20           2.974840e+16        5.710088e+17         0.264614              0.299683       187.351137   838.811051
#                  10        0          20           5.094196e+22        1.011342e+24         0.206123              0.465920        70.452072   126.538973
# [14, 28]         5         0          5            2.067460e+28        4.134920e+29         0.293027              0.646296       122.474102   415.265147
# [14, 30]         5         0          5            4.134920e+28        5.840328e+29         0.298647              0.726377       158.319994   548.438491
# [15, 29]         5         0          5            1.928587e+20        3.854580e+21         0.293753              0.625667       140.524341   418.463158
# [15, 30, 60, ... 5         0          5            6.832774e+14        1.335791e+16         0.361100              0.488997       152.503422   457.155518
#                                       10           2.369070e+42        4.738141e+43         0.332299              0.319749       159.414856   452.971314
#                                       20           1.240942e+42        2.481883e+43         0.253898              0.256363       271.346679  1335.441749
#                  10        0          20           2.508091e+09        3.844558e+10         0.269642              0.305100        87.429111   145.005302
# [15, 30, 60]     5         0          5            1.210186e+21        1.393582e+22         0.331214              0.603319       153.879630   606.821152
#                                       10           9.596145e+10        1.888727e+12         0.258161              0.435701       182.685060  1106.975253
#                                       20           9.380732e+19        1.857795e+21         0.271626              0.229689       203.076578   784.449669
# [15, 30]         1         0          5                     NaN                 NaN              NaN                   NaN              NaN          NaN
#                  2         0          5                     NaN                 NaN              NaN                   NaN              NaN          NaN
#                  3         0          5            3.329820e+52        4.703172e+53         0.246861              0.510462       495.058526  3441.429066
#                  4         0          5            8.893989e+21        1.778798e+23         0.300491              0.558977       249.857544  1265.922671
#                  5         0          1            7.524982e+05        8.686814e+06       -17.021102            345.903385       112.238219   262.649199
#                                       2            5.219997e+12        1.043999e+14         0.198913              1.267806       132.601443   278.655581
#                                       3            3.101190e+28        6.202381e+29         0.214028              0.995007       223.529965  1278.622570
#                                       4            3.169224e+12        6.264223e+13         0.294902              0.717603       250.943410  1150.732169
#                                       5            2.171648e+42        6.142348e+43         0.302272              0.624420       200.934012   961.705891
#                                       6            3.722825e+42        7.445650e+43         0.311076              0.625433       153.848143   604.548260
#                                       10           2.369070e+42        4.735175e+43         0.274047              0.462036       151.102979   809.621633
#                                       20           5.948880e+27        1.181415e+29         0.249452              0.283829       211.491198  1074.058772
#                            1          5            4.657931e+17        5.365018e+18         0.259756              0.819231       136.602325   286.477741
# [15, 31]         5         0          5            1.464768e+26        2.929536e+27         0.243309              0.665825       177.117964   973.311167
# [15]             5         0          5            2.067460e+28        4.134920e+29         0.219267              0.808184       111.244501   252.122193
#                                       10           1.051251e+20        2.102501e+21         0.294340              0.418731       171.342385   556.628523
#                                       20           2.481883e+42        3.505512e+43         0.252584              0.319888       138.838810   653.274146
#                  10        0          20           2.526167e+15        4.887995e+16         0.251577              0.392747        59.841324    97.860429
# [16, 32]         5         0          5            1.464768e+26        2.929536e+27         0.303446              0.608433       144.862328   310.368022
# [30, 60, 120]    5         0          5            3.104123e+18        6.206210e+19         0.322799              0.574396       150.334122   652.335303
#                                       10           2.369070e+42        4.738141e+43         0.281858              0.389562        97.113119   209.210778
#                                       20           1.153026e+20        2.304597e+21         0.271093              0.246074       170.224752   454.826023
#                  10        0          20           3.753346e+20        7.506643e+21         0.274576              0.344481        79.760402   138.788030
# [30]             5         0          5            2.086200e+21        4.172401e+22         0.233050              0.728240       231.895294  1292.366600
#                                       10           1.127706e+28        2.255411e+29         0.268133              0.476813       182.727889   976.932044
#                                       20           4.185243e+25        8.370103e+26         0.238605              0.313516       117.258071   253.414628
#                  10        0          20           3.715961e+12        7.424344e+13         0.236506              0.440289        74.287265   115.740415
# [60, 120]        5         0          5            2.067460e+28        4.134920e+29         0.283508              0.628077       170.205302   620.287429
#                                       10           2.199847e+20        4.399692e+21         0.309345              0.406279       146.126775   656.037742
#                                       20           2.481883e+42        3.505512e+43         0.261282              0.338834       185.352426  1008.514326
#                  10        0          20           4.133000e+13        8.265883e+14         0.254689              0.353909        76.206856   118.803910
# [60]             5         0          5            9.932344e+05        1.115872e+07         0.373214              0.603858       157.559466   354.575359
#                                       10           7.094184e+16        1.411495e+18         0.330890              0.360660       160.874931   604.323553
#                                       20           3.702018e+16        7.393521e+17         0.280251              0.231756       170.032740   886.587580
#                  10        0          20           5.093067e+09        7.002171e+10         0.265137              0.328703        76.302157   140.698429

# %%
tbl['SPY_m/s'] = tbl['SPY_CAGR/retnStd', 'mean'] / tbl['SPY_CAGR/retnStd', 'std'] 
tbl['grp-SPY_m/s'] = tbl['grp(CAGR/retnStd)_mean/std', 'mean'] - tbl['SPY_m/s'] 
tbl.sort_values(by='grp-SPY_m/s', ascending=False, inplace=True)
# tbl.sort_values(by='days_lookbacks', ascending=False, inplace=True)
tbl
# Out:
#                                                grp(CAGR/retnStd)_mean               grp(CAGR/retnStd)_mean/std             SPY_CAGR/retnStd                SPY_m/s grp-SPY_m/s
#                                                                  mean           std                       mean         std             mean          std
# days_lookbacks   days_eval syms_start syms_end
# [15, 30]         4         0          5            8.893989e+21        1.778798e+23         0.300491              0.558977       249.857544  1265.922671  0.197372    0.103120
#                  3         0          5            3.329820e+52        4.703172e+53         0.246861              0.510462       495.058526  3441.429066  0.143853    0.103008
#                  5         0          5            2.171648e+42        6.142348e+43         0.302272              0.624420       200.934012   961.705891  0.208935    0.093337
# [15, 30, 60]     5         0          10           9.596145e+10        1.888727e+12         0.258161              0.435701       182.685060  1106.975253  0.165031    0.093130
# [30, 60, 120]    5         0          5            3.104123e+18        6.206210e+19         0.322799              0.574396       150.334122   652.335303  0.230455    0.092344
# [60]             5         0          20           3.702018e+16        7.393521e+17         0.280251              0.231756       170.032740   886.587580  0.191783    0.088468
# [15, 30]         5         0          10           2.369070e+42        4.735175e+43         0.274047              0.462036       151.102979   809.621633  0.186634    0.087412
# [60, 120]        5         0          10           2.199847e+20        4.399692e+21         0.309345              0.406279       146.126775   656.037742  0.222741    0.086604
# [30]             5         0          10           1.127706e+28        2.255411e+29         0.268133              0.476813       182.727889   976.932044  0.187043    0.081090
# [15, 30, 60]     5         0          5            1.210186e+21        1.393582e+22         0.331214              0.603319       153.879630   606.821152  0.253583    0.077630
# [60, 120]        5         0          20           2.481883e+42        3.505512e+43         0.261282              0.338834       185.352426  1008.514326  0.183788    0.077494
# [15, 30]         5         0          4            3.169224e+12        6.264223e+13         0.294902              0.717603       250.943410  1150.732169  0.218073    0.076829
# [60]             5         0          10           7.094184e+16        1.411495e+18         0.330890              0.360660       160.874931   604.323553  0.266207    0.064683
# [15, 31]         5         0          5            1.464768e+26        2.929536e+27         0.243309              0.665825       177.117964   973.311167  0.181975    0.061334
# [15, 30]         5         0          6            3.722825e+42        7.445650e+43         0.311076              0.625433       153.848143   604.548260  0.254484    0.056592
# [30]             5         0          5            2.086200e+21        4.172401e+22         0.233050              0.728240       231.895294  1292.366600  0.179435    0.053616
# [120]            5         0          10           2.147785e+12        4.104217e+13         0.289564              0.604811       178.953439   758.264793  0.236004    0.053560
# [15, 30]         5         0          20           5.948880e+27        1.181415e+29         0.249452              0.283829       211.491198  1074.058772  0.196908    0.052544
# [15, 30, 60, ... 5         0          20           1.240942e+42        2.481883e+43         0.253898              0.256363       271.346679  1335.441749  0.203189    0.050709
# [120]            5         0          20           2.974840e+16        5.710088e+17         0.264614              0.299683       187.351137   838.811051  0.223353    0.041261
# [15]             5         0          20           2.481883e+42        3.505512e+43         0.252584              0.319888       138.838810   653.274146  0.212528    0.040056
# [15, 30]         5         0          3            3.101190e+28        6.202381e+29         0.214028              0.995007       223.529965  1278.622570  0.174821    0.039207
# [15, 30, 60, ... 5         0          5            6.832774e+14        1.335791e+16         0.361100              0.488997       152.503422   457.155518  0.333592    0.027508
# [15, 30, 60]     5         0          20           9.380732e+19        1.857795e+21         0.271626              0.229689       203.076578   784.449669  0.258878    0.012748
# [14, 30]         5         0          5            4.134920e+28        5.840328e+29         0.298647              0.726377       158.319994   548.438491  0.288674    0.009973
# [60, 120]        5         0          5            2.067460e+28        4.134920e+29         0.283508              0.628077       170.205302   620.287429  0.274397    0.009111
# [14, 28]         5         0          5            2.067460e+28        4.134920e+29         0.293027              0.646296       122.474102   415.265147  0.294930   -0.001903
# [15]             5         0          10           1.051251e+20        2.102501e+21         0.294340              0.418731       171.342385   556.628523  0.307822   -0.013481
# [15, 30, 60, ... 5         0          10           2.369070e+42        4.738141e+43         0.332299              0.319749       159.414856   452.971314  0.351931   -0.019633
# [15, 29]         5         0          5            1.928587e+20        3.854580e+21         0.293753              0.625667       140.524341   418.463158  0.335811   -0.042058
# [60]             5         0          5            9.932344e+05        1.115872e+07         0.373214              0.603858       157.559466   354.575359  0.444361   -0.071147
# [30, 60, 120]    5         0          20           1.153026e+20        2.304597e+21         0.271093              0.246074       170.224752   454.826023  0.374263   -0.103170
# [120]            5         0          5            5.001869e+05        4.229700e+06         0.329713              0.785886       123.411555   281.441718  0.438498   -0.108784
# [16, 32]         5         0          5            1.464768e+26        2.929536e+27         0.303446              0.608433       144.862328   310.368022  0.466744   -0.163298
# [30, 60, 120]    5         0          10           2.369070e+42        4.738141e+43         0.281858              0.389562        97.113119   209.210778  0.464188   -0.182330
# [15, 30]         5         1          5            4.657931e+17        5.365018e+18         0.259756              0.819231       136.602325   286.477741  0.476834   -0.217078
# [15]             5         0          5            2.067460e+28        4.134920e+29         0.219267              0.808184       111.244501   252.122193  0.441232   -0.221965
# [30]             5         0          20           4.185243e+25        8.370103e+26         0.238605              0.313516       117.258071   253.414628  0.462712   -0.224107
# [15, 30]         5         0          2            5.219997e+12        1.043999e+14         0.198913              1.267806       132.601443   278.655581  0.475861   -0.276948
# [60]             10        0          20           5.093067e+09        7.002171e+10         0.265137              0.328703        76.302157   140.698429  0.542310   -0.277173
# [30, 60, 120]    10        0          20           3.753346e+20        7.506643e+21         0.274576              0.344481        79.760402   138.788030  0.574692   -0.300116
# [15, 30, 60, ... 10        0          20           2.508091e+09        3.844558e+10         0.269642              0.305100        87.429111   145.005302  0.602937   -0.333295
# [120]            10        0          20           5.094196e+22        1.011342e+24         0.206123              0.465920        70.452072   126.538973  0.556762   -0.350639
# [15]             10        0          20           2.526167e+15        4.887995e+16         0.251577              0.392747        59.841324    97.860429  0.611497   -0.359919
# [60, 120]        10        0          20           4.133000e+13        8.265883e+14         0.254689              0.353909        76.206856   118.803910  0.641451   -0.386761
# [30]             10        0          20           3.715961e+12        7.424344e+13         0.236506              0.440289        74.287265   115.740415  0.641844   -0.405338
# [15, 30]         5         0          1            7.524982e+05        8.686814e+06       -17.021102            345.903385       112.238219   262.649199  0.427331  -17.448434
#                  1         0          5                     NaN                 NaN              NaN                   NaN              NaN          NaN       NaN         NaN
#                  2         0          5                     NaN                 NaN              NaN                   NaN              NaN          NaN       NaN         NaN

# %%
# # https://stackoverflow.com/questions/31674195/plot-normal-distribution-given-mean-and-sigma-python
# # loc is mean, scale is standard deviation
# import pylab
# import numpy as np
# from scipy.stats import norm
# # x = np.linspace(-10000,100000,1000)
# x = np.linspace(-40e+10,50e+10,1000)
# y = norm.pdf(x, loc=2.562777e+10, scale=1.036925e+11)    # loc = mean, scale = standard deviation
# # z = norm.pdf(x, loc=3.540615e+10, scale=1.194430e+11)    # for example
# # z1 = norm.pdf(x, loc=298.805901, scale=826.875749)    # for example
# # z1 = norm.pdf(x, loc=1.021825, scale=1.505096)    # for example
# pylab.plot(x,y, 'b')
# # pylab.plot(x,z, 'g')
# # pylab.plot(x,z1, 'r')
# pylab.show()

# %%
# # get values of _cols, where grp(CAGR/retnStd)_mean is max after filtering out inf
# _cols = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
# # _df_no_inf = df.loc[df['grp(CAGR/retnStd)_mean'] != np.inf]  # df with filter out inf in column grp(CAGR/UI)_mean 
# # _idx = _df_no_inf['grp(CAGR/retnStd)_mean'].idxmax()  # index value of max in grp(CAGR/UI)_mean 
# _idx = df['grp(CAGR/retnStd)_mean'].idxmax()  # index value of max in grp(CAGR/UI)_mean 
# grp_inf_replacement = df.loc[[_idx], _cols].squeeze()  # convert df (only has 1 row) to series
# print(f'_idx: {_idx}')
# grp_inf_replacement

# %%
# # get values of _cols, where SPY_CAGR/retnStd is max after filtering out inf
# _cols = ['SPY_CAGR/retnStd']
# # _df_no_inf = df.loc[df['SPY_CAGR/retnStd'] != np.inf]  # df with filter out inf in column grp(CAGR/UI)_mean 
# _idx = df['SPY_CAGR/retnStd'].idxmax()  # index value of max in grp(CAGR/UI)_mean 
# SPY_inf_replacement = df.loc[[_idx], _cols].squeeze()  # convert df (only has 1 row) to series
# print(f'_idx: {_idx}')
# SPY_inf_replacement

# %%
# # # https://stackoverflow.com/questions/50773107/how-to-replace-infinite-value-with-maximum-value-of-a-pandas-column
# # replace inf in column grp(CAGR/UI)_mean
# df['grp(CAGR/UI)_mean'].replace(np.inf, grp_inf_replacement['grp(CAGR/UI)_mean'], inplace=True)
# # replace NaN in column grp(CAGR/UI)_std
# df['grp(CAGR/UI)_std'].replace(np.nan, grp_inf_replacement['grp(CAGR/UI)_std'], inplace=True)
# # replace NaN in column grp(CAGR/UI)_mean/std
# df['grp(CAGR/UI)_mean/std'].replace(np.nan, grp_inf_replacement['grp(CAGR/UI)_mean/std'], inplace=True)
# # replace inf in column SPY_CAGR/UI
# df['SPY_CAGR/UI'].replace(np.inf, SPY_inf_replacement, inplace=True)
# df
# df

# %%
# print(f'n_samples:             {n_samples:>13}')
# print(f'days_lookbacks:        {days_lookbacks}')
# print(f'days_eval:             {days_eval:>13}')
# print(f'n_top_syms:            {n_top_syms:>13}')
# print(f'syms_start:            {syms_start:>13}')
# print(f'syms_end:              {syms_end:>13}')
# print(f'grp(CAGR/UI)_mean:     {grp_CAGR_d_UI[0]:>13,.3f}')
# print(f'grp(CAGR/UI)_std:      {grp_CAGR_d_UI[1]:>13,.3f}')
# print(f'grp(CAGR/UI)_mean/std: {grp_CAGR_d_UI[2]:>13,.3f}')
# print(f'SPY_CAGR/UI:           {SPY_CAGR_d_UI[0]:>13,.3f}')
