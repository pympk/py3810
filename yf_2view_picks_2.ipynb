# %%
# # create empty DataFrame df and append row
# my_cols = ['date', 'days_lookback', 'syms_freq', 'symbols']
# # Creating Empty DataFrame and Storing it in variable df
# df_model_top_picks = pd.DataFrame(columns=my_cols)
# df_model_top_picks

# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.width', 900)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_picks  = f'df_picks'
fp_df_model_top_picks = f'df_model_top_picks'

verbose = True
# verbose = False

# %%
df = pickle_load(path_data_dump, fp_df_picks)
df = df.drop_duplicates(subset=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], keep='last')
df = df.sort_values(by=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], ascending=False)
df = df.reset_index(drop=True)
pickle_dump(df, path_data_dump, fp_df_picks)
print(f'len(df): {len(df)}')
print(df.head())
# Out:
# len(df): 192
#   date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12 sym_freq_11 sym_freq_10 sym_freq_9       sym_freq_8                     sym_freq_7              sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0        2023-08-08                 120      [30, 60, 120]          []          []          []          []          []          []         []  ['SHV', 'STRL']                       ['SMCI']   ['BCC', 'LOB', 'TDS']        ['CLS', 'FTSM', 'SKYW']  ['BKU', 'EME', 'GBX', 'KDN...  ['AMPH', 'BZH', 'CVBF', 'E...         []
# 1        2023-08-08                 120  [15, 30, 60, 120]          []          []          []          []    ['STRL']     ['SHV']    ['TDS']               []  ['CLS', 'LOB', 'SATS', 'SM...          ['BCC', 'EME']  ['CORT', 'FFWM', 'FTSM', '...  ['BKU', 'DINO', 'GBX', 'KD...                ['AMPH', 'BZH']         []
# 2        2023-08-07                 120      [30, 60, 120]          []          []          []          []          []          []         []          ['SHV']                       ['SMCI']                 ['LOB']  ['BCC', 'CLS', 'EME', 'FTS...         ['GBX', 'SATS', 'VNO']  ['AVGO', 'BKU', 'BLDR', 'B...         []
# 3        2023-08-07                 120  [15, 30, 60, 120]          []          []          []          []          []     ['SHV']         []          ['LOB']                ['CLS', 'SMCI']  ['EME', 'SATS', 'TDS']  ['BCC', 'CORT', 'CVBF', 'F...  ['DINO', 'EDU', 'FFWM', 'G...                       ['AVGO']         []
# 4        2023-08-04                 120      [30, 60, 120]          []          []          []          []          []          []         []          ['SHV']                       ['SMCI']                 ['LOB']  ['BCC', 'CLS', 'FTSM', 'GB...          ['EME', 'TDS', 'VNO']  ['AMPH', 'AVGO', 'BKU', 'B...         []

# %%
df.head(50)
# Out:
#    date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12 sym_freq_11      sym_freq_10       sym_freq_9            sym_freq_8                     sym_freq_7                     sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0         2023-08-08                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'STRL']                       ['SMCI']          ['BCC', 'LOB', 'TDS']        ['CLS', 'FTSM', 'SKYW']  ['BKU', 'EME', 'GBX', 'KDN...  ['AMPH', 'BZH', 'CVBF', 'E...         []
# 1         2023-08-08                 120  [15, 30, 60, 120]          []          []          []          []    ['STRL']          ['SHV']          ['TDS']                    []  ['CLS', 'LOB', 'SATS', 'SM...                 ['BCC', 'EME']  ['CORT', 'FFWM', 'FTSM', '...  ['BKU', 'DINO', 'GBX', 'KD...                ['AMPH', 'BZH']         []
# 2         2023-08-07                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                       ['SMCI']                        ['LOB']  ['BCC', 'CLS', 'EME', 'FTS...         ['GBX', 'SATS', 'VNO']  ['AVGO', 'BKU', 'BLDR', 'B...         []
# 3         2023-08-07                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []               ['LOB']                ['CLS', 'SMCI']         ['EME', 'SATS', 'TDS']  ['BCC', 'CORT', 'CVBF', 'F...  ['DINO', 'EDU', 'FFWM', 'G...                       ['AVGO']         []
# 4         2023-08-04                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                       ['SMCI']                        ['LOB']  ['BCC', 'CLS', 'FTSM', 'GB...          ['EME', 'TDS', 'VNO']  ['AMPH', 'AVGO', 'BKU', 'B...         []
# 5         2023-08-04                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []               ['LOB']         ['CLS', 'SMCI', 'TDS']                             []  ['BCC', 'CORT', 'CVBF', 'E...         ['BKU', 'EDU', 'FFWM']                       ['AMPH']         []
# 6         2023-08-03                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                             []         ['BCC', 'LOB', 'SMCI']        ['FTSM', 'GBX', 'SKYW']  ['AMPH', 'BZH', 'CLS', 'SL...  ['AVGO', 'CVBF', 'ELF', 'G...         []
# 7         2023-08-03                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []               ['LOB']                             []  ['BCC', 'CLS', 'SMCI', 'WAL']  ['CORT', 'CVBF', 'FTSM', '...  ['AMPH', 'BZH', 'MATX', 'P...               ['AVGO', 'CADE']         []
# 8         2023-08-02                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                       ['SMCI']          ['BZH', 'GBX', 'LOB']  ['BCC', 'CLS', 'FTSM', 'SK...         ['AMPH', 'EME', 'JOE']  ['AVGO', 'CHTR', 'CSL', 'E...         []
# 9         2023-08-02                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']          ['LOB']                    []                ['CLS', 'SMCI']          ['BZH', 'EME', 'GBX']  ['BCC', 'FTSM', 'HP', 'JOE...  ['AMPH', 'CVBF', 'PKX', 'V...  ['ASTE', 'AVGO', 'BKI', 'B...         []
# 10        2023-08-01                 120      [30, 60, 120]          []          []          []          []          []               []               []                    []                ['BZH', 'SMCI']                 ['GBX', 'LOB']         ['BCC', 'CLS', 'FTSM']         ['AMPH', 'JOE', 'PKX']  ['AVGO', 'BAH', 'EME', 'GE...         []
# 11        2023-08-01                 120  [15, 30, 60, 120]          []          []          []          []          []               []          ['LOB']              ['SMCI']                 ['BZH', 'CLS']                 ['GBX', 'PKX']         ['BCC', 'FTSM', 'JOE']                ['AMPH', 'EME']  ['AVGO', 'BAH', 'BKI', 'ED...         []
# 12        2023-07-27                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                             []                        ['JOE']  ['BCC', 'CLS', 'FTSM', 'GBX']  ['AMPH', 'KDNY', 'PKX', 'X...  ['AVGO', 'BLDR', 'BZH', 'C...         []
# 13        2023-07-27                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']          ['JOE']                    []                             []                        ['PKX']  ['BCC', 'CLS', 'FTSM', 'GB...        ['AMPH', 'KDNY', 'XPO']  ['AVGO', 'BKI', 'BLDR', 'B...         []
# 14        2023-07-26                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                        ['PKX']         ['FTSM', 'GBX', 'XPO']                ['BCC', 'STRL']                       ['AMPH']  ['AAPL', 'AVGO', 'BKI', 'B...         []
# 15        2023-07-26                 120  [15, 30, 60, 120]          []          []          []          []          []   ['PKX', 'SHV']               []                    []                             []         ['FTSM', 'GBX', 'XPO']  ['BCC', 'LOB', 'PRG', 'STRL']                ['AMPH', 'BKI']  ['AAPL', 'AVGO', 'BLDR', '...         []
# 16        2023-07-25                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                        ['PKX']                ['FTSM', 'GBX']        ['AMPH', 'BCC', 'NVDA']                ['STRL', 'XPO']  ['AAPL', 'AVGO', 'BKI', 'B...         []
# 17        2023-07-25                 120  [15, 30, 60, 120]          []          []          []          []          []   ['PKX', 'SHV']               []                    []                             []                ['FTSM', 'GBX']  ['AMPH', 'BCC', 'MLKN', 'N...  ['BKI', 'PTEN', 'STRL', 'X...  ['AAPL', 'AVGO', 'BLDR', '...         []
# 18        2023-07-21                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                             []         ['BCC', 'SIRI', 'XPO']        ['FTSM', 'GBX', 'KDNY']  ['AMPH', 'HELE', 'SKYW', '...  ['AAPL', 'AVGO', 'BECN', '...         []
# 19        2023-07-21                 120  [15, 30, 60, 120]          []          []          []          []          []               []  ['SHV', 'SIRI']                    []                             []          ['BCC', 'PKX', 'XPO']        ['FTSM', 'GBX', 'KDNY']  ['AMPH', 'BKI', 'HELE', 'S...  ['AAPL', 'AVGO', 'BECN', '...         []
# 20        2023-07-20                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                             []  ['BCC', 'NVDA', 'SIRI', 'X...        ['AMPH', 'FTSM', 'GBX']  ['DAL', 'KDNY', 'SKYW', 'S...  ['AN', 'AVGO', 'BKI', 'BLD...         []
# 21        2023-07-20                 120  [15, 30, 60, 120]          []          []          []          []          []               []  ['SHV', 'SIRI']                    []                             []         ['BCC', 'NVDA', 'XPO']  ['AMPH', 'FTSM', 'GBX', 'P...  ['BKI', 'DAL', 'KDNY', 'PK...  ['AN', 'AVGO', 'BLDR', 'BO...         []
# 22        2023-07-18                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                             []        ['BCC', 'FTSM', 'NVDA']               ['BECN', 'BLDR']       ['META', 'SKYW', 'STRL']  ['AN', 'AVGO', 'BOOT', 'BZ...         []
# 23        2023-07-18                 120  [15, 30, 60, 120]          []          []          []          []          []               []          ['SHV']               ['BCC']                             []        ['FTSM', 'GBX', 'NVDA']  ['BECN', 'BLDR', 'EXTR', '...  ['META', 'OSTK', 'SIRI', '...  ['AN', 'AVGO', 'BKI', 'BOO...         []
# 24        2023-07-14                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                             []         ['BCC', 'BZH', 'NVDA']  ['BECN', 'FTSM', 'META', '...  ['BLDR', 'KDNY', 'SKYW', 'W']  ['AAPL', 'AN', 'AVGO', 'BO...         []
# 25        2023-07-14                 120  [15, 30, 60, 120]          []          []          []          []          []               []          ['SHV']               ['BCC']                        ['BZH']                ['GBX', 'NVDA']  ['BECN', 'FTSM', 'META', '...  ['BLDR', 'KDNY', 'MARA', '...  ['AAPL', 'AN', 'AVGO', 'BO...         []
# 26        2023-07-13                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                             []                ['BCC', 'NVDA']  ['BECN', 'BZH', 'FTSM', 'M...   ['CCL', 'KDNY', 'NCLH', 'W']  ['AVGO', 'BLDR', 'CAR', 'C...         []
# 27        2023-07-13                 120  [15, 30, 60, 120]          []          []          []          []          []               []          ['SHV']       ['BCC', 'SKYW']                             []         ['BZH', 'GBX', 'NVDA']  ['AN', 'BECN', 'FTSM', 'ME...  ['CCL', 'COMM', 'HELE', 'K...               ['AVGO', 'BLDR']         []
# 28        2023-07-12                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                             []        ['BZH', 'FTSM', 'NVDA']               ['KDNY', 'NCLH']  ['BLDR', 'CCL', 'STRL', 'T...  ['AAPL', 'AVGO', 'BCC', 'C...         []
# 29        2023-07-12                 120  [15, 30, 60, 120]          []          []          []          []          []               []          ['SHV']       ['BZH', 'SKYW']                             []        ['FTSM', 'GBX', 'NVDA']  ['HELE', 'KDNY', 'NCLH', 'W']  ['BLDR', 'CCL', 'COMM', 'M...                 ['AAPL', 'AN']         []
# 30        2023-07-11                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                             []               ['FTSM', 'KDNY']  ['CCL', 'NCLH', 'NVDA', 'R...     ['BCC', 'BZH', 'DAL', 'W']  ['AAL', 'AAPL', 'BECN', 'B...         []
# 31        2023-07-11                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []              ['SKYW']                             []  ['BZH', 'FTSM', 'GBX', 'KD...  ['BCC', 'CCL', 'MARA', 'NC...  ['AAL', 'DAL', 'HELE', 'OS...                             []         []
# 32        2023-07-10                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                             []               ['FTSM', 'NVDA']  ['CCL', 'ISEE', 'KDNY', 'N...  ['BCC', 'BECN', 'BLDR', 'B...  ['AAPL', 'CAR', 'CELH', 'C...         []
# 33        2023-07-10                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []              ['SKYW']         ['BCC', 'CCL', 'FTSM']  ['BZH', 'GBX', 'KDNY', 'NC...  ['CAR', 'COMM', 'DAL', 'HA...               ['BECN', 'BLDR']                             []         []
# 34        2023-07-07                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                             []  ['CCL', 'FTSM', 'KDNY', 'N...               ['ISEE', 'NCLH']  ['AAPL', 'BZH', 'DAL', 'EL...  ['AAL', 'BCC', 'BECN', 'BL...         []
# 35        2023-07-07                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []              ['SKYW']               ['FTSM', 'KDNY']  ['BZH', 'CCL', 'DAL', 'GBX...  ['BCC', 'CAR', 'COMM', 'IS...  ['AAPL', 'DLR', 'ELF', 'OS...                             []         []
# 36        2023-07-06                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                             []  ['CCL', 'FTSM', 'ISEE', 'K...                       ['NCLH']  ['AAPL', 'BCC', 'BZH', 'DA...         ['AMPH', 'ANF', 'CAR']         []
# 37        2023-07-06                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []       ['CCL', 'SKYW']               ['FTSM', 'KDNY']  ['BCC', 'BZH', 'DAL', 'GBX...  ['AMPH', 'COMM', 'MARA', '...  ['AAPL', 'CAR', 'ELF', 'OS...                             []         []
# 38        2023-07-05                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                       ['SKYW']                ['CCL', 'STRL']  ['BZH', 'ISEE', 'KDNY', 'N...  ['AAPL', 'BCC', 'BLDR', 'D...                 ['ANF', 'CAR']         []
# 39        2023-07-05                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []               ['CCL']  ['BZH', 'DAL', 'MARA', 'SK...  ['BCC', 'CAR', 'GBX', 'JBL...  ['EXP', 'ISEE', 'KDNY', 'N...                       ['AAPL']                             []         []
# 40        2023-07-03                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                       ['SKYW']                        ['CCL']  ['BZH', 'FTSM', 'ISEE', 'N...  ['BLDR', 'KDNY', 'NVDA', '...  ['AAPL', 'ANF', 'BCC', 'CA...         []
# 41        2023-07-03                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']               []  ['CCL', 'SKYW', 'W']                        ['BZH']                 ['DAL', 'GBX']  ['EXP', 'FTSM', 'ISEE', 'M...  ['BLDR', 'CAR', 'KDNY', 'N...                             []         []
# 42        2023-06-30                 120      [30, 60, 120]          []          []          []          []          []               []               []               ['SHV']                       ['SKYW']                        ['CCL']        ['ISEE', 'NCLH', 'RCL']  ['BLDR', 'BZH', 'FTSM', 'K...  ['AAPL', 'ANF', 'BCC', 'BMA']         []
# 43        2023-06-30                 120  [15, 30, 60, 120]          []          []          []          []          []          ['SHV']         ['SKYW']               ['CCL']               ['KDNY', 'NCLH']  ['BZH', 'DAL', 'GBX', 'OST...  ['CAR', 'EXP', 'ISEE', 'MA...       ['BLDR', 'FTSM', 'NVDA']                             []         []
# 44        2023-06-29                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                             []                       ['FTSM']        ['CCL', 'ISEE', 'NCLH']  ['BECN', 'BLDR', 'BZH', 'K...  ['AAPL', 'ANF', 'BCC', 'BM...         []
# 45        2023-06-29                 120  [15, 30, 60, 120]          []          []          []          []    ['SKYW']          ['SHV']               []                    []        ['CCL', 'KDNY', 'NCLH']         ['BZH', 'FTSM', 'GBX']  ['BECN', 'CAR', 'DAL', 'IS...  ['BLDR', 'BMA', 'MARA', 'N...                             []         []
# 46        2023-06-28                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                             []                       ['FTSM']  ['CCL', 'ISEE', 'NCLH', 'R...  ['BLDR', 'BZH', 'KDNY', 'M...  ['AAPL', 'ANF', 'BCC', 'BE...         []
# 47        2023-06-28                 120  [15, 30, 60, 120]          []          []          []          []          []  ['SHV', 'SKYW']               []                    []  ['CCL', 'KDNY', 'NCLH', 'R...    ['CAR', 'DAL', 'FTSM', 'W']               ['BECN', 'ISEE']  ['BLDR', 'BZH', 'MARA', 'M...                             []         []
# 48        2023-06-27                 120      [30, 60, 120]          []          []          []          []          []               []               []       ['SHV', 'SKYW']                       ['NVDA']                       ['FTSM']        ['AMPH', 'ISEE', 'RCL']  ['BECN', 'BLDR', 'KDNY', '...  ['AAPL', 'ACLS', 'ANF', 'B...         []
# 49        2023-06-27                 120  [15, 30, 60, 120]          []          []          []          []          []  ['SHV', 'SKYW']               []                    []       ['AMPH', 'KDNY', 'NVDA']  ['BECN', 'CAR', 'DAL', 'FT...                ['CCL', 'ISEE']  ['BLDR', 'MARA', 'META', '...                             []         []

# %%
df_mp_res = pickle_load(path_data_dump, 'df_model_picks_results')
df_mp = pickle_load(path_data_dump, 'df_model_picks')
# df_mp_res 
df_mp
# Out:
#          date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0  2023-07-14  [30, 60, 120]  sym_freq_8          ['SHV']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 1  2023-07-13  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-14  [4.0, 12.0]   926.000000      [2.0]  898.559998      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 2  2023-07-12  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-13  [4.0, 12.0]   938.440002      [2.0]  899.119995      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 3  2023-07-11  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-12  [4.0, 12.0]   933.999985      [2.0]  892.039978      None          None           NaN          NaN        None         NaN        NaN        NaN    0

# %%
from itertools import product
from ast import literal_eval

my_cols = ['sym_freq_12', 'sym_freq_9', 'sym_freq_8']
my_days_lookbacks = [[30, 60, 120], [15, 30, 60, 120]]

my_dates = []
for my_days_lookback in my_days_lookbacks:
  my_row = (df['days_lookbacks'] == str(my_days_lookback))
  l_dates = df.loc[my_row, 'date_end_df_train'].tolist()     
  my_dates.append(l_dates)

my_dates = [val for sublist in my_dates for val in sublist]
my_dates = sorted(list(set(my_dates)), reverse=True)

d_lbk_freq = list(product(my_dates, my_days_lookbacks, my_cols))

picks = []
prev_date = ''
# print(f'Model predicts the best performing symbols are:\n[30, 60, 120]        sym_freq_9\n[15, 30, 60, 120]    sym_freq_12\n[30, 60, 120]        sym_freq_8')
print(f'Model predicts the best performing symbols are:')
print(f'1st    {"[30, 60, 120]":<20}{"sym_freq_9":<14}{"days_eval = 4":<20}')
print(f'2nd    {"[15, 30, 60, 120]":<20}{"sym_freq_12":<14}{"days_eval = 5":<20}')
print(f'3rd    {"[30, 60, 120]":<20}{"sym_freq_8":<14}{"days_eval = 4":<20}')
for i, item in enumerate(d_lbk_freq):
  _date, my_days_lookback, my_col = item[0], item[1], item[2]
  my_row = (df['date_end_df_train'] == _date) & (df['days_lookbacks'] == str(my_days_lookback))  
  list_in_df = df.loc[my_row, my_col]
  my_str = list_in_df.tolist()[0]
  my_list = literal_eval(my_str)
  blank = ' '
  if _date != prev_date:
    if prev_date == '':
      print('\nModel Results:')  
      print(f'{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')
    else:
      print(f'\n{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}') 
  else:
    print(f'{i:<6}{blank:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')

  picks.append((i, my_list))
  prev_date = _date
# Out:
# Model predicts the best performing symbols are:
# 1st    [30, 60, 120]       sym_freq_9    days_eval = 4
# 2nd    [15, 30, 60, 120]   sym_freq_12   days_eval = 5
# 3rd    [30, 60, 120]       sym_freq_8    days_eval = 4
#
# Model Results:
# 0     2023-08-08    [30, 60, 120]        sym_freq_12: []
# 1                   [30, 60, 120]        sym_freq_9 : []
# 2                   [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 3                   [15, 30, 60, 120]    sym_freq_12: []
# 4                   [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 5                   [15, 30, 60, 120]    sym_freq_8 : []
#
# 6     2023-08-07    [30, 60, 120]        sym_freq_12: []
# 7                   [30, 60, 120]        sym_freq_9 : []
# 8                   [30, 60, 120]        sym_freq_8 : ['SHV']
# 9                   [15, 30, 60, 120]    sym_freq_12: []
# 10                  [15, 30, 60, 120]    sym_freq_9 : []
# 11                  [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 12    2023-08-04    [30, 60, 120]        sym_freq_12: []
# 13                  [30, 60, 120]        sym_freq_9 : []
# 14                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 15                  [15, 30, 60, 120]    sym_freq_12: []
# 16                  [15, 30, 60, 120]    sym_freq_9 : []
# 17                  [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 18    2023-08-03    [30, 60, 120]        sym_freq_12: []
# 19                  [30, 60, 120]        sym_freq_9 : []
# 20                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 21                  [15, 30, 60, 120]    sym_freq_12: []
# 22                  [15, 30, 60, 120]    sym_freq_9 : []
# 23                  [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 24    2023-08-02    [30, 60, 120]        sym_freq_12: []
# 25                  [30, 60, 120]        sym_freq_9 : []
# 26                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 27                  [15, 30, 60, 120]    sym_freq_12: []
# 28                  [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 29                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 30    2023-08-01    [30, 60, 120]        sym_freq_12: []
# 31                  [30, 60, 120]        sym_freq_9 : []
# 32                  [30, 60, 120]        sym_freq_8 : []
# 33                  [15, 30, 60, 120]    sym_freq_12: []
# 34                  [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 35                  [15, 30, 60, 120]    sym_freq_8 : ['SMCI']
#
# 36    2023-07-27    [30, 60, 120]        sym_freq_12: []
# 37                  [30, 60, 120]        sym_freq_9 : []
# 38                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 39                  [15, 30, 60, 120]    sym_freq_12: []
# 40                  [15, 30, 60, 120]    sym_freq_9 : ['JOE']
# 41                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 42    2023-07-26    [30, 60, 120]        sym_freq_12: []
# 43                  [30, 60, 120]        sym_freq_9 : []
# 44                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 45                  [15, 30, 60, 120]    sym_freq_12: []
# 46                  [15, 30, 60, 120]    sym_freq_9 : []
# 47                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 48    2023-07-25    [30, 60, 120]        sym_freq_12: []
# 49                  [30, 60, 120]        sym_freq_9 : []
# 50                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 51                  [15, 30, 60, 120]    sym_freq_12: []
# 52                  [15, 30, 60, 120]    sym_freq_9 : []
# 53                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 54    2023-07-21    [30, 60, 120]        sym_freq_12: []
# 55                  [30, 60, 120]        sym_freq_9 : []
# 56                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 57                  [15, 30, 60, 120]    sym_freq_12: []
# 58                  [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 59                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 60    2023-07-20    [30, 60, 120]        sym_freq_12: []
# 61                  [30, 60, 120]        sym_freq_9 : []
# 62                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 63                  [15, 30, 60, 120]    sym_freq_12: []
# 64                  [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 65                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 66    2023-07-18    [30, 60, 120]        sym_freq_12: []
# 67                  [30, 60, 120]        sym_freq_9 : []
# 68                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 69                  [15, 30, 60, 120]    sym_freq_12: []
# 70                  [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 71                  [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 72    2023-07-14    [30, 60, 120]        sym_freq_12: []
# 73                  [30, 60, 120]        sym_freq_9 : []
# 74                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 75                  [15, 30, 60, 120]    sym_freq_12: []
# 76                  [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 77                  [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 78    2023-07-13    [30, 60, 120]        sym_freq_12: []
# 79                  [30, 60, 120]        sym_freq_9 : []
# 80                  [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 81                  [15, 30, 60, 120]    sym_freq_12: []
# 82                  [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 83                  [15, 30, 60, 120]    sym_freq_8 : ['BCC', 'SKYW']
#
# 84    2023-07-12    [30, 60, 120]        sym_freq_12: []
# 85                  [30, 60, 120]        sym_freq_9 : []
# 86                  [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 87                  [15, 30, 60, 120]    sym_freq_12: []
# 88                  [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 89                  [15, 30, 60, 120]    sym_freq_8 : ['BZH', 'SKYW']
#
# 90    2023-07-11    [30, 60, 120]        sym_freq_12: []
# 91                  [30, 60, 120]        sym_freq_9 : []
# 92                  [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 93                  [15, 30, 60, 120]    sym_freq_12: []
# 94                  [15, 30, 60, 120]    sym_freq_9 : []
# 95                  [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 96    2023-07-10    [30, 60, 120]        sym_freq_12: []
# 97                  [30, 60, 120]        sym_freq_9 : []
# 98                  [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 99                  [15, 30, 60, 120]    sym_freq_12: []
# 100                 [15, 30, 60, 120]    sym_freq_9 : []
# 101                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 102   2023-07-07    [30, 60, 120]        sym_freq_12: []
# 103                 [30, 60, 120]        sym_freq_9 : []
# 104                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 105                 [15, 30, 60, 120]    sym_freq_12: []
# 106                 [15, 30, 60, 120]    sym_freq_9 : []
# 107                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 108   2023-07-06    [30, 60, 120]        sym_freq_12: []
# 109                 [30, 60, 120]        sym_freq_9 : []
# 110                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 111                 [15, 30, 60, 120]    sym_freq_12: []
# 112                 [15, 30, 60, 120]    sym_freq_9 : []
# 113                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW']
#
# 114   2023-07-05    [30, 60, 120]        sym_freq_12: []
# 115                 [30, 60, 120]        sym_freq_9 : []
# 116                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 117                 [15, 30, 60, 120]    sym_freq_12: []
# 118                 [15, 30, 60, 120]    sym_freq_9 : []
# 119                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 120   2023-07-03    [30, 60, 120]        sym_freq_12: []
# 121                 [30, 60, 120]        sym_freq_9 : []
# 122                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 123                 [15, 30, 60, 120]    sym_freq_12: []
# 124                 [15, 30, 60, 120]    sym_freq_9 : []
# 125                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW', 'W']
#
# 126   2023-06-30    [30, 60, 120]        sym_freq_12: []
# 127                 [30, 60, 120]        sym_freq_9 : []
# 128                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 129                 [15, 30, 60, 120]    sym_freq_12: []
# 130                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 131                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 132   2023-06-29    [30, 60, 120]        sym_freq_12: []
# 133                 [30, 60, 120]        sym_freq_9 : []
# 134                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 135                 [15, 30, 60, 120]    sym_freq_12: []
# 136                 [15, 30, 60, 120]    sym_freq_9 : []
# 137                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 138   2023-06-28    [30, 60, 120]        sym_freq_12: []
# 139                 [30, 60, 120]        sym_freq_9 : []
# 140                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 141                 [15, 30, 60, 120]    sym_freq_12: []
# 142                 [15, 30, 60, 120]    sym_freq_9 : []
# 143                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 144   2023-06-27    [30, 60, 120]        sym_freq_12: []
# 145                 [30, 60, 120]        sym_freq_9 : []
# 146                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 147                 [15, 30, 60, 120]    sym_freq_12: []
# 148                 [15, 30, 60, 120]    sym_freq_9 : []
# 149                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 150   2023-06-26    [30, 60, 120]        sym_freq_12: []
# 151                 [30, 60, 120]        sym_freq_9 : []
# 152                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 153                 [15, 30, 60, 120]    sym_freq_12: []
# 154                 [15, 30, 60, 120]    sym_freq_9 : []
# 155                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 156   2023-06-23    [30, 60, 120]        sym_freq_12: []
# 157                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 158                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 159                 [15, 30, 60, 120]    sym_freq_12: []
# 160                 [15, 30, 60, 120]    sym_freq_9 : ['CCL', 'NVDA']
# 161                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH']
#
# 162   2023-06-22    [30, 60, 120]        sym_freq_12: []
# 163                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 164                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 165                 [15, 30, 60, 120]    sym_freq_12: []
# 166                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 167                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'PBR']
#
# 168   2023-06-21    [30, 60, 120]        sym_freq_12: []
# 169                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 170                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 171                 [15, 30, 60, 120]    sym_freq_12: []
# 172                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 173                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 174   2023-06-20    [30, 60, 120]        sym_freq_12: []
# 175                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 176                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 177                 [15, 30, 60, 120]    sym_freq_12: []
# 178                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 179                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 180   2023-06-16    [30, 60, 120]        sym_freq_12: []
# 181                 [30, 60, 120]        sym_freq_9 : []
# 182                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 183                 [15, 30, 60, 120]    sym_freq_12: []
# 184                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 185                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 186   2023-06-15    [30, 60, 120]        sym_freq_12: []
# 187                 [30, 60, 120]        sym_freq_9 : []
# 188                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 189                 [15, 30, 60, 120]    sym_freq_12: []
# 190                 [15, 30, 60, 120]    sym_freq_9 : []
# 191                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'NVDA', 'SKYW']
#
# 192   2023-06-14    [30, 60, 120]        sym_freq_12: []
# 193                 [30, 60, 120]        sym_freq_9 : []
# 194                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA', 'SHV']
# 195                 [15, 30, 60, 120]    sym_freq_12: []
# 196                 [15, 30, 60, 120]    sym_freq_9 : ['AVGO']
# 197                 [15, 30, 60, 120]    sym_freq_8 : ['ORCL', 'SKYW']
#
# 198   2023-06-13    [30, 60, 120]        sym_freq_12: []
# 199                 [30, 60, 120]        sym_freq_9 : []
# 200                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 201                 [15, 30, 60, 120]    sym_freq_12: []
# 202                 [15, 30, 60, 120]    sym_freq_9 : []
# 203                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 204   2023-06-12    [30, 60, 120]        sym_freq_12: []
# 205                 [30, 60, 120]        sym_freq_9 : []
# 206                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 207                 [15, 30, 60, 120]    sym_freq_12: []
# 208                 [15, 30, 60, 120]    sym_freq_9 : []
# 209                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 210   2023-06-09    [30, 60, 120]        sym_freq_12: []
# 211                 [30, 60, 120]        sym_freq_9 : []
# 212                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 213                 [15, 30, 60, 120]    sym_freq_12: []
# 214                 [15, 30, 60, 120]    sym_freq_9 : []
# 215                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 216   2023-06-08    [30, 60, 120]        sym_freq_12: []
# 217                 [30, 60, 120]        sym_freq_9 : []
# 218                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 219                 [15, 30, 60, 120]    sym_freq_12: []
# 220                 [15, 30, 60, 120]    sym_freq_9 : []
# 221                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 222   2023-06-07    [30, 60, 120]        sym_freq_12: []
# 223                 [30, 60, 120]        sym_freq_9 : []
# 224                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 225                 [15, 30, 60, 120]    sym_freq_12: []
# 226                 [15, 30, 60, 120]    sym_freq_9 : []
# 227                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 228   2023-06-06    [30, 60, 120]        sym_freq_12: []
# 229                 [30, 60, 120]        sym_freq_9 : []
# 230                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 231                 [15, 30, 60, 120]    sym_freq_12: []
# 232                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 233                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 234   2023-06-05    [30, 60, 120]        sym_freq_12: []
# 235                 [30, 60, 120]        sym_freq_9 : []
# 236                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 237                 [15, 30, 60, 120]    sym_freq_12: []
# 238                 [15, 30, 60, 120]    sym_freq_9 : []
# 239                 [15, 30, 60, 120]    sym_freq_8 : ['META', 'SKYW']
#
# 240   2023-06-02    [30, 60, 120]        sym_freq_12: []
# 241                 [30, 60, 120]        sym_freq_9 : []
# 242                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 243                 [15, 30, 60, 120]    sym_freq_12: []
# 244                 [15, 30, 60, 120]    sym_freq_9 : ['META']
# 245                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 246   2023-06-01    [30, 60, 120]        sym_freq_12: []
# 247                 [30, 60, 120]        sym_freq_9 : []
# 248                 [30, 60, 120]        sym_freq_8 : ['META', 'NVDA']
# 249                 [15, 30, 60, 120]    sym_freq_12: []
# 250                 [15, 30, 60, 120]    sym_freq_9 : ['AVGO', 'RMBS']
# 251                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 252   2023-05-31    [30, 60, 120]        sym_freq_12: []
# 253                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 254                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA']
# 255                 [15, 30, 60, 120]    sym_freq_12: []
# 256                 [15, 30, 60, 120]    sym_freq_9 : []
# 257                 [15, 30, 60, 120]    sym_freq_8 : ['RMBS']
#
# 258   2023-05-30    [30, 60, 120]        sym_freq_12: []
# 259                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 260                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA']
# 261                 [15, 30, 60, 120]    sym_freq_12: []
# 262                 [15, 30, 60, 120]    sym_freq_9 : []
# 263                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 264   2023-05-26    [30, 60, 120]        sym_freq_12: []
# 265                 [30, 60, 120]        sym_freq_9 : ['AVGO', 'SHV']
# 266                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 267                 [15, 30, 60, 120]    sym_freq_12: ['AVGO']
# 268                 [15, 30, 60, 120]    sym_freq_9 : ['RMBS']
# 269                 [15, 30, 60, 120]    sym_freq_8 : ['AMD']
#
# 270   2023-05-25    [30, 60, 120]        sym_freq_12: []
# 271                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 272                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'NVDA']
# 273                 [15, 30, 60, 120]    sym_freq_12: []
# 274                 [15, 30, 60, 120]    sym_freq_9 : []
# 275                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 276   2023-05-24    [30, 60, 120]        sym_freq_12: []
# 277                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 278                 [30, 60, 120]        sym_freq_8 : []
# 279                 [15, 30, 60, 120]    sym_freq_12: []
# 280                 [15, 30, 60, 120]    sym_freq_9 : []
# 281                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 282   2023-05-23    [30, 60, 120]        sym_freq_12: []
# 283                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 284                 [30, 60, 120]        sym_freq_8 : []
# 285                 [15, 30, 60, 120]    sym_freq_12: []
# 286                 [15, 30, 60, 120]    sym_freq_9 : []
# 287                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 288   2023-05-22    [30, 60, 120]        sym_freq_12: []
# 289                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 290                 [30, 60, 120]        sym_freq_8 : []
# 291                 [15, 30, 60, 120]    sym_freq_12: []
# 292                 [15, 30, 60, 120]    sym_freq_9 : []
# 293                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 294   2023-05-19    [30, 60, 120]        sym_freq_12: []
# 295                 [30, 60, 120]        sym_freq_9 : []
# 296                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 297                 [15, 30, 60, 120]    sym_freq_12: []
# 298                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 299                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 300   2023-05-18    [30, 60, 120]        sym_freq_12: []
# 301                 [30, 60, 120]        sym_freq_9 : []
# 302                 [30, 60, 120]        sym_freq_8 : ['SHV', 'TMHC']
# 303                 [15, 30, 60, 120]    sym_freq_12: []
# 304                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 305                 [15, 30, 60, 120]    sym_freq_8 : ['TMHC']
#
# 306   2023-05-17    [30, 60, 120]        sym_freq_12: []
# 307                 [30, 60, 120]        sym_freq_9 : []
# 308                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 309                 [15, 30, 60, 120]    sym_freq_12: []
# 310                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 311                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 312   2023-05-16    [30, 60, 120]        sym_freq_12: []
# 313                 [30, 60, 120]        sym_freq_9 : []
# 314                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 315                 [15, 30, 60, 120]    sym_freq_12: []
# 316                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 317                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 318   2023-05-15    [30, 60, 120]        sym_freq_12: []
# 319                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 320                 [30, 60, 120]        sym_freq_8 : []
# 321                 [15, 30, 60, 120]    sym_freq_12: []
# 322                 [15, 30, 60, 120]    sym_freq_9 : []
# 323                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 324   2023-05-12    [30, 60, 120]        sym_freq_12: []
# 325                 [30, 60, 120]        sym_freq_9 : []
# 326                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 327                 [15, 30, 60, 120]    sym_freq_12: []
# 328                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE', 'SHV']
# 329                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 330   2023-05-11    [30, 60, 120]        sym_freq_12: []
# 331                 [30, 60, 120]        sym_freq_9 : []
# 332                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 333                 [15, 30, 60, 120]    sym_freq_12: []
# 334                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 335                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 336   2023-05-10    [30, 60, 120]        sym_freq_12: []
# 337                 [30, 60, 120]        sym_freq_9 : []
# 338                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 339                 [15, 30, 60, 120]    sym_freq_12: []
# 340                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 341                 [15, 30, 60, 120]    sym_freq_8 : ['BLDR']
#
# 342   2023-05-09    [30, 60, 120]        sym_freq_12: []
# 343                 [30, 60, 120]        sym_freq_9 : []
# 344                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 345                 [15, 30, 60, 120]    sym_freq_12: []
# 346                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 347                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 348   2023-05-08    [30, 60, 120]        sym_freq_12: []
# 349                 [30, 60, 120]        sym_freq_9 : []
# 350                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 351                 [15, 30, 60, 120]    sym_freq_12: []
# 352                 [15, 30, 60, 120]    sym_freq_9 : []
# 353                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 354   2023-05-05    [30, 60, 120]        sym_freq_12: []
# 355                 [30, 60, 120]        sym_freq_9 : []
# 356                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 357                 [15, 30, 60, 120]    sym_freq_12: []
# 358                 [15, 30, 60, 120]    sym_freq_9 : []
# 359                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 360   2023-05-04    [30, 60, 120]        sym_freq_12: []
# 361                 [30, 60, 120]        sym_freq_9 : []
# 362                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 363                 [15, 30, 60, 120]    sym_freq_12: []
# 364                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP']
# 365                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 366   2023-05-03    [30, 60, 120]        sym_freq_12: []
# 367                 [30, 60, 120]        sym_freq_9 : []
# 368                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 369                 [15, 30, 60, 120]    sym_freq_12: []
# 370                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE']
# 371                 [15, 30, 60, 120]    sym_freq_8 : ['CCEP', 'SHV', 'SKYW']
#
# 372   2023-05-02    [30, 60, 120]        sym_freq_12: []
# 373                 [30, 60, 120]        sym_freq_9 : []
# 374                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 375                 [15, 30, 60, 120]    sym_freq_12: []
# 376                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP', 'ISEE', 'SHV']
# 377                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 378   2023-05-01    [30, 60, 120]        sym_freq_12: []
# 379                 [30, 60, 120]        sym_freq_9 : []
# 380                 [30, 60, 120]        sym_freq_8 : []
# 381                 [15, 30, 60, 120]    sym_freq_12: []
# 382                 [15, 30, 60, 120]    sym_freq_9 : []
# 383                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 384   2023-04-28    [30, 60, 120]        sym_freq_12: []
# 385                 [30, 60, 120]        sym_freq_9 : []
# 386                 [30, 60, 120]        sym_freq_8 : []
# 387                 [15, 30, 60, 120]    sym_freq_12: []
# 388                 [15, 30, 60, 120]    sym_freq_9 : []
# 389                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 390   2023-04-27    [30, 60, 120]        sym_freq_12: []
# 391                 [30, 60, 120]        sym_freq_9 : []
# 392                 [30, 60, 120]        sym_freq_8 : []
# 393                 [15, 30, 60, 120]    sym_freq_12: []
# 394                 [15, 30, 60, 120]    sym_freq_9 : []
# 395                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 396   2023-04-26    [30, 60, 120]        sym_freq_12: []
# 397                 [30, 60, 120]        sym_freq_9 : []
# 398                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 399                 [15, 30, 60, 120]    sym_freq_12: []
# 400                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 401                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 402   2023-04-25    [30, 60, 120]        sym_freq_12: []
# 403                 [30, 60, 120]        sym_freq_9 : []
# 404                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 405                 [15, 30, 60, 120]    sym_freq_12: []
# 406                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 407                 [15, 30, 60, 120]    sym_freq_8 : ['ELF']
#
# 408   2023-04-24    [30, 60, 120]        sym_freq_12: []
# 409                 [30, 60, 120]        sym_freq_9 : []
# 410                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 411                 [15, 30, 60, 120]    sym_freq_12: []
# 412                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 413                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 414   2023-04-21    [30, 60, 120]        sym_freq_12: []
# 415                 [30, 60, 120]        sym_freq_9 : []
# 416                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 417                 [15, 30, 60, 120]    sym_freq_12: []
# 418                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 419                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 420   2023-04-20    [30, 60, 120]        sym_freq_12: []
# 421                 [30, 60, 120]        sym_freq_9 : []
# 422                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 423                 [15, 30, 60, 120]    sym_freq_12: []
# 424                 [15, 30, 60, 120]    sym_freq_9 : []
# 425                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 426   2023-04-19    [30, 60, 120]        sym_freq_12: []
# 427                 [30, 60, 120]        sym_freq_9 : []
# 428                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 429                 [15, 30, 60, 120]    sym_freq_12: []
# 430                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 431                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 432   2023-04-18    [30, 60, 120]        sym_freq_12: []
# 433                 [30, 60, 120]        sym_freq_9 : []
# 434                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 435                 [15, 30, 60, 120]    sym_freq_12: []
# 436                 [15, 30, 60, 120]    sym_freq_9 : []
# 437                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 438   2023-04-17    [30, 60, 120]        sym_freq_12: []
# 439                 [30, 60, 120]        sym_freq_9 : []
# 440                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 441                 [15, 30, 60, 120]    sym_freq_12: []
# 442                 [15, 30, 60, 120]    sym_freq_9 : []
# 443                 [15, 30, 60, 120]    sym_freq_8 : ['ELF', 'SHV']
#
# 444   2023-04-14    [30, 60, 120]        sym_freq_12: []
# 445                 [30, 60, 120]        sym_freq_9 : []
# 446                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 447                 [15, 30, 60, 120]    sym_freq_12: []
# 448                 [15, 30, 60, 120]    sym_freq_9 : []
# 449                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 450   2023-04-13    [30, 60, 120]        sym_freq_12: []
# 451                 [30, 60, 120]        sym_freq_9 : []
# 452                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 453                 [15, 30, 60, 120]    sym_freq_12: []
# 454                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 455                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 456   2023-04-12    [30, 60, 120]        sym_freq_12: []
# 457                 [30, 60, 120]        sym_freq_9 : []
# 458                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 459                 [15, 30, 60, 120]    sym_freq_12: []
# 460                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 461                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 462   2023-04-11    [30, 60, 120]        sym_freq_12: []
# 463                 [30, 60, 120]        sym_freq_9 : []
# 464                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 465                 [15, 30, 60, 120]    sym_freq_12: []
# 466                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 467                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 468   2023-04-10    [30, 60, 120]        sym_freq_12: []
# 469                 [30, 60, 120]        sym_freq_9 : []
# 470                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 471                 [15, 30, 60, 120]    sym_freq_12: []
# 472                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 473                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 474   2023-04-06    [30, 60, 120]        sym_freq_12: []
# 475                 [30, 60, 120]        sym_freq_9 : []
# 476                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 477                 [15, 30, 60, 120]    sym_freq_12: []
# 478                 [15, 30, 60, 120]    sym_freq_9 : []
# 479                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 480   2023-04-05    [30, 60, 120]        sym_freq_12: []
# 481                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 482                 [30, 60, 120]        sym_freq_8 : []
# 483                 [15, 30, 60, 120]    sym_freq_12: []
# 484                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 485                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 486   2023-04-04    [30, 60, 120]        sym_freq_12: []
# 487                 [30, 60, 120]        sym_freq_9 : []
# 488                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 489                 [15, 30, 60, 120]    sym_freq_12: []
# 490                 [15, 30, 60, 120]    sym_freq_9 : []
# 491                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA', 'SHV']
#
# 492   2023-04-03    [30, 60, 120]        sym_freq_12: []
# 493                 [30, 60, 120]        sym_freq_9 : []
# 494                 [30, 60, 120]        sym_freq_8 : ['GE', 'NVDA']
# 495                 [15, 30, 60, 120]    sym_freq_12: []
# 496                 [15, 30, 60, 120]    sym_freq_9 : []
# 497                 [15, 30, 60, 120]    sym_freq_8 : ['GE', 'PERI']
#
# 498   2023-03-31    [30, 60, 120]        sym_freq_12: []
# 499                 [30, 60, 120]        sym_freq_9 : []
# 500                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 501                 [15, 30, 60, 120]    sym_freq_12: []
# 502                 [15, 30, 60, 120]    sym_freq_9 : []
# 503                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 504   2023-03-30    [30, 60, 120]        sym_freq_12: []
# 505                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 506                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 507                 [15, 30, 60, 120]    sym_freq_12: []
# 508                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 509                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 510   2023-03-29    [30, 60, 120]        sym_freq_12: []
# 511                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 512                 [30, 60, 120]        sym_freq_8 : []
# 513                 [15, 30, 60, 120]    sym_freq_12: []
# 514                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 515                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 516   2023-03-28    [30, 60, 120]        sym_freq_12: []
# 517                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 518                 [30, 60, 120]        sym_freq_8 : []
# 519                 [15, 30, 60, 120]    sym_freq_12: []
# 520                 [15, 30, 60, 120]    sym_freq_9 : []
# 521                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 522   2023-03-27    [30, 60, 120]        sym_freq_12: []
# 523                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 524                 [30, 60, 120]        sym_freq_8 : ['GE']
# 525                 [15, 30, 60, 120]    sym_freq_12: []
# 526                 [15, 30, 60, 120]    sym_freq_9 : []
# 527                 [15, 30, 60, 120]    sym_freq_8 : ['GE', 'NVDA', 'SGEN']
#
# 528   2023-03-24    [30, 60, 120]        sym_freq_12: []
# 529                 [30, 60, 120]        sym_freq_9 : []
# 530                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 531                 [15, 30, 60, 120]    sym_freq_12: []
# 532                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 533                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 534   2023-03-23    [30, 60, 120]        sym_freq_12: []
# 535                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 536                 [30, 60, 120]        sym_freq_8 : []
# 537                 [15, 30, 60, 120]    sym_freq_12: []
# 538                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 539                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'GE']
#
# 540   2023-03-22    [30, 60, 120]        sym_freq_12: []
# 541                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 542                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 543                 [15, 30, 60, 120]    sym_freq_12: []
# 544                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'NVDA']
# 545                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 546   2023-03-21    [30, 60, 120]        sym_freq_12: []
# 547                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 548                 [30, 60, 120]        sym_freq_8 : ['GE']
# 549                 [15, 30, 60, 120]    sym_freq_12: []
# 550                 [15, 30, 60, 120]    sym_freq_9 : ['GE']
# 551                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 552   2023-03-20    [30, 60, 120]        sym_freq_12: []
# 553                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 554                 [30, 60, 120]        sym_freq_8 : []
# 555                 [15, 30, 60, 120]    sym_freq_12: []
# 556                 [15, 30, 60, 120]    sym_freq_9 : []
# 557                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 558   2023-03-17    [30, 60, 120]        sym_freq_12: []
# 559                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 560                 [30, 60, 120]        sym_freq_8 : ['GE']
# 561                 [15, 30, 60, 120]    sym_freq_12: []
# 562                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'GE']
# 563                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 564   2023-03-16    [30, 60, 120]        sym_freq_12: []
# 565                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 566                 [30, 60, 120]        sym_freq_8 : []
# 567                 [15, 30, 60, 120]    sym_freq_12: []
# 568                 [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 569                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 570   2023-03-15    [30, 60, 120]        sym_freq_12: []
# 571                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 572                 [30, 60, 120]        sym_freq_8 : []
# 573                 [15, 30, 60, 120]    sym_freq_12: []
# 574                 [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 575                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'FCN']

# %%
model_top_picks = [([30, 60, 120], 'sym_freq_9'), ([15, 30, 60, 120], 'sym_freq_12'), ([30, 60, 120], 'sym_freq_8')]

# %%
df_model_top_picks = pickle_load(path_data_dump, fp_df_model_top_picks)

z_items   = zip(d_lbk_freq, picks)
for i, item in enumerate(z_items):
  _date, _days_lookback, _sym_freq, _syms = item[0][0], item[0][1], item[0][2], item[1][1]
  print(i, _date, _days_lookback, _sym_freq, _syms)
  dlb_sym_freq = (_days_lookback, _sym_freq)
  if dlb_sym_freq in model_top_picks and _syms:
    row_add = [_date, _days_lookback, _sym_freq, _syms]
    df_model_top_picks.loc[len(df_model_top_picks)] = row_add
    print(f'added row to df_model_top_picks:\n{row_add}\n')
# Out:
# 0 2023-08-08 [30, 60, 120] sym_freq_12 []
# 1 2023-08-08 [30, 60, 120] sym_freq_9 []
# 2 2023-08-08 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-08', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 3 2023-08-08 [15, 30, 60, 120] sym_freq_12 []
# 4 2023-08-08 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 5 2023-08-08 [15, 30, 60, 120] sym_freq_8 []
# 6 2023-08-07 [30, 60, 120] sym_freq_12 []
# 7 2023-08-07 [30, 60, 120] sym_freq_9 []
# 8 2023-08-07 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-07', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 9 2023-08-07 [15, 30, 60, 120] sym_freq_12 []
# 10 2023-08-07 [15, 30, 60, 120] sym_freq_9 []
# 11 2023-08-07 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 12 2023-08-04 [30, 60, 120] sym_freq_12 []
# 13 2023-08-04 [30, 60, 120] sym_freq_9 []
# 14 2023-08-04 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 15 2023-08-04 [15, 30, 60, 120] sym_freq_12 []
# 16 2023-08-04 [15, 30, 60, 120] sym_freq_9 []
# 17 2023-08-04 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 18 2023-08-03 [30, 60, 120] sym_freq_12 []
# 19 2023-08-03 [30, 60, 120] sym_freq_9 []
# 20 2023-08-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 21 2023-08-03 [15, 30, 60, 120] sym_freq_12 []
# 22 2023-08-03 [15, 30, 60, 120] sym_freq_9 []
# 23 2023-08-03 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 24 2023-08-02 [30, 60, 120] sym_freq_12 []
# 25 2023-08-02 [30, 60, 120] sym_freq_9 []
# 26 2023-08-02 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 27 2023-08-02 [15, 30, 60, 120] sym_freq_12 []
# 28 2023-08-02 [15, 30, 60, 120] sym_freq_9 ['LOB']
# 29 2023-08-02 [15, 30, 60, 120] sym_freq_8 []
# 30 2023-08-01 [30, 60, 120] sym_freq_12 []
# 31 2023-08-01 [30, 60, 120] sym_freq_9 []
# 32 2023-08-01 [30, 60, 120] sym_freq_8 []
# 33 2023-08-01 [15, 30, 60, 120] sym_freq_12 []
# 34 2023-08-01 [15, 30, 60, 120] sym_freq_9 ['LOB']
# 35 2023-08-01 [15, 30, 60, 120] sym_freq_8 ['SMCI']
# 36 2023-07-27 [30, 60, 120] sym_freq_12 []
# 37 2023-07-27 [30, 60, 120] sym_freq_9 []
# 38 2023-07-27 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-27', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 39 2023-07-27 [15, 30, 60, 120] sym_freq_12 []
# 40 2023-07-27 [15, 30, 60, 120] sym_freq_9 ['JOE']
# 41 2023-07-27 [15, 30, 60, 120] sym_freq_8 []
# 42 2023-07-26 [30, 60, 120] sym_freq_12 []
# 43 2023-07-26 [30, 60, 120] sym_freq_9 []
# 44 2023-07-26 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-26', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 45 2023-07-26 [15, 30, 60, 120] sym_freq_12 []
# 46 2023-07-26 [15, 30, 60, 120] sym_freq_9 []
# 47 2023-07-26 [15, 30, 60, 120] sym_freq_8 []
# 48 2023-07-25 [30, 60, 120] sym_freq_12 []
# 49 2023-07-25 [30, 60, 120] sym_freq_9 []
# 50 2023-07-25 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-25', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 51 2023-07-25 [15, 30, 60, 120] sym_freq_12 []
# 52 2023-07-25 [15, 30, 60, 120] sym_freq_9 []
# 53 2023-07-25 [15, 30, 60, 120] sym_freq_8 []
# 54 2023-07-21 [30, 60, 120] sym_freq_12 []
# 55 2023-07-21 [30, 60, 120] sym_freq_9 []
# 56 2023-07-21 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-21', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 57 2023-07-21 [15, 30, 60, 120] sym_freq_12 []
# 58 2023-07-21 [15, 30, 60, 120] sym_freq_9 ['SHV', 'SIRI']
# 59 2023-07-21 [15, 30, 60, 120] sym_freq_8 []
# 60 2023-07-20 [30, 60, 120] sym_freq_12 []
# 61 2023-07-20 [30, 60, 120] sym_freq_9 []
# 62 2023-07-20 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-20', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 63 2023-07-20 [15, 30, 60, 120] sym_freq_12 []
# 64 2023-07-20 [15, 30, 60, 120] sym_freq_9 ['SHV', 'SIRI']
# 65 2023-07-20 [15, 30, 60, 120] sym_freq_8 []
# 66 2023-07-18 [30, 60, 120] sym_freq_12 []
# 67 2023-07-18 [30, 60, 120] sym_freq_9 []
# 68 2023-07-18 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 69 2023-07-18 [15, 30, 60, 120] sym_freq_12 []
# 70 2023-07-18 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 71 2023-07-18 [15, 30, 60, 120] sym_freq_8 ['BCC']
# 72 2023-07-14 [30, 60, 120] sym_freq_12 []
# 73 2023-07-14 [30, 60, 120] sym_freq_9 []
# 74 2023-07-14 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 75 2023-07-14 [15, 30, 60, 120] sym_freq_12 []
# 76 2023-07-14 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 77 2023-07-14 [15, 30, 60, 120] sym_freq_8 ['BCC']
# 78 2023-07-13 [30, 60, 120] sym_freq_12 []
# 79 2023-07-13 [30, 60, 120] sym_freq_9 []
# 80 2023-07-13 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-13', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 81 2023-07-13 [15, 30, 60, 120] sym_freq_12 []
# 82 2023-07-13 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 83 2023-07-13 [15, 30, 60, 120] sym_freq_8 ['BCC', 'SKYW']
# 84 2023-07-12 [30, 60, 120] sym_freq_12 []
# 85 2023-07-12 [30, 60, 120] sym_freq_9 []
# 86 2023-07-12 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-12', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 87 2023-07-12 [15, 30, 60, 120] sym_freq_12 []
# 88 2023-07-12 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 89 2023-07-12 [15, 30, 60, 120] sym_freq_8 ['BZH', 'SKYW']
# 90 2023-07-11 [30, 60, 120] sym_freq_12 []
# 91 2023-07-11 [30, 60, 120] sym_freq_9 []
# 92 2023-07-11 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-11', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 93 2023-07-11 [15, 30, 60, 120] sym_freq_12 []
# 94 2023-07-11 [15, 30, 60, 120] sym_freq_9 []
# 95 2023-07-11 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 96 2023-07-10 [30, 60, 120] sym_freq_12 []
# 97 2023-07-10 [30, 60, 120] sym_freq_9 []
# 98 2023-07-10 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-10', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 99 2023-07-10 [15, 30, 60, 120] sym_freq_12 []
# 100 2023-07-10 [15, 30, 60, 120] sym_freq_9 []
# 101 2023-07-10 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 102 2023-07-07 [30, 60, 120] sym_freq_12 []
# 103 2023-07-07 [30, 60, 120] sym_freq_9 []
# 104 2023-07-07 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-07', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 105 2023-07-07 [15, 30, 60, 120] sym_freq_12 []
# 106 2023-07-07 [15, 30, 60, 120] sym_freq_9 []
# 107 2023-07-07 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 108 2023-07-06 [30, 60, 120] sym_freq_12 []
# 109 2023-07-06 [30, 60, 120] sym_freq_9 []
# 110 2023-07-06 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-06', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 111 2023-07-06 [15, 30, 60, 120] sym_freq_12 []
# 112 2023-07-06 [15, 30, 60, 120] sym_freq_9 []
# 113 2023-07-06 [15, 30, 60, 120] sym_freq_8 ['CCL', 'SKYW']
# 114 2023-07-05 [30, 60, 120] sym_freq_12 []
# 115 2023-07-05 [30, 60, 120] sym_freq_9 []
# 116 2023-07-05 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-05', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 117 2023-07-05 [15, 30, 60, 120] sym_freq_12 []
# 118 2023-07-05 [15, 30, 60, 120] sym_freq_9 []
# 119 2023-07-05 [15, 30, 60, 120] sym_freq_8 ['CCL']
# 120 2023-07-03 [30, 60, 120] sym_freq_12 []
# 121 2023-07-03 [30, 60, 120] sym_freq_9 []
# 122 2023-07-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 123 2023-07-03 [15, 30, 60, 120] sym_freq_12 []
# 124 2023-07-03 [15, 30, 60, 120] sym_freq_9 []
# 125 2023-07-03 [15, 30, 60, 120] sym_freq_8 ['CCL', 'SKYW', 'W']
# 126 2023-06-30 [30, 60, 120] sym_freq_12 []
# 127 2023-06-30 [30, 60, 120] sym_freq_9 []
# 128 2023-06-30 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-30', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 129 2023-06-30 [15, 30, 60, 120] sym_freq_12 []
# 130 2023-06-30 [15, 30, 60, 120] sym_freq_9 ['SKYW']
# 131 2023-06-30 [15, 30, 60, 120] sym_freq_8 ['CCL']
# 132 2023-06-29 [30, 60, 120] sym_freq_12 []
# 133 2023-06-29 [30, 60, 120] sym_freq_9 []
# 134 2023-06-29 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-29', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 135 2023-06-29 [15, 30, 60, 120] sym_freq_12 []
# 136 2023-06-29 [15, 30, 60, 120] sym_freq_9 []
# 137 2023-06-29 [15, 30, 60, 120] sym_freq_8 []
# 138 2023-06-28 [30, 60, 120] sym_freq_12 []
# 139 2023-06-28 [30, 60, 120] sym_freq_9 []
# 140 2023-06-28 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-28', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 141 2023-06-28 [15, 30, 60, 120] sym_freq_12 []
# 142 2023-06-28 [15, 30, 60, 120] sym_freq_9 []
# 143 2023-06-28 [15, 30, 60, 120] sym_freq_8 []
# 144 2023-06-27 [30, 60, 120] sym_freq_12 []
# 145 2023-06-27 [30, 60, 120] sym_freq_9 []
# 146 2023-06-27 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-27', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 147 2023-06-27 [15, 30, 60, 120] sym_freq_12 []
# 148 2023-06-27 [15, 30, 60, 120] sym_freq_9 []
# 149 2023-06-27 [15, 30, 60, 120] sym_freq_8 []
# 150 2023-06-26 [30, 60, 120] sym_freq_12 []
# 151 2023-06-26 [30, 60, 120] sym_freq_9 []
# 152 2023-06-26 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-26', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 153 2023-06-26 [15, 30, 60, 120] sym_freq_12 []
# 154 2023-06-26 [15, 30, 60, 120] sym_freq_9 []
# 155 2023-06-26 [15, 30, 60, 120] sym_freq_8 []
# 156 2023-06-23 [30, 60, 120] sym_freq_12 []
# 157 2023-06-23 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-23', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 158 2023-06-23 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-23', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 159 2023-06-23 [15, 30, 60, 120] sym_freq_12 []
# 160 2023-06-23 [15, 30, 60, 120] sym_freq_9 ['CCL', 'NVDA']
# 161 2023-06-23 [15, 30, 60, 120] sym_freq_8 ['AMPH']
# 162 2023-06-22 [30, 60, 120] sym_freq_12 []
# 163 2023-06-22 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-22', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 164 2023-06-22 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-22', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 165 2023-06-22 [15, 30, 60, 120] sym_freq_12 []
# 166 2023-06-22 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 167 2023-06-22 [15, 30, 60, 120] sym_freq_8 ['AMPH', 'PBR']
# 168 2023-06-21 [30, 60, 120] sym_freq_12 []
# 169 2023-06-21 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-21', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 170 2023-06-21 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-21', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 171 2023-06-21 [15, 30, 60, 120] sym_freq_12 []
# 172 2023-06-21 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 173 2023-06-21 [15, 30, 60, 120] sym_freq_8 []
# 174 2023-06-20 [30, 60, 120] sym_freq_12 []
# 175 2023-06-20 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-20', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 176 2023-06-20 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-20', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 177 2023-06-20 [15, 30, 60, 120] sym_freq_12 []
# 178 2023-06-20 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 179 2023-06-20 [15, 30, 60, 120] sym_freq_8 []
# 180 2023-06-16 [30, 60, 120] sym_freq_12 []
# 181 2023-06-16 [30, 60, 120] sym_freq_9 []
# 182 2023-06-16 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-16', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 183 2023-06-16 [15, 30, 60, 120] sym_freq_12 []
# 184 2023-06-16 [15, 30, 60, 120] sym_freq_9 ['SKYW']
# 185 2023-06-16 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 186 2023-06-15 [30, 60, 120] sym_freq_12 []
# 187 2023-06-15 [30, 60, 120] sym_freq_9 []
# 188 2023-06-15 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-15', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 189 2023-06-15 [15, 30, 60, 120] sym_freq_12 []
# 190 2023-06-15 [15, 30, 60, 120] sym_freq_9 []
# 191 2023-06-15 [15, 30, 60, 120] sym_freq_8 ['CCL', 'NVDA', 'SKYW']
# 192 2023-06-14 [30, 60, 120] sym_freq_12 []
# 193 2023-06-14 [30, 60, 120] sym_freq_9 []
# 194 2023-06-14 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-14', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA', 'SHV']]
#
# 195 2023-06-14 [15, 30, 60, 120] sym_freq_12 []
# 196 2023-06-14 [15, 30, 60, 120] sym_freq_9 ['AVGO']
# 197 2023-06-14 [15, 30, 60, 120] sym_freq_8 ['ORCL', 'SKYW']
# 198 2023-06-13 [30, 60, 120] sym_freq_12 []
# 199 2023-06-13 [30, 60, 120] sym_freq_9 []
# 200 2023-06-13 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 201 2023-06-13 [15, 30, 60, 120] sym_freq_12 []
# 202 2023-06-13 [15, 30, 60, 120] sym_freq_9 []
# 203 2023-06-13 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 204 2023-06-12 [30, 60, 120] sym_freq_12 []
# 205 2023-06-12 [30, 60, 120] sym_freq_9 []
# 206 2023-06-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 207 2023-06-12 [15, 30, 60, 120] sym_freq_12 []
# 208 2023-06-12 [15, 30, 60, 120] sym_freq_9 []
# 209 2023-06-12 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 210 2023-06-09 [30, 60, 120] sym_freq_12 []
# 211 2023-06-09 [30, 60, 120] sym_freq_9 []
# 212 2023-06-09 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-09', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 213 2023-06-09 [15, 30, 60, 120] sym_freq_12 []
# 214 2023-06-09 [15, 30, 60, 120] sym_freq_9 []
# 215 2023-06-09 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 216 2023-06-08 [30, 60, 120] sym_freq_12 []
# 217 2023-06-08 [30, 60, 120] sym_freq_9 []
# 218 2023-06-08 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-08', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 219 2023-06-08 [15, 30, 60, 120] sym_freq_12 []
# 220 2023-06-08 [15, 30, 60, 120] sym_freq_9 []
# 221 2023-06-08 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 222 2023-06-07 [30, 60, 120] sym_freq_12 []
# 223 2023-06-07 [30, 60, 120] sym_freq_9 []
# 224 2023-06-07 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-07', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 225 2023-06-07 [15, 30, 60, 120] sym_freq_12 []
# 226 2023-06-07 [15, 30, 60, 120] sym_freq_9 []
# 227 2023-06-07 [15, 30, 60, 120] sym_freq_8 []
# 228 2023-06-06 [30, 60, 120] sym_freq_12 []
# 229 2023-06-06 [30, 60, 120] sym_freq_9 []
# 230 2023-06-06 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-06', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 231 2023-06-06 [15, 30, 60, 120] sym_freq_12 []
# 232 2023-06-06 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 233 2023-06-06 [15, 30, 60, 120] sym_freq_8 []
# 234 2023-06-05 [30, 60, 120] sym_freq_12 []
# 235 2023-06-05 [30, 60, 120] sym_freq_9 []
# 236 2023-06-05 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-05', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 237 2023-06-05 [15, 30, 60, 120] sym_freq_12 []
# 238 2023-06-05 [15, 30, 60, 120] sym_freq_9 []
# 239 2023-06-05 [15, 30, 60, 120] sym_freq_8 ['META', 'SKYW']
# 240 2023-06-02 [30, 60, 120] sym_freq_12 []
# 241 2023-06-02 [30, 60, 120] sym_freq_9 []
# 242 2023-06-02 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-02', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 243 2023-06-02 [15, 30, 60, 120] sym_freq_12 []
# 244 2023-06-02 [15, 30, 60, 120] sym_freq_9 ['META']
# 245 2023-06-02 [15, 30, 60, 120] sym_freq_8 []
# 246 2023-06-01 [30, 60, 120] sym_freq_12 []
# 247 2023-06-01 [30, 60, 120] sym_freq_9 []
# 248 2023-06-01 [30, 60, 120] sym_freq_8 ['META', 'NVDA']
# added row to df_model_top_picks:
# ['2023-06-01', [30, 60, 120], 'sym_freq_8', ['META', 'NVDA']]
#
# 249 2023-06-01 [15, 30, 60, 120] sym_freq_12 []
# 250 2023-06-01 [15, 30, 60, 120] sym_freq_9 ['AVGO', 'RMBS']
# 251 2023-06-01 [15, 30, 60, 120] sym_freq_8 []
# 252 2023-05-31 [30, 60, 120] sym_freq_12 []
# 253 2023-05-31 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-31', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 254 2023-05-31 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-31', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA']]
#
# 255 2023-05-31 [15, 30, 60, 120] sym_freq_12 []
# 256 2023-05-31 [15, 30, 60, 120] sym_freq_9 []
# 257 2023-05-31 [15, 30, 60, 120] sym_freq_8 ['RMBS']
# 258 2023-05-30 [30, 60, 120] sym_freq_12 []
# 259 2023-05-30 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 260 2023-05-30 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-30', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA']]
#
# 261 2023-05-30 [15, 30, 60, 120] sym_freq_12 []
# 262 2023-05-30 [15, 30, 60, 120] sym_freq_9 []
# 263 2023-05-30 [15, 30, 60, 120] sym_freq_8 []
# 264 2023-05-26 [30, 60, 120] sym_freq_12 []
# 265 2023-05-26 [30, 60, 120] sym_freq_9 ['AVGO', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-26', [30, 60, 120], 'sym_freq_9', ['AVGO', 'SHV']]
#
# 266 2023-05-26 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-05-26', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 267 2023-05-26 [15, 30, 60, 120] sym_freq_12 ['AVGO']
# added row to df_model_top_picks:
# ['2023-05-26', [15, 30, 60, 120], 'sym_freq_12', ['AVGO']]
#
# 268 2023-05-26 [15, 30, 60, 120] sym_freq_9 ['RMBS']
# 269 2023-05-26 [15, 30, 60, 120] sym_freq_8 ['AMD']
# 270 2023-05-25 [30, 60, 120] sym_freq_12 []
# 271 2023-05-25 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-25', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 272 2023-05-25 [30, 60, 120] sym_freq_8 ['FTSM', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-25', [30, 60, 120], 'sym_freq_8', ['FTSM', 'NVDA']]
#
# 273 2023-05-25 [15, 30, 60, 120] sym_freq_12 []
# 274 2023-05-25 [15, 30, 60, 120] sym_freq_9 []
# 275 2023-05-25 [15, 30, 60, 120] sym_freq_8 ['FTSM']
# 276 2023-05-24 [30, 60, 120] sym_freq_12 []
# 277 2023-05-24 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-24', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 278 2023-05-24 [30, 60, 120] sym_freq_8 []
# 279 2023-05-24 [15, 30, 60, 120] sym_freq_12 []
# 280 2023-05-24 [15, 30, 60, 120] sym_freq_9 []
# 281 2023-05-24 [15, 30, 60, 120] sym_freq_8 []
# 282 2023-05-23 [30, 60, 120] sym_freq_12 []
# 283 2023-05-23 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 284 2023-05-23 [30, 60, 120] sym_freq_8 []
# 285 2023-05-23 [15, 30, 60, 120] sym_freq_12 []
# 286 2023-05-23 [15, 30, 60, 120] sym_freq_9 []
# 287 2023-05-23 [15, 30, 60, 120] sym_freq_8 []
# 288 2023-05-22 [30, 60, 120] sym_freq_12 []
# 289 2023-05-22 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 290 2023-05-22 [30, 60, 120] sym_freq_8 []
# 291 2023-05-22 [15, 30, 60, 120] sym_freq_12 []
# 292 2023-05-22 [15, 30, 60, 120] sym_freq_9 []
# 293 2023-05-22 [15, 30, 60, 120] sym_freq_8 []
# 294 2023-05-19 [30, 60, 120] sym_freq_12 []
# 295 2023-05-19 [30, 60, 120] sym_freq_9 []
# 296 2023-05-19 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 297 2023-05-19 [15, 30, 60, 120] sym_freq_12 []
# 298 2023-05-19 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 299 2023-05-19 [15, 30, 60, 120] sym_freq_8 []
# 300 2023-05-18 [30, 60, 120] sym_freq_12 []
# 301 2023-05-18 [30, 60, 120] sym_freq_9 []
# 302 2023-05-18 [30, 60, 120] sym_freq_8 ['SHV', 'TMHC']
# added row to df_model_top_picks:
# ['2023-05-18', [30, 60, 120], 'sym_freq_8', ['SHV', 'TMHC']]
#
# 303 2023-05-18 [15, 30, 60, 120] sym_freq_12 []
# 304 2023-05-18 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 305 2023-05-18 [15, 30, 60, 120] sym_freq_8 ['TMHC']
# 306 2023-05-17 [30, 60, 120] sym_freq_12 []
# 307 2023-05-17 [30, 60, 120] sym_freq_9 []
# 308 2023-05-17 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-17', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 309 2023-05-17 [15, 30, 60, 120] sym_freq_12 []
# 310 2023-05-17 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 311 2023-05-17 [15, 30, 60, 120] sym_freq_8 []
# 312 2023-05-16 [30, 60, 120] sym_freq_12 []
# 313 2023-05-16 [30, 60, 120] sym_freq_9 []
# 314 2023-05-16 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-16', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 315 2023-05-16 [15, 30, 60, 120] sym_freq_12 []
# 316 2023-05-16 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 317 2023-05-16 [15, 30, 60, 120] sym_freq_8 []
# 318 2023-05-15 [30, 60, 120] sym_freq_12 []
# 319 2023-05-15 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 320 2023-05-15 [30, 60, 120] sym_freq_8 []
# 321 2023-05-15 [15, 30, 60, 120] sym_freq_12 []
# 322 2023-05-15 [15, 30, 60, 120] sym_freq_9 []
# 323 2023-05-15 [15, 30, 60, 120] sym_freq_8 ['ISEE']
# 324 2023-05-12 [30, 60, 120] sym_freq_12 []
# 325 2023-05-12 [30, 60, 120] sym_freq_9 []
# 326 2023-05-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 327 2023-05-12 [15, 30, 60, 120] sym_freq_12 []
# 328 2023-05-12 [15, 30, 60, 120] sym_freq_9 ['ISEE', 'SHV']
# 329 2023-05-12 [15, 30, 60, 120] sym_freq_8 []
# 330 2023-05-11 [30, 60, 120] sym_freq_12 []
# 331 2023-05-11 [30, 60, 120] sym_freq_9 []
# 332 2023-05-11 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-11', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 333 2023-05-11 [15, 30, 60, 120] sym_freq_12 []
# 334 2023-05-11 [15, 30, 60, 120] sym_freq_9 ['BLDR']
# 335 2023-05-11 [15, 30, 60, 120] sym_freq_8 []
# 336 2023-05-10 [30, 60, 120] sym_freq_12 []
# 337 2023-05-10 [30, 60, 120] sym_freq_9 []
# 338 2023-05-10 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-10', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 339 2023-05-10 [15, 30, 60, 120] sym_freq_12 []
# 340 2023-05-10 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 341 2023-05-10 [15, 30, 60, 120] sym_freq_8 ['BLDR']
# 342 2023-05-09 [30, 60, 120] sym_freq_12 []
# 343 2023-05-09 [30, 60, 120] sym_freq_9 []
# 344 2023-05-09 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-09', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 345 2023-05-09 [15, 30, 60, 120] sym_freq_12 []
# 346 2023-05-09 [15, 30, 60, 120] sym_freq_9 ['BLDR']
# 347 2023-05-09 [15, 30, 60, 120] sym_freq_8 []
# 348 2023-05-08 [30, 60, 120] sym_freq_12 []
# 349 2023-05-08 [30, 60, 120] sym_freq_9 []
# 350 2023-05-08 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-08', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 351 2023-05-08 [15, 30, 60, 120] sym_freq_12 []
# 352 2023-05-08 [15, 30, 60, 120] sym_freq_9 []
# 353 2023-05-08 [15, 30, 60, 120] sym_freq_8 []
# 354 2023-05-05 [30, 60, 120] sym_freq_12 []
# 355 2023-05-05 [30, 60, 120] sym_freq_9 []
# 356 2023-05-05 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-05', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 357 2023-05-05 [15, 30, 60, 120] sym_freq_12 []
# 358 2023-05-05 [15, 30, 60, 120] sym_freq_9 []
# 359 2023-05-05 [15, 30, 60, 120] sym_freq_8 []
# 360 2023-05-04 [30, 60, 120] sym_freq_12 []
# 361 2023-05-04 [30, 60, 120] sym_freq_9 []
# 362 2023-05-04 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 363 2023-05-04 [15, 30, 60, 120] sym_freq_12 []
# 364 2023-05-04 [15, 30, 60, 120] sym_freq_9 ['CCEP']
# 365 2023-05-04 [15, 30, 60, 120] sym_freq_8 []
# 366 2023-05-03 [30, 60, 120] sym_freq_12 []
# 367 2023-05-03 [30, 60, 120] sym_freq_9 []
# 368 2023-05-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 369 2023-05-03 [15, 30, 60, 120] sym_freq_12 []
# 370 2023-05-03 [15, 30, 60, 120] sym_freq_9 ['ISEE']
# 371 2023-05-03 [15, 30, 60, 120] sym_freq_8 ['CCEP', 'SHV', 'SKYW']
# 372 2023-05-02 [30, 60, 120] sym_freq_12 []
# 373 2023-05-02 [30, 60, 120] sym_freq_9 []
# 374 2023-05-02 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 375 2023-05-02 [15, 30, 60, 120] sym_freq_12 []
# 376 2023-05-02 [15, 30, 60, 120] sym_freq_9 ['CCEP', 'ISEE', 'SHV']
# 377 2023-05-02 [15, 30, 60, 120] sym_freq_8 []
# 378 2023-05-01 [30, 60, 120] sym_freq_12 []
# 379 2023-05-01 [30, 60, 120] sym_freq_9 []
# 380 2023-05-01 [30, 60, 120] sym_freq_8 []
# 381 2023-05-01 [15, 30, 60, 120] sym_freq_12 []
# 382 2023-05-01 [15, 30, 60, 120] sym_freq_9 []
# 383 2023-05-01 [15, 30, 60, 120] sym_freq_8 ['ISEE']
# 384 2023-04-28 [30, 60, 120] sym_freq_12 []
# 385 2023-04-28 [30, 60, 120] sym_freq_9 []
# 386 2023-04-28 [30, 60, 120] sym_freq_8 []
# 387 2023-04-28 [15, 30, 60, 120] sym_freq_12 []
# 388 2023-04-28 [15, 30, 60, 120] sym_freq_9 []
# 389 2023-04-28 [15, 30, 60, 120] sym_freq_8 ['PHM', 'SHV']
# 390 2023-04-27 [30, 60, 120] sym_freq_12 []
# 391 2023-04-27 [30, 60, 120] sym_freq_9 []
# 392 2023-04-27 [30, 60, 120] sym_freq_8 []
# 393 2023-04-27 [15, 30, 60, 120] sym_freq_12 []
# 394 2023-04-27 [15, 30, 60, 120] sym_freq_9 []
# 395 2023-04-27 [15, 30, 60, 120] sym_freq_8 ['PHM', 'SHV']
# 396 2023-04-26 [30, 60, 120] sym_freq_12 []
# 397 2023-04-26 [30, 60, 120] sym_freq_9 []
# 398 2023-04-26 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-26', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 399 2023-04-26 [15, 30, 60, 120] sym_freq_12 []
# 400 2023-04-26 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 401 2023-04-26 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 402 2023-04-25 [30, 60, 120] sym_freq_12 []
# 403 2023-04-25 [30, 60, 120] sym_freq_9 []
# 404 2023-04-25 [30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-25', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 405 2023-04-25 [15, 30, 60, 120] sym_freq_12 []
# 406 2023-04-25 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 407 2023-04-25 [15, 30, 60, 120] sym_freq_8 ['ELF']
# 408 2023-04-24 [30, 60, 120] sym_freq_12 []
# 409 2023-04-24 [30, 60, 120] sym_freq_9 []
# 410 2023-04-24 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-24', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 411 2023-04-24 [15, 30, 60, 120] sym_freq_12 []
# 412 2023-04-24 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 413 2023-04-24 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 414 2023-04-21 [30, 60, 120] sym_freq_12 []
# 415 2023-04-21 [30, 60, 120] sym_freq_9 []
# 416 2023-04-21 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-21', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 417 2023-04-21 [15, 30, 60, 120] sym_freq_12 []
# 418 2023-04-21 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 419 2023-04-21 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 420 2023-04-20 [30, 60, 120] sym_freq_12 []
# 421 2023-04-20 [30, 60, 120] sym_freq_9 []
# 422 2023-04-20 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-20', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 423 2023-04-20 [15, 30, 60, 120] sym_freq_12 []
# 424 2023-04-20 [15, 30, 60, 120] sym_freq_9 []
# 425 2023-04-20 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 426 2023-04-19 [30, 60, 120] sym_freq_12 []
# 427 2023-04-19 [30, 60, 120] sym_freq_9 []
# 428 2023-04-19 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 429 2023-04-19 [15, 30, 60, 120] sym_freq_12 []
# 430 2023-04-19 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 431 2023-04-19 [15, 30, 60, 120] sym_freq_8 []
# 432 2023-04-18 [30, 60, 120] sym_freq_12 []
# 433 2023-04-18 [30, 60, 120] sym_freq_9 []
# 434 2023-04-18 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 435 2023-04-18 [15, 30, 60, 120] sym_freq_12 []
# 436 2023-04-18 [15, 30, 60, 120] sym_freq_9 []
# 437 2023-04-18 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 438 2023-04-17 [30, 60, 120] sym_freq_12 []
# 439 2023-04-17 [30, 60, 120] sym_freq_9 []
# 440 2023-04-17 [30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-17', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 441 2023-04-17 [15, 30, 60, 120] sym_freq_12 []
# 442 2023-04-17 [15, 30, 60, 120] sym_freq_9 []
# 443 2023-04-17 [15, 30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# 444 2023-04-14 [30, 60, 120] sym_freq_12 []
# 445 2023-04-14 [30, 60, 120] sym_freq_9 []
# 446 2023-04-14 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 447 2023-04-14 [15, 30, 60, 120] sym_freq_12 []
# 448 2023-04-14 [15, 30, 60, 120] sym_freq_9 []
# 449 2023-04-14 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 450 2023-04-13 [30, 60, 120] sym_freq_12 []
# 451 2023-04-13 [30, 60, 120] sym_freq_9 []
# 452 2023-04-13 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 453 2023-04-13 [15, 30, 60, 120] sym_freq_12 []
# 454 2023-04-13 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 455 2023-04-13 [15, 30, 60, 120] sym_freq_8 []
# 456 2023-04-12 [30, 60, 120] sym_freq_12 []
# 457 2023-04-12 [30, 60, 120] sym_freq_9 []
# 458 2023-04-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 459 2023-04-12 [15, 30, 60, 120] sym_freq_12 []
# 460 2023-04-12 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 461 2023-04-12 [15, 30, 60, 120] sym_freq_8 []
# 462 2023-04-11 [30, 60, 120] sym_freq_12 []
# 463 2023-04-11 [30, 60, 120] sym_freq_9 []
# 464 2023-04-11 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-11', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 465 2023-04-11 [15, 30, 60, 120] sym_freq_12 []
# 466 2023-04-11 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 467 2023-04-11 [15, 30, 60, 120] sym_freq_8 []
# 468 2023-04-10 [30, 60, 120] sym_freq_12 []
# 469 2023-04-10 [30, 60, 120] sym_freq_9 []
# 470 2023-04-10 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-10', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 471 2023-04-10 [15, 30, 60, 120] sym_freq_12 []
# 472 2023-04-10 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 473 2023-04-10 [15, 30, 60, 120] sym_freq_8 []
# 474 2023-04-06 [30, 60, 120] sym_freq_12 []
# 475 2023-04-06 [30, 60, 120] sym_freq_9 []
# 476 2023-04-06 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-06', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 477 2023-04-06 [15, 30, 60, 120] sym_freq_12 []
# 478 2023-04-06 [15, 30, 60, 120] sym_freq_9 []
# 479 2023-04-06 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 480 2023-04-05 [30, 60, 120] sym_freq_12 []
# 481 2023-04-05 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 482 2023-04-05 [30, 60, 120] sym_freq_8 []
# 483 2023-04-05 [15, 30, 60, 120] sym_freq_12 []
# 484 2023-04-05 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 485 2023-04-05 [15, 30, 60, 120] sym_freq_8 []
# 486 2023-04-04 [30, 60, 120] sym_freq_12 []
# 487 2023-04-04 [30, 60, 120] sym_freq_9 []
# 488 2023-04-04 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-04', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 489 2023-04-04 [15, 30, 60, 120] sym_freq_12 []
# 490 2023-04-04 [15, 30, 60, 120] sym_freq_9 []
# 491 2023-04-04 [15, 30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# 492 2023-04-03 [30, 60, 120] sym_freq_12 []
# 493 2023-04-03 [30, 60, 120] sym_freq_9 []
# 494 2023-04-03 [30, 60, 120] sym_freq_8 ['GE', 'NVDA']
# added row to df_model_top_picks:
# ['2023-04-03', [30, 60, 120], 'sym_freq_8', ['GE', 'NVDA']]
#
# 495 2023-04-03 [15, 30, 60, 120] sym_freq_12 []
# 496 2023-04-03 [15, 30, 60, 120] sym_freq_9 []
# 497 2023-04-03 [15, 30, 60, 120] sym_freq_8 ['GE', 'PERI']
# 498 2023-03-31 [30, 60, 120] sym_freq_12 []
# 499 2023-03-31 [30, 60, 120] sym_freq_9 []
# 500 2023-03-31 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-03-31', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 501 2023-03-31 [15, 30, 60, 120] sym_freq_12 []
# 502 2023-03-31 [15, 30, 60, 120] sym_freq_9 []
# 503 2023-03-31 [15, 30, 60, 120] sym_freq_8 []
# 504 2023-03-30 [30, 60, 120] sym_freq_12 []
# 505 2023-03-30 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 506 2023-03-30 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 507 2023-03-30 [15, 30, 60, 120] sym_freq_12 []
# 508 2023-03-30 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 509 2023-03-30 [15, 30, 60, 120] sym_freq_8 []
# 510 2023-03-29 [30, 60, 120] sym_freq_12 []
# 511 2023-03-29 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-29', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 512 2023-03-29 [30, 60, 120] sym_freq_8 []
# 513 2023-03-29 [15, 30, 60, 120] sym_freq_12 []
# 514 2023-03-29 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 515 2023-03-29 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 516 2023-03-28 [30, 60, 120] sym_freq_12 []
# 517 2023-03-28 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-28', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 518 2023-03-28 [30, 60, 120] sym_freq_8 []
# 519 2023-03-28 [15, 30, 60, 120] sym_freq_12 []
# 520 2023-03-28 [15, 30, 60, 120] sym_freq_9 []
# 521 2023-03-28 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 522 2023-03-27 [30, 60, 120] sym_freq_12 []
# 523 2023-03-27 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 524 2023-03-27 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 525 2023-03-27 [15, 30, 60, 120] sym_freq_12 []
# 526 2023-03-27 [15, 30, 60, 120] sym_freq_9 []
# 527 2023-03-27 [15, 30, 60, 120] sym_freq_8 ['GE', 'NVDA', 'SGEN']
# 528 2023-03-24 [30, 60, 120] sym_freq_12 []
# 529 2023-03-24 [30, 60, 120] sym_freq_9 []
# 530 2023-03-24 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-24', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 531 2023-03-24 [15, 30, 60, 120] sym_freq_12 []
# 532 2023-03-24 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 533 2023-03-24 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 534 2023-03-23 [30, 60, 120] sym_freq_12 []
# 535 2023-03-23 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 536 2023-03-23 [30, 60, 120] sym_freq_8 []
# 537 2023-03-23 [15, 30, 60, 120] sym_freq_12 []
# 538 2023-03-23 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 539 2023-03-23 [15, 30, 60, 120] sym_freq_8 ['FTSM', 'GE']
# 540 2023-03-22 [30, 60, 120] sym_freq_12 []
# 541 2023-03-22 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 542 2023-03-22 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 543 2023-03-22 [15, 30, 60, 120] sym_freq_12 []
# 544 2023-03-22 [15, 30, 60, 120] sym_freq_9 ['FTSM', 'NVDA']
# 545 2023-03-22 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 546 2023-03-21 [30, 60, 120] sym_freq_12 []
# 547 2023-03-21 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 548 2023-03-21 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 549 2023-03-21 [15, 30, 60, 120] sym_freq_12 []
# 550 2023-03-21 [15, 30, 60, 120] sym_freq_9 ['GE']
# 551 2023-03-21 [15, 30, 60, 120] sym_freq_8 []
# 552 2023-03-20 [30, 60, 120] sym_freq_12 []
# 553 2023-03-20 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 554 2023-03-20 [30, 60, 120] sym_freq_8 []
# 555 2023-03-20 [15, 30, 60, 120] sym_freq_12 []
# 556 2023-03-20 [15, 30, 60, 120] sym_freq_9 []
# 557 2023-03-20 [15, 30, 60, 120] sym_freq_8 []
# 558 2023-03-17 [30, 60, 120] sym_freq_12 []
# 559 2023-03-17 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 560 2023-03-17 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 561 2023-03-17 [15, 30, 60, 120] sym_freq_12 []
# 562 2023-03-17 [15, 30, 60, 120] sym_freq_9 ['FTSM', 'GE']
# 563 2023-03-17 [15, 30, 60, 120] sym_freq_8 []
# 564 2023-03-16 [30, 60, 120] sym_freq_12 []
# 565 2023-03-16 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-16', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 566 2023-03-16 [30, 60, 120] sym_freq_8 []
# 567 2023-03-16 [15, 30, 60, 120] sym_freq_12 []
# 568 2023-03-16 [15, 30, 60, 120] sym_freq_9 ['SGEN']
# 569 2023-03-16 [15, 30, 60, 120] sym_freq_8 []
# 570 2023-03-15 [30, 60, 120] sym_freq_12 []
# 571 2023-03-15 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 572 2023-03-15 [30, 60, 120] sym_freq_8 []
# 573 2023-03-15 [15, 30, 60, 120] sym_freq_12 []
# 574 2023-03-15 [15, 30, 60, 120] sym_freq_9 ['SGEN']
# 575 2023-03-15 [15, 30, 60, 120] sym_freq_8 ['AMPH', 'FCN']

# %%
df_model_top_picks = df_model_top_picks.astype(str)
df_model_top_picks = df_model_top_picks.drop_duplicates(keep='last')
df_model_top_picks = df_model_top_picks.sort_values(by=['date', 'days_lookback', 'syms_freq'], ascending=False)
df_model_top_picks = df_model_top_picks.reset_index(drop=True)
pickle_dump(df_model_top_picks, path_data_dump, fp_df_model_top_picks)
print(f'len(df_model_top_picks): {len(df_model_top_picks)}')
print(f'{fp_df_model_top_picks}:\n{df_model_top_picks}')
# Out:
# len(df_model_top_picks): 107
# df_model_top_picks:
#            date  days_lookback   syms_freq          symbols
# 0    2023-08-08  [30, 60, 120]  sym_freq_8  ['SHV', 'STRL']
# 1    2023-08-07  [30, 60, 120]  sym_freq_8          ['SHV']
# 2    2023-08-04  [30, 60, 120]  sym_freq_8          ['SHV']
# 3    2023-08-03  [30, 60, 120]  sym_freq_8          ['SHV']
# 4    2023-08-02  [30, 60, 120]  sym_freq_8          ['SHV']
# ..          ...            ...         ...              ...
# 102  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 103  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 104  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']
# 105  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 106  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
#
# [107 rows x 4 columns]

# %%
df_mp = df_model_top_picks.copy()
df_close = pickle_load(path_data_dump, 'df_close_clean')

# %%
def get_NYSE_date_n(date, dates_NYSE, n, verbose=False):

  if date in dates_NYSE:
    idx_last = len(dates_NYSE) - 1  # last index of dates_NYSE
    idx_date = dates_NYSE.get_loc(date)  # index of date
    idx_date_n = idx_date + n  # index of date_n
    if verbose:
      print(f"date: {date} is in dates_NYSE,  date's position in dates_NYSE is: {idx_date} of {idx_last},  n: {n},  idx_date_n: {idx_date_n},")
    if 0 <= idx_date_n <= idx_last:  # idx_date_n is within bounds of dates_NYSE
      date_n = dates_NYSE[idx_date_n]
      if verbose:      
        print(f'idx_date_n: {idx_date_n} is wiithin bounds of dates_NYSE ("0 to {idx_last}), date_n: {date_n}"\n')
    else:  # idx_date_n is out-of-bounds of dates_NYSE
      date_n = None   
      if verbose:  
        print(f'idx_date_n: {idx_date_n} is out-of-bounds of dates_NYSE ("0 to {idx_last})"\n')
  else:  # date not in dates_NYSE
      date_n = None  
      if verbose:  
        print(f'date: {date} is not in dates_NYSE\n')

  return date_n

# %%
def get_portf_buy(df_close, date, str_symbols, portf_target, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    sym_cnt = len(l_syms)  # number of symbols
    amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
    ar_sym_share = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
    ar_sym_amt = ar_price * ar_sym_share  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_sym_amt)  # total actual portfolio value
    if verbose:
        # print(date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value)    
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_sym_share = }, {ar_sym_amt = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value

# %%
def get_SPY_buy(df_close, date, portf_target, symbol="SPY", verbose=False):   
    import numpy as np
    price = df_close.loc[date][symbol]    
    share = np.floor(portf_target / price)  # array of shares for each symbol
    value = price * share  # array of actual dollar amount invested in each symbol
    if verbose:
        # print(date, symbol, price, share, value)
        print(f'{date = }, {symbol = }, {price = }, {share = }, {value = }')                        
        print(f'{date} {symbol} {value = }')
    return date, price, share, value

# %%
import pandas_market_calendars as mcal
nyse = mcal.get_calendar('NYSE')
dates_NYSE_2013_2023 = nyse.valid_days(start_date='2013-01-01', end_date='2023-12-31').strftime('%Y-%m-%d')
print(f'len(dates_NYSE_2013_2023): {len(dates_NYSE_2013_2023)}')
print(f'dates_NYSE_2013_2023[0]:  {dates_NYSE_2013_2023[0]}, dates_NYSE_2013_2023[-1]: {dates_NYSE_2013_2023[-1]}')
print(f'{dates_NYSE_2013_2023}')
# Out:
# len(dates_NYSE_2013_2023): 2768
# dates_NYSE_2013_2023[0]:  2013-01-02, dates_NYSE_2013_2023[-1]: 2023-12-29
# Index(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-07', '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-14', '2013-01-15',
#        ...
#        '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20', '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29'], dtype='object', length=2768)

# %% [markdown]
# #### TODO: 2023-07-15 only evaluate performance of df_model_picks, after evaluation, append results to df_model_picks_results
#
#
# #### 2023-07-11 got KeyError: "['ISEE'] not in index". ISEE was in past model picks, but since then ISEE was acquired. The symbol was dropped from df_close_clean. Current program recalculate the performance of all the past picks. Rewrite program such that performance of past picks with win records are not recalculated.

# %%
import numpy as np
# from ast import literal_eval
z_date_syms = zip(df_mp.date, df_mp.symbols)

idx_close = df_close.index.strftime('%Y-%m-%d')

n = 1  # n=1 is the buy date
# n = 4  # n=4 is the sell date

date_buy = []  # buy date of portfolio
shares_syms = []  # lists of shares of each symbol brought on date_buy
value_portf = [] # list of porfolio value on date_buy
shares_SPY = []  # list of shares of SPY brought on date_buy
value_SPY = []  # list of value of SPY shares on date_buy 
for date, syms in z_date_syms:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=verbose)

    if next_date_n in idx_close:
        close_date_n = next_date_n
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is in df_close')
        print(f'picks for {date}: {syms}')      
    else:
        close_date_n = None
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is not in df_close')
        print(f'picks for {date}: {syms}')        

    if close_date_n is None:
        p_date = None
        p_l_syms = None
        p_ar_price = None
        p_ar_sym_share = None
        p_ar_sym_amt = None
        p_portf_value = None  # data not available in df_close
        
        s_date = None
        s_price = None
        s_share = None
        s_value = None  # data not available in df_close

        date_buy.append(p_date)
        shares_syms.append(p_l_syms)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)    
        
        print(f"No data for next_date_n {next_date_n}, pick's portf value = None")
        print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else:    
        p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
            get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
        s_date, s_price, s_share, s_value = \
            get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
                
        date_buy.append(p_date)
        shares_syms.append(p_ar_sym_share)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)

        print(f"next_date_n pick's portf value = {p_portf_value}")
        print(f'next_date_n SPY portf value =    {s_value}')

    print('='*20, '\n')
# Out:
# date: 2023-08-08 is in dates_NYSE,  date's position in dates_NYSE is: 2667 of 2767,  n: 1,  idx_date_n: 2668,
# idx_date_n: 2668 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-09"
#
# date: 2023-08-08,  n: 1,  next_date_n: 2023-08-09 is not in df_close
# picks for 2023-08-08: ['SHV', 'STRL']
# No data for next_date_n 2023-08-09, pick's portf value = None
# No data for next_date_n 2023-08-09, SPY portf value =    None
# ====================
#
# date: 2023-08-07 is in dates_NYSE,  date's position in dates_NYSE is: 2666 of 2767,  n: 1,  idx_date_n: 2667,
# idx_date_n: 2667 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-08"
#
# date: 2023-08-07,  n: 1,  next_date_n: 2023-08-08 is in df_close
# picks for 2023-08-07: ['SHV']
# date = '2023-08-08', l_syms = ['SHV'], ar_price = array([110.09999847]), ar_sym_share = array([9.]), ar_sym_amt = array([990.89998627]), portf_value = 990.8999862670898
# 2023-08-08 portf_value = 990.8999862670898
# date = '2023-08-08', symbol = 'SPY', price = 448.75, share = 2.0, value = 897.5
# 2023-08-08 SPY value = 897.5
# next_date_n pick's portf value = 990.8999862670898
# next_date_n SPY portf value =    897.5
# ====================
#
# date: 2023-08-04 is in dates_NYSE,  date's position in dates_NYSE is: 2665 of 2767,  n: 1,  idx_date_n: 2666,
# idx_date_n: 2666 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-07"
#
# date: 2023-08-04,  n: 1,  next_date_n: 2023-08-07 is in df_close
# picks for 2023-08-04: ['SHV']
# date = '2023-08-07', l_syms = ['SHV'], ar_price = array([110.08000183]), ar_sym_share = array([9.]), ar_sym_amt = array([990.72001648]), portf_value = 990.7200164794922
# 2023-08-07 portf_value = 990.7200164794922
# date = '2023-08-07', symbol = 'SPY', price = 450.7099914550781, share = 2.0, value = 901.4199829101562
# 2023-08-07 SPY value = 901.4199829101562
# next_date_n pick's portf value = 990.7200164794922
# next_date_n SPY portf value =    901.4199829101562
# ====================
#
# date: 2023-08-03 is in dates_NYSE,  date's position in dates_NYSE is: 2664 of 2767,  n: 1,  idx_date_n: 2665,
# idx_date_n: 2665 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-04"
#
# date: 2023-08-03,  n: 1,  next_date_n: 2023-08-04 is in df_close
# picks for 2023-08-03: ['SHV']
# date = '2023-08-04', l_syms = ['SHV'], ar_price = array([110.08000183]), ar_sym_share = array([9.]), ar_sym_amt = array([990.72001648]), portf_value = 990.7200164794922
# 2023-08-04 portf_value = 990.7200164794922
# date = '2023-08-04', symbol = 'SPY', price = 446.80999755859375, share = 2.0, value = 893.6199951171875
# 2023-08-04 SPY value = 893.6199951171875
# next_date_n pick's portf value = 990.7200164794922
# next_date_n SPY portf value =    893.6199951171875
# ====================
#
# date: 2023-08-02 is in dates_NYSE,  date's position in dates_NYSE is: 2663 of 2767,  n: 1,  idx_date_n: 2664,
# idx_date_n: 2664 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-03"
#
# date: 2023-08-02,  n: 1,  next_date_n: 2023-08-03 is in df_close
# picks for 2023-08-02: ['SHV']
# date = '2023-08-03', l_syms = ['SHV'], ar_price = array([110.05000305]), ar_sym_share = array([9.]), ar_sym_amt = array([990.45002747]), portf_value = 990.4500274658203
# 2023-08-03 portf_value = 990.4500274658203
# date = '2023-08-03', symbol = 'SPY', price = 448.8399963378906, share = 2.0, value = 897.6799926757812
# 2023-08-03 SPY value = 897.6799926757812
# next_date_n pick's portf value = 990.4500274658203
# next_date_n SPY portf value =    897.6799926757812
# ====================
#
# date: 2023-07-27 is in dates_NYSE,  date's position in dates_NYSE is: 2659 of 2767,  n: 1,  idx_date_n: 2660,
# idx_date_n: 2660 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-28"
#
# date: 2023-07-27,  n: 1,  next_date_n: 2023-07-28 is in df_close
# picks for 2023-07-27: ['SHV']
# date = '2023-07-28', l_syms = ['SHV'], ar_price = array([109.95308685]), ar_sym_share = array([9.]), ar_sym_amt = array([989.57778168]), portf_value = 989.5777816772461
# 2023-07-28 portf_value = 989.5777816772461
# date = '2023-07-28', symbol = 'SPY', price = 456.9200134277344, share = 2.0, value = 913.8400268554688
# 2023-07-28 SPY value = 913.8400268554688
# next_date_n pick's portf value = 989.5777816772461
# next_date_n SPY portf value =    913.8400268554688
# ====================
#
# date: 2023-07-26 is in dates_NYSE,  date's position in dates_NYSE is: 2658 of 2767,  n: 1,  idx_date_n: 2659,
# idx_date_n: 2659 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-27"
#
# date: 2023-07-26,  n: 1,  next_date_n: 2023-07-27 is in df_close
# picks for 2023-07-26: ['SHV']
# date = '2023-07-27', l_syms = ['SHV'], ar_price = array([109.92321014]), ar_sym_share = array([9.]), ar_sym_amt = array([989.3088913]), portf_value = 989.3088912963867
# 2023-07-27 portf_value = 989.3088912963867
# date = '2023-07-27', symbol = 'SPY', price = 452.489990234375, share = 2.0, value = 904.97998046875
# 2023-07-27 SPY value = 904.97998046875
# next_date_n pick's portf value = 989.3088912963867
# next_date_n SPY portf value =    904.97998046875
# ====================
#
# date: 2023-07-25 is in dates_NYSE,  date's position in dates_NYSE is: 2657 of 2767,  n: 1,  idx_date_n: 2658,
# idx_date_n: 2658 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-26"
#
# date: 2023-07-25,  n: 1,  next_date_n: 2023-07-26 is in df_close
# picks for 2023-07-25: ['SHV']
# date = '2023-07-26', l_syms = ['SHV'], ar_price = array([109.88337708]), ar_sym_share = array([9.]), ar_sym_amt = array([988.95039368]), portf_value = 988.9503936767578
# 2023-07-26 portf_value = 988.9503936767578
# date = '2023-07-26', symbol = 'SPY', price = 455.510009765625, share = 2.0, value = 911.02001953125
# 2023-07-26 SPY value = 911.02001953125
# next_date_n pick's portf value = 988.9503936767578
# next_date_n SPY portf value =    911.02001953125
# ====================
#
# date: 2023-07-21 is in dates_NYSE,  date's position in dates_NYSE is: 2655 of 2767,  n: 1,  idx_date_n: 2656,
# idx_date_n: 2656 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-24"
#
# date: 2023-07-21,  n: 1,  next_date_n: 2023-07-24 is in df_close
# picks for 2023-07-21: ['SHV']
# date = '2023-07-24', l_syms = ['SHV'], ar_price = array([109.853508]), ar_sym_share = array([9.]), ar_sym_amt = array([988.68157196]), portf_value = 988.6815719604492
# 2023-07-24 portf_value = 988.6815719604492
# date = '2023-07-24', symbol = 'SPY', price = 454.20001220703125, share = 2.0, value = 908.4000244140625
# 2023-07-24 SPY value = 908.4000244140625
# next_date_n pick's portf value = 988.6815719604492
# next_date_n SPY portf value =    908.4000244140625
# ====================
#
# date: 2023-07-20 is in dates_NYSE,  date's position in dates_NYSE is: 2654 of 2767,  n: 1,  idx_date_n: 2655,
# idx_date_n: 2655 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-21"
#
# date: 2023-07-20,  n: 1,  next_date_n: 2023-07-21 is in df_close
# picks for 2023-07-20: ['SHV']
# date = '2023-07-21', l_syms = ['SHV'], ar_price = array([109.84355164]), ar_sym_share = array([9.]), ar_sym_amt = array([988.59196472]), portf_value = 988.5919647216797
# 2023-07-21 portf_value = 988.5919647216797
# date = '2023-07-21', symbol = 'SPY', price = 452.17999267578125, share = 2.0, value = 904.3599853515625
# 2023-07-21 SPY value = 904.3599853515625
# next_date_n pick's portf value = 988.5919647216797
# next_date_n SPY portf value =    904.3599853515625
# ====================
#
# date: 2023-07-18 is in dates_NYSE,  date's position in dates_NYSE is: 2652 of 2767,  n: 1,  idx_date_n: 2653,
# idx_date_n: 2653 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-19"
#
# date: 2023-07-18,  n: 1,  next_date_n: 2023-07-19 is in df_close
# picks for 2023-07-18: ['SHV']
# date = '2023-07-19', l_syms = ['SHV'], ar_price = array([109.78380585]), ar_sym_share = array([9.]), ar_sym_amt = array([988.05425262]), portf_value = 988.0542526245117
# 2023-07-19 portf_value = 988.0542526245117
# date = '2023-07-19', symbol = 'SPY', price = 455.20001220703125, share = 2.0, value = 910.4000244140625
# 2023-07-19 SPY value = 910.4000244140625
# next_date_n pick's portf value = 988.0542526245117
# next_date_n SPY portf value =    910.4000244140625
# ====================
#
# date: 2023-07-14 is in dates_NYSE,  date's position in dates_NYSE is: 2650 of 2767,  n: 1,  idx_date_n: 2651,
# idx_date_n: 2651 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-17"
#
# date: 2023-07-14,  n: 1,  next_date_n: 2023-07-17 is in df_close
# picks for 2023-07-14: ['SHV']
# date = '2023-07-17', l_syms = ['SHV'], ar_price = array([109.75392914]), ar_sym_share = array([9.]), ar_sym_amt = array([987.78536224]), portf_value = 987.7853622436523
# 2023-07-17 portf_value = 987.7853622436523
# date = '2023-07-17', symbol = 'SPY', price = 450.8399963378906, share = 2.0, value = 901.6799926757812
# 2023-07-17 SPY value = 901.6799926757812
# next_date_n pick's portf value = 987.7853622436523
# next_date_n SPY portf value =    901.6799926757812
# ====================
#
# date: 2023-07-13 is in dates_NYSE,  date's position in dates_NYSE is: 2649 of 2767,  n: 1,  idx_date_n: 2650,
# idx_date_n: 2650 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-14"
#
# date: 2023-07-13,  n: 1,  next_date_n: 2023-07-14 is in df_close
# picks for 2023-07-13: ['SHV', 'SKYW']
# date = '2023-07-14', l_syms = ['SHV', 'SKYW'], ar_price = array([109.74397278,  40.43000031]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([438.97589111, 485.16000366]), portf_value = 924.1358947753906
# 2023-07-14 portf_value = 924.1358947753906
# date = '2023-07-14', symbol = 'SPY', price = 449.2799987792969, share = 2.0, value = 898.5599975585938
# 2023-07-14 SPY value = 898.5599975585938
# next_date_n pick's portf value = 924.1358947753906
# next_date_n SPY portf value =    898.5599975585938
# ====================
#
# date: 2023-07-12 is in dates_NYSE,  date's position in dates_NYSE is: 2648 of 2767,  n: 1,  idx_date_n: 2649,
# idx_date_n: 2649 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-13"
#
# date: 2023-07-12,  n: 1,  next_date_n: 2023-07-13 is in df_close
# picks for 2023-07-12: ['SHV', 'SKYW']
# date = '2023-07-13', l_syms = ['SHV', 'SKYW'], ar_price = array([109.73401642,  41.47000122]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([438.93606567, 497.64001465]), portf_value = 936.5760803222656
# 2023-07-13 portf_value = 936.5760803222656
# date = '2023-07-13', symbol = 'SPY', price = 449.55999755859375, share = 2.0, value = 899.1199951171875
# 2023-07-13 SPY value = 899.1199951171875
# next_date_n pick's portf value = 936.5760803222656
# next_date_n SPY portf value =    899.1199951171875
# ====================
#
# date: 2023-07-11 is in dates_NYSE,  date's position in dates_NYSE is: 2647 of 2767,  n: 1,  idx_date_n: 2648,
# idx_date_n: 2648 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-12"
#
# date: 2023-07-11,  n: 1,  next_date_n: 2023-07-12 is in df_close
# picks for 2023-07-11: ['SHV', 'SKYW']
# date = '2023-07-12', l_syms = ['SHV', 'SKYW'], ar_price = array([109.67427063,  41.11999893]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([438.69708252, 493.43998718]), portf_value = 932.1370697021484
# 2023-07-12 portf_value = 932.1370697021484
# date = '2023-07-12', symbol = 'SPY', price = 446.0199890136719, share = 2.0, value = 892.0399780273438
# 2023-07-12 SPY value = 892.0399780273438
# next_date_n pick's portf value = 932.1370697021484
# next_date_n SPY portf value =    892.0399780273438
# ====================
#
# date: 2023-07-10 is in dates_NYSE,  date's position in dates_NYSE is: 2646 of 2767,  n: 1,  idx_date_n: 2647,
# idx_date_n: 2647 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-11"
#
# date: 2023-07-10,  n: 1,  next_date_n: 2023-07-11 is in df_close
# picks for 2023-07-10: ['SHV', 'SKYW']
# date = '2023-07-11', l_syms = ['SHV', 'SKYW'], ar_price = array([109.64439392,  41.75      ]), ar_sym_share = array([ 4., 11.]), ar_sym_amt = array([438.57757568, 459.25      ]), portf_value = 897.8275756835938
# 2023-07-11 portf_value = 897.8275756835938
# date = '2023-07-11', symbol = 'SPY', price = 442.4599914550781, share = 2.0, value = 884.9199829101562
# 2023-07-11 SPY value = 884.9199829101562
# next_date_n pick's portf value = 897.8275756835938
# next_date_n SPY portf value =    884.9199829101562
# ====================
#
# date: 2023-07-07 is in dates_NYSE,  date's position in dates_NYSE is: 2645 of 2767,  n: 1,  idx_date_n: 2646,
# idx_date_n: 2646 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-10"
#
# date: 2023-07-07,  n: 1,  next_date_n: 2023-07-10 is in df_close
# picks for 2023-07-07: ['SHV', 'SKYW']
# date = '2023-07-10', l_syms = ['SHV', 'SKYW'], ar_price = array([109.64439392,  42.18999863]), ar_sym_share = array([ 4., 11.]), ar_sym_amt = array([438.57757568, 464.08998489]), portf_value = 902.6675605773926
# 2023-07-10 portf_value = 902.6675605773926
# date = '2023-07-10', symbol = 'SPY', price = 439.6600036621094, share = 2.0, value = 879.3200073242188
# 2023-07-10 SPY value = 879.3200073242188
# next_date_n pick's portf value = 902.6675605773926
# next_date_n SPY portf value =    879.3200073242188
# ====================
#
# date: 2023-07-06 is in dates_NYSE,  date's position in dates_NYSE is: 2644 of 2767,  n: 1,  idx_date_n: 2645,
# idx_date_n: 2645 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-07"
#
# date: 2023-07-06,  n: 1,  next_date_n: 2023-07-07 is in df_close
# picks for 2023-07-06: ['SHV', 'SKYW']
# date = '2023-07-07', l_syms = ['SHV', 'SKYW'], ar_price = array([109.62447357,  40.86000061]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([438.49789429, 490.32000732]), portf_value = 928.8179016113281
# 2023-07-07 portf_value = 928.8179016113281
# date = '2023-07-07', symbol = 'SPY', price = 438.54998779296875, share = 2.0, value = 877.0999755859375
# 2023-07-07 SPY value = 877.0999755859375
# next_date_n pick's portf value = 928.8179016113281
# next_date_n SPY portf value =    877.0999755859375
# ====================
#
# date: 2023-07-05 is in dates_NYSE,  date's position in dates_NYSE is: 2643 of 2767,  n: 1,  idx_date_n: 2644,
# idx_date_n: 2644 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-06"
#
# date: 2023-07-05,  n: 1,  next_date_n: 2023-07-06 is in df_close
# picks for 2023-07-05: ['SHV']
# date = '2023-07-06', l_syms = ['SHV'], ar_price = array([109.62447357]), ar_sym_share = array([9.]), ar_sym_amt = array([986.62026215]), portf_value = 986.6202621459961
# 2023-07-06 portf_value = 986.6202621459961
# date = '2023-07-06', symbol = 'SPY', price = 439.6600036621094, share = 2.0, value = 879.3200073242188
# 2023-07-06 SPY value = 879.3200073242188
# next_date_n pick's portf value = 986.6202621459961
# next_date_n SPY portf value =    879.3200073242188
# ====================
#
# date: 2023-07-03 is in dates_NYSE,  date's position in dates_NYSE is: 2642 of 2767,  n: 1,  idx_date_n: 2643,
# idx_date_n: 2643 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-05"
#
# date: 2023-07-03,  n: 1,  next_date_n: 2023-07-05 is in df_close
# picks for 2023-07-03: ['SHV']
# date = '2023-07-05', l_syms = ['SHV'], ar_price = array([109.56473541]), ar_sym_share = array([9.]), ar_sym_amt = array([986.08261871]), portf_value = 986.0826187133789
# 2023-07-05 portf_value = 986.0826187133789
# date = '2023-07-05', symbol = 'SPY', price = 443.1300048828125, share = 2.0, value = 886.260009765625
# 2023-07-05 SPY value = 886.260009765625
# next_date_n pick's portf value = 986.0826187133789
# next_date_n SPY portf value =    886.260009765625
# ====================
#
# date: 2023-06-30 is in dates_NYSE,  date's position in dates_NYSE is: 2641 of 2767,  n: 1,  idx_date_n: 2642,
# idx_date_n: 2642 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-03"
#
# date: 2023-06-30,  n: 1,  next_date_n: 2023-07-03 is in df_close
# picks for 2023-06-30: ['SHV']
# date = '2023-07-03', l_syms = ['SHV'], ar_price = array([109.54482269]), ar_sym_share = array([9.]), ar_sym_amt = array([985.90340424]), portf_value = 985.9034042358398
# 2023-07-03 portf_value = 985.9034042358398
# date = '2023-07-03', symbol = 'SPY', price = 443.7900085449219, share = 2.0, value = 887.5800170898438
# 2023-07-03 SPY value = 887.5800170898438
# next_date_n pick's portf value = 985.9034042358398
# next_date_n SPY portf value =    887.5800170898438
# ====================
#
# date: 2023-06-29 is in dates_NYSE,  date's position in dates_NYSE is: 2640 of 2767,  n: 1,  idx_date_n: 2641,
# idx_date_n: 2641 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-30"
#
# date: 2023-06-29,  n: 1,  next_date_n: 2023-06-30 is in df_close
# picks for 2023-06-29: ['SHV', 'SKYW']
# date = '2023-06-30', l_syms = ['SHV', 'SKYW'], ar_price = array([109.55278778,  40.72000122]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([438.21115112, 488.64001465]), portf_value = 926.8511657714844
# 2023-06-30 portf_value = 926.8511657714844
# date = '2023-06-30', symbol = 'SPY', price = 443.2799987792969, share = 2.0, value = 886.5599975585938
# 2023-06-30 SPY value = 886.5599975585938
# next_date_n pick's portf value = 926.8511657714844
# next_date_n SPY portf value =    886.5599975585938
# ====================
#
# date: 2023-06-28 is in dates_NYSE,  date's position in dates_NYSE is: 2639 of 2767,  n: 1,  idx_date_n: 2640,
# idx_date_n: 2640 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-29"
#
# date: 2023-06-28,  n: 1,  next_date_n: 2023-06-29 is in df_close
# picks for 2023-06-28: ['SHV', 'SKYW']
# date = '2023-06-29', l_syms = ['SHV', 'SKYW'], ar_price = array([109.49327087,  40.38000107]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([437.9730835 , 484.56001282]), portf_value = 922.5330963134766
# 2023-06-29 portf_value = 922.5330963134766
# date = '2023-06-29', symbol = 'SPY', price = 438.1099853515625, share = 2.0, value = 876.219970703125
# 2023-06-29 SPY value = 876.219970703125
# next_date_n pick's portf value = 922.5330963134766
# next_date_n SPY portf value =    876.219970703125
# ====================
#
# date: 2023-06-27 is in dates_NYSE,  date's position in dates_NYSE is: 2638 of 2767,  n: 1,  idx_date_n: 2639,
# idx_date_n: 2639 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-28"
#
# date: 2023-06-27,  n: 1,  next_date_n: 2023-06-28 is in df_close
# picks for 2023-06-27: ['SHV', 'SKYW']
# date = '2023-06-28', l_syms = ['SHV', 'SKYW'], ar_price = array([109.47343445,  39.65000153]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([437.89373779, 475.80001831]), portf_value = 913.6937561035156
# 2023-06-28 portf_value = 913.6937561035156
# date = '2023-06-28', symbol = 'SPY', price = 436.3900146484375, share = 2.0, value = 872.780029296875
# 2023-06-28 SPY value = 872.780029296875
# next_date_n pick's portf value = 913.6937561035156
# next_date_n SPY portf value =    872.780029296875
# ====================
#
# date: 2023-06-26 is in dates_NYSE,  date's position in dates_NYSE is: 2637 of 2767,  n: 1,  idx_date_n: 2638,
# idx_date_n: 2638 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-27"
#
# date: 2023-06-26,  n: 1,  next_date_n: 2023-06-27 is in df_close
# picks for 2023-06-26: ['SHV', 'SKYW']
# date = '2023-06-27', l_syms = ['SHV', 'SKYW'], ar_price = array([109.46351624,  39.16999817]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([437.85406494, 470.03997803]), portf_value = 907.89404296875
# 2023-06-27 portf_value = 907.89404296875
# date = '2023-06-27', symbol = 'SPY', price = 436.1700134277344, share = 2.0, value = 872.3400268554688
# 2023-06-27 SPY value = 872.3400268554688
# next_date_n pick's portf value = 907.89404296875
# next_date_n SPY portf value =    872.3400268554688
# ====================
#
# date: 2023-06-23 is in dates_NYSE,  date's position in dates_NYSE is: 2636 of 2767,  n: 1,  idx_date_n: 2637,
# idx_date_n: 2637 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-26"
#
# date: 2023-06-23,  n: 1,  next_date_n: 2023-06-26 is in df_close
# picks for 2023-06-23: ['NVDA']
# date = '2023-06-26', l_syms = ['NVDA'], ar_price = array([406.32000732]), ar_sym_share = array([2.]), ar_sym_amt = array([812.64001465]), portf_value = 812.6400146484375
# 2023-06-26 portf_value = 812.6400146484375
# date = '2023-06-26', symbol = 'SPY', price = 431.44000244140625, share = 2.0, value = 862.8800048828125
# 2023-06-26 SPY value = 862.8800048828125
# next_date_n pick's portf value = 812.6400146484375
# next_date_n SPY portf value =    862.8800048828125
# ====================
#
# date: 2023-06-23 is in dates_NYSE,  date's position in dates_NYSE is: 2636 of 2767,  n: 1,  idx_date_n: 2637,
# idx_date_n: 2637 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-26"
#
# date: 2023-06-23,  n: 1,  next_date_n: 2023-06-26 is in df_close
# picks for 2023-06-23: ['SHV', 'SKYW']
# date = '2023-06-26', l_syms = ['SHV', 'SKYW'], ar_price = array([109.44367981,  38.90999985]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([437.77471924, 466.91999817]), portf_value = 904.6947174072266
# 2023-06-26 portf_value = 904.6947174072266
# date = '2023-06-26', symbol = 'SPY', price = 431.44000244140625, share = 2.0, value = 862.8800048828125
# 2023-06-26 SPY value = 862.8800048828125
# next_date_n pick's portf value = 904.6947174072266
# next_date_n SPY portf value =    862.8800048828125
# ====================
#
# date: 2023-06-22 is in dates_NYSE,  date's position in dates_NYSE is: 2635 of 2767,  n: 1,  idx_date_n: 2636,
# idx_date_n: 2636 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-23"
#
# date: 2023-06-22,  n: 1,  next_date_n: 2023-06-23 is in df_close
# picks for 2023-06-22: ['NVDA']
# date = '2023-06-23', l_syms = ['NVDA'], ar_price = array([422.08999634]), ar_sym_share = array([2.]), ar_sym_amt = array([844.17999268]), portf_value = 844.1799926757812
# 2023-06-23 portf_value = 844.1799926757812
# date = '2023-06-23', symbol = 'SPY', price = 433.2099914550781, share = 2.0, value = 866.4199829101562
# 2023-06-23 SPY value = 866.4199829101562
# next_date_n pick's portf value = 844.1799926757812
# next_date_n SPY portf value =    866.4199829101562
# ====================
#
# date: 2023-06-22 is in dates_NYSE,  date's position in dates_NYSE is: 2635 of 2767,  n: 1,  idx_date_n: 2636,
# idx_date_n: 2636 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-23"
#
# date: 2023-06-22,  n: 1,  next_date_n: 2023-06-23 is in df_close
# picks for 2023-06-22: ['SHV', 'SKYW']
# date = '2023-06-23', l_syms = ['SHV', 'SKYW'], ar_price = array([109.42384338,  39.56999969]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([437.69537354, 474.83999634]), portf_value = 912.5353698730469
# 2023-06-23 portf_value = 912.5353698730469
# date = '2023-06-23', symbol = 'SPY', price = 433.2099914550781, share = 2.0, value = 866.4199829101562
# 2023-06-23 SPY value = 866.4199829101562
# next_date_n pick's portf value = 912.5353698730469
# next_date_n SPY portf value =    866.4199829101562
# ====================
#
# date: 2023-06-21 is in dates_NYSE,  date's position in dates_NYSE is: 2634 of 2767,  n: 1,  idx_date_n: 2635,
# idx_date_n: 2635 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-22"
#
# date: 2023-06-21,  n: 1,  next_date_n: 2023-06-22 is in df_close
# picks for 2023-06-21: ['NVDA']
# date = '2023-06-22', l_syms = ['NVDA'], ar_price = array([430.25]), ar_sym_share = array([2.]), ar_sym_amt = array([860.5]), portf_value = 860.5
# 2023-06-22 portf_value = 860.5
# date = '2023-06-22', symbol = 'SPY', price = 436.510009765625, share = 2.0, value = 873.02001953125
# 2023-06-22 SPY value = 873.02001953125
# next_date_n pick's portf value = 860.5
# next_date_n SPY portf value =    873.02001953125
# ====================
#
# date: 2023-06-21 is in dates_NYSE,  date's position in dates_NYSE is: 2634 of 2767,  n: 1,  idx_date_n: 2635,
# idx_date_n: 2635 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-22"
#
# date: 2023-06-21,  n: 1,  next_date_n: 2023-06-22 is in df_close
# picks for 2023-06-21: ['SHV']
# date = '2023-06-22', l_syms = ['SHV'], ar_price = array([109.41392517]), ar_sym_share = array([9.]), ar_sym_amt = array([984.72532654]), portf_value = 984.7253265380859
# 2023-06-22 portf_value = 984.7253265380859
# date = '2023-06-22', symbol = 'SPY', price = 436.510009765625, share = 2.0, value = 873.02001953125
# 2023-06-22 SPY value = 873.02001953125
# next_date_n pick's portf value = 984.7253265380859
# next_date_n SPY portf value =    873.02001953125
# ====================
#
# date: 2023-06-20 is in dates_NYSE,  date's position in dates_NYSE is: 2633 of 2767,  n: 1,  idx_date_n: 2634,
# idx_date_n: 2634 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-21"
#
# date: 2023-06-20,  n: 1,  next_date_n: 2023-06-21 is in df_close
# picks for 2023-06-20: ['NVDA']
# date = '2023-06-21', l_syms = ['NVDA'], ar_price = array([430.45001221]), ar_sym_share = array([2.]), ar_sym_amt = array([860.90002441]), portf_value = 860.9000244140625
# 2023-06-21 portf_value = 860.9000244140625
# date = '2023-06-21', symbol = 'SPY', price = 434.94000244140625, share = 2.0, value = 869.8800048828125
# 2023-06-21 SPY value = 869.8800048828125
# next_date_n pick's portf value = 860.9000244140625
# next_date_n SPY portf value =    869.8800048828125
# ====================
#
# date: 2023-06-20 is in dates_NYSE,  date's position in dates_NYSE is: 2633 of 2767,  n: 1,  idx_date_n: 2634,
# idx_date_n: 2634 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-21"
#
# date: 2023-06-20,  n: 1,  next_date_n: 2023-06-21 is in df_close
# picks for 2023-06-20: ['SHV']
# date = '2023-06-21', l_syms = ['SHV'], ar_price = array([109.37424469]), ar_sym_share = array([9.]), ar_sym_amt = array([984.36820221]), portf_value = 984.3682022094727
# 2023-06-21 portf_value = 984.3682022094727
# date = '2023-06-21', symbol = 'SPY', price = 434.94000244140625, share = 2.0, value = 869.8800048828125
# 2023-06-21 SPY value = 869.8800048828125
# next_date_n pick's portf value = 984.3682022094727
# next_date_n SPY portf value =    869.8800048828125
# ====================
#
# date: 2023-06-16 is in dates_NYSE,  date's position in dates_NYSE is: 2632 of 2767,  n: 1,  idx_date_n: 2633,
# idx_date_n: 2633 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-20"
#
# date: 2023-06-16,  n: 1,  next_date_n: 2023-06-20 is in df_close
# picks for 2023-06-16: ['NVDA', 'SHV']
# date = '2023-06-20', l_syms = ['NVDA', 'SHV'], ar_price = array([438.07998657, 109.36433411]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([438.07998657, 437.45733643]), portf_value = 875.5373229980469
# 2023-06-20 portf_value = 875.5373229980469
# date = '2023-06-20', symbol = 'SPY', price = 437.17999267578125, share = 2.0, value = 874.3599853515625
# 2023-06-20 SPY value = 874.3599853515625
# next_date_n pick's portf value = 875.5373229980469
# next_date_n SPY portf value =    874.3599853515625
# ====================
#
# date: 2023-06-15 is in dates_NYSE,  date's position in dates_NYSE is: 2631 of 2767,  n: 1,  idx_date_n: 2632,
# idx_date_n: 2632 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-16"
#
# date: 2023-06-15,  n: 1,  next_date_n: 2023-06-16 is in df_close
# picks for 2023-06-15: ['NVDA', 'SHV']
# date = '2023-06-16', l_syms = ['NVDA', 'SHV'], ar_price = array([426.92001343, 109.36433411]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([426.92001343, 437.45733643]), portf_value = 864.3773498535156
# 2023-06-16 portf_value = 864.3773498535156
# date = '2023-06-16', symbol = 'SPY', price = 439.4599914550781, share = 2.0, value = 878.9199829101562
# 2023-06-16 SPY value = 878.9199829101562
# next_date_n pick's portf value = 864.3773498535156
# next_date_n SPY portf value =    878.9199829101562
# ====================
#
# date: 2023-06-14 is in dates_NYSE,  date's position in dates_NYSE is: 2630 of 2767,  n: 1,  idx_date_n: 2631,
# idx_date_n: 2631 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-15"
#
# date: 2023-06-14,  n: 1,  next_date_n: 2023-06-15 is in df_close
# picks for 2023-06-14: ['AVGO', 'NVDA', 'SHV']
# date = '2023-06-15', l_syms = ['AVGO', 'NVDA', 'SHV'], ar_price = array([878.74841309, 426.52999878, 109.35441589]), ar_sym_share = array([0., 0., 3.]), ar_sym_amt = array([  0.        ,   0.        , 328.06324768]), portf_value = 328.06324768066406
# 2023-06-15 portf_value = 328.06324768066406
# date = '2023-06-15', symbol = 'SPY', price = 440.9620056152344, share = 2.0, value = 881.9240112304688
# 2023-06-15 SPY value = 881.9240112304688
# next_date_n pick's portf value = 328.06324768066406
# next_date_n SPY portf value =    881.9240112304688
# ====================
#
# date: 2023-06-13 is in dates_NYSE,  date's position in dates_NYSE is: 2629 of 2767,  n: 1,  idx_date_n: 2630,
# idx_date_n: 2630 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-14"
#
# date: 2023-06-13,  n: 1,  next_date_n: 2023-06-14 is in df_close
# picks for 2023-06-13: ['SHV']
# date = '2023-06-14', l_syms = ['SHV'], ar_price = array([109.27505493]), ar_sym_share = array([9.]), ar_sym_amt = array([983.47549438]), portf_value = 983.4754943847656
# 2023-06-14 portf_value = 983.4754943847656
# date = '2023-06-14', symbol = 'SPY', price = 435.5620422363281, share = 2.0, value = 871.1240844726562
# 2023-06-14 SPY value = 871.1240844726562
# next_date_n pick's portf value = 983.4754943847656
# next_date_n SPY portf value =    871.1240844726562
# ====================
#
# date: 2023-06-12 is in dates_NYSE,  date's position in dates_NYSE is: 2628 of 2767,  n: 1,  idx_date_n: 2629,
# idx_date_n: 2629 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-13"
#
# date: 2023-06-12,  n: 1,  next_date_n: 2023-06-13 is in df_close
# picks for 2023-06-12: ['SHV']
# date = '2023-06-13', l_syms = ['SHV'], ar_price = array([109.26515198]), ar_sym_share = array([9.]), ar_sym_amt = array([983.3863678]), portf_value = 983.3863677978516
# 2023-06-13 portf_value = 983.3863677978516
# date = '2023-06-13', symbol = 'SPY', price = 435.0439758300781, share = 2.0, value = 870.0879516601562
# 2023-06-13 SPY value = 870.0879516601562
# next_date_n pick's portf value = 983.3863677978516
# next_date_n SPY portf value =    870.0879516601562
# ====================
#
# date: 2023-06-09 is in dates_NYSE,  date's position in dates_NYSE is: 2627 of 2767,  n: 1,  idx_date_n: 2628,
# idx_date_n: 2628 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-12"
#
# date: 2023-06-09,  n: 1,  next_date_n: 2023-06-12 is in df_close
# picks for 2023-06-09: ['NVDA', 'SHV']
# date = '2023-06-12', l_syms = ['NVDA', 'SHV'], ar_price = array([394.82000732, 109.24530792]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([394.82000732, 436.98123169]), portf_value = 831.8012390136719
# 2023-06-12 portf_value = 831.8012390136719
# date = '2023-06-12', symbol = 'SPY', price = 432.1945495605469, share = 2.0, value = 864.3890991210938
# 2023-06-12 SPY value = 864.3890991210938
# next_date_n pick's portf value = 831.8012390136719
# next_date_n SPY portf value =    864.3890991210938
# ====================
#
# date: 2023-06-08 is in dates_NYSE,  date's position in dates_NYSE is: 2626 of 2767,  n: 1,  idx_date_n: 2627,
# idx_date_n: 2627 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-09"
#
# date: 2023-06-08,  n: 1,  next_date_n: 2023-06-09 is in df_close
# picks for 2023-06-08: ['NVDA', 'SHV']
# date = '2023-06-09', l_syms = ['NVDA', 'SHV'], ar_price = array([387.70001221, 109.2254715 ]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([387.70001221, 436.90188599]), portf_value = 824.6018981933594
# 2023-06-09 portf_value = 824.6018981933594
# date = '2023-06-09', symbol = 'SPY', price = 428.3089904785156, share = 2.0, value = 856.6179809570312
# 2023-06-09 SPY value = 856.6179809570312
# next_date_n pick's portf value = 824.6018981933594
# next_date_n SPY portf value =    856.6179809570312
# ====================
#
# date: 2023-06-07 is in dates_NYSE,  date's position in dates_NYSE is: 2625 of 2767,  n: 1,  idx_date_n: 2626,
# idx_date_n: 2626 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-08"
#
# date: 2023-06-07,  n: 1,  next_date_n: 2023-06-08 is in df_close
# picks for 2023-06-07: ['EXAS']
# date = '2023-06-08', l_syms = ['EXAS'], ar_price = array([90.65000153]), ar_sym_share = array([11.]), ar_sym_amt = array([997.15001678]), portf_value = 997.150016784668
# 2023-06-08 portf_value = 997.150016784668
# date = '2023-06-08', symbol = 'SPY', price = 427.5418701171875, share = 2.0, value = 855.083740234375
# 2023-06-08 SPY value = 855.083740234375
# next_date_n pick's portf value = 997.150016784668
# next_date_n SPY portf value =    855.083740234375
# ====================
#
# date: 2023-06-07 is in dates_NYSE,  date's position in dates_NYSE is: 2625 of 2767,  n: 1,  idx_date_n: 2626,
# idx_date_n: 2626 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-08"
#
# date: 2023-06-07,  n: 1,  next_date_n: 2023-06-08 is in df_close
# picks for 2023-06-07: ['SHV']
# date = '2023-06-08', l_syms = ['SHV'], ar_price = array([109.2254715]), ar_sym_share = array([9.]), ar_sym_amt = array([983.02924347]), portf_value = 983.0292434692383
# 2023-06-08 portf_value = 983.0292434692383
# date = '2023-06-08', symbol = 'SPY', price = 427.5418701171875, share = 2.0, value = 855.083740234375
# 2023-06-08 SPY value = 855.083740234375
# next_date_n pick's portf value = 983.0292434692383
# next_date_n SPY portf value =    855.083740234375
# ====================
#
# date: 2023-06-06 is in dates_NYSE,  date's position in dates_NYSE is: 2624 of 2767,  n: 1,  idx_date_n: 2625,
# idx_date_n: 2625 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-07"
#
# date: 2023-06-06,  n: 1,  next_date_n: 2023-06-07 is in df_close
# picks for 2023-06-06: ['NVDA', 'SHV']
# date = '2023-06-07', l_syms = ['NVDA', 'SHV'], ar_price = array([374.75      , 109.15604401]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([374.75      , 436.62417603]), portf_value = 811.3741760253906
# 2023-06-07 portf_value = 811.3741760253906
# date = '2023-06-07', symbol = 'SPY', price = 424.97137451171875, share = 2.0, value = 849.9427490234375
# 2023-06-07 SPY value = 849.9427490234375
# next_date_n pick's portf value = 811.3741760253906
# next_date_n SPY portf value =    849.9427490234375
# ====================
#
# date: 2023-06-05 is in dates_NYSE,  date's position in dates_NYSE is: 2623 of 2767,  n: 1,  idx_date_n: 2624,
# idx_date_n: 2624 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-06"
#
# date: 2023-06-05,  n: 1,  next_date_n: 2023-06-06 is in df_close
# picks for 2023-06-05: ['NVDA', 'SHV']
# date = '2023-06-06', l_syms = ['NVDA', 'SHV'], ar_price = array([386.5       , 109.13619995]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([386.5      , 436.5447998]), portf_value = 823.0447998046875
# 2023-06-06 portf_value = 823.0447998046875
# date = '2023-06-06', symbol = 'SPY', price = 426.4459228515625, share = 2.0, value = 852.891845703125
# 2023-06-06 SPY value = 852.891845703125
# next_date_n pick's portf value = 823.0447998046875
# next_date_n SPY portf value =    852.891845703125
# ====================
#
# date: 2023-06-02 is in dates_NYSE,  date's position in dates_NYSE is: 2622 of 2767,  n: 1,  idx_date_n: 2623,
# idx_date_n: 2623 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-05"
#
# date: 2023-06-02,  n: 1,  next_date_n: 2023-06-05 is in df_close
# picks for 2023-06-02: ['NVDA', 'SHV']
# date = '2023-06-05', l_syms = ['NVDA', 'SHV'], ar_price = array([391.66946411, 109.11636353]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([391.66946411, 436.4654541 ]), portf_value = 828.1349182128906
# 2023-06-05 portf_value = 828.1349182128906
# date = '2023-06-05', symbol = 'SPY', price = 425.5193786621094, share = 2.0, value = 851.0387573242188
# 2023-06-05 SPY value = 851.0387573242188
# next_date_n pick's portf value = 828.1349182128906
# next_date_n SPY portf value =    851.0387573242188
# ====================
#
# date: 2023-06-01 is in dates_NYSE,  date's position in dates_NYSE is: 2621 of 2767,  n: 1,  idx_date_n: 2622,
# idx_date_n: 2622 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-02"
#
# date: 2023-06-01,  n: 1,  next_date_n: 2023-06-02 is in df_close
# picks for 2023-06-01: ['META', 'NVDA']
# date = '2023-06-02', l_syms = ['META', 'NVDA'], ar_price = array([272.60998535, 393.22930908]), ar_sym_share = array([1., 1.]), ar_sym_amt = array([272.60998535, 393.22930908]), portf_value = 665.8392944335938
# 2023-06-02 portf_value = 665.8392944335938
# date = '2023-06-02', symbol = 'SPY', price = 426.3363342285156, share = 2.0, value = 852.6726684570312
# 2023-06-02 SPY value = 852.6726684570312
# next_date_n pick's portf value = 665.8392944335938
# next_date_n SPY portf value =    852.6726684570312
# ====================
#
# date: 2023-05-31 is in dates_NYSE,  date's position in dates_NYSE is: 2620 of 2767,  n: 1,  idx_date_n: 2621,
# idx_date_n: 2621 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-01"
#
# date: 2023-05-31,  n: 1,  next_date_n: 2023-06-01 is in df_close
# picks for 2023-05-31: ['SHV']
# date = '2023-06-01', l_syms = ['SHV'], ar_price = array([109.10643768]), ar_sym_share = array([9.]), ar_sym_amt = array([981.95793915]), portf_value = 981.9579391479492
# 2023-06-01 portf_value = 981.9579391479492
# date = '2023-06-01', symbol = 'SPY', price = 420.2589111328125, share = 2.0, value = 840.517822265625
# 2023-06-01 SPY value = 840.517822265625
# next_date_n pick's portf value = 981.9579391479492
# next_date_n SPY portf value =    840.517822265625
# ====================
#
# date: 2023-05-31 is in dates_NYSE,  date's position in dates_NYSE is: 2620 of 2767,  n: 1,  idx_date_n: 2621,
# idx_date_n: 2621 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-01"
#
# date: 2023-05-31,  n: 1,  next_date_n: 2023-06-01 is in df_close
# picks for 2023-05-31: ['AVGO', 'NVDA']
# date = '2023-06-01', l_syms = ['AVGO', 'NVDA'], ar_price = array([785.76379395, 397.65887451]), ar_sym_share = array([0., 1.]), ar_sym_amt = array([  0.        , 397.65887451]), portf_value = 397.65887451171875
# 2023-06-01 portf_value = 397.65887451171875
# date = '2023-06-01', symbol = 'SPY', price = 420.2589111328125, share = 2.0, value = 840.517822265625
# 2023-06-01 SPY value = 840.517822265625
# next_date_n pick's portf value = 397.65887451171875
# next_date_n SPY portf value =    840.517822265625
# ====================
#
# date: 2023-05-30 is in dates_NYSE,  date's position in dates_NYSE is: 2619 of 2767,  n: 1,  idx_date_n: 2620,
# idx_date_n: 2620 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-31"
#
# date: 2023-05-30,  n: 1,  next_date_n: 2023-05-31 is in df_close
# picks for 2023-05-30: ['SHV']
# date = '2023-05-31', l_syms = ['SHV'], ar_price = array([109.03502655]), ar_sym_share = array([9.]), ar_sym_amt = array([981.31523895]), portf_value = 981.3152389526367
# 2023-05-31 portf_value = 981.3152389526367
# date = '2023-05-31', symbol = 'SPY', price = 416.3036193847656, share = 2.0, value = 832.6072387695312
# 2023-05-31 SPY value = 832.6072387695312
# next_date_n pick's portf value = 981.3152389526367
# next_date_n SPY portf value =    832.6072387695312
# ====================
#
# date: 2023-05-30 is in dates_NYSE,  date's position in dates_NYSE is: 2619 of 2767,  n: 1,  idx_date_n: 2620,
# idx_date_n: 2620 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-31"
#
# date: 2023-05-30,  n: 1,  next_date_n: 2023-05-31 is in df_close
# picks for 2023-05-30: ['AVGO', 'NVDA']
# date = '2023-05-31', l_syms = ['AVGO', 'NVDA'], ar_price = array([803.67840576, 378.30084229]), ar_sym_share = array([0., 1.]), ar_sym_amt = array([  0.        , 378.30084229]), portf_value = 378.30084228515625
# 2023-05-31 portf_value = 378.30084228515625
# date = '2023-05-31', symbol = 'SPY', price = 416.3036193847656, share = 2.0, value = 832.6072387695312
# 2023-05-31 SPY value = 832.6072387695312
# next_date_n pick's portf value = 378.30084228515625
# next_date_n SPY portf value =    832.6072387695312
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['AVGO', 'SHV']
# date = '2023-05-30', l_syms = ['AVGO', 'SHV'], ar_price = array([799.08288574, 109.01527405]), ar_sym_share = array([0., 4.]), ar_sym_amt = array([  0.        , 436.06109619]), portf_value = 436.06109619140625
# 2023-05-30 portf_value = 436.06109619140625
# date = '2023-05-30', symbol = 'SPY', price = 418.6249694824219, share = 2.0, value = 837.2499389648438
# 2023-05-30 SPY value = 837.2499389648438
# next_date_n pick's portf value = 436.06109619140625
# next_date_n SPY portf value =    837.2499389648438
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['NVDA']
# date = '2023-05-30', l_syms = ['NVDA'], ar_price = array([401.06848145]), ar_sym_share = array([2.]), ar_sym_amt = array([802.13696289]), portf_value = 802.136962890625
# 2023-05-30 portf_value = 802.136962890625
# date = '2023-05-30', symbol = 'SPY', price = 418.6249694824219, share = 2.0, value = 837.2499389648438
# 2023-05-30 SPY value = 837.2499389648438
# next_date_n pick's portf value = 802.136962890625
# next_date_n SPY portf value =    837.2499389648438
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['AVGO']
# date = '2023-05-30', l_syms = ['AVGO'], ar_price = array([799.08288574]), ar_sym_share = array([1.]), ar_sym_amt = array([799.08288574]), portf_value = 799.0828857421875
# 2023-05-30 portf_value = 799.0828857421875
# date = '2023-05-30', symbol = 'SPY', price = 418.6249694824219, share = 2.0, value = 837.2499389648438
# 2023-05-30 SPY value = 837.2499389648438
# next_date_n pick's portf value = 799.0828857421875
# next_date_n SPY portf value =    837.2499389648438
# ====================
#
# date: 2023-05-25 is in dates_NYSE,  date's position in dates_NYSE is: 2617 of 2767,  n: 1,  idx_date_n: 2618,
# idx_date_n: 2618 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-26"
#
# date: 2023-05-25,  n: 1,  next_date_n: 2023-05-26 is in df_close
# picks for 2023-05-25: ['SHV']
# date = '2023-05-26', l_syms = ['SHV'], ar_price = array([109.00539398]), ar_sym_share = array([9.]), ar_sym_amt = array([981.04854584]), portf_value = 981.0485458374023
# 2023-05-26 portf_value = 981.0485458374023
# date = '2023-05-26', symbol = 'SPY', price = 418.4655456542969, share = 2.0, value = 836.9310913085938
# 2023-05-26 SPY value = 836.9310913085938
# next_date_n pick's portf value = 981.0485458374023
# next_date_n SPY portf value =    836.9310913085938
# ====================
#
# date: 2023-05-25 is in dates_NYSE,  date's position in dates_NYSE is: 2617 of 2767,  n: 1,  idx_date_n: 2618,
# idx_date_n: 2618 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-26"
#
# date: 2023-05-25,  n: 1,  next_date_n: 2023-05-26 is in df_close
# picks for 2023-05-25: ['FTSM', 'NVDA']
# date = '2023-05-26', l_syms = ['FTSM', 'NVDA'], ar_price = array([ 58.95495224, 389.41967773]), ar_sym_share = array([8., 1.]), ar_sym_amt = array([471.63961792, 389.41967773]), portf_value = 861.0592956542969
# 2023-05-26 portf_value = 861.0592956542969
# date = '2023-05-26', symbol = 'SPY', price = 418.4655456542969, share = 2.0, value = 836.9310913085938
# 2023-05-26 SPY value = 836.9310913085938
# next_date_n pick's portf value = 861.0592956542969
# next_date_n SPY portf value =    836.9310913085938
# ====================
#
# date: 2023-05-24 is in dates_NYSE,  date's position in dates_NYSE is: 2616 of 2767,  n: 1,  idx_date_n: 2617,
# idx_date_n: 2617 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-25"
#
# date: 2023-05-24,  n: 1,  next_date_n: 2023-05-25 is in df_close
# picks for 2023-05-24: ['SHV']
# date = '2023-05-25', l_syms = ['SHV'], ar_price = array([108.98564911]), ar_sym_share = array([9.]), ar_sym_amt = array([980.87084198]), portf_value = 980.8708419799805
# 2023-05-25 portf_value = 980.8708419799805
# date = '2023-05-25', symbol = 'SPY', price = 413.1154479980469, share = 2.0, value = 826.2308959960938
# 2023-05-25 SPY value = 826.2308959960938
# next_date_n pick's portf value = 980.8708419799805
# next_date_n SPY portf value =    826.2308959960938
# ====================
#
# date: 2023-05-23 is in dates_NYSE,  date's position in dates_NYSE is: 2615 of 2767,  n: 1,  idx_date_n: 2616,
# idx_date_n: 2616 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-24"
#
# date: 2023-05-23,  n: 1,  next_date_n: 2023-05-24 is in df_close
# picks for 2023-05-23: ['SHV']
# date = '2023-05-24', l_syms = ['SHV'], ar_price = array([108.93627167]), ar_sym_share = array([9.]), ar_sym_amt = array([980.42644501]), portf_value = 980.4264450073242
# 2023-05-24 portf_value = 980.4264450073242
# date = '2023-05-24', symbol = 'SPY', price = 409.568603515625, share = 2.0, value = 819.13720703125
# 2023-05-24 SPY value = 819.13720703125
# next_date_n pick's portf value = 980.4264450073242
# next_date_n SPY portf value =    819.13720703125
# ====================
#
# date: 2023-05-22 is in dates_NYSE,  date's position in dates_NYSE is: 2614 of 2767,  n: 1,  idx_date_n: 2615,
# idx_date_n: 2615 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-23"
#
# date: 2023-05-22,  n: 1,  next_date_n: 2023-05-23 is in df_close
# picks for 2023-05-22: ['SHV']
# date = '2023-05-23', l_syms = ['SHV'], ar_price = array([108.93627167]), ar_sym_share = array([9.]), ar_sym_amt = array([980.42644501]), portf_value = 980.4264450073242
# 2023-05-23 portf_value = 980.4264450073242
# date = '2023-05-23', symbol = 'SPY', price = 412.5575256347656, share = 2.0, value = 825.1150512695312
# 2023-05-23 SPY value = 825.1150512695312
# next_date_n pick's portf value = 980.4264450073242
# next_date_n SPY portf value =    825.1150512695312
# ====================
#
# date: 2023-05-19 is in dates_NYSE,  date's position in dates_NYSE is: 2613 of 2767,  n: 1,  idx_date_n: 2614,
# idx_date_n: 2614 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-22"
#
# date: 2023-05-19,  n: 1,  next_date_n: 2023-05-22 is in df_close
# picks for 2023-05-19: ['SHV']
# date = '2023-05-22', l_syms = ['SHV'], ar_price = array([108.91652679]), ar_sym_share = array([9.]), ar_sym_amt = array([980.24874115]), portf_value = 980.2487411499023
# 2023-05-22 portf_value = 980.2487411499023
# date = '2023-05-22', symbol = 'SPY', price = 417.2401428222656, share = 2.0, value = 834.4802856445312
# 2023-05-22 SPY value = 834.4802856445312
# next_date_n pick's portf value = 980.2487411499023
# next_date_n SPY portf value =    834.4802856445312
# ====================
#
# date: 2023-05-18 is in dates_NYSE,  date's position in dates_NYSE is: 2612 of 2767,  n: 1,  idx_date_n: 2613,
# idx_date_n: 2613 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-19"
#
# date: 2023-05-18,  n: 1,  next_date_n: 2023-05-19 is in df_close
# picks for 2023-05-18: ['SHV', 'TMHC']
# date = '2023-05-19', l_syms = ['SHV', 'TMHC'], ar_price = array([108.91652679,  44.25      ]), ar_sym_share = array([ 4., 11.]), ar_sym_amt = array([435.66610718, 486.75      ]), portf_value = 922.4161071777344
# 2023-05-19 portf_value = 922.4161071777344
# date = '2023-05-19', symbol = 'SPY', price = 417.07073974609375, share = 2.0, value = 834.1414794921875
# 2023-05-19 SPY value = 834.1414794921875
# next_date_n pick's portf value = 922.4161071777344
# next_date_n SPY portf value =    834.1414794921875
# ====================
#
# date: 2023-05-17 is in dates_NYSE,  date's position in dates_NYSE is: 2611 of 2767,  n: 1,  idx_date_n: 2612,
# idx_date_n: 2612 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-18"
#
# date: 2023-05-17,  n: 1,  next_date_n: 2023-05-18 is in df_close
# picks for 2023-05-17: ['SHV']
# date = '2023-05-18', l_syms = ['SHV'], ar_price = array([108.91652679]), ar_sym_share = array([9.]), ar_sym_amt = array([980.24874115]), portf_value = 980.2487411499023
# 2023-05-18 portf_value = 980.2487411499023
# date = '2023-05-18', symbol = 'SPY', price = 417.6784973144531, share = 2.0, value = 835.3569946289062
# 2023-05-18 SPY value = 835.3569946289062
# next_date_n pick's portf value = 980.2487411499023
# next_date_n SPY portf value =    835.3569946289062
# ====================
#
# date: 2023-05-16 is in dates_NYSE,  date's position in dates_NYSE is: 2610 of 2767,  n: 1,  idx_date_n: 2611,
# ...
# date = '2023-04-06', symbol = 'SPY', price = 407.6756591796875, share = 2.0, value = 815.351318359375
# 2023-04-06 SPY value = 815.351318359375
# next_date_n pick's portf value = 975.9194412231445
# next_date_n SPY portf value =    815.351318359375
# ====================
#
# date: 2023-04-04 is in dates_NYSE,  date's position in dates_NYSE is: 2581 of 2767,  n: 1,  idx_date_n: 2582,
# idx_date_n: 2582 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-04-05"
#
# date: 2023-04-04,  n: 1,  next_date_n: 2023-04-05 is in df_close
# picks for 2023-04-04: ['NVDA', 'SHV']
# date = '2023-04-05', l_syms = ['NVDA', 'SHV'], ar_price = array([268.78219604, 108.43549347]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([268.78219604, 433.74197388]), portf_value = 702.524169921875
# 2023-04-05 portf_value = 702.524169921875
# date = '2023-04-05', symbol = 'SPY', price = 406.091552734375, share = 2.0, value = 812.18310546875
# 2023-04-05 SPY value = 812.18310546875
# next_date_n pick's portf value = 702.524169921875
# next_date_n SPY portf value =    812.18310546875
# ====================
#
# date: 2023-04-03 is in dates_NYSE,  date's position in dates_NYSE is: 2580 of 2767,  n: 1,  idx_date_n: 2581,
# idx_date_n: 2581 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-04-04"
#
# date: 2023-04-03,  n: 1,  next_date_n: 2023-04-04 is in df_close
# picks for 2023-04-03: ['GE', 'NVDA']
# date = '2023-04-04', l_syms = ['GE', 'NVDA'], ar_price = array([ 94.97976685, 274.50158691]), ar_sym_share = array([5., 1.]), ar_sym_amt = array([474.89883423, 274.50158691]), portf_value = 749.4004211425781
# 2023-04-04 portf_value = 749.4004211425781
# date = '2023-04-04', symbol = 'SPY', price = 407.1575927734375, share = 2.0, value = 814.315185546875
# 2023-04-04 SPY value = 814.315185546875
# next_date_n pick's portf value = 749.4004211425781
# next_date_n SPY portf value =    814.315185546875
# ====================
#
# date: 2023-03-31 is in dates_NYSE,  date's position in dates_NYSE is: 2579 of 2767,  n: 1,  idx_date_n: 2580,
# idx_date_n: 2580 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-04-03"
#
# date: 2023-03-31,  n: 1,  next_date_n: 2023-04-03 is in df_close
# picks for 2023-03-31: ['NVDA']
# date = '2023-04-03', l_syms = ['NVDA'], ar_price = array([279.62106323]), ar_sym_share = array([3.]), ar_sym_amt = array([838.8631897]), portf_value = 838.8631896972656
# 2023-04-03 portf_value = 838.8631896972656
# date = '2023-04-03', symbol = 'SPY', price = 409.42913818359375, share = 2.0, value = 818.8582763671875
# 2023-04-03 SPY value = 818.8582763671875
# next_date_n pick's portf value = 838.8631896972656
# next_date_n SPY portf value =    818.8582763671875
# ====================
#
# date: 2023-03-30 is in dates_NYSE,  date's position in dates_NYSE is: 2578 of 2767,  n: 1,  idx_date_n: 2579,
# idx_date_n: 2579 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-31"
#
# date: 2023-03-30,  n: 1,  next_date_n: 2023-03-31 is in df_close
# picks for 2023-03-30: ['SHV']
# date = '2023-03-31', l_syms = ['SHV'], ar_price = array([108.34593964]), ar_sym_share = array([9.]), ar_sym_amt = array([975.11345673]), portf_value = 975.1134567260742
# 2023-03-31 portf_value = 975.1134567260742
# date = '2023-03-31', symbol = 'SPY', price = 407.8749084472656, share = 2.0, value = 815.7498168945312
# 2023-03-31 SPY value = 815.7498168945312
# next_date_n pick's portf value = 975.1134567260742
# next_date_n SPY portf value =    815.7498168945312
# ====================
#
# date: 2023-03-30 is in dates_NYSE,  date's position in dates_NYSE is: 2578 of 2767,  n: 1,  idx_date_n: 2579,
# idx_date_n: 2579 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-31"
#
# date: 2023-03-30,  n: 1,  next_date_n: 2023-03-31 is in df_close
# picks for 2023-03-30: ['NVDA']
# date = '2023-03-31', l_syms = ['NVDA'], ar_price = array([277.74124146]), ar_sym_share = array([3.]), ar_sym_amt = array([833.22372437]), portf_value = 833.2237243652344
# 2023-03-31 portf_value = 833.2237243652344
# date = '2023-03-31', symbol = 'SPY', price = 407.8749084472656, share = 2.0, value = 815.7498168945312
# 2023-03-31 SPY value = 815.7498168945312
# next_date_n pick's portf value = 833.2237243652344
# next_date_n SPY portf value =    815.7498168945312
# ====================
#
# date: 2023-03-29 is in dates_NYSE,  date's position in dates_NYSE is: 2577 of 2767,  n: 1,  idx_date_n: 2578,
# idx_date_n: 2578 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-30"
#
# date: 2023-03-29,  n: 1,  next_date_n: 2023-03-30 is in df_close
# picks for 2023-03-29: ['SHV']
# date = '2023-03-30', l_syms = ['SHV'], ar_price = array([108.33613586]), ar_sym_share = array([9.]), ar_sym_amt = array([975.02522278]), portf_value = 975.0252227783203
# 2023-03-30 portf_value = 975.0252227783203
# date = '2023-03-30', symbol = 'SPY', price = 402.2059631347656, share = 2.0, value = 804.4119262695312
# 2023-03-30 SPY value = 804.4119262695312
# next_date_n pick's portf value = 975.0252227783203
# next_date_n SPY portf value =    804.4119262695312
# ====================
#
# date: 2023-03-28 is in dates_NYSE,  date's position in dates_NYSE is: 2576 of 2767,  n: 1,  idx_date_n: 2577,
# idx_date_n: 2577 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-29"
#
# date: 2023-03-28,  n: 1,  next_date_n: 2023-03-29 is in df_close
# picks for 2023-03-28: ['SHV']
# date = '2023-03-29', l_syms = ['SHV'], ar_price = array([108.31652832]), ar_sym_share = array([9.]), ar_sym_amt = array([974.84875488]), portf_value = 974.8487548828125
# 2023-03-29 portf_value = 974.8487548828125
# date = '2023-03-29', symbol = 'SPY', price = 399.8646545410156, share = 2.0, value = 799.7293090820312
# 2023-03-29 SPY value = 799.7293090820312
# next_date_n pick's portf value = 974.8487548828125
# next_date_n SPY portf value =    799.7293090820312
# ====================
#
# date: 2023-03-27 is in dates_NYSE,  date's position in dates_NYSE is: 2575 of 2767,  n: 1,  idx_date_n: 2576,
# idx_date_n: 2576 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-28"
#
# date: 2023-03-27,  n: 1,  next_date_n: 2023-03-28 is in df_close
# picks for 2023-03-27: ['SHV']
# date = '2023-03-28', l_syms = ['SHV'], ar_price = array([108.30671692]), ar_sym_share = array([9.]), ar_sym_amt = array([974.76045227]), portf_value = 974.7604522705078
# 2023-03-28 portf_value = 974.7604522705078
# date = '2023-03-28', symbol = 'SPY', price = 394.1359558105469, share = 2.0, value = 788.2719116210938
# 2023-03-28 SPY value = 788.2719116210938
# next_date_n pick's portf value = 974.7604522705078
# next_date_n SPY portf value =    788.2719116210938
# ====================
#
# date: 2023-03-27 is in dates_NYSE,  date's position in dates_NYSE is: 2575 of 2767,  n: 1,  idx_date_n: 2576,
# idx_date_n: 2576 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-28"
#
# date: 2023-03-27,  n: 1,  next_date_n: 2023-03-28 is in df_close
# picks for 2023-03-27: ['GE']
# date = '2023-03-28', l_syms = ['GE'], ar_price = array([93.07117462]), ar_sym_share = array([10.]), ar_sym_amt = array([930.71174622]), portf_value = 930.7117462158203
# 2023-03-28 portf_value = 930.7117462158203
# date = '2023-03-28', symbol = 'SPY', price = 394.1359558105469, share = 2.0, value = 788.2719116210938
# 2023-03-28 SPY value = 788.2719116210938
# next_date_n pick's portf value = 930.7117462158203
# next_date_n SPY portf value =    788.2719116210938
# ====================
#
# date: 2023-03-24 is in dates_NYSE,  date's position in dates_NYSE is: 2574 of 2767,  n: 1,  idx_date_n: 2575,
# idx_date_n: 2575 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-27"
#
# date: 2023-03-24,  n: 1,  next_date_n: 2023-03-27 is in df_close
# picks for 2023-03-24: ['NVDA', 'SHV']
# date = '2023-03-27', l_syms = ['NVDA', 'SHV'], ar_price = array([265.28253174, 108.29690552]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([265.28253174, 433.18762207]), portf_value = 698.4701538085938
# 2023-03-27 portf_value = 698.4701538085938
# date = '2023-03-27', symbol = 'SPY', price = 395.02264404296875, share = 2.0, value = 790.0452880859375
# 2023-03-27 SPY value = 790.0452880859375
# next_date_n pick's portf value = 698.4701538085938
# next_date_n SPY portf value =    790.0452880859375
# ====================
#
# date: 2023-03-23 is in dates_NYSE,  date's position in dates_NYSE is: 2573 of 2767,  n: 1,  idx_date_n: 2574,
# idx_date_n: 2574 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-24"
#
# date: 2023-03-23,  n: 1,  next_date_n: 2023-03-24 is in df_close
# picks for 2023-03-23: ['SHV']
# date = '2023-03-24', l_syms = ['SHV'], ar_price = array([108.29690552]), ar_sym_share = array([9.]), ar_sym_amt = array([974.67214966]), portf_value = 974.6721496582031
# 2023-03-24 portf_value = 974.6721496582031
# date = '2023-03-24', symbol = 'SPY', price = 394.285400390625, share = 2.0, value = 788.57080078125
# 2023-03-24 SPY value = 788.57080078125
# next_date_n pick's portf value = 974.6721496582031
# next_date_n SPY portf value =    788.57080078125
# ====================
#
# date: 2023-03-22 is in dates_NYSE,  date's position in dates_NYSE is: 2572 of 2767,  n: 1,  idx_date_n: 2573,
# idx_date_n: 2573 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-23"
#
# date: 2023-03-22,  n: 1,  next_date_n: 2023-03-23 is in df_close
# picks for 2023-03-22: ['SHV']
# date = '2023-03-23', l_syms = ['SHV'], ar_price = array([108.28710938]), ar_sym_share = array([9.]), ar_sym_amt = array([974.58398438]), portf_value = 974.583984375
# 2023-03-23 portf_value = 974.583984375
# date = '2023-03-23', symbol = 'SPY', price = 391.7149353027344, share = 2.0, value = 783.4298706054688
# 2023-03-23 SPY value = 783.4298706054688
# next_date_n pick's portf value = 974.583984375
# next_date_n SPY portf value =    783.4298706054688
# ====================
#
# date: 2023-03-22 is in dates_NYSE,  date's position in dates_NYSE is: 2572 of 2767,  n: 1,  idx_date_n: 2573,
# idx_date_n: 2573 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-23"
#
# date: 2023-03-22,  n: 1,  next_date_n: 2023-03-23 is in df_close
# picks for 2023-03-22: ['FTSM']
# date = '2023-03-23', l_syms = ['FTSM'], ar_price = array([58.55865097]), ar_sym_share = array([17.]), ar_sym_amt = array([995.4970665]), portf_value = 995.4970664978027
# 2023-03-23 portf_value = 995.4970664978027
# date = '2023-03-23', symbol = 'SPY', price = 391.7149353027344, share = 2.0, value = 783.4298706054688
# 2023-03-23 SPY value = 783.4298706054688
# next_date_n pick's portf value = 995.4970664978027
# next_date_n SPY portf value =    783.4298706054688
# ====================
#
# date: 2023-03-21 is in dates_NYSE,  date's position in dates_NYSE is: 2571 of 2767,  n: 1,  idx_date_n: 2572,
# idx_date_n: 2572 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-22"
#
# date: 2023-03-21,  n: 1,  next_date_n: 2023-03-22 is in df_close
# picks for 2023-03-21: ['SHV']
# date = '2023-03-22', l_syms = ['SHV'], ar_price = array([108.21847534]), ar_sym_share = array([9.]), ar_sym_amt = array([973.96627808]), portf_value = 973.9662780761719
# 2023-03-22 portf_value = 973.9662780761719
# date = '2023-03-22', symbol = 'SPY', price = 390.6588439941406, share = 2.0, value = 781.3176879882812
# 2023-03-22 SPY value = 781.3176879882812
# next_date_n pick's portf value = 973.9662780761719
# next_date_n SPY portf value =    781.3176879882812
# ====================
#
# date: 2023-03-21 is in dates_NYSE,  date's position in dates_NYSE is: 2571 of 2767,  n: 1,  idx_date_n: 2572,
# idx_date_n: 2572 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-22"
#
# date: 2023-03-21,  n: 1,  next_date_n: 2023-03-22 is in df_close
# picks for 2023-03-21: ['GE']
# date = '2023-03-22', l_syms = ['GE'], ar_price = array([89.52379608]), ar_sym_share = array([11.]), ar_sym_amt = array([984.7617569]), portf_value = 984.7617568969727
# 2023-03-22 portf_value = 984.7617568969727
# date = '2023-03-22', symbol = 'SPY', price = 390.6588439941406, share = 2.0, value = 781.3176879882812
# 2023-03-22 SPY value = 781.3176879882812
# next_date_n pick's portf value = 984.7617568969727
# next_date_n SPY portf value =    781.3176879882812
# ====================
#
# date: 2023-03-20 is in dates_NYSE,  date's position in dates_NYSE is: 2570 of 2767,  n: 1,  idx_date_n: 2571,
# idx_date_n: 2571 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-21"
#
# date: 2023-03-20,  n: 1,  next_date_n: 2023-03-21 is in df_close
# picks for 2023-03-20: ['FTSM', 'SHV']
# date = '2023-03-21', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.4899559, 108.179245 ]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([467.91964722, 432.71697998]), portf_value = 900.6366271972656
# 2023-03-21 portf_value = 900.6366271972656
# date = '2023-03-21', symbol = 'SPY', price = 397.4336853027344, share = 2.0, value = 794.8673706054688
# 2023-03-21 SPY value = 794.8673706054688
# next_date_n pick's portf value = 900.6366271972656
# next_date_n SPY portf value =    794.8673706054688
# ====================
#
# date: 2023-03-17 is in dates_NYSE,  date's position in dates_NYSE is: 2569 of 2767,  n: 1,  idx_date_n: 2570,
# idx_date_n: 2570 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-20"
#
# date: 2023-03-17,  n: 1,  next_date_n: 2023-03-20 is in df_close
# picks for 2023-03-17: ['FTSM', 'SHV']
# date = '2023-03-20', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.54883957, 108.20866394]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([468.39071655, 432.83465576]), portf_value = 901.2253723144531
# 2023-03-20 portf_value = 901.2253723144531
# date = '2023-03-20', symbol = 'SPY', price = 392.2828063964844, share = 2.0, value = 784.5656127929688
# 2023-03-20 SPY value = 784.5656127929688
# next_date_n pick's portf value = 901.2253723144531
# next_date_n SPY portf value =    784.5656127929688
# ====================
#
# date: 2023-03-17 is in dates_NYSE,  date's position in dates_NYSE is: 2569 of 2767,  n: 1,  idx_date_n: 2570,
# idx_date_n: 2570 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-20"
#
# date: 2023-03-17,  n: 1,  next_date_n: 2023-03-20 is in df_close
# picks for 2023-03-17: ['GE']
# date = '2023-03-20', l_syms = ['GE'], ar_price = array([89.85355377]), ar_sym_share = array([11.]), ar_sym_amt = array([988.38909149]), portf_value = 988.3890914916992
# 2023-03-20 portf_value = 988.3890914916992
# date = '2023-03-20', symbol = 'SPY', price = 392.2828063964844, share = 2.0, value = 784.5656127929688
# 2023-03-20 SPY value = 784.5656127929688
# next_date_n pick's portf value = 988.3890914916992
# next_date_n SPY portf value =    784.5656127929688
# ====================
#
# date: 2023-03-16 is in dates_NYSE,  date's position in dates_NYSE is: 2568 of 2767,  n: 1,  idx_date_n: 2569,
# idx_date_n: 2569 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-17"
#
# date: 2023-03-16,  n: 1,  next_date_n: 2023-03-17 is in df_close
# picks for 2023-03-16: ['FTSM', 'SHV']
# date = '2023-03-17', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.46051407, 108.22827911]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([467.68411255, 432.91311646]), portf_value = 900.5972290039062
# 2023-03-17 portf_value = 900.5972290039062
# date = '2023-03-17', symbol = 'SPY', price = 388.54669189453125, share = 2.0, value = 777.0933837890625
# 2023-03-17 SPY value = 777.0933837890625
# next_date_n pick's portf value = 900.5972290039062
# next_date_n SPY portf value =    777.0933837890625
# ====================
#
# date: 2023-03-15 is in dates_NYSE,  date's position in dates_NYSE is: 2567 of 2767,  n: 1,  idx_date_n: 2568,
# idx_date_n: 2568 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-03-16"
#
# date: 2023-03-15,  n: 1,  next_date_n: 2023-03-16 is in df_close
# picks for 2023-03-15: ['FTSM', 'SHV']
# date = '2023-03-16', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.4703331 , 108.14984131]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([467.76266479, 432.59936523]), portf_value = 900.3620300292969
# 2023-03-16 portf_value = 900.3620300292969
# date = '2023-03-16', symbol = 'SPY', price = 393.14361572265625, share = 2.0, value = 786.2872314453125
# 2023-03-16 SPY value = 786.2872314453125
# next_date_n pick's portf value = 900.3620300292969
# next_date_n SPY portf value =    786.2872314453125
# ====================

# %% [markdown]
# #### Below cells calculate past performance of model picks

# %%
def calc_portf_shares(df_close, date, str_symbols, portf_target):
  # calculate number of shares to buy for symbols in str_symbols to meet port_target
  import numpy as np
  from ast import literal_eval    
  l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
  # array of closing prices corresponding to symbols in l_syms    
  ar_price = df_close.loc[date][l_syms].values  
  sym_cnt = len(l_syms)  # number of symbols
  amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
  ar_shares = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
  return ar_shares

# %%
def calc_portf_value(df_close, date, str_symbols, ar_shares, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    ar_value = ar_price * ar_shares  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_value)  # total actual portfolio value
    if verbose:
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_shares = }, {ar_value = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_shares, ar_value, portf_value

# %%
def get_next_date_n(df_close, date, n=1):

    """Get the next n(default=1) date from df_close. date has to in df_close.index.

    Edge case: The function won't return the first date in df_close as the
    next trading date, if date is a trading date just before the first date in df_close.
    """

    len_df_close = len(df_close)
    idx_dates = df_close.index.strftime('%Y-%m-%d')  # date index of df_close    

    if date in idx_dates:
        idx_next_date = idx_dates.get_loc(date) + n  # get index position of next date
        print(f'n: {n},  idx_next_date: {idx_next_date}')

        if idx_next_date >= 0:  # if idx_nex_date is negative, stop index loop back from index[0] to index[-1]    
            if idx_next_date >= (len_df_close - n):  # next date's index is within bound of df_close
                next_date = idx_dates[idx_dates.get_loc(date) + n]  # get the next date
                return next_date
        
              
            else:  # idx_next_date is out-of_bounds df_close
                print(f"{date} is the last date in df_close. No data for next {n} day")
                return None    
        
        
        else:  # idx_next_date is negative, no data in df_close
            # no data from df_close
            print(f'idx_next_date: {idx_next_date} is negative, no data for {n} days from {date} in df_close')

    else:     
        # no data from df_close
        print(f'no data for {date} in df_close')
        return None

# %%
def is_date_in_close(date, df_close):
  idx_close = df_close.index.strftime('%Y-%m-%d')
  if date in idx_close:
    return date
  else:
    return None

# %%
def calc_portf_value_date_buy(my_dates, my_symbols, df_close, portf_target, n, verbose=False):
  
  z_date_syms = zip(my_dates, my_symbols)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, syms in z_date_syms:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date = None
      p_ar_shares = None
      p_portf_value = None  # set to None when data are not available in df_close
      SPY_shares = None
      SPY_value = None  # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        print(f'No data for close_date_n {close_date_n}, SPY portf value =    None')

    else:    
      p_ar_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      p_date, l_syms, ar_price, ar_shares, ar_value, p_portf_value = \
        calc_portf_value(df_close, close_date_n, syms, p_ar_shares, verbose)

      syms = str(['SPY'])
      SPY_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      date, l_syms, ar_price, ar_shares, ar_value, SPY_value = \
        calc_portf_value(df_close, close_date_n, syms, SPY_shares, verbose)

      if verbose:
        print(f"close_date_n pick's portf value = {p_portf_value}")
        print(f'close_date_n SPY portf value =    {SPY_value}')

    date_exec.append(p_date)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_portf_value)
    shares_SPY.append(SPY_shares)
    value_SPY.append(SPY_value)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
def calc_portf_value_date_n(my_dates, my_symbols, df_close, my_portf_shares, my_SPY_shares, n, verbose=False):
  
  z_date_syms_shares = zip(my_dates, my_symbols, my_portf_shares, my_SPY_shares)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, symbols, portf_shares, SPY_shares in z_date_syms_shares:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date_exec = None
      p_ar_shares = None
      p_value_portf = None  # set to None when data are not available in df_close
      SPY_ar_shares = None
      SPY_value_portf = None # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        # print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else: 
      if portf_shares is None:
        p_date_exec = None
        p_ar_shares = None
        p_value_portf = None
        SPY_ar_shares = None
        SPY_value_portf = None

      else:  
        p_date_exec, p_ar_syms, p_ar_price, p_ar_shares, p_ar_value, p_value_portf = \
          calc_portf_value(df_close, close_date_n, symbols, portf_shares, verbose)
        
        SPY = str(['SPY'])
        SPY_date_exec, SPY_ar_syms, SPY_ar_price, SPY_ar_shares, SPY_ar_value, SPY_value_portf = \
          calc_portf_value(df_close, close_date_n, SPY, SPY_shares, verbose) 

        if verbose:
          print(f"next_date_n pick's portf value = {p_value_portf}")
          print(f'next_date_n SPY portf value =    {SPY_value_portf}')

    date_exec.append(p_date_exec)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_value_portf)
    shares_SPY.append(SPY_ar_shares)
    value_SPY.append(SPY_value_portf)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
# total target investment for each day's picks, if day's pick has 2 symbols, the function will try to invest $500 for each symbol
portf_target = 1000  
date_buy, shares_syms, value_portf, shares_SPY, value_SPY = calc_portf_value_date_buy(df_mp.date, df_mp.symbols, df_close, portf_target, n=1, verbose=verbose)
# Out:
# No data for close_date_n None, pick's portf value = None
# No data for close_date_n None, SPY portf value =    None
# ====================
#
# date = '2023-08-08', l_syms = ['SHV'], ar_price = array([110.09999847]), ar_shares = array([9.]), ar_value = array([990.89998627]), portf_value = 990.8999862670898
# 2023-08-08 portf_value = 990.8999862670898
# date = '2023-08-08', l_syms = ['SPY'], ar_price = array([448.75]), ar_shares = array([2.]), ar_value = array([897.5]), portf_value = 897.5
# 2023-08-08 portf_value = 897.5
# close_date_n pick's portf value = 990.8999862670898
# close_date_n SPY portf value =    897.5
# ====================
#
# date = '2023-08-07', l_syms = ['SHV'], ar_price = array([110.08000183]), ar_shares = array([9.]), ar_value = array([990.72001648]), portf_value = 990.7200164794922
# 2023-08-07 portf_value = 990.7200164794922
# date = '2023-08-07', l_syms = ['SPY'], ar_price = array([450.70999146]), ar_shares = array([2.]), ar_value = array([901.41998291]), portf_value = 901.4199829101562
# 2023-08-07 portf_value = 901.4199829101562
# close_date_n pick's portf value = 990.7200164794922
# close_date_n SPY portf value =    901.4199829101562
# ====================
#
# date = '2023-08-04', l_syms = ['SHV'], ar_price = array([110.08000183]), ar_shares = array([9.]), ar_value = array([990.72001648]), portf_value = 990.7200164794922
# 2023-08-04 portf_value = 990.7200164794922
# date = '2023-08-04', l_syms = ['SPY'], ar_price = array([446.80999756]), ar_shares = array([2.]), ar_value = array([893.61999512]), portf_value = 893.6199951171875
# 2023-08-04 portf_value = 893.6199951171875
# close_date_n pick's portf value = 990.7200164794922
# close_date_n SPY portf value =    893.6199951171875
# ====================
#
# date = '2023-08-03', l_syms = ['SHV'], ar_price = array([110.05000305]), ar_shares = array([9.]), ar_value = array([990.45002747]), portf_value = 990.4500274658203
# 2023-08-03 portf_value = 990.4500274658203
# date = '2023-08-03', l_syms = ['SPY'], ar_price = array([448.83999634]), ar_shares = array([2.]), ar_value = array([897.67999268]), portf_value = 897.6799926757812
# 2023-08-03 portf_value = 897.6799926757812
# close_date_n pick's portf value = 990.4500274658203
# close_date_n SPY portf value =    897.6799926757812
# ====================
#
# date = '2023-07-28', l_syms = ['SHV'], ar_price = array([109.95308685]), ar_shares = array([9.]), ar_value = array([989.57778168]), portf_value = 989.5777816772461
# 2023-07-28 portf_value = 989.5777816772461
# date = '2023-07-28', l_syms = ['SPY'], ar_price = array([456.92001343]), ar_shares = array([2.]), ar_value = array([913.84002686]), portf_value = 913.8400268554688
# 2023-07-28 portf_value = 913.8400268554688
# close_date_n pick's portf value = 989.5777816772461
# close_date_n SPY portf value =    913.8400268554688
# ====================
#
# date = '2023-07-27', l_syms = ['SHV'], ar_price = array([109.92321014]), ar_shares = array([9.]), ar_value = array([989.3088913]), portf_value = 989.3088912963867
# 2023-07-27 portf_value = 989.3088912963867
# date = '2023-07-27', l_syms = ['SPY'], ar_price = array([452.48999023]), ar_shares = array([2.]), ar_value = array([904.97998047]), portf_value = 904.97998046875
# 2023-07-27 portf_value = 904.97998046875
# close_date_n pick's portf value = 989.3088912963867
# close_date_n SPY portf value =    904.97998046875
# ====================
#
# date = '2023-07-26', l_syms = ['SHV'], ar_price = array([109.88337708]), ar_shares = array([9.]), ar_value = array([988.95039368]), portf_value = 988.9503936767578
# 2023-07-26 portf_value = 988.9503936767578
# date = '2023-07-26', l_syms = ['SPY'], ar_price = array([455.51000977]), ar_shares = array([2.]), ar_value = array([911.02001953]), portf_value = 911.02001953125
# 2023-07-26 portf_value = 911.02001953125
# close_date_n pick's portf value = 988.9503936767578
# close_date_n SPY portf value =    911.02001953125
# ====================
#
# date = '2023-07-24', l_syms = ['SHV'], ar_price = array([109.853508]), ar_shares = array([9.]), ar_value = array([988.68157196]), portf_value = 988.6815719604492
# 2023-07-24 portf_value = 988.6815719604492
# date = '2023-07-24', l_syms = ['SPY'], ar_price = array([454.20001221]), ar_shares = array([2.]), ar_value = array([908.40002441]), portf_value = 908.4000244140625
# 2023-07-24 portf_value = 908.4000244140625
# close_date_n pick's portf value = 988.6815719604492
# close_date_n SPY portf value =    908.4000244140625
# ====================
#
# date = '2023-07-21', l_syms = ['SHV'], ar_price = array([109.84355164]), ar_shares = array([9.]), ar_value = array([988.59196472]), portf_value = 988.5919647216797
# 2023-07-21 portf_value = 988.5919647216797
# date = '2023-07-21', l_syms = ['SPY'], ar_price = array([452.17999268]), ar_shares = array([2.]), ar_value = array([904.35998535]), portf_value = 904.3599853515625
# 2023-07-21 portf_value = 904.3599853515625
# close_date_n pick's portf value = 988.5919647216797
# close_date_n SPY portf value =    904.3599853515625
# ====================
#
# date = '2023-07-19', l_syms = ['SHV'], ar_price = array([109.78380585]), ar_shares = array([9.]), ar_value = array([988.05425262]), portf_value = 988.0542526245117
# 2023-07-19 portf_value = 988.0542526245117
# date = '2023-07-19', l_syms = ['SPY'], ar_price = array([455.20001221]), ar_shares = array([2.]), ar_value = array([910.40002441]), portf_value = 910.4000244140625
# 2023-07-19 portf_value = 910.4000244140625
# close_date_n pick's portf value = 988.0542526245117
# close_date_n SPY portf value =    910.4000244140625
# ====================
#
# date = '2023-07-17', l_syms = ['SHV'], ar_price = array([109.75392914]), ar_shares = array([9.]), ar_value = array([987.78536224]), portf_value = 987.7853622436523
# 2023-07-17 portf_value = 987.7853622436523
# date = '2023-07-17', l_syms = ['SPY'], ar_price = array([450.83999634]), ar_shares = array([2.]), ar_value = array([901.67999268]), portf_value = 901.6799926757812
# 2023-07-17 portf_value = 901.6799926757812
# close_date_n pick's portf value = 987.7853622436523
# close_date_n SPY portf value =    901.6799926757812
# ====================
#
# date = '2023-07-14', l_syms = ['SHV', 'SKYW'], ar_price = array([109.74397278,  40.43000031]), ar_shares = array([ 4., 12.]), ar_value = array([438.97589111, 485.16000366]), portf_value = 924.1358947753906
# 2023-07-14 portf_value = 924.1358947753906
# date = '2023-07-14', l_syms = ['SPY'], ar_price = array([449.27999878]), ar_shares = array([2.]), ar_value = array([898.55999756]), portf_value = 898.5599975585938
# 2023-07-14 portf_value = 898.5599975585938
# close_date_n pick's portf value = 924.1358947753906
# close_date_n SPY portf value =    898.5599975585938
# ====================
#
# date = '2023-07-13', l_syms = ['SHV', 'SKYW'], ar_price = array([109.73401642,  41.47000122]), ar_shares = array([ 4., 12.]), ar_value = array([438.93606567, 497.64001465]), portf_value = 936.5760803222656
# 2023-07-13 portf_value = 936.5760803222656
# date = '2023-07-13', l_syms = ['SPY'], ar_price = array([449.55999756]), ar_shares = array([2.]), ar_value = array([899.11999512]), portf_value = 899.1199951171875
# 2023-07-13 portf_value = 899.1199951171875
# close_date_n pick's portf value = 936.5760803222656
# close_date_n SPY portf value =    899.1199951171875
# ====================
#
# date = '2023-07-12', l_syms = ['SHV', 'SKYW'], ar_price = array([109.67427063,  41.11999893]), ar_shares = array([ 4., 12.]), ar_value = array([438.69708252, 493.43998718]), portf_value = 932.1370697021484
# 2023-07-12 portf_value = 932.1370697021484
# date = '2023-07-12', l_syms = ['SPY'], ar_price = array([446.01998901]), ar_shares = array([2.]), ar_value = array([892.03997803]), portf_value = 892.0399780273438
# 2023-07-12 portf_value = 892.0399780273438
# close_date_n pick's portf value = 932.1370697021484
# close_date_n SPY portf value =    892.0399780273438
# ====================
#
# date = '2023-07-11', l_syms = ['SHV', 'SKYW'], ar_price = array([109.64439392,  41.75      ]), ar_shares = array([ 4., 11.]), ar_value = array([438.57757568, 459.25      ]), portf_value = 897.8275756835938
# 2023-07-11 portf_value = 897.8275756835938
# date = '2023-07-11', l_syms = ['SPY'], ar_price = array([442.45999146]), ar_shares = array([2.]), ar_value = array([884.91998291]), portf_value = 884.9199829101562
# 2023-07-11 portf_value = 884.9199829101562
# close_date_n pick's portf value = 897.8275756835938
# close_date_n SPY portf value =    884.9199829101562
# ====================
#
# date = '2023-07-10', l_syms = ['SHV', 'SKYW'], ar_price = array([109.64439392,  42.18999863]), ar_shares = array([ 4., 11.]), ar_value = array([438.57757568, 464.08998489]), portf_value = 902.6675605773926
# 2023-07-10 portf_value = 902.6675605773926
# date = '2023-07-10', l_syms = ['SPY'], ar_price = array([439.66000366]), ar_shares = array([2.]), ar_value = array([879.32000732]), portf_value = 879.3200073242188
# 2023-07-10 portf_value = 879.3200073242188
# close_date_n pick's portf value = 902.6675605773926
# close_date_n SPY portf value =    879.3200073242188
# ====================
#
# date = '2023-07-07', l_syms = ['SHV', 'SKYW'], ar_price = array([109.62447357,  40.86000061]), ar_shares = array([ 4., 12.]), ar_value = array([438.49789429, 490.32000732]), portf_value = 928.8179016113281
# 2023-07-07 portf_value = 928.8179016113281
# date = '2023-07-07', l_syms = ['SPY'], ar_price = array([438.54998779]), ar_shares = array([2.]), ar_value = array([877.09997559]), portf_value = 877.0999755859375
# 2023-07-07 portf_value = 877.0999755859375
# close_date_n pick's portf value = 928.8179016113281
# close_date_n SPY portf value =    877.0999755859375
# ====================
#
# date = '2023-07-06', l_syms = ['SHV'], ar_price = array([109.62447357]), ar_shares = array([9.]), ar_value = array([986.62026215]), portf_value = 986.6202621459961
# 2023-07-06 portf_value = 986.6202621459961
# date = '2023-07-06', l_syms = ['SPY'], ar_price = array([439.66000366]), ar_shares = array([2.]), ar_value = array([879.32000732]), portf_value = 879.3200073242188
# 2023-07-06 portf_value = 879.3200073242188
# close_date_n pick's portf value = 986.6202621459961
# close_date_n SPY portf value =    879.3200073242188
# ====================
#
# date = '2023-07-05', l_syms = ['SHV'], ar_price = array([109.56473541]), ar_shares = array([9.]), ar_value = array([986.08261871]), portf_value = 986.0826187133789
# 2023-07-05 portf_value = 986.0826187133789
# date = '2023-07-05', l_syms = ['SPY'], ar_price = array([443.13000488]), ar_shares = array([2.]), ar_value = array([886.26000977]), portf_value = 886.260009765625
# 2023-07-05 portf_value = 886.260009765625
# close_date_n pick's portf value = 986.0826187133789
# close_date_n SPY portf value =    886.260009765625
# ====================
#
# date = '2023-07-03', l_syms = ['SHV'], ar_price = array([109.54482269]), ar_shares = array([9.]), ar_value = array([985.90340424]), portf_value = 985.9034042358398
# 2023-07-03 portf_value = 985.9034042358398
# date = '2023-07-03', l_syms = ['SPY'], ar_price = array([443.79000854]), ar_shares = array([2.]), ar_value = array([887.58001709]), portf_value = 887.5800170898438
# 2023-07-03 portf_value = 887.5800170898438
# close_date_n pick's portf value = 985.9034042358398
# close_date_n SPY portf value =    887.5800170898438
# ====================
#
# date = '2023-06-30', l_syms = ['SHV', 'SKYW'], ar_price = array([109.55278778,  40.72000122]), ar_shares = array([ 4., 12.]), ar_value = array([438.21115112, 488.64001465]), portf_value = 926.8511657714844
# 2023-06-30 portf_value = 926.8511657714844
# date = '2023-06-30', l_syms = ['SPY'], ar_price = array([443.27999878]), ar_shares = array([2.]), ar_value = array([886.55999756]), portf_value = 886.5599975585938
# 2023-06-30 portf_value = 886.5599975585938
# close_date_n pick's portf value = 926.8511657714844
# close_date_n SPY portf value =    886.5599975585938
# ====================
#
# date = '2023-06-29', l_syms = ['SHV', 'SKYW'], ar_price = array([109.49327087,  40.38000107]), ar_shares = array([ 4., 12.]), ar_value = array([437.9730835 , 484.56001282]), portf_value = 922.5330963134766
# 2023-06-29 portf_value = 922.5330963134766
# date = '2023-06-29', l_syms = ['SPY'], ar_price = array([438.10998535]), ar_shares = array([2.]), ar_value = array([876.2199707]), portf_value = 876.219970703125
# 2023-06-29 portf_value = 876.219970703125
# close_date_n pick's portf value = 922.5330963134766
# close_date_n SPY portf value =    876.219970703125
# ====================
#
# date = '2023-06-28', l_syms = ['SHV', 'SKYW'], ar_price = array([109.47343445,  39.65000153]), ar_shares = array([ 4., 12.]), ar_value = array([437.89373779, 475.80001831]), portf_value = 913.6937561035156
# 2023-06-28 portf_value = 913.6937561035156
# date = '2023-06-28', l_syms = ['SPY'], ar_price = array([436.39001465]), ar_shares = array([2.]), ar_value = array([872.7800293]), portf_value = 872.780029296875
# 2023-06-28 portf_value = 872.780029296875
# close_date_n pick's portf value = 913.6937561035156
# close_date_n SPY portf value =    872.780029296875
# ====================
#
# date = '2023-06-27', l_syms = ['SHV', 'SKYW'], ar_price = array([109.46351624,  39.16999817]), ar_shares = array([ 4., 12.]), ar_value = array([437.85406494, 470.03997803]), portf_value = 907.89404296875
# 2023-06-27 portf_value = 907.89404296875
# date = '2023-06-27', l_syms = ['SPY'], ar_price = array([436.17001343]), ar_shares = array([2.]), ar_value = array([872.34002686]), portf_value = 872.3400268554688
# 2023-06-27 portf_value = 872.3400268554688
# close_date_n pick's portf value = 907.89404296875
# close_date_n SPY portf value =    872.3400268554688
# ====================
#
# date = '2023-06-26', l_syms = ['NVDA'], ar_price = array([406.32000732]), ar_shares = array([2.]), ar_value = array([812.64001465]), portf_value = 812.6400146484375
# 2023-06-26 portf_value = 812.6400146484375
# date = '2023-06-26', l_syms = ['SPY'], ar_price = array([431.44000244]), ar_shares = array([2.]), ar_value = array([862.88000488]), portf_value = 862.8800048828125
# 2023-06-26 portf_value = 862.8800048828125
# close_date_n pick's portf value = 812.6400146484375
# close_date_n SPY portf value =    862.8800048828125
# ====================
#
# date = '2023-06-26', l_syms = ['SHV', 'SKYW'], ar_price = array([109.44367981,  38.90999985]), ar_shares = array([ 4., 12.]), ar_value = array([437.77471924, 466.91999817]), portf_value = 904.6947174072266
# 2023-06-26 portf_value = 904.6947174072266
# date = '2023-06-26', l_syms = ['SPY'], ar_price = array([431.44000244]), ar_shares = array([2.]), ar_value = array([862.88000488]), portf_value = 862.8800048828125
# 2023-06-26 portf_value = 862.8800048828125
# close_date_n pick's portf value = 904.6947174072266
# close_date_n SPY portf value =    862.8800048828125
# ====================
#
# date = '2023-06-23', l_syms = ['NVDA'], ar_price = array([422.08999634]), ar_shares = array([2.]), ar_value = array([844.17999268]), portf_value = 844.1799926757812
# 2023-06-23 portf_value = 844.1799926757812
# date = '2023-06-23', l_syms = ['SPY'], ar_price = array([433.20999146]), ar_shares = array([2.]), ar_value = array([866.41998291]), portf_value = 866.4199829101562
# 2023-06-23 portf_value = 866.4199829101562
# close_date_n pick's portf value = 844.1799926757812
# close_date_n SPY portf value =    866.4199829101562
# ====================
#
# date = '2023-06-23', l_syms = ['SHV', 'SKYW'], ar_price = array([109.42384338,  39.56999969]), ar_shares = array([ 4., 12.]), ar_value = array([437.69537354, 474.83999634]), portf_value = 912.5353698730469
# 2023-06-23 portf_value = 912.5353698730469
# date = '2023-06-23', l_syms = ['SPY'], ar_price = array([433.20999146]), ar_shares = array([2.]), ar_value = array([866.41998291]), portf_value = 866.4199829101562
# 2023-06-23 portf_value = 866.4199829101562
# close_date_n pick's portf value = 912.5353698730469
# close_date_n SPY portf value =    866.4199829101562
# ====================
#
# date = '2023-06-22', l_syms = ['NVDA'], ar_price = array([430.25]), ar_shares = array([2.]), ar_value = array([860.5]), portf_value = 860.5
# 2023-06-22 portf_value = 860.5
# date = '2023-06-22', l_syms = ['SPY'], ar_price = array([436.51000977]), ar_shares = array([2.]), ar_value = array([873.02001953]), portf_value = 873.02001953125
# 2023-06-22 portf_value = 873.02001953125
# close_date_n pick's portf value = 860.5
# close_date_n SPY portf value =    873.02001953125
# ====================
#
# date = '2023-06-22', l_syms = ['SHV'], ar_price = array([109.41392517]), ar_shares = array([9.]), ar_value = array([984.72532654]), portf_value = 984.7253265380859
# 2023-06-22 portf_value = 984.7253265380859
# date = '2023-06-22', l_syms = ['SPY'], ar_price = array([436.51000977]), ar_shares = array([2.]), ar_value = array([873.02001953]), portf_value = 873.02001953125
# 2023-06-22 portf_value = 873.02001953125
# close_date_n pick's portf value = 984.7253265380859
# close_date_n SPY portf value =    873.02001953125
# ====================
#
# date = '2023-06-21', l_syms = ['NVDA'], ar_price = array([430.45001221]), ar_shares = array([2.]), ar_value = array([860.90002441]), portf_value = 860.9000244140625
# 2023-06-21 portf_value = 860.9000244140625
# date = '2023-06-21', l_syms = ['SPY'], ar_price = array([434.94000244]), ar_shares = array([2.]), ar_value = array([869.88000488]), portf_value = 869.8800048828125
# 2023-06-21 portf_value = 869.8800048828125
# close_date_n pick's portf value = 860.9000244140625
# close_date_n SPY portf value =    869.8800048828125
# ====================
#
# date = '2023-06-21', l_syms = ['SHV'], ar_price = array([109.37424469]), ar_shares = array([9.]), ar_value = array([984.36820221]), portf_value = 984.3682022094727
# 2023-06-21 portf_value = 984.3682022094727
# date = '2023-06-21', l_syms = ['SPY'], ar_price = array([434.94000244]), ar_shares = array([2.]), ar_value = array([869.88000488]), portf_value = 869.8800048828125
# 2023-06-21 portf_value = 869.8800048828125
# close_date_n pick's portf value = 984.3682022094727
# close_date_n SPY portf value =    869.8800048828125
# ====================
#
# date = '2023-06-20', l_syms = ['NVDA', 'SHV'], ar_price = array([438.07998657, 109.36433411]), ar_shares = array([1., 4.]), ar_value = array([438.07998657, 437.45733643]), portf_value = 875.5373229980469
# 2023-06-20 portf_value = 875.5373229980469
# date = '2023-06-20', l_syms = ['SPY'], ar_price = array([437.17999268]), ar_shares = array([2.]), ar_value = array([874.35998535]), portf_value = 874.3599853515625
# 2023-06-20 portf_value = 874.3599853515625
# close_date_n pick's portf value = 875.5373229980469
# close_date_n SPY portf value =    874.3599853515625
# ====================
#
# date = '2023-06-16', l_syms = ['NVDA', 'SHV'], ar_price = array([426.92001343, 109.36433411]), ar_shares = array([1., 4.]), ar_value = array([426.92001343, 437.45733643]), portf_value = 864.3773498535156
# 2023-06-16 portf_value = 864.3773498535156
# date = '2023-06-16', l_syms = ['SPY'], ar_price = array([439.45999146]), ar_shares = array([2.]), ar_value = array([878.91998291]), portf_value = 878.9199829101562
# 2023-06-16 portf_value = 878.9199829101562
# close_date_n pick's portf value = 864.3773498535156
# close_date_n SPY portf value =    878.9199829101562
# ====================
#
# date = '2023-06-15', l_syms = ['AVGO', 'NVDA', 'SHV'], ar_price = array([878.74841309, 426.52999878, 109.35441589]), ar_shares = array([0., 0., 3.]), ar_value = array([  0.        ,   0.        , 328.06324768]), portf_value = 328.06324768066406
# 2023-06-15 portf_value = 328.06324768066406
# date = '2023-06-15', l_syms = ['SPY'], ar_price = array([440.96200562]), ar_shares = array([2.]), ar_value = array([881.92401123]), portf_value = 881.9240112304688
# 2023-06-15 portf_value = 881.9240112304688
# close_date_n pick's portf value = 328.06324768066406
# close_date_n SPY portf value =    881.9240112304688
# ====================
#
# date = '2023-06-14', l_syms = ['SHV'], ar_price = array([109.27505493]), ar_shares = array([9.]), ar_value = array([983.47549438]), portf_value = 983.4754943847656
# 2023-06-14 portf_value = 983.4754943847656
# date = '2023-06-14', l_syms = ['SPY'], ar_price = array([435.56204224]), ar_shares = array([2.]), ar_value = array([871.12408447]), portf_value = 871.1240844726562
# 2023-06-14 portf_value = 871.1240844726562
# close_date_n pick's portf value = 983.4754943847656
# close_date_n SPY portf value =    871.1240844726562
# ====================
#
# date = '2023-06-13', l_syms = ['SHV'], ar_price = array([109.26515198]), ar_shares = array([9.]), ar_value = array([983.3863678]), portf_value = 983.3863677978516
# 2023-06-13 portf_value = 983.3863677978516
# date = '2023-06-13', l_syms = ['SPY'], ar_price = array([435.04397583]), ar_shares = array([2.]), ar_value = array([870.08795166]), portf_value = 870.0879516601562
# 2023-06-13 portf_value = 870.0879516601562
# close_date_n pick's portf value = 983.3863677978516
# close_date_n SPY portf value =    870.0879516601562
# ====================
#
# date = '2023-06-12', l_syms = ['NVDA', 'SHV'], ar_price = array([394.82000732, 109.24530792]), ar_shares = array([1., 4.]), ar_value = array([394.82000732, 436.98123169]), portf_value = 831.8012390136719
# 2023-06-12 portf_value = 831.8012390136719
# date = '2023-06-12', l_syms = ['SPY'], ar_price = array([432.19454956]), ar_shares = array([2.]), ar_value = array([864.38909912]), portf_value = 864.3890991210938
# 2023-06-12 portf_value = 864.3890991210938
# close_date_n pick's portf value = 831.8012390136719
# close_date_n SPY portf value =    864.3890991210938
# ====================
#
# date = '2023-06-09', l_syms = ['NVDA', 'SHV'], ar_price = array([387.70001221, 109.2254715 ]), ar_shares = array([1., 4.]), ar_value = array([387.70001221, 436.90188599]), portf_value = 824.6018981933594
# 2023-06-09 portf_value = 824.6018981933594
# date = '2023-06-09', l_syms = ['SPY'], ar_price = array([428.30899048]), ar_shares = array([2.]), ar_value = array([856.61798096]), portf_value = 856.6179809570312
# 2023-06-09 portf_value = 856.6179809570312
# close_date_n pick's portf value = 824.6018981933594
# close_date_n SPY portf value =    856.6179809570312
# ====================
#
# date = '2023-06-08', l_syms = ['EXAS'], ar_price = array([90.65000153]), ar_shares = array([11.]), ar_value = array([997.15001678]), portf_value = 997.150016784668
# 2023-06-08 portf_value = 997.150016784668
# date = '2023-06-08', l_syms = ['SPY'], ar_price = array([427.54187012]), ar_shares = array([2.]), ar_value = array([855.08374023]), portf_value = 855.083740234375
# 2023-06-08 portf_value = 855.083740234375
# close_date_n pick's portf value = 997.150016784668
# close_date_n SPY portf value =    855.083740234375
# ====================
#
# date = '2023-06-08', l_syms = ['SHV'], ar_price = array([109.2254715]), ar_shares = array([9.]), ar_value = array([983.02924347]), portf_value = 983.0292434692383
# 2023-06-08 portf_value = 983.0292434692383
# date = '2023-06-08', l_syms = ['SPY'], ar_price = array([427.54187012]), ar_shares = array([2.]), ar_value = array([855.08374023]), portf_value = 855.083740234375
# 2023-06-08 portf_value = 855.083740234375
# close_date_n pick's portf value = 983.0292434692383
# close_date_n SPY portf value =    855.083740234375
# ====================
#
# date = '2023-06-07', l_syms = ['NVDA', 'SHV'], ar_price = array([374.75      , 109.15604401]), ar_shares = array([1., 4.]), ar_value = array([374.75      , 436.62417603]), portf_value = 811.3741760253906
# 2023-06-07 portf_value = 811.3741760253906
# date = '2023-06-07', l_syms = ['SPY'], ar_price = array([424.97137451]), ar_shares = array([2.]), ar_value = array([849.94274902]), portf_value = 849.9427490234375
# 2023-06-07 portf_value = 849.9427490234375
# close_date_n pick's portf value = 811.3741760253906
# close_date_n SPY portf value =    849.9427490234375
# ====================
#
# date = '2023-06-06', l_syms = ['NVDA', 'SHV'], ar_price = array([386.5       , 109.13619995]), ar_shares = array([1., 4.]), ar_value = array([386.5      , 436.5447998]), portf_value = 823.0447998046875
# 2023-06-06 portf_value = 823.0447998046875
# date = '2023-06-06', l_syms = ['SPY'], ar_price = array([426.44592285]), ar_shares = array([2.]), ar_value = array([852.8918457]), portf_value = 852.891845703125
# 2023-06-06 portf_value = 852.891845703125
# close_date_n pick's portf value = 823.0447998046875
# close_date_n SPY portf value =    852.891845703125
# ====================
#
# date = '2023-06-05', l_syms = ['NVDA', 'SHV'], ar_price = array([391.66946411, 109.11636353]), ar_shares = array([1., 4.]), ar_value = array([391.66946411, 436.4654541 ]), portf_value = 828.1349182128906
# 2023-06-05 portf_value = 828.1349182128906
# date = '2023-06-05', l_syms = ['SPY'], ar_price = array([425.51937866]), ar_shares = array([2.]), ar_value = array([851.03875732]), portf_value = 851.0387573242188
# 2023-06-05 portf_value = 851.0387573242188
# close_date_n pick's portf value = 828.1349182128906
# close_date_n SPY portf value =    851.0387573242188
# ====================
#
# date = '2023-06-02', l_syms = ['META', 'NVDA'], ar_price = array([272.60998535, 393.22930908]), ar_shares = array([1., 1.]), ar_value = array([272.60998535, 393.22930908]), portf_value = 665.8392944335938
# 2023-06-02 portf_value = 665.8392944335938
# date = '2023-06-02', l_syms = ['SPY'], ar_price = array([426.33633423]), ar_shares = array([2.]), ar_value = array([852.67266846]), portf_value = 852.6726684570312
# 2023-06-02 portf_value = 852.6726684570312
# close_date_n pick's portf value = 665.8392944335938
# close_date_n SPY portf value =    852.6726684570312
# ====================
#
# date = '2023-06-01', l_syms = ['SHV'], ar_price = array([109.10643768]), ar_shares = array([9.]), ar_value = array([981.95793915]), portf_value = 981.9579391479492
# 2023-06-01 portf_value = 981.9579391479492
# date = '2023-06-01', l_syms = ['SPY'], ar_price = array([420.25891113]), ar_shares = array([2.]), ar_value = array([840.51782227]), portf_value = 840.517822265625
# 2023-06-01 portf_value = 840.517822265625
# close_date_n pick's portf value = 981.9579391479492
# close_date_n SPY portf value =    840.517822265625
# ====================
#
# date = '2023-06-01', l_syms = ['AVGO', 'NVDA'], ar_price = array([785.76379395, 397.65887451]), ar_shares = array([0., 1.]), ar_value = array([  0.        , 397.65887451]), portf_value = 397.65887451171875
# 2023-06-01 portf_value = 397.65887451171875
# date = '2023-06-01', l_syms = ['SPY'], ar_price = array([420.25891113]), ar_shares = array([2.]), ar_value = array([840.51782227]), portf_value = 840.517822265625
# 2023-06-01 portf_value = 840.517822265625
# close_date_n pick's portf value = 397.65887451171875
# close_date_n SPY portf value =    840.517822265625
# ====================
#
# date = '2023-05-31', l_syms = ['SHV'], ar_price = array([109.03502655]), ar_shares = array([9.]), ar_value = array([981.31523895]), portf_value = 981.3152389526367
# 2023-05-31 portf_value = 981.3152389526367
# date = '2023-05-31', l_syms = ['SPY'], ar_price = array([416.30361938]), ar_shares = array([2.]), ar_value = array([832.60723877]), portf_value = 832.6072387695312
# 2023-05-31 portf_value = 832.6072387695312
# close_date_n pick's portf value = 981.3152389526367
# close_date_n SPY portf value =    832.6072387695312
# ====================
#
# date = '2023-05-31', l_syms = ['AVGO', 'NVDA'], ar_price = array([803.67840576, 378.30084229]), ar_shares = array([0., 1.]), ar_value = array([  0.        , 378.30084229]), portf_value = 378.30084228515625
# 2023-05-31 portf_value = 378.30084228515625
# date = '2023-05-31', l_syms = ['SPY'], ar_price = array([416.30361938]), ar_shares = array([2.]), ar_value = array([832.60723877]), portf_value = 832.6072387695312
# 2023-05-31 portf_value = 832.6072387695312
# close_date_n pick's portf value = 378.30084228515625
# close_date_n SPY portf value =    832.6072387695312
# ====================
#
# date = '2023-05-30', l_syms = ['AVGO', 'SHV'], ar_price = array([799.08288574, 109.01527405]), ar_shares = array([0., 4.]), ar_value = array([  0.        , 436.06109619]), portf_value = 436.06109619140625
# 2023-05-30 portf_value = 436.06109619140625
# date = '2023-05-30', l_syms = ['SPY'], ar_price = array([418.62496948]), ar_shares = array([2.]), ar_value = array([837.24993896]), portf_value = 837.2499389648438
# 2023-05-30 portf_value = 837.2499389648438
# close_date_n pick's portf value = 436.06109619140625
# close_date_n SPY portf value =    837.2499389648438
# ====================
#
# date = '2023-05-30', l_syms = ['NVDA'], ar_price = array([401.06848145]), ar_shares = array([2.]), ar_value = array([802.13696289]), portf_value = 802.136962890625
# 2023-05-30 portf_value = 802.136962890625
# date = '2023-05-30', l_syms = ['SPY'], ar_price = array([418.62496948]), ar_shares = array([2.]), ar_value = array([837.24993896]), portf_value = 837.2499389648438
# 2023-05-30 portf_value = 837.2499389648438
# close_date_n pick's portf value = 802.136962890625
# close_date_n SPY portf value =    837.2499389648438
# ====================
#
# date = '2023-05-30', l_syms = ['AVGO'], ar_price = array([799.08288574]), ar_shares = array([1.]), ar_value = array([799.08288574]), portf_value = 799.0828857421875
# 2023-05-30 portf_value = 799.0828857421875
# date = '2023-05-30', l_syms = ['SPY'], ar_price = array([418.62496948]), ar_shares = array([2.]), ar_value = array([837.24993896]), portf_value = 837.2499389648438
# 2023-05-30 portf_value = 837.2499389648438
# close_date_n pick's portf value = 799.0828857421875
# close_date_n SPY portf value =    837.2499389648438
# ====================
#
# date = '2023-05-26', l_syms = ['SHV'], ar_price = array([109.00539398]), ar_shares = array([9.]), ar_value = array([981.04854584]), portf_value = 981.0485458374023
# 2023-05-26 portf_value = 981.0485458374023
# date = '2023-05-26', l_syms = ['SPY'], ar_price = array([418.46554565]), ar_shares = array([2.]), ar_value = array([836.93109131]), portf_value = 836.9310913085938
# 2023-05-26 portf_value = 836.9310913085938
# close_date_n pick's portf value = 981.0485458374023
# close_date_n SPY portf value =    836.9310913085938
# ====================
#
# date = '2023-05-26', l_syms = ['FTSM', 'NVDA'], ar_price = array([ 58.95495224, 389.41967773]), ar_shares = array([8., 1.]), ar_value = array([471.63961792, 389.41967773]), portf_value = 861.0592956542969
# 2023-05-26 portf_value = 861.0592956542969
# date = '2023-05-26', l_syms = ['SPY'], ar_price = array([418.46554565]), ar_shares = array([2.]), ar_value = array([836.93109131]), portf_value = 836.9310913085938
# 2023-05-26 portf_value = 836.9310913085938
# close_date_n pick's portf value = 861.0592956542969
# close_date_n SPY portf value =    836.9310913085938
# ====================
#
# date = '2023-05-25', l_syms = ['SHV'], ar_price = array([108.98564911]), ar_shares = array([9.]), ar_value = array([980.87084198]), portf_value = 980.8708419799805
# 2023-05-25 portf_value = 980.8708419799805
# date = '2023-05-25', l_syms = ['SPY'], ar_price = array([413.115448]), ar_shares = array([2.]), ar_value = array([826.230896]), portf_value = 826.2308959960938
# 2023-05-25 portf_value = 826.2308959960938
# close_date_n pick's portf value = 980.8708419799805
# close_date_n SPY portf value =    826.2308959960938
# ====================
#
# date = '2023-05-24', l_syms = ['SHV'], ar_price = array([108.93627167]), ar_shares = array([9.]), ar_value = array([980.42644501]), portf_value = 980.4264450073242
# 2023-05-24 portf_value = 980.4264450073242
# date = '2023-05-24', l_syms = ['SPY'], ar_price = array([409.56860352]), ar_shares = array([2.]), ar_value = array([819.13720703]), portf_value = 819.13720703125
# 2023-05-24 portf_value = 819.13720703125
# close_date_n pick's portf value = 980.4264450073242
# close_date_n SPY portf value =    819.13720703125
# ====================
#
# date = '2023-05-23', l_syms = ['SHV'], ar_price = array([108.93627167]), ar_shares = array([9.]), ar_value = array([980.42644501]), portf_value = 980.4264450073242
# 2023-05-23 portf_value = 980.4264450073242
# date = '2023-05-23', l_syms = ['SPY'], ar_price = array([412.55752563]), ar_shares = array([2.]), ar_value = array([825.11505127]), portf_value = 825.1150512695312
# 2023-05-23 portf_value = 825.1150512695312
# close_date_n pick's portf value = 980.4264450073242
# close_date_n SPY portf value =    825.1150512695312
# ====================
#
# date = '2023-05-22', l_syms = ['SHV'], ar_price = array([108.91652679]), ar_shares = array([9.]), ar_value = array([980.24874115]), portf_value = 980.2487411499023
# 2023-05-22 portf_value = 980.2487411499023
# date = '2023-05-22', l_syms = ['SPY'], ar_price = array([417.24014282]), ar_shares = array([2.]), ar_value = array([834.48028564]), portf_value = 834.4802856445312
# 2023-05-22 portf_value = 834.4802856445312
# close_date_n pick's portf value = 980.2487411499023
# close_date_n SPY portf value =    834.4802856445312
# ====================
#
# date = '2023-05-19', l_syms = ['SHV', 'TMHC'], ar_price = array([108.91652679,  44.25      ]), ar_shares = array([ 4., 11.]), ar_value = array([435.66610718, 486.75      ]), portf_value = 922.4161071777344
# 2023-05-19 portf_value = 922.4161071777344
# date = '2023-05-19', l_syms = ['SPY'], ar_price = array([417.07073975]), ar_shares = array([2.]), ar_value = array([834.14147949]), portf_value = 834.1414794921875
# 2023-05-19 portf_value = 834.1414794921875
# close_date_n pick's portf value = 922.4161071777344
# close_date_n SPY portf value =    834.1414794921875
# ====================
#
# date = '2023-05-18', l_syms = ['SHV'], ar_price = array([108.91652679]), ar_shares = array([9.]), ar_value = array([980.24874115]), portf_value = 980.2487411499023
# 2023-05-18 portf_value = 980.2487411499023
# date = '2023-05-18', l_syms = ['SPY'], ar_price = array([417.67849731]), ar_shares = array([2.]), ar_value = array([835.35699463]), portf_value = 835.3569946289062
# 2023-05-18 portf_value = 835.3569946289062
# close_date_n pick's portf value = 980.2487411499023
# close_date_n SPY portf value =    835.3569946289062
# ====================
#
# date = '2023-05-17', l_syms = ['SHV'], ar_price = array([108.88689423]), ar_shares = array([9.]), ar_value = array([979.98204803]), portf_value = 979.982048034668
# 2023-05-17 portf_value = 979.982048034668
# date = '2023-05-17', l_syms = ['SPY'], ar_price = array([413.69329834]), ar_shares = array([2.]), ar_value = array([827.38659668]), portf_value = 827.3865966796875
# 2023-05-17 portf_value = 827.3865966796875
# close_date_n pick's portf value = 979.982048034668
# close_date_n SPY portf value =    827.3865966796875
# ====================
#
# date = '2023-05-16', l_syms = ['SHV'], ar_price = array([108.86713409]), ar_shares = array([9.]), ar_value = array([979.80420685]), portf_value = 979.8042068481445
# 2023-05-16 portf_value = 979.8042068481445
# date = '2023-05-16', l_syms = ['SPY'], ar_price = array([408.73171997]), ar_shares = array([2.]), ar_value = array([817.46343994]), portf_value = 817.4634399414062
# 2023-05-16 portf_value = 817.4634399414062
# close_date_n pick's portf value = 979.8042068481445
# close_date_n SPY portf value =    817.4634399414062
# ====================
#
# date = '2023-05-15', l_syms = ['SHV'], ar_price = array([108.86713409]), ar_shares = array([9.]), ar_value = array([979.80420685]), portf_value = 979.8042068481445
# 2023-05-15 portf_value = 979.8042068481445
# date = '2023-05-15', l_syms = ['SPY'], ar_price = array([411.48150635]), ar_shares = array([2.]), ar_value = array([822.9630127]), portf_value = 822.9630126953125
# 2023-05-15 portf_value = 822.9630126953125
# close_date_n pick's portf value = 979.8042068481445
# close_date_n SPY portf value =    822.9630126953125
# ====================
#
# date = '2023-05-12', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.59999847, 108.85727692]), ar_shares = array([13.,  4.]), ar_value = array([488.79998016, 435.42910767]), portf_value = 924.2290878295898
# 2023-05-12 portf_value = 924.2290878295898
# date = '2023-05-12', l_syms = ['SPY'], ar_price = array([410.06677246]), ar_shares = array([2.]), ar_value = array([820.13354492]), portf_value = 820.133544921875
# 2023-05-12 portf_value = 820.133544921875
# close_date_n pick's portf value = 924.2290878295898
# close_date_n SPY portf value =    820.133544921875
# ====================
#
# date = '2023-05-11', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.36000061, 108.85727692]), ar_shares = array([13.,  4.]), ar_value = array([485.68000793, 435.42910767]), portf_value = 921.1091156005859
# 2023-05-11 portf_value = 921.1091156005859
# date = '2023-05-11', l_syms = ['SPY'], ar_price = array([410.60476685]), ar_shares = array([2.]), ar_value = array([821.20953369]), portf_value = 821.2095336914062
# 2023-05-11 portf_value = 821.2095336914062
# close_date_n pick's portf value = 921.1091156005859
# close_date_n SPY portf value =    821.2095336914062
# ====================
#
# date = '2023-05-10', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.20000076, 108.81777191]), ar_shares = array([13.,  4.]), ar_value = array([483.60000992, 435.27108765]), portf_value = 918.8710975646973
# 2023-05-10 portf_value = 918.8710975646973
# date = '2023-05-10', l_syms = ['SPY'], ar_price = array([411.32211304]), ar_shares = array([2.]), ar_value = array([822.64422607]), portf_value = 822.6442260742188
# 2023-05-10 portf_value = 822.6442260742188
# close_date_n pick's portf value = 918.8710975646973
# close_date_n SPY portf value =    822.6442260742188
# ====================
#
# date = '2023-05-09', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.34999847, 108.77825928]), ar_shares = array([13.,  4.]), ar_value = array([485.54998016, 435.11303711]), portf_value = 920.6630172729492
# 2023-05-09 portf_value = 920.6630172729492
# date = '2023-05-09', l_syms = ['SPY'], ar_price = array([409.40921021]), ar_shares = array([2.]), ar_value = array([818.81842041]), portf_value = 818.8184204101562
# 2023-05-09 portf_value = 818.8184204101562
# close_date_n pick's portf value = 920.6630172729492
# close_date_n SPY portf value =    818.8184204101562
# ====================
#
# date = '2023-05-08', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.68999863, 108.77825928]), ar_shares = array([13.,  4.]), ar_value = array([489.96998215, 435.11303711]), portf_value = 925.0830192565918
# 2023-05-08 portf_value = 925.0830192565918
# date = '2023-05-08', l_syms = ['SPY'], ar_price = array([411.2124939]), ar_shares = array([2.]), ar_value = array([822.42498779]), portf_value = 822.4249877929688
# 2023-05-08 portf_value = 822.4249877929688
# close_date_n pick's portf value = 925.0830192565918
# close_date_n SPY portf value =    822.4249877929688
# ====================
#
# date = '2023-05-05', l_syms = ['SHV'], ar_price = array([108.76838684]), ar_shares = array([9.]), ar_value = array([978.91548157]), portf_value = 978.9154815673828
# 2023-05-05 portf_value = 978.9154815673828
# date = '2023-05-05', l_syms = ['SPY'], ar_price = array([411.10293579]), ar_shares = array([2.]), ar_value = array([822.20587158]), portf_value = 822.2058715820312
# 2023-05-05 portf_value = 822.2058715820312
# close_date_n pick's portf value = 978.9154815673828
# close_date_n SPY portf value =    822.2058715820312
# ====================
#
# date = '2023-05-04', l_syms = ['SHV'], ar_price = array([108.77825928]), ar_shares = array([9.]), ar_value = array([979.0043335]), portf_value = 979.0043334960938
# 2023-05-04 portf_value = 979.0043334960938
# date = '2023-05-04', l_syms = ['SPY'], ar_price = array([403.63067627]), ar_shares = array([2.]), ar_value = array([807.26135254]), portf_value = 807.2613525390625
# 2023-05-04 portf_value = 807.2613525390625
# close_date_n pick's portf value = 979.0043334960938
# close_date_n SPY portf value =    807.2613525390625
# ====================
#
# date = '2023-05-03', l_syms = ['SHV'], ar_price = array([108.7190094]), ar_shares = array([9.]), ar_value = array([978.47108459]), portf_value = 978.4710845947266
# 2023-05-03 portf_value = 978.4710845947266
# date = '2023-05-03', l_syms = ['SPY'], ar_price = array([406.50997925]), ar_shares = array([2.]), ar_value = array([813.0199585]), portf_value = 813.0199584960938
# 2023-05-03 portf_value = 813.0199584960938
# close_date_n pick's portf value = 978.4710845947266
# close_date_n SPY portf value =    813.0199584960938
# ====================
#
# date = '2023-04-27', l_syms = ['ELF'], ar_price = array([92.84999847]), ar_shares = array([10.]), ar_value = array([928.49998474]), portf_value = 928.4999847412109
# 2023-04-27 portf_value = 928.4999847412109
# date = '2023-04-27', l_syms = ['SPY'], ar_price = array([410.88372803]), ar_shares = array([2.]), ar_value = array([821.76745605]), portf_value = 821.7674560546875
# 2023-04-27 portf_value = 821.7674560546875
# close_date_n pick's portf value = 928.4999847412109
# close_date_n SPY portf value =    821.7674560546875
# ====================
#
# date = '2023-04-26', l_syms = ['ELF', 'SHV'], ar_price = array([ 93.84999847, 108.65196228]), ar_shares = array([5., 4.]), ar_value = array([469.24999237, 434.60784912]), portf_value = 903.8578414916992
# 2023-04-26 portf_value = 903.8578414916992
# date = '2023-04-26', l_syms = ['SPY'], ar_price = array([402.86349487]), ar_shares = array([2.]), ar_value = array([805.72698975]), portf_value = 805.7269897460938
# 2023-04-26 portf_value = 805.7269897460938
# close_date_n pick's portf value = 903.8578414916992
# close_date_n SPY portf value =    805.7269897460938
# ====================
#
# date = '2023-04-25', l_syms = ['ELF'], ar_price = array([92.38999939]), ar_shares = array([10.]), ar_value = array([923.8999939]), portf_value = 923.8999938964844
# 2023-04-25 portf_value = 923.8999938964844
# date = '2023-04-25', l_syms = ['SPY'], ar_price = array([404.57714844]), ar_shares = array([2.]), ar_value = array([809.15429688]), portf_value = 809.154296875
# 2023-04-25 portf_value = 809.154296875
# close_date_n pick's portf value = 923.8999938964844
# close_date_n SPY portf value =    809.154296875
# ====================
#
# date = '2023-04-24', l_syms = ['ELF'], ar_price = array([94.83999634]), ar_shares = array([10.]), ar_value = array([948.39996338]), portf_value = 948.3999633789062
# 2023-04-24 portf_value = 948.3999633789062
# date = '2023-04-24', l_syms = ['SPY'], ar_price = array([411.10293579]), ar_shares = array([2.]), ar_value = array([822.20587158]), portf_value = 822.2058715820312
# 2023-04-24 portf_value = 822.2058715820312
# close_date_n pick's portf value = 948.3999633789062
# close_date_n SPY portf value =    822.2058715820312
# ====================
#
# date = '2023-04-21', l_syms = ['ELF'], ar_price = array([96.68000031]), ar_shares = array([10.]), ar_value = array([966.80000305]), portf_value = 966.8000030517578
# 2023-04-21 portf_value = 966.8000030517578
# date = '2023-04-21', l_syms = ['SPY'], ar_price = array([410.67453003]), ar_shares = array([2.]), ar_value = array([821.34906006]), portf_value = 821.3490600585938
# 2023-04-21 portf_value = 821.3490600585938
# close_date_n pick's portf value = 966.8000030517578
# close_date_n SPY portf value =    821.3490600585938
# ====================
#
# date = '2023-04-20', l_syms = ['SHV'], ar_price = array([108.59293365]), ar_shares = array([9.]), ar_value = array([977.33640289]), portf_value = 977.3364028930664
# 2023-04-20 portf_value = 977.3364028930664
# date = '2023-04-20', l_syms = ['SPY'], ar_price = array([410.35571289]), ar_shares = array([2.]), ar_value = array([820.71142578]), portf_value = 820.71142578125
# 2023-04-20 portf_value = 820.71142578125
# close_date_n pick's portf value = 977.3364028930664
# close_date_n SPY portf value =    820.71142578125
# ====================
#
# date = '2023-04-19', l_syms = ['SHV'], ar_price = array([108.53388977]), ar_shares = array([9.]), ar_value = array([976.80500793]), portf_value = 976.8050079345703
# 2023-04-19 portf_value = 976.8050079345703
# date = '2023-04-19', l_syms = ['SPY'], ar_price = array([412.60733032]), ar_shares = array([2.]), ar_value = array([825.21466064]), portf_value = 825.2146606445312
# 2023-04-19 portf_value = 825.2146606445312
# close_date_n pick's portf value = 976.8050079345703
# close_date_n SPY portf value =    825.2146606445312
# ====================
#
# date = '2023-04-18', l_syms = ['ELF', 'SHV'], ar_price = array([ 92.58000183, 108.52404785]), ar_shares = array([5., 4.]), ar_value = array([462.90000916, 434.09619141]), portf_value = 896.9962005615234
# 2023-04-18 portf_value = 896.9962005615234
# date = '2023-04-18', l_syms = ['SPY'], ar_price = array([412.67706299]), ar_shares = array([2.]), ar_value = array([825.35412598]), portf_value = 825.3541259765625
# 2023-04-18 portf_value = 825.3541259765625
# close_date_n pick's portf value = 896.9962005615234
# close_date_n SPY portf value =    825.3541259765625
# ====================
#
# date = '2023-04-17', l_syms = ['SHV'], ar_price = array([108.50436401]), ar_shares = array([9.]), ar_value = array([976.53927612]), portf_value = 976.5392761230469
# 2023-04-17 portf_value = 976.5392761230469
# date = '2023-04-17', l_syms = ['SPY'], ar_price = array([412.40808105]), ar_shares = array([2.]), ar_value = array([824.81616211]), portf_value = 824.816162109375
# 2023-04-17 portf_value = 824.816162109375
# close_date_n pick's portf value = 976.5392761230469
# close_date_n SPY portf value =    824.816162109375
# ====================
#
# date = '2023-04-14', l_syms = ['SHV'], ar_price = array([108.49452209]), ar_shares = array([9.]), ar_value = array([976.45069885]), portf_value = 976.4506988525391
# 2023-04-14 portf_value = 976.4506988525391
# date = '2023-04-14', l_syms = ['SPY'], ar_price = array([410.93353271]), ar_shares = array([2.]), ar_value = array([821.86706543]), portf_value = 821.8670654296875
# 2023-04-14 portf_value = 821.8670654296875
# close_date_n pick's portf value = 976.4506988525391
# close_date_n SPY portf value =    821.8670654296875
# ====================
#
# date = '2023-04-13', l_syms = ['SHV'], ar_price = array([108.5141983]), ar_shares = array([9.]), ar_value = array([976.62778473]), portf_value = 976.6277847290039
# 2023-04-13 portf_value = 976.6277847290039
# date = '2023-04-13', l_syms = ['SPY'], ar_price = array([411.93981934]), ar_shares = array([2.]), ar_value = array([823.87963867]), portf_value = 823.879638671875
# 2023-04-13 portf_value = 823.879638671875
# close_date_n pick's portf value = 976.6277847290039
# close_date_n SPY portf value =    823.879638671875
# ====================
#
# date = '2023-04-12', l_syms = ['SHV'], ar_price = array([108.45515442]), ar_shares = array([9.]), ar_value = array([976.09638977]), portf_value = 976.0963897705078
# 2023-04-12 portf_value = 976.0963897705078
# date = '2023-04-12', l_syms = ['SPY'], ar_price = array([406.53985596]), ar_shares = array([2.]), ar_value = array([813.07971191]), portf_value = 813.0797119140625
# 2023-04-12 portf_value = 813.0797119140625
# close_date_n pick's portf value = 976.0963897705078
# close_date_n SPY portf value =    813.0797119140625
# ====================
#
# date = '2023-04-11', l_syms = ['SHV'], ar_price = array([108.44532776]), ar_shares = array([9.]), ar_value = array([976.00794983]), portf_value = 976.0079498291016
# 2023-04-11 portf_value = 976.0079498291016
# date = '2023-04-11', l_syms = ['SPY'], ar_price = array([408.20367432]), ar_shares = array([2.]), ar_value = array([816.40734863]), portf_value = 816.4073486328125
# 2023-04-11 portf_value = 816.4073486328125
# close_date_n pick's portf value = 976.0079498291016
# close_date_n SPY portf value =    816.4073486328125
# ====================
#
# date = '2023-04-10', l_syms = ['SHV'], ar_price = array([108.42565155]), ar_shares = array([9.]), ar_value = array([975.83086395]), portf_value = 975.8308639526367
# 2023-04-10 portf_value = 975.8308639526367
# date = '2023-04-10', l_syms = ['SPY'], ar_price = array([408.09408569]), ar_shares = array([2.]), ar_value = array([816.18817139]), portf_value = 816.1881713867188
# 2023-04-10 portf_value = 816.1881713867188
# close_date_n pick's portf value = 975.8308639526367
# close_date_n SPY portf value =    816.1881713867188
# ====================
#
# date = '2023-04-06', l_syms = ['SHV'], ar_price = array([108.43549347]), ar_shares = array([9.]), ar_value = array([975.91944122]), portf_value = 975.9194412231445
# 2023-04-06 portf_value = 975.9194412231445
# date = '2023-04-06', l_syms = ['SPY'], ar_price = array([407.67565918]), ar_shares = array([2.]), ar_value = array([815.35131836]), portf_value = 815.351318359375
# 2023-04-06 portf_value = 815.351318359375
# close_date_n pick's portf value = 975.9194412231445
# close_date_n SPY portf value =    815.351318359375
# ====================
#
# date = '2023-04-05', l_syms = ['NVDA', 'SHV'], ar_price = array([268.78219604, 108.43549347]), ar_shares = array([1., 4.]), ar_value = array([268.78219604, 433.74197388]), portf_value = 702.524169921875
# 2023-04-05 portf_value = 702.524169921875
# date = '2023-04-05', l_syms = ['SPY'], ar_price = array([406.09155273]), ar_shares = array([2.]), ar_value = array([812.18310547]), portf_value = 812.18310546875
# 2023-04-05 portf_value = 812.18310546875
# close_date_n pick's portf value = 702.524169921875
# close_date_n SPY portf value =    812.18310546875
# ====================
#
# date = '2023-04-04', l_syms = ['GE', 'NVDA'], ar_price = array([ 94.97976685, 274.50158691]), ar_shares = array([5., 1.]), ar_value = array([474.89883423, 274.50158691]), portf_value = 749.4004211425781
# 2023-04-04 portf_value = 749.4004211425781
# date = '2023-04-04', l_syms = ['SPY'], ar_price = array([407.15759277]), ar_shares = array([2.]), ar_value = array([814.31518555]), portf_value = 814.315185546875
# 2023-04-04 portf_value = 814.315185546875
# close_date_n pick's portf value = 749.4004211425781
# close_date_n SPY portf value =    814.315185546875
# ====================
#
# date = '2023-04-03', l_syms = ['NVDA'], ar_price = array([279.62106323]), ar_shares = array([3.]), ar_value = array([838.8631897]), portf_value = 838.8631896972656
# 2023-04-03 portf_value = 838.8631896972656
# date = '2023-04-03', l_syms = ['SPY'], ar_price = array([409.42913818]), ar_shares = array([2.]), ar_value = array([818.85827637]), portf_value = 818.8582763671875
# 2023-04-03 portf_value = 818.8582763671875
# close_date_n pick's portf value = 838.8631896972656
# close_date_n SPY portf value =    818.8582763671875
# ====================
#
# date = '2023-03-31', l_syms = ['SHV'], ar_price = array([108.34593964]), ar_shares = array([9.]), ar_value = array([975.11345673]), portf_value = 975.1134567260742
# 2023-03-31 portf_value = 975.1134567260742
# date = '2023-03-31', l_syms = ['SPY'], ar_price = array([407.87490845]), ar_shares = array([2.]), ar_value = array([815.74981689]), portf_value = 815.7498168945312
# 2023-03-31 portf_value = 815.7498168945312
# close_date_n pick's portf value = 975.1134567260742
# close_date_n SPY portf value =    815.7498168945312
# ====================
#
# date = '2023-03-31', l_syms = ['NVDA'], ar_price = array([277.74124146]), ar_shares = array([3.]), ar_value = array([833.22372437]), portf_value = 833.2237243652344
# 2023-03-31 portf_value = 833.2237243652344
# date = '2023-03-31', l_syms = ['SPY'], ar_price = array([407.87490845]), ar_shares = array([2.]), ar_value = array([815.74981689]), portf_value = 815.7498168945312
# 2023-03-31 portf_value = 815.7498168945312
# close_date_n pick's portf value = 833.2237243652344
# close_date_n SPY portf value =    815.7498168945312
# ====================
#
# date = '2023-03-30', l_syms = ['SHV'], ar_price = array([108.33613586]), ar_shares = array([9.]), ar_value = array([975.02522278]), portf_value = 975.0252227783203
# 2023-03-30 portf_value = 975.0252227783203
# date = '2023-03-30', l_syms = ['SPY'], ar_price = array([402.20596313]), ar_shares = array([2.]), ar_value = array([804.41192627]), portf_value = 804.4119262695312
# 2023-03-30 portf_value = 804.4119262695312
# close_date_n pick's portf value = 975.0252227783203
# close_date_n SPY portf value =    804.4119262695312
# ====================
#
# date = '2023-03-29', l_syms = ['SHV'], ar_price = array([108.31652832]), ar_shares = array([9.]), ar_value = array([974.84875488]), portf_value = 974.8487548828125
# 2023-03-29 portf_value = 974.8487548828125
# date = '2023-03-29', l_syms = ['SPY'], ar_price = array([399.86465454]), ar_shares = array([2.]), ar_value = array([799.72930908]), portf_value = 799.7293090820312
# 2023-03-29 portf_value = 799.7293090820312
# close_date_n pick's portf value = 974.8487548828125
# close_date_n SPY portf value =    799.7293090820312
# ====================
#
# date = '2023-03-28', l_syms = ['SHV'], ar_price = array([108.30671692]), ar_shares = array([9.]), ar_value = array([974.76045227]), portf_value = 974.7604522705078
# 2023-03-28 portf_value = 974.7604522705078
# date = '2023-03-28', l_syms = ['SPY'], ar_price = array([394.13595581]), ar_shares = array([2.]), ar_value = array([788.27191162]), portf_value = 788.2719116210938
# 2023-03-28 portf_value = 788.2719116210938
# close_date_n pick's portf value = 974.7604522705078
# close_date_n SPY portf value =    788.2719116210938
# ====================
#
# date = '2023-03-28', l_syms = ['GE'], ar_price = array([93.07117462]), ar_shares = array([10.]), ar_value = array([930.71174622]), portf_value = 930.7117462158203
# 2023-03-28 portf_value = 930.7117462158203
# date = '2023-03-28', l_syms = ['SPY'], ar_price = array([394.13595581]), ar_shares = array([2.]), ar_value = array([788.27191162]), portf_value = 788.2719116210938
# 2023-03-28 portf_value = 788.2719116210938
# close_date_n pick's portf value = 930.7117462158203
# close_date_n SPY portf value =    788.2719116210938
# ====================
#
# date = '2023-03-27', l_syms = ['NVDA', 'SHV'], ar_price = array([265.28253174, 108.29690552]), ar_shares = array([1., 4.]), ar_value = array([265.28253174, 433.18762207]), portf_value = 698.4701538085938
# 2023-03-27 portf_value = 698.4701538085938
# date = '2023-03-27', l_syms = ['SPY'], ar_price = array([395.02264404]), ar_shares = array([2.]), ar_value = array([790.04528809]), portf_value = 790.0452880859375
# 2023-03-27 portf_value = 790.0452880859375
# close_date_n pick's portf value = 698.4701538085938
# close_date_n SPY portf value =    790.0452880859375
# ====================
#
# date = '2023-03-24', l_syms = ['SHV'], ar_price = array([108.29690552]), ar_shares = array([9.]), ar_value = array([974.67214966]), portf_value = 974.6721496582031
# 2023-03-24 portf_value = 974.6721496582031
# date = '2023-03-24', l_syms = ['SPY'], ar_price = array([394.28540039]), ar_shares = array([2.]), ar_value = array([788.57080078]), portf_value = 788.57080078125
# 2023-03-24 portf_value = 788.57080078125
# close_date_n pick's portf value = 974.6721496582031
# close_date_n SPY portf value =    788.57080078125
# ====================
#
# date = '2023-03-23', l_syms = ['SHV'], ar_price = array([108.28710938]), ar_shares = array([9.]), ar_value = array([974.58398438]), portf_value = 974.583984375
# 2023-03-23 portf_value = 974.583984375
# date = '2023-03-23', l_syms = ['SPY'], ar_price = array([391.7149353]), ar_shares = array([2.]), ar_value = array([783.42987061]), portf_value = 783.4298706054688
# 2023-03-23 portf_value = 783.4298706054688
# close_date_n pick's portf value = 974.583984375
# close_date_n SPY portf value =    783.4298706054688
# ====================
#
# date = '2023-03-23', l_syms = ['FTSM'], ar_price = array([58.55865097]), ar_shares = array([17.]), ar_value = array([995.4970665]), portf_value = 995.4970664978027
# 2023-03-23 portf_value = 995.4970664978027
# date = '2023-03-23', l_syms = ['SPY'], ar_price = array([391.7149353]), ar_shares = array([2.]), ar_value = array([783.42987061]), portf_value = 783.4298706054688
# 2023-03-23 portf_value = 783.4298706054688
# close_date_n pick's portf value = 995.4970664978027
# close_date_n SPY portf value =    783.4298706054688
# ====================
#
# date = '2023-03-22', l_syms = ['SHV'], ar_price = array([108.21847534]), ar_shares = array([9.]), ar_value = array([973.96627808]), portf_value = 973.9662780761719
# 2023-03-22 portf_value = 973.9662780761719
# date = '2023-03-22', l_syms = ['SPY'], ar_price = array([390.65884399]), ar_shares = array([2.]), ar_value = array([781.31768799]), portf_value = 781.3176879882812
# 2023-03-22 portf_value = 781.3176879882812
# close_date_n pick's portf value = 973.9662780761719
# close_date_n SPY portf value =    781.3176879882812
# ====================
#
# date = '2023-03-22', l_syms = ['GE'], ar_price = array([89.52379608]), ar_shares = array([11.]), ar_value = array([984.7617569]), portf_value = 984.7617568969727
# 2023-03-22 portf_value = 984.7617568969727
# date = '2023-03-22', l_syms = ['SPY'], ar_price = array([390.65884399]), ar_shares = array([2.]), ar_value = array([781.31768799]), portf_value = 781.3176879882812
# 2023-03-22 portf_value = 781.3176879882812
# close_date_n pick's portf value = 984.7617568969727
# close_date_n SPY portf value =    781.3176879882812
# ====================
#
# date = '2023-03-21', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.4899559, 108.179245 ]), ar_shares = array([8., 4.]), ar_value = array([467.91964722, 432.71697998]), portf_value = 900.6366271972656
# 2023-03-21 portf_value = 900.6366271972656
# date = '2023-03-21', l_syms = ['SPY'], ar_price = array([397.4336853]), ar_shares = array([2.]), ar_value = array([794.86737061]), portf_value = 794.8673706054688
# 2023-03-21 portf_value = 794.8673706054688
# close_date_n pick's portf value = 900.6366271972656
# close_date_n SPY portf value =    794.8673706054688
# ====================
#
# date = '2023-03-20', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.54883957, 108.20866394]), ar_shares = array([8., 4.]), ar_value = array([468.39071655, 432.83465576]), portf_value = 901.2253723144531
# 2023-03-20 portf_value = 901.2253723144531
# date = '2023-03-20', l_syms = ['SPY'], ar_price = array([392.2828064]), ar_shares = array([2.]), ar_value = array([784.56561279]), portf_value = 784.5656127929688
# 2023-03-20 portf_value = 784.5656127929688
# close_date_n pick's portf value = 901.2253723144531
# close_date_n SPY portf value =    784.5656127929688
# ====================
#
# date = '2023-03-20', l_syms = ['GE'], ar_price = array([89.85355377]), ar_shares = array([11.]), ar_value = array([988.38909149]), portf_value = 988.3890914916992
# 2023-03-20 portf_value = 988.3890914916992
# date = '2023-03-20', l_syms = ['SPY'], ar_price = array([392.2828064]), ar_shares = array([2.]), ar_value = array([784.56561279]), portf_value = 784.5656127929688
# 2023-03-20 portf_value = 784.5656127929688
# close_date_n pick's portf value = 988.3890914916992
# close_date_n SPY portf value =    784.5656127929688
# ====================
#
# date = '2023-03-17', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.46051407, 108.22827911]), ar_shares = array([8., 4.]), ar_value = array([467.68411255, 432.91311646]), portf_value = 900.5972290039062
# 2023-03-17 portf_value = 900.5972290039062
# date = '2023-03-17', l_syms = ['SPY'], ar_price = array([388.54669189]), ar_shares = array([2.]), ar_value = array([777.09338379]), portf_value = 777.0933837890625
# 2023-03-17 portf_value = 777.0933837890625
# close_date_n pick's portf value = 900.5972290039062
# close_date_n SPY portf value =    777.0933837890625
# ====================
#
# date = '2023-03-16', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.4703331 , 108.14984131]), ar_shares = array([8., 4.]), ar_value = array([467.76266479, 432.59936523]), portf_value = 900.3620300292969
# 2023-03-16 portf_value = 900.3620300292969
# date = '2023-03-16', l_syms = ['SPY'], ar_price = array([393.14361572]), ar_shares = array([2.]), ar_value = array([786.28723145]), portf_value = 786.2872314453125
# 2023-03-16 portf_value = 786.2872314453125
# close_date_n pick's portf value = 900.3620300292969
# close_date_n SPY portf value =    786.2872314453125
# ====================

# %%
df_mp['date_buy'] = date_buy
df_mp['sh_portf_buy'] = shares_syms
df_mp['$_portf_buy'] = value_portf
df_mp['sh_SPY_buy'] = shares_SPY
df_mp['$_SPY_buy'] = value_SPY
# df_mp.tail()
# df_mp.head()
df_mp
# Out:
#            date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy
# 0    2023-08-08  [30, 60, 120]  sym_freq_8  ['SHV', 'STRL']        None         None          NaN       None         NaN
# 1    2023-08-07  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-08        [9.0]   990.899986      [2.0]  897.500000
# 2    2023-08-04  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-07        [9.0]   990.720016      [2.0]  901.419983
# 3    2023-08-03  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-04        [9.0]   990.720016      [2.0]  893.619995
# 4    2023-08-02  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-03        [9.0]   990.450027      [2.0]  897.679993
# ..          ...            ...         ...              ...         ...          ...          ...        ...         ...
# 102  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-21   [8.0, 4.0]   900.636627      [2.0]  794.867371
# 103  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-20   [8.0, 4.0]   901.225372      [2.0]  784.565613
# 104  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']  2023-03-20       [11.0]   988.389091      [2.0]  784.565613
# 105  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-17   [8.0, 4.0]   900.597229      [2.0]  777.093384
# 106  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-16   [8.0, 4.0]   900.362030      [2.0]  786.287231
#
# [107 rows x 9 columns]

# %%
date_exec, shares_syms, value_portf, shares_SPY, value_SPY  = \
  calc_portf_value_date_n(df_mp.date, df_mp.symbols, df_close, df_mp.sh_portf_buy, df_mp.sh_SPY_buy, n=4, verbose=verbose)
# Out:
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# date = '2023-08-08', l_syms = ['SHV'], ar_price = array([110.09999847]), ar_shares = array([9.]), ar_value = array([990.89998627]), portf_value = 990.8999862670898
# 2023-08-08 portf_value = 990.8999862670898
# date = '2023-08-08', l_syms = ['SPY'], ar_price = array([448.75]), ar_shares = array([2.]), ar_value = array([897.5]), portf_value = 897.5
# 2023-08-08 portf_value = 897.5
# next_date_n pick's portf value = 990.8999862670898
# next_date_n SPY portf value =    897.5
# ====================
#
# date = '2023-08-02', l_syms = ['SHV'], ar_price = array([110.01000214]), ar_shares = array([9.]), ar_value = array([990.09001923]), portf_value = 990.0900192260742
# 2023-08-02 portf_value = 990.0900192260742
# date = '2023-08-02', l_syms = ['SPY'], ar_price = array([450.13000488]), ar_shares = array([2.]), ar_value = array([900.26000977]), portf_value = 900.260009765625
# 2023-08-02 portf_value = 900.260009765625
# next_date_n pick's portf value = 990.0900192260742
# next_date_n SPY portf value =    900.260009765625
# ====================
#
# date = '2023-08-01', l_syms = ['SHV'], ar_price = array([109.98999786]), ar_shares = array([9.]), ar_value = array([989.90998077]), portf_value = 989.9099807739258
# 2023-08-01 portf_value = 989.9099807739258
# date = '2023-08-01', l_syms = ['SPY'], ar_price = array([456.48001099]), ar_shares = array([2.]), ar_value = array([912.96002197]), portf_value = 912.9600219726562
# 2023-08-01 portf_value = 912.9600219726562
# next_date_n pick's portf value = 989.9099807739258
# next_date_n SPY portf value =    912.9600219726562
# ====================
#
# date = '2023-07-31', l_syms = ['SHV'], ar_price = array([109.97299957]), ar_shares = array([9.]), ar_value = array([989.75699615]), portf_value = 989.7569961547852
# 2023-07-31 portf_value = 989.7569961547852
# date = '2023-07-31', l_syms = ['SPY'], ar_price = array([457.79000854]), ar_shares = array([2.]), ar_value = array([915.58001709]), portf_value = 915.5800170898438
# 2023-07-31 portf_value = 915.5800170898438
# next_date_n pick's portf value = 989.7569961547852
# next_date_n SPY portf value =    915.5800170898438
# ====================
#
# date = '2023-07-27', l_syms = ['SHV'], ar_price = array([109.92321014]), ar_shares = array([9.]), ar_value = array([989.3088913]), portf_value = 989.3088912963867
# 2023-07-27 portf_value = 989.3088912963867
# date = '2023-07-27', l_syms = ['SPY'], ar_price = array([452.48999023]), ar_shares = array([2.]), ar_value = array([904.97998047]), portf_value = 904.97998046875
# 2023-07-27 portf_value = 904.97998046875
# next_date_n pick's portf value = 989.3088912963867
# next_date_n SPY portf value =    904.97998046875
# ====================
#
# date = '2023-07-26', l_syms = ['SHV'], ar_price = array([109.88337708]), ar_shares = array([9.]), ar_value = array([988.95039368]), portf_value = 988.9503936767578
# 2023-07-26 portf_value = 988.9503936767578
# date = '2023-07-26', l_syms = ['SPY'], ar_price = array([455.51000977]), ar_shares = array([2.]), ar_value = array([911.02001953]), portf_value = 911.02001953125
# 2023-07-26 portf_value = 911.02001953125
# next_date_n pick's portf value = 988.9503936767578
# next_date_n SPY portf value =    911.02001953125
# ====================
#
# date = '2023-07-24', l_syms = ['SHV'], ar_price = array([109.853508]), ar_shares = array([9.]), ar_value = array([988.68157196]), portf_value = 988.6815719604492
# 2023-07-24 portf_value = 988.6815719604492
# date = '2023-07-24', l_syms = ['SPY'], ar_price = array([454.20001221]), ar_shares = array([2.]), ar_value = array([908.40002441]), portf_value = 908.4000244140625
# 2023-07-24 portf_value = 908.4000244140625
# next_date_n pick's portf value = 988.6815719604492
# next_date_n SPY portf value =    908.4000244140625
# ====================
#
# date = '2023-07-20', l_syms = ['SHV'], ar_price = array([109.83359528]), ar_shares = array([9.]), ar_value = array([988.50235748]), portf_value = 988.5023574829102
# 2023-07-20 portf_value = 988.5023574829102
# date = '2023-07-20', l_syms = ['SPY'], ar_price = array([452.17999268]), ar_shares = array([2.]), ar_value = array([904.35998535]), portf_value = 904.3599853515625
# 2023-07-20 portf_value = 904.3599853515625
# next_date_n pick's portf value = 988.5023574829102
# next_date_n SPY portf value =    904.3599853515625
# ====================
#
# date = '2023-07-19', l_syms = ['SHV', 'SKYW'], ar_price = array([109.78380585,  42.36999893]), ar_shares = array([ 4., 12.]), ar_value = array([439.13522339, 508.43998718]), portf_value = 947.5752105712891
# 2023-07-19 portf_value = 947.5752105712891
# date = '2023-07-19', l_syms = ['SPY'], ar_price = array([455.20001221]), ar_shares = array([2.]), ar_value = array([910.40002441]), portf_value = 910.4000244140625
# 2023-07-19 portf_value = 910.4000244140625
# next_date_n pick's portf value = 947.5752105712891
# next_date_n SPY portf value =    910.4000244140625
# ====================
#
# date = '2023-07-18', l_syms = ['SHV', 'SKYW'], ar_price = array([109.76389313,  41.86999893]), ar_shares = array([ 4., 12.]), ar_value = array([439.05557251, 502.43998718]), portf_value = 941.4955596923828
# 2023-07-18 portf_value = 941.4955596923828
# date = '2023-07-18', l_syms = ['SPY'], ar_price = array([454.19000244]), ar_shares = array([2.]), ar_value = array([908.38000488]), portf_value = 908.3800048828125
# 2023-07-18 portf_value = 908.3800048828125
# next_date_n pick's portf value = 941.4955596923828
# next_date_n SPY portf value =    908.3800048828125
# ====================
#
# date = '2023-07-17', l_syms = ['SHV', 'SKYW'], ar_price = array([109.75392914,  40.45000076]), ar_shares = array([ 4., 12.]), ar_value = array([439.01571655, 485.40000916]), portf_value = 924.4157257080078
# 2023-07-17 portf_value = 924.4157257080078
# date = '2023-07-17', l_syms = ['SPY'], ar_price = array([450.83999634]), ar_shares = array([2.]), ar_value = array([901.67999268]), portf_value = 901.6799926757812
# 2023-07-17 portf_value = 901.6799926757812
# next_date_n pick's portf value = 924.4157257080078
# next_date_n SPY portf value =    901.6799926757812
# ====================
#
# date = '2023-07-14', l_syms = ['SHV', 'SKYW'], ar_price = array([109.74397278,  40.43000031]), ar_shares = array([ 4., 11.]), ar_value = array([438.97589111, 444.73000336]), portf_value = 883.7058944702148
# 2023-07-14 portf_value = 883.7058944702148
# date = '2023-07-14', l_syms = ['SPY'], ar_price = array([449.27999878]), ar_shares = array([2.]), ar_value = array([898.55999756]), portf_value = 898.5599975585938
# 2023-07-14 portf_value = 898.5599975585938
# next_date_n pick's portf value = 883.7058944702148
# next_date_n SPY portf value =    898.5599975585938
# ====================
#
# date = '2023-07-13', l_syms = ['SHV', 'SKYW'], ar_price = array([109.73401642,  41.47000122]), ar_shares = array([ 4., 11.]), ar_value = array([438.93606567, 456.17001343]), portf_value = 895.1060791015625
# 2023-07-13 portf_value = 895.1060791015625
# date = '2023-07-13', l_syms = ['SPY'], ar_price = array([449.55999756]), ar_shares = array([2.]), ar_value = array([899.11999512]), portf_value = 899.1199951171875
# 2023-07-13 portf_value = 899.1199951171875
# next_date_n pick's portf value = 895.1060791015625
# next_date_n SPY portf value =    899.1199951171875
# ====================
#
# date = '2023-07-12', l_syms = ['SHV', 'SKYW'], ar_price = array([109.67427063,  41.11999893]), ar_shares = array([ 4., 12.]), ar_value = array([438.69708252, 493.43998718]), portf_value = 932.1370697021484
# 2023-07-12 portf_value = 932.1370697021484
# date = '2023-07-12', l_syms = ['SPY'], ar_price = array([446.01998901]), ar_shares = array([2.]), ar_value = array([892.03997803]), portf_value = 892.0399780273438
# 2023-07-12 portf_value = 892.0399780273438
# next_date_n pick's portf value = 932.1370697021484
# next_date_n SPY portf value =    892.0399780273438
# ====================
#
# date = '2023-07-11', l_syms = ['SHV'], ar_price = array([109.64439392]), ar_shares = array([9.]), ar_value = array([986.79954529]), portf_value = 986.7995452880859
# 2023-07-11 portf_value = 986.7995452880859
# date = '2023-07-11', l_syms = ['SPY'], ar_price = array([442.45999146]), ar_shares = array([2.]), ar_value = array([884.91998291]), portf_value = 884.9199829101562
# 2023-07-11 portf_value = 884.9199829101562
# next_date_n pick's portf value = 986.7995452880859
# next_date_n SPY portf value =    884.9199829101562
# ====================
#
# date = '2023-07-10', l_syms = ['SHV'], ar_price = array([109.64439392]), ar_shares = array([9.]), ar_value = array([986.79954529]), portf_value = 986.7995452880859
# 2023-07-10 portf_value = 986.7995452880859
# date = '2023-07-10', l_syms = ['SPY'], ar_price = array([439.66000366]), ar_shares = array([2.]), ar_value = array([879.32000732]), portf_value = 879.3200073242188
# 2023-07-10 portf_value = 879.3200073242188
# next_date_n pick's portf value = 986.7995452880859
# next_date_n SPY portf value =    879.3200073242188
# ====================
#
# date = '2023-07-07', l_syms = ['SHV'], ar_price = array([109.62447357]), ar_shares = array([9.]), ar_value = array([986.62026215]), portf_value = 986.6202621459961
# 2023-07-07 portf_value = 986.6202621459961
# date = '2023-07-07', l_syms = ['SPY'], ar_price = array([438.54998779]), ar_shares = array([2.]), ar_value = array([877.09997559]), portf_value = 877.0999755859375
# 2023-07-07 portf_value = 877.0999755859375
# next_date_n pick's portf value = 986.6202621459961
# next_date_n SPY portf value =    877.0999755859375
# ====================
#
# date = '2023-07-06', l_syms = ['SHV', 'SKYW'], ar_price = array([109.62447357,  39.65999985]), ar_shares = array([ 4., 12.]), ar_value = array([438.49789429, 475.91999817]), portf_value = 914.4178924560547
# 2023-07-06 portf_value = 914.4178924560547
# date = '2023-07-06', l_syms = ['SPY'], ar_price = array([439.66000366]), ar_shares = array([2.]), ar_value = array([879.32000732]), portf_value = 879.3200073242188
# 2023-07-06 portf_value = 879.3200073242188
# next_date_n pick's portf value = 914.4178924560547
# next_date_n SPY portf value =    879.3200073242188
# ====================
#
# date = '2023-07-05', l_syms = ['SHV', 'SKYW'], ar_price = array([109.56473541,  40.15999985]), ar_shares = array([ 4., 12.]), ar_value = array([438.25894165, 481.91999817]), portf_value = 920.1789398193359
# 2023-07-05 portf_value = 920.1789398193359
# date = '2023-07-05', l_syms = ['SPY'], ar_price = array([443.13000488]), ar_shares = array([2.]), ar_value = array([886.26000977]), portf_value = 886.260009765625
# 2023-07-05 portf_value = 886.260009765625
# next_date_n pick's portf value = 920.1789398193359
# next_date_n SPY portf value =    886.260009765625
# ====================
#
# date = '2023-07-03', l_syms = ['SHV', 'SKYW'], ar_price = array([109.54482269,  40.88000107]), ar_shares = array([ 4., 12.]), ar_value = array([438.17929077, 490.56001282]), portf_value = 928.7393035888672
# 2023-07-03 portf_value = 928.7393035888672
# date = '2023-07-03', l_syms = ['SPY'], ar_price = array([443.79000854]), ar_shares = array([2.]), ar_value = array([887.58001709]), portf_value = 887.5800170898438
# 2023-07-03 portf_value = 887.5800170898438
# next_date_n pick's portf value = 928.7393035888672
# next_date_n SPY portf value =    887.5800170898438
# ====================
#
# date = '2023-06-30', l_syms = ['SHV', 'SKYW'], ar_price = array([109.55278778,  40.72000122]), ar_shares = array([ 4., 12.]), ar_value = array([438.21115112, 488.64001465]), portf_value = 926.8511657714844
# 2023-06-30 portf_value = 926.8511657714844
# date = '2023-06-30', l_syms = ['SPY'], ar_price = array([443.27999878]), ar_shares = array([2.]), ar_value = array([886.55999756]), portf_value = 886.5599975585938
# 2023-06-30 portf_value = 886.5599975585938
# next_date_n pick's portf value = 926.8511657714844
# next_date_n SPY portf value =    886.5599975585938
# ====================
#
# date = '2023-06-29', l_syms = ['NVDA'], ar_price = array([408.22000122]), ar_shares = array([2.]), ar_value = array([816.44000244]), portf_value = 816.4400024414062
# 2023-06-29 portf_value = 816.4400024414062
# date = '2023-06-29', l_syms = ['SPY'], ar_price = array([438.10998535]), ar_shares = array([2.]), ar_value = array([876.2199707]), portf_value = 876.219970703125
# 2023-06-29 portf_value = 876.219970703125
# next_date_n pick's portf value = 816.4400024414062
# next_date_n SPY portf value =    876.219970703125
# ====================
#
# date = '2023-06-29', l_syms = ['SHV', 'SKYW'], ar_price = array([109.49327087,  40.38000107]), ar_shares = array([ 4., 12.]), ar_value = array([437.9730835 , 484.56001282]), portf_value = 922.5330963134766
# 2023-06-29 portf_value = 922.5330963134766
# date = '2023-06-29', l_syms = ['SPY'], ar_price = array([438.10998535]), ar_shares = array([2.]), ar_value = array([876.2199707]), portf_value = 876.219970703125
# 2023-06-29 portf_value = 876.219970703125
# next_date_n pick's portf value = 922.5330963134766
# next_date_n SPY portf value =    876.219970703125
# ====================
#
# date = '2023-06-28', l_syms = ['NVDA'], ar_price = array([411.17001343]), ar_shares = array([2.]), ar_value = array([822.34002686]), portf_value = 822.3400268554688
# 2023-06-28 portf_value = 822.3400268554688
# date = '2023-06-28', l_syms = ['SPY'], ar_price = array([436.39001465]), ar_shares = array([2.]), ar_value = array([872.7800293]), portf_value = 872.780029296875
# 2023-06-28 portf_value = 872.780029296875
# next_date_n pick's portf value = 822.3400268554688
# next_date_n SPY portf value =    872.780029296875
# ====================
#
# date = '2023-06-28', l_syms = ['SHV', 'SKYW'], ar_price = array([109.47343445,  39.65000153]), ar_shares = array([ 4., 12.]), ar_value = array([437.89373779, 475.80001831]), portf_value = 913.6937561035156
# 2023-06-28 portf_value = 913.6937561035156
# date = '2023-06-28', l_syms = ['SPY'], ar_price = array([436.39001465]), ar_shares = array([2.]), ar_value = array([872.7800293]), portf_value = 872.780029296875
# 2023-06-28 portf_value = 872.780029296875
# next_date_n pick's portf value = 913.6937561035156
# next_date_n SPY portf value =    872.780029296875
# ====================
#
# date = '2023-06-27', l_syms = ['NVDA'], ar_price = array([418.76000977]), ar_shares = array([2.]), ar_value = array([837.52001953]), portf_value = 837.52001953125
# 2023-06-27 portf_value = 837.52001953125
# date = '2023-06-27', l_syms = ['SPY'], ar_price = array([436.17001343]), ar_shares = array([2.]), ar_value = array([872.34002686]), portf_value = 872.3400268554688
# 2023-06-27 portf_value = 872.3400268554688
# next_date_n pick's portf value = 837.52001953125
# next_date_n SPY portf value =    872.3400268554688
# ====================
#
# date = '2023-06-27', l_syms = ['SHV'], ar_price = array([109.46351624]), ar_shares = array([9.]), ar_value = array([985.17164612]), portf_value = 985.1716461181641
# 2023-06-27 portf_value = 985.1716461181641
# date = '2023-06-27', l_syms = ['SPY'], ar_price = array([436.17001343]), ar_shares = array([2.]), ar_value = array([872.34002686]), portf_value = 872.3400268554688
# 2023-06-27 portf_value = 872.3400268554688
# next_date_n pick's portf value = 985.1716461181641
# next_date_n SPY portf value =    872.3400268554688
# ====================
#
# date = '2023-06-26', l_syms = ['NVDA'], ar_price = array([406.32000732]), ar_shares = array([2.]), ar_value = array([812.64001465]), portf_value = 812.6400146484375
# 2023-06-26 portf_value = 812.6400146484375
# date = '2023-06-26', l_syms = ['SPY'], ar_price = array([431.44000244]), ar_shares = array([2.]), ar_value = array([862.88000488]), portf_value = 862.8800048828125
# 2023-06-26 portf_value = 862.8800048828125
# next_date_n pick's portf value = 812.6400146484375
# next_date_n SPY portf value =    862.8800048828125
# ====================
#
# date = '2023-06-26', l_syms = ['SHV'], ar_price = array([109.44367981]), ar_shares = array([9.]), ar_value = array([984.99311829]), portf_value = 984.9931182861328
# 2023-06-26 portf_value = 984.9931182861328
# date = '2023-06-26', l_syms = ['SPY'], ar_price = array([431.44000244]), ar_shares = array([2.]), ar_value = array([862.88000488]), portf_value = 862.8800048828125
# 2023-06-26 portf_value = 862.8800048828125
# next_date_n pick's portf value = 984.9931182861328
# next_date_n SPY portf value =    862.8800048828125
# ====================
#
# date = '2023-06-23', l_syms = ['NVDA', 'SHV'], ar_price = array([422.08999634, 109.42384338]), ar_shares = array([1., 4.]), ar_value = array([422.08999634, 437.69537354]), portf_value = 859.7853698730469
# 2023-06-23 portf_value = 859.7853698730469
# date = '2023-06-23', l_syms = ['SPY'], ar_price = array([433.20999146]), ar_shares = array([2.]), ar_value = array([866.41998291]), portf_value = 866.4199829101562
# 2023-06-23 portf_value = 866.4199829101562
# next_date_n pick's portf value = 859.7853698730469
# next_date_n SPY portf value =    866.4199829101562
# ====================
#
# date = '2023-06-22', l_syms = ['NVDA', 'SHV'], ar_price = array([430.25      , 109.41392517]), ar_shares = array([1., 4.]), ar_value = array([430.25      , 437.65570068]), portf_value = 867.9057006835938
# 2023-06-22 portf_value = 867.9057006835938
# date = '2023-06-22', l_syms = ['SPY'], ar_price = array([436.51000977]), ar_shares = array([2.]), ar_value = array([873.02001953]), portf_value = 873.02001953125
# 2023-06-22 portf_value = 873.02001953125
# next_date_n pick's portf value = 867.9057006835938
# next_date_n SPY portf value =    873.02001953125
# ====================
#
# date = '2023-06-21', l_syms = ['AVGO', 'NVDA', 'SHV'], ar_price = array([847.65997314, 430.45001221, 109.37424469]), ar_shares = array([0., 0., 3.]), ar_value = array([  0.        ,   0.        , 328.12273407]), portf_value = 328.1227340698242
# 2023-06-21 portf_value = 328.1227340698242
# date = '2023-06-21', l_syms = ['SPY'], ar_price = array([434.94000244]), ar_shares = array([2.]), ar_value = array([869.88000488]), portf_value = 869.8800048828125
# 2023-06-21 portf_value = 869.8800048828125
# next_date_n pick's portf value = 328.1227340698242
# next_date_n SPY portf value =    869.8800048828125
# ====================
#
# date = '2023-06-20', l_syms = ['SHV'], ar_price = array([109.36433411]), ar_shares = array([9.]), ar_value = array([984.27900696]), portf_value = 984.2790069580078
# 2023-06-20 portf_value = 984.2790069580078
# date = '2023-06-20', l_syms = ['SPY'], ar_price = array([437.17999268]), ar_shares = array([2.]), ar_value = array([874.35998535]), portf_value = 874.3599853515625
# 2023-06-20 portf_value = 874.3599853515625
# next_date_n pick's portf value = 984.2790069580078
# next_date_n SPY portf value =    874.3599853515625
# ====================
#
# date = '2023-06-16', l_syms = ['SHV'], ar_price = array([109.36433411]), ar_shares = array([9.]), ar_value = array([984.27900696]), portf_value = 984.2790069580078
# 2023-06-16 portf_value = 984.2790069580078
# date = '2023-06-16', l_syms = ['SPY'], ar_price = array([439.45999146]), ar_shares = array([2.]), ar_value = array([878.91998291]), portf_value = 878.9199829101562
# 2023-06-16 portf_value = 878.9199829101562
# next_date_n pick's portf value = 984.2790069580078
# next_date_n SPY portf value =    878.9199829101562
# ====================
#
# date = '2023-06-15', l_syms = ['NVDA', 'SHV'], ar_price = array([426.52999878, 109.35441589]), ar_shares = array([1., 4.]), ar_value = array([426.52999878, 437.41766357]), portf_value = 863.9476623535156
# 2023-06-15 portf_value = 863.9476623535156
# date = '2023-06-15', l_syms = ['SPY'], ar_price = array([440.96200562]), ar_shares = array([2.]), ar_value = array([881.92401123]), portf_value = 881.9240112304688
# 2023-06-15 portf_value = 881.9240112304688
# next_date_n pick's portf value = 863.9476623535156
# next_date_n SPY portf value =    881.9240112304688
# ====================
#
# date = '2023-06-14', l_syms = ['NVDA', 'SHV'], ar_price = array([429.97000122, 109.27505493]), ar_shares = array([1., 4.]), ar_value = array([429.97000122, 437.10021973]), portf_value = 867.0702209472656
# 2023-06-14 portf_value = 867.0702209472656
# date = '2023-06-14', l_syms = ['SPY'], ar_price = array([435.56204224]), ar_shares = array([2.]), ar_value = array([871.12408447]), portf_value = 871.1240844726562
# 2023-06-14 portf_value = 871.1240844726562
# next_date_n pick's portf value = 867.0702209472656
# next_date_n SPY portf value =    871.1240844726562
# ====================
#
# date = '2023-06-13', l_syms = ['EXAS'], ar_price = array([93.56999969]), ar_shares = array([11.]), ar_value = array([1029.26999664]), portf_value = 1029.2699966430664
# 2023-06-13 portf_value = 1029.2699966430664
# date = '2023-06-13', l_syms = ['SPY'], ar_price = array([435.04397583]), ar_shares = array([2.]), ar_value = array([870.08795166]), portf_value = 870.0879516601562
# 2023-06-13 portf_value = 870.0879516601562
# next_date_n pick's portf value = 1029.2699966430664
# next_date_n SPY portf value =    870.0879516601562
# ====================
#
# date = '2023-06-13', l_syms = ['SHV'], ar_price = array([109.26515198]), ar_shares = array([9.]), ar_value = array([983.3863678]), portf_value = 983.3863677978516
# 2023-06-13 portf_value = 983.3863677978516
# date = '2023-06-13', l_syms = ['SPY'], ar_price = array([435.04397583]), ar_shares = array([2.]), ar_value = array([870.08795166]), portf_value = 870.0879516601562
# 2023-06-13 portf_value = 870.0879516601562
# next_date_n pick's portf value = 983.3863677978516
# next_date_n SPY portf value =    870.0879516601562
# ====================
#
# date = '2023-06-12', l_syms = ['NVDA', 'SHV'], ar_price = array([394.82000732, 109.24530792]), ar_shares = array([1., 4.]), ar_value = array([394.82000732, 436.98123169]), portf_value = 831.8012390136719
# 2023-06-12 portf_value = 831.8012390136719
# date = '2023-06-12', l_syms = ['SPY'], ar_price = array([432.19454956]), ar_shares = array([2.]), ar_value = array([864.38909912]), portf_value = 864.3890991210938
# 2023-06-12 portf_value = 864.3890991210938
# next_date_n pick's portf value = 831.8012390136719
# next_date_n SPY portf value =    864.3890991210938
# ====================
#
# date = '2023-06-09', l_syms = ['NVDA', 'SHV'], ar_price = array([387.70001221, 109.2254715 ]), ar_shares = array([1., 4.]), ar_value = array([387.70001221, 436.90188599]), portf_value = 824.6018981933594
# 2023-06-09 portf_value = 824.6018981933594
# date = '2023-06-09', l_syms = ['SPY'], ar_price = array([428.30899048]), ar_shares = array([2.]), ar_value = array([856.61798096]), portf_value = 856.6179809570312
# 2023-06-09 portf_value = 856.6179809570312
# next_date_n pick's portf value = 824.6018981933594
# next_date_n SPY portf value =    856.6179809570312
# ====================
#
# date = '2023-06-08', l_syms = ['NVDA', 'SHV'], ar_price = array([385.1000061, 109.2254715]), ar_shares = array([1., 4.]), ar_value = array([385.1000061 , 436.90188599]), portf_value = 822.0018920898438
# 2023-06-08 portf_value = 822.0018920898438
# date = '2023-06-08', l_syms = ['SPY'], ar_price = array([427.54187012]), ar_shares = array([2.]), ar_value = array([855.08374023]), portf_value = 855.083740234375
# 2023-06-08 portf_value = 855.083740234375
# next_date_n pick's portf value = 822.0018920898438
# next_date_n SPY portf value =    855.083740234375
# ====================
#
# date = '2023-06-07', l_syms = ['META', 'NVDA'], ar_price = array([263.6000061, 374.75     ]), ar_shares = array([1., 1.]), ar_value = array([263.6000061, 374.75     ]), portf_value = 638.3500061035156
# 2023-06-07 portf_value = 638.3500061035156
# date = '2023-06-07', l_syms = ['SPY'], ar_price = array([424.97137451]), ar_shares = array([2.]), ar_value = array([849.94274902]), portf_value = 849.9427490234375
# 2023-06-07 portf_value = 849.9427490234375
# next_date_n pick's portf value = 638.3500061035156
# next_date_n SPY portf value =    849.9427490234375
# ====================
#
# date = '2023-06-06', l_syms = ['SHV'], ar_price = array([109.13619995]), ar_shares = array([9.]), ar_value = array([982.22579956]), portf_value = 982.2257995605469
# 2023-06-06 portf_value = 982.2257995605469
# date = '2023-06-06', l_syms = ['SPY'], ar_price = array([426.44592285]), ar_shares = array([2.]), ar_value = array([852.8918457]), portf_value = 852.891845703125
# 2023-06-06 portf_value = 852.891845703125
# next_date_n pick's portf value = 982.2257995605469
# next_date_n SPY portf value =    852.891845703125
# ====================
#
# date = '2023-06-06', l_syms = ['AVGO', 'NVDA'], ar_price = array([785.8135376, 386.5      ]), ar_shares = array([0., 1.]), ar_value = array([  0. , 386.5]), portf_value = 386.5
# 2023-06-06 portf_value = 386.5
# date = '2023-06-06', l_syms = ['SPY'], ar_price = array([426.44592285]), ar_shares = array([2.]), ar_value = array([852.8918457]), portf_value = 852.891845703125
# 2023-06-06 portf_value = 852.891845703125
# next_date_n pick's portf value = 386.5
# next_date_n SPY portf value =    852.891845703125
# ====================
#
# date = '2023-06-05', l_syms = ['SHV'], ar_price = array([109.11636353]), ar_shares = array([9.]), ar_value = array([982.04727173]), portf_value = 982.0472717285156
# 2023-06-05 portf_value = 982.0472717285156
# date = '2023-06-05', l_syms = ['SPY'], ar_price = array([425.51937866]), ar_shares = array([2.]), ar_value = array([851.03875732]), portf_value = 851.0387573242188
# 2023-06-05 portf_value = 851.0387573242188
# next_date_n pick's portf value = 982.0472717285156
# next_date_n SPY portf value =    851.0387573242188
# ====================
#
# date = '2023-06-05', l_syms = ['AVGO', 'NVDA'], ar_price = array([798.04833984, 391.66946411]), ar_shares = array([0., 1.]), ar_value = array([  0.        , 391.66946411]), portf_value = 391.6694641113281
# 2023-06-05 portf_value = 391.6694641113281
# date = '2023-06-05', l_syms = ['SPY'], ar_price = array([425.51937866]), ar_shares = array([2.]), ar_value = array([851.03875732]), portf_value = 851.0387573242188
# 2023-06-05 portf_value = 851.0387573242188
# next_date_n pick's portf value = 391.6694641113281
# next_date_n SPY portf value =    851.0387573242188
# ====================
#
# date = '2023-06-02', l_syms = ['AVGO', 'SHV'], ar_price = array([807.69696045, 109.11636353]), ar_shares = array([0., 4.]), ar_value = array([  0.       , 436.4654541]), portf_value = 436.4654541015625
# 2023-06-02 portf_value = 436.4654541015625
# date = '2023-06-02', l_syms = ['SPY'], ar_price = array([426.33633423]), ar_shares = array([2.]), ar_value = array([852.67266846]), portf_value = 852.6726684570312
# 2023-06-02 portf_value = 852.6726684570312
# next_date_n pick's portf value = 436.4654541015625
# next_date_n SPY portf value =    852.6726684570312
# ====================
#
# date = '2023-06-02', l_syms = ['NVDA'], ar_price = array([393.22930908]), ar_shares = array([2.]), ar_value = array([786.45861816]), portf_value = 786.4586181640625
# 2023-06-02 portf_value = 786.4586181640625
# date = '2023-06-02', l_syms = ['SPY'], ar_price = array([426.33633423]), ar_shares = array([2.]), ar_value = array([852.67266846]), portf_value = 852.6726684570312
# 2023-06-02 portf_value = 852.6726684570312
# next_date_n pick's portf value = 786.4586181640625
# next_date_n SPY portf value =    852.6726684570312
# ====================
#
# date = '2023-06-02', l_syms = ['AVGO'], ar_price = array([807.69696045]), ar_shares = array([1.]), ar_value = array([807.69696045]), portf_value = 807.6969604492188
# 2023-06-02 portf_value = 807.6969604492188
# date = '2023-06-02', l_syms = ['SPY'], ar_price = array([426.33633423]), ar_shares = array([2.]), ar_value = array([852.67266846]), portf_value = 852.6726684570312
# 2023-06-02 portf_value = 852.6726684570312
# next_date_n pick's portf value = 807.6969604492188
# next_date_n SPY portf value =    852.6726684570312
# ====================
#
# date = '2023-06-01', l_syms = ['SHV'], ar_price = array([109.10643768]), ar_shares = array([9.]), ar_value = array([981.95793915]), portf_value = 981.9579391479492
# 2023-06-01 portf_value = 981.9579391479492
# date = '2023-06-01', l_syms = ['SPY'], ar_price = array([420.25891113]), ar_shares = array([2.]), ar_value = array([840.51782227]), portf_value = 840.517822265625
# 2023-06-01 portf_value = 840.517822265625
# next_date_n pick's portf value = 981.9579391479492
# next_date_n SPY portf value =    840.517822265625
# ====================
#
# date = '2023-06-01', l_syms = ['FTSM', 'NVDA'], ar_price = array([ 59.05306244, 397.65887451]), ar_shares = array([8., 1.]), ar_value = array([472.42449951, 397.65887451]), portf_value = 870.0833740234375
# 2023-06-01 portf_value = 870.0833740234375
# date = '2023-06-01', l_syms = ['SPY'], ar_price = array([420.25891113]), ar_shares = array([2.]), ar_value = array([840.51782227]), portf_value = 840.517822265625
# 2023-06-01 portf_value = 840.517822265625
# next_date_n pick's portf value = 870.0833740234375
# next_date_n SPY portf value =    840.517822265625
# ====================
#
# date = '2023-05-31', l_syms = ['SHV'], ar_price = array([109.03502655]), ar_shares = array([9.]), ar_value = array([981.31523895]), portf_value = 981.3152389526367
# 2023-05-31 portf_value = 981.3152389526367
# date = '2023-05-31', l_syms = ['SPY'], ar_price = array([416.30361938]), ar_shares = array([2.]), ar_value = array([832.60723877]), portf_value = 832.6072387695312
# 2023-05-31 portf_value = 832.6072387695312
# next_date_n pick's portf value = 981.3152389526367
# next_date_n SPY portf value =    832.6072387695312
# ====================
#
# date = '2023-05-30', l_syms = ['SHV'], ar_price = array([109.01527405]), ar_shares = array([9.]), ar_value = array([981.13746643]), portf_value = 981.1374664306641
# 2023-05-30 portf_value = 981.1374664306641
# date = '2023-05-30', l_syms = ['SPY'], ar_price = array([418.62496948]), ar_shares = array([2.]), ar_value = array([837.24993896]), portf_value = 837.2499389648438
# 2023-05-30 portf_value = 837.2499389648438
# next_date_n pick's portf value = 981.1374664306641
# next_date_n SPY portf value =    837.2499389648438
# ====================
#
# date = '2023-05-26', l_syms = ['SHV'], ar_price = array([109.00539398]), ar_shares = array([9.]), ar_value = array([981.04854584]), portf_value = 981.0485458374023
# 2023-05-26 portf_value = 981.0485458374023
# date = '2023-05-26', l_syms = ['SPY'], ar_price = array([418.46554565]), ar_shares = array([2.]), ar_value = array([836.93109131]), portf_value = 836.9310913085938
# 2023-05-26 portf_value = 836.9310913085938
# next_date_n pick's portf value = 981.0485458374023
# next_date_n SPY portf value =    836.9310913085938
# ====================
#
# date = '2023-05-25', l_syms = ['SHV'], ar_price = array([108.98564911]), ar_shares = array([9.]), ar_value = array([980.87084198]), portf_value = 980.8708419799805
# 2023-05-25 portf_value = 980.8708419799805
# date = '2023-05-25', l_syms = ['SPY'], ar_price = array([413.115448]), ar_shares = array([2.]), ar_value = array([826.230896]), portf_value = 826.2308959960938
# 2023-05-25 portf_value = 826.2308959960938
# next_date_n pick's portf value = 980.8708419799805
# next_date_n SPY portf value =    826.2308959960938
# ====================
#
# date = '2023-05-24', l_syms = ['SHV', 'TMHC'], ar_price = array([108.93627167,  42.81000137]), ar_shares = array([ 4., 11.]), ar_value = array([435.74508667, 470.91001511]), portf_value = 906.655101776123
# 2023-05-24 portf_value = 906.655101776123
# date = '2023-05-24', l_syms = ['SPY'], ar_price = array([409.56860352]), ar_shares = array([2.]), ar_value = array([819.13720703]), portf_value = 819.13720703125
# 2023-05-24 portf_value = 819.13720703125
# next_date_n pick's portf value = 906.655101776123
# next_date_n SPY portf value =    819.13720703125
# ====================
#
# date = '2023-05-23', l_syms = ['SHV'], ar_price = array([108.93627167]), ar_shares = array([9.]), ar_value = array([980.42644501]), portf_value = 980.4264450073242
# 2023-05-23 portf_value = 980.4264450073242
# date = '2023-05-23', l_syms = ['SPY'], ar_price = array([412.55752563]), ar_shares = array([2.]), ar_value = array([825.11505127]), portf_value = 825.1150512695312
# 2023-05-23 portf_value = 825.1150512695312
# next_date_n pick's portf value = 980.4264450073242
# next_date_n SPY portf value =    825.1150512695312
# ====================
#
# date = '2023-05-22', l_syms = ['SHV'], ar_price = array([108.91652679]), ar_shares = array([9.]), ar_value = array([980.24874115]), portf_value = 980.2487411499023
# 2023-05-22 portf_value = 980.2487411499023
# date = '2023-05-22', l_syms = ['SPY'], ar_price = array([417.24014282]), ar_shares = array([2.]), ar_value = array([834.48028564]), portf_value = 834.4802856445312
# 2023-05-22 portf_value = 834.4802856445312
# next_date_n pick's portf value = 980.2487411499023
# next_date_n SPY portf value =    834.4802856445312
# ====================
#
# date = '2023-05-19', l_syms = ['SHV'], ar_price = array([108.91652679]), ar_shares = array([9.]), ar_value = array([980.24874115]), portf_value = 980.2487411499023
# 2023-05-19 portf_value = 980.2487411499023
# date = '2023-05-19', l_syms = ['SPY'], ar_price = array([417.07073975]), ar_shares = array([2.]), ar_value = array([834.14147949]), portf_value = 834.1414794921875
# 2023-05-19 portf_value = 834.1414794921875
# next_date_n pick's portf value = 980.2487411499023
# next_date_n SPY portf value =    834.1414794921875
# ====================
#
# date = '2023-05-18', l_syms = ['SHV'], ar_price = array([108.91652679]), ar_shares = array([9.]), ar_value = array([980.24874115]), portf_value = 980.2487411499023
# 2023-05-18 portf_value = 980.2487411499023
# date = '2023-05-18', l_syms = ['SPY'], ar_price = array([417.67849731]), ar_shares = array([2.]), ar_value = array([835.35699463]), portf_value = 835.3569946289062
# 2023-05-18 portf_value = 835.3569946289062
# next_date_n pick's portf value = 980.2487411499023
# next_date_n SPY portf value =    835.3569946289062
# ====================
#
# date = '2023-05-17', l_syms = ['ISEE', 'SHV'], ar_price = array([ 36.95999908, 108.88689423]), ar_shares = array([13.,  4.]), ar_value = array([480.4799881, 435.5475769]), portf_value = 916.0275650024414
# 2023-05-17 portf_value = 916.0275650024414
# date = '2023-05-17', l_syms = ['SPY'], ar_price = array([413.69329834]), ar_shares = array([2.]), ar_value = array([827.38659668]), portf_value = 827.3865966796875
# 2023-05-17 portf_value = 827.3865966796875
# next_date_n pick's portf value = 916.0275650024414
# next_date_n SPY portf value =    827.3865966796875
# ====================
#
# date = '2023-05-16', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.04999924, 108.86713409]), ar_shares = array([13.,  4.]), ar_value = array([481.64999008, 435.46853638]), portf_value = 917.1185264587402
# 2023-05-16 portf_value = 917.1185264587402
# date = '2023-05-16', l_syms = ['SPY'], ar_price = array([408.73171997]), ar_shares = array([2.]), ar_value = array([817.46343994]), portf_value = 817.4634399414062
# 2023-05-16 portf_value = 817.4634399414062
# next_date_n pick's portf value = 917.1185264587402
# next_date_n SPY portf value =    817.4634399414062
# ====================
#
# date = '2023-05-15', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.61000061, 108.86713409]), ar_shares = array([13.,  4.]), ar_value = array([488.93000793, 435.46853638]), portf_value = 924.3985443115234
# 2023-05-15 portf_value = 924.3985443115234
# date = '2023-05-15', l_syms = ['SPY'], ar_price = array([411.48150635]), ar_shares = array([2.]), ar_value = array([822.9630127]), portf_value = 822.9630126953125
# 2023-05-15 portf_value = 822.9630126953125
# next_date_n pick's portf value = 924.3985443115234
# next_date_n SPY portf value =    822.9630126953125
# ====================
#
# date = '2023-05-12', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.59999847, 108.85727692]), ar_shares = array([13.,  4.]), ar_value = array([488.79998016, 435.42910767]), portf_value = 924.2290878295898
# 2023-05-12 portf_value = 924.2290878295898
# date = '2023-05-12', l_syms = ['SPY'], ar_price = array([410.06677246]), ar_shares = array([2.]), ar_value = array([820.13354492]), portf_value = 820.133544921875
# 2023-05-12 portf_value = 820.133544921875
# next_date_n pick's portf value = 924.2290878295898
# next_date_n SPY portf value =    820.133544921875
# ====================
#
# date = '2023-05-11', l_syms = ['ISEE', 'SHV'], ar_price = array([ 37.36000061, 108.85727692]), ar_shares = array([13.,  4.]), ar_value = array([485.68000793, 435.42910767]), portf_value = 921.1091156005859
# 2023-05-11 portf_value = 921.1091156005859
# date = '2023-05-11', l_syms = ['SPY'], ar_price = array([410.60476685]), ar_shares = array([2.]), ar_value = array([821.20953369]), portf_value = 821.2095336914062
# 2023-05-11 portf_value = 821.2095336914062
# next_date_n pick's portf value = 921.1091156005859
# next_date_n SPY portf value =    821.2095336914062
# ====================
#
# date = '2023-05-10', l_syms = ['SHV'], ar_price = array([108.81777191]), ar_shares = array([9.]), ar_value = array([979.3599472]), portf_value = 979.3599472045898
# 2023-05-10 portf_value = 979.3599472045898
# date = '2023-05-10', l_syms = ['SPY'], ar_price = array([411.32211304]), ar_shares = array([2.]), ar_value = array([822.64422607]), portf_value = 822.6442260742188
# 2023-05-10 portf_value = 822.6442260742188
# next_date_n pick's portf value = 979.3599472045898
# next_date_n SPY portf value =    822.6442260742188
# ====================
#
# date = '2023-05-09', l_syms = ['SHV'], ar_price = array([108.77825928]), ar_shares = array([9.]), ar_value = array([979.0043335]), portf_value = 979.0043334960938
# 2023-05-09 portf_value = 979.0043334960938
# date = '2023-05-09', l_syms = ['SPY'], ar_price = array([409.40921021]), ar_shares = array([2.]), ar_value = array([818.81842041]), portf_value = 818.8184204101562
# 2023-05-09 portf_value = 818.8184204101562
# next_date_n pick's portf value = 979.0043334960938
# next_date_n SPY portf value =    818.8184204101562
# ====================
#
# date = '2023-05-08', l_syms = ['SHV'], ar_price = array([108.77825928]), ar_shares = array([9.]), ar_value = array([979.0043335]), portf_value = 979.0043334960938
# 2023-05-08 portf_value = 979.0043334960938
# date = '2023-05-08', l_syms = ['SPY'], ar_price = array([411.2124939]), ar_shares = array([2.]), ar_value = array([822.42498779]), portf_value = 822.4249877929688
# 2023-05-08 portf_value = 822.4249877929688
# next_date_n pick's portf value = 979.0043334960938
# next_date_n SPY portf value =    822.4249877929688
# ====================
#
# date = '2023-05-02', l_syms = ['ELF'], ar_price = array([91.73999786]), ar_shares = array([10.]), ar_value = array([917.39997864]), portf_value = 917.3999786376953
# 2023-05-02 portf_value = 917.3999786376953
# date = '2023-05-02', l_syms = ['SPY'], ar_price = array([409.31954956]), ar_shares = array([2.]), ar_value = array([818.63909912]), portf_value = 818.6390991210938
# 2023-05-02 portf_value = 818.6390991210938
# next_date_n pick's portf value = 917.3999786376953
# next_date_n SPY portf value =    818.6390991210938
# ====================
#
# date = '2023-05-01', l_syms = ['ELF', 'SHV'], ar_price = array([ 92.72000122, 108.66963196]), ar_shares = array([5., 4.]), ar_value = array([463.6000061 , 434.67852783]), portf_value = 898.2785339355469
# 2023-05-01 portf_value = 898.2785339355469
# date = '2023-05-01', l_syms = ['SPY'], ar_price = array([413.97225952]), ar_shares = array([2.]), ar_value = array([827.94451904]), portf_value = 827.9445190429688
# 2023-05-01 portf_value = 827.9445190429688
# next_date_n pick's portf value = 898.2785339355469
# next_date_n SPY portf value =    827.9445190429688
# ====================
#
# date = '2023-04-28', l_syms = ['ELF'], ar_price = array([92.76000214]), ar_shares = array([10.]), ar_value = array([927.60002136]), portf_value = 927.6000213623047
# 2023-04-28 portf_value = 927.6000213623047
# date = '2023-04-28', l_syms = ['SPY'], ar_price = array([414.39068604]), ar_shares = array([2.]), ar_value = array([828.78137207]), portf_value = 828.7813720703125
# 2023-04-28 portf_value = 828.7813720703125
# next_date_n pick's portf value = 927.6000213623047
# next_date_n SPY portf value =    828.7813720703125
# ====================
#
# date = '2023-04-27', l_syms = ['ELF'], ar_price = array([92.84999847]), ar_shares = array([10.]), ar_value = array([928.49998474]), portf_value = 928.4999847412109
# 2023-04-27 portf_value = 928.4999847412109
# date = '2023-04-27', l_syms = ['SPY'], ar_price = array([410.88372803]), ar_shares = array([2.]), ar_value = array([821.76745605]), portf_value = 821.7674560546875
# 2023-04-27 portf_value = 821.7674560546875
# next_date_n pick's portf value = 928.4999847412109
# next_date_n SPY portf value =    821.7674560546875
# ====================
#
# date = '2023-04-26', l_syms = ['ELF'], ar_price = array([93.84999847]), ar_shares = array([10.]), ar_value = array([938.49998474]), portf_value = 938.4999847412109
# 2023-04-26 portf_value = 938.4999847412109
# date = '2023-04-26', l_syms = ['SPY'], ar_price = array([402.86349487]), ar_shares = array([2.]), ar_value = array([805.72698975]), portf_value = 805.7269897460938
# 2023-04-26 portf_value = 805.7269897460938
# next_date_n pick's portf value = 938.4999847412109
# next_date_n SPY portf value =    805.7269897460938
# ====================
#
# date = '2023-04-25', l_syms = ['SHV'], ar_price = array([108.64212036]), ar_shares = array([9.]), ar_value = array([977.77908325]), portf_value = 977.7790832519531
# 2023-04-25 portf_value = 977.7790832519531
# date = '2023-04-25', l_syms = ['SPY'], ar_price = array([404.57714844]), ar_shares = array([2.]), ar_value = array([809.15429688]), portf_value = 809.154296875
# 2023-04-25 portf_value = 809.154296875
# next_date_n pick's portf value = 977.7790832519531
# next_date_n SPY portf value =    809.154296875
# ====================
#
# date = '2023-04-24', l_syms = ['SHV'], ar_price = array([108.6125946]), ar_shares = array([9.]), ar_value = array([977.51335144]), portf_value = 977.5133514404297
# 2023-04-24 portf_value = 977.5133514404297
# date = '2023-04-24', l_syms = ['SPY'], ar_price = array([411.10293579]), ar_shares = array([2.]), ar_value = array([822.20587158]), portf_value = 822.2058715820312
# 2023-04-24 portf_value = 822.2058715820312
# next_date_n pick's portf value = 977.5133514404297
# next_date_n SPY portf value =    822.2058715820312
# ====================
#
# date = '2023-04-21', l_syms = ['ELF', 'SHV'], ar_price = array([ 96.68000031, 108.60276031]), ar_shares = array([5., 4.]), ar_value = array([483.40000153, 434.41104126]), portf_value = 917.8110427856445
# 2023-04-21 portf_value = 917.8110427856445
# date = '2023-04-21', l_syms = ['SPY'], ar_price = array([410.67453003]), ar_shares = array([2.]), ar_value = array([821.34906006]), portf_value = 821.3490600585938
# 2023-04-21 portf_value = 821.3490600585938
# next_date_n pick's portf value = 917.8110427856445
# next_date_n SPY portf value =    821.3490600585938
# ====================
#
# date = '2023-04-20', l_syms = ['SHV'], ar_price = array([108.59293365]), ar_shares = array([9.]), ar_value = array([977.33640289]), portf_value = 977.3364028930664
# 2023-04-20 portf_value = 977.3364028930664
# date = '2023-04-20', l_syms = ['SPY'], ar_price = array([410.35571289]), ar_shares = array([2.]), ar_value = array([820.71142578]), portf_value = 820.71142578125
# 2023-04-20 portf_value = 820.71142578125
# next_date_n pick's portf value = 977.3364028930664
# next_date_n SPY portf value =    820.71142578125
# ====================
#
# date = '2023-04-19', l_syms = ['SHV'], ar_price = array([108.53388977]), ar_shares = array([9.]), ar_value = array([976.80500793]), portf_value = 976.8050079345703
# 2023-04-19 portf_value = 976.8050079345703
# date = '2023-04-19', l_syms = ['SPY'], ar_price = array([412.60733032]), ar_shares = array([2.]), ar_value = array([825.21466064]), portf_value = 825.2146606445312
# 2023-04-19 portf_value = 825.2146606445312
# next_date_n pick's portf value = 976.8050079345703
# next_date_n SPY portf value =    825.2146606445312
# ====================
#
# date = '2023-04-18', l_syms = ['SHV'], ar_price = array([108.52404785]), ar_shares = array([9.]), ar_value = array([976.71643066]), portf_value = 976.7164306640625
# 2023-04-18 portf_value = 976.7164306640625
# date = '2023-04-18', l_syms = ['SPY'], ar_price = array([412.67706299]), ar_shares = array([2.]), ar_value = array([825.35412598]), portf_value = 825.3541259765625
# 2023-04-18 portf_value = 825.3541259765625
# next_date_n pick's portf value = 976.7164306640625
# next_date_n SPY portf value =    825.3541259765625
# ====================
#
# date = '2023-04-17', l_syms = ['SHV'], ar_price = array([108.50436401]), ar_shares = array([9.]), ar_value = array([976.53927612]), portf_value = 976.5392761230469
# 2023-04-17 portf_value = 976.5392761230469
# date = '2023-04-17', l_syms = ['SPY'], ar_price = array([412.40808105]), ar_shares = array([2.]), ar_value = array([824.81616211]), portf_value = 824.816162109375
# 2023-04-17 portf_value = 824.816162109375
# next_date_n pick's portf value = 976.5392761230469
# next_date_n SPY portf value =    824.816162109375
# ====================
#
# date = '2023-04-14', l_syms = ['SHV'], ar_price = array([108.49452209]), ar_shares = array([9.]), ar_value = array([976.45069885]), portf_value = 976.4506988525391
# 2023-04-14 portf_value = 976.4506988525391
# date = '2023-04-14', l_syms = ['SPY'], ar_price = array([410.93353271]), ar_shares = array([2.]), ar_value = array([821.86706543]), portf_value = 821.8670654296875
# 2023-04-14 portf_value = 821.8670654296875
# next_date_n pick's portf value = 976.4506988525391
# next_date_n SPY portf value =    821.8670654296875
# ====================
#
# date = '2023-04-13', l_syms = ['SHV'], ar_price = array([108.5141983]), ar_shares = array([9.]), ar_value = array([976.62778473]), portf_value = 976.6277847290039
# 2023-04-13 portf_value = 976.6277847290039
# date = '2023-04-13', l_syms = ['SPY'], ar_price = array([411.93981934]), ar_shares = array([2.]), ar_value = array([823.87963867]), portf_value = 823.879638671875
# 2023-04-13 portf_value = 823.879638671875
# next_date_n pick's portf value = 976.6277847290039
# next_date_n SPY portf value =    823.879638671875
# ====================
#
# date = '2023-04-12', l_syms = ['SHV'], ar_price = array([108.45515442]), ar_shares = array([9.]), ar_value = array([976.09638977]), portf_value = 976.0963897705078
# 2023-04-12 portf_value = 976.0963897705078
# date = '2023-04-12', l_syms = ['SPY'], ar_price = array([406.53985596]), ar_shares = array([2.]), ar_value = array([813.07971191]), portf_value = 813.0797119140625
# 2023-04-12 portf_value = 813.0797119140625
# next_date_n pick's portf value = 976.0963897705078
# next_date_n SPY portf value =    813.0797119140625
# ====================
#
# date = '2023-04-11', l_syms = ['NVDA', 'SHV'], ar_price = array([271.66189575, 108.44532776]), ar_shares = array([1., 4.]), ar_value = array([271.66189575, 433.78131104]), portf_value = 705.4432067871094
# 2023-04-11 portf_value = 705.4432067871094
# date = '2023-04-11', l_syms = ['SPY'], ar_price = array([408.20367432]), ar_shares = array([2.]), ar_value = array([816.40734863]), portf_value = 816.4073486328125
# 2023-04-11 portf_value = 816.4073486328125
# next_date_n pick's portf value = 705.4432067871094
# next_date_n SPY portf value =    816.4073486328125
# ====================
#
# date = '2023-04-10', l_syms = ['GE', 'NVDA'], ar_price = array([ 94.29027557, 275.76147461]), ar_shares = array([5., 1.]), ar_value = array([471.45137787, 275.76147461]), portf_value = 747.2128524780273
# 2023-04-10 portf_value = 747.2128524780273
# date = '2023-04-10', l_syms = ['SPY'], ar_price = array([408.09408569]), ar_shares = array([2.]), ar_value = array([816.18817139]), portf_value = 816.1881713867188
# 2023-04-10 portf_value = 816.1881713867188
# next_date_n pick's portf value = 747.2128524780273
# next_date_n SPY portf value =    816.1881713867188
# ====================
#
# date = '2023-04-06', l_syms = ['NVDA'], ar_price = array([270.3420105]), ar_shares = array([3.]), ar_value = array([811.02603149]), portf_value = 811.0260314941406
# 2023-04-06 portf_value = 811.0260314941406
# date = '2023-04-06', l_syms = ['SPY'], ar_price = array([407.67565918]), ar_shares = array([2.]), ar_value = array([815.35131836]), portf_value = 815.351318359375
# 2023-04-06 portf_value = 815.351318359375
# next_date_n pick's portf value = 811.0260314941406
# next_date_n SPY portf value =    815.351318359375
# ====================
#
# date = '2023-04-05', l_syms = ['SHV'], ar_price = array([108.43549347]), ar_shares = array([9.]), ar_value = array([975.91944122]), portf_value = 975.9194412231445
# 2023-04-05 portf_value = 975.9194412231445
# date = '2023-04-05', l_syms = ['SPY'], ar_price = array([406.09155273]), ar_shares = array([2.]), ar_value = array([812.18310547]), portf_value = 812.18310546875
# 2023-04-05 portf_value = 812.18310546875
# next_date_n pick's portf value = 975.9194412231445
# next_date_n SPY portf value =    812.18310546875
# ====================
#
# date = '2023-04-05', l_syms = ['NVDA'], ar_price = array([268.78219604]), ar_shares = array([3.]), ar_value = array([806.34658813]), portf_value = 806.3465881347656
# 2023-04-05 portf_value = 806.3465881347656
# date = '2023-04-05', l_syms = ['SPY'], ar_price = array([406.09155273]), ar_shares = array([2.]), ar_value = array([812.18310547]), portf_value = 812.18310546875
# 2023-04-05 portf_value = 812.18310546875
# next_date_n pick's portf value = 806.3465881347656
# next_date_n SPY portf value =    812.18310546875
# ====================
#
# date = '2023-04-04', l_syms = ['SHV'], ar_price = array([108.37644958]), ar_shares = array([9.]), ar_value = array([975.38804626]), portf_value = 975.3880462646484
# 2023-04-04 portf_value = 975.3880462646484
# date = '2023-04-04', l_syms = ['SPY'], ar_price = array([407.15759277]), ar_shares = array([2.]), ar_value = array([814.31518555]), portf_value = 814.315185546875
# 2023-04-04 portf_value = 814.315185546875
# next_date_n pick's portf value = 975.3880462646484
# next_date_n SPY portf value =    814.315185546875
# ====================
#
# date = '2023-04-03', l_syms = ['SHV'], ar_price = array([108.33708191]), ar_shares = array([9.]), ar_value = array([975.03373718]), portf_value = 975.0337371826172
# 2023-04-03 portf_value = 975.0337371826172
# date = '2023-04-03', l_syms = ['SPY'], ar_price = array([409.42913818]), ar_shares = array([2.]), ar_value = array([818.85827637]), portf_value = 818.8582763671875
# 2023-04-03 portf_value = 818.8582763671875
# next_date_n pick's portf value = 975.0337371826172
# next_date_n SPY portf value =    818.8582763671875
# ====================
#
# date = '2023-03-31', l_syms = ['SHV'], ar_price = array([108.34593964]), ar_shares = array([9.]), ar_value = array([975.11345673]), portf_value = 975.1134567260742
# 2023-03-31 portf_value = 975.1134567260742
# date = '2023-03-31', l_syms = ['SPY'], ar_price = array([407.87490845]), ar_shares = array([2.]), ar_value = array([815.74981689]), portf_value = 815.7498168945312
# 2023-03-31 portf_value = 815.7498168945312
# next_date_n pick's portf value = 975.1134567260742
# next_date_n SPY portf value =    815.7498168945312
# ====================
#
# date = '2023-03-31', l_syms = ['GE'], ar_price = array([95.52935791]), ar_shares = array([10.]), ar_value = array([955.2935791]), portf_value = 955.2935791015625
# 2023-03-31 portf_value = 955.2935791015625
# date = '2023-03-31', l_syms = ['SPY'], ar_price = array([407.87490845]), ar_shares = array([2.]), ar_value = array([815.74981689]), portf_value = 815.7498168945312
# 2023-03-31 portf_value = 815.7498168945312
# next_date_n pick's portf value = 955.2935791015625
# next_date_n SPY portf value =    815.7498168945312
# ====================
#
# date = '2023-03-30', l_syms = ['NVDA', 'SHV'], ar_price = array([273.80166626, 108.33613586]), ar_shares = array([1., 4.]), ar_value = array([273.80166626, 433.34454346]), portf_value = 707.1462097167969
# 2023-03-30 portf_value = 707.1462097167969
# date = '2023-03-30', l_syms = ['SPY'], ar_price = array([402.20596313]), ar_shares = array([2.]), ar_value = array([804.41192627]), portf_value = 804.4119262695312
# 2023-03-30 portf_value = 804.4119262695312
# next_date_n pick's portf value = 707.1462097167969
# next_date_n SPY portf value =    804.4119262695312
# ====================
#
# date = '2023-03-29', l_syms = ['SHV'], ar_price = array([108.31652832]), ar_shares = array([9.]), ar_value = array([974.84875488]), portf_value = 974.8487548828125
# 2023-03-29 portf_value = 974.8487548828125
# date = '2023-03-29', l_syms = ['SPY'], ar_price = array([399.86465454]), ar_shares = array([2.]), ar_value = array([799.72930908]), portf_value = 799.7293090820312
# 2023-03-29 portf_value = 799.7293090820312
# next_date_n pick's portf value = 974.8487548828125
# next_date_n SPY portf value =    799.7293090820312
# ====================
#
# date = '2023-03-28', l_syms = ['SHV'], ar_price = array([108.30671692]), ar_shares = array([9.]), ar_value = array([974.76045227]), portf_value = 974.7604522705078
# 2023-03-28 portf_value = 974.7604522705078
# date = '2023-03-28', l_syms = ['SPY'], ar_price = array([394.13595581]), ar_shares = array([2.]), ar_value = array([788.27191162]), portf_value = 788.2719116210938
# 2023-03-28 portf_value = 788.2719116210938
# next_date_n pick's portf value = 974.7604522705078
# next_date_n SPY portf value =    788.2719116210938
# ====================
#
# date = '2023-03-28', l_syms = ['FTSM'], ar_price = array([58.53902817]), ar_shares = array([17.]), ar_value = array([995.16347885]), portf_value = 995.1634788513184
# 2023-03-28 portf_value = 995.1634788513184
# date = '2023-03-28', l_syms = ['SPY'], ar_price = array([394.13595581]), ar_shares = array([2.]), ar_value = array([788.27191162]), portf_value = 788.2719116210938
# 2023-03-28 portf_value = 788.2719116210938
# next_date_n pick's portf value = 995.1634788513184
# next_date_n SPY portf value =    788.2719116210938
# ====================
#
# date = '2023-03-27', l_syms = ['SHV'], ar_price = array([108.29690552]), ar_shares = array([9.]), ar_value = array([974.67214966]), portf_value = 974.6721496582031
# 2023-03-27 portf_value = 974.6721496582031
# date = '2023-03-27', l_syms = ['SPY'], ar_price = array([395.02264404]), ar_shares = array([2.]), ar_value = array([790.04528809]), portf_value = 790.0452880859375
# 2023-03-27 portf_value = 790.0452880859375
# next_date_n pick's portf value = 974.6721496582031
# next_date_n SPY portf value =    790.0452880859375
# ====================
#
# date = '2023-03-27', l_syms = ['GE'], ar_price = array([93.24105072]), ar_shares = array([11.]), ar_value = array([1025.65155792]), portf_value = 1025.6515579223633
# 2023-03-27 portf_value = 1025.6515579223633
# date = '2023-03-27', l_syms = ['SPY'], ar_price = array([395.02264404]), ar_shares = array([2.]), ar_value = array([790.04528809]), portf_value = 790.0452880859375
# 2023-03-27 portf_value = 790.0452880859375
# next_date_n pick's portf value = 1025.6515579223633
# next_date_n SPY portf value =    790.0452880859375
# ====================
#
# date = '2023-03-24', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.58809662, 108.29690552]), ar_shares = array([8., 4.]), ar_value = array([468.70477295, 433.18762207]), portf_value = 901.8923950195312
# 2023-03-24 portf_value = 901.8923950195312
# date = '2023-03-24', l_syms = ['SPY'], ar_price = array([394.28540039]), ar_shares = array([2.]), ar_value = array([788.57080078]), portf_value = 788.57080078125
# 2023-03-24 portf_value = 788.57080078125
# next_date_n pick's portf value = 901.8923950195312
# next_date_n SPY portf value =    788.57080078125
# ====================
#
# date = '2023-03-23', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.55865097, 108.28710938]), ar_shares = array([8., 4.]), ar_value = array([468.46920776, 433.1484375 ]), portf_value = 901.6176452636719
# 2023-03-23 portf_value = 901.6176452636719
# date = '2023-03-23', l_syms = ['SPY'], ar_price = array([391.7149353]), ar_shares = array([2.]), ar_value = array([783.42987061]), portf_value = 783.4298706054688
# 2023-03-23 portf_value = 783.4298706054688
# next_date_n pick's portf value = 901.6176452636719
# next_date_n SPY portf value =    783.4298706054688
# ====================
#
# date = '2023-03-23', l_syms = ['GE'], ar_price = array([91.52231598]), ar_shares = array([11.]), ar_value = array([1006.74547577]), portf_value = 1006.745475769043
# 2023-03-23 portf_value = 1006.745475769043
# date = '2023-03-23', l_syms = ['SPY'], ar_price = array([391.7149353]), ar_shares = array([2.]), ar_value = array([783.42987061]), portf_value = 783.4298706054688
# 2023-03-23 portf_value = 783.4298706054688
# next_date_n pick's portf value = 1006.745475769043
# next_date_n SPY portf value =    783.4298706054688
# ====================
#
# date = '2023-03-22', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.54883957, 108.21847534]), ar_shares = array([8., 4.]), ar_value = array([468.39071655, 432.87390137]), portf_value = 901.2646179199219
# 2023-03-22 portf_value = 901.2646179199219
# date = '2023-03-22', l_syms = ['SPY'], ar_price = array([390.65884399]), ar_shares = array([2.]), ar_value = array([781.31768799]), portf_value = 781.3176879882812
# 2023-03-22 portf_value = 781.3176879882812
# next_date_n pick's portf value = 901.2646179199219
# next_date_n SPY portf value =    781.3176879882812
# ====================
#
# date = '2023-03-21', l_syms = ['FTSM', 'SHV'], ar_price = array([ 58.4899559, 108.179245 ]), ar_shares = array([8., 4.]), ar_value = array([467.91964722, 432.71697998]), portf_value = 900.6366271972656
# 2023-03-21 portf_value = 900.6366271972656
# date = '2023-03-21', l_syms = ['SPY'], ar_price = array([397.4336853]), ar_shares = array([2.]), ar_value = array([794.86737061]), portf_value = 794.8673706054688
# 2023-03-21 portf_value = 794.8673706054688
# next_date_n pick's portf value = 900.6366271972656
# next_date_n SPY portf value =    794.8673706054688
# ====================

# %%
df_mp['date_sell'] = date_exec
df_mp['sh_portf_sell'] = shares_syms
df_mp['$_portf_sell'] = value_portf
df_mp['%_portf_chg'] = (df_mp['$_portf_sell'] / df_mp['$_portf_buy'] - 1) * 100

df_mp['sh_SPY_sell'] = shares_SPY
df_mp['$_SPY_sell'] = value_SPY
df_mp['%_SPY_chg'] = (df_mp['$_SPY_sell'] / df_mp['$_SPY_buy'] - 1) * 100

df_mp['dif_%_chg'] = df_mp['%_portf_chg'] - df_mp['%_SPY_chg']

# %%
# get symbol's close price for that date
date = '2023-03-16'
# _date = '2023-03-21'
# _sym = 'GE'
# _sym = 'NVDA'
_sym = 'FTSM'
# _sym = 'SHV'
_sym = 'SPY'
# _c = df_close.loc['2023-04-11']['NVDA']
_c = df_close.loc[_date][_sym]
_c
# Out:
# 386.3647766113281

# %% [markdown]
# #### dif_%_chg is the percentage change of model icks - percentage change of SPY

# %%
df_mp.head(20)
# Out:
#           date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg
# 0   2023-08-08  [30, 60, 120]  sym_freq_8  ['SHV', 'STRL']        None         None          NaN       None         NaN        None          None           NaN          NaN        None         NaN        NaN        NaN
# 1   2023-08-07  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-08        [9.0]   990.899986      [2.0]  897.500000        None          None           NaN          NaN        None         NaN        NaN        NaN
# 2   2023-08-04  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-07        [9.0]   990.720016      [2.0]  901.419983        None          None           NaN          NaN        None         NaN        NaN        NaN
# 3   2023-08-03  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-04        [9.0]   990.720016      [2.0]  893.619995        None          None           NaN          NaN        None         NaN        NaN        NaN
# 4   2023-08-02  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-03        [9.0]   990.450027      [2.0]  897.679993  2023-08-08         [9.0]    990.899986     0.045430       [2.0]  897.500000  -0.020051   0.065481
# 5   2023-07-27  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-28        [9.0]   989.577782      [2.0]  913.840027  2023-08-02         [9.0]    990.090019     0.051763       [2.0]  900.260010  -1.486039   1.537802
# 6   2023-07-26  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-27        [9.0]   989.308891      [2.0]  904.979980  2023-08-01         [9.0]    989.909981     0.060759       [2.0]  912.960022   0.881792  -0.821034
# 7   2023-07-25  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-26        [9.0]   988.950394      [2.0]  911.020020  2023-07-31         [9.0]    989.756996     0.081561       [2.0]  915.580017   0.500538  -0.418976
# 8   2023-07-21  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-24        [9.0]   988.681572      [2.0]  908.400024  2023-07-27         [9.0]    989.308891     0.063450       [2.0]  904.979980  -0.376491   0.439941
# 9   2023-07-20  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-21        [9.0]   988.591965      [2.0]  904.359985  2023-07-26         [9.0]    988.950394     0.036257       [2.0]  911.020020   0.736436  -0.700180
# 10  2023-07-18  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-19        [9.0]   988.054253      [2.0]  910.400024  2023-07-24         [9.0]    988.681572     0.063490       [2.0]  908.400024  -0.219684   0.283174
# 11  2023-07-14  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-17        [9.0]   987.785362      [2.0]  901.679993  2023-07-20         [9.0]    988.502357     0.072586       [2.0]  904.359985   0.297222  -0.224636
# 12  2023-07-13  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-14  [4.0, 12.0]   924.135895      [2.0]  898.559998  2023-07-19   [4.0, 12.0]    947.575211     2.536349       [2.0]  910.400024   1.317667   1.218683
# 13  2023-07-12  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-13  [4.0, 12.0]   936.576080      [2.0]  899.119995  2023-07-18   [4.0, 12.0]    941.495560     0.525262       [2.0]  908.380005   1.029897  -0.504635
# 14  2023-07-11  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-12  [4.0, 12.0]   932.137070      [2.0]  892.039978  2023-07-17   [4.0, 12.0]    924.415726    -0.828349       [2.0]  901.679993   1.080671  -1.909019
# 15  2023-07-10  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-11  [4.0, 11.0]   897.827576      [2.0]  884.919983  2023-07-14   [4.0, 11.0]    883.705894    -1.572872       [2.0]  898.559998   1.541384  -3.114256
# 16  2023-07-07  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-10  [4.0, 11.0]   902.667561      [2.0]  879.320007  2023-07-13   [4.0, 11.0]    895.106079    -0.837682       [2.0]  899.119995   2.251739  -3.089420
# 17  2023-07-06  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-07  [4.0, 12.0]   928.817902      [2.0]  877.099976  2023-07-12   [4.0, 12.0]    932.137070     0.357354       [2.0]  892.039978   1.703341  -1.345987
# 18  2023-07-05  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-06        [9.0]   986.620262      [2.0]  879.320007  2023-07-11         [9.0]    986.799545     0.018171       [2.0]  884.919983   0.636853  -0.618682
# 19  2023-07-03  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-05        [9.0]   986.082619      [2.0]  886.260010  2023-07-10         [9.0]    986.799545     0.072705       [2.0]  879.320007  -0.783066   0.855771

# %%
df_mp['win'] = np.where(df_mp['dif_%_chg']>0,1,0)
df_mp.head(20)
# Out:
#           date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0   2023-08-08  [30, 60, 120]  sym_freq_8  ['SHV', 'STRL']        None         None          NaN       None         NaN        None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 1   2023-08-07  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-08        [9.0]   990.899986      [2.0]  897.500000        None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 2   2023-08-04  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-07        [9.0]   990.720016      [2.0]  901.419983        None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 3   2023-08-03  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-04        [9.0]   990.720016      [2.0]  893.619995        None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 4   2023-08-02  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-03        [9.0]   990.450027      [2.0]  897.679993  2023-08-08         [9.0]    990.899986     0.045430       [2.0]  897.500000  -0.020051   0.065481    1
# 5   2023-07-27  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-28        [9.0]   989.577782      [2.0]  913.840027  2023-08-02         [9.0]    990.090019     0.051763       [2.0]  900.260010  -1.486039   1.537802    1
# 6   2023-07-26  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-27        [9.0]   989.308891      [2.0]  904.979980  2023-08-01         [9.0]    989.909981     0.060759       [2.0]  912.960022   0.881792  -0.821034    0
# 7   2023-07-25  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-26        [9.0]   988.950394      [2.0]  911.020020  2023-07-31         [9.0]    989.756996     0.081561       [2.0]  915.580017   0.500538  -0.418976    0
# 8   2023-07-21  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-24        [9.0]   988.681572      [2.0]  908.400024  2023-07-27         [9.0]    989.308891     0.063450       [2.0]  904.979980  -0.376491   0.439941    1
# 9   2023-07-20  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-21        [9.0]   988.591965      [2.0]  904.359985  2023-07-26         [9.0]    988.950394     0.036257       [2.0]  911.020020   0.736436  -0.700180    0
# 10  2023-07-18  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-19        [9.0]   988.054253      [2.0]  910.400024  2023-07-24         [9.0]    988.681572     0.063490       [2.0]  908.400024  -0.219684   0.283174    1
# 11  2023-07-14  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-17        [9.0]   987.785362      [2.0]  901.679993  2023-07-20         [9.0]    988.502357     0.072586       [2.0]  904.359985   0.297222  -0.224636    0
# 12  2023-07-13  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-14  [4.0, 12.0]   924.135895      [2.0]  898.559998  2023-07-19   [4.0, 12.0]    947.575211     2.536349       [2.0]  910.400024   1.317667   1.218683    1
# 13  2023-07-12  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-13  [4.0, 12.0]   936.576080      [2.0]  899.119995  2023-07-18   [4.0, 12.0]    941.495560     0.525262       [2.0]  908.380005   1.029897  -0.504635    0
# 14  2023-07-11  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-12  [4.0, 12.0]   932.137070      [2.0]  892.039978  2023-07-17   [4.0, 12.0]    924.415726    -0.828349       [2.0]  901.679993   1.080671  -1.909019    0
# 15  2023-07-10  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-11  [4.0, 11.0]   897.827576      [2.0]  884.919983  2023-07-14   [4.0, 11.0]    883.705894    -1.572872       [2.0]  898.559998   1.541384  -3.114256    0
# 16  2023-07-07  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-10  [4.0, 11.0]   902.667561      [2.0]  879.320007  2023-07-13   [4.0, 11.0]    895.106079    -0.837682       [2.0]  899.119995   2.251739  -3.089420    0
# 17  2023-07-06  [30, 60, 120]  sym_freq_8  ['SHV', 'SKYW']  2023-07-07  [4.0, 12.0]   928.817902      [2.0]  877.099976  2023-07-12   [4.0, 12.0]    932.137070     0.357354       [2.0]  892.039978   1.703341  -1.345987    0
# 18  2023-07-05  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-06        [9.0]   986.620262      [2.0]  879.320007  2023-07-11         [9.0]    986.799545     0.018171       [2.0]  884.919983   0.636853  -0.618682    0
# 19  2023-07-03  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-05        [9.0]   986.082619      [2.0]  886.260010  2023-07-10         [9.0]    986.799545     0.072705       [2.0]  879.320007  -0.783066   0.855771    1

# %% [markdown]
# ### Model Performance Not Good

# %%
wins = df_mp['win'].sum()
attempts = len(df_mp['dif_%_chg'].dropna())

win_rate = wins / attempts
print(f'win_rate: {win_rate:0.6f}, wins: {wins}, attempts: {attempts}')
print(f'sum(dff_%_chg): {df_mp["dif_%_chg"].sum():0.6f}')
# Out:
# win_rate: 0.339806, wins: 35, attempts: 103
# sum(dff_%_chg): -61.556613

# %%
df = df_mp.copy()

# %%
df_model_picks = df[df['dif_%_chg'].isnull()].copy()
pickle_dump(df_model_picks, path_data_dump, 'df_model_picks')
_df = pickle_load(path_data_dump, 'df_model_picks')
_df
# Out:
#          date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0  2023-08-08  [30, 60, 120]  sym_freq_8  ['SHV', 'STRL']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 1  2023-08-07  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-08        [9.0]   990.899986      [2.0]  897.500000      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 2  2023-08-04  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-07        [9.0]   990.720016      [2.0]  901.419983      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 3  2023-08-03  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-04        [9.0]   990.720016      [2.0]  893.619995      None          None           NaN          NaN        None         NaN        NaN        NaN    0

# %%
idx_last_row = df_model_picks.index[-1]
df_model_picks_results = df.iloc[(idx_last_row + 1)::].copy()
pickle_dump(df_model_picks_results, path_data_dump, 'df_model_picks_results')
_df = pickle_load(path_data_dump, 'df_model_picks_results')
_df
# Out:
#            date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 4    2023-08-02  [30, 60, 120]  sym_freq_8          ['SHV']  2023-08-03        [9.0]   990.450027      [2.0]  897.679993  2023-08-08         [9.0]    990.899986     0.045430       [2.0]  897.500000  -0.020051   0.065481    1
# 5    2023-07-27  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-28        [9.0]   989.577782      [2.0]  913.840027  2023-08-02         [9.0]    990.090019     0.051763       [2.0]  900.260010  -1.486039   1.537802    1
# 6    2023-07-26  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-27        [9.0]   989.308891      [2.0]  904.979980  2023-08-01         [9.0]    989.909981     0.060759       [2.0]  912.960022   0.881792  -0.821034    0
# 7    2023-07-25  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-26        [9.0]   988.950394      [2.0]  911.020020  2023-07-31         [9.0]    989.756996     0.081561       [2.0]  915.580017   0.500538  -0.418976    0
# 8    2023-07-21  [30, 60, 120]  sym_freq_8          ['SHV']  2023-07-24        [9.0]   988.681572      [2.0]  908.400024  2023-07-27         [9.0]    989.308891     0.063450       [2.0]  904.979980  -0.376491   0.439941    1
# ..          ...            ...         ...              ...         ...          ...          ...        ...         ...         ...           ...           ...          ...         ...         ...        ...        ...  ...
# 102  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-21   [8.0, 4.0]   900.636627      [2.0]  794.867371  2023-03-24    [8.0, 4.0]    901.892395     0.139431       [2.0]  788.570801  -0.792154   0.931585    1
# 103  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-20   [8.0, 4.0]   901.225372      [2.0]  784.565613  2023-03-23    [8.0, 4.0]    901.617645     0.043527       [2.0]  783.429871  -0.144761   0.188287    1
# 104  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']  2023-03-20       [11.0]   988.389091      [2.0]  784.565613  2023-03-23        [11.0]   1006.745476     1.857202       [2.0]  783.429871  -0.144761   2.001963    1
# 105  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-17   [8.0, 4.0]   900.597229      [2.0]  777.093384  2023-03-22    [8.0, 4.0]    901.264618     0.074105       [2.0]  781.317688   0.543603  -0.469498    0
# 106  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-16   [8.0, 4.0]   900.362030      [2.0]  786.287231  2023-03-21    [8.0, 4.0]    900.636627     0.030499       [2.0]  794.867371   1.091222  -1.060723    0
#
# [103 rows x 18 columns]
