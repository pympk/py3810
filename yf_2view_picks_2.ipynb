# %%
# # create empty DataFrame df and append row
# my_cols = ['date', 'days_lookback', 'syms_freq', 'symbols']
# # Creating Empty DataFrame and Storing it in variable df
# df_model_top_picks = pd.DataFrame(columns=my_cols)
# df_model_top_picks

# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.width', 900)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_picks  = f'df_picks'
fp_df_model_top_picks = f'df_model_top_picks'

verbose = True
# verbose = False

# %%
df = pickle_load(path_data_dump, fp_df_picks)
df = df.drop_duplicates(subset=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], keep='last')
df = df.sort_values(by=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], ascending=False)
df = df.reset_index(drop=True)
pickle_dump(df, path_data_dump, fp_df_picks)
print(f'len(df): {len(df)}')
print(df.head())
# Out:
# len(df): 226
#   date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12      sym_freq_11 sym_freq_10       sym_freq_9        sym_freq_8       sym_freq_7                     sym_freq_6              sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0        2023-09-18                 120      [30, 60, 120]          []          []          []          []               []          []          ['SHV']          ['FTSM']               []        ['CELH', 'DELL', 'LLY']   ['CCJ', 'FTI', 'VST']  ['ANF', 'ARCH', 'CLS', 'CP...       ['CLMT', 'HZNP', 'SKYW']         []
# 1        2023-09-18                 120  [15, 30, 60, 120]          []          []          []          []          ['SHV']    ['FTSM']         ['DELL']                []  ['ARCH', 'CCJ']  ['CELH', 'FTI', 'LLY', 'TW...                ['RCKT']  ['ANF', 'CLS', 'CPRI', 'HA...                             []         []
# 2        2023-09-15                 120      [30, 60, 120]          []          []          []          []               []          []  ['FTSM', 'SHV']                []         ['DELL']         ['ANF', 'CELH', 'LLY']         ['CCJ', 'MMYT']  ['ARCH', 'CLS', 'CPRI', 'P...  ['CLMT', 'HRB', 'HZNP', 'O...         []
# 3        2023-09-15                 120  [15, 30, 60, 120]          []          []          []          []  ['FTSM', 'SHV']    ['DELL']               []                []         ['ARCH']  ['ANF', 'CCJ', 'CELH', 'LL...        ['HZNP', 'MMYT']  ['CLS', 'CPRI', 'HMC', 'PB...                 ['BX', 'CLMT']         []
# 4        2023-09-14                 120      [30, 60, 120]          []          []          []          []               []          []          ['SHV']  ['DELL', 'FTSM']               []         ['CELH', 'LLY', 'TDS']  ['ANF', 'CCJ', 'CPRI']         ['CLS', 'HEP', 'MMYT']  ['ARCH', 'BBW', 'BR', 'CLM...         []

# %%
df.head(50)
# Out:
#    date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12      sym_freq_11       sym_freq_10               sym_freq_9        sym_freq_8                     sym_freq_7                     sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0         2023-09-18                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']          ['FTSM']                             []        ['CELH', 'DELL', 'LLY']          ['CCJ', 'FTI', 'VST']  ['ANF', 'ARCH', 'CLS', 'CP...       ['CLMT', 'HZNP', 'SKYW']         []
# 1         2023-09-18                 120  [15, 30, 60, 120]          []          []          []          []          ['SHV']          ['FTSM']                 ['DELL']                []                ['ARCH', 'CCJ']  ['CELH', 'FTI', 'LLY', 'TW...                       ['RCKT']  ['ANF', 'CLS', 'CPRI', 'HA...                             []         []
# 2         2023-09-15                 120      [30, 60, 120]          []          []          []          []               []                []          ['FTSM', 'SHV']                []                       ['DELL']         ['ANF', 'CELH', 'LLY']                ['CCJ', 'MMYT']  ['ARCH', 'CLS', 'CPRI', 'P...  ['CLMT', 'HRB', 'HZNP', 'O...         []
# 3         2023-09-15                 120  [15, 30, 60, 120]          []          []          []          []  ['FTSM', 'SHV']          ['DELL']                       []                []                       ['ARCH']  ['ANF', 'CCJ', 'CELH', 'LL...               ['HZNP', 'MMYT']  ['CLS', 'CPRI', 'HMC', 'PB...                 ['BX', 'CLMT']         []
# 4         2023-09-14                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']  ['DELL', 'FTSM']                             []         ['CELH', 'LLY', 'TDS']         ['ANF', 'CCJ', 'CPRI']         ['CLS', 'HEP', 'MMYT']  ['ARCH', 'BBW', 'BR', 'CLM...         []
# 5         2023-09-14                 120  [15, 30, 60, 120]          []          []          []          []  ['DELL', 'SHV']                []                       []          ['FTSM']                             []  ['ARCH', 'CELH', 'LLY', 'T...  ['ANF', 'CCJ', 'CPRI', 'HZ...  ['CLS', 'FTI', 'HEP', 'HMC...          ['BBW', 'BR', 'CLMT']         []
# 6         2023-09-13                 120      [30, 60, 120]          []          []          []          []               []                []          ['FTSM', 'SHV']          ['DELL']                       ['MMYT']         ['CELH', 'LLY', 'TDS']               ['CORT', 'CPRI']          ['CCJ', 'CLS', 'VST']  ['ANF', 'BBW', 'CNX', 'FTI...         []
# 7         2023-09-13                 120  [15, 30, 60, 120]          []          []          []          []  ['DELL', 'SHV']                []                 ['FTSM']                []                ['LLY', 'MMYT']        ['CELH', 'TDS', 'TWNK']  ['BBW', 'CORT', 'CPRI', 'H...   ['CCJ', 'CLS', 'FTI', 'VST']          ['ANF', 'ARCH', 'BX']         []
# 8         2023-09-12                 120      [30, 60, 120]          []          []          []          []               []                []          ['FTSM', 'SHV']  ['DELL', 'MMYT']                             []  ['ANF', 'CELH', 'FTI', 'LL...        ['CORT', 'STRL', 'VST']                ['CLS', 'CPRI']  ['BBW', 'BCC', 'CNX', 'HZN...         []
# 9         2023-09-12                 120  [15, 30, 60, 120]          []          []          []          []  ['DELL', 'SHV']                []          ['ANF', 'FTSM']   ['FTI', 'MMYT']                             []  ['CELH', 'LLY', 'TDS', 'TW...  ['CORT', 'HZNP', 'STRL', '...         ['CLS', 'CPRI', 'SLG']                 ['BBW', 'BCC']         []
# 10        2023-09-11                 120      [30, 60, 120]          []          []          []          []               []                []  ['DELL', 'FTSM', 'SHV']                []                       ['MMYT']  ['ANF', 'CELH', 'LLY', 'ST...        ['CORT', 'CPRI', 'VST']                 ['CLS', 'XPO']  ['BBW', 'BR', 'CNX', 'FTI'...         []
# 11        2023-09-11                 120  [15, 30, 60, 120]          []          []          []    ['DELL']          ['SHV']                []          ['ANF', 'FTSM']                []                       ['MMYT']  ['CELH', 'CLS', 'LLY', 'ST...  ['CORT', 'CPRI', 'HZNP', '...                 ['SLG', 'XPO']                  ['BBW', 'BR']         []
# 12        2023-09-08                 120      [30, 60, 120]          []          []          []          []               []                []          ['FTSM', 'SHV']  ['DELL', 'STRL']                             []  ['ANF', 'CELH', 'LLY', 'MM...                        ['VST']        ['CLS', 'CORT', 'CPRI']  ['AEO', 'CNX', 'FTI', 'HZN...         []
# 13        2023-09-08                 120  [15, 30, 60, 120]          []          []          []          []  ['DELL', 'SHV']                []          ['ANF', 'FTSM']  ['CELH', 'STRL']                        ['VST']         ['LLY', 'MMYT', 'TDS']         ['FTI', 'HZNP', 'VNO']  ['CLS', 'CORT', 'CPRI', 'S...         ['AEO', 'CLMT', 'CNX']         []
# 14        2023-09-05                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']          ['FTSM']        ['ANF', 'DELL', 'STRL']  ['AEO', 'CELH', 'CLS', 'SM...  ['CNX', 'LLY', 'MMYT', 'XPO']  ['BCC', 'CORT', 'CPRI', 'U...                ['CDW', 'FFWM']         []
# 15        2023-09-05                 120  [15, 30, 60, 120]          []          []          []          []          ['SHV']   ['ANF', 'DELL']                 ['FTSM']                []                ['STRL', 'UBS']  ['AEO', 'CELH', 'CLS', 'PA...  ['CNX', 'HZNP', 'LLY', 'MM...        ['BCC', 'CORT', 'CPRI']                             []         []
# 16        2023-09-01                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']  ['FTSM', 'STRL']                             []  ['AEO', 'ANF', 'CELH', 'CL...  ['BCC', 'CNX', 'LLY', 'MMY...                       ['CPRI']  ['BKI', 'CDW', 'CORT', 'HRB']         []
# 17        2023-09-01                 120  [15, 30, 60, 120]          []          []          []          []          ['SHV']                []  ['ANF', 'DELL', 'FTSM']   ['STRL', 'TDS']                             []  ['AEO', 'CELH', 'CLS', 'HR...  ['BCC', 'CNX', 'HZNP', 'LL...                       ['CPRI']                             []         []
# 18        2023-08-25                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']          ['STRL']                       ['FTSM']    ['AEO', 'ANF', 'SM', 'TDS']          ['CLS', 'CNX', 'LLY']  ['BCC', 'CPRI', 'MMYT', 'X...  ['CELH', 'CORT', 'DELL', '...         []
# 19        2023-08-25                 120  [15, 30, 60, 120]          []          []          []     ['SHV']               []          ['STRL']           ['ANF', 'TDS']   ['FTSM', 'LLY']                       ['CPRI']  ['AEO', 'CELH', 'HRB', 'MM...     ['CLS', 'CNX', 'UBS', 'X']                 ['BCC', 'XPO']               ['CCOI', 'CCRN']         []
# 20        2023-08-18                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']          ['FTSM']                       ['STRL']                 ['CNX', 'TDS']                 ['CLS', 'XPO']          ['BKI', 'HRB', 'LLY']  ['ADBE', 'AEO', 'BCC', 'BL...         []
# 21        2023-08-18                 120  [15, 30, 60, 120]          []          []          []     ['SHV']               []          ['FTSM']   ['CNX', 'STRL', 'TDS']                []                 ['HRB', 'LLY']  ['AEO', 'BKI', 'CELH', 'CO...         ['CLS', 'CPRI', 'XPO']         ['MMYT', 'REGN', 'SM']        ['ADBE', 'AZTA', 'BCC']         []
# 22        2023-08-17                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']          ['FTSM']                       ['STRL']          ['CLS', 'CNX', 'TDS']                        ['XPO']          ['BKI', 'HRB', 'LLY']  ['ADBE', 'AEO', 'ANF', 'BC...         []
# 23        2023-08-17                 120  [15, 30, 60, 120]          []          []          []     ['SHV']               []  ['FTSM', 'STRL']           ['CNX', 'TDS']                []                 ['HRB', 'LLY']  ['AEO', 'BKI', 'CLS', 'COR...                ['LAUR', 'XPO']                         ['SM']  ['ADBE', 'ANF', 'BCC', 'BL...         []
# 24        2023-08-15                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']          ['STRL']                             []                ['FTSM', 'TDS']                 ['CLS', 'XPO']  ['BKI', 'CNX', 'ELF', 'EME...  ['AEO', 'ANF', 'BCC', 'BZH...         []
# 25        2023-08-15                 120  [15, 30, 60, 120]          []          []          []     ['SHV']         ['STRL']                []                  ['TDS']                []          ['CLS', 'CNX', 'EME']  ['AEO', 'CORT', 'ELF', 'EX...  ['BKI', 'CELH', 'CPRI', 'F...               ['MMYT', 'SAIA']                             []         []
# 26        2023-08-14                 120      [30, 60, 120]          []          []          []          []               []                []                  ['SHV']                []                       ['STRL']  ['CLS', 'FTSM', 'LOB', 'TDS']                 ['EME', 'XPO']                ['BKI', 'SATS']  ['AEO', 'ANF', 'BCC', 'BZH...         []
# 27        2023-08-14                 120  [15, 30, 60, 120]          []          []          []          []          ['SHV']          ['STRL']                  ['TDS']    ['CLS', 'EME']                       ['SATS']  ['AEO', 'CORT', 'FTSM', 'L...  ['BKI', 'CELH', 'DINO', 'E...  ['CNX', 'CPRI', 'CSL', 'FF...                             []         []
# 28        2023-08-11                 120      [30, 60, 120]          []          []          []          []               []                []                       []   ['SHV', 'STRL']                             []                ['FTSM', 'TDS']          ['CLS', 'LOB', 'XPO']  ['BCC', 'DINO', 'EME', 'SA...  ['AEO', 'BKI', 'BZH', 'CEL...         []
# 29        2023-08-11                 120  [15, 30, 60, 120]          []          []          []          []         ['STRL']           ['SHV']                  ['TDS']                []         ['CLS', 'DINO', 'EME']         ['AEO', 'FTSM', 'MPC']  ['CNX', 'CORT', 'CPRI', 'C...                        ['BCC']                             []         []
# 30        2023-08-10                 120      [30, 60, 120]          []          []          []          []               []                []                       []   ['SHV', 'STRL']                             []         ['FTSM', 'LOB', 'TDS']                 ['CLS', 'XPO']  ['BCC', 'DINO', 'SATS', 'S...  ['AEO', 'BZH', 'CELH', 'CO...         []
# 31        2023-08-10                 120  [15, 30, 60, 120]          []          []          []          []         ['STRL']           ['SHV']           ['LOB', 'TDS']                []                ['CLS', 'DINO']  ['AEO', 'CORT', 'FTSM', 'S...  ['CPRI', 'CVBF', 'FFWM', '...  ['BCC', 'EME', 'LAUR', 'SM...                       ['ATSG']         []
# 32        2023-08-09                 120      [30, 60, 120]          []          []          []          []               []                []                       []   ['SHV', 'STRL']                             []         ['FTSM', 'LOB', 'TDS']                 ['CLS', 'GBX']  ['BCC', 'DINO', 'SATS', 'S...  ['BKI', 'BKU', 'BZH', 'CEL...         []
# 33        2023-08-09                 120  [15, 30, 60, 120]          []          []          []          []         ['STRL']           ['SHV']           ['LOB', 'TDS']                []                ['CLS', 'DINO']               ['FTSM', 'SATS']         ['CORT', 'GBX', 'OVV']  ['BCC', 'CNX', 'CVBF', 'EM...                             []         []
# 34        2023-08-08                 120      [30, 60, 120]          []          []          []          []               []                []                       []   ['SHV', 'STRL']                       ['SMCI']          ['BCC', 'LOB', 'TDS']        ['CLS', 'FTSM', 'SKYW']  ['BKU', 'EME', 'GBX', 'KDN...  ['AMPH', 'BZH', 'CVBF', 'E...         []
# 35        2023-08-08                 120  [15, 30, 60, 120]          []          []          []          []         ['STRL']           ['SHV']                  ['TDS']                []  ['CLS', 'LOB', 'SATS', 'SM...                 ['BCC', 'EME']  ['CORT', 'FFWM', 'FTSM', '...  ['BKU', 'DINO', 'GBX', 'KD...                ['AMPH', 'BZH']         []
# 36        2023-08-07                 120      [30, 60, 120]          []          []          []          []               []                []                       []           ['SHV']                       ['SMCI']                        ['LOB']  ['BCC', 'CLS', 'EME', 'FTS...         ['GBX', 'SATS', 'VNO']  ['AVGO', 'BKU', 'BLDR', 'B...         []
# 37        2023-08-07                 120  [15, 30, 60, 120]          []          []          []          []               []           ['SHV']                       []           ['LOB']                ['CLS', 'SMCI']         ['EME', 'SATS', 'TDS']  ['BCC', 'CORT', 'CVBF', 'F...  ['DINO', 'EDU', 'FFWM', 'G...                       ['AVGO']         []
# 38        2023-08-04                 120      [30, 60, 120]          []          []          []          []               []                []                       []           ['SHV']                       ['SMCI']                        ['LOB']  ['BCC', 'CLS', 'FTSM', 'GB...          ['EME', 'TDS', 'VNO']  ['AMPH', 'AVGO', 'BKU', 'B...         []
# 39        2023-08-04                 120  [15, 30, 60, 120]          []          []          []          []               []           ['SHV']                       []           ['LOB']         ['CLS', 'SMCI', 'TDS']                             []  ['BCC', 'CORT', 'CVBF', 'E...         ['BKU', 'EDU', 'FFWM']                       ['AMPH']         []
# 40        2023-08-03                 120      [30, 60, 120]          []          []          []          []               []                []                       []           ['SHV']                             []         ['BCC', 'LOB', 'SMCI']        ['FTSM', 'GBX', 'SKYW']  ['AMPH', 'BZH', 'CLS', 'SL...  ['AVGO', 'CVBF', 'ELF', 'G...         []
# 41        2023-08-03                 120  [15, 30, 60, 120]          []          []          []          []               []           ['SHV']                       []           ['LOB']                             []  ['BCC', 'CLS', 'SMCI', 'WAL']  ['CORT', 'CVBF', 'FTSM', '...  ['AMPH', 'BZH', 'MATX', 'P...               ['AVGO', 'CADE']         []
# 42        2023-08-02                 120      [30, 60, 120]          []          []          []          []               []                []                       []           ['SHV']                       ['SMCI']          ['BZH', 'GBX', 'LOB']  ['BCC', 'CLS', 'FTSM', 'SK...         ['AMPH', 'EME', 'JOE']  ['AVGO', 'CHTR', 'CSL', 'E...         []
# 43        2023-08-02                 120  [15, 30, 60, 120]          []          []          []          []               []           ['SHV']                  ['LOB']                []                ['CLS', 'SMCI']          ['BZH', 'EME', 'GBX']  ['BCC', 'FTSM', 'HP', 'JOE...  ['AMPH', 'CVBF', 'PKX', 'V...  ['ASTE', 'AVGO', 'BKI', 'B...         []
# 44        2023-08-01                 120      [30, 60, 120]          []          []          []          []               []                []                       []                []                ['BZH', 'SMCI']                 ['GBX', 'LOB']         ['BCC', 'CLS', 'FTSM']         ['AMPH', 'JOE', 'PKX']  ['AVGO', 'BAH', 'EME', 'GE...         []
# 45        2023-08-01                 120  [15, 30, 60, 120]          []          []          []          []               []                []                  ['LOB']          ['SMCI']                 ['BZH', 'CLS']                 ['GBX', 'PKX']         ['BCC', 'FTSM', 'JOE']                ['AMPH', 'EME']  ['AVGO', 'BAH', 'BKI', 'ED...         []
# 46        2023-07-27                 120      [30, 60, 120]          []          []          []          []               []                []                       []           ['SHV']                             []                        ['JOE']  ['BCC', 'CLS', 'FTSM', 'GBX']  ['AMPH', 'KDNY', 'PKX', 'X...  ['AVGO', 'BLDR', 'BZH', 'C...         []
# 47        2023-07-27                 120  [15, 30, 60, 120]          []          []          []          []               []           ['SHV']                  ['JOE']                []                             []                        ['PKX']  ['BCC', 'CLS', 'FTSM', 'GB...        ['AMPH', 'KDNY', 'XPO']  ['AVGO', 'BKI', 'BLDR', 'B...         []
# 48        2023-07-26                 120      [30, 60, 120]          []          []          []          []               []                []                       []           ['SHV']                        ['PKX']         ['FTSM', 'GBX', 'XPO']                ['BCC', 'STRL']                       ['AMPH']  ['AAPL', 'AVGO', 'BKI', 'B...         []
# 49        2023-07-26                 120  [15, 30, 60, 120]          []          []          []          []               []    ['PKX', 'SHV']                       []                []                             []         ['FTSM', 'GBX', 'XPO']  ['BCC', 'LOB', 'PRG', 'STRL']                ['AMPH', 'BKI']  ['AAPL', 'AVGO', 'BLDR', '...         []

# %%
df_mp_res = pickle_load(path_data_dump, 'df_model_picks_results')
df_mp = pickle_load(path_data_dump, 'df_model_picks')
# df_mp_res 
df_mp
# Out:
#          date  days_lookback   syms_freq           symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0  2023-09-08  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 1  2023-09-08  [30, 60, 120]  sym_freq_8  ['DELL', 'STRL']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 2  2023-09-05  [30, 60, 120]  sym_freq_9           ['SHV']  2023-09-06        [9.0]   990.809967      [2.0]  892.440002      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 3  2023-09-05  [30, 60, 120]  sym_freq_8          ['FTSM']  2023-09-06       [16.0]   951.840027      [2.0]  892.440002      None          None           NaN          NaN        None         NaN        NaN        NaN    0

# %%
from itertools import product
from ast import literal_eval

my_cols = ['sym_freq_12', 'sym_freq_9', 'sym_freq_8']
my_days_lookbacks = [[30, 60, 120], [15, 30, 60, 120]]

my_dates = []
for my_days_lookback in my_days_lookbacks:
  my_row = (df['days_lookbacks'] == str(my_days_lookback))
  l_dates = df.loc[my_row, 'date_end_df_train'].tolist()     
  my_dates.append(l_dates)

my_dates = [val for sublist in my_dates for val in sublist]
my_dates = sorted(list(set(my_dates)), reverse=True)

d_lbk_freq = list(product(my_dates, my_days_lookbacks, my_cols))

picks = []
prev_date = ''
# print(f'Model predicts the best performing symbols are:\n[30, 60, 120]        sym_freq_9\n[15, 30, 60, 120]    sym_freq_12\n[30, 60, 120]        sym_freq_8')
print(f'Model predicts the best performing symbols are:')
print(f'1st    {"[30, 60, 120]":<20}{"sym_freq_9":<14}{"days_eval = 4":<20}')
print(f'2nd    {"[15, 30, 60, 120]":<20}{"sym_freq_12":<14}{"days_eval = 5":<20}')
print(f'3rd    {"[30, 60, 120]":<20}{"sym_freq_8":<14}{"days_eval = 4":<20}')
for i, item in enumerate(d_lbk_freq):
  _date, my_days_lookback, my_col = item[0], item[1], item[2]
  my_row = (df['date_end_df_train'] == _date) & (df['days_lookbacks'] == str(my_days_lookback))  
  list_in_df = df.loc[my_row, my_col]
  my_str = list_in_df.tolist()[0]
  my_list = literal_eval(my_str)
  blank = ' '
  if _date != prev_date:
    if prev_date == '':
      print('\nModel Results:')  
      print(f'{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')
    else:
      print(f'\n{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}') 
  else:
    print(f'{i:<6}{blank:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')

  picks.append((i, my_list))
  prev_date = _date
# Out:
# Model predicts the best performing symbols are:
# 1st    [30, 60, 120]       sym_freq_9    days_eval = 4
# 2nd    [15, 30, 60, 120]   sym_freq_12   days_eval = 5
# 3rd    [30, 60, 120]       sym_freq_8    days_eval = 4
#
# Model Results:
# 0     2023-09-18    [30, 60, 120]        sym_freq_12: []
# 1                   [30, 60, 120]        sym_freq_9 : ['SHV']
# 2                   [30, 60, 120]        sym_freq_8 : ['FTSM']
# 3                   [15, 30, 60, 120]    sym_freq_12: []
# 4                   [15, 30, 60, 120]    sym_freq_9 : ['DELL']
# 5                   [15, 30, 60, 120]    sym_freq_8 : []
#
# 6     2023-09-15    [30, 60, 120]        sym_freq_12: []
# 7                   [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 8                   [30, 60, 120]        sym_freq_8 : []
# 9                   [15, 30, 60, 120]    sym_freq_12: []
# 10                  [15, 30, 60, 120]    sym_freq_9 : []
# 11                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 12    2023-09-14    [30, 60, 120]        sym_freq_12: []
# 13                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 14                  [30, 60, 120]        sym_freq_8 : ['DELL', 'FTSM']
# 15                  [15, 30, 60, 120]    sym_freq_12: []
# 16                  [15, 30, 60, 120]    sym_freq_9 : []
# 17                  [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 18    2023-09-13    [30, 60, 120]        sym_freq_12: []
# 19                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 20                  [30, 60, 120]        sym_freq_8 : ['DELL']
# 21                  [15, 30, 60, 120]    sym_freq_12: []
# 22                  [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 23                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 24    2023-09-12    [30, 60, 120]        sym_freq_12: []
# 25                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 26                  [30, 60, 120]        sym_freq_8 : ['DELL', 'MMYT']
# 27                  [15, 30, 60, 120]    sym_freq_12: []
# 28                  [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 29                  [15, 30, 60, 120]    sym_freq_8 : ['FTI', 'MMYT']
#
# 30    2023-09-11    [30, 60, 120]        sym_freq_12: []
# 31                  [30, 60, 120]        sym_freq_9 : ['DELL', 'FTSM', 'SHV']
# 32                  [30, 60, 120]        sym_freq_8 : []
# 33                  [15, 30, 60, 120]    sym_freq_12: ['DELL']
# 34                  [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 35                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 36    2023-09-08    [30, 60, 120]        sym_freq_12: []
# 37                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 38                  [30, 60, 120]        sym_freq_8 : ['DELL', 'STRL']
# 39                  [15, 30, 60, 120]    sym_freq_12: []
# 40                  [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 41                  [15, 30, 60, 120]    sym_freq_8 : ['CELH', 'STRL']
#
# 42    2023-09-05    [30, 60, 120]        sym_freq_12: []
# 43                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 44                  [30, 60, 120]        sym_freq_8 : ['FTSM']
# 45                  [15, 30, 60, 120]    sym_freq_12: []
# 46                  [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 47                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 48    2023-09-01    [30, 60, 120]        sym_freq_12: []
# 49                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 50                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 51                  [15, 30, 60, 120]    sym_freq_12: []
# 52                  [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'DELL', 'FTSM']
# 53                  [15, 30, 60, 120]    sym_freq_8 : ['STRL', 'TDS']
#
# 54    2023-08-25    [30, 60, 120]        sym_freq_12: []
# 55                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 56                  [30, 60, 120]        sym_freq_8 : ['STRL']
# 57                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 58                  [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'TDS']
# 59                  [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'LLY']
#
# 60    2023-08-18    [30, 60, 120]        sym_freq_12: []
# 61                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 62                  [30, 60, 120]        sym_freq_8 : ['FTSM']
# 63                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 64                  [15, 30, 60, 120]    sym_freq_9 : ['CNX', 'STRL', 'TDS']
# 65                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 66    2023-08-17    [30, 60, 120]        sym_freq_12: []
# 67                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 68                  [30, 60, 120]        sym_freq_8 : ['FTSM']
# 69                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 70                  [15, 30, 60, 120]    sym_freq_9 : ['CNX', 'TDS']
# 71                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 72    2023-08-15    [30, 60, 120]        sym_freq_12: []
# 73                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 74                  [30, 60, 120]        sym_freq_8 : ['STRL']
# 75                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 76                  [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 77                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 78    2023-08-14    [30, 60, 120]        sym_freq_12: []
# 79                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 80                  [30, 60, 120]        sym_freq_8 : []
# 81                  [15, 30, 60, 120]    sym_freq_12: []
# 82                  [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 83                  [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'EME']
#
# 84    2023-08-11    [30, 60, 120]        sym_freq_12: []
# 85                  [30, 60, 120]        sym_freq_9 : []
# 86                  [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 87                  [15, 30, 60, 120]    sym_freq_12: []
# 88                  [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 89                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 90    2023-08-10    [30, 60, 120]        sym_freq_12: []
# 91                  [30, 60, 120]        sym_freq_9 : []
# 92                  [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 93                  [15, 30, 60, 120]    sym_freq_12: []
# 94                  [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'TDS']
# 95                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 96    2023-08-09    [30, 60, 120]        sym_freq_12: []
# 97                  [30, 60, 120]        sym_freq_9 : []
# 98                  [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 99                  [15, 30, 60, 120]    sym_freq_12: []
# 100                 [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'TDS']
# 101                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 102   2023-08-08    [30, 60, 120]        sym_freq_12: []
# 103                 [30, 60, 120]        sym_freq_9 : []
# 104                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 105                 [15, 30, 60, 120]    sym_freq_12: []
# 106                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 107                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 108   2023-08-07    [30, 60, 120]        sym_freq_12: []
# 109                 [30, 60, 120]        sym_freq_9 : []
# 110                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 111                 [15, 30, 60, 120]    sym_freq_12: []
# 112                 [15, 30, 60, 120]    sym_freq_9 : []
# 113                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 114   2023-08-04    [30, 60, 120]        sym_freq_12: []
# 115                 [30, 60, 120]        sym_freq_9 : []
# 116                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 117                 [15, 30, 60, 120]    sym_freq_12: []
# 118                 [15, 30, 60, 120]    sym_freq_9 : []
# 119                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 120   2023-08-03    [30, 60, 120]        sym_freq_12: []
# 121                 [30, 60, 120]        sym_freq_9 : []
# 122                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 123                 [15, 30, 60, 120]    sym_freq_12: []
# 124                 [15, 30, 60, 120]    sym_freq_9 : []
# 125                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 126   2023-08-02    [30, 60, 120]        sym_freq_12: []
# 127                 [30, 60, 120]        sym_freq_9 : []
# 128                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 129                 [15, 30, 60, 120]    sym_freq_12: []
# 130                 [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 131                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 132   2023-08-01    [30, 60, 120]        sym_freq_12: []
# 133                 [30, 60, 120]        sym_freq_9 : []
# 134                 [30, 60, 120]        sym_freq_8 : []
# 135                 [15, 30, 60, 120]    sym_freq_12: []
# 136                 [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 137                 [15, 30, 60, 120]    sym_freq_8 : ['SMCI']
#
# 138   2023-07-27    [30, 60, 120]        sym_freq_12: []
# 139                 [30, 60, 120]        sym_freq_9 : []
# 140                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 141                 [15, 30, 60, 120]    sym_freq_12: []
# 142                 [15, 30, 60, 120]    sym_freq_9 : ['JOE']
# 143                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 144   2023-07-26    [30, 60, 120]        sym_freq_12: []
# 145                 [30, 60, 120]        sym_freq_9 : []
# 146                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 147                 [15, 30, 60, 120]    sym_freq_12: []
# 148                 [15, 30, 60, 120]    sym_freq_9 : []
# 149                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 150   2023-07-25    [30, 60, 120]        sym_freq_12: []
# 151                 [30, 60, 120]        sym_freq_9 : []
# 152                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 153                 [15, 30, 60, 120]    sym_freq_12: []
# 154                 [15, 30, 60, 120]    sym_freq_9 : []
# 155                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 156   2023-07-21    [30, 60, 120]        sym_freq_12: []
# 157                 [30, 60, 120]        sym_freq_9 : []
# 158                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 159                 [15, 30, 60, 120]    sym_freq_12: []
# 160                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 161                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 162   2023-07-20    [30, 60, 120]        sym_freq_12: []
# 163                 [30, 60, 120]        sym_freq_9 : []
# 164                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 165                 [15, 30, 60, 120]    sym_freq_12: []
# 166                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 167                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 168   2023-07-18    [30, 60, 120]        sym_freq_12: []
# 169                 [30, 60, 120]        sym_freq_9 : []
# 170                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 171                 [15, 30, 60, 120]    sym_freq_12: []
# 172                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 173                 [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 174   2023-07-14    [30, 60, 120]        sym_freq_12: []
# 175                 [30, 60, 120]        sym_freq_9 : []
# 176                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 177                 [15, 30, 60, 120]    sym_freq_12: []
# 178                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 179                 [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 180   2023-07-13    [30, 60, 120]        sym_freq_12: []
# 181                 [30, 60, 120]        sym_freq_9 : []
# 182                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 183                 [15, 30, 60, 120]    sym_freq_12: []
# 184                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 185                 [15, 30, 60, 120]    sym_freq_8 : ['BCC', 'SKYW']
#
# 186   2023-07-12    [30, 60, 120]        sym_freq_12: []
# 187                 [30, 60, 120]        sym_freq_9 : []
# 188                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 189                 [15, 30, 60, 120]    sym_freq_12: []
# 190                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 191                 [15, 30, 60, 120]    sym_freq_8 : ['BZH', 'SKYW']
#
# 192   2023-07-11    [30, 60, 120]        sym_freq_12: []
# 193                 [30, 60, 120]        sym_freq_9 : []
# 194                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 195                 [15, 30, 60, 120]    sym_freq_12: []
# 196                 [15, 30, 60, 120]    sym_freq_9 : []
# 197                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 198   2023-07-10    [30, 60, 120]        sym_freq_12: []
# 199                 [30, 60, 120]        sym_freq_9 : []
# 200                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 201                 [15, 30, 60, 120]    sym_freq_12: []
# 202                 [15, 30, 60, 120]    sym_freq_9 : []
# 203                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 204   2023-07-07    [30, 60, 120]        sym_freq_12: []
# 205                 [30, 60, 120]        sym_freq_9 : []
# 206                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 207                 [15, 30, 60, 120]    sym_freq_12: []
# 208                 [15, 30, 60, 120]    sym_freq_9 : []
# 209                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 210   2023-07-06    [30, 60, 120]        sym_freq_12: []
# 211                 [30, 60, 120]        sym_freq_9 : []
# 212                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 213                 [15, 30, 60, 120]    sym_freq_12: []
# 214                 [15, 30, 60, 120]    sym_freq_9 : []
# 215                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW']
#
# 216   2023-07-05    [30, 60, 120]        sym_freq_12: []
# 217                 [30, 60, 120]        sym_freq_9 : []
# 218                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 219                 [15, 30, 60, 120]    sym_freq_12: []
# 220                 [15, 30, 60, 120]    sym_freq_9 : []
# 221                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 222   2023-07-03    [30, 60, 120]        sym_freq_12: []
# 223                 [30, 60, 120]        sym_freq_9 : []
# 224                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 225                 [15, 30, 60, 120]    sym_freq_12: []
# 226                 [15, 30, 60, 120]    sym_freq_9 : []
# 227                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW', 'W']
#
# 228   2023-06-30    [30, 60, 120]        sym_freq_12: []
# 229                 [30, 60, 120]        sym_freq_9 : []
# 230                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 231                 [15, 30, 60, 120]    sym_freq_12: []
# 232                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 233                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 234   2023-06-29    [30, 60, 120]        sym_freq_12: []
# 235                 [30, 60, 120]        sym_freq_9 : []
# 236                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 237                 [15, 30, 60, 120]    sym_freq_12: []
# 238                 [15, 30, 60, 120]    sym_freq_9 : []
# 239                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 240   2023-06-28    [30, 60, 120]        sym_freq_12: []
# 241                 [30, 60, 120]        sym_freq_9 : []
# 242                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 243                 [15, 30, 60, 120]    sym_freq_12: []
# 244                 [15, 30, 60, 120]    sym_freq_9 : []
# 245                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 246   2023-06-27    [30, 60, 120]        sym_freq_12: []
# 247                 [30, 60, 120]        sym_freq_9 : []
# 248                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 249                 [15, 30, 60, 120]    sym_freq_12: []
# 250                 [15, 30, 60, 120]    sym_freq_9 : []
# 251                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 252   2023-06-26    [30, 60, 120]        sym_freq_12: []
# 253                 [30, 60, 120]        sym_freq_9 : []
# 254                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 255                 [15, 30, 60, 120]    sym_freq_12: []
# 256                 [15, 30, 60, 120]    sym_freq_9 : []
# 257                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 258   2023-06-23    [30, 60, 120]        sym_freq_12: []
# 259                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 260                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 261                 [15, 30, 60, 120]    sym_freq_12: []
# 262                 [15, 30, 60, 120]    sym_freq_9 : ['CCL', 'NVDA']
# 263                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH']
#
# 264   2023-06-22    [30, 60, 120]        sym_freq_12: []
# 265                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 266                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 267                 [15, 30, 60, 120]    sym_freq_12: []
# 268                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 269                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'PBR']
#
# 270   2023-06-21    [30, 60, 120]        sym_freq_12: []
# 271                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 272                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 273                 [15, 30, 60, 120]    sym_freq_12: []
# 274                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 275                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 276   2023-06-20    [30, 60, 120]        sym_freq_12: []
# 277                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 278                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 279                 [15, 30, 60, 120]    sym_freq_12: []
# 280                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 281                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 282   2023-06-16    [30, 60, 120]        sym_freq_12: []
# 283                 [30, 60, 120]        sym_freq_9 : []
# 284                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 285                 [15, 30, 60, 120]    sym_freq_12: []
# 286                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 287                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 288   2023-06-15    [30, 60, 120]        sym_freq_12: []
# 289                 [30, 60, 120]        sym_freq_9 : []
# 290                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 291                 [15, 30, 60, 120]    sym_freq_12: []
# 292                 [15, 30, 60, 120]    sym_freq_9 : []
# 293                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'NVDA', 'SKYW']
#
# 294   2023-06-14    [30, 60, 120]        sym_freq_12: []
# 295                 [30, 60, 120]        sym_freq_9 : []
# 296                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA', 'SHV']
# 297                 [15, 30, 60, 120]    sym_freq_12: []
# 298                 [15, 30, 60, 120]    sym_freq_9 : ['AVGO']
# 299                 [15, 30, 60, 120]    sym_freq_8 : ['ORCL', 'SKYW']
#
# 300   2023-06-13    [30, 60, 120]        sym_freq_12: []
# 301                 [30, 60, 120]        sym_freq_9 : []
# 302                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 303                 [15, 30, 60, 120]    sym_freq_12: []
# 304                 [15, 30, 60, 120]    sym_freq_9 : []
# 305                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 306   2023-06-12    [30, 60, 120]        sym_freq_12: []
# 307                 [30, 60, 120]        sym_freq_9 : []
# 308                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 309                 [15, 30, 60, 120]    sym_freq_12: []
# 310                 [15, 30, 60, 120]    sym_freq_9 : []
# 311                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 312   2023-06-09    [30, 60, 120]        sym_freq_12: []
# 313                 [30, 60, 120]        sym_freq_9 : []
# 314                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 315                 [15, 30, 60, 120]    sym_freq_12: []
# 316                 [15, 30, 60, 120]    sym_freq_9 : []
# 317                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 318   2023-06-08    [30, 60, 120]        sym_freq_12: []
# 319                 [30, 60, 120]        sym_freq_9 : []
# 320                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 321                 [15, 30, 60, 120]    sym_freq_12: []
# 322                 [15, 30, 60, 120]    sym_freq_9 : []
# 323                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 324   2023-06-07    [30, 60, 120]        sym_freq_12: []
# 325                 [30, 60, 120]        sym_freq_9 : []
# 326                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 327                 [15, 30, 60, 120]    sym_freq_12: []
# 328                 [15, 30, 60, 120]    sym_freq_9 : []
# 329                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 330   2023-06-06    [30, 60, 120]        sym_freq_12: []
# 331                 [30, 60, 120]        sym_freq_9 : []
# 332                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 333                 [15, 30, 60, 120]    sym_freq_12: []
# 334                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 335                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 336   2023-06-05    [30, 60, 120]        sym_freq_12: []
# 337                 [30, 60, 120]        sym_freq_9 : []
# 338                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 339                 [15, 30, 60, 120]    sym_freq_12: []
# 340                 [15, 30, 60, 120]    sym_freq_9 : []
# 341                 [15, 30, 60, 120]    sym_freq_8 : ['META', 'SKYW']
#
# 342   2023-06-02    [30, 60, 120]        sym_freq_12: []
# 343                 [30, 60, 120]        sym_freq_9 : []
# 344                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 345                 [15, 30, 60, 120]    sym_freq_12: []
# 346                 [15, 30, 60, 120]    sym_freq_9 : ['META']
# 347                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 348   2023-06-01    [30, 60, 120]        sym_freq_12: []
# 349                 [30, 60, 120]        sym_freq_9 : []
# 350                 [30, 60, 120]        sym_freq_8 : ['META', 'NVDA']
# 351                 [15, 30, 60, 120]    sym_freq_12: []
# 352                 [15, 30, 60, 120]    sym_freq_9 : ['AVGO', 'RMBS']
# 353                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 354   2023-05-31    [30, 60, 120]        sym_freq_12: []
# 355                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 356                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA']
# 357                 [15, 30, 60, 120]    sym_freq_12: []
# 358                 [15, 30, 60, 120]    sym_freq_9 : []
# 359                 [15, 30, 60, 120]    sym_freq_8 : ['RMBS']
#
# 360   2023-05-30    [30, 60, 120]        sym_freq_12: []
# 361                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 362                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA']
# 363                 [15, 30, 60, 120]    sym_freq_12: []
# 364                 [15, 30, 60, 120]    sym_freq_9 : []
# 365                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 366   2023-05-26    [30, 60, 120]        sym_freq_12: []
# 367                 [30, 60, 120]        sym_freq_9 : ['AVGO', 'SHV']
# 368                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 369                 [15, 30, 60, 120]    sym_freq_12: ['AVGO']
# 370                 [15, 30, 60, 120]    sym_freq_9 : ['RMBS']
# 371                 [15, 30, 60, 120]    sym_freq_8 : ['AMD']
#
# 372   2023-05-25    [30, 60, 120]        sym_freq_12: []
# 373                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 374                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'NVDA']
# 375                 [15, 30, 60, 120]    sym_freq_12: []
# 376                 [15, 30, 60, 120]    sym_freq_9 : []
# 377                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 378   2023-05-24    [30, 60, 120]        sym_freq_12: []
# 379                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 380                 [30, 60, 120]        sym_freq_8 : []
# 381                 [15, 30, 60, 120]    sym_freq_12: []
# 382                 [15, 30, 60, 120]    sym_freq_9 : []
# 383                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 384   2023-05-23    [30, 60, 120]        sym_freq_12: []
# 385                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 386                 [30, 60, 120]        sym_freq_8 : []
# 387                 [15, 30, 60, 120]    sym_freq_12: []
# 388                 [15, 30, 60, 120]    sym_freq_9 : []
# 389                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 390   2023-05-22    [30, 60, 120]        sym_freq_12: []
# 391                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 392                 [30, 60, 120]        sym_freq_8 : []
# 393                 [15, 30, 60, 120]    sym_freq_12: []
# 394                 [15, 30, 60, 120]    sym_freq_9 : []
# 395                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 396   2023-05-19    [30, 60, 120]        sym_freq_12: []
# 397                 [30, 60, 120]        sym_freq_9 : []
# 398                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 399                 [15, 30, 60, 120]    sym_freq_12: []
# 400                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 401                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 402   2023-05-18    [30, 60, 120]        sym_freq_12: []
# 403                 [30, 60, 120]        sym_freq_9 : []
# 404                 [30, 60, 120]        sym_freq_8 : ['SHV', 'TMHC']
# 405                 [15, 30, 60, 120]    sym_freq_12: []
# 406                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 407                 [15, 30, 60, 120]    sym_freq_8 : ['TMHC']
#
# 408   2023-05-17    [30, 60, 120]        sym_freq_12: []
# 409                 [30, 60, 120]        sym_freq_9 : []
# 410                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 411                 [15, 30, 60, 120]    sym_freq_12: []
# 412                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 413                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 414   2023-05-16    [30, 60, 120]        sym_freq_12: []
# 415                 [30, 60, 120]        sym_freq_9 : []
# 416                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 417                 [15, 30, 60, 120]    sym_freq_12: []
# 418                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 419                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 420   2023-05-15    [30, 60, 120]        sym_freq_12: []
# 421                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 422                 [30, 60, 120]        sym_freq_8 : []
# 423                 [15, 30, 60, 120]    sym_freq_12: []
# 424                 [15, 30, 60, 120]    sym_freq_9 : []
# 425                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 426   2023-05-12    [30, 60, 120]        sym_freq_12: []
# 427                 [30, 60, 120]        sym_freq_9 : []
# 428                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 429                 [15, 30, 60, 120]    sym_freq_12: []
# 430                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE', 'SHV']
# 431                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 432   2023-05-11    [30, 60, 120]        sym_freq_12: []
# 433                 [30, 60, 120]        sym_freq_9 : []
# 434                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 435                 [15, 30, 60, 120]    sym_freq_12: []
# 436                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 437                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 438   2023-05-10    [30, 60, 120]        sym_freq_12: []
# 439                 [30, 60, 120]        sym_freq_9 : []
# 440                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 441                 [15, 30, 60, 120]    sym_freq_12: []
# 442                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 443                 [15, 30, 60, 120]    sym_freq_8 : ['BLDR']
#
# 444   2023-05-09    [30, 60, 120]        sym_freq_12: []
# 445                 [30, 60, 120]        sym_freq_9 : []
# 446                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 447                 [15, 30, 60, 120]    sym_freq_12: []
# 448                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 449                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 450   2023-05-08    [30, 60, 120]        sym_freq_12: []
# 451                 [30, 60, 120]        sym_freq_9 : []
# 452                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 453                 [15, 30, 60, 120]    sym_freq_12: []
# 454                 [15, 30, 60, 120]    sym_freq_9 : []
# 455                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 456   2023-05-05    [30, 60, 120]        sym_freq_12: []
# 457                 [30, 60, 120]        sym_freq_9 : []
# 458                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 459                 [15, 30, 60, 120]    sym_freq_12: []
# 460                 [15, 30, 60, 120]    sym_freq_9 : []
# 461                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 462   2023-05-04    [30, 60, 120]        sym_freq_12: []
# 463                 [30, 60, 120]        sym_freq_9 : []
# 464                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 465                 [15, 30, 60, 120]    sym_freq_12: []
# 466                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP']
# 467                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 468   2023-05-03    [30, 60, 120]        sym_freq_12: []
# 469                 [30, 60, 120]        sym_freq_9 : []
# 470                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 471                 [15, 30, 60, 120]    sym_freq_12: []
# 472                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE']
# 473                 [15, 30, 60, 120]    sym_freq_8 : ['CCEP', 'SHV', 'SKYW']
#
# 474   2023-05-02    [30, 60, 120]        sym_freq_12: []
# 475                 [30, 60, 120]        sym_freq_9 : []
# 476                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 477                 [15, 30, 60, 120]    sym_freq_12: []
# 478                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP', 'ISEE', 'SHV']
# 479                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 480   2023-05-01    [30, 60, 120]        sym_freq_12: []
# 481                 [30, 60, 120]        sym_freq_9 : []
# 482                 [30, 60, 120]        sym_freq_8 : []
# 483                 [15, 30, 60, 120]    sym_freq_12: []
# 484                 [15, 30, 60, 120]    sym_freq_9 : []
# 485                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 486   2023-04-28    [30, 60, 120]        sym_freq_12: []
# 487                 [30, 60, 120]        sym_freq_9 : []
# 488                 [30, 60, 120]        sym_freq_8 : []
# 489                 [15, 30, 60, 120]    sym_freq_12: []
# 490                 [15, 30, 60, 120]    sym_freq_9 : []
# 491                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 492   2023-04-27    [30, 60, 120]        sym_freq_12: []
# 493                 [30, 60, 120]        sym_freq_9 : []
# 494                 [30, 60, 120]        sym_freq_8 : []
# 495                 [15, 30, 60, 120]    sym_freq_12: []
# 496                 [15, 30, 60, 120]    sym_freq_9 : []
# 497                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 498   2023-04-26    [30, 60, 120]        sym_freq_12: []
# 499                 [30, 60, 120]        sym_freq_9 : []
# 500                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 501                 [15, 30, 60, 120]    sym_freq_12: []
# 502                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 503                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 504   2023-04-25    [30, 60, 120]        sym_freq_12: []
# 505                 [30, 60, 120]        sym_freq_9 : []
# 506                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 507                 [15, 30, 60, 120]    sym_freq_12: []
# 508                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 509                 [15, 30, 60, 120]    sym_freq_8 : ['ELF']
#
# 510   2023-04-24    [30, 60, 120]        sym_freq_12: []
# 511                 [30, 60, 120]        sym_freq_9 : []
# 512                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 513                 [15, 30, 60, 120]    sym_freq_12: []
# 514                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 515                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 516   2023-04-21    [30, 60, 120]        sym_freq_12: []
# 517                 [30, 60, 120]        sym_freq_9 : []
# 518                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 519                 [15, 30, 60, 120]    sym_freq_12: []
# 520                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 521                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 522   2023-04-20    [30, 60, 120]        sym_freq_12: []
# 523                 [30, 60, 120]        sym_freq_9 : []
# 524                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 525                 [15, 30, 60, 120]    sym_freq_12: []
# 526                 [15, 30, 60, 120]    sym_freq_9 : []
# 527                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 528   2023-04-19    [30, 60, 120]        sym_freq_12: []
# 529                 [30, 60, 120]        sym_freq_9 : []
# 530                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 531                 [15, 30, 60, 120]    sym_freq_12: []
# 532                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 533                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 534   2023-04-18    [30, 60, 120]        sym_freq_12: []
# 535                 [30, 60, 120]        sym_freq_9 : []
# 536                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 537                 [15, 30, 60, 120]    sym_freq_12: []
# 538                 [15, 30, 60, 120]    sym_freq_9 : []
# 539                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 540   2023-04-17    [30, 60, 120]        sym_freq_12: []
# 541                 [30, 60, 120]        sym_freq_9 : []
# 542                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 543                 [15, 30, 60, 120]    sym_freq_12: []
# 544                 [15, 30, 60, 120]    sym_freq_9 : []
# 545                 [15, 30, 60, 120]    sym_freq_8 : ['ELF', 'SHV']
#
# 546   2023-04-14    [30, 60, 120]        sym_freq_12: []
# 547                 [30, 60, 120]        sym_freq_9 : []
# 548                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 549                 [15, 30, 60, 120]    sym_freq_12: []
# 550                 [15, 30, 60, 120]    sym_freq_9 : []
# 551                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 552   2023-04-13    [30, 60, 120]        sym_freq_12: []
# 553                 [30, 60, 120]        sym_freq_9 : []
# 554                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 555                 [15, 30, 60, 120]    sym_freq_12: []
# 556                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 557                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 558   2023-04-12    [30, 60, 120]        sym_freq_12: []
# 559                 [30, 60, 120]        sym_freq_9 : []
# 560                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 561                 [15, 30, 60, 120]    sym_freq_12: []
# 562                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 563                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 564   2023-04-11    [30, 60, 120]        sym_freq_12: []
# 565                 [30, 60, 120]        sym_freq_9 : []
# 566                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 567                 [15, 30, 60, 120]    sym_freq_12: []
# 568                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 569                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 570   2023-04-10    [30, 60, 120]        sym_freq_12: []
# 571                 [30, 60, 120]        sym_freq_9 : []
# 572                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 573                 [15, 30, 60, 120]    sym_freq_12: []
# 574                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 575                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 576   2023-04-06    [30, 60, 120]        sym_freq_12: []
# 577                 [30, 60, 120]        sym_freq_9 : []
# 578                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 579                 [15, 30, 60, 120]    sym_freq_12: []
# 580                 [15, 30, 60, 120]    sym_freq_9 : []
# 581                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 582   2023-04-05    [30, 60, 120]        sym_freq_12: []
# 583                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 584                 [30, 60, 120]        sym_freq_8 : []
# 585                 [15, 30, 60, 120]    sym_freq_12: []
# 586                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 587                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 588   2023-04-04    [30, 60, 120]        sym_freq_12: []
# 589                 [30, 60, 120]        sym_freq_9 : []
# 590                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 591                 [15, 30, 60, 120]    sym_freq_12: []
# 592                 [15, 30, 60, 120]    sym_freq_9 : []
# 593                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA', 'SHV']
#
# 594   2023-04-03    [30, 60, 120]        sym_freq_12: []
# 595                 [30, 60, 120]        sym_freq_9 : []
# 596                 [30, 60, 120]        sym_freq_8 : ['GE', 'NVDA']
# 597                 [15, 30, 60, 120]    sym_freq_12: []
# 598                 [15, 30, 60, 120]    sym_freq_9 : []
# 599                 [15, 30, 60, 120]    sym_freq_8 : ['GE', 'PERI']
#
# 600   2023-03-31    [30, 60, 120]        sym_freq_12: []
# 601                 [30, 60, 120]        sym_freq_9 : []
# 602                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 603                 [15, 30, 60, 120]    sym_freq_12: []
# 604                 [15, 30, 60, 120]    sym_freq_9 : []
# 605                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 606   2023-03-30    [30, 60, 120]        sym_freq_12: []
# 607                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 608                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 609                 [15, 30, 60, 120]    sym_freq_12: []
# 610                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 611                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 612   2023-03-29    [30, 60, 120]        sym_freq_12: []
# 613                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 614                 [30, 60, 120]        sym_freq_8 : []
# 615                 [15, 30, 60, 120]    sym_freq_12: []
# 616                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 617                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 618   2023-03-28    [30, 60, 120]        sym_freq_12: []
# 619                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 620                 [30, 60, 120]        sym_freq_8 : []
# 621                 [15, 30, 60, 120]    sym_freq_12: []
# 622                 [15, 30, 60, 120]    sym_freq_9 : []
# 623                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 624   2023-03-27    [30, 60, 120]        sym_freq_12: []
# 625                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 626                 [30, 60, 120]        sym_freq_8 : ['GE']
# 627                 [15, 30, 60, 120]    sym_freq_12: []
# 628                 [15, 30, 60, 120]    sym_freq_9 : []
# 629                 [15, 30, 60, 120]    sym_freq_8 : ['GE', 'NVDA', 'SGEN']
#
# 630   2023-03-24    [30, 60, 120]        sym_freq_12: []
# 631                 [30, 60, 120]        sym_freq_9 : []
# 632                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 633                 [15, 30, 60, 120]    sym_freq_12: []
# 634                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 635                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 636   2023-03-23    [30, 60, 120]        sym_freq_12: []
# 637                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 638                 [30, 60, 120]        sym_freq_8 : []
# 639                 [15, 30, 60, 120]    sym_freq_12: []
# 640                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 641                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'GE']
#
# 642   2023-03-22    [30, 60, 120]        sym_freq_12: []
# 643                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 644                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 645                 [15, 30, 60, 120]    sym_freq_12: []
# 646                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'NVDA']
# 647                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 648   2023-03-21    [30, 60, 120]        sym_freq_12: []
# 649                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 650                 [30, 60, 120]        sym_freq_8 : ['GE']
# 651                 [15, 30, 60, 120]    sym_freq_12: []
# 652                 [15, 30, 60, 120]    sym_freq_9 : ['GE']
# 653                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 654   2023-03-20    [30, 60, 120]        sym_freq_12: []
# 655                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 656                 [30, 60, 120]        sym_freq_8 : []
# 657                 [15, 30, 60, 120]    sym_freq_12: []
# 658                 [15, 30, 60, 120]    sym_freq_9 : []
# 659                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 660   2023-03-17    [30, 60, 120]        sym_freq_12: []
# 661                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 662                 [30, 60, 120]        sym_freq_8 : ['GE']
# 663                 [15, 30, 60, 120]    sym_freq_12: []
# 664                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'GE']
# 665                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 666   2023-03-16    [30, 60, 120]        sym_freq_12: []
# 667                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 668                 [30, 60, 120]        sym_freq_8 : []
# 669                 [15, 30, 60, 120]    sym_freq_12: []
# 670                 [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 671                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 672   2023-03-15    [30, 60, 120]        sym_freq_12: []
# 673                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 674                 [30, 60, 120]        sym_freq_8 : []
# 675                 [15, 30, 60, 120]    sym_freq_12: []
# 676                 [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 677                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'FCN']

# %%
model_top_picks = [([30, 60, 120], 'sym_freq_9'), ([15, 30, 60, 120], 'sym_freq_12'), ([30, 60, 120], 'sym_freq_8')]

# %%
df_model_top_picks = pickle_load(path_data_dump, fp_df_model_top_picks)

z_items   = zip(d_lbk_freq, picks)
for i, item in enumerate(z_items):
  _date, _days_lookback, _sym_freq, _syms = item[0][0], item[0][1], item[0][2], item[1][1]
  print(i, _date, _days_lookback, _sym_freq, _syms)
  dlb_sym_freq = (_days_lookback, _sym_freq)
  if dlb_sym_freq in model_top_picks and _syms:
    row_add = [_date, _days_lookback, _sym_freq, _syms]
    df_model_top_picks.loc[len(df_model_top_picks)] = row_add
    print(f'added row to df_model_top_picks:\n{row_add}\n')
# Out:
# 0 2023-09-18 [30, 60, 120] sym_freq_12 []
# 1 2023-09-18 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 2 2023-09-18 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-09-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 3 2023-09-18 [15, 30, 60, 120] sym_freq_12 []
# 4 2023-09-18 [15, 30, 60, 120] sym_freq_9 ['DELL']
# 5 2023-09-18 [15, 30, 60, 120] sym_freq_8 []
# 6 2023-09-15 [30, 60, 120] sym_freq_12 []
# 7 2023-09-15 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 8 2023-09-15 [30, 60, 120] sym_freq_8 []
# 9 2023-09-15 [15, 30, 60, 120] sym_freq_12 []
# 10 2023-09-15 [15, 30, 60, 120] sym_freq_9 []
# 11 2023-09-15 [15, 30, 60, 120] sym_freq_8 []
# 12 2023-09-14 [30, 60, 120] sym_freq_12 []
# 13 2023-09-14 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 14 2023-09-14 [30, 60, 120] sym_freq_8 ['DELL', 'FTSM']
# added row to df_model_top_picks:
# ['2023-09-14', [30, 60, 120], 'sym_freq_8', ['DELL', 'FTSM']]
#
# 15 2023-09-14 [15, 30, 60, 120] sym_freq_12 []
# 16 2023-09-14 [15, 30, 60, 120] sym_freq_9 []
# 17 2023-09-14 [15, 30, 60, 120] sym_freq_8 ['FTSM']
# 18 2023-09-13 [30, 60, 120] sym_freq_12 []
# 19 2023-09-13 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-13', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 20 2023-09-13 [30, 60, 120] sym_freq_8 ['DELL']
# added row to df_model_top_picks:
# ['2023-09-13', [30, 60, 120], 'sym_freq_8', ['DELL']]
#
# 21 2023-09-13 [15, 30, 60, 120] sym_freq_12 []
# 22 2023-09-13 [15, 30, 60, 120] sym_freq_9 ['FTSM']
# 23 2023-09-13 [15, 30, 60, 120] sym_freq_8 []
# 24 2023-09-12 [30, 60, 120] sym_freq_12 []
# 25 2023-09-12 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-12', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 26 2023-09-12 [30, 60, 120] sym_freq_8 ['DELL', 'MMYT']
# added row to df_model_top_picks:
# ['2023-09-12', [30, 60, 120], 'sym_freq_8', ['DELL', 'MMYT']]
#
# 27 2023-09-12 [15, 30, 60, 120] sym_freq_12 []
# 28 2023-09-12 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 29 2023-09-12 [15, 30, 60, 120] sym_freq_8 ['FTI', 'MMYT']
# 30 2023-09-11 [30, 60, 120] sym_freq_12 []
# 31 2023-09-11 [30, 60, 120] sym_freq_9 ['DELL', 'FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-11', [30, 60, 120], 'sym_freq_9', ['DELL', 'FTSM', 'SHV']]
#
# 32 2023-09-11 [30, 60, 120] sym_freq_8 []
# 33 2023-09-11 [15, 30, 60, 120] sym_freq_12 ['DELL']
# added row to df_model_top_picks:
# ['2023-09-11', [15, 30, 60, 120], 'sym_freq_12', ['DELL']]
#
# 34 2023-09-11 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 35 2023-09-11 [15, 30, 60, 120] sym_freq_8 []
# 36 2023-09-08 [30, 60, 120] sym_freq_12 []
# 37 2023-09-08 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-08', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 38 2023-09-08 [30, 60, 120] sym_freq_8 ['DELL', 'STRL']
# added row to df_model_top_picks:
# ['2023-09-08', [30, 60, 120], 'sym_freq_8', ['DELL', 'STRL']]
#
# 39 2023-09-08 [15, 30, 60, 120] sym_freq_12 []
# 40 2023-09-08 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 41 2023-09-08 [15, 30, 60, 120] sym_freq_8 ['CELH', 'STRL']
# 42 2023-09-05 [30, 60, 120] sym_freq_12 []
# 43 2023-09-05 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 44 2023-09-05 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-09-05', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 45 2023-09-05 [15, 30, 60, 120] sym_freq_12 []
# 46 2023-09-05 [15, 30, 60, 120] sym_freq_9 ['FTSM']
# 47 2023-09-05 [15, 30, 60, 120] sym_freq_8 []
# 48 2023-09-01 [30, 60, 120] sym_freq_12 []
# 49 2023-09-01 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-01', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 50 2023-09-01 [30, 60, 120] sym_freq_8 ['FTSM', 'STRL']
# added row to df_model_top_picks:
# ['2023-09-01', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 51 2023-09-01 [15, 30, 60, 120] sym_freq_12 []
# 52 2023-09-01 [15, 30, 60, 120] sym_freq_9 ['ANF', 'DELL', 'FTSM']
# 53 2023-09-01 [15, 30, 60, 120] sym_freq_8 ['STRL', 'TDS']
# 54 2023-08-25 [30, 60, 120] sym_freq_12 []
# 55 2023-08-25 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-25', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 56 2023-08-25 [30, 60, 120] sym_freq_8 ['STRL']
# added row to df_model_top_picks:
# ['2023-08-25', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 57 2023-08-25 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-25', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 58 2023-08-25 [15, 30, 60, 120] sym_freq_9 ['ANF', 'TDS']
# 59 2023-08-25 [15, 30, 60, 120] sym_freq_8 ['FTSM', 'LLY']
# 60 2023-08-18 [30, 60, 120] sym_freq_12 []
# 61 2023-08-18 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 62 2023-08-18 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-08-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 63 2023-08-18 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-18', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 64 2023-08-18 [15, 30, 60, 120] sym_freq_9 ['CNX', 'STRL', 'TDS']
# 65 2023-08-18 [15, 30, 60, 120] sym_freq_8 []
# 66 2023-08-17 [30, 60, 120] sym_freq_12 []
# 67 2023-08-17 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-17', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 68 2023-08-17 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-08-17', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 69 2023-08-17 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-17', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 70 2023-08-17 [15, 30, 60, 120] sym_freq_9 ['CNX', 'TDS']
# 71 2023-08-17 [15, 30, 60, 120] sym_freq_8 []
# 72 2023-08-15 [30, 60, 120] sym_freq_12 []
# 73 2023-08-15 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 74 2023-08-15 [30, 60, 120] sym_freq_8 ['STRL']
# added row to df_model_top_picks:
# ['2023-08-15', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 75 2023-08-15 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-15', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 76 2023-08-15 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 77 2023-08-15 [15, 30, 60, 120] sym_freq_8 []
# 78 2023-08-14 [30, 60, 120] sym_freq_12 []
# 79 2023-08-14 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 80 2023-08-14 [30, 60, 120] sym_freq_8 []
# 81 2023-08-14 [15, 30, 60, 120] sym_freq_12 []
# 82 2023-08-14 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 83 2023-08-14 [15, 30, 60, 120] sym_freq_8 ['CLS', 'EME']
# 84 2023-08-11 [30, 60, 120] sym_freq_12 []
# 85 2023-08-11 [30, 60, 120] sym_freq_9 []
# 86 2023-08-11 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-11', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 87 2023-08-11 [15, 30, 60, 120] sym_freq_12 []
# 88 2023-08-11 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 89 2023-08-11 [15, 30, 60, 120] sym_freq_8 []
# 90 2023-08-10 [30, 60, 120] sym_freq_12 []
# 91 2023-08-10 [30, 60, 120] sym_freq_9 []
# 92 2023-08-10 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-10', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 93 2023-08-10 [15, 30, 60, 120] sym_freq_12 []
# 94 2023-08-10 [15, 30, 60, 120] sym_freq_9 ['LOB', 'TDS']
# 95 2023-08-10 [15, 30, 60, 120] sym_freq_8 []
# 96 2023-08-09 [30, 60, 120] sym_freq_12 []
# 97 2023-08-09 [30, 60, 120] sym_freq_9 []
# 98 2023-08-09 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-09', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 99 2023-08-09 [15, 30, 60, 120] sym_freq_12 []
# 100 2023-08-09 [15, 30, 60, 120] sym_freq_9 ['LOB', 'TDS']
# 101 2023-08-09 [15, 30, 60, 120] sym_freq_8 []
# 102 2023-08-08 [30, 60, 120] sym_freq_12 []
# 103 2023-08-08 [30, 60, 120] sym_freq_9 []
# 104 2023-08-08 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-08', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 105 2023-08-08 [15, 30, 60, 120] sym_freq_12 []
# 106 2023-08-08 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 107 2023-08-08 [15, 30, 60, 120] sym_freq_8 []
# 108 2023-08-07 [30, 60, 120] sym_freq_12 []
# 109 2023-08-07 [30, 60, 120] sym_freq_9 []
# 110 2023-08-07 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-07', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 111 2023-08-07 [15, 30, 60, 120] sym_freq_12 []
# 112 2023-08-07 [15, 30, 60, 120] sym_freq_9 []
# 113 2023-08-07 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 114 2023-08-04 [30, 60, 120] sym_freq_12 []
# 115 2023-08-04 [30, 60, 120] sym_freq_9 []
# 116 2023-08-04 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 117 2023-08-04 [15, 30, 60, 120] sym_freq_12 []
# 118 2023-08-04 [15, 30, 60, 120] sym_freq_9 []
# 119 2023-08-04 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 120 2023-08-03 [30, 60, 120] sym_freq_12 []
# 121 2023-08-03 [30, 60, 120] sym_freq_9 []
# 122 2023-08-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 123 2023-08-03 [15, 30, 60, 120] sym_freq_12 []
# 124 2023-08-03 [15, 30, 60, 120] sym_freq_9 []
# 125 2023-08-03 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 126 2023-08-02 [30, 60, 120] sym_freq_12 []
# 127 2023-08-02 [30, 60, 120] sym_freq_9 []
# 128 2023-08-02 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 129 2023-08-02 [15, 30, 60, 120] sym_freq_12 []
# 130 2023-08-02 [15, 30, 60, 120] sym_freq_9 ['LOB']
# 131 2023-08-02 [15, 30, 60, 120] sym_freq_8 []
# 132 2023-08-01 [30, 60, 120] sym_freq_12 []
# 133 2023-08-01 [30, 60, 120] sym_freq_9 []
# 134 2023-08-01 [30, 60, 120] sym_freq_8 []
# 135 2023-08-01 [15, 30, 60, 120] sym_freq_12 []
# 136 2023-08-01 [15, 30, 60, 120] sym_freq_9 ['LOB']
# 137 2023-08-01 [15, 30, 60, 120] sym_freq_8 ['SMCI']
# 138 2023-07-27 [30, 60, 120] sym_freq_12 []
# 139 2023-07-27 [30, 60, 120] sym_freq_9 []
# 140 2023-07-27 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-27', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 141 2023-07-27 [15, 30, 60, 120] sym_freq_12 []
# 142 2023-07-27 [15, 30, 60, 120] sym_freq_9 ['JOE']
# 143 2023-07-27 [15, 30, 60, 120] sym_freq_8 []
# 144 2023-07-26 [30, 60, 120] sym_freq_12 []
# 145 2023-07-26 [30, 60, 120] sym_freq_9 []
# 146 2023-07-26 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-26', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 147 2023-07-26 [15, 30, 60, 120] sym_freq_12 []
# 148 2023-07-26 [15, 30, 60, 120] sym_freq_9 []
# 149 2023-07-26 [15, 30, 60, 120] sym_freq_8 []
# 150 2023-07-25 [30, 60, 120] sym_freq_12 []
# 151 2023-07-25 [30, 60, 120] sym_freq_9 []
# 152 2023-07-25 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-25', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 153 2023-07-25 [15, 30, 60, 120] sym_freq_12 []
# 154 2023-07-25 [15, 30, 60, 120] sym_freq_9 []
# 155 2023-07-25 [15, 30, 60, 120] sym_freq_8 []
# 156 2023-07-21 [30, 60, 120] sym_freq_12 []
# 157 2023-07-21 [30, 60, 120] sym_freq_9 []
# 158 2023-07-21 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-21', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 159 2023-07-21 [15, 30, 60, 120] sym_freq_12 []
# 160 2023-07-21 [15, 30, 60, 120] sym_freq_9 ['SHV', 'SIRI']
# 161 2023-07-21 [15, 30, 60, 120] sym_freq_8 []
# 162 2023-07-20 [30, 60, 120] sym_freq_12 []
# 163 2023-07-20 [30, 60, 120] sym_freq_9 []
# 164 2023-07-20 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-20', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 165 2023-07-20 [15, 30, 60, 120] sym_freq_12 []
# 166 2023-07-20 [15, 30, 60, 120] sym_freq_9 ['SHV', 'SIRI']
# 167 2023-07-20 [15, 30, 60, 120] sym_freq_8 []
# 168 2023-07-18 [30, 60, 120] sym_freq_12 []
# 169 2023-07-18 [30, 60, 120] sym_freq_9 []
# 170 2023-07-18 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 171 2023-07-18 [15, 30, 60, 120] sym_freq_12 []
# 172 2023-07-18 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 173 2023-07-18 [15, 30, 60, 120] sym_freq_8 ['BCC']
# 174 2023-07-14 [30, 60, 120] sym_freq_12 []
# 175 2023-07-14 [30, 60, 120] sym_freq_9 []
# 176 2023-07-14 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 177 2023-07-14 [15, 30, 60, 120] sym_freq_12 []
# 178 2023-07-14 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 179 2023-07-14 [15, 30, 60, 120] sym_freq_8 ['BCC']
# 180 2023-07-13 [30, 60, 120] sym_freq_12 []
# 181 2023-07-13 [30, 60, 120] sym_freq_9 []
# 182 2023-07-13 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-13', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 183 2023-07-13 [15, 30, 60, 120] sym_freq_12 []
# 184 2023-07-13 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 185 2023-07-13 [15, 30, 60, 120] sym_freq_8 ['BCC', 'SKYW']
# 186 2023-07-12 [30, 60, 120] sym_freq_12 []
# 187 2023-07-12 [30, 60, 120] sym_freq_9 []
# 188 2023-07-12 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-12', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 189 2023-07-12 [15, 30, 60, 120] sym_freq_12 []
# 190 2023-07-12 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 191 2023-07-12 [15, 30, 60, 120] sym_freq_8 ['BZH', 'SKYW']
# 192 2023-07-11 [30, 60, 120] sym_freq_12 []
# 193 2023-07-11 [30, 60, 120] sym_freq_9 []
# 194 2023-07-11 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-11', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 195 2023-07-11 [15, 30, 60, 120] sym_freq_12 []
# 196 2023-07-11 [15, 30, 60, 120] sym_freq_9 []
# 197 2023-07-11 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 198 2023-07-10 [30, 60, 120] sym_freq_12 []
# 199 2023-07-10 [30, 60, 120] sym_freq_9 []
# 200 2023-07-10 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-10', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 201 2023-07-10 [15, 30, 60, 120] sym_freq_12 []
# 202 2023-07-10 [15, 30, 60, 120] sym_freq_9 []
# 203 2023-07-10 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 204 2023-07-07 [30, 60, 120] sym_freq_12 []
# 205 2023-07-07 [30, 60, 120] sym_freq_9 []
# 206 2023-07-07 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-07', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 207 2023-07-07 [15, 30, 60, 120] sym_freq_12 []
# 208 2023-07-07 [15, 30, 60, 120] sym_freq_9 []
# 209 2023-07-07 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 210 2023-07-06 [30, 60, 120] sym_freq_12 []
# 211 2023-07-06 [30, 60, 120] sym_freq_9 []
# 212 2023-07-06 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-06', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 213 2023-07-06 [15, 30, 60, 120] sym_freq_12 []
# 214 2023-07-06 [15, 30, 60, 120] sym_freq_9 []
# 215 2023-07-06 [15, 30, 60, 120] sym_freq_8 ['CCL', 'SKYW']
# 216 2023-07-05 [30, 60, 120] sym_freq_12 []
# 217 2023-07-05 [30, 60, 120] sym_freq_9 []
# 218 2023-07-05 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-05', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 219 2023-07-05 [15, 30, 60, 120] sym_freq_12 []
# 220 2023-07-05 [15, 30, 60, 120] sym_freq_9 []
# 221 2023-07-05 [15, 30, 60, 120] sym_freq_8 ['CCL']
# 222 2023-07-03 [30, 60, 120] sym_freq_12 []
# 223 2023-07-03 [30, 60, 120] sym_freq_9 []
# 224 2023-07-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 225 2023-07-03 [15, 30, 60, 120] sym_freq_12 []
# 226 2023-07-03 [15, 30, 60, 120] sym_freq_9 []
# 227 2023-07-03 [15, 30, 60, 120] sym_freq_8 ['CCL', 'SKYW', 'W']
# 228 2023-06-30 [30, 60, 120] sym_freq_12 []
# 229 2023-06-30 [30, 60, 120] sym_freq_9 []
# 230 2023-06-30 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-30', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 231 2023-06-30 [15, 30, 60, 120] sym_freq_12 []
# 232 2023-06-30 [15, 30, 60, 120] sym_freq_9 ['SKYW']
# 233 2023-06-30 [15, 30, 60, 120] sym_freq_8 ['CCL']
# 234 2023-06-29 [30, 60, 120] sym_freq_12 []
# 235 2023-06-29 [30, 60, 120] sym_freq_9 []
# 236 2023-06-29 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-29', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 237 2023-06-29 [15, 30, 60, 120] sym_freq_12 []
# 238 2023-06-29 [15, 30, 60, 120] sym_freq_9 []
# 239 2023-06-29 [15, 30, 60, 120] sym_freq_8 []
# 240 2023-06-28 [30, 60, 120] sym_freq_12 []
# 241 2023-06-28 [30, 60, 120] sym_freq_9 []
# 242 2023-06-28 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-28', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 243 2023-06-28 [15, 30, 60, 120] sym_freq_12 []
# 244 2023-06-28 [15, 30, 60, 120] sym_freq_9 []
# 245 2023-06-28 [15, 30, 60, 120] sym_freq_8 []
# 246 2023-06-27 [30, 60, 120] sym_freq_12 []
# 247 2023-06-27 [30, 60, 120] sym_freq_9 []
# 248 2023-06-27 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-27', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 249 2023-06-27 [15, 30, 60, 120] sym_freq_12 []
# 250 2023-06-27 [15, 30, 60, 120] sym_freq_9 []
# 251 2023-06-27 [15, 30, 60, 120] sym_freq_8 []
# 252 2023-06-26 [30, 60, 120] sym_freq_12 []
# 253 2023-06-26 [30, 60, 120] sym_freq_9 []
# 254 2023-06-26 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-26', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 255 2023-06-26 [15, 30, 60, 120] sym_freq_12 []
# 256 2023-06-26 [15, 30, 60, 120] sym_freq_9 []
# 257 2023-06-26 [15, 30, 60, 120] sym_freq_8 []
# 258 2023-06-23 [30, 60, 120] sym_freq_12 []
# 259 2023-06-23 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-23', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 260 2023-06-23 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-23', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 261 2023-06-23 [15, 30, 60, 120] sym_freq_12 []
# 262 2023-06-23 [15, 30, 60, 120] sym_freq_9 ['CCL', 'NVDA']
# 263 2023-06-23 [15, 30, 60, 120] sym_freq_8 ['AMPH']
# 264 2023-06-22 [30, 60, 120] sym_freq_12 []
# 265 2023-06-22 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-22', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 266 2023-06-22 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-22', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 267 2023-06-22 [15, 30, 60, 120] sym_freq_12 []
# 268 2023-06-22 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 269 2023-06-22 [15, 30, 60, 120] sym_freq_8 ['AMPH', 'PBR']
# 270 2023-06-21 [30, 60, 120] sym_freq_12 []
# 271 2023-06-21 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-21', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 272 2023-06-21 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-21', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 273 2023-06-21 [15, 30, 60, 120] sym_freq_12 []
# 274 2023-06-21 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 275 2023-06-21 [15, 30, 60, 120] sym_freq_8 []
# 276 2023-06-20 [30, 60, 120] sym_freq_12 []
# 277 2023-06-20 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-20', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 278 2023-06-20 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-20', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 279 2023-06-20 [15, 30, 60, 120] sym_freq_12 []
# 280 2023-06-20 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 281 2023-06-20 [15, 30, 60, 120] sym_freq_8 []
# 282 2023-06-16 [30, 60, 120] sym_freq_12 []
# 283 2023-06-16 [30, 60, 120] sym_freq_9 []
# 284 2023-06-16 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-16', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 285 2023-06-16 [15, 30, 60, 120] sym_freq_12 []
# 286 2023-06-16 [15, 30, 60, 120] sym_freq_9 ['SKYW']
# 287 2023-06-16 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 288 2023-06-15 [30, 60, 120] sym_freq_12 []
# 289 2023-06-15 [30, 60, 120] sym_freq_9 []
# 290 2023-06-15 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-15', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 291 2023-06-15 [15, 30, 60, 120] sym_freq_12 []
# 292 2023-06-15 [15, 30, 60, 120] sym_freq_9 []
# 293 2023-06-15 [15, 30, 60, 120] sym_freq_8 ['CCL', 'NVDA', 'SKYW']
# 294 2023-06-14 [30, 60, 120] sym_freq_12 []
# 295 2023-06-14 [30, 60, 120] sym_freq_9 []
# 296 2023-06-14 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-14', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA', 'SHV']]
#
# 297 2023-06-14 [15, 30, 60, 120] sym_freq_12 []
# 298 2023-06-14 [15, 30, 60, 120] sym_freq_9 ['AVGO']
# 299 2023-06-14 [15, 30, 60, 120] sym_freq_8 ['ORCL', 'SKYW']
# 300 2023-06-13 [30, 60, 120] sym_freq_12 []
# 301 2023-06-13 [30, 60, 120] sym_freq_9 []
# 302 2023-06-13 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 303 2023-06-13 [15, 30, 60, 120] sym_freq_12 []
# 304 2023-06-13 [15, 30, 60, 120] sym_freq_9 []
# 305 2023-06-13 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 306 2023-06-12 [30, 60, 120] sym_freq_12 []
# 307 2023-06-12 [30, 60, 120] sym_freq_9 []
# 308 2023-06-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 309 2023-06-12 [15, 30, 60, 120] sym_freq_12 []
# 310 2023-06-12 [15, 30, 60, 120] sym_freq_9 []
# 311 2023-06-12 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 312 2023-06-09 [30, 60, 120] sym_freq_12 []
# 313 2023-06-09 [30, 60, 120] sym_freq_9 []
# 314 2023-06-09 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-09', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 315 2023-06-09 [15, 30, 60, 120] sym_freq_12 []
# 316 2023-06-09 [15, 30, 60, 120] sym_freq_9 []
# 317 2023-06-09 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 318 2023-06-08 [30, 60, 120] sym_freq_12 []
# 319 2023-06-08 [30, 60, 120] sym_freq_9 []
# 320 2023-06-08 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-08', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 321 2023-06-08 [15, 30, 60, 120] sym_freq_12 []
# 322 2023-06-08 [15, 30, 60, 120] sym_freq_9 []
# 323 2023-06-08 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 324 2023-06-07 [30, 60, 120] sym_freq_12 []
# 325 2023-06-07 [30, 60, 120] sym_freq_9 []
# 326 2023-06-07 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-07', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 327 2023-06-07 [15, 30, 60, 120] sym_freq_12 []
# 328 2023-06-07 [15, 30, 60, 120] sym_freq_9 []
# 329 2023-06-07 [15, 30, 60, 120] sym_freq_8 []
# 330 2023-06-06 [30, 60, 120] sym_freq_12 []
# 331 2023-06-06 [30, 60, 120] sym_freq_9 []
# 332 2023-06-06 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-06', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 333 2023-06-06 [15, 30, 60, 120] sym_freq_12 []
# 334 2023-06-06 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 335 2023-06-06 [15, 30, 60, 120] sym_freq_8 []
# 336 2023-06-05 [30, 60, 120] sym_freq_12 []
# 337 2023-06-05 [30, 60, 120] sym_freq_9 []
# 338 2023-06-05 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-05', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 339 2023-06-05 [15, 30, 60, 120] sym_freq_12 []
# 340 2023-06-05 [15, 30, 60, 120] sym_freq_9 []
# 341 2023-06-05 [15, 30, 60, 120] sym_freq_8 ['META', 'SKYW']
# 342 2023-06-02 [30, 60, 120] sym_freq_12 []
# 343 2023-06-02 [30, 60, 120] sym_freq_9 []
# 344 2023-06-02 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-02', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 345 2023-06-02 [15, 30, 60, 120] sym_freq_12 []
# 346 2023-06-02 [15, 30, 60, 120] sym_freq_9 ['META']
# 347 2023-06-02 [15, 30, 60, 120] sym_freq_8 []
# 348 2023-06-01 [30, 60, 120] sym_freq_12 []
# 349 2023-06-01 [30, 60, 120] sym_freq_9 []
# 350 2023-06-01 [30, 60, 120] sym_freq_8 ['META', 'NVDA']
# added row to df_model_top_picks:
# ['2023-06-01', [30, 60, 120], 'sym_freq_8', ['META', 'NVDA']]
#
# 351 2023-06-01 [15, 30, 60, 120] sym_freq_12 []
# 352 2023-06-01 [15, 30, 60, 120] sym_freq_9 ['AVGO', 'RMBS']
# 353 2023-06-01 [15, 30, 60, 120] sym_freq_8 []
# 354 2023-05-31 [30, 60, 120] sym_freq_12 []
# 355 2023-05-31 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-31', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 356 2023-05-31 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-31', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA']]
#
# 357 2023-05-31 [15, 30, 60, 120] sym_freq_12 []
# 358 2023-05-31 [15, 30, 60, 120] sym_freq_9 []
# 359 2023-05-31 [15, 30, 60, 120] sym_freq_8 ['RMBS']
# 360 2023-05-30 [30, 60, 120] sym_freq_12 []
# 361 2023-05-30 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 362 2023-05-30 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-30', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA']]
#
# 363 2023-05-30 [15, 30, 60, 120] sym_freq_12 []
# 364 2023-05-30 [15, 30, 60, 120] sym_freq_9 []
# 365 2023-05-30 [15, 30, 60, 120] sym_freq_8 []
# 366 2023-05-26 [30, 60, 120] sym_freq_12 []
# 367 2023-05-26 [30, 60, 120] sym_freq_9 ['AVGO', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-26', [30, 60, 120], 'sym_freq_9', ['AVGO', 'SHV']]
#
# 368 2023-05-26 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-05-26', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 369 2023-05-26 [15, 30, 60, 120] sym_freq_12 ['AVGO']
# added row to df_model_top_picks:
# ['2023-05-26', [15, 30, 60, 120], 'sym_freq_12', ['AVGO']]
#
# 370 2023-05-26 [15, 30, 60, 120] sym_freq_9 ['RMBS']
# 371 2023-05-26 [15, 30, 60, 120] sym_freq_8 ['AMD']
# 372 2023-05-25 [30, 60, 120] sym_freq_12 []
# 373 2023-05-25 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-25', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 374 2023-05-25 [30, 60, 120] sym_freq_8 ['FTSM', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-25', [30, 60, 120], 'sym_freq_8', ['FTSM', 'NVDA']]
#
# 375 2023-05-25 [15, 30, 60, 120] sym_freq_12 []
# 376 2023-05-25 [15, 30, 60, 120] sym_freq_9 []
# 377 2023-05-25 [15, 30, 60, 120] sym_freq_8 ['FTSM']
# 378 2023-05-24 [30, 60, 120] sym_freq_12 []
# 379 2023-05-24 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-24', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 380 2023-05-24 [30, 60, 120] sym_freq_8 []
# 381 2023-05-24 [15, 30, 60, 120] sym_freq_12 []
# 382 2023-05-24 [15, 30, 60, 120] sym_freq_9 []
# 383 2023-05-24 [15, 30, 60, 120] sym_freq_8 []
# 384 2023-05-23 [30, 60, 120] sym_freq_12 []
# 385 2023-05-23 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 386 2023-05-23 [30, 60, 120] sym_freq_8 []
# 387 2023-05-23 [15, 30, 60, 120] sym_freq_12 []
# 388 2023-05-23 [15, 30, 60, 120] sym_freq_9 []
# 389 2023-05-23 [15, 30, 60, 120] sym_freq_8 []
# 390 2023-05-22 [30, 60, 120] sym_freq_12 []
# 391 2023-05-22 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 392 2023-05-22 [30, 60, 120] sym_freq_8 []
# 393 2023-05-22 [15, 30, 60, 120] sym_freq_12 []
# 394 2023-05-22 [15, 30, 60, 120] sym_freq_9 []
# 395 2023-05-22 [15, 30, 60, 120] sym_freq_8 []
# 396 2023-05-19 [30, 60, 120] sym_freq_12 []
# 397 2023-05-19 [30, 60, 120] sym_freq_9 []
# 398 2023-05-19 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 399 2023-05-19 [15, 30, 60, 120] sym_freq_12 []
# 400 2023-05-19 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 401 2023-05-19 [15, 30, 60, 120] sym_freq_8 []
# 402 2023-05-18 [30, 60, 120] sym_freq_12 []
# 403 2023-05-18 [30, 60, 120] sym_freq_9 []
# 404 2023-05-18 [30, 60, 120] sym_freq_8 ['SHV', 'TMHC']
# added row to df_model_top_picks:
# ['2023-05-18', [30, 60, 120], 'sym_freq_8', ['SHV', 'TMHC']]
#
# 405 2023-05-18 [15, 30, 60, 120] sym_freq_12 []
# 406 2023-05-18 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 407 2023-05-18 [15, 30, 60, 120] sym_freq_8 ['TMHC']
# 408 2023-05-17 [30, 60, 120] sym_freq_12 []
# 409 2023-05-17 [30, 60, 120] sym_freq_9 []
# 410 2023-05-17 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-17', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 411 2023-05-17 [15, 30, 60, 120] sym_freq_12 []
# 412 2023-05-17 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 413 2023-05-17 [15, 30, 60, 120] sym_freq_8 []
# 414 2023-05-16 [30, 60, 120] sym_freq_12 []
# 415 2023-05-16 [30, 60, 120] sym_freq_9 []
# 416 2023-05-16 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-16', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 417 2023-05-16 [15, 30, 60, 120] sym_freq_12 []
# 418 2023-05-16 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 419 2023-05-16 [15, 30, 60, 120] sym_freq_8 []
# 420 2023-05-15 [30, 60, 120] sym_freq_12 []
# 421 2023-05-15 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 422 2023-05-15 [30, 60, 120] sym_freq_8 []
# 423 2023-05-15 [15, 30, 60, 120] sym_freq_12 []
# 424 2023-05-15 [15, 30, 60, 120] sym_freq_9 []
# 425 2023-05-15 [15, 30, 60, 120] sym_freq_8 ['ISEE']
# 426 2023-05-12 [30, 60, 120] sym_freq_12 []
# 427 2023-05-12 [30, 60, 120] sym_freq_9 []
# 428 2023-05-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 429 2023-05-12 [15, 30, 60, 120] sym_freq_12 []
# 430 2023-05-12 [15, 30, 60, 120] sym_freq_9 ['ISEE', 'SHV']
# 431 2023-05-12 [15, 30, 60, 120] sym_freq_8 []
# 432 2023-05-11 [30, 60, 120] sym_freq_12 []
# 433 2023-05-11 [30, 60, 120] sym_freq_9 []
# 434 2023-05-11 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-11', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 435 2023-05-11 [15, 30, 60, 120] sym_freq_12 []
# 436 2023-05-11 [15, 30, 60, 120] sym_freq_9 ['BLDR']
# 437 2023-05-11 [15, 30, 60, 120] sym_freq_8 []
# 438 2023-05-10 [30, 60, 120] sym_freq_12 []
# 439 2023-05-10 [30, 60, 120] sym_freq_9 []
# 440 2023-05-10 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-10', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 441 2023-05-10 [15, 30, 60, 120] sym_freq_12 []
# 442 2023-05-10 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 443 2023-05-10 [15, 30, 60, 120] sym_freq_8 ['BLDR']
# 444 2023-05-09 [30, 60, 120] sym_freq_12 []
# 445 2023-05-09 [30, 60, 120] sym_freq_9 []
# 446 2023-05-09 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-09', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 447 2023-05-09 [15, 30, 60, 120] sym_freq_12 []
# 448 2023-05-09 [15, 30, 60, 120] sym_freq_9 ['BLDR']
# 449 2023-05-09 [15, 30, 60, 120] sym_freq_8 []
# 450 2023-05-08 [30, 60, 120] sym_freq_12 []
# 451 2023-05-08 [30, 60, 120] sym_freq_9 []
# 452 2023-05-08 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-08', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 453 2023-05-08 [15, 30, 60, 120] sym_freq_12 []
# 454 2023-05-08 [15, 30, 60, 120] sym_freq_9 []
# 455 2023-05-08 [15, 30, 60, 120] sym_freq_8 []
# 456 2023-05-05 [30, 60, 120] sym_freq_12 []
# 457 2023-05-05 [30, 60, 120] sym_freq_9 []
# 458 2023-05-05 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-05', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 459 2023-05-05 [15, 30, 60, 120] sym_freq_12 []
# 460 2023-05-05 [15, 30, 60, 120] sym_freq_9 []
# 461 2023-05-05 [15, 30, 60, 120] sym_freq_8 []
# 462 2023-05-04 [30, 60, 120] sym_freq_12 []
# 463 2023-05-04 [30, 60, 120] sym_freq_9 []
# 464 2023-05-04 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 465 2023-05-04 [15, 30, 60, 120] sym_freq_12 []
# 466 2023-05-04 [15, 30, 60, 120] sym_freq_9 ['CCEP']
# 467 2023-05-04 [15, 30, 60, 120] sym_freq_8 []
# 468 2023-05-03 [30, 60, 120] sym_freq_12 []
# 469 2023-05-03 [30, 60, 120] sym_freq_9 []
# 470 2023-05-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 471 2023-05-03 [15, 30, 60, 120] sym_freq_12 []
# 472 2023-05-03 [15, 30, 60, 120] sym_freq_9 ['ISEE']
# 473 2023-05-03 [15, 30, 60, 120] sym_freq_8 ['CCEP', 'SHV', 'SKYW']
# 474 2023-05-02 [30, 60, 120] sym_freq_12 []
# 475 2023-05-02 [30, 60, 120] sym_freq_9 []
# 476 2023-05-02 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 477 2023-05-02 [15, 30, 60, 120] sym_freq_12 []
# 478 2023-05-02 [15, 30, 60, 120] sym_freq_9 ['CCEP', 'ISEE', 'SHV']
# 479 2023-05-02 [15, 30, 60, 120] sym_freq_8 []
# 480 2023-05-01 [30, 60, 120] sym_freq_12 []
# 481 2023-05-01 [30, 60, 120] sym_freq_9 []
# 482 2023-05-01 [30, 60, 120] sym_freq_8 []
# 483 2023-05-01 [15, 30, 60, 120] sym_freq_12 []
# 484 2023-05-01 [15, 30, 60, 120] sym_freq_9 []
# 485 2023-05-01 [15, 30, 60, 120] sym_freq_8 ['ISEE']
# 486 2023-04-28 [30, 60, 120] sym_freq_12 []
# 487 2023-04-28 [30, 60, 120] sym_freq_9 []
# 488 2023-04-28 [30, 60, 120] sym_freq_8 []
# 489 2023-04-28 [15, 30, 60, 120] sym_freq_12 []
# 490 2023-04-28 [15, 30, 60, 120] sym_freq_9 []
# 491 2023-04-28 [15, 30, 60, 120] sym_freq_8 ['PHM', 'SHV']
# 492 2023-04-27 [30, 60, 120] sym_freq_12 []
# 493 2023-04-27 [30, 60, 120] sym_freq_9 []
# 494 2023-04-27 [30, 60, 120] sym_freq_8 []
# 495 2023-04-27 [15, 30, 60, 120] sym_freq_12 []
# 496 2023-04-27 [15, 30, 60, 120] sym_freq_9 []
# 497 2023-04-27 [15, 30, 60, 120] sym_freq_8 ['PHM', 'SHV']
# 498 2023-04-26 [30, 60, 120] sym_freq_12 []
# 499 2023-04-26 [30, 60, 120] sym_freq_9 []
# 500 2023-04-26 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-26', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 501 2023-04-26 [15, 30, 60, 120] sym_freq_12 []
# 502 2023-04-26 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 503 2023-04-26 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 504 2023-04-25 [30, 60, 120] sym_freq_12 []
# 505 2023-04-25 [30, 60, 120] sym_freq_9 []
# 506 2023-04-25 [30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-25', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 507 2023-04-25 [15, 30, 60, 120] sym_freq_12 []
# 508 2023-04-25 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 509 2023-04-25 [15, 30, 60, 120] sym_freq_8 ['ELF']
# 510 2023-04-24 [30, 60, 120] sym_freq_12 []
# 511 2023-04-24 [30, 60, 120] sym_freq_9 []
# 512 2023-04-24 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-24', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 513 2023-04-24 [15, 30, 60, 120] sym_freq_12 []
# 514 2023-04-24 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 515 2023-04-24 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 516 2023-04-21 [30, 60, 120] sym_freq_12 []
# 517 2023-04-21 [30, 60, 120] sym_freq_9 []
# 518 2023-04-21 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-21', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 519 2023-04-21 [15, 30, 60, 120] sym_freq_12 []
# 520 2023-04-21 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 521 2023-04-21 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 522 2023-04-20 [30, 60, 120] sym_freq_12 []
# 523 2023-04-20 [30, 60, 120] sym_freq_9 []
# 524 2023-04-20 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-20', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 525 2023-04-20 [15, 30, 60, 120] sym_freq_12 []
# 526 2023-04-20 [15, 30, 60, 120] sym_freq_9 []
# 527 2023-04-20 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 528 2023-04-19 [30, 60, 120] sym_freq_12 []
# 529 2023-04-19 [30, 60, 120] sym_freq_9 []
# 530 2023-04-19 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 531 2023-04-19 [15, 30, 60, 120] sym_freq_12 []
# 532 2023-04-19 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 533 2023-04-19 [15, 30, 60, 120] sym_freq_8 []
# 534 2023-04-18 [30, 60, 120] sym_freq_12 []
# 535 2023-04-18 [30, 60, 120] sym_freq_9 []
# 536 2023-04-18 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 537 2023-04-18 [15, 30, 60, 120] sym_freq_12 []
# 538 2023-04-18 [15, 30, 60, 120] sym_freq_9 []
# 539 2023-04-18 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 540 2023-04-17 [30, 60, 120] sym_freq_12 []
# 541 2023-04-17 [30, 60, 120] sym_freq_9 []
# 542 2023-04-17 [30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-17', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 543 2023-04-17 [15, 30, 60, 120] sym_freq_12 []
# 544 2023-04-17 [15, 30, 60, 120] sym_freq_9 []
# 545 2023-04-17 [15, 30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# 546 2023-04-14 [30, 60, 120] sym_freq_12 []
# 547 2023-04-14 [30, 60, 120] sym_freq_9 []
# 548 2023-04-14 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 549 2023-04-14 [15, 30, 60, 120] sym_freq_12 []
# 550 2023-04-14 [15, 30, 60, 120] sym_freq_9 []
# 551 2023-04-14 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 552 2023-04-13 [30, 60, 120] sym_freq_12 []
# 553 2023-04-13 [30, 60, 120] sym_freq_9 []
# 554 2023-04-13 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 555 2023-04-13 [15, 30, 60, 120] sym_freq_12 []
# 556 2023-04-13 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 557 2023-04-13 [15, 30, 60, 120] sym_freq_8 []
# 558 2023-04-12 [30, 60, 120] sym_freq_12 []
# 559 2023-04-12 [30, 60, 120] sym_freq_9 []
# 560 2023-04-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 561 2023-04-12 [15, 30, 60, 120] sym_freq_12 []
# 562 2023-04-12 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 563 2023-04-12 [15, 30, 60, 120] sym_freq_8 []
# 564 2023-04-11 [30, 60, 120] sym_freq_12 []
# 565 2023-04-11 [30, 60, 120] sym_freq_9 []
# 566 2023-04-11 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-11', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 567 2023-04-11 [15, 30, 60, 120] sym_freq_12 []
# 568 2023-04-11 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 569 2023-04-11 [15, 30, 60, 120] sym_freq_8 []
# 570 2023-04-10 [30, 60, 120] sym_freq_12 []
# 571 2023-04-10 [30, 60, 120] sym_freq_9 []
# 572 2023-04-10 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-10', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 573 2023-04-10 [15, 30, 60, 120] sym_freq_12 []
# 574 2023-04-10 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 575 2023-04-10 [15, 30, 60, 120] sym_freq_8 []
# 576 2023-04-06 [30, 60, 120] sym_freq_12 []
# 577 2023-04-06 [30, 60, 120] sym_freq_9 []
# 578 2023-04-06 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-06', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 579 2023-04-06 [15, 30, 60, 120] sym_freq_12 []
# 580 2023-04-06 [15, 30, 60, 120] sym_freq_9 []
# 581 2023-04-06 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 582 2023-04-05 [30, 60, 120] sym_freq_12 []
# 583 2023-04-05 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 584 2023-04-05 [30, 60, 120] sym_freq_8 []
# 585 2023-04-05 [15, 30, 60, 120] sym_freq_12 []
# 586 2023-04-05 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 587 2023-04-05 [15, 30, 60, 120] sym_freq_8 []
# 588 2023-04-04 [30, 60, 120] sym_freq_12 []
# 589 2023-04-04 [30, 60, 120] sym_freq_9 []
# 590 2023-04-04 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-04', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 591 2023-04-04 [15, 30, 60, 120] sym_freq_12 []
# 592 2023-04-04 [15, 30, 60, 120] sym_freq_9 []
# 593 2023-04-04 [15, 30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# 594 2023-04-03 [30, 60, 120] sym_freq_12 []
# 595 2023-04-03 [30, 60, 120] sym_freq_9 []
# 596 2023-04-03 [30, 60, 120] sym_freq_8 ['GE', 'NVDA']
# added row to df_model_top_picks:
# ['2023-04-03', [30, 60, 120], 'sym_freq_8', ['GE', 'NVDA']]
#
# 597 2023-04-03 [15, 30, 60, 120] sym_freq_12 []
# 598 2023-04-03 [15, 30, 60, 120] sym_freq_9 []
# 599 2023-04-03 [15, 30, 60, 120] sym_freq_8 ['GE', 'PERI']
# 600 2023-03-31 [30, 60, 120] sym_freq_12 []
# 601 2023-03-31 [30, 60, 120] sym_freq_9 []
# 602 2023-03-31 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-03-31', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 603 2023-03-31 [15, 30, 60, 120] sym_freq_12 []
# 604 2023-03-31 [15, 30, 60, 120] sym_freq_9 []
# 605 2023-03-31 [15, 30, 60, 120] sym_freq_8 []
# 606 2023-03-30 [30, 60, 120] sym_freq_12 []
# 607 2023-03-30 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 608 2023-03-30 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 609 2023-03-30 [15, 30, 60, 120] sym_freq_12 []
# 610 2023-03-30 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 611 2023-03-30 [15, 30, 60, 120] sym_freq_8 []
# 612 2023-03-29 [30, 60, 120] sym_freq_12 []
# 613 2023-03-29 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-29', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 614 2023-03-29 [30, 60, 120] sym_freq_8 []
# 615 2023-03-29 [15, 30, 60, 120] sym_freq_12 []
# 616 2023-03-29 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 617 2023-03-29 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 618 2023-03-28 [30, 60, 120] sym_freq_12 []
# 619 2023-03-28 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-28', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 620 2023-03-28 [30, 60, 120] sym_freq_8 []
# 621 2023-03-28 [15, 30, 60, 120] sym_freq_12 []
# 622 2023-03-28 [15, 30, 60, 120] sym_freq_9 []
# 623 2023-03-28 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 624 2023-03-27 [30, 60, 120] sym_freq_12 []
# 625 2023-03-27 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 626 2023-03-27 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 627 2023-03-27 [15, 30, 60, 120] sym_freq_12 []
# 628 2023-03-27 [15, 30, 60, 120] sym_freq_9 []
# 629 2023-03-27 [15, 30, 60, 120] sym_freq_8 ['GE', 'NVDA', 'SGEN']
# 630 2023-03-24 [30, 60, 120] sym_freq_12 []
# 631 2023-03-24 [30, 60, 120] sym_freq_9 []
# 632 2023-03-24 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-24', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 633 2023-03-24 [15, 30, 60, 120] sym_freq_12 []
# 634 2023-03-24 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 635 2023-03-24 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 636 2023-03-23 [30, 60, 120] sym_freq_12 []
# 637 2023-03-23 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 638 2023-03-23 [30, 60, 120] sym_freq_8 []
# 639 2023-03-23 [15, 30, 60, 120] sym_freq_12 []
# 640 2023-03-23 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 641 2023-03-23 [15, 30, 60, 120] sym_freq_8 ['FTSM', 'GE']
# 642 2023-03-22 [30, 60, 120] sym_freq_12 []
# 643 2023-03-22 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 644 2023-03-22 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 645 2023-03-22 [15, 30, 60, 120] sym_freq_12 []
# 646 2023-03-22 [15, 30, 60, 120] sym_freq_9 ['FTSM', 'NVDA']
# 647 2023-03-22 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 648 2023-03-21 [30, 60, 120] sym_freq_12 []
# 649 2023-03-21 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 650 2023-03-21 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 651 2023-03-21 [15, 30, 60, 120] sym_freq_12 []
# 652 2023-03-21 [15, 30, 60, 120] sym_freq_9 ['GE']
# 653 2023-03-21 [15, 30, 60, 120] sym_freq_8 []
# 654 2023-03-20 [30, 60, 120] sym_freq_12 []
# 655 2023-03-20 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 656 2023-03-20 [30, 60, 120] sym_freq_8 []
# 657 2023-03-20 [15, 30, 60, 120] sym_freq_12 []
# 658 2023-03-20 [15, 30, 60, 120] sym_freq_9 []
# 659 2023-03-20 [15, 30, 60, 120] sym_freq_8 []
# 660 2023-03-17 [30, 60, 120] sym_freq_12 []
# 661 2023-03-17 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 662 2023-03-17 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 663 2023-03-17 [15, 30, 60, 120] sym_freq_12 []
# 664 2023-03-17 [15, 30, 60, 120] sym_freq_9 ['FTSM', 'GE']
# 665 2023-03-17 [15, 30, 60, 120] sym_freq_8 []
# 666 2023-03-16 [30, 60, 120] sym_freq_12 []
# 667 2023-03-16 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-16', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 668 2023-03-16 [30, 60, 120] sym_freq_8 []
# 669 2023-03-16 [15, 30, 60, 120] sym_freq_12 []
# 670 2023-03-16 [15, 30, 60, 120] sym_freq_9 ['SGEN']
# 671 2023-03-16 [15, 30, 60, 120] sym_freq_8 []
# 672 2023-03-15 [30, 60, 120] sym_freq_12 []
# 673 2023-03-15 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 674 2023-03-15 [30, 60, 120] sym_freq_8 []
# 675 2023-03-15 [15, 30, 60, 120] sym_freq_12 []
# 676 2023-03-15 [15, 30, 60, 120] sym_freq_9 ['SGEN']
# 677 2023-03-15 [15, 30, 60, 120] sym_freq_8 ['AMPH', 'FCN']

# %%
df_model_top_picks = df_model_top_picks.astype(str)
df_model_top_picks = df_model_top_picks.drop_duplicates(keep='last')
df_model_top_picks = df_model_top_picks.sort_values(by=['date', 'days_lookback', 'syms_freq'], ascending=False)
df_model_top_picks = df_model_top_picks.reset_index(drop=True)
pickle_dump(df_model_top_picks, path_data_dump, fp_df_model_top_picks)
print(f'len(df_model_top_picks): {len(df_model_top_picks)}')
print(f'{fp_df_model_top_picks}:\n{df_model_top_picks}')
# Out:
# len(df_model_top_picks): 140
# df_model_top_picks:
#            date  days_lookback   syms_freq           symbols
# 0    2023-09-18  [30, 60, 120]  sym_freq_9           ['SHV']
# 1    2023-09-18  [30, 60, 120]  sym_freq_8          ['FTSM']
# 2    2023-09-15  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']
# 3    2023-09-14  [30, 60, 120]  sym_freq_9           ['SHV']
# 4    2023-09-14  [30, 60, 120]  sym_freq_8  ['DELL', 'FTSM']
# ..          ...            ...         ...               ...
# 135  2023-03-20  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']
# 136  2023-03-17  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']
# 137  2023-03-17  [30, 60, 120]  sym_freq_8            ['GE']
# 138  2023-03-16  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']
# 139  2023-03-15  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']
#
# [140 rows x 4 columns]

# %%
df_mp = df_model_top_picks.copy()
df_close = pickle_load(path_data_dump, 'df_close_clean')

# %%
def get_NYSE_date_n(date, dates_NYSE, n, verbose=False):

  if date in dates_NYSE:
    idx_last = len(dates_NYSE) - 1  # last index of dates_NYSE
    idx_date = dates_NYSE.get_loc(date)  # index of date
    idx_date_n = idx_date + n  # index of date_n
    if verbose:
      print(f"date: {date} is in dates_NYSE,  date's position in dates_NYSE is: {idx_date} of {idx_last},  n: {n},  idx_date_n: {idx_date_n},")
    if 0 <= idx_date_n <= idx_last:  # idx_date_n is within bounds of dates_NYSE
      date_n = dates_NYSE[idx_date_n]
      if verbose:      
        print(f'idx_date_n: {idx_date_n} is wiithin bounds of dates_NYSE ("0 to {idx_last}), date_n: {date_n}"\n')
    else:  # idx_date_n is out-of-bounds of dates_NYSE
      date_n = None   
      if verbose:  
        print(f'idx_date_n: {idx_date_n} is out-of-bounds of dates_NYSE ("0 to {idx_last})"\n')
  else:  # date not in dates_NYSE
      date_n = None  
      if verbose:  
        print(f'date: {date} is not in dates_NYSE\n')

  return date_n

# %%
def get_portf_buy(df_close, date, str_symbols, portf_target, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    sym_cnt = len(l_syms)  # number of symbols
    amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
    ar_sym_share = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
    ar_sym_amt = ar_price * ar_sym_share  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_sym_amt)  # total actual portfolio value
    if verbose:
        # print(date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value)    
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_sym_share = }, {ar_sym_amt = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value

# %%
def get_SPY_buy(df_close, date, portf_target, symbol="SPY", verbose=False):   
    import numpy as np
    price = df_close.loc[date][symbol]    
    share = np.floor(portf_target / price)  # array of shares for each symbol
    value = price * share  # array of actual dollar amount invested in each symbol
    if verbose:
        # print(date, symbol, price, share, value)
        print(f'{date = }, {symbol = }, {price = }, {share = }, {value = }')                        
        print(f'{date} {symbol} {value = }')
    return date, price, share, value

# %%
import pandas_market_calendars as mcal
nyse = mcal.get_calendar('NYSE')
dates_NYSE_2013_2023 = nyse.valid_days(start_date='2013-01-01', end_date='2023-12-31').strftime('%Y-%m-%d')
print(f'len(dates_NYSE_2013_2023): {len(dates_NYSE_2013_2023)}')
print(f'dates_NYSE_2013_2023[0]:  {dates_NYSE_2013_2023[0]}, dates_NYSE_2013_2023[-1]: {dates_NYSE_2013_2023[-1]}')
print(f'{dates_NYSE_2013_2023}')
# Out:
# len(dates_NYSE_2013_2023): 2768
# dates_NYSE_2013_2023[0]:  2013-01-02, dates_NYSE_2013_2023[-1]: 2023-12-29
# Index(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-07', '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-14', '2013-01-15',
#        ...
#        '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20', '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29'], dtype='object', length=2768)

# %% [markdown]
# #### TODO: 2023-07-15 only evaluate performance of df_model_picks, after evaluation, append results to df_model_picks_results
#
#
# #### 2023-07-11 got KeyError: "['ISEE'] not in index". ISEE was in past model picks, but since then ISEE was acquired. The symbol was dropped from df_close_clean. Current program recalculate the performance of all the past picks. Rewrite program such that performance of past picks with win records are not recalculated.

# %%
import numpy as np
# from ast import literal_eval
z_date_syms = zip(df_mp.date, df_mp.symbols)

idx_close = df_close.index.strftime('%Y-%m-%d')

n = 1  # n=1 is the buy date
# n = 4  # n=4 is the sell date

date_buy = []  # buy date of portfolio
shares_syms = []  # lists of shares of each symbol brought on date_buy
value_portf = [] # list of porfolio value on date_buy
shares_SPY = []  # list of shares of SPY brought on date_buy
value_SPY = []  # list of value of SPY shares on date_buy 
for date, syms in z_date_syms:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=verbose)

    if next_date_n in idx_close:
        close_date_n = next_date_n
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is in df_close')
        print(f'picks for {date}: {syms}')      
    else:
        close_date_n = None
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is not in df_close')
        print(f'picks for {date}: {syms}')        

    if close_date_n is None:
        p_date = None
        p_l_syms = None
        p_ar_price = None
        p_ar_sym_share = None
        p_ar_sym_amt = None
        p_portf_value = None  # data not available in df_close
        
        s_date = None
        s_price = None
        s_share = None
        s_value = None  # data not available in df_close

        date_buy.append(p_date)
        shares_syms.append(p_l_syms)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)    
        
        print(f"No data for next_date_n {next_date_n}, pick's portf value = None")
        print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else:    
        p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
            get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
        s_date, s_price, s_share, s_value = \
            get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
                
        date_buy.append(p_date)
        shares_syms.append(p_ar_sym_share)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)

        print(f"next_date_n pick's portf value = {p_portf_value}")
        print(f'next_date_n SPY portf value =    {s_value}')

    print('='*20, '\n')
# Out:
# date: 2023-09-18 is in dates_NYSE,  date's position in dates_NYSE is: 2695 of 2767,  n: 1,  idx_date_n: 2696,
# idx_date_n: 2696 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-19"
#
# date: 2023-09-18,  n: 1,  next_date_n: 2023-09-19 is not in df_close
# picks for 2023-09-18: ['SHV']
# No data for next_date_n 2023-09-19, pick's portf value = None
# No data for next_date_n 2023-09-19, SPY portf value =    None
# ====================
#
# date: 2023-09-18 is in dates_NYSE,  date's position in dates_NYSE is: 2695 of 2767,  n: 1,  idx_date_n: 2696,
# idx_date_n: 2696 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-19"
#
# date: 2023-09-18,  n: 1,  next_date_n: 2023-09-19 is not in df_close
# picks for 2023-09-18: ['FTSM']
# No data for next_date_n 2023-09-19, pick's portf value = None
# No data for next_date_n 2023-09-19, SPY portf value =    None
# ====================
#
# date: 2023-09-15 is in dates_NYSE,  date's position in dates_NYSE is: 2694 of 2767,  n: 1,  idx_date_n: 2695,
# idx_date_n: 2695 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-18"
#
# date: 2023-09-15,  n: 1,  next_date_n: 2023-09-18 is in df_close
# picks for 2023-09-15: ['FTSM', 'SHV']
# date = '2023-09-18', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.56999969, 110.29000092]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([476.55999756, 441.16000366]), portf_value = 917.7200012207031
# 2023-09-18 portf_value = 917.7200012207031
# date = '2023-09-18', symbol = 'SPY', price = 443.6300048828125, share = 2.0, value = 887.260009765625
# 2023-09-18 SPY value = 887.260009765625
# next_date_n pick's portf value = 917.7200012207031
# next_date_n SPY portf value =    887.260009765625
# ====================
#
# date: 2023-09-14 is in dates_NYSE,  date's position in dates_NYSE is: 2693 of 2767,  n: 1,  idx_date_n: 2694,
# idx_date_n: 2694 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-15"
#
# date: 2023-09-14,  n: 1,  next_date_n: 2023-09-15 is in df_close
# picks for 2023-09-14: ['SHV']
# date = '2023-09-15', l_syms = ['SHV'], ar_price = array([110.26999664]), ar_sym_share = array([9.]), ar_sym_amt = array([992.42996979]), portf_value = 992.4299697875977
# 2023-09-15 portf_value = 992.4299697875977
# date = '2023-09-15', symbol = 'SPY', price = 443.3699951171875, share = 2.0, value = 886.739990234375
# 2023-09-15 SPY value = 886.739990234375
# next_date_n pick's portf value = 992.4299697875977
# next_date_n SPY portf value =    886.739990234375
# ====================
#
# date: 2023-09-14 is in dates_NYSE,  date's position in dates_NYSE is: 2693 of 2767,  n: 1,  idx_date_n: 2694,
# idx_date_n: 2694 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-15"
#
# date: 2023-09-14,  n: 1,  next_date_n: 2023-09-15 is in df_close
# picks for 2023-09-14: ['DELL', 'FTSM']
# date = '2023-09-15', l_syms = ['DELL', 'FTSM'], ar_price = array([69.29000092, 59.56000137]), ar_sym_share = array([7., 8.]), ar_sym_amt = array([485.03000641, 476.48001099]), portf_value = 961.5100173950195
# 2023-09-15 portf_value = 961.5100173950195
# date = '2023-09-15', symbol = 'SPY', price = 443.3699951171875, share = 2.0, value = 886.739990234375
# 2023-09-15 SPY value = 886.739990234375
# next_date_n pick's portf value = 961.5100173950195
# next_date_n SPY portf value =    886.739990234375
# ====================
#
# date: 2023-09-13 is in dates_NYSE,  date's position in dates_NYSE is: 2692 of 2767,  n: 1,  idx_date_n: 2693,
# idx_date_n: 2693 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-14"
#
# date: 2023-09-13,  n: 1,  next_date_n: 2023-09-14 is in df_close
# picks for 2023-09-13: ['FTSM', 'SHV']
# date = '2023-09-14', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.54999924, 110.26000214]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([476.3999939 , 441.04000854]), portf_value = 917.4400024414062
# 2023-09-14 portf_value = 917.4400024414062
# date = '2023-09-14', symbol = 'SPY', price = 448.7770080566406, share = 2.0, value = 897.5540161132812
# 2023-09-14 SPY value = 897.5540161132812
# next_date_n pick's portf value = 917.4400024414062
# next_date_n SPY portf value =    897.5540161132812
# ====================
#
# date: 2023-09-13 is in dates_NYSE,  date's position in dates_NYSE is: 2692 of 2767,  n: 1,  idx_date_n: 2693,
# idx_date_n: 2693 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-14"
#
# date: 2023-09-13,  n: 1,  next_date_n: 2023-09-14 is in df_close
# picks for 2023-09-13: ['DELL']
# date = '2023-09-14', l_syms = ['DELL'], ar_price = array([71.16000366]), ar_sym_share = array([14.]), ar_sym_amt = array([996.24005127]), portf_value = 996.2400512695312
# 2023-09-14 portf_value = 996.2400512695312
# date = '2023-09-14', symbol = 'SPY', price = 448.7770080566406, share = 2.0, value = 897.5540161132812
# 2023-09-14 SPY value = 897.5540161132812
# next_date_n pick's portf value = 996.2400512695312
# next_date_n SPY portf value =    897.5540161132812
# ====================
#
# date: 2023-09-12 is in dates_NYSE,  date's position in dates_NYSE is: 2691 of 2767,  n: 1,  idx_date_n: 2692,
# idx_date_n: 2692 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-13"
#
# date: 2023-09-12,  n: 1,  next_date_n: 2023-09-13 is in df_close
# picks for 2023-09-12: ['FTSM', 'SHV']
# date = '2023-09-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.55500031, 110.20999908]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([476.44000244, 440.83999634]), portf_value = 917.2799987792969
# 2023-09-13 portf_value = 917.2799987792969
# date = '2023-09-13', symbol = 'SPY', price = 444.9405517578125, share = 2.0, value = 889.881103515625
# 2023-09-13 SPY value = 889.881103515625
# next_date_n pick's portf value = 917.2799987792969
# next_date_n SPY portf value =    889.881103515625
# ====================
#
# date: 2023-09-12 is in dates_NYSE,  date's position in dates_NYSE is: 2691 of 2767,  n: 1,  idx_date_n: 2692,
# idx_date_n: 2692 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-13"
#
# date: 2023-09-12,  n: 1,  next_date_n: 2023-09-13 is in df_close
# picks for 2023-09-12: ['DELL', 'MMYT']
# date = '2023-09-13', l_syms = ['DELL', 'MMYT'], ar_price = array([70.44999695, 39.54999924]), ar_sym_share = array([ 7., 12.]), ar_sym_amt = array([493.14997864, 474.59999084]), portf_value = 967.7499694824219
# 2023-09-13 portf_value = 967.7499694824219
# date = '2023-09-13', symbol = 'SPY', price = 444.9405517578125, share = 2.0, value = 889.881103515625
# 2023-09-13 SPY value = 889.881103515625
# next_date_n pick's portf value = 967.7499694824219
# next_date_n SPY portf value =    889.881103515625
# ====================
#
# date: 2023-09-11 is in dates_NYSE,  date's position in dates_NYSE is: 2690 of 2767,  n: 1,  idx_date_n: 2691,
# idx_date_n: 2691 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-12"
#
# date: 2023-09-11,  n: 1,  next_date_n: 2023-09-12 is in df_close
# picks for 2023-09-11: ['DELL', 'FTSM', 'SHV']
# date = '2023-09-12', l_syms = ['DELL', 'FTSM', 'SHV'], ar_price = array([ 70.73000336,  59.52999878, 110.19000244]), ar_sym_share = array([4., 5., 3.]), ar_sym_amt = array([282.92001343, 297.6499939 , 330.57000732]), portf_value = 911.1400146484375
# 2023-09-12 portf_value = 911.1400146484375
# date = '2023-09-12', symbol = 'SPY', price = 444.42236328125, share = 2.0, value = 888.8447265625
# 2023-09-12 SPY value = 888.8447265625
# next_date_n pick's portf value = 911.1400146484375
# next_date_n SPY portf value =    888.8447265625
# ====================
#
# date: 2023-09-11 is in dates_NYSE,  date's position in dates_NYSE is: 2690 of 2767,  n: 1,  idx_date_n: 2691,
# idx_date_n: 2691 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-12"
#
# date: 2023-09-11,  n: 1,  next_date_n: 2023-09-12 is in df_close
# picks for 2023-09-11: ['DELL']
# date = '2023-09-12', l_syms = ['DELL'], ar_price = array([70.73000336]), ar_sym_share = array([14.]), ar_sym_amt = array([990.220047]), portf_value = 990.2200469970703
# 2023-09-12 portf_value = 990.2200469970703
# date = '2023-09-12', symbol = 'SPY', price = 444.42236328125, share = 2.0, value = 888.8447265625
# 2023-09-12 SPY value = 888.8447265625
# next_date_n pick's portf value = 990.2200469970703
# next_date_n SPY portf value =    888.8447265625
# ====================
#
# date: 2023-09-08 is in dates_NYSE,  date's position in dates_NYSE is: 2689 of 2767,  n: 1,  idx_date_n: 2690,
# idx_date_n: 2690 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-11"
#
# date: 2023-09-08,  n: 1,  next_date_n: 2023-09-11 is in df_close
# picks for 2023-09-08: ['FTSM', 'SHV']
# date = '2023-09-11', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.52999878, 110.18000031]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([476.23999023, 440.72000122]), portf_value = 916.9599914550781
# 2023-09-11 portf_value = 916.9599914550781
# date = '2023-09-11', symbol = 'SPY', price = 446.8737487792969, share = 2.0, value = 893.7474975585938
# 2023-09-11 SPY value = 893.7474975585938
# next_date_n pick's portf value = 916.9599914550781
# next_date_n SPY portf value =    893.7474975585938
# ====================
#
# date: 2023-09-08 is in dates_NYSE,  date's position in dates_NYSE is: 2689 of 2767,  n: 1,  idx_date_n: 2690,
# idx_date_n: 2690 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-11"
#
# date: 2023-09-08,  n: 1,  next_date_n: 2023-09-11 is in df_close
# picks for 2023-09-08: ['DELL', 'STRL']
# date = '2023-09-11', l_syms = ['DELL', 'STRL'], ar_price = array([72.16000366, 77.43000031]), ar_sym_share = array([6., 6.]), ar_sym_amt = array([432.96002197, 464.58000183]), portf_value = 897.5400238037109
# 2023-09-11 portf_value = 897.5400238037109
# date = '2023-09-11', symbol = 'SPY', price = 446.8737487792969, share = 2.0, value = 893.7474975585938
# 2023-09-11 SPY value = 893.7474975585938
# next_date_n pick's portf value = 897.5400238037109
# next_date_n SPY portf value =    893.7474975585938
# ====================
#
# date: 2023-09-05 is in dates_NYSE,  date's position in dates_NYSE is: 2686 of 2767,  n: 1,  idx_date_n: 2687,
# idx_date_n: 2687 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-06"
#
# date: 2023-09-05,  n: 1,  next_date_n: 2023-09-06 is in df_close
# picks for 2023-09-05: ['SHV']
# date = '2023-09-06', l_syms = ['SHV'], ar_price = array([110.08999634]), ar_sym_share = array([9.]), ar_sym_amt = array([990.80996704]), portf_value = 990.8099670410156
# 2023-09-06 portf_value = 990.8099670410156
# date = '2023-09-06', symbol = 'SPY', price = 444.65155029296875, share = 2.0, value = 889.3031005859375
# 2023-09-06 SPY value = 889.3031005859375
# next_date_n pick's portf value = 990.8099670410156
# next_date_n SPY portf value =    889.3031005859375
# ====================
#
# date: 2023-09-05 is in dates_NYSE,  date's position in dates_NYSE is: 2686 of 2767,  n: 1,  idx_date_n: 2687,
# idx_date_n: 2687 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-06"
#
# date: 2023-09-05,  n: 1,  next_date_n: 2023-09-06 is in df_close
# picks for 2023-09-05: ['FTSM']
# date = '2023-09-06', l_syms = ['FTSM'], ar_price = array([59.49000168]), ar_sym_share = array([16.]), ar_sym_amt = array([951.84002686]), portf_value = 951.8400268554688
# 2023-09-06 portf_value = 951.8400268554688
# date = '2023-09-06', symbol = 'SPY', price = 444.65155029296875, share = 2.0, value = 889.3031005859375
# 2023-09-06 SPY value = 889.3031005859375
# next_date_n pick's portf value = 951.8400268554688
# next_date_n SPY portf value =    889.3031005859375
# ====================
#
# date: 2023-09-01 is in dates_NYSE,  date's position in dates_NYSE is: 2685 of 2767,  n: 1,  idx_date_n: 2686,
# idx_date_n: 2686 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-05"
#
# date: 2023-09-01,  n: 1,  next_date_n: 2023-09-05 is in df_close
# picks for 2023-09-01: ['SHV']
# date = '2023-09-05', l_syms = ['SHV'], ar_price = array([110.06999969]), ar_sym_share = array([9.]), ar_sym_amt = array([990.62999725]), portf_value = 990.629997253418
# 2023-09-05 portf_value = 990.629997253418
# date = '2023-09-05', symbol = 'SPY', price = 447.66094970703125, share = 2.0, value = 895.3218994140625
# 2023-09-05 SPY value = 895.3218994140625
# next_date_n pick's portf value = 990.629997253418
# next_date_n SPY portf value =    895.3218994140625
# ====================
#
# date: 2023-09-01 is in dates_NYSE,  date's position in dates_NYSE is: 2685 of 2767,  n: 1,  idx_date_n: 2686,
# idx_date_n: 2686 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-05"
#
# date: 2023-09-01,  n: 1,  next_date_n: 2023-09-05 is in df_close
# picks for 2023-09-01: ['FTSM', 'STRL']
# date = '2023-09-05', l_syms = ['FTSM', 'STRL'], ar_price = array([59.47999954, 80.54000092]), ar_sym_share = array([8., 6.]), ar_sym_amt = array([475.83999634, 483.24000549]), portf_value = 959.0800018310547
# 2023-09-05 portf_value = 959.0800018310547
# date = '2023-09-05', symbol = 'SPY', price = 447.66094970703125, share = 2.0, value = 895.3218994140625
# 2023-09-05 SPY value = 895.3218994140625
# next_date_n pick's portf value = 959.0800018310547
# next_date_n SPY portf value =    895.3218994140625
# ====================
#
# date: 2023-08-25 is in dates_NYSE,  date's position in dates_NYSE is: 2680 of 2767,  n: 1,  idx_date_n: 2681,
# idx_date_n: 2681 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-28"
#
# date: 2023-08-25,  n: 1,  next_date_n: 2023-08-28 is in df_close
# picks for 2023-08-25: ['SHV']
# date = '2023-08-28', l_syms = ['SHV'], ar_price = array([109.93941498]), ar_sym_share = array([9.]), ar_sym_amt = array([989.4547348]), portf_value = 989.4547348022461
# 2023-08-28 portf_value = 989.4547348022461
# date = '2023-08-28', symbol = 'SPY', price = 441.2037353515625, share = 2.0, value = 882.407470703125
# 2023-08-28 SPY value = 882.407470703125
# next_date_n pick's portf value = 989.4547348022461
# next_date_n SPY portf value =    882.407470703125
# ====================
#
# date: 2023-08-25 is in dates_NYSE,  date's position in dates_NYSE is: 2680 of 2767,  n: 1,  idx_date_n: 2681,
# idx_date_n: 2681 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-28"
#
# date: 2023-08-25,  n: 1,  next_date_n: 2023-08-28 is in df_close
# picks for 2023-08-25: ['STRL']
# date = '2023-08-28', l_syms = ['STRL'], ar_price = array([79.16000366]), ar_sym_share = array([12.]), ar_sym_amt = array([949.92004395]), portf_value = 949.9200439453125
# 2023-08-28 portf_value = 949.9200439453125
# date = '2023-08-28', symbol = 'SPY', price = 441.2037353515625, share = 2.0, value = 882.407470703125
# 2023-08-28 SPY value = 882.407470703125
# next_date_n pick's portf value = 949.9200439453125
# next_date_n SPY portf value =    882.407470703125
# ====================
#
# date: 2023-08-25 is in dates_NYSE,  date's position in dates_NYSE is: 2680 of 2767,  n: 1,  idx_date_n: 2681,
# idx_date_n: 2681 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-28"
#
# date: 2023-08-25,  n: 1,  next_date_n: 2023-08-28 is in df_close
# picks for 2023-08-25: ['SHV']
# date = '2023-08-28', l_syms = ['SHV'], ar_price = array([109.93941498]), ar_sym_share = array([9.]), ar_sym_amt = array([989.4547348]), portf_value = 989.4547348022461
# 2023-08-28 portf_value = 989.4547348022461
# date = '2023-08-28', symbol = 'SPY', price = 441.2037353515625, share = 2.0, value = 882.407470703125
# 2023-08-28 SPY value = 882.407470703125
# next_date_n pick's portf value = 989.4547348022461
# next_date_n SPY portf value =    882.407470703125
# ====================
#
# date: 2023-08-18 is in dates_NYSE,  date's position in dates_NYSE is: 2675 of 2767,  n: 1,  idx_date_n: 2676,
# idx_date_n: 2676 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-21"
#
# date: 2023-08-18,  n: 1,  next_date_n: 2023-08-21 is in df_close
# picks for 2023-08-18: ['SHV']
# date = '2023-08-21', l_syms = ['SHV'], ar_price = array([109.83983612]), ar_sym_share = array([9.]), ar_sym_amt = array([988.55852509]), portf_value = 988.5585250854492
# 2023-08-21 portf_value = 988.5585250854492
# date = '2023-08-21', symbol = 'SPY', price = 437.7957458496094, share = 2.0, value = 875.5914916992188
# 2023-08-21 SPY value = 875.5914916992188
# next_date_n pick's portf value = 988.5585250854492
# next_date_n SPY portf value =    875.5914916992188
# ====================
#
# date: 2023-08-18 is in dates_NYSE,  date's position in dates_NYSE is: 2675 of 2767,  n: 1,  idx_date_n: 2676,
# idx_date_n: 2676 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-21"
#
# date: 2023-08-18,  n: 1,  next_date_n: 2023-08-21 is in df_close
# picks for 2023-08-18: ['FTSM']
# date = '2023-08-21', l_syms = ['FTSM'], ar_price = array([59.35337067]), ar_sym_share = array([16.]), ar_sym_amt = array([949.65393066]), portf_value = 949.6539306640625
# 2023-08-21 portf_value = 949.6539306640625
# date = '2023-08-21', symbol = 'SPY', price = 437.7957458496094, share = 2.0, value = 875.5914916992188
# 2023-08-21 SPY value = 875.5914916992188
# next_date_n pick's portf value = 949.6539306640625
# next_date_n SPY portf value =    875.5914916992188
# ====================
#
# date: 2023-08-18 is in dates_NYSE,  date's position in dates_NYSE is: 2675 of 2767,  n: 1,  idx_date_n: 2676,
# idx_date_n: 2676 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-21"
#
# date: 2023-08-18,  n: 1,  next_date_n: 2023-08-21 is in df_close
# picks for 2023-08-18: ['SHV']
# date = '2023-08-21', l_syms = ['SHV'], ar_price = array([109.83983612]), ar_sym_share = array([9.]), ar_sym_amt = array([988.55852509]), portf_value = 988.5585250854492
# 2023-08-21 portf_value = 988.5585250854492
# date = '2023-08-21', symbol = 'SPY', price = 437.7957458496094, share = 2.0, value = 875.5914916992188
# 2023-08-21 SPY value = 875.5914916992188
# next_date_n pick's portf value = 988.5585250854492
# next_date_n SPY portf value =    875.5914916992188
# ====================
#
# date: 2023-08-17 is in dates_NYSE,  date's position in dates_NYSE is: 2674 of 2767,  n: 1,  idx_date_n: 2675,
# idx_date_n: 2675 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-18"
#
# date: 2023-08-17,  n: 1,  next_date_n: 2023-08-18 is in df_close
# picks for 2023-08-17: ['SHV']
# date = '2023-08-18', l_syms = ['SHV'], ar_price = array([109.82987213]), ar_sym_share = array([9.]), ar_sym_amt = array([988.46884918]), portf_value = 988.4688491821289
# 2023-08-18 portf_value = 988.4688491821289
# date = '2023-08-18', symbol = 'SPY', price = 434.9657287597656, share = 2.0, value = 869.9314575195312
# 2023-08-18 SPY value = 869.9314575195312
# next_date_n pick's portf value = 988.4688491821289
# next_date_n SPY portf value =    869.9314575195312
# ====================
#
# date: 2023-08-17 is in dates_NYSE,  date's position in dates_NYSE is: 2674 of 2767,  n: 1,  idx_date_n: 2675,
# idx_date_n: 2675 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-18"
#
# date: 2023-08-17,  n: 1,  next_date_n: 2023-08-18 is in df_close
# picks for 2023-08-17: ['FTSM']
# date = '2023-08-18', l_syms = ['FTSM'], ar_price = array([59.34341431]), ar_sym_share = array([16.]), ar_sym_amt = array([949.49462891]), portf_value = 949.49462890625
# 2023-08-18 portf_value = 949.49462890625
# date = '2023-08-18', symbol = 'SPY', price = 434.9657287597656, share = 2.0, value = 869.9314575195312
# 2023-08-18 SPY value = 869.9314575195312
# next_date_n pick's portf value = 949.49462890625
# next_date_n SPY portf value =    869.9314575195312
# ====================
#
# date: 2023-08-17 is in dates_NYSE,  date's position in dates_NYSE is: 2674 of 2767,  n: 1,  idx_date_n: 2675,
# idx_date_n: 2675 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-18"
#
# date: 2023-08-17,  n: 1,  next_date_n: 2023-08-18 is in df_close
# picks for 2023-08-17: ['SHV']
# date = '2023-08-18', l_syms = ['SHV'], ar_price = array([109.82987213]), ar_sym_share = array([9.]), ar_sym_amt = array([988.46884918]), portf_value = 988.4688491821289
# 2023-08-18 portf_value = 988.4688491821289
# date = '2023-08-18', symbol = 'SPY', price = 434.9657287597656, share = 2.0, value = 869.9314575195312
# 2023-08-18 SPY value = 869.9314575195312
# next_date_n pick's portf value = 988.4688491821289
# next_date_n SPY portf value =    869.9314575195312
# ====================
#
# date: 2023-08-15 is in dates_NYSE,  date's position in dates_NYSE is: 2672 of 2767,  n: 1,  idx_date_n: 2673,
# idx_date_n: 2673 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-16"
#
# date: 2023-08-15,  n: 1,  next_date_n: 2023-08-16 is in df_close
# picks for 2023-08-15: ['SHV']
# date = '2023-08-16', l_syms = ['SHV'], ar_price = array([109.77012634]), ar_sym_share = array([9.]), ar_sym_amt = array([987.93113708]), portf_value = 987.9311370849609
# 2023-08-16 portf_value = 987.9311370849609
# date = '2023-08-16', symbol = 'SPY', price = 438.0946960449219, share = 2.0, value = 876.1893920898438
# 2023-08-16 SPY value = 876.1893920898438
# next_date_n pick's portf value = 987.9311370849609
# next_date_n SPY portf value =    876.1893920898438
# ====================
#
# date: 2023-08-15 is in dates_NYSE,  date's position in dates_NYSE is: 2672 of 2767,  n: 1,  idx_date_n: 2673,
# idx_date_n: 2673 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-16"
#
# date: 2023-08-15,  n: 1,  next_date_n: 2023-08-16 is in df_close
# picks for 2023-08-15: ['STRL']
# date = '2023-08-16', l_syms = ['STRL'], ar_price = array([80.48999786]), ar_sym_share = array([12.]), ar_sym_amt = array([965.87997437]), portf_value = 965.8799743652344
# 2023-08-16 portf_value = 965.8799743652344
# date = '2023-08-16', symbol = 'SPY', price = 438.0946960449219, share = 2.0, value = 876.1893920898438
# 2023-08-16 SPY value = 876.1893920898438
# next_date_n pick's portf value = 965.8799743652344
# next_date_n SPY portf value =    876.1893920898438
# ====================
#
# date: 2023-08-15 is in dates_NYSE,  date's position in dates_NYSE is: 2672 of 2767,  n: 1,  idx_date_n: 2673,
# idx_date_n: 2673 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-16"
#
# date: 2023-08-15,  n: 1,  next_date_n: 2023-08-16 is in df_close
# picks for 2023-08-15: ['SHV']
# date = '2023-08-16', l_syms = ['SHV'], ar_price = array([109.77012634]), ar_sym_share = array([9.]), ar_sym_amt = array([987.93113708]), portf_value = 987.9311370849609
# 2023-08-16 portf_value = 987.9311370849609
# date = '2023-08-16', symbol = 'SPY', price = 438.0946960449219, share = 2.0, value = 876.1893920898438
# 2023-08-16 SPY value = 876.1893920898438
# next_date_n pick's portf value = 987.9311370849609
# next_date_n SPY portf value =    876.1893920898438
# ====================
#
# date: 2023-08-14 is in dates_NYSE,  date's position in dates_NYSE is: 2671 of 2767,  n: 1,  idx_date_n: 2672,
# idx_date_n: 2672 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-15"
#
# date: 2023-08-14,  n: 1,  next_date_n: 2023-08-15 is in df_close
# picks for 2023-08-14: ['SHV']
# date = '2023-08-15', l_syms = ['SHV'], ar_price = array([109.76016998]), ar_sym_share = array([9.]), ar_sym_amt = array([987.84152985]), portf_value = 987.8415298461914
# 2023-08-15 portf_value = 987.8415298461914
# date = '2023-08-15', symbol = 'SPY', price = 441.3332824707031, share = 2.0, value = 882.6665649414062
# 2023-08-15 SPY value = 882.6665649414062
# next_date_n pick's portf value = 987.8415298461914
# next_date_n SPY portf value =    882.6665649414062
# ====================
#
# date: 2023-08-11 is in dates_NYSE,  date's position in dates_NYSE is: 2670 of 2767,  n: 1,  idx_date_n: 2671,
# idx_date_n: 2671 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-14"
#
# date: 2023-08-11,  n: 1,  next_date_n: 2023-08-14 is in df_close
# picks for 2023-08-11: ['SHV', 'STRL']
# date = '2023-08-14', l_syms = ['SHV', 'STRL'], ar_price = array([109.74024963,  80.13999939]), ar_sym_share = array([4., 6.]), ar_sym_amt = array([438.96099854, 480.83999634]), portf_value = 919.8009948730469
# 2023-08-14 portf_value = 919.8009948730469
# date = '2023-08-14', symbol = 'SPY', price = 446.534912109375, share = 2.0, value = 893.06982421875
# 2023-08-14 SPY value = 893.06982421875
# next_date_n pick's portf value = 919.8009948730469
# next_date_n SPY portf value =    893.06982421875
# ====================
#
# date: 2023-08-10 is in dates_NYSE,  date's position in dates_NYSE is: 2669 of 2767,  n: 1,  idx_date_n: 2670,
# idx_date_n: 2670 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-11"
#
# date: 2023-08-10,  n: 1,  next_date_n: 2023-08-11 is in df_close
# picks for 2023-08-10: ['SHV', 'STRL']
# date = '2023-08-11', l_syms = ['SHV', 'STRL'], ar_price = array([109.72032928,  80.79000092]), ar_sym_share = array([4., 6.]), ar_sym_amt = array([438.88131714, 484.74000549]), portf_value = 923.6213226318359
# 2023-08-11 portf_value = 923.6213226318359
# date = '2023-08-11', symbol = 'SPY', price = 444.08355712890625, share = 2.0, value = 888.1671142578125
# 2023-08-11 SPY value = 888.1671142578125
# next_date_n pick's portf value = 923.6213226318359
# next_date_n SPY portf value =    888.1671142578125
# ====================
#
# date: 2023-08-09 is in dates_NYSE,  date's position in dates_NYSE is: 2668 of 2767,  n: 1,  idx_date_n: 2669,
# idx_date_n: 2669 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-10"
#
# date: 2023-08-09,  n: 1,  next_date_n: 2023-08-10 is in df_close
# picks for 2023-08-09: ['SHV', 'STRL']
# date = '2023-08-10', l_syms = ['SHV', 'STRL'], ar_price = array([109.70041656,  79.88999939]), ar_sym_share = array([4., 6.]), ar_sym_amt = array([438.80166626, 479.33999634]), portf_value = 918.1416625976562
# 2023-08-10 portf_value = 918.1416625976562
# date = '2023-08-10', symbol = 'SPY', price = 444.3426513671875, share = 2.0, value = 888.685302734375
# 2023-08-10 SPY value = 888.685302734375
# next_date_n pick's portf value = 918.1416625976562
# next_date_n SPY portf value =    888.685302734375
# ====================
#
# date: 2023-08-08 is in dates_NYSE,  date's position in dates_NYSE is: 2667 of 2767,  n: 1,  idx_date_n: 2668,
# idx_date_n: 2668 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-09"
#
# date: 2023-08-08,  n: 1,  next_date_n: 2023-08-09 is in df_close
# picks for 2023-08-08: ['SHV', 'STRL']
# date = '2023-08-09', l_syms = ['SHV', 'STRL'], ar_price = array([109.65062714,  78.34999847]), ar_sym_share = array([4., 6.]), ar_sym_amt = array([438.60250854, 470.09999084]), portf_value = 908.7024993896484
# 2023-08-09 portf_value = 908.7024993896484
# date = '2023-08-09', symbol = 'SPY', price = 444.1832275390625, share = 2.0, value = 888.366455078125
# 2023-08-09 SPY value = 888.366455078125
# next_date_n pick's portf value = 908.7024993896484
# next_date_n SPY portf value =    888.366455078125
# ====================
#
# date: 2023-08-07 is in dates_NYSE,  date's position in dates_NYSE is: 2666 of 2767,  n: 1,  idx_date_n: 2667,
# idx_date_n: 2667 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-08"
#
# date: 2023-08-07,  n: 1,  next_date_n: 2023-08-08 is in df_close
# picks for 2023-08-07: ['SHV']
# date = '2023-08-08', l_syms = ['SHV'], ar_price = array([109.64066315]), ar_sym_share = array([9.]), ar_sym_amt = array([986.76596832]), portf_value = 986.7659683227539
# 2023-08-08 portf_value = 986.7659683227539
# date = '2023-08-08', symbol = 'SPY', price = 447.17266845703125, share = 2.0, value = 894.3453369140625
# 2023-08-08 SPY value = 894.3453369140625
# next_date_n pick's portf value = 986.7659683227539
# next_date_n SPY portf value =    894.3453369140625
# ====================
#
# date: 2023-08-04 is in dates_NYSE,  date's position in dates_NYSE is: 2665 of 2767,  n: 1,  idx_date_n: 2666,
# idx_date_n: 2666 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-07"
#
# date: 2023-08-04,  n: 1,  next_date_n: 2023-08-07 is in df_close
# picks for 2023-08-04: ['SHV']
# date = '2023-08-07', l_syms = ['SHV'], ar_price = array([109.62075043]), ar_sym_share = array([9.]), ar_sym_amt = array([986.58675385]), portf_value = 986.5867538452148
# 2023-08-07 portf_value = 986.5867538452148
# date = '2023-08-07', symbol = 'SPY', price = 449.1257629394531, share = 2.0, value = 898.2515258789062
# 2023-08-07 SPY value = 898.2515258789062
# next_date_n pick's portf value = 986.5867538452148
# next_date_n SPY portf value =    898.2515258789062
# ====================
#
# date: 2023-08-03 is in dates_NYSE,  date's position in dates_NYSE is: 2664 of 2767,  n: 1,  idx_date_n: 2665,
# idx_date_n: 2665 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-04"
#
# date: 2023-08-03,  n: 1,  next_date_n: 2023-08-04 is in df_close
# picks for 2023-08-03: ['SHV']
# date = '2023-08-04', l_syms = ['SHV'], ar_price = array([109.62075043]), ar_sym_share = array([9.]), ar_sym_amt = array([986.58675385]), portf_value = 986.5867538452148
# 2023-08-04 portf_value = 986.5867538452148
# date = '2023-08-04', symbol = 'SPY', price = 445.2394714355469, share = 2.0, value = 890.4789428710938
# 2023-08-04 SPY value = 890.4789428710938
# next_date_n pick's portf value = 986.5867538452148
# next_date_n SPY portf value =    890.4789428710938
# ====================
#
# date: 2023-08-02 is in dates_NYSE,  date's position in dates_NYSE is: 2663 of 2767,  n: 1,  idx_date_n: 2664,
# idx_date_n: 2664 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-03"
#
# date: 2023-08-02,  n: 1,  next_date_n: 2023-08-03 is in df_close
# picks for 2023-08-02: ['SHV']
# date = '2023-08-03', l_syms = ['SHV'], ar_price = array([109.59088135]), ar_sym_share = array([9.]), ar_sym_amt = array([986.31793213]), portf_value = 986.3179321289062
# 2023-08-03 portf_value = 986.3179321289062
# date = '2023-08-03', symbol = 'SPY', price = 447.2623596191406, share = 2.0, value = 894.5247192382812
# 2023-08-03 SPY value = 894.5247192382812
# next_date_n pick's portf value = 986.3179321289062
# next_date_n SPY portf value =    894.5247192382812
# ====================
#
# date: 2023-07-27 is in dates_NYSE,  date's position in dates_NYSE is: 2659 of 2767,  n: 1,  idx_date_n: 2660,
# idx_date_n: 2660 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-28"
#
# date: 2023-07-27,  n: 1,  next_date_n: 2023-07-28 is in df_close
# picks for 2023-07-27: ['SHV']
# date = '2023-07-28', l_syms = ['SHV'], ar_price = array([109.49436951]), ar_sym_share = array([9.]), ar_sym_amt = array([985.44932556]), portf_value = 985.4493255615234
# 2023-07-28 portf_value = 985.4493255615234
# date = '2023-07-28', symbol = 'SPY', price = 455.31396484375, share = 2.0, value = 910.6279296875
# 2023-07-28 SPY value = 910.6279296875
# next_date_n pick's portf value = 985.4493255615234
# next_date_n SPY portf value =    910.6279296875
# ====================
#
# date: 2023-07-26 is in dates_NYSE,  date's position in dates_NYSE is: 2658 of 2767,  n: 1,  idx_date_n: 2659,
# idx_date_n: 2659 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-27"
#
# date: 2023-07-26,  n: 1,  next_date_n: 2023-07-27 is in df_close
# picks for 2023-07-26: ['SHV']
# date = '2023-07-27', l_syms = ['SHV'], ar_price = array([109.46461487]), ar_sym_share = array([9.]), ar_sym_amt = array([985.18153381]), portf_value = 985.1815338134766
# 2023-07-27 portf_value = 985.1815338134766
# date = '2023-07-27', symbol = 'SPY', price = 450.8995056152344, share = 2.0, value = 901.7990112304688
# 2023-07-27 SPY value = 901.7990112304688
# next_date_n pick's portf value = 985.1815338134766
# next_date_n SPY portf value =    901.7990112304688
# ====================
#
# date: 2023-07-25 is in dates_NYSE,  date's position in dates_NYSE is: 2657 of 2767,  n: 1,  idx_date_n: 2658,
# idx_date_n: 2658 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-26"
#
# date: 2023-07-25,  n: 1,  next_date_n: 2023-07-26 is in df_close
# picks for 2023-07-25: ['SHV']
# date = '2023-07-26', l_syms = ['SHV'], ar_price = array([109.42494965]), ar_sym_share = array([9.]), ar_sym_amt = array([984.82454681]), portf_value = 984.8245468139648
# 2023-07-26 portf_value = 984.8245468139648
# date = '2023-07-26', symbol = 'SPY', price = 453.9089050292969, share = 2.0, value = 907.8178100585938
# 2023-07-26 SPY value = 907.8178100585938
# next_date_n pick's portf value = 984.8245468139648
# next_date_n SPY portf value =    907.8178100585938
# ====================
#
# date: 2023-07-21 is in dates_NYSE,  date's position in dates_NYSE is: 2655 of 2767,  n: 1,  idx_date_n: 2656,
# idx_date_n: 2656 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-24"
#
# date: 2023-07-21,  n: 1,  next_date_n: 2023-07-24 is in df_close
# picks for 2023-07-21: ['SHV']
# date = '2023-07-24', l_syms = ['SHV'], ar_price = array([109.39520264]), ar_sym_share = array([9.]), ar_sym_amt = array([984.55682373]), portf_value = 984.5568237304688
# 2023-07-24 portf_value = 984.5568237304688
# date = '2023-07-24', symbol = 'SPY', price = 452.603515625, share = 2.0, value = 905.20703125
# 2023-07-24 SPY value = 905.20703125
# next_date_n pick's portf value = 984.5568237304688
# next_date_n SPY portf value =    905.20703125
# ====================
#
# date: 2023-07-20 is in dates_NYSE,  date's position in dates_NYSE is: 2654 of 2767,  n: 1,  idx_date_n: 2655,
# idx_date_n: 2655 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-21"
#
# date: 2023-07-20,  n: 1,  next_date_n: 2023-07-21 is in df_close
# picks for 2023-07-20: ['SHV']
# date = '2023-07-21', l_syms = ['SHV'], ar_price = array([109.38528442]), ar_sym_share = array([9.]), ar_sym_amt = array([984.46755981]), portf_value = 984.4675598144531
# 2023-07-21 portf_value = 984.4675598144531
# date = '2023-07-21', symbol = 'SPY', price = 450.5906066894531, share = 2.0, value = 901.1812133789062
# 2023-07-21 SPY value = 901.1812133789062
# next_date_n pick's portf value = 984.4675598144531
# next_date_n SPY portf value =    901.1812133789062
# ====================
#
# date: 2023-07-18 is in dates_NYSE,  date's position in dates_NYSE is: 2652 of 2767,  n: 1,  idx_date_n: 2653,
# idx_date_n: 2653 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-19"
#
# date: 2023-07-18,  n: 1,  next_date_n: 2023-07-19 is in df_close
# picks for 2023-07-18: ['SHV']
# date = '2023-07-19', l_syms = ['SHV'], ar_price = array([109.32579041]), ar_sym_share = array([9.]), ar_sym_amt = array([983.93211365]), portf_value = 983.9321136474609
# 2023-07-19 portf_value = 983.9321136474609
# date = '2023-07-19', symbol = 'SPY', price = 453.6000061035156, share = 2.0, value = 907.2000122070312
# 2023-07-19 SPY value = 907.2000122070312
# next_date_n pick's portf value = 983.9321136474609
# next_date_n SPY portf value =    907.2000122070312
# ====================
#
# date: 2023-07-14 is in dates_NYSE,  date's position in dates_NYSE is: 2650 of 2767,  n: 1,  idx_date_n: 2651,
# idx_date_n: 2651 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-17"
#
# date: 2023-07-14,  n: 1,  next_date_n: 2023-07-17 is in df_close
# picks for 2023-07-14: ['SHV']
# date = '2023-07-17', l_syms = ['SHV'], ar_price = array([109.29603577]), ar_sym_share = array([9.]), ar_sym_amt = array([983.6643219]), portf_value = 983.6643218994141
# 2023-07-17 portf_value = 983.6643218994141
# date = '2023-07-17', symbol = 'SPY', price = 449.25531005859375, share = 2.0, value = 898.5106201171875
# 2023-07-17 SPY value = 898.5106201171875
# next_date_n pick's portf value = 983.6643218994141
# next_date_n SPY portf value =    898.5106201171875
# ====================
#
# date: 2023-07-13 is in dates_NYSE,  date's position in dates_NYSE is: 2649 of 2767,  n: 1,  idx_date_n: 2650,
# idx_date_n: 2650 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-14"
#
# date: 2023-07-13,  n: 1,  next_date_n: 2023-07-14 is in df_close
# picks for 2023-07-13: ['SHV', 'SKYW']
# date = '2023-07-14', l_syms = ['SHV', 'SKYW'], ar_price = array([109.28612518,  40.43000031]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([437.14450073, 485.16000366]), portf_value = 922.3045043945312
# 2023-07-14 portf_value = 922.3045043945312
# date = '2023-07-14', symbol = 'SPY', price = 447.7008056640625, share = 2.0, value = 895.401611328125
# 2023-07-14 SPY value = 895.401611328125
# next_date_n pick's portf value = 922.3045043945312
# next_date_n SPY portf value =    895.401611328125
# ====================
#
# date: 2023-07-12 is in dates_NYSE,  date's position in dates_NYSE is: 2648 of 2767,  n: 1,  idx_date_n: 2649,
# idx_date_n: 2649 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-13"
#
# date: 2023-07-12,  n: 1,  next_date_n: 2023-07-13 is in df_close
# picks for 2023-07-12: ['SHV', 'SKYW']
# date = '2023-07-13', l_syms = ['SHV', 'SKYW'], ar_price = array([109.27620697,  41.47000122]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([437.10482788, 497.64001465]), portf_value = 934.7448425292969
# 2023-07-13 portf_value = 934.7448425292969
# date = '2023-07-13', symbol = 'SPY', price = 447.9798278808594, share = 2.0, value = 895.9596557617188
# 2023-07-13 SPY value = 895.9596557617188
# next_date_n pick's portf value = 934.7448425292969
# next_date_n SPY portf value =    895.9596557617188
# ====================
#
# date: 2023-07-11 is in dates_NYSE,  date's position in dates_NYSE is: 2647 of 2767,  n: 1,  idx_date_n: 2648,
# idx_date_n: 2648 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-12"
#
# date: 2023-07-11,  n: 1,  next_date_n: 2023-07-12 is in df_close
# picks for 2023-07-11: ['SHV', 'SKYW']
# date = '2023-07-12', l_syms = ['SHV', 'SKYW'], ar_price = array([109.21671295,  41.11999893]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([436.86685181, 493.43998718]), portf_value = 930.3068389892578
# 2023-07-12 portf_value = 930.3068389892578
# date = '2023-07-12', symbol = 'SPY', price = 444.4522399902344, share = 2.0, value = 888.9044799804688
# 2023-07-12 SPY value = 888.9044799804688
# next_date_n pick's portf value = 930.3068389892578
# next_date_n SPY portf value =    888.9044799804688
# ====================
#
# date: 2023-07-10 is in dates_NYSE,  date's position in dates_NYSE is: 2646 of 2767,  n: 1,  idx_date_n: 2647,
# idx_date_n: 2647 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-11"
#
# date: 2023-07-10,  n: 1,  next_date_n: 2023-07-11 is in df_close
# picks for 2023-07-10: ['SHV', 'SKYW']
# date = '2023-07-11', l_syms = ['SHV', 'SKYW'], ar_price = array([109.18695831,  41.75      ]), ar_sym_share = array([ 4., 11.]), ar_sym_amt = array([436.74783325, 459.25      ]), portf_value = 895.9978332519531
# 2023-07-11 portf_value = 895.9978332519531
# date = '2023-07-11', symbol = 'SPY', price = 440.9047546386719, share = 2.0, value = 881.8095092773438
# 2023-07-11 SPY value = 881.8095092773438
# next_date_n pick's portf value = 895.9978332519531
# next_date_n SPY portf value =    881.8095092773438
# ====================
#
# date: 2023-07-07 is in dates_NYSE,  date's position in dates_NYSE is: 2645 of 2767,  n: 1,  idx_date_n: 2646,
# idx_date_n: 2646 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-10"
#
# date: 2023-07-07,  n: 1,  next_date_n: 2023-07-10 is in df_close
# picks for 2023-07-07: ['SHV', 'SKYW']
# date = '2023-07-10', l_syms = ['SHV', 'SKYW'], ar_price = array([109.18695831,  42.18999863]), ar_sym_share = array([ 4., 11.]), ar_sym_amt = array([436.74783325, 464.08998489]), portf_value = 900.837818145752
# 2023-07-10 portf_value = 900.837818145752
# date = '2023-07-10', symbol = 'SPY', price = 438.1146240234375, share = 2.0, value = 876.229248046875
# 2023-07-10 SPY value = 876.229248046875
# next_date_n pick's portf value = 900.837818145752
# next_date_n SPY portf value =    876.229248046875
# ====================
#
# date: 2023-07-06 is in dates_NYSE,  date's position in dates_NYSE is: 2644 of 2767,  n: 1,  idx_date_n: 2645,
# idx_date_n: 2645 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-07"
#
# date: 2023-07-06,  n: 1,  next_date_n: 2023-07-07 is in df_close
# picks for 2023-07-06: ['SHV', 'SKYW']
# date = '2023-07-07', l_syms = ['SHV', 'SKYW'], ar_price = array([109.16712189,  40.86000061]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([436.66848755, 490.32000732]), portf_value = 926.9884948730469
# 2023-07-07 portf_value = 926.9884948730469
# date = '2023-07-07', symbol = 'SPY', price = 437.0085144042969, share = 2.0, value = 874.0170288085938
# 2023-07-07 SPY value = 874.0170288085938
# next_date_n pick's portf value = 926.9884948730469
# next_date_n SPY portf value =    874.0170288085938
# ====================
#
# date: 2023-07-05 is in dates_NYSE,  date's position in dates_NYSE is: 2643 of 2767,  n: 1,  idx_date_n: 2644,
# idx_date_n: 2644 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-06"
#
# date: 2023-07-05,  n: 1,  next_date_n: 2023-07-06 is in df_close
# picks for 2023-07-05: ['SHV']
# date = '2023-07-06', l_syms = ['SHV'], ar_price = array([109.16712189]), ar_sym_share = array([9.]), ar_sym_amt = array([982.50409698]), portf_value = 982.5040969848633
# 2023-07-06 portf_value = 982.5040969848633
# date = '2023-07-06', symbol = 'SPY', price = 438.1146240234375, share = 2.0, value = 876.229248046875
# 2023-07-06 SPY value = 876.229248046875
# next_date_n pick's portf value = 982.5040969848633
# next_date_n SPY portf value =    876.229248046875
# ====================
#
# date: 2023-07-03 is in dates_NYSE,  date's position in dates_NYSE is: 2642 of 2767,  n: 1,  idx_date_n: 2643,
# idx_date_n: 2643 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-05"
#
# date: 2023-07-03,  n: 1,  next_date_n: 2023-07-05 is in df_close
# picks for 2023-07-03: ['SHV']
# date = '2023-07-05', l_syms = ['SHV'], ar_price = array([109.1076355]), ar_sym_share = array([9.]), ar_sym_amt = array([981.96871948]), portf_value = 981.9687194824219
# 2023-07-05 portf_value = 981.9687194824219
# date = '2023-07-05', symbol = 'SPY', price = 441.5724182128906, share = 2.0, value = 883.1448364257812
# 2023-07-05 SPY value = 883.1448364257812
# next_date_n pick's portf value = 981.9687194824219
# next_date_n SPY portf value =    883.1448364257812
# ====================
#
# date: 2023-06-30 is in dates_NYSE,  date's position in dates_NYSE is: 2641 of 2767,  n: 1,  idx_date_n: 2642,
# idx_date_n: 2642 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-07-03"
#
# date: 2023-06-30,  n: 1,  next_date_n: 2023-07-03 is in df_close
# picks for 2023-06-30: ['SHV']
# date = '2023-07-03', l_syms = ['SHV'], ar_price = array([109.0878067]), ar_sym_share = array([9.]), ar_sym_amt = array([981.79026031]), portf_value = 981.7902603149414
# 2023-07-03 portf_value = 981.7902603149414
# date = '2023-07-03', symbol = 'SPY', price = 442.2301025390625, share = 2.0, value = 884.460205078125
# 2023-07-03 SPY value = 884.460205078125
# next_date_n pick's portf value = 981.7902603149414
# next_date_n SPY portf value =    884.460205078125
# ====================
#
# date: 2023-06-29 is in dates_NYSE,  date's position in dates_NYSE is: 2640 of 2767,  n: 1,  idx_date_n: 2641,
# idx_date_n: 2641 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-30"
#
# date: 2023-06-29,  n: 1,  next_date_n: 2023-06-30 is in df_close
# picks for 2023-06-29: ['SHV', 'SKYW']
# date = '2023-06-30', l_syms = ['SHV', 'SKYW'], ar_price = array([109.09572601,  40.72000122]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([436.38290405, 488.64001465]), portf_value = 925.0229187011719
# 2023-06-30 portf_value = 925.0229187011719
# date = '2023-06-30', symbol = 'SPY', price = 441.7218933105469, share = 2.0, value = 883.4437866210938
# 2023-06-30 SPY value = 883.4437866210938
# next_date_n pick's portf value = 925.0229187011719
# next_date_n SPY portf value =    883.4437866210938
# ====================
#
# date: 2023-06-28 is in dates_NYSE,  date's position in dates_NYSE is: 2639 of 2767,  n: 1,  idx_date_n: 2640,
# idx_date_n: 2640 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-29"
#
# date: 2023-06-28,  n: 1,  next_date_n: 2023-06-29 is in df_close
# picks for 2023-06-28: ['SHV', 'SKYW']
# date = '2023-06-29', l_syms = ['SHV', 'SKYW'], ar_price = array([109.03647614,  40.38000107]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([436.14590454, 484.56001282]), portf_value = 920.7059173583984
# 2023-06-29 portf_value = 920.7059173583984
# date = '2023-06-29', symbol = 'SPY', price = 436.5700378417969, share = 2.0, value = 873.1400756835938
# 2023-06-29 SPY value = 873.1400756835938
# next_date_n pick's portf value = 920.7059173583984
# next_date_n SPY portf value =    873.1400756835938
# ====================
#
# date: 2023-06-27 is in dates_NYSE,  date's position in dates_NYSE is: 2638 of 2767,  n: 1,  idx_date_n: 2639,
# idx_date_n: 2639 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-28"
#
# date: 2023-06-27,  n: 1,  next_date_n: 2023-06-28 is in df_close
# picks for 2023-06-27: ['SHV', 'SKYW']
# date = '2023-06-28', l_syms = ['SHV', 'SKYW'], ar_price = array([109.01672363,  39.65000153]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([436.06689453, 475.80001831]), portf_value = 911.8669128417969
# 2023-06-28 portf_value = 911.8669128417969
# date = '2023-06-28', symbol = 'SPY', price = 434.85614013671875, share = 2.0, value = 869.7122802734375
# 2023-06-28 SPY value = 869.7122802734375
# next_date_n pick's portf value = 911.8669128417969
# next_date_n SPY portf value =    869.7122802734375
# ====================
#
# date: 2023-06-26 is in dates_NYSE,  date's position in dates_NYSE is: 2637 of 2767,  n: 1,  idx_date_n: 2638,
# idx_date_n: 2638 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-27"
#
# date: 2023-06-26,  n: 1,  next_date_n: 2023-06-27 is in df_close
# picks for 2023-06-26: ['SHV', 'SKYW']
# date = '2023-06-27', l_syms = ['SHV', 'SKYW'], ar_price = array([109.00683594,  39.16999817]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([436.02734375, 470.03997803]), portf_value = 906.0673217773438
# 2023-06-27 portf_value = 906.0673217773438
# date = '2023-06-27', symbol = 'SPY', price = 434.63690185546875, share = 2.0, value = 869.2738037109375
# 2023-06-27 SPY value = 869.2738037109375
# next_date_n pick's portf value = 906.0673217773438
# next_date_n SPY portf value =    869.2738037109375
# ====================
#
# date: 2023-06-23 is in dates_NYSE,  date's position in dates_NYSE is: 2636 of 2767,  n: 1,  idx_date_n: 2637,
# idx_date_n: 2637 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-26"
#
# date: 2023-06-23,  n: 1,  next_date_n: 2023-06-26 is in df_close
# picks for 2023-06-23: ['NVDA']
# date = '2023-06-26', l_syms = ['NVDA'], ar_price = array([406.28652954]), ar_sym_share = array([2.]), ar_sym_amt = array([812.57305908]), portf_value = 812.5730590820312
# 2023-06-26 portf_value = 812.5730590820312
# date = '2023-06-26', symbol = 'SPY', price = 429.92352294921875, share = 2.0, value = 859.8470458984375
# 2023-06-26 SPY value = 859.8470458984375
# next_date_n pick's portf value = 812.5730590820312
# next_date_n SPY portf value =    859.8470458984375
# ====================
#
# date: 2023-06-23 is in dates_NYSE,  date's position in dates_NYSE is: 2636 of 2767,  n: 1,  idx_date_n: 2637,
# idx_date_n: 2637 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-26"
#
# date: 2023-06-23,  n: 1,  next_date_n: 2023-06-26 is in df_close
# picks for 2023-06-23: ['SHV', 'SKYW']
# date = '2023-06-26', l_syms = ['SHV', 'SKYW'], ar_price = array([108.98708344,  38.90999985]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([435.94833374, 466.91999817]), portf_value = 902.8683319091797
# 2023-06-26 portf_value = 902.8683319091797
# date = '2023-06-26', symbol = 'SPY', price = 429.92352294921875, share = 2.0, value = 859.8470458984375
# 2023-06-26 SPY value = 859.8470458984375
# next_date_n pick's portf value = 902.8683319091797
# next_date_n SPY portf value =    859.8470458984375
# ====================
#
# date: 2023-06-22 is in dates_NYSE,  date's position in dates_NYSE is: 2635 of 2767,  n: 1,  idx_date_n: 2636,
# idx_date_n: 2636 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-23"
#
# date: 2023-06-22,  n: 1,  next_date_n: 2023-06-23 is in df_close
# picks for 2023-06-22: ['NVDA']
# date = '2023-06-23', l_syms = ['NVDA'], ar_price = array([422.05523682]), ar_sym_share = array([2.]), ar_sym_amt = array([844.11047363]), portf_value = 844.1104736328125
# 2023-06-23 portf_value = 844.1104736328125
# date = '2023-06-23', symbol = 'SPY', price = 431.6872863769531, share = 2.0, value = 863.3745727539062
# 2023-06-23 SPY value = 863.3745727539062
# next_date_n pick's portf value = 844.1104736328125
# next_date_n SPY portf value =    863.3745727539062
# ====================
#
# date: 2023-06-22 is in dates_NYSE,  date's position in dates_NYSE is: 2635 of 2767,  n: 1,  idx_date_n: 2636,
# idx_date_n: 2636 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-06-23"
#
# date: 2023-06-22,  n: 1,  next_date_n: 2023-06-23 is in df_close
# picks for 2023-06-22: ['SHV', 'SKYW']
# date = '2023-06-23', l_syms = ['SHV', 'SKYW'], ar_price = array([108.96733093,  39.56999969]), ar_sym_share = array([ 4., 12.]), ar_sym_amt = array([435.86932373, 474.83999634]), portf_value = 910.7093200683594
# 2023-06-23 portf_value = 910.7093200683594
# ...
# next_date_n SPY portf value =    829.6806640625
# ====================
#
# date: 2023-05-30 is in dates_NYSE,  date's position in dates_NYSE is: 2619 of 2767,  n: 1,  idx_date_n: 2620,
# idx_date_n: 2620 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-31"
#
# date: 2023-05-30,  n: 1,  next_date_n: 2023-05-31 is in df_close
# picks for 2023-05-30: ['AVGO', 'NVDA']
# date = '2023-05-31', l_syms = ['AVGO', 'NVDA'], ar_price = array([803.67840576, 378.26968384]), ar_sym_share = array([0., 1.]), ar_sym_amt = array([  0.        , 378.26968384]), portf_value = 378.2696838378906
# 2023-05-31 portf_value = 378.2696838378906
# date = '2023-05-31', symbol = 'SPY', price = 414.84033203125, share = 2.0, value = 829.6806640625
# 2023-05-31 SPY value = 829.6806640625
# next_date_n pick's portf value = 378.2696838378906
# next_date_n SPY portf value =    829.6806640625
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['AVGO', 'SHV']
# date = '2023-05-30', l_syms = ['AVGO', 'SHV'], ar_price = array([799.08288574, 108.56047058]), ar_sym_share = array([0., 4.]), ar_sym_amt = array([  0.        , 434.24188232]), portf_value = 434.24188232421875
# 2023-05-30 portf_value = 434.24188232421875
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 434.24188232421875
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['NVDA']
# date = '2023-05-30', l_syms = ['NVDA'], ar_price = array([401.03543091]), ar_sym_share = array([2.]), ar_sym_amt = array([802.07086182]), portf_value = 802.0708618164062
# 2023-05-30 portf_value = 802.0708618164062
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 802.0708618164062
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['AVGO']
# date = '2023-05-30', l_syms = ['AVGO'], ar_price = array([799.08288574]), ar_sym_share = array([1.]), ar_sym_amt = array([799.08288574]), portf_value = 799.0828857421875
# 2023-05-30 portf_value = 799.0828857421875
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 799.0828857421875
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-25 is in dates_NYSE,  date's position in dates_NYSE is: 2617 of 2767,  n: 1,  idx_date_n: 2618,
# idx_date_n: 2618 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-26"
#
# date: 2023-05-25,  n: 1,  next_date_n: 2023-05-26 is in df_close
# picks for 2023-05-25: ['SHV']
# date = '2023-05-26', l_syms = ['SHV'], ar_price = array([108.55062866]), ar_sym_share = array([9.]), ar_sym_amt = array([976.95565796]), portf_value = 976.9556579589844
# 2023-05-26 portf_value = 976.9556579589844
# date = '2023-05-26', symbol = 'SPY', price = 416.9946594238281, share = 2.0, value = 833.9893188476562
# 2023-05-26 SPY value = 833.9893188476562
# next_date_n pick's portf value = 976.9556579589844
# next_date_n SPY portf value =    833.9893188476562
# ====================
#
# date: 2023-05-25 is in dates_NYSE,  date's position in dates_NYSE is: 2617 of 2767,  n: 1,  idx_date_n: 2618,
# idx_date_n: 2618 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-26"
#
# date: 2023-05-25,  n: 1,  next_date_n: 2023-05-26 is in df_close
# picks for 2023-05-25: ['FTSM', 'NVDA']
# date = '2023-05-26', l_syms = ['FTSM', 'NVDA'], ar_price = array([ 58.71099472, 389.38763428]), ar_sym_share = array([8., 1.]), ar_sym_amt = array([469.68795776, 389.38763428]), portf_value = 859.0755920410156
# 2023-05-26 portf_value = 859.0755920410156
# date = '2023-05-26', symbol = 'SPY', price = 416.9946594238281, share = 2.0, value = 833.9893188476562
# 2023-05-26 SPY value = 833.9893188476562
# next_date_n pick's portf value = 859.0755920410156
# next_date_n SPY portf value =    833.9893188476562
# ====================
#
# date: 2023-05-24 is in dates_NYSE,  date's position in dates_NYSE is: 2616 of 2767,  n: 1,  idx_date_n: 2617,
# idx_date_n: 2617 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-25"
#
# date: 2023-05-24,  n: 1,  next_date_n: 2023-05-25 is in df_close
# picks for 2023-05-24: ['SHV']
# date = '2023-05-25', l_syms = ['SHV'], ar_price = array([108.53096771]), ar_sym_share = array([9.]), ar_sym_amt = array([976.77870941]), portf_value = 976.7787094116211
# 2023-05-25 portf_value = 976.7787094116211
# date = '2023-05-25', symbol = 'SPY', price = 411.6633605957031, share = 2.0, value = 823.3267211914062
# 2023-05-25 SPY value = 823.3267211914062
# next_date_n pick's portf value = 976.7787094116211
# next_date_n SPY portf value =    823.3267211914062
# ====================
#
# date: 2023-05-23 is in dates_NYSE,  date's position in dates_NYSE is: 2615 of 2767,  n: 1,  idx_date_n: 2616,
# idx_date_n: 2616 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-24"
#
# date: 2023-05-23,  n: 1,  next_date_n: 2023-05-24 is in df_close
# picks for 2023-05-23: ['SHV']
# date = '2023-05-24', l_syms = ['SHV'], ar_price = array([108.48179626]), ar_sym_share = array([9.]), ar_sym_amt = array([976.33616638]), portf_value = 976.3361663818359
# 2023-05-24 portf_value = 976.3361663818359
# date = '2023-05-24', symbol = 'SPY', price = 408.1289978027344, share = 2.0, value = 816.2579956054688
# 2023-05-24 SPY value = 816.2579956054688
# next_date_n pick's portf value = 976.3361663818359
# next_date_n SPY portf value =    816.2579956054688
# ====================
#
# date: 2023-05-22 is in dates_NYSE,  date's position in dates_NYSE is: 2614 of 2767,  n: 1,  idx_date_n: 2615,
# idx_date_n: 2615 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-23"
#
# date: 2023-05-22,  n: 1,  next_date_n: 2023-05-23 is in df_close
# picks for 2023-05-22: ['SHV']
# date = '2023-05-23', l_syms = ['SHV'], ar_price = array([108.48179626]), ar_sym_share = array([9.]), ar_sym_amt = array([976.33616638]), portf_value = 976.3361663818359
# 2023-05-23 portf_value = 976.3361663818359
# date = '2023-05-23', symbol = 'SPY', price = 411.107421875, share = 2.0, value = 822.21484375
# 2023-05-23 SPY value = 822.21484375
# next_date_n pick's portf value = 976.3361663818359
# next_date_n SPY portf value =    822.21484375
# ====================
#
# date: 2023-05-19 is in dates_NYSE,  date's position in dates_NYSE is: 2613 of 2767,  n: 1,  idx_date_n: 2614,
# idx_date_n: 2614 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-22"
#
# date: 2023-05-19,  n: 1,  next_date_n: 2023-05-22 is in df_close
# picks for 2023-05-19: ['SHV']
# date = '2023-05-22', l_syms = ['SHV'], ar_price = array([108.46212006]), ar_sym_share = array([9.]), ar_sym_amt = array([976.15908051]), portf_value = 976.1590805053711
# 2023-05-22 portf_value = 976.1590805053711
# date = '2023-05-22', symbol = 'SPY', price = 415.7735595703125, share = 2.0, value = 831.547119140625
# 2023-05-22 SPY value = 831.547119140625
# next_date_n pick's portf value = 976.1590805053711
# next_date_n SPY portf value =    831.547119140625
# ====================
#
# date: 2023-05-18 is in dates_NYSE,  date's position in dates_NYSE is: 2612 of 2767,  n: 1,  idx_date_n: 2613,
# idx_date_n: 2613 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-19"
#
# date: 2023-05-18,  n: 1,  next_date_n: 2023-05-19 is in df_close
# picks for 2023-05-18: ['SHV', 'TMHC']
# date = '2023-05-19', l_syms = ['SHV', 'TMHC'], ar_price = array([108.46212006,  44.25      ]), ar_sym_share = array([ 4., 11.]), ar_sym_amt = array([433.84848022, 486.75      ]), portf_value = 920.5984802246094
# 2023-05-19 portf_value = 920.5984802246094
# date = '2023-05-19', symbol = 'SPY', price = 415.6047668457031, share = 2.0, value = 831.2095336914062
# 2023-05-19 SPY value = 831.2095336914062
# next_date_n pick's portf value = 920.5984802246094
# next_date_n SPY portf value =    831.2095336914062
# ====================
#
# date: 2023-05-17 is in dates_NYSE,  date's position in dates_NYSE is: 2611 of 2767,  n: 1,  idx_date_n: 2612,
# idx_date_n: 2612 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-18"
#
# date: 2023-05-17,  n: 1,  next_date_n: 2023-05-18 is in df_close
# picks for 2023-05-17: ['SHV']
# date = '2023-05-18', l_syms = ['SHV'], ar_price = array([108.46212006]), ar_sym_share = array([9.]), ar_sym_amt = array([976.15908051]), portf_value = 976.1590805053711
# 2023-05-18 portf_value = 976.1590805053711
# date = '2023-05-18', symbol = 'SPY', price = 416.21038818359375, share = 2.0, value = 832.4207763671875
# 2023-05-18 SPY value = 832.4207763671875
# next_date_n pick's portf value = 976.1590805053711
# next_date_n SPY portf value =    832.4207763671875
# ====================
#
# date: 2023-05-16 is in dates_NYSE,  date's position in dates_NYSE is: 2610 of 2767,  n: 1,  idx_date_n: 2611,
# idx_date_n: 2611 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-17"
#
# date: 2023-05-16,  n: 1,  next_date_n: 2023-05-17 is in df_close
# picks for 2023-05-16: ['SHV']
# date = '2023-05-17', l_syms = ['SHV'], ar_price = array([108.43262482]), ar_sym_share = array([9.]), ar_sym_amt = array([975.89362335]), portf_value = 975.8936233520508
# 2023-05-17 portf_value = 975.8936233520508
# date = '2023-05-17', symbol = 'SPY', price = 412.23919677734375, share = 2.0, value = 824.4783935546875
# 2023-05-17 SPY value = 824.4783935546875
# next_date_n pick's portf value = 975.8936233520508
# next_date_n SPY portf value =    824.4783935546875
# ====================
#
# date: 2023-05-15 is in dates_NYSE,  date's position in dates_NYSE is: 2609 of 2767,  n: 1,  idx_date_n: 2610,
# idx_date_n: 2610 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-16"
#
# date: 2023-05-15,  n: 1,  next_date_n: 2023-05-16 is in df_close
# picks for 2023-05-15: ['SHV']
# date = '2023-05-16', l_syms = ['SHV'], ar_price = array([108.41294861]), ar_sym_share = array([9.]), ar_sym_amt = array([975.71653748]), portf_value = 975.7165374755859
# 2023-05-16 portf_value = 975.7165374755859
# date = '2023-05-16', symbol = 'SPY', price = 407.2950439453125, share = 2.0, value = 814.590087890625
# 2023-05-16 SPY value = 814.590087890625
# next_date_n pick's portf value = 975.7165374755859
# next_date_n SPY portf value =    814.590087890625
# ====================
#
# date: 2023-05-12 is in dates_NYSE,  date's position in dates_NYSE is: 2608 of 2767,  n: 1,  idx_date_n: 2609,
# idx_date_n: 2609 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-15"
#
# date: 2023-05-12,  n: 1,  next_date_n: 2023-05-15 is in df_close
# picks for 2023-05-12: ['SHV']
# date = '2023-05-15', l_syms = ['SHV'], ar_price = array([108.41294861]), ar_sym_share = array([9.]), ar_sym_amt = array([975.71653748]), portf_value = 975.7165374755859
# 2023-05-15 portf_value = 975.7165374755859
# date = '2023-05-15', symbol = 'SPY', price = 410.03515625, share = 2.0, value = 820.0703125
# 2023-05-15 SPY value = 820.0703125
# next_date_n pick's portf value = 975.7165374755859
# next_date_n SPY portf value =    820.0703125
# ====================
#
# date: 2023-05-11 is in dates_NYSE,  date's position in dates_NYSE is: 2607 of 2767,  n: 1,  idx_date_n: 2608,
# idx_date_n: 2608 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-12"
#
# date: 2023-05-11,  n: 1,  next_date_n: 2023-05-12 is in df_close
# picks for 2023-05-11: ['ISEE', 'SHV']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 51
#      47     print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')
#      49 else:
#      50     p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
# ---> 51         get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
#      52     s_date, s_price, s_share, s_value = \
#      53         get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
#      55     date_buy.append(p_date)
#
# Cell In[12], line 6, in get_portf_buy(df_close, date, str_symbols, portf_target, verbose)
#       4 l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
#       5 # array of closing prices corresponding to symbols in l_syms
# ----> 6 ar_price = df_close.loc[date][l_syms].values
#       7 sym_cnt = len(l_syms)  # number of symbols
#       8 amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     key = np.asarray(key, dtype=bool)
#    1005     return self._get_values(key)
# -> 1007 return self._get_with(key)
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\series.py:1047, in Series._get_with(self, key)
#    1044         return self.iloc[key]
#    1046 # handle the dup indexing case GH#4246
# -> 1047 return self.loc[key]
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1239, in _LocIndexer._getitem_iterable(self, key, axis)
#    1236 self._validate_key(key, axis)
#    1238 # A collection of keys
# -> 1239 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240 return self.obj._reindex_with_indexers(
#    1241     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1242 )
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1429 ax = self.obj._get_axis(axis)
#    1430 axis_name = self.obj._get_axis_name(axis)
# -> 1432 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434 return keyarr, indexer
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['ISEE'] not in index"

# %% [markdown]
# #### Below cells calculate past performance of model picks

# %%
def calc_portf_shares(df_close, date, str_symbols, portf_target):
  # calculate number of shares to buy for symbols in str_symbols to meet port_target
  import numpy as np
  from ast import literal_eval    
  l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
  # array of closing prices corresponding to symbols in l_syms    
  ar_price = df_close.loc[date][l_syms].values  
  sym_cnt = len(l_syms)  # number of symbols
  amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
  ar_shares = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
  return ar_shares

# %%
def calc_portf_value(df_close, date, str_symbols, ar_shares, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    ar_value = ar_price * ar_shares  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_value)  # total actual portfolio value
    if verbose:
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_shares = }, {ar_value = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_shares, ar_value, portf_value

# %%
def get_next_date_n(df_close, date, n=1):

    """Get the next n(default=1) date from df_close. date has to in df_close.index.

    Edge case: The function won't return the first date in df_close as the
    next trading date, if date is a trading date just before the first date in df_close.
    """

    len_df_close = len(df_close)
    idx_dates = df_close.index.strftime('%Y-%m-%d')  # date index of df_close    

    if date in idx_dates:
        idx_next_date = idx_dates.get_loc(date) + n  # get index position of next date
        print(f'n: {n},  idx_next_date: {idx_next_date}')

        if idx_next_date >= 0:  # if idx_nex_date is negative, stop index loop back from index[0] to index[-1]    
            if idx_next_date >= (len_df_close - n):  # next date's index is within bound of df_close
                next_date = idx_dates[idx_dates.get_loc(date) + n]  # get the next date
                return next_date
        
              
            else:  # idx_next_date is out-of_bounds df_close
                print(f"{date} is the last date in df_close. No data for next {n} day")
                return None    
        
        
        else:  # idx_next_date is negative, no data in df_close
            # no data from df_close
            print(f'idx_next_date: {idx_next_date} is negative, no data for {n} days from {date} in df_close')

    else:     
        # no data from df_close
        print(f'no data for {date} in df_close')
        return None

# %%
def is_date_in_close(date, df_close):
  idx_close = df_close.index.strftime('%Y-%m-%d')
  if date in idx_close:
    return date
  else:
    return None

# %%
def calc_portf_value_date_buy(my_dates, my_symbols, df_close, portf_target, n, verbose=False):
  
  z_date_syms = zip(my_dates, my_symbols)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, syms in z_date_syms:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date = None
      p_ar_shares = None
      p_portf_value = None  # set to None when data are not available in df_close
      SPY_shares = None
      SPY_value = None  # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        print(f'No data for close_date_n {close_date_n}, SPY portf value =    None')

    else:    
      p_ar_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      p_date, l_syms, ar_price, ar_shares, ar_value, p_portf_value = \
        calc_portf_value(df_close, close_date_n, syms, p_ar_shares, verbose)

      syms = str(['SPY'])
      SPY_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      date, l_syms, ar_price, ar_shares, ar_value, SPY_value = \
        calc_portf_value(df_close, close_date_n, syms, SPY_shares, verbose)

      if verbose:
        print(f"close_date_n pick's portf value = {p_portf_value}")
        print(f'close_date_n SPY portf value =    {SPY_value}')

    date_exec.append(p_date)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_portf_value)
    shares_SPY.append(SPY_shares)
    value_SPY.append(SPY_value)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
def calc_portf_value_date_n(my_dates, my_symbols, df_close, my_portf_shares, my_SPY_shares, n, verbose=False):
  
  z_date_syms_shares = zip(my_dates, my_symbols, my_portf_shares, my_SPY_shares)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, symbols, portf_shares, SPY_shares in z_date_syms_shares:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date_exec = None
      p_ar_shares = None
      p_value_portf = None  # set to None when data are not available in df_close
      SPY_ar_shares = None
      SPY_value_portf = None # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        # print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else: 
      if portf_shares is None:
        p_date_exec = None
        p_ar_shares = None
        p_value_portf = None
        SPY_ar_shares = None
        SPY_value_portf = None

      else:  
        p_date_exec, p_ar_syms, p_ar_price, p_ar_shares, p_ar_value, p_value_portf = \
          calc_portf_value(df_close, close_date_n, symbols, portf_shares, verbose)
        
        SPY = str(['SPY'])
        SPY_date_exec, SPY_ar_syms, SPY_ar_price, SPY_ar_shares, SPY_ar_value, SPY_value_portf = \
          calc_portf_value(df_close, close_date_n, SPY, SPY_shares, verbose) 

        if verbose:
          print(f"next_date_n pick's portf value = {p_value_portf}")
          print(f'next_date_n SPY portf value =    {SPY_value_portf}')

    date_exec.append(p_date_exec)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_value_portf)
    shares_SPY.append(SPY_ar_shares)
    value_SPY.append(SPY_value_portf)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
# total target investment for each day's picks, if day's pick has 2 symbols, the function will try to invest $500 for each symbol
portf_target = 1000  
date_buy, shares_syms, value_portf, shares_SPY, value_SPY = calc_portf_value_date_buy(df_mp.date, df_mp.symbols, df_close, portf_target, n=1, verbose=verbose)

# %%
df_mp['date_buy'] = date_buy
df_mp['sh_portf_buy'] = shares_syms
df_mp['$_portf_buy'] = value_portf
df_mp['sh_SPY_buy'] = shares_SPY
df_mp['$_SPY_buy'] = value_SPY
# df_mp.tail()
# df_mp.head()
df_mp

# %%
date_exec, shares_syms, value_portf, shares_SPY, value_SPY  = \
  calc_portf_value_date_n(df_mp.date, df_mp.symbols, df_close, df_mp.sh_portf_buy, df_mp.sh_SPY_buy, n=4, verbose=verbose)

# %%
df_mp['date_sell'] = date_exec
df_mp['sh_portf_sell'] = shares_syms
df_mp['$_portf_sell'] = value_portf
df_mp['%_portf_chg'] = (df_mp['$_portf_sell'] / df_mp['$_portf_buy'] - 1) * 100

df_mp['sh_SPY_sell'] = shares_SPY
df_mp['$_SPY_sell'] = value_SPY
df_mp['%_SPY_chg'] = (df_mp['$_SPY_sell'] / df_mp['$_SPY_buy'] - 1) * 100

df_mp['dif_%_chg'] = df_mp['%_portf_chg'] - df_mp['%_SPY_chg']

# %%
# get symbol's close price for that date
date = '2023-03-16'
# _date = '2023-03-21'
# _sym = 'GE'
# _sym = 'NVDA'
_sym = 'FTSM'
# _sym = 'SHV'
_sym = 'SPY'
# _c = df_close.loc['2023-04-11']['NVDA']
_c = df_close.loc[_date][_sym]
_c

# %% [markdown]
# #### dif_%_chg is the percentage change of model icks - percentage change of SPY

# %%
df_mp.head(20)

# %%
df_mp['win'] = np.where(df_mp['dif_%_chg']>0,1,0)
df_mp.head(20)

# %% [markdown]
# ### Model Performance Not Good

# %%
wins = df_mp['win'].sum()
attempts = len(df_mp['dif_%_chg'].dropna())

win_rate = wins / attempts
print(f'win_rate: {win_rate:0.6f}, wins: {wins}, attempts: {attempts}')
print(f'sum(dff_%_chg): {df_mp["dif_%_chg"].sum():0.6f}')

# %%
df = df_mp.copy()

# %%
df_model_picks = df[df['dif_%_chg'].isnull()].copy()
pickle_dump(df_model_picks, path_data_dump, 'df_model_picks')
_df = pickle_load(path_data_dump, 'df_model_picks')
_df

# %%
idx_last_row = df_model_picks.index[-1]
df_model_picks_results = df.iloc[(idx_last_row + 1)::].copy()
pickle_dump(df_model_picks_results, path_data_dump, 'df_model_picks_results')
_df = pickle_load(path_data_dump, 'df_model_picks_results')
_df
