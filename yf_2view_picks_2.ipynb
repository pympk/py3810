# %%
# # create empty DataFrame df and append row
# my_cols = ['date', 'days_lookback', 'syms_freq', 'symbols']
# # Creating Empty DataFrame and Storing it in variable df
# df_model_top_picks = pd.DataFrame(columns=my_cols)
# df_model_top_picks

# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.width', 900)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_picks  = f'df_picks'
fp_df_model_top_picks = f'df_model_top_picks'

verbose = True
# verbose = False

# %%
df = pickle_load(path_data_dump, fp_df_picks)
df = df.drop_duplicates(subset=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], keep='last')
df = df.sort_values(by=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], ascending=False)
df = df.reset_index(drop=True)
pickle_dump(df, path_data_dump, fp_df_picks)
print(f'len(df): {len(df)}')
print(df.head())
# Out:
# len(df): 252
#   date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12 sym_freq_11 sym_freq_10       sym_freq_9      sym_freq_8 sym_freq_7                     sym_freq_6                   sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0        2023-10-19                 120      [30, 60, 120]          []          []          []          []          []          []  ['FTSM', 'SHV']              []         []  ['ANF', 'CLS', 'ICPT', 'MM...               ['CNX', 'JBL']        ['ARLP', 'NGS', 'TWNK']  ['AKAM', 'CBOE', 'CPRI', '...         []
# 1        2023-10-19                 120  [15, 30, 60, 120]          []          []          []     ['SHV']          []    ['FTSM']  ['PGR', 'USAC']              []         []  ['ANF', 'CLS', 'ICPT', 'MM...  ['ALL', 'CNX', 'FL', 'JBL']  ['ARLP', 'CI', 'HUM', 'NGS...                             []         []
# 2        2023-10-17                 120      [30, 60, 120]          []          []          []          []          []          []  ['FTSM', 'SHV']              []         []  ['ANF', 'CLS', 'ICPT', 'MM...                      ['CNX']  ['ARLP', 'JBL', 'LRN', 'NG...  ['AIZ', 'CPRI', 'DELL', 'H...         []
# 3        2023-10-17                 120  [15, 30, 60, 120]          []          []          []          []     ['SHV']    ['FTSM']               []  ['CLS', 'PGR']    ['JBL']  ['ANF', 'ICPT', 'MMYT', 'S...              ['CNX', 'SWBI']  ['ARLP', 'LRN', 'NGS', 'TW...  ['AEO', 'AIZ', 'BAH', 'CPRI']         []
# 4        2023-10-12                 120      [30, 60, 120]          []          []          []          []          []          []  ['FTSM', 'SHV']              []         []  ['ANF', 'CLS', 'DELL', 'IC...      ['CNX', 'SPLK', 'USAC']  ['AKAM', 'LRN', 'MLKN', 'N...   ['HRB', 'JBL', 'LII', 'LLY']         []

# %%
df.head(50)
# Out:
#    date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13      sym_freq_12      sym_freq_11       sym_freq_10               sym_freq_9        sym_freq_8                sym_freq_7                     sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0         2023-10-19                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                        []  ['ANF', 'CLS', 'ICPT', 'MM...                 ['CNX', 'JBL']        ['ARLP', 'NGS', 'TWNK']  ['AKAM', 'CBOE', 'CPRI', '...         []
# 1         2023-10-19                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []          ['FTSM']          ['PGR', 'USAC']                []                        []  ['ANF', 'CLS', 'ICPT', 'MM...    ['ALL', 'CNX', 'FL', 'JBL']  ['ARLP', 'CI', 'HUM', 'NGS...                             []         []
# 2         2023-10-17                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                        []  ['ANF', 'CLS', 'ICPT', 'MM...                        ['CNX']  ['ARLP', 'JBL', 'LRN', 'NG...  ['AIZ', 'CPRI', 'DELL', 'H...         []
# 3         2023-10-17                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']          ['FTSM']                       []    ['CLS', 'PGR']                   ['JBL']  ['ANF', 'ICPT', 'MMYT', 'S...                ['CNX', 'SWBI']  ['ARLP', 'LRN', 'NGS', 'TW...  ['AEO', 'AIZ', 'BAH', 'CPRI']         []
# 4         2023-10-12                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                        []  ['ANF', 'CLS', 'DELL', 'IC...        ['CNX', 'SPLK', 'USAC']  ['AKAM', 'LRN', 'MLKN', 'N...   ['HRB', 'JBL', 'LII', 'LLY']         []
# 5         2023-10-12                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']          ['FTSM']                 ['ICPT']    ['ANF', 'CLS']                  ['MLKN']  ['DELL', 'JBL', 'MMYT', 'N...        ['CNX', 'SPLK', 'USAC']  ['AKAM', 'BAH', 'CME', 'LR...                             []         []
# 6         2023-10-06                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                   ['CLS']                ['ANF', 'USAC']        ['ICPT', 'LRN', 'MMYT']  ['CNX', 'DELL', 'MLKN', 'N...  ['ARCH', 'CCJ', 'CNK', 'HR...         []
# 7         2023-10-06                 120  [15, 30, 60, 120]          []          []          []          ['SHV']         ['FTSM']           ['CLS']                       []          ['ICPT']  ['MLKN', 'SPLK', 'USAC']  ['ANF', 'CNK', 'JBL', 'SBL...         ['LRN', 'MMYT', 'NGS']  ['CNX', 'DELL', 'HOLI', 'H...                             []         []
# 8         2023-10-05                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                        []          ['ANF', 'CLS', 'LRN']  ['DELL', 'ICPT', 'MMYT', '...                 ['NGS', 'VST']  ['ARCH', 'CBOE', 'DBI', 'H...         []
# 9         2023-10-05                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []                []                  ['CLS']  ['ICPT', 'SPLK']                        []  ['ANF', 'CBOE', 'JBL', 'LR...  ['CNK', 'DELL', 'MMYT', 'N...               ['HOLI', 'HZNP']                             []         []
# 10        2023-10-04                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                  ['SPLK']  ['ANF', 'BBW', 'ICPT', 'LRN']  ['CLS', 'DELL', 'MLKN', 'M...                             []  ['AKAM', 'ARLP', 'CBOE', '...         []
# 11        2023-10-04                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []          ['SPLK']                 ['ICPT']          ['MLKN']                        []  ['ANF', 'BBW', 'CBOE', 'HZ...  ['CLS', 'DELL', 'MMYT', 'T...  ['HOLI', 'HRB', 'NGS', 'WSM']                       ['AKAM']         []
# 12        2023-10-02                 120      [30, 60, 120]          []          []          []               []               []                []                 ['FTSM']           ['ANF']                        []                ['DELL', 'LRN']  ['ARCH', 'BBW', 'CLS', 'IC...  ['HRB', 'MMYT', 'SHV', 'SP...  ['CELH', 'DBI', 'HZNP', 'I...         []
# 13        2023-10-02                 120  [15, 30, 60, 120]          []          []          []         ['FTSM']               []                []                  ['ANF']          ['ICPT']    ['HRB', 'NGS', 'SPLK']        ['DELL', 'LRN', 'MLKN']  ['ARCH', 'BBW', 'CLS', 'JB...  ['ARLP', 'HZNP', 'MMYT', '...                             []         []
# 14        2023-09-29                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []           ['ANF', 'DELL']                ['ARCH', 'CCJ']  ['CLS', 'ICPT', 'LRN', 'NGS']                       ['MMYT']  ['BBW', 'CELH', 'HRB', 'HZ...         []
# 15        2023-09-29                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []          ['FTSM']                 ['ARCH']   ['ICPT', 'NGS']           ['ANF', 'DELL']        ['CCJ', 'MLKN', 'SPLK']          ['CLS', 'HRB', 'LRN']       ['HZNP', 'MMYT', 'RCKT']  ['ARLP', 'BBW', 'CASY', 'C...         []
# 16        2023-09-28                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']           ['CCJ']                   ['ANF']               ['ARCH', 'DELL']                       ['USAC']  ['APO', 'CLS', 'ICPT', 'LR...  ['CELH', 'HRB', 'LII', 'SB...         []
# 17        2023-09-28                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []          ['FTSM']                 ['ARCH']   ['CCJ', 'USAC']    ['ANF', 'ICPT', 'NGS']       ['DELL', 'SPLK', 'TWNK']                             []  ['APO', 'CLS', 'HRB', 'LRN...                       ['ARLP']         []
# 18        2023-09-25                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                   ['CCJ']                ['DELL', 'HRB']  ['ARCH', 'CLS', 'LRN', 'VST']         ['APO', 'MMYT', 'PBR']  ['BBW', 'CELH', 'CLMT', 'C...         []
# 19        2023-09-25                 120  [15, 30, 60, 120]          []          []          []               []  ['FTSM', 'SHV']                []                       []   ['ARCH', 'CCJ']                   ['HRB']  ['DELL', 'NGS', 'TWNK', 'YY']          ['CLS', 'LRN', 'VST']  ['APO', 'CASY', 'CRS', 'MM...                       ['ARLP']         []
# 20        2023-09-22                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                  ['DELL']                 ['CCJ', 'HRB']          ['CLS', 'LRN', 'VST']  ['AKAM', 'APO', 'ARCH', 'M...  ['BBW', 'BX', 'CELH', 'CLM...         []
# 21        2023-09-22                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []                []                       []                []          ['ARCH', 'DELL']  ['CCJ', 'HRB', 'SPLK', 'TW...   ['CLS', 'LRN', 'NGS', 'VST']  ['AKAM', 'APO', 'CASY', 'M...                       ['ARLP']         []
# 22        2023-09-21                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                  ['DELL']                        ['HRB']                        ['CCJ']  ['APO', 'ARCH', 'CLS', 'HE...  ['BBW', 'CELH', 'CLMT', 'C...         []
# 23        2023-09-21                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []          ['DELL']                       []                []                  ['ARCH']  ['HRB', 'SPLK', 'TWNK', 'YY']                 ['CCJ', 'NGS']  ['APO', 'CASY', 'CLS', 'HE...                             []         []
# 24        2023-09-20                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                   ['CCJ']                ['DELL', 'HRB']                       ['CPRI']  ['APO', 'CLS', 'LRN', 'MMY...  ['ARCH', 'BBW', 'CELH', 'C...         []
# 25        2023-09-20                 120  [15, 30, 60, 120]          []          []          []          ['SHV']         ['FTSM']                []                 ['DELL']                []                   ['CCJ']  ['ARCH', 'HRB', 'TWNK', 'YY']  ['APO', 'CPRI', 'NGS', 'USO']  ['BX', 'CLS', 'GEL', 'HMC'...                             []         []
# 26        2023-09-18                 120      [30, 60, 120]          []          []          []               []               []                []                  ['SHV']          ['FTSM']                        []        ['CELH', 'DELL', 'LLY']          ['CCJ', 'FTI', 'VST']  ['ANF', 'ARCH', 'CLS', 'CP...       ['CLMT', 'HZNP', 'SKYW']         []
# 27        2023-09-18                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']          ['FTSM']                 ['DELL']                []           ['ARCH', 'CCJ']  ['CELH', 'FTI', 'LLY', 'TW...                       ['RCKT']  ['ANF', 'CLS', 'CPRI', 'HA...                             []         []
# 28        2023-09-15                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']                []                  ['DELL']         ['ANF', 'CELH', 'LLY']                ['CCJ', 'MMYT']  ['ARCH', 'CLS', 'CPRI', 'P...  ['CLMT', 'HRB', 'HZNP', 'O...         []
# 29        2023-09-15                 120  [15, 30, 60, 120]          []          []          []               []  ['FTSM', 'SHV']          ['DELL']                       []                []                  ['ARCH']  ['ANF', 'CCJ', 'CELH', 'LL...               ['HZNP', 'MMYT']  ['CLS', 'CPRI', 'HMC', 'PB...                 ['BX', 'CLMT']         []
# 30        2023-09-14                 120      [30, 60, 120]          []          []          []               []               []                []                  ['SHV']  ['DELL', 'FTSM']                        []         ['CELH', 'LLY', 'TDS']         ['ANF', 'CCJ', 'CPRI']         ['CLS', 'HEP', 'MMYT']  ['ARCH', 'BBW', 'BR', 'CLM...         []
# 31        2023-09-14                 120  [15, 30, 60, 120]          []          []          []               []  ['DELL', 'SHV']                []                       []          ['FTSM']                        []  ['ARCH', 'CELH', 'LLY', 'T...  ['ANF', 'CCJ', 'CPRI', 'HZ...  ['CLS', 'FTI', 'HEP', 'HMC...          ['BBW', 'BR', 'CLMT']         []
# 32        2023-09-13                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']          ['DELL']                  ['MMYT']         ['CELH', 'LLY', 'TDS']               ['CORT', 'CPRI']          ['CCJ', 'CLS', 'VST']  ['ANF', 'BBW', 'CNX', 'FTI...         []
# 33        2023-09-13                 120  [15, 30, 60, 120]          []          []          []               []  ['DELL', 'SHV']                []                 ['FTSM']                []           ['LLY', 'MMYT']        ['CELH', 'TDS', 'TWNK']  ['BBW', 'CORT', 'CPRI', 'H...   ['CCJ', 'CLS', 'FTI', 'VST']          ['ANF', 'ARCH', 'BX']         []
# 34        2023-09-12                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']  ['DELL', 'MMYT']                        []  ['ANF', 'CELH', 'FTI', 'LL...        ['CORT', 'STRL', 'VST']                ['CLS', 'CPRI']  ['BBW', 'BCC', 'CNX', 'HZN...         []
# 35        2023-09-12                 120  [15, 30, 60, 120]          []          []          []               []  ['DELL', 'SHV']                []          ['ANF', 'FTSM']   ['FTI', 'MMYT']                        []  ['CELH', 'LLY', 'TDS', 'TW...  ['CORT', 'HZNP', 'STRL', '...         ['CLS', 'CPRI', 'SLG']                 ['BBW', 'BCC']         []
# 36        2023-09-11                 120      [30, 60, 120]          []          []          []               []               []                []  ['DELL', 'FTSM', 'SHV']                []                  ['MMYT']  ['ANF', 'CELH', 'LLY', 'ST...        ['CORT', 'CPRI', 'VST']                 ['CLS', 'XPO']  ['BBW', 'BR', 'CNX', 'FTI'...         []
# 37        2023-09-11                 120  [15, 30, 60, 120]          []          []          []         ['DELL']          ['SHV']                []          ['ANF', 'FTSM']                []                  ['MMYT']  ['CELH', 'CLS', 'LLY', 'ST...  ['CORT', 'CPRI', 'HZNP', '...                 ['SLG', 'XPO']                  ['BBW', 'BR']         []
# 38        2023-09-08                 120      [30, 60, 120]          []          []          []               []               []                []          ['FTSM', 'SHV']  ['DELL', 'STRL']                        []  ['ANF', 'CELH', 'LLY', 'MM...                        ['VST']        ['CLS', 'CORT', 'CPRI']  ['AEO', 'CNX', 'FTI', 'HZN...         []
# 39        2023-09-08                 120  [15, 30, 60, 120]          []          []          []               []  ['DELL', 'SHV']                []          ['ANF', 'FTSM']  ['CELH', 'STRL']                   ['VST']         ['LLY', 'MMYT', 'TDS']         ['FTI', 'HZNP', 'VNO']  ['CLS', 'CORT', 'CPRI', 'S...         ['AEO', 'CLMT', 'CNX']         []
# 40        2023-09-05                 120      [30, 60, 120]          []          []          []               []               []                []                  ['SHV']          ['FTSM']   ['ANF', 'DELL', 'STRL']  ['AEO', 'CELH', 'CLS', 'SM...  ['CNX', 'LLY', 'MMYT', 'XPO']  ['BCC', 'CORT', 'CPRI', 'U...                ['CDW', 'FFWM']         []
# 41        2023-09-05                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']   ['ANF', 'DELL']                 ['FTSM']                []           ['STRL', 'UBS']  ['AEO', 'CELH', 'CLS', 'PA...  ['CNX', 'HZNP', 'LLY', 'MM...        ['BCC', 'CORT', 'CPRI']                             []         []
# 42        2023-09-01                 120      [30, 60, 120]          []          []          []               []               []                []                  ['SHV']  ['FTSM', 'STRL']                        []  ['AEO', 'ANF', 'CELH', 'CL...  ['BCC', 'CNX', 'LLY', 'MMY...                       ['CPRI']  ['BKI', 'CDW', 'CORT', 'HRB']         []
# 43        2023-09-01                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']                []  ['ANF', 'DELL', 'FTSM']   ['STRL', 'TDS']                        []  ['AEO', 'CELH', 'CLS', 'HR...  ['BCC', 'CNX', 'HZNP', 'LL...                       ['CPRI']                             []         []
# 44        2023-08-25                 120      [30, 60, 120]          []          []          []               []               []                []                  ['SHV']          ['STRL']                  ['FTSM']    ['AEO', 'ANF', 'SM', 'TDS']          ['CLS', 'CNX', 'LLY']  ['BCC', 'CPRI', 'MMYT', 'X...  ['CELH', 'CORT', 'DELL', '...         []
# 45        2023-08-25                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []          ['STRL']           ['ANF', 'TDS']   ['FTSM', 'LLY']                  ['CPRI']  ['AEO', 'CELH', 'HRB', 'MM...     ['CLS', 'CNX', 'UBS', 'X']                 ['BCC', 'XPO']               ['CCOI', 'CCRN']         []
# 46        2023-08-18                 120      [30, 60, 120]          []          []          []               []               []                []                  ['SHV']          ['FTSM']                  ['STRL']                 ['CNX', 'TDS']                 ['CLS', 'XPO']          ['BKI', 'HRB', 'LLY']  ['ADBE', 'AEO', 'BCC', 'BL...         []
# 47        2023-08-18                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []          ['FTSM']   ['CNX', 'STRL', 'TDS']                []            ['HRB', 'LLY']  ['AEO', 'BKI', 'CELH', 'CO...         ['CLS', 'CPRI', 'XPO']         ['MMYT', 'REGN', 'SM']        ['ADBE', 'AZTA', 'BCC']         []
# 48        2023-08-17                 120      [30, 60, 120]          []          []          []               []               []                []                  ['SHV']          ['FTSM']                  ['STRL']          ['CLS', 'CNX', 'TDS']                        ['XPO']          ['BKI', 'HRB', 'LLY']  ['ADBE', 'AEO', 'ANF', 'BC...         []
# 49        2023-08-17                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []  ['FTSM', 'STRL']           ['CNX', 'TDS']                []            ['HRB', 'LLY']  ['AEO', 'BKI', 'CLS', 'COR...                ['LAUR', 'XPO']                         ['SM']  ['ADBE', 'ANF', 'BCC', 'BL...         []

# %%
df_mp_res = pickle_load(path_data_dump, 'df_model_picks_results')
df_mp = pickle_load(path_data_dump, 'df_model_picks')
# df_mp_res 
df_mp
# Out:
#          date  days_lookback   syms_freq           symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0  2023-09-08  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 1  2023-09-08  [30, 60, 120]  sym_freq_8  ['DELL', 'STRL']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 2  2023-09-05  [30, 60, 120]  sym_freq_9           ['SHV']  2023-09-06        [9.0]   990.809967      [2.0]  892.440002      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 3  2023-09-05  [30, 60, 120]  sym_freq_8          ['FTSM']  2023-09-06       [16.0]   951.840027      [2.0]  892.440002      None          None           NaN          NaN        None         NaN        NaN        NaN    0

# %%
from itertools import product
from ast import literal_eval

my_cols = ['sym_freq_12', 'sym_freq_9', 'sym_freq_8']
my_days_lookbacks = [[30, 60, 120], [15, 30, 60, 120]]

my_dates = []
for my_days_lookback in my_days_lookbacks:
  my_row = (df['days_lookbacks'] == str(my_days_lookback))
  l_dates = df.loc[my_row, 'date_end_df_train'].tolist()     
  my_dates.append(l_dates)

my_dates = [val for sublist in my_dates for val in sublist]
my_dates = sorted(list(set(my_dates)), reverse=True)

d_lbk_freq = list(product(my_dates, my_days_lookbacks, my_cols))

picks = []
prev_date = ''
# print(f'Model predicts the best performing symbols are:\n[30, 60, 120]        sym_freq_9\n[15, 30, 60, 120]    sym_freq_12\n[30, 60, 120]        sym_freq_8')
print(f'Model predicts the best performing symbols are:')
print(f'1st    {"[30, 60, 120]":<20}{"sym_freq_9":<14}{"days_eval = 4":<20}')
print(f'2nd    {"[15, 30, 60, 120]":<20}{"sym_freq_12":<14}{"days_eval = 5":<20}')
print(f'3rd    {"[30, 60, 120]":<20}{"sym_freq_8":<14}{"days_eval = 4":<20}')
for i, item in enumerate(d_lbk_freq):
  _date, my_days_lookback, my_col = item[0], item[1], item[2]
  my_row = (df['date_end_df_train'] == _date) & (df['days_lookbacks'] == str(my_days_lookback))  
  list_in_df = df.loc[my_row, my_col]
  my_str = list_in_df.tolist()[0]
  my_list = literal_eval(my_str)
  blank = ' '
  if _date != prev_date:
    if prev_date == '':
      print('\nModel Results:')  
      print(f'{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')
    else:
      print(f'\n{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}') 
  else:
    print(f'{i:<6}{blank:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')

  picks.append((i, my_list))
  prev_date = _date
# Out:
# Model predicts the best performing symbols are:
# 1st    [30, 60, 120]       sym_freq_9    days_eval = 4
# 2nd    [15, 30, 60, 120]   sym_freq_12   days_eval = 5
# 3rd    [30, 60, 120]       sym_freq_8    days_eval = 4
#
# Model Results:
# 0     2023-10-19    [30, 60, 120]        sym_freq_12: []
# 1                   [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 2                   [30, 60, 120]        sym_freq_8 : []
# 3                   [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 4                   [15, 30, 60, 120]    sym_freq_9 : ['PGR', 'USAC']
# 5                   [15, 30, 60, 120]    sym_freq_8 : []
#
# 6     2023-10-17    [30, 60, 120]        sym_freq_12: []
# 7                   [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 8                   [30, 60, 120]        sym_freq_8 : []
# 9                   [15, 30, 60, 120]    sym_freq_12: []
# 10                  [15, 30, 60, 120]    sym_freq_9 : []
# 11                  [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'PGR']
#
# 12    2023-10-12    [30, 60, 120]        sym_freq_12: []
# 13                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 14                  [30, 60, 120]        sym_freq_8 : []
# 15                  [15, 30, 60, 120]    sym_freq_12: []
# 16                  [15, 30, 60, 120]    sym_freq_9 : ['ICPT']
# 17                  [15, 30, 60, 120]    sym_freq_8 : ['ANF', 'CLS']
#
# 18    2023-10-06    [30, 60, 120]        sym_freq_12: []
# 19                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 20                  [30, 60, 120]        sym_freq_8 : []
# 21                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 22                  [15, 30, 60, 120]    sym_freq_9 : []
# 23                  [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 24    2023-10-05    [30, 60, 120]        sym_freq_12: []
# 25                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 26                  [30, 60, 120]        sym_freq_8 : []
# 27                  [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 28                  [15, 30, 60, 120]    sym_freq_9 : ['CLS']
# 29                  [15, 30, 60, 120]    sym_freq_8 : ['ICPT', 'SPLK']
#
# 30    2023-10-04    [30, 60, 120]        sym_freq_12: []
# 31                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 32                  [30, 60, 120]        sym_freq_8 : []
# 33                  [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 34                  [15, 30, 60, 120]    sym_freq_9 : ['ICPT']
# 35                  [15, 30, 60, 120]    sym_freq_8 : ['MLKN']
#
# 36    2023-10-02    [30, 60, 120]        sym_freq_12: []
# 37                  [30, 60, 120]        sym_freq_9 : ['FTSM']
# 38                  [30, 60, 120]        sym_freq_8 : ['ANF']
# 39                  [15, 30, 60, 120]    sym_freq_12: ['FTSM']
# 40                  [15, 30, 60, 120]    sym_freq_9 : ['ANF']
# 41                  [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 42    2023-09-29    [30, 60, 120]        sym_freq_12: []
# 43                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 44                  [30, 60, 120]        sym_freq_8 : []
# 45                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 46                  [15, 30, 60, 120]    sym_freq_9 : ['ARCH']
# 47                  [15, 30, 60, 120]    sym_freq_8 : ['ICPT', 'NGS']
#
# 48    2023-09-28    [30, 60, 120]        sym_freq_12: []
# 49                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 50                  [30, 60, 120]        sym_freq_8 : ['CCJ']
# 51                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 52                  [15, 30, 60, 120]    sym_freq_9 : ['ARCH']
# 53                  [15, 30, 60, 120]    sym_freq_8 : ['CCJ', 'USAC']
#
# 54    2023-09-25    [30, 60, 120]        sym_freq_12: []
# 55                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 56                  [30, 60, 120]        sym_freq_8 : []
# 57                  [15, 30, 60, 120]    sym_freq_12: []
# 58                  [15, 30, 60, 120]    sym_freq_9 : []
# 59                  [15, 30, 60, 120]    sym_freq_8 : ['ARCH', 'CCJ']
#
# 60    2023-09-22    [30, 60, 120]        sym_freq_12: []
# 61                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 62                  [30, 60, 120]        sym_freq_8 : []
# 63                  [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 64                  [15, 30, 60, 120]    sym_freq_9 : []
# 65                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 66    2023-09-21    [30, 60, 120]        sym_freq_12: []
# 67                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 68                  [30, 60, 120]        sym_freq_8 : []
# 69                  [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 70                  [15, 30, 60, 120]    sym_freq_9 : []
# 71                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 72    2023-09-20    [30, 60, 120]        sym_freq_12: []
# 73                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 74                  [30, 60, 120]        sym_freq_8 : []
# 75                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 76                  [15, 30, 60, 120]    sym_freq_9 : ['DELL']
# 77                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 78    2023-09-18    [30, 60, 120]        sym_freq_12: []
# 79                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 80                  [30, 60, 120]        sym_freq_8 : ['FTSM']
# 81                  [15, 30, 60, 120]    sym_freq_12: []
# 82                  [15, 30, 60, 120]    sym_freq_9 : ['DELL']
# 83                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 84    2023-09-15    [30, 60, 120]        sym_freq_12: []
# 85                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 86                  [30, 60, 120]        sym_freq_8 : []
# 87                  [15, 30, 60, 120]    sym_freq_12: []
# 88                  [15, 30, 60, 120]    sym_freq_9 : []
# 89                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 90    2023-09-14    [30, 60, 120]        sym_freq_12: []
# 91                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 92                  [30, 60, 120]        sym_freq_8 : ['DELL', 'FTSM']
# 93                  [15, 30, 60, 120]    sym_freq_12: []
# 94                  [15, 30, 60, 120]    sym_freq_9 : []
# 95                  [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 96    2023-09-13    [30, 60, 120]        sym_freq_12: []
# 97                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 98                  [30, 60, 120]        sym_freq_8 : ['DELL']
# 99                  [15, 30, 60, 120]    sym_freq_12: []
# 100                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 101                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 102   2023-09-12    [30, 60, 120]        sym_freq_12: []
# 103                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 104                 [30, 60, 120]        sym_freq_8 : ['DELL', 'MMYT']
# 105                 [15, 30, 60, 120]    sym_freq_12: []
# 106                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 107                 [15, 30, 60, 120]    sym_freq_8 : ['FTI', 'MMYT']
#
# 108   2023-09-11    [30, 60, 120]        sym_freq_12: []
# 109                 [30, 60, 120]        sym_freq_9 : ['DELL', 'FTSM', 'SHV']
# 110                 [30, 60, 120]        sym_freq_8 : []
# 111                 [15, 30, 60, 120]    sym_freq_12: ['DELL']
# 112                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 113                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 114   2023-09-08    [30, 60, 120]        sym_freq_12: []
# 115                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 116                 [30, 60, 120]        sym_freq_8 : ['DELL', 'STRL']
# 117                 [15, 30, 60, 120]    sym_freq_12: []
# 118                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 119                 [15, 30, 60, 120]    sym_freq_8 : ['CELH', 'STRL']
#
# 120   2023-09-05    [30, 60, 120]        sym_freq_12: []
# 121                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 122                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 123                 [15, 30, 60, 120]    sym_freq_12: []
# 124                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 125                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 126   2023-09-01    [30, 60, 120]        sym_freq_12: []
# 127                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 128                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 129                 [15, 30, 60, 120]    sym_freq_12: []
# 130                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'DELL', 'FTSM']
# 131                 [15, 30, 60, 120]    sym_freq_8 : ['STRL', 'TDS']
#
# 132   2023-08-25    [30, 60, 120]        sym_freq_12: []
# 133                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 134                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 135                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 136                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'TDS']
# 137                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'LLY']
#
# 138   2023-08-18    [30, 60, 120]        sym_freq_12: []
# 139                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 140                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 141                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 142                 [15, 30, 60, 120]    sym_freq_9 : ['CNX', 'STRL', 'TDS']
# 143                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 144   2023-08-17    [30, 60, 120]        sym_freq_12: []
# 145                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 146                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 147                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 148                 [15, 30, 60, 120]    sym_freq_9 : ['CNX', 'TDS']
# 149                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 150   2023-08-15    [30, 60, 120]        sym_freq_12: []
# 151                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 152                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 153                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 154                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 155                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 156   2023-08-14    [30, 60, 120]        sym_freq_12: []
# 157                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 158                 [30, 60, 120]        sym_freq_8 : []
# 159                 [15, 30, 60, 120]    sym_freq_12: []
# 160                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 161                 [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'EME']
#
# 162   2023-08-11    [30, 60, 120]        sym_freq_12: []
# 163                 [30, 60, 120]        sym_freq_9 : []
# 164                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 165                 [15, 30, 60, 120]    sym_freq_12: []
# 166                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 167                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 168   2023-08-10    [30, 60, 120]        sym_freq_12: []
# 169                 [30, 60, 120]        sym_freq_9 : []
# 170                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 171                 [15, 30, 60, 120]    sym_freq_12: []
# 172                 [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'TDS']
# 173                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 174   2023-08-09    [30, 60, 120]        sym_freq_12: []
# 175                 [30, 60, 120]        sym_freq_9 : []
# 176                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 177                 [15, 30, 60, 120]    sym_freq_12: []
# 178                 [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'TDS']
# 179                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 180   2023-08-08    [30, 60, 120]        sym_freq_12: []
# 181                 [30, 60, 120]        sym_freq_9 : []
# 182                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 183                 [15, 30, 60, 120]    sym_freq_12: []
# 184                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 185                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 186   2023-08-07    [30, 60, 120]        sym_freq_12: []
# 187                 [30, 60, 120]        sym_freq_9 : []
# 188                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 189                 [15, 30, 60, 120]    sym_freq_12: []
# 190                 [15, 30, 60, 120]    sym_freq_9 : []
# 191                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 192   2023-08-04    [30, 60, 120]        sym_freq_12: []
# 193                 [30, 60, 120]        sym_freq_9 : []
# 194                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 195                 [15, 30, 60, 120]    sym_freq_12: []
# 196                 [15, 30, 60, 120]    sym_freq_9 : []
# 197                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 198   2023-08-03    [30, 60, 120]        sym_freq_12: []
# 199                 [30, 60, 120]        sym_freq_9 : []
# 200                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 201                 [15, 30, 60, 120]    sym_freq_12: []
# 202                 [15, 30, 60, 120]    sym_freq_9 : []
# 203                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 204   2023-08-02    [30, 60, 120]        sym_freq_12: []
# 205                 [30, 60, 120]        sym_freq_9 : []
# 206                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 207                 [15, 30, 60, 120]    sym_freq_12: []
# 208                 [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 209                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 210   2023-08-01    [30, 60, 120]        sym_freq_12: []
# 211                 [30, 60, 120]        sym_freq_9 : []
# 212                 [30, 60, 120]        sym_freq_8 : []
# 213                 [15, 30, 60, 120]    sym_freq_12: []
# 214                 [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 215                 [15, 30, 60, 120]    sym_freq_8 : ['SMCI']
#
# 216   2023-07-27    [30, 60, 120]        sym_freq_12: []
# 217                 [30, 60, 120]        sym_freq_9 : []
# 218                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 219                 [15, 30, 60, 120]    sym_freq_12: []
# 220                 [15, 30, 60, 120]    sym_freq_9 : ['JOE']
# 221                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 222   2023-07-26    [30, 60, 120]        sym_freq_12: []
# 223                 [30, 60, 120]        sym_freq_9 : []
# 224                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 225                 [15, 30, 60, 120]    sym_freq_12: []
# 226                 [15, 30, 60, 120]    sym_freq_9 : []
# 227                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 228   2023-07-25    [30, 60, 120]        sym_freq_12: []
# 229                 [30, 60, 120]        sym_freq_9 : []
# 230                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 231                 [15, 30, 60, 120]    sym_freq_12: []
# 232                 [15, 30, 60, 120]    sym_freq_9 : []
# 233                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 234   2023-07-21    [30, 60, 120]        sym_freq_12: []
# 235                 [30, 60, 120]        sym_freq_9 : []
# 236                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 237                 [15, 30, 60, 120]    sym_freq_12: []
# 238                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 239                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 240   2023-07-20    [30, 60, 120]        sym_freq_12: []
# 241                 [30, 60, 120]        sym_freq_9 : []
# 242                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 243                 [15, 30, 60, 120]    sym_freq_12: []
# 244                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 245                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 246   2023-07-18    [30, 60, 120]        sym_freq_12: []
# 247                 [30, 60, 120]        sym_freq_9 : []
# 248                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 249                 [15, 30, 60, 120]    sym_freq_12: []
# 250                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 251                 [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 252   2023-07-14    [30, 60, 120]        sym_freq_12: []
# 253                 [30, 60, 120]        sym_freq_9 : []
# 254                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 255                 [15, 30, 60, 120]    sym_freq_12: []
# 256                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 257                 [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 258   2023-07-13    [30, 60, 120]        sym_freq_12: []
# 259                 [30, 60, 120]        sym_freq_9 : []
# 260                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 261                 [15, 30, 60, 120]    sym_freq_12: []
# 262                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 263                 [15, 30, 60, 120]    sym_freq_8 : ['BCC', 'SKYW']
#
# 264   2023-07-12    [30, 60, 120]        sym_freq_12: []
# 265                 [30, 60, 120]        sym_freq_9 : []
# 266                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 267                 [15, 30, 60, 120]    sym_freq_12: []
# 268                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 269                 [15, 30, 60, 120]    sym_freq_8 : ['BZH', 'SKYW']
#
# 270   2023-07-11    [30, 60, 120]        sym_freq_12: []
# 271                 [30, 60, 120]        sym_freq_9 : []
# 272                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 273                 [15, 30, 60, 120]    sym_freq_12: []
# 274                 [15, 30, 60, 120]    sym_freq_9 : []
# 275                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 276   2023-07-10    [30, 60, 120]        sym_freq_12: []
# 277                 [30, 60, 120]        sym_freq_9 : []
# 278                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 279                 [15, 30, 60, 120]    sym_freq_12: []
# 280                 [15, 30, 60, 120]    sym_freq_9 : []
# 281                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 282   2023-07-07    [30, 60, 120]        sym_freq_12: []
# 283                 [30, 60, 120]        sym_freq_9 : []
# 284                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 285                 [15, 30, 60, 120]    sym_freq_12: []
# 286                 [15, 30, 60, 120]    sym_freq_9 : []
# 287                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 288   2023-07-06    [30, 60, 120]        sym_freq_12: []
# 289                 [30, 60, 120]        sym_freq_9 : []
# 290                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 291                 [15, 30, 60, 120]    sym_freq_12: []
# 292                 [15, 30, 60, 120]    sym_freq_9 : []
# 293                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW']
#
# 294   2023-07-05    [30, 60, 120]        sym_freq_12: []
# 295                 [30, 60, 120]        sym_freq_9 : []
# 296                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 297                 [15, 30, 60, 120]    sym_freq_12: []
# 298                 [15, 30, 60, 120]    sym_freq_9 : []
# 299                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 300   2023-07-03    [30, 60, 120]        sym_freq_12: []
# 301                 [30, 60, 120]        sym_freq_9 : []
# 302                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 303                 [15, 30, 60, 120]    sym_freq_12: []
# 304                 [15, 30, 60, 120]    sym_freq_9 : []
# 305                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW', 'W']
#
# 306   2023-06-30    [30, 60, 120]        sym_freq_12: []
# 307                 [30, 60, 120]        sym_freq_9 : []
# 308                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 309                 [15, 30, 60, 120]    sym_freq_12: []
# 310                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 311                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 312   2023-06-29    [30, 60, 120]        sym_freq_12: []
# 313                 [30, 60, 120]        sym_freq_9 : []
# 314                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 315                 [15, 30, 60, 120]    sym_freq_12: []
# 316                 [15, 30, 60, 120]    sym_freq_9 : []
# 317                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 318   2023-06-28    [30, 60, 120]        sym_freq_12: []
# 319                 [30, 60, 120]        sym_freq_9 : []
# 320                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 321                 [15, 30, 60, 120]    sym_freq_12: []
# 322                 [15, 30, 60, 120]    sym_freq_9 : []
# 323                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 324   2023-06-27    [30, 60, 120]        sym_freq_12: []
# 325                 [30, 60, 120]        sym_freq_9 : []
# 326                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 327                 [15, 30, 60, 120]    sym_freq_12: []
# 328                 [15, 30, 60, 120]    sym_freq_9 : []
# 329                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 330   2023-06-26    [30, 60, 120]        sym_freq_12: []
# 331                 [30, 60, 120]        sym_freq_9 : []
# 332                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 333                 [15, 30, 60, 120]    sym_freq_12: []
# 334                 [15, 30, 60, 120]    sym_freq_9 : []
# 335                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 336   2023-06-23    [30, 60, 120]        sym_freq_12: []
# 337                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 338                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 339                 [15, 30, 60, 120]    sym_freq_12: []
# 340                 [15, 30, 60, 120]    sym_freq_9 : ['CCL', 'NVDA']
# 341                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH']
#
# 342   2023-06-22    [30, 60, 120]        sym_freq_12: []
# 343                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 344                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 345                 [15, 30, 60, 120]    sym_freq_12: []
# 346                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 347                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'PBR']
#
# 348   2023-06-21    [30, 60, 120]        sym_freq_12: []
# 349                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 350                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 351                 [15, 30, 60, 120]    sym_freq_12: []
# 352                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 353                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 354   2023-06-20    [30, 60, 120]        sym_freq_12: []
# 355                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 356                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 357                 [15, 30, 60, 120]    sym_freq_12: []
# 358                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 359                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 360   2023-06-16    [30, 60, 120]        sym_freq_12: []
# 361                 [30, 60, 120]        sym_freq_9 : []
# 362                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 363                 [15, 30, 60, 120]    sym_freq_12: []
# 364                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 365                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 366   2023-06-15    [30, 60, 120]        sym_freq_12: []
# 367                 [30, 60, 120]        sym_freq_9 : []
# 368                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 369                 [15, 30, 60, 120]    sym_freq_12: []
# 370                 [15, 30, 60, 120]    sym_freq_9 : []
# 371                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'NVDA', 'SKYW']
#
# 372   2023-06-14    [30, 60, 120]        sym_freq_12: []
# 373                 [30, 60, 120]        sym_freq_9 : []
# 374                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA', 'SHV']
# 375                 [15, 30, 60, 120]    sym_freq_12: []
# 376                 [15, 30, 60, 120]    sym_freq_9 : ['AVGO']
# 377                 [15, 30, 60, 120]    sym_freq_8 : ['ORCL', 'SKYW']
#
# 378   2023-06-13    [30, 60, 120]        sym_freq_12: []
# 379                 [30, 60, 120]        sym_freq_9 : []
# 380                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 381                 [15, 30, 60, 120]    sym_freq_12: []
# 382                 [15, 30, 60, 120]    sym_freq_9 : []
# 383                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 384   2023-06-12    [30, 60, 120]        sym_freq_12: []
# 385                 [30, 60, 120]        sym_freq_9 : []
# 386                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 387                 [15, 30, 60, 120]    sym_freq_12: []
# 388                 [15, 30, 60, 120]    sym_freq_9 : []
# 389                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 390   2023-06-09    [30, 60, 120]        sym_freq_12: []
# 391                 [30, 60, 120]        sym_freq_9 : []
# 392                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 393                 [15, 30, 60, 120]    sym_freq_12: []
# 394                 [15, 30, 60, 120]    sym_freq_9 : []
# 395                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 396   2023-06-08    [30, 60, 120]        sym_freq_12: []
# 397                 [30, 60, 120]        sym_freq_9 : []
# 398                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 399                 [15, 30, 60, 120]    sym_freq_12: []
# 400                 [15, 30, 60, 120]    sym_freq_9 : []
# 401                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 402   2023-06-07    [30, 60, 120]        sym_freq_12: []
# 403                 [30, 60, 120]        sym_freq_9 : []
# 404                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 405                 [15, 30, 60, 120]    sym_freq_12: []
# 406                 [15, 30, 60, 120]    sym_freq_9 : []
# 407                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 408   2023-06-06    [30, 60, 120]        sym_freq_12: []
# 409                 [30, 60, 120]        sym_freq_9 : []
# 410                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 411                 [15, 30, 60, 120]    sym_freq_12: []
# 412                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 413                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 414   2023-06-05    [30, 60, 120]        sym_freq_12: []
# 415                 [30, 60, 120]        sym_freq_9 : []
# 416                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 417                 [15, 30, 60, 120]    sym_freq_12: []
# 418                 [15, 30, 60, 120]    sym_freq_9 : []
# 419                 [15, 30, 60, 120]    sym_freq_8 : ['META', 'SKYW']
#
# 420   2023-06-02    [30, 60, 120]        sym_freq_12: []
# 421                 [30, 60, 120]        sym_freq_9 : []
# 422                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 423                 [15, 30, 60, 120]    sym_freq_12: []
# 424                 [15, 30, 60, 120]    sym_freq_9 : ['META']
# 425                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 426   2023-06-01    [30, 60, 120]        sym_freq_12: []
# 427                 [30, 60, 120]        sym_freq_9 : []
# 428                 [30, 60, 120]        sym_freq_8 : ['META', 'NVDA']
# 429                 [15, 30, 60, 120]    sym_freq_12: []
# 430                 [15, 30, 60, 120]    sym_freq_9 : ['AVGO', 'RMBS']
# 431                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 432   2023-05-31    [30, 60, 120]        sym_freq_12: []
# 433                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 434                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA']
# 435                 [15, 30, 60, 120]    sym_freq_12: []
# 436                 [15, 30, 60, 120]    sym_freq_9 : []
# 437                 [15, 30, 60, 120]    sym_freq_8 : ['RMBS']
#
# 438   2023-05-30    [30, 60, 120]        sym_freq_12: []
# 439                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 440                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA']
# 441                 [15, 30, 60, 120]    sym_freq_12: []
# 442                 [15, 30, 60, 120]    sym_freq_9 : []
# 443                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 444   2023-05-26    [30, 60, 120]        sym_freq_12: []
# 445                 [30, 60, 120]        sym_freq_9 : ['AVGO', 'SHV']
# 446                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 447                 [15, 30, 60, 120]    sym_freq_12: ['AVGO']
# 448                 [15, 30, 60, 120]    sym_freq_9 : ['RMBS']
# 449                 [15, 30, 60, 120]    sym_freq_8 : ['AMD']
#
# 450   2023-05-25    [30, 60, 120]        sym_freq_12: []
# 451                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 452                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'NVDA']
# 453                 [15, 30, 60, 120]    sym_freq_12: []
# 454                 [15, 30, 60, 120]    sym_freq_9 : []
# 455                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 456   2023-05-24    [30, 60, 120]        sym_freq_12: []
# 457                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 458                 [30, 60, 120]        sym_freq_8 : []
# 459                 [15, 30, 60, 120]    sym_freq_12: []
# 460                 [15, 30, 60, 120]    sym_freq_9 : []
# 461                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 462   2023-05-23    [30, 60, 120]        sym_freq_12: []
# 463                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 464                 [30, 60, 120]        sym_freq_8 : []
# 465                 [15, 30, 60, 120]    sym_freq_12: []
# 466                 [15, 30, 60, 120]    sym_freq_9 : []
# 467                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 468   2023-05-22    [30, 60, 120]        sym_freq_12: []
# 469                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 470                 [30, 60, 120]        sym_freq_8 : []
# 471                 [15, 30, 60, 120]    sym_freq_12: []
# 472                 [15, 30, 60, 120]    sym_freq_9 : []
# 473                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 474   2023-05-19    [30, 60, 120]        sym_freq_12: []
# 475                 [30, 60, 120]        sym_freq_9 : []
# 476                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 477                 [15, 30, 60, 120]    sym_freq_12: []
# 478                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 479                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 480   2023-05-18    [30, 60, 120]        sym_freq_12: []
# 481                 [30, 60, 120]        sym_freq_9 : []
# 482                 [30, 60, 120]        sym_freq_8 : ['SHV', 'TMHC']
# 483                 [15, 30, 60, 120]    sym_freq_12: []
# 484                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 485                 [15, 30, 60, 120]    sym_freq_8 : ['TMHC']
#
# 486   2023-05-17    [30, 60, 120]        sym_freq_12: []
# 487                 [30, 60, 120]        sym_freq_9 : []
# 488                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 489                 [15, 30, 60, 120]    sym_freq_12: []
# 490                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 491                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 492   2023-05-16    [30, 60, 120]        sym_freq_12: []
# 493                 [30, 60, 120]        sym_freq_9 : []
# 494                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 495                 [15, 30, 60, 120]    sym_freq_12: []
# 496                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 497                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 498   2023-05-15    [30, 60, 120]        sym_freq_12: []
# 499                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 500                 [30, 60, 120]        sym_freq_8 : []
# 501                 [15, 30, 60, 120]    sym_freq_12: []
# 502                 [15, 30, 60, 120]    sym_freq_9 : []
# 503                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 504   2023-05-12    [30, 60, 120]        sym_freq_12: []
# 505                 [30, 60, 120]        sym_freq_9 : []
# 506                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 507                 [15, 30, 60, 120]    sym_freq_12: []
# 508                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE', 'SHV']
# 509                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 510   2023-05-11    [30, 60, 120]        sym_freq_12: []
# 511                 [30, 60, 120]        sym_freq_9 : []
# 512                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 513                 [15, 30, 60, 120]    sym_freq_12: []
# 514                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 515                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 516   2023-05-10    [30, 60, 120]        sym_freq_12: []
# 517                 [30, 60, 120]        sym_freq_9 : []
# 518                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 519                 [15, 30, 60, 120]    sym_freq_12: []
# 520                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 521                 [15, 30, 60, 120]    sym_freq_8 : ['BLDR']
#
# 522   2023-05-09    [30, 60, 120]        sym_freq_12: []
# 523                 [30, 60, 120]        sym_freq_9 : []
# 524                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 525                 [15, 30, 60, 120]    sym_freq_12: []
# 526                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 527                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 528   2023-05-08    [30, 60, 120]        sym_freq_12: []
# 529                 [30, 60, 120]        sym_freq_9 : []
# 530                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 531                 [15, 30, 60, 120]    sym_freq_12: []
# 532                 [15, 30, 60, 120]    sym_freq_9 : []
# 533                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 534   2023-05-05    [30, 60, 120]        sym_freq_12: []
# 535                 [30, 60, 120]        sym_freq_9 : []
# 536                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 537                 [15, 30, 60, 120]    sym_freq_12: []
# 538                 [15, 30, 60, 120]    sym_freq_9 : []
# 539                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 540   2023-05-04    [30, 60, 120]        sym_freq_12: []
# 541                 [30, 60, 120]        sym_freq_9 : []
# 542                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 543                 [15, 30, 60, 120]    sym_freq_12: []
# 544                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP']
# 545                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 546   2023-05-03    [30, 60, 120]        sym_freq_12: []
# 547                 [30, 60, 120]        sym_freq_9 : []
# 548                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 549                 [15, 30, 60, 120]    sym_freq_12: []
# 550                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE']
# 551                 [15, 30, 60, 120]    sym_freq_8 : ['CCEP', 'SHV', 'SKYW']
#
# 552   2023-05-02    [30, 60, 120]        sym_freq_12: []
# 553                 [30, 60, 120]        sym_freq_9 : []
# 554                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 555                 [15, 30, 60, 120]    sym_freq_12: []
# 556                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP', 'ISEE', 'SHV']
# 557                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 558   2023-05-01    [30, 60, 120]        sym_freq_12: []
# 559                 [30, 60, 120]        sym_freq_9 : []
# 560                 [30, 60, 120]        sym_freq_8 : []
# 561                 [15, 30, 60, 120]    sym_freq_12: []
# 562                 [15, 30, 60, 120]    sym_freq_9 : []
# 563                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 564   2023-04-28    [30, 60, 120]        sym_freq_12: []
# 565                 [30, 60, 120]        sym_freq_9 : []
# 566                 [30, 60, 120]        sym_freq_8 : []
# 567                 [15, 30, 60, 120]    sym_freq_12: []
# 568                 [15, 30, 60, 120]    sym_freq_9 : []
# 569                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 570   2023-04-27    [30, 60, 120]        sym_freq_12: []
# 571                 [30, 60, 120]        sym_freq_9 : []
# 572                 [30, 60, 120]        sym_freq_8 : []
# 573                 [15, 30, 60, 120]    sym_freq_12: []
# 574                 [15, 30, 60, 120]    sym_freq_9 : []
# 575                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 576   2023-04-26    [30, 60, 120]        sym_freq_12: []
# 577                 [30, 60, 120]        sym_freq_9 : []
# 578                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 579                 [15, 30, 60, 120]    sym_freq_12: []
# 580                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 581                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 582   2023-04-25    [30, 60, 120]        sym_freq_12: []
# 583                 [30, 60, 120]        sym_freq_9 : []
# 584                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 585                 [15, 30, 60, 120]    sym_freq_12: []
# 586                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 587                 [15, 30, 60, 120]    sym_freq_8 : ['ELF']
#
# 588   2023-04-24    [30, 60, 120]        sym_freq_12: []
# 589                 [30, 60, 120]        sym_freq_9 : []
# 590                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 591                 [15, 30, 60, 120]    sym_freq_12: []
# 592                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 593                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 594   2023-04-21    [30, 60, 120]        sym_freq_12: []
# 595                 [30, 60, 120]        sym_freq_9 : []
# 596                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 597                 [15, 30, 60, 120]    sym_freq_12: []
# 598                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 599                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 600   2023-04-20    [30, 60, 120]        sym_freq_12: []
# 601                 [30, 60, 120]        sym_freq_9 : []
# 602                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 603                 [15, 30, 60, 120]    sym_freq_12: []
# 604                 [15, 30, 60, 120]    sym_freq_9 : []
# 605                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 606   2023-04-19    [30, 60, 120]        sym_freq_12: []
# 607                 [30, 60, 120]        sym_freq_9 : []
# 608                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 609                 [15, 30, 60, 120]    sym_freq_12: []
# 610                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 611                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 612   2023-04-18    [30, 60, 120]        sym_freq_12: []
# 613                 [30, 60, 120]        sym_freq_9 : []
# 614                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 615                 [15, 30, 60, 120]    sym_freq_12: []
# 616                 [15, 30, 60, 120]    sym_freq_9 : []
# 617                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 618   2023-04-17    [30, 60, 120]        sym_freq_12: []
# 619                 [30, 60, 120]        sym_freq_9 : []
# 620                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 621                 [15, 30, 60, 120]    sym_freq_12: []
# 622                 [15, 30, 60, 120]    sym_freq_9 : []
# 623                 [15, 30, 60, 120]    sym_freq_8 : ['ELF', 'SHV']
#
# 624   2023-04-14    [30, 60, 120]        sym_freq_12: []
# 625                 [30, 60, 120]        sym_freq_9 : []
# 626                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 627                 [15, 30, 60, 120]    sym_freq_12: []
# 628                 [15, 30, 60, 120]    sym_freq_9 : []
# 629                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 630   2023-04-13    [30, 60, 120]        sym_freq_12: []
# 631                 [30, 60, 120]        sym_freq_9 : []
# 632                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 633                 [15, 30, 60, 120]    sym_freq_12: []
# 634                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 635                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 636   2023-04-12    [30, 60, 120]        sym_freq_12: []
# 637                 [30, 60, 120]        sym_freq_9 : []
# 638                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 639                 [15, 30, 60, 120]    sym_freq_12: []
# 640                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 641                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 642   2023-04-11    [30, 60, 120]        sym_freq_12: []
# 643                 [30, 60, 120]        sym_freq_9 : []
# 644                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 645                 [15, 30, 60, 120]    sym_freq_12: []
# 646                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 647                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 648   2023-04-10    [30, 60, 120]        sym_freq_12: []
# 649                 [30, 60, 120]        sym_freq_9 : []
# 650                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 651                 [15, 30, 60, 120]    sym_freq_12: []
# 652                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 653                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 654   2023-04-06    [30, 60, 120]        sym_freq_12: []
# 655                 [30, 60, 120]        sym_freq_9 : []
# 656                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 657                 [15, 30, 60, 120]    sym_freq_12: []
# 658                 [15, 30, 60, 120]    sym_freq_9 : []
# 659                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 660   2023-04-05    [30, 60, 120]        sym_freq_12: []
# 661                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 662                 [30, 60, 120]        sym_freq_8 : []
# 663                 [15, 30, 60, 120]    sym_freq_12: []
# 664                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 665                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 666   2023-04-04    [30, 60, 120]        sym_freq_12: []
# 667                 [30, 60, 120]        sym_freq_9 : []
# 668                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 669                 [15, 30, 60, 120]    sym_freq_12: []
# 670                 [15, 30, 60, 120]    sym_freq_9 : []
# 671                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA', 'SHV']
#
# 672   2023-04-03    [30, 60, 120]        sym_freq_12: []
# 673                 [30, 60, 120]        sym_freq_9 : []
# 674                 [30, 60, 120]        sym_freq_8 : ['GE', 'NVDA']
# 675                 [15, 30, 60, 120]    sym_freq_12: []
# 676                 [15, 30, 60, 120]    sym_freq_9 : []
# 677                 [15, 30, 60, 120]    sym_freq_8 : ['GE', 'PERI']
#
# 678   2023-03-31    [30, 60, 120]        sym_freq_12: []
# 679                 [30, 60, 120]        sym_freq_9 : []
# 680                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 681                 [15, 30, 60, 120]    sym_freq_12: []
# 682                 [15, 30, 60, 120]    sym_freq_9 : []
# 683                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 684   2023-03-30    [30, 60, 120]        sym_freq_12: []
# 685                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 686                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 687                 [15, 30, 60, 120]    sym_freq_12: []
# 688                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 689                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 690   2023-03-29    [30, 60, 120]        sym_freq_12: []
# 691                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 692                 [30, 60, 120]        sym_freq_8 : []
# 693                 [15, 30, 60, 120]    sym_freq_12: []
# 694                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 695                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 696   2023-03-28    [30, 60, 120]        sym_freq_12: []
# 697                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 698                 [30, 60, 120]        sym_freq_8 : []
# 699                 [15, 30, 60, 120]    sym_freq_12: []
# 700                 [15, 30, 60, 120]    sym_freq_9 : []
# 701                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 702   2023-03-27    [30, 60, 120]        sym_freq_12: []
# 703                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 704                 [30, 60, 120]        sym_freq_8 : ['GE']
# 705                 [15, 30, 60, 120]    sym_freq_12: []
# 706                 [15, 30, 60, 120]    sym_freq_9 : []
# 707                 [15, 30, 60, 120]    sym_freq_8 : ['GE', 'NVDA', 'SGEN']
#
# 708   2023-03-24    [30, 60, 120]        sym_freq_12: []
# 709                 [30, 60, 120]        sym_freq_9 : []
# 710                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 711                 [15, 30, 60, 120]    sym_freq_12: []
# 712                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 713                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 714   2023-03-23    [30, 60, 120]        sym_freq_12: []
# 715                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 716                 [30, 60, 120]        sym_freq_8 : []
# 717                 [15, 30, 60, 120]    sym_freq_12: []
# 718                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 719                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'GE']
#
# 720   2023-03-22    [30, 60, 120]        sym_freq_12: []
# 721                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 722                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 723                 [15, 30, 60, 120]    sym_freq_12: []
# 724                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'NVDA']
# 725                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 726   2023-03-21    [30, 60, 120]        sym_freq_12: []
# 727                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 728                 [30, 60, 120]        sym_freq_8 : ['GE']
# 729                 [15, 30, 60, 120]    sym_freq_12: []
# 730                 [15, 30, 60, 120]    sym_freq_9 : ['GE']
# 731                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 732   2023-03-20    [30, 60, 120]        sym_freq_12: []
# 733                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 734                 [30, 60, 120]        sym_freq_8 : []
# 735                 [15, 30, 60, 120]    sym_freq_12: []
# 736                 [15, 30, 60, 120]    sym_freq_9 : []
# 737                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 738   2023-03-17    [30, 60, 120]        sym_freq_12: []
# 739                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 740                 [30, 60, 120]        sym_freq_8 : ['GE']
# 741                 [15, 30, 60, 120]    sym_freq_12: []
# 742                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'GE']
# 743                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 744   2023-03-16    [30, 60, 120]        sym_freq_12: []
# 745                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 746                 [30, 60, 120]        sym_freq_8 : []
# 747                 [15, 30, 60, 120]    sym_freq_12: []
# 748                 [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 749                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 750   2023-03-15    [30, 60, 120]        sym_freq_12: []
# 751                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 752                 [30, 60, 120]        sym_freq_8 : []
# 753                 [15, 30, 60, 120]    sym_freq_12: []
# 754                 [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 755                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'FCN']

# %%
model_top_picks = [([30, 60, 120], 'sym_freq_9'), ([15, 30, 60, 120], 'sym_freq_12'), ([30, 60, 120], 'sym_freq_8')]

# %%
df_model_top_picks = pickle_load(path_data_dump, fp_df_model_top_picks)

z_items   = zip(d_lbk_freq, picks)
for i, item in enumerate(z_items):
  _date, _days_lookback, _sym_freq, _syms = item[0][0], item[0][1], item[0][2], item[1][1]
  print(i, _date, _days_lookback, _sym_freq, _syms)
  dlb_sym_freq = (_days_lookback, _sym_freq)
  if dlb_sym_freq in model_top_picks and _syms:
    row_add = [_date, _days_lookback, _sym_freq, _syms]
    df_model_top_picks.loc[len(df_model_top_picks)] = row_add
    print(f'added row to df_model_top_picks:\n{row_add}\n')
# Out:
# 0 2023-10-19 [30, 60, 120] sym_freq_12 []
# 1 2023-10-19 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-19', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 2 2023-10-19 [30, 60, 120] sym_freq_8 []
# 3 2023-10-19 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-10-19', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 4 2023-10-19 [15, 30, 60, 120] sym_freq_9 ['PGR', 'USAC']
# 5 2023-10-19 [15, 30, 60, 120] sym_freq_8 []
# 6 2023-10-17 [30, 60, 120] sym_freq_12 []
# 7 2023-10-17 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-17', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 8 2023-10-17 [30, 60, 120] sym_freq_8 []
# 9 2023-10-17 [15, 30, 60, 120] sym_freq_12 []
# 10 2023-10-17 [15, 30, 60, 120] sym_freq_9 []
# 11 2023-10-17 [15, 30, 60, 120] sym_freq_8 ['CLS', 'PGR']
# 12 2023-10-12 [30, 60, 120] sym_freq_12 []
# 13 2023-10-12 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-12', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 14 2023-10-12 [30, 60, 120] sym_freq_8 []
# 15 2023-10-12 [15, 30, 60, 120] sym_freq_12 []
# 16 2023-10-12 [15, 30, 60, 120] sym_freq_9 ['ICPT']
# 17 2023-10-12 [15, 30, 60, 120] sym_freq_8 ['ANF', 'CLS']
# 18 2023-10-06 [30, 60, 120] sym_freq_12 []
# 19 2023-10-06 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-06', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 20 2023-10-06 [30, 60, 120] sym_freq_8 []
# 21 2023-10-06 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-10-06', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 22 2023-10-06 [15, 30, 60, 120] sym_freq_9 []
# 23 2023-10-06 [15, 30, 60, 120] sym_freq_8 ['ICPT']
# 24 2023-10-05 [30, 60, 120] sym_freq_12 []
# 25 2023-10-05 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-05', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 26 2023-10-05 [30, 60, 120] sym_freq_8 []
# 27 2023-10-05 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-05', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 28 2023-10-05 [15, 30, 60, 120] sym_freq_9 ['CLS']
# 29 2023-10-05 [15, 30, 60, 120] sym_freq_8 ['ICPT', 'SPLK']
# 30 2023-10-04 [30, 60, 120] sym_freq_12 []
# 31 2023-10-04 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-04', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 32 2023-10-04 [30, 60, 120] sym_freq_8 []
# 33 2023-10-04 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-04', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 34 2023-10-04 [15, 30, 60, 120] sym_freq_9 ['ICPT']
# 35 2023-10-04 [15, 30, 60, 120] sym_freq_8 ['MLKN']
# 36 2023-10-02 [30, 60, 120] sym_freq_12 []
# 37 2023-10-02 [30, 60, 120] sym_freq_9 ['FTSM']
# added row to df_model_top_picks:
# ['2023-10-02', [30, 60, 120], 'sym_freq_9', ['FTSM']]
#
# 38 2023-10-02 [30, 60, 120] sym_freq_8 ['ANF']
# added row to df_model_top_picks:
# ['2023-10-02', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 39 2023-10-02 [15, 30, 60, 120] sym_freq_12 ['FTSM']
# added row to df_model_top_picks:
# ['2023-10-02', [15, 30, 60, 120], 'sym_freq_12', ['FTSM']]
#
# 40 2023-10-02 [15, 30, 60, 120] sym_freq_9 ['ANF']
# 41 2023-10-02 [15, 30, 60, 120] sym_freq_8 ['ICPT']
# 42 2023-09-29 [30, 60, 120] sym_freq_12 []
# 43 2023-09-29 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-29', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 44 2023-09-29 [30, 60, 120] sym_freq_8 []
# 45 2023-09-29 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-29', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 46 2023-09-29 [15, 30, 60, 120] sym_freq_9 ['ARCH']
# 47 2023-09-29 [15, 30, 60, 120] sym_freq_8 ['ICPT', 'NGS']
# 48 2023-09-28 [30, 60, 120] sym_freq_12 []
# 49 2023-09-28 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-28', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 50 2023-09-28 [30, 60, 120] sym_freq_8 ['CCJ']
# added row to df_model_top_picks:
# ['2023-09-28', [30, 60, 120], 'sym_freq_8', ['CCJ']]
#
# 51 2023-09-28 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-28', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 52 2023-09-28 [15, 30, 60, 120] sym_freq_9 ['ARCH']
# 53 2023-09-28 [15, 30, 60, 120] sym_freq_8 ['CCJ', 'USAC']
# 54 2023-09-25 [30, 60, 120] sym_freq_12 []
# 55 2023-09-25 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-25', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 56 2023-09-25 [30, 60, 120] sym_freq_8 []
# 57 2023-09-25 [15, 30, 60, 120] sym_freq_12 []
# 58 2023-09-25 [15, 30, 60, 120] sym_freq_9 []
# 59 2023-09-25 [15, 30, 60, 120] sym_freq_8 ['ARCH', 'CCJ']
# 60 2023-09-22 [30, 60, 120] sym_freq_12 []
# 61 2023-09-22 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-22', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 62 2023-09-22 [30, 60, 120] sym_freq_8 []
# 63 2023-09-22 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-22', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 64 2023-09-22 [15, 30, 60, 120] sym_freq_9 []
# 65 2023-09-22 [15, 30, 60, 120] sym_freq_8 []
# 66 2023-09-21 [30, 60, 120] sym_freq_12 []
# 67 2023-09-21 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-21', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 68 2023-09-21 [30, 60, 120] sym_freq_8 []
# 69 2023-09-21 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-21', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 70 2023-09-21 [15, 30, 60, 120] sym_freq_9 []
# 71 2023-09-21 [15, 30, 60, 120] sym_freq_8 []
# 72 2023-09-20 [30, 60, 120] sym_freq_12 []
# 73 2023-09-20 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 74 2023-09-20 [30, 60, 120] sym_freq_8 []
# 75 2023-09-20 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-20', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 76 2023-09-20 [15, 30, 60, 120] sym_freq_9 ['DELL']
# 77 2023-09-20 [15, 30, 60, 120] sym_freq_8 []
# 78 2023-09-18 [30, 60, 120] sym_freq_12 []
# 79 2023-09-18 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 80 2023-09-18 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-09-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 81 2023-09-18 [15, 30, 60, 120] sym_freq_12 []
# 82 2023-09-18 [15, 30, 60, 120] sym_freq_9 ['DELL']
# 83 2023-09-18 [15, 30, 60, 120] sym_freq_8 []
# 84 2023-09-15 [30, 60, 120] sym_freq_12 []
# 85 2023-09-15 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 86 2023-09-15 [30, 60, 120] sym_freq_8 []
# 87 2023-09-15 [15, 30, 60, 120] sym_freq_12 []
# 88 2023-09-15 [15, 30, 60, 120] sym_freq_9 []
# 89 2023-09-15 [15, 30, 60, 120] sym_freq_8 []
# 90 2023-09-14 [30, 60, 120] sym_freq_12 []
# 91 2023-09-14 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 92 2023-09-14 [30, 60, 120] sym_freq_8 ['DELL', 'FTSM']
# added row to df_model_top_picks:
# ['2023-09-14', [30, 60, 120], 'sym_freq_8', ['DELL', 'FTSM']]
#
# 93 2023-09-14 [15, 30, 60, 120] sym_freq_12 []
# 94 2023-09-14 [15, 30, 60, 120] sym_freq_9 []
# 95 2023-09-14 [15, 30, 60, 120] sym_freq_8 ['FTSM']
# 96 2023-09-13 [30, 60, 120] sym_freq_12 []
# 97 2023-09-13 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-13', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 98 2023-09-13 [30, 60, 120] sym_freq_8 ['DELL']
# added row to df_model_top_picks:
# ['2023-09-13', [30, 60, 120], 'sym_freq_8', ['DELL']]
#
# 99 2023-09-13 [15, 30, 60, 120] sym_freq_12 []
# 100 2023-09-13 [15, 30, 60, 120] sym_freq_9 ['FTSM']
# 101 2023-09-13 [15, 30, 60, 120] sym_freq_8 []
# 102 2023-09-12 [30, 60, 120] sym_freq_12 []
# 103 2023-09-12 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-12', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 104 2023-09-12 [30, 60, 120] sym_freq_8 ['DELL', 'MMYT']
# added row to df_model_top_picks:
# ['2023-09-12', [30, 60, 120], 'sym_freq_8', ['DELL', 'MMYT']]
#
# 105 2023-09-12 [15, 30, 60, 120] sym_freq_12 []
# 106 2023-09-12 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 107 2023-09-12 [15, 30, 60, 120] sym_freq_8 ['FTI', 'MMYT']
# 108 2023-09-11 [30, 60, 120] sym_freq_12 []
# 109 2023-09-11 [30, 60, 120] sym_freq_9 ['DELL', 'FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-11', [30, 60, 120], 'sym_freq_9', ['DELL', 'FTSM', 'SHV']]
#
# 110 2023-09-11 [30, 60, 120] sym_freq_8 []
# 111 2023-09-11 [15, 30, 60, 120] sym_freq_12 ['DELL']
# added row to df_model_top_picks:
# ['2023-09-11', [15, 30, 60, 120], 'sym_freq_12', ['DELL']]
#
# 112 2023-09-11 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 113 2023-09-11 [15, 30, 60, 120] sym_freq_8 []
# 114 2023-09-08 [30, 60, 120] sym_freq_12 []
# 115 2023-09-08 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-08', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 116 2023-09-08 [30, 60, 120] sym_freq_8 ['DELL', 'STRL']
# added row to df_model_top_picks:
# ['2023-09-08', [30, 60, 120], 'sym_freq_8', ['DELL', 'STRL']]
#
# 117 2023-09-08 [15, 30, 60, 120] sym_freq_12 []
# 118 2023-09-08 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 119 2023-09-08 [15, 30, 60, 120] sym_freq_8 ['CELH', 'STRL']
# 120 2023-09-05 [30, 60, 120] sym_freq_12 []
# 121 2023-09-05 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 122 2023-09-05 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-09-05', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 123 2023-09-05 [15, 30, 60, 120] sym_freq_12 []
# 124 2023-09-05 [15, 30, 60, 120] sym_freq_9 ['FTSM']
# 125 2023-09-05 [15, 30, 60, 120] sym_freq_8 []
# 126 2023-09-01 [30, 60, 120] sym_freq_12 []
# 127 2023-09-01 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-01', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 128 2023-09-01 [30, 60, 120] sym_freq_8 ['FTSM', 'STRL']
# added row to df_model_top_picks:
# ['2023-09-01', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 129 2023-09-01 [15, 30, 60, 120] sym_freq_12 []
# 130 2023-09-01 [15, 30, 60, 120] sym_freq_9 ['ANF', 'DELL', 'FTSM']
# 131 2023-09-01 [15, 30, 60, 120] sym_freq_8 ['STRL', 'TDS']
# 132 2023-08-25 [30, 60, 120] sym_freq_12 []
# 133 2023-08-25 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-25', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 134 2023-08-25 [30, 60, 120] sym_freq_8 ['STRL']
# added row to df_model_top_picks:
# ['2023-08-25', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 135 2023-08-25 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-25', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 136 2023-08-25 [15, 30, 60, 120] sym_freq_9 ['ANF', 'TDS']
# 137 2023-08-25 [15, 30, 60, 120] sym_freq_8 ['FTSM', 'LLY']
# 138 2023-08-18 [30, 60, 120] sym_freq_12 []
# 139 2023-08-18 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 140 2023-08-18 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-08-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 141 2023-08-18 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-18', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 142 2023-08-18 [15, 30, 60, 120] sym_freq_9 ['CNX', 'STRL', 'TDS']
# 143 2023-08-18 [15, 30, 60, 120] sym_freq_8 []
# 144 2023-08-17 [30, 60, 120] sym_freq_12 []
# 145 2023-08-17 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-17', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 146 2023-08-17 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-08-17', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 147 2023-08-17 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-17', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 148 2023-08-17 [15, 30, 60, 120] sym_freq_9 ['CNX', 'TDS']
# 149 2023-08-17 [15, 30, 60, 120] sym_freq_8 []
# 150 2023-08-15 [30, 60, 120] sym_freq_12 []
# 151 2023-08-15 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 152 2023-08-15 [30, 60, 120] sym_freq_8 ['STRL']
# added row to df_model_top_picks:
# ['2023-08-15', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 153 2023-08-15 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-15', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 154 2023-08-15 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 155 2023-08-15 [15, 30, 60, 120] sym_freq_8 []
# 156 2023-08-14 [30, 60, 120] sym_freq_12 []
# 157 2023-08-14 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 158 2023-08-14 [30, 60, 120] sym_freq_8 []
# 159 2023-08-14 [15, 30, 60, 120] sym_freq_12 []
# 160 2023-08-14 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 161 2023-08-14 [15, 30, 60, 120] sym_freq_8 ['CLS', 'EME']
# 162 2023-08-11 [30, 60, 120] sym_freq_12 []
# 163 2023-08-11 [30, 60, 120] sym_freq_9 []
# 164 2023-08-11 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-11', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 165 2023-08-11 [15, 30, 60, 120] sym_freq_12 []
# 166 2023-08-11 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 167 2023-08-11 [15, 30, 60, 120] sym_freq_8 []
# 168 2023-08-10 [30, 60, 120] sym_freq_12 []
# 169 2023-08-10 [30, 60, 120] sym_freq_9 []
# 170 2023-08-10 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-10', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 171 2023-08-10 [15, 30, 60, 120] sym_freq_12 []
# 172 2023-08-10 [15, 30, 60, 120] sym_freq_9 ['LOB', 'TDS']
# 173 2023-08-10 [15, 30, 60, 120] sym_freq_8 []
# 174 2023-08-09 [30, 60, 120] sym_freq_12 []
# 175 2023-08-09 [30, 60, 120] sym_freq_9 []
# 176 2023-08-09 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-09', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 177 2023-08-09 [15, 30, 60, 120] sym_freq_12 []
# 178 2023-08-09 [15, 30, 60, 120] sym_freq_9 ['LOB', 'TDS']
# 179 2023-08-09 [15, 30, 60, 120] sym_freq_8 []
# 180 2023-08-08 [30, 60, 120] sym_freq_12 []
# 181 2023-08-08 [30, 60, 120] sym_freq_9 []
# 182 2023-08-08 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-08', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 183 2023-08-08 [15, 30, 60, 120] sym_freq_12 []
# 184 2023-08-08 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 185 2023-08-08 [15, 30, 60, 120] sym_freq_8 []
# 186 2023-08-07 [30, 60, 120] sym_freq_12 []
# 187 2023-08-07 [30, 60, 120] sym_freq_9 []
# 188 2023-08-07 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-07', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 189 2023-08-07 [15, 30, 60, 120] sym_freq_12 []
# 190 2023-08-07 [15, 30, 60, 120] sym_freq_9 []
# 191 2023-08-07 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 192 2023-08-04 [30, 60, 120] sym_freq_12 []
# 193 2023-08-04 [30, 60, 120] sym_freq_9 []
# 194 2023-08-04 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 195 2023-08-04 [15, 30, 60, 120] sym_freq_12 []
# 196 2023-08-04 [15, 30, 60, 120] sym_freq_9 []
# 197 2023-08-04 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 198 2023-08-03 [30, 60, 120] sym_freq_12 []
# 199 2023-08-03 [30, 60, 120] sym_freq_9 []
# 200 2023-08-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 201 2023-08-03 [15, 30, 60, 120] sym_freq_12 []
# 202 2023-08-03 [15, 30, 60, 120] sym_freq_9 []
# 203 2023-08-03 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 204 2023-08-02 [30, 60, 120] sym_freq_12 []
# 205 2023-08-02 [30, 60, 120] sym_freq_9 []
# 206 2023-08-02 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 207 2023-08-02 [15, 30, 60, 120] sym_freq_12 []
# 208 2023-08-02 [15, 30, 60, 120] sym_freq_9 ['LOB']
# 209 2023-08-02 [15, 30, 60, 120] sym_freq_8 []
# 210 2023-08-01 [30, 60, 120] sym_freq_12 []
# 211 2023-08-01 [30, 60, 120] sym_freq_9 []
# 212 2023-08-01 [30, 60, 120] sym_freq_8 []
# 213 2023-08-01 [15, 30, 60, 120] sym_freq_12 []
# 214 2023-08-01 [15, 30, 60, 120] sym_freq_9 ['LOB']
# 215 2023-08-01 [15, 30, 60, 120] sym_freq_8 ['SMCI']
# 216 2023-07-27 [30, 60, 120] sym_freq_12 []
# 217 2023-07-27 [30, 60, 120] sym_freq_9 []
# 218 2023-07-27 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-27', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 219 2023-07-27 [15, 30, 60, 120] sym_freq_12 []
# 220 2023-07-27 [15, 30, 60, 120] sym_freq_9 ['JOE']
# 221 2023-07-27 [15, 30, 60, 120] sym_freq_8 []
# 222 2023-07-26 [30, 60, 120] sym_freq_12 []
# 223 2023-07-26 [30, 60, 120] sym_freq_9 []
# 224 2023-07-26 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-26', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 225 2023-07-26 [15, 30, 60, 120] sym_freq_12 []
# 226 2023-07-26 [15, 30, 60, 120] sym_freq_9 []
# 227 2023-07-26 [15, 30, 60, 120] sym_freq_8 []
# 228 2023-07-25 [30, 60, 120] sym_freq_12 []
# 229 2023-07-25 [30, 60, 120] sym_freq_9 []
# 230 2023-07-25 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-25', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 231 2023-07-25 [15, 30, 60, 120] sym_freq_12 []
# 232 2023-07-25 [15, 30, 60, 120] sym_freq_9 []
# 233 2023-07-25 [15, 30, 60, 120] sym_freq_8 []
# 234 2023-07-21 [30, 60, 120] sym_freq_12 []
# 235 2023-07-21 [30, 60, 120] sym_freq_9 []
# 236 2023-07-21 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-21', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 237 2023-07-21 [15, 30, 60, 120] sym_freq_12 []
# 238 2023-07-21 [15, 30, 60, 120] sym_freq_9 ['SHV', 'SIRI']
# 239 2023-07-21 [15, 30, 60, 120] sym_freq_8 []
# 240 2023-07-20 [30, 60, 120] sym_freq_12 []
# 241 2023-07-20 [30, 60, 120] sym_freq_9 []
# 242 2023-07-20 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-20', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 243 2023-07-20 [15, 30, 60, 120] sym_freq_12 []
# 244 2023-07-20 [15, 30, 60, 120] sym_freq_9 ['SHV', 'SIRI']
# 245 2023-07-20 [15, 30, 60, 120] sym_freq_8 []
# 246 2023-07-18 [30, 60, 120] sym_freq_12 []
# 247 2023-07-18 [30, 60, 120] sym_freq_9 []
# 248 2023-07-18 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 249 2023-07-18 [15, 30, 60, 120] sym_freq_12 []
# 250 2023-07-18 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 251 2023-07-18 [15, 30, 60, 120] sym_freq_8 ['BCC']
# 252 2023-07-14 [30, 60, 120] sym_freq_12 []
# 253 2023-07-14 [30, 60, 120] sym_freq_9 []
# 254 2023-07-14 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 255 2023-07-14 [15, 30, 60, 120] sym_freq_12 []
# 256 2023-07-14 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 257 2023-07-14 [15, 30, 60, 120] sym_freq_8 ['BCC']
# 258 2023-07-13 [30, 60, 120] sym_freq_12 []
# 259 2023-07-13 [30, 60, 120] sym_freq_9 []
# 260 2023-07-13 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-13', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 261 2023-07-13 [15, 30, 60, 120] sym_freq_12 []
# 262 2023-07-13 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 263 2023-07-13 [15, 30, 60, 120] sym_freq_8 ['BCC', 'SKYW']
# 264 2023-07-12 [30, 60, 120] sym_freq_12 []
# 265 2023-07-12 [30, 60, 120] sym_freq_9 []
# 266 2023-07-12 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-12', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 267 2023-07-12 [15, 30, 60, 120] sym_freq_12 []
# 268 2023-07-12 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 269 2023-07-12 [15, 30, 60, 120] sym_freq_8 ['BZH', 'SKYW']
# 270 2023-07-11 [30, 60, 120] sym_freq_12 []
# 271 2023-07-11 [30, 60, 120] sym_freq_9 []
# 272 2023-07-11 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-11', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 273 2023-07-11 [15, 30, 60, 120] sym_freq_12 []
# 274 2023-07-11 [15, 30, 60, 120] sym_freq_9 []
# 275 2023-07-11 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 276 2023-07-10 [30, 60, 120] sym_freq_12 []
# 277 2023-07-10 [30, 60, 120] sym_freq_9 []
# 278 2023-07-10 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-10', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 279 2023-07-10 [15, 30, 60, 120] sym_freq_12 []
# 280 2023-07-10 [15, 30, 60, 120] sym_freq_9 []
# 281 2023-07-10 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 282 2023-07-07 [30, 60, 120] sym_freq_12 []
# 283 2023-07-07 [30, 60, 120] sym_freq_9 []
# 284 2023-07-07 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-07', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 285 2023-07-07 [15, 30, 60, 120] sym_freq_12 []
# 286 2023-07-07 [15, 30, 60, 120] sym_freq_9 []
# 287 2023-07-07 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 288 2023-07-06 [30, 60, 120] sym_freq_12 []
# 289 2023-07-06 [30, 60, 120] sym_freq_9 []
# 290 2023-07-06 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-06', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 291 2023-07-06 [15, 30, 60, 120] sym_freq_12 []
# 292 2023-07-06 [15, 30, 60, 120] sym_freq_9 []
# 293 2023-07-06 [15, 30, 60, 120] sym_freq_8 ['CCL', 'SKYW']
# 294 2023-07-05 [30, 60, 120] sym_freq_12 []
# 295 2023-07-05 [30, 60, 120] sym_freq_9 []
# 296 2023-07-05 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-05', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 297 2023-07-05 [15, 30, 60, 120] sym_freq_12 []
# 298 2023-07-05 [15, 30, 60, 120] sym_freq_9 []
# 299 2023-07-05 [15, 30, 60, 120] sym_freq_8 ['CCL']
# 300 2023-07-03 [30, 60, 120] sym_freq_12 []
# 301 2023-07-03 [30, 60, 120] sym_freq_9 []
# 302 2023-07-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 303 2023-07-03 [15, 30, 60, 120] sym_freq_12 []
# 304 2023-07-03 [15, 30, 60, 120] sym_freq_9 []
# 305 2023-07-03 [15, 30, 60, 120] sym_freq_8 ['CCL', 'SKYW', 'W']
# 306 2023-06-30 [30, 60, 120] sym_freq_12 []
# 307 2023-06-30 [30, 60, 120] sym_freq_9 []
# 308 2023-06-30 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-30', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 309 2023-06-30 [15, 30, 60, 120] sym_freq_12 []
# 310 2023-06-30 [15, 30, 60, 120] sym_freq_9 ['SKYW']
# 311 2023-06-30 [15, 30, 60, 120] sym_freq_8 ['CCL']
# 312 2023-06-29 [30, 60, 120] sym_freq_12 []
# 313 2023-06-29 [30, 60, 120] sym_freq_9 []
# 314 2023-06-29 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-29', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 315 2023-06-29 [15, 30, 60, 120] sym_freq_12 []
# 316 2023-06-29 [15, 30, 60, 120] sym_freq_9 []
# 317 2023-06-29 [15, 30, 60, 120] sym_freq_8 []
# 318 2023-06-28 [30, 60, 120] sym_freq_12 []
# 319 2023-06-28 [30, 60, 120] sym_freq_9 []
# 320 2023-06-28 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-28', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 321 2023-06-28 [15, 30, 60, 120] sym_freq_12 []
# 322 2023-06-28 [15, 30, 60, 120] sym_freq_9 []
# 323 2023-06-28 [15, 30, 60, 120] sym_freq_8 []
# 324 2023-06-27 [30, 60, 120] sym_freq_12 []
# 325 2023-06-27 [30, 60, 120] sym_freq_9 []
# 326 2023-06-27 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-27', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 327 2023-06-27 [15, 30, 60, 120] sym_freq_12 []
# 328 2023-06-27 [15, 30, 60, 120] sym_freq_9 []
# 329 2023-06-27 [15, 30, 60, 120] sym_freq_8 []
# 330 2023-06-26 [30, 60, 120] sym_freq_12 []
# 331 2023-06-26 [30, 60, 120] sym_freq_9 []
# 332 2023-06-26 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-26', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 333 2023-06-26 [15, 30, 60, 120] sym_freq_12 []
# 334 2023-06-26 [15, 30, 60, 120] sym_freq_9 []
# 335 2023-06-26 [15, 30, 60, 120] sym_freq_8 []
# 336 2023-06-23 [30, 60, 120] sym_freq_12 []
# 337 2023-06-23 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-23', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 338 2023-06-23 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-23', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 339 2023-06-23 [15, 30, 60, 120] sym_freq_12 []
# 340 2023-06-23 [15, 30, 60, 120] sym_freq_9 ['CCL', 'NVDA']
# 341 2023-06-23 [15, 30, 60, 120] sym_freq_8 ['AMPH']
# 342 2023-06-22 [30, 60, 120] sym_freq_12 []
# 343 2023-06-22 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-22', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 344 2023-06-22 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-22', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 345 2023-06-22 [15, 30, 60, 120] sym_freq_12 []
# 346 2023-06-22 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 347 2023-06-22 [15, 30, 60, 120] sym_freq_8 ['AMPH', 'PBR']
# 348 2023-06-21 [30, 60, 120] sym_freq_12 []
# 349 2023-06-21 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-21', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 350 2023-06-21 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-21', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 351 2023-06-21 [15, 30, 60, 120] sym_freq_12 []
# 352 2023-06-21 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 353 2023-06-21 [15, 30, 60, 120] sym_freq_8 []
# 354 2023-06-20 [30, 60, 120] sym_freq_12 []
# 355 2023-06-20 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-20', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 356 2023-06-20 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-20', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 357 2023-06-20 [15, 30, 60, 120] sym_freq_12 []
# 358 2023-06-20 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 359 2023-06-20 [15, 30, 60, 120] sym_freq_8 []
# 360 2023-06-16 [30, 60, 120] sym_freq_12 []
# 361 2023-06-16 [30, 60, 120] sym_freq_9 []
# 362 2023-06-16 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-16', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 363 2023-06-16 [15, 30, 60, 120] sym_freq_12 []
# 364 2023-06-16 [15, 30, 60, 120] sym_freq_9 ['SKYW']
# 365 2023-06-16 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 366 2023-06-15 [30, 60, 120] sym_freq_12 []
# 367 2023-06-15 [30, 60, 120] sym_freq_9 []
# 368 2023-06-15 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-15', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 369 2023-06-15 [15, 30, 60, 120] sym_freq_12 []
# 370 2023-06-15 [15, 30, 60, 120] sym_freq_9 []
# 371 2023-06-15 [15, 30, 60, 120] sym_freq_8 ['CCL', 'NVDA', 'SKYW']
# 372 2023-06-14 [30, 60, 120] sym_freq_12 []
# 373 2023-06-14 [30, 60, 120] sym_freq_9 []
# 374 2023-06-14 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-14', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA', 'SHV']]
#
# 375 2023-06-14 [15, 30, 60, 120] sym_freq_12 []
# 376 2023-06-14 [15, 30, 60, 120] sym_freq_9 ['AVGO']
# 377 2023-06-14 [15, 30, 60, 120] sym_freq_8 ['ORCL', 'SKYW']
# 378 2023-06-13 [30, 60, 120] sym_freq_12 []
# 379 2023-06-13 [30, 60, 120] sym_freq_9 []
# 380 2023-06-13 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 381 2023-06-13 [15, 30, 60, 120] sym_freq_12 []
# 382 2023-06-13 [15, 30, 60, 120] sym_freq_9 []
# 383 2023-06-13 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 384 2023-06-12 [30, 60, 120] sym_freq_12 []
# 385 2023-06-12 [30, 60, 120] sym_freq_9 []
# 386 2023-06-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 387 2023-06-12 [15, 30, 60, 120] sym_freq_12 []
# 388 2023-06-12 [15, 30, 60, 120] sym_freq_9 []
# 389 2023-06-12 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 390 2023-06-09 [30, 60, 120] sym_freq_12 []
# 391 2023-06-09 [30, 60, 120] sym_freq_9 []
# 392 2023-06-09 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-09', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 393 2023-06-09 [15, 30, 60, 120] sym_freq_12 []
# 394 2023-06-09 [15, 30, 60, 120] sym_freq_9 []
# 395 2023-06-09 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 396 2023-06-08 [30, 60, 120] sym_freq_12 []
# 397 2023-06-08 [30, 60, 120] sym_freq_9 []
# 398 2023-06-08 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-08', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 399 2023-06-08 [15, 30, 60, 120] sym_freq_12 []
# 400 2023-06-08 [15, 30, 60, 120] sym_freq_9 []
# 401 2023-06-08 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 402 2023-06-07 [30, 60, 120] sym_freq_12 []
# 403 2023-06-07 [30, 60, 120] sym_freq_9 []
# 404 2023-06-07 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-07', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 405 2023-06-07 [15, 30, 60, 120] sym_freq_12 []
# 406 2023-06-07 [15, 30, 60, 120] sym_freq_9 []
# 407 2023-06-07 [15, 30, 60, 120] sym_freq_8 []
# 408 2023-06-06 [30, 60, 120] sym_freq_12 []
# 409 2023-06-06 [30, 60, 120] sym_freq_9 []
# 410 2023-06-06 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-06', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 411 2023-06-06 [15, 30, 60, 120] sym_freq_12 []
# 412 2023-06-06 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 413 2023-06-06 [15, 30, 60, 120] sym_freq_8 []
# 414 2023-06-05 [30, 60, 120] sym_freq_12 []
# 415 2023-06-05 [30, 60, 120] sym_freq_9 []
# 416 2023-06-05 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-05', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 417 2023-06-05 [15, 30, 60, 120] sym_freq_12 []
# 418 2023-06-05 [15, 30, 60, 120] sym_freq_9 []
# 419 2023-06-05 [15, 30, 60, 120] sym_freq_8 ['META', 'SKYW']
# 420 2023-06-02 [30, 60, 120] sym_freq_12 []
# 421 2023-06-02 [30, 60, 120] sym_freq_9 []
# 422 2023-06-02 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-02', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 423 2023-06-02 [15, 30, 60, 120] sym_freq_12 []
# 424 2023-06-02 [15, 30, 60, 120] sym_freq_9 ['META']
# 425 2023-06-02 [15, 30, 60, 120] sym_freq_8 []
# 426 2023-06-01 [30, 60, 120] sym_freq_12 []
# 427 2023-06-01 [30, 60, 120] sym_freq_9 []
# 428 2023-06-01 [30, 60, 120] sym_freq_8 ['META', 'NVDA']
# added row to df_model_top_picks:
# ['2023-06-01', [30, 60, 120], 'sym_freq_8', ['META', 'NVDA']]
#
# 429 2023-06-01 [15, 30, 60, 120] sym_freq_12 []
# 430 2023-06-01 [15, 30, 60, 120] sym_freq_9 ['AVGO', 'RMBS']
# 431 2023-06-01 [15, 30, 60, 120] sym_freq_8 []
# 432 2023-05-31 [30, 60, 120] sym_freq_12 []
# 433 2023-05-31 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-31', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 434 2023-05-31 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-31', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA']]
#
# 435 2023-05-31 [15, 30, 60, 120] sym_freq_12 []
# 436 2023-05-31 [15, 30, 60, 120] sym_freq_9 []
# 437 2023-05-31 [15, 30, 60, 120] sym_freq_8 ['RMBS']
# 438 2023-05-30 [30, 60, 120] sym_freq_12 []
# 439 2023-05-30 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 440 2023-05-30 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-30', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA']]
#
# 441 2023-05-30 [15, 30, 60, 120] sym_freq_12 []
# 442 2023-05-30 [15, 30, 60, 120] sym_freq_9 []
# 443 2023-05-30 [15, 30, 60, 120] sym_freq_8 []
# 444 2023-05-26 [30, 60, 120] sym_freq_12 []
# 445 2023-05-26 [30, 60, 120] sym_freq_9 ['AVGO', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-26', [30, 60, 120], 'sym_freq_9', ['AVGO', 'SHV']]
#
# 446 2023-05-26 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-05-26', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 447 2023-05-26 [15, 30, 60, 120] sym_freq_12 ['AVGO']
# added row to df_model_top_picks:
# ['2023-05-26', [15, 30, 60, 120], 'sym_freq_12', ['AVGO']]
#
# 448 2023-05-26 [15, 30, 60, 120] sym_freq_9 ['RMBS']
# 449 2023-05-26 [15, 30, 60, 120] sym_freq_8 ['AMD']
# 450 2023-05-25 [30, 60, 120] sym_freq_12 []
# 451 2023-05-25 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-25', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 452 2023-05-25 [30, 60, 120] sym_freq_8 ['FTSM', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-25', [30, 60, 120], 'sym_freq_8', ['FTSM', 'NVDA']]
#
# 453 2023-05-25 [15, 30, 60, 120] sym_freq_12 []
# 454 2023-05-25 [15, 30, 60, 120] sym_freq_9 []
# 455 2023-05-25 [15, 30, 60, 120] sym_freq_8 ['FTSM']
# 456 2023-05-24 [30, 60, 120] sym_freq_12 []
# 457 2023-05-24 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-24', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 458 2023-05-24 [30, 60, 120] sym_freq_8 []
# 459 2023-05-24 [15, 30, 60, 120] sym_freq_12 []
# 460 2023-05-24 [15, 30, 60, 120] sym_freq_9 []
# 461 2023-05-24 [15, 30, 60, 120] sym_freq_8 []
# 462 2023-05-23 [30, 60, 120] sym_freq_12 []
# 463 2023-05-23 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 464 2023-05-23 [30, 60, 120] sym_freq_8 []
# 465 2023-05-23 [15, 30, 60, 120] sym_freq_12 []
# 466 2023-05-23 [15, 30, 60, 120] sym_freq_9 []
# 467 2023-05-23 [15, 30, 60, 120] sym_freq_8 []
# 468 2023-05-22 [30, 60, 120] sym_freq_12 []
# 469 2023-05-22 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 470 2023-05-22 [30, 60, 120] sym_freq_8 []
# 471 2023-05-22 [15, 30, 60, 120] sym_freq_12 []
# 472 2023-05-22 [15, 30, 60, 120] sym_freq_9 []
# 473 2023-05-22 [15, 30, 60, 120] sym_freq_8 []
# 474 2023-05-19 [30, 60, 120] sym_freq_12 []
# 475 2023-05-19 [30, 60, 120] sym_freq_9 []
# 476 2023-05-19 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 477 2023-05-19 [15, 30, 60, 120] sym_freq_12 []
# 478 2023-05-19 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 479 2023-05-19 [15, 30, 60, 120] sym_freq_8 []
# 480 2023-05-18 [30, 60, 120] sym_freq_12 []
# 481 2023-05-18 [30, 60, 120] sym_freq_9 []
# 482 2023-05-18 [30, 60, 120] sym_freq_8 ['SHV', 'TMHC']
# added row to df_model_top_picks:
# ['2023-05-18', [30, 60, 120], 'sym_freq_8', ['SHV', 'TMHC']]
#
# 483 2023-05-18 [15, 30, 60, 120] sym_freq_12 []
# 484 2023-05-18 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 485 2023-05-18 [15, 30, 60, 120] sym_freq_8 ['TMHC']
# 486 2023-05-17 [30, 60, 120] sym_freq_12 []
# 487 2023-05-17 [30, 60, 120] sym_freq_9 []
# 488 2023-05-17 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-17', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 489 2023-05-17 [15, 30, 60, 120] sym_freq_12 []
# 490 2023-05-17 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 491 2023-05-17 [15, 30, 60, 120] sym_freq_8 []
# 492 2023-05-16 [30, 60, 120] sym_freq_12 []
# 493 2023-05-16 [30, 60, 120] sym_freq_9 []
# 494 2023-05-16 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-16', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 495 2023-05-16 [15, 30, 60, 120] sym_freq_12 []
# 496 2023-05-16 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 497 2023-05-16 [15, 30, 60, 120] sym_freq_8 []
# 498 2023-05-15 [30, 60, 120] sym_freq_12 []
# 499 2023-05-15 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 500 2023-05-15 [30, 60, 120] sym_freq_8 []
# 501 2023-05-15 [15, 30, 60, 120] sym_freq_12 []
# 502 2023-05-15 [15, 30, 60, 120] sym_freq_9 []
# 503 2023-05-15 [15, 30, 60, 120] sym_freq_8 ['ISEE']
# 504 2023-05-12 [30, 60, 120] sym_freq_12 []
# 505 2023-05-12 [30, 60, 120] sym_freq_9 []
# 506 2023-05-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 507 2023-05-12 [15, 30, 60, 120] sym_freq_12 []
# 508 2023-05-12 [15, 30, 60, 120] sym_freq_9 ['ISEE', 'SHV']
# 509 2023-05-12 [15, 30, 60, 120] sym_freq_8 []
# 510 2023-05-11 [30, 60, 120] sym_freq_12 []
# 511 2023-05-11 [30, 60, 120] sym_freq_9 []
# 512 2023-05-11 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-11', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 513 2023-05-11 [15, 30, 60, 120] sym_freq_12 []
# 514 2023-05-11 [15, 30, 60, 120] sym_freq_9 ['BLDR']
# 515 2023-05-11 [15, 30, 60, 120] sym_freq_8 []
# 516 2023-05-10 [30, 60, 120] sym_freq_12 []
# 517 2023-05-10 [30, 60, 120] sym_freq_9 []
# 518 2023-05-10 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-10', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 519 2023-05-10 [15, 30, 60, 120] sym_freq_12 []
# 520 2023-05-10 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 521 2023-05-10 [15, 30, 60, 120] sym_freq_8 ['BLDR']
# 522 2023-05-09 [30, 60, 120] sym_freq_12 []
# 523 2023-05-09 [30, 60, 120] sym_freq_9 []
# 524 2023-05-09 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-09', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 525 2023-05-09 [15, 30, 60, 120] sym_freq_12 []
# 526 2023-05-09 [15, 30, 60, 120] sym_freq_9 ['BLDR']
# 527 2023-05-09 [15, 30, 60, 120] sym_freq_8 []
# 528 2023-05-08 [30, 60, 120] sym_freq_12 []
# 529 2023-05-08 [30, 60, 120] sym_freq_9 []
# 530 2023-05-08 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-08', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 531 2023-05-08 [15, 30, 60, 120] sym_freq_12 []
# 532 2023-05-08 [15, 30, 60, 120] sym_freq_9 []
# 533 2023-05-08 [15, 30, 60, 120] sym_freq_8 []
# 534 2023-05-05 [30, 60, 120] sym_freq_12 []
# 535 2023-05-05 [30, 60, 120] sym_freq_9 []
# 536 2023-05-05 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-05', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 537 2023-05-05 [15, 30, 60, 120] sym_freq_12 []
# 538 2023-05-05 [15, 30, 60, 120] sym_freq_9 []
# 539 2023-05-05 [15, 30, 60, 120] sym_freq_8 []
# 540 2023-05-04 [30, 60, 120] sym_freq_12 []
# 541 2023-05-04 [30, 60, 120] sym_freq_9 []
# 542 2023-05-04 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 543 2023-05-04 [15, 30, 60, 120] sym_freq_12 []
# 544 2023-05-04 [15, 30, 60, 120] sym_freq_9 ['CCEP']
# 545 2023-05-04 [15, 30, 60, 120] sym_freq_8 []
# 546 2023-05-03 [30, 60, 120] sym_freq_12 []
# 547 2023-05-03 [30, 60, 120] sym_freq_9 []
# 548 2023-05-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 549 2023-05-03 [15, 30, 60, 120] sym_freq_12 []
# 550 2023-05-03 [15, 30, 60, 120] sym_freq_9 ['ISEE']
# 551 2023-05-03 [15, 30, 60, 120] sym_freq_8 ['CCEP', 'SHV', 'SKYW']
# 552 2023-05-02 [30, 60, 120] sym_freq_12 []
# 553 2023-05-02 [30, 60, 120] sym_freq_9 []
# 554 2023-05-02 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 555 2023-05-02 [15, 30, 60, 120] sym_freq_12 []
# 556 2023-05-02 [15, 30, 60, 120] sym_freq_9 ['CCEP', 'ISEE', 'SHV']
# 557 2023-05-02 [15, 30, 60, 120] sym_freq_8 []
# 558 2023-05-01 [30, 60, 120] sym_freq_12 []
# 559 2023-05-01 [30, 60, 120] sym_freq_9 []
# 560 2023-05-01 [30, 60, 120] sym_freq_8 []
# 561 2023-05-01 [15, 30, 60, 120] sym_freq_12 []
# 562 2023-05-01 [15, 30, 60, 120] sym_freq_9 []
# 563 2023-05-01 [15, 30, 60, 120] sym_freq_8 ['ISEE']
# 564 2023-04-28 [30, 60, 120] sym_freq_12 []
# 565 2023-04-28 [30, 60, 120] sym_freq_9 []
# 566 2023-04-28 [30, 60, 120] sym_freq_8 []
# 567 2023-04-28 [15, 30, 60, 120] sym_freq_12 []
# 568 2023-04-28 [15, 30, 60, 120] sym_freq_9 []
# 569 2023-04-28 [15, 30, 60, 120] sym_freq_8 ['PHM', 'SHV']
# 570 2023-04-27 [30, 60, 120] sym_freq_12 []
# 571 2023-04-27 [30, 60, 120] sym_freq_9 []
# 572 2023-04-27 [30, 60, 120] sym_freq_8 []
# 573 2023-04-27 [15, 30, 60, 120] sym_freq_12 []
# 574 2023-04-27 [15, 30, 60, 120] sym_freq_9 []
# 575 2023-04-27 [15, 30, 60, 120] sym_freq_8 ['PHM', 'SHV']
# 576 2023-04-26 [30, 60, 120] sym_freq_12 []
# 577 2023-04-26 [30, 60, 120] sym_freq_9 []
# 578 2023-04-26 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-26', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 579 2023-04-26 [15, 30, 60, 120] sym_freq_12 []
# 580 2023-04-26 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 581 2023-04-26 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 582 2023-04-25 [30, 60, 120] sym_freq_12 []
# 583 2023-04-25 [30, 60, 120] sym_freq_9 []
# 584 2023-04-25 [30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-25', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 585 2023-04-25 [15, 30, 60, 120] sym_freq_12 []
# 586 2023-04-25 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 587 2023-04-25 [15, 30, 60, 120] sym_freq_8 ['ELF']
# 588 2023-04-24 [30, 60, 120] sym_freq_12 []
# 589 2023-04-24 [30, 60, 120] sym_freq_9 []
# 590 2023-04-24 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-24', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 591 2023-04-24 [15, 30, 60, 120] sym_freq_12 []
# 592 2023-04-24 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 593 2023-04-24 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 594 2023-04-21 [30, 60, 120] sym_freq_12 []
# 595 2023-04-21 [30, 60, 120] sym_freq_9 []
# 596 2023-04-21 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-21', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 597 2023-04-21 [15, 30, 60, 120] sym_freq_12 []
# 598 2023-04-21 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 599 2023-04-21 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 600 2023-04-20 [30, 60, 120] sym_freq_12 []
# 601 2023-04-20 [30, 60, 120] sym_freq_9 []
# 602 2023-04-20 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-20', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 603 2023-04-20 [15, 30, 60, 120] sym_freq_12 []
# 604 2023-04-20 [15, 30, 60, 120] sym_freq_9 []
# 605 2023-04-20 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 606 2023-04-19 [30, 60, 120] sym_freq_12 []
# 607 2023-04-19 [30, 60, 120] sym_freq_9 []
# 608 2023-04-19 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 609 2023-04-19 [15, 30, 60, 120] sym_freq_12 []
# 610 2023-04-19 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 611 2023-04-19 [15, 30, 60, 120] sym_freq_8 []
# 612 2023-04-18 [30, 60, 120] sym_freq_12 []
# 613 2023-04-18 [30, 60, 120] sym_freq_9 []
# 614 2023-04-18 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 615 2023-04-18 [15, 30, 60, 120] sym_freq_12 []
# 616 2023-04-18 [15, 30, 60, 120] sym_freq_9 []
# 617 2023-04-18 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 618 2023-04-17 [30, 60, 120] sym_freq_12 []
# 619 2023-04-17 [30, 60, 120] sym_freq_9 []
# 620 2023-04-17 [30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-17', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 621 2023-04-17 [15, 30, 60, 120] sym_freq_12 []
# 622 2023-04-17 [15, 30, 60, 120] sym_freq_9 []
# 623 2023-04-17 [15, 30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# 624 2023-04-14 [30, 60, 120] sym_freq_12 []
# 625 2023-04-14 [30, 60, 120] sym_freq_9 []
# 626 2023-04-14 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 627 2023-04-14 [15, 30, 60, 120] sym_freq_12 []
# 628 2023-04-14 [15, 30, 60, 120] sym_freq_9 []
# 629 2023-04-14 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 630 2023-04-13 [30, 60, 120] sym_freq_12 []
# 631 2023-04-13 [30, 60, 120] sym_freq_9 []
# 632 2023-04-13 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 633 2023-04-13 [15, 30, 60, 120] sym_freq_12 []
# 634 2023-04-13 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 635 2023-04-13 [15, 30, 60, 120] sym_freq_8 []
# 636 2023-04-12 [30, 60, 120] sym_freq_12 []
# 637 2023-04-12 [30, 60, 120] sym_freq_9 []
# 638 2023-04-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 639 2023-04-12 [15, 30, 60, 120] sym_freq_12 []
# 640 2023-04-12 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 641 2023-04-12 [15, 30, 60, 120] sym_freq_8 []
# 642 2023-04-11 [30, 60, 120] sym_freq_12 []
# 643 2023-04-11 [30, 60, 120] sym_freq_9 []
# 644 2023-04-11 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-11', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 645 2023-04-11 [15, 30, 60, 120] sym_freq_12 []
# 646 2023-04-11 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 647 2023-04-11 [15, 30, 60, 120] sym_freq_8 []
# 648 2023-04-10 [30, 60, 120] sym_freq_12 []
# 649 2023-04-10 [30, 60, 120] sym_freq_9 []
# 650 2023-04-10 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-10', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 651 2023-04-10 [15, 30, 60, 120] sym_freq_12 []
# 652 2023-04-10 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 653 2023-04-10 [15, 30, 60, 120] sym_freq_8 []
# 654 2023-04-06 [30, 60, 120] sym_freq_12 []
# 655 2023-04-06 [30, 60, 120] sym_freq_9 []
# 656 2023-04-06 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-06', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 657 2023-04-06 [15, 30, 60, 120] sym_freq_12 []
# 658 2023-04-06 [15, 30, 60, 120] sym_freq_9 []
# 659 2023-04-06 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 660 2023-04-05 [30, 60, 120] sym_freq_12 []
# 661 2023-04-05 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 662 2023-04-05 [30, 60, 120] sym_freq_8 []
# 663 2023-04-05 [15, 30, 60, 120] sym_freq_12 []
# 664 2023-04-05 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 665 2023-04-05 [15, 30, 60, 120] sym_freq_8 []
# 666 2023-04-04 [30, 60, 120] sym_freq_12 []
# 667 2023-04-04 [30, 60, 120] sym_freq_9 []
# 668 2023-04-04 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-04', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 669 2023-04-04 [15, 30, 60, 120] sym_freq_12 []
# 670 2023-04-04 [15, 30, 60, 120] sym_freq_9 []
# 671 2023-04-04 [15, 30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# 672 2023-04-03 [30, 60, 120] sym_freq_12 []
# 673 2023-04-03 [30, 60, 120] sym_freq_9 []
# 674 2023-04-03 [30, 60, 120] sym_freq_8 ['GE', 'NVDA']
# added row to df_model_top_picks:
# ['2023-04-03', [30, 60, 120], 'sym_freq_8', ['GE', 'NVDA']]
#
# 675 2023-04-03 [15, 30, 60, 120] sym_freq_12 []
# 676 2023-04-03 [15, 30, 60, 120] sym_freq_9 []
# 677 2023-04-03 [15, 30, 60, 120] sym_freq_8 ['GE', 'PERI']
# 678 2023-03-31 [30, 60, 120] sym_freq_12 []
# 679 2023-03-31 [30, 60, 120] sym_freq_9 []
# 680 2023-03-31 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-03-31', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 681 2023-03-31 [15, 30, 60, 120] sym_freq_12 []
# 682 2023-03-31 [15, 30, 60, 120] sym_freq_9 []
# 683 2023-03-31 [15, 30, 60, 120] sym_freq_8 []
# 684 2023-03-30 [30, 60, 120] sym_freq_12 []
# 685 2023-03-30 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 686 2023-03-30 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 687 2023-03-30 [15, 30, 60, 120] sym_freq_12 []
# 688 2023-03-30 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 689 2023-03-30 [15, 30, 60, 120] sym_freq_8 []
# 690 2023-03-29 [30, 60, 120] sym_freq_12 []
# 691 2023-03-29 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-29', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 692 2023-03-29 [30, 60, 120] sym_freq_8 []
# 693 2023-03-29 [15, 30, 60, 120] sym_freq_12 []
# 694 2023-03-29 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 695 2023-03-29 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 696 2023-03-28 [30, 60, 120] sym_freq_12 []
# 697 2023-03-28 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-28', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 698 2023-03-28 [30, 60, 120] sym_freq_8 []
# 699 2023-03-28 [15, 30, 60, 120] sym_freq_12 []
# 700 2023-03-28 [15, 30, 60, 120] sym_freq_9 []
# 701 2023-03-28 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 702 2023-03-27 [30, 60, 120] sym_freq_12 []
# 703 2023-03-27 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 704 2023-03-27 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 705 2023-03-27 [15, 30, 60, 120] sym_freq_12 []
# 706 2023-03-27 [15, 30, 60, 120] sym_freq_9 []
# 707 2023-03-27 [15, 30, 60, 120] sym_freq_8 ['GE', 'NVDA', 'SGEN']
# 708 2023-03-24 [30, 60, 120] sym_freq_12 []
# 709 2023-03-24 [30, 60, 120] sym_freq_9 []
# 710 2023-03-24 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-24', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 711 2023-03-24 [15, 30, 60, 120] sym_freq_12 []
# 712 2023-03-24 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 713 2023-03-24 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 714 2023-03-23 [30, 60, 120] sym_freq_12 []
# 715 2023-03-23 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 716 2023-03-23 [30, 60, 120] sym_freq_8 []
# 717 2023-03-23 [15, 30, 60, 120] sym_freq_12 []
# 718 2023-03-23 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 719 2023-03-23 [15, 30, 60, 120] sym_freq_8 ['FTSM', 'GE']
# 720 2023-03-22 [30, 60, 120] sym_freq_12 []
# 721 2023-03-22 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 722 2023-03-22 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 723 2023-03-22 [15, 30, 60, 120] sym_freq_12 []
# 724 2023-03-22 [15, 30, 60, 120] sym_freq_9 ['FTSM', 'NVDA']
# 725 2023-03-22 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 726 2023-03-21 [30, 60, 120] sym_freq_12 []
# 727 2023-03-21 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 728 2023-03-21 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 729 2023-03-21 [15, 30, 60, 120] sym_freq_12 []
# 730 2023-03-21 [15, 30, 60, 120] sym_freq_9 ['GE']
# 731 2023-03-21 [15, 30, 60, 120] sym_freq_8 []
# 732 2023-03-20 [30, 60, 120] sym_freq_12 []
# 733 2023-03-20 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 734 2023-03-20 [30, 60, 120] sym_freq_8 []
# 735 2023-03-20 [15, 30, 60, 120] sym_freq_12 []
# 736 2023-03-20 [15, 30, 60, 120] sym_freq_9 []
# 737 2023-03-20 [15, 30, 60, 120] sym_freq_8 []
# 738 2023-03-17 [30, 60, 120] sym_freq_12 []
# 739 2023-03-17 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 740 2023-03-17 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 741 2023-03-17 [15, 30, 60, 120] sym_freq_12 []
# 742 2023-03-17 [15, 30, 60, 120] sym_freq_9 ['FTSM', 'GE']
# 743 2023-03-17 [15, 30, 60, 120] sym_freq_8 []
# 744 2023-03-16 [30, 60, 120] sym_freq_12 []
# 745 2023-03-16 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-16', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 746 2023-03-16 [30, 60, 120] sym_freq_8 []
# 747 2023-03-16 [15, 30, 60, 120] sym_freq_12 []
# 748 2023-03-16 [15, 30, 60, 120] sym_freq_9 ['SGEN']
# 749 2023-03-16 [15, 30, 60, 120] sym_freq_8 []
# 750 2023-03-15 [30, 60, 120] sym_freq_12 []
# 751 2023-03-15 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 752 2023-03-15 [30, 60, 120] sym_freq_8 []
# 753 2023-03-15 [15, 30, 60, 120] sym_freq_12 []
# 754 2023-03-15 [15, 30, 60, 120] sym_freq_9 ['SGEN']
# 755 2023-03-15 [15, 30, 60, 120] sym_freq_8 ['AMPH', 'FCN']

# %%
df_model_top_picks = df_model_top_picks.astype(str)
df_model_top_picks = df_model_top_picks.drop_duplicates(keep='last')
df_model_top_picks = df_model_top_picks.sort_values(by=['date', 'days_lookback', 'syms_freq'], ascending=False)
df_model_top_picks = df_model_top_picks.reset_index(drop=True)
pickle_dump(df_model_top_picks, path_data_dump, fp_df_model_top_picks)
print(f'len(df_model_top_picks): {len(df_model_top_picks)}')
print(f'{fp_df_model_top_picks}:\n{df_model_top_picks}')
# Out:
# len(df_model_top_picks): 165
# df_model_top_picks:
#            date      days_lookback    syms_freq          symbols
# 0    2023-10-19      [30, 60, 120]   sym_freq_9  ['FTSM', 'SHV']
# 1    2023-10-19  [15, 30, 60, 120]  sym_freq_12          ['SHV']
# 2    2023-10-17      [30, 60, 120]   sym_freq_9  ['FTSM', 'SHV']
# 3    2023-10-12      [30, 60, 120]   sym_freq_9  ['FTSM', 'SHV']
# 4    2023-10-06      [30, 60, 120]   sym_freq_9  ['FTSM', 'SHV']
# ..          ...                ...          ...              ...
# 160  2023-03-20      [30, 60, 120]   sym_freq_9  ['FTSM', 'SHV']
# 161  2023-03-17      [30, 60, 120]   sym_freq_9  ['FTSM', 'SHV']
# 162  2023-03-17      [30, 60, 120]   sym_freq_8           ['GE']
# 163  2023-03-16      [30, 60, 120]   sym_freq_9  ['FTSM', 'SHV']
# 164  2023-03-15      [30, 60, 120]   sym_freq_9  ['FTSM', 'SHV']
#
# [165 rows x 4 columns]

# %%
df_mp = df_model_top_picks.copy()
df_close = pickle_load(path_data_dump, 'df_close_clean')

# %%
def get_NYSE_date_n(date, dates_NYSE, n, verbose=False):

  if date in dates_NYSE:
    idx_last = len(dates_NYSE) - 1  # last index of dates_NYSE
    idx_date = dates_NYSE.get_loc(date)  # index of date
    idx_date_n = idx_date + n  # index of date_n
    if verbose:
      print(f"date: {date} is in dates_NYSE,  date's position in dates_NYSE is: {idx_date} of {idx_last},  n: {n},  idx_date_n: {idx_date_n},")
    if 0 <= idx_date_n <= idx_last:  # idx_date_n is within bounds of dates_NYSE
      date_n = dates_NYSE[idx_date_n]
      if verbose:      
        print(f'idx_date_n: {idx_date_n} is wiithin bounds of dates_NYSE ("0 to {idx_last}), date_n: {date_n}"\n')
    else:  # idx_date_n is out-of-bounds of dates_NYSE
      date_n = None   
      if verbose:  
        print(f'idx_date_n: {idx_date_n} is out-of-bounds of dates_NYSE ("0 to {idx_last})"\n')
  else:  # date not in dates_NYSE
      date_n = None  
      if verbose:  
        print(f'date: {date} is not in dates_NYSE\n')

  return date_n

# %%
def get_portf_buy(df_close, date, str_symbols, portf_target, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    sym_cnt = len(l_syms)  # number of symbols
    amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
    ar_sym_share = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
    ar_sym_amt = ar_price * ar_sym_share  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_sym_amt)  # total actual portfolio value
    if verbose:
        # print(date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value)    
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_sym_share = }, {ar_sym_amt = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value

# %%
def get_SPY_buy(df_close, date, portf_target, symbol="SPY", verbose=False):   
    import numpy as np
    price = df_close.loc[date][symbol]    
    share = np.floor(portf_target / price)  # array of shares for each symbol
    value = price * share  # array of actual dollar amount invested in each symbol
    if verbose:
        # print(date, symbol, price, share, value)
        print(f'{date = }, {symbol = }, {price = }, {share = }, {value = }')                        
        print(f'{date} {symbol} {value = }')
    return date, price, share, value

# %%
import pandas_market_calendars as mcal
nyse = mcal.get_calendar('NYSE')
dates_NYSE_2013_2023 = nyse.valid_days(start_date='2013-01-01', end_date='2023-12-31').strftime('%Y-%m-%d')
print(f'len(dates_NYSE_2013_2023): {len(dates_NYSE_2013_2023)}')
print(f'dates_NYSE_2013_2023[0]:  {dates_NYSE_2013_2023[0]}, dates_NYSE_2013_2023[-1]: {dates_NYSE_2013_2023[-1]}')
print(f'{dates_NYSE_2013_2023}')
# Out:
# len(dates_NYSE_2013_2023): 2768
# dates_NYSE_2013_2023[0]:  2013-01-02, dates_NYSE_2013_2023[-1]: 2023-12-29
# Index(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-07', '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-14', '2013-01-15',
#        ...
#        '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20', '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29'], dtype='object', length=2768)

# %% [markdown]
# #### TODO: 2023-07-15 only evaluate performance of df_model_picks, after evaluation, append results to df_model_picks_results
#
#
# #### 2023-07-11 got KeyError: "['ISEE'] not in index". ISEE was in past model picks, but since then ISEE was acquired. The symbol was dropped from df_close_clean. Current program recalculate the performance of all the past picks. Rewrite program such that performance of past picks with win records are not recalculated.

# %%
import numpy as np
# from ast import literal_eval
z_date_syms = zip(df_mp.date, df_mp.symbols)

idx_close = df_close.index.strftime('%Y-%m-%d')

n = 1  # n=1 is the buy date
# n = 4  # n=4 is the sell date

date_buy = []  # buy date of portfolio
shares_syms = []  # lists of shares of each symbol brought on date_buy
value_portf = [] # list of porfolio value on date_buy
shares_SPY = []  # list of shares of SPY brought on date_buy
value_SPY = []  # list of value of SPY shares on date_buy 
for date, syms in z_date_syms:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=verbose)

    if next_date_n in idx_close:
        close_date_n = next_date_n
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is in df_close')
        print(f'picks for {date}: {syms}')      
    else:
        close_date_n = None
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is not in df_close')
        print(f'picks for {date}: {syms}')        

    if close_date_n is None:
        p_date = None
        p_l_syms = None
        p_ar_price = None
        p_ar_sym_share = None
        p_ar_sym_amt = None
        p_portf_value = None  # data not available in df_close
        
        s_date = None
        s_price = None
        s_share = None
        s_value = None  # data not available in df_close

        date_buy.append(p_date)
        shares_syms.append(p_l_syms)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)    
        
        print(f"No data for next_date_n {next_date_n}, pick's portf value = None")
        print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else:    
        p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
            get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
        s_date, s_price, s_share, s_value = \
            get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
                
        date_buy.append(p_date)
        shares_syms.append(p_ar_sym_share)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)

        print(f"next_date_n pick's portf value = {p_portf_value}")
        print(f'next_date_n SPY portf value =    {s_value}')

    print('='*20, '\n')
# Out:
# date: 2023-10-19 is in dates_NYSE,  date's position in dates_NYSE is: 2718 of 2767,  n: 1,  idx_date_n: 2719,
# idx_date_n: 2719 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-20"
#
# date: 2023-10-19,  n: 1,  next_date_n: 2023-10-20 is not in df_close
# picks for 2023-10-19: ['FTSM', 'SHV']
# No data for next_date_n 2023-10-20, pick's portf value = None
# No data for next_date_n 2023-10-20, SPY portf value =    None
# ====================
#
# date: 2023-10-19 is in dates_NYSE,  date's position in dates_NYSE is: 2718 of 2767,  n: 1,  idx_date_n: 2719,
# idx_date_n: 2719 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-20"
#
# date: 2023-10-19,  n: 1,  next_date_n: 2023-10-20 is not in df_close
# picks for 2023-10-19: ['SHV']
# No data for next_date_n 2023-10-20, pick's portf value = None
# No data for next_date_n 2023-10-20, SPY portf value =    None
# ====================
#
# date: 2023-10-17 is in dates_NYSE,  date's position in dates_NYSE is: 2716 of 2767,  n: 1,  idx_date_n: 2717,
# idx_date_n: 2717 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-18"
#
# date: 2023-10-17,  n: 1,  next_date_n: 2023-10-18 is in df_close
# picks for 2023-10-17: ['FTSM', 'SHV']
# date = '2023-10-18', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.54999924, 110.29000092]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([476.3999939 , 441.16000366]), portf_value = 917.5599975585938
# 2023-10-18 portf_value = 917.5599975585938
# date = '2023-10-18', symbol = 'SPY', price = 430.2099914550781, share = 2.0, value = 860.4199829101562
# 2023-10-18 SPY value = 860.4199829101562
# next_date_n pick's portf value = 917.5599975585938
# next_date_n SPY portf value =    860.4199829101562
# ====================
#
# date: 2023-10-12 is in dates_NYSE,  date's position in dates_NYSE is: 2713 of 2767,  n: 1,  idx_date_n: 2714,
# idx_date_n: 2714 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-13"
#
# date: 2023-10-12,  n: 1,  next_date_n: 2023-10-13 is in df_close
# picks for 2023-10-12: ['FTSM', 'SHV']
# date = '2023-10-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.56999969, 110.26000214]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([476.55999756, 441.04000854]), portf_value = 917.6000061035156
# 2023-10-13 portf_value = 917.6000061035156
# date = '2023-10-13', symbol = 'SPY', price = 431.5, share = 2.0, value = 863.0
# 2023-10-13 SPY value = 863.0
# next_date_n pick's portf value = 917.6000061035156
# next_date_n SPY portf value =    863.0
# ====================
#
# date: 2023-10-06 is in dates_NYSE,  date's position in dates_NYSE is: 2709 of 2767,  n: 1,  idx_date_n: 2710,
# idx_date_n: 2710 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-09"
#
# date: 2023-10-06,  n: 1,  next_date_n: 2023-10-09 is in df_close
# picks for 2023-10-06: ['FTSM', 'SHV']
# date = '2023-10-09', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.50999832, 110.16000366]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([476.07998657, 440.64001465]), portf_value = 916.7200012207031
# 2023-10-09 portf_value = 916.7200012207031
# date = '2023-10-09', symbol = 'SPY', price = 432.2900085449219, share = 2.0, value = 864.5800170898438
# 2023-10-09 SPY value = 864.5800170898438
# next_date_n pick's portf value = 916.7200012207031
# next_date_n SPY portf value =    864.5800170898438
# ====================
#
# date: 2023-10-06 is in dates_NYSE,  date's position in dates_NYSE is: 2709 of 2767,  n: 1,  idx_date_n: 2710,
# idx_date_n: 2710 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-09"
#
# date: 2023-10-06,  n: 1,  next_date_n: 2023-10-09 is in df_close
# picks for 2023-10-06: ['SHV']
# date = '2023-10-09', l_syms = ['SHV'], ar_price = array([110.16000366]), ar_sym_share = array([9.]), ar_sym_amt = array([991.44003296]), portf_value = 991.4400329589844
# 2023-10-09 portf_value = 991.4400329589844
# date = '2023-10-09', symbol = 'SPY', price = 432.2900085449219, share = 2.0, value = 864.5800170898438
# 2023-10-09 SPY value = 864.5800170898438
# next_date_n pick's portf value = 991.4400329589844
# next_date_n SPY portf value =    864.5800170898438
# ====================
#
# date: 2023-10-05 is in dates_NYSE,  date's position in dates_NYSE is: 2708 of 2767,  n: 1,  idx_date_n: 2709,
# idx_date_n: 2709 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-06"
#
# date: 2023-10-05,  n: 1,  next_date_n: 2023-10-06 is in df_close
# picks for 2023-10-05: ['FTSM', 'SHV']
# date = '2023-10-06', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.47999954, 110.15000153]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.83999634, 440.6000061 ]), portf_value = 916.4400024414062
# 2023-10-06 portf_value = 916.4400024414062
# date = '2023-10-06', symbol = 'SPY', price = 429.5400085449219, share = 2.0, value = 859.0800170898438
# 2023-10-06 SPY value = 859.0800170898438
# next_date_n pick's portf value = 916.4400024414062
# next_date_n SPY portf value =    859.0800170898438
# ====================
#
# date: 2023-10-05 is in dates_NYSE,  date's position in dates_NYSE is: 2708 of 2767,  n: 1,  idx_date_n: 2709,
# idx_date_n: 2709 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-06"
#
# date: 2023-10-05,  n: 1,  next_date_n: 2023-10-06 is in df_close
# picks for 2023-10-05: ['FTSM', 'SHV']
# date = '2023-10-06', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.47999954, 110.15000153]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.83999634, 440.6000061 ]), portf_value = 916.4400024414062
# 2023-10-06 portf_value = 916.4400024414062
# date = '2023-10-06', symbol = 'SPY', price = 429.5400085449219, share = 2.0, value = 859.0800170898438
# 2023-10-06 SPY value = 859.0800170898438
# next_date_n pick's portf value = 916.4400024414062
# next_date_n SPY portf value =    859.0800170898438
# ====================
#
# date: 2023-10-04 is in dates_NYSE,  date's position in dates_NYSE is: 2707 of 2767,  n: 1,  idx_date_n: 2708,
# idx_date_n: 2708 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-05"
#
# date: 2023-10-04,  n: 1,  next_date_n: 2023-10-05 is in df_close
# picks for 2023-10-04: ['FTSM', 'SHV']
# date = '2023-10-05', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.49000168, 110.13999939]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.92001343, 440.55999756]), portf_value = 916.4800109863281
# 2023-10-05 portf_value = 916.4800109863281
# date = '2023-10-05', symbol = 'SPY', price = 424.5, share = 2.0, value = 849.0
# 2023-10-05 SPY value = 849.0
# next_date_n pick's portf value = 916.4800109863281
# next_date_n SPY portf value =    849.0
# ====================
#
# date: 2023-10-04 is in dates_NYSE,  date's position in dates_NYSE is: 2707 of 2767,  n: 1,  idx_date_n: 2708,
# idx_date_n: 2708 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-05"
#
# date: 2023-10-04,  n: 1,  next_date_n: 2023-10-05 is in df_close
# picks for 2023-10-04: ['FTSM', 'SHV']
# date = '2023-10-05', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.49000168, 110.13999939]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.92001343, 440.55999756]), portf_value = 916.4800109863281
# 2023-10-05 portf_value = 916.4800109863281
# date = '2023-10-05', symbol = 'SPY', price = 424.5, share = 2.0, value = 849.0
# 2023-10-05 SPY value = 849.0
# next_date_n pick's portf value = 916.4800109863281
# next_date_n SPY portf value =    849.0
# ====================
#
# date: 2023-10-02 is in dates_NYSE,  date's position in dates_NYSE is: 2705 of 2767,  n: 1,  idx_date_n: 2706,
# idx_date_n: 2706 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-03"
#
# date: 2023-10-02,  n: 1,  next_date_n: 2023-10-03 is in df_close
# picks for 2023-10-02: ['FTSM']
# date = '2023-10-03', l_syms = ['FTSM'], ar_price = array([59.43000031]), ar_sym_share = array([16.]), ar_sym_amt = array([950.88000488]), portf_value = 950.8800048828125
# 2023-10-03 portf_value = 950.8800048828125
# date = '2023-10-03', symbol = 'SPY', price = 421.5899963378906, share = 2.0, value = 843.1799926757812
# 2023-10-03 SPY value = 843.1799926757812
# next_date_n pick's portf value = 950.8800048828125
# next_date_n SPY portf value =    843.1799926757812
# ====================
#
# date: 2023-10-02 is in dates_NYSE,  date's position in dates_NYSE is: 2705 of 2767,  n: 1,  idx_date_n: 2706,
# idx_date_n: 2706 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-03"
#
# date: 2023-10-02,  n: 1,  next_date_n: 2023-10-03 is in df_close
# picks for 2023-10-02: ['ANF']
# date = '2023-10-03', l_syms = ['ANF'], ar_price = array([55.49000168]), ar_sym_share = array([18.]), ar_sym_amt = array([998.82003021]), portf_value = 998.8200302124023
# 2023-10-03 portf_value = 998.8200302124023
# date = '2023-10-03', symbol = 'SPY', price = 421.5899963378906, share = 2.0, value = 843.1799926757812
# 2023-10-03 SPY value = 843.1799926757812
# next_date_n pick's portf value = 998.8200302124023
# next_date_n SPY portf value =    843.1799926757812
# ====================
#
# date: 2023-10-02 is in dates_NYSE,  date's position in dates_NYSE is: 2705 of 2767,  n: 1,  idx_date_n: 2706,
# idx_date_n: 2706 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-03"
#
# date: 2023-10-02,  n: 1,  next_date_n: 2023-10-03 is in df_close
# picks for 2023-10-02: ['FTSM']
# date = '2023-10-03', l_syms = ['FTSM'], ar_price = array([59.43000031]), ar_sym_share = array([16.]), ar_sym_amt = array([950.88000488]), portf_value = 950.8800048828125
# 2023-10-03 portf_value = 950.8800048828125
# date = '2023-10-03', symbol = 'SPY', price = 421.5899963378906, share = 2.0, value = 843.1799926757812
# 2023-10-03 SPY value = 843.1799926757812
# next_date_n pick's portf value = 950.8800048828125
# next_date_n SPY portf value =    843.1799926757812
# ====================
#
# date: 2023-09-29 is in dates_NYSE,  date's position in dates_NYSE is: 2704 of 2767,  n: 1,  idx_date_n: 2705,
# idx_date_n: 2705 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-02"
#
# date: 2023-09-29,  n: 1,  next_date_n: 2023-10-02 is in df_close
# picks for 2023-09-29: ['FTSM', 'SHV']
# date = '2023-10-02', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.43999863, 110.02999878]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.51998901, 440.11999512]), portf_value = 915.6399841308594
# 2023-10-02 portf_value = 915.6399841308594
# date = '2023-10-02', symbol = 'SPY', price = 427.30999755859375, share = 2.0, value = 854.6199951171875
# 2023-10-02 SPY value = 854.6199951171875
# next_date_n pick's portf value = 915.6399841308594
# next_date_n SPY portf value =    854.6199951171875
# ====================
#
# date: 2023-09-29 is in dates_NYSE,  date's position in dates_NYSE is: 2704 of 2767,  n: 1,  idx_date_n: 2705,
# idx_date_n: 2705 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-02"
#
# date: 2023-09-29,  n: 1,  next_date_n: 2023-10-02 is in df_close
# picks for 2023-09-29: ['SHV']
# date = '2023-10-02', l_syms = ['SHV'], ar_price = array([110.02999878]), ar_sym_share = array([9.]), ar_sym_amt = array([990.26998901]), portf_value = 990.2699890136719
# 2023-10-02 portf_value = 990.2699890136719
# date = '2023-10-02', symbol = 'SPY', price = 427.30999755859375, share = 2.0, value = 854.6199951171875
# 2023-10-02 SPY value = 854.6199951171875
# next_date_n pick's portf value = 990.2699890136719
# next_date_n SPY portf value =    854.6199951171875
# ====================
#
# date: 2023-09-28 is in dates_NYSE,  date's position in dates_NYSE is: 2703 of 2767,  n: 1,  idx_date_n: 2704,
# idx_date_n: 2704 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-29"
#
# date: 2023-09-28,  n: 1,  next_date_n: 2023-09-29 is in df_close
# picks for 2023-09-28: ['FTSM', 'SHV']
# date = '2023-09-29', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.41999817, 110.00500488]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.35998535, 440.02001953]), portf_value = 915.3800048828125
# 2023-09-29 portf_value = 915.3800048828125
# date = '2023-09-29', symbol = 'SPY', price = 427.4800109863281, share = 2.0, value = 854.9600219726562
# 2023-09-29 SPY value = 854.9600219726562
# next_date_n pick's portf value = 915.3800048828125
# next_date_n SPY portf value =    854.9600219726562
# ====================
#
# date: 2023-09-28 is in dates_NYSE,  date's position in dates_NYSE is: 2703 of 2767,  n: 1,  idx_date_n: 2704,
# idx_date_n: 2704 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-29"
#
# date: 2023-09-28,  n: 1,  next_date_n: 2023-09-29 is in df_close
# picks for 2023-09-28: ['CCJ']
# date = '2023-09-29', l_syms = ['CCJ'], ar_price = array([39.63999939]), ar_sym_share = array([25.]), ar_sym_amt = array([990.99998474]), portf_value = 990.9999847412109
# 2023-09-29 portf_value = 990.9999847412109
# date = '2023-09-29', symbol = 'SPY', price = 427.4800109863281, share = 2.0, value = 854.9600219726562
# 2023-09-29 SPY value = 854.9600219726562
# next_date_n pick's portf value = 990.9999847412109
# next_date_n SPY portf value =    854.9600219726562
# ====================
#
# date: 2023-09-28 is in dates_NYSE,  date's position in dates_NYSE is: 2703 of 2767,  n: 1,  idx_date_n: 2704,
# idx_date_n: 2704 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-29"
#
# date: 2023-09-28,  n: 1,  next_date_n: 2023-09-29 is in df_close
# picks for 2023-09-28: ['SHV']
# date = '2023-09-29', l_syms = ['SHV'], ar_price = array([110.00500488]), ar_sym_share = array([9.]), ar_sym_amt = array([990.04504395]), portf_value = 990.0450439453125
# 2023-09-29 portf_value = 990.0450439453125
# date = '2023-09-29', symbol = 'SPY', price = 427.4800109863281, share = 2.0, value = 854.9600219726562
# 2023-09-29 SPY value = 854.9600219726562
# next_date_n pick's portf value = 990.0450439453125
# next_date_n SPY portf value =    854.9600219726562
# ====================
#
# date: 2023-09-25 is in dates_NYSE,  date's position in dates_NYSE is: 2700 of 2767,  n: 1,  idx_date_n: 2701,
# idx_date_n: 2701 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-26"
#
# date: 2023-09-25,  n: 1,  next_date_n: 2023-09-26 is in df_close
# picks for 2023-09-25: ['FTSM', 'SHV']
# date = '2023-09-26', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.38809967, 109.9352951 ]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.10479736, 439.74118042]), portf_value = 914.8459777832031
# 2023-09-26 portf_value = 914.8459777832031
# date = '2023-09-26', symbol = 'SPY', price = 425.8800048828125, share = 2.0, value = 851.760009765625
# 2023-09-26 SPY value = 851.760009765625
# next_date_n pick's portf value = 914.8459777832031
# next_date_n SPY portf value =    851.760009765625
# ====================
#
# date: 2023-09-22 is in dates_NYSE,  date's position in dates_NYSE is: 2699 of 2767,  n: 1,  idx_date_n: 2700,
# idx_date_n: 2700 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-25"
#
# date: 2023-09-22,  n: 1,  next_date_n: 2023-09-25 is in df_close
# picks for 2023-09-22: ['FTSM', 'SHV']
# date = '2023-09-25', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.40304184, 109.92533875]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.22433472, 439.70135498]), portf_value = 914.9256896972656
# 2023-09-25 portf_value = 914.9256896972656
# date = '2023-09-25', symbol = 'SPY', price = 432.2300109863281, share = 2.0, value = 864.4600219726562
# 2023-09-25 SPY value = 864.4600219726562
# next_date_n pick's portf value = 914.9256896972656
# next_date_n SPY portf value =    864.4600219726562
# ====================
#
# date: 2023-09-22 is in dates_NYSE,  date's position in dates_NYSE is: 2699 of 2767,  n: 1,  idx_date_n: 2700,
# idx_date_n: 2700 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-25"
#
# date: 2023-09-22,  n: 1,  next_date_n: 2023-09-25 is in df_close
# picks for 2023-09-22: ['FTSM', 'SHV']
# date = '2023-09-25', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.40304184, 109.92533875]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.22433472, 439.70135498]), portf_value = 914.9256896972656
# 2023-09-25 portf_value = 914.9256896972656
# date = '2023-09-25', symbol = 'SPY', price = 432.2300109863281, share = 2.0, value = 864.4600219726562
# 2023-09-25 SPY value = 864.4600219726562
# next_date_n pick's portf value = 914.9256896972656
# next_date_n SPY portf value =    864.4600219726562
# ====================
#
# date: 2023-09-21 is in dates_NYSE,  date's position in dates_NYSE is: 2698 of 2767,  n: 1,  idx_date_n: 2699,
# idx_date_n: 2699 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-22"
#
# date: 2023-09-21,  n: 1,  next_date_n: 2023-09-22 is in df_close
# picks for 2023-09-21: ['FTSM', 'SHV']
# date = '2023-09-22', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.37814331, 109.91537476]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.02514648, 439.66149902]), portf_value = 914.6866455078125
# 2023-09-22 portf_value = 914.6866455078125
# date = '2023-09-22', symbol = 'SPY', price = 430.4200134277344, share = 2.0, value = 860.8400268554688
# 2023-09-22 SPY value = 860.8400268554688
# next_date_n pick's portf value = 914.6866455078125
# next_date_n SPY portf value =    860.8400268554688
# ====================
#
# date: 2023-09-21 is in dates_NYSE,  date's position in dates_NYSE is: 2698 of 2767,  n: 1,  idx_date_n: 2699,
# idx_date_n: 2699 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-22"
#
# date: 2023-09-21,  n: 1,  next_date_n: 2023-09-22 is in df_close
# picks for 2023-09-21: ['FTSM', 'SHV']
# date = '2023-09-22', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.37814331, 109.91537476]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.02514648, 439.66149902]), portf_value = 914.6866455078125
# 2023-09-22 portf_value = 914.6866455078125
# date = '2023-09-22', symbol = 'SPY', price = 430.4200134277344, share = 2.0, value = 860.8400268554688
# 2023-09-22 SPY value = 860.8400268554688
# next_date_n pick's portf value = 914.6866455078125
# next_date_n SPY portf value =    860.8400268554688
# ====================
#
# date: 2023-09-20 is in dates_NYSE,  date's position in dates_NYSE is: 2697 of 2767,  n: 1,  idx_date_n: 2698,
# idx_date_n: 2698 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-21"
#
# date: 2023-09-20,  n: 1,  next_date_n: 2023-09-21 is in df_close
# picks for 2023-09-20: ['FTSM', 'SHV']
# date = '2023-09-21', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.34328842, 109.89546204]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.74630737, 439.58184814]), portf_value = 914.3281555175781
# 2023-09-21 portf_value = 914.3281555175781
# date = '2023-09-21', symbol = 'SPY', price = 431.3900146484375, share = 2.0, value = 862.780029296875
# 2023-09-21 SPY value = 862.780029296875
# next_date_n pick's portf value = 914.3281555175781
# next_date_n SPY portf value =    862.780029296875
# ====================
#
# date: 2023-09-20 is in dates_NYSE,  date's position in dates_NYSE is: 2697 of 2767,  n: 1,  idx_date_n: 2698,
# idx_date_n: 2698 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-21"
#
# date: 2023-09-20,  n: 1,  next_date_n: 2023-09-21 is in df_close
# picks for 2023-09-20: ['SHV']
# date = '2023-09-21', l_syms = ['SHV'], ar_price = array([109.89546204]), ar_sym_share = array([9.]), ar_sym_amt = array([989.05915833]), portf_value = 989.0591583251953
# 2023-09-21 portf_value = 989.0591583251953
# date = '2023-09-21', symbol = 'SPY', price = 431.3900146484375, share = 2.0, value = 862.780029296875
# 2023-09-21 SPY value = 862.780029296875
# next_date_n pick's portf value = 989.0591583251953
# next_date_n SPY portf value =    862.780029296875
# ====================
#
# date: 2023-09-18 is in dates_NYSE,  date's position in dates_NYSE is: 2695 of 2767,  n: 1,  idx_date_n: 2696,
# idx_date_n: 2696 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-19"
#
# date: 2023-09-18,  n: 1,  next_date_n: 2023-09-19 is in df_close
# picks for 2023-09-18: ['SHV']
# date = '2023-09-19', l_syms = ['SHV'], ar_price = array([109.82575989]), ar_sym_share = array([9.]), ar_sym_amt = array([988.43183899]), portf_value = 988.4318389892578
# 2023-09-19 portf_value = 988.4318389892578
# date = '2023-09-19', symbol = 'SPY', price = 442.7099914550781, share = 2.0, value = 885.4199829101562
# 2023-09-19 SPY value = 885.4199829101562
# next_date_n pick's portf value = 988.4318389892578
# next_date_n SPY portf value =    885.4199829101562
# ====================
#
# date: 2023-09-18 is in dates_NYSE,  date's position in dates_NYSE is: 2695 of 2767,  n: 1,  idx_date_n: 2696,
# idx_date_n: 2696 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-19"
#
# date: 2023-09-18,  n: 1,  next_date_n: 2023-09-19 is in df_close
# picks for 2023-09-18: ['FTSM']
# date = '2023-09-19', l_syms = ['FTSM'], ar_price = array([59.32337189]), ar_sym_share = array([16.]), ar_sym_amt = array([949.1739502]), portf_value = 949.1739501953125
# 2023-09-19 portf_value = 949.1739501953125
# date = '2023-09-19', symbol = 'SPY', price = 442.7099914550781, share = 2.0, value = 885.4199829101562
# 2023-09-19 SPY value = 885.4199829101562
# next_date_n pick's portf value = 949.1739501953125
# next_date_n SPY portf value =    885.4199829101562
# ====================
#
# date: 2023-09-15 is in dates_NYSE,  date's position in dates_NYSE is: 2694 of 2767,  n: 1,  idx_date_n: 2695,
# idx_date_n: 2695 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-18"
#
# date: 2023-09-15,  n: 1,  next_date_n: 2023-09-18 is in df_close
# picks for 2023-09-15: ['FTSM', 'SHV']
# date = '2023-09-18', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.32337189, 109.82575989]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.5869751 , 439.30303955]), portf_value = 913.8900146484375
# 2023-09-18 portf_value = 913.8900146484375
# date = '2023-09-18', symbol = 'SPY', price = 443.6300048828125, share = 2.0, value = 887.260009765625
# 2023-09-18 SPY value = 887.260009765625
# next_date_n pick's portf value = 913.8900146484375
# next_date_n SPY portf value =    887.260009765625
# ====================
#
# date: 2023-09-14 is in dates_NYSE,  date's position in dates_NYSE is: 2693 of 2767,  n: 1,  idx_date_n: 2694,
# idx_date_n: 2694 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-15"
#
# date: 2023-09-14,  n: 1,  next_date_n: 2023-09-15 is in df_close
# picks for 2023-09-14: ['SHV']
# date = '2023-09-15', l_syms = ['SHV'], ar_price = array([109.80583954]), ar_sym_share = array([9.]), ar_sym_amt = array([988.25255585]), portf_value = 988.252555847168
# 2023-09-15 portf_value = 988.252555847168
# date = '2023-09-15', symbol = 'SPY', price = 443.3699951171875, share = 2.0, value = 886.739990234375
# 2023-09-15 SPY value = 886.739990234375
# next_date_n pick's portf value = 988.252555847168
# next_date_n SPY portf value =    886.739990234375
# ====================
#
# date: 2023-09-14 is in dates_NYSE,  date's position in dates_NYSE is: 2693 of 2767,  n: 1,  idx_date_n: 2694,
# idx_date_n: 2694 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-15"
#
# date: 2023-09-14,  n: 1,  next_date_n: 2023-09-15 is in df_close
# picks for 2023-09-14: ['DELL', 'FTSM']
# date = '2023-09-15', l_syms = ['DELL', 'FTSM'], ar_price = array([69.29000092, 59.31341553]), ar_sym_share = array([7., 8.]), ar_sym_amt = array([485.03000641, 474.50732422]), portf_value = 959.5373306274414
# 2023-09-15 portf_value = 959.5373306274414
# date = '2023-09-15', symbol = 'SPY', price = 443.3699951171875, share = 2.0, value = 886.739990234375
# 2023-09-15 SPY value = 886.739990234375
# next_date_n pick's portf value = 959.5373306274414
# next_date_n SPY portf value =    886.739990234375
# ====================
#
# date: 2023-09-13 is in dates_NYSE,  date's position in dates_NYSE is: 2692 of 2767,  n: 1,  idx_date_n: 2693,
# idx_date_n: 2693 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-14"
#
# date: 2023-09-13,  n: 1,  next_date_n: 2023-09-14 is in df_close
# picks for 2023-09-13: ['FTSM', 'SHV']
# date = '2023-09-14', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.30345535, 109.79588318]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.42764282, 439.18353271]), portf_value = 913.6111755371094
# 2023-09-14 portf_value = 913.6111755371094
# date = '2023-09-14', symbol = 'SPY', price = 448.7770080566406, share = 2.0, value = 897.5540161132812
# 2023-09-14 SPY value = 897.5540161132812
# next_date_n pick's portf value = 913.6111755371094
# next_date_n SPY portf value =    897.5540161132812
# ====================
#
# date: 2023-09-13 is in dates_NYSE,  date's position in dates_NYSE is: 2692 of 2767,  n: 1,  idx_date_n: 2693,
# idx_date_n: 2693 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-14"
#
# date: 2023-09-13,  n: 1,  next_date_n: 2023-09-14 is in df_close
# picks for 2023-09-13: ['DELL']
# date = '2023-09-14', l_syms = ['DELL'], ar_price = array([71.16000366]), ar_sym_share = array([14.]), ar_sym_amt = array([996.24005127]), portf_value = 996.2400512695312
# 2023-09-14 portf_value = 996.2400512695312
# date = '2023-09-14', symbol = 'SPY', price = 448.7770080566406, share = 2.0, value = 897.5540161132812
# 2023-09-14 SPY value = 897.5540161132812
# next_date_n pick's portf value = 996.2400512695312
# next_date_n SPY portf value =    897.5540161132812
# ====================
#
# date: 2023-09-12 is in dates_NYSE,  date's position in dates_NYSE is: 2691 of 2767,  n: 1,  idx_date_n: 2692,
# idx_date_n: 2692 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-13"
#
# date: 2023-09-12,  n: 1,  next_date_n: 2023-09-13 is in df_close
# picks for 2023-09-12: ['FTSM', 'SHV']
# date = '2023-09-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.30843353, 109.74609375]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.46746826, 438.984375  ]), portf_value = 913.4518432617188
# 2023-09-13 portf_value = 913.4518432617188
# date = '2023-09-13', symbol = 'SPY', price = 444.9405517578125, share = 2.0, value = 889.881103515625
# 2023-09-13 SPY value = 889.881103515625
# next_date_n pick's portf value = 913.4518432617188
# next_date_n SPY portf value =    889.881103515625
# ====================
#
# date: 2023-09-12 is in dates_NYSE,  date's position in dates_NYSE is: 2691 of 2767,  n: 1,  idx_date_n: 2692,
# idx_date_n: 2692 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-13"
#
# date: 2023-09-12,  n: 1,  next_date_n: 2023-09-13 is in df_close
# picks for 2023-09-12: ['DELL', 'MMYT']
# date = '2023-09-13', l_syms = ['DELL', 'MMYT'], ar_price = array([70.44999695, 39.54999924]), ar_sym_share = array([ 7., 12.]), ar_sym_amt = array([493.14997864, 474.59999084]), portf_value = 967.7499694824219
# 2023-09-13 portf_value = 967.7499694824219
# date = '2023-09-13', symbol = 'SPY', price = 444.9405517578125, share = 2.0, value = 889.881103515625
# 2023-09-13 SPY value = 889.881103515625
# next_date_n pick's portf value = 967.7499694824219
# next_date_n SPY portf value =    889.881103515625
# ====================
#
# date: 2023-09-11 is in dates_NYSE,  date's position in dates_NYSE is: 2690 of 2767,  n: 1,  idx_date_n: 2691,
# idx_date_n: 2691 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-12"
#
# date: 2023-09-11,  n: 1,  next_date_n: 2023-09-12 is in df_close
# picks for 2023-09-11: ['DELL', 'FTSM', 'SHV']
# date = '2023-09-12', l_syms = ['DELL', 'FTSM', 'SHV'], ar_price = array([ 70.73000336,  59.283535  , 109.72618103]), ar_sym_share = array([4., 5., 3.]), ar_sym_amt = array([282.92001343, 296.41767502, 329.17854309]), portf_value = 908.5162315368652
# 2023-09-12 portf_value = 908.5162315368652
# date = '2023-09-12', symbol = 'SPY', price = 444.42236328125, share = 2.0, value = 888.8447265625
# 2023-09-12 SPY value = 888.8447265625
# next_date_n pick's portf value = 908.5162315368652
# next_date_n SPY portf value =    888.8447265625
# ====================
#
# date: 2023-09-11 is in dates_NYSE,  date's position in dates_NYSE is: 2690 of 2767,  n: 1,  idx_date_n: 2691,
# idx_date_n: 2691 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-12"
#
# date: 2023-09-11,  n: 1,  next_date_n: 2023-09-12 is in df_close
# picks for 2023-09-11: ['DELL']
# date = '2023-09-12', l_syms = ['DELL'], ar_price = array([70.73000336]), ar_sym_share = array([14.]), ar_sym_amt = array([990.220047]), portf_value = 990.2200469970703
# 2023-09-12 portf_value = 990.2200469970703
# date = '2023-09-12', symbol = 'SPY', price = 444.42236328125, share = 2.0, value = 888.8447265625
# 2023-09-12 SPY value = 888.8447265625
# next_date_n pick's portf value = 990.2200469970703
# next_date_n SPY portf value =    888.8447265625
# ====================
#
# date: 2023-09-08 is in dates_NYSE,  date's position in dates_NYSE is: 2689 of 2767,  n: 1,  idx_date_n: 2690,
# idx_date_n: 2690 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-11"
#
# date: 2023-09-08,  n: 1,  next_date_n: 2023-09-11 is in df_close
# picks for 2023-09-08: ['FTSM', 'SHV']
# date = '2023-09-11', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.283535  , 109.71622467]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.26828003, 438.86489868]), portf_value = 913.1331787109375
# 2023-09-11 portf_value = 913.1331787109375
# date = '2023-09-11', symbol = 'SPY', price = 446.8737487792969, share = 2.0, value = 893.7474975585938
# 2023-09-11 SPY value = 893.7474975585938
# next_date_n pick's portf value = 913.1331787109375
# next_date_n SPY portf value =    893.7474975585938
# ====================
#
# date: 2023-09-08 is in dates_NYSE,  date's position in dates_NYSE is: 2689 of 2767,  n: 1,  idx_date_n: 2690,
# idx_date_n: 2690 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-11"
#
# date: 2023-09-08,  n: 1,  next_date_n: 2023-09-11 is in df_close
# picks for 2023-09-08: ['DELL', 'STRL']
# date = '2023-09-11', l_syms = ['DELL', 'STRL'], ar_price = array([72.16000366, 77.43000031]), ar_sym_share = array([6., 6.]), ar_sym_amt = array([432.96002197, 464.58000183]), portf_value = 897.5400238037109
# 2023-09-11 portf_value = 897.5400238037109
# date = '2023-09-11', symbol = 'SPY', price = 446.8737487792969, share = 2.0, value = 893.7474975585938
# 2023-09-11 SPY value = 893.7474975585938
# next_date_n pick's portf value = 897.5400238037109
# next_date_n SPY portf value =    893.7474975585938
# ====================
#
# date: 2023-09-05 is in dates_NYSE,  date's position in dates_NYSE is: 2686 of 2767,  n: 1,  idx_date_n: 2687,
# idx_date_n: 2687 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-06"
#
# date: 2023-09-05,  n: 1,  next_date_n: 2023-09-06 is in df_close
# picks for 2023-09-05: ['SHV']
# date = '2023-09-06', l_syms = ['SHV'], ar_price = array([109.62659454]), ar_sym_share = array([9.]), ar_sym_amt = array([986.63935089]), portf_value = 986.6393508911133
# 2023-09-06 portf_value = 986.6393508911133
# date = '2023-09-06', symbol = 'SPY', price = 444.65155029296875, share = 2.0, value = 889.3031005859375
# 2023-09-06 SPY value = 889.3031005859375
# next_date_n pick's portf value = 986.6393508911133
# next_date_n SPY portf value =    889.3031005859375
# ====================
#
# date: 2023-09-05 is in dates_NYSE,  date's position in dates_NYSE is: 2686 of 2767,  n: 1,  idx_date_n: 2687,
# idx_date_n: 2687 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-06"
#
# date: 2023-09-05,  n: 1,  next_date_n: 2023-09-06 is in df_close
# picks for 2023-09-05: ['FTSM']
# date = '2023-09-06', l_syms = ['FTSM'], ar_price = array([59.24370575]), ar_sym_share = array([16.]), ar_sym_amt = array([947.89929199]), portf_value = 947.8992919921875
# 2023-09-06 portf_value = 947.8992919921875
# date = '2023-09-06', symbol = 'SPY', price = 444.65155029296875, share = 2.0, value = 889.3031005859375
# 2023-09-06 SPY value = 889.3031005859375
# next_date_n pick's portf value = 947.8992919921875
# next_date_n SPY portf value =    889.3031005859375
# ====================
#
# date: 2023-09-01 is in dates_NYSE,  date's position in dates_NYSE is: 2685 of 2767,  n: 1,  idx_date_n: 2686,
# idx_date_n: 2686 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-05"
#
# date: 2023-09-01,  n: 1,  next_date_n: 2023-09-05 is in df_close
# picks for 2023-09-01: ['SHV']
# date = '2023-09-05', l_syms = ['SHV'], ar_price = array([109.60668182]), ar_sym_share = array([9.]), ar_sym_amt = array([986.46013641]), portf_value = 986.4601364135742
# 2023-09-05 portf_value = 986.4601364135742
# date = '2023-09-05', symbol = 'SPY', price = 447.66094970703125, share = 2.0, value = 895.3218994140625
# 2023-09-05 SPY value = 895.3218994140625
# next_date_n pick's portf value = 986.4601364135742
# next_date_n SPY portf value =    895.3218994140625
# ====================
#
# date: 2023-09-01 is in dates_NYSE,  date's position in dates_NYSE is: 2685 of 2767,  n: 1,  idx_date_n: 2686,
# idx_date_n: 2686 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-05"
#
# date: 2023-09-01,  n: 1,  next_date_n: 2023-09-05 is in df_close
# picks for 2023-09-01: ['FTSM', 'STRL']
# date = '2023-09-05', l_syms = ['FTSM', 'STRL'], ar_price = array([59.23374557, 80.54000092]), ar_sym_share = array([8., 6.]), ar_sym_amt = array([473.8699646 , 483.24000549]), portf_value = 957.1099700927734
# 2023-09-05 portf_value = 957.1099700927734
# date = '2023-09-05', symbol = 'SPY', price = 447.66094970703125, share = 2.0, value = 895.3218994140625
# 2023-09-05 SPY value = 895.3218994140625
# next_date_n pick's portf value = 957.1099700927734
# next_date_n SPY portf value =    895.3218994140625
# ====================
#
# date: 2023-08-25 is in dates_NYSE,  date's position in dates_NYSE is: 2680 of 2767,  n: 1,  idx_date_n: 2681,
# idx_date_n: 2681 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-28"
#
# date: 2023-08-25,  n: 1,  next_date_n: 2023-08-28 is in df_close
# picks for 2023-08-25: ['SHV']
# date = '2023-08-28', l_syms = ['SHV'], ar_price = array([109.47664642]), ar_sym_share = array([9.]), ar_sym_amt = array([985.28981781]), portf_value = 985.2898178100586
# 2023-08-28 portf_value = 985.2898178100586
# date = '2023-08-28', symbol = 'SPY', price = 441.2037353515625, share = 2.0, value = 882.407470703125
# 2023-08-28 SPY value = 882.407470703125
# next_date_n pick's portf value = 985.2898178100586
# next_date_n SPY portf value =    882.407470703125
# ====================
#
# date: 2023-08-25 is in dates_NYSE,  date's position in dates_NYSE is: 2680 of 2767,  n: 1,  idx_date_n: 2681,
# idx_date_n: 2681 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-28"
#
# date: 2023-08-25,  n: 1,  next_date_n: 2023-08-28 is in df_close
# picks for 2023-08-25: ['STRL']
# date = '2023-08-28', l_syms = ['STRL'], ar_price = array([79.16000366]), ar_sym_share = array([12.]), ar_sym_amt = array([949.92004395]), portf_value = 949.9200439453125
# 2023-08-28 portf_value = 949.9200439453125
# date = '2023-08-28', symbol = 'SPY', price = 441.2037353515625, share = 2.0, value = 882.407470703125
# 2023-08-28 SPY value = 882.407470703125
# next_date_n pick's portf value = 949.9200439453125
# next_date_n SPY portf value =    882.407470703125
# ====================
#
# date: 2023-08-25 is in dates_NYSE,  date's position in dates_NYSE is: 2680 of 2767,  n: 1,  idx_date_n: 2681,
# idx_date_n: 2681 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-28"
#
# date: 2023-08-25,  n: 1,  next_date_n: 2023-08-28 is in df_close
# picks for 2023-08-25: ['SHV']
# date = '2023-08-28', l_syms = ['SHV'], ar_price = array([109.47664642]), ar_sym_share = array([9.]), ar_sym_amt = array([985.28981781]), portf_value = 985.2898178100586
# 2023-08-28 portf_value = 985.2898178100586
# date = '2023-08-28', symbol = 'SPY', price = 441.2037353515625, share = 2.0, value = 882.407470703125
# 2023-08-28 SPY value = 882.407470703125
# next_date_n pick's portf value = 985.2898178100586
# next_date_n SPY portf value =    882.407470703125
# ====================
#
# date: 2023-08-18 is in dates_NYSE,  date's position in dates_NYSE is: 2675 of 2767,  n: 1,  idx_date_n: 2676,
# idx_date_n: 2676 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-21"
#
# date: 2023-08-18,  n: 1,  next_date_n: 2023-08-21 is in df_close
# picks for 2023-08-18: ['SHV']
# date = '2023-08-21', l_syms = ['SHV'], ar_price = array([109.37748718]), ar_sym_share = array([9.]), ar_sym_amt = array([984.39738464]), portf_value = 984.3973846435547
# 2023-08-21 portf_value = 984.3973846435547
# date = '2023-08-21', symbol = 'SPY', price = 437.7957458496094, share = 2.0, value = 875.5914916992188
# 2023-08-21 SPY value = 875.5914916992188
# next_date_n pick's portf value = 984.3973846435547
# next_date_n SPY portf value =    875.5914916992188
# ====================
#
# date: 2023-08-18 is in dates_NYSE,  date's position in dates_NYSE is: 2675 of 2767,  n: 1,  idx_date_n: 2676,
# idx_date_n: 2676 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-21"
#
# date: 2023-08-18,  n: 1,  next_date_n: 2023-08-21 is in df_close
# picks for 2023-08-18: ['FTSM']
# date = '2023-08-21', l_syms = ['FTSM'], ar_price = array([59.10763931]), ar_sym_share = array([16.]), ar_sym_amt = array([945.722229]), portf_value = 945.7222290039062
# 2023-08-21 portf_value = 945.7222290039062
# date = '2023-08-21', symbol = 'SPY', price = 437.7957458496094, share = 2.0, value = 875.5914916992188
# 2023-08-21 SPY value = 875.5914916992188
# next_date_n pick's portf value = 945.7222290039062
# next_date_n SPY portf value =    875.5914916992188
# ====================
#
# date: 2023-08-18 is in dates_NYSE,  date's position in dates_NYSE is: 2675 of 2767,  n: 1,  idx_date_n: 2676,
# idx_date_n: 2676 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-21"
#
# date: 2023-08-18,  n: 1,  next_date_n: 2023-08-21 is in df_close
# picks for 2023-08-18: ['SHV']
# date = '2023-08-21', l_syms = ['SHV'], ar_price = array([109.37748718]), ar_sym_share = array([9.]), ar_sym_amt = array([984.39738464]), portf_value = 984.3973846435547
# 2023-08-21 portf_value = 984.3973846435547
# date = '2023-08-21', symbol = 'SPY', price = 437.7957458496094, share = 2.0, value = 875.5914916992188
# 2023-08-21 SPY value = 875.5914916992188
# next_date_n pick's portf value = 984.3973846435547
# next_date_n SPY portf value =    875.5914916992188
# ====================
#
# date: 2023-08-17 is in dates_NYSE,  date's position in dates_NYSE is: 2674 of 2767,  n: 1,  idx_date_n: 2675,
# idx_date_n: 2675 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-18"
#
# date: 2023-08-17,  n: 1,  next_date_n: 2023-08-18 is in df_close
# picks for 2023-08-17: ['SHV']
# date = '2023-08-18', l_syms = ['SHV'], ar_price = array([109.36756897]), ar_sym_share = array([9.]), ar_sym_amt = array([984.30812073]), portf_value = 984.3081207275391
# 2023-08-18 portf_value = 984.3081207275391
# date = '2023-08-18', symbol = 'SPY', price = 434.9657287597656, share = 2.0, value = 869.9314575195312
# 2023-08-18 SPY value = 869.9314575195312
# next_date_n pick's portf value = 984.3081207275391
# next_date_n SPY portf value =    869.9314575195312
# ====================
#
# date: 2023-08-17 is in dates_NYSE,  date's position in dates_NYSE is: 2674 of 2767,  n: 1,  idx_date_n: 2675,
# idx_date_n: 2675 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-18"
#
# date: 2023-08-17,  n: 1,  next_date_n: 2023-08-18 is in df_close
# picks for 2023-08-17: ['FTSM']
# date = '2023-08-18', l_syms = ['FTSM'], ar_price = array([59.0977211]), ar_sym_share = array([16.]), ar_sym_amt = array([945.5635376]), portf_value = 945.5635375976562
# 2023-08-18 portf_value = 945.5635375976562
# date = '2023-08-18', symbol = 'SPY', price = 434.9657287597656, share = 2.0, value = 869.9314575195312
# 2023-08-18 SPY value = 869.9314575195312
# next_date_n pick's portf value = 945.5635375976562
# next_date_n SPY portf value =    869.9314575195312
# ====================
#
# date: 2023-08-17 is in dates_NYSE,  date's position in dates_NYSE is: 2674 of 2767,  n: 1,  idx_date_n: 2675,
# idx_date_n: 2675 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-18"
#
# date: 2023-08-17,  n: 1,  next_date_n: 2023-08-18 is in df_close
# picks for 2023-08-17: ['SHV']
# date = '2023-08-18', l_syms = ['SHV'], ar_price = array([109.36756897]), ar_sym_share = array([9.]), ar_sym_amt = array([984.30812073]), portf_value = 984.3081207275391
# 2023-08-18 portf_value = 984.3081207275391
# date = '2023-08-18', symbol = 'SPY', price = 434.9657287597656, share = 2.0, value = 869.9314575195312
# 2023-08-18 SPY value = 869.9314575195312
# next_date_n pick's portf value = 984.3081207275391
# next_date_n SPY portf value =    869.9314575195312
# ====================
#
# date: 2023-08-15 is in dates_NYSE,  date's position in dates_NYSE is: 2672 of 2767,  n: 1,  idx_date_n: 2673,
# idx_date_n: 2673 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-16"
#
# date: 2023-08-15,  n: 1,  next_date_n: 2023-08-16 is in df_close
# picks for 2023-08-15: ['SHV']
# date = '2023-08-16', l_syms = ['SHV'], ar_price = array([109.30807495]), ar_sym_share = array([9.]), ar_sym_amt = array([983.77267456]), portf_value = 983.7726745605469
# 2023-08-16 portf_value = 983.7726745605469
# date = '2023-08-16', symbol = 'SPY', price = 438.0946960449219, share = 2.0, value = 876.1893920898438
# 2023-08-16 SPY value = 876.1893920898438
# next_date_n pick's portf value = 983.7726745605469
# next_date_n SPY portf value =    876.1893920898438
# ====================
#
# date: 2023-08-15 is in dates_NYSE,  date's position in dates_NYSE is: 2672 of 2767,  n: 1,  idx_date_n: 2673,
# idx_date_n: 2673 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-16"
#
# date: 2023-08-15,  n: 1,  next_date_n: 2023-08-16 is in df_close
# picks for 2023-08-15: ['STRL']
# date = '2023-08-16', l_syms = ['STRL'], ar_price = array([80.48999786]), ar_sym_share = array([12.]), ar_sym_amt = array([965.87997437]), portf_value = 965.8799743652344
# 2023-08-16 portf_value = 965.8799743652344
# date = '2023-08-16', symbol = 'SPY', price = 438.0946960449219, share = 2.0, value = 876.1893920898438
# 2023-08-16 SPY value = 876.1893920898438
# next_date_n pick's portf value = 965.8799743652344
# next_date_n SPY portf value =    876.1893920898438
# ====================
#
# date: 2023-08-15 is in dates_NYSE,  date's position in dates_NYSE is: 2672 of 2767,  n: 1,  idx_date_n: 2673,
# idx_date_n: 2673 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-16"
#
# date: 2023-08-15,  n: 1,  next_date_n: 2023-08-16 is in df_close
# picks for 2023-08-15: ['SHV']
# date = '2023-08-16', l_syms = ['SHV'], ar_price = array([109.30807495]), ar_sym_share = array([9.]), ar_sym_amt = array([983.77267456]), portf_value = 983.7726745605469
# 2023-08-16 portf_value = 983.7726745605469
# date = '2023-08-16', symbol = 'SPY', price = 438.0946960449219, share = 2.0, value = 876.1893920898438
# 2023-08-16 SPY value = 876.1893920898438
# next_date_n pick's portf value = 983.7726745605469
# next_date_n SPY portf value =    876.1893920898438
# ====================
#
# date: 2023-08-14 is in dates_NYSE,  date's position in dates_NYSE is: 2671 of 2767,  n: 1,  idx_date_n: 2672,
# idx_date_n: 2672 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-15"
#
# date: 2023-08-14,  n: 1,  next_date_n: 2023-08-15 is in df_close
# picks for 2023-08-14: ['SHV']
# date = '2023-08-15', l_syms = ['SHV'], ar_price = array([109.29815674]), ar_sym_share = array([9.]), ar_sym_amt = array([983.68341064]), portf_value = 983.6834106445312
# 2023-08-15 portf_value = 983.6834106445312
# date = '2023-08-15', symbol = 'SPY', price = 441.3332824707031, share = 2.0, value = 882.6665649414062
# 2023-08-15 SPY value = 882.6665649414062
# next_date_n pick's portf value = 983.6834106445312
# next_date_n SPY portf value =    882.6665649414062
# ====================
#
# date: 2023-08-11 is in dates_NYSE,  date's position in dates_NYSE is: 2670 of 2767,  n: 1,  idx_date_n: 2671,
# idx_date_n: 2671 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-14"
#
# date: 2023-08-11,  n: 1,  next_date_n: 2023-08-14 is in df_close
# picks for 2023-08-11: ['SHV', 'STRL']
# date = '2023-08-14', l_syms = ['SHV', 'STRL'], ar_price = array([109.27832031,  80.13999939]), ar_sym_share = array([4., 6.]), ar_sym_amt = array([437.11328125, 480.83999634]), portf_value = 917.9532775878906
# 2023-08-14 portf_value = 917.9532775878906
# date = '2023-08-14', symbol = 'SPY', price = 446.534912109375, share = 2.0, value = 893.06982421875
# 2023-08-14 SPY value = 893.06982421875
# next_date_n pick's portf value = 917.9532775878906
# next_date_n SPY portf value =    893.06982421875
# ====================
#
# date: 2023-08-10 is in dates_NYSE,  date's position in dates_NYSE is: 2669 of 2767,  n: 1,  idx_date_n: 2670,
# idx_date_n: 2670 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-11"
#
# date: 2023-08-10,  n: 1,  next_date_n: 2023-08-11 is in df_close
# picks for 2023-08-10: ['SHV', 'STRL']
# date = '2023-08-11', l_syms = ['SHV', 'STRL'], ar_price = array([109.25848389,  80.79000092]), ar_sym_share = array([4., 6.]), ar_sym_amt = array([437.03393555, 484.74000549]), portf_value = 921.7739410400391
# 2023-08-11 portf_value = 921.7739410400391
# date = '2023-08-11', symbol = 'SPY', price = 444.08355712890625, share = 2.0, value = 888.1671142578125
# 2023-08-11 SPY value = 888.1671142578125
# next_date_n pick's portf value = 921.7739410400391
# next_date_n SPY portf value =    888.1671142578125
# ====================
#
# date: 2023-08-09 is in dates_NYSE,  date's position in dates_NYSE is: 2668 of 2767,  n: 1,  idx_date_n: 2669,
# idx_date_n: 2669 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-10"
#
# date: 2023-08-09,  n: 1,  next_date_n: 2023-08-10 is in df_close
# picks for 2023-08-09: ['SHV', 'STRL']
# date = '2023-08-10', l_syms = ['SHV', 'STRL'], ar_price = array([109.23865509,  79.88999939]), ar_sym_share = array([4., 6.]), ar_sym_amt = array([436.95462036, 479.33999634]), portf_value = 916.2946166992188
# 2023-08-10 portf_value = 916.2946166992188
# date = '2023-08-10', symbol = 'SPY', price = 444.3426513671875, share = 2.0, value = 888.685302734375
# 2023-08-10 SPY value = 888.685302734375
# next_date_n pick's portf value = 916.2946166992188
# next_date_n SPY portf value =    888.685302734375
# ====================
#
# date: 2023-08-08 is in dates_NYSE,  date's position in dates_NYSE is: 2667 of 2767,  n: 1,  idx_date_n: 2668,
# idx_date_n: 2668 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-09"
#
# date: 2023-08-08,  n: 1,  next_date_n: 2023-08-09 is in df_close
# picks for 2023-08-08: ['SHV', 'STRL']
# date = '2023-08-09', l_syms = ['SHV', 'STRL'], ar_price = array([109.18907928,  78.34999847]), ar_sym_share = array([4., 6.]), ar_sym_amt = array([436.75631714, 470.09999084]), portf_value = 906.8563079833984
# 2023-08-09 portf_value = 906.8563079833984
# date = '2023-08-09', symbol = 'SPY', price = 444.1832275390625, share = 2.0, value = 888.366455078125
# 2023-08-09 SPY value = 888.366455078125
# next_date_n pick's portf value = 906.8563079833984
# next_date_n SPY portf value =    888.366455078125
# ====================
#
# date: 2023-08-07 is in dates_NYSE,  date's position in dates_NYSE is: 2666 of 2767,  n: 1,  idx_date_n: 2667,
# idx_date_n: 2667 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-08"
#
# date: 2023-08-07,  n: 1,  next_date_n: 2023-08-08 is in df_close
# picks for 2023-08-07: ['SHV']
# date = '2023-08-08', l_syms = ['SHV'], ar_price = array([109.17915344]), ar_sym_share = array([9.]), ar_sym_amt = array([982.61238098]), portf_value = 982.6123809814453
# 2023-08-08 portf_value = 982.6123809814453
# date = '2023-08-08', symbol = 'SPY', price = 447.17266845703125, share = 2.0, value = 894.3453369140625
# 2023-08-08 SPY value = 894.3453369140625
# next_date_n pick's portf value = 982.6123809814453
# next_date_n SPY portf value =    894.3453369140625
# ====================
#
# date: 2023-08-04 is in dates_NYSE,  date's position in dates_NYSE is: 2665 of 2767,  n: 1,  idx_date_n: 2666,
# idx_date_n: 2666 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-07"
#
# date: 2023-08-04,  n: 1,  next_date_n: 2023-08-07 is in df_close
# picks for 2023-08-04: ['SHV']
# date = '2023-08-07', l_syms = ['SHV'], ar_price = array([109.15932465]), ar_sym_share = array([9.]), ar_sym_amt = array([982.43392181]), portf_value = 982.4339218139648
# 2023-08-07 portf_value = 982.4339218139648
# date = '2023-08-07', symbol = 'SPY', price = 449.1257629394531, share = 2.0, value = 898.2515258789062
# 2023-08-07 SPY value = 898.2515258789062
# next_date_n pick's portf value = 982.4339218139648
# next_date_n SPY portf value =    898.2515258789062
# ====================
#
# date: 2023-08-03 is in dates_NYSE,  date's position in dates_NYSE is: 2664 of 2767,  n: 1,  idx_date_n: 2665,
# idx_date_n: 2665 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-08-04"
#
# date: 2023-08-03,  n: 1,  next_date_n: 2023-08-04 is in df_close
# picks for 2023-08-03: ['SHV']
# date = '2023-08-04', l_syms = ['SHV'], ar_price = array([109.15932465]), ar_sym_share = array([9.]), ar_sym_amt = array([982.43392181]), portf_value = 982.4339218139648
# ...
# next_date_n pick's portf value = 973.1078338623047
# next_date_n SPY portf value =    829.6806640625
# ====================
#
# date: 2023-05-30 is in dates_NYSE,  date's position in dates_NYSE is: 2619 of 2767,  n: 1,  idx_date_n: 2620,
# idx_date_n: 2620 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-31"
#
# date: 2023-05-30,  n: 1,  next_date_n: 2023-05-31 is in df_close
# picks for 2023-05-30: ['AVGO', 'NVDA']
# date = '2023-05-31', l_syms = ['AVGO', 'NVDA'], ar_price = array([799.32495117, 378.26968384]), ar_sym_share = array([0., 1.]), ar_sym_amt = array([  0.        , 378.26968384]), portf_value = 378.2696838378906
# 2023-05-31 portf_value = 378.2696838378906
# date = '2023-05-31', symbol = 'SPY', price = 414.84033203125, share = 2.0, value = 829.6806640625
# 2023-05-31 SPY value = 829.6806640625
# next_date_n pick's portf value = 378.2696838378906
# next_date_n SPY portf value =    829.6806640625
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['AVGO', 'SHV']
# date = '2023-05-30', l_syms = ['AVGO', 'SHV'], ar_price = array([794.7543335 , 108.10350037]), ar_sym_share = array([0., 4.]), ar_sym_amt = array([  0.        , 432.41400146]), portf_value = 432.41400146484375
# 2023-05-30 portf_value = 432.41400146484375
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 432.41400146484375
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['NVDA']
# date = '2023-05-30', l_syms = ['NVDA'], ar_price = array([401.03543091]), ar_sym_share = array([2.]), ar_sym_amt = array([802.07086182]), portf_value = 802.0708618164062
# 2023-05-30 portf_value = 802.0708618164062
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 802.0708618164062
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['AVGO']
# date = '2023-05-30', l_syms = ['AVGO'], ar_price = array([794.7543335]), ar_sym_share = array([1.]), ar_sym_amt = array([794.7543335]), portf_value = 794.7543334960938
# 2023-05-30 portf_value = 794.7543334960938
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 794.7543334960938
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-25 is in dates_NYSE,  date's position in dates_NYSE is: 2617 of 2767,  n: 1,  idx_date_n: 2618,
# idx_date_n: 2618 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-26"
#
# date: 2023-05-25,  n: 1,  next_date_n: 2023-05-26 is in df_close
# picks for 2023-05-25: ['SHV']
# date = '2023-05-26', l_syms = ['SHV'], ar_price = array([108.09370422]), ar_sym_share = array([9.]), ar_sym_amt = array([972.84333801]), portf_value = 972.8433380126953
# 2023-05-26 portf_value = 972.8433380126953
# date = '2023-05-26', symbol = 'SPY', price = 416.9946594238281, share = 2.0, value = 833.9893188476562
# 2023-05-26 SPY value = 833.9893188476562
# next_date_n pick's portf value = 972.8433380126953
# next_date_n SPY portf value =    833.9893188476562
# ====================
#
# date: 2023-05-25 is in dates_NYSE,  date's position in dates_NYSE is: 2617 of 2767,  n: 1,  idx_date_n: 2618,
# idx_date_n: 2618 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-26"
#
# date: 2023-05-25,  n: 1,  next_date_n: 2023-05-26 is in df_close
# picks for 2023-05-25: ['FTSM', 'NVDA']
# date = '2023-05-26', l_syms = ['FTSM', 'NVDA'], ar_price = array([ 58.46792603, 389.38763428]), ar_sym_share = array([8., 1.]), ar_sym_amt = array([467.7434082 , 389.38763428]), portf_value = 857.1310424804688
# 2023-05-26 portf_value = 857.1310424804688
# date = '2023-05-26', symbol = 'SPY', price = 416.9946594238281, share = 2.0, value = 833.9893188476562
# 2023-05-26 SPY value = 833.9893188476562
# next_date_n pick's portf value = 857.1310424804688
# next_date_n SPY portf value =    833.9893188476562
# ====================
#
# date: 2023-05-24 is in dates_NYSE,  date's position in dates_NYSE is: 2616 of 2767,  n: 1,  idx_date_n: 2617,
# idx_date_n: 2617 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-25"
#
# date: 2023-05-24,  n: 1,  next_date_n: 2023-05-25 is in df_close
# picks for 2023-05-24: ['SHV']
# date = '2023-05-25', l_syms = ['SHV'], ar_price = array([108.0741272]), ar_sym_share = array([9.]), ar_sym_amt = array([972.66714478]), portf_value = 972.6671447753906
# 2023-05-25 portf_value = 972.6671447753906
# date = '2023-05-25', symbol = 'SPY', price = 411.6633605957031, share = 2.0, value = 823.3267211914062
# 2023-05-25 SPY value = 823.3267211914062
# next_date_n pick's portf value = 972.6671447753906
# next_date_n SPY portf value =    823.3267211914062
# ====================
#
# date: 2023-05-23 is in dates_NYSE,  date's position in dates_NYSE is: 2615 of 2767,  n: 1,  idx_date_n: 2616,
# idx_date_n: 2616 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-24"
#
# date: 2023-05-23,  n: 1,  next_date_n: 2023-05-24 is in df_close
# picks for 2023-05-23: ['SHV']
# date = '2023-05-24', l_syms = ['SHV'], ar_price = array([108.02516174]), ar_sym_share = array([9.]), ar_sym_amt = array([972.22645569]), portf_value = 972.2264556884766
# 2023-05-24 portf_value = 972.2264556884766
# date = '2023-05-24', symbol = 'SPY', price = 408.1289978027344, share = 2.0, value = 816.2579956054688
# 2023-05-24 SPY value = 816.2579956054688
# next_date_n pick's portf value = 972.2264556884766
# next_date_n SPY portf value =    816.2579956054688
# ====================
#
# date: 2023-05-22 is in dates_NYSE,  date's position in dates_NYSE is: 2614 of 2767,  n: 1,  idx_date_n: 2615,
# idx_date_n: 2615 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-23"
#
# date: 2023-05-22,  n: 1,  next_date_n: 2023-05-23 is in df_close
# picks for 2023-05-22: ['SHV']
# date = '2023-05-23', l_syms = ['SHV'], ar_price = array([108.02516174]), ar_sym_share = array([9.]), ar_sym_amt = array([972.22645569]), portf_value = 972.2264556884766
# 2023-05-23 portf_value = 972.2264556884766
# date = '2023-05-23', symbol = 'SPY', price = 411.107421875, share = 2.0, value = 822.21484375
# 2023-05-23 SPY value = 822.21484375
# next_date_n pick's portf value = 972.2264556884766
# next_date_n SPY portf value =    822.21484375
# ====================
#
# date: 2023-05-19 is in dates_NYSE,  date's position in dates_NYSE is: 2613 of 2767,  n: 1,  idx_date_n: 2614,
# idx_date_n: 2614 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-22"
#
# date: 2023-05-19,  n: 1,  next_date_n: 2023-05-22 is in df_close
# picks for 2023-05-19: ['SHV']
# date = '2023-05-22', l_syms = ['SHV'], ar_price = array([108.00557709]), ar_sym_share = array([9.]), ar_sym_amt = array([972.05019379]), portf_value = 972.0501937866211
# 2023-05-22 portf_value = 972.0501937866211
# date = '2023-05-22', symbol = 'SPY', price = 415.7735595703125, share = 2.0, value = 831.547119140625
# 2023-05-22 SPY value = 831.547119140625
# next_date_n pick's portf value = 972.0501937866211
# next_date_n SPY portf value =    831.547119140625
# ====================
#
# date: 2023-05-18 is in dates_NYSE,  date's position in dates_NYSE is: 2612 of 2767,  n: 1,  idx_date_n: 2613,
# idx_date_n: 2613 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-19"
#
# date: 2023-05-18,  n: 1,  next_date_n: 2023-05-19 is in df_close
# picks for 2023-05-18: ['SHV', 'TMHC']
# date = '2023-05-19', l_syms = ['SHV', 'TMHC'], ar_price = array([108.00557709,  44.25      ]), ar_sym_share = array([ 4., 11.]), ar_sym_amt = array([432.02230835, 486.75      ]), portf_value = 918.7723083496094
# 2023-05-19 portf_value = 918.7723083496094
# date = '2023-05-19', symbol = 'SPY', price = 415.6047668457031, share = 2.0, value = 831.2095336914062
# 2023-05-19 SPY value = 831.2095336914062
# next_date_n pick's portf value = 918.7723083496094
# next_date_n SPY portf value =    831.2095336914062
# ====================
#
# date: 2023-05-17 is in dates_NYSE,  date's position in dates_NYSE is: 2611 of 2767,  n: 1,  idx_date_n: 2612,
# idx_date_n: 2612 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-18"
#
# date: 2023-05-17,  n: 1,  next_date_n: 2023-05-18 is in df_close
# picks for 2023-05-17: ['SHV']
# date = '2023-05-18', l_syms = ['SHV'], ar_price = array([108.00557709]), ar_sym_share = array([9.]), ar_sym_amt = array([972.05019379]), portf_value = 972.0501937866211
# 2023-05-18 portf_value = 972.0501937866211
# date = '2023-05-18', symbol = 'SPY', price = 416.21038818359375, share = 2.0, value = 832.4207763671875
# 2023-05-18 SPY value = 832.4207763671875
# next_date_n pick's portf value = 972.0501937866211
# next_date_n SPY portf value =    832.4207763671875
# ====================
#
# date: 2023-05-16 is in dates_NYSE,  date's position in dates_NYSE is: 2610 of 2767,  n: 1,  idx_date_n: 2611,
# idx_date_n: 2611 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-17"
#
# date: 2023-05-16,  n: 1,  next_date_n: 2023-05-17 is in df_close
# picks for 2023-05-16: ['SHV']
# date = '2023-05-17', l_syms = ['SHV'], ar_price = array([107.97620392]), ar_sym_share = array([9.]), ar_sym_amt = array([971.78583527]), portf_value = 971.7858352661133
# 2023-05-17 portf_value = 971.7858352661133
# date = '2023-05-17', symbol = 'SPY', price = 412.23919677734375, share = 2.0, value = 824.4783935546875
# 2023-05-17 SPY value = 824.4783935546875
# next_date_n pick's portf value = 971.7858352661133
# next_date_n SPY portf value =    824.4783935546875
# ====================
#
# date: 2023-05-15 is in dates_NYSE,  date's position in dates_NYSE is: 2609 of 2767,  n: 1,  idx_date_n: 2610,
# idx_date_n: 2610 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-16"
#
# date: 2023-05-15,  n: 1,  next_date_n: 2023-05-16 is in df_close
# picks for 2023-05-15: ['SHV']
# date = '2023-05-16', l_syms = ['SHV'], ar_price = array([107.95661163]), ar_sym_share = array([9.]), ar_sym_amt = array([971.6095047]), portf_value = 971.609504699707
# 2023-05-16 portf_value = 971.609504699707
# date = '2023-05-16', symbol = 'SPY', price = 407.2950439453125, share = 2.0, value = 814.590087890625
# 2023-05-16 SPY value = 814.590087890625
# next_date_n pick's portf value = 971.609504699707
# next_date_n SPY portf value =    814.590087890625
# ====================
#
# date: 2023-05-12 is in dates_NYSE,  date's position in dates_NYSE is: 2608 of 2767,  n: 1,  idx_date_n: 2609,
# idx_date_n: 2609 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-15"
#
# date: 2023-05-12,  n: 1,  next_date_n: 2023-05-15 is in df_close
# picks for 2023-05-12: ['SHV']
# date = '2023-05-15', l_syms = ['SHV'], ar_price = array([107.95661163]), ar_sym_share = array([9.]), ar_sym_amt = array([971.6095047]), portf_value = 971.609504699707
# 2023-05-15 portf_value = 971.609504699707
# date = '2023-05-15', symbol = 'SPY', price = 410.03515625, share = 2.0, value = 820.0703125
# 2023-05-15 SPY value = 820.0703125
# next_date_n pick's portf value = 971.609504699707
# next_date_n SPY portf value =    820.0703125
# ====================
#
# date: 2023-05-11 is in dates_NYSE,  date's position in dates_NYSE is: 2607 of 2767,  n: 1,  idx_date_n: 2608,
# idx_date_n: 2608 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-12"
#
# date: 2023-05-11,  n: 1,  next_date_n: 2023-05-12 is in df_close
# picks for 2023-05-11: ['ISEE', 'SHV']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 51
#      47     print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')
#      49 else:
#      50     p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
# ---> 51         get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
#      52     s_date, s_price, s_share, s_value = \
#      53         get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
#      55     date_buy.append(p_date)
#
# Cell In[12], line 6, in get_portf_buy(df_close, date, str_symbols, portf_target, verbose)
#       4 l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
#       5 # array of closing prices corresponding to symbols in l_syms
# ----> 6 ar_price = df_close.loc[date][l_syms].values
#       7 sym_cnt = len(l_syms)  # number of symbols
#       8 amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     key = np.asarray(key, dtype=bool)
#    1005     return self._get_values(key)
# -> 1007 return self._get_with(key)
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\series.py:1047, in Series._get_with(self, key)
#    1044         return self.iloc[key]
#    1046 # handle the dup indexing case GH#4246
# -> 1047 return self.loc[key]
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1239, in _LocIndexer._getitem_iterable(self, key, axis)
#    1236 self._validate_key(key, axis)
#    1238 # A collection of keys
# -> 1239 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240 return self.obj._reindex_with_indexers(
#    1241     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1242 )
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1429 ax = self.obj._get_axis(axis)
#    1430 axis_name = self.obj._get_axis_name(axis)
# -> 1432 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434 return keyarr, indexer
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['ISEE'] not in index"

# %% [markdown]
# #### Below cells calculate past performance of model picks

# %%
def calc_portf_shares(df_close, date, str_symbols, portf_target):
  # calculate number of shares to buy for symbols in str_symbols to meet port_target
  import numpy as np
  from ast import literal_eval    
  l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
  # array of closing prices corresponding to symbols in l_syms    
  ar_price = df_close.loc[date][l_syms].values  
  sym_cnt = len(l_syms)  # number of symbols
  amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
  ar_shares = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
  return ar_shares

# %%
def calc_portf_value(df_close, date, str_symbols, ar_shares, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    ar_value = ar_price * ar_shares  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_value)  # total actual portfolio value
    if verbose:
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_shares = }, {ar_value = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_shares, ar_value, portf_value

# %%
def get_next_date_n(df_close, date, n=1):

    """Get the next n(default=1) date from df_close. date has to in df_close.index.

    Edge case: The function won't return the first date in df_close as the
    next trading date, if date is a trading date just before the first date in df_close.
    """

    len_df_close = len(df_close)
    idx_dates = df_close.index.strftime('%Y-%m-%d')  # date index of df_close    

    if date in idx_dates:
        idx_next_date = idx_dates.get_loc(date) + n  # get index position of next date
        print(f'n: {n},  idx_next_date: {idx_next_date}')

        if idx_next_date >= 0:  # if idx_nex_date is negative, stop index loop back from index[0] to index[-1]    
            if idx_next_date >= (len_df_close - n):  # next date's index is within bound of df_close
                next_date = idx_dates[idx_dates.get_loc(date) + n]  # get the next date
                return next_date
        
              
            else:  # idx_next_date is out-of_bounds df_close
                print(f"{date} is the last date in df_close. No data for next {n} day")
                return None    
        
        
        else:  # idx_next_date is negative, no data in df_close
            # no data from df_close
            print(f'idx_next_date: {idx_next_date} is negative, no data for {n} days from {date} in df_close')

    else:     
        # no data from df_close
        print(f'no data for {date} in df_close')
        return None

# %%
def is_date_in_close(date, df_close):
  idx_close = df_close.index.strftime('%Y-%m-%d')
  if date in idx_close:
    return date
  else:
    return None

# %%
def calc_portf_value_date_buy(my_dates, my_symbols, df_close, portf_target, n, verbose=False):
  
  z_date_syms = zip(my_dates, my_symbols)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, syms in z_date_syms:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date = None
      p_ar_shares = None
      p_portf_value = None  # set to None when data are not available in df_close
      SPY_shares = None
      SPY_value = None  # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        print(f'No data for close_date_n {close_date_n}, SPY portf value =    None')

    else:    
      p_ar_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      p_date, l_syms, ar_price, ar_shares, ar_value, p_portf_value = \
        calc_portf_value(df_close, close_date_n, syms, p_ar_shares, verbose)

      syms = str(['SPY'])
      SPY_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      date, l_syms, ar_price, ar_shares, ar_value, SPY_value = \
        calc_portf_value(df_close, close_date_n, syms, SPY_shares, verbose)

      if verbose:
        print(f"close_date_n pick's portf value = {p_portf_value}")
        print(f'close_date_n SPY portf value =    {SPY_value}')

    date_exec.append(p_date)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_portf_value)
    shares_SPY.append(SPY_shares)
    value_SPY.append(SPY_value)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
def calc_portf_value_date_n(my_dates, my_symbols, df_close, my_portf_shares, my_SPY_shares, n, verbose=False):
  
  z_date_syms_shares = zip(my_dates, my_symbols, my_portf_shares, my_SPY_shares)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, symbols, portf_shares, SPY_shares in z_date_syms_shares:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date_exec = None
      p_ar_shares = None
      p_value_portf = None  # set to None when data are not available in df_close
      SPY_ar_shares = None
      SPY_value_portf = None # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        # print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else: 
      if portf_shares is None:
        p_date_exec = None
        p_ar_shares = None
        p_value_portf = None
        SPY_ar_shares = None
        SPY_value_portf = None

      else:  
        p_date_exec, p_ar_syms, p_ar_price, p_ar_shares, p_ar_value, p_value_portf = \
          calc_portf_value(df_close, close_date_n, symbols, portf_shares, verbose)
        
        SPY = str(['SPY'])
        SPY_date_exec, SPY_ar_syms, SPY_ar_price, SPY_ar_shares, SPY_ar_value, SPY_value_portf = \
          calc_portf_value(df_close, close_date_n, SPY, SPY_shares, verbose) 

        if verbose:
          print(f"next_date_n pick's portf value = {p_value_portf}")
          print(f'next_date_n SPY portf value =    {SPY_value_portf}')

    date_exec.append(p_date_exec)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_value_portf)
    shares_SPY.append(SPY_ar_shares)
    value_SPY.append(SPY_value_portf)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
# total target investment for each day's picks, if day's pick has 2 symbols, the function will try to invest $500 for each symbol
portf_target = 1000  
date_buy, shares_syms, value_portf, shares_SPY, value_SPY = calc_portf_value_date_buy(df_mp.date, df_mp.symbols, df_close, portf_target, n=1, verbose=verbose)

# %%
df_mp['date_buy'] = date_buy
df_mp['sh_portf_buy'] = shares_syms
df_mp['$_portf_buy'] = value_portf
df_mp['sh_SPY_buy'] = shares_SPY
df_mp['$_SPY_buy'] = value_SPY
# df_mp.tail()
# df_mp.head()
df_mp

# %%
date_exec, shares_syms, value_portf, shares_SPY, value_SPY  = \
  calc_portf_value_date_n(df_mp.date, df_mp.symbols, df_close, df_mp.sh_portf_buy, df_mp.sh_SPY_buy, n=4, verbose=verbose)

# %%
df_mp['date_sell'] = date_exec
df_mp['sh_portf_sell'] = shares_syms
df_mp['$_portf_sell'] = value_portf
df_mp['%_portf_chg'] = (df_mp['$_portf_sell'] / df_mp['$_portf_buy'] - 1) * 100

df_mp['sh_SPY_sell'] = shares_SPY
df_mp['$_SPY_sell'] = value_SPY
df_mp['%_SPY_chg'] = (df_mp['$_SPY_sell'] / df_mp['$_SPY_buy'] - 1) * 100

df_mp['dif_%_chg'] = df_mp['%_portf_chg'] - df_mp['%_SPY_chg']

# %%
# get symbol's close price for that date
date = '2023-03-16'
# _date = '2023-03-21'
# _sym = 'GE'
# _sym = 'NVDA'
_sym = 'FTSM'
# _sym = 'SHV'
_sym = 'SPY'
# _c = df_close.loc['2023-04-11']['NVDA']
_c = df_close.loc[_date][_sym]
_c

# %% [markdown]
# #### dif_%_chg is the percentage change of model icks - percentage change of SPY

# %%
df_mp.head(20)

# %%
df_mp['win'] = np.where(df_mp['dif_%_chg']>0,1,0)
df_mp.head(20)

# %% [markdown]
# ### Model Performance Not Good

# %%
wins = df_mp['win'].sum()
attempts = len(df_mp['dif_%_chg'].dropna())

win_rate = wins / attempts
print(f'win_rate: {win_rate:0.6f}, wins: {wins}, attempts: {attempts}')
print(f'sum(dff_%_chg): {df_mp["dif_%_chg"].sum():0.6f}')

# %%
df = df_mp.copy()

# %%
df_model_picks = df[df['dif_%_chg'].isnull()].copy()
pickle_dump(df_model_picks, path_data_dump, 'df_model_picks')
_df = pickle_load(path_data_dump, 'df_model_picks')
_df

# %%
idx_last_row = df_model_picks.index[-1]
df_model_picks_results = df.iloc[(idx_last_row + 1)::].copy()
pickle_dump(df_model_picks_results, path_data_dump, 'df_model_picks_results')
_df = pickle_load(path_data_dump, 'df_model_picks_results')
_df
