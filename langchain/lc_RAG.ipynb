# %%
import os
import sys
sys.path.append('../..')

import openai
from langchain.chains import ConversationalRetrievalChain, RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain_openai import OpenAIEmbeddings
from langchain.indexes import VectorstoreIndexCreator
from langchain.indexes.vectorstore import VectorStoreIndexWrapper
from langchain.llms import OpenAI
from langchain.vectorstores import Chroma

# %%
from py3810.myUtils import pickle_dump, pickle_load
path_lumen_docs = '..\langchain\docs\lumen\\docs\\'

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv('.env\my_api_key.env')) # read local .env file

SECRET_KEY1 = os.environ.get("SECRET_KEY")
DATABASE_PASSWORD2 = os.environ.get("DATABASE_PASSWORD")
print(f"SECRET_KEY = {SECRET_KEY1}")
print(f"DATABASE_PASSWORD = {DATABASE_PASSWORD2}")

openai.api_key  = os.environ['openai_api']
os.environ["OPENAI_API_KEY"] = openai.api_key
# Out:
# SECRET_KEY = my_secret_key
# DATABASE_PASSWORD = my_db_pwd

# %%
# loader = TextLoader(path_lumen_docs + "data.txt", encoding = 'utf-8') #

# %%
# data = pickle_load(filename_pickle='lumen_data', path_pickle_dump=path_lumen_docs)

# %%
# documents =data

# with open('data.txt', 'w', encoding="utf-8") as f:
#   for doc in documents:
#     f.write(str(doc) + '\n')

# %%
# from langchain.vectorstores import Chroma

vectorstore = Chroma(persist_directory="./persist")

# %%
PERSIST = True

if PERSIST and os.path.exists("persist"):
  print("Reusing index...\n")

  vectorstore = Chroma(persist_directory="persist", embedding_function=OpenAIEmbeddings())  
  # vectorstore = Chroma(persist_directory="./persist")
  
  index = VectorStoreIndexWrapper(vectorstore=vectorstore)


  
  print('elkfjdsl')

# %%
vectorstore = Chroma(persist_directory="./persist")
loader = TextLoader(path_lumen_docs + "lumen_data.txt", encoding='utf-8')
index = VectorstoreIndexCreator().from_loaders([loader])
vectorstore.persist()
# Out:
# c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
print("Reusing index...\n")
vectorstore = Chroma(persist_directory="persist", embedding_function=OpenAIEmbeddings())  
# vectorstore = Chroma(persist_directory="./persist")
index = VectorStoreIndexWrapper(vectorstore=vectorstore)
# Out:
# Reusing index...

# %%
my_text = 'lumen optometric'
retriever=index.vectorstore.as_retriever(search_kwargs={my_text: 1})
retriever
# Out:
# VectorStoreRetriever(tags=['Chroma', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x000001FBA5E13DC0>, search_kwargs={'lumen optometric': 1})

# %%
index
# Out:
# VectorStoreIndexWrapper(vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x000001FBA5E13DC0>)

# %%
# query = "where is lumen optometric located"
query = None
if len(sys.argv) > 2:
  query = sys.argv[2]

chain = ConversationalRetrievalChain.from_llm(
  llm=ChatOpenAI(model="gpt-3.5-turbo"),
  retriever=index.vectorstore.as_retriever(search_kwargs={"k": 1}),
)

chat_history = []
while True:
  print(f'query: {query}')
  print(f'sys.argv: {sys.argv}')
  if not query:
    query = input("Prompt: ")
  if query in ['quit', 'q', 'exit']:
    sys.exit()
  result = chain({"question": query, "chat_history": chat_history})
  print(f'Prompt: {query}')
  ans = result['answer']
  print(f'Chatbot: {ans}')
  chat_history.append((query, result['answer']))
  print(f'\nchat_history: {chat_history}\n')
  query = None
# Out:
# query: None
# sys.argv: ['c:\\Users\\ping\\MyDrive\\py_files\\python\\py3810\\.venv\\lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\ping\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-14904HCH4LHFcy8eH.json']
# Prompt: where is lumen optometric located
# Chatbot: I don't know.
#
# chat_history: [('where is lumen optometric located', "I don't know.")]
#
# query: None
# sys.argv: ['c:\\Users\\ping\\MyDrive\\py_files\\python\\py3810\\.venv\\lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\ping\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-14904HCH4LHFcy8eH.json']
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\IPython\core\interactiveshell.py:3468: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# https://medium.com/@AndresHerranz/llms-langchain-and-vectorstores-2489a2ea1ef1
persist_directory = "db"
vectorstore = Chroma.from_documents(documents, embeddings, persist_directory=persist_directory)

vectorstore.persist()
print("Vector-store saved and ready to use!")

# %%
# %%

# Enable to save to disk & reuse the model (for repeated queries on the same data)
PERSIST = False
# PERSIST = True

query = None
# query = 'hello'
if len(sys.argv) > 1:
  query = sys.argv[1]


if PERSIST and os.path.exists("persist"):
  print("Reusing index...\n")
  vectorstore = Chroma(persist_directory="persist", embedding_function=OpenAIEmbeddings())  
  # vectorstore = Chroma(persist_directory="./persist")
  index = VectorStoreIndexWrapper(vectorstore=vectorstore)
else:
  loader = TextLoader(path_lumen_docs + "lumen_data.txt", encoding='utf-8')
  # loader = DirectoryLoader("data/")  
  if PERSIST:
    index = VectorstoreIndexCreator(vectorstore_kwargs={"persist_directory": "persist"}).from_loaders([loader])
  else:
    index = VectorstoreIndexCreator().from_loaders([loader])
  if PERSIST:
    vectorstore.save("persist")

# vectorstore.save("persist")
vectorstore.persist()

chain = ConversationalRetrievalChain.from_llm(
  llm=ChatOpenAI(model="gpt-3.5-turbo"),
  retriever=index.vectorstore.as_retriever(search_kwargs={"k": 2}),
)

chat_history = []
while True:
  if not query:
    query = input("Prompt: ")
  if query in ['quit', 'q', 'exit']:
    sys.exit()
  result = chain({"question": query, "chat_history": chat_history})
  print(f'Prompt: {query}')
  ans = result['answer']
  print(f'Chatbot: {ans}')

# %%
import os
import sys
sys.path.append('../..')

import openai
from langchain.chains import ConversationalRetrievalChain, RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.indexes import VectorstoreIndexCreator
from langchain.indexes.vectorstore import VectorStoreIndexWrapper
from langchain.llms import OpenAI
from langchain.vectorstores import Chroma

# %%
from py3810.myUtils import pickle_dump, pickle_load
path_lumen_docs = '..\langchain\docs\lumen\\docs\\'

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv('.env\my_api_key.env')) # read local .env file

SECRET_KEY1 = os.environ.get("SECRET_KEY")
DATABASE_PASSWORD2 = os.environ.get("DATABASE_PASSWORD")
print(f"SECRET_KEY = {SECRET_KEY1}")
print(f"DATABASE_PASSWORD = {DATABASE_PASSWORD2}")

openai.api_key  = os.environ['openai_api']
os.environ["OPENAI_API_KEY"] = openai.api_key

# %%
# Enable to save to disk & reuse the model (for repeated queries on the same data)
PERSIST = False

query = None
if len(sys.argv) > 1:
  query = sys.argv[1]

if PERSIST and os.path.exists("persist"):
  print("Reusing index...\n")
  vectorstore = Chroma(persist_directory="persist", embedding_function=OpenAIEmbeddings())
  index = VectorStoreIndexWrapper(vectorstore=vectorstore)
else:
  loader = TextLoader("C:\\Users\\ping\\Desktop\\docs_raw_merged_cleaned.txt", encoding = 'utf-8') # Use this line if you only need data.txt
  # loader = TextLoader("data/data.txt") # Use this line if you only need data.txt  
  # loader = DirectoryLoader("data/")
  if PERSIST:
    index = VectorstoreIndexCreator(vectorstore_kwargs={"persist_directory":"persist"}).from_loaders([loader])
  else:
    index = VectorstoreIndexCreator().from_loaders([loader])

chain = ConversationalRetrievalChain.from_llm(
  llm=ChatOpenAI(model="gpt-3.5-turbo"),
  retriever=index.vectorstore.as_retriever(search_kwargs={"k": 1}),
)

# %%
query = "what is lumen optometric's address"

# %%
chat_history = []
while True:
  if not query:
    query = input("Prompt: ")
  if query in ['quit', 'q', 'exit']:
    sys.exit()
  result = chain({"question": query, "chat_history": chat_history})
  print(result['answer'])

  chat_history.append((query, result['answer']))
  query = None

# %%
import os
import sys

import openai
from langchain.chains import ConversationalRetrievalChain, RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.indexes import VectorstoreIndexCreator
from langchain.indexes.vectorstore import VectorStoreIndexWrapper
from langchain.llms import OpenAI
from langchain.vectorstores import Chroma

import constants

os.environ["OPENAI_API_KEY"] = constants.APIKEY

# Enable to save to disk & reuse the model (for repeated queries on the same data)
PERSIST = False

query = None
if len(sys.argv) > 1:
  query = sys.argv[1]

if PERSIST and os.path.exists("persist"):
  print("Reusing index...\n")
  vectorstore = Chroma(persist_directory="persist", embedding_function=OpenAIEmbeddings())
  index = VectorStoreIndexWrapper(vectorstore=vectorstore)
else:
  #loader = TextLoader("data/data.txt") # Use this line if you only need data.txt
  loader = DirectoryLoader("data/")
  if PERSIST:
    index = VectorstoreIndexCreator(vectorstore_kwargs={"persist_directory":"persist"}).from_loaders([loader])
  else:
    index = VectorstoreIndexCreator().from_loaders([loader])

chain = ConversationalRetrievalChain.from_llm(
  llm=ChatOpenAI(model="gpt-3.5-turbo"),
  retriever=index.vectorstore.as_retriever(search_kwargs={"k": 1}),
)

chat_history = []
while True:
  if not query:
    query = input("Prompt: ")
  if query in ['quit', 'q', 'exit']:
    sys.exit()
  result = chain({"question": query, "chat_history": chat_history})
  print(result['answer'])

  chat_history.append((query, result['answer']))
  query = None
