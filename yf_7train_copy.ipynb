# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump, delete_all_rows
from yf_utils import split_train_val_test, random_slices, lookback_slices
from yf_utils import top_set_sym_freq_cnt, get_grp_top_syms_n_freq
from yf_utils import eval_grp_top_syms_n_freq


pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.width", 500)  # code-runner format

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"

path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = "df_close_clean"

# %% [markdown]
# ### Run below cell for Colab

# %%
#######################################################################
## SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# select run type
run_type = "train"
# run_type = 'validate'
# run_type = "test"

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms
# n_samples = 400
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
days_lookbacks = [15, 30, 60]
# days_lookbacks = [30, 60, 120]
# days_lookbacks = [15, 30, 60, 120]
days_lookbacks.sort()

# number of days in dataframe to evaluate effectiveness of the training, days_eval = len(df_eval)
#  days_eval = 4 means buy at close on 1st day after the signal, hold for 2nd and 3rd day, sell at close on 4th day
days_eval = 4
# days_eval = 5

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20
# n_top_syms = 5

# slice starts and ends for selecting the best performing symbols
# syms_start = 1, syms_end = 11 will keep the 2nd to 11th best performing symbols  
syms_start = 0
syms_end = 10


##########################################################
# fp_df_eval_results = f"df_eval_results_{run_type}"
fp_df_eval_results = "test_df_eval"
##########################################################

#### Delete all rows in df_eval_results ##################
delete_all_rows(path_data_dump, fp_df_eval_results)
##########################################################

# %%
path_data_dump
# Out:
# 'C:/Users/ping/MyDrive/stocks/yfinance/VSCode_dump/'

# %%
print(f"verbose : {verbose }")
print(f"store_results: {store_results}")
print(f"run_type: {run_type}")
print(f"n_samples: {n_samples}")
print(f"days_lookbacks: {days_lookbacks}")
print(f"days_eval: {days_eval}")
print(f"n_top_syms: {n_top_syms}")
print(f"syms_start: {syms_start}")
print(f"syms_end: {syms_end}")
print(f"fp_df_eval_results: {fp_df_eval_results}")

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = split_train_val_test(df_close_clean)
# Out:
# verbose : True
# store_results: True
# run_type: train
# n_samples: 2
# days_lookbacks: [15, 30, 60]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10
# fp_df_eval_results: test_df_eval

# %%
# max_days_lookbacks = max(days_lookbacks)
# print(f"max_days_lookbacks: {max_days_lookbacks}")

# Load df according to run_type
if run_type == "train":
    df = df_train.copy()
elif run_type == "validate":
    df = df_val.copy()
elif run_type == "test":
    df = df_test.copy()
else:
    msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop)

# Print dataframe for the run, and lengths of other dataframes
print(f"run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n")
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f"run_type: {run_type}, len(df): {len(df)}")
print(
    f"len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}"
)

# return n_samples slices
max_lookback_slices = random_slices(
    len_df,
    n_samples=n_samples,
    days_lookback=max(days_lookbacks),
    days_eval=days_eval,
    verbose=False,
)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = lookback_slices(
    max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False
)
# Out:
# run_type: train, df.tail(3):
#                      A         AA        AAL         AAP        AAPL         AB        ABBV        ABR         ABT       ACGL       ACHC       ACIW       ACLS   ACRS        ADBE  ...        XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION          ZS        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                               ...
# 2022-05-16  118.837852  59.085037  16.549999  202.640701  144.107010  33.026737  145.170074  13.654121  106.067047  46.110001  70.750000  25.250000  56.380001  11.03  402.859985  ...  79.743790  29.299999  107.992798  38.626312  36.172478  113.506256  329.329987  78.040001  38.689999  48.793896  140.080002  24.322893  162.986786  33.939999  27.013489
# 2022-05-17  121.584053  62.143196  17.820000  205.077820  147.770615  34.519226  144.525803  13.821313  110.736671  46.880001  73.699997  25.660000  60.560001  12.32  409.649994  ...  81.927467  30.370001  108.271980  40.212486  37.141956  117.706520  344.579987  80.070000  41.180000  50.609951  141.779999  25.388994  163.902649  34.439999  27.532978
# 2022-05-18  119.321884  59.310482  16.889999  185.391281  139.433502  34.047913  142.331497  13.375465  108.996429  45.820000  69.480003  25.110001  57.020000  11.92  397.880005  ...  78.924896  29.490000  105.374329  40.026455  36.364544  114.817596  326.420013  77.820000  40.400002  49.198967  128.089996  24.954659  156.447617  32.150002  25.866690
#
# [3 rows x 1261 columns]
#
# run_type: train, len(df): 1050
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %% [markdown]
# ### Run below cell to use test data to debug code, results should match yf_test.ipynb

# %%
# ####### RUN THIS CELL TO USE TEST DATA TO DEBUG CODE, RESULTS SHOULD MATCH yf_test.ipynb ################# 

# # load test data to debug code if needed
# test_dic = pickle_load(path_data_dump, 'yf_test_dic')
# for i, key in enumerate(test_dic.keys()):
#   print(f'{i}: {key}')

# # convert dictionary entries into variables
# locals().update(test_dic)
# del df_eval_results  # delete df_eval_results loaded from locals().update(test_dic)

# # Delete all rows in df_eval_results
# delete_all_rows(path_data_dump, fp_df_eval_results)

# %%
max_days_lookbacks = max(days_lookbacks)
print(f"max_days_lookbacks: {max_days_lookbacks}")

if verbose:
    print(f"number of max_lookback_slices is equal to n_samples = {n_samples}")
    print(f"max_lookback_slices:\n{max_lookback_slices}\n")
    print(f"number of sets in sets_lookback_slices is equal to n_samples = {n_samples}")
    print(f"sets_lookback_slices:\n{sets_lookback_slices}\n")
    print(f"days_lookbacks: {days_lookbacks}")
    print(
        f'number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): {len(days_lookbacks)}'
    )

# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the max_lookback_slices. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in max_lookback_slices. There are as many sub-lists as there are tuples in max_lookback_slices.
grp_top_set_syms_n_freq, grp_top_set_syms, dates_end_df_train = get_grp_top_syms_n_freq(
    df, sets_lookback_slices, days_lookbacks, n_top_syms, syms_start, syms_end, verbose
)

# #### print the best performing symbols for each set in sets_lookback_slices
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
    l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
    if verbose:
        print(f"max_lookback_slices:             {max_lookback_slices}")
        # print(f'set_lookback_slices: {sets_lookback_slices[i]}\n')
        print(
            f"set_lookback_slices {i + 1} of {len(sets_lookback_slices):>3}:    {sets_lookback_slices[i]}\n"
        )
        print(f"max_days_lookbacks:              {max_days_lookbacks}")
        print(f"df end date for days_lookbacks:  {dates_end_df_train[i]}")
        print(f"days_lookbacks:                  {days_lookbacks}")
        print(f"sym_freq_15:                     {l_sym_freq_cnt[0]}")
        print(f"sym_freq_14:                     {l_sym_freq_cnt[1]}")
        print(f"sym_freq_13:                     {l_sym_freq_cnt[2]}")
        print(f"sym_freq_12:                     {l_sym_freq_cnt[3]}")
        print(f"sym_freq_11:                     {l_sym_freq_cnt[4]}")
        print(f"sym_freq_10:                     {l_sym_freq_cnt[5]}")
        print(f"sym_freq_9:                      {l_sym_freq_cnt[6]}")
        print(f"sym_freq_8:                      {l_sym_freq_cnt[7]}")
        print(f"sym_freq_7:                      {l_sym_freq_cnt[8]}")
        print(f"sym_freq_6:                      {l_sym_freq_cnt[9]}")
        print(f"sym_freq_5:                      {l_sym_freq_cnt[10]}")
        print(f"sym_freq_4:                      {l_sym_freq_cnt[11]}")
        print(f"sym_freq_3:                      {l_sym_freq_cnt[12]}")
        print(f"sym_freq_2:                      {l_sym_freq_cnt[13]}\n")


# #### Evaluate performance of symbols in set_lookback_slices versus SPY
l_row_add_total = eval_grp_top_syms_n_freq(
    df, max_lookback_slices, sets_lookback_slices, grp_top_set_syms_n_freq, days_lookbacks, days_eval, n_samples, n_top_syms, syms_start, syms_end, verbose
)

for row_add_total in l_row_add_total:
    print(f"row_add_total: {row_add_total}")

if store_results:  # record results to df
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results BEFORW store results:\n{df_eval_results}\n")

    for row_add_total in l_row_add_total:
        # print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f"appended row_add_total to df_eval_results:\n{row_add_total}\n")

    pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
    print(f"Save results to: {fp_df_eval_results}")
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results AFTER store results:\n{df_eval_results}\n")
# Out:
# max_days_lookbacks: 60
# number of max_lookback_slices is equal to n_samples = 2
# max_lookback_slices:
# [(777, 837, 841), (759, 819, 823)]
#
# number of sets in sets_lookback_slices is equal to n_samples = 2
# sets_lookback_slices:
# [[(822, 837, 841), (807, 837, 841), (777, 837, 841)], [(804, 819, 823), (789, 819, 823), (759, 819, 823)]]
#
# days_lookbacks: [15, 30, 60]
# number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): 3
#
# ########## 1 of 2 lb_slices: [(822, 837, 841), (807, 837, 841), (777, 837, 841)] in sets_lookcak_slices ##########
# days lookback:       15,  1 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(822, 837, 841), (807, 837, 841), (777, 837, 841)]
# lb_slice:            (822, 837, 841)
# days eval:           4
# iloc_start_train:    822
# iloc_end_train:      837
# date_start_df_train: 2021-06-24
# date_end_df_train:   2021-07-15
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['NTLA', 'WB', 'TX', 'NKE', 'PAYX', 'AAPL', 'ORLY', 'CLAR', 'SWX',
#        'ZTS', 'DQ', 'TGT', 'AZO', 'KNX', 'CMP', 'MAA', 'BRKR', 'NVO',
#        'ORCL', 'HUM'], dtype=object), 'r_CAGR/retnStd': array(['NTLA', 'TX', 'WB', 'NKE', 'DQ', 'AAPL', 'CLAR', 'PAYX', 'SWX',
#        'ORLY', 'NVO', 'MAA', 'AZO', 'CMP', 'ZTS', 'BRKR', 'ORCL', 'HUM',
#        'IRT', 'WAT'], dtype=object), 'r_retnStd/UI': array(['WB', 'NKE', 'PAYX', 'TGT', 'KNX', 'TX', 'ORLY', 'AAPL', 'FSD',
#        'EOS', 'ZTS', 'DPZ', 'BR', 'CLAR', 'ADP', 'PG', 'AZO', 'SWX',
#        'BRKR', 'PZZA'], dtype=object)}}
# most_freq_syms: [('WB', 3), ('TX', 3), ('NKE', 3), ('PAYX', 3), ('AAPL', 3), ('ORLY', 3), ('CLAR', 3), ('SWX', 3), ('ZTS', 3), ('AZO', 3), ('BRKR', 3), ('NTLA', 2), ('DQ', 2), ('TGT', 2), ('KNX', 2), ('CMP', 2), ('MAA', 2), ('NVO', 2), ('ORCL', 2), ('HUM', 2), ('IRT', 1), ('WAT', 1), ('FSD', 1), ('EOS', 1), ('DPZ', 1), ('BR', 1), ('ADP', 1), ('PG', 1), ('PZZA', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(822, 837, 841), (807, 837, 841), (777, 837, 841)]
# lb_slice:            (807, 837, 841)
# days eval:           4
# iloc_start_train:    807
# iloc_end_train:      837
# date_start_df_train: 2021-06-03
# date_end_df_train:   2021-07-15
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['NTLA', 'ISRG', 'GNRC', 'AAPL', 'MSCI', 'ORLY', 'IDXX', 'ADBE',
#        'ZTS', 'TYL', 'AVXL', 'WB', 'NOW', 'CMG', 'MSFT', 'BLFS', 'DHR',
#        'DPZ', 'WAT', 'LULU'], dtype=object), 'r_CAGR/retnStd': array(['NTLA', 'GNRC', 'AVXL', 'BLFS', 'WB', 'MSCI', 'IDXX', 'ADBE',
#        'ISRG', 'AAPL', 'TYL', 'WAT', 'AXON', 'NOW', 'CMG', 'DPZ', 'FTNT',
#        'ORLY', 'DXCM', 'ZTS'], dtype=object), 'r_retnStd/UI': array(['ISRG', 'ORLY', 'ZTS', 'AAPL', 'DHR', 'MSFT', 'MSCI', 'QQQ',
#        'PZZA', 'NOW', 'DPZ', 'ADBE', 'CMG', 'LULU', 'XLK', 'AZO', 'IDXX',
#        'TYL', 'FTEC', 'VGT'], dtype=object)}}
# most_freq_syms: [('ISRG', 3), ('AAPL', 3), ('MSCI', 3), ('ORLY', 3), ('IDXX', 3), ('ADBE', 3), ('ZTS', 3), ('TYL', 3), ('NOW', 3), ('CMG', 3), ('DPZ', 3), ('NTLA', 2), ('GNRC', 2), ('AVXL', 2), ('WB', 2), ('MSFT', 2), ('BLFS', 2), ('DHR', 2), ('WAT', 2), ('LULU', 2), ('AXON', 1), ('FTNT', 1), ('DXCM', 1), ('QQQ', 1), ('PZZA', 1), ('XLK', 1), ('AZO', 1), ('FTEC', 1), ('VGT', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(822, 837, 841), (807, 837, 841), (777, 837, 841)]
# lb_slice:            (777, 837, 841)
# days eval:           4
# iloc_start_train:    777
# iloc_end_train:      837
# date_start_df_train: 2021-04-21
# date_end_df_train:   2021-07-15
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['RRC', 'CUTR', 'BBW', 'CLAR', 'DDS', 'PRFT', 'IT', 'AR', 'EVRI',
#        'CPT', 'AVXL', 'MSI', 'JYNT', 'DPZ', 'BX', 'TGT', 'GDEN', 'NTLA',
#        'INVH', 'WAT'], dtype=object), 'r_CAGR/retnStd': array(['CLAR', 'BBW', 'RRC', 'DDS', 'CUTR', 'NTLA', 'PRFT', 'EVRI',
#        'AVXL', 'AR', 'JYNT', 'DPZ', 'CROX', 'BX', 'NAVI', 'GDEN', 'WAT',
#        'NVO', 'CPT', 'TGT'], dtype=object), 'r_retnStd/UI': array(['IT', 'MSI', 'CPT', 'PRFT', 'AMH', 'EXLS', 'CUTR', 'EFX', 'SEE',
#        'INVH', 'MCO', 'TGT', 'AR', 'TROW', 'RRC', 'ANET', 'CUBE', 'EXPD',
#        'DDS', 'MAA'], dtype=object)}}
# most_freq_syms: [('RRC', 3), ('CUTR', 3), ('DDS', 3), ('PRFT', 3), ('AR', 3), ('CPT', 3), ('TGT', 3), ('BBW', 2), ('CLAR', 2), ('IT', 2), ('EVRI', 2), ('AVXL', 2), ('MSI', 2), ('JYNT', 2), ('DPZ', 2), ('BX', 2), ('GDEN', 2), ('NTLA', 2), ('INVH', 2), ('WAT', 2), ('CROX', 1), ('NAVI', 1), ('NVO', 1), ('AMH', 1), ('EXLS', 1), ('EFX', 1), ('SEE', 1), ('MCO', 1), ('TROW', 1), ('ANET', 1), ('CUBE', 1), ('EXPD', 1), ('MAA', 1)]
# +++ finish lookback slice 60 +++
#
# grp_most_freq_syms: [[('WB', 3), ('TX', 3), ('NKE', 3), ('PAYX', 3), ('AAPL', 3), ('ORLY', 3), ('CLAR', 3), ('SWX', 3), ('ZTS', 3), ('AZO', 3), ('BRKR', 3), ('NTLA', 2), ('DQ', 2), ('TGT', 2), ('KNX', 2), ('CMP', 2), ('MAA', 2), ('NVO', 2), ('ORCL', 2), ('HUM', 2), ('IRT', 1), ('WAT', 1), ('FSD', 1), ('EOS', 1), ('DPZ', 1), ('BR', 1), ('ADP', 1), ('PG', 1), ('PZZA', 1)], [('ISRG', 3), ('AAPL', 3), ('MSCI', 3), ('ORLY', 3), ('IDXX', 3), ('ADBE', 3), ('ZTS', 3), ('TYL', 3), ('NOW', 3), ('CMG', 3), ('DPZ', 3), ('NTLA', 2), ('GNRC', 2), ('AVXL', 2), ('WB', 2), ('MSFT', 2), ('BLFS', 2), ('DHR', 2), ('WAT', 2), ('LULU', 2), ('AXON', 1), ('FTNT', 1), ('DXCM', 1), ('QQQ', 1), ('PZZA', 1), ('XLK', 1), ('AZO', 1), ('FTEC', 1), ('VGT', 1)], [('RRC', 3), ('CUTR', 3), ('DDS', 3), ('PRFT', 3), ('AR', 3), ('CPT', 3), ('TGT', 3), ('BBW', 2), ('CLAR', 2), ('IT', 2), ('EVRI', 2), ('AVXL', 2), ('MSI', 2), ('JYNT', 2), ('DPZ', 2), ('BX', 2), ('GDEN', 2), ('NTLA', 2), ('INVH', 2), ('WAT', 2), ('CROX', 1), ('NAVI', 1), ('NVO', 1), ('AMH', 1), ('EXLS', 1), ('EFX', 1), ('SEE', 1), ('MCO', 1), ('TROW', 1), ('ANET', 1), ('CUBE', 1), ('EXPD', 1), ('MAA', 1)]]
# **** finish lookback slices [(822, 837, 841), (807, 837, 841), (777, 837, 841)] ****
#
# top 20 ranked symbols and frequency from set [(822, 837, 841), (807, 837, 841), (777, 837, 841)]:
# [('AAPL', 6), ('DPZ', 6), ('NTLA', 6), ('ORLY', 6), ('ZTS', 6), ('CLAR', 5), ('TGT', 5), ('WAT', 5), ('WB', 5), ('AVXL', 4), ('AZO', 4), ('ADBE', 3), ('AR', 3), ('BRKR', 3), ('CMG', 3), ('CPT', 3), ('CUTR', 3), ('DDS', 3), ('IDXX', 3), ('ISRG', 3)]
# top 20 ranked symbols from set [(822, 837, 841), (807, 837, 841), (777, 837, 841)]:
# ['AAPL', 'DPZ', 'NTLA', 'ORLY', 'ZTS', 'CLAR', 'TGT', 'WAT', 'WB', 'AVXL']
# ===== finish top 20 ranked symbols from days_lookback set [(822, 837, 841), (807, 837, 841), (777, 837, 841)] =====
#
#
#
# ########## 2 of 2 lb_slices: [(804, 819, 823), (789, 819, 823), (759, 819, 823)] in sets_lookcak_slices ##########
# days lookback:       15,  1 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(804, 819, 823), (789, 819, 823), (759, 819, 823)]
# lb_slice:            (804, 819, 823)
# days eval:           4
# iloc_start_train:    804
# iloc_end_train:      819
# date_start_df_train: 2021-05-28
# date_end_df_train:   2021-06-18
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['AVXL', 'ALNY', 'BLFS', 'GWRE', 'NTNX', 'GKOS', 'LC', 'DXCM',
#        'CPE', 'NVDA', 'CUTR', 'VRNS', 'PTCT', 'PRFT', 'RMBS', 'GNRC',
#        'ARWR', 'ILMN', 'SHOP', 'WIX'], dtype=object), 'r_CAGR/retnStd': array(['AVXL', 'ALNY', 'BLFS', 'LC', 'CUTR', 'CPE', 'SHOP', 'GWRE',
#        'GNRC', 'NTNX', 'DXCM', 'HUBS', 'ARWR', 'VRNS', 'CVE', 'NVDA',
#        'DBRG', 'SIG', 'PRO', 'WIX'], dtype=object), 'r_retnStd/UI': array(['ALNY', 'GKOS', 'GWRE', 'NTNX', 'QTWO', 'ENV', 'RMBS', 'PTCT',
#        'AVXL', 'PRFT', 'NVDA', 'TNDM', 'SBAC', 'NVS', 'EXR', 'ILMN',
#        'NSA', 'PZZA', 'DXCM', 'STE'], dtype=object)}}
# most_freq_syms: [('AVXL', 3), ('ALNY', 3), ('GWRE', 3), ('NTNX', 3), ('DXCM', 3), ('NVDA', 3), ('BLFS', 2), ('GKOS', 2), ('LC', 2), ('CPE', 2), ('CUTR', 2), ('VRNS', 2), ('PTCT', 2), ('PRFT', 2), ('RMBS', 2), ('GNRC', 2), ('ARWR', 2), ('ILMN', 2), ('SHOP', 2), ('WIX', 2), ('HUBS', 1), ('CVE', 1), ('DBRG', 1), ('SIG', 1), ('PRO', 1), ('QTWO', 1), ('ENV', 1), ('TNDM', 1), ('SBAC', 1), ('NVS', 1), ('EXR', 1), ('NSA', 1), ('PZZA', 1), ('STE', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(804, 819, 823), (789, 819, 823), (759, 819, 823)]
# lb_slice:            (789, 819, 823)
# days eval:           4
# iloc_start_train:    789
# iloc_end_train:      819
# date_start_df_train: 2021-05-07
# date_end_df_train:   2021-06-18
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['BBW', 'AVXL', 'ALNY', 'CUTR', 'NTNX', 'JYNT', 'SHOP', 'ENPH',
#        'ARWR', 'BLFS', 'DDS', 'ZS', 'ILMN', 'SGRY', 'PBR', 'PRO', 'PBH',
#        'ITCI', 'CHRD', 'BOX'], dtype=object), 'r_CAGR/retnStd': array(['BBW', 'AVXL', 'CUTR', 'ALNY', 'SHOP', 'JYNT', 'BLFS', 'ENPH',
#        'PRO', 'DDS', 'NTNX', 'ARWR', 'NVDA', 'ZS', 'ITCI', 'CHRD', 'PBR',
#        'SGRY', 'ILMN', 'PRFT'], dtype=object), 'r_retnStd/UI': array(['ALNY', 'AVXL', 'BBW', 'PBH', 'NTNX', 'ILMN', 'MUC', 'SGRY', 'CRM',
#        'ENV', 'BOX', 'CPRX', 'TM', 'ARWR', 'JYNT', 'ZS', 'SEM', 'NVS',
#        'ZD', 'FTSM'], dtype=object)}}
# most_freq_syms: [('BBW', 3), ('AVXL', 3), ('ALNY', 3), ('NTNX', 3), ('JYNT', 3), ('ARWR', 3), ('ZS', 3), ('ILMN', 3), ('SGRY', 3), ('CUTR', 2), ('SHOP', 2), ('ENPH', 2), ('BLFS', 2), ('DDS', 2), ('PBR', 2), ('PRO', 2), ('PBH', 2), ('ITCI', 2), ('CHRD', 2), ('BOX', 2), ('NVDA', 1), ('PRFT', 1), ('MUC', 1), ('CRM', 1), ('ENV', 1), ('CPRX', 1), ('TM', 1), ('SEM', 1), ('NVS', 1), ('ZD', 1), ('FTSM', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(804, 819, 823), (789, 819, 823), (759, 819, 823)]
# lb_slice:            (759, 819, 823)
# days eval:           4
# iloc_start_train:    759
# iloc_end_train:      819
# date_start_df_train: 2021-03-25
# date_end_df_train:   2021-06-18
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['BBW', 'CHRD', 'PRFT', 'PBR', 'GDEN', 'SGRY', 'BX', 'JYNT', 'DDS',
#        'NAVI', 'CLAR', 'EVRI', 'CUTR', 'CPT', 'ET', 'MAG', 'CUBE', 'FTNT',
#        'PSA', 'DPZ'], dtype=object), 'r_CAGR/retnStd': array(['BBW', 'CHRD', 'JYNT', 'CUTR', 'PRFT', 'GDEN', 'NVDA', 'CLAR',
#        'BX', 'PSA', 'DDS', 'PBR', 'DPZ', 'IQV', 'EVRI', 'SGRY', 'FTNT',
#        'WST', 'NVO', 'NOG'], dtype=object), 'r_retnStd/UI': array(['IT', 'PRG', 'BUD', 'IRM', 'NAVI', 'SGRY', 'MAG', 'AMH', 'ANET',
#        'CPT', 'PBR', 'MUC', 'ELS', 'INVH', 'NDAQ', 'EFX', 'TRGP', 'CM',
#        'DXC', 'MCO'], dtype=object)}}
# most_freq_syms: [('PBR', 3), ('SGRY', 3), ('BBW', 2), ('CHRD', 2), ('PRFT', 2), ('GDEN', 2), ('BX', 2), ('JYNT', 2), ('DDS', 2), ('NAVI', 2), ('CLAR', 2), ('EVRI', 2), ('CUTR', 2), ('CPT', 2), ('MAG', 2), ('FTNT', 2), ('PSA', 2), ('DPZ', 2), ('ET', 1), ('CUBE', 1), ('NVDA', 1), ('IQV', 1), ('WST', 1), ('NVO', 1), ('NOG', 1), ('IT', 1), ('PRG', 1), ('BUD', 1), ('IRM', 1), ('AMH', 1), ('ANET', 1), ('MUC', 1), ('ELS', 1), ('INVH', 1), ('NDAQ', 1), ('EFX', 1), ('TRGP', 1), ('CM', 1), ('DXC', 1), ('MCO', 1)]
# +++ finish lookback slice 60 +++
#
# grp_most_freq_syms: [[('AVXL', 3), ('ALNY', 3), ('GWRE', 3), ('NTNX', 3), ('DXCM', 3), ('NVDA', 3), ('BLFS', 2), ('GKOS', 2), ('LC', 2), ('CPE', 2), ('CUTR', 2), ('VRNS', 2), ('PTCT', 2), ('PRFT', 2), ('RMBS', 2), ('GNRC', 2), ('ARWR', 2), ('ILMN', 2), ('SHOP', 2), ('WIX', 2), ('HUBS', 1), ('CVE', 1), ('DBRG', 1), ('SIG', 1), ('PRO', 1), ('QTWO', 1), ('ENV', 1), ('TNDM', 1), ('SBAC', 1), ('NVS', 1), ('EXR', 1), ('NSA', 1), ('PZZA', 1), ('STE', 1)], [('BBW', 3), ('AVXL', 3), ('ALNY', 3), ('NTNX', 3), ('JYNT', 3), ('ARWR', 3), ('ZS', 3), ('ILMN', 3), ('SGRY', 3), ('CUTR', 2), ('SHOP', 2), ('ENPH', 2), ('BLFS', 2), ('DDS', 2), ('PBR', 2), ('PRO', 2), ('PBH', 2), ('ITCI', 2), ('CHRD', 2), ('BOX', 2), ('NVDA', 1), ('PRFT', 1), ('MUC', 1), ('CRM', 1), ('ENV', 1), ('CPRX', 1), ('TM', 1), ('SEM', 1), ('NVS', 1), ('ZD', 1), ('FTSM', 1)], [('PBR', 3), ('SGRY', 3), ('BBW', 2), ('CHRD', 2), ('PRFT', 2), ('GDEN', 2), ('BX', 2), ('JYNT', 2), ('DDS', 2), ('NAVI', 2), ('CLAR', 2), ('EVRI', 2), ('CUTR', 2), ('CPT', 2), ('MAG', 2), ('FTNT', 2), ('PSA', 2), ('DPZ', 2), ('ET', 1), ('CUBE', 1), ('NVDA', 1), ('IQV', 1), ('WST', 1), ('NVO', 1), ('NOG', 1), ('IT', 1), ('PRG', 1), ('BUD', 1), ('IRM', 1), ('AMH', 1), ('ANET', 1), ('MUC', 1), ('ELS', 1), ('INVH', 1), ('NDAQ', 1), ('EFX', 1), ('TRGP', 1), ('CM', 1), ('DXC', 1), ('MCO', 1)]]
# **** finish lookback slices [(804, 819, 823), (789, 819, 823), (759, 819, 823)] ****
#
# top 20 ranked symbols and frequency from set [(804, 819, 823), (789, 819, 823), (759, 819, 823)]:
# [('ALNY', 6), ('AVXL', 6), ('CUTR', 6), ('NTNX', 6), ('SGRY', 6), ('ARWR', 5), ('BBW', 5), ('ILMN', 5), ('JYNT', 5), ('NVDA', 5), ('PBR', 5), ('PRFT', 5), ('BLFS', 4), ('CHRD', 4), ('DDS', 4), ('SHOP', 4), ('DXCM', 3), ('GWRE', 3), ('PRO', 3), ('ZS', 3)]
# top 20 ranked symbols from set [(804, 819, 823), (789, 819, 823), (759, 819, 823)]:
# ['ALNY', 'AVXL', 'CUTR', 'NTNX', 'SGRY', 'ARWR', 'BBW', 'ILMN', 'JYNT', 'NVDA']
# ===== finish top 20 ranked symbols from days_lookback set [(804, 819, 823), (789, 819, 823), (759, 819, 823)] =====
#
#
# max_lookback_slices:             [(777, 837, 841), (759, 819, 823)]
# set_lookback_slices 1 of   2:    [(822, 837, 841), (807, 837, 841), (777, 837, 841)]
#
# max_days_lookbacks:              60
# df end date for days_lookbacks:  2021-07-15
# days_lookbacks:                  [15, 30, 60]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     []
# sym_freq_9:                      []
# sym_freq_8:                      []
# sym_freq_7:                      []
# sym_freq_6:                      ['AAPL', 'DPZ', 'NTLA', 'ORLY', 'ZTS']
# sym_freq_5:                      ['CLAR', 'TGT', 'WAT', 'WB']
# sym_freq_4:                      ['AVXL', 'AZO']
# sym_freq_3:                      ['ADBE', 'AR', 'BRKR', 'CMG', 'CPT', 'CUTR', 'DDS', 'IDXX', 'ISRG']
# sym_freq_2:                      []
#
# max_lookback_slices:             [(777, 837, 841), (759, 819, 823)]
# set_lookback_slices 2 of   2:    [(804, 819, 823), (789, 819, 823), (759, 819, 823)]
#
# max_days_lookbacks:              60
# df end date for days_lookbacks:  2021-06-18
# days_lookbacks:                  [15, 30, 60]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     []
# sym_freq_9:                      []
# sym_freq_8:                      []
# sym_freq_7:                      []
# sym_freq_6:                      ['ALNY', 'AVXL', 'CUTR', 'NTNX', 'SGRY']
# sym_freq_5:                      ['ARWR', 'BBW', 'ILMN', 'JYNT', 'NVDA', 'PBR', 'PRFT']
# sym_freq_4:                      ['BLFS', 'CHRD', 'DDS', 'SHOP']
# sym_freq_3:                      ['DXCM', 'GWRE', 'PRO', 'ZS']
# sym_freq_2:                      []
#
# z_grp_top_set_syms_n_freq:
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
#
#
# 1 of 2 max_lookback_slice: (777, 837, 841)
#
# len(idx_train): 60
# idx_train: DatetimeIndex(['2021-04-21', '2021-04-22', '2021-04-23', '2021-04-26', '2021-04-27', '2021-04-28', '2021-04-29', '2021-04-30', '2021-05-03', '2021-05-04', '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-10', '2021-05-11', '2021-05-12', '2021-05-13', '2021-05-14', '2021-05-17', '2021-05-18', '2021-05-19', '2021-05-20', '2021-05-21', '2021-05-24', '2021-05-25', '2021-05-26', '2021-05-27', '2021-05-28', '2021-06-01', '2021-06-02', '2021-06-03', '2021-06-04', '2021-06-07', '2021-06-08',
#                '2021-06-09', '2021-06-10', '2021-06-11', '2021-06-14', '2021-06-15', '2021-06-16', '2021-06-17', '2021-06-18', '2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24', '2021-06-25', '2021-06-28', '2021-06-29', '2021-06-30', '2021-07-01', '2021-07-02', '2021-07-06', '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2021-04-21 - 2021-07-15
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2021-07-16', '2021-07-19', '2021-07-20', '2021-07-21'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2021-07-16 - 2021-07-21
#
# top_set_syms_n_freq: [('AAPL', 6), ('DPZ', 6), ('NTLA', 6), ('ORLY', 6), ('ZTS', 6), ('CLAR', 5), ('TGT', 5), ('WAT', 5), ('WB', 5), ('AVXL', 4), ('AZO', 4), ('ADBE', 3), ('AR', 3), ('BRKR', 3), ('CMG', 3), ('CPT', 3), ('CUTR', 3), ('DDS', 3), ('IDXX', 3), ('ISRG', 3)]
#
# set_lookback_slices: [(822, 837, 841), (807, 837, 841), (777, 837, 841)]
# max_lookback_slice:  (777, 837, 841)
# days_lookbacks:      [15, 30, 60]
# date_end_df_train:   2021-07-15
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['AAPL', 'DPZ', 'NTLA', 'ORLY', 'ZTS']
# sym_freq_5:          ['CLAR', 'TGT', 'WAT', 'WB']
# sym_freq_4:          ['AVXL', 'AZO']
# sym_freq_3:          ['ADBE', 'AR', 'BRKR', 'CMG', 'CPT', 'CUTR', 'DDS', 'IDXX', 'ISRG']
# sym_freq_2:          []
#
# iloc_start_eval:    837,  df_eval first date: 2021-07-16
# iloc_end_eval:      841,  df_eval last date:  2021-07-21
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   AAPL         DPZ        NTLA        ORLY         ZTS         SPY
# Date
# 2021-07-16  144.125198  468.595642  135.250000  601.299988  195.508118  415.305115
# 2021-07-19  140.246170  464.527863  138.940002  594.450012  193.696762  409.171967
# 2021-07-20  143.888901  461.110626  146.119995  607.380005  196.177048  415.035553
# 2021-07-21  143.150558  456.644775  152.750000  604.390015  194.147705  418.395813
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                          5,493.9689
# grp(CAGR)_std                          10,988.5508
# grp(CAGR)_mean/std                          0.5000
# grp(CAGR/UI)_mean              10,988,428,164.2108
# grp(CAGR/UI)_std               21,976,856,360.9266
# grp(CAGR/UI)_mean/std                       0.5000
# grp(CAGR/retnStd)_mean                531,208.3142
# grp(CAGR/retnStd)_std               1,062,893.1842
# grp(CAGR/retnStd)_mean/std                  0.4998
# grp(retnStd/UI)_mean                    4,136.7548
# grp(retnStd/UI)_std                     8,270.7745
# grp(retnStd/UI)_mean/std                    0.5002
# SPY_CAGR                                    0.8642
# SPY_CAGR/UI                               116.9206
# SPY_CAGR/retnStd                           69.0819
# SPY_retnStd/UI                              1.6925
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
# iloc_start_eval:    837,  df_eval first date: 2021-07-16
# iloc_end_eval:      841,  df_eval last date:  2021-07-21
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  CLAR         TGT         WAT         WB         SPY
# Date
# 2021-07-16  26.971716  234.875473  370.690002  56.678547  415.305115
# 2021-07-19  26.629187  234.847366  362.989990  56.772556  409.171967
# 2021-07-20  27.157665  238.204773  372.119995  57.035782  415.035553
# 2021-07-21  27.940584  239.457932  370.670013  58.079292  418.395813
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              7.3056
# grp(CAGR)_std                               6.8364
# grp(CAGR)_mean/std                          1.0686
# grp(CAGR/UI)_mean                   3,404,495.9522
# grp(CAGR/UI)_std                    5,855,892.0993
# grp(CAGR/UI)_mean/std                       0.5814
# grp(CAGR/retnStd)_mean                    662.3554
# grp(CAGR/retnStd)_std                     402.9373
# grp(CAGR/retnStd)_mean/std                  1.6438
# grp(retnStd/UI)_mean                    3,647.8283
# grp(retnStd/UI)_std                     6,258.2975
# grp(retnStd/UI)_mean/std                    0.5829
# SPY_CAGR                                    0.8642
# SPY_CAGR/UI                               116.9206
# SPY_CAGR/retnStd                           69.0819
# SPY_retnStd/UI                              1.6925
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
# iloc_start_eval:    837,  df_eval first date: 2021-07-16
# iloc_end_eval:      841,  df_eval last date:  2021-07-21
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  AVXL          AZO         SPY
# Date
# 2021-07-16  21.680000  1605.300049  415.305115
# 2021-07-19  21.549999  1584.569946  409.171967
# 2021-07-20  20.959999  1601.750000  415.035553
# 2021-07-21  22.670000  1591.250000  418.395813
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             20.5163
# grp(CAGR)_std                              21.0384
# grp(CAGR)_mean/std                          0.9752
# grp(CAGR/UI)_mean                       1,198.2081
# grp(CAGR/UI)_std                        1,264.4857
# grp(CAGR/UI)_mean/std                       0.9476
# grp(CAGR/retnStd)_mean                    414.7519
# grp(CAGR/retnStd)_std                     466.7513
# grp(CAGR/retnStd)_mean/std                  0.8886
# grp(retnStd/UI)_mean                        2.0342
# grp(retnStd/UI)_std                         0.7596
# grp(retnStd/UI)_mean/std                    2.6780
# SPY_CAGR                                    0.8642
# SPY_CAGR/UI                               116.9206
# SPY_CAGR/retnStd                           69.0819
# SPY_retnStd/UI                              1.6925
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
# iloc_start_eval:    837,  df_eval first date: 2021-07-16
# iloc_end_eval:      841,  df_eval last date:  2021-07-21
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   ADBE     AR       BRKR          CMG         CPT       CUTR         DDS        IDXX        ISRG         SPY
# Date
# 2021-07-16  606.099976  13.24  77.767754  1560.489990  133.110641  47.060001  149.637634  667.760010  316.703339  415.305115
# 2021-07-19  602.049988  12.54  77.539490  1551.160034  132.093964  46.980000  141.849579  669.400024  310.730011  409.171967
# 2021-07-20  608.719971  13.07  80.328270  1574.349976  135.670792  47.720001  147.153732  669.390015  318.350006  415.035553
# 2021-07-21  612.260010  13.91  79.583946  1755.989990  135.310333  49.439999  157.865540  670.510010  314.980011  418.395813
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                          2,272.1243
# grp(CAGR)_std                           6,347.6803
# grp(CAGR)_mean/std                          0.3579
# grp(CAGR/UI)_mean                     766,867.7867
# grp(CAGR/UI)_std                    2,121,095.7033
# grp(CAGR/UI)_mean/std                       0.3615
# grp(CAGR/retnStd)_mean                 43,315.9111
# grp(CAGR/retnStd)_std                 119,697.8227
# grp(CAGR/retnStd)_mean/std                  0.3619
# grp(retnStd/UI)_mean                       21.0484
# grp(retnStd/UI)_std                        41.7938
# grp(retnStd/UI)_mean/std                    0.5036
# SPY_CAGR                                    0.8642
# SPY_CAGR/UI                               116.9206
# SPY_CAGR/retnStd                           69.0819
# SPY_retnStd/UI                              1.6925
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2272.124266475972, 6347.680252011941, 0.35794560788656715, 766867.7867273419, 2121095.7033327827, 0.36154322764521984, 43315.911145969905, 119697.82273459613, 0.361877185034631, 21.04838190702447, 41.7938143189786, 0.5036243341270334, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
# ================================================================================
#
#
#
# 2 of 2 max_lookback_slice: (759, 819, 823)
#
# len(idx_train): 60
# idx_train: DatetimeIndex(['2021-03-25', '2021-03-26', '2021-03-29', '2021-03-30', '2021-03-31', '2021-04-01', '2021-04-05', '2021-04-06', '2021-04-07', '2021-04-08', '2021-04-09', '2021-04-12', '2021-04-13', '2021-04-14', '2021-04-15', '2021-04-16', '2021-04-19', '2021-04-20', '2021-04-21', '2021-04-22', '2021-04-23', '2021-04-26', '2021-04-27', '2021-04-28', '2021-04-29', '2021-04-30', '2021-05-03', '2021-05-04', '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-10', '2021-05-11', '2021-05-12',
#                '2021-05-13', '2021-05-14', '2021-05-17', '2021-05-18', '2021-05-19', '2021-05-20', '2021-05-21', '2021-05-24', '2021-05-25', '2021-05-26', '2021-05-27', '2021-05-28', '2021-06-01', '2021-06-02', '2021-06-03', '2021-06-04', '2021-06-07', '2021-06-08', '2021-06-09', '2021-06-10', '2021-06-11', '2021-06-14', '2021-06-15', '2021-06-16', '2021-06-17', '2021-06-18'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2021-03-25 - 2021-06-18
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2021-06-21 - 2021-06-24
#
# top_set_syms_n_freq: [('ALNY', 6), ('AVXL', 6), ('CUTR', 6), ('NTNX', 6), ('SGRY', 6), ('ARWR', 5), ('BBW', 5), ('ILMN', 5), ('JYNT', 5), ('NVDA', 5), ('PBR', 5), ('PRFT', 5), ('BLFS', 4), ('CHRD', 4), ('DDS', 4), ('SHOP', 4), ('DXCM', 3), ('GWRE', 3), ('PRO', 3), ('ZS', 3)]
#
# set_lookback_slices: [(804, 819, 823), (789, 819, 823), (759, 819, 823)]
# max_lookback_slice:  (759, 819, 823)
# days_lookbacks:      [15, 30, 60]
# date_end_df_train:   2021-06-18
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['ALNY', 'AVXL', 'CUTR', 'NTNX', 'SGRY']
# sym_freq_5:          ['ARWR', 'BBW', 'ILMN', 'JYNT', 'NVDA', 'PBR', 'PRFT']
# sym_freq_4:          ['BLFS', 'CHRD', 'DDS', 'SHOP']
# sym_freq_3:          ['DXCM', 'GWRE', 'PRO', 'ZS']
# sym_freq_2:          []
#
# iloc_start_eval:    819,  df_eval first date: 2021-06-21
# iloc_end_eval:      823,  df_eval last date:  2021-06-24
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   ALNY       AVXL       CUTR       NTNX       SGRY         SPY
# Date
# 2021-06-21  171.259995  25.170000  48.290001  36.340000  66.449997  405.214783
# 2021-06-22  172.949997  23.830000  46.549999  38.930000  65.480003  407.381104
# 2021-06-23  174.630005  24.230000  46.439999  39.139999  63.930000  406.890076
# 2021-06-24  173.679993  24.940001  47.330002  39.599998  66.790001  409.297119
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                            272.4135
# grp(CAGR)_std                             544.1116
# grp(CAGR)_mean/std                          0.5007
# grp(CAGR/UI)_mean                 544,253,939.7437
# grp(CAGR/UI)_std                1,088,507,475.3991
# grp(CAGR/UI)_mean/std                       0.5000
# grp(CAGR/retnStd)_mean                  9,227.9058
# grp(CAGR/retnStd)_std                  18,316.0843
# grp(CAGR/retnStd)_mean/std                  0.5038
# grp(retnStd/UI)_mean                   11,869.1403
# grp(retnStd/UI)_std                    23,735.2570
# grp(retnStd/UI)_mean/std                    0.5001
# SPY_CAGR                                    1.3211
# SPY_CAGR/UI                             2,192.0328
# SPY_CAGR/retnStd                          408.8687
# SPY_retnStd/UI                              5.3612
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2272.124266475972, 6347.680252011941, 0.35794560788656715, 766867.7867273419, 2121095.7033327827, 0.36154322764521984, 43315.911145969905, 119697.82273459613, 0.361877185034631, 21.04838190702447, 41.7938143189786, 0.5036243341270334, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 272.4134699432118, 544.1115515434996, 0.5006573912471576, 544253939.743677, 1088507475.399063, 0.5000001856157629, 9227.905773996443, 18316.08432596597, 0.5038143311512502, 11869.140264579872, 23735.25703927725, 0.5000636919557578, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
# iloc_start_eval:    819,  df_eval first date: 2021-06-21
# iloc_end_eval:      823,  df_eval last date:  2021-06-24
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  ARWR        BBW        ILMN       JYNT        NVDA       PBR       PRFT         SPY
# Date
# 2021-06-21  89.809998  14.816236  461.049988  77.099998  183.963730  4.802688  80.110001  405.214783
# 2021-06-22  88.830002  15.249148  465.690002  77.800003  188.551010  4.856097  80.550003  407.381104
# 2021-06-23  88.089996  16.265169  469.130005  78.029999  190.253159  4.897180  80.870003  406.890076
# 2021-06-24  89.510002  16.203323  468.070007  82.809998  191.733185  4.995781  82.129997  409.297119
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                            329.8415
# grp(CAGR)_std                             630.6056
# grp(CAGR)_mean/std                          0.5231
# grp(CAGR/UI)_mean                 133,798,252.4624
# grp(CAGR/UI)_std                  275,485,388.8379
# grp(CAGR/UI)_mean/std                       0.4857
# grp(CAGR/retnStd)_mean                 12,921.3678
# grp(CAGR/retnStd)_std                  21,377.8298
# grp(CAGR/retnStd)_mean/std                  0.6044
# grp(retnStd/UI)_mean                   12,607.9886
# grp(retnStd/UI)_std                    17,215.8836
# grp(retnStd/UI)_mean/std                    0.7323
# SPY_CAGR                                    1.3211
# SPY_CAGR/UI                             2,192.0328
# SPY_CAGR/retnStd                          408.8687
# SPY_retnStd/UI                              5.3612
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2272.124266475972, 6347.680252011941, 0.35794560788656715, 766867.7867273419, 2121095.7033327827, 0.36154322764521984, 43315.911145969905, 119697.82273459613, 0.361877185034631, 21.04838190702447, 41.7938143189786, 0.5036243341270334, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 272.4134699432118, 544.1115515434996, 0.5006573912471576, 544253939.743677, 1088507475.399063, 0.5000001856157629, 9227.905773996443, 18316.08432596597, 0.5038143311512502, 11869.140264579872, 23735.25703927725, 0.5000636919557578, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 329.84146202480594, 630.6056491014691, 0.5230550384297811, 133798252.46241185, 275485388.83785725, 0.48568184696416566, 12921.367807322486, 21377.829835704328, 0.6044284151678379, 12607.988607950345, 17215.883626868625, 0.7323462960839958, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
# iloc_start_eval:    819,  df_eval first date: 2021-06-21
# iloc_end_eval:      823,  df_eval last date:  2021-06-24
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  BLFS       CHRD         DDS        SHOP         SPY
# Date
# 2021-06-21  43.230000  70.622566  139.338593  148.022995  405.214783
# 2021-06-22  43.869999  70.573746  145.060715  150.843994  407.381104
# 2021-06-23  44.000000  70.350571  154.298843  150.052994  406.890076
# 2021-06-24  44.389999  71.815193  157.607986  147.899002  409.297119
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                          7,810.0532
# grp(CAGR)_std                          13,520.9075
# grp(CAGR)_mean/std                          0.5776
# grp(CAGR/UI)_mean              15,618,599,488.5440
# grp(CAGR/UI)_std               27,042,685,185.2152
# grp(CAGR/UI)_mean/std                       0.5776
# grp(CAGR/retnStd)_mean                452,876.2038
# grp(CAGR/retnStd)_std                 783,257.4715
# grp(CAGR/retnStd)_mean/std                  0.5782
# grp(retnStd/UI)_mean                   11,047.8861
# grp(retnStd/UI)_std                    14,112.3194
# grp(retnStd/UI)_mean/std                    0.7829
# SPY_CAGR                                    1.3211
# SPY_CAGR/UI                             2,192.0328
# SPY_CAGR/retnStd                          408.8687
# SPY_retnStd/UI                              5.3612
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2272.124266475972, 6347.680252011941, 0.35794560788656715, 766867.7867273419, 2121095.7033327827, 0.36154322764521984, 43315.911145969905, 119697.82273459613, 0.361877185034631, 21.04838190702447, 41.7938143189786, 0.5036243341270334, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 272.4134699432118, 544.1115515434996, 0.5006573912471576, 544253939.743677, 1088507475.399063, 0.5000001856157629, 9227.905773996443, 18316.08432596597, 0.5038143311512502, 11869.140264579872, 23735.25703927725, 0.5000636919557578, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 329.84146202480594, 630.6056491014691, 0.5230550384297811, 133798252.46241185, 275485388.83785725, 0.48568184696416566, 12921.367807322486, 21377.829835704328, 0.6044284151678379, 12607.988607950345, 17215.883626868625, 0.7323462960839958, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 7810.053161822098, 13520.907513497681, 0.5776278814144289, 15618599488.543962, 27042685185.215244, 0.5775535743426452, 452876.2037731167, 783257.4715460314, 0.5781958298836368, 11047.886050953968, 14112.319399523356, 0.7828540254925856, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
# iloc_start_eval:    819,  df_eval first date: 2021-06-21
# iloc_end_eval:      823,  df_eval last date:  2021-06-24
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   DXCM        GWRE        PRO          ZS         SPY
# Date
# 2021-06-21  105.757500  111.760002  49.869999  216.410004  405.214783
# 2021-06-22  106.877502  112.190002  49.430000  219.610001  407.381104
# 2021-06-23  107.930000  112.029999  49.000000  218.860001  406.890076
# 2021-06-24  106.250000  113.949997  48.250000  219.639999  409.297119
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              1.5288
# grp(CAGR)_std                               1.9177
# grp(CAGR)_mean/std                          0.7972
# grp(CAGR/UI)_mean                       1,803.6972
# grp(CAGR/UI)_std                        2,356.6986
# grp(CAGR/UI)_mean/std                       0.7653
# grp(CAGR/retnStd)_mean                    147.6154
# grp(CAGR/retnStd)_std                     312.8235
# grp(CAGR/retnStd)_mean/std                  0.4719
# grp(retnStd/UI)_mean                        4.2674
# grp(retnStd/UI)_std                         4.1499
# grp(retnStd/UI)_mean/std                    1.0283
# SPY_CAGR                                    1.3211
# SPY_CAGR/UI                             2,192.0328
# SPY_CAGR/retnStd                          408.8687
# SPY_retnStd/UI                              5.3612
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2272.124266475972, 6347.680252011941, 0.35794560788656715, 766867.7867273419, 2121095.7033327827, 0.36154322764521984, 43315.911145969905, 119697.82273459613, 0.361877185034631, 21.04838190702447, 41.7938143189786, 0.5036243341270334, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 272.4134699432118, 544.1115515434996, 0.5006573912471576, 544253939.743677, 1088507475.399063, 0.5000001856157629, 9227.905773996443, 18316.08432596597, 0.5038143311512502, 11869.140264579872, 23735.25703927725, 0.5000636919557578, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 329.84146202480594, 630.6056491014691, 0.5230550384297811, 133798252.46241185, 275485388.83785725, 0.48568184696416566, 12921.367807322486, 21377.829835704328, 0.6044284151678379, 12607.988607950345, 17215.883626868625, 0.7323462960839958, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 7810.053161822098, 13520.907513497681, 0.5776278814144289, 15618599488.543962, 27042685185.215244, 0.5775535743426452, 452876.2037731167, 783257.4715460314, 0.5781958298836368, 11047.886050953968, 14112.319399523356, 0.7828540254925856, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 1.5288186137999937, 1.917692388764045, 0.7972178555630182, 1803.6972499634196, 2356.6986166531665, 0.7653491359556682, 147.6153656348646, 312.8234665149564, 0.47188072966324907, 4.267398462139161, 4.149878844983735, 1.0283188067761257, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
# ================================================================================
#
#
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2272.124266475972, 6347.680252011941, 0.35794560788656715, 766867.7867273419, 2121095.7033327827, 0.36154322764521984, 43315.911145969905, 119697.82273459613, 0.361877185034631, 21.04838190702447, 41.7938143189786, 0.5036243341270334, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 272.4134699432118, 544.1115515434996, 0.5006573912471576, 544253939.743677, 1088507475.399063, 0.5000001856157629, 9227.905773996443, 18316.08432596597, 0.5038143311512502, 11869.140264579872, 23735.25703927725, 0.5000636919557578, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 329.84146202480594, 630.6056491014691, 0.5230550384297811, 133798252.46241185, 275485388.83785725, 0.48568184696416566, 12921.367807322486, 21377.829835704328, 0.6044284151678379, 12607.988607950345, 17215.883626868625, 0.7323462960839958, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 7810.053161822098, 13520.907513497681, 0.5776278814144289, 15618599488.543962, 27042685185.215244, 0.5775535743426452, 452876.2037731167, 783257.4715460314, 0.5781958298836368, 11047.886050953968, 14112.319399523356, 0.7828540254925856, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 1.5288186137999937, 1.917692388764045, 0.7972178555630182, 1803.6972499634196, 2356.6986166531665, 0.7653491359556682, 147.6153656348646, 312.8234665149564, 0.47188072966324907, 4.267398462139161, 4.149878844983735, 1.0283188067761257, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]]
#
#
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2272.124266475972, 6347.680252011941, 0.35794560788656715, 766867.7867273419, 2121095.7033327827, 0.36154322764521984, 43315.911145969905, 119697.82273459613, 0.361877185034631, 21.04838190702447, 41.7938143189786, 0.5036243341270334, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 272.4134699432118, 544.1115515434996, 0.5006573912471576, 544253939.743677, 1088507475.399063, 0.5000001856157629, 9227.905773996443, 18316.08432596597, 0.5038143311512502, 11869.140264579872, 23735.25703927725, 0.5000636919557578, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 329.84146202480594, 630.6056491014691, 0.5230550384297811, 133798252.46241185, 275485388.83785725, 0.48568184696416566, 12921.367807322486, 21377.829835704328, 0.6044284151678379, 12607.988607950345, 17215.883626868625, 0.7323462960839958, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 7810.053161822098, 13520.907513497681, 0.5776278814144289, 15618599488.543962, 27042685185.215244, 0.5775535743426452, 452876.2037731167, 783257.4715460314, 0.5781958298836368, 11047.886050953968, 14112.319399523356, 0.7828540254925856, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 1.5288186137999937, 1.917692388764045, 0.7972178555630182, 1803.6972499634196, 2356.6986166531665, 0.7653491359556682, 147.6153656348646, 312.8234665149564, 0.47188072966324907, 4.267398462139161, 4.149878844983735, 1.0283188067761257, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
# df_eval_results BEFORW store results:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 5493.96890384954, 10988.550779458106, 0.4999721086168991, 10988428164.21079, 21976856360.926582, 0.499999999260472, 531208.314196155, 1062893.1842084473, 0.49977582139804005, 4136.754838885949, 8270.774537539155, 0.5001653497033638, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 7.305600455985197, 6.836414908763713, 1.0686303498958245, 3404495.952216503, 5855892.09934878, 0.581379556599943, 662.3554391329513, 402.93733856862855, 1.6438174766475222, 3647.8282531108744, 6258.2974703016225, 0.5828786935139191, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 20.51630303058249, 21.038438703133693, 0.9751818240926104, 1198.2081274820082, 1264.485687763123, 0.9475853614457591, 414.7518835026032, 466.75133417274486, 0.8885928183530448, 2.03416267649238, 0.759580744818789, 2.678007164304388, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2272.124266475972, 6347.680252011941, 0.35794560788656715, 766867.7867273419, 2121095.7033327827, 0.36154322764521984, 43315.911145969905, 119697.82273459613, 0.361877185034631, 21.04838190702447, 41.7938143189786, 0.5036243341270334, 0.8641643612935201, 116.92061748300519, 69.08192396943855, 1.6924922000541012]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 272.4134699432118, 544.1115515434996, 0.5006573912471576, 544253939.743677, 1088507475.399063, 0.5000001856157629, 9227.905773996443, 18316.08432596597, 0.5038143311512502, 11869.140264579872, 23735.25703927725, 0.5000636919557578, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 329.84146202480594, 630.6056491014691, 0.5230550384297811, 133798252.46241185, 275485388.83785725, 0.48568184696416566, 12921.367807322486, 21377.829835704328, 0.6044284151678379, 12607.988607950345, 17215.883626868625, 0.7323462960839958, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 7810.053161822098, 13520.907513497681, 0.5776278814144289, 15618599488.543962, 27042685185.215244, 0.5775535743426452, 452876.2037731167, 783257.4715460314, 0.5781958298836368, 11047.886050953968, 14112.319399523356, 0.7828540254925856, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 1.5288186137999937, 1.917692388764045, 0.7972178555630182, 1803.6972499634196, 2356.6986166531665, 0.7653491359556682, 147.6153656348646, 312.8234665149564, 0.47188072966324907, 4.267398462139161, 4.149878844983735, 1.0283188067761257, 1.3210591756817358, 2192.032751269219, 408.8686534826625, 5.361214983339799]
#
# Save results to: test_df_eval
# df_eval_results AFTER store results:
#    n_samples days_lookbacks  days_eval  n_top_syms  syms_start  syms_end  sym_freq_cnt  grp(CAGR)_mean  grp(CAGR)_std  grp(CAGR)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  grp(CAGR/retnStd)_mean  grp(CAGR/retnStd)_std  grp(CAGR/retnStd)_mean/std  grp(retnStd/UI)_mean  grp(retnStd/UI)_std  grp(retnStd/UI)_mean/std  SPY_CAGR  SPY_CAGR/UI  SPY_CAGR/retnStd  SPY_retnStd/UI
# 0          2   [15, 30, 60]          4          20           0        10             6     5493.968904   10988.550779            0.499972       1.098843e+10      2.197686e+10             0.500000          531208.314196            1.062893e+06               0.499776                 4136.754839           8270.774538             0.500165       0.864164   116.920617         69.081924        1.692492
# 1          2   [15, 30, 60]          4          20           0        10             5        7.305600       6.836415            1.068630       3.404496e+06      5.855892e+06             0.581380             662.355439            4.029373e+02               1.643817                 3647.828253           6258.297470             0.582879       0.864164   116.920617         69.081924        1.692492
# 2          2   [15, 30, 60]          4          20           0        10             4       20.516303      21.038439            0.975182       1.198208e+03      1.264486e+03             0.947585             414.751884            4.667513e+02               0.888593                    2.034163              0.759581             2.678007       0.864164   116.920617         69.081924        1.692492
# 3          2   [15, 30, 60]          4          20           0        10             3     2272.124266    6347.680252            0.357946       7.668678e+05      2.121096e+06             0.361543           43315.911146            1.196978e+05               0.361877                   21.048382             41.793814             0.503624       0.864164   116.920617         69.081924        1.692492
# 4          2   [15, 30, 60]          4          20           0        10             6      272.413470     544.111552            0.500657       5.442539e+08      1.088507e+09             0.500000            9227.905774            1.831608e+04               0.503814                11869.140265          23735.257039             0.500064       1.321059  2192.032751        408.868653        5.361215
# 5          2   [15, 30, 60]          4          20           0        10             5      329.841462     630.605649            0.523055       1.337983e+08      2.754854e+08             0.485682           12921.367807            2.137783e+04               0.604428                12607.988608          17215.883627             0.732346       1.321059  2192.032751        408.868653        5.361215
# 6          2   [15, 30, 60]          4          20           0        10             4     7810.053162   13520.907513            0.577628       1.561860e+10      2.704269e+10             0.577554          452876.203773            7.832575e+05               0.578196                11047.886051          14112.319400             0.782854       1.321059  2192.032751        408.868653        5.361215
# 7          2   [15, 30, 60]          4          20           0        10             3        1.528819       1.917692            0.797218       1.803697e+03      2.356699e+03             0.765349             147.615366            3.128235e+02               0.471881                    4.267398              4.149879             1.028319       1.321059  2192.032751        408.868653        5.361215
