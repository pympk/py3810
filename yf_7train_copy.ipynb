# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump, delete_all_rows
from yf_utils import split_train_val_test, random_slices, lookback_slices
from yf_utils import top_set_sym_freq_cnt, get_grp_top_syms_n_freq
from yf_utils import eval_grp_top_syms_n_freq


pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.width", 500)  # code-runner format

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"

####################
path_data_dump = path_dir + "VSCode_dump/"
# path_data_dump = '/content/colab_dump/'
####################

fp_df_close_clean = "df_close_clean"

# %%
#######################################################################
## SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# select run type
run_type = "train"
# run_type = 'validate'
# run_type = "test"

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms
# n_samples = 400
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
# days_lookbacks = [15, 30, 60]
# days_lookbacks = [30, 60, 120]
days_lookbacks = [15, 30, 60, 120]
days_lookbacks.sort()

# number of days in dataframe to evaluate effectiveness of the training, days_eval = len(df_eval)
#  days_eval = 4 means buy at close on 1st day after the signal, hold for 2nd and 3rd day, sell at close on 4th day
days_eval = 4
# days_eval = 5

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20
# n_top_syms = 5

# slice starts and ends for selecting the best performing symbols
syms_start = 0
syms_end = 10


##########################################################
# fp_df_eval_results = f"df_eval_results_{run_type}"
fp_df_eval_results = "test_df_eval"
##########################################################

#### Delete all rows in df_eval_results ##################
delete_all_rows(path_data_dump, fp_df_eval_results)
##########################################################

# %%
path_data_dump
# Out:
# 'C:/Users/ping/MyDrive/stocks/yfinance/VSCode_dump/'

# %%
print(f"verbose : {verbose }")
print(f"store_results: {store_results}")
print(f"run_type: {run_type}")
print(f"n_samples: {n_samples}")
print(f"days_lookbacks: {days_lookbacks}")
print(f"days_eval: {days_eval}")
print(f"n_top_syms: {n_top_syms}")
print(f"syms_start: {syms_start}")
print(f"syms_end: {syms_end}")
print(f"fp_df_eval_results: {fp_df_eval_results}")

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = split_train_val_test(df_close_clean)
# Out:
# verbose : True
# store_results: True
# run_type: train
# n_samples: 2
# days_lookbacks: [15, 30, 60, 120]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10
# fp_df_eval_results: test_df_eval

# %%
# max_days_lookbacks = max(days_lookbacks)
# print(f"max_days_lookbacks: {max_days_lookbacks}")

# Load df according to run_type
if run_type == "train":
    df = df_train.copy()
elif run_type == "validate":
    df = df_val.copy()
elif run_type == "test":
    df = df_test.copy()
else:
    msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop)

# Print dataframe for the run, and lengths of other dataframes
print(f"run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n")
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f"run_type: {run_type}, len(df): {len(df)}")
print(
    f"len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}"
)

# return n_samples slices
max_lookback_slices = random_slices(
    len_df,
    n_samples=n_samples,
    days_lookback=max(days_lookbacks),
    days_eval=days_eval,
    verbose=False,
)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = lookback_slices(
    max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False
)
# Out:
# run_type: train, df.tail(3):
#                      A         AA        AAL         AAP        AAPL         AB        ABB        ABBV         ABC        ABM        ABR         ABT       ACGL       ACHC       ACIW  ...        XRX         XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA          ZD          ZG       ZION        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                                   ...
# 2021-07-06  147.387589  36.058010  21.010000  197.164200  140.569183  41.311390  32.729343  106.834770  112.808167  42.026814  15.067636  114.871323  38.799999  62.580002  37.310001  ...  21.389660  118.042938  39.580002  112.666039  65.499908  56.030933  155.889175  544.349976  122.278259  120.370003  49.311123  28.451982  191.272812  49.270000  49.729626
# 2021-07-07  147.892136  35.820732  20.309999  197.863297  143.093140  40.027229  33.240738  107.776360  112.436760  41.542629  14.982608  115.886429  39.020000  63.369999  37.580002  ...  21.750668  118.248718  38.279999  114.187622  65.509743  54.880238  154.280304  546.650024  123.982613  119.040001  48.920223  28.031702  194.604935  47.599998  50.391369
# 2021-07-08  147.239197  34.960560  20.350000  196.039978  141.776718  39.206070  33.307030  107.407112  111.850349  41.223064  14.838054  115.296707  37.619999  62.360001  36.730000  ...  21.497965  116.798424  38.000000  113.703041  64.329208  52.823471  152.518188  539.840027  123.452171  114.580002  47.518684  27.718935  194.171158  47.230000  49.502457
#
# [3 rows x 1310 columns]
#
# run_type: train, len(df): 1050
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %% [markdown]
# ### Run below cell to use test data to debug code, results should match yf_test.ipynb

# %%
# ####### RUN THIS CELL TO USE TEST DATA TO DEBUG CODE, RESULTS SHOULD MATCH yf_test.ipynb ################# 

# # load test data to debug code if needed
# test_dic = pickle_load(path_data_dump, 'yf_test_dic')
# for i, key in enumerate(test_dic.keys()):
#   print(f'{i}: {key}')

# # convert dictionary entries into variables
# locals().update(test_dic)
# del df_eval_results  # delete df_eval_results loaded from locals().update(test_dic)

# # Delete all rows in df_eval_results
# delete_all_rows(path_data_dump, fp_df_eval_results)

# %%
max_days_lookbacks = max(days_lookbacks)
print(f"max_days_lookbacks: {max_days_lookbacks}")

if verbose:
    print(f"number of max_lookback_slices is equal to n_samples = {n_samples}")
    print(f"max_lookback_slices:\n{max_lookback_slices}\n")
    print(f"number of sets in sets_lookback_slices is equal to n_samples = {n_samples}")
    print(f"sets_lookback_slices:\n{sets_lookback_slices}\n")
    print(f"days_lookbacks: {days_lookbacks}")
    print(
        f'number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): {len(days_lookbacks)}'
    )

# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the max_lookback_slices. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in max_lookback_slices. There are as many sub-lists as there are tuples in max_lookback_slices.
grp_top_set_syms_n_freq, grp_top_set_syms, dates_end_df_train = get_grp_top_syms_n_freq(
    df, sets_lookback_slices, days_lookbacks, n_top_syms, syms_start, syms_end, verbose
)

# #### print the best performing symbols for each set in sets_lookback_slices
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
    l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
    if verbose:
        print(f"max_lookback_slices:             {max_lookback_slices}")
        # print(f'set_lookback_slices: {sets_lookback_slices[i]}\n')
        print(
            f"set_lookback_slices {i + 1} of {len(sets_lookback_slices):>3}:    {sets_lookback_slices[i]}\n"
        )
        print(f"max_days_lookbacks:              {max_days_lookbacks}")
        print(f"df end date for days_lookbacks:  {dates_end_df_train[i]}")
        print(f"days_lookbacks:                  {days_lookbacks}")
        print(f"sym_freq_15:                     {l_sym_freq_cnt[0]}")
        print(f"sym_freq_14:                     {l_sym_freq_cnt[1]}")
        print(f"sym_freq_13:                     {l_sym_freq_cnt[2]}")
        print(f"sym_freq_12:                     {l_sym_freq_cnt[3]}")
        print(f"sym_freq_11:                     {l_sym_freq_cnt[4]}")
        print(f"sym_freq_10:                     {l_sym_freq_cnt[5]}")
        print(f"sym_freq_9:                      {l_sym_freq_cnt[6]}")
        print(f"sym_freq_8:                      {l_sym_freq_cnt[7]}")
        print(f"sym_freq_7:                      {l_sym_freq_cnt[8]}")
        print(f"sym_freq_6:                      {l_sym_freq_cnt[9]}")
        print(f"sym_freq_5:                      {l_sym_freq_cnt[10]}")
        print(f"sym_freq_4:                      {l_sym_freq_cnt[11]}")
        print(f"sym_freq_3:                      {l_sym_freq_cnt[12]}")
        print(f"sym_freq_2:                      {l_sym_freq_cnt[13]}\n")


# #### Evaluate performance of symbols in set_lookback_slices versus SPY
l_row_add_total = eval_grp_top_syms_n_freq(
    df, max_lookback_slices, sets_lookback_slices, grp_top_set_syms_n_freq, days_lookbacks, days_eval, n_samples, n_top_syms, syms_start, syms_end, verbose
)

for row_add_total in l_row_add_total:
    print(f"row_add_total: {row_add_total}")

if store_results:  # record results to df
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results BEFORW store results:\n{df_eval_results}\n")

    for row_add_total in l_row_add_total:
        # print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f"appended row_add_total to df_eval_results:\n{row_add_total}\n")

    pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
    print(f"Save results to: {fp_df_eval_results}")
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results AFTER store results:\n{df_eval_results}\n")
# Out:
# max_days_lookbacks: 120
# number of max_lookback_slices is equal to n_samples = 2
# max_lookback_slices:
# [(691, 811, 815), (761, 881, 885)]
#
# number of sets in sets_lookback_slices is equal to n_samples = 2
# sets_lookback_slices:
# [[(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)], [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]]
#
# days_lookbacks: [15, 30, 60, 120]
# number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): 4
#
# ########## 1 of 2 lb_slices: [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)] in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)]
# lb_slice:            (796, 811, 815)
# days eval:           4
# iloc_start_train:    796
# iloc_end_train:      811
# date_start_df_train: 2020-07-07
# date_end_df_train:   2020-07-27
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['RUN', 'GTLS', 'AN', 'MARA', 'CWH', 'TSM', 'EVH', 'SOHU', 'STC',
#        'LRN', 'WSO', 'HCA', 'BBWI', 'WY', 'SGRY', 'PHM', 'WHR', 'BCC',
#        'AMN', 'ASA'], dtype=object), 'r_CAGR/retnStd': array(['RUN', 'MARA', 'AN', 'CWH', 'GTLS', 'SOHU', 'EVH', 'LRN', 'TSM',
#        'STC', 'SGRY', 'PHM', 'HCA', 'NVAX', 'ASA', 'BBWI', 'PAAS', 'TMHC',
#        'BCC', 'WY'], dtype=object), 'r_retnStd/UI': array(['GTLS', 'WSO', 'TSM', 'CTSH', 'AN', 'HD', 'BFZ', 'XYL', 'BBWI',
#        'HCA', 'WAT', 'AOS', 'HOLX', 'LNT', 'STC', 'NEA', 'RUN', 'LH',
#        'WY', 'AMN'], dtype=object)}}
# most_freq_syms: [('RUN', 3), ('GTLS', 3), ('AN', 3), ('TSM', 3), ('STC', 3), ('HCA', 3), ('BBWI', 3), ('WY', 3), ('MARA', 2), ('CWH', 2), ('EVH', 2), ('SOHU', 2), ('LRN', 2), ('WSO', 2), ('SGRY', 2), ('PHM', 2), ('BCC', 2), ('AMN', 2), ('ASA', 2), ('WHR', 1), ('NVAX', 1), ('PAAS', 1), ('TMHC', 1), ('CTSH', 1), ('HD', 1), ('BFZ', 1), ('XYL', 1), ('WAT', 1), ('AOS', 1), ('HOLX', 1), ('LNT', 1), ('NEA', 1), ('LH', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)]
# lb_slice:            (781, 811, 815)
# days eval:           4
# iloc_start_train:    781
# iloc_end_train:      811
# date_start_df_train: 2020-06-15
# date_end_df_train:   2020-07-27
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['NVAX', 'OSTK', 'RUN', 'LRN', 'EVH', 'DQ', 'TSM', 'MED', 'GTLS',
#        'ASA', 'SOHU', 'AU', 'CELH', 'WPM', 'MAG', 'CINF', 'BCC', 'TSLA',
#        'INFY', 'PDCO'], dtype=object), 'r_CAGR/retnStd': array(['OSTK', 'NVAX', 'RUN', 'LRN', 'EVH', 'DQ', 'SOHU', 'GTLS', 'ASA',
#        'MED', 'AU', 'CELH', 'TSM', 'TSLA', 'PLUG', 'CRSP', 'MAG', 'ARWR',
#        'WPM', 'CWH'], dtype=object), 'r_retnStd/UI': array(['TSM', 'MED', 'RUN', 'EVH', 'GLD', 'SLGN', 'TIP', 'ABB', 'MUC',
#        'AU', 'INFY', 'APD', 'CINF', 'NVAX', 'MKC', 'ICHR', 'FCX', 'BCC',
#        'WPM', 'ASA'], dtype=object)}}
# most_freq_syms: [('NVAX', 3), ('RUN', 3), ('EVH', 3), ('TSM', 3), ('MED', 3), ('ASA', 3), ('AU', 3), ('WPM', 3), ('OSTK', 2), ('LRN', 2), ('DQ', 2), ('GTLS', 2), ('SOHU', 2), ('CELH', 2), ('MAG', 2), ('CINF', 2), ('BCC', 2), ('TSLA', 2), ('INFY', 2), ('PDCO', 1), ('PLUG', 1), ('CRSP', 1), ('ARWR', 1), ('CWH', 1), ('GLD', 1), ('SLGN', 1), ('TIP', 1), ('ABB', 1), ('MUC', 1), ('APD', 1), ('MKC', 1), ('ICHR', 1), ('FCX', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)]
# lb_slice:            (751, 811, 815)
# days eval:           4
# iloc_start_train:    751
# iloc_end_train:      811
# date_start_df_train: 2020-05-01
# date_end_df_train:   2020-07-27
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['NVAX', 'CWH', 'OSTK', 'RUN', 'CELH', 'SWBI', 'MED', 'TWLO',
#        'TSLA', 'APPS', 'MARA', 'WIX', 'STKL', 'MCFT', 'GPRE', 'IAC', 'SQ',
#        'HZO', 'MELI', 'LGIH'], dtype=object), 'r_CAGR/retnStd': array(['NVAX', 'OSTK', 'CWH', 'RUN', 'CELH', 'SWBI', 'MARA', 'MED', 'WIX',
#        'STKL', 'TSLA', 'APPS', 'TWLO', 'MCFT', 'LRN', 'SQ', 'HZO', 'DQ',
#        'GPRE', 'LGIH'], dtype=object), 'r_retnStd/UI': array(['MUC', 'CWH', 'CELH', 'RUN', 'TWLO', 'MELI', 'NYT', 'NZF', 'PRAA',
#        'TSLA', 'FTSM', 'RGR', 'APPS', 'SWBI', 'TSM', 'BSIG', 'GPRE',
#        'IAC', 'LRCX', 'WSO'], dtype=object)}}
# most_freq_syms: [('CWH', 3), ('RUN', 3), ('CELH', 3), ('SWBI', 3), ('TWLO', 3), ('TSLA', 3), ('APPS', 3), ('GPRE', 3), ('NVAX', 2), ('OSTK', 2), ('MED', 2), ('MARA', 2), ('WIX', 2), ('STKL', 2), ('MCFT', 2), ('IAC', 2), ('SQ', 2), ('HZO', 2), ('MELI', 2), ('LGIH', 2), ('LRN', 1), ('DQ', 1), ('MUC', 1), ('NYT', 1), ('NZF', 1), ('PRAA', 1), ('FTSM', 1), ('RGR', 1), ('TSM', 1), ('BSIG', 1), ('LRCX', 1), ('WSO', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)]
# lb_slice:            (691, 811, 815)
# days eval:           4
# iloc_start_train:    691
# iloc_end_train:      811
# date_start_df_train: 2020-02-05
# date_end_df_train:   2020-07-27
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['NVAX', 'OSTK', 'LRN', 'REGN', 'TDOC', 'UNFI', 'SHV', 'IEI',
#        'SWBI', 'SFM', 'ZTO', 'CELH', 'WPM', 'FIZZ', 'EQT', 'AU', 'SHOP',
#        'ETSY', 'CYRX', 'JD'], dtype=object), 'r_CAGR/retnStd': array(['NVAX', 'OSTK', 'LRN', 'CELH', 'SWBI', 'WPM', 'ETSY', 'UNFI',
#        'SHOP', 'RUN', 'STKL', 'TDOC', 'EQT', 'CWH', 'REGN', 'WST', 'TSLA',
#        'ZTO', 'EBAY', 'TWLO'], dtype=object), 'r_retnStd/UI': array(['REGN', 'IEI', 'NVAX', 'SHV', 'TDOC', 'CALM', 'SFM', 'FIZZ', 'ZTO',
#        'VRTX', 'YUMC', 'LLY', 'UNFI', 'DPZ', 'TPVG', 'FOLD', 'MPWR',
#        'CLX', 'CHT', 'JD'], dtype=object)}}
# most_freq_syms: [('NVAX', 3), ('REGN', 3), ('TDOC', 3), ('UNFI', 3), ('ZTO', 3), ('OSTK', 2), ('LRN', 2), ('SHV', 2), ('IEI', 2), ('SWBI', 2), ('SFM', 2), ('CELH', 2), ('WPM', 2), ('FIZZ', 2), ('EQT', 2), ('SHOP', 2), ('ETSY', 2), ('JD', 2), ('AU', 1), ('CYRX', 1), ('RUN', 1), ('STKL', 1), ('CWH', 1), ('WST', 1), ('TSLA', 1), ('EBAY', 1), ('TWLO', 1), ('CALM', 1), ('VRTX', 1), ('YUMC', 1), ('LLY', 1), ('DPZ', 1), ('TPVG', 1), ('FOLD', 1), ('MPWR', 1), ('CLX', 1), ('CHT', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('RUN', 3), ('GTLS', 3), ('AN', 3), ('TSM', 3), ('STC', 3), ('HCA', 3), ('BBWI', 3), ('WY', 3), ('MARA', 2), ('CWH', 2), ('EVH', 2), ('SOHU', 2), ('LRN', 2), ('WSO', 2), ('SGRY', 2), ('PHM', 2), ('BCC', 2), ('AMN', 2), ('ASA', 2), ('WHR', 1), ('NVAX', 1), ('PAAS', 1), ('TMHC', 1), ('CTSH', 1), ('HD', 1), ('BFZ', 1), ('XYL', 1), ('WAT', 1), ('AOS', 1), ('HOLX', 1), ('LNT', 1), ('NEA', 1), ('LH', 1)], [('NVAX', 3), ('RUN', 3), ('EVH', 3), ('TSM', 3), ('MED', 3), ('ASA', 3), ('AU', 3), ('WPM', 3), ('OSTK', 2), ('LRN', 2), ('DQ', 2), ('GTLS', 2), ('SOHU', 2), ('CELH', 2), ('MAG', 2), ('CINF', 2), ('BCC', 2), ('TSLA', 2), ('INFY', 2), ('PDCO', 1), ('PLUG', 1), ('CRSP', 1), ('ARWR', 1), ('CWH', 1), ('GLD', 1), ('SLGN', 1), ('TIP', 1), ('ABB', 1), ('MUC', 1), ('APD', 1), ('MKC', 1), ('ICHR', 1), ('FCX', 1)], [('CWH', 3), ('RUN', 3), ('CELH', 3), ('SWBI', 3), ('TWLO', 3), ('TSLA', 3), ('APPS', 3), ('GPRE', 3), ('NVAX', 2), ('OSTK', 2), ('MED', 2), ('MARA', 2), ('WIX', 2), ('STKL', 2), ('MCFT', 2), ('IAC', 2), ('SQ', 2), ('HZO', 2), ('MELI', 2), ('LGIH', 2), ('LRN', 1), ('DQ', 1), ('MUC', 1), ('NYT', 1), ('NZF', 1), ('PRAA', 1), ('FTSM', 1), ('RGR', 1), ('TSM', 1), ('BSIG', 1), ('LRCX', 1), ('WSO', 1)], [('NVAX', 3), ('REGN', 3), ('TDOC', 3), ('UNFI', 3), ('ZTO', 3), ('OSTK', 2), ('LRN', 2), ('SHV', 2), ('IEI', 2), ('SWBI', 2), ('SFM', 2), ('CELH', 2), ('WPM', 2), ('FIZZ', 2), ('EQT', 2), ('SHOP', 2), ('ETSY', 2), ('JD', 2), ('AU', 1), ('CYRX', 1), ('RUN', 1), ('STKL', 1), ('CWH', 1), ('WST', 1), ('TSLA', 1), ('EBAY', 1), ('TWLO', 1), ('CALM', 1), ('VRTX', 1), ('YUMC', 1), ('LLY', 1), ('DPZ', 1), ('TPVG', 1), ('FOLD', 1), ('MPWR', 1), ('CLX', 1), ('CHT', 1)]]
# **** finish lookback slices [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)] ****
#
# top 20 ranked symbols and frequency from set [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)]:
# [('RUN', 10), ('NVAX', 9), ('CELH', 7), ('CWH', 7), ('LRN', 7), ('TSM', 7), ('OSTK', 6), ('TSLA', 6), ('ASA', 5), ('EVH', 5), ('GTLS', 5), ('MED', 5), ('SWBI', 5), ('WPM', 5), ('AU', 4), ('BCC', 4), ('MARA', 4), ('SOHU', 4), ('TWLO', 4), ('AN', 3)]
# top 20 ranked symbols from set [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)]:
# ['RUN', 'NVAX', 'CELH', 'CWH', 'LRN', 'TSM', 'OSTK', 'TSLA', 'ASA', 'EVH']
# ===== finish top 20 ranked symbols from days_lookback set [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)] =====
#
#
#
# ########## 2 of 2 lb_slices: [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)] in sets_lookcak_slices ##########
# days lookback:       15,  1 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]
# lb_slice:            (866, 881, 885)
# days eval:           4
# iloc_start_train:    866
# iloc_end_train:      881
# date_start_df_train: 2020-10-14
# date_end_df_train:   2020-11-03
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['AVXL', 'ALGN', 'ARLP', 'ARWR', 'TCBI', 'TPR', 'LOB', 'GBTC',
#        'BTC-USD', 'PNFP', 'DLB', 'DBRG', 'UBSI', 'YY', 'UMBF', 'NSP',
#        'FLR', 'PEN', 'SONY', 'BPOP'], dtype=object), 'r_CAGR/retnStd': array(['AVXL', 'ARWR', 'ARLP', 'ALGN', 'TPR', 'GBTC', 'TCBI', 'LOB',
#        'PNFP', 'FLR', 'BTC-USD', 'SSB', 'DLB', 'BANC', 'UMBF', 'UBSI',
#        'COLB', 'INDB', 'BPOP', 'OZK'], dtype=object), 'r_retnStd/UI': array(['PNM', 'TCBI', 'AVXL', 'BTC-USD', 'LOB', 'DBRG', 'ALGN', 'NSP',
#        'YY', 'TPR', 'GBTC', 'PKI', 'DLB', 'MATX', 'MAT', 'PEN', 'SCI',
#        'SONY', 'WD', 'HOG'], dtype=object)}}
# most_freq_syms: [('AVXL', 3), ('ALGN', 3), ('TCBI', 3), ('TPR', 3), ('LOB', 3), ('GBTC', 3), ('BTC-USD', 3), ('DLB', 3), ('ARLP', 2), ('ARWR', 2), ('PNFP', 2), ('DBRG', 2), ('UBSI', 2), ('YY', 2), ('UMBF', 2), ('NSP', 2), ('FLR', 2), ('PEN', 2), ('SONY', 2), ('BPOP', 2), ('SSB', 1), ('BANC', 1), ('COLB', 1), ('INDB', 1), ('OZK', 1), ('PNM', 1), ('PKI', 1), ('MATX', 1), ('MAT', 1), ('SCI', 1), ('WD', 1), ('HOG', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]
# lb_slice:            (851, 881, 885)
# days eval:           4
# iloc_start_train:    851
# iloc_end_train:      881
# date_start_df_train: 2020-09-23
# date_end_df_train:   2020-11-03
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['LOB', 'MGI', 'DBRG', 'MATX', 'EXAS', 'TCBI', 'SPWR', 'NSP', 'PNM',
#        'GBTC', 'BTC-USD', 'PPBI', 'WD', 'ALGN', 'TPR', 'PNFP', 'EXLS',
#        'LSCC', 'FLR', 'UMBF'], dtype=object), 'r_CAGR/retnStd': array(['LOB', 'MGI', 'SPWR', 'EXAS', 'DBRG', 'TCBI', 'MATX', 'PPBI',
#        'FLR', 'DAR', 'PNFP', 'DQ', 'OLN', 'TEX', 'UMBF', 'AVXL', 'TPR',
#        'FOLD', 'ACRS', 'DDS'], dtype=object), 'r_retnStd/UI': array(['PNM', 'LOB', 'MATX', 'NSP', 'DBRG', 'ALGN', 'TCBI', 'BTC-USD',
#        'EXAS', 'EXLS', 'WD', 'MAT', 'CROX', 'LSCC', 'GRMN', 'GBTC', 'DUK',
#        'HOG', 'X', 'GNRC'], dtype=object)}}
# most_freq_syms: [('LOB', 3), ('DBRG', 3), ('MATX', 3), ('EXAS', 3), ('TCBI', 3), ('MGI', 2), ('SPWR', 2), ('NSP', 2), ('PNM', 2), ('GBTC', 2), ('BTC-USD', 2), ('PPBI', 2), ('WD', 2), ('ALGN', 2), ('TPR', 2), ('PNFP', 2), ('EXLS', 2), ('LSCC', 2), ('FLR', 2), ('UMBF', 2), ('DAR', 1), ('DQ', 1), ('OLN', 1), ('TEX', 1), ('AVXL', 1), ('FOLD', 1), ('ACRS', 1), ('DDS', 1), ('MAT', 1), ('CROX', 1), ('GRMN', 1), ('DUK', 1), ('HOG', 1), ('X', 1), ('GNRC', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]
# lb_slice:            (821, 881, 885)
# days eval:           4
# iloc_start_train:    821
# iloc_end_train:      881
# date_start_df_train: 2020-08-11
# date_end_df_train:   2020-11-03
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['LOB', 'GME', 'GOGO', 'SPWR', 'BLFS', 'OLN', 'STAA', 'CROX',
#        'ALGN', 'BKE', 'FDX', 'PWR', 'BGNE', 'PCTY', 'SLM', 'MEOH', 'CTRN',
#        'DAR', 'SAGE', 'TPR'], dtype=object), 'r_CAGR/retnStd': array(['GME', 'GOGO', 'LOB', 'SPWR', 'OLN', 'NVCR', 'TPR', 'FDX', 'BLFS',
#        'PCTY', 'BGNE', 'CROX', 'DQ', 'EAT', 'PWR', 'DDS', 'BOOT', 'STAA',
#        'HIBB', 'MEOH'], dtype=object), 'r_retnStd/UI': array(['ALGN', 'STAA', 'LOB', 'BLFS', 'BKE', 'GKOS', 'GME', 'CROX',
#        'QNST', 'SCHW', 'AQN', 'BFAM', 'AMN', 'PWR', 'GOGO', 'SLM', 'CORT',
#        'SAGE', 'PSA', 'DAR'], dtype=object)}}
# most_freq_syms: [('LOB', 3), ('GME', 3), ('GOGO', 3), ('BLFS', 3), ('STAA', 3), ('CROX', 3), ('PWR', 3), ('SPWR', 2), ('OLN', 2), ('ALGN', 2), ('BKE', 2), ('FDX', 2), ('BGNE', 2), ('PCTY', 2), ('SLM', 2), ('MEOH', 2), ('DAR', 2), ('SAGE', 2), ('TPR', 2), ('CTRN', 1), ('NVCR', 1), ('DQ', 1), ('EAT', 1), ('DDS', 1), ('BOOT', 1), ('HIBB', 1), ('GKOS', 1), ('QNST', 1), ('SCHW', 1), ('AQN', 1), ('BFAM', 1), ('AMN', 1), ('CORT', 1), ('PSA', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  4 of 4 days_lookbacks: [15, 30, 60, 120]
# lb_slices:           [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]
# lb_slice:            (761, 881, 885)
# days eval:           4
# iloc_start_train:    761
# iloc_end_train:      881
# date_start_df_train: 2020-05-15
# date_end_df_train:   2020-11-03
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['APPS', 'GOGO', 'SPWR', 'PLUG', 'DQ', 'FDX', 'RUN', 'LOB', 'CROX',
#        'CELH', 'FCX', 'DAR', 'TRUP', 'BBWI', 'GTLS', 'COOP', 'UPS',
#        'GNRC', 'VSTO', 'ALGN'], dtype=object), 'r_CAGR/retnStd': array(['APPS', 'SPWR', 'RUN', 'DQ', 'PLUG', 'GOGO', 'LOB', 'FDX', 'CELH',
#        'TRUP', 'BBWI', 'PWR', 'OSTK', 'VSTO', 'GTLS', 'DAR', 'HIBB',
#        'GNRC', 'MGI', 'COOP'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'UPS', 'ALGN', 'FCX', 'CROX', 'SAGE', 'GOGO', 'TMO', 'FDX',
#        'ON', 'HZNP', 'CCS', 'QCOM', 'TSM', 'NSP', 'STKL', 'APPS', 'CLAR',
#        'BSIG', 'NUS'], dtype=object)}}
# most_freq_syms: [('APPS', 3), ('GOGO', 3), ('FDX', 3), ('SPWR', 2), ('PLUG', 2), ('DQ', 2), ('RUN', 2), ('LOB', 2), ('CROX', 2), ('CELH', 2), ('FCX', 2), ('DAR', 2), ('TRUP', 2), ('BBWI', 2), ('GTLS', 2), ('COOP', 2), ('UPS', 2), ('GNRC', 2), ('VSTO', 2), ('ALGN', 2), ('PWR', 1), ('OSTK', 1), ('HIBB', 1), ('MGI', 1), ('FTSM', 1), ('SAGE', 1), ('TMO', 1), ('ON', 1), ('HZNP', 1), ('CCS', 1), ('QCOM', 1), ('TSM', 1), ('NSP', 1), ('STKL', 1), ('CLAR', 1), ('BSIG', 1), ('NUS', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('AVXL', 3), ('ALGN', 3), ('TCBI', 3), ('TPR', 3), ('LOB', 3), ('GBTC', 3), ('BTC-USD', 3), ('DLB', 3), ('ARLP', 2), ('ARWR', 2), ('PNFP', 2), ('DBRG', 2), ('UBSI', 2), ('YY', 2), ('UMBF', 2), ('NSP', 2), ('FLR', 2), ('PEN', 2), ('SONY', 2), ('BPOP', 2), ('SSB', 1), ('BANC', 1), ('COLB', 1), ('INDB', 1), ('OZK', 1), ('PNM', 1), ('PKI', 1), ('MATX', 1), ('MAT', 1), ('SCI', 1), ('WD', 1), ('HOG', 1)], [('LOB', 3), ('DBRG', 3), ('MATX', 3), ('EXAS', 3), ('TCBI', 3), ('MGI', 2), ('SPWR', 2), ('NSP', 2), ('PNM', 2), ('GBTC', 2), ('BTC-USD', 2), ('PPBI', 2), ('WD', 2), ('ALGN', 2), ('TPR', 2), ('PNFP', 2), ('EXLS', 2), ('LSCC', 2), ('FLR', 2), ('UMBF', 2), ('DAR', 1), ('DQ', 1), ('OLN', 1), ('TEX', 1), ('AVXL', 1), ('FOLD', 1), ('ACRS', 1), ('DDS', 1), ('MAT', 1), ('CROX', 1), ('GRMN', 1), ('DUK', 1), ('HOG', 1), ('X', 1), ('GNRC', 1)], [('LOB', 3), ('GME', 3), ('GOGO', 3), ('BLFS', 3), ('STAA', 3), ('CROX', 3), ('PWR', 3), ('SPWR', 2), ('OLN', 2), ('ALGN', 2), ('BKE', 2), ('FDX', 2), ('BGNE', 2), ('PCTY', 2), ('SLM', 2), ('MEOH', 2), ('DAR', 2), ('SAGE', 2), ('TPR', 2), ('CTRN', 1), ('NVCR', 1), ('DQ', 1), ('EAT', 1), ('DDS', 1), ('BOOT', 1), ('HIBB', 1), ('GKOS', 1), ('QNST', 1), ('SCHW', 1), ('AQN', 1), ('BFAM', 1), ('AMN', 1), ('CORT', 1), ('PSA', 1)], [('APPS', 3), ('GOGO', 3), ('FDX', 3), ('SPWR', 2), ('PLUG', 2), ('DQ', 2), ('RUN', 2), ('LOB', 2), ('CROX', 2), ('CELH', 2), ('FCX', 2), ('DAR', 2), ('TRUP', 2), ('BBWI', 2), ('GTLS', 2), ('COOP', 2), ('UPS', 2), ('GNRC', 2), ('VSTO', 2), ('ALGN', 2), ('PWR', 1), ('OSTK', 1), ('HIBB', 1), ('MGI', 1), ('FTSM', 1), ('SAGE', 1), ('TMO', 1), ('ON', 1), ('HZNP', 1), ('CCS', 1), ('QCOM', 1), ('TSM', 1), ('NSP', 1), ('STKL', 1), ('CLAR', 1), ('BSIG', 1), ('NUS', 1)]]
# **** finish lookback slices [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)] ****
#
# top 20 ranked symbols and frequency from set [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]:
# [('LOB', 11), ('ALGN', 9), ('TPR', 7), ('CROX', 6), ('GOGO', 6), ('SPWR', 6), ('TCBI', 6), ('BTC-USD', 5), ('DAR', 5), ('DBRG', 5), ('FDX', 5), ('GBTC', 5), ('NSP', 5), ('AVXL', 4), ('DQ', 4), ('FLR', 4), ('MATX', 4), ('PNFP', 4), ('PWR', 4), ('UMBF', 4)]
# top 20 ranked symbols from set [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]:
# ['LOB', 'ALGN', 'TPR', 'CROX', 'GOGO', 'SPWR', 'TCBI', 'BTC-USD', 'DAR', 'DBRG']
# ===== finish top 20 ranked symbols from days_lookback set [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)] =====
#
#
# max_lookback_slices:             [(691, 811, 815), (761, 881, 885)]
# set_lookback_slices 1 of   2:    [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)]
#
# max_days_lookbacks:              120
# df end date for days_lookbacks:  2020-07-27
# days_lookbacks:                  [15, 30, 60, 120]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     ['RUN']
# sym_freq_9:                      ['NVAX']
# sym_freq_8:                      []
# sym_freq_7:                      ['CELH', 'CWH', 'LRN', 'TSM']
# sym_freq_6:                      ['OSTK', 'TSLA']
# sym_freq_5:                      ['ASA', 'EVH', 'GTLS', 'MED', 'SWBI', 'WPM']
# sym_freq_4:                      ['AU', 'BCC', 'MARA', 'SOHU', 'TWLO']
# sym_freq_3:                      ['AN']
# sym_freq_2:                      []
#
# max_lookback_slices:             [(691, 811, 815), (761, 881, 885)]
# set_lookback_slices 2 of   2:    [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]
#
# max_days_lookbacks:              120
# df end date for days_lookbacks:  2020-11-03
# days_lookbacks:                  [15, 30, 60, 120]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     ['LOB']
# sym_freq_10:                     []
# sym_freq_9:                      ['ALGN']
# sym_freq_8:                      []
# sym_freq_7:                      ['TPR']
# sym_freq_6:                      ['CROX', 'GOGO', 'SPWR', 'TCBI']
# sym_freq_5:                      ['BTC-USD', 'DAR', 'DBRG', 'FDX', 'GBTC', 'NSP']
# sym_freq_4:                      ['AVXL', 'DQ', 'FLR', 'MATX', 'PNFP', 'PWR', 'UMBF']
# sym_freq_3:                      []
# sym_freq_2:                      []
#
# z_grp_top_set_syms_n_freq:
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
#
#
# 1 of 2 max_lookback_slice: (691, 811, 815)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2020-02-05', '2020-02-06', '2020-02-07', '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14', '2020-02-18', '2020-02-19',
#                ...
#                '2020-07-14', '2020-07-15', '2020-07-16', '2020-07-17', '2020-07-20', '2020-07-21', '2020-07-22', '2020-07-23', '2020-07-24', '2020-07-27'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2020-02-05 - 2020-07-27
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2020-07-28', '2020-07-29', '2020-07-30', '2020-07-31'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2020-07-28 - 2020-07-31
#
# top_set_syms_n_freq: [('RUN', 10), ('NVAX', 9), ('CELH', 7), ('CWH', 7), ('LRN', 7), ('TSM', 7), ('OSTK', 6), ('TSLA', 6), ('ASA', 5), ('EVH', 5), ('GTLS', 5), ('MED', 5), ('SWBI', 5), ('WPM', 5), ('AU', 4), ('BCC', 4), ('MARA', 4), ('SOHU', 4), ('TWLO', 4), ('AN', 3)]
#
# set_lookback_slices: [(796, 811, 815), (781, 811, 815), (751, 811, 815), (691, 811, 815)]
# max_lookback_slice:  (691, 811, 815)
# days_lookbacks:      [15, 30, 60, 120]
# date_end_df_train:   2020-07-27
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         ['RUN']
# sym_freq_9:          ['NVAX']
# sym_freq_8:          []
# sym_freq_7:          ['CELH', 'CWH', 'LRN', 'TSM']
# sym_freq_6:          ['OSTK', 'TSLA']
# sym_freq_5:          ['ASA', 'EVH', 'GTLS', 'MED', 'SWBI', 'WPM']
# sym_freq_4:          ['AU', 'BCC', 'MARA', 'SOHU', 'TWLO']
# sym_freq_3:          ['AN']
# sym_freq_2:          []
#
# iloc_start_eval:    811,  df_eval first date: 2020-07-28
# iloc_end_eval:      815,  df_eval last date:  2020-07-31
# frequency count of symbol(s): 10
#
# df_eval_n_SPY:
#                   RUN         SPY
# Date
# 2020-07-28  40.459999  308.147308
# 2020-07-29  36.605000  311.937164
# 2020-07-30  36.669998  310.824158
# 2020-07-31  36.689999  313.280334
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.9997
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                         -12.2745
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -21.9890
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        0.5582
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    3.0057
# SPY_CAGR/UI                             1,684.7923
# SPY_CAGR/retnStd                          449.3678
# SPY_retnStd/UI                              3.7493
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# iloc_start_eval:    811,  df_eval first date: 2020-07-28
# iloc_end_eval:      815,  df_eval last date:  2020-07-31
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#                   NVAX         SPY
# Date
# 2020-07-28  148.600006  308.147308
# 2020-07-29  145.360001  311.937164
# 2020-07-30  146.619995  310.824158
# 2020-07-31  143.100006  313.280334
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.9579
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                         -42.5967
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -64.2415
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        0.6631
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    3.0057
# SPY_CAGR/UI                             1,684.7923
# SPY_CAGR/retnStd                          449.3678
# SPY_retnStd/UI                              3.7493
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# iloc_start_eval:    811,  df_eval first date: 2020-07-28
# iloc_end_eval:      815,  df_eval last date:  2020-07-31
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#              CELH        CWH        LRN        TSM         SPY
# Date
# 2020-07-28  14.64  29.814436  46.980000  73.042450  308.147308
# 2020-07-29  15.19  28.481167  48.599998  78.502586  311.937164
# 2020-07-30  14.72  29.871687  47.750000  75.900703  310.824158
# 2020-07-31  14.67  29.953487  45.790001  74.913147  313.280334
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              1.7871
# grp(CAGR)_std                               3.2610
# grp(CAGR)_mean/std                          0.5480
# grp(CAGR/UI)_mean                          65.2844
# grp(CAGR/UI)_std                          114.4500
# grp(CAGR/UI)_mean/std                       0.5704
# grp(CAGR/retnStd)_mean                     37.1065
# grp(CAGR/retnStd)_std                      71.0779
# grp(CAGR/retnStd)_mean/std                  0.5221
# grp(retnStd/UI)_mean                        1.4079
# grp(retnStd/UI)_std                         0.2830
# grp(retnStd/UI)_mean/std                    4.9753
# SPY_CAGR                                    3.0057
# SPY_CAGR/UI                             1,684.7923
# SPY_CAGR/retnStd                          449.3678
# SPY_retnStd/UI                              3.7493
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 1.7870828262729146, 3.2610319098843514, 0.5480114502578699, 65.2844173949555, 114.45001783590857, 0.5704185864658955, 37.10646649758617, 71.07790612135433, 0.5220534554610081, 1.4079203878852316, 0.2829814023820566, 4.975310660113209, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# iloc_start_eval:    811,  df_eval first date: 2020-07-28
# iloc_end_eval:      815,  df_eval last date:  2020-07-31
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  OSTK       TSLA         SPY
# Date
# 2020-07-28  58.369999  98.432671  308.147308
# 2020-07-29  60.740002  99.940666  311.937164
# 2020-07-30  76.190002  99.166000  310.824158
# 2020-07-31  75.589996  95.384003  313.280334
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                  1,349,086,122.2999
# grp(CAGR)_std                   1,349,086,123.2287
# grp(CAGR)_mean/std                          1.0000
# grp(CAGR/UI)_mean             342,619,431,298.4343
# grp(CAGR/UI)_std              342,619,431,338.6021
# grp(CAGR/UI)_mean/std                       1.0000
# grp(CAGR/retnStd)_mean         11,841,778,600.4630
# grp(CAGR/retnStd)_std          11,841,778,642.8908
# grp(CAGR/retnStd)_mean/std                  1.0000
# grp(retnStd/UI)_mean                       14.9399
# grp(retnStd/UI)_std                        13.9932
# grp(retnStd/UI)_mean/std                    1.0677
# SPY_CAGR                                    3.0057
# SPY_CAGR/UI                             1,684.7923
# SPY_CAGR/retnStd                          449.3678
# SPY_retnStd/UI                              3.7493
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 1.7870828262729146, 3.2610319098843514, 0.5480114502578699, 65.2844173949555, 114.45001783590857, 0.5704185864658955, 37.10646649758617, 71.07790612135433, 0.5220534554610081, 1.4079203878852316, 0.2829814023820566, 4.975310660113209, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1349086122.2998981, 1349086123.2287364, 0.9999999993115056, 342619431298.43427, 342619431338.6021, 0.9999999998827624, 11841778600.463018, 11841778642.89084, 0.9999999964171074, 14.939919263994382, 13.993186333110541, 1.0676567086542463, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# iloc_start_eval:    811,  df_eval first date: 2020-07-28
# iloc_end_eval:      815,  df_eval last date:  2020-07-31
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   ASA    EVH       GTLS         MED       SWBI        WPM         SPY
# Date
# 2020-07-28  23.468170  11.06  65.169998  147.941589  17.374784  53.534210  308.147308
# 2020-07-29  23.278669  11.39  68.269997  151.658432  17.801031  52.850086  311.937164
# 2020-07-30  22.869747  11.59  69.620003  150.130112  17.620419  50.874840  310.824158
# 2020-07-31  23.498091  11.65  68.529999  151.142975  17.259195  52.349052  313.280334
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             24.8000
# grp(CAGR)_std                              33.8928
# grp(CAGR)_mean/std                          0.7317
# grp(CAGR/UI)_mean                  25,899,754.2695
# grp(CAGR/UI)_std                   57,909,368.4357
# grp(CAGR/UI)_mean/std                       0.4472
# grp(CAGR/retnStd)_mean                  1,769.8002
# grp(CAGR/retnStd)_std                   2,817.7745
# grp(CAGR/retnStd)_mean/std                  0.6281
# grp(retnStd/UI)_mean                    3,357.4737
# grp(retnStd/UI)_std                     7,503.2287
# grp(retnStd/UI)_mean/std                    0.4475
# SPY_CAGR                                    3.0057
# SPY_CAGR/UI                             1,684.7923
# SPY_CAGR/retnStd                          449.3678
# SPY_retnStd/UI                              3.7493
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 1.7870828262729146, 3.2610319098843514, 0.5480114502578699, 65.2844173949555, 114.45001783590857, 0.5704185864658955, 37.10646649758617, 71.07790612135433, 0.5220534554610081, 1.4079203878852316, 0.2829814023820566, 4.975310660113209, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1349086122.2998981, 1349086123.2287364, 0.9999999993115056, 342619431298.43427, 342619431338.6021, 0.9999999998827624, 11841778600.463018, 11841778642.89084, 0.9999999964171074, 14.939919263994382, 13.993186333110541, 1.0676567086542463, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 24.800007482988136, 33.89281464901524, 0.7317187356615336, 25899754.26951271, 57909368.43574564, 0.4472463604615242, 1769.800244480148, 2817.7744728136754, 0.628084419656525, 3357.4736783555813, 7503.228676046757, 0.4474705254651177, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# iloc_start_eval:    811,  df_eval first date: 2020-07-28
# iloc_end_eval:      815,  df_eval last date:  2020-07-31
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                    AU        BCC  MARA       SOHU        TWLO         SPY
# Date
# 2020-07-28  34.896023  39.035934  1.71  17.260000  249.789993  308.147308
# 2020-07-29  34.368298  40.081234  1.82  17.930000  264.619995  311.937164
# 2020-07-30  30.542269  39.086117  1.78  19.219999  267.450012  310.824158
# 2020-07-31  30.334944  38.960674  2.03  22.969999  277.420013  313.280334
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                  5,335,254,498.5201
# grp(CAGR)_std                  10,669,600,007.7983
# grp(CAGR)_mean/std                          0.5000
# grp(CAGR/UI)_mean             10,669,784,507,201,054.0000
# grp(CAGR/UI)_std              21,339,562,214,506,124.0000
# grp(CAGR/UI)_mean/std                       0.5000
# grp(CAGR/retnStd)_mean         79,344,067,452.1149
# grp(CAGR/retnStd)_std         158,674,317,697.5637
# grp(CAGR/retnStd)_mean/std                  0.5000
# grp(retnStd/UI)_mean                   34,858.2871
# grp(retnStd/UI)_std                    52,143.0852
# grp(retnStd/UI)_mean/std                    0.6685
# SPY_CAGR                                    3.0057
# SPY_CAGR/UI                             1,684.7923
# SPY_CAGR/retnStd                          449.3678
# SPY_retnStd/UI                              3.7493
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 1.7870828262729146, 3.2610319098843514, 0.5480114502578699, 65.2844173949555, 114.45001783590857, 0.5704185864658955, 37.10646649758617, 71.07790612135433, 0.5220534554610081, 1.4079203878852316, 0.2829814023820566, 4.975310660113209, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1349086122.2998981, 1349086123.2287364, 0.9999999993115056, 342619431298.43427, 342619431338.6021, 0.9999999998827624, 11841778600.463018, 11841778642.89084, 0.9999999964171074, 14.939919263994382, 13.993186333110541, 1.0676567086542463, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 24.800007482988136, 33.89281464901524, 0.7317187356615336, 25899754.26951271, 57909368.43574564, 0.4472463604615242, 1769.800244480148, 2817.7744728136754, 0.628084419656525, 3357.4736783555813, 7503.228676046757, 0.4474705254651177, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 5335254498.520062, 10669600007.79833, 0.5000425971564599, 1.0669784507201054e+16, 2.1339562214506124e+16, 0.5000001593260422, 79344067452.11491, 158674317697.56372, 0.5000435395181356, 34858.28706627689, 52143.085222330876, 0.668512170264686, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# iloc_start_eval:    811,  df_eval first date: 2020-07-28
# iloc_end_eval:      815,  df_eval last date:  2020-07-31
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                    AN         SPY
# Date
# 2020-07-28  54.560001  308.147308
# 2020-07-29  54.150002  311.937164
# 2020-07-30  51.630001  310.824158
# 2020-07-31  51.340000  313.280334
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.9940
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                         -24.8036
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -52.7057
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        0.4706
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    3.0057
# SPY_CAGR/UI                             1,684.7923
# SPY_CAGR/retnStd                          449.3678
# SPY_retnStd/UI                              3.7493
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 1.7870828262729146, 3.2610319098843514, 0.5480114502578699, 65.2844173949555, 114.45001783590857, 0.5704185864658955, 37.10646649758617, 71.07790612135433, 0.5220534554610081, 1.4079203878852316, 0.2829814023820566, 4.975310660113209, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1349086122.2998981, 1349086123.2287364, 0.9999999993115056, 342619431298.43427, 342619431338.6021, 0.9999999998827624, 11841778600.463018, 11841778642.89084, 0.9999999964171074, 14.939919263994382, 13.993186333110541, 1.0676567086542463, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 24.800007482988136, 33.89281464901524, 0.7317187356615336, 25899754.26951271, 57909368.43574564, 0.4472463604615242, 1769.800244480148, 2817.7744728136754, 0.628084419656525, 3357.4736783555813, 7503.228676046757, 0.4474705254651177, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 5335254498.520062, 10669600007.79833, 0.5000425971564599, 1.0669784507201054e+16, 2.1339562214506124e+16, 0.5000001593260422, 79344067452.11491, 158674317697.56372, 0.5000435395181356, 34858.28706627689, 52143.085222330876, 0.668512170264686, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 3, -0.9939626630368025, 0.0, -inf, -24.803586793734933, 0.0, -inf, -52.7057239865856, 0.0, -inf, 0.4706051813280815, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# ================================================================================
#
#
#
# 2 of 2 max_lookback_slice: (761, 881, 885)
#
# len(idx_train): 120
# idx_train: DatetimeIndex(['2020-05-15', '2020-05-18', '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22', '2020-05-26', '2020-05-27', '2020-05-28', '2020-05-29',
#                ...
#                '2020-10-21', '2020-10-22', '2020-10-23', '2020-10-26', '2020-10-27', '2020-10-28', '2020-10-29', '2020-10-30', '2020-11-02', '2020-11-03'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2020-05-15 - 2020-11-03
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2020-11-04', '2020-11-05', '2020-11-06', '2020-11-09'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2020-11-04 - 2020-11-09
#
# top_set_syms_n_freq: [('LOB', 11), ('ALGN', 9), ('TPR', 7), ('CROX', 6), ('GOGO', 6), ('SPWR', 6), ('TCBI', 6), ('BTC-USD', 5), ('DAR', 5), ('DBRG', 5), ('FDX', 5), ('GBTC', 5), ('NSP', 5), ('AVXL', 4), ('DQ', 4), ('FLR', 4), ('MATX', 4), ('PNFP', 4), ('PWR', 4), ('UMBF', 4)]
#
# set_lookback_slices: [(866, 881, 885), (851, 881, 885), (821, 881, 885), (761, 881, 885)]
# max_lookback_slice:  (761, 881, 885)
# days_lookbacks:      [15, 30, 60, 120]
# date_end_df_train:   2020-11-03
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         ['LOB']
# sym_freq_10:         []
# sym_freq_9:          ['ALGN']
# sym_freq_8:          []
# sym_freq_7:          ['TPR']
# sym_freq_6:          ['CROX', 'GOGO', 'SPWR', 'TCBI']
# sym_freq_5:          ['BTC-USD', 'DAR', 'DBRG', 'FDX', 'GBTC', 'NSP']
# sym_freq_4:          ['AVXL', 'DQ', 'FLR', 'MATX', 'PNFP', 'PWR', 'UMBF']
# sym_freq_3:          []
# sym_freq_2:          []
#
# iloc_start_eval:    881,  df_eval first date: 2020-11-04
# iloc_end_eval:      885,  df_eval last date:  2020-11-09
# frequency count of symbol(s): 11
#
# df_eval_n_SPY:
#                   LOB         SPY
# Date
# 2020-11-04  37.874886  330.929688
# 2020-11-05  40.487972  337.383698
# 2020-11-06  39.345367  337.306610
# 2020-11-09  40.587322  341.545166
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                            332.6429
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                             inf
# grp(CAGR/UI)_mean                      23,574.2692
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                          inf
# grp(CAGR/retnStd)_mean                  8,308.6771
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                     inf
# grp(retnStd/UI)_mean                        2.8373
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                   13.1854
# SPY_CAGR/UI                           115,415.7959
# SPY_CAGR/retnStd                        1,613.3572
# SPY_retnStd/UI                             71.5377
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 1.7870828262729146, 3.2610319098843514, 0.5480114502578699, 65.2844173949555, 114.45001783590857, 0.5704185864658955, 37.10646649758617, 71.07790612135433, 0.5220534554610081, 1.4079203878852316, 0.2829814023820566, 4.975310660113209, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1349086122.2998981, 1349086123.2287364, 0.9999999993115056, 342619431298.43427, 342619431338.6021, 0.9999999998827624, 11841778600.463018, 11841778642.89084, 0.9999999964171074, 14.939919263994382, 13.993186333110541, 1.0676567086542463, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 24.800007482988136, 33.89281464901524, 0.7317187356615336, 25899754.26951271, 57909368.43574564, 0.4472463604615242, 1769.800244480148, 2817.7744728136754, 0.628084419656525, 3357.4736783555813, 7503.228676046757, 0.4474705254651177, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 5335254498.520062, 10669600007.79833, 0.5000425971564599, 1.0669784507201054e+16, 2.1339562214506124e+16, 0.5000001593260422, 79344067452.11491, 158674317697.56372, 0.5000435395181356, 34858.28706627689, 52143.085222330876, 0.668512170264686, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397], [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 3, -0.9939626630368025, 0.0, -inf, -24.803586793734933, 0.0, -inf, -52.7057239865856, 0.0, -inf, 0.4706051813280815, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 11, 332.6429098251804, 0.0, inf, 23574.269207853824, 0.0, inf, 8308.677116860503, 0.0, inf, 2.8373071761346216, 0.0, inf, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
# iloc_start_eval:    881,  df_eval first date: 2020-11-04
# iloc_end_eval:      885,  df_eval last date:  2020-11-09
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#                   ALGN         SPY
# Date
# 2020-11-04  483.459991  330.929688
# 2020-11-05  491.910004  337.383698
# 2020-11-06  477.850006  337.306610
# 2020-11-09  476.989990  341.545166
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.6775
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                         -32.5138
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -35.8723
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        0.9064
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                   13.1854
# SPY_CAGR/UI                           115,415.7959
# SPY_CAGR/retnStd                        1,613.3572
# SPY_retnStd/UI                             71.5377
#
# type(l_row_add_total): <class 'list'>
# ...
#
#
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 1.7870828262729146, 3.2610319098843514, 0.5480114502578699, 65.2844173949555, 114.45001783590857, 0.5704185864658955, 37.10646649758617, 71.07790612135433, 0.5220534554610081, 1.4079203878852316, 0.2829814023820566, 4.975310660113209, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1349086122.2998981, 1349086123.2287364, 0.9999999993115056, 342619431298.43427, 342619431338.6021, 0.9999999998827624, 11841778600.463018, 11841778642.89084, 0.9999999964171074, 14.939919263994382, 13.993186333110541, 1.0676567086542463, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 24.800007482988136, 33.89281464901524, 0.7317187356615336, 25899754.26951271, 57909368.43574564, 0.4472463604615242, 1769.800244480148, 2817.7744728136754, 0.628084419656525, 3357.4736783555813, 7503.228676046757, 0.4474705254651177, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 5335254498.520062, 10669600007.79833, 0.5000425971564599, 1.0669784507201054e+16, 2.1339562214506124e+16, 0.5000001593260422, 79344067452.11491, 158674317697.56372, 0.5000435395181356, 34858.28706627689, 52143.085222330876, 0.668512170264686, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 3, -0.9939626630368025, 0.0, -inf, -24.803586793734933, 0.0, -inf, -52.7057239865856, 0.0, -inf, 0.4706051813280815, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 11, 332.6429098251804, 0.0, inf, 23574.269207853824, 0.0, inf, 8308.677116860503, 0.0, inf, 2.8373071761346216, 0.0, inf, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.6775273204748977, 0.0, -inf, -32.513802442391615, 0.0, -inf, -35.872297603989296, 0.0, -inf, 0.9063763576374827, 0.0, inf, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 41.75075633267711, 0.0, inf, 5290.5711685627475, 0.0, inf, 1860.3425860599195, 0.0, inf, 2.8438693003141005, 0.0, inf, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 196996.6710303219, 206244.7397746814, 0.9551597352036088, 23110979.702880207, 33620551.803247474, 0.6874063173659117, 2360961.280721119, 2545292.0713050454, 0.9275797097464675, 4.817432116186043, 4.986892057865277, 0.9660189272771679, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 303.60996055003335, 326.9503560276805, 0.9286118058985349, 1322316.046120294, 2869089.6627579313, 0.4608834862446261, 6757.148088088034, 6109.177466759038, 1.1060651167615776, 2382.9818811648497, 5320.189651342192, 0.44791295749460075, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
# row_add_total: [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 261262.44125786104, 630696.7741084113, 0.41424413756863815, 36812288.46779047, 79544518.07092887, 0.4627885033506068, 3905009.609399187, 9440289.551811408, 0.41365358424306925, 1244.4270667316632, 3037.9389679412748, 0.4096287252192483, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
# df_eval_results BEFORW store results:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 10, -0.9997297078337037, 0.0, -inf, -12.274488186293105, 0.0, -inf, -21.989023107513656, 0.0, -inf, 0.5582097997840981, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.957912870935883, 0.0, -inf, -42.596723348682154, 0.0, -inf, -64.24145543043967, 0.0, -inf, 0.6630722025718373, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 1.7870828262729146, 3.2610319098843514, 0.5480114502578699, 65.2844173949555, 114.45001783590857, 0.5704185864658955, 37.10646649758617, 71.07790612135433, 0.5220534554610081, 1.4079203878852316, 0.2829814023820566, 4.975310660113209, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 1349086122.2998981, 1349086123.2287364, 0.9999999993115056, 342619431298.43427, 342619431338.6021, 0.9999999998827624, 11841778600.463018, 11841778642.89084, 0.9999999964171074, 14.939919263994382, 13.993186333110541, 1.0676567086542463, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 24.800007482988136, 33.89281464901524, 0.7317187356615336, 25899754.26951271, 57909368.43574564, 0.4472463604615242, 1769.800244480148, 2817.7744728136754, 0.628084419656525, 3357.4736783555813, 7503.228676046757, 0.4474705254651177, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 5335254498.520062, 10669600007.79833, 0.5000425971564599, 1.0669784507201054e+16, 2.1339562214506124e+16, 0.5000001593260422, 79344067452.11491, 158674317697.56372, 0.5000435395181356, 34858.28706627689, 52143.085222330876, 0.668512170264686, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 3, -0.9939626630368025, 0.0, -inf, -24.803586793734933, 0.0, -inf, -52.7057239865856, 0.0, -inf, 0.4706051813280815, 0.0, inf, 3.0057094148884618, 1684.79230674888, 449.3678082695133, 3.7492501148155397]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 11, 332.6429098251804, 0.0, inf, 23574.269207853824, 0.0, inf, 8308.677116860503, 0.0, inf, 2.8373071761346216, 0.0, inf, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 9, -0.6775273204748977, 0.0, -inf, -32.513802442391615, 0.0, -inf, -35.872297603989296, 0.0, -inf, 0.9063763576374827, 0.0, inf, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 7, 41.75075633267711, 0.0, inf, 5290.5711685627475, 0.0, inf, 1860.3425860599195, 0.0, inf, 2.8438693003141005, 0.0, inf, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 6, 196996.6710303219, 206244.7397746814, 0.9551597352036088, 23110979.702880207, 33620551.803247474, 0.6874063173659117, 2360961.280721119, 2545292.0713050454, 0.9275797097464675, 4.817432116186043, 4.986892057865277, 0.9660189272771679, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 5, 303.60996055003335, 326.9503560276805, 0.9286118058985349, 1322316.046120294, 2869089.6627579313, 0.4608834862446261, 6757.148088088034, 6109.177466759038, 1.1060651167615776, 2382.9818811648497, 5320.189651342192, 0.44791295749460075, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60, 120]', 4, 20, 0, 10, 4, 261262.44125786104, 630696.7741084113, 0.41424413756863815, 36812288.46779047, 79544518.07092887, 0.4627885033506068, 3905009.609399187, 9440289.551811408, 0.41365358424306925, 1244.4270667316632, 3037.9389679412748, 0.4096287252192483, 13.18543836539385, 115415.79593422274, 1613.3572178762656, 71.5376574111403]
#
# Save results to: test_df_eval
# df_eval_results AFTER store results:
#     n_samples     days_lookbacks  days_eval  n_top_syms  syms_start  syms_end  sym_freq_cnt  grp(CAGR)_mean  grp(CAGR)_std  grp(CAGR)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  grp(CAGR/retnStd)_mean  grp(CAGR/retnStd)_std  grp(CAGR/retnStd)_mean/std  grp(retnStd/UI)_mean  grp(retnStd/UI)_std  grp(retnStd/UI)_mean/std   SPY_CAGR    SPY_CAGR/UI  SPY_CAGR/retnStd  SPY_retnStd/UI
# 0           2  [15, 30, 60, 120]          4          20           0        10            10   -9.997297e-01   0.000000e+00                -inf      -1.227449e+01      0.000000e+00                 -inf          -2.198902e+01            0.000000e+00                   -inf                    0.558210              0.000000                  inf        3.005709    1684.792307        449.367808        3.749250
# 1           2  [15, 30, 60, 120]          4          20           0        10             9   -9.579129e-01   0.000000e+00                -inf      -4.259672e+01      0.000000e+00                 -inf          -6.424146e+01            0.000000e+00                   -inf                    0.663072              0.000000                  inf        3.005709    1684.792307        449.367808        3.749250
# 2           2  [15, 30, 60, 120]          4          20           0        10             7    1.787083e+00   3.261032e+00            0.548011       6.528442e+01      1.144500e+02             0.570419           3.710647e+01            7.107791e+01               0.522053                    1.407920              0.282981             4.975311        3.005709    1684.792307        449.367808        3.749250
# 3           2  [15, 30, 60, 120]          4          20           0        10             6    1.349086e+09   1.349086e+09            1.000000       3.426194e+11      3.426194e+11             1.000000           1.184178e+10            1.184178e+10               1.000000                   14.939919             13.993186             1.067657        3.005709    1684.792307        449.367808        3.749250
# 4           2  [15, 30, 60, 120]          4          20           0        10             5    2.480001e+01   3.389281e+01            0.731719       2.589975e+07      5.790937e+07             0.447246           1.769800e+03            2.817774e+03               0.628084                 3357.473678           7503.228676             0.447471        3.005709    1684.792307        449.367808        3.749250
# ..        ...                ...        ...         ...         ...       ...           ...             ...            ...                 ...                ...               ...                  ...                    ...                     ...                    ...                         ...                   ...                  ...             ...            ...               ...             ...
# 8           2  [15, 30, 60, 120]          4          20           0        10             9   -6.775273e-01   0.000000e+00                -inf      -3.251380e+01      0.000000e+00                 -inf          -3.587230e+01            0.000000e+00                   -inf                    0.906376              0.000000                  inf       13.185438  115415.795934       1613.357218       71.537657
# 9           2  [15, 30, 60, 120]          4          20           0        10             7    4.175076e+01   0.000000e+00                 inf       5.290571e+03      0.000000e+00                  inf           1.860343e+03            0.000000e+00                    inf                    2.843869              0.000000                  inf       13.185438  115415.795934       1613.357218       71.537657
# 10          2  [15, 30, 60, 120]          4          20           0        10             6    1.969967e+05   2.062447e+05            0.955160       2.311098e+07      3.362055e+07             0.687406           2.360961e+06            2.545292e+06               0.927580                    4.817432              4.986892             0.966019       13.185438  115415.795934       1613.357218       71.537657
# 11          2  [15, 30, 60, 120]          4          20           0        10             5    3.036100e+02   3.269504e+02            0.928612       1.322316e+06      2.869090e+06             0.460883           6.757148e+03            6.109177e+03               1.106065                 2382.981881           5320.189651             0.447913       13.185438  115415.795934       1613.357218       71.537657
# 12          2  [15, 30, 60, 120]          4          20           0        10             4    2.612624e+05   6.306968e+05            0.414244       3.681229e+07      7.954452e+07             0.462789           3.905010e+06            9.440290e+06               0.413654                 1244.427067           3037.938968             0.409629       13.185438  115415.795934       1613.357218       71.537657
#
# [13 rows x 23 columns]
