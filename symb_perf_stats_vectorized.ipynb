# %%
import pandas as pd
from myUtils import pickle_load, symb_perf_stats, symb_perf_stats_vectorized

# from symb_perf_stats_vectorized import symb_perf_stats_vectorized
# path_close = 'C:/Users/ping/Desktop/test/VSCode_dump/'
file_close = 'df_symbols_close'
path_dir = "C:/Users/ping/MyDrive/stocks/yfinance"
path_data_dump = path_dir + "/VSCode_dump/"

df_close = pickle_load(path_data_dump, file_close)
# df_close = df_close['2021-10-30':'2022-10-29']
df_close = df_close[-252::]
format1 = 'df_close({}):\n{}\n{}'.format(len(df_close), df_close.head(3), df_close.tail(3))
print(format1)

# %%
# %%timeit
caches_perf_stats = []
for symbol in df_close.columns:
    close = df_close[symbol].values
    date_first = df_close.index[0].strftime('%Y-%m-%d')
    date_last = df_close.index[-1].strftime('%Y-%m-%d')
    year, CAGR, CAGR_Std, CAGR_UI, return_std, Std_UI, DD, UI, MDD = symb_perf_stats(close)
#     print('symbol: {}'.format(symbol))
#     print('year: {:<10.6f}, CAGR: {:<10.6f}, CAGR_Std: {:<10.6f}, CAGR_UI: {:<10.6f}'
#           .format(year, CAGR, CAGR_Std, CAGR_UI))
#     print('return_std: {:<10.6f}, Std_UI: {:<10.6f}, UI: {:<10.6f}, MDD: {:<10.6f}'
#           .format(return_std, Std_UI, UI, MDD))
#     print('DD:\n{}\n{}\n{}\n{}\n'.format(DD[:3], DD[-3:], len(DD), type(DD)))
    cache = (symbol, date_first, date_last, year, CAGR,
             UI, Std_UI, CAGR_Std, CAGR_UI)
    # append performance data (tuple) to caches_perf_stats (list)
    caches_perf_stats.append(cache)
column_names = ['symbol', 'first date', 'last date', 'Year', 'CAGR',
                'UI', 'Std/UI', 'CAGR/Std', 'CAGR/UI']
# write symbols' performance stats to dataframe
df_perf_stats = pd.DataFrame(caches_perf_stats, columns=column_names)

# %%
print(df_perf_stats.head(), '\n')
print(df_perf_stats.tail())
# Out:
#   symbol  first date   last date  Year      CAGR        UI    Std/UI  \
# 0      A  2021-11-09  2022-11-08   1.0 -0.126221  0.197171  0.108500
# 1     AA  2021-11-09  2022-11-08   1.0 -0.078111  0.365037  0.113854
# 2   AADI  2021-11-09  2022-11-08   1.0 -0.500383  0.396811  0.107630
# 3   AAIN  2021-11-09  2022-11-08   1.0 -0.004454  0.029976  0.263045
# 4    AAL  2021-11-09  2022-11-08   1.0 -0.359838  0.300892  0.120503
#
#     CAGR/Std   CAGR/UI
# 0  -5.900131 -0.640162
# 1  -1.879427 -0.213979
# 2 -11.716117 -1.261011
# 3  -0.564831 -0.148576
# 4  -9.924244 -1.195905
#
#      symbol  first date   last date  Year      CAGR        UI    Std/UI  \
# 3645     ZS  2021-11-09  2022-11-08   1.0 -0.659879  0.465553  0.102376
# 3646    ZTO  2021-11-09  2022-11-08   1.0 -0.292701  0.203893  0.177895
# 3647    ZTS  2021-11-09  2022-11-08   1.0 -0.376944  0.275818  0.068802
# 3648   ZUMZ  2021-11-09  2022-11-08   1.0 -0.573867  0.398901  0.080644
# 3649    ZWS  2021-11-09  2022-11-08   1.0 -0.368541  0.215897  0.119504
#
#        CAGR/Std   CAGR/UI
# 3645 -13.845187 -1.417411
# 3646  -8.069724 -1.435566
# 3647 -19.863369 -1.366643
# 3648 -17.839203 -1.438619
# 3649 -14.284202 -1.707022

# %%
# %%timeit
symbols, period_yr, drawdown, UI, max_drawdown, returns_std, Std_UI, CAGR, CAGR_Std, CAGR_UI = \
    symb_perf_stats_vectorized(df_close)
caches_perf_stats_vect = []
for symbol in symbols:
    date_first = drawdown.index[0].strftime('%Y-%m-%d')
    date_last = drawdown.index[-1].strftime('%Y-%m-%d')
    cache = (symbol, date_first, date_last, period_yr, CAGR[symbol],
             UI[symbol], Std_UI[symbol], CAGR_Std[symbol], CAGR_UI[symbol])
    # append performance data (tuple) to caches_perf_stats (list)
    caches_perf_stats_vect.append(cache)
column_names = ['symbol', 'first date', 'last date', 'Year', 'CAGR',
                'UI', 'Std/UI', 'CAGR/Std', 'CAGR/UI']
# write symbols' performance stats to dataframe
df_perf_stats_vect = pd.DataFrame(caches_perf_stats_vect, columns=column_names)

# print('symbols({}):\n{}\n'.format(type(symbols), symbols))
# print('period_yr({}): {:<10.6f}\n'.format(type(period_yr), period_yr))  
# print('drawdown({}):\n{}\n'.format(type(drawdown), drawdown))
# print('UI({}):\n{}\n'.format(type(UI), UI))
# print('max_drawdown({}):\n{}\n'.format(type(max_drawdown), max_drawdown))
# print('returns_std({}):\n{}\n'.format(type(returns_std), returns_std))
# print('Std_UI({}):\n{}\n'.format(type(Std_UI), Std_UI))
# print('CAGR({}):\n{}\n'.format(type(CAGR), CAGR))
# print('CAGR_Std({}):\n{}\n'.format(type(CAGR_Std), CAGR_Std))
# print('CAGR_UI({}):\n{}\n'.format(type(CAGR_UI), CAGR_UI))
# print('CAGR["XOM"]: {}'.format(CAGR['XOM']))

# %%
print(f'df_perf_stats.head():\n{df_perf_stats.head()}\n')
print(f'df_perf_stats_vect.head():\n{df_perf_stats_vect.head()}\n')
print(f'df_perf_stats.tail():\n{df_perf_stats.tail()}\n')
print(f'df_perf_stats_vect.tail():\n{df_perf_stats_vect.tail()}\n')
# Out:
# df_perf_stats.head():
#   symbol  first date   last date  Year      CAGR        UI    Std/UI  \
# 0      A  2021-11-09  2022-11-08   1.0 -0.126221  0.197171  0.108500
# 1     AA  2021-11-09  2022-11-08   1.0 -0.078111  0.365037  0.113854
# 2   AADI  2021-11-09  2022-11-08   1.0 -0.500383  0.396811  0.107630
# 3   AAIN  2021-11-09  2022-11-08   1.0 -0.004454  0.029976  0.263045
# 4    AAL  2021-11-09  2022-11-08   1.0 -0.359838  0.300892  0.120503
#
#     CAGR/Std   CAGR/UI
# 0  -5.900131 -0.640162
# 1  -1.879427 -0.213979
# 2 -11.716117 -1.261011
# 3  -0.564831 -0.148576
# 4  -9.924244 -1.195905
#
# df_perf_stats_vect.head():
#   symbol  first date   last date  Year      CAGR        UI    Std/UI  \
# 0      A  2021-11-09  2022-11-08   1.0 -0.126221  0.197171  0.108500
# 1     AA  2021-11-09  2022-11-08   1.0 -0.078111  0.365037  0.113854
# 2   AADI  2021-11-09  2022-11-08   1.0 -0.500383  0.396811  0.107630
# 3   AAIN  2021-11-09  2022-11-08   1.0 -0.004454  0.029976  0.263045
# 4    AAL  2021-11-09  2022-11-08   1.0 -0.359838  0.300892  0.120503
#
#     CAGR/Std   CAGR/UI
# 0  -5.900131 -0.640162
# 1  -1.879427 -0.213979
# 2 -11.716117 -1.261011
# 3  -0.564831 -0.148576
# 4  -9.924244 -1.195905
#
# df_perf_stats.tail():
#      symbol  first date   last date  Year      CAGR        UI    Std/UI  \
# 3645     ZS  2021-11-09  2022-11-08   1.0 -0.659879  0.465553  0.102376
# 3646    ZTO  2021-11-09  2022-11-08   1.0 -0.292701  0.203893  0.177895
# 3647    ZTS  2021-11-09  2022-11-08   1.0 -0.376944  0.275818  0.068802
# 3648   ZUMZ  2021-11-09  2022-11-08   1.0 -0.573867  0.398901  0.080644
# 3649    ZWS  2021-11-09  2022-11-08   1.0 -0.368541  0.215897  0.119504
#
#        CAGR/Std   CAGR/UI
# 3645 -13.845187 -1.417411
# 3646  -8.069724 -1.435566
# 3647 -19.863369 -1.366643
# 3648 -17.839203 -1.438619
# 3649 -14.284202 -1.707022
#
# df_perf_stats_vect.tail():
#      symbol  first date   last date  Year      CAGR        UI    Std/UI  \
# 3645     ZS  2021-11-09  2022-11-08   1.0 -0.659879  0.465553  0.102376
# 3646    ZTO  2021-11-09  2022-11-08   1.0 -0.292701  0.203893  0.177895
# 3647    ZTS  2021-11-09  2022-11-08   1.0 -0.376944  0.275818  0.068802
# 3648   ZUMZ  2021-11-09  2022-11-08   1.0 -0.573867  0.398901  0.080644
# 3649    ZWS  2021-11-09  2022-11-08   1.0 -0.368541  0.215897  0.119504
#
#        CAGR/Std   CAGR/UI
# 3645 -13.845187 -1.417411
# 3646  -8.069724 -1.435566
# 3647 -19.863369 -1.366643
# 3648 -17.839203 -1.438619
# 3649 -14.284202 -1.707022

# %%
df_perf_stats_vect.head(50)
# Out:
#    symbol  first date   last date  Year      CAGR        UI    Std/UI  \
# 0       A  2021-11-09  2022-11-08   1.0 -0.126221  0.197171  0.108500
# 1      AA  2021-11-09  2022-11-08   1.0 -0.078111  0.365037  0.113854
# 2    AADI  2021-11-09  2022-11-08   1.0 -0.500383  0.396811  0.107630
# 3    AAIN  2021-11-09  2022-11-08   1.0 -0.004454  0.029976  0.263045
# 4     AAL  2021-11-09  2022-11-08   1.0 -0.359838  0.300892  0.120503
# 5    AAMC  2021-11-09  2022-11-08   1.0       NaN  0.239109  0.254974
# 6     AAN  2021-11-09  2022-11-08   1.0 -0.606608  0.364415  0.096836
# 7    AAON  2021-11-09  2022-11-08   1.0 -0.019118  0.292420  0.082652
# 8     AAP  2021-11-09  2022-11-08   1.0 -0.190914  0.181553  0.117939
# 9    AAPL  2021-11-09  2022-11-08   1.0 -0.069627  0.140062  0.154256
# 10    AAT  2021-11-09  2022-11-08   1.0 -0.273299  0.187086  0.092333
# 11   AAWW  2021-11-09  2022-11-08   1.0  0.188695  0.187431  0.117746
# 12     AB  2021-11-09  2022-11-08   1.0 -0.293299  0.212948  0.104234
# 13    ABB  2021-11-09  2022-11-08   1.0 -0.147826  0.206484  0.094347
# 14   ABBV  2021-11-09  2022-11-08   1.0  0.334805  0.117431  0.121587
# 15    ABC  2021-11-09  2022-11-08   1.0  0.297507  0.088008  0.169221
# 16   ABCB  2021-11-09  2022-11-08   1.0 -0.044308  0.163005  0.125122
# 17   ABCL  2021-11-09  2022-11-08   1.0 -0.167913  0.382620  0.116176
# 18   ABCM  2021-11-09  2022-11-08   1.0 -0.350756  0.315537  0.081133
# 19    ABG  2021-11-09  2022-11-08   1.0 -0.098000  0.147174  0.216398
# 20    ABM  2021-11-09  2022-11-08   1.0 -0.065437  0.151785  0.152833
# 21   ABMD  2021-11-09  2022-11-08   1.0  0.007136  0.238752  0.180342
# 22   ABNB  2021-11-09  2022-11-08   1.0 -0.491987  0.367248  0.105445
# 23    ABR  2021-11-09  2022-11-08   1.0 -0.210708  0.178073  0.120912
# 24   ABST  2021-11-09  2022-11-08   1.0 -0.057113  0.208394  0.158922
# 25    ABT  2021-11-09  2022-11-08   1.0 -0.198671  0.191637  0.085830
# 26     AC  2021-11-09  2022-11-08   1.0  0.055047  0.139653  0.164367
# 27    ACA  2021-11-09  2022-11-08   1.0  0.017408  0.118613  0.204280
# 28   ACAB  2021-11-09  2022-11-08   1.0       NaN  0.003535  0.523170
# 29   ACAD  2021-11-09  2022-11-08   1.0 -0.290681  0.311102  0.147812
# 30   ACAQ  2021-11-09  2022-11-08   1.0       NaN  0.003480  0.516107
# 31   ACBA  2021-11-09  2022-11-08   1.0  0.042079  0.001860  0.548948
# 32   ACCD  2021-11-09  2022-11-08   1.0 -0.763864  0.644891  0.108850
# 33   ACDI  2021-11-09  2022-11-08   1.0       NaN  0.003481  0.529122
# 34   ACET  2021-11-09  2022-11-08   1.0  1.077586  0.260676  0.219122
# 35   ACEV  2021-11-09  2022-11-08   1.0  0.039117  0.007315  0.421092
# 36   ACGL  2021-11-09  2022-11-08   1.0  0.373632  0.067578  0.263595
# 37   ACHC  2021-11-09  2022-11-08   1.0  0.235193  0.093158  0.244416
# 38    ACI  2021-11-09  2022-11-08   1.0 -0.172706  0.200931  0.132312
# 39   ACIW  2021-11-09  2022-11-08   1.0 -0.385047  0.235273  0.104850
# 40   ACLS  2021-11-09  2022-11-08   1.0  0.125201  0.225600  0.190116
# 41   ACLX  2021-11-09  2022-11-08   1.0       NaN  0.242170  0.240924
# 42    ACM  2021-11-09  2022-11-08   1.0  0.084873  0.099544  0.187603
# 43    ACN  2021-11-09  2022-11-08   1.0 -0.257898  0.253737  0.079575
# 44   ACNB  2021-11-09  2022-11-08   1.0  0.363691  0.068817  0.235997
# 45   ACNT  2021-11-09  2022-11-08   1.0  0.179134  0.172054  0.177686
# 46   ACRE  2021-11-09  2022-11-08   1.0 -0.170243  0.150913  0.139400
# 47   ACRS  2021-11-09  2022-11-08   1.0  0.042444  0.186849  0.236478
# 48    ACT  2021-11-09  2022-11-08   1.0  0.232498  0.086601  0.233116
# 49    ACU  2021-11-09  2022-11-08   1.0 -0.341307  0.181767  0.124395
#
#      CAGR/Std    CAGR/UI
# 0   -5.900131  -0.640162
# 1   -1.879427  -0.213979
# 2  -11.716117  -1.261011
# 3   -0.564831  -0.148576
# 4   -9.924244  -1.195905
# 5         NaN        NaN
# 6  -17.189987  -1.664608
# 7   -0.791022  -0.065380
# 8   -8.916153  -1.051564
# 9   -3.222642  -0.497113
# 10 -15.821295  -1.460820
# 11   8.550116   1.006746
# 12 -13.213747  -1.377326
# 13  -7.588198  -0.715921
# 14  23.449007   2.851087
# 15  19.976511   3.380453
# 16  -2.172411  -0.271817
# 17  -3.777453  -0.438850
# 18 -13.701184  -1.111614
# 19  -3.077093  -0.665877
# 20  -2.820838  -0.431117
# 21   0.165736   0.029889
# 22 -12.704775  -1.339659
# 23  -9.786225  -1.183269
# 24  -1.724521  -0.274064
# 25 -12.078546  -1.036706
# 26   2.398132   0.394173
# 27   0.718438   0.146762
# 28        NaN        NaN
# 29  -6.321276  -0.934360
# 30        NaN        NaN
# 31  41.209472  22.621864
# 32 -10.881832  -1.184485
# 33        NaN        NaN
# 34  18.865379   4.133811
# 35  12.699405   5.347620
# 36  20.974922   5.528880
# 37  10.329365   2.524665
# 38  -6.496218  -0.859529
# 39 -15.608984  -1.636599
# 40   2.919111   0.554969
# 41        NaN        NaN
# 42   4.544813   0.852621
# 43 -12.772826  -1.016400
# 44  22.393926   5.284895
# 45   5.859494   1.041149
# 46  -8.092465  -1.128089
# 47   0.960573   0.227154
# 48  11.516544   2.684691
# 49 -15.094751  -1.877718
