# %%
def top_set_sym_freq_cnt(top_set_syms_n_freq):
    # accommodate upto 5 periods of days_lookbacks(i.e. days_lookbacks = [5, 10, 15, 20, 25], len(days_lookbacks)*3 = 15)
    sym_freq_cnt_15 = []
    sym_freq_cnt_14 = []
    sym_freq_cnt_13 = []
    sym_freq_cnt_12 = []
    sym_freq_cnt_11 = []
    sym_freq_cnt_10 = []
    sym_freq_cnt_9 = []
    sym_freq_cnt_8 = []
    sym_freq_cnt_7 = []
    sym_freq_cnt_6 = []
    sym_freq_cnt_5 = []
    sym_freq_cnt_4 = []
    sym_freq_cnt_3 = []
    sym_freq_cnt_2 = []

    for sym_n_freq in top_set_syms_n_freq:
        _sym = sym_n_freq[0]
        _freq = sym_n_freq[1]
        if _freq == 15:
            sym_freq_cnt_15.append(_sym)
        elif _freq == 14:
            sym_freq_cnt_14.append(_sym)
        elif _freq == 13:
            sym_freq_cnt_13.append(_sym)
        elif _freq == 12:
            sym_freq_cnt_12.append(_sym)                        
        elif _freq == 11:
            sym_freq_cnt_11.append(_sym)
        elif _freq == 10:
            sym_freq_cnt_10.append(_sym)            
        elif _freq == 9:
            sym_freq_cnt_9.append(_sym)
        elif _freq == 8:
            sym_freq_cnt_8.append(_sym)
        elif _freq == 7:
            sym_freq_cnt_7.append(_sym)  
        elif _freq == 6:
            sym_freq_cnt_6.append(_sym)
        elif _freq == 5:
            sym_freq_cnt_5.append(_sym)
        elif _freq == 4:
            sym_freq_cnt_4.append(_sym)
        elif _freq == 3:
            sym_freq_cnt_3.append(_sym)          
        else:
            sym_freq_cnt_2.append(_sym)

    l_sym_freq_cnt = []

    l_sym_freq_cnt.append(sym_freq_cnt_15)
    l_sym_freq_cnt.append(sym_freq_cnt_14)
    l_sym_freq_cnt.append(sym_freq_cnt_13)
    l_sym_freq_cnt.append(sym_freq_cnt_12)    
    l_sym_freq_cnt.append(sym_freq_cnt_11)   
    l_sym_freq_cnt.append(sym_freq_cnt_10)
    l_sym_freq_cnt.append(sym_freq_cnt_9)
    l_sym_freq_cnt.append(sym_freq_cnt_8)
    l_sym_freq_cnt.append(sym_freq_cnt_7)    
    l_sym_freq_cnt.append(sym_freq_cnt_6)
    l_sym_freq_cnt.append(sym_freq_cnt_5)
    l_sym_freq_cnt.append(sym_freq_cnt_4)
    l_sym_freq_cnt.append(sym_freq_cnt_3)    
    l_sym_freq_cnt.append(sym_freq_cnt_2)    

    return l_sym_freq_cnt

# %%
import pandas as pd
# import numpy as np
import datetime
# from IPython.display import display, HTML
from yf_utils import _2_split_train_val_test, _3_random_slices, _4_lookback_slices
from yf_utils import _5_perf_ranks, _6_grp_tuples_sort_sum
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 16)
pd.set_option('display.width', 790)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = 'df_close_clean'

# %% [markdown]
# #### Check run results

# %%
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_train)
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_validate)
# df = pickle_load(path_data_dump, fp_df_eval_results)
# df = pickle_load(path_data_dump, fp_df_picks)
# df

# %% [markdown]
# #### Select run parameters. Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb

# %%
# SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
store_results = False
# store_results = True

# select run type
# run_type = 'train'
# run_type = 'validate'
run_type = 'test'
# run_type = 'current'

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms 
# n_samples = 400  
# n_samples = 20
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
days_lookbacks = [15, 30]
# days_lookbacks = [30, 60, 120]
# days_lookbacks = [15, 30, 60, 120]
days_lookbacks.sort()

# number of days in dataframe to evaluate effectiveness of the training, days_eval = len(df_eval)
#  days_eval = 4 means buy at close on 1st day after the signal, hold for 2nd and 3rd day, sell at close on 4th day
days_eval = 4
# days_eval = 5

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20  

# slice starts and ends for selecting the best performing symbols
syms_start = 0
syms_end = 10

# get picks of previous days by dropping the last n rows from df_current
#  drop_last_n_rows = 1 drops the last row from df_current
drop_last_n_rows = 0

# over-ride parameters for run_type 'current'
if run_type == 'current':
  days_eval = 0  # no need to eval, df_eval will be empty
  n_samples = 1  # no need to repeat sample the current result, repeat sample will yield the same tuple


fp_df_eval_results = f'df_eval_results_{run_type}'
fp_df_picks = f'df_picks'

print(f'verbose : {verbose }')
print(f'store_results: {store_results}')
print(f'run_type: {run_type}')
print(f'n_samples: {n_samples}')
print(f'days_lookbacks: {days_lookbacks}')
print(f'days_eval: {days_eval}')
print(f'n_top_syms: {n_top_syms}')
print(f'syms_start: {syms_start}')
print(f'syms_end: {syms_end}')
print(f'fp_df_eval_results: {fp_df_eval_results}')
print(f'fp_df_picks: {fp_df_picks}')
# Out:
# verbose : True
# store_results: False
# run_type: test
# n_samples: 20
# days_lookbacks: [15, 30]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10
# fp_df_eval_results: df_eval_results_test
# fp_df_picks: df_picks

# %% [markdown]
# #### Load previous run results

# %%
if run_type != 'current':
  df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)

df_picks = pickle_load(path_data_dump, fp_df_picks)
df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# %% [markdown]
# #### Drop the last n row in df_close_clean to get previous picks

# %%
# # drop the last n row(s)
# n = 1
# df_close_clean = df_close_clean[:-n]
# df_close_clean.tail(2)

# %% [markdown]
# #### Split dataframe into Train, Validate and Test

# %%
# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = _2_split_train_val_test(df_close_clean)

# %% [markdown]
# #### Create df_current, a df with the latest data

# %%
max_days_lookbacks = max(days_lookbacks)
print(f'max_days_lookbacks: {max_days_lookbacks}')


# df_current = df_test.tail(max_days_lookbacks)  
df_current = df_test.copy()

# df_current.tail(3)
# Out:
# max_days_lookbacks: 30

# %% [markdown]
# #### Load df according to run_type

# %%
if run_type == 'train':
  df = df_train.copy()    
elif run_type == 'validate':
  df = df_val.copy()
elif run_type == 'test':
  df = df_test.copy()
elif run_type == 'current':  # get the current picks
  print(f'run_type: current')
  slice_start = -(max_days_lookbacks + drop_last_n_rows)  
  slice_end = -drop_last_n_rows
  if drop_last_n_rows == 0:  # return df with all rows
    df = df_current[slice_start:].copy()
  else:  # return df with dropped drop_last_n_rows rows  
    df = df_current[slice_start:slice_end].copy()            
  print(f'dropped last {drop_last_n_rows} row(s) from df')          
  print(f'df.tail():\n{df.tail()}\n')
else:
  msg_stop = f"ERROR run_type must be 'train', 'validate', 'test' or 'current', run_type is: {run_type}"
  raise SystemExit(msg_stop )

# %% [markdown]
# #### Print dataframe for the run, and lengths of other dataframes

# %%
print(f'run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n')
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
len_df_current = len(df_current)
print(f'run_type: {run_type}, len(df): {len(df)}')
print(f'len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}, len_df_current: {len_df_current} ')
# Out:
# run_type: test, df.tail(3):
#                      A         AA    AAL         AAP        AAPL         AB        ABB        ABBV         ABC    ABM    ABR        ABT       ACGL       ACHC       ACIW  ...       XRAY    XRX        XYL       YELP       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                      ...
# 2023-03-22  133.729996  40.060001  13.82  113.599998  157.830002  33.930000  33.119999  153.669998  153.440002  43.02  11.14  96.860001  65.870003  69.800003  25.570000  ...  36.380001  14.85  97.570000  29.860001  62.520000  29.540001  125.389999  288.109985  73.790001  41.270000  30.120001  28.270000  161.380005  17.920000  20.270000
# 2023-03-23  131.130005  40.230000  13.63  111.139999  158.929993  33.669998  33.380001  155.300003  150.929993  42.43  10.84  97.040001  65.599998  69.440002  24.959999  ...  36.759998  14.56  97.230003  29.940001  63.830002  30.129999  124.959999  288.750000  74.410004  42.470001  27.450001  28.540001  161.240005  17.490000  19.790001
# 2023-03-24  131.960007  40.080002  13.72  110.830002  160.250000  33.490002  32.750000  158.020004  156.410004  43.43  11.11  98.050003  66.050003  70.160004  25.270000  ...  37.250000  14.63  98.589996  30.040001  61.680000  29.959999  126.040001  288.730011  75.209999  42.560001  28.250000  28.510000  164.179993  17.620001  19.850000
#
# [3 rows x 1322 columns]
#
# run_type: test, len(df): 150
# len_df_train: 1050, len_df_val: 300, len_df_test: 150, len_df_current: 150

# %% [markdown]
# #### Create a sets of iloc lookback slices (iloc_start_train:iloc_end_train:iloc_end_eval), where:
# * iloc_end_train - iloc_start_train = days_lookback
# * iloc_end_eval - iloc_end_train = days_eval
# #### for example, if given:
# * n_samples = 2
# * days_lookbacks = [10, 20, 30]
# * days_eval = 5
# #### a possible result is:
#   - max_lookback_slices: [(417, 447, 452), (265, 295, 300)], where:
#     - len(max_lookback_slices) = n_samples = 2
#     - middle number in the tuples, 447 and 295, is the iloc of the "pivot day" for the days in "days_lookbacks" to lookback
#     - 447 - 417 = middle number - first number = max(days_lookbacks) = 30
#     - 295 - 265 = middle number - first number = max(days_lookbacks) = 30
#     - 452 - 447 = last number - middle number = days_eval = 5
#     - 300 - 295 = last number - middle number = days_eval = 5
#   - sets_lookback_slices: [[(437, 447, 452), (427, 447, 452), (417, 447, 452)], [(285, 295, 300), (275, 295, 300), (265, 295, 300)]], where:
#     - len(sets_lookback_slices) = n_samples = 2
#     - last tuple in each list, i.e. (417, 447, 452) and (265, 295, 300), is a tuple from max_lookback_slices
#     - where a set, e.g. [(437, 447, 452), (427, 447, 452), (417, 447, 452)]:
#       - middle number, 447, iloc of the "pivot day" is constant for that set
#       - middle number - first number, is the training period specified in days_lookbacks
#         - 447 - 437 = middle number - first number = days_lookbacks[0] = 10
#         - 447 - 427 = middle number - first number = days_lookbacks[1] = 20
#         - 447 - 417 = middle number - first number = days_lookbacks[2] = 30
#       - last number, 452, iloc of the end of the evaluation period is constant
#         - 452 - 447 = last number - middle number = days_eval = 5

# %%
# return n_samples slices
max_lookback_slices = _3_random_slices(len_df, n_samples=n_samples, days_lookback=max(days_lookbacks), days_eval=days_eval, verbose=False)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = _4_lookback_slices(max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False)

if verbose:
  print(f'number of max_lookback_slices is equal to n_samples = {n_samples}')
  print(f'max_lookback_slices:\n{max_lookback_slices}\n')
  print(f'days_lookbacks: {days_lookbacks}')  
  print(f'sets_lookback_slices:\n{sets_lookback_slices}\n')
  print(f'number of sets in sets_lookback_slices is equal to n_samples = {n_samples}')
  print(f'number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): {len(days_lookbacks)}')
# Out:
# number of max_lookback_slices is equal to n_samples = 20
# max_lookback_slices:
# [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# days_lookbacks: [15, 30]
# sets_lookback_slices:
# [[(126, 141, 145), (111, 141, 145)], [(111, 126, 130), (96, 126, 130)], [(78, 93, 97), (63, 93, 97)], [(59, 74, 78), (44, 74, 78)], [(119, 134, 138), (104, 134, 138)], [(65, 80, 84), (50, 80, 84)], [(117, 132, 136), (102, 132, 136)], [(94, 109, 113), (79, 109, 113)], [(22, 37, 41), (7, 37, 41)], [(35, 50, 54), (20, 50, 54)], [(49, 64, 68), (34, 64, 68)], [(102, 117, 121), (87, 117, 121)], [(124, 139, 143), (109, 139, 143)], [(78, 93, 97), (63, 93, 97)], [(123, 138, 142), (108, 138, 142)], [(28, 43, 47), (13, 43, 47)], [(19, 34, 38), (4, 34, 38)], [(119, 134, 138), (104, 134, 138)], [(76, 91, 95), (61, 91, 95)], [(124, 139, 143), (109, 139, 143)]]
#
# number of sets in sets_lookback_slices is equal to n_samples = 20
# number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): 2

# %% [markdown]
# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the max_lookback_slices. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in max_lookback_slices. There are as many sub-lists as there are tuples in max_lookback_slices.

# %%
# grp_top_set_syms_n_freq is a list of lists of top_set_syms_n_freq, e.g.
#   [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)],
#    [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
#   where each list is the best performing symbols from a lb_slices, e.g.
#     [(483, 513, 523), (453, 513, 523), (393, 513, 523)]  
grp_top_set_syms_n_freq = []  # list of lists of top_set_symbols_n_freq, there are n_samples lists in list
grp_top_set_syms = []  # grp_top_set_syms_n_freq without the frequency count

# lb_slices, e.g  [(483, 513, 523), (453, 513, 523), (393, 513, 523)],
#  is one max_lookback_slice, e.g. (393, 513, 523), along with
#  the remaining slices of the days_lookbacks, e.g. (483, 513, 523), (453, 513, 523)  
for i, lb_slices in enumerate(sets_lookback_slices):
  print(f'\n########## {i + 1} of {len(sets_lookback_slices)} lb_slices in sets_lookcak_slices ##########')
  # unsorted list of the most frequent symbols in performance metrics of the lb_slices  
  grp_most_freq_syms = []
  for j, lb_slice in enumerate(lb_slices):  # lb_slice, e.g. (246, 276, 286)
    iloc_start_train = lb_slice[0]     # iloc of start of training period
    iloc_end_train   = lb_slice[1]     # iloc of end of training period
    iloc_start_eval  = iloc_end_train  # iloc of start of evaluation period
    iloc_end_eval    = lb_slice[2]     # iloc of end of evaluation period
    lookback         = iloc_end_train - iloc_start_train
    d_eval           = iloc_end_eval - iloc_start_eval

    _df = df.iloc[iloc_start_train:iloc_end_train]
    date_start_df_train = _df.index[0].strftime('%Y-%m-%d')
    date_end_df_train = _df.index[-1].strftime('%Y-%m-%d')

    if verbose:
      print(f'days lookback:       {lookback},  {j + 1} of {len(days_lookbacks)} days_lookbacks: {days_lookbacks}')
      print(f'lb_slices:           {lb_slices}')
      print(f'lb_slice:            {lb_slice}')
      print(f'days eval:           {d_eval}')    
      print(f'iloc_start_train:    {iloc_start_train}')
      print(f'iloc_end_train:      {iloc_end_train}')
      print(f'date_start_df_train: {date_start_df_train}')
      print(f'date_end_df_train:   {date_end_df_train}')


    perf_ranks, most_freq_syms = _5_perf_ranks(_df, n_top_syms=n_top_syms)
    # unsorted list of the most frequent symbols in performance metrics of the lb_slices  
    grp_most_freq_syms.append(most_freq_syms)  
    if verbose:    
      # 1 lookback of r_CAGR/UI, r_CAGR/retnStd, r_retnStd/UI
      print(f'perf_ranks: {perf_ranks}')  
      # most common symbols of perf_ranks 
      print(f'most_freq_syms: {most_freq_syms}')     
      # grp_perf_ranks[lookback] = perf_ranks
      print(f'+++ finish lookback slice {lookback} +++\n')

  if verbose:
    print(f'grp_most_freq_syms: {grp_most_freq_syms}')
    # grp_most_freq_syms a is list of lists of tuples of 
    #  the most-common-symbols symbol:frequency cumulated from
    #  each days_lookback  
    print(f'**** finish lookback slices {lb_slices} ****\n')

  # flatten list of lists of (symbol:frequency)
  flat_grp_most_freq_syms = [val for sublist in grp_most_freq_syms for val in sublist]
  # return "symbol, frequency" pairs of the most frequent symbols, i.e. best performing symbols,
  #  in flat_grp_most_freq_syms. The paris are sorted in descending frequency.   
  set_most_freq_syms = _6_grp_tuples_sort_sum(flat_grp_most_freq_syms, reverse=True)
  # get the top n_top_syms of the most frequent "symbol, frequency" pairs
  top_set_syms_n_freq = set_most_freq_syms[0:n_top_syms]
  # get symbols from top_set_syms_n_freq, i[0] = symbol, i[1]=symbol's frequency count
  top_set_syms = [i[0] for i in top_set_syms_n_freq[syms_start:syms_end]]  

  # grp_top_set_syms_n_freq is a list of lists of top_set_syms_n_freq, e.g.
  #   [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)],
  #    [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
  #   where each list is the best performing symbols from a lb_slices, e.g.
  #     [(483, 513, 523), (453, 513, 523), (393, 513, 523)]    
  grp_top_set_syms_n_freq.append(top_set_syms_n_freq)
  grp_top_set_syms.append(top_set_syms)

  if verbose:  
    print(f'top {n_top_syms} ranked symbols and frequency from set {lb_slices}:\n{top_set_syms_n_freq}')
    print(f'top {n_top_syms} ranked symbols from set {lb_slices}:\n{top_set_syms}')  
    print(f'===== finish top {n_top_syms} ranked symbols from days_lookback set {lb_slices} =====\n\n')
# Out:
# ########## 1 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(126, 141, 145), (111, 141, 145)]
# lb_slice:            (126, 141, 145)
# days eval:           4
# iloc_start_train:    126
# iloc_end_train:      141
# date_start_df_train: 2023-02-21
# date_end_df_train:   2023-03-13
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['HY', 'FSLR', 'SGEN', 'FCN', 'LNTH', 'SHV', 'DY', 'NTRA', 'ANET',
#        'ISEE', 'MYGN', 'MLR', 'SRPT', 'JYNT', 'GE', 'FTSM', 'TNK', 'AXON',
#        'DQ', 'PCH'], dtype=object), 'r_CAGR/retnStd': array(['HY', 'FSLR', 'SGEN', 'FCN', 'LNTH', 'DY', 'MYGN', 'ISEE', 'NTRA',
#        'DQ', 'SRPT', 'TNK', 'ANET', 'JYNT', 'SHV', 'MLR', 'AXON', 'GE',
#        'AMPH', 'PCH'], dtype=object), 'r_retnStd/UI': array(['SHV', 'FCN', 'FSLR', 'FTSM', 'LNTH', 'SGEN', 'MLR', 'HY', 'ANET',
#        'GE', 'LAUR', 'PCH', 'JYNT', 'DY', 'IRBT', 'NVDA', 'AXON', 'NTRA',
#        'META', 'SSYS'], dtype=object)}}
# most_freq_syms: [('HY', 3), ('FSLR', 3), ('SGEN', 3), ('FCN', 3), ('LNTH', 3), ('SHV', 3), ('DY', 3), ('NTRA', 3), ('ANET', 3), ('MLR', 3), ('JYNT', 3), ('GE', 3), ('AXON', 3), ('PCH', 3), ('ISEE', 2), ('MYGN', 2), ('SRPT', 2), ('FTSM', 2), ('TNK', 2), ('DQ', 2), ('AMPH', 1), ('LAUR', 1), ('IRBT', 1), ('NVDA', 1), ('META', 1), ('SSYS', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(126, 141, 145), (111, 141, 145)]
# lb_slice:            (111, 141, 145)
# days eval:           4
# iloc_start_train:    111
# iloc_end_train:      141
# date_start_df_train: 2023-01-30
# date_end_df_train:   2023-03-13
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TA', 'TNK', 'SGEN', 'SHV', 'FCN', 'TNP', 'FTSM', 'HY', 'ATCO',
#        'LNTH', 'NTRA', 'ELF', 'STNG', 'WST', 'ANET', 'OEC', 'AMPH',
#        'PDFS', 'CTLT', 'FIZZ'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'TNK', 'SGEN', 'HY', 'TNP', 'STNG', 'FCN', 'NTRA', 'SHV',
#        'ANET', 'FTSM', 'WST', 'LNTH', 'OEC', 'ELF', 'CTLT', 'ASC', 'LSCC',
#        'PDFS', 'MPWR'], dtype=object), 'r_retnStd/UI': array(['TA', 'SHV', 'FTSM', 'ATCO', 'SGEN', 'FCN', 'LNTH', 'TNK', 'AMPH',
#        'ELF', 'PDFS', 'FIZZ', 'TNP', 'SRPT', 'LMT', 'EURN', 'WST', 'NVDA',
#        'EME', 'PWR'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('TNK', 3), ('SGEN', 3), ('SHV', 3), ('FCN', 3), ('TNP', 3), ('FTSM', 3), ('LNTH', 3), ('ELF', 3), ('WST', 3), ('PDFS', 3), ('HY', 2), ('ATCO', 2), ('NTRA', 2), ('STNG', 2), ('ANET', 2), ('OEC', 2), ('AMPH', 2), ('CTLT', 2), ('FIZZ', 2), ('ASC', 1), ('LSCC', 1), ('MPWR', 1), ('SRPT', 1), ('LMT', 1), ('EURN', 1), ('NVDA', 1), ('EME', 1), ('PWR', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('HY', 3), ('FSLR', 3), ('SGEN', 3), ('FCN', 3), ('LNTH', 3), ('SHV', 3), ('DY', 3), ('NTRA', 3), ('ANET', 3), ('MLR', 3), ('JYNT', 3), ('GE', 3), ('AXON', 3), ('PCH', 3), ('ISEE', 2), ('MYGN', 2), ('SRPT', 2), ('FTSM', 2), ('TNK', 2), ('DQ', 2), ('AMPH', 1), ('LAUR', 1), ('IRBT', 1), ('NVDA', 1), ('META', 1), ('SSYS', 1)], [('TA', 3), ('TNK', 3), ('SGEN', 3), ('SHV', 3), ('FCN', 3), ('TNP', 3), ('FTSM', 3), ('LNTH', 3), ('ELF', 3), ('WST', 3), ('PDFS', 3), ('HY', 2), ('ATCO', 2), ('NTRA', 2), ('STNG', 2), ('ANET', 2), ('OEC', 2), ('AMPH', 2), ('CTLT', 2), ('FIZZ', 2), ('ASC', 1), ('LSCC', 1), ('MPWR', 1), ('SRPT', 1), ('LMT', 1), ('EURN', 1), ('NVDA', 1), ('EME', 1), ('PWR', 1)]]
# **** finish lookback slices [(126, 141, 145), (111, 141, 145)] ****
#
# top 20 ranked symbols and frequency from set [(126, 141, 145), (111, 141, 145)]:
# [('FCN', 6), ('LNTH', 6), ('SGEN', 6), ('SHV', 6), ('ANET', 5), ('FTSM', 5), ('HY', 5), ('NTRA', 5), ('TNK', 5), ('AMPH', 3), ('AXON', 3), ('DY', 3), ('ELF', 3), ('FSLR', 3), ('GE', 3), ('JYNT', 3), ('MLR', 3), ('PCH', 3), ('PDFS', 3), ('SRPT', 3)]
# top 20 ranked symbols from set [(126, 141, 145), (111, 141, 145)]:
# ['FCN', 'LNTH', 'SGEN', 'SHV', 'ANET', 'FTSM', 'HY', 'NTRA', 'TNK', 'AMPH']
# ===== finish top 20 ranked symbols from days_lookback set [(126, 141, 145), (111, 141, 145)] =====
#
#
#
# ########## 2 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(111, 126, 130), (96, 126, 130)]
# lb_slice:            (111, 126, 130)
# days eval:           4
# iloc_start_train:    111
# iloc_end_train:      126
# date_start_df_train: 2023-01-30
# date_end_df_train:   2023-02-17
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TA', 'AMCX', 'STNG', 'CTLT', 'ELF', 'GM', 'TNK', 'PAG', 'TNP',
#        'ASC', 'WIRE', 'AN', 'FCF', 'MMS', 'THR', 'SMG', 'OEC', 'CAR',
#        'MCFT', 'TSLA'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'AMCX', 'STNG', 'CTLT', 'TNK', 'SMG', 'PAG', 'AN', 'ELF',
#        'ASC', 'TNP', 'WIRE', 'TSLA', 'CAR', 'EBS', 'MCFT', 'THR', 'FCF',
#        'MPWR', 'OEC'], dtype=object), 'r_retnStd/UI': array(['TA', 'GM', 'MMS', 'ELF', 'ATCO', 'STNG', 'SFBS', 'CTLT', 'FCF',
#        'CINF', 'ALSN', 'KBR', 'ENS', 'MGM', 'PRGS', 'THR', 'OEC', 'STBA',
#        'ETN', 'FISV'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('STNG', 3), ('CTLT', 3), ('ELF', 3), ('FCF', 3), ('THR', 3), ('OEC', 3), ('AMCX', 2), ('GM', 2), ('TNK', 2), ('PAG', 2), ('TNP', 2), ('ASC', 2), ('WIRE', 2), ('AN', 2), ('MMS', 2), ('SMG', 2), ('CAR', 2), ('MCFT', 2), ('TSLA', 2), ('EBS', 1), ('MPWR', 1), ('ATCO', 1), ('SFBS', 1), ('CINF', 1), ('ALSN', 1), ('KBR', 1), ('ENS', 1), ('MGM', 1), ('PRGS', 1), ('STBA', 1), ('ETN', 1), ('FISV', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(111, 126, 130), (96, 126, 130)]
# lb_slice:            (96, 126, 130)
# days eval:           4
# iloc_start_train:    96
# iloc_end_train:      126
# date_start_df_train: 2023-01-06
# date_end_df_train:   2023-02-17
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TSLA', 'TA', 'RVNC', 'WIRE', 'CTLT', 'MARA', 'AMCX', 'SMG',
#        'EVRI', 'CRUS', 'CAR', 'NATI', 'OEC', 'ACLS', 'NVDA', 'AN', 'SHV',
#        'FATE', 'BTC-USD', 'THR'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'MARA', 'TA', 'RVNC', 'SMG', 'AMCX', 'WIRE', 'HUBS',
#        'CTLT', 'BTC-USD', 'AN', 'FATE', 'CAR', 'NVDA', 'ACLS', 'EVRI',
#        'PAG', 'TNK', 'CRUS', 'NATI'], dtype=object), 'r_retnStd/UI': array(['TA', 'SHV', 'OEC', 'FTSM', 'LRN', 'CTLT', 'CRUS', 'EVRI', 'NATI',
#        'FISV', 'WIRE', 'CIGI', 'NVGS', 'PDFS', 'BYD', 'RVNC', 'URI',
#        'EFR', 'TSLA', 'STX'], dtype=object)}}
# most_freq_syms: [('TSLA', 3), ('TA', 3), ('RVNC', 3), ('WIRE', 3), ('CTLT', 3), ('EVRI', 3), ('CRUS', 3), ('NATI', 3), ('MARA', 2), ('AMCX', 2), ('SMG', 2), ('CAR', 2), ('OEC', 2), ('ACLS', 2), ('NVDA', 2), ('AN', 2), ('SHV', 2), ('FATE', 2), ('BTC-USD', 2), ('THR', 1), ('HUBS', 1), ('PAG', 1), ('TNK', 1), ('FTSM', 1), ('LRN', 1), ('FISV', 1), ('CIGI', 1), ('NVGS', 1), ('PDFS', 1), ('BYD', 1), ('URI', 1), ('EFR', 1), ('STX', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('TA', 3), ('STNG', 3), ('CTLT', 3), ('ELF', 3), ('FCF', 3), ('THR', 3), ('OEC', 3), ('AMCX', 2), ('GM', 2), ('TNK', 2), ('PAG', 2), ('TNP', 2), ('ASC', 2), ('WIRE', 2), ('AN', 2), ('MMS', 2), ('SMG', 2), ('CAR', 2), ('MCFT', 2), ('TSLA', 2), ('EBS', 1), ('MPWR', 1), ('ATCO', 1), ('SFBS', 1), ('CINF', 1), ('ALSN', 1), ('KBR', 1), ('ENS', 1), ('MGM', 1), ('PRGS', 1), ('STBA', 1), ('ETN', 1), ('FISV', 1)], [('TSLA', 3), ('TA', 3), ('RVNC', 3), ('WIRE', 3), ('CTLT', 3), ('EVRI', 3), ('CRUS', 3), ('NATI', 3), ('MARA', 2), ('AMCX', 2), ('SMG', 2), ('CAR', 2), ('OEC', 2), ('ACLS', 2), ('NVDA', 2), ('AN', 2), ('SHV', 2), ('FATE', 2), ('BTC-USD', 2), ('THR', 1), ('HUBS', 1), ('PAG', 1), ('TNK', 1), ('FTSM', 1), ('LRN', 1), ('FISV', 1), ('CIGI', 1), ('NVGS', 1), ('PDFS', 1), ('BYD', 1), ('URI', 1), ('EFR', 1), ('STX', 1)]]
# **** finish lookback slices [(111, 126, 130), (96, 126, 130)] ****
#
# top 20 ranked symbols and frequency from set [(111, 126, 130), (96, 126, 130)]:
# [('CTLT', 6), ('TA', 6), ('OEC', 5), ('TSLA', 5), ('WIRE', 5), ('AMCX', 4), ('AN', 4), ('CAR', 4), ('SMG', 4), ('THR', 4), ('CRUS', 3), ('ELF', 3), ('EVRI', 3), ('FCF', 3), ('NATI', 3), ('PAG', 3), ('RVNC', 3), ('STNG', 3), ('TNK', 3), ('ACLS', 2)]
# top 20 ranked symbols from set [(111, 126, 130), (96, 126, 130)]:
# ['CTLT', 'TA', 'OEC', 'TSLA', 'WIRE', 'AMCX', 'AN', 'CAR', 'SMG', 'THR']
# ===== finish top 20 ranked symbols from days_lookback set [(111, 126, 130), (96, 126, 130)] =====
#
#
#
# ########## 3 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(78, 93, 97), (63, 93, 97)]
# lb_slice:            (78, 93, 97)
# days eval:           4
# iloc_start_train:    78
# iloc_end_train:      93
# date_start_df_train: 2022-12-09
# date_end_df_train:   2022-12-30
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['HZNP', 'ARWR', 'AGYS', 'BMA', 'CYTK', 'PBF', 'XPRO', 'MSGS',
#        'HAL', 'CCU', 'SHV', 'AVXL', 'HLF', 'BVH', 'ALGN', 'VLO', 'THS',
#        'CROX', 'SLB', 'AJRD'], dtype=object), 'r_CAGR/retnStd': array(['ARWR', 'CYTK', 'AGYS', 'BMA', 'PBF', 'XPRO', 'HAL', 'CCU', 'AVXL',
#        'MSGS', 'HLF', 'CLMT', 'KDNY', 'HZNP', 'SLB', 'THS', 'USO', 'PAR',
#        'ANGO', 'CROX'], dtype=object), 'r_retnStd/UI': array(['HZNP', 'SHV', 'AGYS', 'AJRD', 'MSGS', 'BVH', 'VLO', 'ALGN', 'PBF',
#        'ARWR', 'ALL', 'DGX', 'BMA', 'HAL', 'MPC', 'FTSM', 'CCU', 'CROX',
#        'TVTX', 'ACGL'], dtype=object)}}
# most_freq_syms: [('HZNP', 3), ('ARWR', 3), ('AGYS', 3), ('BMA', 3), ('PBF', 3), ('MSGS', 3), ('HAL', 3), ('CCU', 3), ('CROX', 3), ('CYTK', 2), ('XPRO', 2), ('SHV', 2), ('AVXL', 2), ('HLF', 2), ('BVH', 2), ('ALGN', 2), ('VLO', 2), ('THS', 2), ('SLB', 2), ('AJRD', 2), ('CLMT', 1), ('KDNY', 1), ('USO', 1), ('PAR', 1), ('ANGO', 1), ('ALL', 1), ('DGX', 1), ('MPC', 1), ('FTSM', 1), ('TVTX', 1), ('ACGL', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(78, 93, 97), (63, 93, 97)]
# lb_slice:            (63, 93, 97)
# days eval:           4
# iloc_start_train:    63
# iloc_end_train:      93
# date_start_df_train: 2022-11-17
# date_end_df_train:   2022-12-30
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['SHV', 'HZNP', 'RCM', 'AXSM', 'FTSM', 'BURL', 'NVO', 'ZTO', 'RARE',
#        'BVH', 'MSGS', 'CAG', 'ARWR', 'AMBC', 'BDX', 'EXC', 'AVA', 'KHC',
#        'CPB', 'ZBH'], dtype=object), 'r_CAGR/retnStd': array(['RCM', 'HZNP', 'AXSM', 'NVO', 'BMA', 'RARE', 'BURL', 'MSGS',
#        'ARWR', 'SHV', 'ZTO', 'FTSM', 'AVA', 'EDU', 'EXC', 'BDX', 'CCU',
#        'AMBC', 'ZBH', 'VCEL'], dtype=object), 'r_retnStd/UI': array(['SHV', 'BVH', 'FTSM', 'HZNP', 'AXSM', 'MMS', 'CAG', 'CPB', 'ZTO',
#        'BURL', 'ACGL', 'AJRD', 'RCM', 'SJW', 'KHC', 'TECK', 'AMBC', 'NVO',
#        'TOL', 'EXAS'], dtype=object)}}
# most_freq_syms: [('SHV', 3), ('HZNP', 3), ('RCM', 3), ('AXSM', 3), ('FTSM', 3), ('BURL', 3), ('NVO', 3), ('ZTO', 3), ('AMBC', 3), ('RARE', 2), ('BVH', 2), ('MSGS', 2), ('CAG', 2), ('ARWR', 2), ('BDX', 2), ('EXC', 2), ('AVA', 2), ('KHC', 2), ('CPB', 2), ('ZBH', 2), ('BMA', 1), ('EDU', 1), ('CCU', 1), ('VCEL', 1), ('MMS', 1), ('ACGL', 1), ('AJRD', 1), ('SJW', 1), ('TECK', 1), ('TOL', 1), ('EXAS', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('HZNP', 3), ('ARWR', 3), ('AGYS', 3), ('BMA', 3), ('PBF', 3), ('MSGS', 3), ('HAL', 3), ('CCU', 3), ('CROX', 3), ('CYTK', 2), ('XPRO', 2), ('SHV', 2), ('AVXL', 2), ('HLF', 2), ('BVH', 2), ('ALGN', 2), ('VLO', 2), ('THS', 2), ('SLB', 2), ('AJRD', 2), ('CLMT', 1), ('KDNY', 1), ('USO', 1), ('PAR', 1), ('ANGO', 1), ('ALL', 1), ('DGX', 1), ('MPC', 1), ('FTSM', 1), ('TVTX', 1), ('ACGL', 1)], [('SHV', 3), ('HZNP', 3), ('RCM', 3), ('AXSM', 3), ('FTSM', 3), ('BURL', 3), ('NVO', 3), ('ZTO', 3), ('AMBC', 3), ('RARE', 2), ('BVH', 2), ('MSGS', 2), ('CAG', 2), ('ARWR', 2), ('BDX', 2), ('EXC', 2), ('AVA', 2), ('KHC', 2), ('CPB', 2), ('ZBH', 2), ('BMA', 1), ('EDU', 1), ('CCU', 1), ('VCEL', 1), ('MMS', 1), ('ACGL', 1), ('AJRD', 1), ('SJW', 1), ('TECK', 1), ('TOL', 1), ('EXAS', 1)]]
# **** finish lookback slices [(78, 93, 97), (63, 93, 97)] ****
#
# top 20 ranked symbols and frequency from set [(78, 93, 97), (63, 93, 97)]:
# [('HZNP', 6), ('ARWR', 5), ('MSGS', 5), ('SHV', 5), ('BMA', 4), ('BVH', 4), ('CCU', 4), ('FTSM', 4), ('AGYS', 3), ('AJRD', 3), ('AMBC', 3), ('AXSM', 3), ('BURL', 3), ('CROX', 3), ('HAL', 3), ('NVO', 3), ('PBF', 3), ('RCM', 3), ('ZTO', 3), ('ACGL', 2)]
# top 20 ranked symbols from set [(78, 93, 97), (63, 93, 97)]:
# ['HZNP', 'ARWR', 'MSGS', 'SHV', 'BMA', 'BVH', 'CCU', 'FTSM', 'AGYS', 'AJRD']
# ===== finish top 20 ranked symbols from days_lookback set [(78, 93, 97), (63, 93, 97)] =====
#
#
#
# ########## 4 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(59, 74, 78), (44, 74, 78)]
# lb_slice:            (59, 74, 78)
# days eval:           4
# iloc_start_train:    59
# iloc_end_train:      74
# date_start_df_train: 2022-11-11
# date_end_df_train:   2022-12-02
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['HZNP', 'BBW', 'ENR', 'CTRN', 'BMRN', 'BURL', 'ROST', 'GIS', 'AZN',
#        'AEO', 'SRPT', 'ANF', 'SAGE', 'MRK', 'KHC', 'FLO', 'BTI', 'GSK',
#        'BERY', 'AZTA'], dtype=object), 'r_CAGR/retnStd': array(['BBW', 'CTRN', 'HZNP', 'BMRN', 'BURL', 'AEO', 'BIDU', 'ROST',
#        'BABA', 'ANF', 'CELH', 'SAGE', 'AXSM', 'ENR', 'SRPT', 'AZTA',
#        'CCRN', 'BERY', 'ETSY', 'ZTO'], dtype=object), 'r_retnStd/UI': array(['ENR', 'HZNP', 'AZN', 'GIS', 'AMPH', 'BMY', 'ROST', 'SHV', 'LMT',
#        'MGI', 'KHC', 'FTSM', 'BMRN', 'BBW', 'FLO', 'CPB', 'MRK', 'SRPT',
#        'PM', 'BTI'], dtype=object)}}
# most_freq_syms: [('HZNP', 3), ('BBW', 3), ('ENR', 3), ('BMRN', 3), ('ROST', 3), ('SRPT', 3), ('CTRN', 2), ('BURL', 2), ('GIS', 2), ('AZN', 2), ('AEO', 2), ('ANF', 2), ('SAGE', 2), ('MRK', 2), ('KHC', 2), ('FLO', 2), ('BTI', 2), ('BERY', 2), ('AZTA', 2), ('GSK', 1), ('BIDU', 1), ('BABA', 1), ('CELH', 1), ('AXSM', 1), ('CCRN', 1), ('ETSY', 1), ('ZTO', 1), ('AMPH', 1), ('BMY', 1), ('SHV', 1), ('LMT', 1), ('MGI', 1), ('FTSM', 1), ('CPB', 1), ('PM', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(59, 74, 78), (44, 74, 78)]
# lb_slice:            (44, 74, 78)
# days eval:           4
# iloc_start_train:    44
# iloc_end_train:      74
# date_start_df_train: 2022-10-21
# date_end_df_train:   2022-12-02
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['BBW', 'HZNP', 'BURL', 'AXSM', 'GILD', 'PRG', 'RUN', 'SPWR', 'AEO',
#        'GBX', 'UNVR', 'NEOG', 'UAA', 'NOMD', 'HEES', 'AXON', 'ACLS',
#        'ROST', 'APD', 'WYNN'], dtype=object), 'r_CAGR/retnStd': array(['AXSM', 'BURL', 'BBW', 'PRG', 'HZNP', 'SPWR', 'NEOG', 'AEO', 'RUN',
#        'UNVR', 'GBX', 'AXON', 'AMKR', 'UAA', 'WYNN', 'CTRN', 'GPS',
#        'HEES', 'ROST', 'ACLS'], dtype=object), 'r_retnStd/UI': array(['GILD', 'BVH', 'FTSM', 'SHV', 'QNST', 'UVV', 'HZNP', 'PTMN', 'BBW',
#        'ELF', 'PNM', 'GNL', 'APD', 'AIG', 'CHGG', 'TAK', 'NOMD', 'KRG',
#        'CCEP', 'FIVE'], dtype=object)}}
# most_freq_syms: [('BBW', 3), ('HZNP', 3), ('BURL', 2), ('AXSM', 2), ('GILD', 2), ('PRG', 2), ('RUN', 2), ('SPWR', 2), ('AEO', 2), ('GBX', 2), ('UNVR', 2), ('NEOG', 2), ('UAA', 2), ('NOMD', 2), ('HEES', 2), ('AXON', 2), ('ACLS', 2), ('ROST', 2), ('APD', 2), ('WYNN', 2), ('AMKR', 1), ('CTRN', 1), ('GPS', 1), ('BVH', 1), ('FTSM', 1), ('SHV', 1), ('QNST', 1), ('UVV', 1), ('PTMN', 1), ('ELF', 1), ('PNM', 1), ('GNL', 1), ('AIG', 1), ('CHGG', 1), ('TAK', 1), ('KRG', 1), ('CCEP', 1), ('FIVE', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('HZNP', 3), ('BBW', 3), ('ENR', 3), ('BMRN', 3), ('ROST', 3), ('SRPT', 3), ('CTRN', 2), ('BURL', 2), ('GIS', 2), ('AZN', 2), ('AEO', 2), ('ANF', 2), ('SAGE', 2), ('MRK', 2), ('KHC', 2), ('FLO', 2), ('BTI', 2), ('BERY', 2), ('AZTA', 2), ('GSK', 1), ('BIDU', 1), ('BABA', 1), ('CELH', 1), ('AXSM', 1), ('CCRN', 1), ('ETSY', 1), ('ZTO', 1), ('AMPH', 1), ('BMY', 1), ('SHV', 1), ('LMT', 1), ('MGI', 1), ('FTSM', 1), ('CPB', 1), ('PM', 1)], [('BBW', 3), ('HZNP', 3), ('BURL', 2), ('AXSM', 2), ('GILD', 2), ('PRG', 2), ('RUN', 2), ('SPWR', 2), ('AEO', 2), ('GBX', 2), ('UNVR', 2), ('NEOG', 2), ('UAA', 2), ('NOMD', 2), ('HEES', 2), ('AXON', 2), ('ACLS', 2), ('ROST', 2), ('APD', 2), ('WYNN', 2), ('AMKR', 1), ('CTRN', 1), ('GPS', 1), ('BVH', 1), ('FTSM', 1), ('SHV', 1), ('QNST', 1), ('UVV', 1), ('PTMN', 1), ('ELF', 1), ('PNM', 1), ('GNL', 1), ('AIG', 1), ('CHGG', 1), ('TAK', 1), ('KRG', 1), ('CCEP', 1), ('FIVE', 1)]]
# **** finish lookback slices [(59, 74, 78), (44, 74, 78)] ****
#
# top 20 ranked symbols and frequency from set [(59, 74, 78), (44, 74, 78)]:
# [('BBW', 6), ('HZNP', 6), ('ROST', 5), ('AEO', 4), ('BURL', 4), ('AXSM', 3), ('BMRN', 3), ('CTRN', 3), ('ENR', 3), ('SRPT', 3), ('ACLS', 2), ('ANF', 2), ('APD', 2), ('AXON', 2), ('AZN', 2), ('AZTA', 2), ('BERY', 2), ('BTI', 2), ('FLO', 2), ('FTSM', 2)]
# top 20 ranked symbols from set [(59, 74, 78), (44, 74, 78)]:
# ['BBW', 'HZNP', 'ROST', 'AEO', 'BURL', 'AXSM', 'BMRN', 'CTRN', 'ENR', 'SRPT']
# ===== finish top 20 ranked symbols from days_lookback set [(59, 74, 78), (44, 74, 78)] =====
#
#
#
# ########## 5 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(119, 134, 138), (104, 134, 138)]
# lb_slice:            (119, 134, 138)
# days eval:           4
# iloc_start_train:    119
# iloc_end_train:      134
# date_start_df_train: 2023-02-09
# date_end_df_train:   2023-03-02
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TA', 'SHV', 'HY', 'OEC', 'SGEN', 'TNK', 'LNTH', 'SRPT', 'NTRA',
#        'TX', 'PKE', 'AMPH', 'TNP', 'DY', 'WST', 'FCN', 'ACGL', 'SATS',
#        'MYGN', 'EME'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'HY', 'SGEN', 'TNK', 'OEC', 'NTRA', 'TX', 'SRPT', 'LNTH',
#        'TNP', 'HLF', 'MYGN', 'AMCX', 'DY', 'WST', 'PKE', 'AXON', 'FSLR',
#        'ARCH', 'CLMT'], dtype=object), 'r_retnStd/UI': array(['SHV', 'TA', 'OEC', 'FCN', 'LNTH', 'SGEN', 'AMPH', 'PKE', 'PRGO',
#        'FTSM', 'HY', 'TNK', 'KBR', 'LAUR', 'SATS', 'EME', 'FSS', 'ACGL',
#        'SRPT', 'TWNK'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('HY', 3), ('OEC', 3), ('SGEN', 3), ('TNK', 3), ('LNTH', 3), ('SRPT', 3), ('PKE', 3), ('SHV', 2), ('NTRA', 2), ('TX', 2), ('AMPH', 2), ('TNP', 2), ('DY', 2), ('WST', 2), ('FCN', 2), ('ACGL', 2), ('SATS', 2), ('MYGN', 2), ('EME', 2), ('HLF', 1), ('AMCX', 1), ('AXON', 1), ('FSLR', 1), ('ARCH', 1), ('CLMT', 1), ('PRGO', 1), ('FTSM', 1), ('KBR', 1), ('LAUR', 1), ('FSS', 1), ('TWNK', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(119, 134, 138), (104, 134, 138)]
# lb_slice:            (104, 134, 138)
# days eval:           4
# iloc_start_train:    104
# iloc_end_train:      134
# date_start_df_train: 2023-01-19
# date_end_df_train:   2023-03-02
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TA', 'TNK', 'ELF', 'OEC', 'SHV', 'SGEN', 'TSLA', 'TEX', 'CTLT',
#        'SMG', 'ASC', 'AMPH', 'LNTH', 'WIRE', 'THR', 'ASTE', 'LRN', 'PDFS',
#        'NTRA', 'NVGS'], dtype=object), 'r_CAGR/retnStd': array(['TNK', 'TA', 'TSLA', 'ELF', 'SMG', 'OEC', 'CTLT', 'HY', 'TEX',
#        'ASC', 'WIRE', 'THR', 'NTRA', 'ASTE', 'SGEN', 'NVDA', 'STRL',
#        'ACLS', 'TWLO', 'LNTH'], dtype=object), 'r_retnStd/UI': array(['TA', 'SHV', 'ELF', 'OEC', 'AMPH', 'LRN', 'KBR', 'FTSM', 'SGEN',
#        'PGR', 'NVGS', 'LNTH', 'PDFS', 'EME', 'TNK', 'CLX', 'PRGS', 'PKE',
#        'MWA', 'AIR'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('TNK', 3), ('ELF', 3), ('OEC', 3), ('SGEN', 3), ('LNTH', 3), ('SHV', 2), ('TSLA', 2), ('TEX', 2), ('CTLT', 2), ('SMG', 2), ('ASC', 2), ('AMPH', 2), ('WIRE', 2), ('THR', 2), ('ASTE', 2), ('LRN', 2), ('PDFS', 2), ('NTRA', 2), ('NVGS', 2), ('HY', 1), ('NVDA', 1), ('STRL', 1), ('ACLS', 1), ('TWLO', 1), ('KBR', 1), ('FTSM', 1), ('PGR', 1), ('EME', 1), ('CLX', 1), ('PRGS', 1), ('PKE', 1), ('MWA', 1), ('AIR', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('TA', 3), ('HY', 3), ('OEC', 3), ('SGEN', 3), ('TNK', 3), ('LNTH', 3), ('SRPT', 3), ('PKE', 3), ('SHV', 2), ('NTRA', 2), ('TX', 2), ('AMPH', 2), ('TNP', 2), ('DY', 2), ('WST', 2), ('FCN', 2), ('ACGL', 2), ('SATS', 2), ('MYGN', 2), ('EME', 2), ('HLF', 1), ('AMCX', 1), ('AXON', 1), ('FSLR', 1), ('ARCH', 1), ('CLMT', 1), ('PRGO', 1), ('FTSM', 1), ('KBR', 1), ('LAUR', 1), ('FSS', 1), ('TWNK', 1)], [('TA', 3), ('TNK', 3), ('ELF', 3), ('OEC', 3), ('SGEN', 3), ('LNTH', 3), ('SHV', 2), ('TSLA', 2), ('TEX', 2), ('CTLT', 2), ('SMG', 2), ('ASC', 2), ('AMPH', 2), ('WIRE', 2), ('THR', 2), ('ASTE', 2), ('LRN', 2), ('PDFS', 2), ('NTRA', 2), ('NVGS', 2), ('HY', 1), ('NVDA', 1), ('STRL', 1), ('ACLS', 1), ('TWLO', 1), ('KBR', 1), ('FTSM', 1), ('PGR', 1), ('EME', 1), ('CLX', 1), ('PRGS', 1), ('PKE', 1), ('MWA', 1), ('AIR', 1)]]
# **** finish lookback slices [(119, 134, 138), (104, 134, 138)] ****
#
# top 20 ranked symbols and frequency from set [(119, 134, 138), (104, 134, 138)]:
# [('LNTH', 6), ('OEC', 6), ('SGEN', 6), ('TA', 6), ('TNK', 6), ('AMPH', 4), ('HY', 4), ('NTRA', 4), ('PKE', 4), ('SHV', 4), ('ELF', 3), ('EME', 3), ('SRPT', 3), ('ACGL', 2), ('ASC', 2), ('ASTE', 2), ('CTLT', 2), ('DY', 2), ('FCN', 2), ('FTSM', 2)]
# top 20 ranked symbols from set [(119, 134, 138), (104, 134, 138)]:
# ['LNTH', 'OEC', 'SGEN', 'TA', 'TNK', 'AMPH', 'HY', 'NTRA', 'PKE', 'SHV']
# ===== finish top 20 ranked symbols from days_lookback set [(119, 134, 138), (104, 134, 138)] =====
#
#
#
# ########## 6 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(65, 80, 84), (50, 80, 84)]
# lb_slice:            (65, 80, 84)
# days eval:           4
# iloc_start_train:    65
# iloc_end_train:      80
# date_start_df_train: 2022-11-21
# date_end_df_train:   2022-12-12
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['BBW', 'CTRN', 'HZNP', 'RCM', 'AXSM', 'RARE', 'YY', 'BURL', 'GDS',
#        'BVH', 'WB', 'ZTO', 'BIDU', 'WYNN', 'NVO', 'AEO', 'SHV', 'BMRN',
#        'ANF', 'FE'], dtype=object), 'r_CAGR/retnStd': array(['HZNP', 'RCM', 'CTRN', 'BBW', 'AXSM', 'GDS', 'YY', 'RARE', 'WB',
#        'FIVN', 'BIDU', 'ZTO', 'NVO', 'BMRN', 'BURL', 'WYNN', 'ANF',
#        'TEAM', 'TFX', 'TCOM'], dtype=object), 'r_retnStd/UI': array(['BVH', 'SHV', 'AZN', 'BBW', 'BURL', 'FE', 'AXSM', 'FTSM', 'AEO',
#        'MOH', 'WYNN', 'CIEN', 'CTRN', 'RARE', 'ZTO', 'MGI', 'ETR', 'ANF',
#        'WB', 'NVO'], dtype=object)}}
# most_freq_syms: [('BBW', 3), ('CTRN', 3), ('AXSM', 3), ('RARE', 3), ('BURL', 3), ('WB', 3), ('ZTO', 3), ('WYNN', 3), ('NVO', 3), ('ANF', 3), ('HZNP', 2), ('RCM', 2), ('YY', 2), ('GDS', 2), ('BVH', 2), ('BIDU', 2), ('AEO', 2), ('SHV', 2), ('BMRN', 2), ('FE', 2), ('FIVN', 1), ('TEAM', 1), ('TFX', 1), ('TCOM', 1), ('AZN', 1), ('FTSM', 1), ('MOH', 1), ('CIEN', 1), ('MGI', 1), ('ETR', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(65, 80, 84), (50, 80, 84)]
# lb_slice:            (50, 80, 84)
# days eval:           4
# iloc_start_train:    50
# iloc_end_train:      80
# date_start_df_train: 2022-10-31
# date_end_df_train:   2022-12-12
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['GDS', 'HZNP', 'ZTO', 'BVH', 'AXSM', 'BIDU', 'ACLS', 'SHV', 'LSCC',
#        'BBW', 'AU', 'HTHT', 'RIO', 'JD', 'BERY', 'APD', 'AMBA', 'PUK',
#        'WB', 'FTSM'], dtype=object), 'r_CAGR/retnStd': array(['GDS', 'HZNP', 'AXSM', 'ZTO', 'HTHT', 'JD', 'BIDU', 'WB', 'LSCC',
#        'ACLS', 'TCOM', 'YUMC', 'AMBA', 'AU', 'PUK', 'BVH', 'WYNN', 'BBW',
#        'RIO', 'BERY'], dtype=object), 'r_retnStd/UI': array(['BVH', 'SHV', 'FTSM', 'ATCO', 'ZTO', 'APD', 'BBW', 'RIO', 'ELF',
#        'PNM', 'BERY', 'ACLS', 'HZNP', 'PG', 'AEO', 'AU', 'PNW', 'ANF',
#        'SKX', 'ENR'], dtype=object)}}
# most_freq_syms: [('HZNP', 3), ('ZTO', 3), ('BVH', 3), ('ACLS', 3), ('BBW', 3), ('AU', 3), ('RIO', 3), ('BERY', 3), ('GDS', 2), ('AXSM', 2), ('BIDU', 2), ('SHV', 2), ('LSCC', 2), ('HTHT', 2), ('JD', 2), ('APD', 2), ('AMBA', 2), ('PUK', 2), ('WB', 2), ('FTSM', 2), ('TCOM', 1), ('YUMC', 1), ('WYNN', 1), ('ATCO', 1), ('ELF', 1), ('PNM', 1), ('PG', 1), ('AEO', 1), ('PNW', 1), ('ANF', 1), ('SKX', 1), ('ENR', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('BBW', 3), ('CTRN', 3), ('AXSM', 3), ('RARE', 3), ('BURL', 3), ('WB', 3), ('ZTO', 3), ('WYNN', 3), ('NVO', 3), ('ANF', 3), ('HZNP', 2), ('RCM', 2), ('YY', 2), ('GDS', 2), ('BVH', 2), ('BIDU', 2), ('AEO', 2), ('SHV', 2), ('BMRN', 2), ('FE', 2), ('FIVN', 1), ('TEAM', 1), ('TFX', 1), ('TCOM', 1), ('AZN', 1), ('FTSM', 1), ('MOH', 1), ('CIEN', 1), ('MGI', 1), ('ETR', 1)], [('HZNP', 3), ('ZTO', 3), ('BVH', 3), ('ACLS', 3), ('BBW', 3), ('AU', 3), ('RIO', 3), ('BERY', 3), ('GDS', 2), ('AXSM', 2), ('BIDU', 2), ('SHV', 2), ('LSCC', 2), ('HTHT', 2), ('JD', 2), ('APD', 2), ('AMBA', 2), ('PUK', 2), ('WB', 2), ('FTSM', 2), ('TCOM', 1), ('YUMC', 1), ('WYNN', 1), ('ATCO', 1), ('ELF', 1), ('PNM', 1), ('PG', 1), ('AEO', 1), ('PNW', 1), ('ANF', 1), ('SKX', 1), ('ENR', 1)]]
# **** finish lookback slices [(65, 80, 84), (50, 80, 84)] ****
#
# top 20 ranked symbols and frequency from set [(65, 80, 84), (50, 80, 84)]:
# [('BBW', 6), ('ZTO', 6), ('AXSM', 5), ('BVH', 5), ('HZNP', 5), ('WB', 5), ('ANF', 4), ('BIDU', 4), ('GDS', 4), ('SHV', 4), ('WYNN', 4), ('ACLS', 3), ('AEO', 3), ('AU', 3), ('BERY', 3), ('BURL', 3), ('CTRN', 3), ('FTSM', 3), ('NVO', 3), ('RARE', 3)]
# top 20 ranked symbols from set [(65, 80, 84), (50, 80, 84)]:
# ['BBW', 'ZTO', 'AXSM', 'BVH', 'HZNP', 'WB', 'ANF', 'BIDU', 'GDS', 'SHV']
# ===== finish top 20 ranked symbols from days_lookback set [(65, 80, 84), (50, 80, 84)] =====
#
#
#
# ########## 7 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(117, 132, 136), (102, 132, 136)]
# lb_slice:            (117, 132, 136)
# days eval:           4
# iloc_start_train:    117
# iloc_end_train:      132
# date_start_df_train: 2023-02-07
# date_end_df_train:   2023-02-28
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TA', 'SHV', 'SGEN', 'TNK', 'TNP', 'LNTH', 'OEC', 'ACGL', 'HY',
#        'WST', 'EME', 'EURN', 'TEX', 'AMCX', 'FTSM', 'TIMB', 'TWNK', 'PKE',
#        'LAUR', 'FTI'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'TNK', 'SGEN', 'TNP', 'LNTH', 'HY', 'OEC', 'ACGL', 'AMCX',
#        'WST', 'TEX', 'SHV', 'TIMB', 'PKE', 'NSP', 'EME', 'FTI', 'EURN',
#        'ASC', 'STNG'], dtype=object), 'r_retnStd/UI': array(['SHV', 'TA', 'SGEN', 'LAUR', 'OEC', 'TNK', 'LNTH', 'KBR', 'FTSM',
#        'MSGS', 'ACGL', 'TWNK', 'QNST', 'EME', 'EURN', 'SATS', 'TNP',
#        'PDFS', 'FIZZ', 'FCN'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('SHV', 3), ('SGEN', 3), ('TNK', 3), ('TNP', 3), ('LNTH', 3), ('OEC', 3), ('ACGL', 3), ('EME', 3), ('EURN', 3), ('HY', 2), ('WST', 2), ('TEX', 2), ('AMCX', 2), ('FTSM', 2), ('TIMB', 2), ('TWNK', 2), ('PKE', 2), ('LAUR', 2), ('FTI', 2), ('NSP', 1), ('ASC', 1), ('STNG', 1), ('KBR', 1), ('MSGS', 1), ('QNST', 1), ('SATS', 1), ('PDFS', 1), ('FIZZ', 1), ('FCN', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(117, 132, 136), (102, 132, 136)]
# lb_slice:            (102, 132, 136)
# days eval:           4
# iloc_start_train:    102
# iloc_end_train:      132
# date_start_df_train: 2023-01-17
# date_end_df_train:   2023-02-28
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TA', 'TNK', 'ELF', 'TSLA', 'SGEN', 'OEC', 'SHV', 'CTLT', 'LNTH',
#        'LRN', 'FTSM', 'TEX', 'NVGS', 'WIRE', 'PDFS', 'SMG', 'ASC', 'COTY',
#        'NVDA', 'ACLS'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'TSLA', 'TNK', 'ELF', 'SGEN', 'CTLT', 'OEC', 'LNTH', 'WIRE',
#        'TEX', 'SMG', 'TNP', 'PAG', 'SHV', 'ASC', 'ACLS', 'NVDA', 'PDFS',
#        'PRG', 'NVGS'], dtype=object), 'r_retnStd/UI': array(['TA', 'ELF', 'SHV', 'OEC', 'LRN', 'FTSM', 'SGEN', 'NVGS', 'PDFS',
#        'LNTH', 'TNK', 'PKE', 'COTY', 'TEX', 'CTLT', 'KEX', 'EME', 'MMS',
#        'ORI', 'EURN'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('TNK', 3), ('ELF', 3), ('SGEN', 3), ('OEC', 3), ('SHV', 3), ('CTLT', 3), ('LNTH', 3), ('TEX', 3), ('NVGS', 3), ('PDFS', 3), ('TSLA', 2), ('LRN', 2), ('FTSM', 2), ('WIRE', 2), ('SMG', 2), ('ASC', 2), ('COTY', 2), ('NVDA', 2), ('ACLS', 2), ('TNP', 1), ('PAG', 1), ('PRG', 1), ('PKE', 1), ('KEX', 1), ('EME', 1), ('MMS', 1), ('ORI', 1), ('EURN', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('TA', 3), ('SHV', 3), ('SGEN', 3), ('TNK', 3), ('TNP', 3), ('LNTH', 3), ('OEC', 3), ('ACGL', 3), ('EME', 3), ('EURN', 3), ('HY', 2), ('WST', 2), ('TEX', 2), ('AMCX', 2), ('FTSM', 2), ('TIMB', 2), ('TWNK', 2), ('PKE', 2), ('LAUR', 2), ('FTI', 2), ('NSP', 1), ('ASC', 1), ('STNG', 1), ('KBR', 1), ('MSGS', 1), ('QNST', 1), ('SATS', 1), ('PDFS', 1), ('FIZZ', 1), ('FCN', 1)], [('TA', 3), ('TNK', 3), ('ELF', 3), ('SGEN', 3), ('OEC', 3), ('SHV', 3), ('CTLT', 3), ('LNTH', 3), ('TEX', 3), ('NVGS', 3), ('PDFS', 3), ('TSLA', 2), ('LRN', 2), ('FTSM', 2), ('WIRE', 2), ('SMG', 2), ('ASC', 2), ('COTY', 2), ('NVDA', 2), ('ACLS', 2), ('TNP', 1), ('PAG', 1), ('PRG', 1), ('PKE', 1), ('KEX', 1), ('EME', 1), ('MMS', 1), ('ORI', 1), ('EURN', 1)]]
# **** finish lookback slices [(117, 132, 136), (102, 132, 136)] ****
#
# top 20 ranked symbols and frequency from set [(117, 132, 136), (102, 132, 136)]:
# [('LNTH', 6), ('OEC', 6), ('SGEN', 6), ('SHV', 6), ('TA', 6), ('TNK', 6), ('TEX', 5), ('EME', 4), ('EURN', 4), ('FTSM', 4), ('PDFS', 4), ('TNP', 4), ('ACGL', 3), ('ASC', 3), ('CTLT', 3), ('ELF', 3), ('NVGS', 3), ('PKE', 3), ('ACLS', 2), ('AMCX', 2)]
# top 20 ranked symbols from set [(117, 132, 136), (102, 132, 136)]:
# ['LNTH', 'OEC', 'SGEN', 'SHV', 'TA', 'TNK', 'TEX', 'EME', 'EURN', 'FTSM']
# ===== finish top 20 ranked symbols from days_lookback set [(117, 132, 136), (102, 132, 136)] =====
#
#
#
# ########## 8 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(94, 109, 113), (79, 109, 113)]
# lb_slice:            (94, 109, 113)
# days eval:           4
# iloc_start_train:    94
# iloc_end_train:      109
# date_start_df_train: 2023-01-04
# date_end_df_train:   2023-01-25
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['MARA', 'RVNC', 'NATI', 'W', 'TX', 'ACLS', 'BTC-USD', 'MELI',
#        'NEOG', 'GBTC', 'ICPT', 'H', 'WBD', 'SCVL', 'BMA', 'AMX', 'EXPE',
#        'TRIP', 'JYNT', 'MTDR'], dtype=object), 'r_CAGR/retnStd': array(['MARA', 'RVNC', 'W', 'NATI', 'ACLS', 'GBTC', 'ICPT', 'WBD',
#        'BTC-USD', 'MELI', 'BMA', 'TX', 'JYNT', 'NEOG', 'EXPE', 'NVDA',
#        'SCVL', 'CNK', 'MYGN', 'BLFS'], dtype=object), 'r_retnStd/UI': array(['DCP', 'PAGP', 'H', 'AMX', 'NATI', 'TX', 'NEOG', 'SHV', 'SONY',
#        'HSBC', 'PAA', 'CRUS', 'GVA', 'SCVL', 'SBGI', 'MPC', 'MELI',
#        'TRIP', 'DIS', 'ALLY'], dtype=object)}}
# most_freq_syms: [('NATI', 3), ('TX', 3), ('MELI', 3), ('NEOG', 3), ('SCVL', 3), ('MARA', 2), ('RVNC', 2), ('W', 2), ('ACLS', 2), ('BTC-USD', 2), ('GBTC', 2), ('ICPT', 2), ('H', 2), ('WBD', 2), ('BMA', 2), ('AMX', 2), ('EXPE', 2), ('TRIP', 2), ('JYNT', 2), ('MTDR', 1), ('NVDA', 1), ('CNK', 1), ('MYGN', 1), ('BLFS', 1), ('DCP', 1), ('PAGP', 1), ('SHV', 1), ('SONY', 1), ('HSBC', 1), ('PAA', 1), ('CRUS', 1), ('GVA', 1), ('SBGI', 1), ('MPC', 1), ('DIS', 1), ('ALLY', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(94, 109, 113), (79, 109, 113)]
# lb_slice:            (79, 109, 113)
# days eval:           4
# iloc_start_train:    79
# iloc_end_train:      109
# date_start_df_train: 2022-12-12
# date_end_df_train:   2023-01-25
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['BMA', 'SHV', 'GBTC', 'ALGN', 'ACIW', 'CCU', 'COLL', 'HLF', 'NTES',
#        'MARA', 'JOE', 'BVH', 'CROX', 'HSBC', 'CCOI', 'FTSM', 'PAR',
#        'BABA', 'BGNE', 'EXAS'], dtype=object), 'r_CAGR/retnStd': array(['BMA', 'MARA', 'GBTC', 'CCU', 'BTC-USD', 'W', 'NEOG', 'PAR',
#        'NATI', 'TX', 'HLF', 'ALGN', 'HSBC', 'ACLS', 'BABA', 'BVH', 'NTES',
#        'CROX', 'ACIW', 'PUK'], dtype=object), 'r_retnStd/UI': array(['SHV', 'LRN', 'COLL', 'FTSM', 'ACIW', 'ALGN', 'JOE', 'BMA', 'NTES',
#        'HLF', 'LH', 'CCJ', 'CCU', 'VRSN', 'PRGO', 'WB', 'DCP', 'SGRY',
#        'IRDM', 'CCOI'], dtype=object)}}
# most_freq_syms: [('BMA', 3), ('ALGN', 3), ('ACIW', 3), ('CCU', 3), ('HLF', 3), ('NTES', 3), ('SHV', 2), ('GBTC', 2), ('COLL', 2), ('MARA', 2), ('JOE', 2), ('BVH', 2), ('CROX', 2), ('HSBC', 2), ('CCOI', 2), ('FTSM', 2), ('PAR', 2), ('BABA', 2), ('BGNE', 1), ('EXAS', 1), ('BTC-USD', 1), ('W', 1), ('NEOG', 1), ('NATI', 1), ('TX', 1), ('ACLS', 1), ('PUK', 1), ('LRN', 1), ('LH', 1), ('CCJ', 1), ('VRSN', 1), ('PRGO', 1), ('WB', 1), ('DCP', 1), ('SGRY', 1), ('IRDM', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('NATI', 3), ('TX', 3), ('MELI', 3), ('NEOG', 3), ('SCVL', 3), ('MARA', 2), ('RVNC', 2), ('W', 2), ('ACLS', 2), ('BTC-USD', 2), ('GBTC', 2), ('ICPT', 2), ('H', 2), ('WBD', 2), ('BMA', 2), ('AMX', 2), ('EXPE', 2), ('TRIP', 2), ('JYNT', 2), ('MTDR', 1), ('NVDA', 1), ('CNK', 1), ('MYGN', 1), ('BLFS', 1), ('DCP', 1), ('PAGP', 1), ('SHV', 1), ('SONY', 1), ('HSBC', 1), ('PAA', 1), ('CRUS', 1), ('GVA', 1), ('SBGI', 1), ('MPC', 1), ('DIS', 1), ('ALLY', 1)], [('BMA', 3), ('ALGN', 3), ('ACIW', 3), ('CCU', 3), ('HLF', 3), ('NTES', 3), ('SHV', 2), ('GBTC', 2), ('COLL', 2), ('MARA', 2), ('JOE', 2), ('BVH', 2), ('CROX', 2), ('HSBC', 2), ('CCOI', 2), ('FTSM', 2), ('PAR', 2), ('BABA', 2), ('BGNE', 1), ('EXAS', 1), ('BTC-USD', 1), ('W', 1), ('NEOG', 1), ('NATI', 1), ('TX', 1), ('ACLS', 1), ('PUK', 1), ('LRN', 1), ('LH', 1), ('CCJ', 1), ('VRSN', 1), ('PRGO', 1), ('WB', 1), ('DCP', 1), ('SGRY', 1), ('IRDM', 1)]]
# **** finish lookback slices [(94, 109, 113), (79, 109, 113)] ****
#
# top 20 ranked symbols and frequency from set [(94, 109, 113), (79, 109, 113)]:
# [('BMA', 5), ('GBTC', 4), ('MARA', 4), ('NATI', 4), ('NEOG', 4), ('TX', 4), ('ACIW', 3), ('ACLS', 3), ('ALGN', 3), ('BTC-USD', 3), ('CCU', 3), ('HLF', 3), ('HSBC', 3), ('MELI', 3), ('NTES', 3), ('SCVL', 3), ('SHV', 3), ('W', 3), ('AMX', 2), ('BABA', 2)]
# top 20 ranked symbols from set [(94, 109, 113), (79, 109, 113)]:
# ['BMA', 'GBTC', 'MARA', 'NATI', 'NEOG', 'TX', 'ACIW', 'ACLS', 'ALGN', 'BTC-USD']
# ===== finish top 20 ranked symbols from days_lookback set [(94, 109, 113), (79, 109, 113)] =====
#
#
#
# ########## 9 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(22, 37, 41), (7, 37, 41)]
# lb_slice:            (22, 37, 41)
# days eval:           4
# iloc_start_train:    22
# iloc_end_train:      37
# date_start_df_train: 2022-09-21
# date_end_df_train:   2022-10-11
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['RCKT', 'FCN', 'PBF', 'BIIB', 'WIRE', 'WWE', 'ATEN', 'ISEE', 'CAR',
#        'AVXL', 'DXCM', 'XPRO', 'SBS', 'HLIT', 'MERC', 'BLDR', 'ATKR',
#        'MRK', 'AZPN', 'AZO'], dtype=object), 'r_CAGR/retnStd': array(['RCKT', 'PBF', 'FCN', 'ISEE', 'BIIB', 'CAR', 'XPRO', 'WWE', 'DXCM',
#        'WIRE', 'ATEN', 'SBS', 'AVXL', 'MERC', 'ATKR', 'BLDR', 'HLIT',
#        'ROCK', 'AZPN', 'OI'], dtype=object), 'r_retnStd/UI': array(['FCN', 'WIRE', 'BIIB', 'ATEN', 'LRN', 'WWE', 'SHV', 'HALO', 'HLIT',
#        'RCKT', 'ATCO', 'AVXL', 'AZO', 'ORLY', 'PBF', 'MRK', 'RGR', 'MOH',
#        'SATS', 'REGN'], dtype=object)}}
# most_freq_syms: [('RCKT', 3), ('FCN', 3), ('PBF', 3), ('BIIB', 3), ('WIRE', 3), ('WWE', 3), ('ATEN', 3), ('AVXL', 3), ('HLIT', 3), ('ISEE', 2), ('CAR', 2), ('DXCM', 2), ('XPRO', 2), ('SBS', 2), ('MERC', 2), ('BLDR', 2), ('ATKR', 2), ('MRK', 2), ('AZPN', 2), ('AZO', 2), ('ROCK', 1), ('OI', 1), ('LRN', 1), ('SHV', 1), ('HALO', 1), ('ATCO', 1), ('ORLY', 1), ('RGR', 1), ('MOH', 1), ('SATS', 1), ('REGN', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(22, 37, 41), (7, 37, 41)]
# lb_slice:            (7, 37, 41)
# days eval:           4
# iloc_start_train:    7
# iloc_end_train:      37
# date_start_df_train: 2022-08-30
# date_end_df_train:   2022-10-11
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['ISEE', 'LRN', 'RVNC', 'AZPN', 'REGN', 'HLIT', 'BIIB', 'CCRN',
#        'FCN', 'SIGI', 'MODN', 'WWE', 'TTC', 'PCG', 'PRO', 'HFWA', 'AXGN',
#        'DXCM', 'MRK', 'SHV'], dtype=object), 'r_CAGR/retnStd': array(['ISEE', 'RVNC', 'AZPN', 'CCRN', 'LRN', 'FCN', 'HLIT', 'REGN',
#        'HFWA', 'TTC', 'DXCM', 'WWE', 'BIIB', 'MODN', 'PCG', 'SIGI', 'PRO',
#        'AXGN', 'WING', 'UNM'], dtype=object), 'r_retnStd/UI': array(['LRN', 'BIIB', 'ISEE', 'REGN', 'HLIT', 'SIGI', 'MRK', 'AZPN',
#        'HUM', 'CCRN', 'MODN', 'PRO', 'AMN', 'FTSM', 'LLY', 'SHV', 'ABBV',
#        'LVS', 'AXGN', 'IBOC'], dtype=object)}}
# most_freq_syms: [('ISEE', 3), ('LRN', 3), ('AZPN', 3), ('REGN', 3), ('HLIT', 3), ('BIIB', 3), ('CCRN', 3), ('SIGI', 3), ('MODN', 3), ('PRO', 3), ('AXGN', 3), ('RVNC', 2), ('FCN', 2), ('WWE', 2), ('TTC', 2), ('PCG', 2), ('HFWA', 2), ('DXCM', 2), ('MRK', 2), ('SHV', 2), ('WING', 1), ('UNM', 1), ('HUM', 1), ('AMN', 1), ('FTSM', 1), ('LLY', 1), ('ABBV', 1), ('LVS', 1), ('IBOC', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('RCKT', 3), ('FCN', 3), ('PBF', 3), ('BIIB', 3), ('WIRE', 3), ('WWE', 3), ('ATEN', 3), ('AVXL', 3), ('HLIT', 3), ('ISEE', 2), ('CAR', 2), ('DXCM', 2), ('XPRO', 2), ('SBS', 2), ('MERC', 2), ('BLDR', 2), ('ATKR', 2), ('MRK', 2), ('AZPN', 2), ('AZO', 2), ('ROCK', 1), ('OI', 1), ('LRN', 1), ('SHV', 1), ('HALO', 1), ('ATCO', 1), ('ORLY', 1), ('RGR', 1), ('MOH', 1), ('SATS', 1), ('REGN', 1)], [('ISEE', 3), ('LRN', 3), ('AZPN', 3), ('REGN', 3), ('HLIT', 3), ('BIIB', 3), ('CCRN', 3), ('SIGI', 3), ('MODN', 3), ('PRO', 3), ('AXGN', 3), ('RVNC', 2), ('FCN', 2), ('WWE', 2), ('TTC', 2), ('PCG', 2), ('HFWA', 2), ('DXCM', 2), ('MRK', 2), ('SHV', 2), ('WING', 1), ('UNM', 1), ('HUM', 1), ('AMN', 1), ('FTSM', 1), ('LLY', 1), ('ABBV', 1), ('LVS', 1), ('IBOC', 1)]]
# **** finish lookback slices [(22, 37, 41), (7, 37, 41)] ****
#
# top 20 ranked symbols and frequency from set [(22, 37, 41), (7, 37, 41)]:
# [('BIIB', 6), ('HLIT', 6), ('AZPN', 5), ('FCN', 5), ('ISEE', 5), ('WWE', 5), ('DXCM', 4), ('LRN', 4), ('MRK', 4), ('REGN', 4), ('ATEN', 3), ('AVXL', 3), ('AXGN', 3), ('CCRN', 3), ('MODN', 3), ('PBF', 3), ('PRO', 3), ('RCKT', 3), ('SHV', 3), ('SIGI', 3)]
# top 20 ranked symbols from set [(22, 37, 41), (7, 37, 41)]:
# ['BIIB', 'HLIT', 'AZPN', 'FCN', 'ISEE', 'WWE', 'DXCM', 'LRN', 'MRK', 'REGN']
# ===== finish top 20 ranked symbols from days_lookback set [(22, 37, 41), (7, 37, 41)] =====
#
#
#
# ########## 10 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(35, 50, 54), (20, 50, 54)]
# lb_slice:            (35, 50, 54)
# days eval:           4
# iloc_start_train:    35
# iloc_end_train:      50
# date_start_df_train: 2022-10-10
# date_end_df_train:   2022-10-28
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['CBRL', 'EAT', 'NCLH', 'UAL', 'ASC', 'CCL', 'VRE', 'GBX', 'PI',
#        'NTNX', 'CATO', 'LOCO', 'HY', 'PLAY', 'STBA', 'ISRG', 'CAR',
#        'CLDT', 'ORCL', 'TDS'], dtype=object), 'r_CAGR/retnStd': array(['ASC', 'CCL', 'EAT', 'NCLH', 'HY', 'PI', 'CBRL', 'GBX', 'CAR',
#        'VRE', 'ASTE', 'UAL', 'EXTR', 'PLAY', 'ISRG', 'CATO', 'BBW', 'PMT',
#        'CLDT', 'STBA'], dtype=object), 'r_retnStd/UI': array(['FHN', 'NTNX', 'UAL', 'GILD', 'LOCO', 'CBRL', 'QSR', 'UNH', 'RLJ',
#        'STBA', 'SUN', 'MAIN', 'CATO', 'ORCL', 'VRE', 'CLDT', 'TDS', 'IBM',
#        'GSK', 'APLE'], dtype=object)}}
# most_freq_syms: [('CBRL', 3), ('UAL', 3), ('VRE', 3), ('CATO', 3), ('STBA', 3), ('CLDT', 3), ('EAT', 2), ('NCLH', 2), ('ASC', 2), ('CCL', 2), ('GBX', 2), ('PI', 2), ('NTNX', 2), ('LOCO', 2), ('HY', 2), ('PLAY', 2), ('ISRG', 2), ('CAR', 2), ('ORCL', 2), ('TDS', 2), ('ASTE', 1), ('EXTR', 1), ('BBW', 1), ('PMT', 1), ('FHN', 1), ('GILD', 1), ('QSR', 1), ('UNH', 1), ('RLJ', 1), ('SUN', 1), ('MAIN', 1), ('IBM', 1), ('GSK', 1), ('APLE', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(35, 50, 54), (20, 50, 54)]
# lb_slice:            (20, 50, 54)
# days eval:           4
# iloc_start_train:    20
# iloc_end_train:      50
# date_start_df_train: 2022-09-19
# date_end_df_train:   2022-10-28
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['PBF', 'ATEN', 'CAR', 'HLIT', 'ORLY', 'AZO', 'EXTR', 'DXCM', 'MRK',
#        'AVXL', 'BIIB', 'CATO', 'SHV', 'CSGS', 'WWE', 'SIGI', 'BBW',
#        'ISEE', 'LOCO', 'RCKT'], dtype=object), 'r_CAGR/retnStd': array(['PBF', 'CAR', 'ATEN', 'EXTR', 'XPRO', 'ISEE', 'HLIT', 'DXCM',
#        'CATO', 'MODN', 'AZO', 'BBW', 'RCKT', 'ORLY', 'PSX', 'AVXL', 'SLB',
#        'CSGS', 'CVLT', 'HFWA'], dtype=object), 'r_retnStd/UI': array(['ATEN', 'SHV', 'ORLY', 'BIIB', 'PBF', 'AZO', 'MRK', 'WWE', 'SIGI',
#        'HLIT', 'LLY', 'FTSM', 'CORT', 'AVXL', 'VRTX', 'LOCO', 'CSGS',
#        'FMC', 'CAR', 'SANM'], dtype=object)}}
# most_freq_syms: [('PBF', 3), ('ATEN', 3), ('CAR', 3), ('HLIT', 3), ('ORLY', 3), ('AZO', 3), ('AVXL', 3), ('CSGS', 3), ('EXTR', 2), ('DXCM', 2), ('MRK', 2), ('BIIB', 2), ('CATO', 2), ('SHV', 2), ('WWE', 2), ('SIGI', 2), ('BBW', 2), ('ISEE', 2), ('LOCO', 2), ('RCKT', 2), ('XPRO', 1), ('MODN', 1), ('PSX', 1), ('SLB', 1), ('CVLT', 1), ('HFWA', 1), ('LLY', 1), ('FTSM', 1), ('CORT', 1), ('VRTX', 1), ('FMC', 1), ('SANM', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('CBRL', 3), ('UAL', 3), ('VRE', 3), ('CATO', 3), ('STBA', 3), ('CLDT', 3), ('EAT', 2), ('NCLH', 2), ('ASC', 2), ('CCL', 2), ('GBX', 2), ('PI', 2), ('NTNX', 2), ('LOCO', 2), ('HY', 2), ('PLAY', 2), ('ISRG', 2), ('CAR', 2), ('ORCL', 2), ('TDS', 2), ('ASTE', 1), ('EXTR', 1), ('BBW', 1), ('PMT', 1), ('FHN', 1), ('GILD', 1), ('QSR', 1), ('UNH', 1), ('RLJ', 1), ('SUN', 1), ('MAIN', 1), ('IBM', 1), ('GSK', 1), ('APLE', 1)], [('PBF', 3), ('ATEN', 3), ('CAR', 3), ('HLIT', 3), ('ORLY', 3), ('AZO', 3), ('AVXL', 3), ('CSGS', 3), ('EXTR', 2), ('DXCM', 2), ('MRK', 2), ('BIIB', 2), ('CATO', 2), ('SHV', 2), ('WWE', 2), ('SIGI', 2), ('BBW', 2), ('ISEE', 2), ('LOCO', 2), ('RCKT', 2), ('XPRO', 1), ('MODN', 1), ('PSX', 1), ('SLB', 1), ('CVLT', 1), ('HFWA', 1), ('LLY', 1), ('FTSM', 1), ('CORT', 1), ('VRTX', 1), ('FMC', 1), ('SANM', 1)]]
# **** finish lookback slices [(35, 50, 54), (20, 50, 54)] ****
#
# top 20 ranked symbols and frequency from set [(35, 50, 54), (20, 50, 54)]:
# [('CAR', 5), ('CATO', 5), ('LOCO', 4), ('ATEN', 3), ('AVXL', 3), ('AZO', 3), ('BBW', 3), ('CBRL', 3), ('CLDT', 3), ('CSGS', 3), ('EXTR', 3), ('HLIT', 3), ('ORLY', 3), ('PBF', 3), ('STBA', 3), ('UAL', 3), ('VRE', 3), ('ASC', 2), ('BIIB', 2), ('CCL', 2)]
# top 20 ranked symbols from set [(35, 50, 54), (20, 50, 54)]:
# ['CAR', 'CATO', 'LOCO', 'ATEN', 'AVXL', 'AZO', 'BBW', 'CBRL', 'CLDT', 'CSGS']
# ===== finish top 20 ranked symbols from days_lookback set [(35, 50, 54), (20, 50, 54)] =====
#
#
#
# ########## 11 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(49, 64, 68), (34, 64, 68)]
# lb_slice:            (49, 64, 68)
# days eval:           4
# iloc_start_train:    49
# iloc_end_train:      64
# date_start_df_train: 2022-10-28
# date_end_df_train:   2022-11-17
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['GDS', 'JD', 'AXON', 'WB', 'AMKR', 'RUN', 'YUMC', 'TSM', 'HTHT',
#        'WYNN', 'CROX', 'BABA', 'NTES', 'ZTO', 'NYT', 'SPWR', 'RMBS',
#        'PUK', 'ACLS', 'LSCC'], dtype=object), 'r_CAGR/retnStd': array(['GDS', 'JD', 'WB', 'RUN', 'AMKR', 'HTHT', 'AXON', 'YUMC', 'WYNN',
#        'CROX', 'TSM', 'BABA', 'SPWR', 'NTES', 'TSE', 'ZTO', 'LSCC',
#        'ACLS', 'PKX', 'UAA'], dtype=object), 'r_retnStd/UI': array(['AXON', 'ATCO', 'PTMN', 'MYI', 'NAD', 'BVH', 'PNM', 'FTSM', 'ETN',
#        'IFN', 'TSM', 'TCPC', 'AMKR', 'QNST', 'YUMC', 'BFZ', 'NYT', 'LVS',
#        'UVV', 'GS'], dtype=object)}}
# most_freq_syms: [('AXON', 3), ('AMKR', 3), ('YUMC', 3), ('TSM', 3), ('GDS', 2), ('JD', 2), ('WB', 2), ('RUN', 2), ('HTHT', 2), ('WYNN', 2), ('CROX', 2), ('BABA', 2), ('NTES', 2), ('ZTO', 2), ('NYT', 2), ('SPWR', 2), ('ACLS', 2), ('LSCC', 2), ('RMBS', 1), ('PUK', 1), ('TSE', 1), ('PKX', 1), ('UAA', 1), ('ATCO', 1), ('PTMN', 1), ('MYI', 1), ('NAD', 1), ('BVH', 1), ('PNM', 1), ('FTSM', 1), ('ETN', 1), ('IFN', 1), ('TCPC', 1), ('QNST', 1), ('BFZ', 1), ('LVS', 1), ('UVV', 1), ('GS', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(49, 64, 68), (34, 64, 68)]
# lb_slice:            (34, 64, 68)
# days eval:           4
# iloc_start_train:    34
# iloc_end_train:      64
# date_start_df_train: 2022-10-07
# date_end_df_train:   2022-11-17
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['AMKR', 'AXON', 'GILD', 'GBX', 'GE', 'UNFI', 'SRI', 'ASC', 'OSBC',
#        'HEES', 'SKT', 'DD', 'T', 'TEX', 'EIG', 'BGNE', 'FMX', 'CAT',
#        'WBA', 'PMT'], dtype=object), 'r_CAGR/retnStd': array(['AMKR', 'AXON', 'SRI', 'ASC', 'GBX', 'HY', 'PKX', 'TEX', 'RNR',
#        'RMBS', 'GE', 'BGNE', 'SMG', 'HEES', 'STRL', 'OSBC', 'ALE', 'ISRG',
#        'UNFI', 'EXTR'], dtype=object), 'r_retnStd/UI': array(['GILD', 'T', 'UNFI', 'UVV', 'AFL', 'GE', 'TCPC', 'SHV', 'DENN',
#        'GBX', 'APD', 'MET', 'FTSM', 'PMT', 'CAT', 'QNST', 'OSBC', 'DD',
#        'SKT', 'GS'], dtype=object)}}
# most_freq_syms: [('GBX', 3), ('GE', 3), ('UNFI', 3), ('OSBC', 3), ('AMKR', 2), ('AXON', 2), ('GILD', 2), ('SRI', 2), ('ASC', 2), ('HEES', 2), ('SKT', 2), ('DD', 2), ('T', 2), ('TEX', 2), ('BGNE', 2), ('CAT', 2), ('PMT', 2), ('EIG', 1), ('FMX', 1), ('WBA', 1), ('HY', 1), ('PKX', 1), ('RNR', 1), ('RMBS', 1), ('SMG', 1), ('STRL', 1), ('ALE', 1), ('ISRG', 1), ('EXTR', 1), ('UVV', 1), ('AFL', 1), ('TCPC', 1), ('SHV', 1), ('DENN', 1), ('APD', 1), ('MET', 1), ('FTSM', 1), ('QNST', 1), ('GS', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('AXON', 3), ('AMKR', 3), ('YUMC', 3), ('TSM', 3), ('GDS', 2), ('JD', 2), ('WB', 2), ('RUN', 2), ('HTHT', 2), ('WYNN', 2), ('CROX', 2), ('BABA', 2), ('NTES', 2), ('ZTO', 2), ('NYT', 2), ('SPWR', 2), ('ACLS', 2), ('LSCC', 2), ('RMBS', 1), ('PUK', 1), ('TSE', 1), ('PKX', 1), ('UAA', 1), ('ATCO', 1), ('PTMN', 1), ('MYI', 1), ('NAD', 1), ('BVH', 1), ('PNM', 1), ('FTSM', 1), ('ETN', 1), ('IFN', 1), ('TCPC', 1), ('QNST', 1), ('BFZ', 1), ('LVS', 1), ('UVV', 1), ('GS', 1)], [('GBX', 3), ('GE', 3), ('UNFI', 3), ('OSBC', 3), ('AMKR', 2), ('AXON', 2), ('GILD', 2), ('SRI', 2), ('ASC', 2), ('HEES', 2), ('SKT', 2), ('DD', 2), ('T', 2), ('TEX', 2), ('BGNE', 2), ('CAT', 2), ('PMT', 2), ('EIG', 1), ('FMX', 1), ('WBA', 1), ('HY', 1), ('PKX', 1), ('RNR', 1), ('RMBS', 1), ('SMG', 1), ('STRL', 1), ('ALE', 1), ('ISRG', 1), ('EXTR', 1), ('UVV', 1), ('AFL', 1), ('TCPC', 1), ('SHV', 1), ('DENN', 1), ('APD', 1), ('MET', 1), ('FTSM', 1), ('QNST', 1), ('GS', 1)]]
# **** finish lookback slices [(49, 64, 68), (34, 64, 68)] ****
#
# top 20 ranked symbols and frequency from set [(49, 64, 68), (34, 64, 68)]:
# [('AMKR', 5), ('AXON', 5), ('GBX', 3), ('GE', 3), ('OSBC', 3), ('TSM', 3), ('UNFI', 3), ('YUMC', 3), ('ACLS', 2), ('ASC', 2), ('BABA', 2), ('BGNE', 2), ('CAT', 2), ('CROX', 2), ('DD', 2), ('FTSM', 2), ('GDS', 2), ('GILD', 2), ('GS', 2), ('HEES', 2)]
# top 20 ranked symbols from set [(49, 64, 68), (34, 64, 68)]:
# ['AMKR', 'AXON', 'GBX', 'GE', 'OSBC', 'TSM', 'UNFI', 'YUMC', 'ACLS', 'ASC']
# ===== finish top 20 ranked symbols from days_lookback set [(49, 64, 68), (34, 64, 68)] =====
#
#
#
# ########## 12 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(102, 117, 121), (87, 117, 121)]
# lb_slice:            (102, 117, 121)
# days eval:           4
# iloc_start_train:    102
# iloc_end_train:      117
# date_start_df_train: 2023-01-17
# date_end_df_train:   2023-02-06
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TSLA', 'W', 'META', 'CTLT', 'ALGN', 'JWN', 'LRN', 'ELF', 'ICPT',
#        'AN', 'CRUS', 'PAG', 'SMG', 'SHOP', 'CACC', 'SAIA', 'DBRG', 'ALLY',
#        'PACW', 'AX'], dtype=object), 'r_CAGR/retnStd': array(['TSLA', 'W', 'CTLT', 'ALGN', 'META', 'JWN', 'SMG', 'ICPT', 'ELF',
#        'SHOP', 'AN', 'CACC', 'LRN', 'DBRG', 'SAIA', 'PACW', 'RVNC', 'PRG',
#        'PAG', 'CRUS'], dtype=object), 'r_retnStd/UI': array(['LRN', 'META', 'CRUS', 'PAG', 'ELF', 'SUN', 'ALGN', 'OI', 'AX',
#        'CUBE', 'ICPT', 'ALLY', 'JWN', 'ST', 'AN', 'OEC', 'JOE', 'BYD',
# ...
#        'DK', 'HLIT', 'DINO'], dtype=object), 'r_retnStd/UI': array(['FCN', 'BIIB', 'MODN', 'ATEN', 'LRN', 'AVXL', 'PRO', 'PBF', 'SHV',
#        'AGYS', 'LW', 'ORLY', 'MNST', 'LLY', 'HLIT', 'WWE', 'ACRS', 'SAIA',
#        'CVLT', 'FTSM'], dtype=object)}}
# most_freq_syms: [('PBF', 3), ('PRO', 3), ('FCN', 3), ('ACRS', 3), ('ATEN', 3), ('BIIB', 3), ('MODN', 3), ('AVXL', 3), ('HLIT', 3), ('RCKT', 2), ('SBS', 2), ('LRN', 2), ('AGYS', 2), ('TCOM', 2), ('CAR', 2), ('RVNC', 2), ('MARA', 2), ('DINO', 2), ('DK', 2), ('BLDR', 2), ('ISEE', 1), ('ARCH', 1), ('SHV', 1), ('LW', 1), ('ORLY', 1), ('MNST', 1), ('LLY', 1), ('WWE', 1), ('SAIA', 1), ('CVLT', 1), ('FTSM', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(19, 34, 38), (4, 34, 38)]
# lb_slice:            (4, 34, 38)
# days eval:           4
# iloc_start_train:    4
# iloc_end_train:      34
# date_start_df_train: 2022-08-25
# date_end_df_train:   2022-10-06
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['ISEE', 'LRN', 'RVNC', 'BIIB', 'MODN', 'REGN', 'AZPN', 'HLIT',
#        'PCG', 'AXGN', 'PRO', 'WIX', 'SHV', 'CCRN', 'PEN', 'FTSM', 'NTNX',
#        'LAUR', 'WYNN', 'FSLR'], dtype=object), 'r_CAGR/retnStd': array(['ISEE', 'RVNC', 'LRN', 'MODN', 'AZPN', 'HLIT', 'PCG', 'REGN',
#        'BIIB', 'PRO', 'WIX', 'AXGN', 'PEN', 'LAUR', 'MOH', 'SHV', 'HFWA',
#        'CCRN', 'TTC', 'XPRO'], dtype=object), 'r_retnStd/UI': array(['LRN', 'BIIB', 'ISEE', 'REGN', 'MODN', 'HLIT', 'FSLR', 'AZPN',
#        'FTSM', 'SHV', 'ABBV', 'NTNX', 'AXGN', 'NFLX', 'HUM', 'SIGI',
#        'RVNC', 'CCRN', 'PCG', 'LVS'], dtype=object)}}
# most_freq_syms: [('ISEE', 3), ('LRN', 3), ('RVNC', 3), ('BIIB', 3), ('MODN', 3), ('REGN', 3), ('AZPN', 3), ('HLIT', 3), ('PCG', 3), ('AXGN', 3), ('SHV', 3), ('CCRN', 3), ('PRO', 2), ('WIX', 2), ('PEN', 2), ('FTSM', 2), ('NTNX', 2), ('LAUR', 2), ('FSLR', 2), ('WYNN', 1), ('MOH', 1), ('HFWA', 1), ('TTC', 1), ('XPRO', 1), ('ABBV', 1), ('NFLX', 1), ('HUM', 1), ('SIGI', 1), ('LVS', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('PBF', 3), ('PRO', 3), ('FCN', 3), ('ACRS', 3), ('ATEN', 3), ('BIIB', 3), ('MODN', 3), ('AVXL', 3), ('HLIT', 3), ('RCKT', 2), ('SBS', 2), ('LRN', 2), ('AGYS', 2), ('TCOM', 2), ('CAR', 2), ('RVNC', 2), ('MARA', 2), ('DINO', 2), ('DK', 2), ('BLDR', 2), ('ISEE', 1), ('ARCH', 1), ('SHV', 1), ('LW', 1), ('ORLY', 1), ('MNST', 1), ('LLY', 1), ('WWE', 1), ('SAIA', 1), ('CVLT', 1), ('FTSM', 1)], [('ISEE', 3), ('LRN', 3), ('RVNC', 3), ('BIIB', 3), ('MODN', 3), ('REGN', 3), ('AZPN', 3), ('HLIT', 3), ('PCG', 3), ('AXGN', 3), ('SHV', 3), ('CCRN', 3), ('PRO', 2), ('WIX', 2), ('PEN', 2), ('FTSM', 2), ('NTNX', 2), ('LAUR', 2), ('FSLR', 2), ('WYNN', 1), ('MOH', 1), ('HFWA', 1), ('TTC', 1), ('XPRO', 1), ('ABBV', 1), ('NFLX', 1), ('HUM', 1), ('SIGI', 1), ('LVS', 1)]]
# **** finish lookback slices [(19, 34, 38), (4, 34, 38)] ****
#
# top 20 ranked symbols and frequency from set [(19, 34, 38), (4, 34, 38)]:
# [('BIIB', 6), ('HLIT', 6), ('MODN', 6), ('LRN', 5), ('PRO', 5), ('RVNC', 5), ('ISEE', 4), ('SHV', 4), ('ACRS', 3), ('ATEN', 3), ('AVXL', 3), ('AXGN', 3), ('AZPN', 3), ('CCRN', 3), ('FCN', 3), ('FTSM', 3), ('PBF', 3), ('PCG', 3), ('REGN', 3), ('AGYS', 2)]
# top 20 ranked symbols from set [(19, 34, 38), (4, 34, 38)]:
# ['BIIB', 'HLIT', 'MODN', 'LRN', 'PRO', 'RVNC', 'ISEE', 'SHV', 'ACRS', 'ATEN']
# ===== finish top 20 ranked symbols from days_lookback set [(19, 34, 38), (4, 34, 38)] =====
#
#
#
# ########## 18 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(119, 134, 138), (104, 134, 138)]
# lb_slice:            (119, 134, 138)
# days eval:           4
# iloc_start_train:    119
# iloc_end_train:      134
# date_start_df_train: 2023-02-09
# date_end_df_train:   2023-03-02
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['TA', 'SHV', 'HY', 'OEC', 'SGEN', 'TNK', 'LNTH', 'SRPT', 'NTRA',
#        'TX', 'PKE', 'AMPH', 'TNP', 'DY', 'WST', 'FCN', 'ACGL', 'SATS',
#        'MYGN', 'EME'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'HY', 'SGEN', 'TNK', 'OEC', 'NTRA', 'TX', 'SRPT', 'LNTH',
#        'TNP', 'HLF', 'MYGN', 'AMCX', 'DY', 'WST', 'PKE', 'AXON', 'FSLR',
#        'ARCH', 'CLMT'], dtype=object), 'r_retnStd/UI': array(['SHV', 'TA', 'OEC', 'FCN', 'LNTH', 'SGEN', 'AMPH', 'PKE', 'PRGO',
#        'FTSM', 'HY', 'TNK', 'KBR', 'LAUR', 'SATS', 'EME', 'FSS', 'ACGL',
#        'SRPT', 'TWNK'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('HY', 3), ('OEC', 3), ('SGEN', 3), ('TNK', 3), ('LNTH', 3), ('SRPT', 3), ('PKE', 3), ('SHV', 2), ('NTRA', 2), ('TX', 2), ('AMPH', 2), ('TNP', 2), ('DY', 2), ('WST', 2), ('FCN', 2), ('ACGL', 2), ('SATS', 2), ('MYGN', 2), ('EME', 2), ('HLF', 1), ('AMCX', 1), ('AXON', 1), ('FSLR', 1), ('ARCH', 1), ('CLMT', 1), ('PRGO', 1), ('FTSM', 1), ('KBR', 1), ('LAUR', 1), ('FSS', 1), ('TWNK', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(119, 134, 138), (104, 134, 138)]
# lb_slice:            (104, 134, 138)
# days eval:           4
# iloc_start_train:    104
# iloc_end_train:      134
# date_start_df_train: 2023-01-19
# date_end_df_train:   2023-03-02
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TA', 'TNK', 'ELF', 'OEC', 'SHV', 'SGEN', 'TSLA', 'TEX', 'CTLT',
#        'SMG', 'ASC', 'AMPH', 'LNTH', 'WIRE', 'THR', 'ASTE', 'LRN', 'PDFS',
#        'NTRA', 'NVGS'], dtype=object), 'r_CAGR/retnStd': array(['TNK', 'TA', 'TSLA', 'ELF', 'SMG', 'OEC', 'CTLT', 'HY', 'TEX',
#        'ASC', 'WIRE', 'THR', 'NTRA', 'ASTE', 'SGEN', 'NVDA', 'STRL',
#        'ACLS', 'TWLO', 'LNTH'], dtype=object), 'r_retnStd/UI': array(['TA', 'SHV', 'ELF', 'OEC', 'AMPH', 'LRN', 'KBR', 'FTSM', 'SGEN',
#        'PGR', 'NVGS', 'LNTH', 'PDFS', 'EME', 'TNK', 'CLX', 'PRGS', 'PKE',
#        'MWA', 'AIR'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('TNK', 3), ('ELF', 3), ('OEC', 3), ('SGEN', 3), ('LNTH', 3), ('SHV', 2), ('TSLA', 2), ('TEX', 2), ('CTLT', 2), ('SMG', 2), ('ASC', 2), ('AMPH', 2), ('WIRE', 2), ('THR', 2), ('ASTE', 2), ('LRN', 2), ('PDFS', 2), ('NTRA', 2), ('NVGS', 2), ('HY', 1), ('NVDA', 1), ('STRL', 1), ('ACLS', 1), ('TWLO', 1), ('KBR', 1), ('FTSM', 1), ('PGR', 1), ('EME', 1), ('CLX', 1), ('PRGS', 1), ('PKE', 1), ('MWA', 1), ('AIR', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('TA', 3), ('HY', 3), ('OEC', 3), ('SGEN', 3), ('TNK', 3), ('LNTH', 3), ('SRPT', 3), ('PKE', 3), ('SHV', 2), ('NTRA', 2), ('TX', 2), ('AMPH', 2), ('TNP', 2), ('DY', 2), ('WST', 2), ('FCN', 2), ('ACGL', 2), ('SATS', 2), ('MYGN', 2), ('EME', 2), ('HLF', 1), ('AMCX', 1), ('AXON', 1), ('FSLR', 1), ('ARCH', 1), ('CLMT', 1), ('PRGO', 1), ('FTSM', 1), ('KBR', 1), ('LAUR', 1), ('FSS', 1), ('TWNK', 1)], [('TA', 3), ('TNK', 3), ('ELF', 3), ('OEC', 3), ('SGEN', 3), ('LNTH', 3), ('SHV', 2), ('TSLA', 2), ('TEX', 2), ('CTLT', 2), ('SMG', 2), ('ASC', 2), ('AMPH', 2), ('WIRE', 2), ('THR', 2), ('ASTE', 2), ('LRN', 2), ('PDFS', 2), ('NTRA', 2), ('NVGS', 2), ('HY', 1), ('NVDA', 1), ('STRL', 1), ('ACLS', 1), ('TWLO', 1), ('KBR', 1), ('FTSM', 1), ('PGR', 1), ('EME', 1), ('CLX', 1), ('PRGS', 1), ('PKE', 1), ('MWA', 1), ('AIR', 1)]]
# **** finish lookback slices [(119, 134, 138), (104, 134, 138)] ****
#
# top 20 ranked symbols and frequency from set [(119, 134, 138), (104, 134, 138)]:
# [('LNTH', 6), ('OEC', 6), ('SGEN', 6), ('TA', 6), ('TNK', 6), ('AMPH', 4), ('HY', 4), ('NTRA', 4), ('PKE', 4), ('SHV', 4), ('ELF', 3), ('EME', 3), ('SRPT', 3), ('ACGL', 2), ('ASC', 2), ('ASTE', 2), ('CTLT', 2), ('DY', 2), ('FCN', 2), ('FTSM', 2)]
# top 20 ranked symbols from set [(119, 134, 138), (104, 134, 138)]:
# ['LNTH', 'OEC', 'SGEN', 'TA', 'TNK', 'AMPH', 'HY', 'NTRA', 'PKE', 'SHV']
# ===== finish top 20 ranked symbols from days_lookback set [(119, 134, 138), (104, 134, 138)] =====
#
#
#
# ########## 19 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(76, 91, 95), (61, 91, 95)]
# lb_slice:            (76, 91, 95)
# days eval:           4
# iloc_start_train:    76
# iloc_end_train:      91
# date_start_df_train: 2022-12-07
# date_end_df_train:   2022-12-28
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['HZNP', 'AGYS', 'CYTK', 'PBF', 'EDU', 'MSGS', 'SHV', 'BMA', 'WB',
#        'CCU', 'BGNE', 'AJRD', 'HLF', 'FTSM', 'DOOR', 'ARWR', 'ALGN',
#        'BVH', 'PRO', 'DGX'], dtype=object), 'r_CAGR/retnStd': array(['CYTK', 'EDU', 'AGYS', 'BMA', 'PBF', 'HZNP', 'WB', 'MSGS', 'CCU',
#        'PRO', 'BGNE', 'HLF', 'SHV', 'ARWR', 'DOOR', 'NVO', 'CCEP', 'ANGO',
#        'FTSM', 'D'], dtype=object), 'r_retnStd/UI': array(['HZNP', 'SHV', 'MSGS', 'AJRD', 'AGYS', 'BVH', 'PBF', 'FTSM',
#        'ALGN', 'MPC', 'WB', 'DGX', 'ACGL', 'ALL', 'ZTO', 'TCOM', 'RDN',
#        'JOE', 'JAZZ', 'HAL'], dtype=object)}}
# most_freq_syms: [('HZNP', 3), ('AGYS', 3), ('PBF', 3), ('MSGS', 3), ('SHV', 3), ('WB', 3), ('FTSM', 3), ('CYTK', 2), ('EDU', 2), ('BMA', 2), ('CCU', 2), ('BGNE', 2), ('AJRD', 2), ('HLF', 2), ('DOOR', 2), ('ARWR', 2), ('ALGN', 2), ('BVH', 2), ('PRO', 2), ('DGX', 2), ('NVO', 1), ('CCEP', 1), ('ANGO', 1), ('D', 1), ('MPC', 1), ('ACGL', 1), ('ALL', 1), ('ZTO', 1), ('TCOM', 1), ('RDN', 1), ('JOE', 1), ('JAZZ', 1), ('HAL', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(76, 91, 95), (61, 91, 95)]
# lb_slice:            (61, 91, 95)
# days eval:           4
# iloc_start_train:    61
# iloc_end_train:      91
# date_start_df_train: 2022-11-15
# date_end_df_train:   2022-12-28
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['SHV', 'HZNP', 'FTSM', 'AXSM', 'CPB', 'NVO', 'CAG', 'BURL', 'ZTO',
#        'KHC', 'MSGS', 'AJRD', 'ACGL', 'EDU', 'MRK', 'BVH', 'CALM', 'BDX',
#        'AVA', 'SJW'], dtype=object), 'r_CAGR/retnStd': array(['HZNP', 'NVO', 'EDU', 'SHV', 'MSGS', 'BMA', 'CCU', 'AXSM', 'FTSM',
#        'BURL', 'ZTO', 'KHC', 'AVA', 'MRK', 'CPB', 'CAG', 'TAK', 'RARE',
#        'BDX', 'CALM'], dtype=object), 'r_retnStd/UI': array(['SHV', 'BVH', 'FTSM', 'CPB', 'HZNP', 'CAG', 'AXSM', 'MMS', 'ZTO',
#        'ACGL', 'AJRD', 'BURL', 'KHC', 'SJW', 'BBWI', 'NVO', 'PPL', 'PG',
#        'CALM', 'TOL'], dtype=object)}}
# most_freq_syms: [('SHV', 3), ('HZNP', 3), ('FTSM', 3), ('AXSM', 3), ('CPB', 3), ('NVO', 3), ('CAG', 3), ('BURL', 3), ('ZTO', 3), ('KHC', 3), ('CALM', 3), ('MSGS', 2), ('AJRD', 2), ('ACGL', 2), ('EDU', 2), ('MRK', 2), ('BVH', 2), ('BDX', 2), ('AVA', 2), ('SJW', 2), ('BMA', 1), ('CCU', 1), ('TAK', 1), ('RARE', 1), ('MMS', 1), ('BBWI', 1), ('PPL', 1), ('PG', 1), ('TOL', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('HZNP', 3), ('AGYS', 3), ('PBF', 3), ('MSGS', 3), ('SHV', 3), ('WB', 3), ('FTSM', 3), ('CYTK', 2), ('EDU', 2), ('BMA', 2), ('CCU', 2), ('BGNE', 2), ('AJRD', 2), ('HLF', 2), ('DOOR', 2), ('ARWR', 2), ('ALGN', 2), ('BVH', 2), ('PRO', 2), ('DGX', 2), ('NVO', 1), ('CCEP', 1), ('ANGO', 1), ('D', 1), ('MPC', 1), ('ACGL', 1), ('ALL', 1), ('ZTO', 1), ('TCOM', 1), ('RDN', 1), ('JOE', 1), ('JAZZ', 1), ('HAL', 1)], [('SHV', 3), ('HZNP', 3), ('FTSM', 3), ('AXSM', 3), ('CPB', 3), ('NVO', 3), ('CAG', 3), ('BURL', 3), ('ZTO', 3), ('KHC', 3), ('CALM', 3), ('MSGS', 2), ('AJRD', 2), ('ACGL', 2), ('EDU', 2), ('MRK', 2), ('BVH', 2), ('BDX', 2), ('AVA', 2), ('SJW', 2), ('BMA', 1), ('CCU', 1), ('TAK', 1), ('RARE', 1), ('MMS', 1), ('BBWI', 1), ('PPL', 1), ('PG', 1), ('TOL', 1)]]
# **** finish lookback slices [(76, 91, 95), (61, 91, 95)] ****
#
# top 20 ranked symbols and frequency from set [(76, 91, 95), (61, 91, 95)]:
# [('FTSM', 6), ('HZNP', 6), ('SHV', 6), ('MSGS', 5), ('AJRD', 4), ('BVH', 4), ('EDU', 4), ('NVO', 4), ('ZTO', 4), ('ACGL', 3), ('AGYS', 3), ('AXSM', 3), ('BMA', 3), ('BURL', 3), ('CAG', 3), ('CALM', 3), ('CCU', 3), ('CPB', 3), ('KHC', 3), ('PBF', 3)]
# top 20 ranked symbols from set [(76, 91, 95), (61, 91, 95)]:
# ['FTSM', 'HZNP', 'SHV', 'MSGS', 'AJRD', 'BVH', 'EDU', 'NVO', 'ZTO', 'ACGL']
# ===== finish top 20 ranked symbols from days_lookback set [(76, 91, 95), (61, 91, 95)] =====
#
#
#
# ########## 20 of 20 lb_slices in sets_lookcak_slices ##########
# days lookback:       15,  1 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(124, 139, 143), (109, 139, 143)]
# lb_slice:            (124, 139, 143)
# days eval:           4
# iloc_start_train:    124
# iloc_end_train:      139
# date_start_df_train: 2023-02-16
# date_end_df_train:   2023-03-09
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['HY', 'FSLR', 'DY', 'LNTH', 'SRPT', 'OEC', 'SHV', 'TNK', 'FCN',
#        'DQ', 'PDFS', 'OTTR', 'NTRA', 'GE', 'AXON', 'EME', 'BFAM', 'SATS',
#        'FTSM', 'PRG'], dtype=object), 'r_CAGR/retnStd': array(['HY', 'FSLR', 'DY', 'LNTH', 'SRPT', 'OEC', 'DQ', 'NTRA', 'TNK',
#        'BFAM', 'MYGN', 'GE', 'SHV', 'FCN', 'OTTR', 'PDFS', 'AXON', 'KR',
#        'EME', 'VST'], dtype=object), 'r_retnStd/UI': array(['FSLR', 'DY', 'LNTH', 'SHV', 'HY', 'FCN', 'PDFS', 'OTTR', 'LAUR',
#        'SRPT', 'FTSM', 'META', 'PRG', 'EME', 'AXON', 'OEC', 'SATS', 'TNK',
#        'AY', 'GE'], dtype=object)}}
# most_freq_syms: [('HY', 3), ('FSLR', 3), ('DY', 3), ('LNTH', 3), ('SRPT', 3), ('OEC', 3), ('SHV', 3), ('TNK', 3), ('FCN', 3), ('PDFS', 3), ('OTTR', 3), ('GE', 3), ('AXON', 3), ('EME', 3), ('DQ', 2), ('NTRA', 2), ('BFAM', 2), ('SATS', 2), ('FTSM', 2), ('PRG', 2), ('MYGN', 1), ('KR', 1), ('VST', 1), ('LAUR', 1), ('META', 1), ('AY', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 2 days_lookbacks: [15, 30]
# lb_slices:           [(124, 139, 143), (109, 139, 143)]
# lb_slice:            (109, 139, 143)
# days eval:           4
# iloc_start_train:    109
# iloc_end_train:      139
# date_start_df_train: 2023-01-26
# date_end_df_train:   2023-03-09
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TA', 'TNK', 'TNP', 'SHV', 'ASC', 'OEC', 'LNTH', 'FTSM', 'HY',
#        'CTLT', 'STNG', 'ELF', 'SGEN', 'NTRA', 'MCFT', 'STRL', 'WIRE',
#        'PDFS', 'EURN', 'ANET'], dtype=object), 'r_CAGR/retnStd': array(['TA', 'TNK', 'TNP', 'HY', 'STNG', 'ASC', 'NTRA', 'CTLT', 'OEC',
#        'LNTH', 'SHV', 'PRG', 'ANET', 'STRL', 'WIRE', 'MCFT', 'SGEN',
#        'THR', 'FTSM', 'PAG'], dtype=object), 'r_retnStd/UI': array(['TA', 'SHV', 'FTSM', 'TNK', 'ELF', 'OEC', 'LNTH', 'ATCO', 'SGEN',
#        'PDFS', 'TNP', 'EME', 'FCN', 'MCFT', 'KBR', 'AMPH', 'SRPT', 'ASC',
#        'EURN', 'ETN'], dtype=object)}}
# most_freq_syms: [('TA', 3), ('TNK', 3), ('TNP', 3), ('SHV', 3), ('ASC', 3), ('OEC', 3), ('LNTH', 3), ('FTSM', 3), ('SGEN', 3), ('MCFT', 3), ('HY', 2), ('CTLT', 2), ('STNG', 2), ('ELF', 2), ('NTRA', 2), ('STRL', 2), ('WIRE', 2), ('PDFS', 2), ('EURN', 2), ('ANET', 2), ('PRG', 1), ('THR', 1), ('PAG', 1), ('ATCO', 1), ('EME', 1), ('FCN', 1), ('KBR', 1), ('AMPH', 1), ('SRPT', 1), ('ETN', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_freq_syms: [[('HY', 3), ('FSLR', 3), ('DY', 3), ('LNTH', 3), ('SRPT', 3), ('OEC', 3), ('SHV', 3), ('TNK', 3), ('FCN', 3), ('PDFS', 3), ('OTTR', 3), ('GE', 3), ('AXON', 3), ('EME', 3), ('DQ', 2), ('NTRA', 2), ('BFAM', 2), ('SATS', 2), ('FTSM', 2), ('PRG', 2), ('MYGN', 1), ('KR', 1), ('VST', 1), ('LAUR', 1), ('META', 1), ('AY', 1)], [('TA', 3), ('TNK', 3), ('TNP', 3), ('SHV', 3), ('ASC', 3), ('OEC', 3), ('LNTH', 3), ('FTSM', 3), ('SGEN', 3), ('MCFT', 3), ('HY', 2), ('CTLT', 2), ('STNG', 2), ('ELF', 2), ('NTRA', 2), ('STRL', 2), ('WIRE', 2), ('PDFS', 2), ('EURN', 2), ('ANET', 2), ('PRG', 1), ('THR', 1), ('PAG', 1), ('ATCO', 1), ('EME', 1), ('FCN', 1), ('KBR', 1), ('AMPH', 1), ('SRPT', 1), ('ETN', 1)]]
# **** finish lookback slices [(124, 139, 143), (109, 139, 143)] ****
#
# top 20 ranked symbols and frequency from set [(124, 139, 143), (109, 139, 143)]:
# [('LNTH', 6), ('OEC', 6), ('SHV', 6), ('TNK', 6), ('FTSM', 5), ('HY', 5), ('PDFS', 5), ('EME', 4), ('FCN', 4), ('NTRA', 4), ('SRPT', 4), ('ASC', 3), ('AXON', 3), ('DY', 3), ('FSLR', 3), ('GE', 3), ('MCFT', 3), ('OTTR', 3), ('PRG', 3), ('SGEN', 3)]
# top 20 ranked symbols from set [(124, 139, 143), (109, 139, 143)]:
# ['LNTH', 'OEC', 'SHV', 'TNK', 'FTSM', 'HY', 'PDFS', 'EME', 'FCN', 'NTRA']
# ===== finish top 20 ranked symbols from days_lookback set [(124, 139, 143), (109, 139, 143)] =====

# %% [markdown]
# #### Output the best performing symbols for each set in sets_lookback_slices

# %%
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
  l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
  if verbose:
    print(f'set_lookback_slices: {sets_lookback_slices[i]}')
    print(f'max_lookback_slices: {max_lookback_slices}\n')

    if run_type == 'current':
      print(f'data below will be added to {fp_df_picks}')
 
    print(f'date_end_df_train:   {date_end_df_train}')    
    print(f'max_days_lookbacks:  {max_days_lookbacks}')   
    print(f'days_lookbacks:      {days_lookbacks}')
    print(f'sym_freq_15:         {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14:         {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13:         {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12:         {l_sym_freq_cnt[3]}')
    print(f'sym_freq_11:         {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10:         {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9:          {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8:          {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7:          {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6:          {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5:          {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4:          {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3:          {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2:          {l_sym_freq_cnt[13]}\n')

if run_type == 'current':  # record results to df
  row_picks0      = [date_end_df_train, max_days_lookbacks, str(days_lookbacks)]
  row_picks1      = [str(l_sym_freq_cnt[0]),  str(l_sym_freq_cnt[1]), str(l_sym_freq_cnt[2]),  str(l_sym_freq_cnt[3])]
  row_picks2      = [str(l_sym_freq_cnt[4]),  str(l_sym_freq_cnt[5]), str(l_sym_freq_cnt[6]),  str(l_sym_freq_cnt[7])]
  row_picks3      = [str(l_sym_freq_cnt[8]),  str(l_sym_freq_cnt[9]), str(l_sym_freq_cnt[10]), str(l_sym_freq_cnt[11])]
  row_picks4      = [str(l_sym_freq_cnt[12]), str(l_sym_freq_cnt[13])]
  row_picks_total = row_picks0 + row_picks1 + row_picks2 + row_picks3 + row_picks4
  print(f'row_picks_total: {row_picks_total}')

  df_picks.loc[len(df_picks)] = row_picks_total
  pickle_dump(df_picks, path_data_dump, fp_df_picks)
  print(f'appended row_picks_total to df_picks:\n{row_picks_total}\n')
# Out:
# set_lookback_slices: [(126, 141, 145), (111, 141, 145)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['FCN', 'LNTH', 'SGEN', 'SHV']
# sym_freq_5:          ['ANET', 'FTSM', 'HY', 'NTRA', 'TNK']
# sym_freq_4:          []
# sym_freq_3:          ['AMPH', 'AXON', 'DY', 'ELF', 'FSLR', 'GE', 'JYNT', 'MLR', 'PCH', 'PDFS', 'SRPT']
# sym_freq_2:          []
#
# set_lookback_slices: [(111, 126, 130), (96, 126, 130)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['CTLT', 'TA']
# sym_freq_5:          ['OEC', 'TSLA', 'WIRE']
# sym_freq_4:          ['AMCX', 'AN', 'CAR', 'SMG', 'THR']
# sym_freq_3:          ['CRUS', 'ELF', 'EVRI', 'FCF', 'NATI', 'PAG', 'RVNC', 'STNG', 'TNK']
# sym_freq_2:          ['ACLS']
#
# set_lookback_slices: [(78, 93, 97), (63, 93, 97)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['HZNP']
# sym_freq_5:          ['ARWR', 'MSGS', 'SHV']
# sym_freq_4:          ['BMA', 'BVH', 'CCU', 'FTSM']
# sym_freq_3:          ['AGYS', 'AJRD', 'AMBC', 'AXSM', 'BURL', 'CROX', 'HAL', 'NVO', 'PBF', 'RCM', 'ZTO']
# sym_freq_2:          ['ACGL']
#
# set_lookback_slices: [(59, 74, 78), (44, 74, 78)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BBW', 'HZNP']
# sym_freq_5:          ['ROST']
# sym_freq_4:          ['AEO', 'BURL']
# sym_freq_3:          ['AXSM', 'BMRN', 'CTRN', 'ENR', 'SRPT']
# sym_freq_2:          ['ACLS', 'ANF', 'APD', 'AXON', 'AZN', 'AZTA', 'BERY', 'BTI', 'FLO', 'FTSM']
#
# set_lookback_slices: [(119, 134, 138), (104, 134, 138)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SGEN', 'TA', 'TNK']
# sym_freq_5:          []
# sym_freq_4:          ['AMPH', 'HY', 'NTRA', 'PKE', 'SHV']
# sym_freq_3:          ['ELF', 'EME', 'SRPT']
# sym_freq_2:          ['ACGL', 'ASC', 'ASTE', 'CTLT', 'DY', 'FCN', 'FTSM']
#
# set_lookback_slices: [(65, 80, 84), (50, 80, 84)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BBW', 'ZTO']
# sym_freq_5:          ['AXSM', 'BVH', 'HZNP', 'WB']
# sym_freq_4:          ['ANF', 'BIDU', 'GDS', 'SHV', 'WYNN']
# sym_freq_3:          ['ACLS', 'AEO', 'AU', 'BERY', 'BURL', 'CTRN', 'FTSM', 'NVO', 'RARE']
# sym_freq_2:          []
#
# set_lookback_slices: [(117, 132, 136), (102, 132, 136)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SGEN', 'SHV', 'TA', 'TNK']
# sym_freq_5:          ['TEX']
# sym_freq_4:          ['EME', 'EURN', 'FTSM', 'PDFS', 'TNP']
# sym_freq_3:          ['ACGL', 'ASC', 'CTLT', 'ELF', 'NVGS', 'PKE']
# sym_freq_2:          ['ACLS', 'AMCX']
#
# set_lookback_slices: [(94, 109, 113), (79, 109, 113)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          []
# sym_freq_5:          ['BMA']
# sym_freq_4:          ['GBTC', 'MARA', 'NATI', 'NEOG', 'TX']
# sym_freq_3:          ['ACIW', 'ACLS', 'ALGN', 'BTC-USD', 'CCU', 'HLF', 'HSBC', 'MELI', 'NTES', 'SCVL', 'SHV', 'W']
# sym_freq_2:          ['AMX', 'BABA']
#
# set_lookback_slices: [(22, 37, 41), (7, 37, 41)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BIIB', 'HLIT']
# sym_freq_5:          ['AZPN', 'FCN', 'ISEE', 'WWE']
# sym_freq_4:          ['DXCM', 'LRN', 'MRK', 'REGN']
# sym_freq_3:          ['ATEN', 'AVXL', 'AXGN', 'CCRN', 'MODN', 'PBF', 'PRO', 'RCKT', 'SHV', 'SIGI']
# sym_freq_2:          []
#
# set_lookback_slices: [(35, 50, 54), (20, 50, 54)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          []
# sym_freq_5:          ['CAR', 'CATO']
# sym_freq_4:          ['LOCO']
# sym_freq_3:          ['ATEN', 'AVXL', 'AZO', 'BBW', 'CBRL', 'CLDT', 'CSGS', 'EXTR', 'HLIT', 'ORLY', 'PBF', 'STBA', 'UAL', 'VRE']
# sym_freq_2:          ['ASC', 'BIIB', 'CCL']
#
# set_lookback_slices: [(49, 64, 68), (34, 64, 68)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          []
# sym_freq_5:          ['AMKR', 'AXON']
# sym_freq_4:          []
# sym_freq_3:          ['GBX', 'GE', 'OSBC', 'TSM', 'UNFI', 'YUMC']
# sym_freq_2:          ['ACLS', 'ASC', 'BABA', 'BGNE', 'CAT', 'CROX', 'DD', 'FTSM', 'GDS', 'GILD', 'GS', 'HEES']
#
# set_lookback_slices: [(102, 117, 121), (87, 117, 121)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['ALGN', 'CTLT', 'META']
# sym_freq_5:          ['SMG']
# sym_freq_4:          ['ALLY', 'ICPT', 'LRN', 'SHOP', 'W']
# sym_freq_3:          ['AN', 'CRUS', 'ELF', 'JWN', 'PAG', 'RVNC', 'TSLA']
# sym_freq_2:          ['ACLS', 'AX', 'CACC', 'CCL']
#
# set_lookback_slices: [(124, 139, 143), (109, 139, 143)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SHV', 'TNK']
# sym_freq_5:          ['FTSM', 'HY', 'PDFS']
# sym_freq_4:          ['EME', 'FCN', 'NTRA', 'SRPT']
# sym_freq_3:          ['ASC', 'AXON', 'DY', 'FSLR', 'GE', 'MCFT', 'OTTR', 'PRG', 'SGEN']
# sym_freq_2:          []
#
# set_lookback_slices: [(78, 93, 97), (63, 93, 97)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['HZNP']
# sym_freq_5:          ['ARWR', 'MSGS', 'SHV']
# sym_freq_4:          ['BMA', 'BVH', 'CCU', 'FTSM']
# sym_freq_3:          ['AGYS', 'AJRD', 'AMBC', 'AXSM', 'BURL', 'CROX', 'HAL', 'NVO', 'PBF', 'RCM', 'ZTO']
# sym_freq_2:          ['ACGL']
#
# set_lookback_slices: [(123, 138, 142), (108, 138, 142)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SGEN', 'TA', 'TNK']
# sym_freq_5:          ['HY', 'PDFS', 'SHV', 'TNP']
# sym_freq_4:          ['EME', 'FCN', 'NTRA', 'PRG', 'SRPT']
# sym_freq_3:          ['ASC', 'DY', 'ELF', 'FTSM', 'OTTR']
# sym_freq_2:          ['ALV']
#
# set_lookback_slices: [(28, 43, 47), (13, 43, 47)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LOCO']
# sym_freq_5:          ['WAFD']
# sym_freq_4:          ['ASC', 'PBF']
# sym_freq_3:          ['AZPN', 'CCRN', 'CLMT', 'FCN', 'HFWA', 'HLIT', 'IBOC', 'LRN', 'SIGI', 'SLB', 'TNP', 'UCBI']
# sym_freq_2:          ['ATEN', 'BIIB', 'CAR', 'CLDT']
#
# set_lookback_slices: [(19, 34, 38), (4, 34, 38)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BIIB', 'HLIT', 'MODN']
# sym_freq_5:          ['LRN', 'PRO', 'RVNC']
# sym_freq_4:          ['ISEE', 'SHV']
# sym_freq_3:          ['ACRS', 'ATEN', 'AVXL', 'AXGN', 'AZPN', 'CCRN', 'FCN', 'FTSM', 'PBF', 'PCG', 'REGN']
# sym_freq_2:          ['AGYS']
#
# set_lookback_slices: [(119, 134, 138), (104, 134, 138)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SGEN', 'TA', 'TNK']
# sym_freq_5:          []
# sym_freq_4:          ['AMPH', 'HY', 'NTRA', 'PKE', 'SHV']
# sym_freq_3:          ['ELF', 'EME', 'SRPT']
# sym_freq_2:          ['ACGL', 'ASC', 'ASTE', 'CTLT', 'DY', 'FCN', 'FTSM']
#
# set_lookback_slices: [(76, 91, 95), (61, 91, 95)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['FTSM', 'HZNP', 'SHV']
# sym_freq_5:          ['MSGS']
# sym_freq_4:          ['AJRD', 'BVH', 'EDU', 'NVO', 'ZTO']
# sym_freq_3:          ['ACGL', 'AGYS', 'AXSM', 'BMA', 'BURL', 'CAG', 'CALM', 'CCU', 'CPB', 'KHC', 'PBF']
# sym_freq_2:          []
#
# set_lookback_slices: [(124, 139, 143), (109, 139, 143)]
# max_lookback_slices: [(111, 141, 145), (96, 126, 130), (63, 93, 97), (44, 74, 78), (104, 134, 138), (50, 80, 84), (102, 132, 136), (79, 109, 113), (7, 37, 41), (20, 50, 54), (34, 64, 68), (87, 117, 121), (109, 139, 143), (63, 93, 97), (108, 138, 142), (13, 43, 47), (4, 34, 38), (104, 134, 138), (61, 91, 95), (109, 139, 143)]
#
# date_end_df_train:   2023-03-09
# max_days_lookbacks:  30
# days_lookbacks:      [15, 30]
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_11:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SHV', 'TNK']
# sym_freq_5:          ['FTSM', 'HY', 'PDFS']
# sym_freq_4:          ['EME', 'FCN', 'NTRA', 'SRPT']
# sym_freq_3:          ['ASC', 'AXON', 'DY', 'FSLR', 'GE', 'MCFT', 'OTTR', 'PRG', 'SGEN']
# sym_freq_2:          []

# %% [markdown]
# #### Evaluate performance of symbols in set_lookback_slices versus SPY

# %%
# top_set_syms_n_freq
# len(l_sym_freq_cnt)
len(sets_lookback_slices)
# Out:
# 20

# %%
zip_cnt_n_syms = zip([15,14,13,12,11,10,9,8,7,6,5,4,3], l_sym_freq_cnt[:-1])
for stuffs in zip_cnt_n_syms:
  print(stuffs)
# print(list(zip_cnt_n_syms))
# zip_cnt_n_syms
# Out:
# (15, [])
# (14, [])
# (13, [])
# (12, [])
# (11, [])
# (10, [])
# (9, [])
# (8, [])
# (7, [])
# (6, ['LNTH', 'OEC', 'SHV', 'TNK'])
# (5, ['FTSM', 'HY', 'PDFS'])
# (4, ['EME', 'FCN', 'NTRA', 'SRPT'])
# (3, ['ASC', 'AXON', 'DY', 'FSLR', 'GE', 'MCFT', 'OTTR', 'PRG', 'SGEN'])

# %%
print(df_SPY)
print(df_eval)
# Out:
#                    SPY
# Date
# 2023-01-18  390.001556
# 2023-01-19  387.162415
# 2023-01-20  394.374878
# 2023-01-23  399.106812
#                   BABA        BVH      CLAR   DENN       EXAS   GBTC       NATI       NTES       PRGO    RCM        TPX
# Date
# 2023-01-18  113.220001  27.820312  9.326365  12.03  67.919998  10.83  52.221962  88.214859  35.337753  13.16  38.177521
# 2023-01-19  116.580002  28.118494  9.316390  11.98  66.190002  11.46  53.485233  88.962440  36.250980  13.03  37.200146
# 2023-01-20  119.860001  29.370853  9.805151  12.30  68.230003  12.18  53.962692  88.802956  36.250980  12.98  38.287228
# 2023-01-23  119.529999  29.291340  9.705403  12.43  67.820000  12.28  53.544918  89.989120  36.886265  13.32  39.025249

# %%
# col_add1 = ['grp(CAGR)_mean',         'grp(CAGR)_std',         'grp(CAGR)_mean/std']
# col_add2 = ['grp(CAGR/UI)_mean',      'grp(CAGR/UI)_std',      'grp(CAGR/UI)_mean/std']
# col_add3 = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
# col_add4 = ['grp(retnStd/UI)_mean',   'grp(retnStd/UI)_std',   'grp(retnStd/UI)_mean/std']
# col_add5 = ['SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI']

# %%
def compare_picks_v_SPY (df_eval, df_SPY):
  import numpy as np
  from myUtils import symb_perf_stats_vectorized_v8 as sps

  _d_cols_values = {}

  if np.all(df_eval.index == df_SPY.index):
    (
      _symbols,
      _period_yr,
      _retn,
      _DD,
      _UI,
      _MDD,
      _retnMean,
      _retnStd,
      _retnStd_div_UI,
      _CAGR,
      _CAGR_div_retnStd,
      _CAGR_div_UI,
      SPY_retnStd_d_UI,     
      SPY_CAGR,
      SPY_CAGR_d_retnStd,
      SPY_CAGR_d_UI,
    ) = sps(df_SPY)

    (
      _symbols,
      _period_yr,
      _retn,
      _DD,
      _UI,
      _MDD,
      _retnMean,
      _retnStd,
      _retnStd_div_UI,
      _CAGR,
      _CAGR_div_retnStd,
      _CAGR_div_UI,
      grp_retnStd_d_UI,     
      grp_CAGR,
      grp_CAGR_d_retnStd,
      grp_CAGR_d_UI,
    ) = sps(df_eval)  

    ### column names for rows ###
    col_add1 = ['grp(CAGR)_mean',         'grp(CAGR)_std',         'grp(CAGR)_mean/std']
    col_add2 = ['grp(CAGR/UI)_mean',      'grp(CAGR/UI)_std',      'grp(CAGR/UI)_mean/std']
    col_add3 = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
    col_add4 = ['grp(retnStd/UI)_mean',   'grp(retnStd/UI)_std',   'grp(retnStd/UI)_mean/std']
    col_add5 = ['SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI']
    cols = col_add1 + col_add2 + col_add3 + col_add4 + col_add5

    row_add1      = [grp_CAGR[0],           grp_CAGR[1],           grp_CAGR[2]]
    row_add2      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
    row_add3      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
    row_add4      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
    row_add5      = [SPY_CAGR[0], SPY_CAGR_d_UI[0], SPY_CAGR_d_retnStd[0], SPY_retnStd_d_UI[0]]
    rows = row_add1 + row_add2 + row_add3 + row_add4 + row_add5

    _d_cols_values = dict(zip(cols, rows))

  return _d_cols_values

# %%
# d_cols_values  = compare_picks_v_SPY (df_eval, df_SPY)

# val_rows = []
# for key_col in d_cols_values:
#   print(f'{key_col:<30}{d_cols_values[key_col]:>10,.4f}')
#   val_rows.append(d_cols_values[key_col])

# val_rows

# %%
# # row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt]
# row_add1      = [grp_CAGR[0],           grp_CAGR[1],           grp_CAGR[2]]
# row_add2      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
# row_add3      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
# row_add4      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
# row_add5      = [SPY_CAGR[0], SPY_CAGR_d_UI[0], SPY_CAGR_d_retnStd[0], SPY_retnStd_d_UI[0]]
# row_add_total = row_add1 + row_add2 + row_add3 + row_add4 + row_add5
# print(type(row_add_total), type(row_add_total[8]))
# row_add_total

# %%
from myUtils import symb_perf_stats_vectorized_v8

print('z_grp_top_set_syms_n_freq:')
# zip max_lookback_slices with top performing symbols:freq pairs
z_grp_top_set_syms_n_freq = zip(max_lookback_slices, grp_top_set_syms_n_freq)

idx_train = pd.Index([])
idx_eval = pd.Index([])
for i, (_lookback_slice, _top_set_syms_n_freq) in enumerate(z_grp_top_set_syms_n_freq):
  iloc_start_train = _lookback_slice[0]
  iloc_end_train = _lookback_slice[1]
  iloc_start_eval = iloc_end_train
  iloc_end_eval = _lookback_slice[2]

  print(f'{i + 1 } of {n_samples} max_lookback_slice: {_lookback_slice}\n')
  # print(f'max_lookback_slice: {_lookback_slice}\n')
  # dates correspond to max_lookback_slice
  idx_train = df.index[iloc_start_train:iloc_end_train]
  date_start_df_train = idx_train[0].strftime('%Y-%m-%d')
  date_end_df_train = idx_train[-1].strftime('%Y-%m-%d')
  print(f'len(idx_train): {len(idx_train)}')
  print(f'idx_train: {idx_train}')
  print(f'df_train_dates (inclusive): {date_start_df_train} - {date_end_df_train}\n')     

  if run_type != 'current':
    idx_eval = df.index[iloc_start_eval:iloc_end_eval]
    date_start_df_eval = idx_eval[0].strftime('%Y-%m-%d')
    date_end_df_eval = idx_eval[-1].strftime('%Y-%m-%d')
    print(f'len(idx_eval): {len(idx_eval)}')
    print(f'idx_eval: {idx_eval}')
    print(f'df_eval dates (inclusive): {date_start_df_eval} - {date_end_df_eval}\n')
  else: # run_type == "current'
    print(f'run_type: {run_type}, idx_eval is empty: {idx_eval.empty}')

  print(f'top_set_syms_n_freq: {_top_set_syms_n_freq}\n')   

  l_sym_freq_cnt = top_set_sym_freq_cnt(_top_set_syms_n_freq)
  if verbose:
    print(f'set_lookback_slices: {sets_lookback_slices[i]}')    
    print(f'max_lookback_slice:  {_lookback_slice}')
    print(f'days_lookbacks:      {days_lookbacks}')
    print(f'date_end_df_train:   {date_end_df_train}')
    print(f'sym_freq_15:         {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14:         {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13:         {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12:         {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10:         {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9:          {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8:          {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7:          {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6:          {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5:          {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4:          {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3:          {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2:          {l_sym_freq_cnt[13]}\n') 

  if idx_eval.empty:
    if run_type == 'current':
      msg_stop = f'\n\n**** Normal termination for run_type "{run_type}". Wrote current picks to df_picks ****'
      print(f'df_picks:\n{df_picks}')
      raise SystemExit(msg_stop)
    else:
      msg_stop = f'\n\n**** STOPPED df_eval is empty but run_type != "current", the run_type is "{run_type}" ****'
      raise SystemExit(msg_stop)    

  _sym_idx = ['SPY']
  df_SPY = df[iloc_start_eval:iloc_end_eval][_sym_idx]



  print(f'\nSPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR: {SPY_retnStd_d_UI[0]:>17,.1f}, {SPY_CAGR_d_retnStd[0]:>17,.1f}, {SPY_CAGR_d_UI[0]:>17.1f}, {SPY_CAGR[0]:>17.1f}')



  # drop list with frequency count 2 or less, in l_sym_freq_cnt from zip
  zip_cnt_n_syms = zip([15,14,13,12,11,10,9,8,7,6,5,4,3], l_sym_freq_cnt[:-1])
  for item in zip_cnt_n_syms:
    sym_freq_cnt = item[0]
    syms = item[1]
    if syms:  # iterate ONLY if there are symbols in syms
      df_eval = df[iloc_start_eval:iloc_end_eval][syms]      

      if verbose:
        print(f'iloc_start_eval: {iloc_start_eval:>6},  df_eval first date: {date_start_df_eval:>10}') 
        print(f'iloc_end_eval:   {iloc_end_eval:>6},  df_eval last date:  {date_end_df_eval:>10}')        
        print(f'frequency count of symbol(s): {sym_freq_cnt}')      

        syms_n_SPY = syms + ['SPY']
        df_eval_n_SPY = df[iloc_start_eval:iloc_end_eval][syms_n_SPY]   
        print(f'\ndf_eval_n_SPY:\n{df_eval_n_SPY}\n')


      d_cols_values  = compare_picks_v_SPY (df_eval, df_SPY)
      val_rows = []
      for key_col in d_cols_values:
        print(f'{key_col:<30}{d_cols_values[key_col]:>10,.4f}')
        val_rows.append(d_cols_values[key_col])



      print(f'grp(retnStd/UI):   mean, std, mean/std: {grp_retnStd_d_UI[0]  :>17,.1f}, {grp_retnStd_d_UI[1]  :>17,.1f}, {grp_retnStd_d_UI[2]  :>17,.1f}')
      print(f'grp(CAGR/retnStd): mean, std, mean/std: {grp_CAGR_d_retnStd[0]:>17,.1f}, {grp_CAGR_d_retnStd[1]:>17,.1f}, {grp_CAGR_d_retnStd[2]:>17,.1f}')
      print(f'grp(CAGR/UI):      mean, std, mean/std: {grp_CAGR_d_UI[0]     :>17,.1f}, {grp_CAGR_d_UI[1]     :>17,.1f}, {grp_CAGR_d_UI[2]     :>17,.1f}')
      print(f'grp(CAGR):         mean, std, mean/std: {grp_CAGR[0]          :>17,.1f}, {grp_CAGR[1]          :>17,.1f}, {grp_CAGR[2]          :>17,.1f}\n')

      if store_results:  # record results to df
        row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt]
        row_add_total = row_add0 + val_rows
                
        # row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt]
        # row_add1      = [grp_CAGR[0],           grp_CAGR[1],           grp_CAGR[2]]
        # row_add2      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
        # row_add3      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
        # row_add4      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
        # row_add5      = [SPY_CAGR[0], SPY_CAGR_d_UI[0], SPY_CAGR_d_retnStd[0], SPY_retnStd_d_UI[0]]
        # row_add_total = row_add0 + row_add1 + row_add2 + row_add3 + row_add4 + row_add5
        print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f'appended row_add to df_eval_results:\n{row_add_total}\n')
  
  print('='*50, '\n')
# Out:
# z_grp_top_set_syms_n_freq:
# 1 of 20 max_lookback_slice: (111, 141, 145)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03', '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09', '2023-03-10', '2023-03-13'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-30 - 2023-03-13
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-03-14', '2023-03-15', '2023-03-16', '2023-03-17'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-03-14 - 2023-03-17
#
# top_set_syms_n_freq: [('FCN', 6), ('LNTH', 6), ('SGEN', 6), ('SHV', 6), ('ANET', 5), ('FTSM', 5), ('HY', 5), ('NTRA', 5), ('TNK', 5), ('AMPH', 3), ('AXON', 3), ('DY', 3), ('ELF', 3), ('FSLR', 3), ('GE', 3), ('JYNT', 3), ('MLR', 3), ('PCH', 3), ('PDFS', 3), ('SRPT', 3)]
#
# set_lookback_slices: [(126, 141, 145), (111, 141, 145)]
# max_lookback_slice:  (111, 141, 145)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-03-13
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['FCN', 'LNTH', 'SGEN', 'SHV']
# sym_freq_5:          ['ANET', 'FTSM', 'HY', 'NTRA', 'TNK']
# sym_freq_4:          []
# sym_freq_3:          ['AMPH', 'AXON', 'DY', 'ELF', 'FSLR', 'GE', 'JYNT', 'MLR', 'PCH', 'PDFS', 'SRPT']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.0,             541.3,            1634.3,               5.9
# iloc_start_eval:    141,  df_eval first date: 2023-03-14
# iloc_end_eval:      145,  df_eval last date:  2023-03-17
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                    FCN       LNTH        SGEN         SHV         SPY
# Date
# 2023-03-14  196.139999  73.019997  199.839996  110.199997  390.240662
# 2023-03-15  196.130005  73.239998  199.940002  110.309998  387.799957
# 2023-03-16  198.009995  78.830002  200.479996  110.300003  394.603973
# 2023-03-17  195.940002  77.839996  200.300003  110.379997  389.989990
#
# grp(CAGR)_mean                   53.5058
# grp(CAGR)_std                    92.5144
# grp(CAGR)_mean/std                0.5784
# grp(CAGR/UI)_mean             9,435.4133
# grp(CAGR/UI)_std              14,259.3105
# grp(CAGR/UI)_mean/std             0.6617
# grp(CAGR/retnStd)_mean        1,491.7024
# grp(CAGR/retnStd)_std         2,325.9460
# grp(CAGR/retnStd)_mean/std        0.6413
# grp(retnStd/UI)_mean              5.3118
# grp(retnStd/UI)_std               3.2718
# grp(retnStd/UI)_mean/std          1.6235
# SPY_CAGR                         -0.0525
# SPY_CAGR/UI                      -7.9250
# SPY_CAGR/retnStd                 -4.1384
# SPY_retnStd/UI                    1.9150
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    141,  df_eval first date: 2023-03-14
# iloc_end_eval:      145,  df_eval last date:  2023-03-17
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   ANET       FTSM         HY       NTRA        TNK         SPY
# Date
# 2023-03-14  153.149994  59.619999  45.080002  56.430000  44.590000  390.240662
# 2023-03-15  153.800003  59.619999  43.330002  57.040001  42.410000  387.799957
# 2023-03-16  162.679993  59.580002  44.740002  58.290001  41.580002  394.603973
# 2023-03-17  163.259995  59.570000  42.369999  56.630001  40.939999  389.989990
#
# grp(CAGR)_mean                   42.4208
# grp(CAGR)_std                    85.7012
# grp(CAGR)_mean/std                0.4950
# grp(CAGR/UI)_mean             85,527,962.6350
# grp(CAGR/UI)_std              171,055,998.8557
# grp(CAGR/UI)_mean/std             0.5000
# grp(CAGR/retnStd)_mean        1,621.7874
# grp(CAGR/retnStd)_std         3,402.8461
# grp(CAGR/retnStd)_mean/std        0.4766
# grp(retnStd/UI)_mean          10,152.0230
# grp(retnStd/UI)_std           20,302.3738
# grp(retnStd/UI)_mean/std          0.5000
# SPY_CAGR                         -0.0525
# SPY_CAGR/UI                      -7.9250
# SPY_CAGR/retnStd                 -4.1384
# SPY_retnStd/UI                    1.9150
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    141,  df_eval first date: 2023-03-14
# iloc_end_eval:      145,  df_eval last date:  2023-03-17
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AMPH        AXON         DY        ELF        FSLR         GE   JYNT        MLR        PCH       PDFS        SRPT         SPY
# Date
# 2023-03-14  37.200001  215.000000  99.190002  72.019997  207.289993  91.169998  16.35  32.491215  48.070000  38.369999  144.899994  390.240662
# 2023-03-15  36.840000  211.210007  95.389999  73.330002  203.220001  89.760002  15.79  33.197544  48.529999  37.939999  145.470001  387.799957
# 2023-03-16  37.599998  216.979996  97.220001  74.320000  206.559998  91.970001  16.09  34.650002  49.259998  39.439999  149.669998  394.603973
# 2023-03-17  36.290001  213.119995  95.389999  72.470001  199.619995  90.290001  16.02  33.000000  48.990002  39.209999  122.690002  389.989990
#
# grp(CAGR)_mean                    0.6149
# grp(CAGR)_std                     2.1411
# grp(CAGR)_mean/std                0.2872
# grp(CAGR/UI)_mean               195.4511
# grp(CAGR/UI)_std                458.9752
# grp(CAGR/UI)_mean/std             0.4258
# grp(CAGR/retnStd)_mean           50.6580
# grp(CAGR/retnStd)_std           148.0489
# grp(CAGR/retnStd)_mean/std        0.3422
# grp(retnStd/UI)_mean              1.6750
# grp(retnStd/UI)_std               0.8607
# grp(retnStd/UI)_mean/std          1.9461
# SPY_CAGR                         -0.0525
# SPY_CAGR/UI                      -7.9250
# SPY_CAGR/retnStd                 -4.1384
# SPY_retnStd/UI                    1.9150
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# ==================================================
#
# 2 of 20 max_lookback_slice: (96, 126, 130)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-06', '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20', '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-06 - 2023-02-17
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-02-21 - 2023-02-24
#
# top_set_syms_n_freq: [('CTLT', 6), ('TA', 6), ('OEC', 5), ('TSLA', 5), ('WIRE', 5), ('AMCX', 4), ('AN', 4), ('CAR', 4), ('SMG', 4), ('THR', 4), ('CRUS', 3), ('ELF', 3), ('EVRI', 3), ('FCF', 3), ('NATI', 3), ('PAG', 3), ('RVNC', 3), ('STNG', 3), ('TNK', 3), ('ACLS', 2)]
#
# set_lookback_slices: [(111, 126, 130), (96, 126, 130)]
# max_lookback_slice:  (96, 126, 130)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-02-17
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['CTLT', 'TA']
# sym_freq_5:          ['OEC', 'TSLA', 'WIRE']
# sym_freq_4:          ['AMCX', 'AN', 'CAR', 'SMG', 'THR']
# sym_freq_3:          ['CRUS', 'ELF', 'EVRI', 'FCF', 'NATI', 'PAG', 'RVNC', 'STNG', 'TNK']
# sym_freq_2:          ['ACLS']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.0,             541.3,            1634.3,               5.9
# iloc_start_eval:    126,  df_eval first date: 2023-02-21
# iloc_end_eval:      130,  df_eval last date:  2023-02-24
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  CTLT         TA         SPY
# Date
# 2023-02-21  68.660004  84.099998  397.572662
# 2023-02-22  67.660004  84.300003  397.024750
# 2023-02-23  67.650002  84.279999  399.136688
# 2023-02-24  67.980003  84.370003  394.872955
#
# grp(CAGR)_mean                   -0.1288
# grp(CAGR)_std                     0.4378
# grp(CAGR)_mean/std               -0.2942
# grp(CAGR/UI)_mean             1,277.3989
# grp(CAGR/UI)_std              1,326.7797
# grp(CAGR/UI)_mean/std             0.9628
# grp(CAGR/retnStd)_mean          110.3080
# grp(CAGR/retnStd)_std           179.0669
# grp(CAGR/retnStd)_mean/std        0.6160
# grp(retnStd/UI)_mean              4.8587
# grp(retnStd/UI)_std               4.1406
# grp(retnStd/UI)_mean/std          1.1734
# SPY_CAGR                         -0.4358
# SPY_CAGR/UI                     -80.9215
# SPY_CAGR/retnStd                -66.4173
# SPY_retnStd/UI                    1.2184
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    126,  df_eval first date: 2023-02-21
# iloc_end_eval:      130,  df_eval last date:  2023-02-24
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   OEC        TSLA        WIRE         SPY
# Date
# 2023-02-21  24.268862  197.369995  192.350006  397.572662
# 2023-02-22  24.848356  200.860001  188.080002  397.024750
# 2023-02-23  24.768427  202.070007  188.419998  399.136688
# 2023-02-24  25.277981  196.880005  188.479996  394.872955
#
# grp(CAGR)_mean                    9.5424
# grp(CAGR)_std                    14.2095
# grp(CAGR)_mean/std                0.6716
# grp(CAGR/UI)_mean             6,121.8707
# grp(CAGR/UI)_std              8,699.9429
# grp(CAGR/UI)_mean/std             0.7037
# grp(CAGR/retnStd)_mean          790.1847
# grp(CAGR/retnStd)_std         1,177.7606
# grp(CAGR/retnStd)_mean/std        0.6709
# grp(retnStd/UI)_mean              3.1789
# grp(retnStd/UI)_std               3.0767
# grp(retnStd/UI)_mean/std          1.0332
# SPY_CAGR                         -0.4358
# SPY_CAGR/UI                     -80.9215
# SPY_CAGR/retnStd                -66.4173
# SPY_retnStd/UI                    1.2184
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    126,  df_eval first date: 2023-02-21
# iloc_end_eval:      130,  df_eval last date:  2023-02-24
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  AMCX          AN         CAR        SMG        THR         SPY
# Date
# 2023-02-21  23.930000  143.380005  225.240005  81.118446  26.200001  397.572662
# 2023-02-22  23.850000  143.850006  223.529999  82.169998  26.480000  397.024750
# 2023-02-23  24.610001  141.860001  220.130005  82.959999  26.490000  399.136688
# 2023-02-24  23.670000  139.250000  218.210007  82.849998  26.440001  394.872955
#
# grp(CAGR)_mean                    0.7203
# grp(CAGR)_std                     2.2252
# grp(CAGR)_mean/std                0.3237
# grp(CAGR/UI)_mean             1,694.5504
# grp(CAGR/UI)_std              2,886.5973
# grp(CAGR/UI)_mean/std             0.5870
# grp(CAGR/retnStd)_mean          123.3100
# grp(CAGR/retnStd)_std           373.8356
# grp(CAGR/retnStd)_mean/std        0.3299
# grp(retnStd/UI)_mean              3.4401
# grp(retnStd/UI)_std               3.5129
# grp(retnStd/UI)_mean/std          0.9793
# SPY_CAGR                         -0.4358
# SPY_CAGR/UI                     -80.9215
# SPY_CAGR/retnStd                -66.4173
# SPY_retnStd/UI                    1.2184
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    126,  df_eval first date: 2023-02-21
# iloc_end_eval:      130,  df_eval last date:  2023-02-24
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   CRUS        ELF       EVRI        FCF       NATI         PAG       RVNC       STNG        TNK         SPY
# Date
# 2023-02-21  101.660004  73.190002  18.559999  16.290001  52.009998  145.160004  33.180000  60.733772  37.669998  397.572662
# 2023-02-22  101.790001  73.120003  18.600000  15.910000  51.700001  147.600006  33.060001  58.541218  37.360001  397.024750
# 2023-02-23  102.769997  73.750000  18.610001  15.900000  51.049999  145.809998  34.049999  60.654045  42.320000  399.136688
# 2023-02-24  102.080002  73.339996  18.200001  15.780000  50.360001  143.830002  34.119999  61.052689  43.320000  394.872955
#
# grp(CAGR)_mean                13,930.8844
# grp(CAGR)_std                 39,399.8770
# grp(CAGR)_mean/std                0.3536
# grp(CAGR/UI)_mean             3,386,063.8237
# grp(CAGR/UI)_std              9,575,380.7217
# grp(CAGR/UI)_mean/std             0.3536
# grp(CAGR/retnStd)_mean        230,765.0850
# grp(CAGR/retnStd)_std         652,606.9771
# grp(CAGR/retnStd)_mean/std        0.3536
# grp(retnStd/UI)_mean              3.4548
# grp(retnStd/UI)_std               4.5567
# grp(retnStd/UI)_mean/std          0.7582
# SPY_CAGR                         -0.4358
# SPY_CAGR/UI                     -80.9215
# SPY_CAGR/retnStd                -66.4173
# SPY_retnStd/UI                    1.2184
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# ==================================================
#
# 3 of 20 max_lookback_slice: (63, 93, 97)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-11-17', '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28', '2022-11-29', '2022-11-30', '2022-12-01', '2022-12-02', '2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09', '2022-12-12', '2022-12-13', '2022-12-14', '2022-12-15', '2022-12-16', '2022-12-19', '2022-12-20', '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-27', '2022-12-28', '2022-12-29', '2022-12-30'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-11-17 - 2022-12-30
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-01-03 - 2023-01-06
#
# top_set_syms_n_freq: [('HZNP', 6), ('ARWR', 5), ('MSGS', 5), ('SHV', 5), ('BMA', 4), ('BVH', 4), ('CCU', 4), ('FTSM', 4), ('AGYS', 3), ('AJRD', 3), ('AMBC', 3), ('AXSM', 3), ('BURL', 3), ('CROX', 3), ('HAL', 3), ('NVO', 3), ('PBF', 3), ('RCM', 3), ('ZTO', 3), ('ACGL', 2)]
#
# set_lookback_slices: [(78, 93, 97), (63, 93, 97)]
# max_lookback_slice:  (63, 93, 97)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2022-12-30
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['HZNP']
# sym_freq_5:          ['ARWR', 'MSGS', 'SHV']
# sym_freq_4:          ['BMA', 'BVH', 'CCU', 'FTSM']
# sym_freq_3:          ['AGYS', 'AJRD', 'AMBC', 'AXSM', 'BURL', 'CROX', 'HAL', 'NVO', 'PBF', 'RCM', 'ZTO']
# sym_freq_2:          ['ACGL']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.0,             541.3,            1634.3,               5.9
# iloc_start_eval:     93,  df_eval first date: 2023-01-03
# iloc_end_eval:       97,  df_eval last date:  2023-01-06
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   HZNP         SPY
# Date
# 2023-01-03  113.500000  379.372131
# 2023-01-04  113.480003  382.300964
# 2023-01-05  113.239998  377.937592
# 2023-01-06  113.000000  386.604492
#
# grp(CAGR)_mean                   -0.3099
# grp(CAGR)_std                     0.0000
# grp(CAGR)_mean/std                  -inf
# grp(CAGR/UI)_mean              -124.7320
# grp(CAGR/UI)_std                  0.0000
# grp(CAGR/UI)_mean/std               -inf
# grp(CAGR/retnStd)_mean         -338.6489
# grp(CAGR/retnStd)_std             0.0000
# grp(CAGR/retnStd)_mean/std          -inf
# grp(retnStd/UI)_mean              0.3683
# grp(retnStd/UI)_std               0.0000
# grp(retnStd/UI)_mean/std             inf
# SPY_CAGR                          3.8857
# SPY_CAGR/UI                     680.8922
# SPY_CAGR/retnStd                276.5214
# SPY_retnStd/UI                    2.4623
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     93,  df_eval first date: 2023-01-03
# iloc_end_eval:       97,  df_eval last date:  2023-01-06
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  ARWR        MSGS         SHV         SPY
# Date
# 2023-01-03  38.509998  181.270004  109.282875  379.372131
# 2023-01-04  38.080002  186.490005  109.292809  382.300964
# 2023-01-05  37.090000  184.000000  109.312698  377.937592
# 2023-01-06  37.380001  183.669998  109.332573  386.604492
#
# grp(CAGR)_mean                    0.3799
# grp(CAGR)_std                     1.2230
# grp(CAGR)_mean/std                0.3106
# grp(CAGR/UI)_mean             26,007.4977
# grp(CAGR/UI)_std              36,665.5661
# grp(CAGR/UI)_mean/std             0.7093
# grp(CAGR/retnStd)_mean          318.2229
# grp(CAGR/retnStd)_std           423.0833
# grp(CAGR/retnStd)_mean/std        0.7522
# grp(retnStd/UI)_mean             29.3779
# grp(retnStd/UI)_std              39.8987
# grp(retnStd/UI)_mean/std          0.7363
# SPY_CAGR                          3.8857
# SPY_CAGR/UI                     680.8922
# SPY_CAGR/retnStd                276.5214
# SPY_retnStd/UI                    2.4623
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     93,  df_eval first date: 2023-01-03
# iloc_end_eval:       97,  df_eval last date:  2023-01-06
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   BMA        BVH    CCU       FTSM         SPY
# Date
# 2023-01-03  15.810000  25.226133  12.75  59.040157  379.372131
# 2023-01-04  16.520000  25.474619  12.68  59.060020  382.300964
# 2023-01-05  17.610001  25.713165  12.92  59.060020  377.937592
# 2023-01-06  18.110001  25.733042  13.25  59.079887  386.604492
#
# grp(CAGR)_mean                22,539.6105
# grp(CAGR)_std                 39,023.1897
# grp(CAGR)_mean/std                0.5776
# grp(CAGR/UI)_mean             45,067,068,521.5891
# grp(CAGR/UI)_std              78,053,393,583.6788
# grp(CAGR/UI)_mean/std             0.5774
# grp(CAGR/retnStd)_mean        1,465,601.5072
# grp(CAGR/retnStd)_std         2,536,634.9940
# grp(CAGR/retnStd)_mean/std        0.5778
# grp(retnStd/UI)_mean          9,856.4373
# grp(retnStd/UI)_std           12,525.3364
# grp(retnStd/UI)_mean/std          0.7869
# SPY_CAGR                          3.8857
# SPY_CAGR/UI                     680.8922
# SPY_CAGR/retnStd                276.5214
# SPY_retnStd/UI                    2.4623
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     93,  df_eval first date: 2023-01-03
# iloc_end_eval:       97,  df_eval last date:  2023-01-06
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AGYS       AJRD       AMBC       AXSM        BURL        CROX        HAL         NVO        PBF    RCM        ZTO         SPY
# Date
# 2023-01-03  77.769997  55.869999  16.760000  73.320000  206.160004  106.809998  37.497932  136.960007  37.392174  10.73  27.570000  379.372131
# 2023-01-04  77.209999  55.900002  16.790001  73.339996  216.270004  108.529999  38.264622  136.770004  36.984005  11.03  28.400000  382.300964
# 2023-01-05  77.480003  56.090000  16.700001  69.040001  220.740005  109.949997  38.782383  136.250000  38.108955  11.28  27.900000  377.937592
# 2023-01-06  76.360001  55.900002  16.959999  67.989998  223.910004  111.110001  40.036961  138.639999  39.064667  12.43  27.629999  386.604492
#
# grp(CAGR)_mean                21,198.7663
# grp(CAGR)_std                 66,613.0003
# grp(CAGR)_mean/std                0.3182
# grp(CAGR/UI)_mean             42,390,182,743.3305
# grp(CAGR/UI)_std              133,228,337,337.5671
# grp(CAGR/UI)_mean/std             0.3182
# grp(CAGR/retnStd)_mean        592,702.2053
# grp(CAGR/retnStd)_std         1,838,424.7787
# grp(CAGR/retnStd)_mean/std        0.3224
# grp(retnStd/UI)_mean          11,149.7463
# grp(retnStd/UI)_std           21,413.9798
# grp(retnStd/UI)_mean/std          0.5207
# SPY_CAGR                          3.8857
# SPY_CAGR/UI                     680.8922
# SPY_CAGR/retnStd                276.5214
# SPY_retnStd/UI                    2.4623
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# ==================================================
#
# 4 of 20 max_lookback_slice: (44, 74, 78)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-10-21', '2022-10-24', '2022-10-25', '2022-10-26', '2022-10-27', '2022-10-28', '2022-10-31', '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04', '2022-11-07', '2022-11-08', '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-14', '2022-11-15', '2022-11-16', '2022-11-17', '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28', '2022-11-29', '2022-11-30', '2022-12-01', '2022-12-02'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-10-21 - 2022-12-02
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2022-12-05 - 2022-12-08
#
# top_set_syms_n_freq: [('BBW', 6), ('HZNP', 6), ('ROST', 5), ('AEO', 4), ('BURL', 4), ('AXSM', 3), ('BMRN', 3), ('CTRN', 3), ('ENR', 3), ('SRPT', 3), ('ACLS', 2), ('ANF', 2), ('APD', 2), ('AXON', 2), ('AZN', 2), ('AZTA', 2), ('BERY', 2), ('BTI', 2), ('FLO', 2), ('FTSM', 2)]
#
# set_lookback_slices: [(59, 74, 78), (44, 74, 78)]
# max_lookback_slice:  (44, 74, 78)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2022-12-02
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BBW', 'HZNP']
# sym_freq_5:          ['ROST']
# sym_freq_4:          ['AEO', 'BURL']
# sym_freq_3:          ['AXSM', 'BMRN', 'CTRN', 'ENR', 'SRPT']
# sym_freq_2:          ['ACLS', 'ANF', 'APD', 'AXON', 'AZN', 'AZTA', 'BERY', 'BTI', 'FLO', 'FTSM']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.0,             541.3,            1634.3,               5.9
# iloc_start_eval:     74,  df_eval first date: 2022-12-05
# iloc_end_eval:       78,  df_eval last date:  2022-12-08
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   BBW       HZNP         SPY
# Date
# 2022-12-05  23.314154  98.480003  396.251160
# 2022-12-06  23.276625  96.849998  390.539276
# 2022-12-07  23.614376  96.300003  389.874878
# 2022-12-08  24.402460  96.910004  392.929138
#
# grp(CAGR)_mean                   22.2153
# grp(CAGR)_std                    22.9560
# grp(CAGR)_mean/std                0.9677
# grp(CAGR/UI)_mean             28,038.5903
# grp(CAGR/UI)_std              28,085.0199
# grp(CAGR/UI)_mean/std             0.9983
# grp(CAGR/retnStd)_mean        1,540.2034
# grp(CAGR/retnStd)_std         1,619.4526
# grp(CAGR/retnStd)_mean/std        0.9511
# grp(retnStd/UI)_mean              9.1742
# grp(retnStd/UI)_std               8.5884
# grp(retnStd/UI)_mean/std          1.0682
# SPY_CAGR                         -0.5070
# SPY_CAGR/UI                     -43.7547
# SPY_CAGR/retnStd                -55.6267
# SPY_retnStd/UI                    0.7866
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     74,  df_eval first date: 2022-12-05
# iloc_end_eval:       78,  df_eval last date:  2022-12-08
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   ROST         SPY
# Date
# 2022-12-05  116.982582  396.251160
# 2022-12-06  116.155251  390.539276
# 2022-12-07  114.989014  389.874878
# 2022-12-08  116.763290  392.929138
#
# grp(CAGR)_mean                   -0.1458
# grp(CAGR)_std                     0.0000
# grp(CAGR)_mean/std                  -inf
# grp(CAGR/UI)_mean               -15.7252
# grp(CAGR/UI)_std                  0.0000
# grp(CAGR/UI)_mean/std               -inf
# grp(CAGR/retnStd)_mean          -12.8226
# grp(CAGR/retnStd)_std             0.0000
# grp(CAGR/retnStd)_mean/std          -inf
# grp(retnStd/UI)_mean              1.2264
# grp(retnStd/UI)_std               0.0000
# grp(retnStd/UI)_mean/std             inf
# SPY_CAGR                         -0.5070
# SPY_CAGR/UI                     -43.7547
# SPY_CAGR/retnStd                -55.6267
# SPY_retnStd/UI                    0.7866
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     74,  df_eval first date: 2022-12-05
# iloc_end_eval:       78,  df_eval last date:  2022-12-08
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#               AEO        BURL         SPY
# Date
# 2022-12-05  16.08  200.259995  396.251160
# 2022-12-06  15.59  199.649994  390.539276
# 2022-12-07  15.98  198.500000  389.874878
# 2022-12-08  16.26  198.910004  392.929138
#
# grp(CAGR)_mean                    0.5570
# grp(CAGR)_std                     0.9904
# grp(CAGR)_mean/std                0.5624
# grp(CAGR/UI)_mean                12.0227
# grp(CAGR/UI)_std                 87.4867
# grp(CAGR/UI)_mean/std             0.1374
# grp(CAGR/retnStd)_mean          -35.3254
# grp(CAGR/retnStd)_std            98.2733
# grp(CAGR/retnStd)_mean/std       -0.3595
# grp(retnStd/UI)_mean              1.0728
# grp(retnStd/UI)_std               0.5080
# grp(retnStd/UI)_mean/std          2.1120
# SPY_CAGR                         -0.5070
# SPY_CAGR/UI                     -43.7547
# SPY_CAGR/retnStd                -55.6267
# SPY_retnStd/UI                    0.7866
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     74,  df_eval first date: 2022-12-05
# iloc_end_eval:       78,  df_eval last date:  2022-12-08
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AXSM        BMRN       CTRN        ENR        SRPT         SPY
# Date
# 2022-12-05  77.290001  103.529999  30.129999  34.566975  122.959999  396.251160
# 2022-12-06  75.260002  102.220001  30.600000  34.041431  120.099998  390.539276
# 2022-12-07  78.160004  103.690002  29.389999  34.021599  119.760002  389.874878
# 2022-12-08  77.849998  104.389999  29.750000  34.428154  119.339996  392.929138
#
# grp(CAGR)_mean                   -0.0048
# grp(CAGR)_std                     0.7821
# grp(CAGR)_mean/std               -0.0061
# grp(CAGR/UI)_mean                25.6534
# grp(CAGR/UI)_std                 75.9315
# grp(CAGR/UI)_mean/std             0.3378
# grp(CAGR/retnStd)_mean           -5.9180
# grp(CAGR/retnStd)_std            62.1419
# grp(CAGR/retnStd)_mean/std       -0.0952
# grp(retnStd/UI)_mean              1.2557
# grp(retnStd/UI)_std               0.5837
# grp(retnStd/UI)_mean/std          2.1513
# SPY_CAGR                         -0.5070
# SPY_CAGR/UI                     -43.7547
# SPY_CAGR/retnStd                -55.6267
# SPY_retnStd/UI                    0.7866
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# ==================================================
#
# 5 of 20 max_lookback_slice: (104, 134, 138)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-19', '2023-01-20', '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28', '2023-03-01', '2023-03-02'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-19 - 2023-03-02
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-03-03', '2023-03-06', '2023-03-07', '2023-03-08'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-03-03 - 2023-03-08
#
# top_set_syms_n_freq: [('LNTH', 6), ('OEC', 6), ('SGEN', 6), ('TA', 6), ('TNK', 6), ('AMPH', 4), ('HY', 4), ('NTRA', 4), ('PKE', 4), ('SHV', 4), ('ELF', 3), ('EME', 3), ('SRPT', 3), ('ACGL', 2), ('ASC', 2), ('ASTE', 2), ('CTLT', 2), ('DY', 2), ('FCN', 2), ('FTSM', 2)]
#
# set_lookback_slices: [(119, 134, 138), (104, 134, 138)]
# max_lookback_slice:  (104, 134, 138)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-03-02
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SGEN', 'TA', 'TNK']
# sym_freq_5:          []
# sym_freq_4:          ['AMPH', 'HY', 'NTRA', 'PKE', 'SHV']
# sym_freq_3:          ['ELF', 'EME', 'SRPT']
# sym_freq_2:          ['ACGL', 'ASC', 'ASTE', 'CTLT', 'DY', 'FCN', 'FTSM']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.0,             541.3,            1634.3,               5.9
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  LNTH        OEC        SGEN         TA        TNK         SPY
# Date
# 2023-03-03  72.940002  26.666773  181.289993  84.769997  47.549999  402.653259
# 2023-03-06  73.000000  26.287102  177.350006  84.629997  45.910000  402.932220
# 2023-03-07  72.370003  25.987364  177.500000  84.510002  47.290001  396.755768
# 2023-03-08  75.239998  26.686754  176.360001  84.500000  47.330002  397.403320
#
# grp(CAGR)_mean                    2.2351
# grp(CAGR)_std                     5.1768
# grp(CAGR)_mean/std                0.4318
# grp(CAGR/UI)_mean               551.0276
# grp(CAGR/UI)_std              1,181.4976
# grp(CAGR/UI)_mean/std             0.4664
# grp(CAGR/retnStd)_mean           29.7020
# grp(CAGR/retnStd)_std           312.5086
# grp(CAGR/retnStd)_mean/std        0.0950
# grp(retnStd/UI)_mean              1.6752
# grp(retnStd/UI)_std               1.6499
# grp(retnStd/UI)_mean/std          1.0153
# SPY_CAGR                         -0.6679
# SPY_CAGR/UI                     -64.9327
# SPY_CAGR/retnStd                -85.8143
# SPY_retnStd/UI                    0.7567
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  AMPH         HY       NTRA        PKE         SHV         SPY
# Date
# 2023-03-03  36.110001  47.759998  58.119999  15.641175  110.019997  402.653259
# 2023-03-06  35.130001  47.900002  56.730000  14.110655  110.029999  402.932220
# 2023-03-07  35.299999  46.270000  57.250000  13.980000  110.010002  396.755768
# 2023-03-08  35.430000  46.619999  57.730000  13.840000  110.019997  397.403320
#
# grp(CAGR)_mean                   -0.6196
# grp(CAGR)_std                     0.3626
# grp(CAGR)_mean/std               -1.7087
# grp(CAGR/UI)_mean               -24.1421
# grp(CAGR/UI)_std                 16.1118
# grp(CAGR/UI)_mean/std            -1.4984
# grp(CAGR/retnStd)_mean          -30.5172
# grp(CAGR/retnStd)_std            18.8923
# grp(CAGR/retnStd)_mean/std       -1.6153
# grp(retnStd/UI)_mean              0.8761
# grp(retnStd/UI)_std               0.2777
# grp(retnStd/UI)_mean/std          3.1544
# SPY_CAGR                         -0.6679
# SPY_CAGR/UI                     -64.9327
# SPY_CAGR/retnStd                -85.8143
# SPY_retnStd/UI                    0.7567
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   ELF         EME        SRPT         SPY
# Date
# 2023-03-03  75.190002  168.949997  155.610001  402.653259
# 2023-03-06  72.080002  166.490005  155.990005  402.932220
# 2023-03-07  73.699997  165.809998  155.610001  396.755768
# 2023-03-08  74.010002  167.970001  152.960007  397.403320
#
# grp(CAGR)_mean                   -0.6285
# grp(CAGR)_std                     0.1715
# grp(CAGR)_mean/std               -3.6652
# grp(CAGR/UI)_mean               -46.7194
# grp(CAGR/UI)_std                 22.1453
# grp(CAGR/UI)_mean/std            -2.1097
# grp(CAGR/retnStd)_mean          -51.2350
# grp(CAGR/retnStd)_std            29.1778
# grp(CAGR/retnStd)_mean/std       -1.7560
# grp(retnStd/UI)_mean              0.9627
# grp(retnStd/UI)_std               0.1088
# grp(retnStd/UI)_mean/std          8.8446
# SPY_CAGR                         -0.6679
# SPY_CAGR/UI                     -64.9327
# SPY_CAGR/retnStd                -85.8143
# SPY_retnStd/UI                    0.7567
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# ==================================================
#
# 6 of 20 max_lookback_slice: (50, 80, 84)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-10-31', '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04', '2022-11-07', '2022-11-08', '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-14', '2022-11-15', '2022-11-16', '2022-11-17', '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28', '2022-11-29', '2022-11-30', '2022-12-01', '2022-12-02', '2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09', '2022-12-12'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-10-31 - 2022-12-12
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2022-12-13', '2022-12-14', '2022-12-15', '2022-12-16'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2022-12-13 - 2022-12-16
#
# top_set_syms_n_freq: [('BBW', 6), ('ZTO', 6), ('AXSM', 5), ('BVH', 5), ('HZNP', 5), ('WB', 5), ('ANF', 4), ('BIDU', 4), ('GDS', 4), ('SHV', 4), ('WYNN', 4), ('ACLS', 3), ('AEO', 3), ('AU', 3), ('BERY', 3), ('BURL', 3), ('CTRN', 3), ('FTSM', 3), ('NVO', 3), ('RARE', 3)]
#
# set_lookback_slices: [(65, 80, 84), (50, 80, 84)]
# max_lookback_slice:  (50, 80, 84)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2022-12-12
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BBW', 'ZTO']
# sym_freq_5:          ['AXSM', 'BVH', 'HZNP', 'WB']
# sym_freq_4:          ['ANF', 'BIDU', 'GDS', 'SHV', 'WYNN']
# sym_freq_3:          ['ACLS', 'AEO', 'AU', 'BERY', 'BURL', 'CTRN', 'FTSM', 'NVO', 'RARE']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.0,             541.3,            1634.3,               5.9
# iloc_start_eval:     80,  df_eval first date: 2022-12-13
# iloc_end_eval:       84,  df_eval last date:  2022-12-16
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   BBW        ZTO         SPY
# Date
# 2022-12-13  24.355549  26.500000  398.611298
# 2022-12-14  24.834028  26.670000  396.062775
# 2022-12-15  23.567467  26.860001  386.374390
# 2022-12-16  23.595612  26.879999  381.812805
#
# grp(CAGR)_mean                    0.6883
# grp(CAGR)_std                     1.6185
# grp(CAGR)_mean/std                0.4252
# grp(CAGR/UI)_mean             2,306,754.4418
# grp(CAGR/UI)_std              2,306,780.5248
# grp(CAGR/UI)_mean/std             1.0000
# grp(CAGR/retnStd)_mean          388.4471
# grp(CAGR/retnStd)_std           419.5402
# grp(CAGR/retnStd)_mean/std        0.9259
# grp(retnStd/UI)_mean          2,855.3746
# grp(retnStd/UI)_std           2,854.5358
# grp(retnStd/UI)_mean/std          1.0003
# SPY_CAGR                         -0.9731
# SPY_CAGR/UI                     -37.0512
# SPY_CAGR/retnStd               -128.5286
# SPY_retnStd/UI                    0.2883
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     80,  df_eval first date: 2022-12-13
# iloc_end_eval:       84,  df_eval last date:  2022-12-16
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  AXSM        BVH        HZNP         WB         SPY
# Date
# 2022-12-13  79.449997  24.331591  112.900002  18.480000  398.611298
# 2022-12-14  79.720001  24.709288  113.129997  18.440001  396.062775
# 2022-12-15  77.459999  24.570135  113.000000  18.410000  386.374390
# 2022-12-16  78.400002  24.460804  112.879997  17.590000  381.812805
#
# grp(CAGR)_mean                   -0.2779
# grp(CAGR)_std                     0.5972
# grp(CAGR)_mean/std               -0.4653
# grp(CAGR/UI)_mean                 0.9178
# grp(CAGR/UI)_std                 56.8524
# grp(CAGR/UI)_mean/std             0.0161
# grp(CAGR/retnStd)_mean           -9.9688
# grp(CAGR/retnStd)_std            41.6169
# grp(CAGR/retnStd)_mean/std       -0.2395
# grp(retnStd/UI)_mean              1.1913
# grp(retnStd/UI)_std               0.3121
# grp(retnStd/UI)_mean/std          3.8166
# SPY_CAGR                         -0.9731
# SPY_CAGR/UI                     -37.0512
# SPY_CAGR/retnStd               -128.5286
# SPY_retnStd/UI                    0.2883
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     80,  df_eval first date: 2022-12-13
# iloc_end_eval:       84,  df_eval last date:  2022-12-16
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   ANF        BIDU        GDS         SHV       WYNN         SPY
# Date
# 2022-12-13  23.110001  119.160004  19.990000  109.041298  86.669998  398.611298
# 2022-12-14  23.209999  119.220001  21.110001  109.031387  86.320000  396.062775
# 2022-12-15  21.780001  113.699997  19.450001  109.084068  84.949997  386.374390
# 2022-12-16  21.780001  112.589996  19.990000  109.103951  86.010002  381.812805
#
# grp(CAGR)_mean                   -0.4818
# grp(CAGR)_std                     0.4551
# grp(CAGR)_mean/std               -1.0586
# grp(CAGR/UI)_mean               198.7581
# grp(CAGR/UI)_std                444.7350
# grp(CAGR/UI)_mean/std             0.4469
# grp(CAGR/retnStd)_mean           17.5512
# grp(CAGR/retnStd)_std            98.0835
# grp(CAGR/retnStd)_mean/std        0.1789
# grp(retnStd/UI)_mean              1.7405
# grp(retnStd/UI)_std               1.7265
# grp(retnStd/UI)_mean/std          1.0081
# SPY_CAGR                         -0.9731
# SPY_CAGR/UI                     -37.0512
# SPY_CAGR/retnStd               -128.5286
# SPY_retnStd/UI                    0.2883
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     80,  df_eval first date: 2022-12-13
# iloc_end_eval:       84,  df_eval last date:  2022-12-16
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ACLS    AEO         AU       BERY        BURL       CTRN       FTSM         NVO       RARE         SPY
# Date
# 2022-12-13  86.519997  15.47  19.136503  61.440685  196.669998  29.709999  58.890553  132.839996  44.930000  398.611298
# 2022-12-14  85.410004  15.28  19.334707  61.042305  196.169998  28.990000  58.910355  134.720001  45.459999  396.062775
# 2022-12-15  82.760002  14.66  18.541895  59.797356  191.440002  28.250000  58.910355  133.679993  45.570000  386.374390
# 2022-12-16  81.430000  14.58  18.551805  59.508530  185.800003  27.540001  58.920258  133.179993  45.630001  381.812805
#
# grp(CAGR)_mean                   -0.3209
# grp(CAGR)_std                     1.1504
# grp(CAGR)_mean/std               -0.2789
# grp(CAGR/UI)_mean             601,646.5945
# grp(CAGR/UI)_std              1,671,387.4784
# grp(CAGR/UI)_mean/std             0.3600
# grp(CAGR/retnStd)_mean         -154.4954
# grp(CAGR/retnStd)_std           637.9254
# grp(CAGR/retnStd)_mean/std       -0.2422
# grp(retnStd/UI)_mean          1,075.7071
# grp(retnStd/UI)_std           2,945.5022
# grp(retnStd/UI)_mean/std          0.3652
# SPY_CAGR                         -0.9731
# SPY_CAGR/UI                     -37.0512
# SPY_CAGR/retnStd               -128.5286
# SPY_retnStd/UI                    0.2883
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# ==================================================
#
# 7 of 20 max_lookback_slice: (102, 132, 136)
#
# len(idx_train): 30
# ...
# date_end_df_train:   2022-12-28
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['FTSM', 'HZNP', 'SHV']
# sym_freq_5:          ['MSGS']
# sym_freq_4:          ['AJRD', 'BVH', 'EDU', 'NVO', 'ZTO']
# sym_freq_3:          ['ACGL', 'AGYS', 'AXSM', 'BMA', 'BURL', 'CAG', 'CALM', 'CCU', 'CPB', 'KHC', 'PBF']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.0,             541.3,            1634.3,               5.9
# iloc_start_eval:     91,  df_eval first date: 2022-12-29
# iloc_end_eval:       95,  df_eval last date:  2023-01-04
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  FTSM        HZNP         SHV         SPY
# Date
# 2022-12-29  59.040157  113.510002  109.272926  381.982178
# 2022-12-30  59.040157  113.800003  109.262993  380.975983
# 2023-01-03  59.040157  113.500000  109.282875  379.372131
# 2023-01-04  59.060020  113.480003  109.292809  382.300964
#
# grp(CAGR)_mean                    0.0074
# grp(CAGR)_std                     0.0214
# grp(CAGR)_mean/std                0.3438
# grp(CAGR/UI)_mean             19,214.9389
# grp(CAGR/UI)_std              26,942.8883
# grp(CAGR/UI)_mean/std             0.7132
# grp(CAGR/retnStd)_mean          102.0352
# grp(CAGR/retnStd)_std            81.5633
# grp(CAGR/retnStd)_mean/std        1.2510
# grp(retnStd/UI)_mean            106.9297
# grp(retnStd/UI)_std             148.6799
# grp(retnStd/UI)_mean/std          0.7192
# SPY_CAGR                          0.0726
# SPY_CAGR/UI                      19.8243
# SPY_CAGR/retnStd                 13.7171
# SPY_retnStd/UI                    1.4452
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     91,  df_eval first date: 2022-12-29
# iloc_end_eval:       95,  df_eval last date:  2023-01-04
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   MSGS         SPY
# Date
# 2022-12-29  181.479996  381.982178
# 2022-12-30  183.330002  380.975983
# 2023-01-03  181.270004  379.372131
# 2023-01-04  186.490005  382.300964
#
# grp(CAGR)_mean                    8.8503
# grp(CAGR)_std                     0.0000
# grp(CAGR)_mean/std                   inf
# grp(CAGR/UI)_mean             1,575.2769
# grp(CAGR/UI)_std                  0.0000
# grp(CAGR/UI)_mean/std                inf
# grp(CAGR/retnStd)_mean          541.0689
# grp(CAGR/retnStd)_std             0.0000
# grp(CAGR/retnStd)_mean/std           inf
# grp(retnStd/UI)_mean              2.9114
# grp(retnStd/UI)_std               0.0000
# grp(retnStd/UI)_mean/std             inf
# SPY_CAGR                          0.0726
# SPY_CAGR/UI                      19.8243
# SPY_CAGR/retnStd                 13.7171
# SPY_retnStd/UI                    1.4452
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     91,  df_eval first date: 2022-12-29
# iloc_end_eval:       95,  df_eval last date:  2023-01-04
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  AJRD        BVH        EDU         NVO        ZTO         SPY
# Date
# 2022-12-29  56.000000  24.550259  36.040001  135.199997  26.879999  381.982178
# 2022-12-30  55.930000  24.808680  34.820000  135.339996  26.870001  380.975983
# 2023-01-03  55.869999  25.226133  34.650002  136.960007  27.570000  379.372131
# 2023-01-04  55.900002  25.474619  35.220001  136.770004  28.400000  382.300964
#
# grp(CAGR)_mean                   24.4990
# grp(CAGR)_std                    38.9015
# grp(CAGR)_mean/std                0.6298
# grp(CAGR/UI)_mean             8,629,227.1156
# grp(CAGR/UI)_std              16,988,294.1601
# grp(CAGR/UI)_mean/std             0.5080
# grp(CAGR/retnStd)_mean        2,857.6437
# grp(CAGR/retnStd)_std         3,481.9936
# grp(CAGR/retnStd)_mean/std        0.8207
# grp(retnStd/UI)_mean          1,273.1095
# grp(retnStd/UI)_std           2,505.2272
# grp(retnStd/UI)_mean/std          0.5082
# SPY_CAGR                          0.0726
# SPY_CAGR/UI                      19.8243
# SPY_CAGR/retnStd                 13.7171
# SPY_retnStd/UI                    1.4452
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:     91,  df_eval first date: 2022-12-29
# iloc_end_eval:       95,  df_eval last date:  2023-01-04
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ACGL       AGYS       AXSM        BMA        BURL        CAG       CALM    CCU        CPB        KHC        PBF         SPY
# Date
# 2022-12-29  63.110001  80.180000  76.500000  16.299999  205.830002  38.422710  51.862045  13.25  56.336643  40.255363  40.816803  381.982178
# 2022-12-30  62.779999  79.139999  77.129997  16.420000  202.759995  38.353340  53.110561  13.12  56.376377  40.285049  40.597782  380.975983
# 2023-01-03  62.459999  77.769997  73.320000  15.810000  206.160004  38.482174  54.124981  12.75  55.830002  40.354321  37.392174  379.372131
# 2023-01-04  62.770000  77.209999  73.339996  16.520000  216.270004  38.303787  55.822174  12.68  55.759998  40.809521  36.984005  382.300964
#
# grp(CAGR)_mean                   49.4983
# grp(CAGR)_std                   138.1092
# grp(CAGR)_mean/std                0.3584
# grp(CAGR/UI)_mean             88,119,629.5408
# grp(CAGR/UI)_std              277,296,991.1270
# grp(CAGR/UI)_mean/std             0.3178
# grp(CAGR/retnStd)_mean        8,919.0681
# grp(CAGR/retnStd)_std         27,502.7023
# grp(CAGR/retnStd)_mean/std        0.3243
# grp(retnStd/UI)_mean          1,780.6404
# grp(retnStd/UI)_std           3,776.8662
# grp(retnStd/UI)_mean/std          0.4715
# SPY_CAGR                          0.0726
# SPY_CAGR/UI                      19.8243
# SPY_CAGR/retnStd                 13.7171
# SPY_retnStd/UI                    1.4452
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# ==================================================
#
# 20 of 20 max_lookback_slice: (109, 139, 143)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-26', '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03', '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-26 - 2023-03-09
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-03-10', '2023-03-13', '2023-03-14', '2023-03-15'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-03-10 - 2023-03-15
#
# top_set_syms_n_freq: [('LNTH', 6), ('OEC', 6), ('SHV', 6), ('TNK', 6), ('FTSM', 5), ('HY', 5), ('PDFS', 5), ('EME', 4), ('FCN', 4), ('NTRA', 4), ('SRPT', 4), ('ASC', 3), ('AXON', 3), ('DY', 3), ('FSLR', 3), ('GE', 3), ('MCFT', 3), ('OTTR', 3), ('PRG', 3), ('SGEN', 3)]
#
# set_lookback_slices: [(124, 139, 143), (109, 139, 143)]
# max_lookback_slice:  (109, 139, 143)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-03-09
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SHV', 'TNK']
# sym_freq_5:          ['FTSM', 'HY', 'PDFS']
# sym_freq_4:          ['EME', 'FCN', 'NTRA', 'SRPT']
# sym_freq_3:          ['ASC', 'AXON', 'DY', 'FSLR', 'GE', 'MCFT', 'OTTR', 'PRG', 'SGEN']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.0,             541.3,            1634.3,               5.9
# iloc_start_eval:    139,  df_eval first date: 2023-03-10
# iloc_end_eval:      143,  df_eval last date:  2023-03-15
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  LNTH        OEC         SHV        TNK         SPY
# Date
# 2023-03-10  71.260002  24.508652  110.129997  44.639999  384.442780
# 2023-03-13  70.750000  23.929157  110.260002  43.290001  383.894836
# 2023-03-14  73.019997  24.508652  110.199997  44.590000  390.240662
# 2023-03-15  73.239998  23.819252  110.309998  42.410000  387.799957
#
# grp(CAGR)_mean                    1.8118
# grp(CAGR)_std                     4.1717
# grp(CAGR)_mean/std                0.4343
# grp(CAGR/UI)_mean               742.7311
# grp(CAGR/UI)_std              1,049.7946
# grp(CAGR/UI)_mean/std             0.7075
# grp(CAGR/retnStd)_mean          165.8439
# grp(CAGR/retnStd)_std           235.1037
# grp(CAGR/retnStd)_mean/std        0.7054
# grp(retnStd/UI)_mean              2.4832
# grp(retnStd/UI)_std               1.4146
# grp(retnStd/UI)_mean/std          1.7554
# SPY_CAGR                          1.0758
# SPY_CAGR/UI                     335.4206
# SPY_CAGR/retnStd                109.7457
# SPY_retnStd/UI                    3.0563
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    139,  df_eval first date: 2023-03-10
# iloc_end_eval:      143,  df_eval last date:  2023-03-15
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  FTSM         HY       PDFS         SPY
# Date
# 2023-03-10  59.540001  45.580002  37.080002  384.442780
# 2023-03-13  59.570000  44.340000  36.650002  383.894836
# 2023-03-14  59.619999  45.080002  38.369999  390.240662
# 2023-03-15  59.619999  43.330002  37.939999  387.799957
#
# grp(CAGR)_mean                    1.6651
# grp(CAGR)_std                     3.0016
# grp(CAGR)_mean/std                0.5548
# grp(CAGR/UI)_mean             79,826.3389
# grp(CAGR/UI)_std              112,402.1578
# grp(CAGR/UI)_mean/std             0.7102
# grp(CAGR/retnStd)_mean          172.6832
# grp(CAGR/retnStd)_std           160.7083
# grp(CAGR/retnStd)_mean/std        1.0745
# grp(retnStd/UI)_mean            231.3792
# grp(retnStd/UI)_std             324.2211
# grp(retnStd/UI)_mean/std          0.7136
# SPY_CAGR                          1.0758
# SPY_CAGR/UI                     335.4206
# SPY_CAGR/retnStd                109.7457
# SPY_retnStd/UI                    3.0563
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    139,  df_eval first date: 2023-03-10
# iloc_end_eval:      143,  df_eval last date:  2023-03-15
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                    EME         FCN       NTRA        SRPT         SPY
# Date
# 2023-03-10  158.490005  186.580002  54.130001  143.919998  384.442780
# 2023-03-13  155.679993  195.240005  55.180000  142.770004  383.894836
# 2023-03-14  158.389999  196.139999  56.430000  144.899994  390.240662
# 2023-03-15  155.910004  196.130005  57.040001  145.470001  387.799957
#
# grp(CAGR)_mean                   36.5685
# grp(CAGR)_std                    36.6132
# grp(CAGR)_mean/std                0.9988
# grp(CAGR/UI)_mean             40,808,308.6290
# grp(CAGR/UI)_std              69,211,699.9819
# grp(CAGR/UI)_mean/std             0.5896
# grp(CAGR/retnStd)_mean        4,828.1708
# grp(CAGR/retnStd)_std         6,616.8709
# grp(CAGR/retnStd)_mean/std        0.7297
# grp(retnStd/UI)_mean          2,703.7676
# grp(retnStd/UI)_std           4,220.7416
# grp(retnStd/UI)_mean/std          0.6406
# SPY_CAGR                          1.0758
# SPY_CAGR/UI                     335.4206
# SPY_CAGR/retnStd                109.7457
# SPY_retnStd/UI                    3.0563
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# iloc_start_eval:    139,  df_eval first date: 2023-03-10
# iloc_end_eval:      143,  df_eval last date:  2023-03-15
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#               ASC        AXON         DY        FSLR         GE       MCFT       OTTR        PRG        SGEN         SPY
# Date
# 2023-03-10  17.35  213.000000  99.239998  207.729996  91.000000  32.520000  68.989998  24.700001  172.610001  384.442780
# 2023-03-13  16.49  211.000000  96.529999  203.580002  88.970001  31.180000  67.980003  23.690001  197.649994  383.894836
# 2023-03-14  16.91  215.000000  99.190002  207.289993  91.169998  32.110001  69.529999  23.950001  199.839996  390.240662
# 2023-03-15  15.43  211.210007  95.389999  203.220001  89.760002  32.009998  69.070000  23.070000  199.940002  387.799957
#
# grp(CAGR)_mean                25,572.8458
# grp(CAGR)_std                 72,332.9203
# grp(CAGR)_mean/std                0.3535
# grp(CAGR/UI)_mean             51,146,942,087.7405
# grp(CAGR/UI)_std              144,665,398,440.0732
# grp(CAGR/UI)_mean/std             0.3536
# grp(CAGR/retnStd)_mean        388,643.8790
# grp(CAGR/retnStd)_std         1,099,331.6473
# grp(CAGR/retnStd)_mean/std        0.3535
# grp(retnStd/UI)_mean          14,622.7939
# grp(retnStd/UI)_std           41,355.9301
# grp(retnStd/UI)_mean/std          0.3536
# SPY_CAGR                          1.0758
# SPY_CAGR/UI                     335.4206
# SPY_CAGR/retnStd                109.7457
# SPY_retnStd/UI                    3.0563
# grp(retnStd/UI):   mean, std, mean/std:           6,458.2,          14,924.4,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         142,604.4,         445,552.3,               0.3
# grp(CAGR/UI):      mean, std, mean/std:   6,980,758,716.8,  22,052,488,323.8,               0.3
# grp(CAGR):         mean, std, mean/std:           3,511.2,          11,019.7,               0.3
#
# ==================================================

# %%
from myUtils import symb_perf_stats_vectorized_v8

print('z_grp_top_set_syms_n_freq:')
# zip max_lookback_slices with top performing symbols:freq pairs
z_grp_top_set_syms_n_freq = zip(max_lookback_slices, grp_top_set_syms_n_freq)

idx_train = pd.Index([])
idx_eval = pd.Index([])
for i, (_lookback_slice, _top_set_syms_n_freq) in enumerate(z_grp_top_set_syms_n_freq):
  iloc_start_train = _lookback_slice[0]
  iloc_end_train = _lookback_slice[1]
  iloc_start_eval = iloc_end_train
  iloc_end_eval = _lookback_slice[2]

  print(f'{i + 1 } of {n_samples} max_lookback_slice: {_lookback_slice}\n')
  # print(f'max_lookback_slice: {_lookback_slice}\n')
  # dates correspond to max_lookback_slice
  idx_train = df.index[iloc_start_train:iloc_end_train]
  date_start_df_train = idx_train[0].strftime('%Y-%m-%d')
  date_end_df_train = idx_train[-1].strftime('%Y-%m-%d')
  print(f'len(idx_train): {len(idx_train)}')
  print(f'idx_train: {idx_train}')
  print(f'df_train_dates (inclusive): {date_start_df_train} - {date_end_df_train}\n')     

  if run_type != 'current':
    idx_eval = df.index[iloc_start_eval:iloc_end_eval]
    date_start_df_eval = idx_eval[0].strftime('%Y-%m-%d')
    date_end_df_eval = idx_eval[-1].strftime('%Y-%m-%d')
    print(f'len(idx_eval): {len(idx_eval)}')
    print(f'idx_eval: {idx_eval}')
    print(f'df_eval dates (inclusive): {date_start_df_eval} - {date_end_df_eval}\n')
  else: # run_type == "current'
    print(f'run_type: {run_type}, idx_eval is empty: {idx_eval.empty}')

  print(f'top_set_syms_n_freq: {_top_set_syms_n_freq}\n')   

  l_sym_freq_cnt = top_set_sym_freq_cnt(_top_set_syms_n_freq)
  if verbose:
    print(f'set_lookback_slices: {sets_lookback_slices[i]}')    
    print(f'max_lookback_slice:  {_lookback_slice}')
    print(f'days_lookbacks:      {days_lookbacks}')
    print(f'date_end_df_train:   {date_end_df_train}')
    print(f'sym_freq_15:         {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14:         {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13:         {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12:         {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10:         {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9:          {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8:          {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7:          {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6:          {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5:          {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4:          {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3:          {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2:          {l_sym_freq_cnt[13]}\n') 

  if idx_eval.empty:
    if run_type == 'current':
      msg_stop = f'\n\n**** Normal termination for run_type "{run_type}". Wrote current picks to df_picks ****'
      print(f'df_picks:\n{df_picks}')
      raise SystemExit(msg_stop)
    else:
      msg_stop = f'\n\n**** STOPPED df_eval is empty but run_type != "current", the run_type is "{run_type}" ****'
      raise SystemExit(msg_stop)    

  _sym_idx = ['SPY']
  df_SPY = df[iloc_start_eval:iloc_end_eval][_sym_idx]

  (
    _symbols,
    _period_yr,
    _retn,
    _DD,
    _UI,
    _MDD,
    _retnMean,
    _retnStd,
    _retnStd_div_UI,
    _CAGR,
    _CAGR_div_retnStd,
    _CAGR_div_UI,
    SPY_retnStd_d_UI,     
    SPY_CAGR,
    SPY_CAGR_d_retnStd,
    SPY_CAGR_d_UI,
  ) = symb_perf_stats_vectorized_v8(df_SPY)  

  print(f'\nSPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR: {SPY_retnStd_d_UI[0]:>17,.1f}, {SPY_CAGR_d_retnStd[0]:>17,.1f}, {SPY_CAGR_d_UI[0]:>17.1f}, {SPY_CAGR[0]:>17.1f}')

  # drop list with frequency count 2 or less, in l_sym_freq_cnt from zip
  zip_cnt_n_syms = zip([15,14,13,12,11,10,9,8,7,6,5,4,3], l_sym_freq_cnt[:-1])
  for item in zip_cnt_n_syms:
    sym_freq_cnt = item[0]
    syms = item[1]
    if syms:  # iterate ONLY if there are symbols in syms
      df_eval = df[iloc_start_eval:iloc_end_eval][syms]      

      if verbose:
        print(f'iloc_start_eval: {iloc_start_eval:>6},  df_eval first date: {date_start_df_eval:>10}') 
        print(f'iloc_end_eval:   {iloc_end_eval:>6},  df_eval last date:  {date_end_df_eval:>10}')        
        print(f'frequency count of symbol(s): {sym_freq_cnt}')      

        syms_n_SPY = syms + ['SPY']
        df_eval_n_SPY = df[iloc_start_eval:iloc_end_eval][syms_n_SPY]   
        print(f'\ndf_eval_n_SPY:\n{df_eval_n_SPY}\n')

      (
        _symbols,
        _period_yr,
        _retn,
        _DD,
        _UI,
        _MDD,
        _retnMean,
        _retnStd,
        _retnStd_div_UI,
        _CAGR,
        _CAGR_div_retnStd,
        _CAGR_div_UI,
        grp_retnStd_d_UI,     
        grp_CAGR,
        grp_CAGR_d_retnStd,
        grp_CAGR_d_UI,
      ) = symb_perf_stats_vectorized_v8(df_eval)  
      print(f'grp(retnStd/UI):   mean, std, mean/std: {grp_retnStd_d_UI[0]  :>17,.1f}, {grp_retnStd_d_UI[1]  :>17,.1f}, {grp_retnStd_d_UI[2]  :>17,.1f}')
      print(f'grp(CAGR/retnStd): mean, std, mean/std: {grp_CAGR_d_retnStd[0]:>17,.1f}, {grp_CAGR_d_retnStd[1]:>17,.1f}, {grp_CAGR_d_retnStd[2]:>17,.1f}')
      print(f'grp(CAGR/UI):      mean, std, mean/std: {grp_CAGR_d_UI[0]     :>17,.1f}, {grp_CAGR_d_UI[1]     :>17,.1f}, {grp_CAGR_d_UI[2]     :>17,.1f}')
      print(f'grp(CAGR):         mean, std, mean/std: {grp_CAGR[0]          :>17,.1f}, {grp_CAGR[1]          :>17,.1f}, {grp_CAGR[2]          :>17,.1f}\n')

      if store_results:  # record results to df
        row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt]
        row_add1      = [grp_CAGR[0],           grp_CAGR[1],           grp_CAGR[2]]
        row_add2      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
        row_add3      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
        row_add4      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
        row_add5      = [SPY_CAGR[0], SPY_CAGR_d_UI[0], SPY_CAGR_d_retnStd[0], SPY_retnStd_d_UI[0]]
        row_add_total = row_add0 + row_add1 + row_add2 + row_add3 + row_add4 + row_add5
        print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f'appended row_add to df_eval_results:\n{row_add_total}\n')
  
  print('='*50, '\n')
# Out:
# z_grp_top_set_syms_n_freq:
# 1 of 20 max_lookback_slice: (111, 141, 145)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03', '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09', '2023-03-10', '2023-03-13'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-30 - 2023-03-13
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-03-14', '2023-03-15', '2023-03-16', '2023-03-17'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-03-14 - 2023-03-17
#
# top_set_syms_n_freq: [('FCN', 6), ('LNTH', 6), ('SGEN', 6), ('SHV', 6), ('ANET', 5), ('FTSM', 5), ('HY', 5), ('NTRA', 5), ('TNK', 5), ('AMPH', 3), ('AXON', 3), ('DY', 3), ('ELF', 3), ('FSLR', 3), ('GE', 3), ('JYNT', 3), ('MLR', 3), ('PCH', 3), ('PDFS', 3), ('SRPT', 3)]
#
# set_lookback_slices: [(126, 141, 145), (111, 141, 145)]
# max_lookback_slice:  (111, 141, 145)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-03-13
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['FCN', 'LNTH', 'SGEN', 'SHV']
# sym_freq_5:          ['ANET', 'FTSM', 'HY', 'NTRA', 'TNK']
# sym_freq_4:          []
# sym_freq_3:          ['AMPH', 'AXON', 'DY', 'ELF', 'FSLR', 'GE', 'JYNT', 'MLR', 'PCH', 'PDFS', 'SRPT']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.9,              -4.1,              -7.9,              -0.1
# iloc_start_eval:    141,  df_eval first date: 2023-03-14
# iloc_end_eval:      145,  df_eval last date:  2023-03-17
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                    FCN       LNTH        SGEN         SHV         SPY
# Date
# 2023-03-14  196.139999  73.019997  199.839996  110.199997  390.240662
# 2023-03-15  196.130005  73.239998  199.940002  110.309998  387.799957
# 2023-03-16  198.009995  78.830002  200.479996  110.300003  394.603973
# 2023-03-17  195.940002  77.839996  200.300003  110.379997  389.989990
#
# grp(retnStd/UI):   mean, std, mean/std:               5.3,               3.3,               1.6
# grp(CAGR/retnStd): mean, std, mean/std:           1,491.7,           2,325.9,               0.6
# grp(CAGR/UI):      mean, std, mean/std:           9,435.4,          14,259.3,               0.7
# grp(CAGR):         mean, std, mean/std:              53.5,              92.5,               0.6
#
# iloc_start_eval:    141,  df_eval first date: 2023-03-14
# iloc_end_eval:      145,  df_eval last date:  2023-03-17
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   ANET       FTSM         HY       NTRA        TNK         SPY
# Date
# 2023-03-14  153.149994  59.619999  45.080002  56.430000  44.590000  390.240662
# 2023-03-15  153.800003  59.619999  43.330002  57.040001  42.410000  387.799957
# 2023-03-16  162.679993  59.580002  44.740002  58.290001  41.580002  394.603973
# 2023-03-17  163.259995  59.570000  42.369999  56.630001  40.939999  389.989990
#
# grp(retnStd/UI):   mean, std, mean/std:          10,152.0,          20,302.4,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:           1,621.8,           3,402.8,               0.5
# grp(CAGR/UI):      mean, std, mean/std:      85,527,962.6,     171,055,998.9,               0.5
# grp(CAGR):         mean, std, mean/std:              42.4,              85.7,               0.5
#
# iloc_start_eval:    141,  df_eval first date: 2023-03-14
# iloc_end_eval:      145,  df_eval last date:  2023-03-17
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AMPH        AXON         DY        ELF        FSLR         GE   JYNT        MLR        PCH       PDFS        SRPT         SPY
# Date
# 2023-03-14  37.200001  215.000000  99.190002  72.019997  207.289993  91.169998  16.35  32.491215  48.070000  38.369999  144.899994  390.240662
# 2023-03-15  36.840000  211.210007  95.389999  73.330002  203.220001  89.760002  15.79  33.197544  48.529999  37.939999  145.470001  387.799957
# 2023-03-16  37.599998  216.979996  97.220001  74.320000  206.559998  91.970001  16.09  34.650002  49.259998  39.439999  149.669998  394.603973
# 2023-03-17  36.290001  213.119995  95.389999  72.470001  199.619995  90.290001  16.02  33.000000  48.990002  39.209999  122.690002  389.989990
#
# grp(retnStd/UI):   mean, std, mean/std:               1.7,               0.9,               1.9
# grp(CAGR/retnStd): mean, std, mean/std:              50.7,             148.0,               0.3
# grp(CAGR/UI):      mean, std, mean/std:             195.5,             459.0,               0.4
# grp(CAGR):         mean, std, mean/std:               0.6,               2.1,               0.3
#
# ==================================================
#
# 2 of 20 max_lookback_slice: (96, 126, 130)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-06', '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20', '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-06 - 2023-02-17
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-02-21 - 2023-02-24
#
# top_set_syms_n_freq: [('CTLT', 6), ('TA', 6), ('OEC', 5), ('TSLA', 5), ('WIRE', 5), ('AMCX', 4), ('AN', 4), ('CAR', 4), ('SMG', 4), ('THR', 4), ('CRUS', 3), ('ELF', 3), ('EVRI', 3), ('FCF', 3), ('NATI', 3), ('PAG', 3), ('RVNC', 3), ('STNG', 3), ('TNK', 3), ('ACLS', 2)]
#
# set_lookback_slices: [(111, 126, 130), (96, 126, 130)]
# max_lookback_slice:  (96, 126, 130)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-02-17
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['CTLT', 'TA']
# sym_freq_5:          ['OEC', 'TSLA', 'WIRE']
# sym_freq_4:          ['AMCX', 'AN', 'CAR', 'SMG', 'THR']
# sym_freq_3:          ['CRUS', 'ELF', 'EVRI', 'FCF', 'NATI', 'PAG', 'RVNC', 'STNG', 'TNK']
# sym_freq_2:          ['ACLS']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.2,             -66.4,             -80.9,              -0.4
# iloc_start_eval:    126,  df_eval first date: 2023-02-21
# iloc_end_eval:      130,  df_eval last date:  2023-02-24
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  CTLT         TA         SPY
# Date
# 2023-02-21  68.660004  84.099998  397.572662
# 2023-02-22  67.660004  84.300003  397.024750
# 2023-02-23  67.650002  84.279999  399.136688
# 2023-02-24  67.980003  84.370003  394.872955
#
# grp(retnStd/UI):   mean, std, mean/std:               4.9,               4.1,               1.2
# grp(CAGR/retnStd): mean, std, mean/std:             110.3,             179.1,               0.6
# grp(CAGR/UI):      mean, std, mean/std:           1,277.4,           1,326.8,               1.0
# grp(CAGR):         mean, std, mean/std:              -0.1,               0.4,              -0.3
#
# iloc_start_eval:    126,  df_eval first date: 2023-02-21
# iloc_end_eval:      130,  df_eval last date:  2023-02-24
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   OEC        TSLA        WIRE         SPY
# Date
# 2023-02-21  24.268862  197.369995  192.350006  397.572662
# 2023-02-22  24.848356  200.860001  188.080002  397.024750
# 2023-02-23  24.768427  202.070007  188.419998  399.136688
# 2023-02-24  25.277981  196.880005  188.479996  394.872955
#
# grp(retnStd/UI):   mean, std, mean/std:               3.2,               3.1,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:             790.2,           1,177.8,               0.7
# grp(CAGR/UI):      mean, std, mean/std:           6,121.9,           8,699.9,               0.7
# grp(CAGR):         mean, std, mean/std:               9.5,              14.2,               0.7
#
# iloc_start_eval:    126,  df_eval first date: 2023-02-21
# iloc_end_eval:      130,  df_eval last date:  2023-02-24
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  AMCX          AN         CAR        SMG        THR         SPY
# Date
# 2023-02-21  23.930000  143.380005  225.240005  81.118446  26.200001  397.572662
# 2023-02-22  23.850000  143.850006  223.529999  82.169998  26.480000  397.024750
# 2023-02-23  24.610001  141.860001  220.130005  82.959999  26.490000  399.136688
# 2023-02-24  23.670000  139.250000  218.210007  82.849998  26.440001  394.872955
#
# grp(retnStd/UI):   mean, std, mean/std:               3.4,               3.5,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:             123.3,             373.8,               0.3
# grp(CAGR/UI):      mean, std, mean/std:           1,694.6,           2,886.6,               0.6
# grp(CAGR):         mean, std, mean/std:               0.7,               2.2,               0.3
#
# iloc_start_eval:    126,  df_eval first date: 2023-02-21
# iloc_end_eval:      130,  df_eval last date:  2023-02-24
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   CRUS        ELF       EVRI        FCF       NATI         PAG       RVNC       STNG        TNK         SPY
# Date
# 2023-02-21  101.660004  73.190002  18.559999  16.290001  52.009998  145.160004  33.180000  60.733772  37.669998  397.572662
# 2023-02-22  101.790001  73.120003  18.600000  15.910000  51.700001  147.600006  33.060001  58.541218  37.360001  397.024750
# 2023-02-23  102.769997  73.750000  18.610001  15.900000  51.049999  145.809998  34.049999  60.654045  42.320000  399.136688
# 2023-02-24  102.080002  73.339996  18.200001  15.780000  50.360001  143.830002  34.119999  61.052689  43.320000  394.872955
#
# grp(retnStd/UI):   mean, std, mean/std:               3.5,               4.6,               0.8
# grp(CAGR/retnStd): mean, std, mean/std:         230,765.1,         652,607.0,               0.4
# grp(CAGR/UI):      mean, std, mean/std:       3,386,063.8,       9,575,380.7,               0.4
# grp(CAGR):         mean, std, mean/std:          13,930.9,          39,399.9,               0.4
#
# ==================================================
#
# 3 of 20 max_lookback_slice: (63, 93, 97)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-11-17', '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28', '2022-11-29', '2022-11-30', '2022-12-01', '2022-12-02', '2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09', '2022-12-12', '2022-12-13', '2022-12-14', '2022-12-15', '2022-12-16', '2022-12-19', '2022-12-20', '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-27', '2022-12-28', '2022-12-29', '2022-12-30'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-11-17 - 2022-12-30
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-01-03 - 2023-01-06
#
# top_set_syms_n_freq: [('HZNP', 6), ('ARWR', 5), ('MSGS', 5), ('SHV', 5), ('BMA', 4), ('BVH', 4), ('CCU', 4), ('FTSM', 4), ('AGYS', 3), ('AJRD', 3), ('AMBC', 3), ('AXSM', 3), ('BURL', 3), ('CROX', 3), ('HAL', 3), ('NVO', 3), ('PBF', 3), ('RCM', 3), ('ZTO', 3), ('ACGL', 2)]
#
# set_lookback_slices: [(78, 93, 97), (63, 93, 97)]
# max_lookback_slice:  (63, 93, 97)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2022-12-30
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['HZNP']
# sym_freq_5:          ['ARWR', 'MSGS', 'SHV']
# sym_freq_4:          ['BMA', 'BVH', 'CCU', 'FTSM']
# sym_freq_3:          ['AGYS', 'AJRD', 'AMBC', 'AXSM', 'BURL', 'CROX', 'HAL', 'NVO', 'PBF', 'RCM', 'ZTO']
# sym_freq_2:          ['ACGL']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               2.5,             276.5,             680.9,               3.9
# iloc_start_eval:     93,  df_eval first date: 2023-01-03
# iloc_end_eval:       97,  df_eval last date:  2023-01-06
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   HZNP         SPY
# Date
# 2023-01-03  113.500000  379.372131
# 2023-01-04  113.480003  382.300964
# 2023-01-05  113.239998  377.937592
# 2023-01-06  113.000000  386.604492
#
# grp(retnStd/UI):   mean, std, mean/std:               0.4,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:            -338.6,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:            -124.7,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.3,               0.0,              -inf
#
# iloc_start_eval:     93,  df_eval first date: 2023-01-03
# iloc_end_eval:       97,  df_eval last date:  2023-01-06
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  ARWR        MSGS         SHV         SPY
# Date
# 2023-01-03  38.509998  181.270004  109.282875  379.372131
# 2023-01-04  38.080002  186.490005  109.292809  382.300964
# 2023-01-05  37.090000  184.000000  109.312698  377.937592
# 2023-01-06  37.380001  183.669998  109.332573  386.604492
#
# grp(retnStd/UI):   mean, std, mean/std:              29.4,              39.9,               0.7
# grp(CAGR/retnStd): mean, std, mean/std:             318.2,             423.1,               0.8
# grp(CAGR/UI):      mean, std, mean/std:          26,007.5,          36,665.6,               0.7
# grp(CAGR):         mean, std, mean/std:               0.4,               1.2,               0.3
#
# iloc_start_eval:     93,  df_eval first date: 2023-01-03
# iloc_end_eval:       97,  df_eval last date:  2023-01-06
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   BMA        BVH    CCU       FTSM         SPY
# Date
# 2023-01-03  15.810000  25.226133  12.75  59.040157  379.372131
# 2023-01-04  16.520000  25.474619  12.68  59.060020  382.300964
# 2023-01-05  17.610001  25.713165  12.92  59.060020  377.937592
# 2023-01-06  18.110001  25.733042  13.25  59.079887  386.604492
#
# grp(retnStd/UI):   mean, std, mean/std:           9,856.4,          12,525.3,               0.8
# grp(CAGR/retnStd): mean, std, mean/std:       1,465,601.5,       2,536,635.0,               0.6
# grp(CAGR/UI):      mean, std, mean/std:  45,067,068,521.6,  78,053,393,583.7,               0.6
# grp(CAGR):         mean, std, mean/std:          22,539.6,          39,023.2,               0.6
#
# iloc_start_eval:     93,  df_eval first date: 2023-01-03
# iloc_end_eval:       97,  df_eval last date:  2023-01-06
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AGYS       AJRD       AMBC       AXSM        BURL        CROX        HAL         NVO        PBF    RCM        ZTO         SPY
# Date
# 2023-01-03  77.769997  55.869999  16.760000  73.320000  206.160004  106.809998  37.497932  136.960007  37.392174  10.73  27.570000  379.372131
# 2023-01-04  77.209999  55.900002  16.790001  73.339996  216.270004  108.529999  38.264622  136.770004  36.984005  11.03  28.400000  382.300964
# 2023-01-05  77.480003  56.090000  16.700001  69.040001  220.740005  109.949997  38.782383  136.250000  38.108955  11.28  27.900000  377.937592
# 2023-01-06  76.360001  55.900002  16.959999  67.989998  223.910004  111.110001  40.036961  138.639999  39.064667  12.43  27.629999  386.604492
#
# grp(retnStd/UI):   mean, std, mean/std:          11,149.7,          21,414.0,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:         592,702.2,       1,838,424.8,               0.3
# grp(CAGR/UI):      mean, std, mean/std:  42,390,182,743.3, 133,228,337,337.6,               0.3
# grp(CAGR):         mean, std, mean/std:          21,198.8,          66,613.0,               0.3
#
# ==================================================
#
# 4 of 20 max_lookback_slice: (44, 74, 78)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-10-21', '2022-10-24', '2022-10-25', '2022-10-26', '2022-10-27', '2022-10-28', '2022-10-31', '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04', '2022-11-07', '2022-11-08', '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-14', '2022-11-15', '2022-11-16', '2022-11-17', '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28', '2022-11-29', '2022-11-30', '2022-12-01', '2022-12-02'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-10-21 - 2022-12-02
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2022-12-05 - 2022-12-08
#
# top_set_syms_n_freq: [('BBW', 6), ('HZNP', 6), ('ROST', 5), ('AEO', 4), ('BURL', 4), ('AXSM', 3), ('BMRN', 3), ('CTRN', 3), ('ENR', 3), ('SRPT', 3), ('ACLS', 2), ('ANF', 2), ('APD', 2), ('AXON', 2), ('AZN', 2), ('AZTA', 2), ('BERY', 2), ('BTI', 2), ('FLO', 2), ('FTSM', 2)]
#
# set_lookback_slices: [(59, 74, 78), (44, 74, 78)]
# max_lookback_slice:  (44, 74, 78)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2022-12-02
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BBW', 'HZNP']
# sym_freq_5:          ['ROST']
# sym_freq_4:          ['AEO', 'BURL']
# sym_freq_3:          ['AXSM', 'BMRN', 'CTRN', 'ENR', 'SRPT']
# sym_freq_2:          ['ACLS', 'ANF', 'APD', 'AXON', 'AZN', 'AZTA', 'BERY', 'BTI', 'FLO', 'FTSM']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.8,             -55.6,             -43.8,              -0.5
# iloc_start_eval:     74,  df_eval first date: 2022-12-05
# iloc_end_eval:       78,  df_eval last date:  2022-12-08
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   BBW       HZNP         SPY
# Date
# 2022-12-05  23.314154  98.480003  396.251160
# 2022-12-06  23.276625  96.849998  390.539276
# 2022-12-07  23.614376  96.300003  389.874878
# 2022-12-08  24.402460  96.910004  392.929138
#
# grp(retnStd/UI):   mean, std, mean/std:               9.2,               8.6,               1.1
# grp(CAGR/retnStd): mean, std, mean/std:           1,540.2,           1,619.5,               1.0
# grp(CAGR/UI):      mean, std, mean/std:          28,038.6,          28,085.0,               1.0
# grp(CAGR):         mean, std, mean/std:              22.2,              23.0,               1.0
#
# iloc_start_eval:     74,  df_eval first date: 2022-12-05
# iloc_end_eval:       78,  df_eval last date:  2022-12-08
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   ROST         SPY
# Date
# 2022-12-05  116.982582  396.251160
# 2022-12-06  116.155251  390.539276
# 2022-12-07  114.989014  389.874878
# 2022-12-08  116.763290  392.929138
#
# grp(retnStd/UI):   mean, std, mean/std:               1.2,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -12.8,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -15.7,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.1,               0.0,              -inf
#
# iloc_start_eval:     74,  df_eval first date: 2022-12-05
# iloc_end_eval:       78,  df_eval last date:  2022-12-08
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#               AEO        BURL         SPY
# Date
# 2022-12-05  16.08  200.259995  396.251160
# 2022-12-06  15.59  199.649994  390.539276
# 2022-12-07  15.98  198.500000  389.874878
# 2022-12-08  16.26  198.910004  392.929138
#
# grp(retnStd/UI):   mean, std, mean/std:               1.1,               0.5,               2.1
# grp(CAGR/retnStd): mean, std, mean/std:             -35.3,              98.3,              -0.4
# grp(CAGR/UI):      mean, std, mean/std:              12.0,              87.5,               0.1
# grp(CAGR):         mean, std, mean/std:               0.6,               1.0,               0.6
#
# iloc_start_eval:     74,  df_eval first date: 2022-12-05
# iloc_end_eval:       78,  df_eval last date:  2022-12-08
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AXSM        BMRN       CTRN        ENR        SRPT         SPY
# Date
# 2022-12-05  77.290001  103.529999  30.129999  34.566975  122.959999  396.251160
# 2022-12-06  75.260002  102.220001  30.600000  34.041431  120.099998  390.539276
# 2022-12-07  78.160004  103.690002  29.389999  34.021599  119.760002  389.874878
# 2022-12-08  77.849998  104.389999  29.750000  34.428154  119.339996  392.929138
#
# grp(retnStd/UI):   mean, std, mean/std:               1.3,               0.6,               2.2
# grp(CAGR/retnStd): mean, std, mean/std:              -5.9,              62.1,              -0.1
# grp(CAGR/UI):      mean, std, mean/std:              25.7,              75.9,               0.3
# grp(CAGR):         mean, std, mean/std:              -0.0,               0.8,              -0.0
#
# ==================================================
#
# 5 of 20 max_lookback_slice: (104, 134, 138)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-19', '2023-01-20', '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28', '2023-03-01', '2023-03-02'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-19 - 2023-03-02
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-03-03', '2023-03-06', '2023-03-07', '2023-03-08'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-03-03 - 2023-03-08
#
# top_set_syms_n_freq: [('LNTH', 6), ('OEC', 6), ('SGEN', 6), ('TA', 6), ('TNK', 6), ('AMPH', 4), ('HY', 4), ('NTRA', 4), ('PKE', 4), ('SHV', 4), ('ELF', 3), ('EME', 3), ('SRPT', 3), ('ACGL', 2), ('ASC', 2), ('ASTE', 2), ('CTLT', 2), ('DY', 2), ('FCN', 2), ('FTSM', 2)]
#
# set_lookback_slices: [(119, 134, 138), (104, 134, 138)]
# max_lookback_slice:  (104, 134, 138)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-03-02
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SGEN', 'TA', 'TNK']
# sym_freq_5:          []
# sym_freq_4:          ['AMPH', 'HY', 'NTRA', 'PKE', 'SHV']
# sym_freq_3:          ['ELF', 'EME', 'SRPT']
# sym_freq_2:          ['ACGL', 'ASC', 'ASTE', 'CTLT', 'DY', 'FCN', 'FTSM']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.8,             -85.8,             -64.9,              -0.7
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  LNTH        OEC        SGEN         TA        TNK         SPY
# Date
# 2023-03-03  72.940002  26.666773  181.289993  84.769997  47.549999  402.653259
# 2023-03-06  73.000000  26.287102  177.350006  84.629997  45.910000  402.932220
# 2023-03-07  72.370003  25.987364  177.500000  84.510002  47.290001  396.755768
# 2023-03-08  75.239998  26.686754  176.360001  84.500000  47.330002  397.403320
#
# grp(retnStd/UI):   mean, std, mean/std:               1.7,               1.6,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:              29.7,             312.5,               0.1
# grp(CAGR/UI):      mean, std, mean/std:             551.0,           1,181.5,               0.5
# grp(CAGR):         mean, std, mean/std:               2.2,               5.2,               0.4
#
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  AMPH         HY       NTRA        PKE         SHV         SPY
# Date
# 2023-03-03  36.110001  47.759998  58.119999  15.641175  110.019997  402.653259
# 2023-03-06  35.130001  47.900002  56.730000  14.110655  110.029999  402.932220
# 2023-03-07  35.299999  46.270000  57.250000  13.980000  110.010002  396.755768
# 2023-03-08  35.430000  46.619999  57.730000  13.840000  110.019997  397.403320
#
# grp(retnStd/UI):   mean, std, mean/std:               0.9,               0.3,               3.2
# grp(CAGR/retnStd): mean, std, mean/std:             -30.5,              18.9,              -1.6
# grp(CAGR/UI):      mean, std, mean/std:             -24.1,              16.1,              -1.5
# grp(CAGR):         mean, std, mean/std:              -0.6,               0.4,              -1.7
#
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   ELF         EME        SRPT         SPY
# Date
# 2023-03-03  75.190002  168.949997  155.610001  402.653259
# 2023-03-06  72.080002  166.490005  155.990005  402.932220
# 2023-03-07  73.699997  165.809998  155.610001  396.755768
# 2023-03-08  74.010002  167.970001  152.960007  397.403320
#
# grp(retnStd/UI):   mean, std, mean/std:               1.0,               0.1,               8.8
# grp(CAGR/retnStd): mean, std, mean/std:             -51.2,              29.2,              -1.8
# grp(CAGR/UI):      mean, std, mean/std:             -46.7,              22.1,              -2.1
# grp(CAGR):         mean, std, mean/std:              -0.6,               0.2,              -3.7
#
# ==================================================
#
# 6 of 20 max_lookback_slice: (50, 80, 84)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-10-31', '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04', '2022-11-07', '2022-11-08', '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-14', '2022-11-15', '2022-11-16', '2022-11-17', '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28', '2022-11-29', '2022-11-30', '2022-12-01', '2022-12-02', '2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09', '2022-12-12'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-10-31 - 2022-12-12
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2022-12-13', '2022-12-14', '2022-12-15', '2022-12-16'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2022-12-13 - 2022-12-16
#
# top_set_syms_n_freq: [('BBW', 6), ('ZTO', 6), ('AXSM', 5), ('BVH', 5), ('HZNP', 5), ('WB', 5), ('ANF', 4), ('BIDU', 4), ('GDS', 4), ('SHV', 4), ('WYNN', 4), ('ACLS', 3), ('AEO', 3), ('AU', 3), ('BERY', 3), ('BURL', 3), ('CTRN', 3), ('FTSM', 3), ('NVO', 3), ('RARE', 3)]
#
# set_lookback_slices: [(65, 80, 84), (50, 80, 84)]
# max_lookback_slice:  (50, 80, 84)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2022-12-12
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BBW', 'ZTO']
# sym_freq_5:          ['AXSM', 'BVH', 'HZNP', 'WB']
# sym_freq_4:          ['ANF', 'BIDU', 'GDS', 'SHV', 'WYNN']
# sym_freq_3:          ['ACLS', 'AEO', 'AU', 'BERY', 'BURL', 'CTRN', 'FTSM', 'NVO', 'RARE']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.3,            -128.5,             -37.1,              -1.0
# iloc_start_eval:     80,  df_eval first date: 2022-12-13
# iloc_end_eval:       84,  df_eval last date:  2022-12-16
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   BBW        ZTO         SPY
# Date
# 2022-12-13  24.355549  26.500000  398.611298
# 2022-12-14  24.834028  26.670000  396.062775
# 2022-12-15  23.567467  26.860001  386.374390
# 2022-12-16  23.595612  26.879999  381.812805
#
# grp(retnStd/UI):   mean, std, mean/std:           2,855.4,           2,854.5,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:             388.4,             419.5,               0.9
# grp(CAGR/UI):      mean, std, mean/std:       2,306,754.4,       2,306,780.5,               1.0
# grp(CAGR):         mean, std, mean/std:               0.7,               1.6,               0.4
#
# iloc_start_eval:     80,  df_eval first date: 2022-12-13
# iloc_end_eval:       84,  df_eval last date:  2022-12-16
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  AXSM        BVH        HZNP         WB         SPY
# Date
# 2022-12-13  79.449997  24.331591  112.900002  18.480000  398.611298
# 2022-12-14  79.720001  24.709288  113.129997  18.440001  396.062775
# 2022-12-15  77.459999  24.570135  113.000000  18.410000  386.374390
# 2022-12-16  78.400002  24.460804  112.879997  17.590000  381.812805
#
# grp(retnStd/UI):   mean, std, mean/std:               1.2,               0.3,               3.8
# grp(CAGR/retnStd): mean, std, mean/std:             -10.0,              41.6,              -0.2
# grp(CAGR/UI):      mean, std, mean/std:               0.9,              56.9,               0.0
# grp(CAGR):         mean, std, mean/std:              -0.3,               0.6,              -0.5
#
# iloc_start_eval:     80,  df_eval first date: 2022-12-13
# iloc_end_eval:       84,  df_eval last date:  2022-12-16
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   ANF        BIDU        GDS         SHV       WYNN         SPY
# Date
# 2022-12-13  23.110001  119.160004  19.990000  109.041298  86.669998  398.611298
# 2022-12-14  23.209999  119.220001  21.110001  109.031387  86.320000  396.062775
# 2022-12-15  21.780001  113.699997  19.450001  109.084068  84.949997  386.374390
# 2022-12-16  21.780001  112.589996  19.990000  109.103951  86.010002  381.812805
#
# grp(retnStd/UI):   mean, std, mean/std:               1.7,               1.7,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:              17.6,              98.1,               0.2
# grp(CAGR/UI):      mean, std, mean/std:             198.8,             444.7,               0.4
# grp(CAGR):         mean, std, mean/std:              -0.5,               0.5,              -1.1
#
# iloc_start_eval:     80,  df_eval first date: 2022-12-13
# iloc_end_eval:       84,  df_eval last date:  2022-12-16
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ACLS    AEO         AU       BERY        BURL       CTRN       FTSM         NVO       RARE         SPY
# Date
# 2022-12-13  86.519997  15.47  19.136503  61.440685  196.669998  29.709999  58.890553  132.839996  44.930000  398.611298
# 2022-12-14  85.410004  15.28  19.334707  61.042305  196.169998  28.990000  58.910355  134.720001  45.459999  396.062775
# 2022-12-15  82.760002  14.66  18.541895  59.797356  191.440002  28.250000  58.910355  133.679993  45.570000  386.374390
# 2022-12-16  81.430000  14.58  18.551805  59.508530  185.800003  27.540001  58.920258  133.179993  45.630001  381.812805
#
# grp(retnStd/UI):   mean, std, mean/std:           1,075.7,           2,945.5,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:            -154.5,             637.9,              -0.2
# grp(CAGR/UI):      mean, std, mean/std:         601,646.6,       1,671,387.5,               0.4
# grp(CAGR):         mean, std, mean/std:              -0.3,               1.2,              -0.3
#
# ==================================================
#
# 7 of 20 max_lookback_slice: (102, 132, 136)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20', '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-17 - 2023-02-28
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-03-01', '2023-03-02', '2023-03-03', '2023-03-06'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-03-01 - 2023-03-06
#
# top_set_syms_n_freq: [('LNTH', 6), ('OEC', 6), ('SGEN', 6), ('SHV', 6), ('TA', 6), ('TNK', 6), ('TEX', 5), ('EME', 4), ('EURN', 4), ('FTSM', 4), ('PDFS', 4), ('TNP', 4), ('ACGL', 3), ('ASC', 3), ('CTLT', 3), ('ELF', 3), ('NVGS', 3), ('PKE', 3), ('ACLS', 2), ('AMCX', 2)]
#
# set_lookback_slices: [(117, 132, 136), (102, 132, 136)]
# max_lookback_slice:  (102, 132, 136)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-02-28
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SGEN', 'SHV', 'TA', 'TNK']
# sym_freq_5:          ['TEX']
# sym_freq_4:          ['EME', 'EURN', 'FTSM', 'PDFS', 'TNP']
# sym_freq_3:          ['ACGL', 'ASC', 'CTLT', 'ELF', 'NVGS', 'PKE']
# sym_freq_2:          ['ACLS', 'AMCX']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:          12,541.4,           1,073.6,        13464878.9,               6.7
# iloc_start_eval:    132,  df_eval first date: 2023-03-01
# iloc_end_eval:      136,  df_eval last date:  2023-03-06
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  LNTH        OEC        SGEN         SHV         TA        TNK         SPY
# Date
# 2023-03-01  73.080002  26.037319  178.229996  109.959999  84.260002  46.570000  393.239197
# 2023-03-02  73.349998  26.387016  178.669998  110.010002  84.550003  47.610001  396.297516
# 2023-03-03  72.940002  26.666773  181.289993  110.019997  84.769997  47.549999  402.653259
# 2023-03-06  73.000000  26.287102  177.350006  110.029999  84.629997  45.910000  402.932220
#
# grp(retnStd/UI):   mean, std, mean/std:              58.5,             127.2,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:              90.6,             132.1,               0.7
# grp(CAGR/UI):      mean, std, mean/std:          18,406.7,          40,883.0,               0.5
# grp(CAGR):         mean, std, mean/std:               0.1,               0.6,               0.2
#
# iloc_start_eval:    132,  df_eval first date: 2023-03-01
# iloc_end_eval:      136,  df_eval last date:  2023-03-06
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   TEX         SPY
# Date
# 2023-03-01  59.836365  393.239197
# 2023-03-02  59.756569  396.297516
# 2023-03-03  60.165520  402.653259
# 2023-03-06  59.247875  402.932220
#
# grp(retnStd/UI):   mean, std, mean/std:               1.2,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -61.8,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -73.7,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.6,               0.0,              -inf
#
# iloc_start_eval:    132,  df_eval first date: 2023-03-01
# iloc_end_eval:      136,  df_eval last date:  2023-03-06
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                    EME   EURN       FTSM       PDFS        TNP         SPY
# Date
# 2023-03-01  166.990005  18.76  59.439999  37.220001  23.790001  393.239197
# 2023-03-02  166.860001  18.57  59.459999  37.470001  23.770000  396.297516
# 2023-03-03  168.949997  19.02  59.480000  38.380001  24.510000  402.653259
# 2023-03-06  166.490005  18.50  59.480000  38.080002  23.580000  402.932220
#
# grp(retnStd/UI):   mean, std, mean/std:              65.0,             126.1,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:             147.7,             211.3,               0.7
# grp(CAGR/UI):      mean, std, mean/std:          23,531.2,          46,375.2,               0.5
# grp(CAGR):         mean, std, mean/std:               0.9,               2.5,               0.4
#
# iloc_start_eval:    132,  df_eval first date: 2023-03-01
# iloc_end_eval:      136,  df_eval last date:  2023-03-06
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ACGL        ASC       CTLT        ELF   NVGS        PKE         SPY
# Date
# 2023-03-01  70.970001  18.530001  69.010002  74.190002  13.77  15.407865  393.239197
# 2023-03-02  70.900002  18.590000  71.190002  75.220001  13.95  15.445193  396.297516
# 2023-03-03  71.300003  18.180000  74.260002  75.190002  14.04  15.641175  402.653259
# 2023-03-06  71.699997  17.910000  71.339996  72.080002  13.46  14.110655  402.932220
#
# grp(retnStd/UI):   mean, std, mean/std:               2.0,               2.0,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:             112.2,             224.3,               0.5
# grp(CAGR/UI):      mean, std, mean/std:             564.9,           1,026.7,               0.6
# grp(CAGR):         mean, std, mean/std:               2.2,               5.9,               0.4
#
# ==================================================
#
# 8 of 20 max_lookback_slice: (79, 109, 113)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-12-12', '2022-12-13', '2022-12-14', '2022-12-15', '2022-12-16', '2022-12-19', '2022-12-20', '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-27', '2022-12-28', '2022-12-29', '2022-12-30', '2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20', '2023-01-23', '2023-01-24', '2023-01-25'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-12-12 - 2023-01-25
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-01-26', '2023-01-27', '2023-01-30', '2023-01-31'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-01-26 - 2023-01-31
#
# top_set_syms_n_freq: [('BMA', 5), ('GBTC', 4), ('MARA', 4), ('NATI', 4), ('NEOG', 4), ('TX', 4), ('ACIW', 3), ('ACLS', 3), ('ALGN', 3), ('BTC-USD', 3), ('CCU', 3), ('HLF', 3), ('HSBC', 3), ('MELI', 3), ('NTES', 3), ('SCVL', 3), ('SHV', 3), ('W', 3), ('AMX', 2), ('BABA', 2)]
#
# set_lookback_slices: [(94, 109, 113), (79, 109, 113)]
# max_lookback_slice:  (79, 109, 113)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-01-25
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          []
# sym_freq_5:          ['BMA']
# sym_freq_4:          ['GBTC', 'MARA', 'NATI', 'NEOG', 'TX']
# sym_freq_3:          ['ACIW', 'ACLS', 'ALGN', 'BTC-USD', 'CCU', 'HLF', 'HSBC', 'MELI', 'NTES', 'SCVL', 'SHV', 'W']
# sym_freq_2:          ['AMX', 'BABA']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.8,              38.7,              68.7,               0.4
# iloc_start_eval:    109,  df_eval first date: 2023-01-26
# iloc_end_eval:      113,  df_eval last date:  2023-01-31
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   BMA         SPY
# Date
# 2023-01-26  22.610001  403.211151
# 2023-01-27  21.670000  404.137604
# 2023-01-30  20.840000  399.066956
# 2023-01-31  21.969999  404.934570
#
# grp(retnStd/UI):   mean, std, mean/std:               1.0,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -20.5,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -19.6,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.9,               0.0,              -inf
#
# iloc_start_eval:    109,  df_eval first date: 2023-01-26
# iloc_end_eval:      113,  df_eval last date:  2023-01-31
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#              GBTC  MARA       NATI       NEOG         TX         SPY
# Date
# 2023-01-26  12.24  8.75  54.161633  19.879999  40.540001  403.211151
# 2023-01-27  12.36  8.02  54.221313  20.040001  40.250000  404.137604
# 2023-01-30  11.89  7.17  53.962692  19.959999  39.700001  399.066956
# 2023-01-31  12.15  7.21  53.714016  21.410000  40.349998  404.934570
#
# grp(retnStd/UI):   mean, std, mean/std:               4.0,               6.4,               0.6
# grp(CAGR/retnStd): mean, std, mean/std:           2,956.6,           6,037.4,               0.5
# grp(CAGR/UI):      mean, std, mean/std:          50,647.8,         101,372.8,               0.5
# grp(CAGR):         mean, std, mean/std:             100.7,             202.5,               0.5
#
# iloc_start_eval:    109,  df_eval first date: 2023-01-26
# iloc_end_eval:      113,  df_eval last date:  2023-01-31
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ACIW        ACLS        ALGN       BTC-USD    CCU        HLF       HSBC         MELI       NTES       SCVL         SHV          W         SPY
# Date
# 2023-01-26  27.740000  113.730003  262.950012  23032.777344  15.54  16.940001  36.356087  1188.579956  91.992653  27.660000  109.591019  56.200001  403.211151
# 2023-01-27  27.860001  110.440002  269.200012  23078.728516  15.03  17.219999  36.035984  1221.270020  91.354713  27.559999  109.600960  63.740002  404.137604
# 2023-01-30  27.790001  107.830002  265.820007  22840.138672  15.34  17.160000  35.948685  1161.800049  89.291382  26.700001  109.610901  58.680000  399.066956
# 2023-01-31  27.930000  109.949997  269.730011  23139.283203  15.61  17.570000  35.832279  1181.689941  88.324509  27.309999  109.620842  60.500000  404.934570
#
# grp(retnStd/UI):   mean, std, mean/std:               1.7,               1.7,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:         287,451.7,         951,057.1,               0.3
# grp(CAGR/UI):      mean, std, mean/std:           5,841.6,          12,832.0,               0.5
# grp(CAGR):         mean, std, mean/std:              42.9,             134.4,               0.3
#
# ==================================================
#
# 9 of 20 max_lookback_slice: (7, 37, 41)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-08-30', '2022-08-31', '2022-09-01', '2022-09-02', '2022-09-06', '2022-09-07', '2022-09-08', '2022-09-09', '2022-09-12', '2022-09-13', '2022-09-14', '2022-09-15', '2022-09-16', '2022-09-19', '2022-09-20', '2022-09-21', '2022-09-22', '2022-09-23', '2022-09-26', '2022-09-27', '2022-09-28', '2022-09-29', '2022-09-30', '2022-10-03', '2022-10-04', '2022-10-05', '2022-10-06', '2022-10-07', '2022-10-10', '2022-10-11'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-08-30 - 2022-10-11
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2022-10-12', '2022-10-13', '2022-10-14', '2022-10-17'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2022-10-12 - 2022-10-17
#
# top_set_syms_n_freq: [('BIIB', 6), ('HLIT', 6), ('AZPN', 5), ('FCN', 5), ('ISEE', 5), ('WWE', 5), ('DXCM', 4), ('LRN', 4), ('MRK', 4), ('REGN', 4), ('ATEN', 3), ('AVXL', 3), ('AXGN', 3), ('CCRN', 3), ('MODN', 3), ('PBF', 3), ('PRO', 3), ('RCKT', 3), ('SHV', 3), ('SIGI', 3)]
#
# set_lookback_slices: [(22, 37, 41), (7, 37, 41)]
# max_lookback_slice:  (7, 37, 41)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2022-10-11
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['BIIB', 'HLIT']
# sym_freq_5:          ['AZPN', 'FCN', 'ISEE', 'WWE']
# sym_freq_4:          ['DXCM', 'LRN', 'MRK', 'REGN']
# sym_freq_3:          ['ATEN', 'AVXL', 'AXGN', 'CCRN', 'MODN', 'PBF', 'PRO', 'RCKT', 'SHV', 'SIGI']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               2.0,             427.3,             863.3,               9.8
# iloc_start_eval:     37,  df_eval first date: 2022-10-12
# iloc_end_eval:       41,  df_eval last date:  2022-10-17
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   BIIB   HLIT         SPY
# Date
# 2022-10-12  253.669998  13.66  353.580688
# 2022-10-13  269.940002  13.88  362.912079
# 2022-10-14  264.630005  13.47  354.641785
# 2022-10-17  269.549988  13.98  363.755005
#
# grp(retnStd/UI):   mean, std, mean/std:               2.7,               0.8,               3.4
# grp(CAGR/retnStd): mean, std, mean/std:           2,487.1,           2,273.7,               1.1
# grp(CAGR/UI):      mean, std, mean/std:           8,471.8,           8,066.0,               1.1
# grp(CAGR):         mean, std, mean/std:              84.5,              78.6,               1.1
#
# iloc_start_eval:     37,  df_eval first date: 2022-10-12
# iloc_end_eval:       41,  df_eval last date:  2022-10-17
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   AZPN         FCN   ISEE        WWE         SPY
# Date
# 2022-10-12  244.130005  173.259995  21.00  74.317245  353.580688
# 2022-10-13  250.820007  179.320007  21.49  75.254303  362.912079
# 2022-10-14  242.050003  179.960007  20.84  75.473618  354.641785
# 2022-10-17  252.330002  179.080002  21.91  75.184525  363.755005
#
# grp(retnStd/UI):   mean, std, mean/std:               3.7,               2.0,               1.8
# grp(CAGR/retnStd): mean, std, mean/std:             645.8,             311.5,               2.1
# grp(CAGR/UI):      mean, std, mean/std:           2,535.3,           2,165.9,               1.2
# grp(CAGR):         mean, std, mean/std:              16.5,              11.6,               1.4
#
# iloc_start_eval:     37,  df_eval first date: 2022-10-12
# iloc_end_eval:       41,  df_eval last date:  2022-10-17
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   DXCM        LRN        MRK        REGN         SPY
# Date
# 2022-10-12   98.320000  45.160000  89.204674  728.059998  353.580688
# 2022-10-13  101.720001  45.209999  91.246857  752.559998  362.912079
# 2022-10-14   97.410004  44.570000  90.941025  736.059998  354.641785
# 2022-10-17   99.730003  45.520000  92.854950  735.960022  363.755005
#
# ...
# df_eval dates (inclusive): 2023-03-03 - 2023-03-08
#
# top_set_syms_n_freq: [('LNTH', 6), ('OEC', 6), ('SGEN', 6), ('TA', 6), ('TNK', 6), ('AMPH', 4), ('HY', 4), ('NTRA', 4), ('PKE', 4), ('SHV', 4), ('ELF', 3), ('EME', 3), ('SRPT', 3), ('ACGL', 2), ('ASC', 2), ('ASTE', 2), ('CTLT', 2), ('DY', 2), ('FCN', 2), ('FTSM', 2)]
#
# set_lookback_slices: [(119, 134, 138), (104, 134, 138)]
# max_lookback_slice:  (104, 134, 138)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-03-02
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SGEN', 'TA', 'TNK']
# sym_freq_5:          []
# sym_freq_4:          ['AMPH', 'HY', 'NTRA', 'PKE', 'SHV']
# sym_freq_3:          ['ELF', 'EME', 'SRPT']
# sym_freq_2:          ['ACGL', 'ASC', 'ASTE', 'CTLT', 'DY', 'FCN', 'FTSM']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.8,             -85.8,             -64.9,              -0.7
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  LNTH        OEC        SGEN         TA        TNK         SPY
# Date
# 2023-03-03  72.940002  26.666773  181.289993  84.769997  47.549999  402.653259
# 2023-03-06  73.000000  26.287102  177.350006  84.629997  45.910000  402.932220
# 2023-03-07  72.370003  25.987364  177.500000  84.510002  47.290001  396.755768
# 2023-03-08  75.239998  26.686754  176.360001  84.500000  47.330002  397.403320
#
# grp(retnStd/UI):   mean, std, mean/std:               1.7,               1.6,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:              29.7,             312.5,               0.1
# grp(CAGR/UI):      mean, std, mean/std:             551.0,           1,181.5,               0.5
# grp(CAGR):         mean, std, mean/std:               2.2,               5.2,               0.4
#
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  AMPH         HY       NTRA        PKE         SHV         SPY
# Date
# 2023-03-03  36.110001  47.759998  58.119999  15.641175  110.019997  402.653259
# 2023-03-06  35.130001  47.900002  56.730000  14.110655  110.029999  402.932220
# 2023-03-07  35.299999  46.270000  57.250000  13.980000  110.010002  396.755768
# 2023-03-08  35.430000  46.619999  57.730000  13.840000  110.019997  397.403320
#
# grp(retnStd/UI):   mean, std, mean/std:               0.9,               0.3,               3.2
# grp(CAGR/retnStd): mean, std, mean/std:             -30.5,              18.9,              -1.6
# grp(CAGR/UI):      mean, std, mean/std:             -24.1,              16.1,              -1.5
# grp(CAGR):         mean, std, mean/std:              -0.6,               0.4,              -1.7
#
# iloc_start_eval:    134,  df_eval first date: 2023-03-03
# iloc_end_eval:      138,  df_eval last date:  2023-03-08
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   ELF         EME        SRPT         SPY
# Date
# 2023-03-03  75.190002  168.949997  155.610001  402.653259
# 2023-03-06  72.080002  166.490005  155.990005  402.932220
# 2023-03-07  73.699997  165.809998  155.610001  396.755768
# 2023-03-08  74.010002  167.970001  152.960007  397.403320
#
# grp(retnStd/UI):   mean, std, mean/std:               1.0,               0.1,               8.8
# grp(CAGR/retnStd): mean, std, mean/std:             -51.2,              29.2,              -1.8
# grp(CAGR/UI):      mean, std, mean/std:             -46.7,              22.1,              -2.1
# grp(CAGR):         mean, std, mean/std:              -0.6,               0.2,              -3.7
#
# ==================================================
#
# 19 of 20 max_lookback_slice: (61, 91, 95)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2022-11-15', '2022-11-16', '2022-11-17', '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28', '2022-11-29', '2022-11-30', '2022-12-01', '2022-12-02', '2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09', '2022-12-12', '2022-12-13', '2022-12-14', '2022-12-15', '2022-12-16', '2022-12-19', '2022-12-20', '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-27', '2022-12-28'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2022-11-15 - 2022-12-28
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2022-12-29', '2022-12-30', '2023-01-03', '2023-01-04'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2022-12-29 - 2023-01-04
#
# top_set_syms_n_freq: [('FTSM', 6), ('HZNP', 6), ('SHV', 6), ('MSGS', 5), ('AJRD', 4), ('BVH', 4), ('EDU', 4), ('NVO', 4), ('ZTO', 4), ('ACGL', 3), ('AGYS', 3), ('AXSM', 3), ('BMA', 3), ('BURL', 3), ('CAG', 3), ('CALM', 3), ('CCU', 3), ('CPB', 3), ('KHC', 3), ('PBF', 3)]
#
# set_lookback_slices: [(76, 91, 95), (61, 91, 95)]
# max_lookback_slice:  (61, 91, 95)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2022-12-28
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['FTSM', 'HZNP', 'SHV']
# sym_freq_5:          ['MSGS']
# sym_freq_4:          ['AJRD', 'BVH', 'EDU', 'NVO', 'ZTO']
# sym_freq_3:          ['ACGL', 'AGYS', 'AXSM', 'BMA', 'BURL', 'CAG', 'CALM', 'CCU', 'CPB', 'KHC', 'PBF']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.4,              13.7,              19.8,               0.1
# iloc_start_eval:     91,  df_eval first date: 2022-12-29
# iloc_end_eval:       95,  df_eval last date:  2023-01-04
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  FTSM        HZNP         SHV         SPY
# Date
# 2022-12-29  59.040157  113.510002  109.272926  381.982178
# 2022-12-30  59.040157  113.800003  109.262993  380.975983
# 2023-01-03  59.040157  113.500000  109.282875  379.372131
# 2023-01-04  59.060020  113.480003  109.292809  382.300964
#
# grp(retnStd/UI):   mean, std, mean/std:             106.9,             148.7,               0.7
# grp(CAGR/retnStd): mean, std, mean/std:             102.0,              81.6,               1.3
# grp(CAGR/UI):      mean, std, mean/std:          19,214.9,          26,942.9,               0.7
# grp(CAGR):         mean, std, mean/std:               0.0,               0.0,               0.3
#
# iloc_start_eval:     91,  df_eval first date: 2022-12-29
# iloc_end_eval:       95,  df_eval last date:  2023-01-04
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   MSGS         SPY
# Date
# 2022-12-29  181.479996  381.982178
# 2022-12-30  183.330002  380.975983
# 2023-01-03  181.270004  379.372131
# 2023-01-04  186.490005  382.300964
#
# grp(retnStd/UI):   mean, std, mean/std:               2.9,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             541.1,               0.0,               inf
# grp(CAGR/UI):      mean, std, mean/std:           1,575.3,               0.0,               inf
# grp(CAGR):         mean, std, mean/std:               8.9,               0.0,               inf
#
# iloc_start_eval:     91,  df_eval first date: 2022-12-29
# iloc_end_eval:       95,  df_eval last date:  2023-01-04
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  AJRD        BVH        EDU         NVO        ZTO         SPY
# Date
# 2022-12-29  56.000000  24.550259  36.040001  135.199997  26.879999  381.982178
# 2022-12-30  55.930000  24.808680  34.820000  135.339996  26.870001  380.975983
# 2023-01-03  55.869999  25.226133  34.650002  136.960007  27.570000  379.372131
# 2023-01-04  55.900002  25.474619  35.220001  136.770004  28.400000  382.300964
#
# grp(retnStd/UI):   mean, std, mean/std:           1,273.1,           2,505.2,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:           2,857.6,           3,482.0,               0.8
# grp(CAGR/UI):      mean, std, mean/std:       8,629,227.1,      16,988,294.2,               0.5
# grp(CAGR):         mean, std, mean/std:              24.5,              38.9,               0.6
#
# iloc_start_eval:     91,  df_eval first date: 2022-12-29
# iloc_end_eval:       95,  df_eval last date:  2023-01-04
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ACGL       AGYS       AXSM        BMA        BURL        CAG       CALM    CCU        CPB        KHC        PBF         SPY
# Date
# 2022-12-29  63.110001  80.180000  76.500000  16.299999  205.830002  38.422710  51.862045  13.25  56.336643  40.255363  40.816803  381.982178
# 2022-12-30  62.779999  79.139999  77.129997  16.420000  202.759995  38.353340  53.110561  13.12  56.376377  40.285049  40.597782  380.975983
# 2023-01-03  62.459999  77.769997  73.320000  15.810000  206.160004  38.482174  54.124981  12.75  55.830002  40.354321  37.392174  379.372131
# 2023-01-04  62.770000  77.209999  73.339996  16.520000  216.270004  38.303787  55.822174  12.68  55.759998  40.809521  36.984005  382.300964
#
# grp(retnStd/UI):   mean, std, mean/std:           1,780.6,           3,776.9,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:           8,919.1,          27,502.7,               0.3
# grp(CAGR/UI):      mean, std, mean/std:      88,119,629.5,     277,296,991.1,               0.3
# grp(CAGR):         mean, std, mean/std:              49.5,             138.1,               0.4
#
# ==================================================
#
# 20 of 20 max_lookback_slice: (109, 139, 143)
#
# len(idx_train): 30
# idx_train: DatetimeIndex(['2023-01-26', '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03', '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09'], dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-01-26 - 2023-03-09
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-03-10', '2023-03-13', '2023-03-14', '2023-03-15'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-03-10 - 2023-03-15
#
# top_set_syms_n_freq: [('LNTH', 6), ('OEC', 6), ('SHV', 6), ('TNK', 6), ('FTSM', 5), ('HY', 5), ('PDFS', 5), ('EME', 4), ('FCN', 4), ('NTRA', 4), ('SRPT', 4), ('ASC', 3), ('AXON', 3), ('DY', 3), ('FSLR', 3), ('GE', 3), ('MCFT', 3), ('OTTR', 3), ('PRG', 3), ('SGEN', 3)]
#
# set_lookback_slices: [(124, 139, 143), (109, 139, 143)]
# max_lookback_slice:  (109, 139, 143)
# days_lookbacks:      [15, 30]
# date_end_df_train:   2023-03-09
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          []
# sym_freq_6:          ['LNTH', 'OEC', 'SHV', 'TNK']
# sym_freq_5:          ['FTSM', 'HY', 'PDFS']
# sym_freq_4:          ['EME', 'FCN', 'NTRA', 'SRPT']
# sym_freq_3:          ['ASC', 'AXON', 'DY', 'FSLR', 'GE', 'MCFT', 'OTTR', 'PRG', 'SGEN']
# sym_freq_2:          []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.1,             109.7,             335.4,               1.1
# iloc_start_eval:    139,  df_eval first date: 2023-03-10
# iloc_end_eval:      143,  df_eval last date:  2023-03-15
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  LNTH        OEC         SHV        TNK         SPY
# Date
# 2023-03-10  71.260002  24.508652  110.129997  44.639999  384.442780
# 2023-03-13  70.750000  23.929157  110.260002  43.290001  383.894836
# 2023-03-14  73.019997  24.508652  110.199997  44.590000  390.240662
# 2023-03-15  73.239998  23.819252  110.309998  42.410000  387.799957
#
# grp(retnStd/UI):   mean, std, mean/std:               2.5,               1.4,               1.8
# grp(CAGR/retnStd): mean, std, mean/std:             165.8,             235.1,               0.7
# grp(CAGR/UI):      mean, std, mean/std:             742.7,           1,049.8,               0.7
# grp(CAGR):         mean, std, mean/std:               1.8,               4.2,               0.4
#
# iloc_start_eval:    139,  df_eval first date: 2023-03-10
# iloc_end_eval:      143,  df_eval last date:  2023-03-15
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  FTSM         HY       PDFS         SPY
# Date
# 2023-03-10  59.540001  45.580002  37.080002  384.442780
# 2023-03-13  59.570000  44.340000  36.650002  383.894836
# 2023-03-14  59.619999  45.080002  38.369999  390.240662
# 2023-03-15  59.619999  43.330002  37.939999  387.799957
#
# grp(retnStd/UI):   mean, std, mean/std:             231.4,             324.2,               0.7
# grp(CAGR/retnStd): mean, std, mean/std:             172.7,             160.7,               1.1
# grp(CAGR/UI):      mean, std, mean/std:          79,826.3,         112,402.2,               0.7
# grp(CAGR):         mean, std, mean/std:               1.7,               3.0,               0.6
#
# iloc_start_eval:    139,  df_eval first date: 2023-03-10
# iloc_end_eval:      143,  df_eval last date:  2023-03-15
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                    EME         FCN       NTRA        SRPT         SPY
# Date
# 2023-03-10  158.490005  186.580002  54.130001  143.919998  384.442780
# 2023-03-13  155.679993  195.240005  55.180000  142.770004  383.894836
# 2023-03-14  158.389999  196.139999  56.430000  144.899994  390.240662
# 2023-03-15  155.910004  196.130005  57.040001  145.470001  387.799957
#
# grp(retnStd/UI):   mean, std, mean/std:           2,703.8,           4,220.7,               0.6
# grp(CAGR/retnStd): mean, std, mean/std:           4,828.2,           6,616.9,               0.7
# grp(CAGR/UI):      mean, std, mean/std:      40,808,308.6,      69,211,700.0,               0.6
# grp(CAGR):         mean, std, mean/std:              36.6,              36.6,               1.0
#
# iloc_start_eval:    139,  df_eval first date: 2023-03-10
# iloc_end_eval:      143,  df_eval last date:  2023-03-15
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#               ASC        AXON         DY        FSLR         GE       MCFT       OTTR        PRG        SGEN         SPY
# Date
# 2023-03-10  17.35  213.000000  99.239998  207.729996  91.000000  32.520000  68.989998  24.700001  172.610001  384.442780
# 2023-03-13  16.49  211.000000  96.529999  203.580002  88.970001  31.180000  67.980003  23.690001  197.649994  383.894836
# 2023-03-14  16.91  215.000000  99.190002  207.289993  91.169998  32.110001  69.529999  23.950001  199.839996  390.240662
# 2023-03-15  15.43  211.210007  95.389999  203.220001  89.760002  32.009998  69.070000  23.070000  199.940002  387.799957
#
# grp(retnStd/UI):   mean, std, mean/std:          14,622.8,          41,355.9,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:         388,643.9,       1,099,331.6,               0.4
# grp(CAGR/UI):      mean, std, mean/std:  51,146,942,087.7, 144,665,398,440.1,               0.4
# grp(CAGR):         mean, std, mean/std:          25,572.8,          72,332.9,               0.4
#
# ==================================================

# %%
if store_results:  # record results to df
  pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
  print(f'Save results to: {fp_df_eval_results}')

df = pickle_load(path_data_dump, fp_df_eval_results)
df.tail()
# Out:
#        n_samples   days_lookbacks  days_eval  n_top_syms  syms_start  syms_end  sym_freq_cnt  grp(CAGR)_mean  grp(CAGR)_std  grp(CAGR)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  grp(CAGR/retnStd)_mean  grp(CAGR/retnStd)_std  grp(CAGR/retnStd)_mean/std  grp(retnStd/UI)_mean  grp(retnStd/UI)_std  grp(retnStd/UI)_mean/std  SPY_CAGR  SPY_CAGR/UI  SPY_CAGR/retnStd  SPY_retnStd/UI
# 10768         57  [15, 30, 60,...          6          20           0        10             8       -0.072861       0.124991        -0.582933          141.029300         198.636117          0.709988             -18.241589              147.439007              -0.123723                    1.488370              1.140672             1.304819          -0.902952   -37.133739      -105.585989         0.351692
# 10769         57  [15, 30, 60,...          6          20           0        10             7       -0.985784       0.000000             -inf          -24.200545           0.000000              -inf             -38.364608                0.000000                   -inf                    0.630804              0.000000                  inf          -0.902952   -37.133739      -105.585989         0.351692
# 10770         57  [15, 30, 60,...          6          20           0        10             6       -0.876533       0.131484        -6.666446          -25.873236           2.105890        -12.286131             -34.089238                4.579804              -7.443383                    0.781530              0.167812             4.657170          -0.902952   -37.133739      -105.585989         0.351692
# 10771         57  [15, 30, 60,...          6          20           0        10             5       -0.853924       0.221902        -3.848211          -26.712490           6.312340         -4.231789             -53.312634               16.469317              -3.237088                    0.553516              0.218623             2.531828          -0.902952   -37.133739      -105.585989         0.351692
# 10772         57  [15, 30, 60,...          6          20           0        10             4       -0.962932       0.038941       -24.728181          -23.569370           7.883225         -2.989813             -39.377981                9.622466              -4.092296                    0.591808              0.145305             4.072856          -0.902952   -37.133739      -105.585989         0.351692

# %%
# df = pickle_load(path_data_dump, fp_df_picks)
# df.tail()
