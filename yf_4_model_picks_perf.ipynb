# %%
def get_trading_date_n(date, idx_close, n, verbose=False):
  """
  This function takes a date, a closing price date index, a number of days (n), and an optional verbosity flag,
  and returns the trading date n days away from the input date if it exists in the index, or None otherwise.

  Args:
    date: The date to start from (as a datetime object).
    idx_close: A dictionary or Series containing date index of close prices.
    n: The number of days to move forward or backward in time (positive for future, negative for past).
    verbose: An optional flag to print additional information about the process (default: False).

  Returns:
    The trading date n days away from the input date if it exists in the index, or None otherwise.
  """

  # Check if the input date is present in the closing price index.
  if date in idx_close:
    # Get the last and current index positions of the input date.
    idx_last = len(idx_close) - 1  # Last index of the closing price index.
    idx_date = idx_close.get_loc(date)  # Index of the input date in the index.

    # Calculate the index of the date n days away from the input date.
    idx_date_n = idx_date + n

    # Print debug information if verbose flag is set.
    if verbose:
      print(f"date: {date} is in idx_close, "
            f"date's position in idx_close is: {idx_date} of {idx_last}, "
            f"n: {n}, idx_date_n: {idx_date_n},")

    # Check if the calculated index is within the bounds of the closing price index.
    if 0 <= idx_date_n <= idx_last:
      # Get the date n days away from the input date using the calculated index.
      date_n = idx_close[idx_date_n]

      # Print debug information if verbose flag is set.
      if verbose:
        print(f"idx_date_n: {idx_date_n} is within bounds of idx_close (0 to {idx_last}), date_n: {date_n}\n")

    else:
      # If the calculated index is out of bounds, set the output date to None.
      date_n = None

      # Print debug information if verbose flag is set.
      if verbose:
        print(f"idx_date_n: {idx_date_n} is out-of-bounds of idx_close (0 to {idx_last})\n")

  else:
    # If the input date is not in the closing price index, set the output date to None.
    date_n = None

    # Print debug information if verbose flag is set.
    if verbose:
      print(f"date: {date} is not in idx_close\n")

  # Return the date n days away from the input date if it exists in the index, or None otherwise.
  return date_n

# %%
def any_not_in_list(list1, list2):
  """
  Checks if any items in list1 are not in list2.

  Args:
    list1: A list of items.
    list2: Another list of items.

  Returns:
    True if any item in list1 is not in list2, False if all are present.
  """
  return bool(set(list1) - set(list2))

# %%
def is_date_in_close(date, df_close):
  """
  Checks if a given date is present in a DataFrame's index, considering only the date portion (YYYY-MM-DD).

  Args:
    date (str): The date to check in the format YYYY-MM-DD.
    df_close (pandas.DataFrame): A DataFrame containing a date index.

  Returns:
    str or None: The input date if it's found in the index, otherwise None.
  """  

  # Format the index to YYYY-MM-DD for comparison
  idx_close = df_close.index.strftime('%Y-%m-%d')

  # Check if the date is in the formatted index
  if date in idx_close:
    # Return the date if found
    return date
  else:
    # Return None if not found
    return None

# %%
def calc_portf_shares(df_close, date, str_symbols, portf_target):
  """
  Calculates the number of shares to buy for each symbol in a portfolio to meet a target investment value.

  Args:
    df_close (pandas.DataFrame): DataFrame with closing prices, indexed by date and symbols.
    date (str): The date for which to calculate shares.
    str_symbols (str): String representation of a list of symbols to include in the portfolio.
    portf_target (float): The total target investment value for the portfolio.

  Returns:
    numpy.ndarray: An array containing the number of shares to buy for each symbol.
  """

  # Import necessary libraries
  import numpy as np
  from ast import literal_eval

  # Convert string representation of symbols to a list
  l_syms = literal_eval(str_symbols)

  # Retrieve closing prices for the specified symbols on the given date
  ar_price = df_close.loc[date][l_syms].values

  # Calculate the number of symbols
  sym_cnt = len(l_syms)

  # Determine the target investment amount per symbol
  amt_per_sym = portf_target / sym_cnt

  # Calculate the number of shares to buy for each symbol, rounding down to whole shares
  ar_shares = np.floor(amt_per_sym / ar_price)

  return ar_shares

# %%
def calc_portf_value(df_close, date, str_symbols, ar_shares, verbose=False):
  """
  Calculates the total value of a portfolio of stocks for a given date.

  Args:
  df_close (pandas.DataFrame): DataFrame containing closing prices, indexed by date and symbols.
  date (str): The date for which to calculate the portfolio value.
  str_symbols (str): String representation of a list of symbols in the portfolio.
  ar_shares (numpy.ndarray): Array containing the number of shares held for each symbol.
  verbose (bool, optional): If True, prints details of the calculation. Defaults to False.

  Returns:
  tuple: A tuple containing the date, symbols, closing prices, shares, individual symbol values, and total portfolio value.
  """

  # Import necessary libraries
  import numpy as np
  from ast import literal_eval

  # Convert string representation of symbols to a list
  l_syms = literal_eval(str_symbols)

  # Retrieve closing prices for the specified symbols on the given date
  ar_price = df_close.loc[date][l_syms].values

  # Calculate the dollar value invested in each symbol
  ar_value = ar_price * ar_shares

  # Calculate the total portfolio value by summing the individual symbol values
  portf_value = sum(ar_value)

  # Print details if verbose is True
  if verbose:
    print(f'date = {date}, l_syms = {l_syms}, ar_price = {ar_price}, ar_shares = {ar_shares}, ar_value = {ar_value}, portf_value = {portf_value}')
    print(f'{date} {portf_value = }')

  # Return the calculated values
  return date, l_syms, ar_price, ar_shares, ar_value, portf_value

# %%
def calc_portf_value_date_buy(idx_date, str_symbols, df_close, portf_target, n, verbose=False):
  """
  Calculates portfolio values for multiple dates and symbol combinations, handling potential data gaps.

  Args:
  idx_date (list): List of dates (str) to evaluate portfolios.
  str_symbols (list): List of symbol lists (str) to evaluate for each date.
  df_close (pandas.DataFrame): DataFrame with closing prices, indexed by date and symbols.
  portf_target (float): Target portfolio value for allocation.
  n (int): Number of trading days to offset execution from the lookback date.
  verbose (bool, optional): If True, prints details. Defaults to False.

  Returns:
  tuple: Tuple containing lists of buy dates, shares, and portfolio values for both the selected symbols and SPY.
  """

  from ast import literal_eval

  # Extract trading dates and symbols from the DataFrame
  idx_close = df_close.index.strftime('%Y-%m-%d')  # Trading dates in format YYYY-MM-DD
  symbols_df_close = df_close.columns  # Symbols in df_close

  # Initialize lists to store results
  date_exec = []  # Buy date of portfolio
  shares_syms = []  # Lists of shares of each symbol bought on each date
  value_portf = []  # List of portfolio values on each date
  shares_SPY = []  # List of shares of SPY bought on each date
  value_SPY = []  # List of values of SPY shares on each date

  # Iterate through pairs of dates and symbol lists
  for date, syms in zip(idx_date, str_symbols):

    # Determine the execution date based on the lookback date and the offset n
    next_date_n = get_trading_date_n(date, idx_close, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    # Print information for debugging
    print(f'++++++++++++++')
    print(f'date: {date}')
    print(f'n: {n}')         
    print(f'next_date_n: {next_date_n}')
    print(f'close_date_n: {close_date_n}')
    print(f'syms: {syms}')
    print(f'++++++++++++++')    

    # Convert string representation of symbols back to a list
    l_syms = literal_eval(syms)

    # Check if any symbols are not present in the DataFrame
    sym_not_in_df_close = any_not_in_list(l_syms, symbols_df_close)

    if close_date_n is None or sym_not_in_df_close:
      # Handle missing data:
      print(f'l_syms: {l_syms}')  
      print(f'sym_not_in_df_close: {sym_not_in_df_close}')  

      p_date = None
      p_ar_shares = None
      p_portf_value = None  # Set to None when data are not available
      SPY_shares = None
      SPY_value = None  # Set to None when data are not available

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        print(f'No data for close_date_n {close_date_n}, SPY portf value =    None')

    else:
      # Calculate portfolio values when data is available:
      p_ar_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      p_date, l_syms, ar_price, ar_shares, ar_value, p_portf_value = calc_portf_value(df_close, close_date_n, syms, p_ar_shares, verbose)

      syms = str(['SPY'])
      SPY_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      date, l_syms, ar_price, ar_shares, ar_value, SPY_value = calc_portf_value(df_close, close_date_n, syms, SPY_shares, verbose)

      if verbose:
        print(f"close_date_n pick's portf value = {p_portf_value}")
        print(f'close_date_n SPY portf value =    {SPY_value}')

    date_exec.append(p_date)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_portf_value)
    shares_SPY.append(SPY_shares)
    value_SPY.append(SPY_value)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
def calc_portf_value_date_n(idx_date, str_symbols, df_close, my_portf_shares, my_SPY_shares, n, verbose=False):
  """
  Calculates portfolio values for multiple dates and symbol combinations, taking pre-determined shares as input.

  Args:
  idx_date (list): List of dates (str) to evaluate portfolios.
  str_symbols (list): List of symbol lists (str) to evaluate for each date.
  df_close (pandas.DataFrame): DataFrame with closing prices, indexed by date and symbols.
  my_portf_shares (list): List of lists of shares for each symbol combination.
  my_SPY_shares (list): List of shares of SPY to evaluate for each date.
  n (int): Number of trading days to offset execution from the lookback date.
  verbose (bool, optional): If True, prints details. Defaults to False.

  Returns:
  tuple: Tuple containing lists of buy dates, shares, and portfolio values for both the selected symbols and SPY.
  """

  # Extract trading dates from the DataFrame
  idx_close = df_close.index.strftime('%Y-%m-%d')  # Trading dates in format YYYY-MM-DD

  # Initialize lists to store results
  date_exec = []  # Buy date of portfolio
  shares_syms = []  # Lists of shares of each symbol bought on each date
  value_portf = []  # List of portfolio values on each date
  shares_SPY = []  # List of shares of SPY bought on each date
  value_SPY = []  # List of values of SPY shares on each date

  # Iterate through pairs of dates, symbol lists, and shares
  for date, symbols, portf_shares, SPY_shares in zip(idx_date, str_symbols, my_portf_shares, my_SPY_shares):

    # Determine the execution date based on the lookback date and the offset n
    next_date_n = get_trading_date_n(date, idx_close, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None or portf_shares is None:
      # Handle missing data or missing shares:
      p_date_exec = None
      p_ar_shares = None
      p_value_portf = None  # Set to None when data or shares are unavailable
      SPY_ar_shares = None
      SPY_value_portf = None  # Set to None when data or shares are unavailable

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")

    else:
      # Calculate portfolio values when data and shares are available:
      p_date_exec, p_ar_syms, p_ar_price, p_ar_shares, p_ar_value, p_value_portf = calc_portf_value(df_close, close_date_n, symbols, portf_shares, verbose)

      SPY = str(['SPY'])  # Calculate SPY portfolio value separately
      SPY_date_exec, SPY_ar_syms, SPY_ar_price, SPY_ar_shares, SPY_ar_value, SPY_value_portf = calc_portf_value(df_close, close_date_n, SPY, SPY_shares, verbose)

      if verbose:
        print(f"next_date_n pick's portf value = {p_value_portf}")
        print(f'next_date_n SPY portf value =    {SPY_value_portf}')

    # Append results to lists
    date_exec.append(p_date_exec)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_value_portf)
    shares_SPY.append(SPY_ar_shares)
    value_SPY.append(SPY_value_portf)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
"""
Imports libraries, sets display options, and defines file paths for stock analysis.
"""

import pandas as pd  # Library for data manipulation and analysis
import numpy as np  # Library for numerical operations and array manipulation
from myUtils import pickle_load, pickle_dump  # Functions for loading and saving data

# Set pandas display options for better readability
pd.set_option('display.max_rows', 100)  # Display up to 100 rows
pd.set_option('display.max_columns', 30)  # Display up to 30 columns
pd.set_option('display.max_colwidth', 30)  # Display columns with a maximum width of 30 characters
pd.set_option('display.width', 900)  # Set overall display width to 900 characters

# Define file paths for data storage and retrieval
path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"  # Base directory for stock data
path_data_dump = path_dir + "VSCode_dump/"  # Subdirectory for pickled data

# Define file names for specific datasets
# fp_df_picks = f'df_picks'  # (Commented out) Stock picks by criteria (CAGR/UI, CAGR/rtn_std, rtd/UI)
fp_df_model_top_picks = 'df_model_top_picks'  # Top stock picks from the model developed by backtesting
fp_df_close_clean = 'df_close_clean'  # Historic closing prices for stocks

# Set verbose mode for printing information during execution
verbose = True

# %%
"""
Loads pre-processed datasets from pickled files.
"""

# Load the DataFrame containing historical closing prices:
df_close = pickle_load(path_data_dump, fp_df_close_clean)  # Load from the specified pickle file

# Load the DataFrame containing top stock picks from the model:
df_picks_mp = pickle_load(path_data_dump, fp_df_model_top_picks)  # Load from the specified pickle file

# %%
"""
Extracts and prints information about the date range and length of the df_picks_mp DataFrame.
"""

# Extract dates from the DataFrame and sort them chronologically:
dates_sorted = sorted(df_picks_mp.date.tolist())  # Create a list of dates and sort them

# Extract the first and last dates to determine the date range:
date_start_picks_mp = dates_sorted[0]  # Get the earliest date
date_end_picks_mp = dates_sorted[-1]  # Get the latest date

# Print the date range and the number of rows in the DataFrame:
print(f'date_start_picks_mp: {date_start_picks_mp}')
print(f'date_end_picks_mp: {date_end_picks_mp}')
print(f'len(df_picks_mp): {len(df_picks_mp)}')  # Print the length (number of rows)
# Out:
# date_start_picks_mp: 2018-07-06
# date_end_picks_mp: 2024-01-09
# len(df_picks_mp): 1488

# %%
"""
Filters the df_close DataFrame to match the date range of df_picks_mp and extracts information.
"""

# Create a boolean mask to filter rows within the desired date range:
mask = (df_close.index >= date_start_picks_mp) & (df_close.index <= date_end_picks_mp)  # Select rows between the start and end dates

# Apply the mask to filter the DataFrame:
df_close = df_close.loc[mask]  # Keep only rows that meet the date criteria

# Extract trading dates as formatted strings:
idx_close = df_close.index.strftime('%Y-%m-%d')  # Get trading dates in YYYY-MM-DD format

# Extract symbols present in the filtered DataFrame:
symbols_df_close = df_close.columns  # Get a list of symbols in the DataFrame

# Display the filtered DataFrame to verify its contents:
df_close  # Print the DataFrame to view the filtered data
# Out:
#                      A         AA        AAL         AAP        AAPL         AB        ABBV        ABR         ABT       ACGL       ACHC       ACIW        ACLS       ACRS        ADBE  ...        XRX         XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                                    ...
# 2018-07-06   59.826286  46.141720  37.283413  126.409645   44.790005  18.318951   75.155258   6.375905   56.669937  27.280001  42.250000  26.020000   21.049999  20.490000  248.190002  ...  18.737396   62.475822  39.959999   70.938240  35.505924  84.300117  106.129333  148.250000  76.154495  63.009998  44.027046  18.595818   83.722939  23.650000  27.790464
# 2018-07-09   60.623444  47.267368  38.477585  129.893112   45.411919  18.507799   75.248291   6.375905   56.925198  27.889999  42.950001  26.290001   22.100000  20.799999  249.770004  ...  19.221388   63.626072  40.000000   71.753937  35.515427  86.077866  106.743767  149.720001  76.639511  62.410000  45.157448  19.021460   84.330208  24.049999  28.109341
# 2018-07-10   61.151699  46.875832  38.291603  129.616653   45.357109  18.633709   76.644096   6.346524   57.262531  28.240000  43.090000  26.200001   21.549999  20.730000  248.630005  ...  19.413446   63.766319  39.400002   71.880821  34.935394  84.248070  106.874107  149.869995  75.677994  61.700001  44.730408  19.352510   83.106079  23.950001  28.215631
# 2018-07-11   60.373726  47.042236  35.198517  128.169830   44.768566  18.318951   73.635399   6.428794   57.043736  28.040001  42.939999  26.070000   20.400000  20.889999  248.119995  ...  19.213701   62.372971  39.400002   71.409538  34.516998  84.057297  106.278290  146.669998  74.818596  62.450001  44.487572  18.974161   81.448174  23.600000  27.742149
# 2018-07-12   60.940399  46.396214  35.560688  127.902550   45.519146  18.161572   74.896591   6.428794   57.455822  28.080000  43.310001  26.469999   20.850000  20.430000  254.869995  ...  19.328939   63.654118  40.720001   71.708633  34.773743  84.612282  106.166573  149.360001  75.269569  63.779999  44.001926  19.929491   82.383171  21.250000  27.771143
# ...                ...        ...        ...         ...         ...        ...         ...        ...         ...        ...        ...        ...         ...        ...         ...  ...        ...         ...        ...         ...        ...        ...         ...         ...        ...        ...        ...        ...         ...        ...        ...
# 2024-01-03  131.160004  31.490000  12.950000   61.000000  184.250000  30.370001  160.460007  14.690000  109.519997  76.940002  76.680000  29.530001  120.919998   1.120000  571.789978  ...  15.840000  111.559998  46.009998  129.100006  42.950001  32.970001  120.470001  252.520004  65.860001  53.980000  42.000000  21.059999  192.929993  18.930000  28.180000
# 2024-01-04  131.000000  31.129999  13.090000   60.490002  181.910004  31.049999  161.460007  14.810000  110.980003  77.470001  78.320000  29.330000  116.129997   1.100000  567.049988  ...  16.570000  112.330002  46.139999  128.690002  42.110001  33.459999  120.199997  252.970001  65.570000  52.750000  42.639999  20.490000  194.039993  18.600000  28.320000
# 2024-01-05  130.559998  32.130001  13.600000   61.520000  181.179993  31.100000  162.139999  14.560000  110.800003  76.809998  79.250000  29.309999  117.830002   1.060000  564.599976  ...  16.320000  112.150002  44.970001  128.339996  40.930000  33.259998  119.980003  252.690002  65.160004  52.430000  44.049999  19.950001  194.850006  18.290001  27.930000
# 2024-01-08  133.380005  31.730000  14.580000   61.910000  185.559998  31.250000  161.429993  14.680000  112.400002  77.120003  79.949997  30.020000  120.970001   1.180000  580.549988  ...  16.590000  112.849998  45.689999  128.639999  40.400002  32.720001  121.970001  261.089996  66.650002  54.580002  44.540001  19.650000  196.149994  18.770000  28.049999
# 2024-01-09  130.679993  31.940001  14.380000   61.389999  185.139999  31.549999  162.309998  14.790000  112.730003  76.150002  80.190002  29.770000  120.150002   1.280000  586.200012  ...  16.250000  112.110001  44.930000  128.220001  39.160000  32.689999  121.870003  256.440002  65.430000  54.349998  44.040001  19.500000  195.940002  18.209999  28.040001
#
# [1387 rows x 1267 columns]

# %%
"""
Displays the first few rows of the df_picks_mp DataFrame for a quick overview.
"""

df_picks_mp.head()  # Show the first 5 rows (by default) to preview the data
# Out:
#          date      days_lookback    syms_freq          symbols
# 0  2024-01-09      [30, 60, 120]   sym_freq_9         ['CYTK']
# 1  2024-01-09      [30, 60, 120]   sym_freq_8  ['FTSM', 'SHV']
# 2  2024-01-09  [15, 30, 60, 120]  sym_freq_12         ['CYTK']
# 3  2024-01-08      [30, 60, 120]   sym_freq_9         ['CYTK']
# 4  2024-01-08      [30, 60, 120]   sym_freq_8  ['FTSM', 'SHV']

# %%
"""
Sets a target investment amount and calls a function to calculate portfolio values.
"""

# Set the total target investment amount for each day's picks:
portf_target = 1000  # Invest $1000 in total for each day's picks

# Call the function to calculate portfolio values, handling potential missing data:
date_buy, shares_syms, value_portf, shares_SPY, value_SPY = \
    calc_portf_value_date_buy(df_picks_mp.date, df_picks_mp.symbols, df_close, portf_target, n=1, verbose=verbose)

# Breakdown of the function call:
# - calc_portf_value_date_buy: Function name (assumed to be defined elsewhere)
# - df_picks_mp.date: List of dates from the df_picks_mp DataFrame
# - df_picks_mp.symbols: List of stock symbols from the df_picks_mp DataFrame
# - df_close: DataFrame containing historical closing prices
# - portf_target: Total target investment amount ($1000 in this case)
# - n=1: Offset the execution date by 1 trading day from the lookback date
# - verbose=verbose: Print details if verbose mode is enabled
# Out:
# ++++++++++++++
# date: 2024-01-09
# n: 1
# next_date_n: None
# close_date_n: None
# syms: ['CYTK']
# ++++++++++++++
# l_syms: ['CYTK']
# sym_not_in_df_close: False
# No data for close_date_n None, pick's portf value = None
# No data for close_date_n None, SPY portf value =    None
# ====================
#
# ++++++++++++++
# date: 2024-01-09
# n: 1
# next_date_n: None
# close_date_n: None
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# l_syms: ['FTSM', 'SHV']
# sym_not_in_df_close: False
# No data for close_date_n None, pick's portf value = None
# No data for close_date_n None, SPY portf value =    None
# ====================
#
# ++++++++++++++
# date: 2024-01-09
# n: 1
# next_date_n: None
# close_date_n: None
# syms: ['CYTK']
# ++++++++++++++
# l_syms: ['CYTK']
# sym_not_in_df_close: False
# No data for close_date_n None, pick's portf value = None
# No data for close_date_n None, SPY portf value =    None
# ====================
#
# ++++++++++++++
# date: 2024-01-08
# n: 1
# next_date_n: 2024-01-09
# close_date_n: 2024-01-09
# syms: ['CYTK']
# ++++++++++++++
# date = 2024-01-09, l_syms = ['CYTK'], ar_price = [101.97000122], ar_shares = [9.], ar_value = [917.73001099], portf_value = 917.7300109863281
# 2024-01-09 portf_value = 917.7300109863281
# date = 2024-01-09, l_syms = ['SPY'], ar_price = [473.88000488], ar_shares = [2.], ar_value = [947.76000977], portf_value = 947.760009765625
# 2024-01-09 portf_value = 947.760009765625
# close_date_n pick's portf value = 917.7300109863281
# close_date_n SPY portf value =    947.760009765625
# ====================
#
# ++++++++++++++
# date: 2024-01-08
# n: 1
# next_date_n: 2024-01-09
# close_date_n: 2024-01-09
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2024-01-09, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.72999954 110.22000122], ar_shares = [8. 4.], ar_value = [477.83999634 440.88000488], portf_value = 918.7200012207031
# 2024-01-09 portf_value = 918.7200012207031
# date = 2024-01-09, l_syms = ['SPY'], ar_price = [473.88000488], ar_shares = [2.], ar_value = [947.76000977], portf_value = 947.760009765625
# 2024-01-09 portf_value = 947.760009765625
# close_date_n pick's portf value = 918.7200012207031
# close_date_n SPY portf value =    947.760009765625
# ====================
#
# ++++++++++++++
# date: 2024-01-08
# n: 1
# next_date_n: 2024-01-09
# close_date_n: 2024-01-09
# syms: ['CYTK']
# ++++++++++++++
# date = 2024-01-09, l_syms = ['CYTK'], ar_price = [101.97000122], ar_shares = [9.], ar_value = [917.73001099], portf_value = 917.7300109863281
# 2024-01-09 portf_value = 917.7300109863281
# date = 2024-01-09, l_syms = ['SPY'], ar_price = [473.88000488], ar_shares = [2.], ar_value = [947.76000977], portf_value = 947.760009765625
# 2024-01-09 portf_value = 947.760009765625
# close_date_n pick's portf value = 917.7300109863281
# close_date_n SPY portf value =    947.760009765625
# ====================
#
# ++++++++++++++
# date: 2024-01-05
# n: 1
# next_date_n: 2024-01-08
# close_date_n: 2024-01-08
# syms: ['CYTK']
# ++++++++++++++
# date = 2024-01-08, l_syms = ['CYTK'], ar_price = [108.05999756], ar_shares = [9.], ar_value = [972.53997803], portf_value = 972.5399780273438
# 2024-01-08 portf_value = 972.5399780273438
# date = 2024-01-08, l_syms = ['SPY'], ar_price = [474.6000061], ar_shares = [2.], ar_value = [949.20001221], portf_value = 949.2000122070312
# 2024-01-08 portf_value = 949.2000122070312
# close_date_n pick's portf value = 972.5399780273438
# close_date_n SPY portf value =    949.2000122070312
# ====================
#
# ++++++++++++++
# date: 2024-01-05
# n: 1
# next_date_n: 2024-01-08
# close_date_n: 2024-01-08
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2024-01-08, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.70999908 110.20999908], ar_shares = [8. 4.], ar_value = [477.67999268 440.83999634], portf_value = 918.5199890136719
# 2024-01-08 portf_value = 918.5199890136719
# date = 2024-01-08, l_syms = ['SPY'], ar_price = [474.6000061], ar_shares = [2.], ar_value = [949.20001221], portf_value = 949.2000122070312
# 2024-01-08 portf_value = 949.2000122070312
# close_date_n pick's portf value = 918.5199890136719
# close_date_n SPY portf value =    949.2000122070312
# ====================
#
# ++++++++++++++
# date: 2024-01-05
# n: 1
# next_date_n: 2024-01-08
# close_date_n: 2024-01-08
# syms: ['CYTK']
# ++++++++++++++
# date = 2024-01-08, l_syms = ['CYTK'], ar_price = [108.05999756], ar_shares = [9.], ar_value = [972.53997803], portf_value = 972.5399780273438
# 2024-01-08 portf_value = 972.5399780273438
# date = 2024-01-08, l_syms = ['SPY'], ar_price = [474.6000061], ar_shares = [2.], ar_value = [949.20001221], portf_value = 949.2000122070312
# 2024-01-08 portf_value = 949.2000122070312
# close_date_n pick's portf value = 972.5399780273438
# close_date_n SPY portf value =    949.2000122070312
# ====================
#
# ++++++++++++++
# date: 2024-01-04
# n: 1
# next_date_n: 2024-01-05
# close_date_n: 2024-01-05
# syms: ['CYTK']
# ++++++++++++++
# date = 2024-01-05, l_syms = ['CYTK'], ar_price = [93.73000336], ar_shares = [10.], ar_value = [937.30003357], portf_value = 937.3000335693359
# 2024-01-05 portf_value = 937.3000335693359
# date = 2024-01-05, l_syms = ['SPY'], ar_price = [467.92001343], ar_shares = [2.], ar_value = [935.84002686], portf_value = 935.8400268554688
# 2024-01-05 portf_value = 935.8400268554688
# close_date_n pick's portf value = 937.3000335693359
# close_date_n SPY portf value =    935.8400268554688
# ====================
#
# ++++++++++++++
# date: 2024-01-04
# n: 1
# next_date_n: 2024-01-05
# close_date_n: 2024-01-05
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2024-01-05, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.70000076 110.19000244], ar_shares = [8. 4.], ar_value = [477.6000061  440.76000977], portf_value = 918.3600158691406
# 2024-01-05 portf_value = 918.3600158691406
# date = 2024-01-05, l_syms = ['SPY'], ar_price = [467.92001343], ar_shares = [2.], ar_value = [935.84002686], portf_value = 935.8400268554688
# 2024-01-05 portf_value = 935.8400268554688
# close_date_n pick's portf value = 918.3600158691406
# close_date_n SPY portf value =    935.8400268554688
# ====================
#
# ++++++++++++++
# date: 2024-01-04
# n: 1
# next_date_n: 2024-01-05
# close_date_n: 2024-01-05
# syms: ['CYTK']
# ++++++++++++++
# date = 2024-01-05, l_syms = ['CYTK'], ar_price = [93.73000336], ar_shares = [10.], ar_value = [937.30003357], portf_value = 937.3000335693359
# 2024-01-05 portf_value = 937.3000335693359
# date = 2024-01-05, l_syms = ['SPY'], ar_price = [467.92001343], ar_shares = [2.], ar_value = [935.84002686], portf_value = 935.8400268554688
# 2024-01-05 portf_value = 935.8400268554688
# close_date_n pick's portf value = 937.3000335693359
# close_date_n SPY portf value =    935.8400268554688
# ====================
#
# ++++++++++++++
# date: 2024-01-03
# n: 1
# next_date_n: 2024-01-04
# close_date_n: 2024-01-04
# syms: ['CYTK', 'FTSM', 'SHV']
# ++++++++++++++
# date = 2024-01-04, l_syms = ['CYTK', 'FTSM', 'SHV'], ar_price = [ 88.23999786  59.68999863 110.18000031], ar_shares = [3. 5. 3.], ar_value = [264.71999359 298.44999313 330.54000092], portf_value = 893.7099876403809
# 2024-01-04 portf_value = 893.7099876403809
# date = 2024-01-04, l_syms = ['SPY'], ar_price = [467.27999878], ar_shares = [2.], ar_value = [934.55999756], portf_value = 934.5599975585938
# 2024-01-04 portf_value = 934.5599975585938
# close_date_n pick's portf value = 893.7099876403809
# close_date_n SPY portf value =    934.5599975585938
# ====================
#
# ++++++++++++++
# date: 2024-01-02
# n: 1
# next_date_n: 2024-01-03
# close_date_n: 2024-01-03
# syms: ['CYTK', 'SHV']
# ++++++++++++++
# date = 2024-01-03, l_syms = ['CYTK', 'SHV'], ar_price = [ 86.63999939 110.12999725], ar_shares = [5. 4.], ar_value = [433.19999695 440.51998901], portf_value = 873.7199859619141
# 2024-01-03 portf_value = 873.7199859619141
# date = 2024-01-03, l_syms = ['SPY'], ar_price = [468.79000854], ar_shares = [2.], ar_value = [937.58001709], portf_value = 937.5800170898438
# 2024-01-03 portf_value = 937.5800170898438
# close_date_n pick's portf value = 873.7199859619141
# close_date_n SPY portf value =    937.5800170898438
# ====================
#
# ++++++++++++++
# date: 2023-12-29
# n: 1
# next_date_n: 2024-01-02
# close_date_n: 2024-01-02
# syms: ['CYTK', 'SHV']
# ++++++++++++++
# date = 2024-01-02, l_syms = ['CYTK', 'SHV'], ar_price = [ 84.12000275 110.12000275], ar_shares = [5. 4.], ar_value = [420.60001373 440.48001099], portf_value = 861.0800247192383
# 2024-01-02 portf_value = 861.0800247192383
# date = 2024-01-02, l_syms = ['SPY'], ar_price = [472.6499939], ar_shares = [2.], ar_value = [945.29998779], portf_value = 945.2999877929688
# 2024-01-02 portf_value = 945.2999877929688
# close_date_n pick's portf value = 861.0800247192383
# close_date_n SPY portf value =    945.2999877929688
# ====================
#
# ++++++++++++++
# date: 2023-12-28
# n: 1
# next_date_n: 2023-12-29
# close_date_n: 2023-12-29
# syms: ['CYTK', 'SHV']
# ++++++++++++++
# date = 2023-12-29, l_syms = ['CYTK', 'SHV'], ar_price = [ 83.48999786 110.12999725], ar_shares = [5. 4.], ar_value = [417.44998932 440.51998901], portf_value = 857.9699783325195
# 2023-12-29 portf_value = 857.9699783325195
# date = 2023-12-29, l_syms = ['SPY'], ar_price = [475.30999756], ar_shares = [2.], ar_value = [950.61999512], portf_value = 950.6199951171875
# 2023-12-29 portf_value = 950.6199951171875
# close_date_n pick's portf value = 857.9699783325195
# close_date_n SPY portf value =    950.6199951171875
# ====================
#
# ++++++++++++++
# date: 2023-12-27
# n: 1
# next_date_n: 2023-12-28
# close_date_n: 2023-12-28
# syms: ['CYTK', 'SHV']
# ++++++++++++++
# date = 2023-12-28, l_syms = ['CYTK', 'SHV'], ar_price = [ 83.23999786 110.09999847], ar_shares = [6. 4.], ar_value = [499.43998718 440.3999939 ], portf_value = 939.8399810791016
# 2023-12-28 portf_value = 939.8399810791016
# date = 2023-12-28, l_syms = ['SPY'], ar_price = [476.69000244], ar_shares = [2.], ar_value = [953.38000488], portf_value = 953.3800048828125
# 2023-12-28 portf_value = 953.3800048828125
# close_date_n pick's portf value = 939.8399810791016
# close_date_n SPY portf value =    953.3800048828125
# ====================
#
# ++++++++++++++
# date: 2023-12-26
# n: 1
# next_date_n: 2023-12-27
# close_date_n: 2023-12-27
# syms: ['SHV']
# ++++++++++++++
# date = 2023-12-27, l_syms = ['SHV'], ar_price = [110.02999878], ar_shares = [9.], ar_value = [990.26998901], portf_value = 990.2699890136719
# 2023-12-27 portf_value = 990.2699890136719
# date = 2023-12-27, l_syms = ['SPY'], ar_price = [476.51000977], ar_shares = [2.], ar_value = [953.02001953], portf_value = 953.02001953125
# 2023-12-27 portf_value = 953.02001953125
# close_date_n pick's portf value = 990.2699890136719
# close_date_n SPY portf value =    953.02001953125
# ====================
#
# ++++++++++++++
# date: 2023-12-22
# n: 1
# next_date_n: 2023-12-26
# close_date_n: 2023-12-26
# syms: ['SHV']
# ++++++++++++++
# date = 2023-12-26, l_syms = ['SHV'], ar_price = [110.02999878], ar_shares = [9.], ar_value = [990.26998901], portf_value = 990.2699890136719
# 2023-12-26 portf_value = 990.2699890136719
# date = 2023-12-26, l_syms = ['SPY'], ar_price = [475.6499939], ar_shares = [2.], ar_value = [951.29998779], portf_value = 951.2999877929688
# 2023-12-26 portf_value = 951.2999877929688
# close_date_n pick's portf value = 990.2699890136719
# close_date_n SPY portf value =    951.2999877929688
# ====================
#
# ++++++++++++++
# date: 2023-12-21
# n: 1
# next_date_n: 2023-12-22
# close_date_n: 2023-12-22
# syms: ['SHV']
# ++++++++++++++
# date = 2023-12-22, l_syms = ['SHV'], ar_price = [110.01000214], ar_shares = [9.], ar_value = [990.09001923], portf_value = 990.0900192260742
# 2023-12-22 portf_value = 990.0900192260742
# date = 2023-12-22, l_syms = ['SPY'], ar_price = [473.6499939], ar_shares = [2.], ar_value = [947.29998779], portf_value = 947.2999877929688
# 2023-12-22 portf_value = 947.2999877929688
# close_date_n pick's portf value = 990.0900192260742
# close_date_n SPY portf value =    947.2999877929688
# ====================
#
# ++++++++++++++
# date: 2023-12-20
# n: 1
# next_date_n: 2023-12-21
# close_date_n: 2023-12-21
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-21, l_syms = ['GPS', 'SHV'], ar_price = [ 21.09756088 109.98999786], ar_shares = [23.  4.], ar_value = [485.2439003  439.95999146], portf_value = 925.2038917541504
# 2023-12-21 portf_value = 925.2038917541504
# date = 2023-12-21, l_syms = ['SPY'], ar_price = [472.70001221], ar_shares = [2.], ar_value = [945.40002441], portf_value = 945.4000244140625
# 2023-12-21 portf_value = 945.4000244140625
# close_date_n pick's portf value = 925.2038917541504
# close_date_n SPY portf value =    945.4000244140625
# ====================
#
# ++++++++++++++
# date: 2023-12-19
# n: 1
# next_date_n: 2023-12-20
# close_date_n: 2023-12-20
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-20, l_syms = ['GPS', 'SHV'], ar_price = [ 20.53165054 109.91999817], ar_shares = [24.  4.], ar_value = [492.75961304 439.67999268], portf_value = 932.4396057128906
# 2023-12-20 portf_value = 932.4396057128906
# date = 2023-12-20, l_syms = ['SPY'], ar_price = [468.26000977], ar_shares = [2.], ar_value = [936.52001953], portf_value = 936.52001953125
# 2023-12-20 portf_value = 936.52001953125
# close_date_n pick's portf value = 932.4396057128906
# close_date_n SPY portf value =    936.52001953125
# ====================
#
# ++++++++++++++
# date: 2023-12-18
# n: 1
# next_date_n: 2023-12-19
# close_date_n: 2023-12-19
# syms: ['SHV']
# ++++++++++++++
# date = 2023-12-19, l_syms = ['SHV'], ar_price = [109.88999939], ar_shares = [9.], ar_value = [989.00999451], portf_value = 989.0099945068359
# 2023-12-19 portf_value = 989.0099945068359
# date = 2023-12-19, l_syms = ['SPY'], ar_price = [474.83999634], ar_shares = [2.], ar_value = [949.67999268], portf_value = 949.6799926757812
# 2023-12-19 portf_value = 949.6799926757812
# close_date_n pick's portf value = 989.0099945068359
# close_date_n SPY portf value =    949.6799926757812
# ====================
#
# ++++++++++++++
# date: 2023-12-15
# n: 1
# next_date_n: 2023-12-18
# close_date_n: 2023-12-18
# syms: ['SHV']
# ++++++++++++++
# date = 2023-12-18, l_syms = ['SHV'], ar_price = [109.88999939], ar_shares = [9.], ar_value = [989.00999451], portf_value = 989.0099945068359
# 2023-12-18 portf_value = 989.0099945068359
# date = 2023-12-18, l_syms = ['SPY'], ar_price = [471.97000122], ar_shares = [2.], ar_value = [943.94000244], portf_value = 943.9400024414062
# 2023-12-18 portf_value = 943.9400024414062
# close_date_n pick's portf value = 989.0099945068359
# close_date_n SPY portf value =    943.9400024414062
# ====================
#
# ++++++++++++++
# date: 2023-12-13
# n: 1
# next_date_n: 2023-12-14
# close_date_n: 2023-12-14
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-14, l_syms = ['GPS', 'SHV'], ar_price = [ 21.14720154 109.86000061], ar_shares = [23.  4.], ar_value = [486.38563538 439.44000244], portf_value = 925.8256378173828
# 2023-12-14 portf_value = 925.8256378173828
# date = 2023-12-14, l_syms = ['SPY'], ar_price = [470.10400391], ar_shares = [2.], ar_value = [940.20800781], portf_value = 940.2080078125
# 2023-12-14 portf_value = 940.2080078125
# close_date_n pick's portf value = 925.8256378173828
# close_date_n SPY portf value =    940.2080078125
# ====================
#
# ++++++++++++++
# date: 2023-12-12
# n: 1
# next_date_n: 2023-12-13
# close_date_n: 2023-12-13
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-13, l_syms = ['GPS', 'SHV'], ar_price = [ 21.07770348 109.80599976], ar_shares = [23.  4.], ar_value = [484.78717995 439.22399902], portf_value = 924.0111789703369
# 2023-12-13 portf_value = 924.0111789703369
# date = 2023-12-13, l_syms = ['SPY'], ar_price = [468.60009766], ar_shares = [2.], ar_value = [937.20019531], portf_value = 937.2001953125
# 2023-12-13 portf_value = 937.2001953125
# close_date_n pick's portf value = 924.0111789703369
# close_date_n SPY portf value =    937.2001953125
# ====================
#
# ++++++++++++++
# date: 2023-12-11
# n: 1
# next_date_n: 2023-12-12
# close_date_n: 2023-12-12
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-12, l_syms = ['GPS', 'SHV'], ar_price = [ 21.14720154 109.76618195], ar_shares = [23.  4.], ar_value = [486.38563538 439.06472778], portf_value = 925.4503631591797
# 2023-12-12 portf_value = 925.4503631591797
# date = 2023-12-12, l_syms = ['SPY'], ar_price = [462.22595215], ar_shares = [2.], ar_value = [924.4519043], portf_value = 924.451904296875
# 2023-12-12 portf_value = 924.451904296875
# close_date_n pick's portf value = 925.4503631591797
# close_date_n SPY portf value =    924.451904296875
# ====================
#
# ++++++++++++++
# date: 2023-12-08
# n: 1
# next_date_n: 2023-12-11
# close_date_n: 2023-12-11
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-11, l_syms = ['GPS', 'SHV'], ar_price = [ 21.7726841 109.7363205], ar_shares = [22.  4.], ar_value = [478.99905014 438.94528198], portf_value = 917.9443321228027
# 2023-12-11 portf_value = 917.9443321228027
# date = 2023-12-11, l_syms = ['SPY'], ar_price = [460.12445068], ar_shares = [2.], ar_value = [920.24890137], portf_value = 920.2489013671875
# 2023-12-11 portf_value = 920.2489013671875
# close_date_n pick's portf value = 917.9443321228027
# close_date_n SPY portf value =    920.2489013671875
# ====================
#
# ++++++++++++++
# date: 2023-12-07
# n: 1
# next_date_n: 2023-12-08
# close_date_n: 2023-12-08
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-08, l_syms = ['GPS', 'SHV'], ar_price = [ 21.52447701 109.7363205 ], ar_shares = [23.  4.], ar_value = [495.06297112 438.94528198], portf_value = 934.0082530975342
# 2023-12-08 portf_value = 934.0082530975342
# date = 2023-12-08, l_syms = ['SPY'], ar_price = [458.34170532], ar_shares = [2.], ar_value = [916.68341064], portf_value = 916.6834106445312
# 2023-12-08 portf_value = 916.6834106445312
# close_date_n pick's portf value = 934.0082530975342
# close_date_n SPY portf value =    916.6834106445312
# ====================
#
# ++++++++++++++
# date: 2023-12-06
# n: 1
# next_date_n: 2023-12-07
# close_date_n: 2023-12-07
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-07, l_syms = ['GPS', 'SHV'], ar_price = [ 21.21670151 109.7363205 ], ar_shares = [23.  4.], ar_value = [487.98413467 438.94528198], portf_value = 926.9294166564941
# 2023-12-07 portf_value = 926.9294166564941
# date = 2023-12-07, l_syms = ['SPY'], ar_price = [456.37966919], ar_shares = [2.], ar_value = [912.75933838], portf_value = 912.7593383789062
# 2023-12-07 portf_value = 912.7593383789062
# close_date_n pick's portf value = 926.9294166564941
# close_date_n SPY portf value =    912.7593383789062
# ====================
#
# ++++++++++++++
# date: 2023-12-05
# n: 1
# next_date_n: 2023-12-06
# close_date_n: 2023-12-06
# syms: ['GPS']
# ++++++++++++++
# date = 2023-12-06, l_syms = ['GPS'], ar_price = [20.78978539], ar_shares = [48.], ar_value = [997.90969849], portf_value = 997.9096984863281
# 2023-12-06 portf_value = 997.9096984863281
# date = 2023-12-06, l_syms = ['SPY'], ar_price = [452.92367554], ar_shares = [2.], ar_value = [905.84735107], portf_value = 905.8473510742188
# 2023-12-06 portf_value = 905.8473510742188
# close_date_n pick's portf value = 997.9096984863281
# close_date_n SPY portf value =    905.8473510742188
# ====================
#
# ++++++++++++++
# date: 2023-12-05
# n: 1
# next_date_n: 2023-12-06
# close_date_n: 2023-12-06
# syms: ['LRN', 'SHV']
# ++++++++++++++
# date = 2023-12-06, l_syms = ['LRN', 'SHV'], ar_price = [ 60.68999863 109.68655396], ar_shares = [8. 4.], ar_value = [485.51998901 438.74621582], portf_value = 924.2662048339844
# 2023-12-06 portf_value = 924.2662048339844
# date = 2023-12-06, l_syms = ['SPY'], ar_price = [452.92367554], ar_shares = [2.], ar_value = [905.84735107], portf_value = 905.8473510742188
# 2023-12-06 portf_value = 905.8473510742188
# close_date_n pick's portf value = 924.2662048339844
# close_date_n SPY portf value =    905.8473510742188
# ====================
#
# ++++++++++++++
# date: 2023-12-05
# n: 1
# next_date_n: 2023-12-06
# close_date_n: 2023-12-06
# syms: ['GPS']
# ++++++++++++++
# date = 2023-12-06, l_syms = ['GPS'], ar_price = [20.78978539], ar_shares = [48.], ar_value = [997.90969849], portf_value = 997.9096984863281
# 2023-12-06 portf_value = 997.9096984863281
# date = 2023-12-06, l_syms = ['SPY'], ar_price = [452.92367554], ar_shares = [2.], ar_value = [905.84735107], portf_value = 905.8473510742188
# 2023-12-06 portf_value = 905.8473510742188
# close_date_n pick's portf value = 997.9096984863281
# close_date_n SPY portf value =    905.8473510742188
# ====================
#
# ++++++++++++++
# date: 2023-12-04
# n: 1
# next_date_n: 2023-12-05
# close_date_n: 2023-12-05
# syms: ['GPS']
# ++++++++++++++
# date = 2023-12-05, l_syms = ['GPS'], ar_price = [20.63093376], ar_shares = [48.], ar_value = [990.28482056], portf_value = 990.2848205566406
# 2023-12-05 portf_value = 990.2848205566406
# date = 2023-12-05, l_syms = ['SPY'], ar_price = [454.75622559], ar_shares = [2.], ar_value = [909.51245117], portf_value = 909.512451171875
# 2023-12-05 portf_value = 909.512451171875
# close_date_n pick's portf value = 990.2848205566406
# close_date_n SPY portf value =    909.512451171875
# ====================
#
# ++++++++++++++
# date: 2023-12-04
# n: 1
# next_date_n: 2023-12-05
# close_date_n: 2023-12-05
# syms: ['SHV']
# ++++++++++++++
# date = 2023-12-05, l_syms = ['SHV'], ar_price = [109.66664124], ar_shares = [9.], ar_value = [986.99977112], portf_value = 986.9997711181641
# 2023-12-05 portf_value = 986.9997711181641
# date = 2023-12-05, l_syms = ['SPY'], ar_price = [454.75622559], ar_shares = [2.], ar_value = [909.51245117], portf_value = 909.512451171875
# 2023-12-05 portf_value = 909.512451171875
# close_date_n pick's portf value = 986.9997711181641
# close_date_n SPY portf value =    909.512451171875
# ====================
#
# ++++++++++++++
# date: 2023-12-04
# n: 1
# next_date_n: 2023-12-05
# close_date_n: 2023-12-05
# syms: ['GPS']
# ++++++++++++++
# date = 2023-12-05, l_syms = ['GPS'], ar_price = [20.63093376], ar_shares = [48.], ar_value = [990.28482056], portf_value = 990.2848205566406
# 2023-12-05 portf_value = 990.2848205566406
# date = 2023-12-05, l_syms = ['SPY'], ar_price = [454.75622559], ar_shares = [2.], ar_value = [909.51245117], portf_value = 909.512451171875
# 2023-12-05 portf_value = 909.512451171875
# close_date_n pick's portf value = 990.2848205566406
# close_date_n SPY portf value =    909.512451171875
# ====================
#
# ++++++++++++++
# date: 2023-12-01
# n: 1
# next_date_n: 2023-12-04
# close_date_n: 2023-12-04
# syms: ['GPS']
# ++++++++++++++
# date = 2023-12-04, l_syms = ['GPS'], ar_price = [20.69050217], ar_shares = [48.], ar_value = [993.144104], portf_value = 993.1441040039062
# 2023-12-04 portf_value = 993.1441040039062
# date = 2023-12-04, l_syms = ['SPY'], ar_price = [454.84588623], ar_shares = [2.], ar_value = [909.69177246], portf_value = 909.6917724609375
# 2023-12-04 portf_value = 909.6917724609375
# close_date_n pick's portf value = 993.1441040039062
# close_date_n SPY portf value =    909.6917724609375
# ====================
#
# ++++++++++++++
# date: 2023-12-01
# n: 1
# next_date_n: 2023-12-04
# close_date_n: 2023-12-04
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-12-04, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.35801697 109.64673615], ar_shares = [8. 4.], ar_value = [474.86413574 438.58694458], portf_value = 913.4510803222656
# 2023-12-04 portf_value = 913.4510803222656
# date = 2023-12-04, l_syms = ['SPY'], ar_price = [454.84588623], ar_shares = [2.], ar_value = [909.69177246], portf_value = 909.6917724609375
# 2023-12-04 portf_value = 909.6917724609375
# close_date_n pick's portf value = 913.4510803222656
# close_date_n SPY portf value =    909.6917724609375
# ====================
#
# ++++++++++++++
# date: 2023-12-01
# n: 1
# next_date_n: 2023-12-04
# close_date_n: 2023-12-04
# syms: ['GPS']
# ++++++++++++++
# date = 2023-12-04, l_syms = ['GPS'], ar_price = [20.69050217], ar_shares = [48.], ar_value = [993.144104], portf_value = 993.1441040039062
# 2023-12-04 portf_value = 993.1441040039062
# date = 2023-12-04, l_syms = ['SPY'], ar_price = [454.84588623], ar_shares = [2.], ar_value = [909.69177246], portf_value = 909.6917724609375
# 2023-12-04 portf_value = 909.6917724609375
# close_date_n pick's portf value = 993.1441040039062
# close_date_n SPY portf value =    909.6917724609375
# ====================
#
# ++++++++++++++
# date: 2023-11-30
# n: 1
# next_date_n: 2023-12-01
# close_date_n: 2023-12-01
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-12-01, l_syms = ['GPS', 'SHV'], ar_price = [ 20.8692112  109.63677979], ar_shares = [23.  4.], ar_value = [479.99185753 438.54711914], portf_value = 918.5389766693115
# 2023-12-01 portf_value = 918.5389766693115
# date = 2023-12-01, l_syms = ['SPY'], ar_price = [457.24615479], ar_shares = [2.], ar_value = [914.49230957], portf_value = 914.4923095703125
# 2023-12-01 portf_value = 914.4923095703125
# close_date_n pick's portf value = 918.5389766693115
# close_date_n SPY portf value =    914.4923095703125
# ====================
#
# ++++++++++++++
# date: 2023-11-29
# n: 1
# next_date_n: 2023-11-30
# close_date_n: 2023-11-30
# syms: ['FTSM', 'GPS', 'SHV']
# ++++++++++++++
# date = 2023-11-30, l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = [ 59.30822754  19.92602539 109.60192871], ar_shares = [ 5. 16.  3.], ar_value = [296.5411377  318.81640625 328.80578613], portf_value = 944.163330078125
# 2023-11-30 portf_value = 944.163330078125
# date = 2023-11-30, l_syms = ['SPY'], ar_price = [454.55703735], ar_shares = [2.], ar_value = [909.11407471], portf_value = 909.1140747070312
# 2023-11-30 portf_value = 909.1140747070312
# close_date_n pick's portf value = 944.163330078125
# close_date_n SPY portf value =    909.1140747070312
# ====================
#
# ++++++++++++++
# date: 2023-11-28
# n: 1
# next_date_n: 2023-11-29
# close_date_n: 2023-11-29
# syms: ['SHV']
# ++++++++++++++
# date = 2023-11-29, l_syms = ['SHV'], ar_price = [109.56229401], ar_shares = [9.], ar_value = [986.06064606], portf_value = 986.0606460571289
# 2023-11-29 portf_value = 986.0606460571289
# date = 2023-11-29, l_syms = ['SPY'], ar_price = [452.77426147], ar_shares = [2.], ar_value = [905.54852295], portf_value = 905.5485229492188
# 2023-11-29 portf_value = 905.5485229492188
# close_date_n pick's portf value = 986.0606460571289
# close_date_n SPY portf value =    905.5485229492188
# ====================
#
# ++++++++++++++
# date: 2023-11-28
# n: 1
# next_date_n: 2023-11-29
# close_date_n: 2023-11-29
# syms: ['FTSM', 'GPS']
# ++++++++++++++
# date = 2023-11-29, l_syms = ['FTSM', 'GPS'], ar_price = [59.28532028 20.01538086], ar_shares = [ 8. 24.], ar_value = [474.28256226 480.36914062], portf_value = 954.6517028808594
# 2023-11-29 portf_value = 954.6517028808594
# date = 2023-11-29, l_syms = ['SPY'], ar_price = [452.77426147], ar_shares = [2.], ar_value = [905.54852295], portf_value = 905.5485229492188
# 2023-11-29 portf_value = 905.5485229492188
# close_date_n pick's portf value = 954.6517028808594
# close_date_n SPY portf value =    905.5485229492188
# ====================
#
# ++++++++++++++
# date: 2023-11-27
# n: 1
# next_date_n: 2023-11-28
# close_date_n: 2023-11-28
# syms: ['FTSM', 'GPS', 'SHV']
# ++++++++++++++
# date = 2023-11-28, l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = [ 59.27540588  19.40975571 109.54247284], ar_shares = [ 5. 17.  3.], ar_value = [296.37702942 329.96584702 328.62741852], portf_value = 954.9702949523926
# 2023-11-28 portf_value = 954.9702949523926
# date = 2023-11-28, l_syms = ['SPY'], ar_price = [453.09295654], ar_shares = [2.], ar_value = [906.18591309], portf_value = 906.1859130859375
# 2023-11-28 portf_value = 906.1859130859375
# close_date_n pick's portf value = 954.9702949523926
# close_date_n SPY portf value =    906.1859130859375
# ====================
#
# ++++++++++++++
# date: 2023-11-24
# n: 1
# next_date_n: 2023-11-27
# close_date_n: 2023-11-27
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-11-27, l_syms = ['GPS', 'SHV'], ar_price = [ 19.30054665 109.51274109], ar_shares = [25.  4.], ar_value = [482.51366615 438.05096436], portf_value = 920.5646305084229
# 2023-11-27 portf_value = 920.5646305084229
# date = 2023-11-27, l_syms = ['SPY'], ar_price = [452.64480591], ar_shares = [2.], ar_value = [905.28961182], portf_value = 905.2896118164062
# 2023-11-27 portf_value = 905.2896118164062
# close_date_n pick's portf value = 920.5646305084229
# close_date_n SPY portf value =    905.2896118164062
# ====================
#
# ++++++++++++++
# date: 2023-11-22
# n: 1
# next_date_n: 2023-11-24
# close_date_n: 2023-11-24
# syms: ['GPS', 'SHV']
# ++++++++++++++
# date = 2023-11-24, l_syms = ['GPS', 'SHV'], ar_price = [ 18.72470665 109.49291992], ar_shares = [26.  4.], ar_value = [486.84237289 437.97167969], portf_value = 924.8140525817871
# 2023-11-24 portf_value = 924.8140525817871
# date = 2023-11-24, l_syms = ['SPY'], ar_price = [453.4614563], ar_shares = [2.], ar_value = [906.9229126], portf_value = 906.9229125976562
# 2023-11-24 portf_value = 906.9229125976562
# close_date_n pick's portf value = 924.8140525817871
# close_date_n SPY portf value =    906.9229125976562
# ====================
#
# ++++++++++++++
# date: 2023-11-21
# n: 1
# next_date_n: 2023-11-22
# close_date_n: 2023-11-22
# syms: ['SHV']
# ++++++++++++++
# date = 2023-11-22, l_syms = ['SHV'], ar_price = [109.48300934], ar_shares = [9.], ar_value = [985.34708405], portf_value = 985.3470840454102
# 2023-11-22 portf_value = 985.3470840454102
# date = 2023-11-22, l_syms = ['SPY'], ar_price = [453.18261719], ar_shares = [2.], ar_value = [906.36523438], portf_value = 906.365234375
# 2023-11-22 portf_value = 906.365234375
# close_date_n pick's portf value = 985.3470840454102
# close_date_n SPY portf value =    906.365234375
# ====================
#
# ++++++++++++++
# date: 2023-11-21
# n: 1
# next_date_n: 2023-11-22
# close_date_n: 2023-11-22
# syms: ['FTSM', 'GPS']
# ++++++++++++++
# date = 2023-11-22, l_syms = ['FTSM', 'GPS'], ar_price = [59.19606781 18.66513634], ar_shares = [ 8. 26.], ar_value = [473.56854248 485.29354477], portf_value = 958.8620872497559
# 2023-11-22 portf_value = 958.8620872497559
# date = 2023-11-22, l_syms = ['SPY'], ar_price = [453.18261719], ar_shares = [2.], ar_value = [906.36523438], portf_value = 906.365234375
# 2023-11-22 portf_value = 906.365234375
# close_date_n pick's portf value = 958.8620872497559
# close_date_n SPY portf value =    906.365234375
# ====================
#
# ++++++++++++++
# date: 2023-11-20
# n: 1
# next_date_n: 2023-11-21
# close_date_n: 2023-11-21
# syms: ['SHV']
# ++++++++++++++
# date = 2023-11-21, l_syms = ['SHV'], ar_price = [109.443367], ar_shares = [9.], ar_value = [984.99030304], portf_value = 984.9903030395508
# 2023-11-21 portf_value = 984.9903030395508
# date = 2023-11-21, l_syms = ['SPY'], ar_price = [451.43966675], ar_shares = [2.], ar_value = [902.8793335], portf_value = 902.8793334960938
# 2023-11-21 portf_value = 902.8793334960938
# close_date_n pick's portf value = 984.9903030395508
# close_date_n SPY portf value =    902.8793334960938
# ====================
#
# ++++++++++++++
# date: 2023-11-20
# n: 1
# next_date_n: 2023-11-21
# close_date_n: 2023-11-21
# syms: ['FTSM', 'GPS', 'NRG']
# ++++++++++++++
# date = 2023-11-21, l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = [59.16631317 18.76441956 45.20000076], ar_shares = [ 5. 17.  7.], ar_value = [295.83156586 318.99513245 316.40000534], portf_value = 931.2267036437988
# 2023-11-21 portf_value = 931.2267036437988
# date = 2023-11-21, l_syms = ['SPY'], ar_price = [451.43966675], ar_shares = [2.], ar_value = [902.8793335], portf_value = 902.8793334960938
# 2023-11-21 portf_value = 902.8793334960938
# close_date_n pick's portf value = 931.2267036437988
# close_date_n SPY portf value =    902.8793334960938
# ====================
#
# ++++++++++++++
# date: 2023-11-17
# n: 1
# next_date_n: 2023-11-20
# close_date_n: 2023-11-20
# syms: ['SHV']
# ++++++++++++++
# date = 2023-11-20, l_syms = ['SHV'], ar_price = [109.40372467], ar_shares = [9.], ar_value = [984.63352203], portf_value = 984.6335220336914
# 2023-11-20 portf_value = 984.6335220336914
# date = 2023-11-20, l_syms = ['SPY'], ar_price = [452.4256897], ar_shares = [2.], ar_value = [904.85137939], portf_value = 904.8513793945312
# 2023-11-20 portf_value = 904.8513793945312
# close_date_n pick's portf value = 984.6335220336914
# close_date_n SPY portf value =    904.8513793945312
# ====================
#
# ++++++++++++++
# date: 2023-11-17
# n: 1
# next_date_n: 2023-11-20
# close_date_n: 2023-11-20
# syms: ['FTSM', 'GPS', 'NRG']
# ++++++++++++++
# date = 2023-11-20, l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = [59.15639877 18.29779053 47.29000092], ar_shares = [ 5. 18.  7.], ar_value = [295.78199387 329.36022949 331.03000641], portf_value = 956.1722297668457
# 2023-11-20 portf_value = 956.1722297668457
# date = 2023-11-20, l_syms = ['SPY'], ar_price = [452.4256897], ar_shares = [2.], ar_value = [904.85137939], portf_value = 904.8513793945312
# 2023-11-20 portf_value = 904.8513793945312
# close_date_n pick's portf value = 956.1722297668457
# close_date_n SPY portf value =    904.8513793945312
# ====================
#
# ++++++++++++++
# date: 2023-11-16
# n: 1
# next_date_n: 2023-11-17
# close_date_n: 2023-11-17
# syms: ['SHV']
# ++++++++++++++
# date = 2023-11-17, l_syms = ['SHV'], ar_price = [109.39380646], ar_shares = [9.], ar_value = [984.54425812], portf_value = 984.5442581176758
# 2023-11-17 portf_value = 984.5442581176758
# date = 2023-11-17, l_syms = ['SPY'], ar_price = [448.96969604], ar_shares = [2.], ar_value = [897.93939209], portf_value = 897.9393920898438
# 2023-11-17 portf_value = 897.9393920898438
# close_date_n pick's portf value = 984.5442581176758
# close_date_n SPY portf value =    897.9393920898438
# ====================
#
# ++++++++++++++
# date: 2023-11-16
# n: 1
# next_date_n: 2023-11-17
# close_date_n: 2023-11-17
# syms: ['FTSM', 'NRG']
# ++++++++++++++
# date = 2023-11-17, l_syms = ['FTSM', 'NRG'], ar_price = [59.13656616 48.08000183], ar_shares = [ 8. 10.], ar_value = [473.0925293  480.80001831], portf_value = 953.8925476074219
# 2023-11-17 portf_value = 953.8925476074219
# date = 2023-11-17, l_syms = ['SPY'], ar_price = [448.96969604], ar_shares = [2.], ar_value = [897.93939209], portf_value = 897.9393920898438
# 2023-11-17 portf_value = 897.9393920898438
# close_date_n pick's portf value = 953.8925476074219
# close_date_n SPY portf value =    897.9393920898438
# ====================
#
# ++++++++++++++
# date: 2023-11-15
# n: 1
# next_date_n: 2023-11-16
# close_date_n: 2023-11-16
# syms: ['SHV']
# ++++++++++++++
# date = 2023-11-16, l_syms = ['SHV'], ar_price = [109.3839035], ar_shares = [9.], ar_value = [984.45513153], portf_value = 984.4551315307617
# 2023-11-16 portf_value = 984.4551315307617
# date = 2023-11-16, l_syms = ['SPY'], ar_price = [448.41195679], ar_shares = [2.], ar_value = [896.82391357], portf_value = 896.8239135742188
# 2023-11-16 portf_value = 896.8239135742188
# close_date_n pick's portf value = 984.4551315307617
# close_date_n SPY portf value =    896.8239135742188
# ====================
#
# ++++++++++++++
# date: 2023-11-15
# n: 1
# next_date_n: 2023-11-16
# close_date_n: 2023-11-16
# syms: ['FTSM', 'NRG']
# ++++++++++++++
# date = 2023-11-16, l_syms = ['FTSM', 'NRG'], ar_price = [59.12664795 47.56999969], ar_shares = [ 8. 10.], ar_value = [473.01318359 475.69999695], portf_value = 948.7131805419922
# 2023-11-16 portf_value = 948.7131805419922
# date = 2023-11-16, l_syms = ['SPY'], ar_price = [448.41195679], ar_shares = [2.], ar_value = [896.82391357], portf_value = 896.8239135742188
# 2023-11-16 portf_value = 896.8239135742188
# close_date_n pick's portf value = 948.7131805419922
# close_date_n SPY portf value =    896.8239135742188
# ====================
#
# ++++++++++++++
# date: 2023-11-14
# n: 1
# next_date_n: 2023-11-15
# close_date_n: 2023-11-15
# syms: ['SHV']
# ++++++++++++++
# date = 2023-11-15, l_syms = ['SHV'], ar_price = [109.32443237], ar_shares = [9.], ar_value = [983.91989136], portf_value = 983.9198913574219
# 2023-11-15 portf_value = 983.9198913574219
# date = 2023-11-15, l_syms = ['SPY'], ar_price = [447.86416626], ar_shares = [2.], ar_value = [895.72833252], portf_value = 895.7283325195312
# 2023-11-15 portf_value = 895.7283325195312
# close_date_n pick's portf value = 983.9198913574219
# close_date_n SPY portf value =    895.7283325195312
# ====================
#
# ++++++++++++++
# date: 2023-11-14
# n: 1
# next_date_n: 2023-11-15
# close_date_n: 2023-11-15
# syms: ['FTSM', 'NRG']
# ++++++++++++++
# date = 2023-11-15, l_syms = ['FTSM', 'NRG'], ar_price = [59.10681152 47.50999832], ar_shares = [ 8. 10.], ar_value = [472.85449219 475.09998322], portf_value = 947.954475402832
# 2023-11-15 portf_value = 947.954475402832
# date = 2023-11-15, l_syms = ['SPY'], ar_price = [447.86416626], ar_shares = [2.], ar_value = [895.72833252], portf_value = 895.7283325195312
# 2023-11-15 portf_value = 895.7283325195312
# close_date_n pick's portf value = 947.954475402832
# close_date_n SPY portf value =    895.7283325195312
# ====================
#
# ++++++++++++++
# date: 2023-11-13
# n: 1
# next_date_n: 2023-11-14
# close_date_n: 2023-11-14
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-14, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.11672974 109.31452942], ar_shares = [8. 4.], ar_value = [472.93383789 437.25811768], portf_value = 910.1919555664062
# 2023-11-14 portf_value = 910.1919555664062
# date = 2023-11-14, l_syms = ['SPY'], ar_price = [446.91802979], ar_shares = [2.], ar_value = [893.83605957], portf_value = 893.8360595703125
# 2023-11-14 portf_value = 893.8360595703125
# close_date_n pick's portf value = 910.1919555664062
# close_date_n SPY portf value =    893.8360595703125
# ====================
#
# ++++++++++++++
# date: 2023-11-13
# n: 1
# next_date_n: 2023-11-14
# close_date_n: 2023-11-14
# syms: ['CBOE']
# ++++++++++++++
# date = 2023-11-14, l_syms = ['CBOE'], ar_price = [177.38999939], ar_shares = [5.], ar_value = [886.94999695], portf_value = 886.9499969482422
# 2023-11-14 portf_value = 886.9499969482422
# date = 2023-11-14, l_syms = ['SPY'], ar_price = [446.91802979], ar_shares = [2.], ar_value = [893.83605957], portf_value = 893.8360595703125
# 2023-11-14 portf_value = 893.8360595703125
# close_date_n pick's portf value = 886.9499969482422
# close_date_n SPY portf value =    893.8360595703125
# ====================
#
# ++++++++++++++
# date: 2023-11-10
# n: 1
# next_date_n: 2023-11-13
# close_date_n: 2023-11-13
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-13, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.0671463  109.27488708], ar_shares = [8. 4.], ar_value = [472.53717041 437.09954834], portf_value = 909.63671875
# 2023-11-13 portf_value = 909.63671875
# date = 2023-11-13, l_syms = ['SPY'], ar_price = [438.4125061], ar_shares = [2.], ar_value = [876.82501221], portf_value = 876.8250122070312
# 2023-11-13 portf_value = 876.8250122070312
# close_date_n pick's portf value = 909.63671875
# close_date_n SPY portf value =    876.8250122070312
# ====================
#
# ++++++++++++++
# date: 2023-11-10
# n: 1
# next_date_n: 2023-11-13
# close_date_n: 2023-11-13
# syms: ['CBOE']
# ++++++++++++++
# date = 2023-11-13, l_syms = ['CBOE'], ar_price = [178.47999573], ar_shares = [5.], ar_value = [892.39997864], portf_value = 892.3999786376953
# 2023-11-13 portf_value = 892.3999786376953
# date = 2023-11-13, l_syms = ['SPY'], ar_price = [438.4125061], ar_shares = [2.], ar_value = [876.82501221], portf_value = 876.8250122070312
# 2023-11-13 portf_value = 876.8250122070312
# close_date_n pick's portf value = 892.3999786376953
# close_date_n SPY portf value =    876.8250122070312
# ====================
#
# ++++++++++++++
# date: 2023-11-09
# n: 1
# next_date_n: 2023-11-10
# close_date_n: 2023-11-10
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-10, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.04730988 109.2649765 ], ar_shares = [8. 4.], ar_value = [472.378479   437.05990601], portf_value = 909.4383850097656
# 2023-11-10 portf_value = 909.4383850097656
# date = 2023-11-10, l_syms = ['SPY'], ar_price = [438.83078003], ar_shares = [2.], ar_value = [877.66156006], portf_value = 877.6615600585938
# 2023-11-10 portf_value = 877.6615600585938
# close_date_n pick's portf value = 909.4383850097656
# close_date_n SPY portf value =    877.6615600585938
# ====================
#
# ++++++++++++++
# date: 2023-11-09
# n: 1
# next_date_n: 2023-11-10
# close_date_n: 2023-11-10
# syms: ['CBOE']
# ++++++++++++++
# date = 2023-11-10, l_syms = ['CBOE'], ar_price = [174.97000122], ar_shares = [5.], ar_value = [874.8500061], portf_value = 874.8500061035156
# 2023-11-10 portf_value = 874.8500061035156
# date = 2023-11-10, l_syms = ['SPY'], ar_price = [438.83078003], ar_shares = [2.], ar_value = [877.66156006], portf_value = 877.6615600585938
# 2023-11-10 portf_value = 877.6615600585938
# close_date_n pick's portf value = 874.8500061035156
# close_date_n SPY portf value =    877.6615600585938
# ====================
#
# ++++++++++++++
# date: 2023-11-08
# n: 1
# next_date_n: 2023-11-09
# close_date_n: 2023-11-09
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-09, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.04235077 109.23524475], ar_shares = [8. 4.], ar_value = [472.33880615 436.940979  ], portf_value = 909.27978515625
# 2023-11-09 portf_value = 909.27978515625
# date = 2023-11-09, l_syms = ['SPY'], ar_price = [432.08813477], ar_shares = [2.], ar_value = [864.17626953], portf_value = 864.17626953125
# 2023-11-09 portf_value = 864.17626953125
# close_date_n pick's portf value = 909.27978515625
# close_date_n SPY portf value =    864.17626953125
# ====================
#
# ++++++++++++++
# date: 2023-11-08
# n: 1
# next_date_n: 2023-11-09
# close_date_n: 2023-11-09
# syms: ['NRG']
# ++++++++++++++
# date = 2023-11-09, l_syms = ['NRG'], ar_price = [45.06999969], ar_shares = [22.], ar_value = [991.53999329], portf_value = 991.5399932861328
# 2023-11-09 portf_value = 991.5399932861328
# date = 2023-11-09, l_syms = ['SPY'], ar_price = [432.08813477], ar_shares = [2.], ar_value = [864.17626953], portf_value = 864.17626953125
# 2023-11-09 portf_value = 864.17626953125
# close_date_n pick's portf value = 991.5399932861328
# close_date_n SPY portf value =    864.17626953125
# ====================
#
# ++++++++++++++
# date: 2023-11-07
# n: 1
# next_date_n: 2023-11-08
# close_date_n: 2023-11-08
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-08, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.02747345 109.19560242], ar_shares = [8. 4.], ar_value = [472.2197876  436.78240967], portf_value = 909.002197265625
# 2023-11-08 portf_value = 909.002197265625
# date = 2023-11-08, l_syms = ['SPY'], ar_price = [435.484375], ar_shares = [2.], ar_value = [870.96875], portf_value = 870.96875
# 2023-11-08 portf_value = 870.96875
# close_date_n pick's portf value = 909.002197265625
# close_date_n SPY portf value =    870.96875
# ====================
#
# ++++++++++++++
# date: 2023-11-07
# n: 1
# next_date_n: 2023-11-08
# close_date_n: 2023-11-08
# syms: ['NRG']
# ++++++++++++++
# date = 2023-11-08, l_syms = ['NRG'], ar_price = [45.68000031], ar_shares = [21.], ar_value = [959.28000641], portf_value = 959.2800064086914
# 2023-11-08 portf_value = 959.2800064086914
# date = 2023-11-08, l_syms = ['SPY'], ar_price = [435.484375], ar_shares = [2.], ar_value = [870.96875], portf_value = 870.96875
# 2023-11-08 portf_value = 870.96875
# close_date_n pick's portf value = 959.2800064086914
# close_date_n SPY portf value =    870.96875
# ====================
#
# ++++++++++++++
# date: 2023-11-06
# n: 1
# next_date_n: 2023-11-07
# close_date_n: 2023-11-07
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-07, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.03738785 109.18569183], ar_shares = [8. 4.], ar_value = [472.29910278 436.74276733], portf_value = 909.0418701171875
# 2023-11-07 portf_value = 909.0418701171875
# date = 2023-11-07, l_syms = ['SPY'], ar_price = [435.16564941], ar_shares = [2.], ar_value = [870.33129883], portf_value = 870.331298828125
# 2023-11-07 portf_value = 870.331298828125
# close_date_n pick's portf value = 909.0418701171875
# close_date_n SPY portf value =    870.331298828125
# ====================
#
# ++++++++++++++
# date: 2023-11-06
# n: 1
# next_date_n: 2023-11-07
# close_date_n: 2023-11-07
# syms: ['NRG']
# ++++++++++++++
# date = 2023-11-07, l_syms = ['NRG'], ar_price = [45.41999817], ar_shares = [22.], ar_value = [999.23995972], portf_value = 999.2399597167969
# 2023-11-07 portf_value = 999.2399597167969
# date = 2023-11-07, l_syms = ['SPY'], ar_price = [435.16564941], ar_shares = [2.], ar_value = [870.33129883], portf_value = 870.331298828125
# 2023-11-07 portf_value = 870.331298828125
# close_date_n pick's portf value = 999.2399597167969
# close_date_n SPY portf value =    870.331298828125
# ====================
#
# ++++++++++++++
# date: 2023-11-03
# n: 1
# next_date_n: 2023-11-06
# close_date_n: 2023-11-06
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-06, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.02747345 109.15596008], ar_shares = [8. 4.], ar_value = [472.2197876  436.62384033], portf_value = 908.8436279296875
# 2023-11-06 portf_value = 908.8436279296875
# date = 2023-11-06, l_syms = ['SPY'], ar_price = [433.93066406], ar_shares = [2.], ar_value = [867.86132812], portf_value = 867.861328125
# 2023-11-06 portf_value = 867.861328125
# close_date_n pick's portf value = 908.8436279296875
# close_date_n SPY portf value =    867.861328125
# ====================
#
# ++++++++++++++
# date: 2023-11-03
# n: 1
# next_date_n: 2023-11-06
# close_date_n: 2023-11-06
# syms: ['ANF']
# ++++++++++++++
# date = 2023-11-06, l_syms = ['ANF'], ar_price = [66.26999664], ar_shares = [15.], ar_value = [994.04994965], portf_value = 994.0499496459961
# 2023-11-06 portf_value = 994.0499496459961
# date = 2023-11-06, l_syms = ['SPY'], ar_price = [433.93066406], ar_shares = [2.], ar_value = [867.86132812], portf_value = 867.861328125
# 2023-11-06 portf_value = 867.861328125
# close_date_n pick's portf value = 994.0499496459961
# close_date_n SPY portf value =    867.861328125
# ====================
#
# ++++++++++++++
# date: 2023-11-02
# n: 1
# next_date_n: 2023-11-03
# close_date_n: 2023-11-03
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-03, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.02251434 109.16587067], ar_shares = [8. 4.], ar_value = [472.18011475 436.66348267], portf_value = 908.8435974121094
# 2023-11-03 portf_value = 908.8435974121094
# date = 2023-11-03, l_syms = ['SPY'], ar_price = [432.9347229], ar_shares = [2.], ar_value = [865.8694458], portf_value = 865.8694458007812
# 2023-11-03 portf_value = 865.8694458007812
# close_date_n pick's portf value = 908.8435974121094
# close_date_n SPY portf value =    865.8694458007812
# ====================
#
# ++++++++++++++
# date: 2023-11-02
# n: 1
# next_date_n: 2023-11-03
# close_date_n: 2023-11-03
# syms: ['ANF']
# ++++++++++++++
# date = 2023-11-03, l_syms = ['ANF'], ar_price = [65.5], ar_shares = [15.], ar_value = [982.5], portf_value = 982.5
# 2023-11-03 portf_value = 982.5
# date = 2023-11-03, l_syms = ['SPY'], ar_price = [432.9347229], ar_shares = [2.], ar_value = [865.8694458], portf_value = 865.8694458007812
# 2023-11-03 portf_value = 865.8694458007812
# close_date_n pick's portf value = 982.5
# close_date_n SPY portf value =    865.8694458007812
# ====================
#
# ++++++++++++++
# date: 2023-11-01
# n: 1
# next_date_n: 2023-11-02
# close_date_n: 2023-11-02
# syms: ['FTSM']
# ++++++++++++++
# date = 2023-11-02, l_syms = ['FTSM'], ar_price = [59.00764084], ar_shares = [16.], ar_value = [944.12225342], portf_value = 944.1222534179688
# 2023-11-02 portf_value = 944.1222534179688
# date = 2023-11-02, l_syms = ['SPY'], ar_price = [429.02059937], ar_shares = [2.], ar_value = [858.04119873], portf_value = 858.0411987304688
# 2023-11-02 portf_value = 858.0411987304688
# close_date_n pick's portf value = 944.1222534179688
# close_date_n SPY portf value =    858.0411987304688
# ====================
#
# ++++++++++++++
# date: 2023-11-01
# n: 1
# next_date_n: 2023-11-02
# close_date_n: 2023-11-02
# syms: ['ANF']
# ++++++++++++++
# date = 2023-11-02, l_syms = ['ANF'], ar_price = [63.31000137], ar_shares = [15.], ar_value = [949.6500206], portf_value = 949.6500205993652
# 2023-11-02 portf_value = 949.6500205993652
# date = 2023-11-02, l_syms = ['SPY'], ar_price = [429.02059937], ar_shares = [2.], ar_value = [858.04119873], portf_value = 858.0411987304688
# 2023-11-02 portf_value = 858.0411987304688
# close_date_n pick's portf value = 949.6500205993652
# close_date_n SPY portf value =    858.0411987304688
# ====================
#
# ++++++++++++++
# date: 2023-10-31
# n: 1
# next_date_n: 2023-11-01
# close_date_n: 2023-11-01
# syms: ['SHV']
# ++++++++++++++
# date = 2023-11-01, l_syms = ['SHV'], ar_price = [109.086586], ar_shares = [9.], ar_value = [981.77927399], portf_value = 981.7792739868164
# 2023-11-01 portf_value = 981.7792739868164
# date = 2023-11-01, l_syms = ['SPY'], ar_price = [420.95327759], ar_shares = [2.], ar_value = [841.90655518], portf_value = 841.9065551757812
# 2023-11-01 portf_value = 841.9065551757812
# close_date_n pick's portf value = 981.7792739868164
# close_date_n SPY portf value =    841.9065551757812
# ====================
#
# ++++++++++++++
# date: 2023-10-31
# n: 1
# next_date_n: 2023-11-01
# close_date_n: 2023-11-01
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# date = 2023-11-01, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.9679718 109.086586 ], ar_shares = [8. 4.], ar_value = [471.74377441 436.34634399], portf_value = 908.0901184082031
# ...
# close_date_n pick's portf value = 999.2479705810547
# close_date_n SPY portf value =    781.421630859375
# ====================
#
# ++++++++++++++
# date: 2018-08-03
# n: 1
# next_date_n: 2018-08-06
# close_date_n: 2018-08-06
# syms: ['SHV']
# ++++++++++++++
# date = 2018-08-06, l_syms = ['SHV'], ar_price = [99.9157486], ar_shares = [10.], ar_value = [999.15748596], portf_value = 999.1574859619141
# 2018-08-06 portf_value = 999.1574859619141
# date = 2018-08-06, l_syms = ['SPY'], ar_price = [259.6164856], ar_shares = [3.], ar_value = [778.84945679], portf_value = 778.8494567871094
# 2018-08-06 portf_value = 778.8494567871094
# close_date_n pick's portf value = 999.1574859619141
# close_date_n SPY portf value =    778.8494567871094
# ====================
#
# ++++++++++++++
# date: 2018-08-03
# n: 1
# next_date_n: 2018-08-06
# close_date_n: 2018-08-06
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-08-06, l_syms = ['TNDM'], ar_price = [32.33000183], ar_shares = [30.], ar_value = [969.90005493], portf_value = 969.9000549316406
# 2018-08-06 portf_value = 969.9000549316406
# date = 2018-08-06, l_syms = ['SPY'], ar_price = [259.6164856], ar_shares = [3.], ar_value = [778.84945679], portf_value = 778.8494567871094
# 2018-08-06 portf_value = 778.8494567871094
# close_date_n pick's portf value = 969.9000549316406
# close_date_n SPY portf value =    778.8494567871094
# ====================
#
# ++++++++++++++
# date: 2018-08-02
# n: 1
# next_date_n: 2018-08-03
# close_date_n: 2018-08-03
# syms: ['SHV']
# ++++++++++++++
# date = 2018-08-03, l_syms = ['SHV'], ar_price = [99.92479706], ar_shares = [10.], ar_value = [999.24797058], portf_value = 999.2479705810547
# 2018-08-03 portf_value = 999.2479705810547
# date = 2018-08-03, l_syms = ['SPY'], ar_price = [258.6678772], ar_shares = [3.], ar_value = [776.00363159], portf_value = 776.0036315917969
# 2018-08-03 portf_value = 776.0036315917969
# close_date_n pick's portf value = 999.2479705810547
# close_date_n SPY portf value =    776.0036315917969
# ====================
#
# ++++++++++++++
# date: 2018-08-02
# n: 1
# next_date_n: 2018-08-03
# close_date_n: 2018-08-03
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-08-03, l_syms = ['TNDM'], ar_price = [33.02999878], ar_shares = [30.], ar_value = [990.89996338], portf_value = 990.8999633789062
# 2018-08-03 portf_value = 990.8999633789062
# date = 2018-08-03, l_syms = ['SPY'], ar_price = [258.6678772], ar_shares = [3.], ar_value = [776.00363159], portf_value = 776.0036315917969
# 2018-08-03 portf_value = 776.0036315917969
# close_date_n pick's portf value = 990.8999633789062
# close_date_n SPY portf value =    776.0036315917969
# ====================
#
# ++++++++++++++
# date: 2018-08-01
# n: 1
# next_date_n: 2018-08-02
# close_date_n: 2018-08-02
# syms: ['SHV']
# ++++++++++++++
# date = 2018-08-02, l_syms = ['SHV'], ar_price = [99.90670013], ar_shares = [10.], ar_value = [999.06700134], portf_value = 999.0670013427734
# 2018-08-02 portf_value = 999.0670013427734
# date = 2018-08-02, l_syms = ['SPY'], ar_price = [257.56433105], ar_shares = [3.], ar_value = [772.69299316], portf_value = 772.6929931640625
# 2018-08-02 portf_value = 772.6929931640625
# close_date_n pick's portf value = 999.0670013427734
# close_date_n SPY portf value =    772.6929931640625
# ====================
#
# ++++++++++++++
# date: 2018-08-01
# n: 1
# next_date_n: 2018-08-02
# close_date_n: 2018-08-02
# syms: ['NTRA', 'TNDM']
# ++++++++++++++
# date = 2018-08-02, l_syms = ['NTRA', 'TNDM'], ar_price = [23.85000038 31.38999939], ar_shares = [20. 15.], ar_value = [477.00000763 470.84999084], portf_value = 947.8499984741211
# 2018-08-02 portf_value = 947.8499984741211
# date = 2018-08-02, l_syms = ['SPY'], ar_price = [257.56433105], ar_shares = [3.], ar_value = [772.69299316], portf_value = 772.6929931640625
# 2018-08-02 portf_value = 772.6929931640625
# close_date_n pick's portf value = 947.8499984741211
# close_date_n SPY portf value =    772.6929931640625
# ====================
#
# ++++++++++++++
# date: 2018-07-31
# n: 1
# next_date_n: 2018-08-01
# close_date_n: 2018-08-01
# syms: ['NTRA', 'SHV', 'TNDM']
# ++++++++++++++
# date = 2018-08-01, l_syms = ['NTRA', 'SHV', 'TNDM'], ar_price = [24.07999992 99.88858795 28.56999969], ar_shares = [13.  3. 11.], ar_value = [313.03999901 299.66576385 314.26999664], portf_value = 926.9757595062256
# 2018-08-01 portf_value = 926.9757595062256
# date = 2018-08-01, l_syms = ['SPY'], ar_price = [256.16879272], ar_shares = [3.], ar_value = [768.50637817], portf_value = 768.5063781738281
# 2018-08-01 portf_value = 768.5063781738281
# close_date_n pick's portf value = 926.9757595062256
# close_date_n SPY portf value =    768.5063781738281
# ====================
#
# ++++++++++++++
# date: 2018-07-30
# n: 1
# next_date_n: 2018-07-31
# close_date_n: 2018-07-31
# syms: ['SHV']
# ++++++++++++++
# date = 2018-07-31, l_syms = ['SHV'], ar_price = [99.88409424], ar_shares = [10.], ar_value = [998.84094238], portf_value = 998.8409423828125
# 2018-07-31 portf_value = 998.8409423828125
# date = 2018-07-31, l_syms = ['SPY'], ar_price = [256.59744263], ar_shares = [3.], ar_value = [769.79232788], portf_value = 769.7923278808594
# 2018-07-31 portf_value = 769.7923278808594
# close_date_n pick's portf value = 998.8409423828125
# close_date_n SPY portf value =    769.7923278808594
# ====================
#
# ++++++++++++++
# date: 2018-07-30
# n: 1
# next_date_n: 2018-07-31
# close_date_n: 2018-07-31
# syms: ['NTRA']
# ++++++++++++++
# date = 2018-07-31, l_syms = ['NTRA'], ar_price = [22.95999908], ar_shares = [43.], ar_value = [987.27996063], portf_value = 987.2799606323242
# 2018-07-31 portf_value = 987.2799606323242
# date = 2018-07-31, l_syms = ['SPY'], ar_price = [256.59744263], ar_shares = [3.], ar_value = [769.79232788], portf_value = 769.7923278808594
# 2018-07-31 portf_value = 769.7923278808594
# close_date_n pick's portf value = 987.2799606323242
# close_date_n SPY portf value =    769.7923278808594
# ====================
#
# ++++++++++++++
# date: 2018-07-27
# n: 1
# next_date_n: 2018-07-30
# close_date_n: 2018-07-30
# syms: ['ARWR', 'NTRA']
# ++++++++++++++
# date = 2018-07-30, l_syms = ['ARWR', 'NTRA'], ar_price = [14.         22.52000046], ar_shares = [35. 22.], ar_value = [490.         495.44001007], portf_value = 985.4400100708008
# 2018-07-30 portf_value = 985.4400100708008
# date = 2018-07-30, l_syms = ['SPY'], ar_price = [255.33872986], ar_shares = [3.], ar_value = [766.01618958], portf_value = 766.0161895751953
# 2018-07-30 portf_value = 766.0161895751953
# close_date_n pick's portf value = 985.4400100708008
# close_date_n SPY portf value =    766.0161895751953
# ====================
#
# ++++++++++++++
# date: 2018-07-26
# n: 1
# next_date_n: 2018-07-27
# close_date_n: 2018-07-27
# syms: ['ARWR', 'NTRA', 'SHV', 'TNDM']
# ++++++++++++++
# date = 2018-07-27, l_syms = ['ARWR', 'NTRA', 'SHV', 'TNDM'], ar_price = [16.06999969 22.87000084 99.86595917 25.60000038], ar_shares = [15. 10.  2.  9.], ar_value = [241.04999542 228.70000839 199.73191833 230.40000343], portf_value = 899.8819255828857
# 2018-07-27 portf_value = 899.8819255828857
# date = 2018-07-27, l_syms = ['SPY'], ar_price = [256.67956543], ar_shares = [3.], ar_value = [770.03869629], portf_value = 770.0386962890625
# 2018-07-27 portf_value = 770.0386962890625
# close_date_n pick's portf value = 899.8819255828857
# close_date_n SPY portf value =    770.0386962890625
# ====================
#
# ++++++++++++++
# date: 2018-07-25
# n: 1
# next_date_n: 2018-07-26
# close_date_n: 2018-07-26
# syms: ['ARWR', 'TNDM']
# ++++++++++++++
# date = 2018-07-26, l_syms = ['ARWR', 'TNDM'], ar_price = [17.44000053 26.95999908], ar_shares = [28. 18.], ar_value = [488.32001495 485.27998352], portf_value = 973.5999984741211
# 2018-07-26 portf_value = 973.5999984741211
# date = 2018-07-26, l_syms = ['SPY'], ar_price = [258.43075562], ar_shares = [3.], ar_value = [775.29226685], portf_value = 775.2922668457031
# 2018-07-26 portf_value = 775.2922668457031
# close_date_n pick's portf value = 973.5999984741211
# close_date_n SPY portf value =    775.2922668457031
# ====================
#
# ++++++++++++++
# date: 2018-07-24
# n: 1
# next_date_n: 2018-07-25
# close_date_n: 2018-07-25
# syms: ['ARWR', 'SHV', 'TNDM']
# ++++++++++++++
# date = 2018-07-25, l_syms = ['ARWR', 'SHV', 'TNDM'], ar_price = [16.88999939 99.85694885 27.45999908], ar_shares = [19.  3. 12.], ar_value = [320.9099884  299.57084656 329.51998901], portf_value = 950.0008239746094
# 2018-07-25 portf_value = 950.0008239746094
# date = 2018-07-25, l_syms = ['SPY'], ar_price = [259.04190063], ar_shares = [3.], ar_value = [777.1257019], portf_value = 777.1257019042969
# 2018-07-25 portf_value = 777.1257019042969
# close_date_n pick's portf value = 950.0008239746094
# close_date_n SPY portf value =    777.1257019042969
# ====================
#
# ++++++++++++++
# date: 2018-07-23
# n: 1
# next_date_n: 2018-07-24
# close_date_n: 2018-07-24
# syms: ['ARWR', 'TNDM']
# ++++++++++++++
# date = 2018-07-24, l_syms = ['ARWR', 'TNDM'], ar_price = [16.60000038 26.51000023], ar_shares = [30. 18.], ar_value = [498.00001144 477.18000412], portf_value = 975.1800155639648
# 2018-07-24 portf_value = 975.1800155639648
# date = 2018-07-24, l_syms = ['SPY'], ar_price = [256.85284424], ar_shares = [3.], ar_value = [770.55853271], portf_value = 770.5585327148438
# 2018-07-24 portf_value = 770.5585327148438
# close_date_n pick's portf value = 975.1800155639648
# close_date_n SPY portf value =    770.5585327148438
# ====================
#
# ++++++++++++++
# date: 2018-07-20
# n: 1
# next_date_n: 2018-07-23
# close_date_n: 2018-07-23
# syms: ['ARWR', 'TNDM']
# ++++++++++++++
# date = 2018-07-23, l_syms = ['ARWR', 'TNDM'], ar_price = [16.51000023 28.12999916], ar_shares = [30. 17.], ar_value = [495.30000687 478.20998573], portf_value = 973.5099925994873
# 2018-07-23 portf_value = 973.5099925994873
# date = 2018-07-23, l_syms = ['SPY'], ar_price = [255.56677246], ar_shares = [3.], ar_value = [766.70031738], portf_value = 766.7003173828125
# 2018-07-23 portf_value = 766.7003173828125
# close_date_n pick's portf value = 973.5099925994873
# close_date_n SPY portf value =    766.7003173828125
# ====================
#
# ++++++++++++++
# date: 2018-07-19
# n: 1
# next_date_n: 2018-07-20
# close_date_n: 2018-07-20
# syms: ['ARWR', 'TNDM']
# ++++++++++++++
# date = 2018-07-20, l_syms = ['ARWR', 'TNDM'], ar_price = [16.03000069 26.88999939], ar_shares = [31. 18.], ar_value = [496.93002129 484.01998901], portf_value = 980.9500102996826
# 2018-07-20 portf_value = 980.9500102996826
# date = 2018-07-20, l_syms = ['SPY'], ar_price = [255.09248352], ar_shares = [3.], ar_value = [765.27745056], portf_value = 765.2774505615234
# 2018-07-20 portf_value = 765.2774505615234
# close_date_n pick's portf value = 980.9500102996826
# close_date_n SPY portf value =    765.2774505615234
# ====================
#
# ++++++++++++++
# date: 2018-07-18
# n: 1
# next_date_n: 2018-07-19
# close_date_n: 2018-07-19
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-07-19, l_syms = ['TNDM'], ar_price = [26.61000061], ar_shares = [37.], ar_value = [984.57002258], portf_value = 984.5700225830078
# 2018-07-19 portf_value = 984.5700225830078
# date = 2018-07-19, l_syms = ['SPY'], ar_price = [255.38441467], ar_shares = [3.], ar_value = [766.15324402], portf_value = 766.1532440185547
# 2018-07-19 portf_value = 766.1532440185547
# close_date_n pick's portf value = 984.5700225830078
# close_date_n SPY portf value =    766.1532440185547
# ====================
#
# ++++++++++++++
# date: 2018-07-17
# n: 1
# next_date_n: 2018-07-18
# close_date_n: 2018-07-18
# syms: ['ARWR', 'TNDM']
# ++++++++++++++
# date = 2018-07-18, l_syms = ['ARWR', 'TNDM'], ar_price = [16.67000008 26.13999939], ar_shares = [29. 19.], ar_value = [483.43000221 496.6599884 ], portf_value = 980.0899906158447
# 2018-07-18 portf_value = 980.0899906158447
# date = 2018-07-18, l_syms = ['SPY'], ar_price = [256.35125732], ar_shares = [3.], ar_value = [769.05377197], portf_value = 769.0537719726562
# 2018-07-18 portf_value = 769.0537719726562
# close_date_n pick's portf value = 980.0899906158447
# close_date_n SPY portf value =    769.0537719726562
# ====================
#
# ++++++++++++++
# date: 2018-07-16
# n: 1
# next_date_n: 2018-07-17
# close_date_n: 2018-07-17
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-07-17, l_syms = ['TNDM'], ar_price = [27.], ar_shares = [37.], ar_value = [999.], portf_value = 999.0
# 2018-07-17 portf_value = 999.0
# date = 2018-07-17, l_syms = ['SPY'], ar_price = [255.81306458], ar_shares = [3.], ar_value = [767.43919373], portf_value = 767.4391937255859
# 2018-07-17 portf_value = 767.4391937255859
# close_date_n pick's portf value = 999.0
# close_date_n SPY portf value =    767.4391937255859
# ====================
#
# ++++++++++++++
# date: 2018-07-13
# n: 1
# next_date_n: 2018-07-16
# close_date_n: 2018-07-16
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-07-16, l_syms = ['TNDM'], ar_price = [26.93000031], ar_shares = [37.], ar_value = [996.41001129], portf_value = 996.4100112915039
# 2018-07-16 portf_value = 996.4100112915039
# date = 2018-07-16, l_syms = ['SPY'], ar_price = [254.78239441], ar_shares = [3.], ar_value = [764.34718323], portf_value = 764.3471832275391
# 2018-07-16 portf_value = 764.3471832275391
# close_date_n pick's portf value = 996.4100112915039
# close_date_n SPY portf value =    764.3471832275391
# ====================
#
# ++++++++++++++
# date: 2018-07-12
# n: 1
# next_date_n: 2018-07-13
# close_date_n: 2018-07-13
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-07-13, l_syms = ['TNDM'], ar_price = [25.88999939], ar_shares = [38.], ar_value = [983.81997681], portf_value = 983.8199768066406
# 2018-07-13 portf_value = 983.8199768066406
# date = 2018-07-13, l_syms = ['SPY'], ar_price = [255.01042175], ar_shares = [3.], ar_value = [765.03126526], portf_value = 765.0312652587891
# 2018-07-13 portf_value = 765.0312652587891
# close_date_n pick's portf value = 983.8199768066406
# close_date_n SPY portf value =    765.0312652587891
# ====================
#
# ++++++++++++++
# date: 2018-07-11
# n: 1
# next_date_n: 2018-07-12
# close_date_n: 2018-07-12
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-07-12, l_syms = ['TNDM'], ar_price = [25.45000076], ar_shares = [39.], ar_value = [992.55002975], portf_value = 992.5500297546387
# 2018-07-12 portf_value = 992.5500297546387
# date = 2018-07-12, l_syms = ['SPY'], ar_price = [254.80978394], ar_shares = [3.], ar_value = [764.42935181], portf_value = 764.4293518066406
# 2018-07-12 portf_value = 764.4293518066406
# close_date_n pick's portf value = 992.5500297546387
# close_date_n SPY portf value =    764.4293518066406
# ====================
#
# ++++++++++++++
# date: 2018-07-10
# n: 1
# next_date_n: 2018-07-11
# close_date_n: 2018-07-11
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-07-11, l_syms = ['TNDM'], ar_price = [24.31999969], ar_shares = [41.], ar_value = [997.11998749], portf_value = 997.119987487793
# 2018-07-11 portf_value = 997.119987487793
# date = 2018-07-11, l_syms = ['SPY'], ar_price = [252.520401], ar_shares = [3.], ar_value = [757.561203], portf_value = 757.5612030029297
# 2018-07-11 portf_value = 757.5612030029297
# close_date_n pick's portf value = 997.119987487793
# close_date_n SPY portf value =    757.5612030029297
# ====================
#
# ++++++++++++++
# date: 2018-07-09
# n: 1
# next_date_n: 2018-07-10
# close_date_n: 2018-07-10
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-07-10, l_syms = ['TNDM'], ar_price = [22.87999916], ar_shares = [43.], ar_value = [983.83996391], portf_value = 983.8399639129639
# 2018-07-10 portf_value = 983.8399639129639
# date = 2018-07-10, l_syms = ['SPY'], ar_price = [254.38110352], ar_shares = [3.], ar_value = [763.14331055], portf_value = 763.143310546875
# 2018-07-10 portf_value = 763.143310546875
# close_date_n pick's portf value = 983.8399639129639
# close_date_n SPY portf value =    763.143310546875
# ====================
#
# ++++++++++++++
# date: 2018-07-06
# n: 1
# next_date_n: 2018-07-09
# close_date_n: 2018-07-09
# syms: ['TNDM']
# ++++++++++++++
# date = 2018-07-09, l_syms = ['TNDM'], ar_price = [22.90999985], ar_shares = [43.], ar_value = [985.12999344], portf_value = 985.1299934387207
# 2018-07-09 portf_value = 985.1299934387207
# date = 2018-07-09, l_syms = ['SPY'], ar_price = [253.46896362], ar_shares = [3.], ar_value = [760.40689087], portf_value = 760.4068908691406
# 2018-07-09 portf_value = 760.4068908691406
# close_date_n pick's portf value = 985.1299934387207
# close_date_n SPY portf value =    760.4068908691406
# ====================

# %%
"""
Adds buy information, including dates, shares, and values, for both the portfolio and SPY to the df_picks_mp DataFrame.
"""

# Add columns for portfolio buy information:
df_picks_mp['date_buy'] = date_buy  # Date of portfolio purchase
df_picks_mp['sh_portf_buy'] = shares_syms  # Number of shares bought for each symbol
df_picks_mp['$_portf_buy'] = value_portf  # Total value of the portfolio at purchase

# Add columns for SPY buy information:
df_picks_mp['sh_SPY_buy'] = shares_SPY  # Number of SPY shares bought
df_picks_mp['$_SPY_buy'] = value_SPY  # Total value of SPY at purchase

# Display the updated DataFrame with all buy and sell information:
df_picks_mp  # Show the DataFrame with the added buy columns
# Out:
#             date      days_lookback    syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy
# 0     2024-01-09      [30, 60, 120]   sym_freq_9         ['CYTK']        None         None          NaN       None         NaN
# 1     2024-01-09      [30, 60, 120]   sym_freq_8  ['FTSM', 'SHV']        None         None          NaN       None         NaN
# 2     2024-01-09  [15, 30, 60, 120]  sym_freq_12         ['CYTK']        None         None          NaN       None         NaN
# 3     2024-01-08      [30, 60, 120]   sym_freq_9         ['CYTK']  2024-01-09        [9.0]   917.730011      [2.0]  947.760010
# 4     2024-01-08      [30, 60, 120]   sym_freq_8  ['FTSM', 'SHV']  2024-01-09   [8.0, 4.0]   918.720001      [2.0]  947.760010
# ...          ...                ...          ...              ...         ...          ...          ...        ...         ...
# 1483  2018-07-12      [30, 60, 120]   sym_freq_8         ['TNDM']  2018-07-13       [38.0]   983.819977      [3.0]  765.031265
# 1484  2018-07-11      [30, 60, 120]   sym_freq_8         ['TNDM']  2018-07-12       [39.0]   992.550030      [3.0]  764.429352
# 1485  2018-07-10      [30, 60, 120]   sym_freq_8         ['TNDM']  2018-07-11       [41.0]   997.119987      [3.0]  757.561203
# 1486  2018-07-09      [30, 60, 120]   sym_freq_8         ['TNDM']  2018-07-10       [43.0]   983.839964      [3.0]  763.143311
# 1487  2018-07-06      [30, 60, 120]   sym_freq_8         ['TNDM']  2018-07-09       [43.0]   985.129993      [3.0]  760.406891
#
# [1488 rows x 9 columns]

# %%
"""
Calculates portfolio values for multiple dates and symbol combinations, using pre-determined shares and handling potential missing data.
"""

# Call the function to calculate portfolio values:
date_exec, shares_syms, value_portf, shares_SPY, value_SPY = \
   calc_portf_value_date_n(df_picks_mp.date, df_picks_mp.symbols, df_close, df_picks_mp.sh_portf_buy, df_picks_mp.sh_SPY_buy, n=4, verbose=verbose)

# Breakdown of the function call:
# - calc_portf_value_date_n: Function name (defined in a previous code block)
# - df_picks_mp.date: List of dates from the df_picks_mp DataFrame
# - df_picks_mp.symbols: List of stock symbols from the df_picks_mp DataFrame
# - df_close: DataFrame containing historical closing prices
# - df_picks_mp.sh_portf_buy: List of shares bought for each symbol (from a previous calculation)
# - df_picks_mp.sh_SPY_buy: List of SPY shares bought (from a previous calculation)
# - n=4: Offset the execution date by 4 trading days from the lookback date
# - verbose=verbose: Print details if verbose mode is enabled

# Note: The function handles potential missing data gracefully.
# Out:
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# date = 2024-01-09, l_syms = ['CYTK', 'FTSM', 'SHV'], ar_price = [101.97000122  59.72999954 110.22000122], ar_shares = [3. 5. 3.], ar_value = [305.91000366 298.64999771 330.66000366], portf_value = 935.2200050354004
# 2024-01-09 portf_value = 935.2200050354004
# date = 2024-01-09, l_syms = ['SPY'], ar_price = [473.88000488], ar_shares = [2.], ar_value = [947.76000977], portf_value = 947.760009765625
# 2024-01-09 portf_value = 947.760009765625
# next_date_n pick's portf value = 935.2200050354004
# next_date_n SPY portf value =    947.760009765625
# ====================
#
# date = 2024-01-08, l_syms = ['CYTK', 'SHV'], ar_price = [108.05999756 110.20999908], ar_shares = [5. 4.], ar_value = [540.29998779 440.83999634], portf_value = 981.1399841308594
# 2024-01-08 portf_value = 981.1399841308594
# date = 2024-01-08, l_syms = ['SPY'], ar_price = [474.6000061], ar_shares = [2.], ar_value = [949.20001221], portf_value = 949.2000122070312
# 2024-01-08 portf_value = 949.2000122070312
# next_date_n pick's portf value = 981.1399841308594
# next_date_n SPY portf value =    949.2000122070312
# ====================
#
# date = 2024-01-05, l_syms = ['CYTK', 'SHV'], ar_price = [ 93.73000336 110.19000244], ar_shares = [5. 4.], ar_value = [468.65001678 440.76000977], portf_value = 909.410026550293
# 2024-01-05 portf_value = 909.410026550293
# date = 2024-01-05, l_syms = ['SPY'], ar_price = [467.92001343], ar_shares = [2.], ar_value = [935.84002686], portf_value = 935.8400268554688
# 2024-01-05 portf_value = 935.8400268554688
# next_date_n pick's portf value = 909.410026550293
# next_date_n SPY portf value =    935.8400268554688
# ====================
#
# date = 2024-01-04, l_syms = ['CYTK', 'SHV'], ar_price = [ 88.23999786 110.18000031], ar_shares = [5. 4.], ar_value = [441.19998932 440.72000122], portf_value = 881.9199905395508
# 2024-01-04 portf_value = 881.9199905395508
# date = 2024-01-04, l_syms = ['SPY'], ar_price = [467.27999878], ar_shares = [2.], ar_value = [934.55999756], portf_value = 934.5599975585938
# 2024-01-04 portf_value = 934.5599975585938
# next_date_n pick's portf value = 881.9199905395508
# next_date_n SPY portf value =    934.5599975585938
# ====================
#
# date = 2024-01-03, l_syms = ['CYTK', 'SHV'], ar_price = [ 86.63999939 110.12999725], ar_shares = [6. 4.], ar_value = [519.83999634 440.51998901], portf_value = 960.3599853515625
# 2024-01-03 portf_value = 960.3599853515625
# date = 2024-01-03, l_syms = ['SPY'], ar_price = [468.79000854], ar_shares = [2.], ar_value = [937.58001709], portf_value = 937.5800170898438
# 2024-01-03 portf_value = 937.5800170898438
# next_date_n pick's portf value = 960.3599853515625
# next_date_n SPY portf value =    937.5800170898438
# ====================
#
# date = 2024-01-02, l_syms = ['SHV'], ar_price = [110.12000275], ar_shares = [9.], ar_value = [991.08002472], portf_value = 991.0800247192383
# 2024-01-02 portf_value = 991.0800247192383
# date = 2024-01-02, l_syms = ['SPY'], ar_price = [472.6499939], ar_shares = [2.], ar_value = [945.29998779], portf_value = 945.2999877929688
# 2024-01-02 portf_value = 945.2999877929688
# next_date_n pick's portf value = 991.0800247192383
# next_date_n SPY portf value =    945.2999877929688
# ====================
#
# date = 2023-12-29, l_syms = ['SHV'], ar_price = [110.12999725], ar_shares = [9.], ar_value = [991.16997528], portf_value = 991.1699752807617
# 2023-12-29 portf_value = 991.1699752807617
# date = 2023-12-29, l_syms = ['SPY'], ar_price = [475.30999756], ar_shares = [2.], ar_value = [950.61999512], portf_value = 950.6199951171875
# 2023-12-29 portf_value = 950.6199951171875
# next_date_n pick's portf value = 991.1699752807617
# next_date_n SPY portf value =    950.6199951171875
# ====================
#
# date = 2023-12-28, l_syms = ['SHV'], ar_price = [110.09999847], ar_shares = [9.], ar_value = [990.89998627], portf_value = 990.8999862670898
# 2023-12-28 portf_value = 990.8999862670898
# date = 2023-12-28, l_syms = ['SPY'], ar_price = [476.69000244], ar_shares = [2.], ar_value = [953.38000488], portf_value = 953.3800048828125
# 2023-12-28 portf_value = 953.3800048828125
# next_date_n pick's portf value = 990.8999862670898
# next_date_n SPY portf value =    953.3800048828125
# ====================
#
# date = 2023-12-27, l_syms = ['GPS', 'SHV'], ar_price = [ 21.12734604 110.02999878], ar_shares = [23.  4.], ar_value = [485.92895889 440.11999512], portf_value = 926.0489540100098
# 2023-12-27 portf_value = 926.0489540100098
# date = 2023-12-27, l_syms = ['SPY'], ar_price = [476.51000977], ar_shares = [2.], ar_value = [953.02001953], portf_value = 953.02001953125
# 2023-12-27 portf_value = 953.02001953125
# next_date_n pick's portf value = 926.0489540100098
# next_date_n SPY portf value =    953.02001953125
# ====================
#
# date = 2023-12-26, l_syms = ['GPS', 'SHV'], ar_price = [ 21.28619766 110.02999878], ar_shares = [24.  4.], ar_value = [510.8687439  440.11999512], portf_value = 950.9887390136719
# 2023-12-26 portf_value = 950.9887390136719
# date = 2023-12-26, l_syms = ['SPY'], ar_price = [475.6499939], ar_shares = [2.], ar_value = [951.29998779], portf_value = 951.2999877929688
# 2023-12-26 portf_value = 951.2999877929688
# next_date_n pick's portf value = 950.9887390136719
# next_date_n SPY portf value =    951.2999877929688
# ====================
#
# date = 2023-12-22, l_syms = ['SHV'], ar_price = [110.01000214], ar_shares = [9.], ar_value = [990.09001923], portf_value = 990.0900192260742
# 2023-12-22 portf_value = 990.0900192260742
# date = 2023-12-22, l_syms = ['SPY'], ar_price = [473.6499939], ar_shares = [2.], ar_value = [947.29998779], portf_value = 947.2999877929688
# 2023-12-22 portf_value = 947.2999877929688
# next_date_n pick's portf value = 990.0900192260742
# next_date_n SPY portf value =    947.2999877929688
# ====================
#
# date = 2023-12-21, l_syms = ['SHV'], ar_price = [109.98999786], ar_shares = [9.], ar_value = [989.90998077], portf_value = 989.9099807739258
# 2023-12-21 portf_value = 989.9099807739258
# date = 2023-12-21, l_syms = ['SPY'], ar_price = [472.70001221], ar_shares = [2.], ar_value = [945.40002441], portf_value = 945.4000244140625
# 2023-12-21 portf_value = 945.4000244140625
# next_date_n pick's portf value = 989.9099807739258
# next_date_n SPY portf value =    945.4000244140625
# ====================
#
# date = 2023-12-19, l_syms = ['GPS', 'SHV'], ar_price = [ 21.44505119 109.88999939], ar_shares = [23.  4.], ar_value = [493.23617744 439.55999756], portf_value = 932.7961750030518
# 2023-12-19 portf_value = 932.7961750030518
# date = 2023-12-19, l_syms = ['SPY'], ar_price = [474.83999634], ar_shares = [2.], ar_value = [949.67999268], portf_value = 949.6799926757812
# 2023-12-19 portf_value = 949.6799926757812
# next_date_n pick's portf value = 932.7961750030518
# next_date_n SPY portf value =    949.6799926757812
# ====================
#
# date = 2023-12-18, l_syms = ['GPS', 'SHV'], ar_price = [ 20.81956863 109.88999939], ar_shares = [23.  4.], ar_value = [478.85007858 439.55999756], portf_value = 918.4100761413574
# 2023-12-18 portf_value = 918.4100761413574
# date = 2023-12-18, l_syms = ['SPY'], ar_price = [471.97000122], ar_shares = [2.], ar_value = [943.94000244], portf_value = 943.9400024414062
# 2023-12-18 portf_value = 943.9400024414062
# next_date_n pick's portf value = 918.4100761413574
# next_date_n SPY portf value =    943.9400024414062
# ====================
#
# date = 2023-12-15, l_syms = ['GPS', 'SHV'], ar_price = [ 21.15712929 109.87000275], ar_shares = [23.  4.], ar_value = [486.61397362 439.48001099], portf_value = 926.0939846038818
# 2023-12-15 portf_value = 926.0939846038818
# date = 2023-12-15, l_syms = ['SPY'], ar_price = [469.32998657], ar_shares = [2.], ar_value = [938.65997314], portf_value = 938.6599731445312
# 2023-12-15 portf_value = 938.6599731445312
# next_date_n pick's portf value = 926.0939846038818
# next_date_n SPY portf value =    938.6599731445312
# ====================
#
# date = 2023-12-14, l_syms = ['GPS', 'SHV'], ar_price = [ 21.14720154 109.86000061], ar_shares = [22.  4.], ar_value = [465.23843384 439.44000244], portf_value = 904.6784362792969
# 2023-12-14 portf_value = 904.6784362792969
# date = 2023-12-14, l_syms = ['SPY'], ar_price = [470.10400391], ar_shares = [2.], ar_value = [940.20800781], portf_value = 940.2080078125
# 2023-12-14 portf_value = 940.2080078125
# next_date_n pick's portf value = 904.6784362792969
# next_date_n SPY portf value =    940.2080078125
# ====================
#
# date = 2023-12-13, l_syms = ['GPS', 'SHV'], ar_price = [ 21.07770348 109.80599976], ar_shares = [23.  4.], ar_value = [484.78717995 439.22399902], portf_value = 924.0111789703369
# 2023-12-13 portf_value = 924.0111789703369
# date = 2023-12-13, l_syms = ['SPY'], ar_price = [468.60009766], ar_shares = [2.], ar_value = [937.20019531], portf_value = 937.2001953125
# 2023-12-13 portf_value = 937.2001953125
# next_date_n pick's portf value = 924.0111789703369
# next_date_n SPY portf value =    937.2001953125
# ====================
#
# date = 2023-12-12, l_syms = ['GPS', 'SHV'], ar_price = [ 21.14720154 109.76618195], ar_shares = [23.  4.], ar_value = [486.38563538 439.06472778], portf_value = 925.4503631591797
# 2023-12-12 portf_value = 925.4503631591797
# date = 2023-12-12, l_syms = ['SPY'], ar_price = [462.22595215], ar_shares = [2.], ar_value = [924.4519043], portf_value = 924.451904296875
# 2023-12-12 portf_value = 924.451904296875
# next_date_n pick's portf value = 925.4503631591797
# next_date_n SPY portf value =    924.451904296875
# ====================
#
# date = 2023-12-11, l_syms = ['GPS'], ar_price = [21.7726841], ar_shares = [48.], ar_value = [1045.08883667], portf_value = 1045.0888366699219
# 2023-12-11 portf_value = 1045.0888366699219
# date = 2023-12-11, l_syms = ['SPY'], ar_price = [460.12445068], ar_shares = [2.], ar_value = [920.24890137], portf_value = 920.2489013671875
# 2023-12-11 portf_value = 920.2489013671875
# next_date_n pick's portf value = 1045.0888366699219
# next_date_n SPY portf value =    920.2489013671875
# ====================
#
# date = 2023-12-11, l_syms = ['LRN', 'SHV'], ar_price = [ 60.86000061 109.7363205 ], ar_shares = [8. 4.], ar_value = [486.88000488 438.94528198], portf_value = 925.8252868652344
# 2023-12-11 portf_value = 925.8252868652344
# date = 2023-12-11, l_syms = ['SPY'], ar_price = [460.12445068], ar_shares = [2.], ar_value = [920.24890137], portf_value = 920.2489013671875
# 2023-12-11 portf_value = 920.2489013671875
# next_date_n pick's portf value = 925.8252868652344
# next_date_n SPY portf value =    920.2489013671875
# ====================
#
# date = 2023-12-11, l_syms = ['GPS'], ar_price = [21.7726841], ar_shares = [48.], ar_value = [1045.08883667], portf_value = 1045.0888366699219
# 2023-12-11 portf_value = 1045.0888366699219
# date = 2023-12-11, l_syms = ['SPY'], ar_price = [460.12445068], ar_shares = [2.], ar_value = [920.24890137], portf_value = 920.2489013671875
# 2023-12-11 portf_value = 920.2489013671875
# next_date_n pick's portf value = 1045.0888366699219
# next_date_n SPY portf value =    920.2489013671875
# ====================
#
# date = 2023-12-08, l_syms = ['GPS'], ar_price = [21.52447701], ar_shares = [48.], ar_value = [1033.17489624], portf_value = 1033.1748962402344
# 2023-12-08 portf_value = 1033.1748962402344
# date = 2023-12-08, l_syms = ['SPY'], ar_price = [458.34170532], ar_shares = [2.], ar_value = [916.68341064], portf_value = 916.6834106445312
# 2023-12-08 portf_value = 916.6834106445312
# next_date_n pick's portf value = 1033.1748962402344
# next_date_n SPY portf value =    916.6834106445312
# ====================
#
# date = 2023-12-08, l_syms = ['SHV'], ar_price = [109.7363205], ar_shares = [9.], ar_value = [987.62688446], portf_value = 987.6268844604492
# 2023-12-08 portf_value = 987.6268844604492
# date = 2023-12-08, l_syms = ['SPY'], ar_price = [458.34170532], ar_shares = [2.], ar_value = [916.68341064], portf_value = 916.6834106445312
# 2023-12-08 portf_value = 916.6834106445312
# next_date_n pick's portf value = 987.6268844604492
# next_date_n SPY portf value =    916.6834106445312
# ====================
#
# date = 2023-12-08, l_syms = ['GPS'], ar_price = [21.52447701], ar_shares = [48.], ar_value = [1033.17489624], portf_value = 1033.1748962402344
# 2023-12-08 portf_value = 1033.1748962402344
# date = 2023-12-08, l_syms = ['SPY'], ar_price = [458.34170532], ar_shares = [2.], ar_value = [916.68341064], portf_value = 916.6834106445312
# 2023-12-08 portf_value = 916.6834106445312
# next_date_n pick's portf value = 1033.1748962402344
# next_date_n SPY portf value =    916.6834106445312
# ====================
#
# date = 2023-12-07, l_syms = ['GPS'], ar_price = [21.21670151], ar_shares = [48.], ar_value = [1018.40167236], portf_value = 1018.4016723632812
# 2023-12-07 portf_value = 1018.4016723632812
# date = 2023-12-07, l_syms = ['SPY'], ar_price = [456.37966919], ar_shares = [2.], ar_value = [912.75933838], portf_value = 912.7593383789062
# 2023-12-07 portf_value = 912.7593383789062
# next_date_n pick's portf value = 1018.4016723632812
# next_date_n SPY portf value =    912.7593383789062
# ====================
#
# date = 2023-12-07, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.40780258 109.7363205 ], ar_shares = [8. 4.], ar_value = [475.26242065 438.94528198], portf_value = 914.2077026367188
# 2023-12-07 portf_value = 914.2077026367188
# date = 2023-12-07, l_syms = ['SPY'], ar_price = [456.37966919], ar_shares = [2.], ar_value = [912.75933838], portf_value = 912.7593383789062
# 2023-12-07 portf_value = 912.7593383789062
# next_date_n pick's portf value = 914.2077026367188
# next_date_n SPY portf value =    912.7593383789062
# ====================
#
# date = 2023-12-07, l_syms = ['GPS'], ar_price = [21.21670151], ar_shares = [48.], ar_value = [1018.40167236], portf_value = 1018.4016723632812
# 2023-12-07 portf_value = 1018.4016723632812
# date = 2023-12-07, l_syms = ['SPY'], ar_price = [456.37966919], ar_shares = [2.], ar_value = [912.75933838], portf_value = 912.7593383789062
# 2023-12-07 portf_value = 912.7593383789062
# next_date_n pick's portf value = 1018.4016723632812
# next_date_n SPY portf value =    912.7593383789062
# ====================
#
# date = 2023-12-06, l_syms = ['GPS', 'SHV'], ar_price = [ 20.78978539 109.68655396], ar_shares = [23.  4.], ar_value = [478.16506386 438.74621582], portf_value = 916.9112796783447
# 2023-12-06 portf_value = 916.9112796783447
# date = 2023-12-06, l_syms = ['SPY'], ar_price = [452.92367554], ar_shares = [2.], ar_value = [905.84735107], portf_value = 905.8473510742188
# 2023-12-06 portf_value = 905.8473510742188
# next_date_n pick's portf value = 916.9112796783447
# next_date_n SPY portf value =    905.8473510742188
# ====================
#
# date = 2023-12-05, l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = [ 59.3779335   20.63093376 109.66664124], ar_shares = [ 5. 16.  3.], ar_value = [296.88966751 330.09494019 328.99992371], portf_value = 955.9845314025879
# 2023-12-05 portf_value = 955.9845314025879
# date = 2023-12-05, l_syms = ['SPY'], ar_price = [454.75622559], ar_shares = [2.], ar_value = [909.51245117], portf_value = 909.512451171875
# 2023-12-05 portf_value = 909.512451171875
# next_date_n pick's portf value = 955.9845314025879
# next_date_n SPY portf value =    909.512451171875
# ====================
#
# date = 2023-12-04, l_syms = ['SHV'], ar_price = [109.64673615], ar_shares = [9.], ar_value = [986.82062531], portf_value = 986.8206253051758
# 2023-12-04 portf_value = 986.8206253051758
# date = 2023-12-04, l_syms = ['SPY'], ar_price = [454.84588623], ar_shares = [2.], ar_value = [909.69177246], portf_value = 909.6917724609375
# 2023-12-04 portf_value = 909.6917724609375
# next_date_n pick's portf value = 986.8206253051758
# next_date_n SPY portf value =    909.6917724609375
# ====================
#
# date = 2023-12-04, l_syms = ['FTSM', 'GPS'], ar_price = [59.35801697 20.69050217], ar_shares = [ 8. 24.], ar_value = [474.86413574 496.572052  ], portf_value = 971.4361877441406
# 2023-12-04 portf_value = 971.4361877441406
# date = 2023-12-04, l_syms = ['SPY'], ar_price = [454.84588623], ar_shares = [2.], ar_value = [909.69177246], portf_value = 909.6917724609375
# 2023-12-04 portf_value = 909.6917724609375
# next_date_n pick's portf value = 971.4361877441406
# next_date_n SPY portf value =    909.6917724609375
# ====================
#
# date = 2023-12-01, l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = [ 59.34805679  20.8692112  109.63677979], ar_shares = [ 5. 17.  3.], ar_value = [296.74028397 354.77659035 328.91033936], portf_value = 980.4272136688232
# 2023-12-01 portf_value = 980.4272136688232
# date = 2023-12-01, l_syms = ['SPY'], ar_price = [457.24615479], ar_shares = [2.], ar_value = [914.49230957], portf_value = 914.4923095703125
# 2023-12-01 portf_value = 914.4923095703125
# next_date_n pick's portf value = 980.4272136688232
# next_date_n SPY portf value =    914.4923095703125
# ====================
#
# date = 2023-11-30, l_syms = ['GPS', 'SHV'], ar_price = [ 19.92602539 109.60192871], ar_shares = [25.  4.], ar_value = [498.15063477 438.40771484], portf_value = 936.558349609375
# 2023-11-30 portf_value = 936.558349609375
# date = 2023-11-30, l_syms = ['SPY'], ar_price = [454.55703735], ar_shares = [2.], ar_value = [909.11407471], portf_value = 909.1140747070312
# 2023-11-30 portf_value = 909.1140747070312
# next_date_n pick's portf value = 936.558349609375
# next_date_n SPY portf value =    909.1140747070312
# ====================
#
# date = 2023-11-29, l_syms = ['GPS', 'SHV'], ar_price = [ 20.01538086 109.56229401], ar_shares = [26.  4.], ar_value = [520.39990234 438.24917603], portf_value = 958.6490783691406
# 2023-11-29 portf_value = 958.6490783691406
# date = 2023-11-29, l_syms = ['SPY'], ar_price = [452.77426147], ar_shares = [2.], ar_value = [905.54852295], portf_value = 905.5485229492188
# 2023-11-29 portf_value = 905.5485229492188
# next_date_n pick's portf value = 958.6490783691406
# next_date_n SPY portf value =    905.5485229492188
# ====================
#
# date = 2023-11-28, l_syms = ['SHV'], ar_price = [109.54247284], ar_shares = [9.], ar_value = [985.88225555], portf_value = 985.8822555541992
# 2023-11-28 portf_value = 985.8822555541992
# date = 2023-11-28, l_syms = ['SPY'], ar_price = [453.09295654], ar_shares = [2.], ar_value = [906.18591309], portf_value = 906.1859130859375
# 2023-11-28 portf_value = 906.1859130859375
# next_date_n pick's portf value = 985.8822555541992
# next_date_n SPY portf value =    906.1859130859375
# ====================
#
# date = 2023-11-28, l_syms = ['FTSM', 'GPS'], ar_price = [59.27540588 19.40975571], ar_shares = [ 8. 26.], ar_value = [474.20324707 504.65364838], portf_value = 978.8568954467773
# 2023-11-28 portf_value = 978.8568954467773
# date = 2023-11-28, l_syms = ['SPY'], ar_price = [453.09295654], ar_shares = [2.], ar_value = [906.18591309], portf_value = 906.1859130859375
# 2023-11-28 portf_value = 906.1859130859375
# next_date_n pick's portf value = 978.8568954467773
# next_date_n SPY portf value =    906.1859130859375
# ====================
#
# date = 2023-11-27, l_syms = ['SHV'], ar_price = [109.51274109], ar_shares = [9.], ar_value = [985.6146698], portf_value = 985.6146697998047
# 2023-11-27 portf_value = 985.6146697998047
# date = 2023-11-27, l_syms = ['SPY'], ar_price = [452.64480591], ar_shares = [2.], ar_value = [905.28961182], portf_value = 905.2896118164062
# 2023-11-27 portf_value = 905.2896118164062
# next_date_n pick's portf value = 985.6146697998047
# next_date_n SPY portf value =    905.2896118164062
# ====================
#
# date = 2023-11-27, l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = [59.22582245 19.30054665 46.45999908], ar_shares = [ 5. 17.  7.], ar_value = [296.12911224 328.10929298 325.21999359], portf_value = 949.4583988189697
# 2023-11-27 portf_value = 949.4583988189697
# date = 2023-11-27, l_syms = ['SPY'], ar_price = [452.64480591], ar_shares = [2.], ar_value = [905.28961182], portf_value = 905.2896118164062
# 2023-11-27 portf_value = 905.2896118164062
# next_date_n pick's portf value = 949.4583988189697
# next_date_n SPY portf value =    905.2896118164062
# ====================
#
# date = 2023-11-24, l_syms = ['SHV'], ar_price = [109.49291992], ar_shares = [9.], ar_value = [985.4362793], portf_value = 985.436279296875
# 2023-11-24 portf_value = 985.436279296875
# date = 2023-11-24, l_syms = ['SPY'], ar_price = [453.4614563], ar_shares = [2.], ar_value = [906.9229126], portf_value = 906.9229125976562
# 2023-11-24 portf_value = 906.9229125976562
# next_date_n pick's portf value = 985.436279296875
# next_date_n SPY portf value =    906.9229125976562
# ====================
#
# date = 2023-11-24, l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = [59.20598602 18.72470665 45.88999939], ar_shares = [ 5. 18.  7.], ar_value = [296.02993011 337.0447197  321.22999573], portf_value = 954.3046455383301
# 2023-11-24 portf_value = 954.3046455383301
# date = 2023-11-24, l_syms = ['SPY'], ar_price = [453.4614563], ar_shares = [2.], ar_value = [906.9229126], portf_value = 906.9229125976562
# 2023-11-24 portf_value = 906.9229125976562
# next_date_n pick's portf value = 954.3046455383301
# next_date_n SPY portf value =    906.9229125976562
# ====================
#
# date = 2023-11-22, l_syms = ['SHV'], ar_price = [109.48300934], ar_shares = [9.], ar_value = [985.34708405], portf_value = 985.3470840454102
# 2023-11-22 portf_value = 985.3470840454102
# date = 2023-11-22, l_syms = ['SPY'], ar_price = [453.18261719], ar_shares = [2.], ar_value = [906.36523438], portf_value = 906.365234375
# 2023-11-22 portf_value = 906.365234375
# next_date_n pick's portf value = 985.3470840454102
# next_date_n SPY portf value =    906.365234375
# ====================
#
# date = 2023-11-22, l_syms = ['FTSM', 'NRG'], ar_price = [59.19606781 45.83000183], ar_shares = [ 8. 10.], ar_value = [473.56854248 458.30001831], portf_value = 931.8685607910156
# 2023-11-22 portf_value = 931.8685607910156
# date = 2023-11-22, l_syms = ['SPY'], ar_price = [453.18261719], ar_shares = [2.], ar_value = [906.36523438], portf_value = 906.365234375
# 2023-11-22 portf_value = 906.365234375
# next_date_n pick's portf value = 931.8685607910156
# next_date_n SPY portf value =    906.365234375
# ====================
#
# date = 2023-11-21, l_syms = ['SHV'], ar_price = [109.443367], ar_shares = [9.], ar_value = [984.99030304], portf_value = 984.9903030395508
# 2023-11-21 portf_value = 984.9903030395508
# date = 2023-11-21, l_syms = ['SPY'], ar_price = [451.43966675], ar_shares = [2.], ar_value = [902.8793335], portf_value = 902.8793334960938
# 2023-11-21 portf_value = 902.8793334960938
# next_date_n pick's portf value = 984.9903030395508
# next_date_n SPY portf value =    902.8793334960938
# ====================
#
# date = 2023-11-21, l_syms = ['FTSM', 'NRG'], ar_price = [59.16631317 45.20000076], ar_shares = [ 8. 10.], ar_value = [473.33050537 452.00000763], portf_value = 925.3305130004883
# 2023-11-21 portf_value = 925.3305130004883
# date = 2023-11-21, l_syms = ['SPY'], ar_price = [451.43966675], ar_shares = [2.], ar_value = [902.8793335], portf_value = 902.8793334960938
# 2023-11-21 portf_value = 902.8793334960938
# next_date_n pick's portf value = 925.3305130004883
# next_date_n SPY portf value =    902.8793334960938
# ====================
#
# date = 2023-11-20, l_syms = ['SHV'], ar_price = [109.40372467], ar_shares = [9.], ar_value = [984.63352203], portf_value = 984.6335220336914
# 2023-11-20 portf_value = 984.6335220336914
# date = 2023-11-20, l_syms = ['SPY'], ar_price = [452.4256897], ar_shares = [2.], ar_value = [904.85137939], portf_value = 904.8513793945312
# 2023-11-20 portf_value = 904.8513793945312
# next_date_n pick's portf value = 984.6335220336914
# next_date_n SPY portf value =    904.8513793945312
# ====================
#
# date = 2023-11-20, l_syms = ['FTSM', 'NRG'], ar_price = [59.15639877 47.29000092], ar_shares = [ 8. 10.], ar_value = [473.25119019 472.90000916], portf_value = 946.1511993408203
# 2023-11-20 portf_value = 946.1511993408203
# date = 2023-11-20, l_syms = ['SPY'], ar_price = [452.4256897], ar_shares = [2.], ar_value = [904.85137939], portf_value = 904.8513793945312
# 2023-11-20 portf_value = 904.8513793945312
# next_date_n pick's portf value = 946.1511993408203
# next_date_n SPY portf value =    904.8513793945312
# ====================
#
# date = 2023-11-17, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.13656616 109.39380646], ar_shares = [8. 4.], ar_value = [473.0925293  437.57522583], portf_value = 910.6677551269531
# 2023-11-17 portf_value = 910.6677551269531
# date = 2023-11-17, l_syms = ['SPY'], ar_price = [448.96969604], ar_shares = [2.], ar_value = [897.93939209], portf_value = 897.9393920898438
# 2023-11-17 portf_value = 897.9393920898438
# next_date_n pick's portf value = 910.6677551269531
# next_date_n SPY portf value =    897.9393920898438
# ====================
#
# date = 2023-11-17, l_syms = ['CBOE'], ar_price = [176.66000366], ar_shares = [5.], ar_value = [883.30001831], portf_value = 883.3000183105469
# 2023-11-17 portf_value = 883.3000183105469
# date = 2023-11-17, l_syms = ['SPY'], ar_price = [448.96969604], ar_shares = [2.], ar_value = [897.93939209], portf_value = 897.9393920898438
# 2023-11-17 portf_value = 897.9393920898438
# next_date_n pick's portf value = 883.3000183105469
# next_date_n SPY portf value =    897.9393920898438
# ====================
#
# date = 2023-11-16, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.12664795 109.3839035 ], ar_shares = [8. 4.], ar_value = [473.01318359 437.53561401], portf_value = 910.5487976074219
# 2023-11-16 portf_value = 910.5487976074219
# date = 2023-11-16, l_syms = ['SPY'], ar_price = [448.41195679], ar_shares = [2.], ar_value = [896.82391357], portf_value = 896.8239135742188
# 2023-11-16 portf_value = 896.8239135742188
# next_date_n pick's portf value = 910.5487976074219
# next_date_n SPY portf value =    896.8239135742188
# ====================
#
# date = 2023-11-16, l_syms = ['CBOE'], ar_price = [177.78999329], ar_shares = [5.], ar_value = [888.94996643], portf_value = 888.9499664306641
# 2023-11-16 portf_value = 888.9499664306641
# date = 2023-11-16, l_syms = ['SPY'], ar_price = [448.41195679], ar_shares = [2.], ar_value = [896.82391357], portf_value = 896.8239135742188
# 2023-11-16 portf_value = 896.8239135742188
# next_date_n pick's portf value = 888.9499664306641
# next_date_n SPY portf value =    896.8239135742188
# ====================
#
# date = 2023-11-15, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.10681152 109.32443237], ar_shares = [8. 4.], ar_value = [472.85449219 437.29772949], portf_value = 910.1522216796875
# 2023-11-15 portf_value = 910.1522216796875
# date = 2023-11-15, l_syms = ['SPY'], ar_price = [447.86416626], ar_shares = [2.], ar_value = [895.72833252], portf_value = 895.7283325195312
# 2023-11-15 portf_value = 895.7283325195312
# next_date_n pick's portf value = 910.1522216796875
# next_date_n SPY portf value =    895.7283325195312
# ====================
#
# date = 2023-11-15, l_syms = ['CBOE'], ar_price = [176.97999573], ar_shares = [5.], ar_value = [884.89997864], portf_value = 884.8999786376953
# 2023-11-15 portf_value = 884.8999786376953
# date = 2023-11-15, l_syms = ['SPY'], ar_price = [447.86416626], ar_shares = [2.], ar_value = [895.72833252], portf_value = 895.7283325195312
# 2023-11-15 portf_value = 895.7283325195312
# next_date_n pick's portf value = 884.8999786376953
# next_date_n SPY portf value =    895.7283325195312
# ====================
#
# date = 2023-11-14, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.11672974 109.31452942], ar_shares = [8. 4.], ar_value = [472.93383789 437.25811768], portf_value = 910.1919555664062
# 2023-11-14 portf_value = 910.1919555664062
# date = 2023-11-14, l_syms = ['SPY'], ar_price = [446.91802979], ar_shares = [2.], ar_value = [893.83605957], portf_value = 893.8360595703125
# 2023-11-14 portf_value = 893.8360595703125
# next_date_n pick's portf value = 910.1919555664062
# next_date_n SPY portf value =    893.8360595703125
# ====================
#
# date = 2023-11-14, l_syms = ['NRG'], ar_price = [47.31999969], ar_shares = [22.], ar_value = [1041.03999329], portf_value = 1041.0399932861328
# 2023-11-14 portf_value = 1041.0399932861328
# date = 2023-11-14, l_syms = ['SPY'], ar_price = [446.91802979], ar_shares = [2.], ar_value = [893.83605957], portf_value = 893.8360595703125
# 2023-11-14 portf_value = 893.8360595703125
# next_date_n pick's portf value = 1041.0399932861328
# next_date_n SPY portf value =    893.8360595703125
# ====================
#
# date = 2023-11-13, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.0671463  109.27488708], ar_shares = [8. 4.], ar_value = [472.53717041 437.09954834], portf_value = 909.63671875
# 2023-11-13 portf_value = 909.63671875
# date = 2023-11-13, l_syms = ['SPY'], ar_price = [438.4125061], ar_shares = [2.], ar_value = [876.82501221], portf_value = 876.8250122070312
# 2023-11-13 portf_value = 876.8250122070312
# next_date_n pick's portf value = 909.63671875
# next_date_n SPY portf value =    876.8250122070312
# ====================
#
# date = 2023-11-13, l_syms = ['NRG'], ar_price = [46.09000015], ar_shares = [21.], ar_value = [967.8900032], portf_value = 967.8900032043457
# 2023-11-13 portf_value = 967.8900032043457
# date = 2023-11-13, l_syms = ['SPY'], ar_price = [438.4125061], ar_shares = [2.], ar_value = [876.82501221], portf_value = 876.8250122070312
# 2023-11-13 portf_value = 876.8250122070312
# next_date_n pick's portf value = 967.8900032043457
# next_date_n SPY portf value =    876.8250122070312
# ====================
#
# date = 2023-11-10, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.04730988 109.2649765 ], ar_shares = [8. 4.], ar_value = [472.378479   437.05990601], portf_value = 909.4383850097656
# 2023-11-10 portf_value = 909.4383850097656
# date = 2023-11-10, l_syms = ['SPY'], ar_price = [438.83078003], ar_shares = [2.], ar_value = [877.66156006], portf_value = 877.6615600585938
# 2023-11-10 portf_value = 877.6615600585938
# next_date_n pick's portf value = 909.4383850097656
# next_date_n SPY portf value =    877.6615600585938
# ====================
#
# date = 2023-11-10, l_syms = ['NRG'], ar_price = [45.54999924], ar_shares = [22.], ar_value = [1002.09998322], portf_value = 1002.099983215332
# 2023-11-10 portf_value = 1002.099983215332
# date = 2023-11-10, l_syms = ['SPY'], ar_price = [438.83078003], ar_shares = [2.], ar_value = [877.66156006], portf_value = 877.6615600585938
# 2023-11-10 portf_value = 877.6615600585938
# next_date_n pick's portf value = 1002.099983215332
# next_date_n SPY portf value =    877.6615600585938
# ====================
#
# date = 2023-11-09, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.04235077 109.23524475], ar_shares = [8. 4.], ar_value = [472.33880615 436.940979  ], portf_value = 909.27978515625
# 2023-11-09 portf_value = 909.27978515625
# date = 2023-11-09, l_syms = ['SPY'], ar_price = [432.08813477], ar_shares = [2.], ar_value = [864.17626953], portf_value = 864.17626953125
# 2023-11-09 portf_value = 864.17626953125
# next_date_n pick's portf value = 909.27978515625
# next_date_n SPY portf value =    864.17626953125
# ====================
#
# date = 2023-11-09, l_syms = ['ANF'], ar_price = [66.75], ar_shares = [15.], ar_value = [1001.25], portf_value = 1001.25
# 2023-11-09 portf_value = 1001.25
# date = 2023-11-09, l_syms = ['SPY'], ar_price = [432.08813477], ar_shares = [2.], ar_value = [864.17626953], portf_value = 864.17626953125
# 2023-11-09 portf_value = 864.17626953125
# next_date_n pick's portf value = 1001.25
# next_date_n SPY portf value =    864.17626953125
# ====================
#
# date = 2023-11-08, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.02747345 109.19560242], ar_shares = [8. 4.], ar_value = [472.2197876  436.78240967], portf_value = 909.002197265625
# 2023-11-08 portf_value = 909.002197265625
# date = 2023-11-08, l_syms = ['SPY'], ar_price = [435.484375], ar_shares = [2.], ar_value = [870.96875], portf_value = 870.96875
# 2023-11-08 portf_value = 870.96875
# next_date_n pick's portf value = 909.002197265625
# next_date_n SPY portf value =    870.96875
# ====================
#
# date = 2023-11-08, l_syms = ['ANF'], ar_price = [67.91999817], ar_shares = [15.], ar_value = [1018.79997253], portf_value = 1018.7999725341797
# 2023-11-08 portf_value = 1018.7999725341797
# date = 2023-11-08, l_syms = ['SPY'], ar_price = [435.484375], ar_shares = [2.], ar_value = [870.96875], portf_value = 870.96875
# 2023-11-08 portf_value = 870.96875
# next_date_n pick's portf value = 1018.7999725341797
# next_date_n SPY portf value =    870.96875
# ====================
#
# date = 2023-11-07, l_syms = ['FTSM'], ar_price = [59.03738785], ar_shares = [16.], ar_value = [944.59820557], portf_value = 944.5982055664062
# 2023-11-07 portf_value = 944.5982055664062
# date = 2023-11-07, l_syms = ['SPY'], ar_price = [435.16564941], ar_shares = [2.], ar_value = [870.33129883], portf_value = 870.331298828125
# 2023-11-07 portf_value = 870.331298828125
# next_date_n pick's portf value = 944.5982055664062
# next_date_n SPY portf value =    870.331298828125
# ====================
#
# date = 2023-11-07, l_syms = ['ANF'], ar_price = [67.80999756], ar_shares = [15.], ar_value = [1017.14996338], portf_value = 1017.1499633789062
# 2023-11-07 portf_value = 1017.1499633789062
# date = 2023-11-07, l_syms = ['SPY'], ar_price = [435.16564941], ar_shares = [2.], ar_value = [870.33129883], portf_value = 870.331298828125
# 2023-11-07 portf_value = 870.331298828125
# next_date_n pick's portf value = 1017.1499633789062
# next_date_n SPY portf value =    870.331298828125
# ====================
#
# date = 2023-11-06, l_syms = ['SHV'], ar_price = [109.15596008], ar_shares = [9.], ar_value = [982.40364075], portf_value = 982.4036407470703
# 2023-11-06 portf_value = 982.4036407470703
# date = 2023-11-06, l_syms = ['SPY'], ar_price = [433.93066406], ar_shares = [2.], ar_value = [867.86132812], portf_value = 867.861328125
# 2023-11-06 portf_value = 867.861328125
# next_date_n pick's portf value = 982.4036407470703
# next_date_n SPY portf value =    867.861328125
# ====================
#
# date = 2023-11-06, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.02747345 109.15596008], ar_shares = [8. 4.], ar_value = [472.2197876  436.62384033], portf_value = 908.8436279296875
# 2023-11-06 portf_value = 908.8436279296875
# date = 2023-11-06, l_syms = ['SPY'], ar_price = [433.93066406], ar_shares = [2.], ar_value = [867.86132812], portf_value = 867.861328125
# 2023-11-06 portf_value = 867.861328125
# next_date_n pick's portf value = 908.8436279296875
# next_date_n SPY portf value =    867.861328125
# ====================
#
# date = 2023-11-06, l_syms = ['ANF', 'SPLK'], ar_price = [ 66.26999664 146.61999512], ar_shares = [8. 3.], ar_value = [530.15997314 439.85998535], portf_value = 970.0199584960938
# 2023-11-06 portf_value = 970.0199584960938
# date = 2023-11-06, l_syms = ['SPY'], ar_price = [433.93066406], ar_shares = [2.], ar_value = [867.86132812], portf_value = 867.861328125
# 2023-11-06 portf_value = 867.861328125
# next_date_n pick's portf value = 970.0199584960938
# next_date_n SPY portf value =    867.861328125
# ====================
#
# date = 2023-11-06, l_syms = ['SHV'], ar_price = [109.15596008], ar_shares = [9.], ar_value = [982.40364075], portf_value = 982.4036407470703
# 2023-11-06 portf_value = 982.4036407470703
# date = 2023-11-06, l_syms = ['SPY'], ar_price = [433.93066406], ar_shares = [2.], ar_value = [867.86132812], portf_value = 867.861328125
# 2023-11-06 portf_value = 867.861328125
# next_date_n pick's portf value = 982.4036407470703
# next_date_n SPY portf value =    867.861328125
# ====================
#
# date = 2023-11-03, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.02251434 109.16587067], ar_shares = [8. 4.], ar_value = [472.18011475 436.66348267], portf_value = 908.8435974121094
# 2023-11-03 portf_value = 908.8435974121094
# date = 2023-11-03, l_syms = ['SPY'], ar_price = [432.9347229], ar_shares = [2.], ar_value = [865.8694458], portf_value = 865.8694458007812
# 2023-11-03 portf_value = 865.8694458007812
# next_date_n pick's portf value = 908.8435974121094
# next_date_n SPY portf value =    865.8694458007812
# ====================
#
# date = 2023-11-03, l_syms = ['SPLK'], ar_price = [146.47999573], ar_shares = [6.], ar_value = [878.87997437], portf_value = 878.8799743652344
# 2023-11-03 portf_value = 878.8799743652344
# date = 2023-11-03, l_syms = ['SPY'], ar_price = [432.9347229], ar_shares = [2.], ar_value = [865.8694458], portf_value = 865.8694458007812
# 2023-11-03 portf_value = 865.8694458007812
# next_date_n pick's portf value = 878.8799743652344
# next_date_n SPY portf value =    865.8694458007812
# ====================
#
# date = 2023-11-03, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.02251434 109.16587067], ar_shares = [8. 4.], ar_value = [472.18011475 436.66348267], portf_value = 908.8435974121094
# 2023-11-03 portf_value = 908.8435974121094
# date = 2023-11-03, l_syms = ['SPY'], ar_price = [432.9347229], ar_shares = [2.], ar_value = [865.8694458], portf_value = 865.8694458007812
# 2023-11-03 portf_value = 865.8694458007812
# next_date_n pick's portf value = 908.8435974121094
# next_date_n SPY portf value =    865.8694458007812
# ====================
#
# date = 2023-11-02, l_syms = ['FTSM', 'SHV'], ar_price = [ 59.00764084 109.13613892], ar_shares = [8. 4.], ar_value = [472.06112671 436.54455566], portf_value = 908.6056823730469
# 2023-11-02 portf_value = 908.6056823730469
# date = 2023-11-02, l_syms = ['SPY'], ar_price = [429.02059937], ar_shares = [2.], ar_value = [858.04119873], portf_value = 858.0411987304688
# 2023-11-02 portf_value = 858.0411987304688
# next_date_n pick's portf value = 908.6056823730469
# next_date_n SPY portf value =    858.0411987304688
# ====================
#
# date = 2023-11-02, l_syms = ['SPLK'], ar_price = [146.78999329], ar_shares = [6.], ar_value = [880.73995972], portf_value = 880.7399597167969
# 2023-11-02 portf_value = 880.7399597167969
# date = 2023-11-02, l_syms = ['SPY'], ar_price = [429.02059937], ar_shares = [2.], ar_value = [858.04119873], portf_value = 858.0411987304688
# 2023-11-02 portf_value = 858.0411987304688
# next_date_n pick's portf value = 880.7399597167969
# next_date_n SPY portf value =    858.0411987304688
# ====================
#
# date = 2023-11-02, l_syms = ['SHV'], ar_price = [109.13613892], ar_shares = [9.], ar_value = [982.22525024], portf_value = 982.2252502441406
# 2023-11-02 portf_value = 982.2252502441406
# date = 2023-11-02, l_syms = ['SPY'], ar_price = [429.02059937], ar_shares = [2.], ar_value = [858.04119873], portf_value = 858.0411987304688
# 2023-11-02 portf_value = 858.0411987304688
# next_date_n pick's portf value = 982.2252502441406
# next_date_n SPY portf value =    858.0411987304688
# ====================
#
# date = 2023-11-01, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.9679718 109.086586 ], ar_shares = [8. 4.], ar_value = [471.74377441 436.34634399], portf_value = 908.0901184082031
# 2023-11-01 portf_value = 908.0901184082031
# date = 2023-11-01, l_syms = ['SPY'], ar_price = [420.95327759], ar_shares = [2.], ar_value = [841.90655518], portf_value = 841.9065551757812
# 2023-11-01 portf_value = 841.9065551757812
# next_date_n pick's portf value = 908.0901184082031
# next_date_n SPY portf value =    841.9065551757812
# ====================
#
# date = 2023-11-01, l_syms = ['SPLK'], ar_price = [146.88000488], ar_shares = [6.], ar_value = [881.2800293], portf_value = 881.280029296875
# 2023-11-01 portf_value = 881.280029296875
# date = 2023-11-01, l_syms = ['SPY'], ar_price = [420.95327759], ar_shares = [2.], ar_value = [841.90655518], portf_value = 841.9065551757812
# 2023-11-01 portf_value = 841.9065551757812
# next_date_n pick's portf value = 881.280029296875
# next_date_n SPY portf value =    841.9065551757812
# ====================
#
# date = 2023-10-31, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.93821716 109.04891968], ar_shares = [8. 4.], ar_value = [471.5057373  436.19567871], portf_value = 907.701416015625
# 2023-10-31 portf_value = 907.701416015625
# date = 2023-10-31, l_syms = ['SPY'], ar_price = [416.5112915], ar_shares = [2.], ar_value = [833.02258301], portf_value = 833.0225830078125
# 2023-10-31 portf_value = 833.0225830078125
# next_date_n pick's portf value = 907.701416015625
# next_date_n SPY portf value =    833.0225830078125
# ====================
#
# date = 2023-10-31, l_syms = ['ANF', 'SPLK'], ar_price = [ 60.81999969 147.16000366], ar_shares = [8. 3.], ar_value = [486.55999756 441.48001099], portf_value = 928.0400085449219
# 2023-10-31 portf_value = 928.0400085449219
# date = 2023-10-31, l_syms = ['SPY'], ar_price = [416.5112915], ar_shares = [2.], ar_value = [833.02258301], portf_value = 833.0225830078125
# 2023-10-31 portf_value = 833.0225830078125
# next_date_n pick's portf value = 928.0400085449219
# next_date_n SPY portf value =    833.0225830078125
# ====================
#
# date = 2023-10-30, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.94913101 109.04891968], ar_shares = [8. 4.], ar_value = [471.5930481  436.19567871], portf_value = 907.7887268066406
# 2023-10-30 portf_value = 907.7887268066406
# date = 2023-10-30, l_syms = ['SPY'], ar_price = [413.91183472], ar_shares = [2.], ar_value = [827.82366943], portf_value = 827.8236694335938
# 2023-10-30 portf_value = 827.8236694335938
# next_date_n pick's portf value = 907.7887268066406
# next_date_n SPY portf value =    827.8236694335938
# ====================
#
# date = 2023-10-30, l_syms = ['ANF'], ar_price = [59.61000061], ar_shares = [16.], ar_value = [953.76000977], portf_value = 953.760009765625
# 2023-10-30 portf_value = 953.760009765625
# date = 2023-10-30, l_syms = ['SPY'], ar_price = [413.91183472], ar_shares = [2.], ar_value = [827.82366943], portf_value = 827.8236694335938
# 2023-10-30 portf_value = 827.8236694335938
# next_date_n pick's portf value = 953.760009765625
# next_date_n SPY portf value =    827.8236694335938
# ====================
#
# date = 2023-10-27, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.93431473 109.03904724], ar_shares = [8. 4.], ar_value = [471.47451782 436.15618896], portf_value = 907.6307067871094
# 2023-10-27 portf_value = 907.6307067871094
# date = 2023-10-27, l_syms = ['SPY'], ar_price = [409.02163696], ar_shares = [2.], ar_value = [818.04327393], portf_value = 818.0432739257812
# 2023-10-27 portf_value = 818.0432739257812
# next_date_n pick's portf value = 907.6307067871094
# next_date_n SPY portf value =    818.0432739257812
# ====================
#
# date = 2023-10-27, l_syms = ['SPLK'], ar_price = [147.13999939], ar_shares = [6.], ar_value = [882.83999634], portf_value = 882.8399963378906
# 2023-10-27 portf_value = 882.8399963378906
# date = 2023-10-27, l_syms = ['SPY'], ar_price = [409.02163696], ar_shares = [2.], ar_value = [818.04327393], portf_value = 818.0432739257812
# 2023-10-27 portf_value = 818.0432739257812
# next_date_n pick's portf value = 882.8399963378906
# next_date_n SPY portf value =    818.0432739257812
# ====================
#
# date = 2023-10-26, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.92937851 109.01932526], ar_shares = [8. 4.], ar_value = [471.43502808 436.07730103], portf_value = 907.5123291015625
# 2023-10-26 portf_value = 907.5123291015625
# date = 2023-10-26, l_syms = ['SPY'], ar_price = [410.88409424], ar_shares = [2.], ar_value = [821.76818848], portf_value = 821.7681884765625
# 2023-10-26 portf_value = 821.7681884765625
# next_date_n pick's portf value = 907.5123291015625
# next_date_n SPY portf value =    821.7681884765625
# ====================
#
# date = 2023-10-25, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.88492966 108.95023346], ar_shares = [8. 4.], ar_value = [471.07943726 435.80093384], portf_value = 906.88037109375
# 2023-10-25 portf_value = 906.88037109375
# date = 2023-10-25, l_syms = ['SPY'], ar_price = [415.8638916], ar_shares = [2.], ar_value = [831.7277832], portf_value = 831.727783203125
# 2023-10-25 portf_value = 831.727783203125
# next_date_n pick's portf value = 906.88037109375
# next_date_n SPY portf value =    831.727783203125
# ====================
#
# date = 2023-10-25, l_syms = ['SHV'], ar_price = [108.95023346], ar_shares = [9.], ar_value = [980.55210114], portf_value = 980.5521011352539
# 2023-10-25 portf_value = 980.5521011352539
# date = 2023-10-25, l_syms = ['SPY'], ar_price = [415.8638916], ar_shares = [2.], ar_value = [831.7277832], portf_value = 831.727783203125
# 2023-10-25 portf_value = 831.727783203125
# next_date_n pick's portf value = 980.5521011352539
# next_date_n SPY portf value =    831.727783203125
# ====================
#
# date = 2023-10-24, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.89480972 108.95023346], ar_shares = [8. 4.], ar_value = [471.15847778 435.80093384], portf_value = 906.9594116210938
# 2023-10-24 portf_value = 906.9594116210938
# date = 2023-10-24, l_syms = ['SPY'], ar_price = [421.91937256], ar_shares = [2.], ar_value = [843.83874512], portf_value = 843.8387451171875
# 2023-10-24 portf_value = 843.8387451171875
# next_date_n pick's portf value = 906.9594116210938
# next_date_n SPY portf value =    843.8387451171875
# ====================
#
# date = 2023-10-23, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.89480972 108.94036865], ar_shares = [8. 4.], ar_value = [471.15847778 435.76147461], portf_value = 906.9199523925781
# 2023-10-23 portf_value = 906.9199523925781
# date = 2023-10-23, l_syms = ['SPY'], ar_price = [418.762146], ar_shares = [2.], ar_value = [837.52429199], portf_value = 837.5242919921875
# 2023-10-23 portf_value = 837.5242919921875
# next_date_n pick's portf value = 906.9199523925781
# next_date_n SPY portf value =    837.5242919921875
# ====================
#
# date = 2023-10-20, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.86517715 108.92063904], ar_shares = [8. 4.], ar_value = [470.92141724 435.68255615], portf_value = 906.6039733886719
# 2023-10-20 portf_value = 906.6039733886719
# date = 2023-10-20, l_syms = ['SPY'], ar_price = [419.48922729], ar_shares = [2.], ar_value = [838.97845459], portf_value = 838.9784545898438
# 2023-10-20 portf_value = 838.9784545898438
# next_date_n pick's portf value = 906.6039733886719
# next_date_n SPY portf value =    838.9784545898438
# ====================
#
# date = 2023-10-19, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.84542847 108.89102173], ar_shares = [8. 4.], ar_value = [470.76342773 435.56408691], portf_value = 906.3275146484375
# 2023-10-19 portf_value = 906.3275146484375
# date = 2023-10-19, l_syms = ['SPY'], ar_price = [424.70803833], ar_shares = [2.], ar_value = [849.41607666], portf_value = 849.4160766601562
# 2023-10-19 portf_value = 849.4160766601562
# next_date_n pick's portf value = 906.3275146484375
# next_date_n SPY portf value =    849.4160766601562
# ====================
#
# date = 2023-10-19, l_syms = ['SHV'], ar_price = [108.89102173], ar_shares = [9.], ar_value = [980.01919556], portf_value = 980.0191955566406
# 2023-10-19 portf_value = 980.0191955566406
# date = 2023-10-19, l_syms = ['SPY'], ar_price = [424.70803833], ar_shares = [2.], ar_value = [849.41607666], portf_value = 849.4160766601562
# 2023-10-19 portf_value = 849.4160766601562
# next_date_n pick's portf value = 980.0191955566406
# next_date_n SPY portf value =    849.4160766601562
# ====================
#
# date = 2023-10-18, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.81579208 108.84168243], ar_shares = [8. 4.], ar_value = [470.52633667 435.36672974], portf_value = 905.89306640625
# 2023-10-18 portf_value = 905.89306640625
# date = 2023-10-18, l_syms = ['SPY'], ar_price = [428.47277832], ar_shares = [2.], ar_value = [856.94555664], portf_value = 856.945556640625
# 2023-10-18 portf_value = 856.945556640625
# next_date_n pick's portf value = 905.89306640625
# next_date_n SPY portf value =    856.945556640625
# ====================
#
# date = 2023-10-17, l_syms = ['FTSM', 'SHV'], ar_price = [ 58.82073212 108.83181763], ar_shares = [8. 4.], ar_value = [470.56585693 435.32727051], portf_value = 905.8931274414062
# 2023-10-17 portf_value = 905.8931274414062
# ...
# next_date_n SPY portf value =    779.9986267089844
# ====================
#
# date = 2018-08-16, l_syms = ['MOH'], ar_price = [134.1499939], ar_shares = [7.], ar_value = [939.04995728], portf_value = 939.0499572753906
# 2018-08-16 portf_value = 939.0499572753906
# date = 2018-08-16, l_syms = ['SPY'], ar_price = [259.0874939], ar_shares = [3.], ar_value = [777.26248169], portf_value = 777.2624816894531
# 2018-08-16 portf_value = 777.2624816894531
# next_date_n pick's portf value = 939.0499572753906
# next_date_n SPY portf value =    777.2624816894531
# ====================
#
# date = 2018-08-16, l_syms = ['SHV', 'TNDM'], ar_price = [99.97917175 33.90999985], ar_shares = [ 5. 15.], ar_value = [499.89585876 508.64999771], portf_value = 1008.5458564758301
# 2018-08-16 portf_value = 1008.5458564758301
# date = 2018-08-16, l_syms = ['SPY'], ar_price = [259.0874939], ar_shares = [3.], ar_value = [777.26248169], portf_value = 777.2624816894531
# 2018-08-16 portf_value = 777.2624816894531
# next_date_n pick's portf value = 1008.5458564758301
# next_date_n SPY portf value =    777.2624816894531
# ====================
#
# date = 2018-08-15, l_syms = ['MOH', 'SHV'], ar_price = [134.00999451  99.9701004 ], ar_shares = [3. 5.], ar_value = [402.02998352 499.85050201], portf_value = 901.880485534668
# 2018-08-15 portf_value = 901.880485534668
# date = 2018-08-15, l_syms = ['SPY'], ar_price = [257.00787354], ar_shares = [3.], ar_value = [771.02362061], portf_value = 771.0236206054688
# 2018-08-15 portf_value = 771.0236206054688
# next_date_n pick's portf value = 901.880485534668
# next_date_n SPY portf value =    771.0236206054688
# ====================
#
# date = 2018-08-14, l_syms = ['MOH', 'SHV'], ar_price = [133.91999817  99.9701004 ], ar_shares = [3. 5.], ar_value = [401.75999451 499.85050201], portf_value = 901.6104965209961
# 2018-08-14 portf_value = 901.6104965209961
# date = 2018-08-14, l_syms = ['SPY'], ar_price = [258.9414978], ar_shares = [3.], ar_value = [776.82449341], portf_value = 776.8244934082031
# 2018-08-14 portf_value = 776.8244934082031
# next_date_n pick's portf value = 901.6104965209961
# next_date_n SPY portf value =    776.8244934082031
# ====================
#
# date = 2018-08-13, l_syms = ['SHV'], ar_price = [99.95199585], ar_shares = [10.], ar_value = [999.5199585], portf_value = 999.5199584960938
# 2018-08-13 portf_value = 999.5199584960938
# date = 2018-08-13, l_syms = ['SPY'], ar_price = [257.29974365], ar_shares = [3.], ar_value = [771.89923096], portf_value = 771.8992309570312
# 2018-08-13 portf_value = 771.8992309570312
# next_date_n pick's portf value = 999.5199584960938
# next_date_n SPY portf value =    771.8992309570312
# ====================
#
# date = 2018-08-10, l_syms = ['SHV'], ar_price = [99.96105957], ar_shares = [10.], ar_value = [999.6105957], portf_value = 999.610595703125
# 2018-08-10 portf_value = 999.610595703125
# date = 2018-08-10, l_syms = ['SPY'], ar_price = [258.2666626], ar_shares = [3.], ar_value = [774.79998779], portf_value = 774.7999877929688
# 2018-08-10 portf_value = 774.7999877929688
# next_date_n pick's portf value = 999.610595703125
# next_date_n SPY portf value =    774.7999877929688
# ====================
#
# date = 2018-08-09, l_syms = ['SHV'], ar_price = [99.94297028], ar_shares = [10.], ar_value = [999.42970276], portf_value = 999.4297027587891
# 2018-08-09 portf_value = 999.4297027587891
# date = 2018-08-09, l_syms = ['SPY'], ar_price = [260.00869751], ar_shares = [3.], ar_value = [780.02609253], portf_value = 780.0260925292969
# 2018-08-09 portf_value = 780.0260925292969
# next_date_n pick's portf value = 999.4297027587891
# next_date_n SPY portf value =    780.0260925292969
# ====================
#
# date = 2018-08-09, l_syms = ['TNDM'], ar_price = [31.44000053], ar_shares = [30.], ar_value = [943.20001602], portf_value = 943.2000160217285
# 2018-08-09 portf_value = 943.2000160217285
# date = 2018-08-09, l_syms = ['SPY'], ar_price = [260.00869751], ar_shares = [3.], ar_value = [780.02609253], portf_value = 780.0260925292969
# 2018-08-09 portf_value = 780.0260925292969
# next_date_n pick's portf value = 943.2000160217285
# next_date_n SPY portf value =    780.0260925292969
# ====================
#
# date = 2018-08-08, l_syms = ['SHV'], ar_price = [99.92479706], ar_shares = [10.], ar_value = [999.24797058], portf_value = 999.2479705810547
# 2018-08-08 portf_value = 999.2479705810547
# date = 2018-08-08, l_syms = ['SPY'], ar_price = [260.36437988], ar_shares = [3.], ar_value = [781.09313965], portf_value = 781.0931396484375
# 2018-08-08 portf_value = 781.0931396484375
# next_date_n pick's portf value = 999.2479705810547
# next_date_n SPY portf value =    781.0931396484375
# ====================
#
# date = 2018-08-08, l_syms = ['TNDM'], ar_price = [30.29999924], ar_shares = [30.], ar_value = [908.99997711], portf_value = 908.9999771118164
# 2018-08-08 portf_value = 908.9999771118164
# date = 2018-08-08, l_syms = ['SPY'], ar_price = [260.36437988], ar_shares = [3.], ar_value = [781.09313965], portf_value = 781.0931396484375
# 2018-08-08 portf_value = 781.0931396484375
# next_date_n pick's portf value = 908.9999771118164
# next_date_n SPY portf value =    781.0931396484375
# ====================
#
# date = 2018-08-07, l_syms = ['SHV'], ar_price = [99.92479706], ar_shares = [10.], ar_value = [999.24797058], portf_value = 999.2479705810547
# 2018-08-07 portf_value = 999.2479705810547
# date = 2018-08-07, l_syms = ['SPY'], ar_price = [260.47387695], ar_shares = [3.], ar_value = [781.42163086], portf_value = 781.421630859375
# 2018-08-07 portf_value = 781.421630859375
# next_date_n pick's portf value = 999.2479705810547
# next_date_n SPY portf value =    781.421630859375
# ====================
#
# date = 2018-08-07, l_syms = ['NTRA', 'TNDM'], ar_price = [24.21999931 30.75      ], ar_shares = [20. 15.], ar_value = [484.39998627 461.25      ], portf_value = 945.6499862670898
# 2018-08-07 portf_value = 945.6499862670898
# date = 2018-08-07, l_syms = ['SPY'], ar_price = [260.47387695], ar_shares = [3.], ar_value = [781.42163086], portf_value = 781.421630859375
# 2018-08-07 portf_value = 781.421630859375
# next_date_n pick's portf value = 945.6499862670898
# next_date_n SPY portf value =    781.421630859375
# ====================
#
# date = 2018-08-06, l_syms = ['NTRA', 'SHV', 'TNDM'], ar_price = [23.73999977 99.9157486  32.33000183], ar_shares = [13.  3. 11.], ar_value = [308.61999702 299.74724579 355.63002014], portf_value = 963.9972629547119
# 2018-08-06 portf_value = 963.9972629547119
# date = 2018-08-06, l_syms = ['SPY'], ar_price = [259.6164856], ar_shares = [3.], ar_value = [778.84945679], portf_value = 778.8494567871094
# 2018-08-06 portf_value = 778.8494567871094
# next_date_n pick's portf value = 963.9972629547119
# next_date_n SPY portf value =    778.8494567871094
# ====================
#
# date = 2018-08-03, l_syms = ['SHV'], ar_price = [99.92479706], ar_shares = [10.], ar_value = [999.24797058], portf_value = 999.2479705810547
# 2018-08-03 portf_value = 999.2479705810547
# date = 2018-08-03, l_syms = ['SPY'], ar_price = [258.6678772], ar_shares = [3.], ar_value = [776.00363159], portf_value = 776.0036315917969
# 2018-08-03 portf_value = 776.0036315917969
# next_date_n pick's portf value = 999.2479705810547
# next_date_n SPY portf value =    776.0036315917969
# ====================
#
# date = 2018-08-03, l_syms = ['NTRA'], ar_price = [23.63999939], ar_shares = [43.], ar_value = [1016.51997375], portf_value = 1016.5199737548828
# 2018-08-03 portf_value = 1016.5199737548828
# date = 2018-08-03, l_syms = ['SPY'], ar_price = [258.6678772], ar_shares = [3.], ar_value = [776.00363159], portf_value = 776.0036315917969
# 2018-08-03 portf_value = 776.0036315917969
# next_date_n pick's portf value = 1016.5199737548828
# next_date_n SPY portf value =    776.0036315917969
# ====================
#
# date = 2018-08-02, l_syms = ['ARWR', 'NTRA'], ar_price = [15.31999969 23.85000038], ar_shares = [35. 22.], ar_value = [536.19998932 524.70000839], portf_value = 1060.8999977111816
# 2018-08-02 portf_value = 1060.8999977111816
# date = 2018-08-02, l_syms = ['SPY'], ar_price = [257.56433105], ar_shares = [3.], ar_value = [772.69299316], portf_value = 772.6929931640625
# 2018-08-02 portf_value = 772.6929931640625
# next_date_n pick's portf value = 1060.8999977111816
# next_date_n SPY portf value =    772.6929931640625
# ====================
#
# date = 2018-08-01, l_syms = ['ARWR', 'NTRA', 'SHV', 'TNDM'], ar_price = [15.14000034 24.07999992 99.88858795 28.56999969], ar_shares = [15. 10.  2.  9.], ar_value = [227.10000515 240.79999924 199.7771759  257.12999725], portf_value = 924.8071775436401
# 2018-08-01 portf_value = 924.8071775436401
# date = 2018-08-01, l_syms = ['SPY'], ar_price = [256.16879272], ar_shares = [3.], ar_value = [768.50637817], portf_value = 768.5063781738281
# 2018-08-01 portf_value = 768.5063781738281
# next_date_n pick's portf value = 924.8071775436401
# next_date_n SPY portf value =    768.5063781738281
# ====================
#
# date = 2018-07-31, l_syms = ['ARWR', 'TNDM'], ar_price = [14.56999969 27.55999947], ar_shares = [28. 18.], ar_value = [407.95999146 496.07999039], portf_value = 904.039981842041
# 2018-07-31 portf_value = 904.039981842041
# date = 2018-07-31, l_syms = ['SPY'], ar_price = [256.59744263], ar_shares = [3.], ar_value = [769.79232788], portf_value = 769.7923278808594
# 2018-07-31 portf_value = 769.7923278808594
# next_date_n pick's portf value = 904.039981842041
# next_date_n SPY portf value =    769.7923278808594
# ====================
#
# date = 2018-07-30, l_syms = ['ARWR', 'SHV', 'TNDM'], ar_price = [14.         99.87504578 24.84000015], ar_shares = [19.  3. 12.], ar_value = [266.         299.62513733 298.08000183], portf_value = 863.7051391601562
# 2018-07-30 portf_value = 863.7051391601562
# date = 2018-07-30, l_syms = ['SPY'], ar_price = [255.33872986], ar_shares = [3.], ar_value = [766.01618958], portf_value = 766.0161895751953
# 2018-07-30 portf_value = 766.0161895751953
# next_date_n pick's portf value = 863.7051391601562
# next_date_n SPY portf value =    766.0161895751953
# ====================
#
# date = 2018-07-27, l_syms = ['ARWR', 'TNDM'], ar_price = [16.06999969 25.60000038], ar_shares = [30. 18.], ar_value = [482.09999084 460.80000687], portf_value = 942.8999977111816
# 2018-07-27 portf_value = 942.8999977111816
# date = 2018-07-27, l_syms = ['SPY'], ar_price = [256.67956543], ar_shares = [3.], ar_value = [770.03869629], portf_value = 770.0386962890625
# 2018-07-27 portf_value = 770.0386962890625
# next_date_n pick's portf value = 942.8999977111816
# next_date_n SPY portf value =    770.0386962890625
# ====================
#
# date = 2018-07-26, l_syms = ['ARWR', 'TNDM'], ar_price = [17.44000053 26.95999908], ar_shares = [30. 17.], ar_value = [523.20001602 458.31998444], portf_value = 981.5200004577637
# 2018-07-26 portf_value = 981.5200004577637
# date = 2018-07-26, l_syms = ['SPY'], ar_price = [258.43075562], ar_shares = [3.], ar_value = [775.29226685], portf_value = 775.2922668457031
# 2018-07-26 portf_value = 775.2922668457031
# next_date_n pick's portf value = 981.5200004577637
# next_date_n SPY portf value =    775.2922668457031
# ====================
#
# date = 2018-07-25, l_syms = ['ARWR', 'TNDM'], ar_price = [16.88999939 27.45999908], ar_shares = [31. 18.], ar_value = [523.58998108 494.27998352], portf_value = 1017.8699645996094
# 2018-07-25 portf_value = 1017.8699645996094
# date = 2018-07-25, l_syms = ['SPY'], ar_price = [259.04190063], ar_shares = [3.], ar_value = [777.1257019], portf_value = 777.1257019042969
# 2018-07-25 portf_value = 777.1257019042969
# next_date_n pick's portf value = 1017.8699645996094
# next_date_n SPY portf value =    777.1257019042969
# ====================
#
# date = 2018-07-24, l_syms = ['TNDM'], ar_price = [26.51000023], ar_shares = [37.], ar_value = [980.87000847], portf_value = 980.8700084686279
# 2018-07-24 portf_value = 980.8700084686279
# date = 2018-07-24, l_syms = ['SPY'], ar_price = [256.85284424], ar_shares = [3.], ar_value = [770.55853271], portf_value = 770.5585327148438
# 2018-07-24 portf_value = 770.5585327148438
# next_date_n pick's portf value = 980.8700084686279
# next_date_n SPY portf value =    770.5585327148438
# ====================
#
# date = 2018-07-23, l_syms = ['ARWR', 'TNDM'], ar_price = [16.51000023 28.12999916], ar_shares = [29. 19.], ar_value = [478.79000664 534.46998405], portf_value = 1013.2599906921387
# 2018-07-23 portf_value = 1013.2599906921387
# date = 2018-07-23, l_syms = ['SPY'], ar_price = [255.56677246], ar_shares = [3.], ar_value = [766.70031738], portf_value = 766.7003173828125
# 2018-07-23 portf_value = 766.7003173828125
# next_date_n pick's portf value = 1013.2599906921387
# next_date_n SPY portf value =    766.7003173828125
# ====================
#
# date = 2018-07-20, l_syms = ['TNDM'], ar_price = [26.88999939], ar_shares = [37.], ar_value = [994.92997742], portf_value = 994.9299774169922
# 2018-07-20 portf_value = 994.9299774169922
# date = 2018-07-20, l_syms = ['SPY'], ar_price = [255.09248352], ar_shares = [3.], ar_value = [765.27745056], portf_value = 765.2774505615234
# 2018-07-20 portf_value = 765.2774505615234
# next_date_n pick's portf value = 994.9299774169922
# next_date_n SPY portf value =    765.2774505615234
# ====================
#
# date = 2018-07-19, l_syms = ['TNDM'], ar_price = [26.61000061], ar_shares = [37.], ar_value = [984.57002258], portf_value = 984.5700225830078
# 2018-07-19 portf_value = 984.5700225830078
# date = 2018-07-19, l_syms = ['SPY'], ar_price = [255.38441467], ar_shares = [3.], ar_value = [766.15324402], portf_value = 766.1532440185547
# 2018-07-19 portf_value = 766.1532440185547
# next_date_n pick's portf value = 984.5700225830078
# next_date_n SPY portf value =    766.1532440185547
# ====================
#
# date = 2018-07-18, l_syms = ['TNDM'], ar_price = [26.13999939], ar_shares = [38.], ar_value = [993.31997681], portf_value = 993.3199768066406
# 2018-07-18 portf_value = 993.3199768066406
# date = 2018-07-18, l_syms = ['SPY'], ar_price = [256.35125732], ar_shares = [3.], ar_value = [769.05377197], portf_value = 769.0537719726562
# 2018-07-18 portf_value = 769.0537719726562
# next_date_n pick's portf value = 993.3199768066406
# next_date_n SPY portf value =    769.0537719726562
# ====================
#
# date = 2018-07-17, l_syms = ['TNDM'], ar_price = [27.], ar_shares = [39.], ar_value = [1053.], portf_value = 1053.0
# 2018-07-17 portf_value = 1053.0
# date = 2018-07-17, l_syms = ['SPY'], ar_price = [255.81306458], ar_shares = [3.], ar_value = [767.43919373], portf_value = 767.4391937255859
# 2018-07-17 portf_value = 767.4391937255859
# next_date_n pick's portf value = 1053.0
# next_date_n SPY portf value =    767.4391937255859
# ====================
#
# date = 2018-07-16, l_syms = ['TNDM'], ar_price = [26.93000031], ar_shares = [41.], ar_value = [1104.13001251], portf_value = 1104.130012512207
# 2018-07-16 portf_value = 1104.130012512207
# date = 2018-07-16, l_syms = ['SPY'], ar_price = [254.78239441], ar_shares = [3.], ar_value = [764.34718323], portf_value = 764.3471832275391
# 2018-07-16 portf_value = 764.3471832275391
# next_date_n pick's portf value = 1104.130012512207
# next_date_n SPY portf value =    764.3471832275391
# ====================
#
# date = 2018-07-13, l_syms = ['TNDM'], ar_price = [25.88999939], ar_shares = [43.], ar_value = [1113.26997375], portf_value = 1113.2699737548828
# 2018-07-13 portf_value = 1113.2699737548828
# date = 2018-07-13, l_syms = ['SPY'], ar_price = [255.01042175], ar_shares = [3.], ar_value = [765.03126526], portf_value = 765.0312652587891
# 2018-07-13 portf_value = 765.0312652587891
# next_date_n pick's portf value = 1113.2699737548828
# next_date_n SPY portf value =    765.0312652587891
# ====================
#
# date = 2018-07-12, l_syms = ['TNDM'], ar_price = [25.45000076], ar_shares = [43.], ar_value = [1094.35003281], portf_value = 1094.3500328063965
# 2018-07-12 portf_value = 1094.3500328063965
# date = 2018-07-12, l_syms = ['SPY'], ar_price = [254.80978394], ar_shares = [3.], ar_value = [764.42935181], portf_value = 764.4293518066406
# 2018-07-12 portf_value = 764.4293518066406
# next_date_n pick's portf value = 1094.3500328063965
# next_date_n SPY portf value =    764.4293518066406
# ====================

# %%
"""
Adds calculated portfolio values, performance metrics, and a comparison to SPY to the df_picks_mp DataFrame.
"""

# Add columns for portfolio sell information:
df_picks_mp['date_sell'] = date_exec  # Date of portfolio sale
df_picks_mp['sh_portf_sell'] = shares_syms  # Number of shares sold for each symbol
df_picks_mp['$_portf_sell'] = value_portf  # Total value of the portfolio at sale

# Calculate percentage change for the portfolio:
df_picks_mp['%_portf_chg'] = (df_picks_mp['$_portf_sell'] / df_picks_mp['$_portf_buy'] - 1) * 100

# Add columns for SPY sell information:
df_picks_mp['sh_SPY_sell'] = shares_SPY  # Number of SPY shares sold
df_picks_mp['$_SPY_sell'] = value_SPY  # Total value of SPY at sale

# Calculate percentage change for SPY:
df_picks_mp['%_SPY_chg'] = (df_picks_mp['$_SPY_sell'] / df_picks_mp['$_SPY_buy'] - 1) * 100

# Calculate the difference in percentage change between the portfolio and SPY:
df_picks_mp['dif_%_chg'] = df_picks_mp['%_portf_chg'] - df_picks_mp['%_SPY_chg']

# %%
"""
Adds a "win" column to indicate outperformance of SPY and displays the first 20 rows of the DataFrame.
"""

# Add a "win" column to indicate whether the portfolio outperformed SPY:
df_picks_mp['win'] = np.where(df_picks_mp['dif_%_chg'] > 0, 1, 0)  # 1 for outperformance, 0 otherwise

# Display the first 20 rows of the DataFrame for review:
df_picks_mp.head(20)  # Show the initial rows with the added columns
# Out:
#           date      days_lookback    syms_freq                  symbols    date_buy     sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell    sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0   2024-01-09      [30, 60, 120]   sym_freq_9                 ['CYTK']        None             None          NaN       None         NaN        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 1   2024-01-09      [30, 60, 120]   sym_freq_8          ['FTSM', 'SHV']        None             None          NaN       None         NaN        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 2   2024-01-09  [15, 30, 60, 120]  sym_freq_12                 ['CYTK']        None             None          NaN       None         NaN        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 3   2024-01-08      [30, 60, 120]   sym_freq_9                 ['CYTK']  2024-01-09            [9.0]   917.730011      [2.0]  947.760010        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 4   2024-01-08      [30, 60, 120]   sym_freq_8          ['FTSM', 'SHV']  2024-01-09       [8.0, 4.0]   918.720001      [2.0]  947.760010        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 5   2024-01-08  [15, 30, 60, 120]  sym_freq_12                 ['CYTK']  2024-01-09            [9.0]   917.730011      [2.0]  947.760010        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 6   2024-01-05      [30, 60, 120]   sym_freq_9                 ['CYTK']  2024-01-08            [9.0]   972.539978      [2.0]  949.200012        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 7   2024-01-05      [30, 60, 120]   sym_freq_8          ['FTSM', 'SHV']  2024-01-08       [8.0, 4.0]   918.519989      [2.0]  949.200012        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 8   2024-01-05  [15, 30, 60, 120]  sym_freq_12                 ['CYTK']  2024-01-08            [9.0]   972.539978      [2.0]  949.200012        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 9   2024-01-04      [30, 60, 120]   sym_freq_9                 ['CYTK']  2024-01-05           [10.0]   937.300034      [2.0]  935.840027        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 10  2024-01-04      [30, 60, 120]   sym_freq_8          ['FTSM', 'SHV']  2024-01-05       [8.0, 4.0]   918.360016      [2.0]  935.840027        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 11  2024-01-04  [15, 30, 60, 120]  sym_freq_12                 ['CYTK']  2024-01-05           [10.0]   937.300034      [2.0]  935.840027        None             None           NaN          NaN        None         NaN        NaN        NaN    0
# 12  2024-01-03      [30, 60, 120]   sym_freq_8  ['CYTK', 'FTSM', 'SHV']  2024-01-04  [3.0, 5.0, 3.0]   893.709988      [2.0]  934.559998  2024-01-09  [3.0, 5.0, 3.0]    935.220005     4.644685       [2.0]  947.760010   1.412431   3.232255    1
# 13  2024-01-02      [30, 60, 120]   sym_freq_8          ['CYTK', 'SHV']  2024-01-03       [5.0, 4.0]   873.719986      [2.0]  937.580017  2024-01-08       [5.0, 4.0]    981.139984    12.294557       [2.0]  949.200012   1.239360  11.055196    1
# 14  2023-12-29      [30, 60, 120]   sym_freq_8          ['CYTK', 'SHV']  2024-01-02       [5.0, 4.0]   861.080025      [2.0]  945.299988  2024-01-05       [5.0, 4.0]    909.410027     5.612719       [2.0]  935.840027  -1.000736   6.613455    1
# 15  2023-12-28      [30, 60, 120]   sym_freq_8          ['CYTK', 'SHV']  2023-12-29       [5.0, 4.0]   857.969978      [2.0]  950.619995  2024-01-04       [5.0, 4.0]    881.919991     2.791474       [2.0]  934.559998  -1.689423   4.480898    1
# 16  2023-12-27      [30, 60, 120]   sym_freq_8          ['CYTK', 'SHV']  2023-12-28       [6.0, 4.0]   939.839981      [2.0]  953.380005  2024-01-03       [6.0, 4.0]    960.359985     2.183351       [2.0]  937.580017  -1.657260   3.840611    1
# 17  2023-12-26      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-12-27            [9.0]   990.269989      [2.0]  953.020020  2024-01-02            [9.0]    991.080025     0.081799       [2.0]  945.299988  -0.810060   0.891859    1
# 18  2023-12-22      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-12-26            [9.0]   990.269989      [2.0]  951.299988  2023-12-29            [9.0]    991.169975     0.090883       [2.0]  950.619995  -0.071480   0.162363    1
# 19  2023-12-21      [30, 60, 120]   sym_freq_8                  ['SHV']  2023-12-22            [9.0]   990.090019      [2.0]  947.299988  2023-12-28            [9.0]    990.899986     0.081807       [2.0]  953.380005   0.641826  -0.560019    0

# %% [markdown]
# #### Model Performance Not Good

# %%
"""
Calculates win rate and overall performance relative to SPY.
"""

# Count the number of wins (outperformances of SPY):
wins = df_picks_mp['win'].sum()  # Sum the "win" column to get the total wins

# Count the number of valid attempts (excluding missing data):
attempts = len(df_picks_mp['dif_%_chg'].dropna())  # Count rows with non-null values in 'dif_%_chg'

# Calculate the win rate:
win_rate = wins / attempts  # Divide wins by attempts to get the win rate

# Print the win rate, wins, and attempts:
print(f'win_rate: {win_rate:0.6f}, wins: {wins}, attempts: {attempts}')

# Print the overall difference in percentage change between the portfolio and SPY:
print(f'sum(df_picksf_%_chg): {df_picks_mp["dif_%_chg"].sum():0.6f}')  # Sums the differences to indicate overall outperformance or underperformance
# Out:
# win_rate: 0.497608, wins: 728, attempts: 1463
# sum(df_picksf_%_chg): 16.538105
