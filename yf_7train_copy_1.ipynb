# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump, delete_all_rows
from yf_utils import split_train_val_test, random_slices, lookback_slices
from yf_utils import eval_grp_top_syms_n_freq
from yf_utils import top_set_sym_freq_cnt, get_grp_top_syms_n_freq
# from yf_utils import top_set_sym_freq_cnt, get_grp_top_syms_n_freq_v1


pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.width", 500)  # code-runner format

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"

path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = "df_close_clean"

# %% [markdown]
# ### Run below cell for Colab

# %%
#######################################################################
## SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# select run type
# run_type = "train"
# run_type = 'validate'
run_type = "test"

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms
# n_samples = 400
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
days_lookbacks = [15, 30, 60]
# days_lookbacks = [30, 60, 120]
# days_lookbacks = [15, 30, 60, 120]
days_lookbacks.sort()

# number of days in dataframe to evaluate effectiveness of the training, days_eval = len(df_eval)
#  days_eval = 4 means buy at close on 1st day after the signal, hold for 2nd and 3rd day, sell at close on 4th day
days_eval = 4
# days_eval = 5

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20
# n_top_syms = 5

# slice starts and ends for selecting the best performing symbols
# syms_start = 1, syms_end = 11 will keep the 2nd to 11th best performing symbols  
syms_start = 0
syms_end = 10


##########################################################
fp_df_eval_results = f"df_eval_results_{run_type}"
# fp_df_eval_results = "test_df_eval"
##########################################################

#### Delete all rows in df_eval_results ##################
delete_all_rows(path_data_dump, fp_df_eval_results)
##########################################################

# %%
print(f'path_data_dump: {path_data_dump}')
print(f"verbose : {verbose }")
print(f"store_results: {store_results}")
print(f"run_type: {run_type}")
print(f"n_samples: {n_samples}")
print(f"days_lookbacks: {days_lookbacks}")
print(f"days_eval: {days_eval}")
print(f"n_top_syms: {n_top_syms}")
print(f"syms_start: {syms_start}")
print(f"syms_end: {syms_end}")
print(f"filename of run results: {fp_df_eval_results}")

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = split_train_val_test(df_close_clean)
# Out:
# path_data_dump: C:/Users/ping/MyDrive/stocks/yfinance/VSCode_dump/
# verbose : True
# store_results: True
# run_type: test
# n_samples: 2
# days_lookbacks: [15, 30, 60]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10
# filename of run results: df_eval_results_test

# %%
# max_days_lookbacks = max(days_lookbacks)
# print(f"max_days_lookbacks: {max_days_lookbacks}")

# Load df according to run_type
if run_type == "train":
    df = df_train.copy()
elif run_type == "validate":
    df = df_val.copy()
elif run_type == "test":
    df = df_test.copy()
else:
    msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop)

# Print dataframe for the run, and lengths of other dataframes
print(f"run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n")
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f"run_type: {run_type}, len(df): {len(df)}")
print(
    f"len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}"
)

# return n_samples slices
random_max_lookback_tuples = random_slices(
    len_df,
    n_samples=n_samples,
    days_lookback=max(days_lookbacks),
    days_eval=days_eval,
    verbose=False,
)
# return n_samples * len(days_lookbacks) slices
list_random_lookback_slices = lookback_slices(
    max_slices=random_max_lookback_tuples, days_lookbacks=days_lookbacks, verbose=False
)
# Out:
# run_type: test, df.tail(3):
#                      A         AA    AAL        AAP        AAPL         AB        ABBV    ABR         ABT       ACGL       ACHC   ACIW        ACLS  ACRS        ADBE  ...         XYL       YELP         YUM       YUMC     YY         ZBH        ZBRA         ZD         ZG       ZION          ZS        ZTO         ZTS   ZUMZ        ZWS
# Date                                                                                                                                                                  ...
# 2024-03-06  146.220001  28.219999  14.88  71.900002  169.119995  33.840000  181.059998  12.80  119.339996  88.820000  84.720001  31.25  113.209999  1.44  543.090027  ...  126.349998  37.869999  139.550003  41.720001  31.91  125.830002  287.269989  66.879997  54.029999  41.299999  202.419998  20.440001  183.529999  16.32  31.400000
# 2024-03-07  149.309998  29.870001  14.90  73.680000  169.000000  34.000000  180.570007  12.91  120.919998  87.690002  83.660004  31.51  118.629997  1.35  556.039978  ...  126.970001  38.130001  140.380005  41.099998  31.68  127.360001  288.589996  67.150002  54.060001  41.520000  201.270004  20.070000  181.509995  16.10  32.029999
# 2024-03-08  147.869995  29.850000  14.68  73.080002  170.729996  33.830002  178.850006  12.86  120.959999  87.610001  81.809998  32.09  111.910004  1.41  551.690002  ...  127.080002  38.290001  139.559998  41.250000  29.49  126.739998  282.589996  66.769997  56.150002  42.240002  198.690002  20.139999  182.160004  16.18  31.969999
#
# [3 rows x 1263 columns]
#
# run_type: test, len(df): 150
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %% [markdown]
# ### Run below cell to use test data to debug code, results should match yf_test.ipynb

# %%
# ####### RUN THIS CELL TO USE TEST DATA TO DEBUG CODE, RESULTS SHOULD MATCH yf_test.ipynb ################# 

# # load test data to debug code if needed
# test_dic = pickle_load(path_data_dump, 'yf_test_dic')
# for i, key in enumerate(test_dic.keys()):
#   print(f'{i}: {key}')

# # convert dictionary entries into variables
# locals().update(test_dic)
# del df_eval_results  # delete df_eval_results loaded from locals().update(test_dic)

# # Delete all rows in df_eval_results
# delete_all_rows(path_data_dump, fp_df_eval_results)

# %%
max_days_lookbacks = max(days_lookbacks)
print(f"days_lookbacks: {days_lookbacks}")
print(f"max_days_lookbacks: {max_days_lookbacks}")

if verbose:
    print(f"number of random_max_lookback_tuples is equal to n_samples = {n_samples}")
    print(f"The {n_samples} random_max_lookback_tuples:\n{random_max_lookback_tuples}\n")
    print(f"number of lists in list_random_lookback_slices is equal to n_samples = {n_samples}")
    print(f"list_random_lookback_slices corresponds to:\n - n_samples = {n_samples}\n - days_lookbacks: {days_lookbacks}\n - days_eval: {days_eval}")
    print(f"list_random_lookback_slices:\n{list_random_lookback_slices}\n")
    print(f"days_lookbacks: {days_lookbacks}")
    print(
        f'number of tuples in each list in list_random_lookback_slices is equal to len(days_lookbacks): {len(days_lookbacks)}'
    )

# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the random_max_lookback_tuples. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in random_max_lookback_tuples. There are as many sub-lists as there are tuples in random_max_lookback_tuples.
grp_top_set_syms_n_freq, grp_top_set_syms, dates_end_df_train = get_grp_top_syms_n_freq(
    df, list_random_lookback_slices, days_lookbacks, n_top_syms, syms_start, syms_end, verbose
)

# #### print the best performing symbols for each set in list_random_lookback_slices
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
    l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
    if verbose:
        print(f"random_max_lookback_tuples:      {random_max_lookback_tuples}")
        # print(f'set_lookback_slices: {list_random_lookback_slices[i]}\n')
        print(
            f"set_lookback_slices {i + 1} of {len(list_random_lookback_slices):>3}:    {list_random_lookback_slices[i]}\n"
        )
        print(f"max_days_lookbacks:              {max_days_lookbacks}")
        print(f"df end date for days_lookbacks:  {dates_end_df_train[i]}")
        print(f"days_lookbacks:                  {days_lookbacks}")
        print(f"sym_freq_15:                     {l_sym_freq_cnt[0]}")
        print(f"sym_freq_14:                     {l_sym_freq_cnt[1]}")
        print(f"sym_freq_13:                     {l_sym_freq_cnt[2]}")
        print(f"sym_freq_12:                     {l_sym_freq_cnt[3]}")
        print(f"sym_freq_11:                     {l_sym_freq_cnt[4]}")
        print(f"sym_freq_10:                     {l_sym_freq_cnt[5]}")
        print(f"sym_freq_9:                      {l_sym_freq_cnt[6]}")
        print(f"sym_freq_8:                      {l_sym_freq_cnt[7]}")
        print(f"sym_freq_7:                      {l_sym_freq_cnt[8]}")
        print(f"sym_freq_6:                      {l_sym_freq_cnt[9]}")
        print(f"sym_freq_5:                      {l_sym_freq_cnt[10]}")
        print(f"sym_freq_4:                      {l_sym_freq_cnt[11]}")
        print(f"sym_freq_3:                      {l_sym_freq_cnt[12]}")
        print(f"sym_freq_2:                      {l_sym_freq_cnt[13]}\n")


# #### Evaluate performance of symbols in set_lookback_slices versus SPY
l_row_add_total = eval_grp_top_syms_n_freq(
    df, random_max_lookback_tuples, list_random_lookback_slices, grp_top_set_syms_n_freq, days_lookbacks, days_eval, n_samples, n_top_syms, syms_start, syms_end, verbose
)

for row_add_total in l_row_add_total:
    print(f"row_add_total: {row_add_total}")

if store_results:  # record results to df
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results BEFORW store results:\n{df_eval_results}\n")

    for row_add_total in l_row_add_total:
        # print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f"appended row_add_total to df_eval_results:\n{row_add_total}\n")

    pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
    print(f"Save results to: {fp_df_eval_results}")
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results AFTER store results:\n{df_eval_results}\n")
# Out:
# days_lookbacks: [15, 30, 60]
# max_days_lookbacks: 60
# number of random_max_lookback_tuples is equal to n_samples = 2
# The 2 random_max_lookback_tuples:
# [(17, 77, 81), (38, 98, 102)]
#
# number of lists in list_random_lookback_slices is equal to n_samples = 2
# list_random_lookback_slices corresponds to:
#  - n_samples = 2
#  - days_lookbacks: [15, 30, 60]
#  - days_eval: 4
# list_random_lookback_slices:
# [[(62, 77, 81), (47, 77, 81), (17, 77, 81)], [(83, 98, 102), (68, 98, 102), (38, 98, 102)]]
#
# days_lookbacks: [15, 30, 60]
# number of tuples in each list in list_random_lookback_slices is equal to len(days_lookbacks): 3
#
# ########## 1 of 2 lb_slices: [(62, 77, 81), (47, 77, 81), (17, 77, 81)] in list_random_lookback_slices ##########
# days lookback:       15,  1 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(62, 77, 81), (47, 77, 81), (17, 77, 81)]
# lb_slice:            (62, 77, 81)
# days eval:           4
# iloc_start_train:    62
# iloc_end_train:      77
# date_start_df_train: 2023-11-01
# date_end_df_train:   2023-11-21
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['AXGN', 'RGNX', 'SQ', 'EXPE', 'CYRX', 'SHOP', 'GDDY', 'TRU',
#        'CRSP', 'GPS', 'EFX', 'GIL', 'IT', 'BURL', 'PRAA', 'PI', 'STKL',
#        'NTRA', 'MCO', 'SPGI'], dtype=object), 'r_CAGR/retnStd': array(['AXGN', 'CRSP', 'SQ', 'EXPE', 'RGNX', 'GPS', 'CYRX', 'PRAA',
#        'SHOP', 'SGRY', 'TRU', 'NTRA', 'BURL', 'PI', 'FIVN', 'TRIP',
#        'STKL', 'BLFS', 'CHGG', 'HASI'], dtype=object), 'r_retnStd/UI': array(['GDDY', 'SPGI', 'MSI', 'MCO', 'EFX', 'GIL', 'IR', 'IT', 'PH',
#        'SHV', 'ADX', 'RGNX', 'BUD', 'NMZ', 'RACE', 'HWM', 'NFLX', 'SAP',
#        'APH', 'ITT'], dtype=object)}}
# most_freq_syms: [('RGNX', 3), ('AXGN', 2), ('SQ', 2), ('EXPE', 2), ('CYRX', 2), ('SHOP', 2), ('GDDY', 2), ('TRU', 2), ('CRSP', 2), ('GPS', 2), ('EFX', 2), ('GIL', 2), ('IT', 2), ('BURL', 2), ('PRAA', 2), ('PI', 2), ('STKL', 2), ('NTRA', 2), ('MCO', 2), ('SPGI', 2), ('SGRY', 1), ('FIVN', 1), ('TRIP', 1), ('BLFS', 1), ('CHGG', 1), ('HASI', 1), ('MSI', 1), ('IR', 1), ('PH', 1), ('SHV', 1), ('ADX', 1), ('BUD', 1), ('NMZ', 1), ('RACE', 1), ('HWM', 1), ('NFLX', 1), ('SAP', 1), ('APH', 1), ('ITT', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(62, 77, 81), (47, 77, 81), (17, 77, 81)]
# lb_slice:            (47, 77, 81)
# days eval:           4
# iloc_start_train:    47
# iloc_end_train:      77
# date_start_df_train: 2023-10-11
# date_end_df_train:   2023-11-21
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['SHV', 'GPS', 'STKL', 'PI', 'GBTC', 'SPR', 'OUT', 'DXCM',
#        'BTC-USD', 'TGH', 'FTSM', 'NFLX', 'CMG', 'PLNT', 'LRN', 'CRSP',
#        'HASI', 'VZ', 'AMBC', 'WING'], dtype=object), 'r_CAGR/retnStd': array(['STKL', 'GPS', 'GBTC', 'PI', 'CRSP', 'SPR', 'OUT', 'DXCM', 'HASI',
#        'M', 'BTC-USD', 'PODD', 'VRNS', 'WING', 'SHV', 'DVA', 'CMG', 'TNK',
#        'AMBC', 'NFLX'], dtype=object), 'r_retnStd/UI': array(['SHV', 'TGH', 'FTSM', 'FCN', 'LRN', 'GPS', 'VZ', 'PLNT', 'NFLX',
#        'PI', 'SPR', 'BTC-USD', 'CHE', 'CBOE', 'CMG', 'DECK', 'TXRH',
#        'DGX', 'MCD', 'OUT'], dtype=object)}}
# most_freq_syms: [('SHV', 3), ('GPS', 3), ('PI', 3), ('SPR', 3), ('OUT', 3), ('BTC-USD', 3), ('NFLX', 3), ('CMG', 3), ('STKL', 2), ('GBTC', 2), ('DXCM', 2), ('TGH', 2), ('FTSM', 2), ('PLNT', 2), ('LRN', 2), ('CRSP', 2), ('HASI', 2), ('VZ', 2), ('AMBC', 2), ('WING', 2), ('M', 1), ('PODD', 1), ('VRNS', 1), ('DVA', 1), ('TNK', 1), ('FCN', 1), ('CHE', 1), ('CBOE', 1), ('DECK', 1), ('TXRH', 1), ('DGX', 1), ('MCD', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(62, 77, 81), (47, 77, 81), (17, 77, 81)]
# lb_slice:            (17, 77, 81)
# days eval:           4
# iloc_start_train:    17
# iloc_end_train:      77
# date_start_df_train: 2023-08-29
# date_end_df_train:   2023-11-21
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['SHV', 'FTSM', 'LRN', 'SPLK', 'GPS', 'WING', 'CBOE', 'ANF', 'ALL',
#        'PGR', 'GDDY', 'HIBB', 'EDU', 'NGS', 'GBTC', 'NRG', 'CAH', 'WRB',
#        'BTC-USD', 'USAC'], dtype=object), 'r_CAGR/retnStd': array(['SHV', 'FTSM', 'GPS', 'ANF', 'WING', 'LRN', 'ALL', 'GBTC', 'HIBB',
#        'GDDY', 'EDU', 'RELX', 'ZS', 'CBOE', 'PGR', 'NGS', 'YY', 'NRG',
#        'NTNX', 'CAH'], dtype=object), 'r_retnStd/UI': array(['SHV', 'FTSM', 'SPLK', 'LRN', 'CBOE', 'TGH', 'PGR', 'USAC', 'WING',
#        'GDDY', 'CHE', 'WRB', 'AGYS', 'CAH', 'ALL', 'SHO', 'AIZ', 'NRG',
#        'HMN', 'NGS'], dtype=object)}}
# most_freq_syms: [('SHV', 3), ('FTSM', 3), ('LRN', 3), ('WING', 3), ('CBOE', 3), ('ALL', 3), ('PGR', 3), ('GDDY', 3), ('NGS', 3), ('NRG', 3), ('CAH', 3), ('SPLK', 2), ('GPS', 2), ('ANF', 2), ('HIBB', 2), ('EDU', 2), ('GBTC', 2), ('WRB', 2), ('USAC', 2), ('BTC-USD', 1), ('RELX', 1), ('ZS', 1), ('YY', 1), ('NTNX', 1), ('TGH', 1), ('CHE', 1), ('AGYS', 1), ('SHO', 1), ('AIZ', 1), ('HMN', 1)]
# +++ finish lookback slice 60 +++
#
# grp_most_freq_syms: [[('RGNX', 3), ('AXGN', 2), ('SQ', 2), ('EXPE', 2), ('CYRX', 2), ('SHOP', 2), ('GDDY', 2), ('TRU', 2), ('CRSP', 2), ('GPS', 2), ('EFX', 2), ('GIL', 2), ('IT', 2), ('BURL', 2), ('PRAA', 2), ('PI', 2), ('STKL', 2), ('NTRA', 2), ('MCO', 2), ('SPGI', 2), ('SGRY', 1), ('FIVN', 1), ('TRIP', 1), ('BLFS', 1), ('CHGG', 1), ('HASI', 1), ('MSI', 1), ('IR', 1), ('PH', 1), ('SHV', 1), ('ADX', 1), ('BUD', 1), ('NMZ', 1), ('RACE', 1), ('HWM', 1), ('NFLX', 1), ('SAP', 1), ('APH', 1), ('ITT', 1)], [('SHV', 3), ('GPS', 3), ('PI', 3), ('SPR', 3), ('OUT', 3), ('BTC-USD', 3), ('NFLX', 3), ('CMG', 3), ('STKL', 2), ('GBTC', 2), ('DXCM', 2), ('TGH', 2), ('FTSM', 2), ('PLNT', 2), ('LRN', 2), ('CRSP', 2), ('HASI', 2), ('VZ', 2), ('AMBC', 2), ('WING', 2), ('M', 1), ('PODD', 1), ('VRNS', 1), ('DVA', 1), ('TNK', 1), ('FCN', 1), ('CHE', 1), ('CBOE', 1), ('DECK', 1), ('TXRH', 1), ('DGX', 1), ('MCD', 1)], [('SHV', 3), ('FTSM', 3), ('LRN', 3), ('WING', 3), ('CBOE', 3), ('ALL', 3), ('PGR', 3), ('GDDY', 3), ('NGS', 3), ('NRG', 3), ('CAH', 3), ('SPLK', 2), ('GPS', 2), ('ANF', 2), ('HIBB', 2), ('EDU', 2), ('GBTC', 2), ('WRB', 2), ('USAC', 2), ('BTC-USD', 1), ('RELX', 1), ('ZS', 1), ('YY', 1), ('NTNX', 1), ('TGH', 1), ('CHE', 1), ('AGYS', 1), ('SHO', 1), ('AIZ', 1), ('HMN', 1)]]
# **** finish lookback slices [(62, 77, 81), (47, 77, 81), (17, 77, 81)] ****
#
# top 20 ranked symbols and frequency from set [(62, 77, 81), (47, 77, 81), (17, 77, 81)]:
# [('GPS', 7), ('SHV', 7), ('FTSM', 5), ('GDDY', 5), ('LRN', 5), ('PI', 5), ('WING', 5), ('BTC-USD', 4), ('CBOE', 4), ('CRSP', 4), ('GBTC', 4), ('NFLX', 4), ('STKL', 4), ('ALL', 3), ('CAH', 3), ('CMG', 3), ('HASI', 3), ('NGS', 3), ('NRG', 3), ('OUT', 3)]
# top 20 ranked symbols from set [(62, 77, 81), (47, 77, 81), (17, 77, 81)]:
# ['GPS', 'SHV', 'FTSM', 'GDDY', 'LRN', 'PI', 'WING', 'BTC-USD', 'CBOE', 'CRSP']
# ===== finish top 20 ranked symbols from days_lookback set [(62, 77, 81), (47, 77, 81), (17, 77, 81)] =====
#
#
#
# ########## 2 of 2 lb_slices: [(83, 98, 102), (68, 98, 102), (38, 98, 102)] in list_random_lookback_slices ##########
# days lookback:       15,  1 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(83, 98, 102), (68, 98, 102), (38, 98, 102)]
# lb_slice:            (83, 98, 102)
# days eval:           4
# iloc_start_train:    83
# iloc_end_train:      98
# date_start_df_train: 2023-12-01
# date_end_df_train:   2023-12-21
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['HA', 'MBI', 'MARA', 'SHV', 'STRL', 'PLAB', 'ZG', 'CUTR', 'TNDM',
#        'XRX', 'FFWM', 'COMM', 'AX', 'MOV', 'APPS', 'CM', 'COLL', 'X',
#        'LC', 'WOR'], dtype=object), 'r_CAGR/retnStd': array(['HA', 'MARA', 'MBI', 'CUTR', 'PLAB', 'COMM', 'ZG', 'TNDM', 'STRL',
#        'XRX', 'FFWM', 'APPS', 'NSTG', 'HPP', 'TVTX', 'AX', 'BBWI', 'SMTC',
#        'WOR', 'TEAM'], dtype=object), 'r_retnStd/UI': array(['SHV', 'FAST', 'CM', 'HA', 'STRL', 'MOV', 'MBI', 'BKE', 'COLL',
#        'AX', 'SLM', 'PSA', 'NSA', 'CIGI', 'X', 'LC', 'XRX', 'ANF', 'PLAB',
#        'FFWM'], dtype=object)}}
# most_freq_syms: [('HA', 3), ('MBI', 3), ('STRL', 3), ('PLAB', 3), ('XRX', 3), ('FFWM', 3), ('AX', 3), ('MARA', 2), ('SHV', 2), ('ZG', 2), ('CUTR', 2), ('TNDM', 2), ('COMM', 2), ('MOV', 2), ('APPS', 2), ('CM', 2), ('COLL', 2), ('X', 2), ('LC', 2), ('WOR', 2), ('NSTG', 1), ('HPP', 1), ('TVTX', 1), ('BBWI', 1), ('SMTC', 1), ('TEAM', 1), ('FAST', 1), ('BKE', 1), ('SLM', 1), ('PSA', 1), ('NSA', 1), ('CIGI', 1), ('ANF', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(83, 98, 102), (68, 98, 102), (38, 98, 102)]
# lb_slice:            (68, 98, 102)
# days eval:           4
# iloc_start_train:    68
# iloc_end_train:      98
# date_start_df_train: 2023-11-09
# date_end_df_train:   2023-12-21
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['HA', 'SHV', 'MARA', 'TNDM', 'MBI', 'SQ', 'RUN', 'M', 'ENPH', 'WD',
#        'WOR', 'IBP', 'FFWM', 'NCLH', 'ZG', 'BIG', 'BKE', 'LC', 'AMKR',
#        'XRX'], dtype=object), 'r_CAGR/retnStd': array(['HA', 'MARA', 'TNDM', 'RUN', 'M', 'BIG', 'ENPH', 'FFWM', 'NCLH',
#        'MBI', 'ZG', 'COMM', 'CCL', 'LC', 'WD', 'SQ', 'WOR', 'SMTC',
#        'RCKT', 'HPP'], dtype=object), 'r_retnStd/UI': array(['SHV', 'MBI', 'HA', 'CE', 'SQ', 'X', 'FTSM', 'TNDM', 'IBP', 'TGT',
#        'BKE', 'A', 'KEYS', 'CBRE', 'STC', 'WD', 'XRX', 'BA', 'GPS',
#        'AZTA'], dtype=object)}}
# most_freq_syms: [('HA', 3), ('TNDM', 3), ('MBI', 3), ('SQ', 3), ('WD', 3), ('SHV', 2), ('MARA', 2), ('RUN', 2), ('M', 2), ('ENPH', 2), ('WOR', 2), ('IBP', 2), ('FFWM', 2), ('NCLH', 2), ('ZG', 2), ('BIG', 2), ('BKE', 2), ('LC', 2), ('XRX', 2), ('AMKR', 1), ('COMM', 1), ('CCL', 1), ('SMTC', 1), ('RCKT', 1), ('HPP', 1), ('CE', 1), ('X', 1), ('FTSM', 1), ('TGT', 1), ('A', 1), ('KEYS', 1), ('CBRE', 1), ('STC', 1), ('BA', 1), ('GPS', 1), ('AZTA', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(83, 98, 102), (68, 98, 102), (38, 98, 102)]
# lb_slice:            (38, 98, 102)
# days eval:           4
# iloc_start_train:    38
# iloc_end_train:      98
# date_start_df_train: 2023-09-28
# date_end_df_train:   2023-12-21
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['SHV', 'MARA', 'GPS', 'SPR', 'FTSM', 'GBTC', 'PLNT', 'WOR', 'FL',
#        'ANF', 'BTC-USD', 'X', 'HIBB', 'GDDY', 'M', 'BPMC', 'SQ', 'MBI',
#        'VRNS', 'SHOO'], dtype=object), 'r_CAGR/retnStd': array(['MARA', 'GBTC', 'SPR', 'GPS', 'FL', 'ANF', 'SHV', 'SQ', 'WOR', 'M',
#        'HIBB', 'BTC-USD', 'FTSM', 'PLNT', 'VRNS', 'AMCX', 'AMKR', 'BA',
#        'GDDY', 'ZS'], dtype=object), 'r_retnStd/UI': array(['SHV', 'FTSM', 'TGH', 'X', 'GPS', 'SPR', 'LRN', 'PLNT', 'MBI',
#        'GBTC', 'DECK', 'BTC-USD', 'WOR', 'TGT', 'GDDY', 'GD', 'BPMC',
#        'WM', 'FIVE', 'PI'], dtype=object)}}
# most_freq_syms: [('SHV', 3), ('GPS', 3), ('SPR', 3), ('FTSM', 3), ('GBTC', 3), ('PLNT', 3), ('WOR', 3), ('BTC-USD', 3), ('GDDY', 3), ('MARA', 2), ('FL', 2), ('ANF', 2), ('X', 2), ('HIBB', 2), ('M', 2), ('BPMC', 2), ('SQ', 2), ('MBI', 2), ('VRNS', 2), ('SHOO', 1), ('AMCX', 1), ('AMKR', 1), ('BA', 1), ('ZS', 1), ('TGH', 1), ('LRN', 1), ('DECK', 1), ('TGT', 1), ('GD', 1), ('WM', 1), ('FIVE', 1), ('PI', 1)]
# +++ finish lookback slice 60 +++
#
# grp_most_freq_syms: [[('HA', 3), ('MBI', 3), ('STRL', 3), ('PLAB', 3), ('XRX', 3), ('FFWM', 3), ('AX', 3), ('MARA', 2), ('SHV', 2), ('ZG', 2), ('CUTR', 2), ('TNDM', 2), ('COMM', 2), ('MOV', 2), ('APPS', 2), ('CM', 2), ('COLL', 2), ('X', 2), ('LC', 2), ('WOR', 2), ('NSTG', 1), ('HPP', 1), ('TVTX', 1), ('BBWI', 1), ('SMTC', 1), ('TEAM', 1), ('FAST', 1), ('BKE', 1), ('SLM', 1), ('PSA', 1), ('NSA', 1), ('CIGI', 1), ('ANF', 1)], [('HA', 3), ('TNDM', 3), ('MBI', 3), ('SQ', 3), ('WD', 3), ('SHV', 2), ('MARA', 2), ('RUN', 2), ('M', 2), ('ENPH', 2), ('WOR', 2), ('IBP', 2), ('FFWM', 2), ('NCLH', 2), ('ZG', 2), ('BIG', 2), ('BKE', 2), ('LC', 2), ('XRX', 2), ('AMKR', 1), ('COMM', 1), ('CCL', 1), ('SMTC', 1), ('RCKT', 1), ('HPP', 1), ('CE', 1), ('X', 1), ('FTSM', 1), ('TGT', 1), ('A', 1), ('KEYS', 1), ('CBRE', 1), ('STC', 1), ('BA', 1), ('GPS', 1), ('AZTA', 1)], [('SHV', 3), ('GPS', 3), ('SPR', 3), ('FTSM', 3), ('GBTC', 3), ('PLNT', 3), ('WOR', 3), ('BTC-USD', 3), ('GDDY', 3), ('MARA', 2), ('FL', 2), ('ANF', 2), ('X', 2), ('HIBB', 2), ('M', 2), ('BPMC', 2), ('SQ', 2), ('MBI', 2), ('VRNS', 2), ('SHOO', 1), ('AMCX', 1), ('AMKR', 1), ('BA', 1), ('ZS', 1), ('TGH', 1), ('LRN', 1), ('DECK', 1), ('TGT', 1), ('GD', 1), ('WM', 1), ('FIVE', 1), ('PI', 1)]]
# **** finish lookback slices [(83, 98, 102), (68, 98, 102), (38, 98, 102)] ****
#
# top 20 ranked symbols and frequency from set [(83, 98, 102), (68, 98, 102), (38, 98, 102)]:
# [('MBI', 8), ('SHV', 7), ('WOR', 7), ('HA', 6), ('MARA', 6), ('FFWM', 5), ('SQ', 5), ('TNDM', 5), ('X', 5), ('XRX', 5), ('FTSM', 4), ('GPS', 4), ('LC', 4), ('M', 4), ('ZG', 4), ('ANF', 3), ('AX', 3), ('BKE', 3), ('BTC-USD', 3), ('COMM', 3)]
# top 20 ranked symbols from set [(83, 98, 102), (68, 98, 102), (38, 98, 102)]:
# ['MBI', 'SHV', 'WOR', 'HA', 'MARA', 'FFWM', 'SQ', 'TNDM', 'X', 'XRX']
# ===== finish top 20 ranked symbols from days_lookback set [(83, 98, 102), (68, 98, 102), (38, 98, 102)] =====
#
#
# random_max_lookback_tuples:      [(17, 77, 81), (38, 98, 102)]
# set_lookback_slices 1 of   2:    [(62, 77, 81), (47, 77, 81), (17, 77, 81)]
#
# max_days_lookbacks:              60
# df end date for days_lookbacks:  2023-11-21
# days_lookbacks:                  [15, 30, 60]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     []
# sym_freq_9:                      []
# sym_freq_8:                      []
# sym_freq_7:                      ['GPS', 'SHV']
# sym_freq_6:                      []
# sym_freq_5:                      ['FTSM', 'GDDY', 'LRN', 'PI', 'WING']
# sym_freq_4:                      ['BTC-USD', 'CBOE', 'CRSP', 'GBTC', 'NFLX', 'STKL']
# sym_freq_3:                      ['ALL', 'CAH', 'CMG', 'HASI', 'NGS', 'NRG', 'OUT']
# sym_freq_2:                      []
#
# random_max_lookback_tuples:      [(17, 77, 81), (38, 98, 102)]
# set_lookback_slices 2 of   2:    [(83, 98, 102), (68, 98, 102), (38, 98, 102)]
#
# max_days_lookbacks:              60
# df end date for days_lookbacks:  2023-12-21
# days_lookbacks:                  [15, 30, 60]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     []
# sym_freq_9:                      []
# sym_freq_8:                      ['MBI']
# sym_freq_7:                      ['SHV', 'WOR']
# sym_freq_6:                      ['HA', 'MARA']
# sym_freq_5:                      ['FFWM', 'SQ', 'TNDM', 'X', 'XRX']
# sym_freq_4:                      ['FTSM', 'GPS', 'LC', 'M', 'ZG']
# sym_freq_3:                      ['ANF', 'AX', 'BKE', 'BTC-USD', 'COMM']
# sym_freq_2:                      []
#
# z_grp_top_set_syms_n_freq:
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
#
#
# 1 of 2 max_lookback_slice: (17, 77, 81)
#
# len(idx_train): 60
# idx_train: DatetimeIndex(['2023-08-29', '2023-08-30', '2023-08-31', '2023-09-01', '2023-09-05', '2023-09-06', '2023-09-07', '2023-09-08', '2023-09-11', '2023-09-12', '2023-09-13', '2023-09-14', '2023-09-15', '2023-09-18', '2023-09-19', '2023-09-20', '2023-09-21', '2023-09-22', '2023-09-25', '2023-09-26', '2023-09-27', '2023-09-28', '2023-09-29', '2023-10-02', '2023-10-03', '2023-10-04', '2023-10-05', '2023-10-06', '2023-10-09', '2023-10-10', '2023-10-11', '2023-10-12', '2023-10-13', '2023-10-16',
#                '2023-10-17', '2023-10-18', '2023-10-19', '2023-10-20', '2023-10-23', '2023-10-24', '2023-10-25', '2023-10-26', '2023-10-27', '2023-10-30', '2023-10-31', '2023-11-01', '2023-11-02', '2023-11-03', '2023-11-06', '2023-11-07', '2023-11-08', '2023-11-09', '2023-11-10', '2023-11-13', '2023-11-14', '2023-11-15', '2023-11-16', '2023-11-17', '2023-11-20', '2023-11-21'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-08-29 - 2023-11-21
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-11-22', '2023-11-24', '2023-11-27', '2023-11-28'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-11-22 - 2023-11-28
#
# top_set_syms_n_freq: [('GPS', 7), ('SHV', 7), ('FTSM', 5), ('GDDY', 5), ('LRN', 5), ('PI', 5), ('WING', 5), ('BTC-USD', 4), ('CBOE', 4), ('CRSP', 4), ('GBTC', 4), ('NFLX', 4), ('STKL', 4), ('ALL', 3), ('CAH', 3), ('CMG', 3), ('HASI', 3), ('NGS', 3), ('NRG', 3), ('OUT', 3)]
#
# set_lookback_slices: [(62, 77, 81), (47, 77, 81), (17, 77, 81)]
# max_lookback_slice:  (17, 77, 81)
# days_lookbacks:      [15, 30, 60]
# date_end_df_train:   2023-11-21
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['GPS', 'SHV']
# sym_freq_6:          []
# sym_freq_5:          ['FTSM', 'GDDY', 'LRN', 'PI', 'WING']
# sym_freq_4:          ['BTC-USD', 'CBOE', 'CRSP', 'GBTC', 'NFLX', 'STKL']
# sym_freq_3:          ['ALL', 'CAH', 'CMG', 'HASI', 'NGS', 'NRG', 'OUT']
# sym_freq_2:          []
#
# iloc_start_eval:     77,  df_eval first date: 2023-11-22
# iloc_end_eval:       81,  df_eval last date:  2023-11-28
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                   GPS         SHV         SPY
# Date
# 2023-11-22  18.665136  108.572800  453.182617
# 2023-11-24  18.724707  108.582642  453.461456
# 2023-11-27  19.300547  108.602280  452.644806
# 2023-11-28  19.409756  108.631767  453.092957
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             12.8905
# grp(CAGR)_std                              12.8438
# grp(CAGR)_mean/std                          1.0036
# grp(CAGR/UI)_mean                  25,780,905.0896
# grp(CAGR/UI)_std                   25,687,574.2228
# grp(CAGR/UI)_mean/std                       1.0036
# grp(CAGR/retnStd)_mean                  1,349.3312
# grp(CAGR/retnStd)_std                     717.3544
# grp(CAGR/retnStd)_mean/std                  1.8810
# grp(retnStd/UI)_mean                   12,525.7779
# grp(retnStd/UI)_std                    12,378.0971
# grp(retnStd/UI)_mean/std                    1.0119
# SPY_CAGR                                   -0.0165
# SPY_CAGR/UI                               -16.6854
# SPY_CAGR/retnStd                          -13.3269
# SPY_retnStd/UI                              1.2520
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
# iloc_start_eval:     77,  df_eval first date: 2023-11-22
# iloc_end_eval:       81,  df_eval last date:  2023-11-28
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  FTSM       GDDY        LRN         PI        WING         SPY
# Date
# 2023-11-22  58.707703  95.139999  58.799999  80.900002  234.710144  453.182617
# 2023-11-24  58.717537  94.690002  58.119999  82.500000  235.529648  453.461456
# 2023-11-27  58.737213  96.690002  57.529999  82.800003  240.326782  452.644806
# 2023-11-28  58.786385  97.070000  57.740002  82.760002  237.858261  453.092957
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              2.3101
# grp(CAGR)_std                               2.4753
# grp(CAGR)_mean/std                          0.9332
# grp(CAGR/UI)_mean                      52,833.2599
# grp(CAGR/UI)_std                       93,091.9295
# grp(CAGR/UI)_mean/std                       0.5675
# grp(CAGR/retnStd)_mean                    307.2818
# grp(CAGR/retnStd)_std                     262.1024
# grp(CAGR/retnStd)_mean/std                  1.1724
# grp(retnStd/UI)_mean                      122.5319
# grp(retnStd/UI)_std                       223.6342
# grp(retnStd/UI)_mean/std                    0.5479
# SPY_CAGR                                   -0.0165
# SPY_CAGR/UI                               -16.6854
# SPY_CAGR/retnStd                          -13.3269
# SPY_retnStd/UI                              1.2520
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
# iloc_start_eval:     77,  df_eval first date: 2023-11-22
# iloc_end_eval:       81,  df_eval last date:  2023-11-28
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  BTC-USD        CBOE       CRSP       GBTC        NFLX  STKL         SPY
# Date
# 2023-11-22  37432.339844  179.512527  70.489998  30.450001  478.000000  4.93  453.182617
# 2023-11-24  37720.281250  179.512527  69.970001  31.209999  479.559998  4.90  453.461456
# 2023-11-27  37254.167969  179.851486  71.610001  30.105000  479.170013  4.82  452.644806
# 2023-11-28  37831.085938  180.340012  70.660004  31.510000  479.000000  4.80  453.092957
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              3.0239
# grp(CAGR)_std                               6.1601
# grp(CAGR)_mean/std                          0.4909
# grp(CAGR/UI)_mean                     157,421.7357
# grp(CAGR/UI)_std                      351,368.6692
# grp(CAGR/UI)_mean/std                       0.4480
# grp(CAGR/retnStd)_mean                    161.7370
# grp(CAGR/retnStd)_std                     224.0141
# grp(CAGR/retnStd)_mean/std                  0.7220
# grp(retnStd/UI)_mean                      380.3809
# grp(retnStd/UI)_std                       846.6010
# grp(retnStd/UI)_mean/std                    0.4493
# SPY_CAGR                                   -0.0165
# SPY_CAGR/UI                               -16.6854
# SPY_CAGR/retnStd                          -13.3269
# SPY_retnStd/UI                              1.2520
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
# iloc_start_eval:     77,  df_eval first date: 2023-11-22
# iloc_end_eval:       81,  df_eval last date:  2023-11-28
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                    ALL         CAH          CMG       HASI    NGS        NRG        OUT         SPY
# Date
# 2023-11-22  134.422470  105.351021  2218.929932  23.202850  15.04  45.483921  11.755368  453.182617
# 2023-11-24  134.936096  105.739075  2219.669922  23.143682  15.66  45.543468  11.764927  453.461456
# 2023-11-27  135.785553  106.117180  2209.189941  23.015491  15.77  46.109161  11.803155  452.644806
# 2023-11-28  134.758286  105.629631  2206.669922  23.725479  15.30  46.426746  12.003857  453.092957
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              2.6033
# grp(CAGR)_std                               2.3166
# grp(CAGR)_mean/std                          1.1238
# grp(CAGR/UI)_mean                   2,685,739.7120
# grp(CAGR/UI)_std                    4,247,266.7647
# grp(CAGR/UI)_mean/std                       0.6323
# grp(CAGR/retnStd)_mean                    294.1669
# grp(CAGR/retnStd)_std                     384.7894
# grp(CAGR/retnStd)_mean/std                  0.7645
# grp(retnStd/UI)_mean                    3,334.0582
# grp(retnStd/UI)_std                     5,447.6214
# grp(retnStd/UI)_mean/std                    0.6120
# SPY_CAGR                                   -0.0165
# SPY_CAGR/UI                               -16.6854
# SPY_CAGR/retnStd                          -13.3269
# SPY_retnStd/UI                              1.2520
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2.6033378252764594, 2.3165969036008955, 1.123776787074979, 2685739.7120493865, 4247266.764727497, 0.6323454260876177, 294.1669082733051, 384.78940819782855, 0.7644880602380499, 3334.058219381131, 5447.62135855974, 0.6120209170085567, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
# ================================================================================
#
#
#
# 2 of 2 max_lookback_slice: (38, 98, 102)
#
# len(idx_train): 60
# idx_train: DatetimeIndex(['2023-09-28', '2023-09-29', '2023-10-02', '2023-10-03', '2023-10-04', '2023-10-05', '2023-10-06', '2023-10-09', '2023-10-10', '2023-10-11', '2023-10-12', '2023-10-13', '2023-10-16', '2023-10-17', '2023-10-18', '2023-10-19', '2023-10-20', '2023-10-23', '2023-10-24', '2023-10-25', '2023-10-26', '2023-10-27', '2023-10-30', '2023-10-31', '2023-11-01', '2023-11-02', '2023-11-03', '2023-11-06', '2023-11-07', '2023-11-08', '2023-11-09', '2023-11-10', '2023-11-13', '2023-11-14',
#                '2023-11-15', '2023-11-16', '2023-11-17', '2023-11-20', '2023-11-21', '2023-11-22', '2023-11-24', '2023-11-27', '2023-11-28', '2023-11-29', '2023-11-30', '2023-12-01', '2023-12-04', '2023-12-05', '2023-12-06', '2023-12-07', '2023-12-08', '2023-12-11', '2023-12-12', '2023-12-13', '2023-12-14', '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20', '2023-12-21'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-09-28 - 2023-12-21
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2023-12-22', '2023-12-26', '2023-12-27', '2023-12-28'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2023-12-22 - 2023-12-28
#
# top_set_syms_n_freq: [('MBI', 8), ('SHV', 7), ('WOR', 7), ('HA', 6), ('MARA', 6), ('FFWM', 5), ('SQ', 5), ('TNDM', 5), ('X', 5), ('XRX', 5), ('FTSM', 4), ('GPS', 4), ('LC', 4), ('M', 4), ('ZG', 4), ('ANF', 3), ('AX', 3), ('BKE', 3), ('BTC-USD', 3), ('COMM', 3)]
#
# set_lookback_slices: [(83, 98, 102), (68, 98, 102), (38, 98, 102)]
# max_lookback_slice:  (38, 98, 102)
# days_lookbacks:      [15, 30, 60]
# date_end_df_train:   2023-12-21
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          ['MBI']
# sym_freq_7:          ['SHV', 'WOR']
# sym_freq_6:          ['HA', 'MARA']
# sym_freq_5:          ['FFWM', 'SQ', 'TNDM', 'X', 'XRX']
# sym_freq_4:          ['FTSM', 'GPS', 'LC', 'M', 'ZG']
# sym_freq_3:          ['ANF', 'AX', 'BKE', 'BTC-USD', 'COMM']
# sym_freq_2:          []
#
# iloc_start_eval:     98,  df_eval first date: 2023-12-22
# iloc_end_eval:      102,  df_eval last date:  2023-12-28
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#              MBI         SPY
# Date
# 2023-12-22  6.19  473.649994
# 2023-12-26  6.67  475.649994
# 2023-12-27  6.12  476.510010
# 2023-12-28  6.10  476.690002
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.7078
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                         -11.9203
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -10.8354
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        1.1001
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    0.7116
# SPY_CAGR/UI                         1,423,139.7685
# SPY_CAGR/retnStd                          448.4655
# SPY_retnStd/UI                          3,173.3543
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2.6033378252764594, 2.3165969036008955, 1.123776787074979, 2685739.7120493865, 4247266.764727497, 0.6323454260876177, 294.1669082733051, 384.78940819782855, 0.7644880602380499, 3334.058219381131, 5447.62135855974, 0.6120209170085567, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 8, -0.7077910418069152, 0.0, -inf, -11.920336043832972, 0.0, -inf, -10.83538343409115, 0.0, -inf, 1.100130522961306, 0.0, inf, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# iloc_start_eval:     98,  df_eval first date: 2023-12-22
# iloc_end_eval:      102,  df_eval last date:  2023-12-28
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                    SHV        WOR         SPY
# Date
# 2023-12-22  109.095413  58.430000  473.649994
# 2023-12-26  109.115250  58.869999  475.649994
# 2023-12-27  109.115250  58.880001  476.510010
# 2023-12-28  109.184669  57.880001  476.690002
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.2385
# grp(CAGR)_std                               0.3096
# grp(CAGR)_mean/std                         -0.7703
# grp(CAGR/UI)_mean                      71,078.7001
# grp(CAGR/UI)_std                       71,143.2518
# grp(CAGR/UI)_mean/std                       0.9991
# grp(CAGR/retnStd)_mean                    106.2032
# grp(CAGR/retnStd)_std                     159.5754
# grp(CAGR/retnStd)_mean/std                  0.6655
# grp(retnStd/UI)_mean                      268.1619
# grp(retnStd/UI)_std                       266.9524
# grp(retnStd/UI)_mean/std                    1.0045
# SPY_CAGR                                    0.7116
# SPY_CAGR/UI                         1,423,139.7685
# SPY_CAGR/retnStd                          448.4655
# SPY_retnStd/UI                          3,173.3543
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2.6033378252764594, 2.3165969036008955, 1.123776787074979, 2685739.7120493865, 4247266.764727497, 0.6323454260876177, 294.1669082733051, 384.78940819782855, 0.7644880602380499, 3334.058219381131, 5447.62135855974, 0.6120209170085567, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, -0.7077910418069152, 0.0, -inf, -11.920336043832972, 0.0, -inf, -10.83538343409115, 0.0, -inf, 1.100130522961306, 0.0, inf, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.23852594614106826, 0.3096369221000379, -0.7703407737143343, 71078.70012870211, 71143.25178923718, 0.99909265237515, 106.20321751400033, 159.57543130723823, 0.6655361457837591, 268.16187400089933, 266.9524120740408, 1.004530627453267, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# iloc_start_eval:     98,  df_eval first date: 2023-12-22
# iloc_end_eval:      102,  df_eval last date:  2023-12-28
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                HA       MARA         SPY
# Date
# 2023-12-22  14.29  26.709999  473.649994
# 2023-12-26  14.40  26.959999  475.649994
# 2023-12-27  14.64  31.070000  476.510010
# 2023-12-28  14.69  28.110001  476.690002
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             40.6149
# grp(CAGR)_std                              31.4496
# grp(CAGR)_mean/std                          1.2914
# grp(CAGR/UI)_mean                   9,166,114.5555
# grp(CAGR/UI)_std                    9,164,601.6873
# grp(CAGR/UI)_mean/std                       1.0002
# grp(CAGR/retnStd)_mean                  1,184.8410
# grp(CAGR/retnStd)_std                     475.0936
# grp(CAGR/retnStd)_mean/std                  2.4939
# grp(retnStd/UI)_mean                    5,522.5834
# grp(retnStd/UI)_std                     5,520.4518
# grp(retnStd/UI)_mean/std                    1.0004
# SPY_CAGR                                    0.7116
# SPY_CAGR/UI                         1,423,139.7685
# SPY_CAGR/retnStd                          448.4655
# SPY_retnStd/UI                          3,173.3543
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2.6033378252764594, 2.3165969036008955, 1.123776787074979, 2685739.7120493865, 4247266.764727497, 0.6323454260876177, 294.1669082733051, 384.78940819782855, 0.7644880602380499, 3334.058219381131, 5447.62135855974, 0.6120209170085567, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, -0.7077910418069152, 0.0, -inf, -11.920336043832972, 0.0, -inf, -10.83538343409115, 0.0, -inf, 1.100130522961306, 0.0, inf, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.23852594614106826, 0.3096369221000379, -0.7703407737143343, 71078.70012870211, 71143.25178923718, 0.99909265237515, 106.20321751400033, 159.57543130723823, 0.6655361457837591, 268.16187400089933, 266.9524120740408, 1.004530627453267, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 40.6149343707534, 31.44957624934591, 1.291430258034021, 9166114.555534359, 9164601.687280636, 1.0001650773601893, 1184.8409770789278, 475.09361997454016, 2.4939105205041954, 5522.583396847479, 5520.451838006745, 1.0003861203581306, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# iloc_start_eval:     98,  df_eval first date: 2023-12-22
# iloc_end_eval:      102,  df_eval last date:  2023-12-28
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                 FFWM         SQ       TNDM          X        XRX         SPY
# Date
# 2023-12-22  9.279723  77.139999  29.490000  47.918266  18.453169  473.649994
# 2023-12-26  9.549425  78.180000  31.030001  48.297855  18.561716  475.649994
# 2023-12-27  9.689270  79.599998  30.920000  48.557575  18.690001  476.510010
# 2023-12-28  9.879060  79.510002  30.740000  48.607521  18.580000  476.690002
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             47.4870
# grp(CAGR)_std                              72.5688
# grp(CAGR)_mean/std                          0.6544
# grp(CAGR/UI)_mean                  77,309,808.4090
# grp(CAGR/UI)_std                  152,297,572.2375
# grp(CAGR/UI)_mean/std                       0.5076
# grp(CAGR/retnStd)_mean                  7,093.8024
# grp(CAGR/retnStd)_std                  12,418.3093
# grp(CAGR/retnStd)_mean/std                  0.5712
# grp(retnStd/UI)_mean                    3,535.9053
# grp(retnStd/UI)_std                     4,755.2502
# grp(retnStd/UI)_mean/std                    0.7436
# SPY_CAGR                                    0.7116
# SPY_CAGR/UI                         1,423,139.7685
# SPY_CAGR/retnStd                          448.4655
# SPY_retnStd/UI                          3,173.3543
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2.6033378252764594, 2.3165969036008955, 1.123776787074979, 2685739.7120493865, 4247266.764727497, 0.6323454260876177, 294.1669082733051, 384.78940819782855, 0.7644880602380499, 3334.058219381131, 5447.62135855974, 0.6120209170085567, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, -0.7077910418069152, 0.0, -inf, -11.920336043832972, 0.0, -inf, -10.83538343409115, 0.0, -inf, 1.100130522961306, 0.0, inf, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.23852594614106826, 0.3096369221000379, -0.7703407737143343, 71078.70012870211, 71143.25178923718, 0.99909265237515, 106.20321751400033, 159.57543130723823, 0.6655361457837591, 268.16187400089933, 266.9524120740408, 1.004530627453267, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 40.6149343707534, 31.44957624934591, 1.291430258034021, 9166114.555534359, 9164601.687280636, 1.0001650773601893, 1184.8409770789278, 475.09361997454016, 2.4939105205041954, 5522.583396847479, 5520.451838006745, 1.0003861203581306, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 47.4869551257746, 72.56875683675362, 0.6543718977107248, 77309808.40902692, 152297572.23751697, 0.5076233801577464, 7093.802377817306, 12418.309294462566, 0.5712373729474184, 3535.905262501139, 4755.250192592855, 0.7435792270213119, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# iloc_start_eval:     98,  df_eval first date: 2023-12-22
# iloc_end_eval:      102,  df_eval last date:  2023-12-28
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  FTSM        GPS    LC      M         ZG         SPY
# Date
# 2023-12-22  59.105324  21.018135  8.66  19.99  58.070000  473.649994
# 2023-12-26  59.118221  21.286198  8.91  20.32  57.759998  475.649994
# 2023-12-27  59.128136  21.127346  8.97  20.10  58.509998  476.510010
# 2023-12-28  59.157890  20.948637  8.91  20.35  57.820000  476.690002
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              2.5859
# grp(CAGR)_std                               3.9302
# grp(CAGR)_mean/std                          0.6579
# grp(CAGR/UI)_mean                      31,719.8855
# grp(CAGR/UI)_std                       61,682.6608
# grp(CAGR/UI)_mean/std                       0.5142
# grp(CAGR/retnStd)_mean                    287.3223
# grp(CAGR/retnStd)_std                     284.7838
# grp(CAGR/retnStd)_mean/std                  1.0089
# grp(retnStd/UI)_mean                       60.9515
# grp(retnStd/UI)_std                       117.2360
# grp(retnStd/UI)_mean/std                    0.5199
# SPY_CAGR                                    0.7116
# SPY_CAGR/UI                         1,423,139.7685
# SPY_CAGR/retnStd                          448.4655
# SPY_retnStd/UI                          3,173.3543
#
# type(l_row_add_total): <class 'list'>
# ...
# ================================================================================
#
#
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2.6033378252764594, 2.3165969036008955, 1.123776787074979, 2685739.7120493865, 4247266.764727497, 0.6323454260876177, 294.1669082733051, 384.78940819782855, 0.7644880602380499, 3334.058219381131, 5447.62135855974, 0.6120209170085567, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, -0.7077910418069152, 0.0, -inf, -11.920336043832972, 0.0, -inf, -10.83538343409115, 0.0, -inf, 1.100130522961306, 0.0, inf, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.23852594614106826, 0.3096369221000379, -0.7703407737143343, 71078.70012870211, 71143.25178923718, 0.99909265237515, 106.20321751400033, 159.57543130723823, 0.6655361457837591, 268.16187400089933, 266.9524120740408, 1.004530627453267, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 40.6149343707534, 31.44957624934591, 1.291430258034021, 9166114.555534359, 9164601.687280636, 1.0001650773601893, 1184.8409770789278, 475.09361997454016, 2.4939105205041954, 5522.583396847479, 5520.451838006745, 1.0003861203581306, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 47.4869551257746, 72.56875683675362, 0.6543718977107248, 77309808.40902692, 152297572.23751697, 0.5076233801577464, 7093.802377817306, 12418.309294462566, 0.5712373729474184, 3535.905262501139, 4755.250192592855, 0.7435792270213119, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 2.5858500462035483, 3.9301855731944886, 0.6579460430164236, 31719.885525665664, 61682.660751399395, 0.5142431461169747, 287.3223469594436, 284.78376422588406, 1.0089140711390625, 60.95154530001039, 117.23601291883624, 0.5199046247180702, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 60.20127779010819, 111.8926250078708, 0.5380272183789905, 116407882.889407, 225638230.83332527, 0.5159049619361504, 42690.913220820345, 84290.53086628237, 0.5064734173823721, 2358.969652614675, 3528.008514157641, 0.6686405781472187, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]]
#
#
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2.6033378252764594, 2.3165969036008955, 1.123776787074979, 2685739.7120493865, 4247266.764727497, 0.6323454260876177, 294.1669082733051, 384.78940819782855, 0.7644880602380499, 3334.058219381131, 5447.62135855974, 0.6120209170085567, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 8, -0.7077910418069152, 0.0, -inf, -11.920336043832972, 0.0, -inf, -10.83538343409115, 0.0, -inf, 1.100130522961306, 0.0, inf, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.23852594614106826, 0.3096369221000379, -0.7703407737143343, 71078.70012870211, 71143.25178923718, 0.99909265237515, 106.20321751400033, 159.57543130723823, 0.6655361457837591, 268.16187400089933, 266.9524120740408, 1.004530627453267, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 40.6149343707534, 31.44957624934591, 1.291430258034021, 9166114.555534359, 9164601.687280636, 1.0001650773601893, 1184.8409770789278, 475.09361997454016, 2.4939105205041954, 5522.583396847479, 5520.451838006745, 1.0003861203581306, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 47.4869551257746, 72.56875683675362, 0.6543718977107248, 77309808.40902692, 152297572.23751697, 0.5076233801577464, 7093.802377817306, 12418.309294462566, 0.5712373729474184, 3535.905262501139, 4755.250192592855, 0.7435792270213119, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 2.5858500462035483, 3.9301855731944886, 0.6579460430164236, 31719.885525665664, 61682.660751399395, 0.5142431461169747, 287.3223469594436, 284.78376422588406, 1.0089140711390625, 60.95154530001039, 117.23601291883624, 0.5199046247180702, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 60.20127779010819, 111.8926250078708, 0.5380272183789905, 116407882.889407, 225638230.83332527, 0.5159049619361504, 42690.913220820345, 84290.53086628237, 0.5064734173823721, 2358.969652614675, 3528.008514157641, 0.6686405781472187, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
# df_eval_results BEFORW store results:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 12.890452544814792, 12.843787111404954, 1.0036333079180673, 25780905.089629583, 25687574.22280991, 1.003633307918067, 1349.331232800022, 717.3543500500264, 1.8809828541583713, 12525.777886095102, 12378.097062053637, 1.0119308180652578, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 2.3101017308151737, 2.4753412039947333, 0.9332457792433244, 52833.25991949779, 93091.92952302255, 0.5675385631192831, 307.28175091083244, 262.10236652902904, 1.1723730501944918, 122.53191389663569, 223.63415368622398, 0.5479123464681402, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 3.023937484625034, 6.160124892927275, 0.49088898962047944, 157421.73569419116, 351368.66918547376, 0.44802439574114217, 161.73701264185726, 224.01412178984825, 0.7219947177865229, 380.3809125999275, 846.6009995739952, 0.44930364220138297, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 2.6033378252764594, 2.3165969036008955, 1.123776787074979, 2685739.7120493865, 4247266.764727497, 0.6323454260876177, 294.1669082733051, 384.78940819782855, 0.7644880602380499, 3334.058219381131, 5447.62135855974, 0.6120209170085567, -0.016483396730983868, -16.685444001793208, -13.32689440837746, 1.252012921427855]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 8, -0.7077910418069152, 0.0, -inf, -11.920336043832972, 0.0, -inf, -10.83538343409115, 0.0, -inf, 1.100130522961306, 0.0, inf, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.23852594614106826, 0.3096369221000379, -0.7703407737143343, 71078.70012870211, 71143.25178923718, 0.99909265237515, 106.20321751400033, 159.57543130723823, 0.6655361457837591, 268.16187400089933, 266.9524120740408, 1.004530627453267, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 40.6149343707534, 31.44957624934591, 1.291430258034021, 9166114.555534359, 9164601.687280636, 1.0001650773601893, 1184.8409770789278, 475.09361997454016, 2.4939105205041954, 5522.583396847479, 5520.451838006745, 1.0003861203581306, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 47.4869551257746, 72.56875683675362, 0.6543718977107248, 77309808.40902692, 152297572.23751697, 0.5076233801577464, 7093.802377817306, 12418.309294462566, 0.5712373729474184, 3535.905262501139, 4755.250192592855, 0.7435792270213119, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 2.5858500462035483, 3.9301855731944886, 0.6579460430164236, 31719.885525665664, 61682.660751399395, 0.5142431461169747, 287.3223469594436, 284.78376422588406, 1.0089140711390625, 60.95154530001039, 117.23601291883624, 0.5199046247180702, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 60.20127779010819, 111.8926250078708, 0.5380272183789905, 116407882.889407, 225638230.83332527, 0.5159049619361504, 42690.913220820345, 84290.53086628237, 0.5064734173823721, 2358.969652614675, 3528.008514157641, 0.6686405781472187, 0.7115698842571756, 1423139.7685143512, 448.465452138222, 3173.354294581701]
#
# Save results to: df_eval_results_test
# df_eval_results AFTER store results:
#    n_samples days_lookbacks  days_eval  n_top_syms  syms_start  syms_end  sym_freq_cnt  grp(CAGR)_mean  grp(CAGR)_std  grp(CAGR)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  grp(CAGR/retnStd)_mean  grp(CAGR/retnStd)_std  grp(CAGR/retnStd)_mean/std  grp(retnStd/UI)_mean  grp(retnStd/UI)_std  grp(retnStd/UI)_mean/std  SPY_CAGR   SPY_CAGR/UI  SPY_CAGR/retnStd  SPY_retnStd/UI
# 0          2   [15, 30, 60]          4          20           0        10             7       12.890453      12.843787            1.003633       2.578091e+07      2.568757e+07             1.003633            1349.331233              717.354350               1.880983                12525.777886          12378.097062             1.011931      -0.016483 -1.668544e+01        -13.326894        1.252013
# 1          2   [15, 30, 60]          4          20           0        10             5        2.310102       2.475341            0.933246       5.283326e+04      9.309193e+04             0.567539             307.281751              262.102367               1.172373                  122.531914            223.634154             0.547912      -0.016483 -1.668544e+01        -13.326894        1.252013
# 2          2   [15, 30, 60]          4          20           0        10             4        3.023937       6.160125            0.490889       1.574217e+05      3.513687e+05             0.448024             161.737013              224.014122               0.721995                  380.380913            846.601000             0.449304      -0.016483 -1.668544e+01        -13.326894        1.252013
# 3          2   [15, 30, 60]          4          20           0        10             3        2.603338       2.316597            1.123777       2.685740e+06      4.247267e+06             0.632345             294.166908              384.789408               0.764488                 3334.058219           5447.621359             0.612021      -0.016483 -1.668544e+01        -13.326894        1.252013
# 4          2   [15, 30, 60]          4          20           0        10             8       -0.707791       0.000000                -inf      -1.192034e+01      0.000000e+00                 -inf             -10.835383                0.000000                   -inf                    1.100131              0.000000                  inf       0.711570  1.423140e+06        448.465452     3173.354295
# 5          2   [15, 30, 60]          4          20           0        10             7       -0.238526       0.309637           -0.770341       7.107870e+04      7.114325e+04             0.999093             106.203218              159.575431               0.665536                  268.161874            266.952412             1.004531       0.711570  1.423140e+06        448.465452     3173.354295
# 6          2   [15, 30, 60]          4          20           0        10             6       40.614934      31.449576            1.291430       9.166115e+06      9.164602e+06             1.000165            1184.840977              475.093620               2.493911                 5522.583397           5520.451838             1.000386       0.711570  1.423140e+06        448.465452     3173.354295
# 7          2   [15, 30, 60]          4          20           0        10             5       47.486955      72.568757            0.654372       7.730981e+07      1.522976e+08             0.507623            7093.802378            12418.309294               0.571237                 3535.905263           4755.250193             0.743579       0.711570  1.423140e+06        448.465452     3173.354295
# 8          2   [15, 30, 60]          4          20           0        10             4        2.585850       3.930186            0.657946       3.171989e+04      6.168266e+04             0.514243             287.322347              284.783764               1.008914                   60.951545            117.236013             0.519905       0.711570  1.423140e+06        448.465452     3173.354295
# 9          2   [15, 30, 60]          4          20           0        10             3       60.201278     111.892625            0.538027       1.164079e+08      2.256382e+08             0.515905           42690.913221            84290.530866               0.506473                 2358.969653           3528.008514             0.668641       0.711570  1.423140e+06        448.465452     3173.354295
