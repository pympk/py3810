# %%
# # create empty DataFrame df_picks and append row
# my_cols = ['date', 'days_lookback', 'syms_freq', 'symbols']
# # Creating Empty DataFrame and Storing it in variable df_picks
# df_model_top_picks = pd.DataFrame(columns=my_cols)
# df_model_top_picks

# %%
import pandas as pd
from itertools import product
from ast import literal_eval
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.width', 900)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

# fp_df_picks  = f'df_picks'  # stock picks by criteria: CAGR/UI, CAGR/rtn_std, rtd/UI
fp_df_model_top_picks = 'df_model_top_picks'  # top stock picks from model developed by back test
fp_df_close_clean = 'df_close_clean'  # historic stocks' closing price

verbose = True
# verbose = False

# %%
def get_trading_date_n(date, idx_close, n, verbose=False):

  if date in idx_close:
    idx_last = len(idx_close) - 1  # last index of idx_close
    idx_date = idx_close.get_loc(date)  # index of date
    idx_date_n = idx_date + n  # index of date_n
    if verbose:
      print(f"date: {date} is in idx_close,  date's position in idx_close is: {idx_date} of {idx_last},  n: {n},  idx_date_n: {idx_date_n},")
    if 0 <= idx_date_n <= idx_last:  # idx_date_n is within bounds of idx_close
      date_n = idx_close[idx_date_n]
      if verbose:      
        print(f'idx_date_n: {idx_date_n} is wiithin bounds of idx_close (0 to {idx_last}), date_n: {date_n}\n')
    else:  # idx_date_n is out-of-bounds of idx_close
      date_n = None   
      if verbose:  
        print(f'idx_date_n: {idx_date_n} is out-of-bounds of idx_close (0 to {idx_last})\n')
  else:  # date not in idx_close
      date_n = None  
      if verbose:  
        print(f'date: {date} is not in idx_close\n')

  return date_n

# %%
def get_portf_buy(df_close, date, str_symbols, portf_target, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    sym_cnt = len(l_syms)  # number of symbols
    amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
    ar_sym_share = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
    ar_sym_amt = ar_price * ar_sym_share  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_sym_amt)  # total actual portfolio value
    if verbose:
        # print(date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value)    
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_sym_share = }, {ar_sym_amt = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value

# %%
def get_SPY_buy(df_close, date, portf_target, symbol="SPY", verbose=False):   
    import numpy as np
    price = df_close.loc[date][symbol]    
    share = np.floor(portf_target / price)  # array of shares for each symbol
    value = price * share  # array of actual dollar amount invested in each symbol
    if verbose:
        # print(date, symbol, price, share, value)
        print(f'{date = }, {symbol = }, {price = }, {share = }, {value = }')                        
        print(f'{date} {symbol} {value = }')
    return date, price, share, value

# %% [markdown]
# ### TODO: 2023-12-14, Replace idx_close with dates in df_close, no start_date or end_date needed

# %%
df_close = pickle_load(path_data_dump, fp_df_close_clean)
df_picks_mp = pickle_load(path_data_dump, fp_df_model_top_picks)
# df_picks_mp = df_model_top_picks.copy()

# %%
dates_sorted = sorted(df_picks_mp.date.tolist())
date_start_picks_mp = dates_sorted[0]
date_end_picks_mp = dates_sorted[-1]
print(date_start_picks_mp, date_end_picks_mp)
# Out:
# 2023-03-15 2023-12-15

# %%
# Create a boolean mask for rows between date1 and date2 (inclusive)
mask = (df_close.index >= date_start_picks_mp) & (df_close.index <= date_end_picks_mp)

# Select rows using the mask
df_close = df_close.loc[mask]

# Trading dates
# idx_close = df_close.index.strftime('%Y-%m-%d')
idx_close = df_close.index.strftime('%Y-%m-%d')

df_close
# Out:
#                      A         AA    AAL         AAP        AAPL         AB        ABBV        ABR         ABT       ACGL       ACHC       ACIW        ACLS   ACRS        ADBE  ...        XRX         XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                            ...
# 2023-03-15  133.288239  39.372566  13.86  119.255257  152.371918  32.977055  149.485596  10.526908   96.316017  62.740002  68.459999  22.700001  123.860001  7.990  333.609985  ...  14.261086   95.604477  29.170000  125.356514  59.979794  26.028101  124.543419  287.739990  73.779999  39.919998  29.475050  25.606165  162.472290  19.500000  20.806547
# 2023-03-16  136.062805  40.342766  14.12  119.509888  155.220352  33.193268  150.688766  10.499517   97.527351  66.070000  70.230003  25.780001  129.960007  8.120  353.290009  ...  14.451233   96.208496  29.780001  126.273537  60.515686  26.922306  124.712440  294.929993  74.510002  40.849998  30.818754  27.639652  165.193893  19.250000  20.796629
# 2023-03-17  132.442932  38.758762  13.98  116.934204  154.373779  32.883053  149.640839  10.216486   95.538002  63.150002  69.459999  26.940001  128.220001  7.890  358.140015  ...  13.899805   93.802299  29.330000  125.080414  60.257668  27.720362  123.598854  288.709991  74.129997  39.810001  28.736017  28.083862  163.366241  18.540001  20.360270
# 2023-03-20  133.795395  39.877464  13.96  116.229065  156.764084  33.024059  151.484421  10.791677   96.384964  65.610001  70.449997  26.150000  131.509995  7.950  362.880005  ...  14.118475   96.693703  29.690001  127.082108  60.485916  28.028044  125.607292  290.839996  74.650002  39.830002  28.966366  27.659395  164.707199  18.110001  20.657787
# 2023-03-21  136.251740  41.491177  14.37  117.316147  158.636505  33.334270  152.115128  10.873848   96.837975  67.209999  70.959999  26.200001  133.449997  8.240  374.220001  ...  14.546309   97.555176  30.059999  126.756706  60.704235  27.489597  127.058952  294.429993  75.570000  41.939999  30.991514  27.866692  165.124374  18.549999  21.004896
# ...                ...        ...    ...         ...         ...        ...         ...        ...         ...        ...        ...        ...         ...    ...         ...  ...        ...         ...        ...         ...        ...        ...         ...         ...        ...        ...        ...        ...         ...        ...        ...
# 2023-12-11  128.970001  24.930000  13.72   57.080002  193.179993  29.820000  151.240005  14.100000  106.220001  79.610001  74.959999  28.000000  125.580002  0.973  625.200012  ...  15.170000  107.699997  44.099998  126.629997  39.919998  36.939999  117.980003  239.649994  63.730000  43.820000  38.630001  21.020000  189.460007  18.969999  29.610001
# 2023-12-12  128.789993  24.049999  14.04   56.250000  194.710007  30.559999  153.240005  14.190000  106.680000  80.279999  75.910004  28.320000  126.190002  1.010  633.659973  ...  15.710000  107.940002  44.480000  128.070007  40.320000  39.029999  117.449997  239.380005  62.560001  45.419998  38.130001  21.020000  191.470001  18.570000  29.230000
# 2023-12-13  133.740005  25.990000  14.09   60.830002  197.960007  30.809999  154.300003  14.880000  107.250000  78.379997  78.959999  29.240000  131.500000  1.090  624.260010  ...  16.709999  109.180000  44.490002  130.929993  39.750000  38.500000  117.900002  244.429993  64.720001  50.279999  41.820000  20.400000  197.410004  19.670000  29.320000
# 2023-12-14  137.960007  29.900000  14.59   63.970001  198.110001  31.870001  154.880005  15.700000  108.599998  74.669998  77.580002  29.639999  140.429993  1.060  584.640015  ...  17.580000  110.930000  45.360001  131.110001  40.160000  38.799999  118.529999  272.160004  66.320000  54.500000  45.669998  20.309999  200.089996  19.930000  29.610001
# 2023-12-15  136.779999  31.100000  14.49   62.720001  197.570007  32.020000  154.039993  15.380000  107.290001  73.419998  75.430000  29.719999  136.089996  1.010  584.679993  ...  18.290001  110.720001  44.790001  128.639999  40.029999  38.540001  118.690002  270.179993  66.550003  54.779999  43.840000  19.830000  196.289993  19.389999  29.350000
#
# [192 rows x 1269 columns]

# %%
def all_in_list(list1, list2):
  """
  Checks if all items in list1 are also in list2.

  Args:
    list1: A list of items.
    list2: Another list of items.

  Returns:
    True if all items in list1 are in list2, False otherwise.
  """
  return set(list1).issubset(set(list2))

# %%
def any_not_in_list(list1, list2):
  """
  Checks if any items in list1 are not in list2.

  Args:
    list1: A list of items.
    list2: Another list of items.

  Returns:
    True if any item in list1 is not in list2, False if all are present.
  """
  return bool(set(list1) - set(list2))

# %%
import numpy as np
# from ast import literal_eval
z_date_syms = zip(df_picks_mp.date, df_picks_mp.symbols)

idx_close = df_close.index.strftime('%Y-%m-%d')
symbols_df_close = df_close.columns  # symbols in df_close

n = 1  # n=1 is the buy date
# n = 4  # n=4 is the sell date

date_buy = []  # buy date of portfolio
shares_syms = []  # lists of shares of each symbol brought on date_buy
value_portf = [] # list of porfolio value on date_buy
shares_SPY = []  # list of shares of SPY brought on date_buy
value_SPY = []  # list of value of SPY shares on date_buy 
for date, syms in z_date_syms:
    next_date_n = get_trading_date_n(date, idx_close, n, verbose=verbose)

    if next_date_n in idx_close:
        close_date_n = next_date_n
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is in df_close')
        print(f'picks for {date}: {syms}')      
    else:
        close_date_n = None
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is not in df_close')
        print(f'picks for {date}: {syms}')        

    l_syms = literal_eval(syms)  # convert list stored as str back to list
    # True if symbol(s) in l_syms is not a column in df_close
    sym_not_in_df_close = any_not_in_list(l_syms, symbols_df_close)

    if close_date_n is None or sym_not_in_df_close:
        p_date = None  # portf. buy date
        p_l_syms = None  # portf. list of symbols
        p_ar_price = None  # portf. list of symbols' close
        p_ar_sym_share = None  # portf. list of symbols' share
        p_ar_sym_amt = None  # portf. list of symbols' dollar value 
        p_portf_value = None  # portf. value is none, data not available in df_close
        
        s_date = None  # SPY buy date
        s_price = None # SPY list of symbols' close
        s_share = None # SPY list of symbols' share
        s_value = None  # SPY value is none, data not available in df_close

        date_buy.append(p_date)
        shares_syms.append(p_l_syms)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)    
        
        print(f"No data for next_date_n {next_date_n}, pick's portf value = None")
        print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else:    
        p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
            get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
        s_date, s_price, s_share, s_value = \
            get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
                
        date_buy.append(p_date)
        shares_syms.append(p_ar_sym_share)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)

        print(f"next_date_n pick's portf value = {p_portf_value}")
        print(f'next_date_n SPY portf value =    {s_value}')

    print('='*20, '\n')
# Out:
# date: 2023-12-15 is in idx_close,  date's position in idx_close is: 191 of 191,  n: 1,  idx_date_n: 192,
# idx_date_n: 192 is out-of-bounds of idx_close (0 to 191)
#
# date: 2023-12-15,  n: 1,  next_date_n: None is not in df_close
# picks for 2023-12-15: ['SHV']
# No data for next_date_n None, pick's portf value = None
# No data for next_date_n None, SPY portf value =    None
# ====================
#
# date: 2023-12-13 is in idx_close,  date's position in idx_close is: 189 of 191,  n: 1,  idx_date_n: 190,
# idx_date_n: 190 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-14
#
# date: 2023-12-13,  n: 1,  next_date_n: 2023-12-14 is in df_close
# picks for 2023-12-13: ['GPS', 'SHV']
# date = '2023-12-14', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.29999924, 109.86000061]), ar_sym_share = array([23.,  4.]), ar_sym_amt = array([489.89998245, 439.44000244]), portf_value = 929.3399848937988
# 2023-12-14 portf_value = 929.3399848937988
# date = '2023-12-14', symbol = 'SPY', price = 472.010009765625, share = 2.0, value = 944.02001953125
# 2023-12-14 SPY value = 944.02001953125
# next_date_n pick's portf value = 929.3399848937988
# next_date_n SPY portf value =    944.02001953125
# ====================
#
# date: 2023-12-12 is in idx_close,  date's position in idx_close is: 188 of 191,  n: 1,  idx_date_n: 189,
# idx_date_n: 189 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-13
#
# date: 2023-12-12,  n: 1,  next_date_n: 2023-12-13 is in df_close
# picks for 2023-12-12: ['GPS', 'SHV']
# date = '2023-12-13', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.22999954, 109.80599976]), ar_sym_share = array([23.,  4.]), ar_sym_amt = array([488.28998947, 439.22399902]), portf_value = 927.513988494873
# 2023-12-13 portf_value = 927.513988494873
# date = '2023-12-13', symbol = 'SPY', price = 470.5, share = 2.0, value = 941.0
# 2023-12-13 SPY value = 941.0
# next_date_n pick's portf value = 927.513988494873
# next_date_n SPY portf value =    941.0
# ====================
#
# date: 2023-12-11 is in idx_close,  date's position in idx_close is: 187 of 191,  n: 1,  idx_date_n: 188,
# idx_date_n: 188 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-12
#
# date: 2023-12-11,  n: 1,  next_date_n: 2023-12-12 is in df_close
# picks for 2023-12-11: ['GPS', 'SHV']
# date = '2023-12-12', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.29999924, 109.76618195]), ar_sym_share = array([23.,  4.]), ar_sym_amt = array([489.89998245, 439.06472778]), portf_value = 928.9647102355957
# 2023-12-12 portf_value = 928.9647102355957
# date = '2023-12-12', symbol = 'SPY', price = 464.1000061035156, share = 2.0, value = 928.2000122070312
# 2023-12-12 SPY value = 928.2000122070312
# next_date_n pick's portf value = 928.9647102355957
# next_date_n SPY portf value =    928.2000122070312
# ====================
#
# date: 2023-12-08 is in idx_close,  date's position in idx_close is: 186 of 191,  n: 1,  idx_date_n: 187,
# idx_date_n: 187 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-11
#
# date: 2023-12-08,  n: 1,  next_date_n: 2023-12-11 is in df_close
# picks for 2023-12-08: ['GPS', 'SHV']
# date = '2023-12-11', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.93000031, 109.7363205 ]), ar_sym_share = array([22.,  4.]), ar_sym_amt = array([482.46000671, 438.94528198]), portf_value = 921.4052886962891
# 2023-12-11 portf_value = 921.4052886962891
# date = '2023-12-11', symbol = 'SPY', price = 461.989990234375, share = 2.0, value = 923.97998046875
# 2023-12-11 SPY value = 923.97998046875
# next_date_n pick's portf value = 921.4052886962891
# next_date_n SPY portf value =    923.97998046875
# ====================
#
# date: 2023-12-07 is in idx_close,  date's position in idx_close is: 185 of 191,  n: 1,  idx_date_n: 186,
# idx_date_n: 186 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-08
#
# date: 2023-12-07,  n: 1,  next_date_n: 2023-12-08 is in df_close
# picks for 2023-12-07: ['GPS', 'SHV']
# date = '2023-12-08', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.68000031, 109.7363205 ]), ar_sym_share = array([23.,  4.]), ar_sym_amt = array([498.64000702, 438.94528198]), portf_value = 937.5852890014648
# 2023-12-08 portf_value = 937.5852890014648
# date = '2023-12-08', symbol = 'SPY', price = 460.20001220703125, share = 2.0, value = 920.4000244140625
# 2023-12-08 SPY value = 920.4000244140625
# next_date_n pick's portf value = 937.5852890014648
# next_date_n SPY portf value =    920.4000244140625
# ====================
#
# date: 2023-12-06 is in idx_close,  date's position in idx_close is: 184 of 191,  n: 1,  idx_date_n: 185,
# idx_date_n: 185 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-07
#
# date: 2023-12-06,  n: 1,  next_date_n: 2023-12-07 is in df_close
# picks for 2023-12-06: ['GPS', 'SHV']
# date = '2023-12-07', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.37000084, 109.7363205 ]), ar_sym_share = array([23.,  4.]), ar_sym_amt = array([491.5100193 , 438.94528198]), portf_value = 930.45530128479
# 2023-12-07 portf_value = 930.45530128479
# date = '2023-12-07', symbol = 'SPY', price = 458.2300109863281, share = 2.0, value = 916.4600219726562
# 2023-12-07 SPY value = 916.4600219726562
# next_date_n pick's portf value = 930.45530128479
# next_date_n SPY portf value =    916.4600219726562
# ====================
#
# date: 2023-12-05 is in idx_close,  date's position in idx_close is: 183 of 191,  n: 1,  idx_date_n: 184,
# idx_date_n: 184 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-06
#
# date: 2023-12-05,  n: 1,  next_date_n: 2023-12-06 is in df_close
# picks for 2023-12-05: ['GPS']
# date = '2023-12-06', l_syms = ['GPS'], ar_price = array([20.94000053]), ar_sym_share = array([47.]), ar_sym_amt = array([984.1800251]), portf_value = 984.180025100708
# 2023-12-06 portf_value = 984.180025100708
# date = '2023-12-06', symbol = 'SPY', price = 454.760009765625, share = 2.0, value = 909.52001953125
# 2023-12-06 SPY value = 909.52001953125
# next_date_n pick's portf value = 984.180025100708
# next_date_n SPY portf value =    909.52001953125
# ====================
#
# date: 2023-12-05 is in idx_close,  date's position in idx_close is: 183 of 191,  n: 1,  idx_date_n: 184,
# idx_date_n: 184 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-06
#
# date: 2023-12-05,  n: 1,  next_date_n: 2023-12-06 is in df_close
# picks for 2023-12-05: ['LRN', 'SHV']
# date = '2023-12-06', l_syms = ['LRN', 'SHV'], ar_price = array([ 60.68999863, 109.68655396]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([485.51998901, 438.74621582]), portf_value = 924.2662048339844
# 2023-12-06 portf_value = 924.2662048339844
# date = '2023-12-06', symbol = 'SPY', price = 454.760009765625, share = 2.0, value = 909.52001953125
# 2023-12-06 SPY value = 909.52001953125
# next_date_n pick's portf value = 924.2662048339844
# next_date_n SPY portf value =    909.52001953125
# ====================
#
# date: 2023-12-05 is in idx_close,  date's position in idx_close is: 183 of 191,  n: 1,  idx_date_n: 184,
# idx_date_n: 184 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-06
#
# date: 2023-12-05,  n: 1,  next_date_n: 2023-12-06 is in df_close
# picks for 2023-12-05: ['GPS']
# date = '2023-12-06', l_syms = ['GPS'], ar_price = array([20.94000053]), ar_sym_share = array([47.]), ar_sym_amt = array([984.1800251]), portf_value = 984.180025100708
# 2023-12-06 portf_value = 984.180025100708
# date = '2023-12-06', symbol = 'SPY', price = 454.760009765625, share = 2.0, value = 909.52001953125
# 2023-12-06 SPY value = 909.52001953125
# next_date_n pick's portf value = 984.180025100708
# next_date_n SPY portf value =    909.52001953125
# ====================
#
# date: 2023-12-04 is in idx_close,  date's position in idx_close is: 182 of 191,  n: 1,  idx_date_n: 183,
# idx_date_n: 183 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-05
#
# date: 2023-12-04,  n: 1,  next_date_n: 2023-12-05 is in df_close
# picks for 2023-12-04: ['GPS']
# date = '2023-12-05', l_syms = ['GPS'], ar_price = array([20.78000069]), ar_sym_share = array([48.]), ar_sym_amt = array([997.44003296]), portf_value = 997.4400329589844
# 2023-12-05 portf_value = 997.4400329589844
# date = '2023-12-05', symbol = 'SPY', price = 456.6000061035156, share = 2.0, value = 913.2000122070312
# 2023-12-05 SPY value = 913.2000122070312
# next_date_n pick's portf value = 997.4400329589844
# next_date_n SPY portf value =    913.2000122070312
# ====================
#
# date: 2023-12-04 is in idx_close,  date's position in idx_close is: 182 of 191,  n: 1,  idx_date_n: 183,
# idx_date_n: 183 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-05
#
# date: 2023-12-04,  n: 1,  next_date_n: 2023-12-05 is in df_close
# picks for 2023-12-04: ['SHV']
# date = '2023-12-05', l_syms = ['SHV'], ar_price = array([109.66664124]), ar_sym_share = array([9.]), ar_sym_amt = array([986.99977112]), portf_value = 986.9997711181641
# 2023-12-05 portf_value = 986.9997711181641
# date = '2023-12-05', symbol = 'SPY', price = 456.6000061035156, share = 2.0, value = 913.2000122070312
# 2023-12-05 SPY value = 913.2000122070312
# next_date_n pick's portf value = 986.9997711181641
# next_date_n SPY portf value =    913.2000122070312
# ====================
#
# date: 2023-12-04 is in idx_close,  date's position in idx_close is: 182 of 191,  n: 1,  idx_date_n: 183,
# idx_date_n: 183 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-05
#
# date: 2023-12-04,  n: 1,  next_date_n: 2023-12-05 is in df_close
# picks for 2023-12-04: ['GPS']
# date = '2023-12-05', l_syms = ['GPS'], ar_price = array([20.78000069]), ar_sym_share = array([48.]), ar_sym_amt = array([997.44003296]), portf_value = 997.4400329589844
# 2023-12-05 portf_value = 997.4400329589844
# date = '2023-12-05', symbol = 'SPY', price = 456.6000061035156, share = 2.0, value = 913.2000122070312
# 2023-12-05 SPY value = 913.2000122070312
# next_date_n pick's portf value = 997.4400329589844
# next_date_n SPY portf value =    913.2000122070312
# ====================
#
# date: 2023-12-01 is in idx_close,  date's position in idx_close is: 181 of 191,  n: 1,  idx_date_n: 182,
# idx_date_n: 182 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-04
#
# date: 2023-12-01,  n: 1,  next_date_n: 2023-12-04 is in df_close
# picks for 2023-12-01: ['GPS']
# date = '2023-12-04', l_syms = ['GPS'], ar_price = array([20.84000015]), ar_sym_share = array([47.]), ar_sym_amt = array([979.48000717]), portf_value = 979.4800071716309
# 2023-12-04 portf_value = 979.4800071716309
# date = '2023-12-04', symbol = 'SPY', price = 456.69000244140625, share = 2.0, value = 913.3800048828125
# 2023-12-04 SPY value = 913.3800048828125
# next_date_n pick's portf value = 979.4800071716309
# next_date_n SPY portf value =    913.3800048828125
# ====================
#
# date: 2023-12-01 is in idx_close,  date's position in idx_close is: 181 of 191,  n: 1,  idx_date_n: 182,
# idx_date_n: 182 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-04
#
# date: 2023-12-01,  n: 1,  next_date_n: 2023-12-04 is in df_close
# picks for 2023-12-01: ['FTSM', 'SHV']
# date = '2023-12-04', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.61000061, 109.64673615]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([476.88000488, 438.58694458]), portf_value = 915.4669494628906
# 2023-12-04 portf_value = 915.4669494628906
# date = '2023-12-04', symbol = 'SPY', price = 456.69000244140625, share = 2.0, value = 913.3800048828125
# 2023-12-04 SPY value = 913.3800048828125
# next_date_n pick's portf value = 915.4669494628906
# next_date_n SPY portf value =    913.3800048828125
# ====================
#
# date: 2023-12-01 is in idx_close,  date's position in idx_close is: 181 of 191,  n: 1,  idx_date_n: 182,
# idx_date_n: 182 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-04
#
# date: 2023-12-01,  n: 1,  next_date_n: 2023-12-04 is in df_close
# picks for 2023-12-01: ['GPS']
# date = '2023-12-04', l_syms = ['GPS'], ar_price = array([20.84000015]), ar_sym_share = array([47.]), ar_sym_amt = array([979.48000717]), portf_value = 979.4800071716309
# 2023-12-04 portf_value = 979.4800071716309
# date = '2023-12-04', symbol = 'SPY', price = 456.69000244140625, share = 2.0, value = 913.3800048828125
# 2023-12-04 SPY value = 913.3800048828125
# next_date_n pick's portf value = 979.4800071716309
# next_date_n SPY portf value =    913.3800048828125
# ====================
#
# date: 2023-11-30 is in idx_close,  date's position in idx_close is: 180 of 191,  n: 1,  idx_date_n: 181,
# idx_date_n: 181 is wiithin bounds of idx_close (0 to 191), date_n: 2023-12-01
#
# date: 2023-11-30,  n: 1,  next_date_n: 2023-12-01 is in df_close
# picks for 2023-11-30: ['GPS', 'SHV']
# date = '2023-12-01', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.02000046, 109.63677979]), ar_sym_share = array([23.,  4.]), ar_sym_amt = array([483.46001053, 438.54711914]), portf_value = 922.0071296691895
# 2023-12-01 portf_value = 922.0071296691895
# date = '2023-12-01', symbol = 'SPY', price = 459.1000061035156, share = 2.0, value = 918.2000122070312
# 2023-12-01 SPY value = 918.2000122070312
# next_date_n pick's portf value = 922.0071296691895
# next_date_n SPY portf value =    918.2000122070312
# ====================
#
# date: 2023-11-29 is in idx_close,  date's position in idx_close is: 179 of 191,  n: 1,  idx_date_n: 180,
# idx_date_n: 180 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-30
#
# date: 2023-11-29,  n: 1,  next_date_n: 2023-11-30 is in df_close
# picks for 2023-11-29: ['FTSM', 'GPS', 'SHV']
# date = '2023-11-30', l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = array([ 59.56000137,  20.06999969, 109.60192871]), ar_sym_share = array([ 5., 16.,  3.]), ar_sym_amt = array([297.80000687, 321.11999512, 328.80578613]), portf_value = 947.7257881164551
# 2023-11-30 portf_value = 947.7257881164551
# date = '2023-11-30', symbol = 'SPY', price = 456.3999938964844, share = 2.0, value = 912.7999877929688
# 2023-11-30 SPY value = 912.7999877929688
# next_date_n pick's portf value = 947.7257881164551
# next_date_n SPY portf value =    912.7999877929688
# ====================
#
# date: 2023-11-28 is in idx_close,  date's position in idx_close is: 178 of 191,  n: 1,  idx_date_n: 179,
# idx_date_n: 179 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-29
#
# date: 2023-11-28,  n: 1,  next_date_n: 2023-11-29 is in df_close
# picks for 2023-11-28: ['SHV']
# date = '2023-11-29', l_syms = ['SHV'], ar_price = array([109.56229401]), ar_sym_share = array([9.]), ar_sym_amt = array([986.06064606]), portf_value = 986.0606460571289
# 2023-11-29 portf_value = 986.0606460571289
# date = '2023-11-29', symbol = 'SPY', price = 454.6099853515625, share = 2.0, value = 909.219970703125
# 2023-11-29 SPY value = 909.219970703125
# next_date_n pick's portf value = 986.0606460571289
# next_date_n SPY portf value =    909.219970703125
# ====================
#
# date: 2023-11-28 is in idx_close,  date's position in idx_close is: 178 of 191,  n: 1,  idx_date_n: 179,
# idx_date_n: 179 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-29
#
# date: 2023-11-28,  n: 1,  next_date_n: 2023-11-29 is in df_close
# picks for 2023-11-28: ['FTSM', 'GPS']
# date = '2023-11-29', l_syms = ['FTSM', 'GPS'], ar_price = array([59.53699875, 20.15999985]), ar_sym_share = array([ 8., 24.]), ar_sym_amt = array([476.29598999, 483.83999634]), portf_value = 960.135986328125
# 2023-11-29 portf_value = 960.135986328125
# date = '2023-11-29', symbol = 'SPY', price = 454.6099853515625, share = 2.0, value = 909.219970703125
# 2023-11-29 SPY value = 909.219970703125
# next_date_n pick's portf value = 960.135986328125
# next_date_n SPY portf value =    909.219970703125
# ====================
#
# date: 2023-11-27 is in idx_close,  date's position in idx_close is: 177 of 191,  n: 1,  idx_date_n: 178,
# idx_date_n: 178 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-28
#
# date: 2023-11-27,  n: 1,  next_date_n: 2023-11-28 is in df_close
# picks for 2023-11-27: ['FTSM', 'GPS', 'SHV']
# date = '2023-11-28', l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = array([ 59.52703857,  19.54999924, 109.54247284]), ar_sym_share = array([ 5., 17.,  3.]), ar_sym_amt = array([297.63519287, 332.34998703, 328.62741852]), portf_value = 958.6125984191895
# 2023-11-28 portf_value = 958.6125984191895
# date = '2023-11-28', symbol = 'SPY', price = 454.92999267578125, share = 2.0, value = 909.8599853515625
# 2023-11-28 SPY value = 909.8599853515625
# next_date_n pick's portf value = 958.6125984191895
# next_date_n SPY portf value =    909.8599853515625
# ====================
#
# date: 2023-11-24 is in idx_close,  date's position in idx_close is: 176 of 191,  n: 1,  idx_date_n: 177,
# idx_date_n: 177 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-27
#
# date: 2023-11-24,  n: 1,  next_date_n: 2023-11-27 is in df_close
# picks for 2023-11-24: ['GPS', 'SHV']
# date = '2023-11-27', l_syms = ['GPS', 'SHV'], ar_price = array([ 19.44000053, 109.51274109]), ar_sym_share = array([25.,  4.]), ar_sym_amt = array([486.00001335, 438.05096436]), portf_value = 924.0509777069092
# 2023-11-27 portf_value = 924.0509777069092
# date = '2023-11-27', symbol = 'SPY', price = 454.4800109863281, share = 2.0, value = 908.9600219726562
# 2023-11-27 SPY value = 908.9600219726562
# next_date_n pick's portf value = 924.0509777069092
# next_date_n SPY portf value =    908.9600219726562
# ====================
#
# date: 2023-11-22 is in idx_close,  date's position in idx_close is: 175 of 191,  n: 1,  idx_date_n: 176,
# idx_date_n: 176 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-24
#
# date: 2023-11-22,  n: 1,  next_date_n: 2023-11-24 is in df_close
# picks for 2023-11-22: ['GPS', 'SHV']
# date = '2023-11-24', l_syms = ['GPS', 'SHV'], ar_price = array([ 18.86000061, 109.49291992]), ar_sym_share = array([26.,  4.]), ar_sym_amt = array([490.36001587, 437.97167969]), portf_value = 928.3316955566406
# 2023-11-24 portf_value = 928.3316955566406
# date = '2023-11-24', symbol = 'SPY', price = 455.29998779296875, share = 2.0, value = 910.5999755859375
# 2023-11-24 SPY value = 910.5999755859375
# next_date_n pick's portf value = 928.3316955566406
# next_date_n SPY portf value =    910.5999755859375
# ====================
#
# date: 2023-11-21 is in idx_close,  date's position in idx_close is: 174 of 191,  n: 1,  idx_date_n: 175,
# idx_date_n: 175 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-22
#
# date: 2023-11-21,  n: 1,  next_date_n: 2023-11-22 is in df_close
# picks for 2023-11-21: ['SHV']
# date = '2023-11-22', l_syms = ['SHV'], ar_price = array([109.48300934]), ar_sym_share = array([9.]), ar_sym_amt = array([985.34708405]), portf_value = 985.3470840454102
# 2023-11-22 portf_value = 985.3470840454102
# date = '2023-11-22', symbol = 'SPY', price = 455.0199890136719, share = 2.0, value = 910.0399780273438
# 2023-11-22 SPY value = 910.0399780273438
# next_date_n pick's portf value = 985.3470840454102
# next_date_n SPY portf value =    910.0399780273438
# ====================
#
# date: 2023-11-21 is in idx_close,  date's position in idx_close is: 174 of 191,  n: 1,  idx_date_n: 175,
# idx_date_n: 175 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-22
#
# date: 2023-11-21,  n: 1,  next_date_n: 2023-11-22 is in df_close
# picks for 2023-11-21: ['FTSM', 'GPS']
# date = '2023-11-22', l_syms = ['FTSM', 'GPS'], ar_price = array([59.44736481, 18.79999924]), ar_sym_share = array([ 8., 26.]), ar_sym_amt = array([475.57891846, 488.79998016]), portf_value = 964.3788986206055
# 2023-11-22 portf_value = 964.3788986206055
# date = '2023-11-22', symbol = 'SPY', price = 455.0199890136719, share = 2.0, value = 910.0399780273438
# 2023-11-22 SPY value = 910.0399780273438
# next_date_n pick's portf value = 964.3788986206055
# next_date_n SPY portf value =    910.0399780273438
# ====================
#
# date: 2023-11-20 is in idx_close,  date's position in idx_close is: 173 of 191,  n: 1,  idx_date_n: 174,
# idx_date_n: 174 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-21
#
# date: 2023-11-20,  n: 1,  next_date_n: 2023-11-21 is in df_close
# picks for 2023-11-20: ['SHV']
# date = '2023-11-21', l_syms = ['SHV'], ar_price = array([109.443367]), ar_sym_share = array([9.]), ar_sym_amt = array([984.99030304]), portf_value = 984.9903030395508
# 2023-11-21 portf_value = 984.9903030395508
# date = '2023-11-21', symbol = 'SPY', price = 453.2699890136719, share = 2.0, value = 906.5399780273438
# 2023-11-21 SPY value = 906.5399780273438
# next_date_n pick's portf value = 984.9903030395508
# next_date_n SPY portf value =    906.5399780273438
# ====================
#
# date: 2023-11-20 is in idx_close,  date's position in idx_close is: 173 of 191,  n: 1,  idx_date_n: 174,
# idx_date_n: 174 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-21
#
# date: 2023-11-20,  n: 1,  next_date_n: 2023-11-21 is in df_close
# picks for 2023-11-20: ['FTSM', 'GPS', 'NRG']
# date = '2023-11-21', l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = array([59.4174881 , 18.89999962, 45.20000076]), ar_sym_share = array([ 5., 17.,  7.]), ar_sym_amt = array([297.08744049, 321.29999352, 316.40000534]), portf_value = 934.7874393463135
# 2023-11-21 portf_value = 934.7874393463135
# date = '2023-11-21', symbol = 'SPY', price = 453.2699890136719, share = 2.0, value = 906.5399780273438
# 2023-11-21 SPY value = 906.5399780273438
# next_date_n pick's portf value = 934.7874393463135
# next_date_n SPY portf value =    906.5399780273438
# ====================
#
# date: 2023-11-17 is in idx_close,  date's position in idx_close is: 172 of 191,  n: 1,  idx_date_n: 173,
# idx_date_n: 173 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-20
#
# date: 2023-11-17,  n: 1,  next_date_n: 2023-11-20 is in df_close
# picks for 2023-11-17: ['SHV']
# date = '2023-11-20', l_syms = ['SHV'], ar_price = array([109.40372467]), ar_sym_share = array([9.]), ar_sym_amt = array([984.63352203]), portf_value = 984.6335220336914
# 2023-11-20 portf_value = 984.6335220336914
# date = '2023-11-20', symbol = 'SPY', price = 454.260009765625, share = 2.0, value = 908.52001953125
# 2023-11-20 SPY value = 908.52001953125
# next_date_n pick's portf value = 984.6335220336914
# next_date_n SPY portf value =    908.52001953125
# ====================
#
# date: 2023-11-17 is in idx_close,  date's position in idx_close is: 172 of 191,  n: 1,  idx_date_n: 173,
# idx_date_n: 173 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-20
#
# date: 2023-11-17,  n: 1,  next_date_n: 2023-11-20 is in df_close
# picks for 2023-11-17: ['FTSM', 'GPS', 'NRG']
# date = '2023-11-20', l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = array([59.40752792, 18.43000031, 47.29000092]), ar_sym_share = array([ 5., 18.,  7.]), ar_sym_amt = array([297.03763962, 331.74000549, 331.03000641]), portf_value = 959.8076515197754
# 2023-11-20 portf_value = 959.8076515197754
# date = '2023-11-20', symbol = 'SPY', price = 454.260009765625, share = 2.0, value = 908.52001953125
# 2023-11-20 SPY value = 908.52001953125
# next_date_n pick's portf value = 959.8076515197754
# next_date_n SPY portf value =    908.52001953125
# ====================
#
# date: 2023-11-16 is in idx_close,  date's position in idx_close is: 171 of 191,  n: 1,  idx_date_n: 172,
# idx_date_n: 172 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-17
#
# date: 2023-11-16,  n: 1,  next_date_n: 2023-11-17 is in df_close
# picks for 2023-11-16: ['SHV']
# date = '2023-11-17', l_syms = ['SHV'], ar_price = array([109.39380646]), ar_sym_share = array([9.]), ar_sym_amt = array([984.54425812]), portf_value = 984.5442581176758
# 2023-11-17 portf_value = 984.5442581176758
# date = '2023-11-17', symbol = 'SPY', price = 450.7900085449219, share = 2.0, value = 901.5800170898438
# 2023-11-17 SPY value = 901.5800170898438
# next_date_n pick's portf value = 984.5442581176758
# next_date_n SPY portf value =    901.5800170898438
# ====================
#
# date: 2023-11-16 is in idx_close,  date's position in idx_close is: 171 of 191,  n: 1,  idx_date_n: 172,
# idx_date_n: 172 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-17
#
# date: 2023-11-16,  n: 1,  next_date_n: 2023-11-17 is in df_close
# picks for 2023-11-16: ['FTSM', 'NRG']
# date = '2023-11-17', l_syms = ['FTSM', 'NRG'], ar_price = array([59.38761139, 48.08000183]), ar_sym_share = array([ 8., 10.]), ar_sym_amt = array([475.10089111, 480.80001831]), portf_value = 955.9009094238281
# 2023-11-17 portf_value = 955.9009094238281
# date = '2023-11-17', symbol = 'SPY', price = 450.7900085449219, share = 2.0, value = 901.5800170898438
# 2023-11-17 SPY value = 901.5800170898438
# next_date_n pick's portf value = 955.9009094238281
# next_date_n SPY portf value =    901.5800170898438
# ====================
#
# date: 2023-11-15 is in idx_close,  date's position in idx_close is: 170 of 191,  n: 1,  idx_date_n: 171,
# idx_date_n: 171 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-16
#
# date: 2023-11-15,  n: 1,  next_date_n: 2023-11-16 is in df_close
# picks for 2023-11-15: ['SHV']
# date = '2023-11-16', l_syms = ['SHV'], ar_price = array([109.3839035]), ar_sym_share = array([9.]), ar_sym_amt = array([984.45513153]), portf_value = 984.4551315307617
# 2023-11-16 portf_value = 984.4551315307617
# date = '2023-11-16', symbol = 'SPY', price = 450.2300109863281, share = 2.0, value = 900.4600219726562
# 2023-11-16 SPY value = 900.4600219726562
# next_date_n pick's portf value = 984.4551315307617
# next_date_n SPY portf value =    900.4600219726562
# ====================
#
# date: 2023-11-15 is in idx_close,  date's position in idx_close is: 170 of 191,  n: 1,  idx_date_n: 171,
# idx_date_n: 171 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-16
#
# date: 2023-11-15,  n: 1,  next_date_n: 2023-11-16 is in df_close
# picks for 2023-11-15: ['FTSM', 'NRG']
# date = '2023-11-16', l_syms = ['FTSM', 'NRG'], ar_price = array([59.3776474 , 47.56999969]), ar_sym_share = array([ 8., 10.]), ar_sym_amt = array([475.0211792 , 475.69999695]), portf_value = 950.7211761474609
# 2023-11-16 portf_value = 950.7211761474609
# date = '2023-11-16', symbol = 'SPY', price = 450.2300109863281, share = 2.0, value = 900.4600219726562
# 2023-11-16 SPY value = 900.4600219726562
# next_date_n pick's portf value = 950.7211761474609
# next_date_n SPY portf value =    900.4600219726562
# ====================
#
# date: 2023-11-14 is in idx_close,  date's position in idx_close is: 169 of 191,  n: 1,  idx_date_n: 170,
# idx_date_n: 170 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-15
#
# date: 2023-11-14,  n: 1,  next_date_n: 2023-11-15 is in df_close
# picks for 2023-11-14: ['SHV']
# date = '2023-11-15', l_syms = ['SHV'], ar_price = array([109.32443237]), ar_sym_share = array([9.]), ar_sym_amt = array([983.91989136]), portf_value = 983.9198913574219
# 2023-11-15 portf_value = 983.9198913574219
# date = '2023-11-15', symbol = 'SPY', price = 449.67999267578125, share = 2.0, value = 899.3599853515625
# 2023-11-15 SPY value = 899.3599853515625
# next_date_n pick's portf value = 983.9198913574219
# next_date_n SPY portf value =    899.3599853515625
# ====================
#
# date: 2023-11-14 is in idx_close,  date's position in idx_close is: 169 of 191,  n: 1,  idx_date_n: 170,
# idx_date_n: 170 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-15
#
# date: 2023-11-14,  n: 1,  next_date_n: 2023-11-15 is in df_close
# picks for 2023-11-14: ['FTSM', 'NRG']
# date = '2023-11-15', l_syms = ['FTSM', 'NRG'], ar_price = array([59.35773087, 47.50999832]), ar_sym_share = array([ 8., 10.]), ar_sym_amt = array([474.86184692, 475.09998322]), portf_value = 949.9618301391602
# 2023-11-15 portf_value = 949.9618301391602
# date = '2023-11-15', symbol = 'SPY', price = 449.67999267578125, share = 2.0, value = 899.3599853515625
# 2023-11-15 SPY value = 899.3599853515625
# next_date_n pick's portf value = 949.9618301391602
# next_date_n SPY portf value =    899.3599853515625
# ====================
#
# date: 2023-11-13 is in idx_close,  date's position in idx_close is: 168 of 191,  n: 1,  idx_date_n: 169,
# idx_date_n: 169 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-14
#
# date: 2023-11-13,  n: 1,  next_date_n: 2023-11-14 is in df_close
# picks for 2023-11-13: ['FTSM', 'SHV']
# date = '2023-11-14', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.36769104, 109.31452942]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.94152832, 437.25811768]), portf_value = 912.1996459960938
# 2023-11-14 portf_value = 912.1996459960938
# date = '2023-11-14', symbol = 'SPY', price = 448.7300109863281, share = 2.0, value = 897.4600219726562
# 2023-11-14 SPY value = 897.4600219726562
# next_date_n pick's portf value = 912.1996459960938
# next_date_n SPY portf value =    897.4600219726562
# ====================
#
# date: 2023-11-13 is in idx_close,  date's position in idx_close is: 168 of 191,  n: 1,  idx_date_n: 169,
# idx_date_n: 169 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-14
#
# date: 2023-11-13,  n: 1,  next_date_n: 2023-11-14 is in df_close
# picks for 2023-11-13: ['CBOE']
# date = '2023-11-14', l_syms = ['CBOE'], ar_price = array([177.38999939]), ar_sym_share = array([5.]), ar_sym_amt = array([886.94999695]), portf_value = 886.9499969482422
# 2023-11-14 portf_value = 886.9499969482422
# date = '2023-11-14', symbol = 'SPY', price = 448.7300109863281, share = 2.0, value = 897.4600219726562
# 2023-11-14 SPY value = 897.4600219726562
# next_date_n pick's portf value = 886.9499969482422
# next_date_n SPY portf value =    897.4600219726562
# ====================
#
# date: 2023-11-10 is in idx_close,  date's position in idx_close is: 167 of 191,  n: 1,  idx_date_n: 168,
# idx_date_n: 168 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-13
#
# date: 2023-11-10,  n: 1,  next_date_n: 2023-11-13 is in df_close
# picks for 2023-11-10: ['FTSM', 'SHV']
# date = '2023-11-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.31789398, 109.27488708]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.54315186, 437.09954834]), portf_value = 911.6427001953125
# 2023-11-13 portf_value = 911.6427001953125
# date = '2023-11-13', symbol = 'SPY', price = 440.19000244140625, share = 2.0, value = 880.3800048828125
# 2023-11-13 SPY value = 880.3800048828125
# next_date_n pick's portf value = 911.6427001953125
# next_date_n SPY portf value =    880.3800048828125
# ====================
#
# date: 2023-11-10 is in idx_close,  date's position in idx_close is: 167 of 191,  n: 1,  idx_date_n: 168,
# idx_date_n: 168 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-13
#
# date: 2023-11-10,  n: 1,  next_date_n: 2023-11-13 is in df_close
# picks for 2023-11-10: ['CBOE']
# date = '2023-11-13', l_syms = ['CBOE'], ar_price = array([178.47999573]), ar_sym_share = array([5.]), ar_sym_amt = array([892.39997864]), portf_value = 892.3999786376953
# 2023-11-13 portf_value = 892.3999786376953
# date = '2023-11-13', symbol = 'SPY', price = 440.19000244140625, share = 2.0, value = 880.3800048828125
# 2023-11-13 SPY value = 880.3800048828125
# next_date_n pick's portf value = 892.3999786376953
# next_date_n SPY portf value =    880.3800048828125
# ====================
#
# date: 2023-11-09 is in idx_close,  date's position in idx_close is: 166 of 191,  n: 1,  idx_date_n: 167,
# idx_date_n: 167 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-10
#
# date: 2023-11-09,  n: 1,  next_date_n: 2023-11-10 is in df_close
# picks for 2023-11-09: ['FTSM', 'SHV']
# date = '2023-11-10', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.29797745, 109.2649765 ]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.38381958, 437.05990601]), portf_value = 911.4437255859375
# 2023-11-10 portf_value = 911.4437255859375
# date = '2023-11-10', symbol = 'SPY', price = 440.6099853515625, share = 2.0, value = 881.219970703125
# 2023-11-10 SPY value = 881.219970703125
# next_date_n pick's portf value = 911.4437255859375
# next_date_n SPY portf value =    881.219970703125
# ====================
#
# date: 2023-11-09 is in idx_close,  date's position in idx_close is: 166 of 191,  n: 1,  idx_date_n: 167,
# idx_date_n: 167 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-10
#
# date: 2023-11-09,  n: 1,  next_date_n: 2023-11-10 is in df_close
# picks for 2023-11-09: ['CBOE']
# date = '2023-11-10', l_syms = ['CBOE'], ar_price = array([174.97000122]), ar_sym_share = array([5.]), ar_sym_amt = array([874.8500061]), portf_value = 874.8500061035156
# 2023-11-10 portf_value = 874.8500061035156
# date = '2023-11-10', symbol = 'SPY', price = 440.6099853515625, share = 2.0, value = 881.219970703125
# 2023-11-10 SPY value = 881.219970703125
# next_date_n pick's portf value = 874.8500061035156
# next_date_n SPY portf value =    881.219970703125
# ====================
#
# date: 2023-11-08 is in idx_close,  date's position in idx_close is: 165 of 191,  n: 1,  idx_date_n: 166,
# idx_date_n: 166 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-09
#
# date: 2023-11-08,  n: 1,  next_date_n: 2023-11-09 is in df_close
# picks for 2023-11-08: ['FTSM', 'SHV']
# date = '2023-11-09', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.29299545, 109.23524475]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.34396362, 436.940979  ]), portf_value = 911.2849426269531
# 2023-11-09 portf_value = 911.2849426269531
# date = '2023-11-09', symbol = 'SPY', price = 433.8399963378906, share = 2.0, value = 867.6799926757812
# 2023-11-09 SPY value = 867.6799926757812
# next_date_n pick's portf value = 911.2849426269531
# next_date_n SPY portf value =    867.6799926757812
# ====================
#
# date: 2023-11-08 is in idx_close,  date's position in idx_close is: 165 of 191,  n: 1,  idx_date_n: 166,
# idx_date_n: 166 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-09
#
# date: 2023-11-08,  n: 1,  next_date_n: 2023-11-09 is in df_close
# picks for 2023-11-08: ['NRG']
# date = '2023-11-09', l_syms = ['NRG'], ar_price = array([45.06999969]), ar_sym_share = array([22.]), ar_sym_amt = array([991.53999329]), portf_value = 991.5399932861328
# 2023-11-09 portf_value = 991.5399932861328
# date = '2023-11-09', symbol = 'SPY', price = 433.8399963378906, share = 2.0, value = 867.6799926757812
# 2023-11-09 SPY value = 867.6799926757812
# next_date_n pick's portf value = 991.5399932861328
# next_date_n SPY portf value =    867.6799926757812
# ====================
#
# date: 2023-11-07 is in idx_close,  date's position in idx_close is: 164 of 191,  n: 1,  idx_date_n: 165,
# idx_date_n: 165 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-08
#
# date: 2023-11-07,  n: 1,  next_date_n: 2023-11-08 is in df_close
# picks for 2023-11-07: ['FTSM', 'SHV']
# date = '2023-11-08', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2780571 , 109.19560242]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.22445679, 436.78240967]), portf_value = 911.0068664550781
# 2023-11-08 portf_value = 911.0068664550781
# date = '2023-11-08', symbol = 'SPY', price = 437.25, share = 2.0, value = 874.5
# 2023-11-08 SPY value = 874.5
# next_date_n pick's portf value = 911.0068664550781
# next_date_n SPY portf value =    874.5
# ====================
#
# date: 2023-11-07 is in idx_close,  date's position in idx_close is: 164 of 191,  n: 1,  idx_date_n: 165,
# idx_date_n: 165 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-08
#
# date: 2023-11-07,  n: 1,  next_date_n: 2023-11-08 is in df_close
# picks for 2023-11-07: ['NRG']
# date = '2023-11-08', l_syms = ['NRG'], ar_price = array([45.68000031]), ar_sym_share = array([21.]), ar_sym_amt = array([959.28000641]), portf_value = 959.2800064086914
# 2023-11-08 portf_value = 959.2800064086914
# date = '2023-11-08', symbol = 'SPY', price = 437.25, share = 2.0, value = 874.5
# 2023-11-08 SPY value = 874.5
# next_date_n pick's portf value = 959.2800064086914
# next_date_n SPY portf value =    874.5
# ====================
#
# date: 2023-11-06 is in idx_close,  date's position in idx_close is: 163 of 191,  n: 1,  idx_date_n: 164,
# idx_date_n: 164 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-07
#
# date: 2023-11-06,  n: 1,  next_date_n: 2023-11-07 is in df_close
# picks for 2023-11-06: ['FTSM', 'SHV']
# date = '2023-11-07', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.28801346, 109.18569183]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.30410767, 436.74276733]), portf_value = 911.046875
# 2023-11-07 portf_value = 911.046875
# date = '2023-11-07', symbol = 'SPY', price = 436.92999267578125, share = 2.0, value = 873.8599853515625
# 2023-11-07 SPY value = 873.8599853515625
# next_date_n pick's portf value = 911.046875
# next_date_n SPY portf value =    873.8599853515625
# ====================
#
# date: 2023-11-06 is in idx_close,  date's position in idx_close is: 163 of 191,  n: 1,  idx_date_n: 164,
# idx_date_n: 164 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-07
#
# date: 2023-11-06,  n: 1,  next_date_n: 2023-11-07 is in df_close
# picks for 2023-11-06: ['NRG']
# date = '2023-11-07', l_syms = ['NRG'], ar_price = array([45.41999817]), ar_sym_share = array([22.]), ar_sym_amt = array([999.23995972]), portf_value = 999.2399597167969
# 2023-11-07 portf_value = 999.2399597167969
# date = '2023-11-07', symbol = 'SPY', price = 436.92999267578125, share = 2.0, value = 873.8599853515625
# 2023-11-07 SPY value = 873.8599853515625
# next_date_n pick's portf value = 999.2399597167969
# next_date_n SPY portf value =    873.8599853515625
# ====================
#
# date: 2023-11-03 is in idx_close,  date's position in idx_close is: 162 of 191,  n: 1,  idx_date_n: 163,
# idx_date_n: 163 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-06
#
# date: 2023-11-03,  n: 1,  next_date_n: 2023-11-06 is in df_close
# picks for 2023-11-03: ['FTSM', 'SHV']
# date = '2023-11-06', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2780571 , 109.15596008]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.22445679, 436.62384033]), portf_value = 910.8482971191406
# 2023-11-06 portf_value = 910.8482971191406
# date = '2023-11-06', symbol = 'SPY', price = 435.69000244140625, share = 2.0, value = 871.3800048828125
# 2023-11-06 SPY value = 871.3800048828125
# next_date_n pick's portf value = 910.8482971191406
# next_date_n SPY portf value =    871.3800048828125
# ====================
#
# date: 2023-11-03 is in idx_close,  date's position in idx_close is: 162 of 191,  n: 1,  idx_date_n: 163,
# idx_date_n: 163 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-06
#
# date: 2023-11-03,  n: 1,  next_date_n: 2023-11-06 is in df_close
# picks for 2023-11-03: ['ANF']
# date = '2023-11-06', l_syms = ['ANF'], ar_price = array([66.26999664]), ar_sym_share = array([15.]), ar_sym_amt = array([994.04994965]), portf_value = 994.0499496459961
# 2023-11-06 portf_value = 994.0499496459961
# date = '2023-11-06', symbol = 'SPY', price = 435.69000244140625, share = 2.0, value = 871.3800048828125
# 2023-11-06 SPY value = 871.3800048828125
# next_date_n pick's portf value = 994.0499496459961
# next_date_n SPY portf value =    871.3800048828125
# ====================
#
# date: 2023-11-02 is in idx_close,  date's position in idx_close is: 161 of 191,  n: 1,  idx_date_n: 162,
# idx_date_n: 162 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-03
#
# date: 2023-11-02,  n: 1,  next_date_n: 2023-11-03 is in df_close
# picks for 2023-11-02: ['FTSM', 'SHV']
# date = '2023-11-03', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2730751 , 109.16587067]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.18460083, 436.66348267]), portf_value = 910.8480834960938
# 2023-11-03 portf_value = 910.8480834960938
# date = '2023-11-03', symbol = 'SPY', price = 434.69000244140625, share = 2.0, value = 869.3800048828125
# 2023-11-03 SPY value = 869.3800048828125
# next_date_n pick's portf value = 910.8480834960938
# next_date_n SPY portf value =    869.3800048828125
# ====================
#
# date: 2023-11-02 is in idx_close,  date's position in idx_close is: 161 of 191,  n: 1,  idx_date_n: 162,
# idx_date_n: 162 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-03
#
# date: 2023-11-02,  n: 1,  next_date_n: 2023-11-03 is in df_close
# picks for 2023-11-02: ['ANF']
# date = '2023-11-03', l_syms = ['ANF'], ar_price = array([65.5]), ar_sym_share = array([15.]), ar_sym_amt = array([982.5]), portf_value = 982.5
# 2023-11-03 portf_value = 982.5
# date = '2023-11-03', symbol = 'SPY', price = 434.69000244140625, share = 2.0, value = 869.3800048828125
# 2023-11-03 SPY value = 869.3800048828125
# next_date_n pick's portf value = 982.5
# next_date_n SPY portf value =    869.3800048828125
# ====================
#
# date: 2023-11-01 is in idx_close,  date's position in idx_close is: 160 of 191,  n: 1,  idx_date_n: 161,
# idx_date_n: 161 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-02
#
# date: 2023-11-01,  n: 1,  next_date_n: 2023-11-02 is in df_close
# picks for 2023-11-01: ['FTSM']
# date = '2023-11-02', l_syms = ['FTSM'], ar_price = array([59.25813675]), ar_sym_share = array([16.]), ar_sym_amt = array([948.13018799]), portf_value = 948.1301879882812
# 2023-11-02 portf_value = 948.1301879882812
# date = '2023-11-02', symbol = 'SPY', price = 430.760009765625, share = 2.0, value = 861.52001953125
# 2023-11-02 SPY value = 861.52001953125
# next_date_n pick's portf value = 948.1301879882812
# next_date_n SPY portf value =    861.52001953125
# ====================
#
# date: 2023-11-01 is in idx_close,  date's position in idx_close is: 160 of 191,  n: 1,  idx_date_n: 161,
# idx_date_n: 161 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-02
#
# date: 2023-11-01,  n: 1,  next_date_n: 2023-11-02 is in df_close
# picks for 2023-11-01: ['ANF']
# date = '2023-11-02', l_syms = ['ANF'], ar_price = array([63.31000137]), ar_sym_share = array([15.]), ar_sym_amt = array([949.6500206]), portf_value = 949.6500205993652
# 2023-11-02 portf_value = 949.6500205993652
# date = '2023-11-02', symbol = 'SPY', price = 430.760009765625, share = 2.0, value = 861.52001953125
# 2023-11-02 SPY value = 861.52001953125
# next_date_n pick's portf value = 949.6500205993652
# next_date_n SPY portf value =    861.52001953125
# ====================
#
# date: 2023-10-31 is in idx_close,  date's position in idx_close is: 159 of 191,  n: 1,  idx_date_n: 160,
# idx_date_n: 160 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-01
#
# date: 2023-10-31,  n: 1,  next_date_n: 2023-11-01 is in df_close
# picks for 2023-10-31: ['SHV']
# date = '2023-11-01', l_syms = ['SHV'], ar_price = array([109.086586]), ar_sym_share = array([9.]), ar_sym_amt = array([981.77927399]), portf_value = 981.7792739868164
# 2023-11-01 portf_value = 981.7792739868164
# date = '2023-11-01', symbol = 'SPY', price = 422.6600036621094, share = 2.0, value = 845.3200073242188
# 2023-11-01 SPY value = 845.3200073242188
# next_date_n pick's portf value = 981.7792739868164
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date: 2023-10-31 is in idx_close,  date's position in idx_close is: 159 of 191,  n: 1,  idx_date_n: 160,
# idx_date_n: 160 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-01
#
# date: 2023-10-31,  n: 1,  next_date_n: 2023-11-01 is in df_close
# picks for 2023-10-31: ['FTSM', 'SHV']
# date = '2023-11-01', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.21829987, 109.086586  ]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.74639893, 436.34634399]), portf_value = 910.0927429199219
# 2023-11-01 portf_value = 910.0927429199219
# date = '2023-11-01', symbol = 'SPY', price = 422.6600036621094, share = 2.0, value = 845.3200073242188
# 2023-11-01 SPY value = 845.3200073242188
# next_date_n pick's portf value = 910.0927429199219
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date: 2023-10-31 is in idx_close,  date's position in idx_close is: 159 of 191,  n: 1,  idx_date_n: 160,
# idx_date_n: 160 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-01
#
# date: 2023-10-31,  n: 1,  next_date_n: 2023-11-01 is in df_close
# picks for 2023-10-31: ['ANF', 'SPLK']
# date = '2023-11-01', l_syms = ['ANF', 'SPLK'], ar_price = array([ 62.13000107, 146.88000488]), ar_sym_share = array([8., 3.]), ar_sym_amt = array([497.04000854, 440.64001465]), portf_value = 937.6800231933594
# 2023-11-01 portf_value = 937.6800231933594
# date = '2023-11-01', symbol = 'SPY', price = 422.6600036621094, share = 2.0, value = 845.3200073242188
# 2023-11-01 SPY value = 845.3200073242188
# next_date_n pick's portf value = 937.6800231933594
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date: 2023-10-31 is in idx_close,  date's position in idx_close is: 159 of 191,  n: 1,  idx_date_n: 160,
# idx_date_n: 160 is wiithin bounds of idx_close (0 to 191), date_n: 2023-11-01
#
# date: 2023-10-31,  n: 1,  next_date_n: 2023-11-01 is in df_close
# picks for 2023-10-31: ['SHV']
# date = '2023-11-01', l_syms = ['SHV'], ar_price = array([109.086586]), ar_sym_share = array([9.]), ar_sym_amt = array([981.77927399]), portf_value = 981.7792739868164
# 2023-11-01 portf_value = 981.7792739868164
# date = '2023-11-01', symbol = 'SPY', price = 422.6600036621094, share = 2.0, value = 845.3200073242188
# 2023-11-01 SPY value = 845.3200073242188
# next_date_n pick's portf value = 981.7792739868164
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date: 2023-10-30 is in idx_close,  date's position in idx_close is: 158 of 191,  n: 1,  idx_date_n: 159,
# idx_date_n: 159 is wiithin bounds of idx_close (0 to 191), date_n: 2023-10-31
#
# date: 2023-10-30,  n: 1,  next_date_n: 2023-10-31 is in df_close
# picks for 2023-10-30: ['FTSM', 'SHV']
# date = '2023-10-31', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.18842316, 109.04891968]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.50738525, 436.19567871]), portf_value = 909.7030639648438
# 2023-10-31 portf_value = 909.7030639648438
# date = '2023-10-31', symbol = 'SPY', price = 418.20001220703125, share = 2.0, value = 836.4000244140625
# 2023-10-31 SPY value = 836.4000244140625
# next_date_n pick's portf value = 909.7030639648438
# next_date_n SPY portf value =    836.4000244140625
# ====================
#
# date: 2023-10-30 is in idx_close,  date's position in idx_close is: 158 of 191,  n: 1,  idx_date_n: 159,
# idx_date_n: 159 is wiithin bounds of idx_close (0 to 191), date_n: 2023-10-31
#
# date: 2023-10-30,  n: 1,  next_date_n: 2023-10-31 is in df_close
# picks for 2023-10-30: ['SPLK']
# date = '2023-10-31', l_syms = ['SPLK'], ar_price = array([147.16000366]), ar_sym_share = array([6.]), ar_sym_amt = array([882.96002197]), portf_value = 882.9600219726562
# 2023-10-31 portf_value = 882.9600219726562
# date = '2023-10-31', symbol = 'SPY', price = 418.20001220703125, share = 2.0, value = 836.4000244140625
# 2023-10-31 SPY value = 836.4000244140625
# next_date_n pick's portf value = 882.9600219726562
# next_date_n SPY portf value =    836.4000244140625
# ====================
#
# date: 2023-10-30 is in idx_close,  date's position in idx_close is: 158 of 191,  n: 1,  idx_date_n: 159,
# idx_date_n: 159 is wiithin bounds of idx_close (0 to 191), date_n: 2023-10-31
#
# date: 2023-10-30,  n: 1,  next_date_n: 2023-10-31 is in df_close
# picks for 2023-10-30: ['FTSM', 'SHV']
# date = '2023-10-31', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.18842316, 109.04891968]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.50738525, 436.19567871]), portf_value = 909.7030639648438
# 2023-10-31 portf_value = 909.7030639648438
# date = '2023-10-31', symbol = 'SPY', price = 418.20001220703125, share = 2.0, value = 836.4000244140625
# 2023-10-31 SPY value = 836.4000244140625
# next_date_n pick's portf value = 909.7030639648438
# next_date_n SPY portf value =    836.4000244140625
# ====================
#
# date: 2023-10-27 is in idx_close,  date's position in idx_close is: 157 of 191,  n: 1,  idx_date_n: 158,
# idx_date_n: 158 is wiithin bounds of idx_close (0 to 191), date_n: 2023-10-30
#
# date: 2023-10-27,  n: 1,  next_date_n: 2023-10-30 is in df_close
# picks for 2023-10-27: ['FTSM', 'SHV']
# date = '2023-10-30', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.19937897, 109.04891968]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.59503174, 436.19567871]), portf_value = 909.7907104492188
# 2023-10-30 portf_value = 909.7907104492188
# date = '2023-10-30', symbol = 'SPY', price = 415.5899963378906, share = 2.0, value = 831.1799926757812
# 2023-10-30 SPY value = 831.1799926757812
# next_date_n pick's portf value = 909.7907104492188
# next_date_n SPY portf value =    831.1799926757812
# ====================
#
# date: 2023-10-27 is in idx_close,  date's position in idx_close is: 157 of 191,  n: 1,  idx_date_n: 158,
# idx_date_n: 158 is wiithin bounds of idx_close (0 to 191), date_n: 2023-10-30
#
# date: 2023-10-27,  n: 1,  next_date_n: 2023-10-30 is in df_close
# picks for 2023-10-27: ['SPLK']
# date = '2023-10-30', l_syms = ['SPLK'], ar_price = array([147.19999695]), ar_sym_share = array([6.]), ar_sym_amt = array([883.19998169]), portf_value = 883.1999816894531
# 2023-10-30 portf_value = 883.1999816894531
# ...
#
# date: 2023-04-05,  n: 1,  next_date_n: 2023-04-06 is in df_close
# picks for 2023-04-05: ['SHV']
# date = '2023-04-06', l_syms = ['SHV'], ar_price = array([106.11650848]), ar_sym_share = array([9.]), ar_sym_amt = array([955.04857635]), portf_value = 955.0485763549805
# 2023-04-06 portf_value = 955.0485763549805
# date = '2023-04-06', symbol = 'SPY', price = 406.24267578125, share = 2.0, value = 812.4853515625
# 2023-04-06 SPY value = 812.4853515625
# next_date_n pick's portf value = 955.0485763549805
# next_date_n SPY portf value =    812.4853515625
# ====================
#
# date: 2023-04-04 is in idx_close,  date's position in idx_close is: 14 of 191,  n: 1,  idx_date_n: 15,
# idx_date_n: 15 is wiithin bounds of idx_close (0 to 191), date_n: 2023-04-05
#
# date: 2023-04-04,  n: 1,  next_date_n: 2023-04-05 is in df_close
# picks for 2023-04-04: ['NVDA', 'SHV']
# date = '2023-04-05', l_syms = ['NVDA', 'SHV'], ar_price = array([268.7364502 , 106.11650848]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([268.7364502 , 424.46603394]), portf_value = 693.2024841308594
# 2023-04-05 portf_value = 693.2024841308594
# date = '2023-04-05', symbol = 'SPY', price = 404.6641540527344, share = 2.0, value = 809.3283081054688
# 2023-04-05 SPY value = 809.3283081054688
# next_date_n pick's portf value = 693.2024841308594
# next_date_n SPY portf value =    809.3283081054688
# ====================
#
# date: 2023-04-03 is in idx_close,  date's position in idx_close is: 13 of 191,  n: 1,  idx_date_n: 14,
# idx_date_n: 14 is wiithin bounds of idx_close (0 to 191), date_n: 2023-04-04
#
# date: 2023-04-03,  n: 1,  next_date_n: 2023-04-04 is in df_close
# picks for 2023-04-03: ['GE', 'NVDA']
# date = '2023-04-04', l_syms = ['GE', 'NVDA'], ar_price = array([ 94.91146088, 274.45483398]), ar_sym_share = array([5., 1.]), ar_sym_amt = array([474.55730438, 274.45483398]), portf_value = 749.0121383666992
# 2023-04-04 portf_value = 749.0121383666992
# date = '2023-04-04', symbol = 'SPY', price = 405.7264404296875, share = 2.0, value = 811.452880859375
# 2023-04-04 SPY value = 811.452880859375
# next_date_n pick's portf value = 749.0121383666992
# next_date_n SPY portf value =    811.452880859375
# ====================
#
# date: 2023-03-31 is in idx_close,  date's position in idx_close is: 12 of 191,  n: 1,  idx_date_n: 13,
# idx_date_n: 13 is wiithin bounds of idx_close (0 to 191), date_n: 2023-04-03
#
# date: 2023-03-31,  n: 1,  next_date_n: 2023-04-03 is in df_close
# picks for 2023-03-31: ['NVDA']
# date = '2023-04-03', l_syms = ['NVDA'], ar_price = array([279.57342529]), ar_sym_share = array([3.]), ar_sym_amt = array([838.72027588]), portf_value = 838.7202758789062
# 2023-04-03 portf_value = 838.7202758789062
# date = '2023-04-03', symbol = 'SPY', price = 407.9900207519531, share = 2.0, value = 815.9800415039062
# 2023-04-03 SPY value = 815.9800415039062
# next_date_n pick's portf value = 838.7202758789062
# next_date_n SPY portf value =    815.9800415039062
# ====================
#
# date: 2023-03-30 is in idx_close,  date's position in idx_close is: 11 of 191,  n: 1,  idx_date_n: 12,
# idx_date_n: 12 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-31
#
# date: 2023-03-30,  n: 1,  next_date_n: 2023-03-31 is in df_close
# picks for 2023-03-30: ['SHV']
# date = '2023-03-31', l_syms = ['SHV'], ar_price = array([106.02886963]), ar_sym_share = array([9.]), ar_sym_amt = array([954.25982666]), portf_value = 954.2598266601562
# 2023-03-31 portf_value = 954.2598266601562
# date = '2023-03-31', symbol = 'SPY', price = 406.4412536621094, share = 2.0, value = 812.8825073242188
# 2023-03-31 SPY value = 812.8825073242188
# next_date_n pick's portf value = 954.2598266601562
# next_date_n SPY portf value =    812.8825073242188
# ====================
#
# date: 2023-03-30 is in idx_close,  date's position in idx_close is: 11 of 191,  n: 1,  idx_date_n: 12,
# idx_date_n: 12 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-31
#
# date: 2023-03-30,  n: 1,  next_date_n: 2023-03-31 is in df_close
# picks for 2023-03-30: ['NVDA']
# date = '2023-03-31', l_syms = ['NVDA'], ar_price = array([277.69393921]), ar_sym_share = array([3.]), ar_sym_amt = array([833.08181763]), portf_value = 833.0818176269531
# 2023-03-31 portf_value = 833.0818176269531
# date = '2023-03-31', symbol = 'SPY', price = 406.4412536621094, share = 2.0, value = 812.8825073242188
# 2023-03-31 SPY value = 812.8825073242188
# next_date_n pick's portf value = 833.0818176269531
# next_date_n SPY portf value =    812.8825073242188
# ====================
#
# date: 2023-03-29 is in idx_close,  date's position in idx_close is: 10 of 191,  n: 1,  idx_date_n: 11,
# idx_date_n: 11 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-30
#
# date: 2023-03-29,  n: 1,  next_date_n: 2023-03-30 is in df_close
# picks for 2023-03-29: ['SHV']
# date = '2023-03-30', l_syms = ['SHV'], ar_price = array([106.01929474]), ar_sym_share = array([9.]), ar_sym_amt = array([954.17365265]), portf_value = 954.1736526489258
# 2023-03-30 portf_value = 954.1736526489258
# date = '2023-03-30', symbol = 'SPY', price = 400.7922668457031, share = 2.0, value = 801.5845336914062
# 2023-03-30 SPY value = 801.5845336914062
# next_date_n pick's portf value = 954.1736526489258
# next_date_n SPY portf value =    801.5845336914062
# ====================
#
# date: 2023-03-28 is in idx_close,  date's position in idx_close is: 9 of 191,  n: 1,  idx_date_n: 10,
# idx_date_n: 10 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-29
#
# date: 2023-03-28,  n: 1,  next_date_n: 2023-03-29 is in df_close
# picks for 2023-03-28: ['SHV']
# date = '2023-03-29', l_syms = ['SHV'], ar_price = array([106.00010681]), ar_sym_share = array([9.]), ar_sym_amt = array([954.0009613]), portf_value = 954.0009613037109
# 2023-03-29 portf_value = 954.0009613037109
# date = '2023-03-29', symbol = 'SPY', price = 398.45916748046875, share = 2.0, value = 796.9183349609375
# 2023-03-29 SPY value = 796.9183349609375
# next_date_n pick's portf value = 954.0009613037109
# next_date_n SPY portf value =    796.9183349609375
# ====================
#
# date: 2023-03-27 is in idx_close,  date's position in idx_close is: 8 of 191,  n: 1,  idx_date_n: 9,
# idx_date_n: 9 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-28
#
# date: 2023-03-27,  n: 1,  next_date_n: 2023-03-28 is in df_close
# picks for 2023-03-27: ['SHV']
# date = '2023-03-28', l_syms = ['SHV'], ar_price = array([105.99047852]), ar_sym_share = array([9.]), ar_sym_amt = array([953.91430664]), portf_value = 953.914306640625
# 2023-03-28 portf_value = 953.914306640625
# date = '2023-03-28', symbol = 'SPY', price = 392.7505798339844, share = 2.0, value = 785.5011596679688
# 2023-03-28 SPY value = 785.5011596679688
# next_date_n pick's portf value = 953.914306640625
# next_date_n SPY portf value =    785.5011596679688
# ====================
#
# date: 2023-03-27 is in idx_close,  date's position in idx_close is: 8 of 191,  n: 1,  idx_date_n: 9,
# idx_date_n: 9 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-28
#
# date: 2023-03-27,  n: 1,  next_date_n: 2023-03-28 is in df_close
# picks for 2023-03-27: ['GE']
# date = '2023-03-28', l_syms = ['GE'], ar_price = array([93.00424194]), ar_sym_share = array([10.]), ar_sym_amt = array([930.04241943]), portf_value = 930.0424194335938
# 2023-03-28 portf_value = 930.0424194335938
# date = '2023-03-28', symbol = 'SPY', price = 392.7505798339844, share = 2.0, value = 785.5011596679688
# 2023-03-28 SPY value = 785.5011596679688
# next_date_n pick's portf value = 930.0424194335938
# next_date_n SPY portf value =    785.5011596679688
# ====================
#
# date: 2023-03-24 is in idx_close,  date's position in idx_close is: 7 of 191,  n: 1,  idx_date_n: 8,
# idx_date_n: 8 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-27
#
# date: 2023-03-24,  n: 1,  next_date_n: 2023-03-27 is in df_close
# picks for 2023-03-24: ['NVDA', 'SHV']
# date = '2023-03-27', l_syms = ['NVDA', 'SHV'], ar_price = array([265.23739624, 105.980896  ]), ar_sym_share = array([1., 4.]), ar_sym_amt = array([265.23739624, 423.92358398]), portf_value = 689.1609802246094
# 2023-03-27 portf_value = 689.1609802246094
# date = '2023-03-27', symbol = 'SPY', price = 393.6341552734375, share = 2.0, value = 787.268310546875
# 2023-03-27 SPY value = 787.268310546875
# next_date_n pick's portf value = 689.1609802246094
# next_date_n SPY portf value =    787.268310546875
# ====================
#
# date: 2023-03-23 is in idx_close,  date's position in idx_close is: 6 of 191,  n: 1,  idx_date_n: 7,
# idx_date_n: 7 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-24
#
# date: 2023-03-23,  n: 1,  next_date_n: 2023-03-24 is in df_close
# picks for 2023-03-23: ['SHV']
# date = '2023-03-24', l_syms = ['SHV'], ar_price = array([105.980896]), ar_sym_share = array([9.]), ar_sym_amt = array([953.82806396]), portf_value = 953.8280639648438
# 2023-03-24 portf_value = 953.8280639648438
# date = '2023-03-24', symbol = 'SPY', price = 392.89947509765625, share = 2.0, value = 785.7989501953125
# 2023-03-24 SPY value = 785.7989501953125
# next_date_n pick's portf value = 953.8280639648438
# next_date_n SPY portf value =    785.7989501953125
# ====================
#
# date: 2023-03-22 is in idx_close,  date's position in idx_close is: 5 of 191,  n: 1,  idx_date_n: 6,
# idx_date_n: 6 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-23
#
# date: 2023-03-22,  n: 1,  next_date_n: 2023-03-23 is in df_close
# picks for 2023-03-22: ['SHV']
# date = '2023-03-23', l_syms = ['SHV'], ar_price = array([105.97129822]), ar_sym_share = array([9.]), ar_sym_amt = array([953.74168396]), portf_value = 953.7416839599609
# 2023-03-23 portf_value = 953.7416839599609
# date = '2023-03-23', symbol = 'SPY', price = 390.3381042480469, share = 2.0, value = 780.6762084960938
# 2023-03-23 SPY value = 780.6762084960938
# next_date_n pick's portf value = 953.7416839599609
# next_date_n SPY portf value =    780.6762084960938
# ====================
#
# date: 2023-03-22 is in idx_close,  date's position in idx_close is: 5 of 191,  n: 1,  idx_date_n: 6,
# idx_date_n: 6 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-23
#
# date: 2023-03-22,  n: 1,  next_date_n: 2023-03-23 is in df_close
# picks for 2023-03-22: ['FTSM']
# date = '2023-03-23', l_syms = ['FTSM'], ar_price = array([57.60237503]), ar_sym_share = array([17.]), ar_sym_amt = array([979.24037552]), portf_value = 979.2403755187988
# 2023-03-23 portf_value = 979.2403755187988
# date = '2023-03-23', symbol = 'SPY', price = 390.3381042480469, share = 2.0, value = 780.6762084960938
# 2023-03-23 SPY value = 780.6762084960938
# next_date_n pick's portf value = 979.2403755187988
# next_date_n SPY portf value =    780.6762084960938
# ====================
#
# date: 2023-03-21 is in idx_close,  date's position in idx_close is: 4 of 191,  n: 1,  idx_date_n: 5,
# idx_date_n: 5 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-22
#
# date: 2023-03-21,  n: 1,  next_date_n: 2023-03-22 is in df_close
# picks for 2023-03-21: ['SHV']
# date = '2023-03-22', l_syms = ['SHV'], ar_price = array([105.90413666]), ar_sym_share = array([9.]), ar_sym_amt = array([953.13722992]), portf_value = 953.1372299194336
# 2023-03-22 portf_value = 953.1372299194336
# date = '2023-03-22', symbol = 'SPY', price = 389.28570556640625, share = 2.0, value = 778.5714111328125
# 2023-03-22 SPY value = 778.5714111328125
# next_date_n pick's portf value = 953.1372299194336
# next_date_n SPY portf value =    778.5714111328125
# ====================
#
# date: 2023-03-21 is in idx_close,  date's position in idx_close is: 4 of 191,  n: 1,  idx_date_n: 5,
# idx_date_n: 5 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-22
#
# date: 2023-03-21,  n: 1,  next_date_n: 2023-03-22 is in df_close
# picks for 2023-03-21: ['GE']
# date = '2023-03-22', l_syms = ['GE'], ar_price = array([89.45941925]), ar_sym_share = array([11.]), ar_sym_amt = array([984.05361176]), portf_value = 984.0536117553711
# 2023-03-22 portf_value = 984.0536117553711
# date = '2023-03-22', symbol = 'SPY', price = 389.28570556640625, share = 2.0, value = 778.5714111328125
# 2023-03-22 SPY value = 778.5714111328125
# next_date_n pick's portf value = 984.0536117553711
# next_date_n SPY portf value =    778.5714111328125
# ====================
#
# date: 2023-03-20 is in idx_close,  date's position in idx_close is: 3 of 191,  n: 1,  idx_date_n: 4,
# idx_date_n: 4 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-21
#
# date: 2023-03-20,  n: 1,  next_date_n: 2023-03-21 is in df_close
# picks for 2023-03-20: ['FTSM', 'SHV']
# date = '2023-03-21', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.53480148, 105.86575317]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([460.27841187, 423.4630127 ]), portf_value = 883.7414245605469
# 2023-03-21 portf_value = 883.7414245605469
# date = '2023-03-21', symbol = 'SPY', price = 396.0367126464844, share = 2.0, value = 792.0734252929688
# 2023-03-21 SPY value = 792.0734252929688
# next_date_n pick's portf value = 883.7414245605469
# next_date_n SPY portf value =    792.0734252929688
# ====================
#
# date: 2023-03-17 is in idx_close,  date's position in idx_close is: 2 of 191,  n: 1,  idx_date_n: 3,
# idx_date_n: 3 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-20
#
# date: 2023-03-17,  n: 1,  next_date_n: 2023-03-20 is in df_close
# picks for 2023-03-17: ['FTSM', 'SHV']
# date = '2023-03-20', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.59272003, 105.89453888]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([460.74176025, 423.57815552]), portf_value = 884.3199157714844
# 2023-03-20 portf_value = 884.3199157714844
# date = '2023-03-20', symbol = 'SPY', price = 390.9039611816406, share = 2.0, value = 781.8079223632812
# 2023-03-20 SPY value = 781.8079223632812
# next_date_n pick's portf value = 884.3199157714844
# next_date_n SPY portf value =    781.8079223632812
# ====================
#
# date: 2023-03-17 is in idx_close,  date's position in idx_close is: 2 of 191,  n: 1,  idx_date_n: 3,
# idx_date_n: 3 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-20
#
# date: 2023-03-17,  n: 1,  next_date_n: 2023-03-20 is in df_close
# picks for 2023-03-17: ['GE']
# date = '2023-03-20', l_syms = ['GE'], ar_price = array([89.78894043]), ar_sym_share = array([11.]), ar_sym_amt = array([987.67834473]), portf_value = 987.6783447265625
# 2023-03-20 portf_value = 987.6783447265625
# date = '2023-03-20', symbol = 'SPY', price = 390.9039611816406, share = 2.0, value = 781.8079223632812
# 2023-03-20 SPY value = 781.8079223632812
# next_date_n pick's portf value = 987.6783447265625
# next_date_n SPY portf value =    781.8079223632812
# ====================
#
# date: 2023-03-16 is in idx_close,  date's position in idx_close is: 1 of 191,  n: 1,  idx_date_n: 2,
# idx_date_n: 2 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-17
#
# date: 2023-03-16,  n: 1,  next_date_n: 2023-03-17 is in df_close
# picks for 2023-03-16: ['FTSM', 'SHV']
# date = '2023-03-17', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.5058403 , 105.91373444]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([460.04672241, 423.65493774]), portf_value = 883.70166015625
# 2023-03-17 portf_value = 883.70166015625
# date = '2023-03-17', symbol = 'SPY', price = 387.18096923828125, share = 2.0, value = 774.3619384765625
# 2023-03-17 SPY value = 774.3619384765625
# next_date_n pick's portf value = 883.70166015625
# next_date_n SPY portf value =    774.3619384765625
# ====================
#
# date: 2023-03-15 is in idx_close,  date's position in idx_close is: 0 of 191,  n: 1,  idx_date_n: 1,
# idx_date_n: 1 is wiithin bounds of idx_close (0 to 191), date_n: 2023-03-16
#
# date: 2023-03-15,  n: 1,  next_date_n: 2023-03-16 is in df_close
# picks for 2023-03-15: ['FTSM', 'SHV']
# date = '2023-03-16', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.51549149, 105.8369751 ]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([460.12393188, 423.34790039]), portf_value = 883.4718322753906
# 2023-03-16 portf_value = 883.4718322753906
# date = '2023-03-16', symbol = 'SPY', price = 391.76171875, share = 2.0, value = 783.5234375
# 2023-03-16 SPY value = 783.5234375
# next_date_n pick's portf value = 883.4718322753906
# next_date_n SPY portf value =    783.5234375
# ====================

# %% [markdown]
# #### TODO: 2023-12-17 skip syms that are not in df_close, these symbols are no-longer listed
#
# #### TODO: 2023-07-15 only evaluate performance of df_modelpicks, after evaluation, append results to df_modelpicks_results
#
# #### 2023-07-11 got KeyError: "['ISEE'] not in index". ISEE was in past model picks, but since then ISEE was acquired. The symbol was dropped from df_close_clean. Current program recalculate the performance of all the past picks. Rewrite program such that performance of past picks with win records are not recalculated.

# %%
# import numpy as np
# # from ast import literal_eval
# z_date_syms = zip(df_picks_mp.date, df_picks_mp.symbols)

# idx_close = df_close.index.strftime('%Y-%m-%d')

# n = 1  # n=1 is the buy date
# # n = 4  # n=4 is the sell date

# date_buy = []  # buy date of portfolio
# shares_syms = []  # lists of shares of each symbol brought on date_buy
# value_portf = [] # list of porfolio value on date_buy
# shares_SPY = []  # list of shares of SPY brought on date_buy
# value_SPY = []  # list of value of SPY shares on date_buy 
# for date, syms in z_date_syms:
#     next_date_n = get_trading_date_n(date, idx_close, n, verbose=verbose)

#     if next_date_n in idx_close:
#         close_date_n = next_date_n
#         print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is in df_close')
#         print(f'picks for {date}: {syms}')      
#     else:
#         close_date_n = None
#         print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is not in df_close')
#         print(f'picks for {date}: {syms}')        

#     if close_date_n is None:
#         p_date = None  # portf. buy date
#         p_l_syms = None  # portf. list of symbols
#         p_ar_price = None  # portf. list of symbols' close
#         p_ar_sym_share = None  # portf. list of symbols' share
#         p_ar_sym_amt = None  # portf. list of symbols' dollar value 
#         p_portf_value = None  # portf. value is none, data not available in df_close
        
#         s_date = None  # SPY buy date
#         s_price = None # SPY list of symbols' close
#         s_share = None # SPY list of symbols' share
#         s_value = None  # SPY value is none, data not available in df_close

#         date_buy.append(p_date)
#         shares_syms.append(p_l_syms)
#         value_portf.append(p_portf_value)
#         shares_SPY.append(s_share)
#         value_SPY.append(s_value)    
        
#         print(f"No data for next_date_n {next_date_n}, pick's portf value = None")
#         print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

#     else:    
#         p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
#             get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
#         s_date, s_price, s_share, s_value = \
#             get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
                
#         date_buy.append(p_date)
#         shares_syms.append(p_ar_sym_share)
#         value_portf.append(p_portf_value)
#         shares_SPY.append(s_share)
#         value_SPY.append(s_value)

#         print(f"next_date_n pick's portf value = {p_portf_value}")
#         print(f'next_date_n SPY portf value =    {s_value}')

#     print('='*20, '\n')

# %% [markdown]
# #### Below cells calculate past performance of model picks

# %%
def calc_portf_shares(df_close, date, str_symbols, portf_target):
  # calculate number of shares to buy for symbols in str_symbols to meet port_target
  import numpy as np
  from ast import literal_eval    
  l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
  # array of closing prices corresponding to symbols in l_syms    
  ar_price = df_close.loc[date][l_syms].values  
  sym_cnt = len(l_syms)  # number of symbols
  amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
  ar_shares = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
  return ar_shares

# %%
def calc_portf_value(df_close, date, str_symbols, ar_shares, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    ar_value = ar_price * ar_shares  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_value)  # total actual portfolio value
    if verbose:
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_shares = }, {ar_value = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_shares, ar_value, portf_value

# %%
def get_next_date_n(df_close, date, n=1):

    """Get the next n(default=1) date from df_close. date has to in df_close.index.

    Edge case: The function won't return the first date in df_close as the
    next trading date, if date is a trading date just before the first date in df_close.
    """

    len_df_close = len(df_close)
    idx_dates = df_close.index.strftime('%Y-%m-%d')  # date index of df_close    

    if date in idx_dates:
        idx_next_date = idx_dates.get_loc(date) + n  # get index position of next date
        print(f'n: {n},  idx_next_date: {idx_next_date}')

        if idx_next_date >= 0:  # if idx_nex_date is negative, stop index loop back from index[0] to index[-1]    
            if idx_next_date >= (len_df_close - n):  # next date's index is within bound of df_close
                next_date = idx_dates[idx_dates.get_loc(date) + n]  # get the next date
                return next_date
        
              
            else:  # idx_next_date is out-of_bounds df_close
                print(f"{date} is the last date in df_close. No data for next {n} day")
                return None    
        
        
        else:  # idx_next_date is negative, no data in df_close
            # no data from df_close
            print(f'idx_next_date: {idx_next_date} is negative, no data for {n} days from {date} in df_close')

    else:     
        # no data from df_close
        print(f'no data for {date} in df_close')
        return None

# %%
def is_date_in_close(date, df_close):
  idx_close = df_close.index.strftime('%Y-%m-%d')
  if date in idx_close:
    return date
  else:
    return None

# %%
def calc_portf_value_date_buy_(dates_in_days_lookbacks, my_symbols, df_close, portf_target, n, verbose=False):
  
  z_date_syms = zip(dates_in_days_lookbacks, my_symbols)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, syms in z_date_syms:
    next_date_n = get_trading_date_n(date, idx_close, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)



    l_syms = literal_eval(syms)  # convert list stored as str back to list
    # True if symbol(s) in l_syms is not a column in df_close
    sym_not_in_df_close = any_not_in_list(l_syms, symbols_df_close)

    if close_date_n is None or sym_not_in_df_close:



    # if close_date_n is None:
      p_date = None
      p_ar_shares = None
      p_portf_value = None  # set to None when data are not available in df_close
      SPY_shares = None
      SPY_value = None  # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        print(f'No data for close_date_n {close_date_n}, SPY portf value =    None')

    else:    
      p_ar_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      p_date, l_syms, ar_price, ar_shares, ar_value, p_portf_value = \
        calc_portf_value(df_close, close_date_n, syms, p_ar_shares, verbose)

      syms = str(['SPY'])
      SPY_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      date, l_syms, ar_price, ar_shares, ar_value, SPY_value = \
        calc_portf_value(df_close, close_date_n, syms, SPY_shares, verbose)

      if verbose:
        print(f"close_date_n pick's portf value = {p_portf_value}")
        print(f'close_date_n SPY portf value =    {SPY_value}')

    date_exec.append(p_date)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_portf_value)
    shares_SPY.append(SPY_shares)
    value_SPY.append(SPY_value)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
def calc_portf_value_date_buy(dates_in_days_lookbacks, my_symbols, df_close, portf_target, n, verbose=False):
  
  z_date_syms = zip(dates_in_days_lookbacks, my_symbols)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, syms in z_date_syms:
    next_date_n = get_trading_date_n(date, idx_close, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date = None
      p_ar_shares = None
      p_portf_value = None  # set to None when data are not available in df_close
      SPY_shares = None
      SPY_value = None  # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        print(f'No data for close_date_n {close_date_n}, SPY portf value =    None')

    else:    
      p_ar_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      p_date, l_syms, ar_price, ar_shares, ar_value, p_portf_value = \
        calc_portf_value(df_close, close_date_n, syms, p_ar_shares, verbose)

      syms = str(['SPY'])
      SPY_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      date, l_syms, ar_price, ar_shares, ar_value, SPY_value = \
        calc_portf_value(df_close, close_date_n, syms, SPY_shares, verbose)

      if verbose:
        print(f"close_date_n pick's portf value = {p_portf_value}")
        print(f'close_date_n SPY portf value =    {SPY_value}')

    date_exec.append(p_date)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_portf_value)
    shares_SPY.append(SPY_shares)
    value_SPY.append(SPY_value)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
def calc_portf_value_date_n(dates_in_days_lookbacks, my_symbols, df_close, my_portf_shares, my_SPY_shares, n, verbose=False):
  
  z_date_syms_shares = zip(dates_in_days_lookbacks, my_symbols, my_portf_shares, my_SPY_shares)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, symbols, portf_shares, SPY_shares in z_date_syms_shares:
    next_date_n = get_trading_date_n(date, idx_close, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date_exec = None
      p_ar_shares = None
      p_value_portf = None  # set to None when data are not available in df_close
      SPY_ar_shares = None
      SPY_value_portf = None # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        # print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else: 
      if portf_shares is None:
        p_date_exec = None
        p_ar_shares = None
        p_value_portf = None
        SPY_ar_shares = None
        SPY_value_portf = None

      else:  
        p_date_exec, p_ar_syms, p_ar_price, p_ar_shares, p_ar_value, p_value_portf = \
          calc_portf_value(df_close, close_date_n, symbols, portf_shares, verbose)
        
        SPY = str(['SPY'])
        SPY_date_exec, SPY_ar_syms, SPY_ar_price, SPY_ar_shares, SPY_ar_value, SPY_value_portf = \
          calc_portf_value(df_close, close_date_n, SPY, SPY_shares, verbose) 

        if verbose:
          print(f"next_date_n pick's portf value = {p_value_portf}")
          print(f'next_date_n SPY portf value =    {SPY_value_portf}')

    date_exec.append(p_date_exec)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_value_portf)
    shares_SPY.append(SPY_ar_shares)
    value_SPY.append(SPY_value_portf)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
df_picks_mp
# Out:
#            date  days_lookback   syms_freq          symbols
# 0    2023-12-15  [30, 60, 120]  sym_freq_8          ['SHV']
# 1    2023-12-13  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']
# 2    2023-12-12  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']
# 3    2023-12-11  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']
# 4    2023-12-08  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']
# ..          ...            ...         ...              ...
# 285  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 286  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 287  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']
# 288  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 289  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
#
# [290 rows x 4 columns]

# %%
df_picks_mp.date
# Out:
# 0      2023-12-15
# 1      2023-12-13
# 2      2023-12-12
# 3      2023-12-11
# 4      2023-12-08
#           ...
# 285    2023-03-20
# 286    2023-03-17
# 287    2023-03-17
# 288    2023-03-16
# 289    2023-03-15
# Name: date, Length: 290, dtype: object

# %%
df_picks_mp.symbols
# Out:
# 0              ['SHV']
# 1       ['GPS', 'SHV']
# 2       ['GPS', 'SHV']
# 3       ['GPS', 'SHV']
# 4       ['GPS', 'SHV']
#             ...
# 285    ['FTSM', 'SHV']
# 286    ['FTSM', 'SHV']
# 287             ['GE']
# 288    ['FTSM', 'SHV']
# 289    ['FTSM', 'SHV']
# Name: symbols, Length: 290, dtype: object

# %%
df_close
# Out:
#                      A         AA    AAL         AAP        AAPL         AB        ABBV        ABR         ABT       ACGL       ACHC       ACIW        ACLS   ACRS        ADBE  ...        XRX         XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                            ...
# 2023-03-15  133.288239  39.372566  13.86  119.255257  152.371918  32.977055  149.485596  10.526908   96.316017  62.740002  68.459999  22.700001  123.860001  7.990  333.609985  ...  14.261086   95.604477  29.170000  125.356514  59.979794  26.028101  124.543419  287.739990  73.779999  39.919998  29.475050  25.606165  162.472290  19.500000  20.806547
# 2023-03-16  136.062805  40.342766  14.12  119.509888  155.220352  33.193268  150.688766  10.499517   97.527351  66.070000  70.230003  25.780001  129.960007  8.120  353.290009  ...  14.451233   96.208496  29.780001  126.273537  60.515686  26.922306  124.712440  294.929993  74.510002  40.849998  30.818754  27.639652  165.193893  19.250000  20.796629
# 2023-03-17  132.442932  38.758762  13.98  116.934204  154.373779  32.883053  149.640839  10.216486   95.538002  63.150002  69.459999  26.940001  128.220001  7.890  358.140015  ...  13.899805   93.802299  29.330000  125.080414  60.257668  27.720362  123.598854  288.709991  74.129997  39.810001  28.736017  28.083862  163.366241  18.540001  20.360270
# 2023-03-20  133.795395  39.877464  13.96  116.229065  156.764084  33.024059  151.484421  10.791677   96.384964  65.610001  70.449997  26.150000  131.509995  7.950  362.880005  ...  14.118475   96.693703  29.690001  127.082108  60.485916  28.028044  125.607292  290.839996  74.650002  39.830002  28.966366  27.659395  164.707199  18.110001  20.657787
# 2023-03-21  136.251740  41.491177  14.37  117.316147  158.636505  33.334270  152.115128  10.873848   96.837975  67.209999  70.959999  26.200001  133.449997  8.240  374.220001  ...  14.546309   97.555176  30.059999  126.756706  60.704235  27.489597  127.058952  294.429993  75.570000  41.939999  30.991514  27.866692  165.124374  18.549999  21.004896
# ...                ...        ...    ...         ...         ...        ...         ...        ...         ...        ...        ...        ...         ...    ...         ...  ...        ...         ...        ...         ...        ...        ...         ...         ...        ...        ...        ...        ...         ...        ...        ...
# 2023-12-11  128.970001  24.930000  13.72   57.080002  193.179993  29.820000  151.240005  14.100000  106.220001  79.610001  74.959999  28.000000  125.580002  0.973  625.200012  ...  15.170000  107.699997  44.099998  126.629997  39.919998  36.939999  117.980003  239.649994  63.730000  43.820000  38.630001  21.020000  189.460007  18.969999  29.610001
# 2023-12-12  128.789993  24.049999  14.04   56.250000  194.710007  30.559999  153.240005  14.190000  106.680000  80.279999  75.910004  28.320000  126.190002  1.010  633.659973  ...  15.710000  107.940002  44.480000  128.070007  40.320000  39.029999  117.449997  239.380005  62.560001  45.419998  38.130001  21.020000  191.470001  18.570000  29.230000
# 2023-12-13  133.740005  25.990000  14.09   60.830002  197.960007  30.809999  154.300003  14.880000  107.250000  78.379997  78.959999  29.240000  131.500000  1.090  624.260010  ...  16.709999  109.180000  44.490002  130.929993  39.750000  38.500000  117.900002  244.429993  64.720001  50.279999  41.820000  20.400000  197.410004  19.670000  29.320000
# 2023-12-14  137.960007  29.900000  14.59   63.970001  198.110001  31.870001  154.880005  15.700000  108.599998  74.669998  77.580002  29.639999  140.429993  1.060  584.640015  ...  17.580000  110.930000  45.360001  131.110001  40.160000  38.799999  118.529999  272.160004  66.320000  54.500000  45.669998  20.309999  200.089996  19.930000  29.610001
# 2023-12-15  136.779999  31.100000  14.49   62.720001  197.570007  32.020000  154.039993  15.380000  107.290001  73.419998  75.430000  29.719999  136.089996  1.010  584.679993  ...  18.290001  110.720001  44.790001  128.639999  40.029999  38.540001  118.690002  270.179993  66.550003  54.779999  43.840000  19.830000  196.289993  19.389999  29.350000
#
# [192 rows x 1269 columns]

# %%
# total target investment for each day's picks, if day's pick has 2 symbols, the function will try to invest $500 for each symbol
portf_target = 1000  
date_buy, shares_syms, value_portf, shares_SPY, value_SPY = \
  calc_portf_value_date_buy_(df_picks_mp.date, df_picks_mp.symbols, df_close, portf_target, n=1, verbose=verbose)
# Out:
# No data for close_date_n None, pick's portf value = None
# No data for close_date_n None, SPY portf value =    None
# ====================
#
# date = '2023-12-14', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.29999924, 109.86000061]), ar_shares = array([23.,  4.]), ar_value = array([489.89998245, 439.44000244]), portf_value = 929.3399848937988
# 2023-12-14 portf_value = 929.3399848937988
# date = '2023-12-14', l_syms = ['SPY'], ar_price = array([472.01000977]), ar_shares = array([2.]), ar_value = array([944.02001953]), portf_value = 944.02001953125
# 2023-12-14 portf_value = 944.02001953125
# close_date_n pick's portf value = 929.3399848937988
# close_date_n SPY portf value =    944.02001953125
# ====================
#
# date = '2023-12-13', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.22999954, 109.80599976]), ar_shares = array([23.,  4.]), ar_value = array([488.28998947, 439.22399902]), portf_value = 927.513988494873
# 2023-12-13 portf_value = 927.513988494873
# date = '2023-12-13', l_syms = ['SPY'], ar_price = array([470.5]), ar_shares = array([2.]), ar_value = array([941.]), portf_value = 941.0
# 2023-12-13 portf_value = 941.0
# close_date_n pick's portf value = 927.513988494873
# close_date_n SPY portf value =    941.0
# ====================
#
# date = '2023-12-12', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.29999924, 109.76618195]), ar_shares = array([23.,  4.]), ar_value = array([489.89998245, 439.06472778]), portf_value = 928.9647102355957
# 2023-12-12 portf_value = 928.9647102355957
# date = '2023-12-12', l_syms = ['SPY'], ar_price = array([464.1000061]), ar_shares = array([2.]), ar_value = array([928.20001221]), portf_value = 928.2000122070312
# 2023-12-12 portf_value = 928.2000122070312
# close_date_n pick's portf value = 928.9647102355957
# close_date_n SPY portf value =    928.2000122070312
# ====================
#
# date = '2023-12-11', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.93000031, 109.7363205 ]), ar_shares = array([22.,  4.]), ar_value = array([482.46000671, 438.94528198]), portf_value = 921.4052886962891
# 2023-12-11 portf_value = 921.4052886962891
# date = '2023-12-11', l_syms = ['SPY'], ar_price = array([461.98999023]), ar_shares = array([2.]), ar_value = array([923.97998047]), portf_value = 923.97998046875
# 2023-12-11 portf_value = 923.97998046875
# close_date_n pick's portf value = 921.4052886962891
# close_date_n SPY portf value =    923.97998046875
# ====================
#
# date = '2023-12-08', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.68000031, 109.7363205 ]), ar_shares = array([23.,  4.]), ar_value = array([498.64000702, 438.94528198]), portf_value = 937.5852890014648
# 2023-12-08 portf_value = 937.5852890014648
# date = '2023-12-08', l_syms = ['SPY'], ar_price = array([460.20001221]), ar_shares = array([2.]), ar_value = array([920.40002441]), portf_value = 920.4000244140625
# 2023-12-08 portf_value = 920.4000244140625
# close_date_n pick's portf value = 937.5852890014648
# close_date_n SPY portf value =    920.4000244140625
# ====================
#
# date = '2023-12-07', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.37000084, 109.7363205 ]), ar_shares = array([23.,  4.]), ar_value = array([491.5100193 , 438.94528198]), portf_value = 930.45530128479
# 2023-12-07 portf_value = 930.45530128479
# date = '2023-12-07', l_syms = ['SPY'], ar_price = array([458.23001099]), ar_shares = array([2.]), ar_value = array([916.46002197]), portf_value = 916.4600219726562
# 2023-12-07 portf_value = 916.4600219726562
# close_date_n pick's portf value = 930.45530128479
# close_date_n SPY portf value =    916.4600219726562
# ====================
#
# date = '2023-12-06', l_syms = ['GPS'], ar_price = array([20.94000053]), ar_shares = array([47.]), ar_value = array([984.1800251]), portf_value = 984.180025100708
# 2023-12-06 portf_value = 984.180025100708
# date = '2023-12-06', l_syms = ['SPY'], ar_price = array([454.76000977]), ar_shares = array([2.]), ar_value = array([909.52001953]), portf_value = 909.52001953125
# 2023-12-06 portf_value = 909.52001953125
# close_date_n pick's portf value = 984.180025100708
# close_date_n SPY portf value =    909.52001953125
# ====================
#
# date = '2023-12-06', l_syms = ['LRN', 'SHV'], ar_price = array([ 60.68999863, 109.68655396]), ar_shares = array([8., 4.]), ar_value = array([485.51998901, 438.74621582]), portf_value = 924.2662048339844
# 2023-12-06 portf_value = 924.2662048339844
# date = '2023-12-06', l_syms = ['SPY'], ar_price = array([454.76000977]), ar_shares = array([2.]), ar_value = array([909.52001953]), portf_value = 909.52001953125
# 2023-12-06 portf_value = 909.52001953125
# close_date_n pick's portf value = 924.2662048339844
# close_date_n SPY portf value =    909.52001953125
# ====================
#
# date = '2023-12-06', l_syms = ['GPS'], ar_price = array([20.94000053]), ar_shares = array([47.]), ar_value = array([984.1800251]), portf_value = 984.180025100708
# 2023-12-06 portf_value = 984.180025100708
# date = '2023-12-06', l_syms = ['SPY'], ar_price = array([454.76000977]), ar_shares = array([2.]), ar_value = array([909.52001953]), portf_value = 909.52001953125
# 2023-12-06 portf_value = 909.52001953125
# close_date_n pick's portf value = 984.180025100708
# close_date_n SPY portf value =    909.52001953125
# ====================
#
# date = '2023-12-05', l_syms = ['GPS'], ar_price = array([20.78000069]), ar_shares = array([48.]), ar_value = array([997.44003296]), portf_value = 997.4400329589844
# 2023-12-05 portf_value = 997.4400329589844
# date = '2023-12-05', l_syms = ['SPY'], ar_price = array([456.6000061]), ar_shares = array([2.]), ar_value = array([913.20001221]), portf_value = 913.2000122070312
# 2023-12-05 portf_value = 913.2000122070312
# close_date_n pick's portf value = 997.4400329589844
# close_date_n SPY portf value =    913.2000122070312
# ====================
#
# date = '2023-12-05', l_syms = ['SHV'], ar_price = array([109.66664124]), ar_shares = array([9.]), ar_value = array([986.99977112]), portf_value = 986.9997711181641
# 2023-12-05 portf_value = 986.9997711181641
# date = '2023-12-05', l_syms = ['SPY'], ar_price = array([456.6000061]), ar_shares = array([2.]), ar_value = array([913.20001221]), portf_value = 913.2000122070312
# 2023-12-05 portf_value = 913.2000122070312
# close_date_n pick's portf value = 986.9997711181641
# close_date_n SPY portf value =    913.2000122070312
# ====================
#
# date = '2023-12-05', l_syms = ['GPS'], ar_price = array([20.78000069]), ar_shares = array([48.]), ar_value = array([997.44003296]), portf_value = 997.4400329589844
# 2023-12-05 portf_value = 997.4400329589844
# date = '2023-12-05', l_syms = ['SPY'], ar_price = array([456.6000061]), ar_shares = array([2.]), ar_value = array([913.20001221]), portf_value = 913.2000122070312
# 2023-12-05 portf_value = 913.2000122070312
# close_date_n pick's portf value = 997.4400329589844
# close_date_n SPY portf value =    913.2000122070312
# ====================
#
# date = '2023-12-04', l_syms = ['GPS'], ar_price = array([20.84000015]), ar_shares = array([47.]), ar_value = array([979.48000717]), portf_value = 979.4800071716309
# 2023-12-04 portf_value = 979.4800071716309
# date = '2023-12-04', l_syms = ['SPY'], ar_price = array([456.69000244]), ar_shares = array([2.]), ar_value = array([913.38000488]), portf_value = 913.3800048828125
# 2023-12-04 portf_value = 913.3800048828125
# close_date_n pick's portf value = 979.4800071716309
# close_date_n SPY portf value =    913.3800048828125
# ====================
#
# date = '2023-12-04', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.61000061, 109.64673615]), ar_shares = array([8., 4.]), ar_value = array([476.88000488, 438.58694458]), portf_value = 915.4669494628906
# 2023-12-04 portf_value = 915.4669494628906
# date = '2023-12-04', l_syms = ['SPY'], ar_price = array([456.69000244]), ar_shares = array([2.]), ar_value = array([913.38000488]), portf_value = 913.3800048828125
# 2023-12-04 portf_value = 913.3800048828125
# close_date_n pick's portf value = 915.4669494628906
# close_date_n SPY portf value =    913.3800048828125
# ====================
#
# date = '2023-12-04', l_syms = ['GPS'], ar_price = array([20.84000015]), ar_shares = array([47.]), ar_value = array([979.48000717]), portf_value = 979.4800071716309
# 2023-12-04 portf_value = 979.4800071716309
# date = '2023-12-04', l_syms = ['SPY'], ar_price = array([456.69000244]), ar_shares = array([2.]), ar_value = array([913.38000488]), portf_value = 913.3800048828125
# 2023-12-04 portf_value = 913.3800048828125
# close_date_n pick's portf value = 979.4800071716309
# close_date_n SPY portf value =    913.3800048828125
# ====================
#
# date = '2023-12-01', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.02000046, 109.63677979]), ar_shares = array([23.,  4.]), ar_value = array([483.46001053, 438.54711914]), portf_value = 922.0071296691895
# 2023-12-01 portf_value = 922.0071296691895
# date = '2023-12-01', l_syms = ['SPY'], ar_price = array([459.1000061]), ar_shares = array([2.]), ar_value = array([918.20001221]), portf_value = 918.2000122070312
# 2023-12-01 portf_value = 918.2000122070312
# close_date_n pick's portf value = 922.0071296691895
# close_date_n SPY portf value =    918.2000122070312
# ====================
#
# date = '2023-11-30', l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = array([ 59.56000137,  20.06999969, 109.60192871]), ar_shares = array([ 5., 16.,  3.]), ar_value = array([297.80000687, 321.11999512, 328.80578613]), portf_value = 947.7257881164551
# 2023-11-30 portf_value = 947.7257881164551
# date = '2023-11-30', l_syms = ['SPY'], ar_price = array([456.3999939]), ar_shares = array([2.]), ar_value = array([912.79998779]), portf_value = 912.7999877929688
# 2023-11-30 portf_value = 912.7999877929688
# close_date_n pick's portf value = 947.7257881164551
# close_date_n SPY portf value =    912.7999877929688
# ====================
#
# date = '2023-11-29', l_syms = ['SHV'], ar_price = array([109.56229401]), ar_shares = array([9.]), ar_value = array([986.06064606]), portf_value = 986.0606460571289
# 2023-11-29 portf_value = 986.0606460571289
# date = '2023-11-29', l_syms = ['SPY'], ar_price = array([454.60998535]), ar_shares = array([2.]), ar_value = array([909.2199707]), portf_value = 909.219970703125
# 2023-11-29 portf_value = 909.219970703125
# close_date_n pick's portf value = 986.0606460571289
# close_date_n SPY portf value =    909.219970703125
# ====================
#
# date = '2023-11-29', l_syms = ['FTSM', 'GPS'], ar_price = array([59.53699875, 20.15999985]), ar_shares = array([ 8., 24.]), ar_value = array([476.29598999, 483.83999634]), portf_value = 960.135986328125
# 2023-11-29 portf_value = 960.135986328125
# date = '2023-11-29', l_syms = ['SPY'], ar_price = array([454.60998535]), ar_shares = array([2.]), ar_value = array([909.2199707]), portf_value = 909.219970703125
# 2023-11-29 portf_value = 909.219970703125
# close_date_n pick's portf value = 960.135986328125
# close_date_n SPY portf value =    909.219970703125
# ====================
#
# date = '2023-11-28', l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = array([ 59.52703857,  19.54999924, 109.54247284]), ar_shares = array([ 5., 17.,  3.]), ar_value = array([297.63519287, 332.34998703, 328.62741852]), portf_value = 958.6125984191895
# 2023-11-28 portf_value = 958.6125984191895
# date = '2023-11-28', l_syms = ['SPY'], ar_price = array([454.92999268]), ar_shares = array([2.]), ar_value = array([909.85998535]), portf_value = 909.8599853515625
# 2023-11-28 portf_value = 909.8599853515625
# close_date_n pick's portf value = 958.6125984191895
# close_date_n SPY portf value =    909.8599853515625
# ====================
#
# date = '2023-11-27', l_syms = ['GPS', 'SHV'], ar_price = array([ 19.44000053, 109.51274109]), ar_shares = array([25.,  4.]), ar_value = array([486.00001335, 438.05096436]), portf_value = 924.0509777069092
# 2023-11-27 portf_value = 924.0509777069092
# date = '2023-11-27', l_syms = ['SPY'], ar_price = array([454.48001099]), ar_shares = array([2.]), ar_value = array([908.96002197]), portf_value = 908.9600219726562
# 2023-11-27 portf_value = 908.9600219726562
# close_date_n pick's portf value = 924.0509777069092
# close_date_n SPY portf value =    908.9600219726562
# ====================
#
# date = '2023-11-24', l_syms = ['GPS', 'SHV'], ar_price = array([ 18.86000061, 109.49291992]), ar_shares = array([26.,  4.]), ar_value = array([490.36001587, 437.97167969]), portf_value = 928.3316955566406
# 2023-11-24 portf_value = 928.3316955566406
# date = '2023-11-24', l_syms = ['SPY'], ar_price = array([455.29998779]), ar_shares = array([2.]), ar_value = array([910.59997559]), portf_value = 910.5999755859375
# 2023-11-24 portf_value = 910.5999755859375
# close_date_n pick's portf value = 928.3316955566406
# close_date_n SPY portf value =    910.5999755859375
# ====================
#
# date = '2023-11-22', l_syms = ['SHV'], ar_price = array([109.48300934]), ar_shares = array([9.]), ar_value = array([985.34708405]), portf_value = 985.3470840454102
# 2023-11-22 portf_value = 985.3470840454102
# date = '2023-11-22', l_syms = ['SPY'], ar_price = array([455.01998901]), ar_shares = array([2.]), ar_value = array([910.03997803]), portf_value = 910.0399780273438
# 2023-11-22 portf_value = 910.0399780273438
# close_date_n pick's portf value = 985.3470840454102
# close_date_n SPY portf value =    910.0399780273438
# ====================
#
# date = '2023-11-22', l_syms = ['FTSM', 'GPS'], ar_price = array([59.44736481, 18.79999924]), ar_shares = array([ 8., 26.]), ar_value = array([475.57891846, 488.79998016]), portf_value = 964.3788986206055
# 2023-11-22 portf_value = 964.3788986206055
# date = '2023-11-22', l_syms = ['SPY'], ar_price = array([455.01998901]), ar_shares = array([2.]), ar_value = array([910.03997803]), portf_value = 910.0399780273438
# 2023-11-22 portf_value = 910.0399780273438
# close_date_n pick's portf value = 964.3788986206055
# close_date_n SPY portf value =    910.0399780273438
# ====================
#
# date = '2023-11-21', l_syms = ['SHV'], ar_price = array([109.443367]), ar_shares = array([9.]), ar_value = array([984.99030304]), portf_value = 984.9903030395508
# 2023-11-21 portf_value = 984.9903030395508
# date = '2023-11-21', l_syms = ['SPY'], ar_price = array([453.26998901]), ar_shares = array([2.]), ar_value = array([906.53997803]), portf_value = 906.5399780273438
# 2023-11-21 portf_value = 906.5399780273438
# close_date_n pick's portf value = 984.9903030395508
# close_date_n SPY portf value =    906.5399780273438
# ====================
#
# date = '2023-11-21', l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = array([59.4174881 , 18.89999962, 45.20000076]), ar_shares = array([ 5., 17.,  7.]), ar_value = array([297.08744049, 321.29999352, 316.40000534]), portf_value = 934.7874393463135
# 2023-11-21 portf_value = 934.7874393463135
# date = '2023-11-21', l_syms = ['SPY'], ar_price = array([453.26998901]), ar_shares = array([2.]), ar_value = array([906.53997803]), portf_value = 906.5399780273438
# 2023-11-21 portf_value = 906.5399780273438
# close_date_n pick's portf value = 934.7874393463135
# close_date_n SPY portf value =    906.5399780273438
# ====================
#
# date = '2023-11-20', l_syms = ['SHV'], ar_price = array([109.40372467]), ar_shares = array([9.]), ar_value = array([984.63352203]), portf_value = 984.6335220336914
# 2023-11-20 portf_value = 984.6335220336914
# date = '2023-11-20', l_syms = ['SPY'], ar_price = array([454.26000977]), ar_shares = array([2.]), ar_value = array([908.52001953]), portf_value = 908.52001953125
# 2023-11-20 portf_value = 908.52001953125
# close_date_n pick's portf value = 984.6335220336914
# close_date_n SPY portf value =    908.52001953125
# ====================
#
# date = '2023-11-20', l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = array([59.40752792, 18.43000031, 47.29000092]), ar_shares = array([ 5., 18.,  7.]), ar_value = array([297.03763962, 331.74000549, 331.03000641]), portf_value = 959.8076515197754
# 2023-11-20 portf_value = 959.8076515197754
# date = '2023-11-20', l_syms = ['SPY'], ar_price = array([454.26000977]), ar_shares = array([2.]), ar_value = array([908.52001953]), portf_value = 908.52001953125
# 2023-11-20 portf_value = 908.52001953125
# close_date_n pick's portf value = 959.8076515197754
# close_date_n SPY portf value =    908.52001953125
# ====================
#
# date = '2023-11-17', l_syms = ['SHV'], ar_price = array([109.39380646]), ar_shares = array([9.]), ar_value = array([984.54425812]), portf_value = 984.5442581176758
# 2023-11-17 portf_value = 984.5442581176758
# date = '2023-11-17', l_syms = ['SPY'], ar_price = array([450.79000854]), ar_shares = array([2.]), ar_value = array([901.58001709]), portf_value = 901.5800170898438
# 2023-11-17 portf_value = 901.5800170898438
# close_date_n pick's portf value = 984.5442581176758
# close_date_n SPY portf value =    901.5800170898438
# ====================
#
# date = '2023-11-17', l_syms = ['FTSM', 'NRG'], ar_price = array([59.38761139, 48.08000183]), ar_shares = array([ 8., 10.]), ar_value = array([475.10089111, 480.80001831]), portf_value = 955.9009094238281
# 2023-11-17 portf_value = 955.9009094238281
# date = '2023-11-17', l_syms = ['SPY'], ar_price = array([450.79000854]), ar_shares = array([2.]), ar_value = array([901.58001709]), portf_value = 901.5800170898438
# 2023-11-17 portf_value = 901.5800170898438
# close_date_n pick's portf value = 955.9009094238281
# close_date_n SPY portf value =    901.5800170898438
# ====================
#
# date = '2023-11-16', l_syms = ['SHV'], ar_price = array([109.3839035]), ar_shares = array([9.]), ar_value = array([984.45513153]), portf_value = 984.4551315307617
# 2023-11-16 portf_value = 984.4551315307617
# date = '2023-11-16', l_syms = ['SPY'], ar_price = array([450.23001099]), ar_shares = array([2.]), ar_value = array([900.46002197]), portf_value = 900.4600219726562
# 2023-11-16 portf_value = 900.4600219726562
# close_date_n pick's portf value = 984.4551315307617
# close_date_n SPY portf value =    900.4600219726562
# ====================
#
# date = '2023-11-16', l_syms = ['FTSM', 'NRG'], ar_price = array([59.3776474 , 47.56999969]), ar_shares = array([ 8., 10.]), ar_value = array([475.0211792 , 475.69999695]), portf_value = 950.7211761474609
# 2023-11-16 portf_value = 950.7211761474609
# date = '2023-11-16', l_syms = ['SPY'], ar_price = array([450.23001099]), ar_shares = array([2.]), ar_value = array([900.46002197]), portf_value = 900.4600219726562
# 2023-11-16 portf_value = 900.4600219726562
# close_date_n pick's portf value = 950.7211761474609
# close_date_n SPY portf value =    900.4600219726562
# ====================
#
# date = '2023-11-15', l_syms = ['SHV'], ar_price = array([109.32443237]), ar_shares = array([9.]), ar_value = array([983.91989136]), portf_value = 983.9198913574219
# 2023-11-15 portf_value = 983.9198913574219
# date = '2023-11-15', l_syms = ['SPY'], ar_price = array([449.67999268]), ar_shares = array([2.]), ar_value = array([899.35998535]), portf_value = 899.3599853515625
# 2023-11-15 portf_value = 899.3599853515625
# close_date_n pick's portf value = 983.9198913574219
# close_date_n SPY portf value =    899.3599853515625
# ====================
#
# date = '2023-11-15', l_syms = ['FTSM', 'NRG'], ar_price = array([59.35773087, 47.50999832]), ar_shares = array([ 8., 10.]), ar_value = array([474.86184692, 475.09998322]), portf_value = 949.9618301391602
# 2023-11-15 portf_value = 949.9618301391602
# date = '2023-11-15', l_syms = ['SPY'], ar_price = array([449.67999268]), ar_shares = array([2.]), ar_value = array([899.35998535]), portf_value = 899.3599853515625
# 2023-11-15 portf_value = 899.3599853515625
# close_date_n pick's portf value = 949.9618301391602
# close_date_n SPY portf value =    899.3599853515625
# ====================
#
# date = '2023-11-14', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.36769104, 109.31452942]), ar_shares = array([8., 4.]), ar_value = array([474.94152832, 437.25811768]), portf_value = 912.1996459960938
# 2023-11-14 portf_value = 912.1996459960938
# date = '2023-11-14', l_syms = ['SPY'], ar_price = array([448.73001099]), ar_shares = array([2.]), ar_value = array([897.46002197]), portf_value = 897.4600219726562
# 2023-11-14 portf_value = 897.4600219726562
# close_date_n pick's portf value = 912.1996459960938
# close_date_n SPY portf value =    897.4600219726562
# ====================
#
# date = '2023-11-14', l_syms = ['CBOE'], ar_price = array([177.38999939]), ar_shares = array([5.]), ar_value = array([886.94999695]), portf_value = 886.9499969482422
# 2023-11-14 portf_value = 886.9499969482422
# date = '2023-11-14', l_syms = ['SPY'], ar_price = array([448.73001099]), ar_shares = array([2.]), ar_value = array([897.46002197]), portf_value = 897.4600219726562
# 2023-11-14 portf_value = 897.4600219726562
# close_date_n pick's portf value = 886.9499969482422
# close_date_n SPY portf value =    897.4600219726562
# ====================
#
# date = '2023-11-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.31789398, 109.27488708]), ar_shares = array([8., 4.]), ar_value = array([474.54315186, 437.09954834]), portf_value = 911.6427001953125
# 2023-11-13 portf_value = 911.6427001953125
# date = '2023-11-13', l_syms = ['SPY'], ar_price = array([440.19000244]), ar_shares = array([2.]), ar_value = array([880.38000488]), portf_value = 880.3800048828125
# 2023-11-13 portf_value = 880.3800048828125
# close_date_n pick's portf value = 911.6427001953125
# close_date_n SPY portf value =    880.3800048828125
# ====================
#
# date = '2023-11-13', l_syms = ['CBOE'], ar_price = array([178.47999573]), ar_shares = array([5.]), ar_value = array([892.39997864]), portf_value = 892.3999786376953
# 2023-11-13 portf_value = 892.3999786376953
# date = '2023-11-13', l_syms = ['SPY'], ar_price = array([440.19000244]), ar_shares = array([2.]), ar_value = array([880.38000488]), portf_value = 880.3800048828125
# 2023-11-13 portf_value = 880.3800048828125
# close_date_n pick's portf value = 892.3999786376953
# close_date_n SPY portf value =    880.3800048828125
# ====================
#
# date = '2023-11-10', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.29797745, 109.2649765 ]), ar_shares = array([8., 4.]), ar_value = array([474.38381958, 437.05990601]), portf_value = 911.4437255859375
# 2023-11-10 portf_value = 911.4437255859375
# date = '2023-11-10', l_syms = ['SPY'], ar_price = array([440.60998535]), ar_shares = array([2.]), ar_value = array([881.2199707]), portf_value = 881.219970703125
# 2023-11-10 portf_value = 881.219970703125
# close_date_n pick's portf value = 911.4437255859375
# close_date_n SPY portf value =    881.219970703125
# ====================
#
# date = '2023-11-10', l_syms = ['CBOE'], ar_price = array([174.97000122]), ar_shares = array([5.]), ar_value = array([874.8500061]), portf_value = 874.8500061035156
# 2023-11-10 portf_value = 874.8500061035156
# date = '2023-11-10', l_syms = ['SPY'], ar_price = array([440.60998535]), ar_shares = array([2.]), ar_value = array([881.2199707]), portf_value = 881.219970703125
# 2023-11-10 portf_value = 881.219970703125
# close_date_n pick's portf value = 874.8500061035156
# close_date_n SPY portf value =    881.219970703125
# ====================
#
# date = '2023-11-09', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.29299545, 109.23524475]), ar_shares = array([8., 4.]), ar_value = array([474.34396362, 436.940979  ]), portf_value = 911.2849426269531
# 2023-11-09 portf_value = 911.2849426269531
# date = '2023-11-09', l_syms = ['SPY'], ar_price = array([433.83999634]), ar_shares = array([2.]), ar_value = array([867.67999268]), portf_value = 867.6799926757812
# 2023-11-09 portf_value = 867.6799926757812
# close_date_n pick's portf value = 911.2849426269531
# close_date_n SPY portf value =    867.6799926757812
# ====================
#
# date = '2023-11-09', l_syms = ['NRG'], ar_price = array([45.06999969]), ar_shares = array([22.]), ar_value = array([991.53999329]), portf_value = 991.5399932861328
# 2023-11-09 portf_value = 991.5399932861328
# date = '2023-11-09', l_syms = ['SPY'], ar_price = array([433.83999634]), ar_shares = array([2.]), ar_value = array([867.67999268]), portf_value = 867.6799926757812
# 2023-11-09 portf_value = 867.6799926757812
# close_date_n pick's portf value = 991.5399932861328
# close_date_n SPY portf value =    867.6799926757812
# ====================
#
# date = '2023-11-08', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2780571 , 109.19560242]), ar_shares = array([8., 4.]), ar_value = array([474.22445679, 436.78240967]), portf_value = 911.0068664550781
# 2023-11-08 portf_value = 911.0068664550781
# date = '2023-11-08', l_syms = ['SPY'], ar_price = array([437.25]), ar_shares = array([2.]), ar_value = array([874.5]), portf_value = 874.5
# 2023-11-08 portf_value = 874.5
# close_date_n pick's portf value = 911.0068664550781
# close_date_n SPY portf value =    874.5
# ====================
#
# date = '2023-11-08', l_syms = ['NRG'], ar_price = array([45.68000031]), ar_shares = array([21.]), ar_value = array([959.28000641]), portf_value = 959.2800064086914
# 2023-11-08 portf_value = 959.2800064086914
# date = '2023-11-08', l_syms = ['SPY'], ar_price = array([437.25]), ar_shares = array([2.]), ar_value = array([874.5]), portf_value = 874.5
# 2023-11-08 portf_value = 874.5
# close_date_n pick's portf value = 959.2800064086914
# close_date_n SPY portf value =    874.5
# ====================
#
# date = '2023-11-07', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.28801346, 109.18569183]), ar_shares = array([8., 4.]), ar_value = array([474.30410767, 436.74276733]), portf_value = 911.046875
# 2023-11-07 portf_value = 911.046875
# date = '2023-11-07', l_syms = ['SPY'], ar_price = array([436.92999268]), ar_shares = array([2.]), ar_value = array([873.85998535]), portf_value = 873.8599853515625
# 2023-11-07 portf_value = 873.8599853515625
# close_date_n pick's portf value = 911.046875
# close_date_n SPY portf value =    873.8599853515625
# ====================
#
# date = '2023-11-07', l_syms = ['NRG'], ar_price = array([45.41999817]), ar_shares = array([22.]), ar_value = array([999.23995972]), portf_value = 999.2399597167969
# 2023-11-07 portf_value = 999.2399597167969
# date = '2023-11-07', l_syms = ['SPY'], ar_price = array([436.92999268]), ar_shares = array([2.]), ar_value = array([873.85998535]), portf_value = 873.8599853515625
# 2023-11-07 portf_value = 873.8599853515625
# close_date_n pick's portf value = 999.2399597167969
# close_date_n SPY portf value =    873.8599853515625
# ====================
#
# date = '2023-11-06', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2780571 , 109.15596008]), ar_shares = array([8., 4.]), ar_value = array([474.22445679, 436.62384033]), portf_value = 910.8482971191406
# 2023-11-06 portf_value = 910.8482971191406
# date = '2023-11-06', l_syms = ['SPY'], ar_price = array([435.69000244]), ar_shares = array([2.]), ar_value = array([871.38000488]), portf_value = 871.3800048828125
# 2023-11-06 portf_value = 871.3800048828125
# close_date_n pick's portf value = 910.8482971191406
# close_date_n SPY portf value =    871.3800048828125
# ====================
#
# date = '2023-11-06', l_syms = ['ANF'], ar_price = array([66.26999664]), ar_shares = array([15.]), ar_value = array([994.04994965]), portf_value = 994.0499496459961
# 2023-11-06 portf_value = 994.0499496459961
# date = '2023-11-06', l_syms = ['SPY'], ar_price = array([435.69000244]), ar_shares = array([2.]), ar_value = array([871.38000488]), portf_value = 871.3800048828125
# 2023-11-06 portf_value = 871.3800048828125
# close_date_n pick's portf value = 994.0499496459961
# close_date_n SPY portf value =    871.3800048828125
# ====================
#
# date = '2023-11-03', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2730751 , 109.16587067]), ar_shares = array([8., 4.]), ar_value = array([474.18460083, 436.66348267]), portf_value = 910.8480834960938
# 2023-11-03 portf_value = 910.8480834960938
# date = '2023-11-03', l_syms = ['SPY'], ar_price = array([434.69000244]), ar_shares = array([2.]), ar_value = array([869.38000488]), portf_value = 869.3800048828125
# 2023-11-03 portf_value = 869.3800048828125
# close_date_n pick's portf value = 910.8480834960938
# close_date_n SPY portf value =    869.3800048828125
# ====================
#
# date = '2023-11-03', l_syms = ['ANF'], ar_price = array([65.5]), ar_shares = array([15.]), ar_value = array([982.5]), portf_value = 982.5
# 2023-11-03 portf_value = 982.5
# date = '2023-11-03', l_syms = ['SPY'], ar_price = array([434.69000244]), ar_shares = array([2.]), ar_value = array([869.38000488]), portf_value = 869.3800048828125
# 2023-11-03 portf_value = 869.3800048828125
# close_date_n pick's portf value = 982.5
# close_date_n SPY portf value =    869.3800048828125
# ====================
#
# date = '2023-11-02', l_syms = ['FTSM'], ar_price = array([59.25813675]), ar_shares = array([16.]), ar_value = array([948.13018799]), portf_value = 948.1301879882812
# 2023-11-02 portf_value = 948.1301879882812
# date = '2023-11-02', l_syms = ['SPY'], ar_price = array([430.76000977]), ar_shares = array([2.]), ar_value = array([861.52001953]), portf_value = 861.52001953125
# 2023-11-02 portf_value = 861.52001953125
# close_date_n pick's portf value = 948.1301879882812
# close_date_n SPY portf value =    861.52001953125
# ====================
#
# date = '2023-11-02', l_syms = ['ANF'], ar_price = array([63.31000137]), ar_shares = array([15.]), ar_value = array([949.6500206]), portf_value = 949.6500205993652
# 2023-11-02 portf_value = 949.6500205993652
# date = '2023-11-02', l_syms = ['SPY'], ar_price = array([430.76000977]), ar_shares = array([2.]), ar_value = array([861.52001953]), portf_value = 861.52001953125
# 2023-11-02 portf_value = 861.52001953125
# close_date_n pick's portf value = 949.6500205993652
# close_date_n SPY portf value =    861.52001953125
# ====================
#
# date = '2023-11-01', l_syms = ['SHV'], ar_price = array([109.086586]), ar_shares = array([9.]), ar_value = array([981.77927399]), portf_value = 981.7792739868164
# 2023-11-01 portf_value = 981.7792739868164
# date = '2023-11-01', l_syms = ['SPY'], ar_price = array([422.66000366]), ar_shares = array([2.]), ar_value = array([845.32000732]), portf_value = 845.3200073242188
# 2023-11-01 portf_value = 845.3200073242188
# close_date_n pick's portf value = 981.7792739868164
# close_date_n SPY portf value =    845.3200073242188
# ====================
#
# date = '2023-11-01', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.21829987, 109.086586  ]), ar_shares = array([8., 4.]), ar_value = array([473.74639893, 436.34634399]), portf_value = 910.0927429199219
# 2023-11-01 portf_value = 910.0927429199219
# date = '2023-11-01', l_syms = ['SPY'], ar_price = array([422.66000366]), ar_shares = array([2.]), ar_value = array([845.32000732]), portf_value = 845.3200073242188
# 2023-11-01 portf_value = 845.3200073242188
# close_date_n pick's portf value = 910.0927429199219
# close_date_n SPY portf value =    845.3200073242188
# ====================
#
# date = '2023-11-01', l_syms = ['ANF', 'SPLK'], ar_price = array([ 62.13000107, 146.88000488]), ar_shares = array([8., 3.]), ar_value = array([497.04000854, 440.64001465]), portf_value = 937.6800231933594
# 2023-11-01 portf_value = 937.6800231933594
# date = '2023-11-01', l_syms = ['SPY'], ar_price = array([422.66000366]), ar_shares = array([2.]), ar_value = array([845.32000732]), portf_value = 845.3200073242188
# 2023-11-01 portf_value = 845.3200073242188
# close_date_n pick's portf value = 937.6800231933594
# close_date_n SPY portf value =    845.3200073242188
# ====================
#
# date = '2023-11-01', l_syms = ['SHV'], ar_price = array([109.086586]), ar_shares = array([9.]), ar_value = array([981.77927399]), portf_value = 981.7792739868164
# 2023-11-01 portf_value = 981.7792739868164
# date = '2023-11-01', l_syms = ['SPY'], ar_price = array([422.66000366]), ar_shares = array([2.]), ar_value = array([845.32000732]), portf_value = 845.3200073242188
# 2023-11-01 portf_value = 845.3200073242188
# close_date_n pick's portf value = 981.7792739868164
# close_date_n SPY portf value =    845.3200073242188
# ====================
#
# date = '2023-10-31', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.18842316, 109.04891968]), ar_shares = array([8., 4.]), ar_value = array([473.50738525, 436.19567871]), portf_value = 909.7030639648438
# 2023-10-31 portf_value = 909.7030639648438
# date = '2023-10-31', l_syms = ['SPY'], ar_price = array([418.20001221]), ar_shares = array([2.]), ar_value = array([836.40002441]), portf_value = 836.4000244140625
# 2023-10-31 portf_value = 836.4000244140625
# close_date_n pick's portf value = 909.7030639648438
# close_date_n SPY portf value =    836.4000244140625
# ====================
#
# date = '2023-10-31', l_syms = ['SPLK'], ar_price = array([147.16000366]), ar_shares = array([6.]), ar_value = array([882.96002197]), portf_value = 882.9600219726562
# 2023-10-31 portf_value = 882.9600219726562
# date = '2023-10-31', l_syms = ['SPY'], ar_price = array([418.20001221]), ar_shares = array([2.]), ar_value = array([836.40002441]), portf_value = 836.4000244140625
# 2023-10-31 portf_value = 836.4000244140625
# close_date_n pick's portf value = 882.9600219726562
# close_date_n SPY portf value =    836.4000244140625
# ====================
#
# date = '2023-10-31', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.18842316, 109.04891968]), ar_shares = array([8., 4.]), ar_value = array([473.50738525, 436.19567871]), portf_value = 909.7030639648438
# 2023-10-31 portf_value = 909.7030639648438
# date = '2023-10-31', l_syms = ['SPY'], ar_price = array([418.20001221]), ar_shares = array([2.]), ar_value = array([836.40002441]), portf_value = 836.4000244140625
# 2023-10-31 portf_value = 836.4000244140625
# close_date_n pick's portf value = 909.7030639648438
# close_date_n SPY portf value =    836.4000244140625
# ====================
#
# date = '2023-10-30', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.19937897, 109.04891968]), ar_shares = array([8., 4.]), ar_value = array([473.59503174, 436.19567871]), portf_value = 909.7907104492188
# 2023-10-30 portf_value = 909.7907104492188
# date = '2023-10-30', l_syms = ['SPY'], ar_price = array([415.58999634]), ar_shares = array([2.]), ar_value = array([831.17999268]), portf_value = 831.1799926757812
# 2023-10-30 portf_value = 831.1799926757812
# close_date_n pick's portf value = 909.7907104492188
# close_date_n SPY portf value =    831.1799926757812
# ====================
#
# date = '2023-10-30', l_syms = ['SPLK'], ar_price = array([147.19999695]), ar_shares = array([6.]), ar_value = array([883.19998169]), portf_value = 883.1999816894531
# 2023-10-30 portf_value = 883.1999816894531
# date = '2023-10-30', l_syms = ['SPY'], ar_price = array([415.58999634]), ar_shares = array([2.]), ar_value = array([831.17999268]), portf_value = 831.1799926757812
# 2023-10-30 portf_value = 831.1799926757812
# close_date_n pick's portf value = 883.1999816894531
# close_date_n SPY portf value =    831.1799926757812
# ====================
#
# date = '2023-10-30', l_syms = ['SHV'], ar_price = array([109.04891968]), ar_shares = array([9.]), ar_value = array([981.4402771]), portf_value = 981.4402770996094
# 2023-10-30 portf_value = 981.4402770996094
# date = '2023-10-30', l_syms = ['SPY'], ar_price = array([415.58999634]), ar_shares = array([2.]), ar_value = array([831.17999268]), portf_value = 831.1799926757812
# 2023-10-30 portf_value = 831.1799926757812
# close_date_n pick's portf value = 981.4402770996094
# close_date_n SPY portf value =    831.1799926757812
# ====================
#
# date = '2023-10-27', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.18449783, 109.03904724]), ar_shares = array([8., 4.]), ar_value = array([473.47598267, 436.15618896]), portf_value = 909.6321716308594
# 2023-10-27 portf_value = 909.6321716308594
# date = '2023-10-27', l_syms = ['SPY'], ar_price = array([410.67999268]), ar_shares = array([2.]), ar_value = array([821.35998535]), portf_value = 821.3599853515625
# 2023-10-27 portf_value = 821.3599853515625
# close_date_n pick's portf value = 909.6321716308594
# close_date_n SPY portf value =    821.3599853515625
# ====================
#
# date = '2023-10-27', l_syms = ['SPLK'], ar_price = array([147.13999939]), ar_shares = array([6.]), ar_value = array([882.83999634]), portf_value = 882.8399963378906
# 2023-10-27 portf_value = 882.8399963378906
# date = '2023-10-27', l_syms = ['SPY'], ar_price = array([410.67999268]), ar_shares = array([2.]), ar_value = array([821.35998535]), portf_value = 821.3599853515625
# 2023-10-27 portf_value = 821.3599853515625
# close_date_n pick's portf value = 882.8399963378906
# close_date_n SPY portf value =    821.3599853515625
# ====================
#
# date = '2023-10-26', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.17954254, 109.01931763]), ar_shares = array([8., 4.]), ar_value = array([473.43634033, 436.07727051]), portf_value = 909.5136108398438
# 2023-10-26 portf_value = 909.5136108398438
# date = '2023-10-26', l_syms = ['SPY'], ar_price = array([412.54998779]), ar_shares = array([2.]), ar_value = array([825.09997559]), portf_value = 825.0999755859375
# 2023-10-26 portf_value = 825.0999755859375
# close_date_n pick's portf value = 909.5136108398438
# close_date_n SPY portf value =    825.0999755859375
# ====================
#
# date = '2023-10-26', l_syms = ['ANF', 'SPLK'], ar_price = array([ 59.84999847, 147.13000488]), ar_shares = array([8., 3.]), ar_value = array([478.79998779, 441.39001465]), portf_value = 920.1900024414062
# 2023-10-26 portf_value = 920.1900024414062
# date = '2023-10-26', l_syms = ['SPY'], ar_price = array([412.54998779]), ar_shares = array([2.]), ar_value = array([825.09997559]), portf_value = 825.0999755859375
# 2023-10-26 portf_value = 825.0999755859375
# close_date_n pick's portf value = 920.1900024414062
# close_date_n SPY portf value =    825.0999755859375
# ====================
#
# date = '2023-10-25', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.13490677, 108.95023346]), ar_shares = array([8., 4.]), ar_value = array([473.07925415, 435.80093384]), portf_value = 908.8801879882812
# 2023-10-25 portf_value = 908.8801879882812
# date = '2023-10-25', l_syms = ['SPY'], ar_price = array([417.54998779]), ar_shares = array([2.]), ar_value = array([835.09997559]), portf_value = 835.0999755859375
# 2023-10-25 portf_value = 835.0999755859375
# close_date_n pick's portf value = 908.8801879882812
# close_date_n SPY portf value =    835.0999755859375
# ====================
#
# date = '2023-10-25', l_syms = ['ANF'], ar_price = array([61.58000183]), ar_shares = array([16.]), ar_value = array([985.2800293]), portf_value = 985.280029296875
# 2023-10-25 portf_value = 985.280029296875
# date = '2023-10-25', l_syms = ['SPY'], ar_price = array([417.54998779]), ar_shares = array([2.]), ar_value = array([835.09997559]), portf_value = 835.0999755859375
# 2023-10-25 portf_value = 835.0999755859375
# close_date_n pick's portf value = 985.280029296875
# close_date_n SPY portf value =    835.0999755859375
# ====================
#
# date = '2023-10-24', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.1448288 , 108.95023346]), ar_shares = array([8., 4.]), ar_value = array([473.15863037, 435.80093384]), portf_value = 908.9595642089844
# 2023-10-24 portf_value = 908.9595642089844
# date = '2023-10-24', l_syms = ['SPY'], ar_price = array([423.63000488]), ar_shares = array([2.]), ar_value = array([847.26000977]), portf_value = 847.260009765625
# 2023-10-24 portf_value = 847.260009765625
# close_date_n pick's portf value = 908.9595642089844
# close_date_n SPY portf value =    847.260009765625
# ====================
#
# date = '2023-10-24', l_syms = ['SPLK'], ar_price = array([147.66999817]), ar_shares = array([6.]), ar_value = array([886.01998901]), portf_value = 886.0199890136719
# 2023-10-24 portf_value = 886.0199890136719
# date = '2023-10-24', l_syms = ['SPY'], ar_price = array([423.63000488]), ar_shares = array([2.]), ar_value = array([847.26000977]), portf_value = 847.260009765625
# 2023-10-24 portf_value = 847.260009765625
# close_date_n pick's portf value = 886.0199890136719
# close_date_n SPY portf value =    847.260009765625
# ====================
#
# date = '2023-10-23', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.1448288 , 108.94036865]), ar_shares = array([8., 4.]), ar_value = array([473.15863037, 435.76147461]), portf_value = 908.9201049804688
# 2023-10-23 portf_value = 908.9201049804688
# date = '2023-10-23', l_syms = ['SPY'], ar_price = array([420.45999146]), ar_shares = array([2.]), ar_value = array([840.91998291]), portf_value = 840.9199829101562
# 2023-10-23 portf_value = 840.9199829101562
# close_date_n pick's portf value = 908.9201049804688
# close_date_n SPY portf value =    840.9199829101562
# ====================
#
# date = '2023-10-20', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.11507034, 108.92063904]), ar_shares = array([8., 4.]), ar_value = array([472.92056274, 435.68255615]), portf_value = 908.6031188964844
# 2023-10-20 portf_value = 908.6031188964844
# date = '2023-10-20', l_syms = ['SPY'], ar_price = array([421.19000244]), ar_shares = array([2.]), ar_value = array([842.38000488]), portf_value = 842.3800048828125
# 2023-10-20 portf_value = 842.3800048828125
# close_date_n pick's portf value = 908.6031188964844
# close_date_n SPY portf value =    842.3800048828125
# ====================
#
# date = '2023-10-20', l_syms = ['SHV'], ar_price = array([108.92063904]), ar_shares = array([9.]), ar_value = array([980.28575134]), portf_value = 980.2857513427734
# 2023-10-20 portf_value = 980.2857513427734
# date = '2023-10-20', l_syms = ['SPY'], ar_price = array([421.19000244]), ar_shares = array([2.]), ar_value = array([842.38000488]), portf_value = 842.3800048828125
# 2023-10-20 portf_value = 842.3800048828125
# close_date_n pick's portf value = 980.2857513427734
# close_date_n SPY portf value =    842.3800048828125
# ====================
#
# date = '2023-10-19', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.09523392, 108.89102936]), ar_shares = array([8., 4.]), ar_value = array([472.76187134, 435.56411743]), portf_value = 908.3259887695312
# 2023-10-19 portf_value = 908.3259887695312
# date = '2023-10-19', l_syms = ['SPY'], ar_price = array([426.42999268]), ar_shares = array([2.]), ar_value = array([852.85998535]), portf_value = 852.8599853515625
# 2023-10-19 portf_value = 852.8599853515625
# close_date_n pick's portf value = 908.3259887695312
# close_date_n SPY portf value =    852.8599853515625
# ====================
#
# date = '2023-10-18', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.06547546, 108.84168243]), ar_shares = array([8., 4.]), ar_value = array([472.52380371, 435.36672974]), portf_value = 907.8905334472656
# 2023-10-18 portf_value = 907.8905334472656
# date = '2023-10-18', l_syms = ['SPY'], ar_price = array([430.20999146]), ar_shares = array([2.]), ar_value = array([860.41998291]), portf_value = 860.4199829101562
# 2023-10-18 portf_value = 860.4199829101562
# close_date_n pick's portf value = 907.8905334472656
# close_date_n SPY portf value =    860.4199829101562
# ====================
#
# date = '2023-10-17', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.07043839, 108.83181   ]), ar_shares = array([8., 4.]), ar_value = array([472.56350708, 435.32723999]), portf_value = 907.8907470703125
# 2023-10-17 portf_value = 907.8907470703125
# date = '2023-10-17', l_syms = ['SPY'], ar_price = array([436.01998901]), ar_shares = array([2.]), ar_value = array([872.03997803]), portf_value = 872.0399780273438
# 2023-10-17 portf_value = 872.0399780273438
# close_date_n pick's portf value = 907.8907470703125
# close_date_n SPY portf value =    872.0399780273438
# ====================
#
# date = '2023-10-16', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.07539749, 108.82193756]), ar_shares = array([8., 4.]), ar_value = array([472.60317993, 435.28775024]), portf_value = 907.8909301757812
# 2023-10-16 portf_value = 907.8909301757812
# date = '2023-10-16', l_syms = ['SPY'], ar_price = array([436.04000854]), ar_shares = array([2.]), ar_value = array([872.08001709]), portf_value = 872.0800170898438
# 2023-10-16 portf_value = 872.0800170898438
# close_date_n pick's portf value = 907.8909301757812
# close_date_n SPY portf value =    872.0800170898438
# ====================
#
# date = '2023-10-16', l_syms = ['SHV'], ar_price = array([108.82193756]), ar_shares = array([9.]), ar_value = array([979.39743805]), portf_value = 979.3974380493164
# 2023-10-16 portf_value = 979.3974380493164
# date = '2023-10-16', l_syms = ['SPY'], ar_price = array([436.04000854]), ar_shares = array([2.]), ar_value = array([872.08001709]), portf_value = 872.0800170898438
# 2023-10-16 portf_value = 872.0800170898438
# close_date_n pick's portf value = 979.3974380493164
# close_date_n SPY portf value =    872.0800170898438
# ====================
#
# date = '2023-10-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.0853157 , 108.81207275]), ar_shares = array([8., 4.]), ar_value = array([472.68252563, 435.24829102]), portf_value = 907.9308166503906
# 2023-10-13 portf_value = 907.9308166503906
# date = '2023-10-13', l_syms = ['SPY'], ar_price = array([431.5]), ar_shares = array([2.]), ar_value = array([863.]), portf_value = 863.0
# 2023-10-13 portf_value = 863.0
# close_date_n pick's portf value = 907.9308166503906
# close_date_n SPY portf value =    863.0
# ====================
#
# date = '2023-10-12', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.05556107, 108.79233551]), ar_shares = array([8., 4.]), ar_value = array([472.44448853, 435.16934204]), portf_value = 907.6138305664062
# 2023-10-12 portf_value = 907.6138305664062
# date = '2023-10-12', l_syms = ['SPY'], ar_price = array([433.66000366]), ar_shares = array([2.]), ar_value = array([867.32000732]), portf_value = 867.3200073242188
# 2023-10-12 portf_value = 867.3200073242188
# close_date_n pick's portf value = 907.6138305664062
# close_date_n SPY portf value =    867.3200073242188
# ====================
#
# date = '2023-10-11', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.03076172, 108.73312378]), ar_shares = array([8., 4.]), ar_value = array([472.24609375, 434.93249512]), portf_value = 907.1785888671875
# 2023-10-11 portf_value = 907.1785888671875
# date = '2023-10-11', l_syms = ['SPY'], ar_price = array([436.32000732]), ar_shares = array([2.]), ar_value = array([872.64001465]), portf_value = 872.6400146484375
# 2023-10-11 portf_value = 872.6400146484375
# close_date_n pick's portf value = 907.1785888671875
# close_date_n SPY portf value =    872.6400146484375
# ====================
#
# date = '2023-10-11', l_syms = ['SHV'], ar_price = array([108.73312378]), ar_shares = array([9.]), ar_value = array([978.59811401]), portf_value = 978.5981140136719
# 2023-10-11 portf_value = 978.5981140136719
# date = '2023-10-11', l_syms = ['SPY'], ar_price = array([436.32000732]), ar_shares = array([2.]), ar_value = array([872.64001465]), portf_value = 872.6400146484375
# 2023-10-11 portf_value = 872.6400146484375
# close_date_n pick's portf value = 978.5981140136719
# close_date_n SPY portf value =    872.6400146484375
# ====================
#
# date = '2023-10-10', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.02580261, 108.72325897]), ar_shares = array([8., 4.]), ar_value = array([472.2064209 , 434.89303589]), portf_value = 907.0994567871094
# 2023-10-10 portf_value = 907.0994567871094
# date = '2023-10-10', l_syms = ['SPY'], ar_price = array([434.54000854]), ar_shares = array([2.]), ar_value = array([869.08001709]), portf_value = 869.0800170898438
# 2023-10-10 portf_value = 869.0800170898438
# close_date_n pick's portf value = 907.0994567871094
# close_date_n SPY portf value =    869.0800170898438
# ====================
#
# date = '2023-10-10', l_syms = ['SHV'], ar_price = array([108.72325897]), ar_shares = array([9.]), ar_value = array([978.50933075]), portf_value = 978.5093307495117
# 2023-10-10 portf_value = 978.5093307495117
# date = '2023-10-10', l_syms = ['SPY'], ar_price = array([434.54000854]), ar_shares = array([2.]), ar_value = array([869.08001709]), portf_value = 869.0800170898438
# 2023-10-10 portf_value = 869.0800170898438
# close_date_n pick's portf value = 978.5093307495117
# close_date_n SPY portf value =    869.0800170898438
# ====================
#
# date = '2023-10-09', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.02580261, 108.71338654]), ar_shares = array([8., 4.]), ar_value = array([472.2064209 , 434.85354614]), portf_value = 907.0599670410156
# 2023-10-09 portf_value = 907.0599670410156
# date = '2023-10-09', l_syms = ['SPY'], ar_price = array([432.29000854]), ar_shares = array([2.]), ar_value = array([864.58001709]), portf_value = 864.5800170898438
# 2023-10-09 portf_value = 864.5800170898438
# close_date_n pick's portf value = 907.0599670410156
# close_date_n SPY portf value =    864.5800170898438
# ====================
#
# ...
# ====================
#
# date = '2023-04-19', l_syms = ['SHV'], ar_price = array([106.21281433]), ar_shares = array([9.]), ar_value = array([955.91532898]), portf_value = 955.9153289794922
# 2023-04-19 portf_value = 955.9153289794922
# date = '2023-04-19', l_syms = ['SPY'], ar_price = array([411.15704346]), ar_shares = array([2.]), ar_value = array([822.31408691]), portf_value = 822.3140869140625
# 2023-04-19 portf_value = 822.3140869140625
# close_date_n pick's portf value = 955.9153289794922
# close_date_n SPY portf value =    822.3140869140625
# ====================
#
# date = '2023-04-18', l_syms = ['ELF', 'SHV'], ar_price = array([ 92.58000183, 106.20317841]), ar_shares = array([5., 4.]), ar_value = array([462.90000916, 424.81271362]), portf_value = 887.7127227783203
# 2023-04-18 portf_value = 887.7127227783203
# date = '2023-04-18', l_syms = ['SPY'], ar_price = array([411.22653198]), ar_shares = array([2.]), ar_value = array([822.45306396]), portf_value = 822.4530639648438
# 2023-04-18 portf_value = 822.4530639648438
# close_date_n pick's portf value = 887.7127227783203
# close_date_n SPY portf value =    822.4530639648438
# ====================
#
# date = '2023-04-17', l_syms = ['SHV'], ar_price = array([106.18392181]), ar_shares = array([9.]), ar_value = array([955.65529633]), portf_value = 955.6552963256836
# 2023-04-17 portf_value = 955.6552963256836
# date = '2023-04-17', l_syms = ['SPY'], ar_price = array([410.95846558]), ar_shares = array([2.]), ar_value = array([821.91693115]), portf_value = 821.9169311523438
# 2023-04-17 portf_value = 821.9169311523438
# close_date_n pick's portf value = 955.6552963256836
# close_date_n SPY portf value =    821.9169311523438
# ====================
#
# date = '2023-04-14', l_syms = ['SHV'], ar_price = array([106.17427826]), ar_shares = array([9.]), ar_value = array([955.56850433]), portf_value = 955.5685043334961
# 2023-04-14 portf_value = 955.5685043334961
# date = '2023-04-14', l_syms = ['SPY'], ar_price = array([409.48913574]), ar_shares = array([2.]), ar_value = array([818.97827148]), portf_value = 818.978271484375
# 2023-04-14 portf_value = 818.978271484375
# close_date_n pick's portf value = 955.5685043334961
# close_date_n SPY portf value =    818.978271484375
# ====================
#
# date = '2023-04-13', l_syms = ['SHV'], ar_price = array([106.19354248]), ar_shares = array([9.]), ar_value = array([955.74188232]), portf_value = 955.7418823242188
# 2023-04-13 portf_value = 955.7418823242188
# date = '2023-04-13', l_syms = ['SPY'], ar_price = array([410.49185181]), ar_shares = array([2.]), ar_value = array([820.98370361]), portf_value = 820.9837036132812
# 2023-04-13 portf_value = 820.9837036132812
# close_date_n pick's portf value = 955.7418823242188
# close_date_n SPY portf value =    820.9837036132812
# ====================
#
# date = '2023-04-12', l_syms = ['SHV'], ar_price = array([106.13576508]), ar_shares = array([9.]), ar_value = array([955.22188568]), portf_value = 955.2218856811523
# 2023-04-12 portf_value = 955.2218856811523
# date = '2023-04-12', l_syms = ['SPY'], ar_price = array([405.11090088]), ar_shares = array([2.]), ar_value = array([810.22180176]), portf_value = 810.2218017578125
# 2023-04-12 portf_value = 810.2218017578125
# close_date_n pick's portf value = 955.2218856811523
# close_date_n SPY portf value =    810.2218017578125
# ====================
#
# date = '2023-04-11', l_syms = ['SHV'], ar_price = array([106.12612152]), ar_shares = array([9.]), ar_value = array([955.13509369]), portf_value = 955.1350936889648
# 2023-04-11 portf_value = 955.1350936889648
# date = '2023-04-11', l_syms = ['SPY'], ar_price = array([406.76885986]), ar_shares = array([2.]), ar_value = array([813.53771973]), portf_value = 813.5377197265625
# 2023-04-11 portf_value = 813.5377197265625
# close_date_n pick's portf value = 955.1350936889648
# close_date_n SPY portf value =    813.5377197265625
# ====================
#
# date = '2023-04-10', l_syms = ['SHV'], ar_price = array([106.10688019]), ar_shares = array([9.]), ar_value = array([954.96192169]), portf_value = 954.9619216918945
# 2023-04-10 portf_value = 954.9619216918945
# date = '2023-04-10', l_syms = ['SPY'], ar_price = array([406.65963745]), ar_shares = array([2.]), ar_value = array([813.3192749]), portf_value = 813.3192749023438
# 2023-04-10 portf_value = 813.3192749023438
# close_date_n pick's portf value = 954.9619216918945
# close_date_n SPY portf value =    813.3192749023438
# ====================
#
# date = '2023-04-06', l_syms = ['SHV'], ar_price = array([106.11650848]), ar_shares = array([9.]), ar_value = array([955.04857635]), portf_value = 955.0485763549805
# 2023-04-06 portf_value = 955.0485763549805
# date = '2023-04-06', l_syms = ['SPY'], ar_price = array([406.24267578]), ar_shares = array([2.]), ar_value = array([812.48535156]), portf_value = 812.4853515625
# 2023-04-06 portf_value = 812.4853515625
# close_date_n pick's portf value = 955.0485763549805
# close_date_n SPY portf value =    812.4853515625
# ====================
#
# date = '2023-04-05', l_syms = ['NVDA', 'SHV'], ar_price = array([268.7364502 , 106.11650848]), ar_shares = array([1., 4.]), ar_value = array([268.7364502 , 424.46603394]), portf_value = 693.2024841308594
# 2023-04-05 portf_value = 693.2024841308594
# date = '2023-04-05', l_syms = ['SPY'], ar_price = array([404.66415405]), ar_shares = array([2.]), ar_value = array([809.32830811]), portf_value = 809.3283081054688
# 2023-04-05 portf_value = 809.3283081054688
# close_date_n pick's portf value = 693.2024841308594
# close_date_n SPY portf value =    809.3283081054688
# ====================
#
# date = '2023-04-04', l_syms = ['GE', 'NVDA'], ar_price = array([ 94.91146088, 274.45483398]), ar_shares = array([5., 1.]), ar_value = array([474.55730438, 274.45483398]), portf_value = 749.0121383666992
# 2023-04-04 portf_value = 749.0121383666992
# date = '2023-04-04', l_syms = ['SPY'], ar_price = array([405.72644043]), ar_shares = array([2.]), ar_value = array([811.45288086]), portf_value = 811.452880859375
# 2023-04-04 portf_value = 811.452880859375
# close_date_n pick's portf value = 749.0121383666992
# close_date_n SPY portf value =    811.452880859375
# ====================
#
# date = '2023-04-03', l_syms = ['NVDA'], ar_price = array([279.57342529]), ar_shares = array([3.]), ar_value = array([838.72027588]), portf_value = 838.7202758789062
# 2023-04-03 portf_value = 838.7202758789062
# date = '2023-04-03', l_syms = ['SPY'], ar_price = array([407.99002075]), ar_shares = array([2.]), ar_value = array([815.9800415]), portf_value = 815.9800415039062
# 2023-04-03 portf_value = 815.9800415039062
# close_date_n pick's portf value = 838.7202758789062
# close_date_n SPY portf value =    815.9800415039062
# ====================
#
# date = '2023-03-31', l_syms = ['SHV'], ar_price = array([106.02886963]), ar_shares = array([9.]), ar_value = array([954.25982666]), portf_value = 954.2598266601562
# 2023-03-31 portf_value = 954.2598266601562
# date = '2023-03-31', l_syms = ['SPY'], ar_price = array([406.44125366]), ar_shares = array([2.]), ar_value = array([812.88250732]), portf_value = 812.8825073242188
# 2023-03-31 portf_value = 812.8825073242188
# close_date_n pick's portf value = 954.2598266601562
# close_date_n SPY portf value =    812.8825073242188
# ====================
#
# date = '2023-03-31', l_syms = ['NVDA'], ar_price = array([277.69393921]), ar_shares = array([3.]), ar_value = array([833.08181763]), portf_value = 833.0818176269531
# 2023-03-31 portf_value = 833.0818176269531
# date = '2023-03-31', l_syms = ['SPY'], ar_price = array([406.44125366]), ar_shares = array([2.]), ar_value = array([812.88250732]), portf_value = 812.8825073242188
# 2023-03-31 portf_value = 812.8825073242188
# close_date_n pick's portf value = 833.0818176269531
# close_date_n SPY portf value =    812.8825073242188
# ====================
#
# date = '2023-03-30', l_syms = ['SHV'], ar_price = array([106.01929474]), ar_shares = array([9.]), ar_value = array([954.17365265]), portf_value = 954.1736526489258
# 2023-03-30 portf_value = 954.1736526489258
# date = '2023-03-30', l_syms = ['SPY'], ar_price = array([400.79226685]), ar_shares = array([2.]), ar_value = array([801.58453369]), portf_value = 801.5845336914062
# 2023-03-30 portf_value = 801.5845336914062
# close_date_n pick's portf value = 954.1736526489258
# close_date_n SPY portf value =    801.5845336914062
# ====================
#
# date = '2023-03-29', l_syms = ['SHV'], ar_price = array([106.00010681]), ar_shares = array([9.]), ar_value = array([954.0009613]), portf_value = 954.0009613037109
# 2023-03-29 portf_value = 954.0009613037109
# date = '2023-03-29', l_syms = ['SPY'], ar_price = array([398.45916748]), ar_shares = array([2.]), ar_value = array([796.91833496]), portf_value = 796.9183349609375
# 2023-03-29 portf_value = 796.9183349609375
# close_date_n pick's portf value = 954.0009613037109
# close_date_n SPY portf value =    796.9183349609375
# ====================
#
# date = '2023-03-28', l_syms = ['SHV'], ar_price = array([105.99047852]), ar_shares = array([9.]), ar_value = array([953.91430664]), portf_value = 953.914306640625
# 2023-03-28 portf_value = 953.914306640625
# date = '2023-03-28', l_syms = ['SPY'], ar_price = array([392.75057983]), ar_shares = array([2.]), ar_value = array([785.50115967]), portf_value = 785.5011596679688
# 2023-03-28 portf_value = 785.5011596679688
# close_date_n pick's portf value = 953.914306640625
# close_date_n SPY portf value =    785.5011596679688
# ====================
#
# date = '2023-03-28', l_syms = ['GE'], ar_price = array([93.00424194]), ar_shares = array([10.]), ar_value = array([930.04241943]), portf_value = 930.0424194335938
# 2023-03-28 portf_value = 930.0424194335938
# date = '2023-03-28', l_syms = ['SPY'], ar_price = array([392.75057983]), ar_shares = array([2.]), ar_value = array([785.50115967]), portf_value = 785.5011596679688
# 2023-03-28 portf_value = 785.5011596679688
# close_date_n pick's portf value = 930.0424194335938
# close_date_n SPY portf value =    785.5011596679688
# ====================
#
# date = '2023-03-27', l_syms = ['NVDA', 'SHV'], ar_price = array([265.23739624, 105.980896  ]), ar_shares = array([1., 4.]), ar_value = array([265.23739624, 423.92358398]), portf_value = 689.1609802246094
# 2023-03-27 portf_value = 689.1609802246094
# date = '2023-03-27', l_syms = ['SPY'], ar_price = array([393.63415527]), ar_shares = array([2.]), ar_value = array([787.26831055]), portf_value = 787.268310546875
# 2023-03-27 portf_value = 787.268310546875
# close_date_n pick's portf value = 689.1609802246094
# close_date_n SPY portf value =    787.268310546875
# ====================
#
# date = '2023-03-24', l_syms = ['SHV'], ar_price = array([105.980896]), ar_shares = array([9.]), ar_value = array([953.82806396]), portf_value = 953.8280639648438
# 2023-03-24 portf_value = 953.8280639648438
# date = '2023-03-24', l_syms = ['SPY'], ar_price = array([392.8994751]), ar_shares = array([2.]), ar_value = array([785.7989502]), portf_value = 785.7989501953125
# 2023-03-24 portf_value = 785.7989501953125
# close_date_n pick's portf value = 953.8280639648438
# close_date_n SPY portf value =    785.7989501953125
# ====================
#
# date = '2023-03-23', l_syms = ['SHV'], ar_price = array([105.97129822]), ar_shares = array([9.]), ar_value = array([953.74168396]), portf_value = 953.7416839599609
# 2023-03-23 portf_value = 953.7416839599609
# date = '2023-03-23', l_syms = ['SPY'], ar_price = array([390.33810425]), ar_shares = array([2.]), ar_value = array([780.6762085]), portf_value = 780.6762084960938
# 2023-03-23 portf_value = 780.6762084960938
# close_date_n pick's portf value = 953.7416839599609
# close_date_n SPY portf value =    780.6762084960938
# ====================
#
# date = '2023-03-23', l_syms = ['FTSM'], ar_price = array([57.60237503]), ar_shares = array([17.]), ar_value = array([979.24037552]), portf_value = 979.2403755187988
# 2023-03-23 portf_value = 979.2403755187988
# date = '2023-03-23', l_syms = ['SPY'], ar_price = array([390.33810425]), ar_shares = array([2.]), ar_value = array([780.6762085]), portf_value = 780.6762084960938
# 2023-03-23 portf_value = 780.6762084960938
# close_date_n pick's portf value = 979.2403755187988
# close_date_n SPY portf value =    780.6762084960938
# ====================
#
# date = '2023-03-22', l_syms = ['SHV'], ar_price = array([105.90413666]), ar_shares = array([9.]), ar_value = array([953.13722992]), portf_value = 953.1372299194336
# 2023-03-22 portf_value = 953.1372299194336
# date = '2023-03-22', l_syms = ['SPY'], ar_price = array([389.28570557]), ar_shares = array([2.]), ar_value = array([778.57141113]), portf_value = 778.5714111328125
# 2023-03-22 portf_value = 778.5714111328125
# close_date_n pick's portf value = 953.1372299194336
# close_date_n SPY portf value =    778.5714111328125
# ====================
#
# date = '2023-03-22', l_syms = ['GE'], ar_price = array([89.45941925]), ar_shares = array([11.]), ar_value = array([984.05361176]), portf_value = 984.0536117553711
# 2023-03-22 portf_value = 984.0536117553711
# date = '2023-03-22', l_syms = ['SPY'], ar_price = array([389.28570557]), ar_shares = array([2.]), ar_value = array([778.57141113]), portf_value = 778.5714111328125
# 2023-03-22 portf_value = 778.5714111328125
# close_date_n pick's portf value = 984.0536117553711
# close_date_n SPY portf value =    778.5714111328125
# ====================
#
# date = '2023-03-21', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.53480148, 105.86575317]), ar_shares = array([8., 4.]), ar_value = array([460.27841187, 423.4630127 ]), portf_value = 883.7414245605469
# 2023-03-21 portf_value = 883.7414245605469
# date = '2023-03-21', l_syms = ['SPY'], ar_price = array([396.03671265]), ar_shares = array([2.]), ar_value = array([792.07342529]), portf_value = 792.0734252929688
# 2023-03-21 portf_value = 792.0734252929688
# close_date_n pick's portf value = 883.7414245605469
# close_date_n SPY portf value =    792.0734252929688
# ====================
#
# date = '2023-03-20', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.59272003, 105.89453888]), ar_shares = array([8., 4.]), ar_value = array([460.74176025, 423.57815552]), portf_value = 884.3199157714844
# 2023-03-20 portf_value = 884.3199157714844
# date = '2023-03-20', l_syms = ['SPY'], ar_price = array([390.90396118]), ar_shares = array([2.]), ar_value = array([781.80792236]), portf_value = 781.8079223632812
# 2023-03-20 portf_value = 781.8079223632812
# close_date_n pick's portf value = 884.3199157714844
# close_date_n SPY portf value =    781.8079223632812
# ====================
#
# date = '2023-03-20', l_syms = ['GE'], ar_price = array([89.78894043]), ar_shares = array([11.]), ar_value = array([987.67834473]), portf_value = 987.6783447265625
# 2023-03-20 portf_value = 987.6783447265625
# date = '2023-03-20', l_syms = ['SPY'], ar_price = array([390.90396118]), ar_shares = array([2.]), ar_value = array([781.80792236]), portf_value = 781.8079223632812
# 2023-03-20 portf_value = 781.8079223632812
# close_date_n pick's portf value = 987.6783447265625
# close_date_n SPY portf value =    781.8079223632812
# ====================
#
# date = '2023-03-17', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.5058403 , 105.91373444]), ar_shares = array([8., 4.]), ar_value = array([460.04672241, 423.65493774]), portf_value = 883.70166015625
# 2023-03-17 portf_value = 883.70166015625
# date = '2023-03-17', l_syms = ['SPY'], ar_price = array([387.18096924]), ar_shares = array([2.]), ar_value = array([774.36193848]), portf_value = 774.3619384765625
# 2023-03-17 portf_value = 774.3619384765625
# close_date_n pick's portf value = 883.70166015625
# close_date_n SPY portf value =    774.3619384765625
# ====================
#
# date = '2023-03-16', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.51549149, 105.8369751 ]), ar_shares = array([8., 4.]), ar_value = array([460.12393188, 423.34790039]), portf_value = 883.4718322753906
# 2023-03-16 portf_value = 883.4718322753906
# date = '2023-03-16', l_syms = ['SPY'], ar_price = array([391.76171875]), ar_shares = array([2.]), ar_value = array([783.5234375]), portf_value = 783.5234375
# 2023-03-16 portf_value = 783.5234375
# close_date_n pick's portf value = 883.4718322753906
# close_date_n SPY portf value =    783.5234375
# ====================

# %%
# # total target investment for each day's picks, if day's pick has 2 symbols, the function will try to invest $500 for each symbol
# portf_target = 1000  
# date_buy, shares_syms, value_portf, shares_SPY, value_SPY = \
#   calc_portf_value_date_buy(df_picks_mp.date, df_picks_mp.symbols, df_close, portf_target, n=1, verbose=verbose)

# %%
df_picks_mp['date_buy'] = date_buy
df_picks_mp['sh_portf_buy'] = shares_syms
df_picks_mp['$_portf_buy'] = value_portf
df_picks_mp['sh_SPY_buy'] = shares_SPY
df_picks_mp['$_SPY_buy'] = value_SPY
# df_picks_mp.tail()
# df_picks_mp.head()
df_picks_mp
# Out:
#            date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy
# 0    2023-12-15  [30, 60, 120]  sym_freq_8          ['SHV']        None         None          NaN       None         NaN
# 1    2023-12-13  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']  2023-12-14  [23.0, 4.0]   929.339985      [2.0]  944.020020
# 2    2023-12-12  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']  2023-12-13  [23.0, 4.0]   927.513988      [2.0]  941.000000
# 3    2023-12-11  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']  2023-12-12  [23.0, 4.0]   928.964710      [2.0]  928.200012
# 4    2023-12-08  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']  2023-12-11  [22.0, 4.0]   921.405289      [2.0]  923.979980
# ..          ...            ...         ...              ...         ...          ...          ...        ...         ...
# 285  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-21   [8.0, 4.0]   883.741425      [2.0]  792.073425
# 286  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-20   [8.0, 4.0]   884.319916      [2.0]  781.807922
# 287  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']  2023-03-20       [11.0]   987.678345      [2.0]  781.807922
# 288  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-17   [8.0, 4.0]   883.701660      [2.0]  774.361938
# 289  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-16   [8.0, 4.0]   883.471832      [2.0]  783.523438
#
# [290 rows x 9 columns]

# %%
date_exec, shares_syms, value_portf, shares_SPY, value_SPY  = \
  calc_portf_value_date_n(df_picks_mp.date, df_picks_mp.symbols, df_close, df_picks_mp.sh_portf_buy, df_picks_mp.sh_SPY_buy, n=4, verbose=verbose)
# Out:
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# No data for close_date_n None, pick's portf value = None
# ====================
#
# date = '2023-12-15', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.30999947, 109.87000275]), ar_shares = array([23.,  4.]), ar_value = array([490.12998772, 439.48001099]), portf_value = 929.6099987030029
# 2023-12-15 portf_value = 929.6099987030029
# date = '2023-12-15', l_syms = ['SPY'], ar_price = array([469.32998657]), ar_shares = array([2.]), ar_value = array([938.65997314]), portf_value = 938.6599731445312
# 2023-12-15 portf_value = 938.6599731445312
# next_date_n pick's portf value = 929.6099987030029
# next_date_n SPY portf value =    938.6599731445312
# ====================
#
# date = '2023-12-14', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.29999924, 109.86000061]), ar_shares = array([22.,  4.]), ar_value = array([468.59998322, 439.44000244]), portf_value = 908.0399856567383
# 2023-12-14 portf_value = 908.0399856567383
# date = '2023-12-14', l_syms = ['SPY'], ar_price = array([472.01000977]), ar_shares = array([2.]), ar_value = array([944.02001953]), portf_value = 944.02001953125
# 2023-12-14 portf_value = 944.02001953125
# next_date_n pick's portf value = 908.0399856567383
# next_date_n SPY portf value =    944.02001953125
# ====================
#
# date = '2023-12-13', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.22999954, 109.80599976]), ar_shares = array([23.,  4.]), ar_value = array([488.28998947, 439.22399902]), portf_value = 927.513988494873
# 2023-12-13 portf_value = 927.513988494873
# date = '2023-12-13', l_syms = ['SPY'], ar_price = array([470.5]), ar_shares = array([2.]), ar_value = array([941.]), portf_value = 941.0
# 2023-12-13 portf_value = 941.0
# next_date_n pick's portf value = 927.513988494873
# next_date_n SPY portf value =    941.0
# ====================
#
# date = '2023-12-12', l_syms = ['GPS', 'SHV'], ar_price = array([ 21.29999924, 109.76618195]), ar_shares = array([23.,  4.]), ar_value = array([489.89998245, 439.06472778]), portf_value = 928.9647102355957
# 2023-12-12 portf_value = 928.9647102355957
# date = '2023-12-12', l_syms = ['SPY'], ar_price = array([464.1000061]), ar_shares = array([2.]), ar_value = array([928.20001221]), portf_value = 928.2000122070312
# 2023-12-12 portf_value = 928.2000122070312
# next_date_n pick's portf value = 928.9647102355957
# next_date_n SPY portf value =    928.2000122070312
# ====================
#
# date = '2023-12-11', l_syms = ['GPS'], ar_price = array([21.93000031]), ar_shares = array([47.]), ar_value = array([1030.71001434]), portf_value = 1030.7100143432617
# 2023-12-11 portf_value = 1030.7100143432617
# date = '2023-12-11', l_syms = ['SPY'], ar_price = array([461.98999023]), ar_shares = array([2.]), ar_value = array([923.97998047]), portf_value = 923.97998046875
# 2023-12-11 portf_value = 923.97998046875
# next_date_n pick's portf value = 1030.7100143432617
# next_date_n SPY portf value =    923.97998046875
# ====================
#
# date = '2023-12-11', l_syms = ['LRN', 'SHV'], ar_price = array([ 60.86000061, 109.7363205 ]), ar_shares = array([8., 4.]), ar_value = array([486.88000488, 438.94528198]), portf_value = 925.8252868652344
# 2023-12-11 portf_value = 925.8252868652344
# date = '2023-12-11', l_syms = ['SPY'], ar_price = array([461.98999023]), ar_shares = array([2.]), ar_value = array([923.97998047]), portf_value = 923.97998046875
# 2023-12-11 portf_value = 923.97998046875
# next_date_n pick's portf value = 925.8252868652344
# next_date_n SPY portf value =    923.97998046875
# ====================
#
# date = '2023-12-11', l_syms = ['GPS'], ar_price = array([21.93000031]), ar_shares = array([47.]), ar_value = array([1030.71001434]), portf_value = 1030.7100143432617
# 2023-12-11 portf_value = 1030.7100143432617
# date = '2023-12-11', l_syms = ['SPY'], ar_price = array([461.98999023]), ar_shares = array([2.]), ar_value = array([923.97998047]), portf_value = 923.97998046875
# 2023-12-11 portf_value = 923.97998046875
# next_date_n pick's portf value = 1030.7100143432617
# next_date_n SPY portf value =    923.97998046875
# ====================
#
# date = '2023-12-08', l_syms = ['GPS'], ar_price = array([21.68000031]), ar_shares = array([48.]), ar_value = array([1040.64001465]), portf_value = 1040.6400146484375
# 2023-12-08 portf_value = 1040.6400146484375
# date = '2023-12-08', l_syms = ['SPY'], ar_price = array([460.20001221]), ar_shares = array([2.]), ar_value = array([920.40002441]), portf_value = 920.4000244140625
# 2023-12-08 portf_value = 920.4000244140625
# next_date_n pick's portf value = 1040.6400146484375
# next_date_n SPY portf value =    920.4000244140625
# ====================
#
# date = '2023-12-08', l_syms = ['SHV'], ar_price = array([109.7363205]), ar_shares = array([9.]), ar_value = array([987.62688446]), portf_value = 987.6268844604492
# 2023-12-08 portf_value = 987.6268844604492
# date = '2023-12-08', l_syms = ['SPY'], ar_price = array([460.20001221]), ar_shares = array([2.]), ar_value = array([920.40002441]), portf_value = 920.4000244140625
# 2023-12-08 portf_value = 920.4000244140625
# next_date_n pick's portf value = 987.6268844604492
# next_date_n SPY portf value =    920.4000244140625
# ====================
#
# date = '2023-12-08', l_syms = ['GPS'], ar_price = array([21.68000031]), ar_shares = array([48.]), ar_value = array([1040.64001465]), portf_value = 1040.6400146484375
# 2023-12-08 portf_value = 1040.6400146484375
# date = '2023-12-08', l_syms = ['SPY'], ar_price = array([460.20001221]), ar_shares = array([2.]), ar_value = array([920.40002441]), portf_value = 920.4000244140625
# 2023-12-08 portf_value = 920.4000244140625
# next_date_n pick's portf value = 1040.6400146484375
# next_date_n SPY portf value =    920.4000244140625
# ====================
#
# date = '2023-12-07', l_syms = ['GPS'], ar_price = array([21.37000084]), ar_shares = array([47.]), ar_value = array([1004.39003944]), portf_value = 1004.3900394439697
# 2023-12-07 portf_value = 1004.3900394439697
# date = '2023-12-07', l_syms = ['SPY'], ar_price = array([458.23001099]), ar_shares = array([2.]), ar_value = array([916.46002197]), portf_value = 916.4600219726562
# 2023-12-07 portf_value = 916.4600219726562
# next_date_n pick's portf value = 1004.3900394439697
# next_date_n SPY portf value =    916.4600219726562
# ====================
#
# date = '2023-12-07', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.65999985, 109.7363205 ]), ar_shares = array([8., 4.]), ar_value = array([477.27999878, 438.94528198]), portf_value = 916.2252807617188
# 2023-12-07 portf_value = 916.2252807617188
# date = '2023-12-07', l_syms = ['SPY'], ar_price = array([458.23001099]), ar_shares = array([2.]), ar_value = array([916.46002197]), portf_value = 916.4600219726562
# 2023-12-07 portf_value = 916.4600219726562
# next_date_n pick's portf value = 916.2252807617188
# next_date_n SPY portf value =    916.4600219726562
# ====================
#
# date = '2023-12-07', l_syms = ['GPS'], ar_price = array([21.37000084]), ar_shares = array([47.]), ar_value = array([1004.39003944]), portf_value = 1004.3900394439697
# 2023-12-07 portf_value = 1004.3900394439697
# date = '2023-12-07', l_syms = ['SPY'], ar_price = array([458.23001099]), ar_shares = array([2.]), ar_value = array([916.46002197]), portf_value = 916.4600219726562
# 2023-12-07 portf_value = 916.4600219726562
# next_date_n pick's portf value = 1004.3900394439697
# next_date_n SPY portf value =    916.4600219726562
# ====================
#
# date = '2023-12-06', l_syms = ['GPS', 'SHV'], ar_price = array([ 20.94000053, 109.68655396]), ar_shares = array([23.,  4.]), ar_value = array([481.62001228, 438.74621582]), portf_value = 920.3662281036377
# 2023-12-06 portf_value = 920.3662281036377
# date = '2023-12-06', l_syms = ['SPY'], ar_price = array([454.76000977]), ar_shares = array([2.]), ar_value = array([909.52001953]), portf_value = 909.52001953125
# 2023-12-06 portf_value = 909.52001953125
# next_date_n pick's portf value = 920.3662281036377
# next_date_n SPY portf value =    909.52001953125
# ====================
#
# date = '2023-12-05', l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = array([ 59.63000107,  20.78000069, 109.66664124]), ar_shares = array([ 5., 16.,  3.]), ar_value = array([298.15000534, 332.48001099, 328.99992371]), portf_value = 959.629940032959
# 2023-12-05 portf_value = 959.629940032959
# date = '2023-12-05', l_syms = ['SPY'], ar_price = array([456.6000061]), ar_shares = array([2.]), ar_value = array([913.20001221]), portf_value = 913.2000122070312
# 2023-12-05 portf_value = 913.2000122070312
# next_date_n pick's portf value = 959.629940032959
# next_date_n SPY portf value =    913.2000122070312
# ====================
#
# date = '2023-12-04', l_syms = ['SHV'], ar_price = array([109.64673615]), ar_shares = array([9.]), ar_value = array([986.82062531]), portf_value = 986.8206253051758
# 2023-12-04 portf_value = 986.8206253051758
# date = '2023-12-04', l_syms = ['SPY'], ar_price = array([456.69000244]), ar_shares = array([2.]), ar_value = array([913.38000488]), portf_value = 913.3800048828125
# 2023-12-04 portf_value = 913.3800048828125
# next_date_n pick's portf value = 986.8206253051758
# next_date_n SPY portf value =    913.3800048828125
# ====================
#
# date = '2023-12-04', l_syms = ['FTSM', 'GPS'], ar_price = array([59.61000061, 20.84000015]), ar_shares = array([ 8., 24.]), ar_value = array([476.88000488, 500.16000366]), portf_value = 977.0400085449219
# 2023-12-04 portf_value = 977.0400085449219
# date = '2023-12-04', l_syms = ['SPY'], ar_price = array([456.69000244]), ar_shares = array([2.]), ar_value = array([913.38000488]), portf_value = 913.3800048828125
# 2023-12-04 portf_value = 913.3800048828125
# next_date_n pick's portf value = 977.0400085449219
# next_date_n SPY portf value =    913.3800048828125
# ====================
#
# date = '2023-12-01', l_syms = ['FTSM', 'GPS', 'SHV'], ar_price = array([ 59.59999847,  21.02000046, 109.63677979]), ar_shares = array([ 5., 17.,  3.]), ar_value = array([297.99999237, 357.34000778, 328.91033936]), portf_value = 984.2503395080566
# 2023-12-01 portf_value = 984.2503395080566
# date = '2023-12-01', l_syms = ['SPY'], ar_price = array([459.1000061]), ar_shares = array([2.]), ar_value = array([918.20001221]), portf_value = 918.2000122070312
# 2023-12-01 portf_value = 918.2000122070312
# next_date_n pick's portf value = 984.2503395080566
# next_date_n SPY portf value =    918.2000122070312
# ====================
#
# date = '2023-11-30', l_syms = ['GPS', 'SHV'], ar_price = array([ 20.06999969, 109.60192871]), ar_shares = array([25.,  4.]), ar_value = array([501.74999237, 438.40771484]), portf_value = 940.1577072143555
# 2023-11-30 portf_value = 940.1577072143555
# date = '2023-11-30', l_syms = ['SPY'], ar_price = array([456.3999939]), ar_shares = array([2.]), ar_value = array([912.79998779]), portf_value = 912.7999877929688
# 2023-11-30 portf_value = 912.7999877929688
# next_date_n pick's portf value = 940.1577072143555
# next_date_n SPY portf value =    912.7999877929688
# ====================
#
# date = '2023-11-29', l_syms = ['GPS', 'SHV'], ar_price = array([ 20.15999985, 109.56229401]), ar_shares = array([26.,  4.]), ar_value = array([524.15999603, 438.24917603]), portf_value = 962.4091720581055
# 2023-11-29 portf_value = 962.4091720581055
# date = '2023-11-29', l_syms = ['SPY'], ar_price = array([454.60998535]), ar_shares = array([2.]), ar_value = array([909.2199707]), portf_value = 909.219970703125
# 2023-11-29 portf_value = 909.219970703125
# next_date_n pick's portf value = 962.4091720581055
# next_date_n SPY portf value =    909.219970703125
# ====================
#
# date = '2023-11-28', l_syms = ['SHV'], ar_price = array([109.54247284]), ar_shares = array([9.]), ar_value = array([985.88225555]), portf_value = 985.8822555541992
# 2023-11-28 portf_value = 985.8822555541992
# date = '2023-11-28', l_syms = ['SPY'], ar_price = array([454.92999268]), ar_shares = array([2.]), ar_value = array([909.85998535]), portf_value = 909.8599853515625
# 2023-11-28 portf_value = 909.8599853515625
# next_date_n pick's portf value = 985.8822555541992
# next_date_n SPY portf value =    909.8599853515625
# ====================
#
# date = '2023-11-28', l_syms = ['FTSM', 'GPS'], ar_price = array([59.52703857, 19.54999924]), ar_shares = array([ 8., 26.]), ar_value = array([476.21630859, 508.29998016]), portf_value = 984.5162887573242
# 2023-11-28 portf_value = 984.5162887573242
# date = '2023-11-28', l_syms = ['SPY'], ar_price = array([454.92999268]), ar_shares = array([2.]), ar_value = array([909.85998535]), portf_value = 909.8599853515625
# 2023-11-28 portf_value = 909.8599853515625
# next_date_n pick's portf value = 984.5162887573242
# next_date_n SPY portf value =    909.8599853515625
# ====================
#
# date = '2023-11-27', l_syms = ['SHV'], ar_price = array([109.51274109]), ar_shares = array([9.]), ar_value = array([985.6146698]), portf_value = 985.6146697998047
# 2023-11-27 portf_value = 985.6146697998047
# date = '2023-11-27', l_syms = ['SPY'], ar_price = array([454.48001099]), ar_shares = array([2.]), ar_value = array([908.96002197]), portf_value = 908.9600219726562
# 2023-11-27 portf_value = 908.9600219726562
# next_date_n pick's portf value = 985.6146697998047
# next_date_n SPY portf value =    908.9600219726562
# ====================
#
# date = '2023-11-27', l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = array([59.47724533, 19.44000053, 46.45999908]), ar_shares = array([ 5., 17.,  7.]), ar_value = array([297.38622665, 330.48000908, 325.21999359]), portf_value = 953.0862293243408
# 2023-11-27 portf_value = 953.0862293243408
# date = '2023-11-27', l_syms = ['SPY'], ar_price = array([454.48001099]), ar_shares = array([2.]), ar_value = array([908.96002197]), portf_value = 908.9600219726562
# 2023-11-27 portf_value = 908.9600219726562
# next_date_n pick's portf value = 953.0862293243408
# next_date_n SPY portf value =    908.9600219726562
# ====================
#
# date = '2023-11-24', l_syms = ['SHV'], ar_price = array([109.49291992]), ar_shares = array([9.]), ar_value = array([985.4362793]), portf_value = 985.436279296875
# 2023-11-24 portf_value = 985.436279296875
# date = '2023-11-24', l_syms = ['SPY'], ar_price = array([455.29998779]), ar_shares = array([2.]), ar_value = array([910.59997559]), portf_value = 910.5999755859375
# 2023-11-24 portf_value = 910.5999755859375
# next_date_n pick's portf value = 985.436279296875
# next_date_n SPY portf value =    910.5999755859375
# ====================
#
# date = '2023-11-24', l_syms = ['FTSM', 'GPS', 'NRG'], ar_price = array([59.45732498, 18.86000061, 45.88999939]), ar_shares = array([ 5., 18.,  7.]), ar_value = array([297.28662491, 339.48001099, 321.22999573]), portf_value = 957.9966316223145
# 2023-11-24 portf_value = 957.9966316223145
# date = '2023-11-24', l_syms = ['SPY'], ar_price = array([455.29998779]), ar_shares = array([2.]), ar_value = array([910.59997559]), portf_value = 910.5999755859375
# 2023-11-24 portf_value = 910.5999755859375
# next_date_n pick's portf value = 957.9966316223145
# next_date_n SPY portf value =    910.5999755859375
# ====================
#
# date = '2023-11-22', l_syms = ['SHV'], ar_price = array([109.48300934]), ar_shares = array([9.]), ar_value = array([985.34708405]), portf_value = 985.3470840454102
# 2023-11-22 portf_value = 985.3470840454102
# date = '2023-11-22', l_syms = ['SPY'], ar_price = array([455.01998901]), ar_shares = array([2.]), ar_value = array([910.03997803]), portf_value = 910.0399780273438
# 2023-11-22 portf_value = 910.0399780273438
# next_date_n pick's portf value = 985.3470840454102
# next_date_n SPY portf value =    910.0399780273438
# ====================
#
# date = '2023-11-22', l_syms = ['FTSM', 'NRG'], ar_price = array([59.44736481, 45.83000183]), ar_shares = array([ 8., 10.]), ar_value = array([475.57891846, 458.30001831]), portf_value = 933.8789367675781
# 2023-11-22 portf_value = 933.8789367675781
# date = '2023-11-22', l_syms = ['SPY'], ar_price = array([455.01998901]), ar_shares = array([2.]), ar_value = array([910.03997803]), portf_value = 910.0399780273438
# 2023-11-22 portf_value = 910.0399780273438
# next_date_n pick's portf value = 933.8789367675781
# next_date_n SPY portf value =    910.0399780273438
# ====================
#
# date = '2023-11-21', l_syms = ['SHV'], ar_price = array([109.443367]), ar_shares = array([9.]), ar_value = array([984.99030304]), portf_value = 984.9903030395508
# 2023-11-21 portf_value = 984.9903030395508
# date = '2023-11-21', l_syms = ['SPY'], ar_price = array([453.26998901]), ar_shares = array([2.]), ar_value = array([906.53997803]), portf_value = 906.5399780273438
# 2023-11-21 portf_value = 906.5399780273438
# next_date_n pick's portf value = 984.9903030395508
# next_date_n SPY portf value =    906.5399780273438
# ====================
#
# date = '2023-11-21', l_syms = ['FTSM', 'NRG'], ar_price = array([59.4174881 , 45.20000076]), ar_shares = array([ 8., 10.]), ar_value = array([475.33990479, 452.00000763]), portf_value = 927.3399124145508
# 2023-11-21 portf_value = 927.3399124145508
# date = '2023-11-21', l_syms = ['SPY'], ar_price = array([453.26998901]), ar_shares = array([2.]), ar_value = array([906.53997803]), portf_value = 906.5399780273438
# 2023-11-21 portf_value = 906.5399780273438
# next_date_n pick's portf value = 927.3399124145508
# next_date_n SPY portf value =    906.5399780273438
# ====================
#
# date = '2023-11-20', l_syms = ['SHV'], ar_price = array([109.40372467]), ar_shares = array([9.]), ar_value = array([984.63352203]), portf_value = 984.6335220336914
# 2023-11-20 portf_value = 984.6335220336914
# date = '2023-11-20', l_syms = ['SPY'], ar_price = array([454.26000977]), ar_shares = array([2.]), ar_value = array([908.52001953]), portf_value = 908.52001953125
# 2023-11-20 portf_value = 908.52001953125
# next_date_n pick's portf value = 984.6335220336914
# next_date_n SPY portf value =    908.52001953125
# ====================
#
# date = '2023-11-20', l_syms = ['FTSM', 'NRG'], ar_price = array([59.40752792, 47.29000092]), ar_shares = array([ 8., 10.]), ar_value = array([475.26022339, 472.90000916]), portf_value = 948.1602325439453
# 2023-11-20 portf_value = 948.1602325439453
# date = '2023-11-20', l_syms = ['SPY'], ar_price = array([454.26000977]), ar_shares = array([2.]), ar_value = array([908.52001953]), portf_value = 908.52001953125
# 2023-11-20 portf_value = 908.52001953125
# next_date_n pick's portf value = 948.1602325439453
# next_date_n SPY portf value =    908.52001953125
# ====================
#
# date = '2023-11-17', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.38761139, 109.39380646]), ar_shares = array([8., 4.]), ar_value = array([475.10089111, 437.57522583]), portf_value = 912.6761169433594
# 2023-11-17 portf_value = 912.6761169433594
# date = '2023-11-17', l_syms = ['SPY'], ar_price = array([450.79000854]), ar_shares = array([2.]), ar_value = array([901.58001709]), portf_value = 901.5800170898438
# 2023-11-17 portf_value = 901.5800170898438
# next_date_n pick's portf value = 912.6761169433594
# next_date_n SPY portf value =    901.5800170898438
# ====================
#
# date = '2023-11-17', l_syms = ['CBOE'], ar_price = array([176.66000366]), ar_shares = array([5.]), ar_value = array([883.30001831]), portf_value = 883.3000183105469
# 2023-11-17 portf_value = 883.3000183105469
# date = '2023-11-17', l_syms = ['SPY'], ar_price = array([450.79000854]), ar_shares = array([2.]), ar_value = array([901.58001709]), portf_value = 901.5800170898438
# 2023-11-17 portf_value = 901.5800170898438
# next_date_n pick's portf value = 883.3000183105469
# next_date_n SPY portf value =    901.5800170898438
# ====================
#
# date = '2023-11-16', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.3776474, 109.3839035]), ar_shares = array([8., 4.]), ar_value = array([475.0211792 , 437.53561401]), portf_value = 912.5567932128906
# 2023-11-16 portf_value = 912.5567932128906
# date = '2023-11-16', l_syms = ['SPY'], ar_price = array([450.23001099]), ar_shares = array([2.]), ar_value = array([900.46002197]), portf_value = 900.4600219726562
# 2023-11-16 portf_value = 900.4600219726562
# next_date_n pick's portf value = 912.5567932128906
# next_date_n SPY portf value =    900.4600219726562
# ====================
#
# date = '2023-11-16', l_syms = ['CBOE'], ar_price = array([177.78999329]), ar_shares = array([5.]), ar_value = array([888.94996643]), portf_value = 888.9499664306641
# 2023-11-16 portf_value = 888.9499664306641
# date = '2023-11-16', l_syms = ['SPY'], ar_price = array([450.23001099]), ar_shares = array([2.]), ar_value = array([900.46002197]), portf_value = 900.4600219726562
# 2023-11-16 portf_value = 900.4600219726562
# next_date_n pick's portf value = 888.9499664306641
# next_date_n SPY portf value =    900.4600219726562
# ====================
#
# date = '2023-11-15', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.35773087, 109.32443237]), ar_shares = array([8., 4.]), ar_value = array([474.86184692, 437.29772949]), portf_value = 912.1595764160156
# 2023-11-15 portf_value = 912.1595764160156
# date = '2023-11-15', l_syms = ['SPY'], ar_price = array([449.67999268]), ar_shares = array([2.]), ar_value = array([899.35998535]), portf_value = 899.3599853515625
# 2023-11-15 portf_value = 899.3599853515625
# next_date_n pick's portf value = 912.1595764160156
# next_date_n SPY portf value =    899.3599853515625
# ====================
#
# date = '2023-11-15', l_syms = ['CBOE'], ar_price = array([176.97999573]), ar_shares = array([5.]), ar_value = array([884.89997864]), portf_value = 884.8999786376953
# 2023-11-15 portf_value = 884.8999786376953
# date = '2023-11-15', l_syms = ['SPY'], ar_price = array([449.67999268]), ar_shares = array([2.]), ar_value = array([899.35998535]), portf_value = 899.3599853515625
# 2023-11-15 portf_value = 899.3599853515625
# next_date_n pick's portf value = 884.8999786376953
# next_date_n SPY portf value =    899.3599853515625
# ====================
#
# date = '2023-11-14', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.36769104, 109.31452942]), ar_shares = array([8., 4.]), ar_value = array([474.94152832, 437.25811768]), portf_value = 912.1996459960938
# 2023-11-14 portf_value = 912.1996459960938
# date = '2023-11-14', l_syms = ['SPY'], ar_price = array([448.73001099]), ar_shares = array([2.]), ar_value = array([897.46002197]), portf_value = 897.4600219726562
# 2023-11-14 portf_value = 897.4600219726562
# next_date_n pick's portf value = 912.1996459960938
# next_date_n SPY portf value =    897.4600219726562
# ====================
#
# date = '2023-11-14', l_syms = ['NRG'], ar_price = array([47.31999969]), ar_shares = array([22.]), ar_value = array([1041.03999329]), portf_value = 1041.0399932861328
# 2023-11-14 portf_value = 1041.0399932861328
# date = '2023-11-14', l_syms = ['SPY'], ar_price = array([448.73001099]), ar_shares = array([2.]), ar_value = array([897.46002197]), portf_value = 897.4600219726562
# 2023-11-14 portf_value = 897.4600219726562
# next_date_n pick's portf value = 1041.0399932861328
# next_date_n SPY portf value =    897.4600219726562
# ====================
#
# date = '2023-11-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.31789398, 109.27488708]), ar_shares = array([8., 4.]), ar_value = array([474.54315186, 437.09954834]), portf_value = 911.6427001953125
# 2023-11-13 portf_value = 911.6427001953125
# date = '2023-11-13', l_syms = ['SPY'], ar_price = array([440.19000244]), ar_shares = array([2.]), ar_value = array([880.38000488]), portf_value = 880.3800048828125
# 2023-11-13 portf_value = 880.3800048828125
# next_date_n pick's portf value = 911.6427001953125
# next_date_n SPY portf value =    880.3800048828125
# ====================
#
# date = '2023-11-13', l_syms = ['NRG'], ar_price = array([46.09000015]), ar_shares = array([21.]), ar_value = array([967.8900032]), portf_value = 967.8900032043457
# 2023-11-13 portf_value = 967.8900032043457
# date = '2023-11-13', l_syms = ['SPY'], ar_price = array([440.19000244]), ar_shares = array([2.]), ar_value = array([880.38000488]), portf_value = 880.3800048828125
# 2023-11-13 portf_value = 880.3800048828125
# next_date_n pick's portf value = 967.8900032043457
# next_date_n SPY portf value =    880.3800048828125
# ====================
#
# date = '2023-11-10', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.29797745, 109.2649765 ]), ar_shares = array([8., 4.]), ar_value = array([474.38381958, 437.05990601]), portf_value = 911.4437255859375
# 2023-11-10 portf_value = 911.4437255859375
# date = '2023-11-10', l_syms = ['SPY'], ar_price = array([440.60998535]), ar_shares = array([2.]), ar_value = array([881.2199707]), portf_value = 881.219970703125
# 2023-11-10 portf_value = 881.219970703125
# next_date_n pick's portf value = 911.4437255859375
# next_date_n SPY portf value =    881.219970703125
# ====================
#
# date = '2023-11-10', l_syms = ['NRG'], ar_price = array([45.54999924]), ar_shares = array([22.]), ar_value = array([1002.09998322]), portf_value = 1002.099983215332
# 2023-11-10 portf_value = 1002.099983215332
# date = '2023-11-10', l_syms = ['SPY'], ar_price = array([440.60998535]), ar_shares = array([2.]), ar_value = array([881.2199707]), portf_value = 881.219970703125
# 2023-11-10 portf_value = 881.219970703125
# next_date_n pick's portf value = 1002.099983215332
# next_date_n SPY portf value =    881.219970703125
# ====================
#
# date = '2023-11-09', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.29299545, 109.23524475]), ar_shares = array([8., 4.]), ar_value = array([474.34396362, 436.940979  ]), portf_value = 911.2849426269531
# 2023-11-09 portf_value = 911.2849426269531
# date = '2023-11-09', l_syms = ['SPY'], ar_price = array([433.83999634]), ar_shares = array([2.]), ar_value = array([867.67999268]), portf_value = 867.6799926757812
# 2023-11-09 portf_value = 867.6799926757812
# next_date_n pick's portf value = 911.2849426269531
# next_date_n SPY portf value =    867.6799926757812
# ====================
#
# date = '2023-11-09', l_syms = ['ANF'], ar_price = array([66.75]), ar_shares = array([15.]), ar_value = array([1001.25]), portf_value = 1001.25
# 2023-11-09 portf_value = 1001.25
# date = '2023-11-09', l_syms = ['SPY'], ar_price = array([433.83999634]), ar_shares = array([2.]), ar_value = array([867.67999268]), portf_value = 867.6799926757812
# 2023-11-09 portf_value = 867.6799926757812
# next_date_n pick's portf value = 1001.25
# next_date_n SPY portf value =    867.6799926757812
# ====================
#
# date = '2023-11-08', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2780571 , 109.19560242]), ar_shares = array([8., 4.]), ar_value = array([474.22445679, 436.78240967]), portf_value = 911.0068664550781
# 2023-11-08 portf_value = 911.0068664550781
# date = '2023-11-08', l_syms = ['SPY'], ar_price = array([437.25]), ar_shares = array([2.]), ar_value = array([874.5]), portf_value = 874.5
# 2023-11-08 portf_value = 874.5
# next_date_n pick's portf value = 911.0068664550781
# next_date_n SPY portf value =    874.5
# ====================
#
# date = '2023-11-08', l_syms = ['ANF'], ar_price = array([67.91999817]), ar_shares = array([15.]), ar_value = array([1018.79997253]), portf_value = 1018.7999725341797
# 2023-11-08 portf_value = 1018.7999725341797
# date = '2023-11-08', l_syms = ['SPY'], ar_price = array([437.25]), ar_shares = array([2.]), ar_value = array([874.5]), portf_value = 874.5
# 2023-11-08 portf_value = 874.5
# next_date_n pick's portf value = 1018.7999725341797
# next_date_n SPY portf value =    874.5
# ====================
#
# date = '2023-11-07', l_syms = ['FTSM'], ar_price = array([59.28801346]), ar_shares = array([16.]), ar_value = array([948.60821533]), portf_value = 948.6082153320312
# 2023-11-07 portf_value = 948.6082153320312
# date = '2023-11-07', l_syms = ['SPY'], ar_price = array([436.92999268]), ar_shares = array([2.]), ar_value = array([873.85998535]), portf_value = 873.8599853515625
# 2023-11-07 portf_value = 873.8599853515625
# next_date_n pick's portf value = 948.6082153320312
# next_date_n SPY portf value =    873.8599853515625
# ====================
#
# date = '2023-11-07', l_syms = ['ANF'], ar_price = array([67.80999756]), ar_shares = array([15.]), ar_value = array([1017.14996338]), portf_value = 1017.1499633789062
# 2023-11-07 portf_value = 1017.1499633789062
# date = '2023-11-07', l_syms = ['SPY'], ar_price = array([436.92999268]), ar_shares = array([2.]), ar_value = array([873.85998535]), portf_value = 873.8599853515625
# 2023-11-07 portf_value = 873.8599853515625
# next_date_n pick's portf value = 1017.1499633789062
# next_date_n SPY portf value =    873.8599853515625
# ====================
#
# date = '2023-11-06', l_syms = ['SHV'], ar_price = array([109.15596008]), ar_shares = array([9.]), ar_value = array([982.40364075]), portf_value = 982.4036407470703
# 2023-11-06 portf_value = 982.4036407470703
# date = '2023-11-06', l_syms = ['SPY'], ar_price = array([435.69000244]), ar_shares = array([2.]), ar_value = array([871.38000488]), portf_value = 871.3800048828125
# 2023-11-06 portf_value = 871.3800048828125
# next_date_n pick's portf value = 982.4036407470703
# next_date_n SPY portf value =    871.3800048828125
# ====================
#
# date = '2023-11-06', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2780571 , 109.15596008]), ar_shares = array([8., 4.]), ar_value = array([474.22445679, 436.62384033]), portf_value = 910.8482971191406
# 2023-11-06 portf_value = 910.8482971191406
# date = '2023-11-06', l_syms = ['SPY'], ar_price = array([435.69000244]), ar_shares = array([2.]), ar_value = array([871.38000488]), portf_value = 871.3800048828125
# 2023-11-06 portf_value = 871.3800048828125
# next_date_n pick's portf value = 910.8482971191406
# next_date_n SPY portf value =    871.3800048828125
# ====================
#
# date = '2023-11-06', l_syms = ['ANF', 'SPLK'], ar_price = array([ 66.26999664, 146.61999512]), ar_shares = array([8., 3.]), ar_value = array([530.15997314, 439.85998535]), portf_value = 970.0199584960938
# 2023-11-06 portf_value = 970.0199584960938
# date = '2023-11-06', l_syms = ['SPY'], ar_price = array([435.69000244]), ar_shares = array([2.]), ar_value = array([871.38000488]), portf_value = 871.3800048828125
# 2023-11-06 portf_value = 871.3800048828125
# next_date_n pick's portf value = 970.0199584960938
# next_date_n SPY portf value =    871.3800048828125
# ====================
#
# date = '2023-11-06', l_syms = ['SHV'], ar_price = array([109.15596008]), ar_shares = array([9.]), ar_value = array([982.40364075]), portf_value = 982.4036407470703
# 2023-11-06 portf_value = 982.4036407470703
# date = '2023-11-06', l_syms = ['SPY'], ar_price = array([435.69000244]), ar_shares = array([2.]), ar_value = array([871.38000488]), portf_value = 871.3800048828125
# 2023-11-06 portf_value = 871.3800048828125
# next_date_n pick's portf value = 982.4036407470703
# next_date_n SPY portf value =    871.3800048828125
# ====================
#
# date = '2023-11-03', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2730751 , 109.16587067]), ar_shares = array([8., 4.]), ar_value = array([474.18460083, 436.66348267]), portf_value = 910.8480834960938
# 2023-11-03 portf_value = 910.8480834960938
# date = '2023-11-03', l_syms = ['SPY'], ar_price = array([434.69000244]), ar_shares = array([2.]), ar_value = array([869.38000488]), portf_value = 869.3800048828125
# 2023-11-03 portf_value = 869.3800048828125
# next_date_n pick's portf value = 910.8480834960938
# next_date_n SPY portf value =    869.3800048828125
# ====================
#
# date = '2023-11-03', l_syms = ['SPLK'], ar_price = array([146.47999573]), ar_shares = array([6.]), ar_value = array([878.87997437]), portf_value = 878.8799743652344
# 2023-11-03 portf_value = 878.8799743652344
# date = '2023-11-03', l_syms = ['SPY'], ar_price = array([434.69000244]), ar_shares = array([2.]), ar_value = array([869.38000488]), portf_value = 869.3800048828125
# 2023-11-03 portf_value = 869.3800048828125
# next_date_n pick's portf value = 878.8799743652344
# next_date_n SPY portf value =    869.3800048828125
# ====================
#
# date = '2023-11-03', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.2730751 , 109.16587067]), ar_shares = array([8., 4.]), ar_value = array([474.18460083, 436.66348267]), portf_value = 910.8480834960938
# 2023-11-03 portf_value = 910.8480834960938
# date = '2023-11-03', l_syms = ['SPY'], ar_price = array([434.69000244]), ar_shares = array([2.]), ar_value = array([869.38000488]), portf_value = 869.3800048828125
# 2023-11-03 portf_value = 869.3800048828125
# next_date_n pick's portf value = 910.8480834960938
# next_date_n SPY portf value =    869.3800048828125
# ====================
#
# date = '2023-11-02', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.25813675, 109.13613892]), ar_shares = array([8., 4.]), ar_value = array([474.06509399, 436.54455566]), portf_value = 910.6096496582031
# 2023-11-02 portf_value = 910.6096496582031
# date = '2023-11-02', l_syms = ['SPY'], ar_price = array([430.76000977]), ar_shares = array([2.]), ar_value = array([861.52001953]), portf_value = 861.52001953125
# 2023-11-02 portf_value = 861.52001953125
# next_date_n pick's portf value = 910.6096496582031
# next_date_n SPY portf value =    861.52001953125
# ====================
#
# date = '2023-11-02', l_syms = ['SPLK'], ar_price = array([146.78999329]), ar_shares = array([6.]), ar_value = array([880.73995972]), portf_value = 880.7399597167969
# 2023-11-02 portf_value = 880.7399597167969
# date = '2023-11-02', l_syms = ['SPY'], ar_price = array([430.76000977]), ar_shares = array([2.]), ar_value = array([861.52001953]), portf_value = 861.52001953125
# 2023-11-02 portf_value = 861.52001953125
# next_date_n pick's portf value = 880.7399597167969
# next_date_n SPY portf value =    861.52001953125
# ====================
#
# date = '2023-11-02', l_syms = ['SHV'], ar_price = array([109.13613892]), ar_shares = array([9.]), ar_value = array([982.22525024]), portf_value = 982.2252502441406
# 2023-11-02 portf_value = 982.2252502441406
# date = '2023-11-02', l_syms = ['SPY'], ar_price = array([430.76000977]), ar_shares = array([2.]), ar_value = array([861.52001953]), portf_value = 861.52001953125
# 2023-11-02 portf_value = 861.52001953125
# next_date_n pick's portf value = 982.2252502441406
# next_date_n SPY portf value =    861.52001953125
# ====================
#
# date = '2023-11-01', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.21829987, 109.086586  ]), ar_shares = array([8., 4.]), ar_value = array([473.74639893, 436.34634399]), portf_value = 910.0927429199219
# 2023-11-01 portf_value = 910.0927429199219
# date = '2023-11-01', l_syms = ['SPY'], ar_price = array([422.66000366]), ar_shares = array([2.]), ar_value = array([845.32000732]), portf_value = 845.3200073242188
# 2023-11-01 portf_value = 845.3200073242188
# next_date_n pick's portf value = 910.0927429199219
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date = '2023-11-01', l_syms = ['SPLK'], ar_price = array([146.88000488]), ar_shares = array([6.]), ar_value = array([881.2800293]), portf_value = 881.280029296875
# 2023-11-01 portf_value = 881.280029296875
# date = '2023-11-01', l_syms = ['SPY'], ar_price = array([422.66000366]), ar_shares = array([2.]), ar_value = array([845.32000732]), portf_value = 845.3200073242188
# 2023-11-01 portf_value = 845.3200073242188
# next_date_n pick's portf value = 881.280029296875
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date = '2023-10-31', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.18842316, 109.04891968]), ar_shares = array([8., 4.]), ar_value = array([473.50738525, 436.19567871]), portf_value = 909.7030639648438
# 2023-10-31 portf_value = 909.7030639648438
# date = '2023-10-31', l_syms = ['SPY'], ar_price = array([418.20001221]), ar_shares = array([2.]), ar_value = array([836.40002441]), portf_value = 836.4000244140625
# 2023-10-31 portf_value = 836.4000244140625
# next_date_n pick's portf value = 909.7030639648438
# next_date_n SPY portf value =    836.4000244140625
# ====================
#
# date = '2023-10-31', l_syms = ['ANF', 'SPLK'], ar_price = array([ 60.81999969, 147.16000366]), ar_shares = array([8., 3.]), ar_value = array([486.55999756, 441.48001099]), portf_value = 928.0400085449219
# 2023-10-31 portf_value = 928.0400085449219
# date = '2023-10-31', l_syms = ['SPY'], ar_price = array([418.20001221]), ar_shares = array([2.]), ar_value = array([836.40002441]), portf_value = 836.4000244140625
# 2023-10-31 portf_value = 836.4000244140625
# next_date_n pick's portf value = 928.0400085449219
# next_date_n SPY portf value =    836.4000244140625
# ====================
#
# date = '2023-10-30', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.19937897, 109.04891968]), ar_shares = array([8., 4.]), ar_value = array([473.59503174, 436.19567871]), portf_value = 909.7907104492188
# 2023-10-30 portf_value = 909.7907104492188
# date = '2023-10-30', l_syms = ['SPY'], ar_price = array([415.58999634]), ar_shares = array([2.]), ar_value = array([831.17999268]), portf_value = 831.1799926757812
# 2023-10-30 portf_value = 831.1799926757812
# next_date_n pick's portf value = 909.7907104492188
# next_date_n SPY portf value =    831.1799926757812
# ====================
#
# date = '2023-10-30', l_syms = ['ANF'], ar_price = array([59.61000061]), ar_shares = array([16.]), ar_value = array([953.76000977]), portf_value = 953.760009765625
# 2023-10-30 portf_value = 953.760009765625
# date = '2023-10-30', l_syms = ['SPY'], ar_price = array([415.58999634]), ar_shares = array([2.]), ar_value = array([831.17999268]), portf_value = 831.1799926757812
# 2023-10-30 portf_value = 831.1799926757812
# next_date_n pick's portf value = 953.760009765625
# next_date_n SPY portf value =    831.1799926757812
# ====================
#
# date = '2023-10-27', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.18449783, 109.03904724]), ar_shares = array([8., 4.]), ar_value = array([473.47598267, 436.15618896]), portf_value = 909.6321716308594
# 2023-10-27 portf_value = 909.6321716308594
# date = '2023-10-27', l_syms = ['SPY'], ar_price = array([410.67999268]), ar_shares = array([2.]), ar_value = array([821.35998535]), portf_value = 821.3599853515625
# 2023-10-27 portf_value = 821.3599853515625
# next_date_n pick's portf value = 909.6321716308594
# next_date_n SPY portf value =    821.3599853515625
# ====================
#
# date = '2023-10-27', l_syms = ['SPLK'], ar_price = array([147.13999939]), ar_shares = array([6.]), ar_value = array([882.83999634]), portf_value = 882.8399963378906
# 2023-10-27 portf_value = 882.8399963378906
# date = '2023-10-27', l_syms = ['SPY'], ar_price = array([410.67999268]), ar_shares = array([2.]), ar_value = array([821.35998535]), portf_value = 821.3599853515625
# 2023-10-27 portf_value = 821.3599853515625
# next_date_n pick's portf value = 882.8399963378906
# next_date_n SPY portf value =    821.3599853515625
# ====================
#
# date = '2023-10-26', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.17954254, 109.01931763]), ar_shares = array([8., 4.]), ar_value = array([473.43634033, 436.07727051]), portf_value = 909.5136108398438
# 2023-10-26 portf_value = 909.5136108398438
# date = '2023-10-26', l_syms = ['SPY'], ar_price = array([412.54998779]), ar_shares = array([2.]), ar_value = array([825.09997559]), portf_value = 825.0999755859375
# 2023-10-26 portf_value = 825.0999755859375
# next_date_n pick's portf value = 909.5136108398438
# next_date_n SPY portf value =    825.0999755859375
# ====================
#
# date = '2023-10-25', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.13490677, 108.95023346]), ar_shares = array([8., 4.]), ar_value = array([473.07925415, 435.80093384]), portf_value = 908.8801879882812
# 2023-10-25 portf_value = 908.8801879882812
# date = '2023-10-25', l_syms = ['SPY'], ar_price = array([417.54998779]), ar_shares = array([2.]), ar_value = array([835.09997559]), portf_value = 835.0999755859375
# 2023-10-25 portf_value = 835.0999755859375
# next_date_n pick's portf value = 908.8801879882812
# next_date_n SPY portf value =    835.0999755859375
# ====================
#
# date = '2023-10-25', l_syms = ['SHV'], ar_price = array([108.95023346]), ar_shares = array([9.]), ar_value = array([980.55210114]), portf_value = 980.5521011352539
# 2023-10-25 portf_value = 980.5521011352539
# date = '2023-10-25', l_syms = ['SPY'], ar_price = array([417.54998779]), ar_shares = array([2.]), ar_value = array([835.09997559]), portf_value = 835.0999755859375
# 2023-10-25 portf_value = 835.0999755859375
# next_date_n pick's portf value = 980.5521011352539
# next_date_n SPY portf value =    835.0999755859375
# ====================
#
# date = '2023-10-24', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.1448288 , 108.95023346]), ar_shares = array([8., 4.]), ar_value = array([473.15863037, 435.80093384]), portf_value = 908.9595642089844
# 2023-10-24 portf_value = 908.9595642089844
# date = '2023-10-24', l_syms = ['SPY'], ar_price = array([423.63000488]), ar_shares = array([2.]), ar_value = array([847.26000977]), portf_value = 847.260009765625
# 2023-10-24 portf_value = 847.260009765625
# next_date_n pick's portf value = 908.9595642089844
# next_date_n SPY portf value =    847.260009765625
# ====================
#
# date = '2023-10-23', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.1448288 , 108.94036865]), ar_shares = array([8., 4.]), ar_value = array([473.15863037, 435.76147461]), portf_value = 908.9201049804688
# 2023-10-23 portf_value = 908.9201049804688
# date = '2023-10-23', l_syms = ['SPY'], ar_price = array([420.45999146]), ar_shares = array([2.]), ar_value = array([840.91998291]), portf_value = 840.9199829101562
# 2023-10-23 portf_value = 840.9199829101562
# next_date_n pick's portf value = 908.9201049804688
# next_date_n SPY portf value =    840.9199829101562
# ====================
#
# date = '2023-10-20', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.11507034, 108.92063904]), ar_shares = array([8., 4.]), ar_value = array([472.92056274, 435.68255615]), portf_value = 908.6031188964844
# 2023-10-20 portf_value = 908.6031188964844
# date = '2023-10-20', l_syms = ['SPY'], ar_price = array([421.19000244]), ar_shares = array([2.]), ar_value = array([842.38000488]), portf_value = 842.3800048828125
# 2023-10-20 portf_value = 842.3800048828125
# next_date_n pick's portf value = 908.6031188964844
# next_date_n SPY portf value =    842.3800048828125
# ====================
#
# date = '2023-10-19', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.09523392, 108.89102936]), ar_shares = array([8., 4.]), ar_value = array([472.76187134, 435.56411743]), portf_value = 908.3259887695312
# 2023-10-19 portf_value = 908.3259887695312
# date = '2023-10-19', l_syms = ['SPY'], ar_price = array([426.42999268]), ar_shares = array([2.]), ar_value = array([852.85998535]), portf_value = 852.8599853515625
# 2023-10-19 portf_value = 852.8599853515625
# next_date_n pick's portf value = 908.3259887695312
# next_date_n SPY portf value =    852.8599853515625
# ====================
#
# date = '2023-10-19', l_syms = ['SHV'], ar_price = array([108.89102936]), ar_shares = array([9.]), ar_value = array([980.01926422]), portf_value = 980.0192642211914
# 2023-10-19 portf_value = 980.0192642211914
# date = '2023-10-19', l_syms = ['SPY'], ar_price = array([426.42999268]), ar_shares = array([2.]), ar_value = array([852.85998535]), portf_value = 852.8599853515625
# 2023-10-19 portf_value = 852.8599853515625
# next_date_n pick's portf value = 980.0192642211914
# next_date_n SPY portf value =    852.8599853515625
# ====================
#
# date = '2023-10-18', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.06547546, 108.84168243]), ar_shares = array([8., 4.]), ar_value = array([472.52380371, 435.36672974]), portf_value = 907.8905334472656
# 2023-10-18 portf_value = 907.8905334472656
# date = '2023-10-18', l_syms = ['SPY'], ar_price = array([430.20999146]), ar_shares = array([2.]), ar_value = array([860.41998291]), portf_value = 860.4199829101562
# 2023-10-18 portf_value = 860.4199829101562
# next_date_n pick's portf value = 907.8905334472656
# next_date_n SPY portf value =    860.4199829101562
# ====================
#
# date = '2023-10-17', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.07043839, 108.83181   ]), ar_shares = array([8., 4.]), ar_value = array([472.56350708, 435.32723999]), portf_value = 907.8907470703125
# 2023-10-17 portf_value = 907.8907470703125
# date = '2023-10-17', l_syms = ['SPY'], ar_price = array([436.01998901]), ar_shares = array([2.]), ar_value = array([872.03997803]), portf_value = 872.0399780273438
# 2023-10-17 portf_value = 872.0399780273438
# next_date_n pick's portf value = 907.8907470703125
# next_date_n SPY portf value =    872.0399780273438
# ====================
#
# date = '2023-10-16', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.07539749, 108.82193756]), ar_shares = array([8., 4.]), ar_value = array([472.60317993, 435.28775024]), portf_value = 907.8909301757812
# 2023-10-16 portf_value = 907.8909301757812
# date = '2023-10-16', l_syms = ['SPY'], ar_price = array([436.04000854]), ar_shares = array([2.]), ar_value = array([872.08001709]), portf_value = 872.0800170898438
# 2023-10-16 portf_value = 872.0800170898438
# next_date_n pick's portf value = 907.8909301757812
# next_date_n SPY portf value =    872.0800170898438
# ====================
#
# date = '2023-10-16', l_syms = ['SHV'], ar_price = array([108.82193756]), ar_shares = array([9.]), ar_value = array([979.39743805]), portf_value = 979.3974380493164
# 2023-10-16 portf_value = 979.3974380493164
# date = '2023-10-16', l_syms = ['SPY'], ar_price = array([436.04000854]), ar_shares = array([2.]), ar_value = array([872.08001709]), portf_value = 872.0800170898438
# 2023-10-16 portf_value = 872.0800170898438
# next_date_n pick's portf value = 979.3974380493164
# next_date_n SPY portf value =    872.0800170898438
# ====================
#
# date = '2023-10-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.0853157 , 108.81207275]), ar_shares = array([8., 4.]), ar_value = array([472.68252563, 435.24829102]), portf_value = 907.9308166503906
# 2023-10-13 portf_value = 907.9308166503906
# date = '2023-10-13', l_syms = ['SPY'], ar_price = array([431.5]), ar_shares = array([2.]), ar_value = array([863.]), portf_value = 863.0
# 2023-10-13 portf_value = 863.0
# next_date_n pick's portf value = 907.9308166503906
# next_date_n SPY portf value =    863.0
# ====================
#
# date = '2023-10-13', l_syms = ['SHV'], ar_price = array([108.81207275]), ar_shares = array([9.]), ar_value = array([979.30865479]), portf_value = 979.3086547851562
# 2023-10-13 portf_value = 979.3086547851562
# date = '2023-10-13', l_syms = ['SPY'], ar_price = array([431.5]), ar_shares = array([2.]), ar_value = array([863.]), portf_value = 863.0
# 2023-10-13 portf_value = 863.0
# next_date_n pick's portf value = 979.3086547851562
# next_date_n SPY portf value =    863.0
# ====================
#
# date = '2023-10-12', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.05556107, 108.79233551]), ar_shares = array([8., 4.]), ar_value = array([472.44448853, 435.16934204]), portf_value = 907.6138305664062
# 2023-10-12 portf_value = 907.6138305664062
# date = '2023-10-12', l_syms = ['SPY'], ar_price = array([433.66000366]), ar_shares = array([2.]), ar_value = array([867.32000732]), portf_value = 867.3200073242188
# 2023-10-12 portf_value = 867.3200073242188
# next_date_n pick's portf value = 907.6138305664062
# next_date_n SPY portf value =    867.3200073242188
# ====================
#
# date = '2023-10-12', l_syms = ['SHV'], ar_price = array([108.79233551]), ar_shares = array([9.]), ar_value = array([979.13101959]), portf_value = 979.1310195922852
# 2023-10-12 portf_value = 979.1310195922852
# date = '2023-10-12', l_syms = ['SPY'], ar_price = array([433.66000366]), ar_shares = array([2.]), ar_value = array([867.32000732]), portf_value = 867.3200073242188
# 2023-10-12 portf_value = 867.3200073242188
# next_date_n pick's portf value = 979.1310195922852
# next_date_n SPY portf value =    867.3200073242188
# ====================
#
# date = '2023-10-11', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.03076172, 108.73312378]), ar_shares = array([8., 4.]), ar_value = array([472.24609375, 434.93249512]), portf_value = 907.1785888671875
# 2023-10-11 portf_value = 907.1785888671875
# date = '2023-10-11', l_syms = ['SPY'], ar_price = array([436.32000732]), ar_shares = array([2.]), ar_value = array([872.64001465]), portf_value = 872.6400146484375
# 2023-10-11 portf_value = 872.6400146484375
# next_date_n pick's portf value = 907.1785888671875
# next_date_n SPY portf value =    872.6400146484375
# ====================
#
# date = '2023-10-11', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.03076172, 108.73312378]), ar_shares = array([8., 4.]), ar_value = array([472.24609375, 434.93249512]), portf_value = 907.1785888671875
# ...
# next_date_n SPY portf value =    806.3101806640625
# ====================
#
# date = '2023-04-24', l_syms = ['SHV'], ar_price = array([106.28983307]), ar_shares = array([9.]), ar_value = array([956.60849762]), portf_value = 956.6084976196289
# 2023-04-24 portf_value = 956.6084976196289
# date = '2023-04-24', l_syms = ['SPY'], ar_price = array([409.65789795]), ar_shares = array([2.]), ar_value = array([819.3157959]), portf_value = 819.3157958984375
# 2023-04-24 portf_value = 819.3157958984375
# next_date_n pick's portf value = 956.6084976196289
# next_date_n SPY portf value =    819.3157958984375
# ====================
#
# date = '2023-04-21', l_syms = ['ELF', 'SHV'], ar_price = array([ 96.68000031, 106.28020477]), ar_shares = array([5., 4.]), ar_value = array([483.40000153, 425.12081909]), portf_value = 908.5208206176758
# 2023-04-21 portf_value = 908.5208206176758
# date = '2023-04-21', l_syms = ['SPY'], ar_price = array([409.23101807]), ar_shares = array([2.]), ar_value = array([818.46203613]), portf_value = 818.4620361328125
# 2023-04-21 portf_value = 818.4620361328125
# next_date_n pick's portf value = 908.5208206176758
# next_date_n SPY portf value =    818.4620361328125
# ====================
#
# date = '2023-04-20', l_syms = ['SHV'], ar_price = array([106.27058411]), ar_shares = array([9.]), ar_value = array([956.43525696]), portf_value = 956.4352569580078
# 2023-04-20 portf_value = 956.4352569580078
# date = '2023-04-20', l_syms = ['SPY'], ar_price = array([408.91333008]), ar_shares = array([2.]), ar_value = array([817.82666016]), portf_value = 817.82666015625
# 2023-04-20 portf_value = 817.82666015625
# next_date_n pick's portf value = 956.4352569580078
# next_date_n SPY portf value =    817.82666015625
# ====================
#
# date = '2023-04-19', l_syms = ['SHV'], ar_price = array([106.21281433]), ar_shares = array([9.]), ar_value = array([955.91532898]), portf_value = 955.9153289794922
# 2023-04-19 portf_value = 955.9153289794922
# date = '2023-04-19', l_syms = ['SPY'], ar_price = array([411.15704346]), ar_shares = array([2.]), ar_value = array([822.31408691]), portf_value = 822.3140869140625
# 2023-04-19 portf_value = 822.3140869140625
# next_date_n pick's portf value = 955.9153289794922
# next_date_n SPY portf value =    822.3140869140625
# ====================
#
# date = '2023-04-18', l_syms = ['SHV'], ar_price = array([106.20317841]), ar_shares = array([9.]), ar_value = array([955.82860565]), portf_value = 955.8286056518555
# 2023-04-18 portf_value = 955.8286056518555
# date = '2023-04-18', l_syms = ['SPY'], ar_price = array([411.22653198]), ar_shares = array([2.]), ar_value = array([822.45306396]), portf_value = 822.4530639648438
# 2023-04-18 portf_value = 822.4530639648438
# next_date_n pick's portf value = 955.8286056518555
# next_date_n SPY portf value =    822.4530639648438
# ====================
#
# date = '2023-04-17', l_syms = ['SHV'], ar_price = array([106.18392181]), ar_shares = array([9.]), ar_value = array([955.65529633]), portf_value = 955.6552963256836
# 2023-04-17 portf_value = 955.6552963256836
# date = '2023-04-17', l_syms = ['SPY'], ar_price = array([410.95846558]), ar_shares = array([2.]), ar_value = array([821.91693115]), portf_value = 821.9169311523438
# 2023-04-17 portf_value = 821.9169311523438
# next_date_n pick's portf value = 955.6552963256836
# next_date_n SPY portf value =    821.9169311523438
# ====================
#
# date = '2023-04-14', l_syms = ['SHV'], ar_price = array([106.17427826]), ar_shares = array([9.]), ar_value = array([955.56850433]), portf_value = 955.5685043334961
# 2023-04-14 portf_value = 955.5685043334961
# date = '2023-04-14', l_syms = ['SPY'], ar_price = array([409.48913574]), ar_shares = array([2.]), ar_value = array([818.97827148]), portf_value = 818.978271484375
# 2023-04-14 portf_value = 818.978271484375
# next_date_n pick's portf value = 955.5685043334961
# next_date_n SPY portf value =    818.978271484375
# ====================
#
# date = '2023-04-13', l_syms = ['SHV'], ar_price = array([106.19354248]), ar_shares = array([9.]), ar_value = array([955.74188232]), portf_value = 955.7418823242188
# 2023-04-13 portf_value = 955.7418823242188
# date = '2023-04-13', l_syms = ['SPY'], ar_price = array([410.49185181]), ar_shares = array([2.]), ar_value = array([820.98370361]), portf_value = 820.9837036132812
# 2023-04-13 portf_value = 820.9837036132812
# next_date_n pick's portf value = 955.7418823242188
# next_date_n SPY portf value =    820.9837036132812
# ====================
#
# date = '2023-04-12', l_syms = ['SHV'], ar_price = array([106.13576508]), ar_shares = array([9.]), ar_value = array([955.22188568]), portf_value = 955.2218856811523
# 2023-04-12 portf_value = 955.2218856811523
# date = '2023-04-12', l_syms = ['SPY'], ar_price = array([405.11090088]), ar_shares = array([2.]), ar_value = array([810.22180176]), portf_value = 810.2218017578125
# 2023-04-12 portf_value = 810.2218017578125
# next_date_n pick's portf value = 955.2218856811523
# next_date_n SPY portf value =    810.2218017578125
# ====================
#
# date = '2023-04-11', l_syms = ['NVDA', 'SHV'], ar_price = array([271.6156311 , 106.12612152]), ar_shares = array([1., 4.]), ar_value = array([271.6156311 , 424.50448608]), portf_value = 696.1201171875
# 2023-04-11 portf_value = 696.1201171875
# date = '2023-04-11', l_syms = ['SPY'], ar_price = array([406.76885986]), ar_shares = array([2.]), ar_value = array([813.53771973]), portf_value = 813.5377197265625
# 2023-04-11 portf_value = 813.5377197265625
# next_date_n pick's portf value = 696.1201171875
# next_date_n SPY portf value =    813.5377197265625
# ====================
#
# date = '2023-04-10', l_syms = ['GE', 'NVDA'], ar_price = array([ 94.22246552, 275.71450806]), ar_shares = array([5., 1.]), ar_value = array([471.11232758, 275.71450806]), portf_value = 746.8268356323242
# 2023-04-10 portf_value = 746.8268356323242
# date = '2023-04-10', l_syms = ['SPY'], ar_price = array([406.65963745]), ar_shares = array([2.]), ar_value = array([813.3192749]), portf_value = 813.3192749023438
# 2023-04-10 portf_value = 813.3192749023438
# next_date_n pick's portf value = 746.8268356323242
# next_date_n SPY portf value =    813.3192749023438
# ====================
#
# date = '2023-04-06', l_syms = ['NVDA'], ar_price = array([270.29595947]), ar_shares = array([3.]), ar_value = array([810.88787842]), portf_value = 810.8878784179688
# 2023-04-06 portf_value = 810.8878784179688
# date = '2023-04-06', l_syms = ['SPY'], ar_price = array([406.24267578]), ar_shares = array([2.]), ar_value = array([812.48535156]), portf_value = 812.4853515625
# 2023-04-06 portf_value = 812.4853515625
# next_date_n pick's portf value = 810.8878784179688
# next_date_n SPY portf value =    812.4853515625
# ====================
#
# date = '2023-04-05', l_syms = ['SHV'], ar_price = array([106.11650848]), ar_shares = array([9.]), ar_value = array([955.04857635]), portf_value = 955.0485763549805
# 2023-04-05 portf_value = 955.0485763549805
# date = '2023-04-05', l_syms = ['SPY'], ar_price = array([404.66415405]), ar_shares = array([2.]), ar_value = array([809.32830811]), portf_value = 809.3283081054688
# 2023-04-05 portf_value = 809.3283081054688
# next_date_n pick's portf value = 955.0485763549805
# next_date_n SPY portf value =    809.3283081054688
# ====================
#
# date = '2023-04-05', l_syms = ['NVDA'], ar_price = array([268.7364502]), ar_shares = array([3.]), ar_value = array([806.20935059]), portf_value = 806.2093505859375
# 2023-04-05 portf_value = 806.2093505859375
# date = '2023-04-05', l_syms = ['SPY'], ar_price = array([404.66415405]), ar_shares = array([2.]), ar_value = array([809.32830811]), portf_value = 809.3283081054688
# 2023-04-05 portf_value = 809.3283081054688
# next_date_n pick's portf value = 806.2093505859375
# next_date_n SPY portf value =    809.3283081054688
# ====================
#
# date = '2023-04-04', l_syms = ['SHV'], ar_price = array([106.05873871]), ar_shares = array([9.]), ar_value = array([954.52864838]), portf_value = 954.5286483764648
# 2023-04-04 portf_value = 954.5286483764648
# date = '2023-04-04', l_syms = ['SPY'], ar_price = array([405.72644043]), ar_shares = array([2.]), ar_value = array([811.45288086]), portf_value = 811.452880859375
# 2023-04-04 portf_value = 811.452880859375
# next_date_n pick's portf value = 954.5286483764648
# next_date_n SPY portf value =    811.452880859375
# ====================
#
# date = '2023-04-03', l_syms = ['SHV'], ar_price = array([106.02019501]), ar_shares = array([9.]), ar_value = array([954.18175507]), portf_value = 954.181755065918
# 2023-04-03 portf_value = 954.181755065918
# date = '2023-04-03', l_syms = ['SPY'], ar_price = array([407.99002075]), ar_shares = array([2.]), ar_value = array([815.9800415]), portf_value = 815.9800415039062
# 2023-04-03 portf_value = 815.9800415039062
# next_date_n pick's portf value = 954.181755065918
# next_date_n SPY portf value =    815.9800415039062
# ====================
#
# date = '2023-03-31', l_syms = ['SHV'], ar_price = array([106.02886963]), ar_shares = array([9.]), ar_value = array([954.25982666]), portf_value = 954.2598266601562
# 2023-03-31 portf_value = 954.2598266601562
# date = '2023-03-31', l_syms = ['SPY'], ar_price = array([406.44125366]), ar_shares = array([2.]), ar_value = array([812.88250732]), portf_value = 812.8825073242188
# 2023-03-31 portf_value = 812.8825073242188
# next_date_n pick's portf value = 954.2598266601562
# next_date_n SPY portf value =    812.8825073242188
# ====================
#
# date = '2023-03-31', l_syms = ['GE'], ar_price = array([95.46066284]), ar_shares = array([10.]), ar_value = array([954.60662842]), portf_value = 954.6066284179688
# 2023-03-31 portf_value = 954.6066284179688
# date = '2023-03-31', l_syms = ['SPY'], ar_price = array([406.44125366]), ar_shares = array([2.]), ar_value = array([812.88250732]), portf_value = 812.8825073242188
# 2023-03-31 portf_value = 812.8825073242188
# next_date_n pick's portf value = 954.6066284179688
# next_date_n SPY portf value =    812.8825073242188
# ====================
#
# date = '2023-03-30', l_syms = ['NVDA', 'SHV'], ar_price = array([273.7550354 , 106.01929474]), ar_shares = array([1., 4.]), ar_value = array([273.7550354 , 424.07717896]), portf_value = 697.8322143554688
# 2023-03-30 portf_value = 697.8322143554688
# date = '2023-03-30', l_syms = ['SPY'], ar_price = array([400.79226685]), ar_shares = array([2.]), ar_value = array([801.58453369]), portf_value = 801.5845336914062
# 2023-03-30 portf_value = 801.5845336914062
# next_date_n pick's portf value = 697.8322143554688
# next_date_n SPY portf value =    801.5845336914062
# ====================
#
# date = '2023-03-29', l_syms = ['SHV'], ar_price = array([106.00010681]), ar_shares = array([9.]), ar_value = array([954.0009613]), portf_value = 954.0009613037109
# 2023-03-29 portf_value = 954.0009613037109
# date = '2023-03-29', l_syms = ['SPY'], ar_price = array([398.45916748]), ar_shares = array([2.]), ar_value = array([796.91833496]), portf_value = 796.9183349609375
# 2023-03-29 portf_value = 796.9183349609375
# next_date_n pick's portf value = 954.0009613037109
# next_date_n SPY portf value =    796.9183349609375
# ====================
#
# date = '2023-03-28', l_syms = ['SHV'], ar_price = array([105.99047852]), ar_shares = array([9.]), ar_value = array([953.91430664]), portf_value = 953.914306640625
# 2023-03-28 portf_value = 953.914306640625
# date = '2023-03-28', l_syms = ['SPY'], ar_price = array([392.75057983]), ar_shares = array([2.]), ar_value = array([785.50115967]), portf_value = 785.5011596679688
# 2023-03-28 portf_value = 785.5011596679688
# next_date_n pick's portf value = 953.914306640625
# next_date_n SPY portf value =    785.5011596679688
# ====================
#
# date = '2023-03-28', l_syms = ['FTSM'], ar_price = array([57.58307266]), ar_shares = array([17.]), ar_value = array([978.91223526]), portf_value = 978.9122352600098
# 2023-03-28 portf_value = 978.9122352600098
# date = '2023-03-28', l_syms = ['SPY'], ar_price = array([392.75057983]), ar_shares = array([2.]), ar_value = array([785.50115967]), portf_value = 785.5011596679688
# 2023-03-28 portf_value = 785.5011596679688
# next_date_n pick's portf value = 978.9122352600098
# next_date_n SPY portf value =    785.5011596679688
# ====================
#
# date = '2023-03-27', l_syms = ['SHV'], ar_price = array([105.980896]), ar_shares = array([9.]), ar_value = array([953.82806396]), portf_value = 953.8280639648438
# 2023-03-27 portf_value = 953.8280639648438
# date = '2023-03-27', l_syms = ['SPY'], ar_price = array([393.63415527]), ar_shares = array([2.]), ar_value = array([787.26831055]), portf_value = 787.268310546875
# 2023-03-27 portf_value = 787.268310546875
# next_date_n pick's portf value = 953.8280639648438
# next_date_n SPY portf value =    787.268310546875
# ====================
#
# date = '2023-03-27', l_syms = ['GE'], ar_price = array([93.17399597]), ar_shares = array([11.]), ar_value = array([1024.91395569]), portf_value = 1024.9139556884766
# 2023-03-27 portf_value = 1024.9139556884766
# date = '2023-03-27', l_syms = ['SPY'], ar_price = array([393.63415527]), ar_shares = array([2.]), ar_value = array([787.26831055]), portf_value = 787.268310546875
# 2023-03-27 portf_value = 787.268310546875
# next_date_n pick's portf value = 1024.9139556884766
# next_date_n SPY portf value =    787.268310546875
# ====================
#
# date = '2023-03-24', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.63134003, 105.980896  ]), ar_shares = array([8., 4.]), ar_value = array([461.05072021, 423.92358398]), portf_value = 884.9743041992188
# 2023-03-24 portf_value = 884.9743041992188
# date = '2023-03-24', l_syms = ['SPY'], ar_price = array([392.8994751]), ar_shares = array([2.]), ar_value = array([785.7989502]), portf_value = 785.7989501953125
# 2023-03-24 portf_value = 785.7989501953125
# next_date_n pick's portf value = 884.9743041992188
# next_date_n SPY portf value =    785.7989501953125
# ====================
#
# date = '2023-03-23', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.60237503, 105.97129822]), ar_shares = array([8., 4.]), ar_value = array([460.81900024, 423.88519287]), portf_value = 884.7041931152344
# 2023-03-23 portf_value = 884.7041931152344
# date = '2023-03-23', l_syms = ['SPY'], ar_price = array([390.33810425]), ar_shares = array([2.]), ar_value = array([780.6762085]), portf_value = 780.6762084960938
# 2023-03-23 portf_value = 780.6762084960938
# next_date_n pick's portf value = 884.7041931152344
# next_date_n SPY portf value =    780.6762084960938
# ====================
#
# date = '2023-03-23', l_syms = ['GE'], ar_price = array([91.45649719]), ar_shares = array([11.]), ar_value = array([1006.02146912]), portf_value = 1006.0214691162109
# 2023-03-23 portf_value = 1006.0214691162109
# date = '2023-03-23', l_syms = ['SPY'], ar_price = array([390.33810425]), ar_shares = array([2.]), ar_value = array([780.6762085]), portf_value = 780.6762084960938
# 2023-03-23 portf_value = 780.6762084960938
# next_date_n pick's portf value = 1006.0214691162109
# next_date_n SPY portf value =    780.6762084960938
# ====================
#
# date = '2023-03-22', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.59272003, 105.90413666]), ar_shares = array([8., 4.]), ar_value = array([460.74176025, 423.61654663]), portf_value = 884.3583068847656
# 2023-03-22 portf_value = 884.3583068847656
# date = '2023-03-22', l_syms = ['SPY'], ar_price = array([389.28570557]), ar_shares = array([2.]), ar_value = array([778.57141113]), portf_value = 778.5714111328125
# 2023-03-22 portf_value = 778.5714111328125
# next_date_n pick's portf value = 884.3583068847656
# next_date_n SPY portf value =    778.5714111328125
# ====================
#
# date = '2023-03-21', l_syms = ['FTSM', 'SHV'], ar_price = array([ 57.53480148, 105.86575317]), ar_shares = array([8., 4.]), ar_value = array([460.27841187, 423.4630127 ]), portf_value = 883.7414245605469
# 2023-03-21 portf_value = 883.7414245605469
# date = '2023-03-21', l_syms = ['SPY'], ar_price = array([396.03671265]), ar_shares = array([2.]), ar_value = array([792.07342529]), portf_value = 792.0734252929688
# 2023-03-21 portf_value = 792.0734252929688
# next_date_n pick's portf value = 883.7414245605469
# next_date_n SPY portf value =    792.0734252929688
# ====================

# %%
df_picks_mp['date_sell'] = date_exec
df_picks_mp['sh_portf_sell'] = shares_syms
df_picks_mp['$_portf_sell'] = value_portf
df_picks_mp['%_portf_chg'] = (df_picks_mp['$_portf_sell'] / df_picks_mp['$_portf_buy'] - 1) * 100

df_picks_mp['sh_SPY_sell'] = shares_SPY
df_picks_mp['$_SPY_sell'] = value_SPY
df_picks_mp['%_SPY_chg'] = (df_picks_mp['$_SPY_sell'] / df_picks_mp['$_SPY_buy'] - 1) * 100

df_picks_mp['dif_%_chg'] = df_picks_mp['%_portf_chg'] - df_picks_mp['%_SPY_chg']

# %%
# # get symbol's close price for that date
# date = '2023-03-16'
# # _date = '2023-03-21'
# # _sym = 'GE'
# # _sym = 'NVDA'
# _sym = 'FTSM'
# # _sym = 'SHV'
# _sym = 'SPY'
# # _c = df_close.loc['2023-04-11']['NVDA']
# _c = df_close.loc[_date][_sym]
# _c

# %% [markdown]
# #### dif_%_chg is the percentage change of model icks - percentage change of SPY

# %%
df_picks_mp.head(20)
# Out:
#           date      days_lookback    syms_freq                 symbols    date_buy      sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell     sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg
# 0   2023-12-15      [30, 60, 120]   sym_freq_8                 ['SHV']        None              None          NaN       None         NaN        None              None           NaN          NaN        None         NaN        NaN        NaN
# 1   2023-12-13      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-14       [23.0, 4.0]   929.339985      [2.0]  944.020020        None              None           NaN          NaN        None         NaN        NaN        NaN
# 2   2023-12-12      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-13       [23.0, 4.0]   927.513988      [2.0]  941.000000        None              None           NaN          NaN        None         NaN        NaN        NaN
# 3   2023-12-11      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-12       [23.0, 4.0]   928.964710      [2.0]  928.200012  2023-12-15       [23.0, 4.0]    929.609999     0.069463       [2.0]  938.659973   1.126908  -1.057445
# 4   2023-12-08      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-11       [22.0, 4.0]   921.405289      [2.0]  923.979980  2023-12-14       [22.0, 4.0]    908.039986    -1.450535       [2.0]  944.020020   2.168882  -3.619417
# 5   2023-12-07      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-08       [23.0, 4.0]   937.585289      [2.0]  920.400024  2023-12-13       [23.0, 4.0]    927.513988    -1.074174       [2.0]  941.000000   2.238155  -3.312329
# 6   2023-12-06      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-07       [23.0, 4.0]   930.455301      [2.0]  916.460022  2023-12-12       [23.0, 4.0]    928.964710    -0.160200       [2.0]  928.200012   1.281015  -1.441215
# 7   2023-12-05      [30, 60, 120]   sym_freq_9                 ['GPS']  2023-12-06            [47.0]   984.180025      [2.0]  909.520020  2023-12-11            [47.0]   1030.710014     4.727792       [2.0]  923.979980   1.589845   3.137947
# 8   2023-12-05      [30, 60, 120]   sym_freq_8          ['LRN', 'SHV']  2023-12-06        [8.0, 4.0]   924.266205      [2.0]  909.520020  2023-12-11        [8.0, 4.0]    925.825287     0.168683       [2.0]  923.979980   1.589845  -1.421162
# 9   2023-12-05  [15, 30, 60, 120]  sym_freq_12                 ['GPS']  2023-12-06            [47.0]   984.180025      [2.0]  909.520020  2023-12-11            [47.0]   1030.710014     4.727792       [2.0]  923.979980   1.589845   3.137947
# 10  2023-12-04      [30, 60, 120]   sym_freq_9                 ['GPS']  2023-12-05            [48.0]   997.440033      [2.0]  913.200012  2023-12-08            [48.0]   1040.640015     4.331086       [2.0]  920.400024   0.788438   3.542648
# 11  2023-12-04      [30, 60, 120]   sym_freq_8                 ['SHV']  2023-12-05             [9.0]   986.999771      [2.0]  913.200012  2023-12-08             [9.0]    987.626884     0.063537       [2.0]  920.400024   0.788438  -0.724900
# 12  2023-12-04  [15, 30, 60, 120]  sym_freq_12                 ['GPS']  2023-12-05            [48.0]   997.440033      [2.0]  913.200012  2023-12-08            [48.0]   1040.640015     4.331086       [2.0]  920.400024   0.788438   3.542648
# 13  2023-12-01      [30, 60, 120]   sym_freq_9                 ['GPS']  2023-12-04            [47.0]   979.480007      [2.0]  913.380005  2023-12-07            [47.0]   1004.390039     2.543189       [2.0]  916.460022   0.337211   2.205979
# 14  2023-12-01      [30, 60, 120]   sym_freq_8         ['FTSM', 'SHV']  2023-12-04        [8.0, 4.0]   915.466949      [2.0]  913.380005  2023-12-07        [8.0, 4.0]    916.225281     0.082835       [2.0]  916.460022   0.337211  -0.254375
# 15  2023-12-01  [15, 30, 60, 120]  sym_freq_12                 ['GPS']  2023-12-04            [47.0]   979.480007      [2.0]  913.380005  2023-12-07            [47.0]   1004.390039     2.543189       [2.0]  916.460022   0.337211   2.205979
# 16  2023-11-30      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-01       [23.0, 4.0]   922.007130      [2.0]  918.200012  2023-12-06       [23.0, 4.0]    920.366228    -0.177971       [2.0]  909.520020  -0.945327   0.767356
# 17  2023-11-29      [30, 60, 120]   sym_freq_8  ['FTSM', 'GPS', 'SHV']  2023-11-30  [5.0, 16.0, 3.0]   947.725788      [2.0]  912.799988  2023-12-05  [5.0, 16.0, 3.0]    959.629940     1.256076       [2.0]  913.200012   0.043824   1.212252
# 18  2023-11-28      [30, 60, 120]   sym_freq_9                 ['SHV']  2023-11-29             [9.0]   986.060646      [2.0]  909.219971  2023-12-04             [9.0]    986.820625     0.077072       [2.0]  913.380005   0.457539  -0.380467
# 19  2023-11-28      [30, 60, 120]   sym_freq_8         ['FTSM', 'GPS']  2023-11-29       [8.0, 24.0]   960.135986      [2.0]  909.219971  2023-12-04       [8.0, 24.0]    977.040009     1.760586       [2.0]  913.380005   0.457539   1.303047

# %%
df_picks_mp['win'] = np.where(df_picks_mp['dif_%_chg']>0,1,0)
df_picks_mp.head(20)
# Out:
#           date      days_lookback    syms_freq                 symbols    date_buy      sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell     sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0   2023-12-15      [30, 60, 120]   sym_freq_8                 ['SHV']        None              None          NaN       None         NaN        None              None           NaN          NaN        None         NaN        NaN        NaN    0
# 1   2023-12-13      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-14       [23.0, 4.0]   929.339985      [2.0]  944.020020        None              None           NaN          NaN        None         NaN        NaN        NaN    0
# 2   2023-12-12      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-13       [23.0, 4.0]   927.513988      [2.0]  941.000000        None              None           NaN          NaN        None         NaN        NaN        NaN    0
# 3   2023-12-11      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-12       [23.0, 4.0]   928.964710      [2.0]  928.200012  2023-12-15       [23.0, 4.0]    929.609999     0.069463       [2.0]  938.659973   1.126908  -1.057445    0
# 4   2023-12-08      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-11       [22.0, 4.0]   921.405289      [2.0]  923.979980  2023-12-14       [22.0, 4.0]    908.039986    -1.450535       [2.0]  944.020020   2.168882  -3.619417    0
# 5   2023-12-07      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-08       [23.0, 4.0]   937.585289      [2.0]  920.400024  2023-12-13       [23.0, 4.0]    927.513988    -1.074174       [2.0]  941.000000   2.238155  -3.312329    0
# 6   2023-12-06      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-07       [23.0, 4.0]   930.455301      [2.0]  916.460022  2023-12-12       [23.0, 4.0]    928.964710    -0.160200       [2.0]  928.200012   1.281015  -1.441215    0
# 7   2023-12-05      [30, 60, 120]   sym_freq_9                 ['GPS']  2023-12-06            [47.0]   984.180025      [2.0]  909.520020  2023-12-11            [47.0]   1030.710014     4.727792       [2.0]  923.979980   1.589845   3.137947    1
# 8   2023-12-05      [30, 60, 120]   sym_freq_8          ['LRN', 'SHV']  2023-12-06        [8.0, 4.0]   924.266205      [2.0]  909.520020  2023-12-11        [8.0, 4.0]    925.825287     0.168683       [2.0]  923.979980   1.589845  -1.421162    0
# 9   2023-12-05  [15, 30, 60, 120]  sym_freq_12                 ['GPS']  2023-12-06            [47.0]   984.180025      [2.0]  909.520020  2023-12-11            [47.0]   1030.710014     4.727792       [2.0]  923.979980   1.589845   3.137947    1
# 10  2023-12-04      [30, 60, 120]   sym_freq_9                 ['GPS']  2023-12-05            [48.0]   997.440033      [2.0]  913.200012  2023-12-08            [48.0]   1040.640015     4.331086       [2.0]  920.400024   0.788438   3.542648    1
# 11  2023-12-04      [30, 60, 120]   sym_freq_8                 ['SHV']  2023-12-05             [9.0]   986.999771      [2.0]  913.200012  2023-12-08             [9.0]    987.626884     0.063537       [2.0]  920.400024   0.788438  -0.724900    0
# 12  2023-12-04  [15, 30, 60, 120]  sym_freq_12                 ['GPS']  2023-12-05            [48.0]   997.440033      [2.0]  913.200012  2023-12-08            [48.0]   1040.640015     4.331086       [2.0]  920.400024   0.788438   3.542648    1
# 13  2023-12-01      [30, 60, 120]   sym_freq_9                 ['GPS']  2023-12-04            [47.0]   979.480007      [2.0]  913.380005  2023-12-07            [47.0]   1004.390039     2.543189       [2.0]  916.460022   0.337211   2.205979    1
# 14  2023-12-01      [30, 60, 120]   sym_freq_8         ['FTSM', 'SHV']  2023-12-04        [8.0, 4.0]   915.466949      [2.0]  913.380005  2023-12-07        [8.0, 4.0]    916.225281     0.082835       [2.0]  916.460022   0.337211  -0.254375    0
# 15  2023-12-01  [15, 30, 60, 120]  sym_freq_12                 ['GPS']  2023-12-04            [47.0]   979.480007      [2.0]  913.380005  2023-12-07            [47.0]   1004.390039     2.543189       [2.0]  916.460022   0.337211   2.205979    1
# 16  2023-11-30      [30, 60, 120]   sym_freq_8          ['GPS', 'SHV']  2023-12-01       [23.0, 4.0]   922.007130      [2.0]  918.200012  2023-12-06       [23.0, 4.0]    920.366228    -0.177971       [2.0]  909.520020  -0.945327   0.767356    1
# 17  2023-11-29      [30, 60, 120]   sym_freq_8  ['FTSM', 'GPS', 'SHV']  2023-11-30  [5.0, 16.0, 3.0]   947.725788      [2.0]  912.799988  2023-12-05  [5.0, 16.0, 3.0]    959.629940     1.256076       [2.0]  913.200012   0.043824   1.212252    1
# 18  2023-11-28      [30, 60, 120]   sym_freq_9                 ['SHV']  2023-11-29             [9.0]   986.060646      [2.0]  909.219971  2023-12-04             [9.0]    986.820625     0.077072       [2.0]  913.380005   0.457539  -0.380467    0
# 19  2023-11-28      [30, 60, 120]   sym_freq_8         ['FTSM', 'GPS']  2023-11-29       [8.0, 24.0]   960.135986      [2.0]  909.219971  2023-12-04       [8.0, 24.0]    977.040009     1.760586       [2.0]  913.380005   0.457539   1.303047    1

# %% [markdown]
# ### Model Performance Not Good

# %%
wins = df_picks_mp['win'].sum()
attempts = len(df_picks_mp['dif_%_chg'].dropna())

win_rate = wins / attempts
print(f'win_rate: {win_rate:0.6f}, wins: {wins}, attempts: {attempts}')
print(f'sum(df_picksf_%_chg): {df_picks_mp["dif_%_chg"].sum():0.6f}')
# Out:
# win_rate: 0.421986, wins: 119, attempts: 282
# sum(df_picksf_%_chg): -103.323054

# %%
df_picks = df_picks_mp.copy()

# %%
df_modelpicks = df_picks[df_picks['dif_%_chg'].isnull()].copy()
pickle_dump(df_modelpicks, path_data_dump, 'df_modelpicks')
_df_picks = pickle_load(path_data_dump, 'df_modelpicks')
_df_picks
# Out:
#            date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy  $_SPY_buy date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0    2023-12-15  [30, 60, 120]  sym_freq_8          ['SHV']        None         None          NaN       None        NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 1    2023-12-13  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']  2023-12-14  [23.0, 4.0]   929.339985      [2.0]  944.02002      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 2    2023-12-12  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']  2023-12-13  [23.0, 4.0]   927.513988      [2.0]  941.00000      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 247  2023-05-11  [30, 60, 120]  sym_freq_8  ['ISEE', 'SHV']        None         None          NaN       None        NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 248  2023-05-10  [30, 60, 120]  sym_freq_8  ['ISEE', 'SHV']        None         None          NaN       None        NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 249  2023-05-09  [30, 60, 120]  sym_freq_8  ['ISEE', 'SHV']        None         None          NaN       None        NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 250  2023-05-08  [30, 60, 120]  sym_freq_8  ['ISEE', 'SHV']        None         None          NaN       None        NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 251  2023-05-05  [30, 60, 120]  sym_freq_8  ['ISEE', 'SHV']        None         None          NaN       None        NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0

# %%
idx_last_row = df_modelpicks.index[-1]
df_modelpicks_results = df_picks.iloc[(idx_last_row + 1)::].copy()
pickle_dump(df_modelpicks_results, path_data_dump, 'df_modelpicks_results')
_df_picks = pickle_load(path_data_dump, 'df_modelpicks_results')
_df_picks
# Out:
#            date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 252  2023-05-04  [30, 60, 120]  sym_freq_8          ['SHV']  2023-05-05        [9.0]   957.980621      [2.0]  819.315796  2023-05-10         [9.0]    958.415543     0.045400       [2.0]  819.752686   0.053324  -0.007924    0
# 253  2023-05-03  [30, 60, 120]  sym_freq_8          ['SHV']  2023-05-04        [9.0]   958.067688      [2.0]  804.423889  2023-05-09         [9.0]    958.067688     0.000000       [2.0]  815.940308   1.431636  -1.431636    0
# 254  2023-05-02  [30, 60, 120]  sym_freq_8          ['SHV']  2023-05-03        [9.0]   957.545631      [2.0]  810.162231  2023-05-08         [9.0]    958.067688     0.054520       [2.0]  819.534241   1.156806  -1.102286    0
# 255  2023-04-26  [30, 60, 120]  sym_freq_8          ['ELF']  2023-04-27       [10.0]   928.499985      [2.0]  818.879028  2023-05-02        [10.0]    917.399979    -1.195477       [2.0]  815.761597  -0.380695  -0.814782    0
# 256  2023-04-25  [30, 60, 120]  sym_freq_8   ['ELF', 'SHV']  2023-04-26   [5.0, 4.0]   894.563438      [2.0]  802.894958  2023-05-01    [5.0, 4.0]    888.982605    -0.623861       [2.0]  825.034302   2.757440  -3.381301    0
# 257  2023-04-24  [30, 60, 120]  sym_freq_8          ['ELF']  2023-04-25       [10.0]   923.899994      [2.0]  806.310181  2023-04-28        [10.0]    927.600021     0.400479       [2.0]  825.868286   2.425630  -2.025151    0
# 258  2023-04-21  [30, 60, 120]  sym_freq_8          ['ELF']  2023-04-24       [10.0]   948.399963      [2.0]  819.315796  2023-04-27        [10.0]    928.499985    -2.098269       [2.0]  818.879028  -0.053309  -2.044960    0
# 259  2023-04-20  [30, 60, 120]  sym_freq_8          ['ELF']  2023-04-21       [10.0]   966.800003      [2.0]  818.462036  2023-04-26        [10.0]    938.499985    -2.927184       [2.0]  802.894958  -1.901991  -1.025193    0
# 260  2023-04-19  [30, 60, 120]  sym_freq_8          ['SHV']  2023-04-20        [9.0]   956.435257      [2.0]  817.826660  2023-04-25         [9.0]    956.868530     0.045301       [2.0]  806.310181  -1.408181   1.453482    1
# 261  2023-04-18  [30, 60, 120]  sym_freq_8          ['SHV']  2023-04-19        [9.0]   955.915329      [2.0]  822.314087  2023-04-24         [9.0]    956.608498     0.072514       [2.0]  819.315796  -0.364616   0.437130    1
# 262  2023-04-17  [30, 60, 120]  sym_freq_8   ['ELF', 'SHV']  2023-04-18   [5.0, 4.0]   887.712723      [2.0]  822.453064  2023-04-21    [5.0, 4.0]    908.520821     2.344013       [2.0]  818.462036  -0.485259   2.829272    1
# 263  2023-04-14  [30, 60, 120]  sym_freq_8          ['SHV']  2023-04-17        [9.0]   955.655296      [2.0]  821.916931  2023-04-20         [9.0]    956.435257     0.081615       [2.0]  817.826660  -0.497650   0.579265    1
# 264  2023-04-13  [30, 60, 120]  sym_freq_8          ['SHV']  2023-04-14        [9.0]   955.568504      [2.0]  818.978271  2023-04-19         [9.0]    955.915329     0.036295       [2.0]  822.314087   0.407314  -0.371019    0
# 265  2023-04-12  [30, 60, 120]  sym_freq_8          ['SHV']  2023-04-13        [9.0]   955.741882      [2.0]  820.983704  2023-04-18         [9.0]    955.828606     0.009074       [2.0]  822.453064   0.178976  -0.169902    0
# 266  2023-04-11  [30, 60, 120]  sym_freq_8          ['SHV']  2023-04-12        [9.0]   955.221886      [2.0]  810.221802  2023-04-17         [9.0]    955.655296     0.045373       [2.0]  821.916931   1.443448  -1.398075    0
# 267  2023-04-10  [30, 60, 120]  sym_freq_8          ['SHV']  2023-04-11        [9.0]   955.135094      [2.0]  813.537720  2023-04-14         [9.0]    955.568504     0.045377       [2.0]  818.978271   0.668752  -0.623375    0
# 268  2023-04-06  [30, 60, 120]  sym_freq_8          ['SHV']  2023-04-10        [9.0]   954.961922      [2.0]  813.319275  2023-04-13         [9.0]    955.741882     0.081675       [2.0]  820.983704   0.942364  -0.860690    0
# 269  2023-04-05  [30, 60, 120]  sym_freq_9          ['SHV']  2023-04-06        [9.0]   955.048576      [2.0]  812.485352  2023-04-12         [9.0]    955.221886     0.018147       [2.0]  810.221802  -0.278596   0.296742    1
# 270  2023-04-04  [30, 60, 120]  sym_freq_8  ['NVDA', 'SHV']  2023-04-05   [1.0, 4.0]   693.202484      [2.0]  809.328308  2023-04-11    [1.0, 4.0]    696.120117     0.420892       [2.0]  813.537720   0.520112  -0.099220    0
# 271  2023-04-03  [30, 60, 120]  sym_freq_8   ['GE', 'NVDA']  2023-04-04   [5.0, 1.0]   749.012138      [2.0]  811.452881  2023-04-10    [5.0, 1.0]    746.826836    -0.291758       [2.0]  813.319275   0.230006  -0.521764    0
# 272  2023-03-31  [30, 60, 120]  sym_freq_8         ['NVDA']  2023-04-03        [3.0]   838.720276      [2.0]  815.980042  2023-04-06         [3.0]    810.887878    -3.318436       [2.0]  812.485352  -0.428281  -2.890155    0
# 273  2023-03-30  [30, 60, 120]  sym_freq_9          ['SHV']  2023-03-31        [9.0]   954.259827      [2.0]  812.882507  2023-04-05         [9.0]    955.048576     0.082656       [2.0]  809.328308  -0.437234   0.519890    1
# 274  2023-03-30  [30, 60, 120]  sym_freq_8         ['NVDA']  2023-03-31        [3.0]   833.081818      [2.0]  812.882507  2023-04-05         [3.0]    806.209351    -3.225670       [2.0]  809.328308  -0.437234  -2.788436    0
# 275  2023-03-29  [30, 60, 120]  sym_freq_9          ['SHV']  2023-03-30        [9.0]   954.173653      [2.0]  801.584534  2023-04-04         [9.0]    954.528648     0.037205       [2.0]  811.452881   1.231105  -1.193900    0
# 276  2023-03-28  [30, 60, 120]  sym_freq_9          ['SHV']  2023-03-29        [9.0]   954.000961      [2.0]  796.918335  2023-04-03         [9.0]    954.181755     0.018951       [2.0]  815.980042   2.391927  -2.372976    0
# 277  2023-03-27  [30, 60, 120]  sym_freq_9          ['SHV']  2023-03-28        [9.0]   953.914307      [2.0]  785.501160  2023-03-31         [9.0]    954.259827     0.036221       [2.0]  812.882507   3.485844  -3.449623    0
# 278  2023-03-27  [30, 60, 120]  sym_freq_8           ['GE']  2023-03-28       [10.0]   930.042419      [2.0]  785.501160  2023-03-31        [10.0]    954.606628     2.641192       [2.0]  812.882507   3.485844  -0.844652    0
# 279  2023-03-24  [30, 60, 120]  sym_freq_8  ['NVDA', 'SHV']  2023-03-27   [1.0, 4.0]   689.160980      [2.0]  787.268311  2023-03-30    [1.0, 4.0]    697.832214     1.258231       [2.0]  801.584534   1.818468  -0.560238    0
# 280  2023-03-23  [30, 60, 120]  sym_freq_9          ['SHV']  2023-03-24        [9.0]   953.828064      [2.0]  785.798950  2023-03-29         [9.0]    954.000961     0.018127       [2.0]  796.918335   1.415042  -1.396915    0
# 281  2023-03-22  [30, 60, 120]  sym_freq_9          ['SHV']  2023-03-23        [9.0]   953.741684      [2.0]  780.676208  2023-03-28         [9.0]    953.914307     0.018100       [2.0]  785.501160   0.618048  -0.599948    0
# 282  2023-03-22  [30, 60, 120]  sym_freq_8         ['FTSM']  2023-03-23       [17.0]   979.240376      [2.0]  780.676208  2023-03-28        [17.0]    978.912235    -0.033510       [2.0]  785.501160   0.618048  -0.651557    0
# 283  2023-03-21  [30, 60, 120]  sym_freq_9          ['SHV']  2023-03-22        [9.0]   953.137230      [2.0]  778.571411  2023-03-27         [9.0]    953.828064     0.072480       [2.0]  787.268311   1.117033  -1.044553    0
# 284  2023-03-21  [30, 60, 120]  sym_freq_8           ['GE']  2023-03-22       [11.0]   984.053612      [2.0]  778.571411  2023-03-27        [11.0]   1024.913956     4.152248       [2.0]  787.268311   1.117033   3.035215    1
# 285  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-21   [8.0, 4.0]   883.741425      [2.0]  792.073425  2023-03-24    [8.0, 4.0]    884.974304     0.139507       [2.0]  785.798950  -0.792158   0.931665    1
# 286  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-20   [8.0, 4.0]   884.319916      [2.0]  781.807922  2023-03-23    [8.0, 4.0]    884.704193     0.043455       [2.0]  780.676208  -0.144756   0.188211    1
# 287  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']  2023-03-20       [11.0]   987.678345      [2.0]  781.807922  2023-03-23        [11.0]   1006.021469     1.857196       [2.0]  780.676208  -0.144756   2.001952    1
# 288  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-17   [8.0, 4.0]   883.701660      [2.0]  774.361938  2023-03-22    [8.0, 4.0]    884.358307     0.074306       [2.0]  778.571411   0.543605  -0.469299    0
# 289  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']  2023-03-16   [8.0, 4.0]   883.471832      [2.0]  783.523438  2023-03-21    [8.0, 4.0]    883.741425     0.030515       [2.0]  792.073425   1.091223  -1.060708    0
