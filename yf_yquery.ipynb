# %%
# https://dpguthrie-yahooquery-streamlit-app-eydpjo.streamlit.app/
# https://pypi.org/project/yahooquery/2.3.1/
# https://stackoverflow.com/questions/75528839/how-to-fetch-and-filter-data-retrieved-from-yahooquery
# https://towardsdatascience.com/the-unofficial-yahoo-finance-api-32dcf5d53df

# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html

# calculate Return on Invested Capital (ROIC)
# https://www.investopedia.com/terms/r/returnoninvestmentcapital.asp

# %%
import yfinance as yf
import pandas as pd
from pprint import pprint as pp
from yahooquery import Ticker
from myUtils import pickle_load 
from myUtils import yf_print_symbol_data, yf_candlestick


pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 80)
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.width", 500)  # code-runner format


verbose = False  # True prints more output

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

# filename_pickled_df_OHLCVA_downloaded = 'df_OHLCVA_downloaded '  # OHLCVA downloaded from Yahoo
# filename_pickled_df_adjOHLCV = 'df_adjOHLCV'  # adjusted OHLCV

# %% [markdown]
# ### Available Data from Yahoo Finance for Stocks, ETFs and Cryto

# %%
_symbols = ['NVDA', 'SPY', 'BTC-USD']
_types = ['EQUITY', 'ETF', 'CRYPTOCURRENCY']

z_syms_types = zip(_symbols, _types)
for _sym, _typ in z_syms_types:
  yq_sym = Ticker(_sym).all_modules  # modules for a symbol
  l_sym_modules = list(yq_sym.values())  # list with one nested-dict, keys are the modules 
  d_nested_modules = l_sym_modules[0]  # nested dict, keys are the modules  

  if _typ == 'EQUITY':
    keys_equity = list(d_nested_modules.keys())    
  if _typ == 'ETF':
    keys_ETF = list(d_nested_modules.keys())
  if _typ == 'CRYPTOCURRENCY':
    keys_cryto = list(d_nested_modules.keys())                                   
  
  print(f'modules in {_typ}')
  pp(l_sym_modules, depth=3, indent=1)
  print('='*120, '\n'*2)
# Out:
# modules in EQUITY
# [{'assetProfile': {'address1': '2788 San Tomas Expressway',
#                    'auditRisk': 5,
#                    'boardRisk': 9,
#                    'city': 'Santa Clara',
#                    'companyOfficers': [...],
#                    'compensationAsOfEpochDate': '2022-12-30 16:00:00',
#                    'compensationRisk': 1,
#                    'country': 'United States',
#                    'fullTimeEmployees': 26196,
#                    'governanceEpochDate': '2023-04-30 17:00:00',
#                    'industry': 'Semiconductors',
#                    'industryDisp': 'Semiconductors',
#                    'longBusinessSummary': 'NVIDIA Corporation provides '
#                                           'graphics, and compute and '
#                                           'networking solutions in the United '
#                                           'States, Taiwan, China, and '
#                                           "internationally. The company's "
#                                           'Graphics segment offers GeForce '
#                                           'GPUs for gaming and PCs, the '
#                                           'GeForce NOW game streaming service '
#                                           'and related infrastructure, and '
#                                           'solutions for gaming platforms; '
#                                           'Quadro/NVIDIA RTX GPUs for '
#                                           'enterprise workstation graphics; '
#                                           'vGPU software for cloud-based '
#                                           'visual and virtual computing; '
#                                           'automotive platforms for '
#                                           'infotainment systems; and Omniverse '
#                                           'software for building 3D designs '
#                                           'and virtual worlds. Its Compute & '
#                                           'Networking segment provides Data '
#                                           'Center platforms and systems for '
#                                           'AI, HPC, and accelerated computing; '
#                                           'Mellanox networking and '
#                                           'interconnect solutions; automotive '
#                                           'AI Cockpit, autonomous driving '
#                                           'development agreements, and '
#                                           'autonomous vehicle solutions; '
#                                           'cryptocurrency mining processors; '
#                                           'Jetson for robotics and other '
#                                           'embedded platforms; and NVIDIA AI '
#                                           'Enterprise and other software. The '
#                                           "company's products are used in "
#                                           'gaming, professional visualization, '
#                                           'datacenter, and automotive markets. '
#                                           'NVIDIA Corporation sells its '
#                                           'products to original equipment '
#                                           'manufacturers, original device '
#                                           'manufacturers, system builders, '
#                                           'add-in board manufacturers, '
#                                           'retailers/distributors, independent '
#                                           'software vendors, Internet and '
#                                           'cloud service providers, automotive '
#                                           'manufacturers and tier-1 automotive '
#                                           'suppliers, mapping companies, '
#                                           'start-ups, and other ecosystem '
#                                           'participants. It has a strategic '
#                                           'collaboration with Kroger Co. '
#                                           'NVIDIA Corporation was incorporated '
#                                           'in 1993 and is headquartered in '
#                                           'Santa Clara, California.',
#                    'maxAge': 86400,
#                    'overallRisk': 7,
#                    'phone': '408 486 2000',
#                    'sector': 'Technology',
#                    'shareHolderRightsRisk': 8,
#                    'state': 'CA',
#                    'website': 'https://www.nvidia.com',
#                    'zip': '95051'},
#   'balanceSheetHistory': {'balanceSheetStatements': [...], 'maxAge': 86400},
#   'balanceSheetHistoryQuarterly': {'balanceSheetStatements': [...],
#                                    'maxAge': 86400},
#   'calendarEvents': {'dividendDate': '2023-03-28 17:00:00',
#                      'earnings': {...},
#                      'exDividendDate': '2023-03-06 16:00:00',
#                      'maxAge': 1},
#   'cashflowStatementHistory': {'cashflowStatements': [...], 'maxAge': 86400},
#   'cashflowStatementHistoryQuarterly': {'cashflowStatements': [...],
#                                         'maxAge': 86400},
#   'defaultKeyStatistics': {'52WeekChange': 0.4758768,
#                            'SandP52WeekChange': -0.015065432,
#                            'beta': 1.769896,
#                            'bookValue': 8.962,
#                            'category': None,
#                            'dateShortInterest': '2023-04-13 17:00:00',
#                            'earningsQuarterlyGrowth': -0.529,
#                            'enterpriseToEbitda': 96.257,
#                            'enterpriseToRevenue': 25.411,
#                            'enterpriseValue': 685444431872,
#                            'floatShares': 2370137900,
#                            'forwardEps': 6.05,
#                            'forwardPE': 45.557022,
#                            'fundFamily': None,
#                            'heldPercentInsiders': 0.041810002,
#                            'heldPercentInstitutions': 0.68084,
#                            'impliedSharesOutstanding': 2470000128,
#                            'lastDividendDate': 1678147200,
#                            'lastDividendValue': 0.04,
#                            'lastFiscalYearEnd': '2023-01-28 16:00:00',
#                            'lastSplitDate': '2021-07-19 17:00:00',
#                            'lastSplitFactor': '4:1',
#                            'legalType': None,
#                            'maxAge': 1,
#                            'mostRecentQuarter': '2023-01-28 16:00:00',
#                            'netIncomeToCommon': 4368000000,
#                            'nextFiscalYearEnd': '2024-01-28 16:00:00',
#                            'pegRatio': 2.89,
#                            'priceHint': 2,
#                            'priceToBook': 30.754295,
#                            'profitMargins': 0.16193001,
#                            'sharesOutstanding': 2470000128,
#                            'sharesPercentSharesOut': 0.0137,
#                            'sharesShort': 33783023,
#                            'sharesShortPreviousMonthDate': '2023-03-14 '
#                                                            '17:00:00',
#                            'sharesShortPriorMonth': 37702262,
#                            'shortPercentOfFloat': 0.014199999,
#                            'shortRatio': 0.72,
#                            'trailingEps': 1.72},
#   'earnings': {'earningsChart': {...},
#                'financialCurrency': 'USD',
#                'financialsChart': {...},
#                'maxAge': 86400},
#   'earningsHistory': {'history': [...], 'maxAge': 86400},
#   'earningsTrend': {'maxAge': 1, 'trend': [...]},
#   'esgScores': {'adult': False,
#                 'alcoholic': False,
#                 'animalTesting': False,
#                 'catholic': False,
#                 'coal': False,
#                 'controversialWeapons': False,
#                 'environmentPercentile': None,
#                 'environmentScore': 2.26,
#                 'esgPerformance': 'UNDER_PERF',
#                 'furLeather': False,
#                 'gambling': False,
#                 'gmo': False,
#                 'governancePercentile': None,
#                 'governanceScore': 6.03,
#                 'highestControversy': 2.0,
#                 'maxAge': 86400,
#                 'militaryContract': False,
#                 'nuclear': False,
#                 'palmOil': False,
#                 'peerCount': 28,
#                 'peerEnvironmentPerformance': {...},
#                 'peerEsgScorePerformance': {...},
#                 'peerGovernancePerformance': {...},
#                 'peerGroup': 'Semiconductors',
#                 'peerHighestControversyPerformance': {...},
#                 'peerSocialPerformance': {...},
#                 'percentile': 7.14,
#                 'pesticides': False,
#                 'ratingMonth': 8,
#                 'ratingYear': 2022,
#                 'relatedControversy': [...],
#                 'smallArms': False,
#                 'socialPercentile': None,
#                 'socialScore': 5.16,
#                 'tobacco': False,
#                 'totalEsg': 13.45},
#   'financialData': {'currentPrice': 275.62,
#                     'currentRatio': 3.516,
#                     'debtToEquity': 54.436,
#                     'earningsGrowth': -0.514,
#                     'ebitda': 7120999936,
#                     'ebitdaMargins': 0.26399,
#                     'financialCurrency': 'USD',
#                     'freeCashflow': 4532874752,
#                     'grossMargins': 0.56929,
#                     'grossProfits': 15356000000,
#                     'maxAge': 86400,
#                     'numberOfAnalystOpinions': 40,
#                     'operatingCashflow': 5640999936,
#                     'operatingMargins': 0.20674999,
#                     'profitMargins': 0.16193001,
#                     'quickRatio': 2.609,
#                     'recommendationKey': 'buy',
#                     'recommendationMean': 2.0,
#                     'returnOnAssets': 0.08166,
#                     'returnOnEquity': 0.17934,
#                     'revenueGrowth': -0.208,
#                     'revenuePerShare': 10.846,
#                     'targetHighPrice': 394.0,
#                     'targetLowPrice': 190.0,
#                     'targetMeanPrice': 288.05,
#                     'targetMedianPrice': 300.0,
#                     'totalCash': 13296000000,
#                     'totalCashPerShare': 5.383,
#                     'totalDebt': 12030999552,
#                     'totalRevenue': 26973999104},
#   'fundOwnership': {'maxAge': 1, 'ownershipList': [...]},
#   'incomeStatementHistory': {'incomeStatementHistory': [...], 'maxAge': 86400},
#   'incomeStatementHistoryQuarterly': {'incomeStatementHistory': [...],
#                                       'maxAge': 86400},
#   'indexTrend': {'estimates': [...],
#                  'maxAge': 1,
#                  'peRatio': 15.758,
#                  'pegRatio': 1.98481,
#                  'symbol': 'SP5'},
#   'industryTrend': {'estimates': [], 'maxAge': 1, 'symbol': None},
#   'insiderHolders': {'holders': [...], 'maxAge': 1},
#   'insiderTransactions': {'maxAge': 1, 'transactions': [...]},
#   'institutionOwnership': {'maxAge': 1, 'ownershipList': [...]},
#   'majorHoldersBreakdown': {'insidersPercentHeld': 0.041810002,
#                             'institutionsCount': 4015,
#                             'institutionsFloatPercentHeld': 0.71055,
#                             'institutionsPercentHeld': 0.68084,
#                             'maxAge': 1},
#   'netSharePurchaseActivity': {'buyInfoCount': 18,
#                                'buyInfoShares': 3102553,
#                                'buyPercentInsiderShares': 0.031,
#                                'maxAge': 1,
#                                'netInfoCount': 31,
#                                'netInfoShares': 2680757,
#                                'netPercentInsiderShares': 0.027,
#                                'period': '6m',
#                                'sellInfoCount': 13,
#                                'sellInfoShares': 421796,
#                                'sellPercentInsiderShares': 0.004,
#                                'totalInsiderShares': 103270712},
#   'pageViews': {'longTermTrend': 'UP',
#                 'maxAge': 1,
#                 'midTermTrend': 'UP',
#                 'shortTermTrend': 'UP'},
#   'price': {'averageDailyVolume10Day': 38156520,
#             'averageDailyVolume3Month': 46960116,
#             'currency': 'USD',
#             'currencySymbol': '$',
#             'exchange': 'NMS',
#             'exchangeDataDelayedBy': 0,
#             'exchangeName': 'NasdaqGS',
#             'fromCurrency': None,
#             'lastMarket': None,
#             'longName': 'NVIDIA Corporation',
#             'marketCap': 690772639744,
#             'marketState': 'PREPRE',
#             'maxAge': 1,
#             'postMarketChange': 1.25,
#             'postMarketChangePercent': 0.00453523,
#             'postMarketPrice': 276.87,
#             'postMarketSource': 'DELAYED',
#             'postMarketTime': '2023-05-04 16:59:48',
#             'preMarketSource': 'FREE_REALTIME',
#             'priceHint': 2,
#             'quoteSourceName': 'Delayed Quote',
#             'quoteType': 'EQUITY',
#             'regularMarketChange': -2.399994,
#             'regularMarketChangePercent': -0.008632451,
#             'regularMarketDayHigh': 278.58,
#             'regularMarketDayLow': 272.4,
#             'regularMarketOpen': 276.51,
#             'regularMarketPreviousClose': 278.02,
#             'regularMarketPrice': 275.62,
#             'regularMarketSource': 'FREE_REALTIME',
#             'regularMarketTime': '2023-05-04 13:00:04',
#             'regularMarketVolume': 32185041,
#             'shortName': 'NVIDIA Corporation',
#             'symbol': 'NVDA',
#             'toCurrency': None,
#             'underlyingSymbol': None},
#   'quoteType': {'exchange': 'NMS',
#                 'firstTradeDateEpochUtc': '1999-01-22 06:30:00',
#                 'gmtOffSetMilliseconds': -14400000,
#                 'longName': 'NVIDIA Corporation',
#                 'maxAge': 1,
#                 'messageBoardId': 'finmb_32307',
#                 'quoteType': 'EQUITY',
#                 'shortName': 'NVIDIA Corporation',
#                 'symbol': 'NVDA',
#                 'timeZoneFullName': 'America/New_York',
#                 'timeZoneShortName': 'EDT',
#                 'underlyingSymbol': 'NVDA',
#                 'uuid': '7f5f6a07-b148-30f4-98a2-2caa3df2aed0'},
#   'recommendationTrend': {'maxAge': 86400, 'trend': [...]},
#   'secFilings': {'filings': [...], 'maxAge': 86400},
#   'sectorTrend': {'estimates': [], 'maxAge': 1, 'symbol': None},
#   'summaryDetail': {'algorithm': None,
#                     'ask': 276.87,
#                     'askSize': 1300,
#                     'averageDailyVolume10Day': 38156520,
#                     'averageVolume': 46960116,
#                     'averageVolume10days': 38156520,
#                     'beta': 1.769896,
#                     'bid': 276.8,
#                     'bidSize': 1100,
#                     'coinMarketCapLink': None,
#                     'currency': 'USD',
#                     'dayHigh': 278.58,
#                     'dayLow': 272.4,
#                     'dividendRate': 0.16,
#                     'dividendYield': 0.00059999997,
#                     'exDividendDate': '2023-03-06 16:00:00',
#                     'fiftyDayAverage': 259.8918,
#                     'fiftyTwoWeekHigh': 290.58,
#                     'fiftyTwoWeekLow': 108.13,
#                     'fiveYearAvgDividendYield': 0.19,
#                     'forwardPE': 45.557022,
#                     'fromCurrency': None,
#                     'lastMarket': None,
#                     'marketCap': 690772639744,
#                     'maxAge': 1,
#                     'open': 276.51,
#                     'payoutRatio': 0.092,
#                     'previousClose': 278.02,
#                     'priceHint': 2,
#                     'priceToSalesTrailing12Months': 25.608833,
#                     'regularMarketDayHigh': 278.58,
#                     'regularMarketDayLow': 272.4,
#                     'regularMarketOpen': 276.51,
#                     'regularMarketPreviousClose': 278.02,
#                     'regularMarketVolume': 32185041,
#                     'toCurrency': None,
#                     'tradeable': False,
#                     'trailingAnnualDividendRate': 0.16,
#                     'trailingAnnualDividendYield': 0.00057549815,
#                     'trailingPE': 160.24419,
#                     'twoHundredDayAverage': 185.99225,
#                     'volume': 32185041},
#   'summaryProfile': {'address1': '2788 San Tomas Expressway',
#                      'city': 'Santa Clara',
#                      'companyOfficers': [],
#                      'country': 'United States',
#                      'fullTimeEmployees': 26196,
#                      'industry': 'Semiconductors',
#                      'industryDisp': 'Semiconductors',
#                      'longBusinessSummary': 'NVIDIA Corporation provides '
#                                             'graphics, and compute and '
#                                             'networking solutions in the '
#                                             'United States, Taiwan, China, and '
#                                             "internationally. The company's "
#                                             'Graphics segment offers GeForce '
#                                             'GPUs for gaming and PCs, the '
#                                             'GeForce NOW game streaming '
#                                             'service and related '
#                                             'infrastructure, and solutions for '
#                                             'gaming platforms; Quadro/NVIDIA '
#                                             'RTX GPUs for enterprise '
#                                             'workstation graphics; vGPU '
#                                             'software for cloud-based visual '
#                                             'and virtual computing; automotive '
#                                             'platforms for infotainment '
#                                             'systems; and Omniverse software '
#                                             'for building 3D designs and '
#                                             'virtual worlds. Its Compute & '
#                                             'Networking segment provides Data '
#                                             'Center platforms and systems for '
#                                             'AI, HPC, and accelerated '
#                                             'computing; Mellanox networking '
#                                             'and interconnect solutions; '
#                                             'automotive AI Cockpit, autonomous '
#                                             'driving development agreements, '
#                                             'and autonomous vehicle solutions; '
#                                             'cryptocurrency mining processors; '
#                                             'Jetson for robotics and other '
#                                             'embedded platforms; and NVIDIA AI '
#                                             'Enterprise and other software. '
#                                             "The company's products are used "
#                                             'in gaming, professional '
#                                             'visualization, datacenter, and '
#                                             'automotive markets. NVIDIA '
#                                             'Corporation sells its products to '
#                                             'original equipment manufacturers, '
#                                             'original device manufacturers, '
#                                             'system builders, add-in board '
#                                             'manufacturers, '
#                                             'retailers/distributors, '
#                                             'independent software vendors, '
#                                             'Internet and cloud service '
#                                             'providers, automotive '
#                                             'manufacturers and tier-1 '
#                                             'automotive suppliers, mapping '
#                                             'companies, start-ups, and other '
#                                             'ecosystem participants. It has a '
#                                             'strategic collaboration with '
#                                             'Kroger Co. NVIDIA Corporation was '
#                                             'incorporated in 1993 and is '
#                                             'headquartered in Santa Clara, '
#                                             'California.',
#                      'maxAge': 86400,
#                      'phone': '408 486 2000',
#                      'sector': 'Technology',
#                      'state': 'CA',
#                      'website': 'https://www.nvidia.com',
#                      'zip': '95051'},
#   'upgradeDowngradeHistory': {'history': [...], 'maxAge': 86400}}]
# ========================================================================================================================
#
#
# modules in ETF
# [{'assetProfile': {'companyOfficers': [],
#                    'longBusinessSummary': 'The Trust seeks to achieve its '
#                                           'investment objective by holding a '
#                                           'portfolio of the common stocks that '
#                                           'are included in the index (the '
#                                           '“Portfolio”), with the weight of '
#                                           'each stock in the Portfolio '
#                                           'substantially corresponding to the '
#                                           'weight of such stock in the index.',
#                    'maxAge': 86400},
#   'defaultKeyStatistics': {'beta3Year': 1.0,
#                            'category': 'Large Blend',
#                            'fiveYearAverageReturn': 0.1110473,
#                            'fundFamily': 'SPDR State Street Global Advisors',
#                            'fundInceptionDate': '1993-01-21 16:00:00',
#                            'lastSplitFactor': None,
#                            'legalType': 'Exchange Traded Fund',
#                            'maxAge': 1,
#                            'priceHint': 2,
#                            'threeYearAverageReturn': 0.1474791,
#                            'totalAssets': 380248588288,
#                            'yield': 0.0155,
#                            'ytdReturn': 0.0710348},
#   'fundPerformance': {'annualTotalReturns': {...},
#                       'maxAge': 1,
#                       'pastQuarterlyReturns': {...},
#                       'performanceOverview': {...},
#                       'performanceOverviewCat': {...},
#                       'riskOverviewStatistics': {...},
#                       'riskOverviewStatisticsCat': {...},
#                       'trailingReturns': {...},
#                       'trailingReturnsCat': {...},
#                       'trailingReturnsNav': {...}},
#   'fundProfile': {'brokerages': [],
#                   'categoryName': 'Large Blend',
#                   'family': 'SPDR State Street Global Advisors',
#                   'feesExpensesInvestment': {...},
#                   'feesExpensesInvestmentCat': {...},
#                   'legalType': 'Exchange Traded Fund',
#                   'managementInfo': {...},
#                   'maxAge': 1,
#                   'styleBoxUrl': 'https://s.yimg.com/lq/i/fi/3_0stylelargeeq2.gif'},
#   'pageViews': {'longTermTrend': 'UP',
#                 'maxAge': 1,
#                 'midTermTrend': 'UP',
#                 'shortTermTrend': 'DOWN'},
#   'price': {'averageDailyVolume10Day': 85072140,
#             'averageDailyVolume3Month': 89826083,
#             'currency': 'USD',
#             'currencySymbol': '$',
#             'exchange': 'PCX',
#             'exchangeDataDelayedBy': 0,
#             'exchangeName': 'NYSEArca',
#             'fromCurrency': None,
#             'lastMarket': None,
#             'longName': 'SPDR S&P 500 ETF Trust',
#             'marketCap': 371821019136,
#             'marketState': 'PREPRE',
#             'maxAge': 1,
#             'postMarketChange': 1.125,
#             'postMarketChangePercent': 0.00277689,
#             'postMarketPrice': 406.255,
#             'postMarketSource': 'FREE_REALTIME',
#             'postMarketTime': '2023-05-04 16:59:59',
#             'preMarketSource': 'FREE_REALTIME',
#             'priceHint': 2,
#             'quoteSourceName': 'Nasdaq Real Time Price',
#             'quoteType': 'ETF',
#             'regularMarketChange': -2.8899841,
#             'regularMarketChangePercent': -0.0070829475,
#             'regularMarketDayHigh': 407.27,
#             'regularMarketDayLow': 403.74,
#             'regularMarketOpen': 406.93,
#             'regularMarketPreviousClose': 408.02,
#             'regularMarketPrice': 405.13,
#             'regularMarketSource': 'DELAYED',
#             'regularMarketTime': '2023-05-04 13:00:00',
#             'regularMarketVolume': 93499918,
#             'shortName': 'SPDR S&P 500',
#             'symbol': 'SPY',
#             'toCurrency': None,
#             'underlyingSymbol': None},
#   'quoteType': {'exchange': 'PCX',
#                 'firstTradeDateEpochUtc': '1993-01-29 06:30:00',
#                 'gmtOffSetMilliseconds': -14400000,
#                 'longName': 'SPDR S&P 500 ETF Trust',
#                 'maxAge': 1,
#                 'messageBoardId': 'finmb_6160262',
#                 'quoteType': 'ETF',
#                 'shortName': 'SPDR S&P 500',
#                 'symbol': 'SPY',
#                 'timeZoneFullName': 'America/New_York',
#                 'timeZoneShortName': 'EDT',
#                 'underlyingSymbol': 'SPY',
#                 'uuid': 'e97de790-7e95-3762-8917-c59fcab3735e'},
#   'summaryDetail': {'algorithm': None,
#                     'ask': 406.26,
#                     'askSize': 800,
#                     'averageDailyVolume10Day': 85072140,
#                     'averageVolume': 89826083,
#                     'averageVolume10days': 85072140,
#                     'bid': 406.25,
#                     'bidSize': 800,
#                     'coinMarketCapLink': None,
#                     'currency': 'USD',
#                     'dayHigh': 407.27,
#                     'dayLow': 403.74,
#                     'fiftyDayAverage': 402.9316,
#                     'fiftyTwoWeekHigh': 431.73,
#                     'fiftyTwoWeekLow': 348.11,
#                     'fromCurrency': None,
#                     'lastMarket': None,
#                     'maxAge': 1,
#                     'navPrice': 407.99353,
#                     'open': 406.93,
#                     'previousClose': 408.02,
#                     'priceHint': 2,
#                     'regularMarketDayHigh': 407.27,
#                     'regularMarketDayLow': 403.74,
#                     'regularMarketOpen': 406.93,
#                     'regularMarketPreviousClose': 408.02,
#                     'regularMarketVolume': 93499918,
#                     'toCurrency': None,
#                     'totalAssets': 380248588288,
#                     'tradeable': False,
#                     'trailingAnnualDividendRate': 5.662,
#                     'trailingAnnualDividendYield': 0.013876772,
#                     'trailingPE': 20.408213,
#                     'twoHundredDayAverage': 396.0445,
#                     'volume': 93499918,
#                     'yield': 0.0155},
#   'summaryProfile': {'companyOfficers': [],
#                      'longBusinessSummary': 'The Trust seeks to achieve its '
#                                             'investment objective by holding a '
#                                             'portfolio of the common stocks '
#                                             'that are included in the index '
#                                             '(the “Portfolio”), with the '
#                                             'weight of each stock in the '
#                                             'Portfolio substantially '
#                                             'corresponding to the weight of '
#                                             'such stock in the index.',
#                      'maxAge': 86400},
#   'topHoldings': {'bondHoldings': {},
#                   'bondPosition': 0.0,
#                   'bondRatings': [...],
#                   'equityHoldings': {...},
#                   'holdings': [...],
#                   'maxAge': 1,
#                   'sectorWeightings': [...],
#                   'stockPosition': 0.9993}}]
# ========================================================================================================================
#
#
# modules in CRYPTOCURRENCY
# [{'assetProfile': {'companyOfficers': [],
#                    'description': 'Bitcoin (BTC) is a cryptocurrency launched '
#                                   'in 2010. Users are able to generate BTC '
#                                   'through the process of mining. Bitcoin has '
#                                   'a current supply of 19,363,500. The last '
#                                   'known price of Bitcoin is 29,068.49043891 '
#                                   'USD and is up 1.83 over the last 24 hours. '
#                                   'It is currently trading on 10199 active '
#                                   'market(s) with $19,195,560,912.48 traded '
#                                   'over the last 24 hours. More information '
#                                   'can be found at https://bitcoin.org/.',
#                    'maxAge': 86400,
#                    'name': 'Bitcoin',
#                    'startDate': '2010-07-13'},
#   'pageViews': {'longTermTrend': 'UP',
#                 'maxAge': 1,
#                 'midTermTrend': 'UP',
#                 'shortTermTrend': 'UP'},
#   'price': {'averageDailyVolume10Day': 19151514402,
#             'averageDailyVolume3Month': 23586014655,
#             'circulatingSupply': 19364462,
#             'currency': 'USD',
#             'currencySymbol': '$',
#             'exchange': 'CCC',
#             'exchangeDataDelayedBy': 0,
#             'exchangeName': 'CCC',
#             'fromCurrency': 'BTC',
#             'lastMarket': 'CoinMarketCap',
#             'longName': 'Bitcoin USD',
#             'marketCap': 565608972288,
#             'marketState': 'REGULAR',
#             'maxAge': 1,
#             'priceHint': 2,
#             'quoteSourceName': 'CoinMarketCap',
#             'quoteType': 'CRYPTOCURRENCY',
#             'regularMarketChange': 113.365234,
#             'regularMarketChangePercent': 0.0038963528,
#             'regularMarketDayHigh': 29467.041,
#             'regularMarketDayLow': 28848.174,
#             'regularMarketOpen': 28855.176,
#             'regularMarketPreviousClose': 28855.176,
#             'regularMarketPrice': 29208.607,
#             'regularMarketSource': 'FREE_REALTIME',
#             'regularMarketTime': '2023-05-04 21:07:00',
#             'regularMarketVolume': 16671854592,
#             'shortName': 'Bitcoin USD',
#             'symbol': 'BTC-USD',
#             'toCurrency': 'USD=X',
#             'underlyingSymbol': None,
#             'volume24Hr': 16671854592,
#             'volumeAllCurrencies': 16671854592},
#   'quoteType': {'exchange': 'CCC',
#                 'firstTradeDateEpochUtc': '2014-09-16 17:00:00',
#                 'gmtOffSetMilliseconds': 0,
#                 'longName': 'Bitcoin USD',
#                 'maxAge': 1,
#                 'messageBoardId': 'finmb_BTC_CCC',
#                 'quoteType': 'CRYPTOCURRENCY',
#                 'shortName': 'Bitcoin USD',
#                 'symbol': 'BTC-USD',
#                 'timeZoneFullName': 'UTC',
#                 'timeZoneShortName': 'UTC',
#                 'underlyingSymbol': 'BTC-USD',
#                 'uuid': '74397779-1589-3270-8c45-b7f1a7345b3a'},
#   'summaryDetail': {'algorithm': None,
#                     'averageDailyVolume10Day': 19151514402,
#                     'averageVolume': 23586014655,
#                     'averageVolume10days': 19151514402,
#                     'circulatingSupply': 19364462,
#                     'coinMarketCapLink': 'https://coinmarketcap.com/currencies/bitcoin',
#                     'currency': 'USD',
#                     'dayHigh': 29467.041,
#                     'dayLow': 28848.174,
#                     'fiftyDayAverage': 28343.963,
#                     'fiftyTwoWeekHigh': 36624.36,
#                     'fiftyTwoWeekLow': 15599.047,
#                     'fromCurrency': 'BTC',
#                     'lastMarket': 'CoinMarketCap',
#                     'marketCap': 565608972288,
#                     'maxAge': 1,
#                     'open': 28855.176,
#                     'previousClose': 28855.176,
#                     'priceHint': 2,
#                     'regularMarketDayHigh': 29467.041,
#                     'regularMarketDayLow': 28848.174,
#                     'regularMarketOpen': 28855.176,
#                     'regularMarketPreviousClose': 28855.176,
#                     'regularMarketVolume': 16671854592,
#                     'startDate': '2010-07-12 17:00:00',
#                     'toCurrency': 'USD=X',
#                     'tradeable': False,
#                     'twoHundredDayAverage': 21906.143,
#                     'volume': 16671854592,
#                     'volume24Hr': 16671854592,
#                     'volumeAllCurrencies': 16671854592},
#   'summaryProfile': {'companyOfficers': [],
#                      'description': 'Bitcoin (BTC) is a cryptocurrency '
#                                     'launched in 2010. Users are able to '
#                                     'generate BTC through the process of '
#                                     'mining. Bitcoin has a current supply of '
#                                     '19,363,500. The last known price of '
#                                     'Bitcoin is 29,068.49043891 USD and is up '
#                                     '1.83 over the last 24 hours. It is '
#                                     'currently trading on 10199 active '
#                                     'market(s) with $19,195,560,912.48 traded '
#                                     'over the last 24 hours. More information '
#                                     'can be found at https://bitcoin.org/.',
#                      'maxAge': 86400,
#                      'name': 'Bitcoin',
#                      'startDate': '2010-07-13'}}]
# ========================================================================================================================

# %%
print(f'Modules (i.e. keys) for equity, ETF and crytocurrency\n')
print(f'keys_equity: {sorted(keys_equity)}')
print(f'keys_ETF:    {sorted(keys_ETF)}')
print(f'keys_cryto:  {sorted(keys_cryto)}')
# Out:
# Modules (i.e. keys) for equity, ETF and crytocurrency
#
# keys_equity: ['assetProfile', 'balanceSheetHistory', 'balanceSheetHistoryQuarterly', 'calendarEvents', 'cashflowStatementHistory', 'cashflowStatementHistoryQuarterly', 'defaultKeyStatistics', 'earnings', 'earningsHistory', 'earningsTrend', 'esgScores', 'financialData', 'fundOwnership', 'incomeStatementHistory', 'incomeStatementHistoryQuarterly', 'indexTrend', 'industryTrend', 'insiderHolders', 'insiderTransactions', 'institutionOwnership', 'majorHoldersBreakdown', 'netSharePurchaseActivity', 'pageViews', 'price', 'quoteType', 'recommendationTrend', 'secFilings', 'sectorTrend', 'summaryDetail', 'summaryProfile', 'upgradeDowngradeHistory']
# keys_ETF:    ['assetProfile', 'defaultKeyStatistics', 'fundPerformance', 'fundProfile', 'pageViews', 'price', 'quoteType', 'summaryDetail', 'summaryProfile', 'topHoldings']
# keys_cryto:  ['assetProfile', 'pageViews', 'price', 'quoteType', 'summaryDetail', 'summaryProfile']

# %% [markdown]
# ### Get Yahoo Finance data for a symbol

# %%
my_sym = 'NVDA'
yq_sym = Ticker(my_sym).all_modules
l_sym_modules = list(yq_sym.values())  # list with one nested-dict, keys are the modules 
d_nested_modules = l_sym_modules[0]  # nested dict, keys are the modules
d_sorted_modules = dict(sorted(d_nested_modules.items()))  # nested dict, sorted, keys are the modules

# %%
print(f'Modules in {my_sym}:')
pp(sorted(list(d_sorted_modules.keys())))
# Out:
# Modules in NVDA:
# ['assetProfile',
#  'balanceSheetHistory',
#  'balanceSheetHistoryQuarterly',
#  'calendarEvents',
#  'cashflowStatementHistory',
#  'cashflowStatementHistoryQuarterly',
#  'defaultKeyStatistics',
#  'earnings',
#  'earningsHistory',
#  'earningsTrend',
#  'esgScores',
#  'financialData',
#  'fundOwnership',
#  'incomeStatementHistory',
#  'incomeStatementHistoryQuarterly',
#  'indexTrend',
#  'industryTrend',
#  'insiderHolders',
#  'insiderTransactions',
#  'institutionOwnership',
#  'majorHoldersBreakdown',
#  'netSharePurchaseActivity',
#  'pageViews',
#  'price',
#  'quoteType',
#  'recommendationTrend',
#  'secFilings',
#  'sectorTrend',
#  'summaryDetail',
#  'summaryProfile',
#  'upgradeDowngradeHistory']

# %%
print(f'Modules(i.e. keys): values')
pp(d_sorted_modules, depth=5, indent=1)
# Out:
# Modules(i.e. keys): values
# {'assetProfile': {'address1': '2788 San Tomas Expressway',
#                   'auditRisk': 5,
#                   'boardRisk': 9,
#                   'city': 'Santa Clara',
#                   'companyOfficers': [{'age': 59,
#                                        'exercisedValue': 506809472,
#                                        'fiscalYear': 2022,
#                                        'maxAge': 1,
#                                        'name': 'Mr. Jen-Hsun  Huang',
#                                        'title': 'Co-Founder, CEO, Pres & '
#                                                 'Director',
#                                        'totalPay': 5077254,
#                                        'unexercisedValue': 762842816,
#                                        'yearBorn': 1963},
#                                       {'age': 55,
#                                        'exercisedValue': 0,
#                                        'fiscalYear': 2022,
#                                        'maxAge': 1,
#                                        'name': 'Ms. Colette M. Kress',
#                                        'title': 'Exec. VP & CFO',
#                                        'totalPay': 1506907,
#                                        'unexercisedValue': 0,
#                                        'yearBorn': 1967},
#                                       {'age': 67,
#                                        'exercisedValue': 0,
#                                        'fiscalYear': 2022,
#                                        'maxAge': 1,
#                                        'name': 'Ms. Debora  Shoquist',
#                                        'title': 'Exec. VP of Operations',
#                                        'totalPay': 1368262,
#                                        'unexercisedValue': 0,
#                                        'yearBorn': 1955},
#                                       {'age': 55,
#                                        'exercisedValue': 0,
#                                        'fiscalYear': 2022,
#                                        'maxAge': 1,
#                                        'name': 'Mr. Timothy S. Teter',
#                                        'title': 'Exec. VP, Gen. Counsel & Sec.',
#                                        'totalPay': 1359186,
#                                        'unexercisedValue': 0,
#                                        'yearBorn': 1967},
#                                       {'age': 67,
#                                        'exercisedValue': 0,
#                                        'fiscalYear': 2022,
#                                        'maxAge': 1,
#                                        'name': 'Mr. Ajay K. Puri',
#                                        'title': 'Exec. VP of Worldwide Field '
#                                                 'Operations',
#                                        'totalPay': 2279899,
#                                        'unexercisedValue': 0,
#                                        'yearBorn': 1955},
#                                       {'exercisedValue': 0,
#                                        'fiscalYear': 2002,
#                                        'maxAge': 1,
#                                        'name': 'Mr. Chris A. Malachowsky',
#                                        'title': 'Co-Founder',
#                                        'unexercisedValue': 0},
#                                       {'age': 53,
#                                        'exercisedValue': 0,
#                                        'maxAge': 1,
#                                        'name': 'Mr. Donald F. Robertson Jr.',
#                                        'title': 'VP & Chief Accounting Officer',
#                                        'unexercisedValue': 0,
#                                        'yearBorn': 1969},
#                                       {'age': 61,
#                                        'exercisedValue': 0,
#                                        'maxAge': 1,
#                                        'name': 'Prof. William J. Dally',
#                                        'title': 'Chief Scientist & Sr. VP of '
#                                                 'Research',
#                                        'unexercisedValue': 0,
#                                        'yearBorn': 1961},
#                                       {'exercisedValue': 0,
#                                        'maxAge': 1,
#                                        'name': 'Ms. Simona  Jankowski C.F.A., '
#                                                'J.D.',
#                                        'title': 'VP of Investor Relations',
#                                        'unexercisedValue': 0},
#                                       {'age': 63,
#                                        'exercisedValue': 0,
#                                        'maxAge': 1,
#                                        'name': 'Mr. Robert  Sherbin',
#                                        'title': 'VP of Corp. Communications',
#                                        'unexercisedValue': 0,
#                                        'yearBorn': 1959}],
#                   'compensationAsOfEpochDate': '2022-12-30 16:00:00',
#                   'compensationRisk': 1,
#                   'country': 'United States',
#                   'fullTimeEmployees': 26196,
#                   'governanceEpochDate': '2023-04-30 17:00:00',
#                   'industry': 'Semiconductors',
#                   'industryDisp': 'Semiconductors',
#                   'longBusinessSummary': 'NVIDIA Corporation provides '
#                                          'graphics, and compute and networking '
#                                          'solutions in the United States, '
#                                          'Taiwan, China, and internationally. '
#                                          "The company's Graphics segment "
#                                          'offers GeForce GPUs for gaming and '
#                                          'PCs, the GeForce NOW game streaming '
#                                          'service and related infrastructure, '
#                                          'and solutions for gaming platforms; '
#                                          'Quadro/NVIDIA RTX GPUs for '
#                                          'enterprise workstation graphics; '
#                                          'vGPU software for cloud-based visual '
#                                          'and virtual computing; automotive '
#                                          'platforms for infotainment systems; '
#                                          'and Omniverse software for building '
#                                          '3D designs and virtual worlds. Its '
#                                          'Compute & Networking segment '
#                                          'provides Data Center platforms and '
#                                          'systems for AI, HPC, and accelerated '
#                                          'computing; Mellanox networking and '
#                                          'interconnect solutions; automotive '
#                                          'AI Cockpit, autonomous driving '
#                                          'development agreements, and '
#                                          'autonomous vehicle solutions; '
#                                          'cryptocurrency mining processors; '
#                                          'Jetson for robotics and other '
#                                          'embedded platforms; and NVIDIA AI '
#                                          'Enterprise and other software. The '
#                                          "company's products are used in "
#                                          'gaming, professional visualization, '
#                                          'datacenter, and automotive markets. '
#                                          'NVIDIA Corporation sells its '
#                                          'products to original equipment '
#                                          'manufacturers, original device '
#                                          'manufacturers, system builders, '
#                                          'add-in board manufacturers, '
#                                          'retailers/distributors, independent '
#                                          'software vendors, Internet and cloud '
#                                          'service providers, automotive '
#                                          'manufacturers and tier-1 automotive '
#                                          'suppliers, mapping companies, '
#                                          'start-ups, and other ecosystem '
#                                          'participants. It has a strategic '
#                                          'collaboration with Kroger Co. NVIDIA '
#                                          'Corporation was incorporated in 1993 '
#                                          'and is headquartered in Santa Clara, '
#                                          'California.',
#                   'maxAge': 86400,
#                   'overallRisk': 7,
#                   'phone': '408 486 2000',
#                   'sector': 'Technology',
#                   'shareHolderRightsRisk': 8,
#                   'state': 'CA',
#                   'website': 'https://www.nvidia.com',
#                   'zip': '95051'},
#  'balanceSheetHistory': {'balanceSheetStatements': [{'accountsPayable': 1193000000,
#                                                      'capitalSurplus': 11971000000,
#                                                      'cash': 3389000000,
#                                                      'commonStock': 2000000,
#                                                      'deferredLongTermAssetCharges': 3396000000,
#                                                      'endDate': '2023-01-29',
#                                                      'goodWill': 4372000000,
#                                                      'intangibleAssets': 1676000000,
#                                                      'inventory': 5159000000,
#                                                      'longTermDebt': 9703000000,
#                                                      'longTermInvestments': 299000000,
#                                                      'maxAge': 1,
#                                                      'netReceivables': 3827000000,
#                                                      'netTangibleAssets': 16053000000,
#                                                      'otherAssets': 6917000000,
#                                                      'otherCurrentLiab': 3414000000,
#                                                      'otherLiab': 1913000000,
#                                                      'otherStockholderEquity': -43000000,
#                                                      'propertyPlantEquipment': 4845000000,
#                                                      'retainedEarnings': 10171000000,
#                                                      'shortLongTermDebt': 1250000000,
#                                                      'shortTermInvestments': 9907000000,
#                                                      'totalAssets': 41182000000,
#                                                      'totalCurrentAssets': 23073000000,
#                                                      'totalCurrentLiabilities': 6563000000,
#                                                      'totalLiab': 19081000000,
#                                                      'totalStockholderEquity': 22101000000,
#                                                      'treasuryStock': -43000000},
#                                                     {'accountsPayable': 1783000000,
#                                                      'capitalSurplus': 10385000000,
#                                                      'cash': 1990000000,
#                                                      'commonStock': 3000000,
#                                                      'deferredLongTermAssetCharges': 1222000000,
#                                                      'endDate': '2022-01-30',
#                                                      'goodWill': 4349000000,
#                                                      'intangibleAssets': 2339000000,
#                                                      'inventory': 2605000000,
#                                                      'longTermDebt': 10946000000,
#                                                      'longTermInvestments': 266000000,
#                                                      'maxAge': 1,
#                                                      'netReceivables': 4650000000,
#                                                      'netTangibleAssets': 19924000000,
#                                                      'otherAssets': 4797000000,
#                                                      'otherCurrentLiab': 1999000000,
#                                                      'otherLiab': 1553000000,
#                                                      'otherStockholderEquity': -11000000,
#                                                      'propertyPlantEquipment': 3607000000,
#                                                      'retainedEarnings': 16235000000,
#                                                      'shortTermInvestments': 19218000000,
#                                                      'totalAssets': 44187000000,
#                                                      'totalCurrentAssets': 28829000000,
#                                                      'totalCurrentLiabilities': 4335000000,
#                                                      'totalLiab': 17575000000,
#                                                      'totalStockholderEquity': 26612000000,
#                                                      'treasuryStock': -11000000},
#                                                     {'accountsPayable': 1149000000,
#                                                      'capitalSurplus': 8719000000,
#                                                      'cash': 847000000,
#                                                      'commonStock': 3000000,
#                                                      'deferredLongTermAssetCharges': 806000000,
#                                                      'endDate': '2021-01-31',
#                                                      'goodWill': 4193000000,
#                                                      'intangibleAssets': 2737000000,
#                                                      'inventory': 1826000000,
#                                                      'longTermDebt': 5964000000,
#                                                      'longTermInvestments': 144000000,
#                                                      'maxAge': 1,
#                                                      'netReceivables': 2429000000,
#                                                      'netTangibleAssets': 9963000000,
#                                                      'otherAssets': 2806000000,
#                                                      'otherCurrentLiab': 1480000000,
#                                                      'otherLiab': 1375000000,
#                                                      'otherStockholderEquity': 19000000,
#                                                      'propertyPlantEquipment': 2856000000,
#                                                      'retainedEarnings': 18908000000,
#                                                      'shortLongTermDebt': 999000000,
#                                                      'shortTermInvestments': 10714000000,
#                                                      'totalAssets': 28791000000,
#                                                      'totalCurrentAssets': 16055000000,
#                                                      'totalCurrentLiabilities': 3925000000,
#                                                      'totalLiab': 11898000000,
#                                                      'totalStockholderEquity': 16893000000,
#                                                      'treasuryStock': -10737000000},
#                                                     {'accountsPayable': 687000000,
#                                                      'capitalSurplus': 7045000000,
#                                                      'cash': 10896000000,
#                                                      'commonStock': 1000000,
#                                                      'deferredLongTermAssetCharges': 548000000,
#                                                      'endDate': '2020-01-26',
#                                                      'goodWill': 618000000,
#                                                      'intangibleAssets': 49000000,
#                                                      'inventory': 979000000,
#                                                      'longTermDebt': 1991000000,
#                                                      'longTermInvestments': 77000000,
#                                                      'maxAge': 1,
#                                                      'netReceivables': 1657000000,
#                                                      'netTangibleAssets': 11537000000,
#                                                      'otherAssets': 589000000,
#                                                      'otherCurrentLiab': 783000000,
#                                                      'otherLiab': 775000000,
#                                                      'otherStockholderEquity': 1000000,
#                                                      'propertyPlantEquipment': 2292000000,
#                                                      'retainedEarnings': 14971000000,
#                                                      'shortTermInvestments': 1000000,
#                                                      'totalAssets': 17315000000,
#                                                      'totalCurrentAssets': 13690000000,
#                                                      'totalCurrentLiabilities': 1784000000,
#                                                      'totalLiab': 5111000000,
#                                                      'totalStockholderEquity': 12204000000,
#                                                      'treasuryStock': -9813000000}],
#                          'maxAge': 86400},
#  'balanceSheetHistoryQuarterly': {'balanceSheetStatements': [{'accountsPayable': 1193000000,
#                                                               'capitalSurplus': 11971000000,
#                                                               'cash': 3389000000,
#                                                               'commonStock': 2000000,
#                                                               'deferredLongTermAssetCharges': 3396000000,
#                                                               'endDate': '2023-01-29',
#                                                               'goodWill': 4372000000,
#                                                               'intangibleAssets': 1676000000,
#                                                               'inventory': 5159000000,
#                                                               'longTermDebt': 9703000000,
#                                                               'longTermInvestments': 299000000,
#                                                               'maxAge': 1,
#                                                               'netReceivables': 3827000000,
#                                                               'netTangibleAssets': 16053000000,
#                                                               'otherAssets': 6917000000,
#                                                               'otherCurrentLiab': 3414000000,
#                                                               'otherLiab': 1913000000,
#                                                               'otherStockholderEquity': -43000000,
#                                                               'propertyPlantEquipment': 4845000000,
#                                                               'retainedEarnings': 10171000000,
#                                                               'shortLongTermDebt': 1250000000,
#                                                               'shortTermInvestments': 9907000000,
#                                                               'totalAssets': 41182000000,
#                                                               'totalCurrentAssets': 23073000000,
#                                                               'totalCurrentLiabilities': 6563000000,
#                                                               'totalLiab': 19081000000,
#                                                               'totalStockholderEquity': 22101000000,
#                                                               'treasuryStock': -43000000},
#                                                              {'accountsPayable': 1491000000,
#                                                               'capitalSurplus': 11565000000,
#                                                               'cash': 2800000000,
#                                                               'commonStock': 2000000,
#                                                               'deferredLongTermAssetCharges': 2762000000,
#                                                               'endDate': '2022-10-30',
#                                                               'goodWill': 4372000000,
#                                                               'intangibleAssets': 1850000000,
#                                                               'inventory': 4454000000,
#                                                               'longTermDebt': 9701000000,
#                                                               'longTermInvestments': 314000000,
#                                                               'maxAge': 1,
#                                                               'netReceivables': 4908000000,
#                                                               'netTangibleAssets': 15127000000,
#                                                               'otherAssets': 6028000000,
#                                                               'otherCurrentLiab': 3652000000,
#                                                               'otherLiab': 1785000000,
#                                                               'otherStockholderEquity': -123000000,
#                                                               'propertyPlantEquipment': 4701000000,
#                                                               'retainedEarnings': 9905000000,
#                                                               'shortLongTermDebt': 1249000000,
#                                                               'shortTermInvestments': 10343000000,
#                                                               'totalAssets': 40488000000,
#                                                               'totalCurrentAssets': 23223000000,
#                                                               'totalCurrentLiabilities': 6855000000,
#                                                               'totalLiab': 19139000000,
#                                                               'totalStockholderEquity': 21349000000,
#                                                               'treasuryStock': -123000000},
#                                                              {'accountsPayable': 2421000000,
#                                                               'capitalSurplus': 10968000000,
#                                                               'cash': 3013000000,
#                                                               'commonStock': 2000000,
#                                                               'deferredLongTermAssetCharges': 2225000000,
#                                                               'endDate': '2022-07-31',
#                                                               'goodWill': 4372000000,
#                                                               'intangibleAssets': 2036000000,
#                                                               'inventory': 3889000000,
#                                                               'longTermDebt': 9700000000,
#                                                               'longTermInvestments': 307000000,
#                                                               'maxAge': 1,
#                                                               'netReceivables': 5317000000,
#                                                               'netTangibleAssets': 17443000000,
#                                                               'otherAssets': 5258000000,
#                                                               'otherCurrentLiab': 3337000000,
#                                                               'otherLiab': 1609000000,
#                                                               'otherStockholderEquity': -90000000,
#                                                               'propertyPlantEquipment': 4085000000,
#                                                               'retainedEarnings': 12971000000,
#                                                               'shortLongTermDebt': 1249000000,
#                                                               'shortTermInvestments': 14024000000,
#                                                               'totalAssets': 43476000000,
#                                                               'totalCurrentAssets': 27418000000,
#                                                               'totalCurrentLiabilities': 7573000000,
#                                                               'totalLiab': 19625000000,
#                                                               'totalStockholderEquity': 23851000000,
#                                                               'treasuryStock': -90000000},
#                                                              {'accountsPayable': 1999000000,
#                                                               'capitalSurplus': 10623000000,
#                                                               'cash': 3887000000,
#                                                               'commonStock': 3000000,
#                                                               'deferredLongTermAssetCharges': 1784000000,
#                                                               'endDate': '2022-05-01',
#                                                               'goodWill': 4365000000,
#                                                               'intangibleAssets': 2211000000,
#                                                               'inventory': 3163000000,
#                                                               'longTermDebt': 10947000000,
#                                                               'longTermInvestments': 285000000,
#                                                               'maxAge': 1,
#                                                               'netReceivables': 5438000000,
#                                                               'netTangibleAssets': 19744000000,
#                                                               'otherAssets': 5004000000,
#                                                               'otherCurrentLiab': 3089000000,
#                                                               'otherLiab': 1631000000,
#                                                               'otherStockholderEquity': -64000000,
#                                                               'propertyPlantEquipment': 3772000000,
#                                                               'retainedEarnings': 15758000000,
#                                                               'shortTermInvestments': 16451000000,
#                                                               'totalAssets': 45212000000,
#                                                               'totalCurrentAssets': 29575000000,
#                                                               'totalCurrentLiabilities': 5562000000,
#                                                               'totalLiab': 18892000000,
#                                                               'totalStockholderEquity': 26320000000,
#                                                               'treasuryStock': -64000000}],
#                                   'maxAge': 86400},
#  'calendarEvents': {'dividendDate': '2023-03-28 17:00:00',
#                     'earnings': {'earningsAverage': 0.91,
#                                  'earningsDate': ['2023-05-24 14:00:S'],
#                                  'earningsHigh': 0.95,
#                                  'earningsLow': 0.81,
#                                  'revenueAverage': 6505830000,
#                                  'revenueHigh': 6598000000,
#                                  'revenueLow': 6475080000},
#                     'exDividendDate': '2023-03-06 16:00:00',
#                     'maxAge': 1},
#  'cashflowStatementHistory': {'cashflowStatements': [{'capitalExpenditures': -1833000000,
#                                                       'changeInCash': 1399000000,
#                                                       'changeToAccountReceivables': 822000000,
#                                                       'changeToInventory': -2554000000,
#                                                       'changeToLiabilities': -551000000,
#                                                       'changeToNetincome': 1936000000,
#                                                       'changeToOperatingActivities': 76000000,
#                                                       'depreciation': 1544000000,
#                                                       'dividendsPaid': -398000000,
#                                                       'endDate': '2023-01-29',
#                                                       'investments': 9257000000,
#                                                       'issuanceOfStock': 355000000,
#                                                       'maxAge': 1,
#                                                       'netIncome': 4368000000,
#                                                       'otherCashflowsFromFinancingActivities': -60000000,
#                                                       'repurchaseOfStock': -11514000000,
#                                                       'totalCashFromFinancingActivities': -11617000000,
#                                                       'totalCashFromOperatingActivities': 5641000000,
#                                                       'totalCashflowsFromInvestingActivities': 7375000000},
#                                                      {'capitalExpenditures': -976000000,
#                                                       'changeInCash': 1143000000,
#                                                       'changeToAccountReceivables': -2215000000,
#                                                       'changeToInventory': -774000000,
#                                                       'changeToLiabilities': 568000000,
#                                                       'changeToNetincome': 1545000000,
#                                                       'changeToOperatingActivities': -942000000,
#                                                       'depreciation': 1174000000,
#                                                       'dividendsPaid': -399000000,
#                                                       'endDate': '2022-01-30',
#                                                       'investments': -8591000000,
#                                                       'issuanceOfStock': 281000000,
#                                                       'maxAge': 1,
#                                                       'netBorrowings': 3977000000,
#                                                       'netIncome': 9752000000,
#                                                       'otherCashflowsFromFinancingActivities': -90000000,
#                                                       'repurchaseOfStock': -1904000000,
#                                                       'totalCashFromFinancingActivities': 1865000000,
#                                                       'totalCashFromOperatingActivities': 9108000000,
#                                                       'totalCashflowsFromInvestingActivities': -9830000000},
#                                                      {'capitalExpenditures': -1128000000,
#                                                       'changeInCash': -10049000000,
#                                                       'changeToAccountReceivables': -550000000,
#                                                       'changeToInventory': -524000000,
#                                                       'changeToLiabilities': 312000000,
#                                                       'changeToNetincome': 1095000000,
#                                                       'changeToOperatingActivities': 59000000,
#                                                       'depreciation': 1098000000,
#                                                       'dividendsPaid': -395000000,
#                                                       'endDate': '2021-01-31',
#                                                       'investments': -10023000000,
#                                                       'issuanceOfStock': 194000000,
#                                                       'maxAge': 1,
#                                                       'netBorrowings': 4968000000,
#                                                       'netIncome': 4332000000,
#                                                       'otherCashflowsFromFinancingActivities': -21000000,
#                                                       'repurchaseOfStock': -942000000,
#                                                       'totalCashFromFinancingActivities': 3804000000,
#                                                       'totalCashFromOperatingActivities': 5822000000,
#                                                       'totalCashflowsFromInvestingActivities': -19675000000},
#                                                      {'capitalExpenditures': -489000000,
#                                                       'changeInCash': 10114000000,
#                                                       'changeToAccountReceivables': -233000000,
#                                                       'changeToInventory': 597000000,
#                                                       'changeToLiabilities': 194000000,
#                                                       'changeToNetincome': 867000000,
#                                                       'changeToOperatingActivities': 159000000,
#                                                       'depreciation': 381000000,
#                                                       'dividendsPaid': -390000000,
#                                                       'endDate': '2020-01-26',
#                                                       'investments': 6638000000,
#                                                       'issuanceOfStock': 149000000,
#                                                       'maxAge': 1,
#                                                       'netBorrowings': 4968000000,
#                                                       'netIncome': 2796000000,
#                                                       'otherCashflowsFromFinancingActivities': -21000000,
#                                                       'repurchaseOfStock': -551000000,
#                                                       'totalCashFromFinancingActivities': -792000000,
#                                                       'totalCashFromOperatingActivities': 4761000000,
#                                                       'totalCashflowsFromInvestingActivities': 6145000000}],
#                               'maxAge': 86400},
#  'cashflowStatementHistoryQuarterly': {'cashflowStatements': [{'capitalExpenditures': -509000000,
#                                                                'changeInCash': 589000000,
#                                                                'changeToAccountReceivables': 1080000000,
#                                                                'changeToInventory': -706000000,
#                                                                'changeToLiabilities': -193000000,
#                                                                'changeToNetincome': 121000000,
#                                                                'changeToOperatingActivities': 106000000,
#                                                                'depreciation': 426000000,
#                                                                'dividendsPaid': -98000000,
#                                                                'endDate': '2023-01-29',
#                                                                'investments': 506000000,
#                                                                'issuanceOfStock': 6000000,
#                                                                'maxAge': 1,
#                                                                'netIncome': 1414000000,
#                                                                'otherCashflowsFromFinancingActivities': -7000000,
#                                                                'repurchaseOfStock': -1557000000,
#                                                                'totalCashFromFinancingActivities': -1656000000,
#                                                                'totalCashFromOperatingActivities': 2248000000,
#                                                                'totalCashflowsFromInvestingActivities': -3000000},
#                                                               {'capitalExpenditures': -530000000,
#                                                                'changeInCash': -213000000,
#                                                                'changeToAccountReceivables': 410000000,
#                                                                'changeToInventory': -563000000,
#                                                                'changeToLiabilities': -917000000,
#                                                                'changeToNetincome': 179000000,
#                                                                'changeToOperatingActivities': 197000000,
#                                                                'depreciation': 406000000,
#                                                                'dividendsPaid': -100000000,
#                                                                'endDate': '2022-10-30',
#                                                                'investments': 3678000000,
#                                                                'issuanceOfStock': 144000000,
#                                                                'maxAge': 1,
#                                                                'netIncome': 680000000,
#                                                                'otherCashflowsFromFinancingActivities': -18000000,
#                                                                'repurchaseOfStock': -3779000000,
#                                                                'totalCashFromFinancingActivities': -3753000000,
#                                                                'totalCashFromOperatingActivities': 392000000,
#                                                                'totalCashflowsFromInvestingActivities': 3148000000},
#                                                               {'capitalExpenditures': -433000000,
#                                                                'changeInCash': -874000000,
#                                                                'changeToAccountReceivables': 120000000,
#                                                                'changeToInventory': -725000000,
#                                                                'changeToLiabilities': 304000000,
#                                                                'changeToNetincome': 207000000,
#                                                                'changeToOperatingActivities': 330000000,
#                                                                'depreciation': 378000000,
#                                                                'dividendsPaid': -100000000,
#                                                                'endDate': '2022-07-31',
#                                                                'investments': 2064000000,
#                                                                'issuanceOfStock': 1000000,
#                                                                'maxAge': 1,
#                                                                'netIncome': 656000000,
#                                                                'otherCashflowsFromFinancingActivities': -13000000,
#                                                                'repurchaseOfStock': -3650000000,
#                                                                'totalCashFromFinancingActivities': -3762000000,
#                                                                'totalCashFromOperatingActivities': 1270000000,
#                                                                'totalCashflowsFromInvestingActivities': 1618000000},
#                                                               {'capitalExpenditures': -361000000,
#                                                                'changeInCash': 1897000000,
#                                                                'changeToAccountReceivables': -788000000,
#                                                                'changeToInventory': -560000000,
#                                                                'changeToLiabilities': 255000000,
#                                                                'changeToNetincome': 1429000000,
#                                                                'changeToOperatingActivities': -557000000,
#                                                                'depreciation': 334000000,
#                                                                'dividendsPaid': -100000000,
#                                                                'endDate': '2022-05-01',
#                                                                'investments': 3009000000,
#                                                                'issuanceOfStock': 204000000,
#                                                                'maxAge': 1,
#                                                                'netIncome': 1618000000,
#                                                                'otherCashflowsFromFinancingActivities': -22000000,
#                                                                'repurchaseOfStock': -2528000000,
#                                                                'totalCashFromFinancingActivities': -2446000000,
#                                                                'totalCashFromOperatingActivities': 1731000000,
#                                                                'totalCashflowsFromInvestingActivities': 2612000000}],
#                                        'maxAge': 86400},
#  'defaultKeyStatistics': {'52WeekChange': 0.4758768,
#                           'SandP52WeekChange': -0.015065432,
#                           'beta': 1.769896,
#                           'bookValue': 8.962,
#                           'category': None,
#                           'dateShortInterest': '2023-04-13 17:00:00',
#                           'earningsQuarterlyGrowth': -0.529,
#                           'enterpriseToEbitda': 96.257,
#                           'enterpriseToRevenue': 25.411,
#                           'enterpriseValue': 685444431872,
#                           'floatShares': 2370137900,
#                           'forwardEps': 6.05,
#                           'forwardPE': 45.557022,
#                           'fundFamily': None,
#                           'heldPercentInsiders': 0.041810002,
#                           'heldPercentInstitutions': 0.68084,
#                           'impliedSharesOutstanding': 2470000128,
#                           'lastDividendDate': 1678147200,
#                           'lastDividendValue': 0.04,
#                           'lastFiscalYearEnd': '2023-01-28 16:00:00',
#                           'lastSplitDate': '2021-07-19 17:00:00',
#                           'lastSplitFactor': '4:1',
#                           'legalType': None,
#                           'maxAge': 1,
#                           'mostRecentQuarter': '2023-01-28 16:00:00',
#                           'netIncomeToCommon': 4368000000,
#                           'nextFiscalYearEnd': '2024-01-28 16:00:00',
#                           'pegRatio': 2.89,
#                           'priceHint': 2,
#                           'priceToBook': 30.754295,
#                           'profitMargins': 0.16193001,
#                           'sharesOutstanding': 2470000128,
#                           'sharesPercentSharesOut': 0.0137,
#                           'sharesShort': 33783023,
#                           'sharesShortPreviousMonthDate': '2023-03-14 17:00:00',
#                           'sharesShortPriorMonth': 37702262,
#                           'shortPercentOfFloat': 0.014199999,
#                           'shortRatio': 0.72,
#                           'trailingEps': 1.72},
#  'earnings': {'earningsChart': {'currentQuarterEstimate': 0.91,
#                                 'currentQuarterEstimateDate': '2Q',
#                                 'currentQuarterEstimateYear': 2023,
#                                 'earningsDate': ['2023-05-24 14:00:S'],
#                                 'quarterly': [{'actual': 1.36,
#                                                'date': '2Q2022',
#                                                'estimate': 1.29},
#                                               {'actual': 0.51,
#                                                'date': '3Q2022',
#                                                'estimate': 1.25},
#                                               {'actual': 0.58,
#                                                'date': '4Q2022',
#                                                'estimate': 0.69},
#                                               {'actual': 0.88,
#                                                'date': '1Q2023',
#                                                'estimate': 0.81}]},
#               'financialCurrency': 'USD',
#               'financialsChart': {'quarterly': [{'date': '2Q2022',
#                                                  'earnings': 1618000000,
#                                                  'revenue': 8288000000},
#                                                 {'date': '3Q2022',
#                                                  'earnings': 656000000,
#                                                  'revenue': 6704000000},
#                                                 {'date': '4Q2022',
#                                                  'earnings': 680000000,
# ...
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'down',
#                                           'epochGradeDate': '2013-07-31 '
#                                                             '00:56:27',
#                                           'firm': 'Wells Fargo',
#                                           'fromGrade': 'Outperform',
#                                           'toGrade': 'Market Perform'},
#                                          {'action': 'init',
#                                           'epochGradeDate': '2013-05-23 '
#                                                             '00:49:44',
#                                           'firm': 'Topeka',
#                                           'fromGrade': '',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'down',
#                                           'epochGradeDate': '2013-03-10 '
#                                                             '23:46:00',
#                                           'firm': 'Susquehanna',
#                                           'fromGrade': 'Neutral',
#                                           'toGrade': 'Negative'},
#                                          {'action': 'down',
#                                           'epochGradeDate': '2013-02-14 '
#                                                             '01:29:44',
#                                           'firm': 'Needham',
#                                           'fromGrade': 'Buy',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2013-02-14 '
#                                                             '00:39:57',
#                                           'firm': 'Stifel Nicolaus',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2013-02-14 '
#                                                             '00:16:01',
#                                           'firm': 'BMO Capital',
#                                           'fromGrade': '',
#                                           'toGrade': 'Market Perform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2013-02-13 '
#                                                             '23:42:10',
#                                           'firm': 'Nomura',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2013-02-13 '
#                                                             '23:35:18',
#                                           'firm': 'Deutsche Bank',
#                                           'fromGrade': '',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2013-02-12 '
#                                                             '00:11:56',
#                                           'firm': 'FBR Capital',
#                                           'fromGrade': '',
#                                           'toGrade': 'Market Perform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2013-01-03 '
#                                                             '04:23:39',
#                                           'firm': 'Barclays',
#                                           'fromGrade': '',
#                                           'toGrade': 'Equal-Weight'},
#                                          {'action': 'down',
#                                           'epochGradeDate': '2012-12-04 '
#                                                             '23:10:33',
#                                           'firm': 'Oppenheimer',
#                                           'fromGrade': 'Outperform',
#                                           'toGrade': 'Perform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-11-09 '
#                                                             '00:12:00',
#                                           'firm': 'FBR Capital',
#                                           'fromGrade': '',
#                                           'toGrade': 'Market Perform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-11-09 '
#                                                             '00:05:00',
#                                           'firm': 'Nomura',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-11-08 '
#                                                             '23:28:00',
#                                           'firm': 'Jefferies',
#                                           'fromGrade': '',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-11-07 '
#                                                             '04:14:00',
#                                           'firm': 'Wedbush',
#                                           'fromGrade': '',
#                                           'toGrade': 'Outperform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-11-06 '
#                                                             '02:35:00',
#                                           'firm': 'UBS',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-11-05 '
#                                                             '00:25:00',
#                                           'firm': 'BMO Capital',
#                                           'fromGrade': '',
#                                           'toGrade': 'Market Perform'},
#                                          {'action': 'down',
#                                           'epochGradeDate': '2012-10-19 '
#                                                             '01:12:00',
#                                           'firm': 'FBR Capital',
#                                           'fromGrade': 'Outperform',
#                                           'toGrade': 'Market Perform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-10-10 '
#                                                             '00:07:00',
#                                           'firm': 'Deutsche Bank',
#                                           'fromGrade': '',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'init',
#                                           'epochGradeDate': '2012-09-28 '
#                                                             '00:45:00',
#                                           'firm': 'Brean Capital',
#                                           'fromGrade': '',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-09-12 '
#                                                             '22:57:00',
#                                           'firm': 'Citigroup',
#                                           'fromGrade': '',
#                                           'toGrade': 'Neutral'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-08-10 '
#                                                             '07:14:00',
#                                           'firm': 'Barclays',
#                                           'fromGrade': '',
#                                           'toGrade': 'Equal-Weight'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-08-10 '
#                                                             '03:01:00',
#                                           'firm': 'UBS',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-08-10 '
#                                                             '01:16:00',
#                                           'firm': 'Stifel Nicolaus',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-08-10 '
#                                                             '00:57:00',
#                                           'firm': 'FBR Capital',
#                                           'fromGrade': '',
#                                           'toGrade': 'Outperform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-08-09 '
#                                                             '23:56:00',
#                                           'firm': 'Wedbush',
#                                           'fromGrade': '',
#                                           'toGrade': 'Outperform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-08-09 '
#                                                             '23:28:00',
#                                           'firm': 'Jefferies',
#                                           'fromGrade': '',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-08-09 '
#                                                             '23:21:00',
#                                           'firm': 'Citigroup',
#                                           'fromGrade': '',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-08-07 '
#                                                             '01:10:00',
#                                           'firm': 'FBR Capital',
#                                           'fromGrade': '',
#                                           'toGrade': 'Outperform'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-07-10 '
#                                                             '02:13:00',
#                                           'firm': 'Raymond James',
#                                           'fromGrade': '',
#                                           'toGrade': 'Strong Buy'},
#                                          {'action': 'init',
#                                           'epochGradeDate': '2012-06-28 '
#                                                             '01:50:00',
#                                           'firm': 'Lazard',
#                                           'fromGrade': '',
#                                           'toGrade': 'Neutral'},
#                                          {'action': 'up',
#                                           'epochGradeDate': '2012-06-24 '
#                                                             '23:22:00',
#                                           'firm': 'Canaccord Genuity',
#                                           'fromGrade': 'Hold',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'up',
#                                           'epochGradeDate': '2012-06-11 '
#                                                             '05:28:00',
#                                           'firm': 'UBS',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'init',
#                                           'epochGradeDate': '2012-05-30 '
#                                                             '23:53:00',
#                                           'firm': 'Morgan Stanley',
#                                           'fromGrade': '',
#                                           'toGrade': 'Equal-Weight'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-05-14 '
#                                                             '04:27:00',
#                                           'firm': 'Salman Partners',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-05-13 '
#                                                             '23:19:00',
#                                           'firm': 'Jefferies',
#                                           'fromGrade': '',
#                                           'toGrade': 'Hold'},
#                                          {'action': 'init',
#                                           'epochGradeDate': '2012-04-05 '
#                                                             '00:07:00',
#                                           'firm': 'Cantor Fitzgerald',
#                                           'fromGrade': '',
#                                           'toGrade': 'Buy'},
#                                          {'action': 'main',
#                                           'epochGradeDate': '2012-02-15 '
#                                                             '23:29:00',
#                                           'firm': 'Evercore Partners',
#                                           'fromGrade': '',
#                                           'toGrade': 'Underweight'},
#                                          {'action': 'down',
#                                           'epochGradeDate': '2012-02-15 '
#                                                             '22:34:00',
#                                           'firm': 'Bank oferica',
#                                           'fromGrade': '',
#                                           'toGrade': 'Neutral'},
#                                          {'action': 'up',
#                                           'epochGradeDate': '2012-02-12 '
#                                                             '23:27:00',
#                                           'firm': 'FBR Capital',
#                                           'fromGrade': '',
#                                           'toGrade': 'Outperform'}],
#                              'maxAge': 86400}}

# %%
def print_dict_key_value(my_dict):
  for key, value in my_dict.items():
    val_type = str(type(value))
    val_str = str(value)
    val_trunc = (val_str[:35] + '...') if len(val_str) > 35 else val_str      
    print(f'key: {key:<35}value: {val_type:<18}: {val_trunc}')    
  return None

# %%
print(f'Modules in {my_sym}:')
for k_mod, v_mod in d_sorted_modules.items():
  print(f'{"="*120}\nModule: {k_mod}\index_dict{"="*120}')  
  if isinstance(v_mod, dict):
    print_dict_key_value(v_mod)
  print('\n')
# Out:
# Modules in NVDA:
# ========================================================================================================================
# Module: assetProfile\index_dict========================================================================================================================
# key: address1                           value: <class 'str'>     : 2788 San Tomas Expressway
# key: city                               value: <class 'str'>     : Santa Clara
# key: state                              value: <class 'str'>     : CA
# key: zip                                value: <class 'str'>     : 95051
# key: country                            value: <class 'str'>     : United States
# key: phone                              value: <class 'str'>     : 408 486 2000
# key: website                            value: <class 'str'>     : https://www.nvidia.com
# key: industry                           value: <class 'str'>     : Semiconductors
# key: industryDisp                       value: <class 'str'>     : Semiconductors
# key: sector                             value: <class 'str'>     : Technology
# key: longBusinessSummary                value: <class 'str'>     : NVIDIA Corporation provides graphic...
# key: fullTimeEmployees                  value: <class 'int'>     : 26196
# key: companyOfficers                    value: <class 'list'>    : [{'maxAge': 1, 'name': 'Mr. Jen-Hsu...
# key: auditRisk                          value: <class 'int'>     : 5
# key: boardRisk                          value: <class 'int'>     : 9
# key: compensationRisk                   value: <class 'int'>     : 1
# key: shareHolderRightsRisk              value: <class 'int'>     : 8
# key: overallRisk                        value: <class 'int'>     : 7
# key: governanceEpochDate                value: <class 'str'>     : 2023-04-30 17:00:00
# key: compensationAsOfEpochDate          value: <class 'str'>     : 2022-12-30 16:00:00
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: balanceSheetHistory\index_dict========================================================================================================================
# key: balanceSheetStatements             value: <class 'list'>    : [{'maxAge': 1, 'endDate': '2023-01-...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: balanceSheetHistoryQuarterly\index_dict========================================================================================================================
# key: balanceSheetStatements             value: <class 'list'>    : [{'maxAge': 1, 'endDate': '2023-01-...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: calendarEvents\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: earnings                           value: <class 'dict'>    : {'earningsDate': ['2023-05-24 14:00...
# key: exDividendDate                     value: <class 'str'>     : 2023-03-06 16:00:00
# key: dividendDate                       value: <class 'str'>     : 2023-03-28 17:00:00
#
#
# ========================================================================================================================
# Module: cashflowStatementHistory\index_dict========================================================================================================================
# key: cashflowStatements                 value: <class 'list'>    : [{'maxAge': 1, 'endDate': '2023-01-...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: cashflowStatementHistoryQuarterly\index_dict========================================================================================================================
# key: cashflowStatements                 value: <class 'list'>    : [{'maxAge': 1, 'endDate': '2023-01-...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: defaultKeyStatistics\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: priceHint                          value: <class 'int'>     : 2
# key: enterpriseValue                    value: <class 'int'>     : 685444431872
# key: forwardPE                          value: <class 'float'>   : 45.557022
# key: profitMargins                      value: <class 'float'>   : 0.16193001
# key: floatShares                        value: <class 'int'>     : 2370137900
# key: sharesOutstanding                  value: <class 'int'>     : 2470000128
# key: sharesShort                        value: <class 'int'>     : 33783023
# key: sharesShortPriorMonth              value: <class 'int'>     : 37702262
# key: sharesShortPreviousMonthDate       value: <class 'str'>     : 2023-03-14 17:00:00
# key: dateShortInterest                  value: <class 'str'>     : 2023-04-13 17:00:00
# key: sharesPercentSharesOut             value: <class 'float'>   : 0.0137
# key: heldPercentInsiders                value: <class 'float'>   : 0.041810002
# key: heldPercentInstitutions            value: <class 'float'>   : 0.68084
# key: shortRatio                         value: <class 'float'>   : 0.72
# key: shortPercentOfFloat                value: <class 'float'>   : 0.014199999
# key: beta                               value: <class 'float'>   : 1.769896
# key: impliedSharesOutstanding           value: <class 'int'>     : 2470000128
# key: category                           value: <class 'NoneType'>: None
# key: bookValue                          value: <class 'float'>   : 8.962
# key: priceToBook                        value: <class 'float'>   : 30.754295
# key: fundFamily                         value: <class 'NoneType'>: None
# key: legalType                          value: <class 'NoneType'>: None
# key: lastFiscalYearEnd                  value: <class 'str'>     : 2023-01-28 16:00:00
# key: nextFiscalYearEnd                  value: <class 'str'>     : 2024-01-28 16:00:00
# key: mostRecentQuarter                  value: <class 'str'>     : 2023-01-28 16:00:00
# key: earningsQuarterlyGrowth            value: <class 'float'>   : -0.529
# key: netIncomeToCommon                  value: <class 'int'>     : 4368000000
# key: trailingEps                        value: <class 'float'>   : 1.72
# key: forwardEps                         value: <class 'float'>   : 6.05
# key: pegRatio                           value: <class 'float'>   : 2.89
# key: lastSplitFactor                    value: <class 'str'>     : 4:1
# key: lastSplitDate                      value: <class 'str'>     : 2021-07-19 17:00:00
# key: enterpriseToRevenue                value: <class 'float'>   : 25.411
# key: enterpriseToEbitda                 value: <class 'float'>   : 96.257
# key: 52WeekChange                       value: <class 'float'>   : 0.4758768
# key: SandP52WeekChange                  value: <class 'float'>   : -0.015065432
# key: lastDividendValue                  value: <class 'float'>   : 0.04
# key: lastDividendDate                   value: <class 'int'>     : 1678147200
#
#
# ========================================================================================================================
# Module: earnings\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 86400
# key: earningsChart                      value: <class 'dict'>    : {'quarterly': [{'date': '2Q2022', '...
# key: financialsChart                    value: <class 'dict'>    : {'yearly': [{'date': 2020, 'revenue...
# key: financialCurrency                  value: <class 'str'>     : USD
#
#
# ========================================================================================================================
# Module: earningsHistory\index_dict========================================================================================================================
# key: history                            value: <class 'list'>    : [{'maxAge': 1, 'epsActual': 1.36, '...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: earningsTrend\index_dict========================================================================================================================
# key: trend                              value: <class 'list'>    : [{'maxAge': 1, 'period': '0q', 'end...
# key: maxAge                             value: <class 'int'>     : 1
#
#
# ========================================================================================================================
# Module: esgScores\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 86400
# key: totalEsg                           value: <class 'float'>   : 13.45
# key: environmentScore                   value: <class 'float'>   : 2.26
# key: socialScore                        value: <class 'float'>   : 5.16
# key: governanceScore                    value: <class 'float'>   : 6.03
# key: ratingYear                         value: <class 'int'>     : 2022
# key: ratingMonth                        value: <class 'int'>     : 8
# key: highestControversy                 value: <class 'float'>   : 2.0
# key: peerCount                          value: <class 'int'>     : 28
# key: esgPerformance                     value: <class 'str'>     : UNDER_PERF
# key: peerGroup                          value: <class 'str'>     : Semiconductors
# key: relatedControversy                 value: <class 'list'>    : ['Customer Incidents']
# key: peerEsgScorePerformance            value: <class 'dict'>    : {'min': 10.91, 'avg': 20.4028571428...
# key: peerGovernancePerformance          value: <class 'dict'>    : {'min': 4.64, 'avg': 6.306666666666...
# key: peerSocialPerformance              value: <class 'dict'>    : {'min': 2.59, 'avg': 5.937407407407...
# key: peerEnvironmentPerformance         value: <class 'dict'>    : {'min': 2.26, 'avg': 7.751851851851...
# key: peerHighestControversyPerformance  value: <class 'dict'>    : {'min': 0.0, 'avg': 1.1428571428571...
# key: percentile                         value: <class 'float'>   : 7.14
# key: environmentPercentile              value: <class 'NoneType'>: None
# key: socialPercentile                   value: <class 'NoneType'>: None
# key: governancePercentile               value: <class 'NoneType'>: None
# key: adult                              value: <class 'bool'>    : False
# key: alcoholic                          value: <class 'bool'>    : False
# key: animalTesting                      value: <class 'bool'>    : False
# key: catholic                           value: <class 'bool'>    : False
# key: controversialWeapons               value: <class 'bool'>    : False
# key: smallArms                          value: <class 'bool'>    : False
# key: furLeather                         value: <class 'bool'>    : False
# key: gambling                           value: <class 'bool'>    : False
# key: gmo                                value: <class 'bool'>    : False
# key: militaryContract                   value: <class 'bool'>    : False
# key: nuclear                            value: <class 'bool'>    : False
# key: pesticides                         value: <class 'bool'>    : False
# key: palmOil                            value: <class 'bool'>    : False
# key: coal                               value: <class 'bool'>    : False
# key: tobacco                            value: <class 'bool'>    : False
#
#
# ========================================================================================================================
# Module: financialData\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 86400
# key: currentPrice                       value: <class 'float'>   : 275.62
# key: targetHighPrice                    value: <class 'float'>   : 394.0
# key: targetLowPrice                     value: <class 'float'>   : 190.0
# key: targetMeanPrice                    value: <class 'float'>   : 288.05
# key: targetMedianPrice                  value: <class 'float'>   : 300.0
# key: recommendationMean                 value: <class 'float'>   : 2.0
# key: recommendationKey                  value: <class 'str'>     : buy
# key: numberOfAnalystOpinions            value: <class 'int'>     : 40
# key: totalCash                          value: <class 'int'>     : 13296000000
# key: totalCashPerShare                  value: <class 'float'>   : 5.383
# key: ebitda                             value: <class 'int'>     : 7120999936
# key: totalDebt                          value: <class 'int'>     : 12030999552
# key: quickRatio                         value: <class 'float'>   : 2.609
# key: currentRatio                       value: <class 'float'>   : 3.516
# key: totalRevenue                       value: <class 'int'>     : 26973999104
# key: debtToEquity                       value: <class 'float'>   : 54.436
# key: revenuePerShare                    value: <class 'float'>   : 10.846
# key: returnOnAssets                     value: <class 'float'>   : 0.08166
# key: returnOnEquity                     value: <class 'float'>   : 0.17934
# key: grossProfits                       value: <class 'int'>     : 15356000000
# key: freeCashflow                       value: <class 'int'>     : 4532874752
# key: operatingCashflow                  value: <class 'int'>     : 5640999936
# key: earningsGrowth                     value: <class 'float'>   : -0.514
# key: revenueGrowth                      value: <class 'float'>   : -0.208
# key: grossMargins                       value: <class 'float'>   : 0.56929
# key: ebitdaMargins                      value: <class 'float'>   : 0.26399
# key: operatingMargins                   value: <class 'float'>   : 0.20674999
# key: profitMargins                      value: <class 'float'>   : 0.16193001
# key: financialCurrency                  value: <class 'str'>     : USD
#
#
# ========================================================================================================================
# Module: fundOwnership\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: ownershipList                      value: <class 'list'>    : [{'maxAge': 1, 'reportDate': '2022-...
#
#
# ========================================================================================================================
# Module: incomeStatementHistory\index_dict========================================================================================================================
# key: incomeStatementHistory             value: <class 'list'>    : [{'maxAge': 1, 'endDate': '2023-01-...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: incomeStatementHistoryQuarterly\index_dict========================================================================================================================
# key: incomeStatementHistory             value: <class 'list'>    : [{'maxAge': 1, 'endDate': '2023-01-...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: indexTrend\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: symbol                             value: <class 'str'>     : SP5
# key: peRatio                            value: <class 'float'>   : 15.758
# key: pegRatio                           value: <class 'float'>   : 1.98481
# key: estimates                          value: <class 'list'>    : [{'period': '0q', 'growth': -0.0069...
#
#
# ========================================================================================================================
# Module: industryTrend\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: symbol                             value: <class 'NoneType'>: None
# key: estimates                          value: <class 'list'>    : []
#
#
# ========================================================================================================================
# Module: insiderHolders\index_dict========================================================================================================================
# key: holders                            value: <class 'list'>    : [{'maxAge': 1, 'name': 'COXE TENCH ...
# key: maxAge                             value: <class 'int'>     : 1
#
#
# ========================================================================================================================
# Module: insiderTransactions\index_dict========================================================================================================================
# key: transactions                       value: <class 'list'>    : [{'maxAge': 1, 'shares': 5000, 'val...
# key: maxAge                             value: <class 'int'>     : 1
#
#
# ========================================================================================================================
# Module: institutionOwnership\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: ownershipList                      value: <class 'list'>    : [{'maxAge': 1, 'reportDate': '2022-...
#
#
# ========================================================================================================================
# Module: majorHoldersBreakdown\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: insidersPercentHeld                value: <class 'float'>   : 0.041810002
# key: institutionsPercentHeld            value: <class 'float'>   : 0.68084
# key: institutionsFloatPercentHeld       value: <class 'float'>   : 0.71055
# key: institutionsCount                  value: <class 'int'>     : 4015
#
#
# ========================================================================================================================
# Module: netSharePurchaseActivity\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: period                             value: <class 'str'>     : 6m
# key: buyInfoCount                       value: <class 'int'>     : 18
# key: buyInfoShares                      value: <class 'int'>     : 3102553
# key: buyPercentInsiderShares            value: <class 'float'>   : 0.031
# key: sellInfoCount                      value: <class 'int'>     : 13
# key: sellInfoShares                     value: <class 'int'>     : 421796
# key: sellPercentInsiderShares           value: <class 'float'>   : 0.004
# key: netInfoCount                       value: <class 'int'>     : 31
# key: netInfoShares                      value: <class 'int'>     : 2680757
# key: netPercentInsiderShares            value: <class 'float'>   : 0.027
# key: totalInsiderShares                 value: <class 'int'>     : 103270712
#
#
# ========================================================================================================================
# Module: pageViews\index_dict========================================================================================================================
# key: shortTermTrend                     value: <class 'str'>     : UP
# key: midTermTrend                       value: <class 'str'>     : UP
# key: longTermTrend                      value: <class 'str'>     : UP
# key: maxAge                             value: <class 'int'>     : 1
#
#
# ========================================================================================================================
# Module: price\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: preMarketSource                    value: <class 'str'>     : FREE_REALTIME
# key: postMarketChangePercent            value: <class 'float'>   : 0.00453523
# key: postMarketChange                   value: <class 'float'>   : 1.25
# key: postMarketTime                     value: <class 'str'>     : 2023-05-04 16:59:48
# key: postMarketPrice                    value: <class 'float'>   : 276.87
# key: postMarketSource                   value: <class 'str'>     : DELAYED
# key: regularMarketChangePercent         value: <class 'float'>   : -0.008632451
# key: regularMarketChange                value: <class 'float'>   : -2.399994
# key: regularMarketTime                  value: <class 'str'>     : 2023-05-04 13:00:04
# key: priceHint                          value: <class 'int'>     : 2
# key: regularMarketPrice                 value: <class 'float'>   : 275.62
# key: regularMarketDayHigh               value: <class 'float'>   : 278.58
# key: regularMarketDayLow                value: <class 'float'>   : 272.4
# key: regularMarketVolume                value: <class 'int'>     : 32185041
# key: averageDailyVolume10Day            value: <class 'int'>     : 38156520
# key: averageDailyVolume3Month           value: <class 'int'>     : 46960116
# key: regularMarketPreviousClose         value: <class 'float'>   : 278.02
# key: regularMarketSource                value: <class 'str'>     : FREE_REALTIME
# key: regularMarketOpen                  value: <class 'float'>   : 276.51
# key: exchange                           value: <class 'str'>     : NMS
# key: exchangeName                       value: <class 'str'>     : NasdaqGS
# key: exchangeDataDelayedBy              value: <class 'int'>     : 0
# key: marketState                        value: <class 'str'>     : PREPRE
# key: quoteType                          value: <class 'str'>     : EQUITY
# key: symbol                             value: <class 'str'>     : NVDA
# key: underlyingSymbol                   value: <class 'NoneType'>: None
# key: shortName                          value: <class 'str'>     : NVIDIA Corporation
# key: longName                           value: <class 'str'>     : NVIDIA Corporation
# key: currency                           value: <class 'str'>     : USD
# key: quoteSourceName                    value: <class 'str'>     : Delayed Quote
# key: currencySymbol                     value: <class 'str'>     : $
# key: fromCurrency                       value: <class 'NoneType'>: None
# key: toCurrency                         value: <class 'NoneType'>: None
# key: lastMarket                         value: <class 'NoneType'>: None
# key: marketCap                          value: <class 'int'>     : 690772639744
#
#
# ========================================================================================================================
# Module: quoteType\index_dict========================================================================================================================
# key: exchange                           value: <class 'str'>     : NMS
# key: quoteType                          value: <class 'str'>     : EQUITY
# key: symbol                             value: <class 'str'>     : NVDA
# key: underlyingSymbol                   value: <class 'str'>     : NVDA
# key: shortName                          value: <class 'str'>     : NVIDIA Corporation
# key: longName                           value: <class 'str'>     : NVIDIA Corporation
# key: firstTradeDateEpochUtc             value: <class 'str'>     : 1999-01-22 06:30:00
# key: timeZoneFullName                   value: <class 'str'>     : America/New_York
# key: timeZoneShortName                  value: <class 'str'>     : EDT
# key: uuid                               value: <class 'str'>     : 7f5f6a07-b148-30f4-98a2-2caa3df2aed...
# key: messageBoardId                     value: <class 'str'>     : finmb_32307
# key: gmtOffSetMilliseconds              value: <class 'int'>     : -14400000
# key: maxAge                             value: <class 'int'>     : 1
#
#
# ========================================================================================================================
# Module: recommendationTrend\index_dict========================================================================================================================
# key: trend                              value: <class 'list'>    : [{'period': '0m', 'strongBuy': 7, '...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: secFilings\index_dict========================================================================================================================
# key: filings                            value: <class 'list'>    : [{'date': '2023-04-26', 'epochDate'...
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: sectorTrend\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: symbol                             value: <class 'NoneType'>: None
# key: estimates                          value: <class 'list'>    : []
#
#
# ========================================================================================================================
# Module: summaryDetail\index_dict========================================================================================================================
# key: maxAge                             value: <class 'int'>     : 1
# key: priceHint                          value: <class 'int'>     : 2
# key: previousClose                      value: <class 'float'>   : 278.02
# key: open                               value: <class 'float'>   : 276.51
# key: dayLow                             value: <class 'float'>   : 272.4
# key: dayHigh                            value: <class 'float'>   : 278.58
# key: regularMarketPreviousClose         value: <class 'float'>   : 278.02
# key: regularMarketOpen                  value: <class 'float'>   : 276.51
# key: regularMarketDayLow                value: <class 'float'>   : 272.4
# key: regularMarketDayHigh               value: <class 'float'>   : 278.58
# key: dividendRate                       value: <class 'float'>   : 0.16
# key: dividendYield                      value: <class 'float'>   : 0.00059999997
# key: exDividendDate                     value: <class 'str'>     : 2023-03-06 16:00:00
# key: payoutRatio                        value: <class 'float'>   : 0.092
# key: fiveYearAvgDividendYield           value: <class 'float'>   : 0.19
# key: beta                               value: <class 'float'>   : 1.769896
# key: trailingPE                         value: <class 'float'>   : 160.24419
# key: forwardPE                          value: <class 'float'>   : 45.557022
# key: volume                             value: <class 'int'>     : 32185041
# key: regularMarketVolume                value: <class 'int'>     : 32185041
# key: averageVolume                      value: <class 'int'>     : 46960116
# key: averageVolume10days                value: <class 'int'>     : 38156520
# key: averageDailyVolume10Day            value: <class 'int'>     : 38156520
# key: bid                                value: <class 'float'>   : 276.8
# key: ask                                value: <class 'float'>   : 276.87
# key: bidSize                            value: <class 'int'>     : 1100
# key: askSize                            value: <class 'int'>     : 1300
# key: marketCap                          value: <class 'int'>     : 690772639744
# key: fiftyTwoWeekLow                    value: <class 'float'>   : 108.13
# key: fiftyTwoWeekHigh                   value: <class 'float'>   : 290.58
# key: priceToSalesTrailing12Months       value: <class 'float'>   : 25.608833
# key: fiftyDayAverage                    value: <class 'float'>   : 259.8918
# key: twoHundredDayAverage               value: <class 'float'>   : 185.99225
# key: trailingAnnualDividendRate         value: <class 'float'>   : 0.16
# key: trailingAnnualDividendYield        value: <class 'float'>   : 0.00057549815
# key: currency                           value: <class 'str'>     : USD
# key: fromCurrency                       value: <class 'NoneType'>: None
# key: toCurrency                         value: <class 'NoneType'>: None
# key: lastMarket                         value: <class 'NoneType'>: None
# key: coinMarketCapLink                  value: <class 'NoneType'>: None
# key: algorithm                          value: <class 'NoneType'>: None
# key: tradeable                          value: <class 'bool'>    : False
#
#
# ========================================================================================================================
# Module: summaryProfile\index_dict========================================================================================================================
# key: address1                           value: <class 'str'>     : 2788 San Tomas Expressway
# key: city                               value: <class 'str'>     : Santa Clara
# key: state                              value: <class 'str'>     : CA
# key: zip                                value: <class 'str'>     : 95051
# key: country                            value: <class 'str'>     : United States
# key: phone                              value: <class 'str'>     : 408 486 2000
# key: website                            value: <class 'str'>     : https://www.nvidia.com
# key: industry                           value: <class 'str'>     : Semiconductors
# key: industryDisp                       value: <class 'str'>     : Semiconductors
# key: sector                             value: <class 'str'>     : Technology
# key: longBusinessSummary                value: <class 'str'>     : NVIDIA Corporation provides graphic...
# key: fullTimeEmployees                  value: <class 'int'>     : 26196
# key: companyOfficers                    value: <class 'list'>    : []
# key: maxAge                             value: <class 'int'>     : 86400
#
#
# ========================================================================================================================
# Module: upgradeDowngradeHistory\index_dict========================================================================================================================
# key: history                            value: <class 'list'>    : [{'epochGradeDate': '2023-04-25 05:...
# key: maxAge                             value: <class 'int'>     : 86400

# %%
from typing import Any
def func(dictionary: dict, *value_path, default: Any = None) -> Any:
  dct = dictionary
  # print(f'dictionary: {print_dict_key_value(dct)}\n')
  print_dict_key_value(dct)
  print('='*10)
  for arg in value_path:
    print(f'*args: {arg}')
  print('='*10)  
  print(f'default {type(default)}: {default}')
  print('='*10)  

  value_path = list(value_path)
  while value_path:
    print(f'dct before dct.get(args.pop(0): {dct}')
    print(f'args before dct.get(args.pop(0): {value_path}')
    try:
      dct = dct[value_path.pop(0)]      
      print(f'dct after dct.get(args.pop(0): {dct}')
      print(f'args after dct.get(args.pop(0): {value_path}\n')
    except AttributeError:
      print(f'\nERROR: AttributeError, return default: {default}\n')
      return default
    except KeyError:
      print(f'\nERROR: KeyError, return default: {default}\n')    
      return default

  return dct


_dct = {'a': {'b': {'c1': 'v_c1', 'c2': 'v_c2'}}}

# func_rtn = func(_dct, *['a', 'b', 'c3'])
# func_rtn = func(_dct, *['a', 'b', 'c3'], default=None)
func_rtn = func(_dct, *['a', 'b', 'c2'], default=0)
print(f'type(func_rtn): {type(func_rtn)}, func_rtn: {func_rtn}')
# Out:
# key: a                                  value: <class 'dict'>    : {'b': {'c1': 'v_c1', 'c2': 'v_c2'}}
# ==========
# *args: a
# *args: b
# *args: c2
# ==========
# default <class 'int'>: 0
# ==========
# dct before dct.get(args.pop(0): {'a': {'b': {'c1': 'v_c1', 'c2': 'v_c2'}}}
# args before dct.get(args.pop(0): ['a', 'b', 'c2']
# dct after dct.get(args.pop(0): {'b': {'c1': 'v_c1', 'c2': 'v_c2'}}
# args after dct.get(args.pop(0): ['b', 'c2']
#
# dct before dct.get(args.pop(0): {'b': {'c1': 'v_c1', 'c2': 'v_c2'}}
# args before dct.get(args.pop(0): ['b', 'c2']
# dct after dct.get(args.pop(0): {'c1': 'v_c1', 'c2': 'v_c2'}
# args after dct.get(args.pop(0): ['c2']
#
# dct before dct.get(args.pop(0): {'c1': 'v_c1', 'c2': 'v_c2'}
# args before dct.get(args.pop(0): ['c2']
# dct after dct.get(args.pop(0): v_c2
# args after dct.get(args.pop(0): []
#
# type(func_rtn): <class 'str'>, func_rtn: v_c2

# %%
# https://stackoverflow.com/questions/16003408/how-to-use-dict-get-with-multidimensional-dict
from typing import Any

# def chained_get(dictionary: dict, *args, default: Any = None) -> Any:
def chained_get(dictionary: dict, *args, default=None):    
    """
    Get a value nested in a dictionary by its nested path.
    First arg is an index to list of dictionaries, and must be zero or an integer.
    The four dictionaries are in reverse order. Index zero has the latest data.
    The remaining args are nested keys to dictionaries.
    """
    value_path = list(args)
    index_dict = value_path.pop(0)
    # first arg must be an integer, it's an index to list of dictionaries
    if index_dict is not int and index_dict != 0:  # first arg must be an interger
        raise RuntimeError(f'{index_dict} in *arg[0] must be zero or an integer')
    dict_chain = dictionary
    while value_path:  # iterate on arg in list
        try:

            # dict_chain = dict_chain.get(value_path.pop(0))  # pop drops the first arg in value_path, dict_chain also drops a level
            dict_chain = dict_chain[value_path.pop(0)]  # pop drops the first arg in value_path, dict_chain also drops a level            
            
            if isinstance(dict_chain, list):  # if dict_chain is a list, get the dictionaries in the list
                try:
                    dict_chain = dict_chain[index_dict]  # [0] is first dict in the list of dicts
                except IndexError:
                    msg_err = f"{index_dict} in *arg[0] is out of index range, list's last index is {len(dict_chain)-1}"
                    raise  RuntimeError(msg_err)                   
        # except AttributeError:
        #     return default
        except AttributeError:
            # print(f'\nERROR: AttributeError, return default: {default}\n')
            return default
        except KeyError:
            # print(f'\nERROR: KeyError, return default: {default}\n')    
            return default        


    return dict_chain

# %%
def get_NOPAT(dict, index_dict):
  """
  Get net operating profit after tax from yahoo query for a symbol.
  dict is nested dictionary from a query of all modules for a symbol.
  index_dict is the index for the nested dictionaries, where index_dict=0 is the latest statement.
  The maximum for index_dict is 3 since yahoo returns 4 of the most recent statements.
  """  
  key_chain_operInc = [index_dict, 'incomeStatementHistory', 'incomeStatementHistory', 'operatingIncome']
  # oper_inc = chained_get(d_sorted_modules, *key_chain_operInc)
  oper_inc = chained_get(dict, *key_chain_operInc, default=0)

  key_chain_incTaxExp = [index_dict, 'incomeStatementHistory', 'incomeStatementHistory', 'incomeTaxExpense']
  # inc_tax_exp = chained_get(d_sorted_modules, *key_chain_incTaxExp)
  inc_tax_exp = chained_get(dict, *key_chain_incTaxExp, default=0)

  key_chain_inc_stmt_endDate = [index_dict, 'incomeStatementHistory', 'incomeStatementHistory', 'endDate']
  # inc_stmt_end_date = chained_get(d_sorted_modules, *key_chain_inc_stmt_endDate)
  inc_stmt_end_date = chained_get(dict, *key_chain_inc_stmt_endDate, default=None)

  # https://www.investopedia.com/terms/index_dict/nopat.asp
  NOPAT = oper_inc - inc_tax_exp  # positive inc_tax_exp implies an expense, negative implies a tax credit   

  return NOPAT, oper_inc, inc_tax_exp, inc_stmt_end_date

# %%
def get_Invested_Capital(dict, index_dict):
  """
  Get net operating profit after tax from yahoo query for a symbol.
  dict is nested dictionary from a query of all modules for a symbol.
  index_dict is the index for the nested dictionaries, where index_dict=0 is the latest statement.
  The maximum for index_dict is 3 since yahoo returns 4 of the most recent statements.
  """  

  key_chain_bal_stmt_endDate = [index_dict, 'balanceSheetHistory', 'balanceSheetStatements', 'endDate']
  # bal_stmt_end_date = chained_get(d_sorted_modules, *key_chain_bal_stmt_endDate)
  bal_stmt_end_date = chained_get(dict, *key_chain_bal_stmt_endDate, default=None)

  key_chain_totalLiab = [index_dict, 'balanceSheetHistory', 'balanceSheetStatements', 'totalLiab']
  # totalLiab = chained_get(d_sorted_modules, *key_chain_totalLiab)
  totalLiab = chained_get(dict, *key_chain_totalLiab, default=0)  

  key_chain_totalStockholderEquity = [index_dict, 'balanceSheetHistory', 'balanceSheetStatements', 'totalStockholderEquity']
  # totalStockholderEquity = chained_get(d_sorted_modules, *key_chain_totalStockholderEquity)
  totalStockholderEquity = chained_get(dict, *key_chain_totalStockholderEquity, default=0)

  key_chain_cash = [index_dict, 'balanceSheetHistory', 'balanceSheetStatements', 'cash']
  # cash = chained_get(d_sorted_modules, *key_chain_cash)
  cash = chained_get(dict, *key_chain_cash, default=0)

  key_chain_shortTermInvestments = [index_dict, 'balanceSheetHistory', 'balanceSheetStatements', 'shortTermInvestments']
  # shortTermInvestments = chained_get(d_sorted_modules, *key_chain_shortTermInvestments)
  shortTermInvestments = chained_get(dict, *key_chain_shortTermInvestments, default=0)

  # https://seekingalpha.com/article/4486058-return-on-invested-capital
  Invested_Capital = totalLiab + totalStockholderEquity - (cash + shortTermInvestments)
  return Invested_Capital, totalLiab, totalStockholderEquity, cash, shortTermInvestments, bal_stmt_end_date

# %%
def get_ROIC(dict, index_dict):
  """
  Get Return-of-Invested-Capital for a symbol.
  dict is nested dictionary from a query of all modules for a symbol.
  index_dict is the index for the nested dictionaries, where index_dict=0 is the latest statement.
  The maximum for index_dict is 3 since yahoo returns 4 of the most recent statements.
  """    
  NOPAT, oper_inc, inc_tax_exp, inc_stmt_end_date = get_NOPAT(dict, index_dict)

  Invested_Capital, totalLiab, totalStockholderEquity, cash, shortTermInvestments, bal_stmt_end_date = \
  get_Invested_Capital(dict, index_dict)

  ROIC = NOPAT / Invested_Capital

  return ROIC, NOPAT, oper_inc, inc_tax_exp, inc_stmt_end_date, \
    Invested_Capital, totalLiab, totalStockholderEquity, cash, shortTermInvestments, bal_stmt_end_date

# %%
def get_symbol_modules(symbol):
  """
  Get a yahooquery of all modules for a symbol.
  """     
  from yahooquery import Ticker    
  yq_sym = Ticker(symbol).all_modules
  l_sym_modules = list(yq_sym.values())  # list with one nested-dict, keys are the modules 
  d_nested_modules = l_sym_modules[0]  # nested dict, keys are the modules
  d_sorted_modules = dict(sorted(d_nested_modules.items()))  # nested dict, sorted, keys are the modules
  return d_sorted_modules, symbol

# %%
my_sym = 'ELF'
# my_sym = 'NVDA'
d_sorted_modules, symbol = get_symbol_modules(my_sym)

# %%
my_sym = 'ELF'
d_sorted_modules, symbol = get_symbol_modules(my_sym)

ROIC, NOPAT, oper_inc, inc_tax_exp, inc_stmt_end_date, \
  Invested_Capital, totalLiab, totalStockholderEquity, cash, shortTermInvestments, bal_stmt_end_date = \
  get_ROIC(d_sorted_modules, 0)

print(f'{my_sym}')
print(f'{"Income Statement as of:":25}{inc_stmt_end_date:>16}')
print(f'{" operatingIncome:":<25}{oper_inc:>16,}')
print(f'{" incomeTaxExpense:":<25}{inc_tax_exp:>16,}')
print(f'{"    Net Oper. Prof. A.T.:":<25}{NOPAT:>16,}\n')

print(f'{"Balance Sheet as of:":25}{bal_stmt_end_date:>16}')
print(f'{"  totalLiab:":<25}{totalLiab:>16,}')
print(f'{"  totalStockholderEquity:":<25}{totalStockholderEquity:>16,}')
print(f'{"  cash:":<25}{-cash:>16,}')
print(f'{"  shortTermInvestments:":<25}{-shortTermInvestments:>16,}')
print(f'{"    Invested Capital:":<25}{Invested_Capital:>16,}\n')
print(f'{"ROIC (NOPAT/Inv-Cap):":<25}{ROIC:>16.6f}')
# Out:
# ELF
# Income Statement as of:        2022-03-31
#  operatingIncome:              29,820,000
#  incomeTaxExpense:              3,661,000
#     Net Oper. Prof. A.T.:      26,159,000
#
# Balance Sheet as of:           2022-03-31
#   totalLiab:                  182,203,000
#   totalStockholderEquity:     312,429,000
#   cash:                       -43,353,000
#   shortTermInvestments:                 0
#     Invested Capital:         451,279,000
#
# ROIC (NOPAT/Inv-Cap):            0.057966

# %%
my_sym = 'NVDA'
d_sorted_modules, symbol = get_symbol_modules(my_sym)

ROIC, NOPAT, oper_inc, inc_tax_exp, inc_stmt_end_date, \
  Invested_Capital, totalLiab, totalStockholderEquity, cash, shortTermInvestments, bal_stmt_end_date = \
  get_ROIC(d_sorted_modules, 0)

print(f'{my_sym}')
print(f'{"Income Statement as of:":25}{inc_stmt_end_date:>16}')
print(f'{" operatingIncome:":<25}{oper_inc:>16,}')
print(f'{" incomeTaxExpense:":<25}{inc_tax_exp:>16,}')
print(f'{"    Net Oper. Prof. A.T.:":<25}{NOPAT:>16,}\n')

print(f'{"Balance Sheet as of:":25}{bal_stmt_end_date:>16}')
print(f'{"  totalLiab:":<25}{totalLiab:>16,}')
print(f'{"  totalStockholderEquity:":<25}{totalStockholderEquity:>16,}')
print(f'{"  cash:":<25}{-cash:>16,}')
print(f'{"  shortTermInvestments:":<25}{-shortTermInvestments:>16,}')
print(f'{"    Invested Capital:":<25}{Invested_Capital:>16,}\n')
print(f'{"ROIC (NOPAT/Inv-Cap):":<25}{ROIC:>16.6f}')
# Out:
# NVDA
# Income Statement as of:        2023-01-29
#  operatingIncome:           5,577,000,000
#  incomeTaxExpense:           -187,000,000
#     Net Oper. Prof. A.T.:   5,764,000,000
#
# Balance Sheet as of:           2023-01-29
#   totalLiab:               19,081,000,000
#   totalStockholderEquity:  22,101,000,000
#   cash:                    -3,389,000,000
#   shortTermInvestments:    -9,907,000,000
#     Invested Capital:      27,886,000,000
#
# ROIC (NOPAT/Inv-Cap):            0.206699

# %%
d_sorted_modules
# Out:
# {'assetProfile': {'address1': '2788 San Tomas Expressway',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'zip': '95051',
#   'country': 'United States',
#   'phone': '408 486 2000',
#   'website': 'https://www.nvidia.com',
#   'industry': 'Semiconductors',
#   'industryDisp': 'Semiconductors',
#   'sector': 'Technology',
#   'longBusinessSummary': "NVIDIA Corporation provides graphics, and compute and networking solutions in the United States, Taiwan, China, and internationally. The company's Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building 3D designs and virtual worlds. Its Compute & Networking segment provides Data Center platforms and systems for AI, HPC, and accelerated computing; Mellanox networking and interconnect solutions; automotive AI Cockpit, autonomous driving development agreements, and autonomous vehicle solutions; cryptocurrency mining processors; Jetson for robotics and other embedded platforms; and NVIDIA AI Enterprise and other software. The company's products are used in gaming, professional visualization, datacenter, and automotive markets. NVIDIA Corporation sells its products to original equipment manufacturers, original device manufacturers, system builders, add-in board manufacturers, retailers/distributors, independent software vendors, Internet and cloud service providers, automotive manufacturers and tier-1 automotive suppliers, mapping companies, start-ups, and other ecosystem participants. It has a strategic collaboration with Kroger Co. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.",
#   'fullTimeEmployees': 26196,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. Jen-Hsun  Huang',
#     'age': 59,
#     'title': 'Co-Founder, CEO, Pres & Director',
#     'yearBorn': 1963,
#     'fiscalYear': 2022,
#     'totalPay': 5077254,
#     'exercisedValue': 506809472,
#     'unexercisedValue': 762842816},
#    {'maxAge': 1,
#     'name': 'Ms. Colette M. Kress',
#     'age': 55,
#     'title': 'Exec. VP & CFO',
#     'yearBorn': 1967,
#     'fiscalYear': 2022,
#     'totalPay': 1506907,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Debora  Shoquist',
#     'age': 67,
#     'title': 'Exec. VP of Operations',
#     'yearBorn': 1955,
#     'fiscalYear': 2022,
#     'totalPay': 1368262,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Timothy S. Teter',
#     'age': 55,
#     'title': 'Exec. VP, Gen. Counsel & Sec.',
#     'yearBorn': 1967,
#     'fiscalYear': 2022,
#     'totalPay': 1359186,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Ajay K. Puri',
#     'age': 67,
#     'title': 'Exec. VP of Worldwide Field Operations',
#     'yearBorn': 1955,
#     'fiscalYear': 2022,
#     'totalPay': 2279899,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Chris A. Malachowsky',
#     'title': 'Co-Founder',
#     'fiscalYear': 2002,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Donald F. Robertson Jr.',
#     'age': 53,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Prof. William J. Dally',
#     'age': 61,
#     'title': 'Chief Scientist & Sr. VP of Research',
#     'yearBorn': 1961,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Simona  Jankowski C.F.A., J.D.',
#     'title': 'VP of Investor Relations',
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Robert  Sherbin',
#     'age': 63,
#     'title': 'VP of Corp. Communications',
#     'yearBorn': 1959,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 5,
#   'boardRisk': 9,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 8,
#   'overallRisk': 7,
#   'governanceEpochDate': '2023-04-30 17:00:00',
#   'compensationAsOfEpochDate': '2022-12-30 16:00:00',
#   'maxAge': 86400},
#  'balanceSheetHistory': {'balanceSheetStatements': [{'maxAge': 1,
#     'endDate': '2023-01-29',
#     'cash': 3389000000,
#     'shortTermInvestments': 9907000000,
#     'netReceivables': 3827000000,
#     'inventory': 5159000000,
#     'totalCurrentAssets': 23073000000,
#     'longTermInvestments': 299000000,
#     'propertyPlantEquipment': 4845000000,
#     'goodWill': 4372000000,
#     'intangibleAssets': 1676000000,
#     'otherAssets': 6917000000,
#     'deferredLongTermAssetCharges': 3396000000,
#     'totalAssets': 41182000000,
#     'accountsPayable': 1193000000,
#     'shortLongTermDebt': 1250000000,
#     'otherCurrentLiab': 3414000000,
#     'longTermDebt': 9703000000,
#     'otherLiab': 1913000000,
#     'totalCurrentLiabilities': 6563000000,
#     'totalLiab': 19081000000,
#     'commonStock': 2000000,
#     'retainedEarnings': 10171000000,
#     'treasuryStock': -43000000,
#     'capitalSurplus': 11971000000,
#     'otherStockholderEquity': -43000000,
#     'totalStockholderEquity': 22101000000,
#     'netTangibleAssets': 16053000000},
#    {'maxAge': 1,
#     'endDate': '2022-01-30',
#     'cash': 1990000000,
#     'shortTermInvestments': 19218000000,
#     'netReceivables': 4650000000,
#     'inventory': 2605000000,
#     'totalCurrentAssets': 28829000000,
#     'longTermInvestments': 266000000,
#     'propertyPlantEquipment': 3607000000,
#     'goodWill': 4349000000,
#     'intangibleAssets': 2339000000,
#     'otherAssets': 4797000000,
#     'deferredLongTermAssetCharges': 1222000000,
#     'totalAssets': 44187000000,
#     'accountsPayable': 1783000000,
#     'otherCurrentLiab': 1999000000,
#     'longTermDebt': 10946000000,
#     'otherLiab': 1553000000,
#     'totalCurrentLiabilities': 4335000000,
#     'totalLiab': 17575000000,
#     'commonStock': 3000000,
#     'retainedEarnings': 16235000000,
#     'treasuryStock': -11000000,
#     'capitalSurplus': 10385000000,
#     'otherStockholderEquity': -11000000,
#     'totalStockholderEquity': 26612000000,
#     'netTangibleAssets': 19924000000},
#    {'maxAge': 1,
#     'endDate': '2021-01-31',
#     'cash': 847000000,
#     'shortTermInvestments': 10714000000,
#     'netReceivables': 2429000000,
#     'inventory': 1826000000,
#     'totalCurrentAssets': 16055000000,
#     'longTermInvestments': 144000000,
#     'propertyPlantEquipment': 2856000000,
#     'goodWill': 4193000000,
#     'intangibleAssets': 2737000000,
#     'otherAssets': 2806000000,
#     'deferredLongTermAssetCharges': 806000000,
#     'totalAssets': 28791000000,
#     'accountsPayable': 1149000000,
#     'shortLongTermDebt': 999000000,
#     'otherCurrentLiab': 1480000000,
#     'longTermDebt': 5964000000,
#     'otherLiab': 1375000000,
#     'totalCurrentLiabilities': 3925000000,
#     'totalLiab': 11898000000,
#     'commonStock': 3000000,
#     'retainedEarnings': 18908000000,
#     'treasuryStock': -10737000000,
#     'capitalSurplus': 8719000000,
#     'otherStockholderEquity': 19000000,
#     'totalStockholderEquity': 16893000000,
#     'netTangibleAssets': 9963000000},
#    {'maxAge': 1,
#     'endDate': '2020-01-26',
#     'cash': 10896000000,
#     'shortTermInvestments': 1000000,
#     'netReceivables': 1657000000,
#     'inventory': 979000000,
#     'totalCurrentAssets': 13690000000,
#     'longTermInvestments': 77000000,
#     'propertyPlantEquipment': 2292000000,
#     'goodWill': 618000000,
#     'intangibleAssets': 49000000,
#     'otherAssets': 589000000,
#     'deferredLongTermAssetCharges': 548000000,
#     'totalAssets': 17315000000,
#     'accountsPayable': 687000000,
#     'otherCurrentLiab': 783000000,
#     'longTermDebt': 1991000000,
#     'otherLiab': 775000000,
#     'totalCurrentLiabilities': 1784000000,
#     'totalLiab': 5111000000,
#     'commonStock': 1000000,
#     'retainedEarnings': 14971000000,
#     'treasuryStock': -9813000000,
#     'capitalSurplus': 7045000000,
#     'otherStockholderEquity': 1000000,
#     'totalStockholderEquity': 12204000000,
#     'netTangibleAssets': 11537000000}],
#   'maxAge': 86400},
#  'balanceSheetHistoryQuarterly': {'balanceSheetStatements': [{'maxAge': 1,
#     'endDate': '2023-01-29',
#     'cash': 3389000000,
#     'shortTermInvestments': 9907000000,
#     'netReceivables': 3827000000,
#     'inventory': 5159000000,
#     'totalCurrentAssets': 23073000000,
#     'longTermInvestments': 299000000,
#     'propertyPlantEquipment': 4845000000,
#     'goodWill': 4372000000,
#     'intangibleAssets': 1676000000,
#     'otherAssets': 6917000000,
#     'deferredLongTermAssetCharges': 3396000000,
#     'totalAssets': 41182000000,
#     'accountsPayable': 1193000000,
#     'shortLongTermDebt': 1250000000,
#     'otherCurrentLiab': 3414000000,
#     'longTermDebt': 9703000000,
#     'otherLiab': 1913000000,
#     'totalCurrentLiabilities': 6563000000,
#     'totalLiab': 19081000000,
#     'commonStock': 2000000,
#     'retainedEarnings': 10171000000,
#     'treasuryStock': -43000000,
#     'capitalSurplus': 11971000000,
#     'otherStockholderEquity': -43000000,
#     'totalStockholderEquity': 22101000000,
#     'netTangibleAssets': 16053000000},
#    {'maxAge': 1,
#     'endDate': '2022-10-30',
#     'cash': 2800000000,
#     'shortTermInvestments': 10343000000,
#     'netReceivables': 4908000000,
#     'inventory': 4454000000,
#     'totalCurrentAssets': 23223000000,
#     'longTermInvestments': 314000000,
#     'propertyPlantEquipment': 4701000000,
#     'goodWill': 4372000000,
#     'intangibleAssets': 1850000000,
#     'otherAssets': 6028000000,
#     'deferredLongTermAssetCharges': 2762000000,
#     'totalAssets': 40488000000,
#     'accountsPayable': 1491000000,
#     'shortLongTermDebt': 1249000000,
#     'otherCurrentLiab': 3652000000,
#     'longTermDebt': 9701000000,
#     'otherLiab': 1785000000,
#     'totalCurrentLiabilities': 6855000000,
#     'totalLiab': 19139000000,
#     'commonStock': 2000000,
#     'retainedEarnings': 9905000000,
#     'treasuryStock': -123000000,
#     'capitalSurplus': 11565000000,
#     'otherStockholderEquity': -123000000,
#     'totalStockholderEquity': 21349000000,
#     'netTangibleAssets': 15127000000},
#    {'maxAge': 1,
#     'endDate': '2022-07-31',
#     'cash': 3013000000,
#     'shortTermInvestments': 14024000000,
#     'netReceivables': 5317000000,
#     'inventory': 3889000000,
#     'totalCurrentAssets': 27418000000,
#     'longTermInvestments': 307000000,
#     'propertyPlantEquipment': 4085000000,
#     'goodWill': 4372000000,
#     'intangibleAssets': 2036000000,
#     'otherAssets': 5258000000,
#     'deferredLongTermAssetCharges': 2225000000,
#     'totalAssets': 43476000000,
#     'accountsPayable': 2421000000,
#     'shortLongTermDebt': 1249000000,
#     'otherCurrentLiab': 3337000000,
#     'longTermDebt': 9700000000,
#     'otherLiab': 1609000000,
#     'totalCurrentLiabilities': 7573000000,
#     'totalLiab': 19625000000,
#     'commonStock': 2000000,
#     'retainedEarnings': 12971000000,
#     'treasuryStock': -90000000,
#     'capitalSurplus': 10968000000,
#     'otherStockholderEquity': -90000000,
#     'totalStockholderEquity': 23851000000,
#     'netTangibleAssets': 17443000000},
#    {'maxAge': 1,
#     'endDate': '2022-05-01',
#     'cash': 3887000000,
#     'shortTermInvestments': 16451000000,
#     'netReceivables': 5438000000,
#     'inventory': 3163000000,
#     'totalCurrentAssets': 29575000000,
#     'longTermInvestments': 285000000,
#     'propertyPlantEquipment': 3772000000,
#     'goodWill': 4365000000,
#     'intangibleAssets': 2211000000,
#     'otherAssets': 5004000000,
#     'deferredLongTermAssetCharges': 1784000000,
#     'totalAssets': 45212000000,
#     'accountsPayable': 1999000000,
#     'otherCurrentLiab': 3089000000,
#     'longTermDebt': 10947000000,
#     'otherLiab': 1631000000,
#     'totalCurrentLiabilities': 5562000000,
#     'totalLiab': 18892000000,
#     'commonStock': 3000000,
#     'retainedEarnings': 15758000000,
#     'treasuryStock': -64000000,
#     'capitalSurplus': 10623000000,
#     'otherStockholderEquity': -64000000,
#     'totalStockholderEquity': 26320000000,
#     'netTangibleAssets': 19744000000}],
#   'maxAge': 86400},
#  'calendarEvents': {'maxAge': 1,
#   'earnings': {'earningsDate': ['2023-05-24 14:00:S'],
#    'earningsAverage': 0.91,
#    'earningsLow': 0.81,
#    'earningsHigh': 0.95,
#    'revenueAverage': 6505830000,
#    'revenueLow': 6475080000,
#    'revenueHigh': 6598000000},
#   'exDividendDate': '2023-03-06 16:00:00',
#   'dividendDate': '2023-03-28 17:00:00'},
#  'cashflowStatementHistory': {'cashflowStatements': [{'maxAge': 1,
#     'endDate': '2023-01-29',
#     'netIncome': 4368000000,
#     'depreciation': 1544000000,
#     'changeToNetincome': 1936000000,
#     'changeToAccountReceivables': 822000000,
#     'changeToLiabilities': -551000000,
#     'changeToInventory': -2554000000,
#     'changeToOperatingActivities': 76000000,
#     'totalCashFromOperatingActivities': 5641000000,
#     'capitalExpenditures': -1833000000,
#     'investments': 9257000000,
#     'totalCashflowsFromInvestingActivities': 7375000000,
#     'dividendsPaid': -398000000,
#     'otherCashflowsFromFinancingActivities': -60000000,
#     'totalCashFromFinancingActivities': -11617000000,
#     'changeInCash': 1399000000,
#     'repurchaseOfStock': -11514000000,
#     'issuanceOfStock': 355000000},
#    {'maxAge': 1,
#     'endDate': '2022-01-30',
#     'netIncome': 9752000000,
#     'depreciation': 1174000000,
#     'changeToNetincome': 1545000000,
#     'changeToAccountReceivables': -2215000000,
#     'changeToLiabilities': 568000000,
#     'changeToInventory': -774000000,
#     'changeToOperatingActivities': -942000000,
#     'totalCashFromOperatingActivities': 9108000000,
#     'capitalExpenditures': -976000000,
#     'investments': -8591000000,
#     'totalCashflowsFromInvestingActivities': -9830000000,
#     'dividendsPaid': -399000000,
#     'netBorrowings': 3977000000,
#     'otherCashflowsFromFinancingActivities': -90000000,
#     'totalCashFromFinancingActivities': 1865000000,
#     'changeInCash': 1143000000,
#     'repurchaseOfStock': -1904000000,
#     'issuanceOfStock': 281000000},
#    {'maxAge': 1,
#     'endDate': '2021-01-31',
#     'netIncome': 4332000000,
#     'depreciation': 1098000000,
#     'changeToNetincome': 1095000000,
#     'changeToAccountReceivables': -550000000,
#     'changeToLiabilities': 312000000,
#     'changeToInventory': -524000000,
#     'changeToOperatingActivities': 59000000,
#     'totalCashFromOperatingActivities': 5822000000,
#     'capitalExpenditures': -1128000000,
#     'investments': -10023000000,
#     'totalCashflowsFromInvestingActivities': -19675000000,
#     'dividendsPaid': -395000000,
#     'netBorrowings': 4968000000,
#     'otherCashflowsFromFinancingActivities': -21000000,
#     'totalCashFromFinancingActivities': 3804000000,
#     'changeInCash': -10049000000,
#     'repurchaseOfStock': -942000000,
#     'issuanceOfStock': 194000000},
#    {'maxAge': 1,
#     'endDate': '2020-01-26',
#     'netIncome': 2796000000,
#     'depreciation': 381000000,
#     'changeToNetincome': 867000000,
#     'changeToAccountReceivables': -233000000,
#     'changeToLiabilities': 194000000,
#     'changeToInventory': 597000000,
#     'changeToOperatingActivities': 159000000,
#     'totalCashFromOperatingActivities': 4761000000,
#     'capitalExpenditures': -489000000,
#     'investments': 6638000000,
#     'totalCashflowsFromInvestingActivities': 6145000000,
#     'dividendsPaid': -390000000,
#     'netBorrowings': 4968000000,
#     'otherCashflowsFromFinancingActivities': -21000000,
#     'totalCashFromFinancingActivities': -792000000,
#     'changeInCash': 10114000000,
#     'repurchaseOfStock': -551000000,
#     'issuanceOfStock': 149000000}],
#   'maxAge': 86400},
#  'cashflowStatementHistoryQuarterly': {'cashflowStatements': [{'maxAge': 1,
#     'endDate': '2023-01-29',
#     'netIncome': 1414000000,
#     'depreciation': 426000000,
#     'changeToNetincome': 121000000,
#     'changeToAccountReceivables': 1080000000,
#     'changeToLiabilities': -193000000,
#     'changeToInventory': -706000000,
#     'changeToOperatingActivities': 106000000,
#     'totalCashFromOperatingActivities': 2248000000,
#     'capitalExpenditures': -509000000,
#     'investments': 506000000,
#     'totalCashflowsFromInvestingActivities': -3000000,
#     'dividendsPaid': -98000000,
#     'otherCashflowsFromFinancingActivities': -7000000,
#     'totalCashFromFinancingActivities': -1656000000,
#     'changeInCash': 589000000,
#     'repurchaseOfStock': -1557000000,
#     'issuanceOfStock': 6000000},
#    {'maxAge': 1,
#     'endDate': '2022-10-30',
#     'netIncome': 680000000,
#     'depreciation': 406000000,
#     'changeToNetincome': 179000000,
#     'changeToAccountReceivables': 410000000,
#     'changeToLiabilities': -917000000,
#     'changeToInventory': -563000000,
#     'changeToOperatingActivities': 197000000,
#     'totalCashFromOperatingActivities': 392000000,
#     'capitalExpenditures': -530000000,
#     'investments': 3678000000,
#     'totalCashflowsFromInvestingActivities': 3148000000,
#     'dividendsPaid': -100000000,
#     'otherCashflowsFromFinancingActivities': -18000000,
#     'totalCashFromFinancingActivities': -3753000000,
#     'changeInCash': -213000000,
#     'repurchaseOfStock': -3779000000,
#     'issuanceOfStock': 144000000},
#    {'maxAge': 1,
#     'endDate': '2022-07-31',
#     'netIncome': 656000000,
#     'depreciation': 378000000,
#     'changeToNetincome': 207000000,
#     'changeToAccountReceivables': 120000000,
#     'changeToLiabilities': 304000000,
#     'changeToInventory': -725000000,
#     'changeToOperatingActivities': 330000000,
#     'totalCashFromOperatingActivities': 1270000000,
#     'capitalExpenditures': -433000000,
#     'investments': 2064000000,
#     'totalCashflowsFromInvestingActivities': 1618000000,
#     'dividendsPaid': -100000000,
#     'otherCashflowsFromFinancingActivities': -13000000,
#     'totalCashFromFinancingActivities': -3762000000,
#     'changeInCash': -874000000,
#     'repurchaseOfStock': -3650000000,
#     'issuanceOfStock': 1000000},
#    {'maxAge': 1,
#     'endDate': '2022-05-01',
#     'netIncome': 1618000000,
#     'depreciation': 334000000,
#     'changeToNetincome': 1429000000,
#     'changeToAccountReceivables': -788000000,
#     'changeToLiabilities': 255000000,
#     'changeToInventory': -560000000,
#     'changeToOperatingActivities': -557000000,
#     'totalCashFromOperatingActivities': 1731000000,
#     'capitalExpenditures': -361000000,
#     'investments': 3009000000,
#     'totalCashflowsFromInvestingActivities': 2612000000,
#     'dividendsPaid': -100000000,
#     'otherCashflowsFromFinancingActivities': -22000000,
#     'totalCashFromFinancingActivities': -2446000000,
#     'changeInCash': 1897000000,
#     'repurchaseOfStock': -2528000000,
#     'issuanceOfStock': 204000000}],
#   'maxAge': 86400},
#  'defaultKeyStatistics': {'maxAge': 1,
#   'priceHint': 2,
#   'enterpriseValue': 685444431872,
#   'forwardPE': 45.557022,
#   'profitMargins': 0.16193001,
#   'floatShares': 2370137900,
#   'sharesOutstanding': 2470000128,
#   'sharesShort': 33783023,
#   'sharesShortPriorMonth': 37702262,
#   'sharesShortPreviousMonthDate': '2023-03-14 17:00:00',
#   'dateShortInterest': '2023-04-13 17:00:00',
#   'sharesPercentSharesOut': 0.0137,
#   'heldPercentInsiders': 0.041810002,
#   'heldPercentInstitutions': 0.68084,
#   'shortRatio': 0.72,
#   'shortPercentOfFloat': 0.014199999,
#   'beta': 1.769896,
#   'impliedSharesOutstanding': 2470000128,
#   'category': None,
#   'bookValue': 8.962,
#   'priceToBook': 30.754295,
#   'fundFamily': None,
#   'legalType': None,
#   'lastFiscalYearEnd': '2023-01-28 16:00:00',
#   'nextFiscalYearEnd': '2024-01-28 16:00:00',
#   'mostRecentQuarter': '2023-01-28 16:00:00',
#   'earningsQuarterlyGrowth': -0.529,
#   'netIncomeToCommon': 4368000000,
#   'trailingEps': 1.72,
#   'forwardEps': 6.05,
#   'pegRatio': 2.89,
#   'lastSplitFactor': '4:1',
#   'lastSplitDate': '2021-07-19 17:00:00',
#   'enterpriseToRevenue': 25.411,
#   'enterpriseToEbitda': 96.257,
#   '52WeekChange': 0.4758768,
#   'SandP52WeekChange': -0.015065432,
#   'lastDividendValue': 0.04,
#   'lastDividendDate': 1678147200},
#  'earnings': {'maxAge': 86400,
#   'earningsChart': {'quarterly': [{'date': '2Q2022',
#      'actual': 1.36,
#      'estimate': 1.29},
#     {'date': '3Q2022', 'actual': 0.51, 'estimate': 1.25},
#     {'date': '4Q2022', 'actual': 0.58, 'estimate': 0.69},
#     {'date': '1Q2023', 'actual': 0.88, 'estimate': 0.81}],
#    'currentQuarterEstimate': 0.91,
#    'currentQuarterEstimateDate': '2Q',
#    'currentQuarterEstimateYear': 2023,
#    'earningsDate': ['2023-05-24 14:00:S']},
#   'financialsChart': {'yearly': [{'date': 2020,
#      'revenue': 10918000000,
#      'earnings': 2796000000},
#     {'date': 2021, 'revenue': 16675000000, 'earnings': 4332000000},
#     {'date': 2022, 'revenue': 26914000000, 'earnings': 9752000000},
#     {'date': 2023, 'revenue': 26974000000, 'earnings': 4368000000}],
#    'quarterly': [{'date': '2Q2022',
#      'revenue': 8288000000,
#      'earnings': 1618000000},
#     {'date': '3Q2022', 'revenue': 6704000000, 'earnings': 656000000},
#     {'date': '4Q2022', 'revenue': 5931000000, 'earnings': 680000000},
#     {'date': '1Q2023', 'revenue': 6051000000, 'earnings': 1414000000}]},
#   'financialCurrency': 'USD'},
#  'earningsHistory': {'history': [{'maxAge': 1,
#     'epsActual': 1.36,
#     'epsEstimate': 1.29,
#     'epsDifference': 0.07,
#     'surprisePercent': 0.054,
#     'quarter': '2022-04-30',
#     'period': '-4q'},
#    {'maxAge': 1,
#     'epsActual': 0.51,
#     'epsEstimate': 1.25,
#     'epsDifference': -0.74,
#     'surprisePercent': -0.592,
#     'quarter': '2022-07-31',
#     'period': '-3q'},
#    {'maxAge': 1,
#     'epsActual': 0.58,
#     'epsEstimate': 0.69,
#     'epsDifference': -0.11,
#     'surprisePercent': -0.159,
#     'quarter': '2022-10-31',
#     'period': '-2q'},
#    {'maxAge': 1,
#     'epsActual': 0.88,
#     'epsEstimate': 0.81,
#     'epsDifference': 0.07,
#     'surprisePercent': 0.086,
#     'quarter': '2023-01-31',
#     'period': '-1q'}],
#   'maxAge': 86400},
#  'earningsTrend': {'trend': [{'maxAge': 1,
#     'period': '0q',
#     'endDate': '2023-04-30',
#     'growth': -0.33099997,
#     'earningsEstimate': {'avg': 0.91,
#      'low': 0.81,
#      'high': 0.95,
#      'yearAgoEps': 1.36,
#      'numberOfAnalysts': 31,
#      'growth': -0.33099997},
#     'revenueEstimate': {'avg': 6505830000,
#      'low': 6475080000,
#      'high': 6598000000,
#      'numberOfAnalysts': 31,
#      'yearAgoRevenue': 8288000000,
#      'growth': -0.215},
#     'epsTrend': {'current': 0.91,
#      '7daysAgo': 0.91,
#      '30daysAgo': 0.91,
#      '60daysAgo': 0.91,
#      '90daysAgo': 0.86},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 3,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+1q',
#     'endDate': '2023-07-31',
#     'growth': 1.059,
#     'earningsEstimate': {'avg': 1.05,
#      'low': 0.89,
#      'high': 1.22,
#      'yearAgoEps': 0.51,
#      'numberOfAnalysts': 31,
#      'growth': 1.059},
#     'revenueEstimate': {'avg': 7100110000,
#      'low': 6775000000,
#      'high': 7797000000,
#      'numberOfAnalysts': 30,
#      'yearAgoRevenue': 6704000000,
#      'growth': 0.059},
#     'epsTrend': {'current': 1.05,
#      '7daysAgo': 1.05,
#      '30daysAgo': 1.05,
#      '60daysAgo': 1.05,
#      '90daysAgo': 1.01},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 3,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '0y',
#     'endDate': '2024-01-31',
#     'growth': 0.35599998,
#     'earningsEstimate': {'avg': 4.53,
#      'low': 3.98,
#      'high': 5.18,
#      'yearAgoEps': 3.34,
#      'numberOfAnalysts': 38,
#      'growth': 0.35599998},
#     'revenueEstimate': {'avg': 30071400000,
#      'low': 28035000000,
#      'high': 35819000000,
#      'numberOfAnalysts': 43,
#      'yearAgoRevenue': 26974000000,
#      'growth': 0.115},
#     'epsTrend': {'current': 4.53,
#      '7daysAgo': 4.53,
#      '30daysAgo': 4.5,
#      '60daysAgo': 4.46,
#      '90daysAgo': 4.29},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 5,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+1y',
#     'endDate': '2025-01-31',
#     'growth': 0.336,
#     'earningsEstimate': {'avg': 6.05,
#      'low': 5.25,
#      'high': 8.0,
#      'yearAgoEps': 4.53,
#      'numberOfAnalysts': 37,
#      'growth': 0.336},
#     'revenueEstimate': {'avg': 37415200000,
#      'low': 33506000000,
#      'high': 45617000000,
#      'numberOfAnalysts': 40,
#      'yearAgoRevenue': 30071400000,
#      'growth': 0.244},
#     'epsTrend': {'current': 6.05,
#      '7daysAgo': 6.05,
#      '30daysAgo': 6.01,
#      '60daysAgo': 5.87,
#      '90daysAgo': 5.6},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 4,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+5y',
#     'endDate': None,
#     'growth': 0.21200001,
#     'earningsEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'yearAgoEps': {},
#      'numberOfAnalysts': {},
#      'growth': {}},
#     'revenueEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'numberOfAnalysts': {},
#      'yearAgoRevenue': {},
#      'growth': {}},
#     'epsTrend': {'current': {},
#      '7daysAgo': {},
#      '30daysAgo': {},
#      '60daysAgo': {},
#      '90daysAgo': {}},
#     'epsRevisions': {'upLast7days': {},
#      'upLast30days': {},
#      'downLast30days': {},
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '-5y',
#     'endDate': None,
#     'growth': 0.25942,
#     'earningsEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'yearAgoEps': {},
#      'numberOfAnalysts': {},
#      'growth': {}},
#     'revenueEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'numberOfAnalysts': {},
#      'yearAgoRevenue': {},
#      'growth': {}},
#     'epsTrend': {'current': {},
#      '7daysAgo': {},
#      '30daysAgo': {},
#      '60daysAgo': {},
#      '90daysAgo': {}},
#     'epsRevisions': {'upLast7days': {},
#      'upLast30days': {},
#      'downLast30days': {},
#      'downLast90days': {}}}],
#   'maxAge': 1},
#  'esgScores': {'maxAge': 86400,
#   'totalEsg': 13.45,
#   'environmentScore': 2.26,
#   'socialScore': 5.16,
#   'governanceScore': 6.03,
#   'ratingYear': 2022,
#   'ratingMonth': 8,
#   'highestControversy': 2.0,
#   'peerCount': 28,
#   'esgPerformance': 'UNDER_PERF',
#   'peerGroup': 'Semiconductors',
#   'relatedControversy': ['Customer Incidents'],
#   'peerEsgScorePerformance': {'min': 10.91,
#    'avg': 20.402857142857137,
#    'max': 31.38},
#   'peerGovernancePerformance': {'min': 4.64,
#    'avg': 6.306666666666666,
#    'max': 9.67},
#   'peerSocialPerformance': {'min': 2.59,
#    'avg': 5.937407407407408,
#    'max': 8.93},
#   'peerEnvironmentPerformance': {'min': 2.26,
#    'avg': 7.7518518518518515,
#    'max': 14.83},
#   'peerHighestControversyPerformance': {'min': 0.0,
#    'avg': 1.1428571428571428,
#    'max': 4.0},
#   'percentile': 7.14,
#   'environmentPercentile': None,
#   'socialPercentile': None,
#   'governancePercentile': None,
#   'adult': False,
#   'alcoholic': False,
#   'animalTesting': False,
#   'catholic': False,
#   'controversialWeapons': False,
#   'smallArms': False,
#   'furLeather': False,
#   'gambling': False,
#   'gmo': False,
#   'militaryContract': False,
#   'nuclear': False,
#   'pesticides': False,
#   'palmOil': False,
#   'coal': False,
#   'tobacco': False},
#  'financialData': {'maxAge': 86400,
#   'currentPrice': 275.62,
#   'targetHighPrice': 394.0,
#   'targetLowPrice': 190.0,
#   'targetMeanPrice': 288.05,
#   'targetMedianPrice': 300.0,
#   'recommendationMean': 2.0,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 40,
#   'totalCash': 13296000000,
#   'totalCashPerShare': 5.383,
#   'ebitda': 7120999936,
#   'totalDebt': 12030999552,
#   'quickRatio': 2.609,
#   'currentRatio': 3.516,
#   'totalRevenue': 26973999104,
#   'debtToEquity': 54.436,
#   'revenuePerShare': 10.846,
#   'returnOnAssets': 0.08166,
#   'returnOnEquity': 0.17934,
#   'grossProfits': 15356000000,
#   'freeCashflow': 4532874752,
#   'operatingCashflow': 5640999936,
#   'earningsGrowth': -0.514,
#   'revenueGrowth': -0.208,
#   'grossMargins': 0.56929,
#   'ebitdaMargins': 0.26399,
#   'operatingMargins': 0.20674999,
#   'profitMargins': 0.16193001,
#   'financialCurrency': 'USD'},
#  'fundOwnership': {'maxAge': 1,
#   'ownershipList': [{'maxAge': 1,
#     'reportDate': '2022-12-31',
#     'organization': 'Vanguard Total Stock Market Index Fund',
#     'pctHeld': 0.028800001,
#     'position': 71042851,
#     'value': 19580830245,
#     'pctChange': 0.0027},
#    {'maxAge': 1,
#     'reportDate': '2022-12-31',
#     'organization': 'Vanguard 500 Index Fund',
#     'pctHeld': 0.0233,
#     'position': 57561849,
#     'value': 15865196540,
#     'pctChange': 0.014099999},
#    {'maxAge': 1,
#     'reportDate': '2023-03-31',
#     'organization': 'Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF',
#     'pctHeld': 0.013099999,
#     'position': 32476181,
#     'value': 8951084848,
#     'pctChange': 21.7174},
#    {'maxAge': 1,
#     'reportDate': '2023-02-28',
#     'organization': 'Fidelity 500 Index Fund',
#     'pctHeld': 0.0111,
#     'position': 27296769,
#     'value': 7523535338,
#     'pctChange': 0.0018000001},
#    {'maxAge': 1,
#     'reportDate': '2023-03-31',
#     'organization': 'SPDR S&P 500 ETF Trust',
#     'pctHeld': 0.0108,
#     'position': 26633530,
#     'value': 7340733408,
#     'pctChange': -0.0108},
#    {'maxAge': 1,
#     'reportDate': '2023-02-28',
#     'organization': 'iShares Core S&P 500 ETF',
#     'pctHeld': 0.009,
#     'position': 22223701,
#     'value': 6125296361,
#     'pctChange': -0.0068},
#    {'maxAge': 1,
#     'reportDate': '2022-12-31',
#     'organization': 'Vanguard Growth Index Fund',
#     'pctHeld': 0.008,
#     'position': 19725595,
#     'value': 5436768397,
#     'pctChange': 0.0084},
#    {'maxAge': 1,
#     'reportDate': '2023-02-28',
#     'organization': 'Fidelity Growth Company Fund',
#     'pctHeld': 0.0074,
#     'position': 18198629,
#     'value': 5015906036,
#     'pctChange': -0.013300001},
#    {'maxAge': 1,
#     'reportDate': '2022-12-31',
#     'organization': 'Vanguard Institutional Index Fund-Institutional Index Fund',
#     'pctHeld': 0.0070999996,
#     'position': 17448895,
#     'value': 4809264354,
#     'pctChange': -0.0403},
#    {'maxAge': 1,
#     'reportDate': '2022-11-30',
#     'organization': 'Vanguard Information Technology Index Fund',
#     'pctHeld': 0.0049,
#     'position': 12008389,
#     'value': 3309752117,
#     'pctChange': -0.0198}]},
#  'incomeStatementHistory': {'incomeStatementHistory': [{'maxAge': 1,
#     'endDate': '2023-01-29',
#     'totalRevenue': 26974000000,
#     'costOfRevenue': 11618000000,
#     'grossProfit': 15356000000,
#     'researchDevelopment': 7339000000,
#     'sellingGeneralAdministrative': 2440000000,
#     'nonRecurring': {},
#     'otherOperatingExpenses': {},
#     'totalOperatingExpenses': 21397000000,
#     'operatingIncome': 5577000000,
#     'totalOtherIncomeExpenseNet': -1396000000,
#     'ebit': 5577000000,
#     'interestExpense': -262000000,
#     'incomeBeforeTax': 4181000000,
#     'incomeTaxExpense': -187000000,
#     'minorityInterest': {},
#     'netIncomeFromContinuingOps': 4368000000,
#     'discontinuedOperations': {},
#     'extraordinaryItems': {},
#     'effectOfAccountingCharges': {},
#     'otherItems': {},
#     'netIncome': 4368000000,
#     'netIncomeApplicableToCommonShares': 4368000000},
#    {'maxAge': 1,
#     'endDate': '2022-01-30',
#     'totalRevenue': 26914000000,
#     'costOfRevenue': 9439000000,
#     'grossProfit': 17475000000,
#     'researchDevelopment': 5268000000,
#     'sellingGeneralAdministrative': 2166000000,
#     'nonRecurring': {},
#     'otherOperatingExpenses': {},
#     'totalOperatingExpenses': 16873000000,
#     'operatingIncome': 10041000000,
#     'totalOtherIncomeExpenseNet': -100000000,
#     'ebit': 10041000000,
#     'interestExpense': -236000000,
#     'incomeBeforeTax': 9941000000,
#     'incomeTaxExpense': 189000000,
#     'minorityInterest': {},
#     'netIncomeFromContinuingOps': 9752000000,
#     'discontinuedOperations': {},
#     'extraordinaryItems': {},
#     'effectOfAccountingCharges': {},
#     'otherItems': {},
#     'netIncome': 9752000000,
#     'netIncomeApplicableToCommonShares': 9752000000},
#    {'maxAge': 1,
#     'endDate': '2021-01-31',
#     'totalRevenue': 16675000000,
#     'costOfRevenue': 6118000000,
#     'grossProfit': 10557000000,
#     'researchDevelopment': 3924000000,
#     'sellingGeneralAdministrative': 1912000000,
#     'nonRecurring': {},
#     'otherOperatingExpenses': {},
#     'totalOperatingExpenses': 11954000000,
#     'operatingIncome': 4721000000,
#     'totalOtherIncomeExpenseNet': -312000000,
#     'ebit': 4721000000,
#     'interestExpense': -184000000,
#     'incomeBeforeTax': 4409000000,
#     'incomeTaxExpense': 77000000,
#     'minorityInterest': {},
#     'netIncomeFromContinuingOps': 4332000000,
#     'discontinuedOperations': {},
#     'extraordinaryItems': {},
#     'effectOfAccountingCharges': {},
#     'otherItems': {},
#     'netIncome': 4332000000,
#     'netIncomeApplicableToCommonShares': 4332000000},
#    {'maxAge': 1,
#     'endDate': '2020-01-26',
#     'totalRevenue': 10918000000,
#     'costOfRevenue': 4150000000,
#     'grossProfit': 6768000000,
#     'researchDevelopment': 2829000000,
#     'sellingGeneralAdministrative': 1093000000,
#     'nonRecurring': {},
#     'otherOperatingExpenses': {},
#     'totalOperatingExpenses': 8072000000,
#     'operatingIncome': 2846000000,
#     'totalOtherIncomeExpenseNet': 124000000,
#     'ebit': 2846000000,
#     'interestExpense': -52000000,
#     'incomeBeforeTax': 2970000000,
#     'incomeTaxExpense': 174000000,
#     'minorityInterest': {},
#     'netIncomeFromContinuingOps': 2796000000,
#     'discontinuedOperations': {},
#     'extraordinaryItems': {},
#     'effectOfAccountingCharges': {},
#     'otherItems': {},
#     'netIncome': 2796000000,
#     'netIncomeApplicableToCommonShares': 2796000000}],
#   'maxAge': 86400},
#  'incomeStatementHistoryQuarterly': {'incomeStatementHistory': [{'maxAge': 1,
#     'endDate': '2023-01-29',
#     'totalRevenue': 6051000000,
#     'costOfRevenue': 2218000000,
#     'grossProfit': 3833000000,
#     'researchDevelopment': 1952000000,
#     'sellingGeneralAdministrative': 625000000,
#     'nonRecurring': {},
#     'otherOperatingExpenses': {},
#     'totalOperatingExpenses': 4795000000,
#     'operatingIncome': 1256000000,
#     'totalOtherIncomeExpenseNet': 32000000,
#     'ebit': 1256000000,
#     'interestExpense': -64000000,
#     'incomeBeforeTax': 1288000000,
#     'incomeTaxExpense': -126000000,
#     'minorityInterest': {},
#     'netIncomeFromContinuingOps': 1414000000,
#     'discontinuedOperations': {},
#     'extraordinaryItems': {},
#     'effectOfAccountingCharges': {},
#     'otherItems': {},
#     'netIncome': 1414000000,
#     'netIncomeApplicableToCommonShares': 1414000000},
#    {'maxAge': 1,
#     'endDate': '2022-10-30',
#     'totalRevenue': 5931000000,
#     'costOfRevenue': 2754000000,
#     'grossProfit': 3177000000,
#     'researchDevelopment': 1945000000,
#     'sellingGeneralAdministrative': 631000000,
#     'nonRecurring': {},
#     'otherOperatingExpenses': {},
#     'totalOperatingExpenses': 5330000000,
#     'operatingIncome': 601000000,
#     'totalOtherIncomeExpenseNet': 12000000,
#     'ebit': 601000000,
#     'interestExpense': -65000000,
#     'incomeBeforeTax': 613000000,
#     'incomeTaxExpense': -67000000,
#     'minorityInterest': {},
#     'netIncomeFromContinuingOps': 680000000,
#     'discontinuedOperations': {},
#     'extraordinaryItems': {},
#     'effectOfAccountingCharges': {},
#     'otherItems': {},
#     'netIncome': 680000000,
#     'netIncomeApplicableToCommonShares': 680000000},
#    {'maxAge': 1,
#     'endDate': '2022-07-31',
#     'totalRevenue': 6704000000,
#     'costOfRevenue': 3789000000,
#     'grossProfit': 2915000000,
#     'researchDevelopment': 1824000000,
#     'sellingGeneralAdministrative': 592000000,
#     'nonRecurring': {},
#     'otherOperatingExpenses': {},
#     'totalOperatingExpenses': 6205000000,
#     'operatingIncome': 499000000,
#     'totalOtherIncomeExpenseNet': -24000000,
#     'ebit': 499000000,
#     'interestExpense': -65000000,
#     'incomeBeforeTax': 475000000,
#     'incomeTaxExpense': -181000000,
#     'minorityInterest': {},
#     'netIncomeFromContinuingOps': 656000000,
#     'discontinuedOperations': {},
#     'extraordinaryItems': {},
#     'effectOfAccountingCharges': {},
#     'otherItems': {},
#     'netIncome': 656000000,
#     'netIncomeApplicableToCommonShares': 656000000},
#    {'maxAge': 1,
#     'endDate': '2022-05-01',
#     'totalRevenue': 8288000000,
#     'costOfRevenue': 2857000000,
#     'grossProfit': 5431000000,
#     'researchDevelopment': 1618000000,
#     'sellingGeneralAdministrative': 592000000,
#     'nonRecurring': {},
#     'otherOperatingExpenses': {},
#     'totalOperatingExpenses': 5067000000,
#     'operatingIncome': 3221000000,
#     'totalOtherIncomeExpenseNet': -1416000000,
#     'ebit': 3221000000,
#     'interestExpense': -68000000,
#     'incomeBeforeTax': 1805000000,
#     'incomeTaxExpense': 187000000,
#     'minorityInterest': {},
#     'netIncomeFromContinuingOps': 1618000000,
#     'discontinuedOperations': {},
#     'extraordinaryItems': {},
#     'effectOfAccountingCharges': {},
#     'otherItems': {},
#     'netIncome': 1618000000,
#     'netIncomeApplicableToCommonShares': 1618000000}],
#   'maxAge': 86400},
#  'indexTrend': {'maxAge': 1,
#   'symbol': 'SP5',
#   'peRatio': 15.758,
#   'pegRatio': 1.98481,
#   'estimates': [{'period': '0q', 'growth': -0.0069999998},
#    {'period': '+1q', 'growth': 0.065},
#    {'period': '0y', 'growth': 0.009},
#    {'period': '+1y', 'growth': 0.107},
#    {'period': '+5y', 'growth': 0.0763133},
#    {'period': '-5y'}]},
#  'industryTrend': {'maxAge': 1, 'symbol': None, 'estimates': []},
#  'insiderHolders': {'holders': [{'maxAge': 1,
#     'name': 'COXE TENCH C',
#     'relation': 'Director',
#     'url': '',
#     'transactionDescription': 'Stock Gift',
#     'latestTransDate': '2023-03-13',
#     'positionIndirect': 4186960,
#     'positionIndirectDate': 1678665600},
#    {'maxAge': 1,
#     'name': 'DABIRI JOHN O',
#     'relation': 'Director',
#     'url': '',
#     'transactionDescription': 'Sale',
#     'latestTransDate': '2022-12-19',
#     'positionDirect': 2417,
#     'positionDirectDate': '2022-12-19'},
#    {'maxAge': 1,
#     'name': 'HUANG JEN-HSUN',
#     'relation': 'Chief Executive Officer',
#     'url': '',
#     'transactionDescription': 'Stock Award(Grant)',
#     'latestTransDate': '2023-03-02',
#     'positionDirect': 86604200,
#     'positionDirectDate': '2023-03-02'},
#    {'maxAge': 1,
#     'name': 'HUDSON DAWN E',
#     'relation': 'Director',
#     'url': '',
#     'transactionDescription': 'Sale',
#     'latestTransDate': '2023-03-30',
#     'positionDirect': 85350,
#     'positionDirectDate': '2023-03-30'},
#    {'maxAge': 1,
#     'name': 'KRESS COLETTE M.',
#     'relation': 'Chief Financial Officer',
#     'url': '',
#     'transactionDescription': 'Sale',
#     'latestTransDate': '2023-03-13',
#     'positionDirect': 638969,
#     'positionDirectDate': '2023-03-13'},
#    {'maxAge': 1,
#     'name': 'PERRY MARK L',
#     'relation': 'Director',
#     'url': '',
#     'transactionDescription': 'Sale',
#     'latestTransDate': '2023-02-27',
#     'positionIndirect': 152962,
#     'positionIndirectDate': 1677456000},
#    {'maxAge': 1,
#     'name': 'PURI AJAY K',
#     'relation': 'Officer',
#     'url': '',
#     'transactionDescription': 'Stock Award(Grant)',
#     'latestTransDate': '2023-03-10',
#     'positionDirect': 491657,
#     'positionDirectDate': '2023-03-10'},
#    {'maxAge': 1,
#     'name': 'SHOQUIST DEBORA C',
#     'relation': 'Officer',
#     'url': '',
#     'transactionDescription': 'Stock Award(Grant)',
#     'latestTransDate': '2023-03-10',
#     'positionDirect': 388640,
#     'positionDirectDate': '2023-03-10'},
#    {'maxAge': 1,
#     'name': 'STEVENS MARK A',
#     'relation': 'Director',
#     'url': '',
#     'transactionDescription': 'Sale',
#     'latestTransDate': '2023-01-13',
#     'positionIndirect': 4442790,
#     'positionIndirectDate': 1673568000},
#    {'maxAge': 1,
#     'name': 'TETER TIMOTHY S',
#     'relation': 'General Counsel',
#     'url': '',
#     'transactionDescription': 'Stock Gift',
#     'latestTransDate': '2023-03-17',
#     'positionDirect': 286142,
#     'positionDirectDate': '2023-03-17'}],
#   'maxAge': 1},
#  'insiderTransactions': {'transactions': [{'maxAge': 1,
#     'shares': 5000,
#     'value': 1372765,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 274.55 per share.',
#     'filerName': 'HUDSON DAWN E',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2023-03-30',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 29591,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Gift at price 0.00 per share.',
#     'filerName': 'TETER TIMOTHY S',
#     'filerRelation': 'General Counsel',
#     'moneyText': '',
#     'startDate': '2023-03-17',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 50000,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Gift at price 0.00 per share.',
#     'filerName': 'COXE TENCH C',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2023-03-13',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 6000,
#     'value': 1375747,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 223.71 - 231.61 per share.',
#     'filerName': 'KRESS COLETTE M.',
#     'filerRelation': 'Chief Financial Officer',
#     'moneyText': '',
#     'startDate': '2023-03-13',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 16340,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'SHOQUIST DEBORA C',
#     'filerRelation': 'Officer',
#     'moneyText': '',
#     'startDate': '2023-03-10',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 19094,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'PURI AJAY K',
#     'filerRelation': 'Officer',
#     'moneyText': '',
#     'startDate': '2023-03-10',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 19829,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'KRESS COLETTE M.',
#     'filerRelation': 'Chief Financial Officer',
#     'moneyText': '',
#     'startDate': '2023-03-10',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 16340,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'TETER TIMOTHY S',
#     'filerRelation': 'General Counsel',
#     'moneyText': '',
#     'startDate': '2023-03-10',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 50000,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Gift at price 0.00 per share.',
#     'filerName': 'COXE TENCH C',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2023-03-07',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 116176,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'HUANG JEN-HSUN',
#     'filerRelation': 'Chief Executive Officer',
#     'moneyText': '',
#     'startDate': '2023-03-02',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 9144,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'SHOQUIST DEBORA C',
#     'filerRelation': 'Officer',
#     'moneyText': '',
#     'startDate': '2023-03-02',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 9920,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'PURI AJAY K',
#     'filerRelation': 'Officer',
#     'moneyText': '',
#     'startDate': '2023-03-02',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 10536,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'KRESS COLETTE M.',
#     'filerRelation': 'Chief Financial Officer',
#     'moneyText': '',
#     'startDate': '2023-03-02',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 6048,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Award(Grant) at price 0.00 per share.',
#     'filerName': 'TETER TIMOTHY S',
#     'filerRelation': 'General Counsel',
#     'moneyText': '',
#     'startDate': '2023-03-02',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 20000,
#     'value': 4727428,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 235.31 - 238.00 per share.',
#     'filerName': 'PERRY MARK L',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2023-02-27',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 7500,
#     'value': 1728002,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 230.40 per share.',
#     'filerName': 'HUDSON DAWN E',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2023-02-24',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 23532,
#     'value': 4824060,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 205.00 per share.',
#     'filerName': 'SHOQUIST DEBORA C',
#     'filerRelation': 'Officer',
#     'moneyText': '',
#     'startDate': '2023-01-27',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 10741,
#     'value': 2148200,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 200.00 per share.',
#     'filerName': 'KRESS COLETTE M.',
#     'filerRelation': 'Chief Financial Officer',
#     'moneyText': '',
#     'startDate': '2023-01-26',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 10741,
#     'value': 2148200,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 200.00 per share.',
#     'filerName': 'KRESS COLETTE M.',
#     'filerRelation': 'Chief Financial Officer',
#     'moneyText': '',
#     'startDate': '2023-01-26',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 65000,
#     'value': 10759900,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 164.70 - 167.42 per share.',
#     'filerName': 'STEVENS MARK A',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2023-01-13',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 210000,
#     'value': 33273900,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 157.92 - 160.10 per share.',
#     'filerName': 'STEVENS MARK A',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2023-01-10',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 804305,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Gift at price 0.00 per share.',
#     'filerName': 'STEVENS MARK A',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2022-12-29',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 60000,
#     'value': 9905486,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 165.08 - 165.57 per share.',
#     'filerName': 'STEVENS MARK A',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2022-12-21',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 293,
#     'value': 48579,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 165.80 per share.',
#     'filerName': 'DABIRI JOHN O',
#     'filerRelation': 'Director',
#     'moneyText': '',
#     'startDate': '2022-12-19',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 2494,
#     'value': 418718,
#     'filerUrl': '',
#     'transactionText': 'Sale at price 167.89 per share.',
#     'filerName': 'ROBERTSON DONALD F JR',
#     'filerRelation': 'Officer',
#     'moneyText': '',
#     'startDate': '2022-12-15',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 237500,
#     'value': 950000,
#     'filerUrl': '',
#     'transactionText': 'Conversion of Exercise of derivative security at price 4.00 per share.',
#     'filerName': 'HUANG JEN-HSUN',
#     'filerRelation': 'Chief Executive Officer',
#     'moneyText': '',
#     'startDate': '2022-12-13',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 237500,
#     'value': 950000,
#     'filerUrl': '',
#     'transactionText': 'Conversion of Exercise of derivative security at price 4.00 per share.',
#     'filerName': 'HUANG JEN-HSUN',
#     'filerRelation': 'Chief Executive Officer',
#     'moneyText': '',
#     'startDate': '2022-12-08',
#     'ownership': 'D'},
#    {'maxAge': 1,
#     'shares': 749730,
#     'value': 0,
#     'filerUrl': '',
#     'transactionText': 'Stock Gift at price 0.00 per share.',
#     'filerName': 'HUANG JEN-HSUN',
#     'filerRelation': 'Chief Executive Officer',
#     'moneyText': '',
#     'startDate': '2022-11-30',
#     'ownership': 'I'},
#    {'maxAge': 1,
#     'shares': 490897,
#     'value': 1548780,
#     'filerUrl': '',
#     'transactionText': 'Conversion of Exercise of derivative security at price 3.15 per share.',
#     'filerName': 'HUANG JEN-HSUN',
#     'filerRelation': 'Chief Executive Officer',
#     'moneyText': '',
#     'startDate': '2022-11-29',
#     'ownership': 'D'},
# ...
#    {'epochGradeDate': '2016-08-12 00:15:11',
#     'firm': 'Deutsche Bank',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-08-11 23:27:21',
#     'firm': 'RBC Capital',
#     'toGrade': 'Outperform',
#     'fromGrade': 'Sector Perform',
#     'action': 'up'},
#    {'epochGradeDate': '2016-08-10 01:24:20',
#     'firm': 'Barclays',
#     'toGrade': 'Underweight',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-08-08 00:00:40',
#     'firm': 'Jefferies',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-07-15 00:45:10',
#     'firm': 'Wells Fargo',
#     'toGrade': 'Underperform',
#     'fromGrade': 'Market Perform',
#     'action': 'down'},
#    {'epochGradeDate': '2016-07-15 00:44:17',
#     'firm': 'Mizuho',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2016-06-13 02:04:26',
#     'firm': 'Nomura',
#     'toGrade': 'Buy',
#     'fromGrade': 'Neutral',
#     'action': 'up'},
#    {'epochGradeDate': '2016-06-01 20:56:10',
#     'firm': 'Goldman Sachs',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2016-05-13 05:46:21',
#     'firm': 'Jefferies',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-05-13 05:46:20',
#     'firm': 'Deutsche Bank',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-05-13 05:32:47',
#     'firm': 'Barclays',
#     'toGrade': 'Underweight',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-05-13 00:24:29',
#     'firm': 'Topeka',
#     'toGrade': 'Buy',
#     'fromGrade': 'Hold',
#     'action': 'up'},
#    {'epochGradeDate': '2016-05-12 23:53:24',
#     'firm': 'Roth Capital',
#     'toGrade': 'Buy',
#     'fromGrade': 'Neutral',
#     'action': 'up'},
#    {'epochGradeDate': '2016-04-06 05:03:34',
#     'firm': 'Deutsche Bank',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-04-06 00:13:15',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Neutral',
#     'fromGrade': 'Buy',
#     'action': 'down'},
#    {'epochGradeDate': '2016-04-04 00:05:54',
#     'firm': 'Jefferies',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2018-05-05 06:32:15',
#     'firm': 'Argus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2018-05-05 07:00:37',
#     'firm': 'B. Riley FBR',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-02-18 03:37:04',
#     'firm': 'Deutsche Bank',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2016-01-13 21:22:56',
#     'firm': 'Barclays',
#     'toGrade': 'Underweight',
#     'fromGrade': 'Equal-Weight',
#     'action': 'down'},
#    {'epochGradeDate': '2015-11-15 21:26:42',
#     'firm': 'Canaccord Genuity',
#     'toGrade': 'Buy',
#     'fromGrade': 'Hold',
#     'action': 'up'},
#    {'epochGradeDate': '2015-11-06 06:48:12',
#     'firm': 'Canaccord Genuity',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-11-06 02:01:31',
#     'firm': 'Deutsche Bank',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-11-05 22:55:36',
#     'firm': 'MKM Partners',
#     'toGrade': 'Buy',
#     'fromGrade': 'Neutral',
#     'action': 'up'},
#    {'epochGradeDate': '2015-11-05 22:13:20',
#     'firm': 'Wedbush',
#     'toGrade': 'Outperform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-11-05 21:34:10',
#     'firm': 'Morgan Stanley',
#     'toGrade': 'Equal-Weight',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-11-05 21:31:47',
#     'firm': 'Roth Capital',
#     'toGrade': 'Neutral',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-11-02 23:39:16',
#     'firm': 'Needham',
#     'toGrade': 'Hold',
#     'fromGrade': 'Buy',
#     'action': 'down'},
#    {'epochGradeDate': '2015-10-29 22:37:23',
#     'firm': 'Morgan Stanley',
#     'toGrade': 'Equal-Weight',
#     'fromGrade': 'Underweight',
#     'action': 'up'},
#    {'epochGradeDate': '2015-10-12 02:07:25',
#     'firm': 'Roth Capital',
#     'toGrade': 'Neutral',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2015-09-16 22:52:56',
#     'firm': 'Jefferies',
#     'toGrade': 'Buy',
#     'fromGrade': 'Hold',
#     'action': 'up'},
#    {'epochGradeDate': '2015-08-07 06:17:31',
#     'firm': 'Canaccord Genuity',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-08-07 04:00:00',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-08-07 01:18:30',
#     'firm': 'Roth Capital',
#     'toGrade': 'Buy',
#     'fromGrade': 'Neutral',
#     'action': 'up'},
#    {'epochGradeDate': '2015-08-07 00:16:45',
#     'firm': 'Morgan Stanley',
#     'toGrade': 'Underweight',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-08-03 00:30:56',
#     'firm': 'Macquarie',
#     'toGrade': 'Outperform',
#     'fromGrade': 'Neutral',
#     'action': 'up'},
#    {'epochGradeDate': '2015-06-17 02:05:37',
#     'firm': 'Tigress Financial',
#     'toGrade': 'Buy',
#     'fromGrade': 'Neutral',
#     'action': 'up'},
#    {'epochGradeDate': '2015-06-10 01:04:11',
#     'firm': 'Nomura',
#     'toGrade': 'Neutral',
#     'fromGrade': 'Buy',
#     'action': 'down'},
#    {'epochGradeDate': '2015-05-08 02:00:00',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2015-05-08 01:12:44',
#     'firm': 'Roth Capital',
#     'toGrade': 'Neutral',
#     'fromGrade': 'Buy',
#     'action': 'down'},
#    {'epochGradeDate': '2015-03-22 23:04:27',
#     'firm': 'Goldman Sachs',
#     'toGrade': 'Sell',
#     'fromGrade': 'Neutral',
#     'action': 'down'},
#    {'epochGradeDate': '2015-03-09 23:58:31',
#     'firm': 'Bank of America',
#     'toGrade': 'Buy',
#     'fromGrade': 'Neutral',
#     'action': 'up'},
#    {'epochGradeDate': '2015-02-12 01:00:00',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-12-18 22:54:08',
#     'firm': 'Bank of America',
#     'toGrade': 'Neutral',
#     'fromGrade': 'Underperform',
#     'action': 'up'},
#    {'epochGradeDate': '2014-11-25 01:00:00',
#     'firm': 'Nomura',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-11-07 01:00:00',
#     'firm': 'JP Morgan',
#     'toGrade': 'Neutral',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-11-07 00:00:00',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-11-03 01:43:22',
#     'firm': 'Pacific Crest',
#     'toGrade': 'Sector Perform',
#     'fromGrade': 'Underperform',
#     'action': 'up'},
#    {'epochGradeDate': '2014-08-08 09:00:00',
#     'firm': 'Nomura',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-08-07 23:54:25',
#     'firm': 'Needham',
#     'toGrade': 'Buy',
#     'fromGrade': 'Hold',
#     'action': 'up'},
#    {'epochGradeDate': '2014-06-22 23:14:34',
#     'firm': 'Pacific Crest',
#     'toGrade': 'Underperform',
#     'fromGrade': 'Sector Perform',
#     'action': 'down'},
#    {'epochGradeDate': '2014-06-19 00:08:30',
#     'firm': 'Bank of America',
#     'toGrade': 'Underperform',
#     'fromGrade': 'Neutral',
#     'action': 'down'},
#    {'epochGradeDate': '2014-05-18 23:14:30',
#     'firm': 'RBC Capital',
#     'toGrade': 'Outperform',
#     'fromGrade': 'Sector Perform',
#     'action': 'up'},
#    {'epochGradeDate': '2014-05-08 20:23:27',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-05-08 19:31:35',
#     'firm': 'JP Morgan',
#     'toGrade': 'Neutral',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-05-08 19:03:06',
#     'firm': 'Jefferies',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-05-08 17:47:01',
#     'firm': 'Citigroup',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-04-10 10:55:53',
#     'firm': 'ISI Group',
#     'toGrade': 'Neutral',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2014-04-01 01:00:00',
#     'firm': 'JMP Securities',
#     'toGrade': 'Market Outperform',
#     'fromGrade': '',
#     'action': 'up'},
#    {'epochGradeDate': '2014-03-21 01:41:26',
#     'firm': 'CLSA',
#     'toGrade': 'Underperform',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2014-03-18 23:46:47',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2018-05-05 07:00:37',
#     'firm': 'B. Riley FBR',
#     'toGrade': 'Buy',
#     'fromGrade': 'Neutral',
#     'action': 'up'},
#    {'epochGradeDate': '2014-02-12 23:35:18',
#     'firm': 'FBR Capital',
#     'toGrade': 'Market Perform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-02-12 23:34:33',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2014-02-03 08:00:00',
#     'firm': 'Susquehanna',
#     'toGrade': 'Neutral',
#     'fromGrade': 'Negative',
#     'action': 'up'},
#    {'epochGradeDate': '2014-01-20 22:24:03',
#     'firm': 'Evercore Partners',
#     'toGrade': 'Equal-weight',
#     'fromGrade': 'Underweight',
#     'action': 'up'},
#    {'epochGradeDate': '2014-01-09 00:30:00',
#     'firm': 'Canaccord Genuity',
#     'toGrade': 'Hold',
#     'fromGrade': 'Buy',
#     'action': 'down'},
#    {'epochGradeDate': '2013-11-17 22:22:32',
#     'firm': 'Morgan Stanley',
#     'toGrade': 'Underweight',
#     'fromGrade': 'Equal-weight',
#     'action': 'down'},
#    {'epochGradeDate': '2013-11-08 00:39:33',
#     'firm': 'FBR Capital',
#     'toGrade': 'Market Perform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2013-10-11 00:25:45',
#     'firm': 'Macquarie',
#     'toGrade': 'Underperform',
#     'fromGrade': 'Neutral',
#     'action': 'down'},
#    {'epochGradeDate': '2013-08-09 00:34:06',
#     'firm': 'Nomura',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2013-07-31 00:56:27',
#     'firm': 'Wells Fargo',
#     'toGrade': 'Market Perform',
#     'fromGrade': 'Outperform',
#     'action': 'down'},
#    {'epochGradeDate': '2013-05-23 00:49:44',
#     'firm': 'Topeka',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2013-03-10 23:46:00',
#     'firm': 'Susquehanna',
#     'toGrade': 'Negative',
#     'fromGrade': 'Neutral',
#     'action': 'down'},
#    {'epochGradeDate': '2013-02-14 01:29:44',
#     'firm': 'Needham',
#     'toGrade': 'Hold',
#     'fromGrade': 'Buy',
#     'action': 'down'},
#    {'epochGradeDate': '2013-02-14 00:39:57',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2013-02-14 00:16:01',
#     'firm': 'BMO Capital',
#     'toGrade': 'Market Perform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2013-02-13 23:42:10',
#     'firm': 'Nomura',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2013-02-13 23:35:18',
#     'firm': 'Deutsche Bank',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2013-02-12 00:11:56',
#     'firm': 'FBR Capital',
#     'toGrade': 'Market Perform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2013-01-03 04:23:39',
#     'firm': 'Barclays',
#     'toGrade': 'Equal-Weight',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-12-04 23:10:33',
#     'firm': 'Oppenheimer',
#     'toGrade': 'Perform',
#     'fromGrade': 'Outperform',
#     'action': 'down'},
#    {'epochGradeDate': '2012-11-09 00:12:00',
#     'firm': 'FBR Capital',
#     'toGrade': 'Market Perform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-11-09 00:05:00',
#     'firm': 'Nomura',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-11-08 23:28:00',
#     'firm': 'Jefferies',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-11-07 04:14:00',
#     'firm': 'Wedbush',
#     'toGrade': 'Outperform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-11-06 02:35:00',
#     'firm': 'UBS',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-11-05 00:25:00',
#     'firm': 'BMO Capital',
#     'toGrade': 'Market Perform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-10-19 01:12:00',
#     'firm': 'FBR Capital',
#     'toGrade': 'Market Perform',
#     'fromGrade': 'Outperform',
#     'action': 'down'},
#    {'epochGradeDate': '2012-10-10 00:07:00',
#     'firm': 'Deutsche Bank',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-09-28 00:45:00',
#     'firm': 'Brean Capital',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2012-09-12 22:57:00',
#     'firm': 'Citigroup',
#     'toGrade': 'Neutral',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-08-10 07:14:00',
#     'firm': 'Barclays',
#     'toGrade': 'Equal-Weight',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-08-10 03:01:00',
#     'firm': 'UBS',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-08-10 01:16:00',
#     'firm': 'Stifel Nicolaus',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-08-10 00:57:00',
#     'firm': 'FBR Capital',
#     'toGrade': 'Outperform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-08-09 23:56:00',
#     'firm': 'Wedbush',
#     'toGrade': 'Outperform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-08-09 23:28:00',
#     'firm': 'Jefferies',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-08-09 23:21:00',
#     'firm': 'Citigroup',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-08-07 01:10:00',
#     'firm': 'FBR Capital',
#     'toGrade': 'Outperform',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-07-10 02:13:00',
#     'firm': 'Raymond James',
#     'toGrade': 'Strong Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-06-28 01:50:00',
#     'firm': 'Lazard',
#     'toGrade': 'Neutral',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2012-06-24 23:22:00',
#     'firm': 'Canaccord Genuity',
#     'toGrade': 'Buy',
#     'fromGrade': 'Hold',
#     'action': 'up'},
#    {'epochGradeDate': '2012-06-11 05:28:00',
#     'firm': 'UBS',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'up'},
#    {'epochGradeDate': '2012-05-30 23:53:00',
#     'firm': 'Morgan Stanley',
#     'toGrade': 'Equal-Weight',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2012-05-14 04:27:00',
#     'firm': 'Salman Partners',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-05-13 23:19:00',
#     'firm': 'Jefferies',
#     'toGrade': 'Hold',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-04-05 00:07:00',
#     'firm': 'Cantor Fitzgerald',
#     'toGrade': 'Buy',
#     'fromGrade': '',
#     'action': 'init'},
#    {'epochGradeDate': '2012-02-15 23:29:00',
#     'firm': 'Evercore Partners',
#     'toGrade': 'Underweight',
#     'fromGrade': '',
#     'action': 'main'},
#    {'epochGradeDate': '2012-02-15 22:34:00',
#     'firm': 'Bank oferica',
#     'toGrade': 'Neutral',
#     'fromGrade': '',
#     'action': 'down'},
#    {'epochGradeDate': '2012-02-12 23:27:00',
#     'firm': 'FBR Capital',
#     'toGrade': 'Outperform',
#     'fromGrade': '',
#     'action': 'up'}],
#   'maxAge': 86400}}

# %% [markdown]
# ### yahooquery single moudule

# %%
my_sym = 'NVDA'

# report_period = 'q'  # quarterly report
report_period = 'a'  # annual report

df_bal_sht = Ticker(my_sym).balance_sheet(frequency=report_period, trailing=True)
df_inc_stmt = Ticker(my_sym).income_statement(frequency=report_period, trailing=True)
df_cash_flow_stmt = Ticker(my_sym).cash_flow(frequency=report_period, trailing=True)

df1 = df_inc_stmt.head(4).copy()
df2 = df_bal_sht.head(4).copy()
df3 = df_cash_flow_stmt.head(4).copy()
df = pd.concat([df1, df2, df3], axis=1)

# https://stackoverflow.com/questions/14984119/python-pandas-remove-duplicate-columns
print(f'df.shape before drop duplicates: {df.shape}')
df = df.loc[:, ~df.columns.duplicated()].copy()  # drop duplicate columns, asOfDate, periodType, currencyCode 
print(f'df.shape after drop duplicates:  {df.shape}')
# Out:
# df.shape before drop duplicates: (4, 191)
# df.shape after drop duplicates:  (4, 184)

# %%
df
# Out:
#          asOfDate periodType currencyCode  BasicAverageShares  BasicEPS  CostOfRevenue  DilutedAverageShares  DilutedEPS  DilutedNIAvailtoComStockholders          EBIT  EBITDA   GrossProfit  InterestExpense  InterestExpenseNonOperating  InterestIncome  InterestIncomeNonOperating     NetIncome  NetIncomeCommonStockholders  NetIncomeContinuousOperations  NetIncomeFromContinuingAndDiscontinuedOperation  NetIncomeFromContinuingOperationNetMinorityInterest  \
# symbol
# NVDA   2020-01-31        12M          USD        2.436000e+09    1.1475   4.150000e+09         2.472000e+09         1.13         2.796000e+09              3.022000e+09     NaN  6.768000e+09       52000000.0           52000000.0             178000000.0          178000000.0         2.796000e+09         2.796000e+09                 2.796000e+09                   2.796000e+09                                     2.796000e+09
# NVDA   2021-01-31        12M          USD        2.467000e+09    1.7600   6.279000e+09         2.510000e+09         1.73         4.332000e+09              4.593000e+09     NaN  1.039600e+10      184000000.0          184000000.0              57000000.0           57000000.0         4.332000e+09         4.332000e+09                 4.332000e+09                   4.332000e+09                                     4.332000e+09
# NVDA   2022-01-31        12M          USD        2.496000e+09    3.9100   9.439000e+09         2.535000e+09         3.85         9.752000e+09              1.017700e+10     NaN  1.747500e+10      236000000.0          236000000.0              29000000.0           29000000.0         9.752000e+09         9.752000e+09                 9.752000e+09                   9.752000e+09                                     9.752000e+09
# NVDA   2023-01-31        12M          USD                 NaN       NaN   1.161800e+10                  NaN          NaN         4.368000e+09              4.443000e+09     NaN  1.535600e+10      262000000.0          262000000.0             267000000.0          267000000.0         4.368000e+09         4.368000e+09                 4.368000e+09                   4.368000e+09                                     4.368000e+09
#
#         NetIncomeIncludingNoncontrollingInterests  NetInterestIncome  NetNonOperatingInterestIncomeExpense  NormalizedEBITDA  NormalizedIncome  OperatingExpense  OperatingIncome  OperatingRevenue  OtherIncomeExpense  OtherNonOperatingIncomeExpenses  PretaxIncome  ReconciledCostOfRevenue  ReconciledDepreciation  ResearchAndDevelopment  RestructuringAndMergernAcquisition  SellingGeneralAndAdministration  SpecialIncomeCharges  TaxEffectOfUnusualItems  TaxProvision  ...  ChangeInReceivables  \
# symbol                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# NVDA           2.796000e+09                              126000000.0          126000000.0                       3.403000e+09      2.796000e+09      3.922000e+09     2.846000e+09      1.091800e+10       -2.000000e+06           -2000000.0              2.970000e+09         4.150000e+09             3.810000e+08            2.829000e+09                     NaN                        1.093000e+09                              NaN                   0.0       174000000.0  ...        -2.330000e+08
# NVDA           4.332000e+09                             -127000000.0         -127000000.0                       5.691000e+09      4.332000e+09      5.864000e+09     4.532000e+09      1.667500e+10        4.000000e+06            4000000.0              4.409000e+09         6.279000e+09             1.098000e+09            3.924000e+09                     NaN                        1.940000e+09                              NaN                   0.0        77000000.0  ...        -5.500000e+08
# NVDA           9.752000e+09                             -207000000.0         -207000000.0                       1.135100e+10      9.752000e+09      7.434000e+09     1.004100e+10      2.691400e+10        1.070000e+08          107000000.0              9.941000e+09         9.439000e+09             1.174000e+09            5.268000e+09                     NaN                        2.166000e+09                              NaN                   0.0       189000000.0  ...        -2.215000e+09
# NVDA           4.368000e+09                                5000000.0            5000000.0                       7.340000e+09      5.179800e+09      9.779000e+09     5.577000e+09      2.697400e+10       -1.401000e+09          -48000000.0              4.181000e+09         1.161800e+10             1.544000e+09            7.339000e+09            1.353000e+09                        2.440000e+09                    -1.353000e+09          -541200000.0      -187000000.0  ...         8.220000e+08
#
#         ChangeInWorkingCapital  ChangesInAccountReceivables  ChangesInCash  CommonStockDividendPaid  CommonStockPayments  DeferredIncomeTax   DeferredTax  DepreciationAmortizationDepletion  DepreciationAndAmortization  EndCashPosition  FinancingCashFlow  FreeCashFlow  GainLossOnInvestmentSecurities  IncomeTaxPaidSupplementalData  InterestPaidSupplementalData  InvestingCashFlow  IssuanceOfDebt  LongTermDebtIssuance  LongTermDebtPayments  NetBusinessPurchaseAndSale  NetCommonStockIssuance  \
# symbol
# NVDA           7.170000e+08           -2.330000e+08           1.011400e+10         -390000000.0             0.000000e+00       1.800000e+07  1.800000e+07         3.810000e+08                       3.810000e+08             1.089600e+10      -7.920000e+08  4.272000e+09                  NaN                    1.760000e+08                     54000000.0                6.145000e+09             NaN                  NaN          0.000000e+00                   NaN                0.000000e+00
# NVDA          -7.030000e+08           -5.500000e+08          -1.004900e+10         -395000000.0             0.000000e+00      -2.820000e+08 -2.820000e+08         1.098000e+09                       1.098000e+09             8.470000e+08       3.804000e+09  4.694000e+09                  NaN                    2.490000e+08                    138000000.0               -1.967500e+10    4.968000e+09         4.968000e+09          0.000000e+00         -8.524000e+09                0.000000e+00
# NVDA          -3.363000e+09           -2.215000e+09           1.143000e+09         -399000000.0                      NaN      -4.060000e+08 -4.060000e+08         1.174000e+09                       1.174000e+09             1.990000e+09       1.865000e+09  8.132000e+09         -100000000.0                    3.960000e+08                    246000000.0               -9.830000e+09    4.977000e+09         4.977000e+09         -1.000000e+09         -2.630000e+08                         NaN
# NVDA          -2.207000e+09            8.220000e+08           1.399000e+09         -398000000.0            -1.003900e+10      -2.164000e+09 -2.164000e+09         1.544000e+09                       1.544000e+09             3.389000e+09      -1.161700e+10  3.808000e+09           45000000.0                    1.404000e+09                    254000000.0                7.375000e+09    0.000000e+00         0.000000e+00          0.000000e+00         -4.900000e+07               -1.003900e+10
#
#         NetIncomeFromContinuingOperations  NetInvestmentPurchaseAndSale  NetIssuancePaymentsOfDebt  NetLongTermDebtIssuance  NetOtherFinancingCharges  NetPPEPurchaseAndSale  OperatingCashFlow  OperatingGainsLosses  OtherNonCashItems  ProceedsFromStockOptionExercised  PurchaseOfBusiness  PurchaseOfInvestment  PurchaseOfPPE  RepaymentOfDebt  RepurchaseOfCapitalStock  SaleOfInvestment  SaleOfPPE  StockBasedCompensation
# symbol
# NVDA           2.796000e+09                       6.634000e+09                  0.000000e+00               0.000000e+00            -5.510000e+08             -4.890000e+08         4.761000e+09                  NaN        5.000000e+06          149000000.0                              NaN        -1.475000e+09   -4.890000e+08     0.000000e+00         0.000000e+00           8.109000e+09        0.0         8.440000e+08
# NVDA           4.332000e+09                      -1.002300e+10                  4.968000e+09               4.968000e+09            -9.630000e+08             -1.128000e+09         5.822000e+09                  NaN       -2.000000e+07          194000000.0                    -8.524000e+09        -1.934200e+10   -1.128000e+09     0.000000e+00         0.000000e+00           9.319000e+09        NaN         1.397000e+09
# NVDA           9.752000e+09                      -8.591000e+09                  3.977000e+09               3.977000e+09            -1.994000e+09             -9.760000e+08         9.108000e+09         -100000000.0        4.700000e+07          281000000.0                    -2.630000e+08        -2.481100e+10   -9.760000e+08    -1.000000e+09                  NaN           1.622000e+10        NaN         2.004000e+09
# NVDA           4.368000e+09                       9.257000e+09                  0.000000e+00               0.000000e+00            -1.535000e+09             -1.833000e+09         5.641000e+09           45000000.0        1.346000e+09          355000000.0                    -4.900000e+07        -1.197400e+10   -1.833000e+09     0.000000e+00        -1.003900e+10           2.123100e+10        NaN         2.709000e+09
#
# [4 rows x 184 columns]

# %%
row_last = df.iloc[3]
date = row_last['asOfDate'].strftime('%Y-%m-%d')
period = row_last['periodType']
oper_inc = row_last['OperatingIncome']
tax_prov = row_last['TaxProvision']
invested_cap = row_last['InvestedCapital']
NOPAT = oper_inc - tax_prov
ROIC = NOPAT / invested_cap

print(f'{my_sym} ROIC for the last {period}, end date: {date}')
print(f'Operating Income:         {oper_inc:>21,.0f}')
print(f'Tax Provision:            {-tax_prov:>21,.0f}')
print(f'   Net Oper. Prof. A.T.:  {NOPAT:>21,.0f}')
print(f'       Invested Capital:  {invested_cap:>21,.0f}')
print(f'                   ROIC:  {ROIC:>21,.6f}')
# Out:
# NVDA ROIC for the last 12M, end date: 2023-01-31
# Operating Income:                 5,577,000,000
# Tax Provision:                      187,000,000
#    Net Oper. Prof. A.T.:          5,764,000,000
#        Invested Capital:         10,953,000,000
#                    ROIC:               0.526249

# %%
df_metrics = df[['asOfDate', 'periodType', 'OperatingIncome', 'TaxProvision', 'InvestedCapital']].copy()
df_metrics['ROIC'] = (df_metrics['OperatingIncome'] - df_metrics['TaxProvision']) / df_metrics['InvestedCapital']
df_metrics['SalesGR'] = df['OperatingIncome'].pct_change()
df_metrics['DilEPSGR'] = df['DilutedEPS'].pct_change()
df_metrics['OperCFGR'] = df['OperatingCashFlow'].pct_change()
df_metrics['FreeCFGR'] = df['FreeCashFlow'].pct_change()
df_metrics
# Out:
#          asOfDate periodType  OperatingIncome  TaxProvision  InvestedCapital      ROIC   SalesGR  DilEPSGR  OperCFGR  FreeCFGR
# symbol
# NVDA   2020-01-31        12M     2.846000e+09   174000000.0     1.991000e+09  1.342039       NaN       NaN       NaN       NaN
# NVDA   2021-01-31        12M     4.532000e+09    77000000.0     6.963000e+09  0.639810  0.592410  0.530973  0.222852  0.098783
# NVDA   2022-01-31        12M     1.004100e+10   189000000.0     1.094600e+10  0.900055  1.215578  1.225434  0.564411  0.732424
# NVDA   2023-01-31        12M     5.577000e+09  -187000000.0     1.095300e+10  0.526249 -0.444577  0.000000 -0.380654 -0.531727

# %%
# TODO get longbusinesssummary,pageview, more financial metrics

# %%
d_companies_profiles = Ticker(['NVDA', 'GOOG']).summary_profile

# %%
# d_companies_profiles.items().keys()
d_companies_profiles  # nested dict(s)
# # l_symbols = list(d_companies_profiles.keys())  # list of keys to nested dict(s)
# l_sum_profils = list(d_companies_profiles.values())  # list of value(s), i.e. dict(s), to nested dict(s)
# l_sum_profils
# Out:
# {'NVDA': {'address1': '2788 San Tomas Expressway',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'zip': '95051',
#   'country': 'United States',
#   'phone': '408 486 2000',
#   'website': 'https://www.nvidia.com',
#   'industry': 'Semiconductors',
#   'industryDisp': 'Semiconductors',
#   'sector': 'Technology',
#   'longBusinessSummary': "NVIDIA Corporation provides graphics, and compute and networking solutions in the United States, Taiwan, China, and internationally. The company's Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building 3D designs and virtual worlds. Its Compute & Networking segment provides Data Center platforms and systems for AI, HPC, and accelerated computing; Mellanox networking and interconnect solutions; automotive AI Cockpit, autonomous driving development agreements, and autonomous vehicle solutions; cryptocurrency mining processors; Jetson for robotics and other embedded platforms; and NVIDIA AI Enterprise and other software. The company's products are used in gaming, professional visualization, datacenter, and automotive markets. NVIDIA Corporation sells its products to original equipment manufacturers, original device manufacturers, system builders, add-in board manufacturers, retailers/distributors, independent software vendors, Internet and cloud service providers, automotive manufacturers and tier-1 automotive suppliers, mapping companies, start-ups, and other ecosystem participants. It has a strategic collaboration with Kroger Co. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.",
#   'fullTimeEmployees': 26196,
#   'companyOfficers': [],
#   'maxAge': 86400},
#  'GOOG': {'address1': '1600 Amphitheatre Parkway',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'zip': '94043',
#   'country': 'United States',
#   'phone': '650 253 0000',
#   'website': 'https://www.abc.xyz',
#   'industry': 'Internet Content & Information',
#   'industryDisp': 'Internet Content & Information',
#   'sector': 'Communication Services',
#   'longBusinessSummary': 'Alphabet Inc. offers various products and platforms in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, including ads, Android, Chrome, hardware, Gmail, Google Drive, Google Maps, Google Photos, Google Play, Search, and YouTube. It is also involved in the sale of apps and in-app purchases and digital content in the Google Play store; and Fitbit wearable devices, Google Nest home products, Pixel phones, and other devices, as well as in the provision of YouTube non-advertising services. The Google Cloud segment offers infrastructure, cybersecurity, data, analytics, AI, and machine learning, and other services; Google Workspace that include cloud-based collaboration tools for enterprises, such as Gmail, Docs, Drive, Calendar, and Meet; and other services for enterprise customers. The Other Bets segment sells health technology and internet services. The company was founded in 1998 and is headquartered in Mountain View, California.',
#   'fullTimeEmployees': 190711,
#   'companyOfficers': [],
#   'maxAge': 86400}}

# %%
print(company)
print(d_companies_profiles[company]['industry'])
print(d_companies_profiles[company]['sector'])
# Out:
# GOOG
# Internet Content & Information
# Communication Services

# %%
companies = []
industries = []
sectors = []

# for company in companies:
for company in d_companies_profiles:
    companies.append(company)
    industries.append(d_companies_profiles[company]['industry'])
    sectors.append(d_companies_profiles[company]['sector'])

print('Companies:', companies)
print('Industries:', industries)
print('Sectors:', sectors)
# Out:
# Companies: ['NVDA', 'GOOG']
# Industries: ['Semiconductors', 'Internet Content & Information']
# Sectors: ['Technology', 'Communication Services']

# %%
# extract keys and values where keys == 'industry' and 'sector'
companies = d_companies_profiles.copy()

d_coms_inds_secs = {}
for company in companies:
    com_prfl = companies[company]
    d_com_ind_sec = {key:val for key, val in com_prfl.items() if any([key == 'industry', key == 'sector'])}  
    # print(company)     
    # print(com_prfl)
    # print(d_com_ind_sec)
    d_coms_inds_secs[company] = d_com_ind_sec

d_coms_inds_secs
# Out:
# {'NVDA': {'industry': 'Semiconductors', 'sector': 'Technology'},
#  'GOOG': {'industry': 'Internet Content & Information',
#   'sector': 'Communication Services'}}
