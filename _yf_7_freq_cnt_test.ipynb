# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
from yf_utils import _2_split_train_val_test, _3_random_slices, _4_lookback_slices
from yf_utils import _5_perf_ranks, _6_grp_tuples_sort_sum
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 16)
pd.set_option('display.width', 790)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"
fp_df_close_clean = 'df_close_clean'

# fp_df_eval_results = 'df_eval_results'
# fp_df_eval_sym_freq_results = 'df_eval_sym_freq_results'
fp_df_eval_sym_freq_results_test = 'df_eval_sym_freq_results_test'

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# %%
# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.

###################################  USE df_test as df_train
df_train, df_val, df_test = _2_split_train_val_test(df_close_clean)
df_train = df_test.copy()
###################################  USE df_test as df_train

len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f'len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test} ')
# Out:
# len_df_train: 150, len_df_val: 300, len_df_test: 150

# %%
print(f'df_train.index: {df_train.index[0]}, {df_train.index[-1]}')
print(f'df_val.index:   {df_val.index[0]}, {df_val.index[-1]}')
# Out:
# df_train.index: 2022-07-22 00:00:00, 2023-02-24 00:00:00
# df_val.index:   2021-05-13 00:00:00, 2022-07-21 00:00:00

# %%
col_add0 = ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'sym_freq_cnt']
col_add1 = ['grp(CAGR)_mean',         'grp(CAGR)_std',         'grp(CAGR)_mean/std']
col_add2 = ['grp(CAGR/UI)_mean',      'grp(CAGR/UI)_std',      'grp(CAGR/UI)_mean/std']
col_add3 = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
col_add4 = ['grp(retnStd/UI)_mean',   'grp(retnStd/UI)_std',   'grp(retnStd/UI)_mean/std']
col_add5 = ['SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI']

col_add_total = col_add0 + col_add1 + col_add2 + col_add3 + col_add4 + col_add5
print(f'col_add_total:\n{col_add_total}, total columns: {len(col_add_total)}')
# Out:
# col_add_total:
# ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'sym_freq_cnt', 'grp(CAGR)_mean', 'grp(CAGR)_std', 'grp(CAGR)_mean/std', 'grp(CAGR/UI)_mean', 'grp(CAGR/UI)_std', 'grp(CAGR/UI)_mean/std', 'grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std', 'grp(retnStd/UI)_mean', 'grp(retnStd/UI)_std', 'grp(retnStd/UI)_mean/std', 'SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI'], total columns: 23

# %%
# # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_test)
# df
# Out:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []

# %%
# if store_results:  # record results to df
# my_cols = ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'grp(CAGR/UI)_mean', 'grp(CAGR/UI)_std', 'grp(CAGR/UI)_mean/std', 'SPY_CAGR/UI']
# df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
df_eval_sym_freq_results_test = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_test)
df_eval_sym_freq_results_test
# Out:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []

# %%
# verbose = True  # True prints more output
verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# number of max lookback tuples to create for iloc start_train:end_train:end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms 
# n_samples = 114  
n_samples = 57  
# n_samples = 1

# for training, the number of days to lookback from iloc max-lookback end_train
days_lookbacks = [15, 30, 60, 120]
days_lookbacks = [30, 60, 120]
days_lookbacks = [60, 120]
days_lookbacks = [120]
days_lookbacks = [60]
days_lookbacks = [30]
days_lookbacks = [15]
days_lookbacks = [15, 30]
days_lookbacks = [15, 30, 60]


days_lookbacks.sort()

# number of days from end_train are used to evaluate effectiveness of the training
# days_eval = 10
days_eval = 6
days_eval = 5
days_eval = 4
# days_eval = 3
# days_eval = 2  


# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20  

syms_start = 0  #  start index of n_top_syms for evaluation
# syms_start = 1  #  start index of n_top_syms for evaluation

# syms_end = n_top_syms  #  end index of n_top_syms for evaluation
# syms_end = 1  #  end index of n_top_syms for evaluation
# syms_end = 2  #  end index of n_top_syms for evaluation
# syms_end = 3  #  end index of n_top_syms for evaluation
# syms_end = 4  #  end index of n_top_syms for evaluation
# syms_end = 5  #  end index of n_top_syms for evaluation
# syms_end = 6  #  end index of n_top_syms for evaluation
syms_end = 10  #  end index of n_top_syms for evaluation

# %% [markdown]
# create a sets of iloc lookback slices (start_train:end_train:end_eval), where
# end_train - start_train = days_lookback
# end_eval - end_train = days_eval
# for example,
# if given:
#  n_samples = 2
#  days_lookbacks = [30, 60, 120]
#  days_eval = 10
# a possible result is:
#  max_lookback_slices:
#  [(150, 270, 280), (5, 125, 135)]
#  where 270-150=125-5=max(days_lookbacks), 280-270=135-125=days_eval
#  sets_lookback_slices:
#  [[(240, 270, 280), (210, 270, 280), (150, 270, 280)], [(95, 125, 135), (65, 125, 135), (5, 125, 135)]]
#   where in a set, 270-240=days_lookbacks[0], 270-210=days_lookbacks[1], 270-150=days_lookbacks[2]
#   and 270, i.e. end_train, is constant for the set

# %%
# return n_samples slices
max_lookback_slices = _3_random_slices(len_df_train, n_samples=n_samples, days_lookback=max(days_lookbacks), days_eval=days_eval)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = _4_lookback_slices(max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False)

if verbose:
  print(f'max_lookback_slices:\n{max_lookback_slices}')
  print(f'sets_lookback_slices:\n{sets_lookback_slices}')

# %% [markdown]
# Generate lists, n_samples long, of the highest performance ranked symbols. The performance metrics are: CAGR/UI, CAGR/retnStd, retnStd/UI. n_top_syms of the best performing symbols from each metric are combined. The symbols are sorted by their number of appearances in the combined pool, and are placed in a list. A slice of the best performing symbols is selected by syms_start:syms_end, i.e. top_set_syms_n_freq[syms_start:syms_end].
#
# The performance metrics are calculated based on slices in sets_lookback_slices.  The first two numbers are ilocs for training. The last two numbers are ilocs for evaluation.

# %%
grp_top_set_syms_n_freq = []  # list of lists of top_set_symbols_n_freq, there are n_samples lists in list
grp_top_set_syms = []  # list of lists of top_set_symbols, there are n_samples lists in list
# loop thru lists of tuples of start_train:end_train:end_eval, i.e.
#  [[(887, 917, 927), (857, 917, 927), (797, 917, 927)],
#  [(483, 513, 523), (453, 513, 523), (393, 513, 523)]]
for lb_slices in sets_lookback_slices:
  grp_most_common_syms = []  
  for lb_slice in lb_slices:  # lb_slice, e.g. (246, 276, 286)
    start_train = lb_slice[0]
    end_train = lb_slice[1]
    start_eval = end_train
    end_eval = lb_slice[2]
    lookback = end_train - start_train
    d_eval = end_eval - start_eval

    _df = df_train.iloc[start_train:end_train]
    date_start_train = _df.index[0].strftime('%Y-%m-%d')
    date_end_train = _df.index[-1].strftime('%Y-%m-%d')

    if verbose:
      print(f'days lookback:    {lookback}')
      print(f'lb_slices:        {lb_slices}')
      print(f'lb_slice:         {lb_slice}')
      print(f'days eval:        {d_eval}')    
      print(f'iloc_start_train: {start_train}')
      print(f'iloc_end_train:   {end_train}')
      print(f'date_start_train: {date_start_train}')
      print(f'date_end_train:   {date_end_train}')


    perf_ranks, most_common_syms = _5_perf_ranks(_df, n_top_syms=n_top_syms)
    grp_most_common_syms.append(most_common_syms)
    
    if verbose:    
      # 1 lookback of r_CAGR/UI, r_CAGR/retnStd, r_retnStd/UI
      print(f'perf_ranks: {perf_ranks}')  
      # most common symbols of perf_ranks 
      print(f'most_common_syms: {most_common_syms}')     
      # grp_perf_ranks[lookback] = perf_ranks
      print(f'+++ finish lookback slice {lookback} +++\n')

  if verbose:
    print(f'grp_most_common_syms: {grp_most_common_syms}')
    # grp_most_common_syms a is list of lists of tuples of 
    #  the most-common-symbols symbol:frequency cumulated from
    #  each days_lookback  
    print(f'**** finish lookback slices {lb_slices} ****\n')

  # flatten list of lists of (symbol:frequency)
  flat_grp_most_common_syms = [val for sublist in grp_most_common_syms for val in sublist]
  # group symbols from set of days_lookbacks (i.e. lb_slices) and sum frequency of the symbols
  set_most_common_syms = _6_grp_tuples_sort_sum(flat_grp_most_common_syms, reverse=True)
  # get the top few most-frequent symbol:frequency pairs
  top_set_syms_n_freq = set_most_common_syms[0:n_top_syms]
  # get symbols from top_set_syms_n_freq

###################################  
  # top_set_syms = [i[0] for i in top_set_syms_n_freq]
  top_set_syms = [i[0] for i in top_set_syms_n_freq[syms_start:syms_end]]  
###################################  
  
  grp_top_set_syms_n_freq.append(top_set_syms_n_freq)
  grp_top_set_syms.append(top_set_syms)

  if verbose:  
    print(f'top {n_top_syms} ranked symbols and frequency from set {lb_slices}:\n{top_set_syms_n_freq}')
    print(f'top {n_top_syms} ranked symbols from set {lb_slices}:\n{top_set_syms}')  
    print(f'===== finish top {n_top_syms} ranked symbols from days_lookback set {lb_slices} =====\n\n')

# %%
def top_set_sym_freq_cnt(top_set_syms_n_freq):
    sym_freq_cnt_6 = []
    sym_freq_cnt_5 = []
    sym_freq_cnt_4 = []
    sym_freq_cnt_3 = []
    sym_freq_cnt_2 = []

    for sym_n_freq in top_set_syms_n_freq:
        _sym = sym_n_freq[0]
        _freq = sym_n_freq[1]
        # print(_sym, _freq)
        if _freq == 6:
            sym_freq_cnt_6.append(_sym)
        elif _freq == 5:
            sym_freq_cnt_5.append(_sym)
        elif _freq == 4:
            sym_freq_cnt_4.append(_sym)
        elif _freq == 3:
            sym_freq_cnt_3.append(_sym)          
        else:
            sym_freq_cnt_2.append(_sym)

    l_sym_freq_cnt = []
    l_sym_freq_cnt.append(sym_freq_cnt_6)
    l_sym_freq_cnt.append(sym_freq_cnt_5)
    l_sym_freq_cnt.append(sym_freq_cnt_4)
    l_sym_freq_cnt.append(sym_freq_cnt_3)    
    l_sym_freq_cnt.append(sym_freq_cnt_2)    

    # if verbose:
    #     print(f'sym_freq_cnt_6: {sym_freq_cnt_6}')
    #     print(f'sym_freq_cnt_5: {sym_freq_cnt_5}')
    #     print(f'sym_freq_cnt_4: {sym_freq_cnt_4}')
    #     print(f'sym_freq_cnt_3: {sym_freq_cnt_3}')
    #     print(f'sym_freq_cnt_2: {sym_freq_cnt_2}')

    # return sym_freq_cnt_6, sym_freq_cnt_5, sym_freq_cnt_4, sym_freq_cnt_3, sym_freq_cnt_2
    return l_sym_freq_cnt

# %%
for top_set_syms_n_freq in grp_top_set_syms_n_freq:
  l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
  print(f'sym_freq_6: {l_sym_freq_cnt[0]}')
  print(f'sym_freq_5: {l_sym_freq_cnt[1]}')
  print(f'sym_freq_4: {l_sym_freq_cnt[2]}')
  print(f'sym_freq_3: {l_sym_freq_cnt[3]}')
  print(f'sym_freq_2: {l_sym_freq_cnt[4]}\n')
# Out:
# sym_freq_6: ['AXON', 'GILD']
# sym_freq_5: ['GBX', 'LOCO', 'RMBS', 'SLB', 'STRL']
# sym_freq_4: ['ASC', 'ELF', 'EME', 'SANM']
# sym_freq_3: ['ATEN', 'CAT', 'CCRN', 'FTI', 'HEES', 'HOG', 'NTNX', 'SKT', 'TWNK']
# sym_freq_2: []
#
# sym_freq_6: ['BVH']
# sym_freq_5: ['BGNE', 'COLL', 'HZNP', 'NEOG']
# sym_freq_4: ['BABA', 'EDU', 'EXAS', 'NATI', 'NSTG', 'NTES', 'WB']
# sym_freq_3: ['ACIW', 'ACLS', 'ALGN', 'AU', 'BMA', 'BURL', 'CROX', 'DENN']
# sym_freq_2: []
#
# sym_freq_6: ['ELF', 'GILD']
# sym_freq_5: ['AMKR', 'EME', 'RMBS']
# sym_freq_4: ['ASC', 'DD', 'LOCO']
# sym_freq_3: ['BIIB', 'CAT', 'DENN', 'FTI', 'HFWA', 'LVS', 'MODN', 'NTNX', 'NYT', 'OSBC', 'PKX']
# sym_freq_2: ['AXON']
#
# sym_freq_6: ['ZTO']
# sym_freq_5: ['AXSM', 'BIDU', 'GDS']
# sym_freq_4: ['AU', 'BVH', 'CTRN', 'PUK', 'WB']
# sym_freq_3: ['ACLS', 'AER', 'ATKR', 'BERY', 'BURL', 'COUP', 'ELF', 'GILD']
# sym_freq_2: ['BBW', 'HZNP', 'NVO']
#
# sym_freq_6: ['HLIT']
# sym_freq_5: ['ASC', 'CAR', 'CATO', 'LOCO', 'PBF', 'SIGI', 'SLB']
# sym_freq_4: ['BBW', 'ISEE', 'STLD', 'XPRO']
# sym_freq_3: ['ATEN', 'BIIB', 'CBRL', 'CCRN', 'DINO', 'GBX', 'NTNX', 'PCG']
# sym_freq_2: []
#
# sym_freq_6: ['GPS']
# sym_freq_5: ['ANF', 'AXON']
# sym_freq_4: ['AEO', 'BURL', 'GILD', 'LSCC', 'RMBS']
# sym_freq_3: ['AMKR', 'APD', 'ELF', 'EXTR', 'FTI', 'ISEE', 'MRK', 'PDFS', 'PERI', 'SANM', 'TSM', 'TTC']
# sym_freq_2: []
#
# sym_freq_6: ['COUP', 'HZNP']
# sym_freq_5: ['BBW', 'BURL', 'BVH', 'EDU', 'NVO', 'SJW', 'TCOM', 'WB', 'ZTO']
# sym_freq_4: ['BGNE', 'GDS']
# sym_freq_3: ['ACGL', 'AJRD', 'BA', 'BMRN', 'CAT', 'COLL', 'EXAS']
# sym_freq_2: []
#
# sym_freq_6: []
# sym_freq_5: ['BURL', 'ROST']
# sym_freq_4: ['AEO', 'ANF', 'AXON', 'ELF', 'GILD', 'GPS']
# sym_freq_3: ['AMKR', 'ATKR', 'BMRN', 'CTRN', 'FTI', 'MRK', 'PDFS', 'RMBS', 'SANM']
# sym_freq_2: ['BBW', 'HZNP', 'ACLS']
#
# sym_freq_6: ['AEO', 'ANF', 'NVO', 'ZTO']
# sym_freq_5: ['AXSM', 'BIDU', 'BURL', 'CTRN', 'RIO']
# sym_freq_4: ['GDS', 'WB']
# sym_freq_3: ['ACLS', 'ATEN', 'ATKR', 'AU', 'AZN', 'COUP', 'ELF']
# sym_freq_2: ['BBW', 'HZNP']
#
# sym_freq_6: ['EXAS', 'HSBC', 'PUK']
# sym_freq_5: ['BVH', 'MELI']
# sym_freq_4: ['MARA', 'NEOG', 'TX']
# sym_freq_3: ['ALGN', 'BMA', 'BURL', 'CCOI', 'CCU', 'COLL', 'HZNP', 'LVS', 'NATI', 'PEN', 'RVNC', 'TSLA']
# sym_freq_2: []
#
# sym_freq_6: ['AMKR', 'GILD']
# sym_freq_5: ['GBX', 'PKX', 'RMBS']
# sym_freq_4: ['ASC', 'BA', 'ELF', 'EME', 'LOCO', 'RCL', 'SRI']
# sym_freq_3: ['CAT', 'CHGG', 'FTI', 'HEES', 'HFWA', 'MODN', 'NTNX']
# sym_freq_2: ['AXON']
#
# sym_freq_6: ['BURL', 'COUP']
# sym_freq_5: ['BVH', 'EDU', 'MRK', 'NVO']
# sym_freq_4: ['BGNE', 'CALM', 'CPB', 'MSGS', 'SJW', 'ZTO']
# sym_freq_3: ['AGYS', 'BA', 'BBW', 'BMRN', 'CAT']
# sym_freq_2: ['HZNP', 'AJRD', 'ACGL']
#
# sym_freq_6: []
# sym_freq_5: ['AMKR', 'ELF']
# sym_freq_4: ['ASC', 'BIIB', 'CHGG', 'GILD', 'GPS', 'RMBS']
# sym_freq_3: ['APD', 'DD', 'GE', 'ISEE', 'MRK', 'NTNX', 'STBA', 'TSM', 'TTC', 'UNFI']
# sym_freq_2: ['AXON', 'ACLS']
#
# sym_freq_6: ['HLIT']
# sym_freq_5: ['CAR', 'CATO', 'GILD', 'ISEE', 'LOCO', 'NTNX', 'SIGI']
# sym_freq_4: ['ASC', 'BBW', 'PBF', 'SLB', 'XPRO']
# sym_freq_3: ['ATEN', 'AVXL', 'AZO', 'BIIB', 'CBRL', 'CCRN', 'CLDT']
# sym_freq_2: []
#
# sym_freq_6: ['AMKR', 'GILD']
# sym_freq_5: ['GBX', 'PKX', 'RMBS']
# sym_freq_4: ['ASC', 'BA', 'ELF', 'EME', 'LOCO', 'RCL', 'SRI']
# sym_freq_3: ['CAT', 'CHGG', 'FTI', 'HEES', 'HFWA', 'MODN', 'NTNX']
# sym_freq_2: ['AXON']
#
# sym_freq_6: ['BURL', 'NVO']
# sym_freq_5: ['AJRD', 'MSGS', 'WB']
# sym_freq_4: ['BMA', 'BVH', 'COLL', 'GDS', 'SJW', 'ZTO']
# sym_freq_3: ['ACGL', 'AGYS', 'ALL', 'ARWR', 'BBW', 'BGNE', 'BUD', 'CAT']
# sym_freq_2: ['HZNP']
#
# sym_freq_6: ['ATEN', 'HLIT', 'LOCO', 'XPRO']
# sym_freq_5: ['CAR', 'HFWA', 'SIGI', 'STBA']
# sym_freq_4: ['AAWW', 'BIIB', 'CCRN', 'TNK', 'WAFD']
# sym_freq_3: ['ASC', 'ATCO', 'CAH', 'CLMT', 'FCN', 'ISEE']
# sym_freq_2: ['SLB']
#
# sym_freq_6: ['ZTO']
# sym_freq_5: ['COUP', 'GDS', 'NVO']
# sym_freq_4: ['BVH', 'EXAS', 'RARE']
# sym_freq_3: ['AGYS', 'ATKR', 'AZTA', 'BERY', 'BMRN', 'BURL', 'CAT', 'EDU', 'GILD', 'HHC', 'HTHT']
# sym_freq_2: ['BBW', 'HZNP']
#
# sym_freq_6: ['AJRD', 'ZTO']
# sym_freq_5: ['BURL', 'BVH', 'COUP', 'GDS']
# sym_freq_4: ['AMBA', 'EXAS']
# sym_freq_3: ['AGYS', 'AZTA', 'BMRN', 'CAT', 'EDU', 'ENV', 'HTHT', 'KDNY', 'NSTG', 'NVO']
# sym_freq_2: ['BBW', 'HZNP']
#
# sym_freq_6: ['HSBC']
# sym_freq_5: ['ACLS', 'BMA', 'BVH', 'NTES', 'PUK', 'TX']
# sym_freq_4: ['BABA', 'COLL', 'CROX', 'EXAS', 'MARA', 'NATI', 'NEOG']
# sym_freq_3: ['ACIW', 'ALGN', 'AU', 'CCU', 'H', 'HLF']
# sym_freq_2: []
#
# sym_freq_6: ['BURL', 'COUP']
# sym_freq_5: ['BVH', 'EDU', 'MRK', 'NVO']
# sym_freq_4: ['BGNE', 'CALM', 'CPB', 'MSGS', 'SJW', 'ZTO']
# sym_freq_3: ['AGYS', 'BA', 'BBW', 'BMRN', 'CAT']
# sym_freq_2: ['HZNP', 'AJRD', 'ACGL']
#
# sym_freq_6: ['BVH']
# sym_freq_5: ['ACLS', 'COLL', 'HSBC', 'HZNP']
# sym_freq_4: ['BMA', 'CCU', 'EXAS', 'MARA', 'NATI', 'NEOG']
# sym_freq_3: ['ACIW', 'ALGN', 'AU', 'BGNE', 'HLF', 'LVS', 'MELI', 'NTES', 'PUK']
# sym_freq_2: []
#
# sym_freq_6: ['BURL', 'HZNP', 'TCOM']
# sym_freq_5: ['AJRD', 'MSGS', 'NTES', 'NVO']
# sym_freq_4: ['ACIW', 'BGNE', 'BMA', 'BVH', 'GDS', 'SJW']
# sym_freq_3: ['ACGL', 'AGYS', 'AIG', 'ALGN', 'BBW', 'BUD']
# sym_freq_2: ['COLL']
#
# sym_freq_6: ['AMKR', 'GILD']
# sym_freq_5: ['GBX', 'PKX', 'RMBS']
# sym_freq_4: ['ASC', 'BA', 'ELF', 'EME', 'LOCO', 'RCL', 'SRI']
# sym_freq_3: ['CAT', 'CHGG', 'FTI', 'HEES', 'HFWA', 'MODN', 'NTNX']
# sym_freq_2: ['AXON']
#
# sym_freq_6: []
# sym_freq_5: ['BURL', 'ROST']
# sym_freq_4: ['AEO', 'ANF', 'AXON', 'ELF', 'GILD', 'GPS']
# sym_freq_3: ['AMKR', 'ATKR', 'BMRN', 'CTRN', 'FTI', 'MRK', 'PDFS', 'RMBS', 'SANM']
# sym_freq_2: ['BBW', 'HZNP', 'ACLS']
#
# sym_freq_6: ['CRUS']
# sym_freq_5: ['MMS', 'THR', 'TWLO', 'WIRE']
# sym_freq_4: ['ACLS', 'CAR', 'MCFT', 'SMG', 'TNK']
# sym_freq_3: ['ALGN', 'BVH', 'CINF', 'COUP', 'DCP', 'ELF', 'FCF', 'IPGP']
# sym_freq_2: ['CTLT', 'TA']
#
# sym_freq_6: ['BVH']
# sym_freq_5: ['AU', 'COLL', 'EXAS']
# sym_freq_4: ['BMA', 'GE', 'HSBC', 'NSTG', 'PRGO']
# sym_freq_3: ['ACLS', 'BABA', 'BGNE', 'BURL', 'CAT', 'CLAR', 'DENN', 'HEES', 'HZNP', 'MTH', 'NATI']
# sym_freq_2: []
#
# sym_freq_6: ['AU']
# sym_freq_5: ['BVH', 'COLL', 'EXAS']
# sym_freq_4: ['BABA', 'BGNE', 'BMA', 'EDU', 'GE', 'HSBC']
# sym_freq_3: ['ACLS', 'BURL', 'CLAR', 'DENN', 'HEES', 'HZNP', 'NTES', 'SPR', 'TPX', 'WB']
# sym_freq_2: []
#
# sym_freq_6: ['GPS']
# sym_freq_5: ['ANF', 'AXON']
# sym_freq_4: ['AEO', 'BURL', 'GILD', 'LSCC', 'RMBS']
# sym_freq_3: ['AMKR', 'APD', 'ELF', 'EXTR', 'FTI', 'ISEE', 'MRK', 'PDFS', 'PERI', 'SANM', 'TSM', 'TTC']
# sym_freq_2: []
#
# sym_freq_6: ['ALGN', 'META']
# sym_freq_5: []
# sym_freq_4: ['ACLS', 'BSIG', 'ICPT', 'LRN', 'MMS', 'SMG', 'TSLA', 'URI', 'WYNN']
# sym_freq_3: ['BURL', 'BVH', 'CINF', 'ELF', 'MCFT', 'MTH']
# sym_freq_2: ['CRUS', 'CTLT', 'THR']
#
# sym_freq_6: []
# sym_freq_5: ['ANF', 'AXSM', 'BERY', 'BURL', 'GILD', 'MRK']
# sym_freq_4: ['BKE', 'HEES']
# sym_freq_3: ['BBWI', 'BVH', 'CTRN', 'ELF', 'GPS', 'IIM', 'INCY', 'NOMD', 'ROST']
# sym_freq_2: ['BBW', 'HZNP', 'AEO']
#
# sym_freq_6: ['CRUS']
# sym_freq_5: ['MMS', 'THR', 'TWLO', 'WIRE']
# sym_freq_4: ['ACLS', 'CAR', 'MCFT', 'SMG', 'TNK']
# sym_freq_3: ['ALGN', 'BVH', 'CINF', 'COUP', 'DCP', 'ELF', 'FCF', 'IPGP']
# sym_freq_2: ['CTLT', 'TA']
#
# sym_freq_6: ['AU', 'COLL']
# sym_freq_5: ['BVH', 'EXAS']
# sym_freq_4: ['ACIW', 'BMA', 'CLF', 'HSBC', 'SHYF']
# sym_freq_3: ['AJRD', 'BABA', 'BURL', 'DENN', 'HEES', 'HZNP', 'PLAY', 'SPR', 'TPX', 'ZUMZ']
# sym_freq_2: ['ACLS']
#
# sym_freq_6: ['HLIT', 'LOCO']
# sym_freq_5: ['ASC', 'CATO', 'SIGI', 'STLD']
# sym_freq_4: ['CAR', 'CLMT', 'ISEE', 'WWE', 'XPRO']
# sym_freq_3: ['ATCO', 'ATEN', 'BIIB', 'CSGS', 'HFWA', 'M', 'NTNX', 'PBF']
# sym_freq_2: ['SLB']
#
# sym_freq_6: ['AJRD', 'ZTO']
# sym_freq_5: ['BURL', 'BVH', 'COUP', 'GDS']
# sym_freq_4: ['AMBA', 'EXAS']
# sym_freq_3: ['AGYS', 'AZTA', 'BMRN', 'CAT', 'EDU', 'ENV', 'HTHT', 'KDNY', 'NSTG', 'NVO']
# sym_freq_2: ['BBW', 'HZNP']
#
# sym_freq_6: ['HAL', 'SLB', 'STRL']
# sym_freq_5: ['GILD', 'XPRO']
# sym_freq_4: ['APA', 'ASC', 'CAT', 'COP', 'MRO', 'NOV', 'PTEN', 'RMBS']
# sym_freq_3: ['ATEN', 'BSM', 'CCRN', 'CVE', 'ELF', 'ENLC', 'FANG']
# sym_freq_2: []
#
# sym_freq_6: ['HLIT', 'LOCO']
# sym_freq_5: ['AAWW', 'ASC', 'AZPN', 'XPRO']
# sym_freq_4: ['ATEN', 'BIIB', 'CLMT', 'FTI', 'HFWA', 'MODN', 'MUR', 'PBF', 'WAFD']
# sym_freq_3: ['ATCO', 'CCRN', 'FCN', 'IBOC', 'ISEE']
# sym_freq_2: []
#
# sym_freq_6: []
# sym_freq_5: ['NATI', 'SBGI', 'W']
# sym_freq_4: ['CLF', 'LRN', 'MARA', 'NEOG', 'PHM', 'RVNC', 'SMG']
# sym_freq_3: ['ACLS', 'ALLY', 'BURL', 'COUP', 'PEN', 'PUK', 'SHYF', 'VRNS', 'ZTO']
# sym_freq_2: ['BVH']
#
# sym_freq_6: []
# sym_freq_5: ['ANF', 'AXSM', 'BERY', 'BURL', 'GILD', 'MRK']
# sym_freq_4: ['BKE', 'HEES']
# sym_freq_3: ['BBWI', 'BVH', 'CTRN', 'ELF', 'GPS', 'IIM', 'INCY', 'NOMD', 'ROST']
# sym_freq_2: ['BBW', 'HZNP', 'AEO']
#
# sym_freq_6: ['BURL', 'COUP', 'MSGS']
# sym_freq_5: ['ACGL', 'BVH', 'MRK', 'SJW']
# sym_freq_4: ['AXSM', 'EDU', 'ZTO']
# sym_freq_3: ['AGYS', 'BA', 'BGNE', 'BMA', 'CAG', 'CALM', 'CAT']
# sym_freq_2: ['HZNP', 'AJRD', 'NVO']
#
# sym_freq_6: ['AU', 'HZNP']
# sym_freq_5: ['EXAS']
# sym_freq_4: ['ACIW', 'AJRD', 'ANF', 'BABA', 'BMA', 'BVH']
# sym_freq_3: ['ACGL', 'BURL', 'CHTR', 'GDS', 'HEES', 'KN', 'MLKN', 'NKE', 'PLAY', 'SHYF']
# sym_freq_2: ['COLL']
#
# sym_freq_6: ['CTLT']
# sym_freq_5: ['ACLS', 'FORM']
# sym_freq_4: ['ALGN', 'ELF', 'ICPT', 'LRN', 'NVDA', 'THR', 'TSLA']
# sym_freq_3: ['BIDU', 'BVH', 'CINF', 'MMS', 'MPWR', 'MTH', 'RCL', 'RVNC']
# sym_freq_2: ['META', 'CRUS']
#
# sym_freq_6: []
# sym_freq_5: ['ANF', 'AXSM', 'BERY', 'BURL', 'GILD', 'MRK']
# sym_freq_4: ['BKE', 'HEES']
# sym_freq_3: ['BBWI', 'BVH', 'CTRN', 'ELF', 'GPS', 'IIM', 'INCY', 'NOMD', 'ROST']
# sym_freq_2: ['BBW', 'HZNP', 'AEO']
#
# sym_freq_6: ['BVH', 'HSBC']
# sym_freq_5: ['ACLS', 'MELI', 'NTES', 'PUK', 'TX']
# sym_freq_4: ['BOOT', 'COLL', 'EXAS', 'MARA', 'RVNC', 'WB']
# sym_freq_3: ['ALGN', 'AU', 'BMA', 'CCU', 'EDU', 'HZNP', 'LVS']
# sym_freq_2: []
#
# sym_freq_6: ['BURL', 'NVO']
# sym_freq_5: ['AJRD', 'MSGS', 'WB']
# sym_freq_4: ['BMA', 'BVH', 'COLL', 'GDS', 'SJW', 'ZTO']
# sym_freq_3: ['ACGL', 'AGYS', 'ALL', 'ARWR', 'BBW', 'BGNE', 'BUD', 'CAT']
# sym_freq_2: ['HZNP']
#
# sym_freq_6: ['AJRD', 'BURL', 'BVH', 'COUP', 'MSGS', 'NVO']
# sym_freq_5: ['ACGL', 'ARWR', 'BMA']
# sym_freq_4: ['CCU', 'SJW']
# sym_freq_3: ['AGYS', 'AMBC', 'AXSM', 'BBW', 'BDX', 'BUD', 'CAT', 'ELF']
# sym_freq_2: ['HZNP']
#
# sym_freq_6: ['AU', 'HZNP']
# sym_freq_5: ['EXAS']
# sym_freq_4: ['ACIW', 'AJRD', 'ANF', 'BABA', 'BMA', 'BVH']
# sym_freq_3: ['ACGL', 'BURL', 'CHTR', 'GDS', 'HEES', 'KN', 'MLKN', 'NKE', 'PLAY', 'SHYF']
# sym_freq_2: ['COLL']
#
# sym_freq_6: ['AMKR', 'GILD']
# sym_freq_5: ['GBX', 'PKX', 'RMBS']
# sym_freq_4: ['ASC', 'BA', 'ELF', 'EME', 'LOCO', 'RCL', 'SRI']
# sym_freq_3: ['CAT', 'CHGG', 'FTI', 'HEES', 'HFWA', 'MODN', 'NTNX']
# sym_freq_2: ['AXON']
#
# sym_freq_6: ['AJRD', 'ZTO']
# sym_freq_5: ['BURL', 'BVH', 'COUP', 'GDS']
# sym_freq_4: ['AMBA', 'EXAS']
# sym_freq_3: ['AGYS', 'AZTA', 'BMRN', 'CAT', 'EDU', 'ENV', 'HTHT', 'KDNY', 'NSTG', 'NVO']
# sym_freq_2: ['BBW', 'HZNP']
#
# sym_freq_6: []
# sym_freq_5: ['ANF', 'ATKR', 'AXSM', 'GILD']
# sym_freq_4: ['BKE']
# sym_freq_3: ['ATEN', 'BIDU', 'BURL', 'BVH', 'CTRN', 'ELF', 'EME', 'GDS', 'MRK', 'PEN', 'ROST', 'SKX']
# sym_freq_2: ['BBW', 'HZNP', 'AEO']
#
# sym_freq_6: ['AMKR']
# sym_freq_5: ['ELF', 'GILD']
# sym_freq_4: ['ASC', 'RMBS']
# sym_freq_3: ['BIIB', 'FTI', 'GBX', 'GE', 'ISEE', 'MODN', 'NTNX', 'OSBC', 'TSM', 'UNFI', 'UVV', 'YUMC']
# sym_freq_2: ['AXON', 'ACLS', 'BABA']
#
# sym_freq_6: ['ALGN']
# sym_freq_5: ['TSLA']
# sym_freq_4: ['ACLS', 'CAR', 'COUP', 'META', 'MMS', 'ON', 'THR']
# sym_freq_3: ['BURL', 'BVH', 'ELF', 'FCF', 'MPWR', 'MTH', 'NSTG', 'PAR', 'PEN']
# sym_freq_2: ['CRUS', 'CTLT']
#
# sym_freq_6: ['AMKR', 'GILD']
# sym_freq_5: ['GBX', 'PKX', 'RMBS']
# sym_freq_4: ['ASC', 'BA', 'ELF', 'EME', 'LOCO', 'RCL', 'SRI']
# sym_freq_3: ['CAT', 'CHGG', 'FTI', 'HEES', 'HFWA', 'MODN', 'NTNX']
# sym_freq_2: ['AXON']
#
# sym_freq_6: []
# sym_freq_5: ['ALGN', 'CTLT', 'THR']
# sym_freq_4: ['ACLS', 'ELF', 'ICPT', 'NVDA', 'RCL', 'SMG', 'TSLA', 'W']
# sym_freq_3: ['BIDU', 'BURL', 'BVH', 'CINF', 'MEOH', 'NSTG', 'NYT']
# sym_freq_2: ['META', 'CRUS']
#
# sym_freq_6: ['AJRD', 'BBW', 'BVH', 'ZTO']
# sym_freq_5: ['BURL', 'COUP', 'GDS', 'NVO', 'PFGC']
# sym_freq_4: ['ACGL', 'EDU', 'SJW']
# sym_freq_3: ['AGYS', 'AMBA', 'AZTA', 'BMRN', 'CAT', 'ENV', 'EXAS']
# sym_freq_2: ['HZNP']
#
# sym_freq_6: ['AZPN', 'HLIT', 'LOCO']
# sym_freq_5: ['WAFD', 'XPRO']
# sym_freq_4: ['AAWW', 'BIIB', 'HFWA', 'TNK']
# sym_freq_3: ['AVXL', 'CCRN', 'CLMT', 'ELF', 'FBP', 'FCN', 'FSLR', 'IBOC', 'IRBT', 'LRN']
# sym_freq_2: ['ISEE']
#
# sym_freq_6: ['HLIT', 'LOCO']
# sym_freq_5: ['ASC', 'CATO', 'SIGI', 'STLD']
# sym_freq_4: ['CAR', 'CLMT', 'ISEE', 'WWE', 'XPRO']
# sym_freq_3: ['ATCO', 'ATEN', 'BIIB', 'CSGS', 'HFWA', 'M', 'NTNX', 'PBF']
# sym_freq_2: ['SLB']

# %%
from myUtils import symb_perf_stats_vectorized_v8

print('z_grp_top_set_syms_n_freq:')
z_grp_top_set_syms_n_freq = zip(max_lookback_slices, grp_top_set_syms_n_freq)

for i, (_lookback_slice, _top_set_syms_n_freq) in enumerate(z_grp_top_set_syms_n_freq):
  start_train = _lookback_slice[0]
  end_train = _lookback_slice[1]
  start_eval = end_train
  end_eval = _lookback_slice[2]

  print(f'{i + 1 } of {n_samples} max_lookback_slice')
  print(f'max_lookback_slice: {_lookback_slice}')
  # dates correspond to max_lookback_slice
  d_start_train = df_train.index[start_train].strftime('%Y-%m-%d')
  d_end_train = df_train.index[end_train].strftime('%Y-%m-%d')
  d_start_eval = d_end_train
  d_end_eval = df_train.index[end_eval].strftime('%Y-%m-%d')
  d_df_eval_start = d_end_train
  d_df_eval_end = df_train.index[end_eval - 1].strftime('%Y-%m-%d')  
  print(f'max lookback dates: {d_start_train}, {d_end_train}, {d_end_eval}')
  print(f'df_eval dates (inclusive): {d_df_eval_start} - {d_df_eval_end}')    
  print(f'top_set_syms_n_freq: {_top_set_syms_n_freq}\n')

  l_sym_freq_cnt = top_set_sym_freq_cnt(_top_set_syms_n_freq)
  print(f'sym_freq_6: {l_sym_freq_cnt[0]}')
  print(f'sym_freq_5: {l_sym_freq_cnt[1]}')
  print(f'sym_freq_4: {l_sym_freq_cnt[2]}')
  print(f'sym_freq_3: {l_sym_freq_cnt[3]}\n')

  _sym_idx = ['SPY']
  df_SPY = df_train[start_eval:end_eval][_sym_idx]

  (
    _symbols,
    _period_yr,
    _retn,
    _DD,
    _UI,
    _MDD,
    _retnMean,
    _retnStd,
    _retnStd_div_UI,
    _CAGR,
    _CAGR_div_retnStd,
    _CAGR_div_UI,
    SPY_retnStd_d_UI,     
    SPY_CAGR,
    SPY_CAGR_d_retnStd,
    SPY_CAGR_d_UI,
  ) = symb_perf_stats_vectorized_v8(df_SPY)  

  print(f'\nSPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR: {SPY_retnStd_d_UI[0]:>17,.1f}, {SPY_CAGR_d_retnStd[0]:>17,.1f}, {SPY_CAGR_d_UI[0]:>17.1f}, {SPY_CAGR[0]:>17.1f}')

  # drop last list, with frequency count 2 or less, in l_sym_freq_cnt from zip
  zip_cnt_n_syms = zip([6,5,4,3], l_sym_freq_cnt[:-1])  
  for item in zip_cnt_n_syms:
    sym_freq_cnt = item[0]
    syms = item[1]
    if syms:  # iterate ONLY if there are symbols in syms
      df_eval = df_train[start_eval:end_eval][syms]      

      if verbose:
        print(f'start_eval: {start_eval},  date: {d_end_train}')
        print(f'end_eval:   {end_eval},  date: {d_end_eval},  df_eval last date: {d_df_eval_end}')
        print(f'frequency count of symbol(s): {sym_freq_cnt}')      
        # print(f'\ndf_eval:\n{df_eval}\n')

        syms_n_SPY = syms + ['SPY']
        df_eval_n_SPY = df_train[start_eval:end_eval][syms_n_SPY]   
        print(f'\ndf_eval_n_SPY:\n{df_eval_n_SPY}\n')

      (
        _symbols,
        _period_yr,
        _retn,
        _DD,
        _UI,
        _MDD,
        _retnMean,
        _retnStd,
        _retnStd_div_UI,
        _CAGR,
        _CAGR_div_retnStd,
        _CAGR_div_UI,
        grp_retnStd_d_UI,     
        grp_CAGR,
        grp_CAGR_d_retnStd,
        grp_CAGR_d_UI,
      ) = symb_perf_stats_vectorized_v8(df_eval)  
      print(f'grp(retnStd/UI):   mean, std, mean/std: {grp_retnStd_d_UI[0]  :>17,.1f}, {grp_retnStd_d_UI[1]  :>17,.1f}, {grp_retnStd_d_UI[2]  :>17,.1f}')
      print(f'grp(CAGR/retnStd): mean, std, mean/std: {grp_CAGR_d_retnStd[0]:>17,.1f}, {grp_CAGR_d_retnStd[1]:>17,.1f}, {grp_CAGR_d_retnStd[2]:>17,.1f}')
      print(f'grp(CAGR/UI):      mean, std, mean/std: {grp_CAGR_d_UI[0]     :>17,.1f}, {grp_CAGR_d_UI[1]     :>17,.1f}, {grp_CAGR_d_UI[2]     :>17,.1f}')
      print(f'grp(CAGR):         mean, std, mean/std: {grp_CAGR[0]          :>17,.1f}, {grp_CAGR[1]          :>17,.1f}, {grp_CAGR[2]          :>17,.1f}')

      if store_results:  # record results to df
        row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt]
        row_add1      = [grp_CAGR[0],           grp_CAGR[1],           grp_CAGR[2]]
        row_add2      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
        row_add3      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
        row_add4      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
        row_add5      = [SPY_CAGR[0], SPY_CAGR_d_UI[0], SPY_CAGR_d_retnStd[0], SPY_retnStd_d_UI[0]]
        row_add_total = row_add0 + row_add1 + row_add2 + row_add3 + row_add4 + row_add5
        print(f'row_add_total: {row_add_total}')


        # df_eval_sym_freq_results.loc[len(df_eval_sym_freq_results)] = row_add_total
        # print(f'appended row_add to df_eval_sym_freq_results:\n{row_add_total}\n')
        df_eval_sym_freq_results_test.loc[len(df_eval_sym_freq_results_test)] = row_add_total       
        print(f'appended row_add to df_eval_sym_freq_results_test:\n{row_add_total}\n')        
  
  
  print('='*50, '\n')
# Out:
# z_grp_top_set_syms_n_freq:
# 1 of 57 max_lookback_slice
# max_lookback_slice: (19, 79, 83)
# max lookback dates: 2022-08-18, 2022-11-11, 2022-11-17
# df_eval dates (inclusive): 2022-11-11 - 2022-11-16
# top_set_syms_n_freq: [('AXON', 6), ('GILD', 6), ('GBX', 5), ('LOCO', 5), ('RMBS', 5), ('SLB', 5), ('STRL', 5), ('ASC', 4), ('ELF', 4), ('EME', 4), ('SANM', 4), ('ATEN', 3), ('CAT', 3), ('CCRN', 3), ('FTI', 3), ('HEES', 3), ('HOG', 3), ('NTNX', 3), ('SKT', 3), ('TWNK', 3)]
#
# sym_freq_6: ['AXON', 'GILD']
# sym_freq_5: ['GBX', 'LOCO', 'RMBS', 'SLB', 'STRL']
# sym_freq_4: ['ASC', 'ELF', 'EME', 'SANM']
# sym_freq_3: ['ATEN', 'CAT', 'CCRN', 'FTI', 'HEES', 'HOG', 'NTNX', 'SKT', 'TWNK']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.4,             -60.9,             -83.2,              -0.5
# grp(retnStd/UI):   mean, std, mean/std:               6.0,               2.3,               2.6
# grp(CAGR/retnStd): mean, std, mean/std:           1,063.6,             738.8,               1.4
# grp(CAGR/UI):      mean, std, mean/std:           4,655.2,           1,959.9,               2.4
# grp(CAGR):         mean, std, mean/std:              19.5,              17.6,               1.1
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 19.50606605907694, 17.55768162824051, 1.1109704841499441, 4655.183309655495, 1959.8722987656465, 2.375248281527011, 1063.6396686975836, 738.7764838023492, 1.439731355853698, 5.983430908972917, 2.313326422144985, 2.5865052383852087, -0.4766428757124376, -83.1849767087381, -60.85837399150734, 1.3668616371568914]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 19.50606605907694, 17.55768162824051, 1.1109704841499441, 4655.183309655495, 1959.8722987656465, 2.375248281527011, 1063.6396686975836, 738.7764838023492, 1.439731355853698, 5.983430908972917, 2.313326422144985, 2.5865052383852087, -0.4766428757124376, -83.1849767087381, -60.85837399150734, 1.3668616371568914]
#
# grp(retnStd/UI):   mean, std, mean/std:               1.1,               0.2,               4.4
# grp(CAGR/retnStd): mean, std, mean/std:             -38.4,              15.6,              -2.5
# grp(CAGR/UI):      mean, std, mean/std:             -38.4,              15.9,              -2.4
# grp(CAGR):         mean, std, mean/std:              -0.8,               0.3,              -2.7
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, -0.7953051908337463, 0.29952442075247687, -2.6552265382426907, -38.424011661013886, 15.85607030633355, -2.4232997784870944, -38.41226791804833, 15.645449468920175, -2.4551719012198814, 1.0644826621119818, 0.24444306975490251, 4.354726289353649, -0.4766428757124376, -83.1849767087381, -60.85837399150734, 1.3668616371568914]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, -0.7953051908337463, 0.29952442075247687, -2.6552265382426907, -38.424011661013886, 15.85607030633355, -2.4232997784870944, -38.41226791804833, 15.645449468920175, -2.4551719012198814, 1.0644826621119818, 0.24444306975490251, 4.354726289353649, -0.4766428757124376, -83.1849767087381, -60.85837399150734, 1.3668616371568914]
#
# grp(retnStd/UI):   mean, std, mean/std:           4,049.6,           7,010.7,               0.6
# grp(CAGR/retnStd): mean, std, mean/std:           7,407.3,          12,407.6,               0.6
# grp(CAGR/UI):      mean, std, mean/std:     116,971,289.7,     202,598,954.9,               0.6
# grp(CAGR):         mean, std, mean/std:              61.5,              99.6,               0.6
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 61.49071900685924, 99.60958725942712, 0.6173172753613605, 116971289.69923353, 202598954.87414366, 0.5773538652847305, 7407.333037667954, 12407.560986937016, 0.5970015416782215, 4049.6346857378057, 7010.698405804846, 0.577636413853535, -0.4766428757124376, -83.1849767087381, -60.85837399150734, 1.3668616371568914]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 61.49071900685924, 99.60958725942712, 0.6173172753613605, 116971289.69923353, 202598954.87414366, 0.5773538652847305, 7407.333037667954, 12407.560986937016, 0.5970015416782215, 4049.6346857378057, 7010.698405804846, 0.577636413853535, -0.4766428757124376, -83.1849767087381, -60.85837399150734, 1.3668616371568914]
#
# grp(retnStd/UI):   mean, std, mean/std:           5,169.1,          14,615.7,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:          22,157.3,          62,505.0,               0.4
# grp(CAGR/UI):      mean, std, mean/std:   1,028,068,998.1,   2,907,815,992.2,               0.4
# grp(CAGR):         mean, std, mean/std:             517.5,           1,452.7,               0.4
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 517.4843537602336, 1452.727376882431, 0.35621573737445544, 1028068998.0528011, 2907815992.245623, 0.3535536639162827, 22157.289041410688, 62504.97403223965, 0.35448841287386357, 5169.076655209282, 14615.716349492232, 0.3536656385226621, -0.4766428757124376, -83.1849767087381, -60.85837399150734, 1.3668616371568914]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 517.4843537602336, 1452.727376882431, 0.35621573737445544, 1028068998.0528011, 2907815992.245623, 0.3535536639162827, 22157.289041410688, 62504.97403223965, 0.35448841287386357, 5169.076655209282, 14615.716349492232, 0.3536656385226621, -0.4766428757124376, -83.1849767087381, -60.85837399150734, 1.3668616371568914]
#
# ==================================================
#
# 2 of 57 max_lookback_slice
# max_lookback_slice: (65, 125, 129)
# max lookback dates: 2022-10-24, 2023-01-20, 2023-01-26
# df_eval dates (inclusive): 2023-01-20 - 2023-01-25
# top_set_syms_n_freq: [('BVH', 6), ('BGNE', 5), ('COLL', 5), ('HZNP', 5), ('NEOG', 5), ('BABA', 4), ('EDU', 4), ('EXAS', 4), ('NATI', 4), ('NSTG', 4), ('NTES', 4), ('WB', 4), ('ACIW', 3), ('ACLS', 3), ('ALGN', 3), ('AU', 3), ('BMA', 3), ('BURL', 3), ('CROX', 3), ('DENN', 3)]
#
# sym_freq_6: ['BVH']
# sym_freq_5: ['BGNE', 'COLL', 'HZNP', 'NEOG']
# sym_freq_4: ['BABA', 'EDU', 'EXAS', 'NATI', 'NSTG', 'NTES', 'WB']
# sym_freq_3: ['ACIW', 'ACLS', 'ALGN', 'AU', 'BMA', 'BURL', 'CROX', 'DENN']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:
 1.5680701995526407, 2448.608193043083, 268.01100857422404, 9.136222448731823]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 88.6476785338053, 227.11375062575615, 0.39032281528334767, 172317358.69625962, 455901650.3051449, 0.37797046485996233, 5145.745806632704, 13155.469644364468, 0.3911487727720185, 4317.735152852237, 11415.755606385808, 0.3782259625842864, 1.5680701995526407, 2448.608193043083, 268.01100857422404, 9.136222448731823]
#
# ==================================================
#
# 3 of 57 max_lookback_slice
# max_lookback_slice: (23, 83, 87)
# max lookback dates: 2022-08-24, 2022-11-17, 2022-11-23
# df_eval dates (inclusive): 2022-11-17 - 2022-11-22
# top_set_syms_n_freq: [('AXON', 8), ('ELF', 6), ('GILD', 6), ('AMKR', 5), ('EME', 5), ('RMBS', 5), ('ASC', 4), ('DD', 4), ('LOCO', 4), ('BIIB', 3), ('CAT', 3), ('DENN', 3), ('FTI', 3), ('HFWA', 3), ('LVS', 3), ('MODN', 3), ('NTNX', 3), ('NYT', 3), ('OSBC', 3), ('PKX', 3)]
#
# sym_freq_6: ['ELF', 'GILD']
# sym_freq_5: ['AMKR', 'EME', 'RMBS']
# sym_freq_4: ['ASC', 'DD', 'LOCO']
# sym_freq_3: ['BIIB', 'CAT', 'DENN', 'FTI', 'HFWA', 'LVS', 'MODN', 'NTNX', 'NYT', 'OSBC', 'PKX']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.8,             331.1,            1271.4,               2.3
# grp(retnStd/UI):   mean, std, mean/std:           4,571.4,           4,568.3,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:             681.5,             185.7,               3.7
# grp(CAGR/UI):      mean, std, mean/std:       3,963,444.7,       3,961,881.3,               1.0
# grp(CAGR):         mean, std, mean/std:               7.6,               3.6,               2.1
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 7.5506852402817275, 3.588022200807356, 2.1044143033960925, 3963444.736986281, 3961881.3419624623, 1.0003946092497167, 681.4593934852963, 185.66848362662495, 3.6703019283320883, 4571.448244969191, 4568.294909575719, 1.0006902652862586, 2.3114687241785403, 1271.4019500145357, 331.1366899731401, 3.839507938904821]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 7.5506852402817275, 3.588022200807356, 2.1044143033960925, 3963444.736986281, 3961881.3419624623, 1.0003946092497167, 681.4593934852963, 185.66848362662495, 3.6703019283320883, 4571.448244969191, 4568.294909575719, 1.0006902652862586, 2.3114687241785403, 1271.4019500145357, 331.1366899731401, 3.839507938904821]
#
# grp(retnStd/UI):   mean, std, mean/std:               1.7,               1.2,               1.4
# grp(CAGR/retnStd): mean, std, mean/std:              54.6,             117.9,               0.5
# grp(CAGR/UI):      mean, std, mean/std:             237.5,             363.9,               0.7
# grp(CAGR):         mean, std, mean/std:               0.3,               1.2,               0.2
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 0.2745923045364262, 1.202643911937508, 0.22832386362314583, 237.49211677295207, 363.8750920931461, 0.6526748379692829, 54.555475975994874, 117.91070186408255, 0.46268468521951295, 1.7421948515895833, 1.2111101484915363, 1.4385106538488877, 2.3114687241785403, 1271.4019500145357, 331.1366899731401, 3.839507938904821]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 0.2745923045364262, 1.202643911937508, 0.22832386362314583, 237.49211677295207, 363.8750920931461, 0.6526748379692829, 54.555475975994874, 117.91070186408255, 0.46268468521951295, 1.7421948515895833, 1.2111101484915363, 1.4385106538488877, 2.3114687241785403, 1271.4019500145357, 331.1366899731401, 3.839507938904821]
#
# grp(retnStd/UI):   mean, std, mean/std:          21,242.4,          19,765.9,               1.1
# grp(CAGR/retnStd): mean, std, mean/std:          12,276.1,          16,702.2,               0.7
# grp(CAGR/UI):      mean, std, mean/std:     574,527,617.6,     801,768,812.3,               0.7
# grp(CAGR):         mean, std, mean/std:             287.2,             400.9,               0.7
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 287.2387008181327, 400.9023990632956, 0.7164803739994149, 574527617.571464, 801768812.2966174, 0.7165751632640399, 12276.091191096455, 16702.20870140979, 0.7349980718454477, 21242.407951713863, 19765.854567987964, 1.0747022284640944, 2.3114687241785403, 1271.4019500145357, 331.1366899731401, 3.839507938904821]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 287.2387008181327, 400.9023990632956, 0.7164803739994149, 574527617.571464, 801768812.2966174, 0.7165751632640399, 12276.091191096455, 16702.20870140979, 0.7349980718454477, 21242.407951713863, 19765.854567987964, 1.0747022284640944, 2.3114687241785403, 1271.4019500145357, 331.1366899731401, 3.839507938904821]
#
# grp(retnStd/UI):   mean, std, mean/std:           1,561.6,           4,932.8,               0.3
# grp(CAGR/retnStd): mean, std, mean/std:             145.7,             379.1,               0.4
# grp(CAGR/UI):      mean, std, mean/std:       1,925,253.2,       6,087,424.1,               0.3
# grp(CAGR):         mean, std, mean/std:               1.3,               3.2,               0.4
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 1.3292975264762024, 3.22910243200963, 0.41166161633618875, 1925253.1512213962, 6087424.139097881, 0.3162672925738845, 145.66989735465572, 379.109005424115, 0.38424277785670796, 1561.6114179282747, 4932.841834650785, 0.3165743946944991, 2.3114687241785403, 1271.4019500145357, 331.1366899731401, 3.839507938904821]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 1.3292975264762024, 3.22910243200963, 0.41166161633618875, 1925253.1512213962, 6087424.139097881, 0.3162672925738845, 145.66989735465572, 379.109005424115, 0.38424277785670796, 1561.6114179282747, 4932.841834650785, 0.3165743946944991, 2.3114687241785403, 1271.4019500145357, 331.1366899731401, 3.839507938904821]
#
# ==================================================
#
# 4 of 57 max_lookback_slice
# max_lookback_slice: (41, 101, 105)
# max lookback dates: 2022-09-20, 2022-12-14, 2022-12-20
# df_eval dates (inclusive): 2022-12-14 - 2022-12-19
# top_set_syms_n_freq: [('BBW', 9), ('HZNP', 8), ('NVO', 7), ('ZTO', 6), ('AXSM', 5), ('BIDU', 5), ('GDS', 5), ('AU', 4), ('BVH', 4), ('CTRN', 4), ('PUK', 4), ('WB', 4), ('ACLS', 3), ('AER', 3), ('ATKR', 3), ('BERY', 3), ('BURL', 3), ('COUP', 3), ('ELF', 3), ('GILD', 3)]
#
# sym_freq_6: ['ZTO']
# sym_freq_5: ['AXSM', 'BIDU', 'GDS']
# sym_freq_4: ['AU', 'BVH', 'CTRN', 'PUK', 'WB']
# sym_freq_3: ['ACLS', 'AER', 'ATKR', 'BERY', 'BURL', 'COUP', 'ELF', 'GILD']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.2,            -150.9,             -29.1,              -1.0
# grp(retnStd/UI):   mean, std, mean/std:           5,696.6,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             417.7,               0.0,               inf
# grp(CAGR/UI):      mean, std, mean/std:       2,379,266.2,               0.0,               inf
# grp(CAGR):         mean, std, mean/std:               1.2,               0.0,               inf
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 1.189633089403869, 0.0, inf, 2379266.178807738, 0.0, inf, 417.66093505367445, 0.0, inf, 5696.6452428738, 0.0, inf, -0.984672740089511, -29.087581755731684, -150.90779820001686, 0.19275068686098182]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 1.189633089403869, 0.0, inf, 2379266.178807738, 0.0, inf, 417.66093505367445, 0.0, inf, 5696.6452428738, 0.0, inf, -0.984672740089511, -29.087581755731684, -150.90779820001686, 0.19275068686098182]
#
# grp(retnStd/UI):   mean, std, mean/std:               0.6,               0.1,               4.5
# grp(CAGR/retnStd): mean, std, mean/std:             -41.1,              14.3,              -2.9
# grp(CAGR/UI):      mean, std, mean/std:             -22.7,               8.2,              -2.8
# grp(CAGR):         mean, std, mean/std:              -1.0,               0.0,            -165.1
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, -0.993248657522329, 0.006017083592835545, -165.071440706753, -22.657203382332444, 8.22513925542058, -2.754628545334447, -41.07184996251623, 14.258606920574703, -2.880495281993565, 0.5726699040367654, 0.12697673597514011, 4.510037997424067, -0.984672740089511, -29.087581755731684, -150.90779820001686, 0.19275068686098182]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, -0.993248657522329, 0.006017083592835545, -165.071440706753, -22.657203382332444, 8.22513925542058, -2.754628545334447, -41.07184996251623, 14.258606920574703, -2.880495281993565, 0.5726699040367654, 0.12697673597514011, 4.510037997424067, -0.984672740089511, -29.087581755731684, -150.90779820001686, 0.19275068686098182]
#
# grp(retnStd/UI):   mean, std, mean/std:               0.4,               0.2,               2.2
# grp(CAGR/retnStd): mean, std, mean/std:            -111.3,              76.5,              -1.5
# grp(CAGR/UI):      mean, std, mean/std:             -34.2,              17.5,              -2.0
# grp(CAGR):         mean, std, mean/std:              -0.9,               0.2,              -4.3
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, -0.8769511005429281, 0.2022790506626938, -4.335353056433261, -34.2489145455268, 17.469916643561028, -1.9604509422859835, -111.31736446509481, 76.48850707123184, -1.4553475904743145, 0.42301079619771975, 0.1962869529591951, 2.1550632368604594, -0.984672740089511, -29.087581755731684, -150.90779820001686, 0.19275068686098182]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, -0.8769511005429281, 0.2022790506626938, -4.335353056433261, -34.2489145455268, 17.469916643561028, -1.9604509422859835, -111.31736446509481, 76.48850707123184, -1.4553475904743145, 0.42301079619771975, 0.1962869529591951, 2.1550632368604594, -0.984672740089511, -29.087581755731684, -150.90779820001686, 0.19275068686098182]
#
# grp(retnStd/UI):   mean, std, mean/std:               0.5,               0.4,               1.3
# grp(CAGR/retnStd): mean, std, mean/std:             -97.1,              43.2,              -2.2
# grp(CAGR/UI):      mean, std, mean/std:             -37.6,              19.2,              -2.0
# grp(CAGR):         mean, std, mean/std:              -0.9,               0.3,              -2.9
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.8542783140433579, 0.29539343554510034, -2.8920016874001506, -37.645985223097256, 19.185557188806772, -1.9622044255801263, -97.09476659586308, 43.23745793243921, -2.2456169080887856, 0.48157575242292094, 0.361786713720228, 1.33110402941808, -0.984672740089511, -29.087581755731684, -150.90779820001686, 0.19275068686098182]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.8542783140433579, 0.29539343554510034, -2.8920016874001506, -37.645985223097256, 19.185557188806772, -1.9622044255801263, -97.09476659586308, 43.23745793243921, -2.2456169080887856, 0.48157575242292094, 0.361786713720228, 1.33110402941808, -0.984672740089511, -29.087581755731684, -150.90779820001686, 0.19275068686098182]
#
# ==================================================
#
# 5 of 57 max_lookback_slice
# max_lookback_slice: (9, 69, 73)
# max lookback dates: 2022-08-04, 2022-10-28, 2022-11-03
# df_eval dates (inclusive): 2022-10-28 - 2022-11-02
# top_set_syms_n_freq: [('HLIT', 6), ('ASC', 5), ('CAR', 5), ('CATO', 5), ('LOCO', 5), ('PBF', 5), ('SIGI', 5), ('SLB', 5), ('BBW', 4), ('ISEE', 4), ('STLD', 4), ('XPRO', 4), ('ATEN', 3), ('BIIB', 3), ('CBRL', 3), ('CCRN', 3), ('DINO', 3), ('GBX', 3), ('NTNX', 3), ('PCG', 3)]
#
# sym_freq_6: ['HLIT']
# sym_freq_5: ['ASC', 'CAR', 'CATO', 'LOCO', 'PBF', 'SIGI', 'SLB']
# sym_freq_4: ['BBW', 'ISEE', 'STLD', 'XPRO']
# sym_freq_3: ['ATEN', 'BIIB', 'CBRL', 'CCRN', 'DINO', 'GBX', 'NTNX', 'PCG']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.5,            -104.2,             -49.2,              -1.0
# grp(retnStd/UI):   mean, std, mean/std:               0.8,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -18.2,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -14.0,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -1.0,               0.0,              -inf
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, -0.9994882901171591, 0.0, -inf, -13.997067254099651, 0.0, -inf, -18.20218791292116, 0.0, -inf, 0.7689771867569597, 0.0, inf, -0.9555024482420653, -49.194403575653766, -104.19308537004025, 0.47214652873499763]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, -0.9994882901171591, 0.0, -inf, -13.997067254099651, 0.0, -inf, -18.20218791292116, 0.0, -inf, 0.7689771867569597, 0.0, inf, -0.9555024482420653, -49.194403575653766, -104.19308537004025, 0.47214652873499763]
#
# grp(retnStd/UI):   mean, std, mean/std:               1.5,               1.3,               1.1
# grp(CAGR/retnStd): mean, std, mean/std:             531.5,           1,376.1,               0.4
# grp(CAGR/UI):      mean, std, mean/std:           2,473.4,           6,037.3,               0.4
# grp(CAGR):         mean, std, mean/std:              12.2,              30.8,               0.4
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 12.192042448971977, 30.783105950082003, 0.3960627777048436, 2473.37155987771, 6037.335297486533, 0.4096793432870004, 531.5305953781331, 1376.1322390369223, 0.38624964977938564, 1.522393202866365, 1.32720503343704, 1.1470670804524072, -0.9555024482420653, -49.194403575653766, -104.19308537004025, 0.47214652873499763]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 12.192042448971977, 30.783105950082003, 0.3960627777048436, 2473.37155987771, 6037.335297486533, 0.4096793432870004, 531.5305953781331, 1376.1322390369223, 0.38624964977938564, 1.522393202866365, 1.32720503343704, 1.1470670804524072, -0.9555024482420653, -49.194403575653766, -104.19308537004025, 0.47214652873499763]
#
# grp(retnStd/UI):   mean, std, mean/std:               1.1,               0.3,               4.3
# grp(CAGR/retnStd): mean, std, mean/std:             -40.9,              18.8,              -2.2
# grp(CAGR/UI):      mean, std, mean/std:             -40.1,               5.0,              -8.0
# grp(CAGR):         mean, std, mean/std:              -0.9,               0.0,             -25.0
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, -0.8936549929960111, 0.035734342392175926, -25.008295470736797, -40.13562010177779, 4.985979010476437, -8.049696963714778, -40.85538207098041, 18.819018951932154, -2.1709623745708475, 1.09945787656501, 0.25693488826573874, 4.27913034304582, -0.9555024482420653, -49.194403575653766, -104.19308537004025, 0.47214652873499763]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, -0.8936549929960111, 0.035734342392175926, -25.008295470736797, -40.13562010177779, 4.985979010476437, -8.049696963714778, -40.85538207098041, 18.819018951932154, -2.1709623745708475, 1.09945787656501, 0.25693488826573874, 4.27913034304582, -0.9555024482420653, -49.194403575653766, -104.19308537004025, 0.47214652873499763]
#
# grp(retnStd/UI):   mean, std, mean/std:               1.5,               0.9,               1.5
# grp(CAGR/retnStd): mean, std, mean/std:             525.9,           1,153.9,               0.5
# grp(CAGR/UI):      mean, std, mean/std:           1,711.6,           3,739.6,               0.5
# grp(CAGR):         mean, std, mean/std:              19.5,              41.6,               0.5
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 19.476188516585587, 41.64790604522528, 0.467639081192617, 1711.5909045682745, 3739.631727396724, 0.45768969495821643, 525.9441409813809, 1153.9428683672763, 0.45578005237429453, 1.4533118363022401, 0.9447663294513099, 1.538276493348654, -0.9555024482420653, -49.194403575653766, -104.19308537004025, 0.47214652873499763]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 19.476188516585587, 41.64790604522528, 0.467639081192617, 1711.5909045682745, 3739.631727396724, 0.45768969495821643, 525.9441409813809, 1153.9428683672763, 0.45578005237429453, 1.4533118363022401, 0.9447663294513099, 1.538276493348654, -0.9555024482420653, -49.194403575653766, -104.19308537004025, 0.47214652873499763]
#
# ==================================================
#
# 6 of 57 max_lookback_slice
# max_lookback_slice: (29, 89, 93)
# max lookback dates: 2022-09-01, 2022-11-28, 2022-12-02
# df_eval dates (inclusive): 2022-11-28 - 2022-12-01
# top_set_syms_n_freq: [('GPS', 6), ('ANF', 5), ('AXON', 5), ('AEO', 4), ('BURL', 4), ('GILD', 4), ('LSCC', 4), ('RMBS', 4), ('AMKR', 3), ('APD', 3), ('ELF', 3), ('EXTR', 3), ('FTI', 3), ('ISEE', 3), ('MRK', 3), ('PDFS', 3), ('PERI', 3), ('SANM', 3), ('TSM', 3), ('TTC', 3)]
#
# sym_freq_6: ['GPS']
# sym_freq_5: ['ANF', 'AXON']
# sym_freq_4: ['AEO', 'BURL', 'GILD', 'LSCC', 'RMBS']
# sym_freq_3: ['AMKR', 'APD', 'ELF', 'EXTR', 'FTI', 'ISEE', 'MRK', 'PDFS', 'PERI', 'SANM', 'TSM', 'TTC']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR
# max lookback dates: 2022-09-29, 2022-12-23, 2022-12-30
# df_eval dates (inclusive): 2022-12-23 - 2022-12-29
# top_set_syms_n_freq: [('COUP', 6), ('HZNP', 6), ('BBW', 5), ('BURL', 5), ('BVH', 5), ('EDU', 5), ('NVO', 5), ('SJW', 5), ('TCOM', 5), ('WB', 5), ('ZTO', 5), ('BGNE', 4), ('GDS', 4), ('ACGL', 3), ('AJRD', 3), ('BA', 3), ('BMRN', 3), ('CAT', 3), ('COLL', 3), ('EXAS', 3)]
#
# sym_freq_6: ['COUP', 'HZNP']
# sym_freq_5: ['BBW', 'BURL', 'BVH', 'EDU', 'NVO', 'SJW', 'TCOM', 'WB', 'ZTO']
# sym_freq_4: ['BGNE', 'GDS']
# sym_freq_3: ['ACGL', 'AJRD', 'BA', 'BMRN', 'CAT', 'COLL', 'EXAS']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.5,               9.6,              14.7,               0.1
# grp(retnStd/UI):   mean, std, mean/std:           1,627.0,           1,613.5,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:             582.4,             195.3,               3.0
# grp(CAGR/UI):      mean, std, mean/std:       1,262,596.3,       1,257,375.9,               1.0
# grp(CAGR):         mean, std, mean/std:               0.9,               0.4,               2.1
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 0.8598669193809911, 0.4001191421549728, 2.149027199123481, 1262596.2578781154, 1257375.8651938126, 1.0041518155619267, 582.3621631649244, 195.2794114268857, 2.9821995002425834, 1627.0090689352915, 1613.5225659566318, 1.0083584222887294, 0.12320574683675267, 14.674341651750511, 9.60972181005477, 1.5270308487386768]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 0.8598669193809911, 0.4001191421549728, 2.149027199123481, 1262596.2578781154, 1257375.8651938126, 1.0041518155619267, 582.3621631649244, 195.2794114268857, 2.9821995002425834, 1627.0090689352915, 1613.5225659566318, 1.0083584222887294, 0.12320574683675267, 14.674341651750511, 9.60972181005477, 1.5270308487386768]
#
# grp(retnStd/UI):   mean, std, mean/std:               1.9,               0.7,               2.9
# grp(CAGR/retnStd): mean, std, mean/std:             719.7,           1,551.5,               0.5
# grp(CAGR/UI):      mean, std, mean/std:           1,543.8,           3,141.3,               0.5
# grp(CAGR):         mean, std, mean/std:              37.2,              97.8,               0.4
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 37.206884443478366, 97.80054938807129, 0.3804363541542281, 1543.7872820782968, 3141.3014605894723, 0.49144830620255137, 719.6596941039966, 1551.4692737795897, 0.4638568782937015, 1.8773481772640348, 0.6552083566378997, 2.8652689762648276, 0.12320574683675267, 14.674341651750511, 9.60972181005477, 1.5270308487386768]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 37.206884443478366, 97.80054938807129, 0.3804363541542281, 1543.7872820782968, 3141.3014605894723, 0.49144830620255137, 719.6596941039966, 1551.4692737795897, 0.4638568782937015, 1.8773481772640348, 0.6552083566378997, 2.8652689762648276, 0.12320574683675267, 14.674341651750511, 9.60972181005477, 1.5270308487386768]
#
# grp(retnStd/UI):   mean, std, mean/std:               2.0,               1.0,               2.0
# grp(CAGR/retnStd): mean, std, mean/std:          13,727.6,          13,761.3,               1.0
# grp(CAGR/UI):      mean, std, mean/std:          41,760.4,          41,794.7,               1.0
# grp(CAGR):         mean, std, mean/std:             520.9,             521.5,               1.0
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 520.9131557958723, 521.4831553899008, 0.9989069645143142, 41760.44541609888, 41794.73731019574, 0.9991795164582002, 13727.567661446896, 13761.30498823157, 0.9975483918993492, 2.0280189968420426, 1.0115812003407243, 2.0048009948770877, 0.12320574683675267, 14.674341651750511, 9.60972181005477, 1.5270308487386768]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 520.9131557958723, 521.4831553899008, 0.9989069645143142, 41760.44541609888, 41794.73731019574, 0.9991795164582002, 13727.567661446896, 13761.30498823157, 0.9975483918993492, 2.0280189968420426, 1.0115812003407243, 2.0048009948770877, 0.12320574683675267, 14.674341651750511, 9.60972181005477, 1.5270308487386768]
#
# grp(retnStd/UI):   mean, std, mean/std:              64.6,             155.5,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:             210.9,             557.1,               0.4
# grp(CAGR/UI):      mean, std, mean/std:         100,159.6,         245,361.8,               0.4
# grp(CAGR):         mean, std, mean/std:              -0.1,               0.5,              -0.2
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.09132197217811065, 0.46020322543390085, -0.19843835751478725, 100159.57841504793, 245361.82087752386, 0.4082117505357287, 210.90527051554636, 557.075745194591, 0.3785935258083718, 64.63258380385915, 155.54441621761396, 0.41552493734931073, 0.12320574683675267, 14.674341651750511, 9.60972181005477, 1.5270308487386768]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.09132197217811065, 0.46020322543390085, -0.19843835751478725, 100159.57841504793, 245361.82087752386, 0.4082117505357287, 210.90527051554636, 557.075745194591, 0.3785935258083718, 64.63258380385915, 155.54441621761396, 0.41552493734931073, 0.12320574683675267, 14.674341651750511, 9.60972181005477, 1.5270308487386768]
#
# ==================================================
#
# 8 of 57 max_lookback_slice
# max_lookback_slice: (33, 93, 97)
# max lookback dates: 2022-09-08, 2022-12-02, 2022-12-08
# df_eval dates (inclusive): 2022-12-02 - 2022-12-07
# top_set_syms_n_freq: [('BBW', 9), ('HZNP', 9), ('BURL', 5), ('ROST', 5), ('AEO', 4), ('ANF', 4), ('AXON', 4), ('ELF', 4), ('GILD', 4), ('GPS', 4), ('AMKR', 3), ('ATKR', 3), ('BMRN', 3), ('CTRN', 3), ('FTI', 3), ('MRK', 3), ('PDFS', 3), ('RMBS', 3), ('SANM', 3), ('ACLS', 2)]
#
# sym_freq_6: []
# sym_freq_5: ['BURL', 'ROST']
# sym_freq_4: ['AEO', 'ANF', 'AXON', 'ELF', 'GILD', 'GPS']
# sym_freq_3: ['AMKR', 'ATKR', 'BMRN', 'CTRN', 'FTI', 'MRK', 'PDFS', 'RMBS', 'SANM']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.3,            -135.1,             -37.8,              -0.9
# grp(retnStd/UI):   mean, std, mean/std:               0.3,               0.2,               1.5
# grp(CAGR/retnStd): mean, std, mean/std:            -365.5,             156.5,              -2.3
# grp(CAGR/UI):      mean, std, mean/std:             -81.0,              29.5,              -2.7
# grp(CAGR):         mean, std, mean/std:              -0.7,               0.2,              -3.6
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, -0.7109574975725974, 0.19745139386275773, -3.600670948247454, -80.96355469679902, 29.450664636957942, -2.749124873575757, -365.50421784172227, 156.53158915516107, -2.335018891806038, 0.31352191270231683, 0.21484498409050495, 1.459293611296243, -0.944286436256797, -37.78092913905939, -135.09531476481112, 0.27966128362654624]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, -0.7109574975725974, 0.19745139386275773, -3.600670948247454, -80.96355469679902, 29.450664636957942, -2.749124873575757, -365.50421784172227, 156.53158915516107, -2.335018891806038, 0.31352191270231683, 0.21484498409050495, 1.459293611296243, -0.944286436256797, -37.78092913905939, -135.09531476481112, 0.27966128362654624]
#
# grp(retnStd/UI):   mean, std, mean/std:               0.9,               0.4,               2.4
# grp(CAGR/retnStd): mean, std, mean/std:             -45.0,              42.6,              -1.1
# grp(CAGR/UI):      mean, std, mean/std:             -29.7,              20.4,              -1.5
# grp(CAGR):         mean, std, mean/std:              -0.7,               0.3,              -2.2
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, -0.7047073277936938, 0.31380833672779385, -2.245661588031604, -29.72817014957687, 20.37637413857216, -1.4589529004231379, -45.047882594840566, 42.58182664847957, -1.057913343331152, 0.8723911092847678, 0.3591891171656968, 2.4287793465700322, -0.944286436256797, -37.78092913905939, -135.09531476481112, 0.27966128362654624]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, -0.7047073277936938, 0.31380833672779385, -2.245661588031604, -29.72817014957687, 20.37637413857216, -1.4589529004231379, -45.047882594840566, 42.58182664847957, -1.057913343331152, 0.8723911092847678, 0.3591891171656968, 2.4287793465700322, -0.944286436256797, -37.78092913905939, -135.09531476481112, 0.27966128362654624]
#
# grp(retnStd/UI):   mean, std, mean/std:               0.6,               0.4,               1.5
# grp(CAGR/retnStd): mean, std, mean/std:             -62.1,              33.0,              -1.9
# grp(CAGR/UI):      mean, std, mean/std:             -28.0,              16.2,              -1.7
# grp(CAGR):         mean, std, mean/std:              -0.8,               0.3,              -2.6
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.8249297037609924, 0.3153349254632379, -2.6160429345057232, -28.045871179491876, 16.18128372143218, -1.7332290603337606, -62.068699087640624, 32.98431804195835, -1.8817639039462604, 0.6365498277030086, 0.4247061225530137, 1.498800685698972, -0.944286436256797, -37.78092913905939, -135.09531476481112, 0.27966128362654624]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.8249297037609924, 0.3153349254632379, -2.6160429345057232, -28.045871179491876, 16.18128372143218, -1.7332290603337606, -62.068699087640624, 32.98431804195835, -1.8817639039462604, 0.6365498277030086, 0.4247061225530137, 1.498800685698972, -0.944286436256797, -37.78092913905939, -135.09531476481112, 0.27966128362654624]
#
# ==================================================
#
# 9 of 57 max_lookback_slice
# max_lookback_slice: (39, 99, 103)
# max lookback dates: 2022-09-16, 2022-12-12, 2022-12-16
# df_eval dates (inclusive): 2022-12-12 - 2022-12-15
# top_set_syms_n_freq: [('BBW', 9), ('HZNP', 8), ('AEO', 6), ('ANF', 6), ('NVO', 6), ('ZTO', 6), ('AXSM', 5), ('BIDU', 5), ('BURL', 5), ('CTRN', 5), ('RIO', 5), ('GDS', 4), ('WB', 4), ('ACLS', 3), ('ATEN', 3), ('ATKR', 3), ('AU', 3), ('AZN', 3), ('COUP', 3), ('ELF', 3)]
#
# sym_freq_6: ['AEO', 'ANF', 'NVO', 'ZTO']
# sym_freq_5: ['AXSM', 'BIDU', 'BURL', 'CTRN', 'RIO']
# sym_freq_4: ['GDS', 'WB']
# sym_freq_3: ['ACLS', 'ATEN', 'ATKR', 'AU', 'AZN', 'COUP', 'ELF']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.8,             -65.8,             -55.0,              -0.9
# grp(retnStd/UI):   mean, std, mean/std:           5,084.5,           8,803.9,               0.6
# grp(CAGR/retnStd): mean, std, mean/std:             950.9,           1,289.5,               0.7
# grp(CAGR/UI):      mean, std, mean/std:      15,728,637.7,      27,241,217.2,               0.6
# grp(CAGR):         mean, std, mean/std:              10.1,              13.3,               0.8
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 10.064587724176395, 13.255238607433638, 0.7592913279231426, 15728637.68714188, 27241217.18433929, 0.5773838070710042, 950.9330974643777, 1289.4715375495014, 0.7374595481739142, 5084.456205802158, 8803.871177904535, 0.5775250572228775, -0.8627069530644641, -55.02394320942013, -65.79245949347768, 0.8363259807132597]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 10.064587724176395, 13.255238607433638, 0.7592913279231426, 15728637.68714188, 27241217.18433929, 0.5773838070710042, 950.9330974643777, 1289.4715375495014, 0.7374595481739142, 5084.456205802158, 8803.871177904535, 0.5775250572228775, -0.8627069530644641, -55.02394320942013, -65.79245949347768, 0.8363259807132597]
#
# grp(retnStd/UI):   mean, std, mean/std:               0.8,               0.4,               2.0
# grp(CAGR/retnStd): mean, std, mean/std:            -126.9,             140.4,              -0.9
# grp(CAGR/UI):      mean, std, mean/std:             -48.0,              14.8,              -3.2
# grp(CAGR):         mean, std, mean/std:              -0.8,               0.1,              -5.6
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, -0.826669696018093, 0.1472077626666562, -5.615666463799472, -47.99160900332349, 14.8328039797678, -3.23550483568615, -126.8583319936419, 140.4337261720672, -0.9033323792762433, 0.8036878475096497, 0.4008782818862517, 2.004817631247218, -0.8627069530644641, -55.02394320942013, -65.79245949347768, 0.8363259807132597]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, -0.826669696018093, 0.1472077626666562, -5.615666463799472, -47.99160900332349, 14.8328039797678, -3.23550483568615, -126.8583319936419, 140.4337261720672, -0.9033323792762433, 0.8036878475096497, 0.4008782818862517, 2.004817631247218, -0.8627069530644641, -55.02394320942013, -65.79245949347768, 0.8363259807132597]
#
# grp(retnStd/UI):   mean, std, mean/std:               5.7,               4.1,               1.4
# grp(CAGR/retnStd): mean, std, mean/std:             609.5,             557.0,               1.1
# grp(CAGR/UI):      mean, std, mean/std:           5,760.1,           5,678.5,               1.0
# grp(CAGR):         mean, std, mean/std:              14.1,              10.9,               1.3
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 14.080609465890984, 10.870783733908336, 1.2952708664390502, 5760.135768492462, 5678.497901757823, 1.0143766658273077, 609.4769346509281, 556.9870112886954, 1.094239043816816, 5.680776295003161, 4.125470790530291, 1.3770007311754473, -0.8627069530644641, -55.02394320942013, -65.79245949347768, 0.8363259807132597]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 14.080609465890984, 10.870783733908336, 1.2952708664390502, 5760.135768492462, 5678.497901757823, 1.0143766658273077, 609.4769346509281, 556.9870112886954, 1.094239043816816, 5.680776295003161, 4.125470790530291, 1.3770007311754473, -0.8627069530644641, -55.02394320942013, -65.79245949347768, 0.8363259807132597]
#
# grp(retnStd/UI):   mean, std, mean/std:               1.4,               0.5,               2.6
# grp(CAGR/retnStd): mean, std, mean/std:              19.2,              86.5,               0.2
# grp(CAGR/UI):      mean, std, mean/std:              61.7,             162.2,               0.4
# grp(CAGR):         mean, std, mean/std:               0.3,               1.3,               0.2
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 0.2849938017426723, 1.294710559224752, 0.2201216323695708, 61.706078997385156, 162.2161652115148, 0.3803941420815007, 19.23195063470201, 86.50271070122585, 0.22232772220431085, 1.366772054940768, 0.5242044715309201, 2.6073262041225247, -0.8627069530644641, -55.02394320942013, -65.79245949347768, 0.8363259807132597]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 0.2849938017426723, 1.294710559224752, 0.2201216323695708, 61.706078997385156, 162.2161652115148, 0.3803941420815007, 19.23195063470201, 86.50271070122585, 0.22232772220431085, 1.366772054940768, 0.5242044715309201, 2.6073262041225247, -0.8627069530644641, -55.02394320942013, -65.79245949347768, 0.8363259807132597]
#
# ==================================================
#
# 10 of 57 max_lookback_slice
# max_lookback_slice: (71, 131, 135)
# max lookback dates: 2022-11-01, 2023-01-30, 2023-02-03
# df_eval dates (inclusive): 2023-01-30 - 2023-02-02
# top_set_syms_n_freq: [('EXAS', 6), ('HSBC', 6), ('PUK', 6), ('BVH', 5), ('MELI', 5), ('MARA', 4), ('NEOG', 4), ('TX', 4), ('ALGN', 3), ('BMA', 3), ('BURL', 3), ('CCOI', 3), ('CCU', 3), ('COLL', 3), ('HZNP', 3), ('LVS', 3), ('NATI', 3), ('PEN', 3), ('RVNC', 3), ('TSLA', 3)]
#
# sym_freq_6: ['EXAS', 'HSBC', 'PUK']
# sym_freq_5: ['BVH', 'MELI']
# sym_freq_4: ['MARA', 'NEOG', 'TX']
# sym_freq_3: ['ALGN', 'BMA', 'BURL', 'CCOI', 'CCU', 'COLL', 'HZNP', 'LVS', 'NATI', 'PEN', 'RVNC', 'TSLA']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:           3,775.4,          14,242.2,        53769739.6,              26.9
# grp(retnStd/UI):   mean, std, mean/std:           8,352.3,          11,810.3,               0.7
# ...
#
# sym_freq_6: ['AJRD', 'BBW', 'BVH', 'ZTO']
# sym_freq_5: ['BURL', 'COUP', 'GDS', 'NVO', 'PFGC']
# sym_freq_4: ['ACGL', 'EDU', 'SJW']
# sym_freq_3: ['AGYS', 'AMBA', 'AZTA', 'BMRN', 'CAT', 'ENV', 'EXAS']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               0.8,             -79.8,             -62.7,              -0.7
# grp(retnStd/UI):   mean, std, mean/std:             212.3,             365.4,               0.6
# grp(CAGR/retnStd): mean, std, mean/std:             106.9,             183.7,               0.6
# grp(CAGR/UI):      mean, std, mean/std:          81,298.1,         140,651.2,               0.6
# grp(CAGR):         mean, std, mean/std:               0.1,               0.9,               0.1
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 0.10202319620575212, 0.8524258201907142, 0.11968571785275856, 81298.06310555097, 140651.17880157914, 0.578011956943785, 106.9028024908173, 183.66664559149643, 0.582047993235451, 212.3372137826783, 365.3708352070084, 0.5811553449863459, -0.6525343439203135, -62.65964214005915, -79.83230189449435, 0.7848908355776785]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 0.10202319620575212, 0.8524258201907142, 0.11968571785275856, 81298.06310555097, 140651.17880157914, 0.578011956943785, 106.9028024908173, 183.66664559149643, 0.582047993235451, 212.3372137826783, 365.3708352070084, 0.5811553449863459, -0.6525343439203135, -62.65964214005915, -79.83230189449435, 0.7848908355776785]
#
# grp(retnStd/UI):   mean, std, mean/std:           6,022.9,          12,042.7,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:           2,180.9,           4,300.2,               0.5
# grp(CAGR/UI):      mean, std, mean/std:      64,916,993.6,     129,833,836.9,               0.5
# grp(CAGR):         mean, std, mean/std:              33.0,              64.7,               0.5
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 32.99135454170958, 64.66091904793237, 0.5102209344914118, 64916993.553124204, 129833836.87153521, 0.5000005785653294, 2180.863847106624, 4300.225223706561, 0.5071510755027006, 6022.912626893935, 12042.657040766328, 0.5001315412790889, -0.6525343439203135, -62.65964214005915, -79.83230189449435, 0.7848908355776785]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 32.99135454170958, 64.66091904793237, 0.5102209344914118, 64916993.553124204, 129833836.87153521, 0.5000005785653294, 2180.863847106624, 4300.225223706561, 0.5071510755027006, 6022.912626893935, 12042.657040766328, 0.5001315412790889, -0.6525343439203135, -62.65964214005915, -79.83230189449435, 0.7848908355776785]
#
# grp(retnStd/UI):   mean, std, mean/std:              12.5,              15.8,               0.8
# grp(CAGR/retnStd): mean, std, mean/std:           1,038.1,           1,447.9,               0.7
# grp(CAGR/UI):      mean, std, mean/std:          35,811.4,          50,592.3,               0.7
# grp(CAGR):         mean, std, mean/std:              13.3,              19.1,               0.7
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 13.296560511265504, 19.096020681846937, 0.6963000686266266, 35811.36536461135, 50592.277740748665, 0.7078425199221208, 1038.071968400042, 1447.891104415546, 0.7169544486006556, 12.480504621954774, 15.78565746014289, 0.790623048388496, -0.6525343439203135, -62.65964214005915, -79.83230189449435, 0.7848908355776785]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 13.296560511265504, 19.096020681846937, 0.6963000686266266, 35811.36536461135, 50592.277740748665, 0.7078425199221208, 1038.071968400042, 1447.891104415546, 0.7169544486006556, 12.480504621954774, 15.78565746014289, 0.790623048388496, -0.6525343439203135, -62.65964214005915, -79.83230189449435, 0.7848908355776785]
#
# grp(retnStd/UI):   mean, std, mean/std:               1.1,               0.7,               1.6
# grp(CAGR/retnStd): mean, std, mean/std:             -29.9,              88.8,              -0.3
# grp(CAGR/UI):      mean, std, mean/std:              14.9,              81.2,               0.2
# grp(CAGR):         mean, std, mean/std:              -0.2,               0.8,              -0.3
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.23316639159418526, 0.8303611696826301, -0.28080117436525015, 14.935735935587005, 81.2047684832487, 0.18392683354140735, -29.90876112381963, 88.79676907946946, -0.3368226280513936, 1.0745188596481865, 0.656382923553507, 1.6370304910295155, -0.6525343439203135, -62.65964214005915, -79.83230189449435, 0.7848908355776785]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.23316639159418526, 0.8303611696826301, -0.28080117436525015, 14.935735935587005, 81.2047684832487, 0.18392683354140735, -29.90876112381963, 88.79676907946946, -0.3368226280513936, 1.0745188596481865, 0.656382923553507, 1.6370304910295155, -0.6525343439203135, -62.65964214005915, -79.83230189449435, 0.7848908355776785]
#
# ==================================================
#
# 56 of 57 max_lookback_slice
# max_lookback_slice: (2, 62, 66)
# max lookback dates: 2022-07-26, 2022-10-19, 2022-10-25
# df_eval dates (inclusive): 2022-10-19 - 2022-10-24
# top_set_syms_n_freq: [('ISEE', 7), ('AZPN', 6), ('HLIT', 6), ('LOCO', 6), ('WAFD', 5), ('XPRO', 5), ('AAWW', 4), ('BIIB', 4), ('HFWA', 4), ('TNK', 4), ('AVXL', 3), ('CCRN', 3), ('CLMT', 3), ('ELF', 3), ('FBP', 3), ('FCN', 3), ('FSLR', 3), ('IBOC', 3), ('IRBT', 3), ('LRN', 3)]
#
# sym_freq_6: ['AZPN', 'HLIT', 'LOCO']
# sym_freq_5: ['WAFD', 'XPRO']
# sym_freq_4: ['AAWW', 'BIIB', 'HFWA', 'TNK']
# sym_freq_3: ['AVXL', 'CCRN', 'CLMT', 'ELF', 'FBP', 'FCN', 'FSLR', 'IBOC', 'IRBT', 'LRN']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               3.2,             688.4,            2215.8,               9.3
# grp(retnStd/UI):   mean, std, mean/std:           8,721.2,           8,846.0,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:           2,008.9,           1,992.1,               1.0
# grp(CAGR/UI):      mean, std, mean/std:      35,140,325.2,      44,976,061.1,               0.8
# grp(CAGR):         mean, std, mean/std:              17.7,              22.4,               0.8
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 17.685193360824716, 22.398566195418795, 0.78956810032072, 35140325.21068568, 44976061.06892869, 0.781311755087465, 2008.928615418806, 1992.0676559048622, 1.0084640496340396, 8721.231785348971, 8845.960949602355, 0.9858998739691486, 9.290310866698759, 2215.8469978741145, 688.3807429307095, 3.21892647438157]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, 17.685193360824716, 22.398566195418795, 0.78956810032072, 35140325.21068568, 44976061.06892869, 0.781311755087465, 2008.928615418806, 1992.0676559048622, 1.0084640496340396, 8721.231785348971, 8845.960949602355, 0.9858998739691486, 9.290310866698759, 2215.8469978741145, 688.3807429307095, 3.21892647438157]
#
# grp(retnStd/UI):   mean, std, mean/std:          24,965.2,          24,964.0,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:         139,697.5,         139,711.2,               1.0
# grp(CAGR/UI):      mean, std, mean/std:   6,975,330,502.0,   6,975,330,518.5,               1.0
# grp(CAGR):         mean, std, mean/std:           3,487.5,           3,487.8,               1.0
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 3487.5302643159152, 3487.800245919672, 0.9999225925842306, 6975330501.950537, 6975330518.5206375, 0.9999999976244709, 139697.5028931981, 139711.204534812, 0.9999019288276878, 24965.218607966624, 24964.009256435475, 1.0000484438023847, 9.290310866698759, 2215.8469978741145, 688.3807429307095, 3.21892647438157]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 3487.5302643159152, 3487.800245919672, 0.9999225925842306, 6975330501.950537, 6975330518.5206375, 0.9999999976244709, 139697.5028931981, 139711.204534812, 0.9999019288276878, 24965.218607966624, 24964.009256435475, 1.0000484438023847, 9.290310866698759, 2215.8469978741145, 688.3807429307095, 3.21892647438157]
#
# grp(retnStd/UI):   mean, std, mean/std:               2.5,               1.0,               2.4
# grp(CAGR/retnStd): mean, std, mean/std:             494.4,             652.5,               0.8
# grp(CAGR/UI):      mean, std, mean/std:           1,898.0,           2,785.8,               0.7
# grp(CAGR):         mean, std, mean/std:               6.5,               9.5,               0.7
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 6.539406543589379, 9.465296330415262, 0.6908823892365642, 1898.0193659983124, 2785.763018095484, 0.6813283662929496, 494.44677346988044, 652.4567505577897, 0.7578230634401046, 2.527521182947844, 1.049362855285739, 2.408624595597684, 9.290310866698759, 2215.8469978741145, 688.3807429307095, 3.21892647438157]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 6.539406543589379, 9.465296330415262, 0.6908823892365642, 1898.0193659983124, 2785.763018095484, 0.6813283662929496, 494.44677346988044, 652.4567505577897, 0.7578230634401046, 2.527521182947844, 1.049362855285739, 2.408624595597684, 9.290310866698759, 2215.8469978741145, 688.3807429307095, 3.21892647438157]
#
# grp(retnStd/UI):   mean, std, mean/std:               5.1,               5.4,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:           6,576.8,          18,269.1,               0.4
# grp(CAGR/UI):      mean, std, mean/std:          99,649.8,         288,623.3,               0.3
# grp(CAGR):         mean, std, mean/std:             239.7,             682.0,               0.4
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 239.7132838078118, 681.9792100840639, 0.3514964683135482, 99649.80261587005, 288623.2753652014, 0.3452590664761217, 6576.759363054545, 18269.100592552357, 0.359993603939958, 5.127704210398068, 5.371460445440782, 0.9546201191429027, 9.290310866698759, 2215.8469978741145, 688.3807429307095, 3.21892647438157]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 239.7132838078118, 681.9792100840639, 0.3514964683135482, 99649.80261587005, 288623.2753652014, 0.3452590664761217, 6576.759363054545, 18269.100592552357, 0.359993603939958, 5.127704210398068, 5.371460445440782, 0.9546201191429027, 9.290310866698759, 2215.8469978741145, 688.3807429307095, 3.21892647438157]
#
# ==================================================
#
# 57 of 57 max_lookback_slice
# max_lookback_slice: (8, 68, 72)
# max lookback dates: 2022-08-03, 2022-10-27, 2022-11-02
# df_eval dates (inclusive): 2022-10-27 - 2022-11-01
# top_set_syms_n_freq: [('SLB', 7), ('HLIT', 6), ('LOCO', 6), ('ASC', 5), ('CATO', 5), ('SIGI', 5), ('STLD', 5), ('CAR', 4), ('CLMT', 4), ('ISEE', 4), ('WWE', 4), ('XPRO', 4), ('ATCO', 3), ('ATEN', 3), ('BIIB', 3), ('CSGS', 3), ('HFWA', 3), ('M', 3), ('NTNX', 3), ('PBF', 3)]
#
# sym_freq_6: ['HLIT', 'LOCO']
# sym_freq_5: ['ASC', 'CATO', 'SIGI', 'STLD']
# sym_freq_4: ['CAR', 'CLMT', 'ISEE', 'WWE', 'XPRO']
# sym_freq_3: ['ATCO', 'ATEN', 'BIIB', 'CSGS', 'HFWA', 'M', 'NTNX', 'PBF']
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               2.1,             122.3,             251.1,               1.7
# grp(retnStd/UI):   mean, std, mean/std:               1.0,               0.1,               9.4
# grp(CAGR/retnStd): mean, std, mean/std:             -14.9,               4.5,              -3.3
# grp(CAGR/UI):      mean, std, mean/std:             -14.6,               2.9,              -5.0
# grp(CAGR):         mean, std, mean/std:              -0.6,               0.4,              -1.6
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 6, -0.6114053064501858, 0.38835746080782396, -1.5743364506977644, -14.632454996998153, 2.9351767381806697, -4.985204061704265, -14.881915762363366, 4.466643056368107, -3.33178979707057, 1.0155222870273042, 0.1075667178418887, 9.440859658096203, 1.7119788743904265, 251.06796752328296, 122.30758329024215, 2.0527587968726833]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 6, -0.6114053064501858, 0.38835746080782396, -1.5743364506977644, -14.632454996998153, 2.9351767381806697, -4.985204061704265, -14.881915762363366, 4.466643056368107, -3.33178979707057, 1.0155222870273042, 0.1075667178418887, 9.440859658096203, 1.7119788743904265, 251.06796752328296, 122.30758329024215, 2.0527587968726833]
#
# grp(retnStd/UI):   mean, std, mean/std:          12,103.4,          13,116.5,               0.9
# grp(CAGR/retnStd): mean, std, mean/std:           6,436.9,          10,070.1,               0.6
# grp(CAGR/UI):      mean, std, mean/std:     194,796,004.4,     319,232,180.6,               0.6
# grp(CAGR):         mean, std, mean/std:              97.6,             159.5,               0.6
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 97.64353537662056, 159.4678683297471, 0.6123085258449282, 194796004.42093065, 319232180.5921264, 0.6102016534160627, 6436.941038493798, 10070.086910412892, 0.6392140500632354, 12103.413633394619, 13116.478090839293, 0.9227639881354881, 1.7119788743904265, 251.06796752328296, 122.30758329024215, 2.0527587968726833]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 5, 97.64353537662056, 159.4678683297471, 0.6123085258449282, 194796004.42093065, 319232180.5921264, 0.6102016534160627, 6436.941038493798, 10070.086910412892, 0.6392140500632354, 12103.413633394619, 13116.478090839293, 0.9227639881354881, 1.7119788743904265, 251.06796752328296, 122.30758329024215, 2.0527587968726833]
#
# grp(retnStd/UI):   mean, std, mean/std:           6,854.8,          13,703.6,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:           2,713.3,           4,821.4,               0.6
# grp(CAGR/UI):      mean, std, mean/std:      84,532,624.2,     169,061,891.2,               0.5
# grp(CAGR):         mean, std, mean/std:              47.5,              82.4,               0.6
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 47.53467422116724, 82.3772649085355, 0.577036325179594, 84532624.18495625, 169061891.18806168, 0.5000099288545373, 2713.3064892399725, 4821.381984953889, 0.5627653020871198, 6854.841788139706, 13703.614009599358, 0.5002214586121516, 1.7119788743904265, 251.06796752328296, 122.30758329024215, 2.0527587968726833]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 4, 47.53467422116724, 82.3772649085355, 0.577036325179594, 84532624.18495625, 169061891.18806168, 0.5000099288545373, 2713.3064892399725, 4821.381984953889, 0.5627653020871198, 6854.841788139706, 13703.614009599358, 0.5002214586121516, 1.7119788743904265, 251.06796752328296, 122.30758329024215, 2.0527587968726833]
#
# grp(retnStd/UI):   mean, std, mean/std:           2,089.9,           5,508.6,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:           2,326.2,           5,085.1,               0.5
# grp(CAGR/UI):      mean, std, mean/std:      32,673,128.9,      86,425,772.8,               0.4
# grp(CAGR):         mean, std, mean/std:              23.7,              42.4,               0.6
# row_add_total: [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 23.65791458930409, 42.44147664997417, 0.5574243984114179, 32673128.880945265, 86425772.83687177, 0.3780484432880414, 2326.18899148055, 5085.067182388595, 0.45745491810550193, 2089.8728105703144, 5508.626400758976, 0.37938183832586153, 1.7119788743904265, 251.06796752328296, 122.30758329024215, 2.0527587968726833]
# appended row_add to df_eval_sym_freq_results_test:
# [57, '[15, 30, 60]', 4, 20, 0, 10, 3, 23.65791458930409, 42.44147664997417, 0.5574243984114179, 32673128.880945265, 86425772.83687177, 0.3780484432880414, 2326.18899148055, 5085.067182388595, 0.45745491810550193, 2089.8728105703144, 5508.626400758976, 0.37938183832586153, 1.7119788743904265, 251.06796752328296, 122.30758329024215, 2.0527587968726833]
#
# ==================================================

# %%
# pickle_dump(df_eval_sym_freq_results, path_data_dump, fp_df_eval_sym_freq_results)
pickle_dump(df_eval_sym_freq_results_test, path_data_dump, fp_df_eval_sym_freq_results_test)

# %%
# https://towardsdatascience.com/pandas-groupby-a-simple-but-detailed-tutorial-314b8f37005d
# https://towardsdatascience.com/accessing-data-in-a-multiindex-dataframe-in-pandas-569e8767201d
# https://towardsdatascience.com/summarizing-data-with-pandas-crosstab-efc8b9abecf
# https://towardsdatascience.com/how-to-flatten-multiindex-columns-and-rows-in-pandas-f5406c50e569
# https://datascientyst.com/list-aggregation-functions-aggfunc-groupby-pandas/

# %%
df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_test)
df
# Out:
#      n_samples   days_lookbacks days_eval n_top_syms syms_start syms_end sym_freq_cnt  grp(CAGR)_mean  grp(CAGR)_std  grp(CAGR)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  grp(CAGR/retnStd)_mean  grp(CAGR/retnStd)_std  grp(CAGR/retnStd)_mean/std  grp(retnStd/UI)_mean  grp(retnStd/UI)_std  grp(retnStd/UI)_mean/std  SPY_CAGR  SPY_CAGR/UI  SPY_CAGR/retnStd  SPY_retnStd/UI
# 0           57  [15, 30, 60,...         6         20          0       10            6       94.562870      95.360736         0.991633        2.326079e+08       2.326080e+08          1.000000            7572.469282             7689.817721               0.984740                15240.906112          15240.497106             1.000027           1.274855   189.903417       103.706078         1.831170
# 1           57  [15, 30, 60,...         6         20          0       10            5        4.160346      10.496394         0.396360        4.257191e+02       1.006395e+03          0.423014             154.159131              405.007470               0.380633                    1.179793              0.629508             1.874152           1.274855   189.903417       103.706078         1.831170
# 2           57  [15, 30, 60,...         6         20          0       10            4        1.962740       4.378000         0.448319        6.963529e+03       1.857026e+04          0.374983             124.840658              202.122558               0.617648                   53.401984            145.992902             0.365785           1.274855   189.903417       103.706078         1.831170
# 3           57  [15, 30, 60,...         6         20          0       10            3    67966.293119   96120.121112         0.707097        3.447739e+06       4.875893e+06          0.707099          598687.587472           846739.482696               0.707051                    2.455574              2.338732             1.049960           1.274855   189.903417       103.706078         1.831170
# 4           57  [15, 30, 60,...         6         20          0       10            6       -0.468234       0.000000             -inf       -2.598420e+01       0.000000e+00              -inf             -41.701153                0.000000                   -inf                    0.623105              0.000000                  inf           1.911171   232.447231       181.632041         1.279770
# ...        ...              ...       ...        ...        ...      ...          ...             ...            ...              ...                 ...                ...               ...                    ...                     ...                    ...                         ...                   ...                  ...                ...          ...              ...              ...
# 3631        57     [15, 30, 60]         4         20          0       10            3      239.713284     681.979210         0.351496        9.964980e+04       2.886233e+05          0.345259            6576.759363            18269.100593               0.359994                    5.127704              5.371460             0.954620           9.290311  2215.846998       688.380743         3.218926
# 3632        57     [15, 30, 60]         4         20          0       10            6       -0.611405       0.388357        -1.574336       -1.463245e+01       2.935177e+00         -4.985204             -14.881916                4.466643              -3.331790                    1.015522              0.107567             9.440860           1.711979   251.067968       122.307583         2.052759
# 3633        57     [15, 30, 60]         4         20          0       10            5       97.643535     159.467868         0.612309        1.947960e+08       3.192322e+08          0.610202            6436.941038            10070.086910               0.639214                12103.413633          13116.478091             0.922764           1.711979   251.067968       122.307583         2.052759
# 3634        57     [15, 30, 60]         4         20          0       10            4       47.534674      82.377265         0.577036        8.453262e+07       1.690619e+08          0.500010            2713.306489             4821.381985               0.562765                 6854.841788          13703.614010             0.500221           1.711979   251.067968       122.307583         2.052759
# 3635        57     [15, 30, 60]         4         20          0       10            3       23.657915      42.441477         0.557424        3.267313e+07       8.642577e+07          0.378048            2326.188991             5085.067182               0.457455                 2089.872811           5508.626401             0.379382           1.711979   251.067968       122.307583         2.052759
#
# [3636 rows x 23 columns]

# %%
# pd.crosstab(df['days_lookbacks'], df['grp(CAGR/UI)_mean'])
tbl = df.groupby(['days_lookbacks', 'days_eval', 'sym_freq_cnt'])\
        .agg({'grp(CAGR)_mean':          ['count', 'mean', 'std',],
              'grp(CAGR/UI)_mean':       ['mean', 'std',],
              'grp(CAGR/retnStd)_mean':  ['mean', 'std',],
              'SPY_CAGR':                ['mean', 'std',],
              'SPY_CAGR/UI':             ['mean', 'std',],
              'SPY_CAGR/retnStd':        ['mean', 'std',],                           
              })

# %%
tbl
# Out:
#                                         grp(CAGR)_mean                             grp(CAGR/UI)_mean               grp(CAGR/retnStd)_mean                SPY_CAGR              SPY_CAGR/UI               SPY_CAGR/retnStd
#                                                  count          mean           std              mean           std                   mean           std      mean        std          mean           std             mean          std
# days_lookbacks   days_eval sym_freq_cnt
# [120]            4         3                        57  7.160189e+04  3.787630e+05     1.431899e+11   7.575289e+11     1.219301e+06        6.443590e+06  1.622151   5.560079  1.888205e+06  9.981365e+06       583.339314  2648.752670
#                  5         3                        57  4.097137e+03  1.173244e+04     1.703780e+09   5.008042e+09     6.767117e+04        1.950623e+05  1.352828   2.055144  1.382311e+03  2.798544e+03       156.500174   234.768493
#                  6         3                        57  1.146583e+03  3.291551e+03     1.081330e+09   3.513702e+09     2.079432e+04        5.922263e+04  0.808830   1.630601  7.219396e+02  2.497623e+03        92.317989   204.897099
# [15, 30, 60, ... 4         3                        51  8.299452e+08  3.347058e+09     1.657202e+15   6.694768e+15     7.203621e+09        2.905836e+10  1.886524   6.457245  3.498366e+06  1.274541e+07       893.248168  3376.069642
#                            4                        57  1.167023e+04  3.529550e+04     6.611386e+09   2.345191e+10     2.311203e+05        7.189044e+05  1.596529   6.160858  3.130111e+06  1.209189e+07       788.537118  3204.919670
#                            5                        57  8.300062e+01  3.854488e+02     4.563672e+07   1.870784e+08     4.053242e+03        1.322700e+04  1.596529   6.160858  3.130111e+06  1.209189e+07       788.537118  3204.919670
#                            6                        54  1.749694e+01  3.648385e+01     1.877524e+07   5.369208e+07     1.076292e+03        2.258692e+03  1.700482   6.316284  3.304008e+06  1.240584e+07       833.829183  3288.343789
#                  5         3                        54  1.642821e+06  6.758321e+06     3.049406e+08   1.202337e+09     1.449622e+07        5.959657e+07  0.870845   1.706578  1.115844e+03  2.596571e+03       106.165088   207.908369
#                            4                        57  2.751256e+02  1.043525e+03     3.746738e+07   1.869170e+08     6.376060e+03        2.170587e+04  0.788441   1.697291  1.054953e+03  2.539473e+03        96.680240   206.297008
#                            4                        48  1.672579e+00  5.053428e+00     2.104241e+06   9.051168e+06     1.482721e+02        5.653098e+02  1.683298   3.592001  2.696918e+05  1.043477e+06       213.617114   437.184053
#                            5                        17  2.328220e-02  2.600673e-01     9.468496e+04   2.171646e+05     1.608179e+02        2.184174e+02  6.448871  11.739118  1.265344e+07  2.350914e+07      3397.344281  6203.879628
#                  5         3                        57  1.218158e+03  5.360884e+03     2.402176e+08   1.243055e+09     2.067063e+04        8.932326e+04  0.899955   1.801398  1.460272e+03  2.982041e+03       121.047226   224.598526
#                            4                        51  1.204511e+00  2.453598e+00     4.432688e+05   1.530788e+06     1.130984e+02        2.942920e+02  0.604374   1.514296  1.556195e+03  3.138026e+03        98.755694   217.081910
#                            5                        20  2.069140e-01  2.563576e-01     1.601742e+05   3.271721e+05     1.895965e+02        1.605187e+02  0.755158   1.782241  1.937873e+03  3.704009e+03       116.735241   223.890185
#                  6         3                        57  8.448617e+02  2.252115e+03     1.613433e+06   5.998694e+06     1.536324e+04        4.031267e+04  1.362028   2.073423  1.428477e+03  3.689994e+03       161.831837   269.616673
#                            4                        54  1.133591e+00  2.158729e+00     1.549507e+05   1.137622e+06     6.230090e+01        1.515042e+02  1.417735   2.117156  1.506108e+03  3.777580e+03       169.230482   275.223862
#                            5                        18  5.062715e-02  5.646242e-01     8.621612e+02   8.592889e+02     1.017636e+02        1.498597e+02  0.631909   1.528731  1.662109e+02  2.600452e+02        62.998013   159.667079
# [60]             4         3                        57  1.822882e+03  9.684515e+03     3.633813e+09   1.937118e+10     2.743248e+04        1.360450e+05  2.387627   5.319278  1.392903e+06  7.617331e+06       450.980944  1915.430169
#                  5         3                        57  1.781022e+02  6.281373e+02     2.346760e+08   1.174752e+09     3.237532e+03        9.617296e+03  2.596190   7.844253  1.762952e+03  6.981164e+03       163.444216   392.857810
#                  6         3                        57  2.562169e+01  8.308088e+01     4.022217e+07   1.905276e+08     6.720198e+02        1.483608e+03  2.990359   6.293381  1.548455e+03  5.479619e+03       177.728754   326.029401

# %%
tbl['dif_CAGR_mean'] = tbl['grp(CAGR)_mean', 'mean'] - tbl['SPY_CAGR', 'mean']
tbl['dif_CAGR/UI_mean'] = tbl['grp(CAGR/UI)_mean', 'mean'] - tbl['SPY_CAGR/UI', 'mean'] 
tbl['dif_CAGR/retnStd_mean'] = tbl['grp(CAGR/retnStd)_mean', 'mean'] - tbl['SPY_CAGR/retnStd', 'mean'] 
tbl['grp_CAGR/UI_mean/std'] = tbl['grp(CAGR/UI)_mean', 'mean'] / tbl['grp(CAGR/UI)_mean', 'std']  
tbl['SPY_CAGR/UI_mean/std'] = tbl['SPY_CAGR/UI', 'mean'] / tbl['SPY_CAGR/UI', 'std'] 
tbl['dif_CAGR/UI_mean/std'] = tbl['grp_CAGR/UI_mean/std']  - tbl['SPY_CAGR/UI_mean/std'] 
# tbl.sort_values(by='dif_CAGR/UI_mean', ascending=False, inplace=True)
# tbl.sort_values(by='dif_CAGR/UI_mean/std', ascending=False, inplace=True)
      retnMean,
      retnStd,
      retnStd_div_UI,
      CAGR,
      CAGR_div_retnStd,
      CAGR_div_UI,
      grp_retnStd_div_UI,     
      grp_CAGR,
      grp_CAGR_div_retnStd,
      grp_CAGR_div_UI,
    ) = symb_perf_stats_vectorized_v8(_df)

    # display(HTML(_df.to_html()))
    print(f'_df:\n{_df}\n')
    print(f'symbols:\n{symbols}\n')
    print(f'period_yr:\n{period_yr}\n')
    print(f'retn:\n{retn}\n')
    print(f'DD:\n{DD}\n')
    print(f'UI:\n{UI}\n')
    print(f'MDD:\n{MDD}\n')
    print(f'retnMean:\n{retnMean}\n')
    print(f'retnStd:\n{retnStd}\n')
    print(f'retnStd_div_UI:\n{retnStd_div_UI}\n')
    print(f'CAGR:\n{CAGR}\n')
    print(f'CAGR_div_retnStd:\n{CAGR_div_retnStd}\n')
    print(f'CAGR_div_UI:\n{CAGR_div_UI}\n')
    print(f'grp_retnStd_div_UI:\n{grp_retnStd_div_UI}\n')
    print(f'grp_CAGR:\n{grp_CAGR}\n')
    print(f'grp_CAGR_div_retnStd:\n{grp_CAGR_div_retnStd}\n')
    print(f'grp_CAGR_div_UI:\n{grp_CAGR_div_UI}\n')

# %%
# # https://stackoverflow.com/questions/31674195/plot-normal-distribution-given-mean-and-sigma-python
# # loc is mean, scale is standard deviation
# import pylab
# import numpy as np
# from scipy.stats import norm
# # x = np.linspace(-10000,100000,1000)
# x = np.linspace(-40e+10,50e+10,1000)
# y = norm.pdf(x, loc=2.562777e+10, scale=1.036925e+11)    # loc = mean, scale = standard deviation
# # z = norm.pdf(x, loc=3.540615e+10, scale=1.194430e+11)    # for example
# # z1 = norm.pdf(x, loc=298.805901, scale=826.875749)    # for example
# # z1 = norm.pdf(x, loc=1.021825, scale=1.505096)    # for example
# pylab.plot(x,y, 'b')
# # pylab.plot(x,z, 'g')
# # pylab.plot(x,z1, 'r')
# pylab.show()

# %%
# # get values of _cols, where grp(CAGR/retnStd)_mean is max after filtering out inf
# _cols = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
# # _df_no_inf = df.loc[df['grp(CAGR/retnStd)_mean'] != np.inf]  # df with filter out inf in column grp(CAGR/UI)_mean 
# # _idx = _df_no_inf['grp(CAGR/retnStd)_mean'].idxmax()  # index value of max in grp(CAGR/UI)_mean 
# _idx = df['grp(CAGR/retnStd)_mean'].idxmax()  # index value of max in grp(CAGR/UI)_mean 
# grp_inf_replacement = df.loc[[_idx], _cols].squeeze()  # convert df (only has 1 row) to series
# print(f'_idx: {_idx}')
# grp_inf_replacement

# %%
# # get values of _cols, where SPY_CAGR/retnStd is max after filtering out inf
# _cols = ['SPY_CAGR/retnStd']
# # _df_no_inf = df.loc[df['SPY_CAGR/retnStd'] != np.inf]  # df with filter out inf in column grp(CAGR/UI)_mean 
# _idx = df['SPY_CAGR/retnStd'].idxmax()  # index value of max in grp(CAGR/UI)_mean 
# SPY_inf_replacement = df.loc[[_idx], _cols].squeeze()  # convert df (only has 1 row) to series
# print(f'_idx: {_idx}')
# SPY_inf_replacement
