# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
from yf_utils import _2_split_train_val_test, _3_random_slices, _4_lookback_slices
from yf_utils import _5_perf_ranks, _6_grp_tuples_sort_sum
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 16)
pd.set_option('display.width', 790)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"
fp_df_close_clean = 'df_close_clean'
fp_df_eval_sym_freq_results_train = 'df_eval_sym_freq_results_train'
fp_df_eval_sym_freq_results_validate = 'df_eval_sym_freq_results_validate'
fp_df_eval_sym_freq_results_test = 'df_eval_sym_freq_results_test'

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# %%
def top_set_sym_freq_cnt(top_set_syms_n_freq):
    # accommodate upto 5 periods of days_lookbacks(i.e. days_lookbacks = [5, 10, 15, 20, 25])
    sym_freq_cnt_15 = []
    sym_freq_cnt_14 = []
    sym_freq_cnt_13 = []
    sym_freq_cnt_12 = []
    sym_freq_cnt_11 = []
    sym_freq_cnt_10 = []
    sym_freq_cnt_9 = []
    sym_freq_cnt_8 = []
    sym_freq_cnt_7 = []
    sym_freq_cnt_6 = []
    sym_freq_cnt_5 = []
    sym_freq_cnt_4 = []
    sym_freq_cnt_3 = []
    sym_freq_cnt_2 = []

    for sym_n_freq in top_set_syms_n_freq:
        _sym = sym_n_freq[0]
        _freq = sym_n_freq[1]
        # print(_sym, _freq)
        if _freq == 15:
            sym_freq_cnt_15.append(_sym)
        elif _freq == 14:
            sym_freq_cnt_14.append(_sym)
        elif _freq == 13:
            sym_freq_cnt_13.append(_sym)
        elif _freq == 12:
            sym_freq_cnt_12.append(_sym)                        
        elif _freq == 11:
            sym_freq_cnt_11.append(_sym)
        elif _freq == 10:
            sym_freq_cnt_10.append(_sym)            
        elif _freq == 9:
            sym_freq_cnt_9.append(_sym)
        elif _freq == 8:
            sym_freq_cnt_8.append(_sym)
        elif _freq == 7:
            sym_freq_cnt_7.append(_sym)  
        elif _freq == 6:
            sym_freq_cnt_6.append(_sym)
        elif _freq == 5:
            sym_freq_cnt_5.append(_sym)
        elif _freq == 4:
            sym_freq_cnt_4.append(_sym)
        elif _freq == 3:
            sym_freq_cnt_3.append(_sym)          
        else:
            sym_freq_cnt_2.append(_sym)

    l_sym_freq_cnt = []

    l_sym_freq_cnt.append(sym_freq_cnt_15)
    l_sym_freq_cnt.append(sym_freq_cnt_14)
    l_sym_freq_cnt.append(sym_freq_cnt_13)
    l_sym_freq_cnt.append(sym_freq_cnt_12)    
    l_sym_freq_cnt.append(sym_freq_cnt_11)   
    l_sym_freq_cnt.append(sym_freq_cnt_10)
    l_sym_freq_cnt.append(sym_freq_cnt_9)
    l_sym_freq_cnt.append(sym_freq_cnt_8)
    l_sym_freq_cnt.append(sym_freq_cnt_7)    
    l_sym_freq_cnt.append(sym_freq_cnt_6)
    l_sym_freq_cnt.append(sym_freq_cnt_5)
    l_sym_freq_cnt.append(sym_freq_cnt_4)
    l_sym_freq_cnt.append(sym_freq_cnt_3)    
    l_sym_freq_cnt.append(sym_freq_cnt_2)    

    return l_sym_freq_cnt

# %%
col_add0 = ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'sym_freq_cnt']
col_add1 = ['grp(CAGR)_mean',         'grp(CAGR)_std',         'grp(CAGR)_mean/std']
col_add2 = ['grp(CAGR/UI)_mean',      'grp(CAGR/UI)_std',      'grp(CAGR/UI)_mean/std']
col_add3 = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
col_add4 = ['grp(retnStd/UI)_mean',   'grp(retnStd/UI)_std',   'grp(retnStd/UI)_mean/std']
col_add5 = ['SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI']

col_add_total = col_add0 + col_add1 + col_add2 + col_add3 + col_add4 + col_add5
print(f'col_add_total:\n{col_add_total}, total columns: {len(col_add_total)}')
# Out:
# col_add_total:
# ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'sym_freq_cnt', 'grp(CAGR)_mean', 'grp(CAGR)_std', 'grp(CAGR)_mean/std', 'grp(CAGR/UI)_mean', 'grp(CAGR/UI)_std', 'grp(CAGR/UI)_mean/std', 'grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std', 'grp(retnStd/UI)_mean', 'grp(retnStd/UI)_std', 'grp(retnStd/UI)_mean/std', 'SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI'], total columns: 23

# %% [markdown]
# #### DANGER: Create a new Dataframe to store run results from below will destroy previous stored data

# %%
###################################  To create a new dataframe, select one choice from below
# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_train)
# df

# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_validate)
# df

# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_test)
# df
###################################

# %% [markdown]
# #### Select type of run from below: Train, Validate or Test

# %%
###################################  Select type of run: train, validate or test
df_eval_sym_freq_results_train = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_train)
# df_eval_sym_freq_results_train
# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = _2_split_train_val_test(df_close_clean)
run_type = 'train'

# df_eval_sym_freq_results_validate = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_validate)
# # df_eval_sym_freq_results_validate
# # Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# # The default split is 0.7, 0.2, 0.1 respectively.
# df_train, df_val, df_test = _2_split_train_val_test(df_close_clean)
# df_train = df_test.copy()
# run_type = 'validate'

# df_eval_sym_freq_results_test = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_test)
# # df_eval_sym_freq_results_test
# # Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# # The default split is 0.7, 0.2, 0.1 respectively.
# df_train, df_val, df_test = _2_split_train_val_test(df_close_clean)
# df_train = df_val.copy()
# run_type = 'test'
###################################

# %%
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f'len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test} ')
# Out:
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %%
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# number of max lookback tuples to create for iloc start_train:end_train:end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms 
# n_samples = 400  
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback end_train
days_lookbacks = [10, 20, 30]
days_lookbacks.sort()

# number of days from end_train are used to evaluate effectiveness of the training
days_eval = 6


# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20  

syms_start = 0  #  start index of n_top_syms for evaluation
syms_end = 10  #  end index of n_top_syms for evaluation

# %% [markdown]
# create a sets of iloc lookback slices (start_train:end_train:end_eval), where
# end_train - start_train = days_lookback
# end_eval - end_train = days_eval
# for example,
# if given:
#  n_samples = 2
#  days_lookbacks = [30, 60, 120]
#  days_eval = 10
# a possible result is:
#  max_lookback_slices:
#  [(150, 270, 280), (5, 125, 135)]
#  where 270-150=125-5=max(days_lookbacks), 280-270=135-125=days_eval
#  sets_lookback_slices:
#  [[(240, 270, 280), (210, 270, 280), (150, 270, 280)], [(95, 125, 135), (65, 125, 135), (5, 125, 135)]]
#   where in a set, 270-240=days_lookbacks[0], 270-210=days_lookbacks[1], 270-150=days_lookbacks[2]
#   and 270, i.e. end_train, is constant for the set

# %%
# return n_samples slices
max_lookback_slices = _3_random_slices(len_df_train, n_samples=n_samples, days_lookback=max(days_lookbacks), days_eval=days_eval)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = _4_lookback_slices(max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False)

if verbose:
  print(f'max_lookback_slices:\n{max_lookback_slices}')
  print(f'sets_lookback_slices:\n{sets_lookback_slices}')
# Out:
# max_lookback_slices:
# [(502, 532, 538), (278, 308, 314)]
# sets_lookback_slices:
# [[(522, 532, 538), (512, 532, 538), (502, 532, 538)], [(298, 308, 314), (288, 308, 314), (278, 308, 314)]]

# %% [markdown]
# Generate lists, n_samples long, of the highest performance ranked symbols. The performance metrics are: CAGR/UI, CAGR/retnStd, retnStd/UI. n_top_syms of the best performing symbols from each metric are combined. The symbols are sorted by their number of appearances in the combined pool, and are placed in a list. A slice of the best performing symbols is selected by syms_start:syms_end, i.e. top_set_syms_n_freq[syms_start:syms_end].
#
# The performance metrics are calculated based on slices in sets_lookback_slices.  The first two numbers are ilocs for training. The last two numbers are ilocs for evaluation.

# %%
grp_top_set_syms_n_freq = []  # list of lists of top_set_symbols_n_freq, there are n_samples lists in list
grp_top_set_syms = []  # list of lists of top_set_symbols, there are n_samples lists in list
# loop thru lists of tuples of start_train:end_train:end_eval, i.e.
#  [[(887, 917, 927), (857, 917, 927), (797, 917, 927)],
#  [(483, 513, 523), (453, 513, 523), (393, 513, 523)]]
for lb_slices in sets_lookback_slices:
  grp_most_common_syms = []  
  for lb_slice in lb_slices:  # lb_slice, e.g. (246, 276, 286)
    start_train = lb_slice[0]
    end_train = lb_slice[1]
    start_eval = end_train
    end_eval = lb_slice[2]
    lookback = end_train - start_train
    d_eval = end_eval - start_eval

    _df = df_train.iloc[start_train:end_train]
    date_start_train = _df.index[0].strftime('%Y-%m-%d')
    date_end_train = _df.index[-1].strftime('%Y-%m-%d')

    if verbose:
      print(f'days lookback:    {lookback}')
      print(f'lb_slices:        {lb_slices}')
      print(f'lb_slice:         {lb_slice}')
      print(f'days eval:        {d_eval}')    
      print(f'iloc_start_train: {start_train}')
      print(f'iloc_end_train:   {end_train}')
      print(f'date_start_train: {date_start_train}')
      print(f'date_end_train:   {date_end_train}')


    perf_ranks, most_common_syms = _5_perf_ranks(_df, n_top_syms=n_top_syms)
    grp_most_common_syms.append(most_common_syms)
    
    if verbose:    
      # 1 lookback of r_CAGR/UI, r_CAGR/retnStd, r_retnStd/UI
      print(f'perf_ranks: {perf_ranks}')  
      # most common symbols of perf_ranks 
      print(f'most_common_syms: {most_common_syms}')     
      # grp_perf_ranks[lookback] = perf_ranks
      print(f'+++ finish lookback slice {lookback} +++\n')

  if verbose:
    print(f'grp_most_common_syms: {grp_most_common_syms}')
    # grp_most_common_syms a is list of lists of tuples of 
    #  the most-common-symbols symbol:frequency cumulated from
    #  each days_lookback  
    print(f'**** finish lookback slices {lb_slices} ****\n')

  # flatten list of lists of (symbol:frequency)
  flat_grp_most_common_syms = [val for sublist in grp_most_common_syms for val in sublist]
  # group symbols from set of days_lookbacks (i.e. lb_slices) and sum frequency of the symbols
  set_most_common_syms = _6_grp_tuples_sort_sum(flat_grp_most_common_syms, reverse=True)
  # get the top few most-frequent symbol:frequency pairs
  top_set_syms_n_freq = set_most_common_syms[0:n_top_syms]
  # get symbols from top_set_syms_n_freq

###################################  
  # top_set_syms = [i[0] for i in top_set_syms_n_freq]
  top_set_syms = [i[0] for i in top_set_syms_n_freq[syms_start:syms_end]]  
###################################  
  
  grp_top_set_syms_n_freq.append(top_set_syms_n_freq)
  grp_top_set_syms.append(top_set_syms)

  if verbose:  
    print(f'top {n_top_syms} ranked symbols and frequency from set {lb_slices}:\n{top_set_syms_n_freq}')
    print(f'top {n_top_syms} ranked symbols from set {lb_slices}:\n{top_set_syms}')  
    print(f'===== finish top {n_top_syms} ranked symbols from days_lookback set {lb_slices} =====\n\n')
# Out:
# days lookback:    10
# lb_slices:        [(522, 532, 538), (512, 532, 538), (502, 532, 538)]
# lb_slice:         (522, 532, 538)
# days eval:        6
# iloc_start_train: 522
# iloc_end_train:   532
# date_start_train: 2019-04-16
# date_end_train:   2019-04-30
# perf_ranks: {'period-10': {'r_CAGR/UI': array(['PI', 'MGI', 'SOHU', 'PRO', 'USB', 'YELP', 'RCII', 'QCOM', 'HELE',
#        'MA', 'SAP', 'STZ', 'AZTA', 'SBS', 'UFPI', 'MSFT', 'KDP', 'RNG',
#        'NOW', 'F'], dtype=object), 'r_CAGR/retnStd': array(['PI', 'MGI', 'SOHU', 'RCII', 'QCOM', 'HELE', 'PRO', 'SBS', 'UFPI',
#        'AZTA', 'PLAY', 'YELP', 'SAP', 'VRNS', 'AXSM', 'STZ', 'RNG', 'KDP',
#        'NOW', 'FDP'], dtype=object), 'r_retnStd/UI': array(['MA', 'USB', 'YELP', 'PI', 'PRO', 'STZ', 'MGI', 'SAP', 'MSFT',
#        'SYF', 'TAP', 'AZTA', 'CSL', 'HELE', 'RTX', 'SOHU', 'EVT', 'QCOM',
#        'F', 'PAYX'], dtype=object)}}
# most_common_syms: [('PI', 3), ('MGI', 3), ('SOHU', 3), ('PRO', 3), ('YELP', 3), ('QCOM', 3), ('HELE', 3), ('SAP', 3), ('STZ', 3), ('AZTA', 3), ('USB', 2), ('RCII', 2), ('MA', 2), ('SBS', 2), ('UFPI', 2), ('MSFT', 2), ('KDP', 2), ('RNG', 2), ('NOW', 2), ('F', 2), ('PLAY', 1), ('VRNS', 1), ('AXSM', 1), ('FDP', 1), ('SYF', 1), ('TAP', 1), ('CSL', 1), ('RTX', 1), ('EVT', 1), ('PAYX', 1)]
# +++ finish lookback slice 10 +++
#
# days lookback:    20
# lb_slices:        [(522, 532, 538), (512, 532, 538), (502, 532, 538)]
# lb_slice:         (512, 532, 538)
# days eval:        6
# iloc_start_train: 512
# iloc_end_train:   532
# date_start_train: 2019-04-02
# date_end_train:   2019-04-30
# perf_ranks: {'period-20': {'r_CAGR/UI': array(['PI', 'QCOM', 'MGI', 'ADNT', 'FIVE', 'PPC', 'AZTA', 'MRVL', 'STNG',
#        'DIS', 'TYL', 'EVT', 'HELE', 'BR', 'CSL', 'F', 'XPO', 'AXSM',
#        'STZ', 'PRO'], dtype=object), 'r_CAGR/retnStd': array(['PI', 'ADNT', 'MGI', 'QCOM', 'FIVE', 'MRVL', 'STNG', 'PPC', 'AXSM',
#        'SBLK', 'XPO', 'AZTA', 'HEES', 'TYL', 'STZ', 'HELE', 'UFPI', 'DIS',
#        'HRI', 'SHOP'], dtype=object), 'r_retnStd/UI': array(['PI', 'EVT', 'FIVE', 'CSL', 'AZTA', 'MSFT', 'DIS', 'QCOM', 'F',
#        'TYL', 'PPC', 'META', 'HAS', 'PRO', 'HELE', 'SYF', 'TER', 'JPM',
#        'BX', 'FSLR'], dtype=object)}}
# most_common_syms: [('PI', 3), ('QCOM', 3), ('FIVE', 3), ('PPC', 3), ('AZTA', 3), ('DIS', 3), ('TYL', 3), ('HELE', 3), ('MGI', 2), ('ADNT', 2), ('MRVL', 2), ('STNG', 2), ('EVT', 2), ('CSL', 2), ('F', 2), ('XPO', 2), ('AXSM', 2), ('STZ', 2), ('PRO', 2), ('BR', 1), ('SBLK', 1), ('HEES', 1), ('UFPI', 1), ('HRI', 1), ('SHOP', 1), ('MSFT', 1), ('META', 1), ('HAS', 1), ('SYF', 1), ('TER', 1), ('JPM', 1), ('BX', 1), ('FSLR', 1)]
# +++ finish lookback slice 20 +++
#
# days lookback:    30
# lb_slices:        [(522, 532, 538), (512, 532, 538), (502, 532, 538)]
# lb_slice:         (502, 532, 538)
# days eval:        6
# iloc_start_train: 502
# iloc_end_train:   532
# date_start_train: 2019-03-19
# date_end_train:   2019-04-30
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['QCOM', 'CPRX', 'CAG', 'KMX', 'PI', 'ADNT', 'STZ', 'XPO', 'MGI',
#        'DIS', 'META', 'STNG', 'FTSM', 'PPC', 'AN', 'APD', 'ELF', 'ATCO',
#        'F', 'MSCI'], dtype=object), 'r_CAGR/retnStd': array(['ADNT', 'CPRX', 'PI', 'QCOM', 'MGI', 'XPO', 'ELF', 'PPC', 'CAG',
#        'KMX', 'STZ', 'STNG', 'ATCO', 'PLCE', 'MSCI', 'SBLK', 'AN', 'RCII',
#        'MTH', 'MRVL'], dtype=object), 'r_retnStd/UI': array(['QCOM', 'CAG', 'FTSM', 'KMX', 'DIS', 'META', 'F', 'PRGS', 'APD',
#        'HELE', 'PRO', 'EXP', 'STZ', 'LULU', 'WRB', 'BRO', 'CPRX', 'ATHM',
#        'CINF', 'NVRO'], dtype=object)}}
# most_common_syms: [('QCOM', 3), ('CPRX', 3), ('CAG', 3), ('KMX', 3), ('STZ', 3), ('PI', 2), ('ADNT', 2), ('XPO', 2), ('MGI', 2), ('DIS', 2), ('META', 2), ('STNG', 2), ('FTSM', 2), ('PPC', 2), ('AN', 2), ('APD', 2), ('ELF', 2), ('ATCO', 2), ('F', 2), ('MSCI', 2), ('PLCE', 1), ('SBLK', 1), ('RCII', 1), ('MTH', 1), ('MRVL', 1), ('PRGS', 1), ('HELE', 1), ('PRO', 1), ('EXP', 1), ('LULU', 1), ('WRB', 1), ('BRO', 1), ('ATHM', 1), ('CINF', 1), ('NVRO', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_common_syms: [[('PI', 3), ('MGI', 3), ('SOHU', 3), ('PRO', 3), ('YELP', 3), ('QCOM', 3), ('HELE', 3), ('SAP', 3), ('STZ', 3), ('AZTA', 3), ('USB', 2), ('RCII', 2), ('MA', 2), ('SBS', 2), ('UFPI', 2), ('MSFT', 2), ('KDP', 2), ('RNG', 2), ('NOW', 2), ('F', 2), ('PLAY', 1), ('VRNS', 1), ('AXSM', 1), ('FDP', 1), ('SYF', 1), ('TAP', 1), ('CSL', 1), ('RTX', 1), ('EVT', 1), ('PAYX', 1)], [('PI', 3), ('QCOM', 3), ('FIVE', 3), ('PPC', 3), ('AZTA', 3), ('DIS', 3), ('TYL', 3), ('HELE', 3), ('MGI', 2), ('ADNT', 2), ('MRVL', 2), ('STNG', 2), ('EVT', 2), ('CSL', 2), ('F', 2), ('XPO', 2), ('AXSM', 2), ('STZ', 2), ('PRO', 2), ('BR', 1), ('SBLK', 1), ('HEES', 1), ('UFPI', 1), ('HRI', 1), ('SHOP', 1), ('MSFT', 1), ('META', 1), ('HAS', 1), ('SYF', 1), ('TER', 1), ('JPM', 1), ('BX', 1), ('FSLR', 1)], [('QCOM', 3), ('CPRX', 3), ('CAG', 3), ('KMX', 3), ('STZ', 3), ('PI', 2), ('ADNT', 2), ('XPO', 2), ('MGI', 2), ('DIS', 2), ('META', 2), ('STNG', 2), ('FTSM', 2), ('PPC', 2), ('AN', 2), ('APD', 2), ('ELF', 2), ('ATCO', 2), ('F', 2), ('MSCI', 2), ('PLCE', 1), ('SBLK', 1), ('RCII', 1), ('MTH', 1), ('MRVL', 1), ('PRGS', 1), ('HELE', 1), ('PRO', 1), ('EXP', 1), ('LULU', 1), ('WRB', 1), ('BRO', 1), ('ATHM', 1), ('CINF', 1), ('NVRO', 1)]]
# **** finish lookback slices [(522, 532, 538), (512, 532, 538), (502, 532, 538)] ****
#
# top 20 ranked symbols and frequency from set [(522, 532, 538), (512, 532, 538), (502, 532, 538)]:
# [('QCOM', 9), ('PI', 8), ('STZ', 8), ('HELE', 7), ('MGI', 7), ('AZTA', 6), ('F', 6), ('PRO', 6), ('DIS', 5), ('PPC', 5), ('ADNT', 4), ('STNG', 4), ('XPO', 4), ('AXSM', 3), ('CAG', 3), ('CPRX', 3), ('CSL', 3), ('EVT', 3), ('FIVE', 3), ('KMX', 3)]
# top 20 ranked symbols from set [(522, 532, 538), (512, 532, 538), (502, 532, 538)]:
# ['QCOM', 'PI', 'STZ', 'HELE', 'MGI', 'AZTA', 'F', 'PRO', 'DIS', 'PPC']
# ===== finish top 20 ranked symbols from days_lookback set [(522, 532, 538), (512, 532, 538), (502, 532, 538)] =====
#
#
# days lookback:    10
# lb_slices:        [(298, 308, 314), (288, 308, 314), (278, 308, 314)]
# lb_slice:         (298, 308, 314)
# days eval:        6
# iloc_start_train: 298
# iloc_end_train:   308
# date_start_train: 2018-05-24
# date_end_train:   2018-06-07
# perf_ranks: {'period-10': {'r_CAGR/UI': array(['JAZZ', 'JWN', 'AVXL', 'MOV', 'FIVE', 'SIG', 'SPTN', 'RARE',
#        'SCVL', 'SGEN', 'PTCT', 'KSS', 'DECK', 'CELH', 'FL', 'DDS', 'CYRX',
#        'WSM', 'SEAS', 'STRL'], dtype=object), 'r_CAGR/retnStd': array(['AVXL', 'SPTN', 'FIVE', 'MOV', 'RARE', 'SCVL', 'SIG', 'KSS',
#        'CYRX', 'PTCT', 'FL', 'CELH', 'SGEN', 'DDS', 'WSM', 'M', 'DECK',
#        'PI', 'EXAS', 'RGNX'], dtype=object), 'r_retnStd/UI': array(['JWN', 'JAZZ', 'STRL', 'SIG', 'BIIB', 'MOV', 'SGEN', 'KRG', 'AVGO',
#        'BCC', 'LSCC', 'SITC', 'DECK', 'DLB', 'NSTG', 'UE', 'RARE', 'NSA',
#        'SIX', 'MSCI'], dtype=object)}}
# most_common_syms: [('MOV', 3), ('SIG', 3), ('RARE', 3), ('SGEN', 3), ('DECK', 3), ('JAZZ', 2), ('JWN', 2), ('AVXL', 2), ('FIVE', 2), ('SPTN', 2), ('SCVL', 2), ('PTCT', 2), ('KSS', 2), ('CELH', 2), ('FL', 2), ('DDS', 2), ('CYRX', 2), ('WSM', 2), ('STRL', 2), ('SEAS', 1), ('M', 1), ('PI', 1), ('EXAS', 1), ('RGNX', 1), ('BIIB', 1), ('KRG', 1), ('AVGO', 1), ('BCC', 1), ('LSCC', 1), ('SITC', 1), ('DLB', 1), ('NSTG', 1), ('UE', 1), ('NSA', 1), ('SIX', 1), ('MSCI', 1)]
# +++ finish lookback slice 10 +++
#
# days lookback:    20
# lb_slices:        [(298, 308, 314), (288, 308, 314), (278, 308, 314)]
# lb_slice:         (288, 308, 314)
# days eval:        6
# iloc_start_train: 288
# iloc_end_train:   308
# date_start_train: 2018-05-10
# date_end_train:   2018-06-07
# perf_ranks: {'period-20': {'r_CAGR/UI': array(['AVXL', 'TNDM', 'TTD', 'CATO', 'SIG', 'WWE', 'SPTN', 'SCVL', 'FL',
#        'M', 'RARE', 'UVV', 'MOV', 'CYRX', 'RL', 'LULU', 'WSM', 'MED',
#        'DDS', 'FIVE'], dtype=object), 'r_CAGR/retnStd': array(['AVXL', 'TNDM', 'TTD', 'CATO', 'WWE', 'SPTN', 'SIG', 'CYRX', 'M',
#        'RARE', 'SCVL', 'DDS', 'FL', 'FIVE', 'TRUP', 'CUTR', 'NSTG', 'WSM',
#        'MED', 'MOV'], dtype=object), 'r_retnStd/UI': array(['SIG', 'LULU', 'WWE', 'FDUS', 'RL', 'CATO', 'SCVL', 'UVV', 'TTD',
#        'OEC', 'FL', 'MOV', 'MCHP', 'GM', 'AVXL', 'TNDM', 'SPTN', 'WOLF',
#        'KEYS', 'XHR'], dtype=object)}}
# most_common_syms: [('AVXL', 3), ('TNDM', 3), ('TTD', 3), ('CATO', 3), ('SIG', 3), ('WWE', 3), ('SPTN', 3), ('SCVL', 3), ('FL', 3), ('MOV', 3), ('M', 2), ('RARE', 2), ('UVV', 2), ('CYRX', 2), ('RL', 2), ('LULU', 2), ('WSM', 2), ('MED', 2), ('DDS', 2), ('FIVE', 2), ('TRUP', 1), ('CUTR', 1), ('NSTG', 1), ('FDUS', 1), ('OEC', 1), ('MCHP', 1), ('GM', 1), ('WOLF', 1), ('KEYS', 1), ('XHR', 1)]
# +++ finish lookback slice 20 +++
#
# days lookback:    30
# lb_slices:        [(298, 308, 314), (288, 308, 314), (278, 308, 314)]
# lb_slice:         (278, 308, 314)
# days eval:        6
# iloc_start_train: 278
# iloc_end_train:   308
# date_start_train: 2018-04-26
# date_end_train:   2018-06-07
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['TNDM', 'CYRX', 'STAA', 'WWE', 'RARE', 'PERI', 'KN', 'TTD', 'TRIP',
#        'ROCC', 'MED', 'XHR', 'NSTG', 'PI', 'W', 'ARWR', 'HTHT', 'ENSG',
#        'NOG', 'AXON'], dtype=object), 'r_CAGR/retnStd': array(['CYRX', 'TNDM', 'STAA', 'RARE', 'PERI', 'NOG', 'PI', 'ROCC', 'WWE',
#        'TTD', 'NSTG', 'HTHT', 'W', 'ARWR', 'BLFS', 'RGNX', 'MED', 'KN',
#        'AVXL', 'TRIP'], dtype=object), 'r_retnStd/UI': array(['WWE', 'XHR', 'KN', 'FDUS', 'TRIP', 'STAA', 'UVV', 'ENSG', 'TTD',
#        'MED', 'MCHP', 'SCVL', 'TNDM', 'VSH', 'LULU', 'ENS', 'RARE',
#        'ARCC', 'ZTO', 'PERI'], dtype=object)}}
# most_common_syms: [('TNDM', 3), ('STAA', 3), ('WWE', 3), ('RARE', 3), ('PERI', 3), ('KN', 3), ('TTD', 3), ('TRIP', 3), ('MED', 3), ('CYRX', 2), ('ROCC', 2), ('XHR', 2), ('NSTG', 2), ('PI', 2), ('W', 2), ('ARWR', 2), ('HTHT', 2), ('ENSG', 2), ('NOG', 2), ('AXON', 1), ('BLFS', 1), ('RGNX', 1), ('AVXL', 1), ('FDUS', 1), ('UVV', 1), ('MCHP', 1), ('SCVL', 1), ('VSH', 1), ('LULU', 1), ('ENS', 1), ('ARCC', 1), ('ZTO', 1)]
# +++ finish lookback slice 30 +++
#
# grp_most_common_syms: [[('MOV', 3), ('SIG', 3), ('RARE', 3), ('SGEN', 3), ('DECK', 3), ('JAZZ', 2), ('JWN', 2), ('AVXL', 2), ('FIVE', 2), ('SPTN', 2), ('SCVL', 2), ('PTCT', 2), ('KSS', 2), ('CELH', 2), ('FL', 2), ('DDS', 2), ('CYRX', 2), ('WSM', 2), ('STRL', 2), ('SEAS', 1), ('M', 1), ('PI', 1), ('EXAS', 1), ('RGNX', 1), ('BIIB', 1), ('KRG', 1), ('AVGO', 1), ('BCC', 1), ('LSCC', 1), ('SITC', 1), ('DLB', 1), ('NSTG', 1), ('UE', 1), ('NSA', 1), ('SIX', 1), ('MSCI', 1)], [('AVXL', 3), ('TNDM', 3), ('TTD', 3), ('CATO', 3), ('SIG', 3), ('WWE', 3), ('SPTN', 3), ('SCVL', 3), ('FL', 3), ('MOV', 3), ('M', 2), ('RARE', 2), ('UVV', 2), ('CYRX', 2), ('RL', 2), ('LULU', 2), ('WSM', 2), ('MED', 2), ('DDS', 2), ('FIVE', 2), ('TRUP', 1), ('CUTR', 1), ('NSTG', 1), ('FDUS', 1), ('OEC', 1), ('MCHP', 1), ('GM', 1), ('WOLF', 1), ('KEYS', 1), ('XHR', 1)], [('TNDM', 3), ('STAA', 3), ('WWE', 3), ('RARE', 3), ('PERI', 3), ('KN', 3), ('TTD', 3), ('TRIP', 3), ('MED', 3), ('CYRX', 2), ('ROCC', 2), ('XHR', 2), ('NSTG', 2), ('PI', 2), ('W', 2), ('ARWR', 2), ('HTHT', 2), ('ENSG', 2), ('NOG', 2), ('AXON', 1), ('BLFS', 1), ('RGNX', 1), ('AVXL', 1), ('FDUS', 1), ('UVV', 1), ('MCHP', 1), ('SCVL', 1), ('VSH', 1), ('LULU', 1), ('ENS', 1), ('ARCC', 1), ('ZTO', 1)]]
# **** finish lookback slices [(298, 308, 314), (288, 308, 314), (278, 308, 314)] ****
#
# top 20 ranked symbols and frequency from set [(298, 308, 314), (288, 308, 314), (278, 308, 314)]:
# [('RARE', 8), ('AVXL', 6), ('CYRX', 6), ('MOV', 6), ('SCVL', 6), ('SIG', 6), ('TNDM', 6), ('TTD', 6), ('WWE', 6), ('FL', 5), ('MED', 5), ('SPTN', 5), ('DDS', 4), ('FIVE', 4), ('NSTG', 4), ('WSM', 4), ('CATO', 3), ('DECK', 3), ('KN', 3), ('LULU', 3)]
# top 20 ranked symbols from set [(298, 308, 314), (288, 308, 314), (278, 308, 314)]:
# ['RARE', 'AVXL', 'CYRX', 'MOV', 'SCVL', 'SIG', 'TNDM', 'TTD', 'WWE', 'FL']
# ===== finish top 20 ranked symbols from days_lookback set [(298, 308, 314), (288, 308, 314), (278, 308, 314)] =====

# %%
for item, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
  l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
  if verbose:
    print(f'{item + 1} of {len(grp_top_set_syms_n_freq)} max_lookback_slices: {max_lookback_slices}')
    print(f'max_lookback_slice: {max_lookback_slices[item]}')
    print(f'sym_freq_15: {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14: {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13: {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12: {l_sym_freq_cnt[3]}')
    print(f'sym_freq_11: {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10: {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9: {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8: {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7: {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6: {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5: {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4: {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3: {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2: {l_sym_freq_cnt[13]}\n')
# Out:
# 1 of 2 max_lookback_slices: [(502, 532, 538), (278, 308, 314)]
# max_lookback_slice: (502, 532, 538)
# sym_freq_15: []
# sym_freq_14: []
# sym_freq_13: []
# sym_freq_12: []
# sym_freq_11: []
# sym_freq_10: []
# sym_freq_9: ['QCOM']
# sym_freq_8: ['PI', 'STZ']
# sym_freq_7: ['HELE', 'MGI']
# sym_freq_6: ['AZTA', 'F', 'PRO']
# sym_freq_5: ['DIS', 'PPC']
# sym_freq_4: ['ADNT', 'STNG', 'XPO']
# sym_freq_3: ['AXSM', 'CAG', 'CPRX', 'CSL', 'EVT', 'FIVE', 'KMX']
# sym_freq_2: []
#
# 2 of 2 max_lookback_slices: [(502, 532, 538), (278, 308, 314)]
# max_lookback_slice: (278, 308, 314)
# sym_freq_15: []
# sym_freq_14: []
# sym_freq_13: []
# sym_freq_12: []
# sym_freq_11: []
# sym_freq_10: []
# sym_freq_9: []
# sym_freq_8: ['RARE']
# sym_freq_7: []
# sym_freq_6: ['AVXL', 'CYRX', 'MOV', 'SCVL', 'SIG', 'TNDM', 'TTD', 'WWE']
# sym_freq_5: ['FL', 'MED', 'SPTN']
# sym_freq_4: ['DDS', 'FIVE', 'NSTG', 'WSM']
# sym_freq_3: ['CATO', 'DECK', 'KN', 'LULU']
# sym_freq_2: []

# %%
from myUtils import symb_perf_stats_vectorized_v8

print('z_grp_top_set_syms_n_freq:')
z_grp_top_set_syms_n_freq = zip(max_lookback_slices, grp_top_set_syms_n_freq)

for i, (_lookback_slice, _top_set_syms_n_freq) in enumerate(z_grp_top_set_syms_n_freq):
  start_train = _lookback_slice[0]
  end_train = _lookback_slice[1]
  start_eval = end_train
  end_eval = _lookback_slice[2]

  print(f'{i + 1 } of {n_samples} max_lookback_slice')
  print(f'max_lookback_slice: {_lookback_slice}')
  # dates correspond to max_lookback_slice
  d_start_train = df_train.index[start_train].strftime('%Y-%m-%d')
  d_end_train = df_train.index[end_train].strftime('%Y-%m-%d')
  d_start_eval = d_end_train
  d_end_eval = df_train.index[end_eval].strftime('%Y-%m-%d')
  d_df_eval_start = d_end_train
  d_df_eval_end = df_train.index[end_eval - 1].strftime('%Y-%m-%d')  
  print(f'max lookback dates: {d_start_train}, {d_end_train}, {d_end_eval}')
  print(f'df_eval dates (inclusive): {d_df_eval_start} - {d_df_eval_end}')    
  print(f'top_set_syms_n_freq: {_top_set_syms_n_freq}\n')

  l_sym_freq_cnt = top_set_sym_freq_cnt(_top_set_syms_n_freq)
  if verbose:
    print(f'sym_freq_15: {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14: {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13: {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12: {l_sym_freq_cnt[3]}')
    print(f'sym_freq_11: {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10: {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9: {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8: {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7: {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6: {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5: {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4: {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3: {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2: {l_sym_freq_cnt[13]}\n')  


  _sym_idx = ['SPY']
  df_SPY = df_train[start_eval:end_eval][_sym_idx]

  (
    _symbols,
    _period_yr,
    _retn,
    _DD,
    _UI,
    _MDD,
    _retnMean,
    _retnStd,
    _retnStd_div_UI,
    _CAGR,
    _CAGR_div_retnStd,
    _CAGR_div_UI,
    SPY_retnStd_d_UI,     
    SPY_CAGR,
    SPY_CAGR_d_retnStd,
    SPY_CAGR_d_UI,
  ) = symb_perf_stats_vectorized_v8(df_SPY)  

  print(f'\nSPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR: {SPY_retnStd_d_UI[0]:>17,.3f}, {SPY_CAGR_d_retnStd[0]:>17,.3f}, {SPY_CAGR_d_UI[0]:>17.1f}, {SPY_CAGR[0]:>17.1f}')

  # drop last list, with frequency count 2 or less, in l_sym_freq_cnt from zip
  # zip_cnt_n_syms = zip([6,5,4,3], l_sym_freq_cnt[:-1])  
  zip_cnt_n_syms = zip([15,14,13,12,11,10,9,8,7,6,5,4,3], l_sym_freq_cnt[:-1])
  for item in zip_cnt_n_syms:
    sym_freq_cnt = item[0]
    syms = item[1]
    if syms:  # iterate ONLY if there are symbols in syms
      df_eval = df_train[start_eval:end_eval][syms]      

      if verbose:
        print(f'start_eval: {start_eval},  date: {d_end_train}')
        print(f'end_eval:   {end_eval},  date: {d_end_eval},  df_eval last date: {d_df_eval_end}')
        print(f'frequency count of symbol(s): {sym_freq_cnt}')      
        # print(f'\ndf_eval:\n{df_eval}\n')

        syms_n_SPY = syms + ['SPY']
        df_eval_n_SPY = df_train[start_eval:end_eval][syms_n_SPY]   
        print(f'\ndf_eval_n_SPY:\n{df_eval_n_SPY}\n')

      (
        _symbols,
        _period_yr,
        _retn,
        _DD,
        _UI,
        _MDD,
        _retnMean,
        _retnStd,
        _retnStd_div_UI,
        _CAGR,
        _CAGR_div_retnStd,
        _CAGR_div_UI,
        grp_retnStd_d_UI,     
        grp_CAGR,
        grp_CAGR_d_retnStd,
        grp_CAGR_d_UI,
      ) = symb_perf_stats_vectorized_v8(df_eval)  
      print(f'grp(retnStd/UI):   mean, std, mean/std: {grp_retnStd_d_UI[0]  :>17,.3f}, {grp_retnStd_d_UI[1]  :>17,.3f}, {grp_retnStd_d_UI[2]  :>17,.3f}')
      print(f'grp(CAGR/retnStd): mean, std, mean/std: {grp_CAGR_d_retnStd[0]:>17,.3f}, {grp_CAGR_d_retnStd[1]:>17,.3f}, {grp_CAGR_d_retnStd[2]:>17,.3f}')
      print(f'grp(CAGR/UI):      mean, std, mean/std: {grp_CAGR_d_UI[0]     :>17,.3f}, {grp_CAGR_d_UI[1]     :>17,.3f}, {grp_CAGR_d_UI[2]     :>17,.3f}')
      print(f'grp(CAGR):         mean, std, mean/std: {grp_CAGR[0]          :>17,.3f}, {grp_CAGR[1]          :>17,.3f}, {grp_CAGR[2]          :>17,.3f}')

      if store_results:  # record results to df
        row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt]
        row_add1      = [grp_CAGR[0],           grp_CAGR[1],           grp_CAGR[2]]
        row_add2      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
        row_add3      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
        row_add4      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
        row_add5      = [SPY_CAGR[0], SPY_CAGR_d_UI[0], SPY_CAGR_d_retnStd[0], SPY_retnStd_d_UI[0]]
        row_add_total = row_add0 + row_add1 + row_add2 + row_add3 + row_add4 + row_add5
        print(f'row_add_total: {row_add_total}')

        if run_type == 'train':
          df_eval_sym_freq_results_train.loc[len(df_eval_sym_freq_results_train)] = row_add_total
          print(f'appended row_add to df_eval_sym_freq_results_train:\n{row_add_total}\n')
        elif run_type == 'validate':
          df_eval_sym_freq_results_validate.loc[len(df_eval_sym_freq_results_validate)] = row_add_total       
          print(f'appended row_add to df_eval_sym_freq_results_validate:\n{row_add_total}\n')
        elif run_type == 'test':
          df_eval_sym_freq_results_test.loc[len(df_eval_sym_freq_results_test)] = row_add_total       
          print(f'appended row_add to df_eval_sym_freq_results_test:\n{row_add_total}\n')
        else:
          msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
          raise SystemExit(msg_stop )                             

  print(f'\n{"="*200}\n{"="*200}\n\n')
# Out:
# z_grp_top_set_syms_n_freq:
# 1 of 2 max_lookback_slice
# max_lookback_slice: (502, 532, 538)
# max lookback dates: 2019-03-19, 2019-05-01, 2019-05-09
# df_eval dates (inclusive): 2019-05-01 - 2019-05-08
# top_set_syms_n_freq: [('QCOM', 9), ('PI', 8), ('STZ', 8), ('HELE', 7), ('MGI', 7), ('AZTA', 6), ('F', 6), ('PRO', 6), ('DIS', 5), ('PPC', 5), ('ADNT', 4), ('STNG', 4), ('XPO', 4), ('AXSM', 3), ('CAG', 3), ('CPRX', 3), ('CSL', 3), ('EVT', 3), ('FIVE', 3), ('KMX', 3)]
#
# sym_freq_15: []
# sym_freq_14: []
# sym_freq_13: []
# sym_freq_12: []
# sym_freq_11: []
# sym_freq_10: []
# sym_freq_9: ['QCOM']
# sym_freq_8: ['PI', 'STZ']
# sym_freq_7: ['HELE', 'MGI']
# sym_freq_6: ['AZTA', 'F', 'PRO']
# sym_freq_5: ['DIS', 'PPC']
# sym_freq_4: ['ADNT', 'STNG', 'XPO']
# sym_freq_3: ['AXSM', 'CAG', 'CPRX', 'CSL', 'EVT', 'FIVE', 'KMX']
# sym_freq_2: []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:             0.674,           -62.258,             -41.9,              -0.5
# start_eval: 532,  date: 2019-05-01
# end_eval:   538,  date: 2019-05-09,  df_eval last date: 2019-05-08
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#                  QCOM         SPY
# Date
# 2019-05-01  78.485146  274.212097
# 2019-05-02  79.184853  273.620026
# 2019-05-03  81.138573  276.298126
# 2019-05-06  80.193497  275.161102
# 2019-05-07  77.421951  270.566010
# 2019-05-08  76.822189  270.190155
#
# grp(retnStd/UI):   mean, std, mean/std:             0.688,             0.000,               inf
# grp(CAGR/retnStd): mean, std, mean/std:           -33.047,             0.000,              -inf
# grp(CAGR/UI):      mean, std, mean/std:           -22.725,             0.000,              -inf
# grp(CAGR):         mean, std, mean/std:            -0.660,             0.000,              -inf
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 9, -0.6601867800303172, 0.0, -inf, -22.72493192501177, 0.0, -inf, -33.04743213706222, 0.0, -inf, 0.6876459214973646, 0.0, inf, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 9, -0.6601867800303172, 0.0, -inf, -22.72493192501177, 0.0, -inf, -33.04743213706222, 0.0, -inf, 0.6876459214973646, 0.0, inf, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
#
# start_eval: 532,  date: 2019-05-01
# end_eval:   538,  date: 2019-05-09,  df_eval last date: 2019-05-08
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#                    PI         STZ         SPY
# Date
# 2019-05-01  27.940001  200.060654  274.212097
# 2019-05-02  28.680000  197.259109  273.620026
# 2019-05-03  29.639999  199.409790  276.298126
# 2019-05-06  29.209999  198.475952  275.161102
# 2019-05-07  28.799999  196.080017  270.566010
# 2019-05-08  28.680000  195.438568  270.190155
#
# grp(retnStd/UI):   mean, std, mean/std:             0.863,             0.242,             3.575
# grp(CAGR/retnStd): mean, std, mean/std:            27.363,           106.100,             0.258
# grp(CAGR/UI):      mean, std, mean/std:            49.249,            98.208,             0.501
# grp(CAGR):         mean, std, mean/std:             1.021,             1.713,             0.596
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 8, 1.0209521229661171, 1.7130810638374883, 0.5959742037420419, 49.24897859666952, 98.20845321417751, 0.501473925969133, 27.362959898101288, 106.0996860621944, 0.2578985943658819, 0.8633358107751556, 0.24152338596753958, 3.574543340044044, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 8, 1.0209521229661171, 1.7130810638374883, 0.5959742037420419, 49.24897859666952, 98.20845321417751, 0.501473925969133, 27.362959898101288, 106.0996860621944, 0.2578985943658819, 0.8633358107751556, 0.24152338596753958, 3.574543340044044, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
#
# start_eval: 532,  date: 2019-05-01
# end_eval:   538,  date: 2019-05-09,  df_eval last date: 2019-05-08
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                   HELE   MGI         SPY
# Date
# 2019-05-01  141.020004  3.34  274.212097
# 2019-05-02  143.509995  3.14  273.620026
# 2019-05-03  144.509995  3.37  276.298126
# 2019-05-06  142.690002  3.32  275.161102
# 2019-05-07  140.500000  3.31  270.566010
# 2019-05-08  139.899994  2.60  270.190155
#
# grp(retnStd/UI):   mean, std, mean/std:             0.835,             0.150,             5.559
# grp(CAGR/retnStd): mean, std, mean/std:           -18.646,             8.175,            -2.281
# grp(CAGR/UI):      mean, std, mean/std:           -14.348,             4.027,            -3.563
# grp(CAGR):         mean, std, mean/std:            -0.665,             0.335,            -1.989
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 7, -0.6654696428725625, 0.3345270622856146, -1.989284927580519, -14.34779507708463, 4.0271094598523725, -3.5628023574036645, -18.646342101539634, 8.175077260097892, -2.2808765603416887, 0.835351497339852, 0.150268270043593, 5.559067773239923, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 7, -0.6654696428725625, 0.3345270622856146, -1.989284927580519, -14.34779507708463, 4.0271094598523725, -3.5628023574036645, -18.646342101539634, 8.175077260097892, -2.2808765603416887, 0.835351497339852, 0.150268270043593, 5.559067773239923, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
#
# start_eval: 532,  date: 2019-05-01
# end_eval:   538,  date: 2019-05-09,  df_eval last date: 2019-05-08
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  AZTA         F        PRO         SPY
# Date
# 2019-05-01  37.261482  8.899076  50.810001  274.212097
# 2019-05-02  37.075367  8.933639  50.639999  273.620026
# 2019-05-03  38.280197  8.994116  51.250000  276.298126
# 2019-05-06  38.956074  8.959557  52.150002  275.161102
# 2019-05-07  39.103001  8.968198  51.480000  270.566010
# 2019-05-08  37.574928  8.933639  51.639999  270.190155
#
# grp(retnStd/UI):   mean, std, mean/std:             1.451,             0.151,             9.596
# grp(CAGR/retnStd): mean, std, mean/std:            63.283,            39.702,             1.594
# grp(CAGR/UI):      mean, std, mean/std:            94.741,            66.896,             1.416
# grp(CAGR):         mean, std, mean/std:             0.668,             0.439,             1.521
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 6, 0.6679871834817886, 0.4392411223870295, 1.5207756046420526, 94.74092527268196, 66.89644955056377, 1.416232489305309, 63.28294695121184, 39.70237152581134, 1.593933674971287, 1.4513389669115424, 0.15125140884298383, 9.595540154063606, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 6, 0.6679871834817886, 0.4392411223870295, 1.5207756046420526, 94.74092527268196, 66.89644955056377, 1.416232489305309, 63.28294695121184, 39.70237152581134, 1.593933674971287, 1.4513389669115424, 0.15125140884298383, 9.595540154063606, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
#
# start_eval: 532,  date: 2019-05-01
# end_eval:   538,  date: 2019-05-09,  df_eval last date: 2019-05-08
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                    DIS        PPC         SPY
# Date
# 2019-05-01  134.733398  26.860001  274.212097
# 2019-05-02  132.520447  27.400000  273.620026
# 2019-05-03  132.708145  27.980000  276.298126
# 2019-05-06  133.370056  28.750000  275.161102
# 2019-05-07  131.828888  28.209999  270.566010
# 2019-05-08  133.360184  28.110001  270.190155
#
# grp(retnStd/UI):   mean, std, mean/std:             1.113,             0.364,             3.056
# grp(CAGR/retnStd): mean, std, mean/std:           233.999,           272.617,             0.858
# grp(CAGR/UI):      mean, std, mean/std:           359.790,           388.710,             0.926
# grp(CAGR):         mean, std, mean/std:             4.248,             4.652,             0.913
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 5, 4.248454939972577, 4.6517406921833295, 0.9133043351086993, 359.78989075619995, 388.71046150853033, 0.9255986817537821, 233.9992312440395, 272.6174616940629, 0.8583427847576337, 1.113166471960064, 0.36428257916344664, 3.0557773981846315, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 5, 4.248454939972577, 4.6517406921833295, 0.9133043351086993, 359.78989075619995, 388.71046150853033, 0.9255986817537821, 233.9992312440395, 272.6174616940629, 0.8583427847576337, 1.113166471960064, 0.36428257916344664, 3.0557773981846315, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
#
# start_eval: 532,  date: 2019-05-01
# end_eval:   538,  date: 2019-05-09,  df_eval last date: 2019-05-08
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                  ADNT       STNG        XPO         SPY
# Date
# 2019-05-01  23.020000  24.028454  23.217175  274.212097
# 2019-05-02  23.900000  25.750059  22.169237  273.620026
# 2019-05-03  24.889999  25.666752  22.290285  276.298126
# 2019-05-06  24.350000  25.564938  22.646517  275.161102
# 2019-05-07  21.969999  25.250235  21.619329  270.566010
# 2019-05-08  22.030001  24.556044  21.678125  270.190155
#
# grp(retnStd/UI):   mean, std, mean/std:             0.991,             0.479,             2.067
# grp(CAGR/retnStd): mean, std, mean/std:             1.190,            40.677,             0.029
# grp(CAGR/UI):      mean, std, mean/std:            20.672,            53.144,             0.389
# grp(CAGR):         mean, std, mean/std:             0.043,             1.376,             0.031
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 4, 0.04292404596923668, 1.375842841310812, 0.031198364144804133, 20.671763476350176, 53.14411735525571, 0.3889755725580008, 1.1903136752784462, 40.67673261318734, 0.02926276519300737, 0.9911026560667673, 0.47939570774669577, 2.0673999371526466, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 4, 0.04292404596923668, 1.375842841310812, 0.031198364144804133, 20.671763476350176, 53.14411735525571, 0.3889755725580008, 1.1903136752784462, 40.67673261318734, 0.02926276519300737, 0.9911026560667673, 0.47939570774669577, 2.0673999371526466, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
#
# start_eval: 532,  date: 2019-05-01
# end_eval:   538,  date: 2019-05-09,  df_eval last date: 2019-05-08
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  AXSM        CAG  CPRX         CSL        EVT        FIVE        KMX         SPY
# Date
# 2019-05-01  17.680000  26.714888  5.67  133.396820  17.827286  142.300003  78.349998  274.212097
# 2019-05-02  17.500000  26.546478  5.68  133.073227  17.692858  143.580002  78.239998  273.620026
# 2019-05-03  17.950001  26.599659  6.06  133.701401  17.864639  146.080002  78.620003  276.298126
# 2019-05-06  19.150000  26.413523  6.11  132.311737  17.834755  142.339996  78.309998  275.161102
# 2019-05-07  19.540001  25.881708  3.69  131.017258  17.536022  137.710007  77.680000  270.566010
# 2019-05-08  19.639999  26.227386  2.79  129.475357  17.550949  136.649994  77.709999  270.190155
#
# grp(retnStd/UI):   mean, std, mean/std:             1.416,             1.967,             0.720
# grp(CAGR/retnStd): mean, std, mean/std:         1,046.152,         2,714.126,             0.385
# grp(CAGR/UI):      mean, std, mean/std:         6,812.357,        16,773.830,             0.406
# grp(CAGR):         mean, std, mean/std:            27.850,            69.908,             0.398
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 3, 27.850432703189146, 69.90825128019503, 0.3983854865939002, 6812.357360784353, 16773.830443762996, 0.4061300955451942, 1046.1524330790105, 2714.1255397222435, 0.3854473265028378, 1.4164303836571093, 1.967191386242764, 0.7200267312894347, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 3, 27.850432703189146, 69.90825128019503, 0.3983854865939002, 6812.357360784353, 16773.830443762996, 0.4061300955451942, 1046.1524330790105, 2714.1255397222435, 0.3854473265028378, 1.4164303836571093, 1.967191386242764, 0.7200267312894347, -0.5251256889224045, -41.9386735196264, -62.25836697093567, 0.6736230897158738]
#
#
# ========================================================================================================================================================================================================
# ========================================================================================================================================================================================================
#
#
# 2 of 2 max_lookback_slice
# max_lookback_slice: (278, 308, 314)
# max lookback dates: 2018-04-26, 2018-06-08, 2018-06-18
# df_eval dates (inclusive): 2018-06-08 - 2018-06-15
# top_set_syms_n_freq: [('RARE', 8), ('AVXL', 6), ('CYRX', 6), ('MOV', 6), ('SCVL', 6), ('SIG', 6), ('TNDM', 6), ('TTD', 6), ('WWE', 6), ('FL', 5), ('MED', 5), ('SPTN', 5), ('DDS', 4), ('FIVE', 4), ('NSTG', 4), ('WSM', 4), ('CATO', 3), ('DECK', 3), ('KN', 3), ('LULU', 3)]
#
# sym_freq_15: []
# sym_freq_14: []
# sym_freq_13: []
# sym_freq_12: []
# sym_freq_11: []
# sym_freq_10: []
# sym_freq_9: []
# sym_freq_8: ['RARE']
# sym_freq_7: []
# sym_freq_6: ['AVXL', 'CYRX', 'MOV', 'SCVL', 'SIG', 'TNDM', 'TTD', 'WWE']
# sym_freq_5: ['FL', 'MED', 'SPTN']
# sym_freq_4: ['DDS', 'FIVE', 'NSTG', 'WSM']
# sym_freq_3: ['CATO', 'DECK', 'KN', 'LULU']
# sym_freq_2: []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:             1.335,            16.378,              21.9,               0.0
# start_eval: 308,  date: 2018-06-08
# end_eval:   314,  date: 2018-06-18,  df_eval last date: 2018-06-15
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#                  RARE         SPY
# Date
# 2018-06-08  79.349998  256.438385
# 2018-06-11  79.809998  256.779480
# 2018-06-12  78.330002  257.111389
# 2018-06-13  78.089996  256.290924
# 2018-06-14  81.559998  256.936188
# 2018-06-15  82.720001  256.608368
#
# grp(retnStd/UI):   mean, std, mean/std:             1.806,             0.000,               inf
# grp(CAGR/retnStd): mean, std, mean/std:           340.460,             0.000,               inf
# grp(CAGR/UI):      mean, std, mean/std:           614.794,             0.000,               inf
# grp(CAGR):         mean, std, mean/std:             7.136,             0.000,               inf
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 8, 7.135905859600095, 0.0, inf, 614.7936593065214, 0.0, inf, 340.4598997233131, 0.0, inf, 1.8057740715019754, 0.0, inf, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 8, 7.135905859600095, 0.0, inf, 614.7936593065214, 0.0, inf, 340.4598997233131, 0.0, inf, 1.8057740715019754, 0.0, inf, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
#
# start_eval: 308,  date: 2018-06-08
# end_eval:   314,  date: 2018-06-18,  df_eval last date: 2018-06-15
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#              AVXL   CYRX        MOV       SCVL        SIG       TNDM    TTD        WWE         SPY
# Date
# 2018-06-08  3.740  13.80  46.541821  16.365559  49.908184  15.640000  8.862  59.410030  256.438385
# 2018-06-11  4.080  13.76  46.096012  16.469799  50.916977  16.330000  8.882  59.698532  256.779480
# 2018-06-12  3.970  13.71  44.892345  15.669048  52.168957  17.700001  9.077  59.621586  257.111389
# 2018-06-13  4.055  14.52  43.376617  15.688004  51.421368  17.760000  9.006  59.333107  256.290924
# 2018-06-14  4.080  14.84  43.376617  15.512694  49.998253  18.860001  9.053  59.728146  256.936188
# 2018-06-15  4.180  14.72  43.956154  15.749600  50.385551  19.910000  9.012  60.383320  256.608368
#
# grp(retnStd/UI):   mean, std, mean/std:         8,138.019,        21,525.331,             0.378
# grp(CAGR/retnStd): mean, std, mean/std:       904,973.886,     2,391,191.558,             0.378
# grp(CAGR/UI):      mean, std, mean/std: 58,835,862,947.990, 155,665,050,028.669,             0.378
# grp(CAGR):         mean, std, mean/std:        24,056.797,        63,536.007,             0.379
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 6, 24056.797312481558, 63536.00702545934, 0.3786325020840832, 58835862947.99014, 155665050028.66855, 0.37796450094067, 904973.8859621919, 2391191.557694276, 0.37846147584881057, 8138.019352048506, 21525.33091050039, 0.378067096198677, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 6, 24056.797312481558, 63536.00702545934, 0.3786325020840832, 58835862947.99014, 155665050028.66855, 0.37796450094067, 904973.8859621919, 2391191.557694276, 0.37846147584881057, 8138.019352048506, 21525.33091050039, 0.378067096198677, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
#
# start_eval: 308,  date: 2018-06-08
# end_eval:   314,  date: 2018-06-18,  df_eval last date: 2018-06-15
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                    FL         MED       SPTN         SPY
# Date
# 2018-06-08  50.666733  128.026855  20.762798  256.438385
# 2018-06-11  49.884205  131.356598  20.762798  256.779480
# 2018-06-12  49.824009  135.615570  20.779280  257.111389
# 2018-06-13  49.204868  135.340210  20.729826  256.290924
# 2018-06-14  49.574631  139.134613  21.518507  256.936188
# 2018-06-15  48.903885  140.545670  21.750957  256.608368
#
# grp(retnStd/UI):   mean, std, mean/std:            10.460,             7.119,             1.469
# grp(CAGR/retnStd): mean, std, mean/std:         2,999.216,         3,875.478,             0.774
# grp(CAGR/UI):      mean, std, mean/std:        47,114.385,        59,935.085,             0.786
# grp(CAGR):         mean, std, mean/std:            39.248,            49.612,             0.791
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 5, 39.24812999511824, 49.61226526493241, 0.7910973180831579, 47114.38484363554, 59935.08508663552, 0.7860902303806228, 2999.215842360077, 3875.4779628733827, 0.7738957287571256, 10.460129321647239, 7.119237877747496, 1.4692765575852327, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 5, 39.24812999511824, 49.61226526493241, 0.7910973180831579, 47114.38484363554, 59935.08508663552, 0.7860902303806228, 2999.215842360077, 3875.4779628733827, 0.7738957287571256, 10.460129321647239, 7.119237877747496, 1.4692765575852327, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
#
# start_eval: 308,  date: 2018-06-08
# end_eval:   314,  date: 2018-06-18,  df_eval last date: 2018-06-15
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   DDS        FIVE   NSTG        WSM         SPY
# Date
# 2018-06-08  82.949226  101.190002  14.26  55.239223  256.438385
# 2018-06-11  83.974609  101.239998  14.38  54.392960  256.779480
# 2018-06-12  85.742500  101.889999  13.63  55.265949  257.111389
# 2018-06-13  81.402336  101.650002  14.27  54.152431  256.290924
# 2018-06-14  78.609093  102.089996  13.97  54.205879  256.936188
# 2018-06-15  80.332764  100.010002  13.83  55.506474  256.608368
#
# grp(retnStd/UI):   mean, std, mean/std:             1.059,             0.252,             4.205
# grp(CAGR/retnStd): mean, std, mean/std:           -20.252,            22.776,            -0.889
# grp(CAGR/UI):      mean, std, mean/std:           -19.017,            26.767,            -0.710
# grp(CAGR):         mean, std, mean/std:            -0.440,             0.437,            -1.007
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 4, -0.43960483406834433, 0.43651829044797075, -1.0070708231199341, -19.016935840058103, 26.767188158718394, -0.7104569866395944, -20.25169182823248, 22.776294183718, -0.8891565794188647, 1.0585553990499528, 0.251746072066472, 4.204853685941315, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 4, -0.43960483406834433, 0.43651829044797075, -1.0070708231199341, -19.016935840058103, 26.767188158718394, -0.7104569866395944, -20.25169182823248, 22.776294183718, -0.8891565794188647, 1.0585553990499528, 0.251746072066472, 4.204853685941315, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
#
# start_eval: 308,  date: 2018-06-08
# end_eval:   314,  date: 2018-06-18,  df_eval last date: 2018-06-15
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  CATO        DECK     KN        LULU         SPY
# Date
# 2018-06-08  19.026583  121.650002  15.48  122.019997  256.438385
# 2018-06-11  19.073879  121.250000  15.81  122.370003  256.779480
# 2018-06-12  19.239389  120.800003  15.64  124.959999  257.111389
# 2018-06-13  19.349737  119.330002  15.82  125.129997  256.290924
# 2018-06-14  19.333975  119.099998  15.93  125.879997  256.936188
# 2018-06-15  19.862055  118.809998  15.87  128.369995  256.608368
#
# grp(retnStd/UI):   mean, std, mean/std:         5,215.788,         9,015.385,             0.579
# grp(CAGR/retnStd): mean, std, mean/std:           555.306,           596.184,             0.931
# grp(CAGR/UI):      mean, std, mean/std:     7,290,416.074,    12,613,683.247,             0.578
# grp(CAGR):         mean, std, mean/std:             5.357,             4.825,             1.110
# row_add_total: [2, '[10, 20, 30]', 6, 20, 0, 10, 3, 5.356599201895465, 4.824997808220656, 1.1101765046958334, 7290416.073504952, 12613683.247303134, 0.5779767836697245, 555.3064232730873, 596.1835091349743, 0.931435396592574, 5215.787787398647, 9015.38498831206, 0.5785429900287811, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
# appended row_add to df_eval_sym_freq_results_train:
# [2, '[10, 20, 30]', 6, 20, 0, 10, 3, 5.356599201895465, 4.824997808220656, 1.1101765046958334, 7290416.073504952, 12613683.247303134, 0.5779767836697245, 555.3064232730873, 596.1835091349743, 0.931435396592574, 5215.787787398647, 9015.38498831206, 0.5785429900287811, 0.033961052242881706, 21.864891547380687, 16.377843673790473, 1.3350287121357227]
#
#
# ========================================================================================================================================================================================================
# ========================================================================================================================================================================================================

# %%
if store_results:  # record results to df
  if run_type == 'train':
    pickle_dump(df_eval_sym_freq_results_train, path_data_dump, fp_df_eval_sym_freq_results_train)
    print(f'Save results to: {fp_df_eval_sym_freq_results_train}')
  elif run_type == 'validate':
    pickle_dump(df_eval_sym_freq_results_validate, path_data_dump, fp_df_eval_sym_freq_results_validate)   
    print(f'Save results to: {fp_df_eval_sym_freq_results_validate}')
  elif run_type == 'test':
    pickle_dump(df_eval_sym_freq_results_test, path_data_dump, fp_df_eval_sym_freq_results_test)   
    print(f'Save results to: {fp_df_eval_sym_freq_results_test}')
  else:
    msg_stop = f"ERROR: Result was not saved. run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop )
# Out:
# Save results to: df_eval_sym_freq_results_train

# %%
if verbose:
  from IPython.display import display, HTML
  df = df_eval.copy()
  df_SPY = df_SPY.copy()  
  _my_df = [df_eval, df_SPY]
  for _df in _my_df:
    # print(f'_df:\n{_df}')
    (
      symbols,
      period_yr,
      retn,
      DD,
      UI,
      MDD,
      retnMean,
      retnStd,
      retnStd_div_UI,
      CAGR,
      CAGR_div_retnStd,
      CAGR_div_UI,
      grp_retnStd_div_UI,     
      grp_CAGR,
      grp_CAGR_div_retnStd,
      grp_CAGR_div_UI,
    ) = symb_perf_stats_vectorized_v8(_df)

    # display(HTML(_df.to_html()))
    print(f'_df:\n{_df}\n')
    print(f'symbols:\n{symbols}\n')
    print(f'period_yr:\n{period_yr}\n')
    print(f'retn:\n{retn}\n')
    print(f'DD:\n{DD}\n')
    print(f'UI:\n{UI}\n')
    print(f'MDD:\n{MDD}\n')
    print(f'retnMean:\n{retnMean}\n')
    print(f'retnStd:\n{retnStd}\n')
    print(f'retnStd_div_UI:\n{retnStd_div_UI}\n')
    print(f'CAGR:\n{CAGR}\n')
    print(f'CAGR_div_retnStd:\n{CAGR_div_retnStd}\n')
    print(f'CAGR_div_UI:\n{CAGR_div_UI}\n')
    print(f'grp_retnStd_div_UI:\n{grp_retnStd_div_UI}\n')
    print(f'grp_CAGR_div_retnStd:\n{grp_CAGR_div_retnStd}\n')    
    print(f'grp_CAGR_div_UI:\n{grp_CAGR_div_UI}\n')
    print(f'grp_CAGR:\n{grp_CAGR}\n')
# Out:
# _df:
#                  CATO        DECK     KN        LULU
# Date
# 2018-06-08  19.026583  121.650002  15.48  122.019997
# 2018-06-11  19.073879  121.250000  15.81  122.370003
# 2018-06-12  19.239389  120.800003  15.64  124.959999
# 2018-06-13  19.349737  119.330002  15.82  125.129997
# 2018-06-14  19.333975  119.099998  15.93  125.879997
# 2018-06-15  19.862055  118.809998  15.87  128.369995
#
# symbols:
# Index(['CATO', 'DECK', 'KN', 'LULU'], dtype='object')
#
# period_yr:
# 0.01984126984126984
#
# retn:
#                 CATO      DECK        KN      LULU
# Date
# 2018-06-08  0.000000  0.000000  0.000000  0.000000
# 2018-06-11  0.002486 -0.003288  0.021318  0.002868
# 2018-06-12  0.008677 -0.003711 -0.010753  0.021165
# 2018-06-13  0.005736 -0.012169  0.011509  0.001360
# 2018-06-14 -0.000815 -0.001927  0.006953  0.005994
# 2018-06-15  0.027314 -0.002435 -0.003767  0.019781
#
# DD:
#                 CATO      DECK        KN      LULU
# Date
# 2018-06-08  0.000000  0.000000  0.000000  0.000000
# 2018-06-11  0.000000 -0.003288  0.000000  0.000000
# 2018-06-12  0.000000 -0.006987 -0.010753  0.000000
# 2018-06-13  0.000000 -0.019071  0.000000  0.000000
# 2018-06-14 -0.000815 -0.020962  0.000000  0.000000
# 2018-06-15  0.000000 -0.023346 -0.003767  0.000001
#
# UI:
# CATO    3.325598e-04
# DECK    1.531752e-02
# KN      4.651289e-03
# LULU    4.082483e-07
# dtype: float64
#
# MDD:
# CATO   -0.000815
# DECK   -0.023346
# KN     -0.010753
# LULU    0.000000
# dtype: float64
#
# retnMean:
# CATO    0.008680
# DECK   -0.004706
# KN      0.005052
# LULU    0.010234
# dtype: float64
#
# retnStd:
# CATO    0.009843
# DECK    0.003783
# KN      0.011291
# LULU    0.008504
# dtype: float64
#
# retnStd_div_UI:
# CATO       29.596843
# DECK        0.247001
# KN          2.427511
# LULU    20830.879794
# dtype: float64
#
# CAGR:
# CATO     7.722370
# DECK    -0.695954
# KN       2.504462
# LULU    11.895518
# dtype: float64
#
# CAGR_div_retnStd:
# CATO     784.576885
# DECK    -183.946912
# KN       221.809371
# LULU    1398.786349
# dtype: float64
#
# CAGR_div_UI:
# CATO    2.322100e+04
# DECK   -4.543513e+01
# KN      5.384447e+02
# LULU    2.913795e+07
# dtype: float64
#
# grp_retnStd_div_UI:
# [5215.787787398647, 9015.38498831206, 0.5785429900287811]
#
# grp_CAGR_div_retnStd:
# [555.3064232730873, 596.1835091349743, 0.931435396592574]
#
# grp_CAGR_div_UI:
# [7290416.073504952, 12613683.247303134, 0.5779767836697245]
#
# grp_CAGR:
# [5.356599201895465, 4.824997808220656, 1.1101765046958334]
#
# _df:
#                    SPY
# Date
# 2018-06-08  256.438385
# 2018-06-11  256.779480
# 2018-06-12  257.111389
# 2018-06-13  256.290924
# 2018-06-14  256.936188
# 2018-06-15  256.608368
#
# symbols:
# Index(['SPY'], dtype='object')
#
# period_yr:
# 0.01984126984126984
#
# retn:
#                  SPY
# Date
# 2018-06-08  0.000000
# 2018-06-11  0.001330
# 2018-06-12  0.001293
# 2018-06-13 -0.003191
# 2018-06-14  0.002518
# 2018-06-15 -0.001276
#
# DD:
#                  SPY
# Date
# 2018-06-08  0.000000
# 2018-06-11  0.000000
# 2018-06-12  0.000000
# 2018-06-13 -0.003191
# 2018-06-14 -0.000681
# 2018-06-15 -0.001956
#
# UI:
# SPY    0.001553
# dtype: float64
#
# MDD:
# SPY   -0.003191
# dtype: float64
#
# retnMean:
# SPY    0.000135
# dtype: float64
#
# retnStd:
# SPY    0.002074
# dtype: float64
#
# retnStd_div_UI:
# SPY    1.335029
# dtype: float64
#
# CAGR:
# SPY    0.033961
# dtype: float64
#
# CAGR_div_retnStd:
# SPY    16.377844
# dtype: float64
#
# CAGR_div_UI:
# SPY    21.864892
# dtype: float64
#
# grp_retnStd_div_UI:
# [1.3350287121357227, 0.0, inf]
#
# grp_CAGR_div_retnStd:
# [16.377843673790473, 0.0, inf]
#
# grp_CAGR_div_UI:
# [21.864891547380687, 0.0, inf]
#
# grp_CAGR:
# [0.033961052242881706, 0.0, inf]
