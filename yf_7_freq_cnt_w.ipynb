# %%
def top_set_sym_freq_cnt(top_set_syms_n_freq):
    # accommodate upto 5 periods of days_lookbacks(i.e. days_lookbacks = [5, 10, 15, 20, 25])
    sym_freq_cnt_15 = []
    sym_freq_cnt_14 = []
    sym_freq_cnt_13 = []
    sym_freq_cnt_12 = []
    sym_freq_cnt_11 = []
    sym_freq_cnt_10 = []
    sym_freq_cnt_9 = []
    sym_freq_cnt_8 = []
    sym_freq_cnt_7 = []
    sym_freq_cnt_6 = []
    sym_freq_cnt_5 = []
    sym_freq_cnt_4 = []
    sym_freq_cnt_3 = []
    sym_freq_cnt_2 = []

    for sym_n_freq in top_set_syms_n_freq:
        _sym = sym_n_freq[0]
        _freq = sym_n_freq[1]
        if _freq == 15:
            sym_freq_cnt_15.append(_sym)
        elif _freq == 14:
            sym_freq_cnt_14.append(_sym)
        elif _freq == 13:
            sym_freq_cnt_13.append(_sym)
        elif _freq == 12:
            sym_freq_cnt_12.append(_sym)                        
        elif _freq == 11:
            sym_freq_cnt_11.append(_sym)
        elif _freq == 10:
            sym_freq_cnt_10.append(_sym)            
        elif _freq == 9:
            sym_freq_cnt_9.append(_sym)
        elif _freq == 8:
            sym_freq_cnt_8.append(_sym)
        elif _freq == 7:
            sym_freq_cnt_7.append(_sym)  
        elif _freq == 6:
            sym_freq_cnt_6.append(_sym)
        elif _freq == 5:
            sym_freq_cnt_5.append(_sym)
        elif _freq == 4:
            sym_freq_cnt_4.append(_sym)
        elif _freq == 3:
            sym_freq_cnt_3.append(_sym)          
        else:
            sym_freq_cnt_2.append(_sym)

    l_sym_freq_cnt = []

    l_sym_freq_cnt.append(sym_freq_cnt_15)
    l_sym_freq_cnt.append(sym_freq_cnt_14)
    l_sym_freq_cnt.append(sym_freq_cnt_13)
    l_sym_freq_cnt.append(sym_freq_cnt_12)    
    l_sym_freq_cnt.append(sym_freq_cnt_11)   
    l_sym_freq_cnt.append(sym_freq_cnt_10)
    l_sym_freq_cnt.append(sym_freq_cnt_9)
    l_sym_freq_cnt.append(sym_freq_cnt_8)
    l_sym_freq_cnt.append(sym_freq_cnt_7)    
    l_sym_freq_cnt.append(sym_freq_cnt_6)
    l_sym_freq_cnt.append(sym_freq_cnt_5)
    l_sym_freq_cnt.append(sym_freq_cnt_4)
    l_sym_freq_cnt.append(sym_freq_cnt_3)    
    l_sym_freq_cnt.append(sym_freq_cnt_2)    

    return l_sym_freq_cnt

# %%
import pandas as pd
# import numpy as np
import datetime
# from IPython.display import display, HTML
from yf_utils import _2_split_train_val_test, _3_random_slices, _4_lookback_slices
from yf_utils import _5_perf_ranks, _6_grp_tuples_sort_sum
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 16)
pd.set_option('display.width', 790)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = 'df_close_clean'



str_today = datetime.date.today().strftime('%Y-%m-%d')
# str_today = '2023-03-08'

###########################################################################################################
fp_df_eval_sym_freq_results_train    = f'df_eval_sym_freq_results_train_{str_today}'
fp_df_eval_sym_freq_results_validate = f'df_eval_sym_freq_results_validate_{str_today}'
fp_df_eval_sym_freq_results_test     = f'df_eval_sym_freq_results_test_{str_today}'
fp_df_eval_sym_freq_results_current  = f'df_eval_sym_freq_results_current_{str_today}'
###########################################################################################################

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# %% [markdown]
# #### Check run results

# %%
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_train)
# df
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_validate)
# df
# df = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_test)
# df

# %% [markdown]
# #### Create column names

# %%
col_add0 = ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'sym_freq_cnt']
col_add1 = ['grp(CAGR)_mean',         'grp(CAGR)_std',         'grp(CAGR)_mean/std']
col_add2 = ['grp(CAGR/UI)_mean',      'grp(CAGR/UI)_std',      'grp(CAGR/UI)_mean/std']
col_add3 = ['grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std']
col_add4 = ['grp(retnStd/UI)_mean',   'grp(retnStd/UI)_std',   'grp(retnStd/UI)_mean/std']
col_add5 = ['SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI']

col_add_total = col_add0 + col_add1 + col_add2 + col_add3 + col_add4 + col_add5
print(f'col_add_total:\n{col_add_total}, total columns: {len(col_add_total)}')
# Out:
# col_add_total:
# ['n_samples', 'days_lookbacks', 'days_eval', 'n_top_syms', 'syms_start', 'syms_end', 'sym_freq_cnt', 'grp(CAGR)_mean', 'grp(CAGR)_std', 'grp(CAGR)_mean/std', 'grp(CAGR/UI)_mean', 'grp(CAGR/UI)_std', 'grp(CAGR/UI)_mean/std', 'grp(CAGR/retnStd)_mean', 'grp(CAGR/retnStd)_std', 'grp(CAGR/retnStd)_mean/std', 'grp(retnStd/UI)_mean', 'grp(retnStd/UI)_std', 'grp(retnStd/UI)_mean/std', 'SPY_CAGR', 'SPY_CAGR/UI', 'SPY_CAGR/retnStd', 'SPY_retnStd/UI'], total columns: 23

# %% [markdown]
# #### DANGER: Create a new Dataframe to store run results. Previous data will be destroyed. To create a new dataframe, uncomment one choice from below.

# %%
# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_train)
# df

# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_validate)
# df

# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_test)
# df

# # # Creating Empty DataFrame and save it to file
# df = pd.DataFrame(columns=col_add_total)
# pickle_dump(df, path_data_dump, fp_df_eval_sym_freq_results_current)
# df
# Out:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []

# %% [markdown]
# #### Select run parameters. Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb

# %%
# SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
store_results = False
# store_results = True

# select run type
run_type = 'train'
# run_type = 'validate'
# run_type = 'test'
# run_type = 'current'

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms 
# n_samples = 400  
n_samples = 3

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
# days_lookbacks = [7, 15, 30, 60, 120]
days_lookbacks = [30, 60, 120]
# days_lookbacks = [2]
days_lookbacks.sort()

# number of days from iloc_end_train are used to evaluate effectiveness of the training
days_eval = 4

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20  

syms_start = 0  #  start index of n_top_syms for evaluation
syms_end = 10  #  end index of n_top_syms for evaluation

# over-ride parameters for run_type 'current'
if run_type == 'current':
  days_eval = 0
  n_samples = 1

print(f'verbose : {verbose }')
print(f'store_results: {store_results}')
print(f'run_type: {run_type}')
print(f'n_samples: {n_samples}')
print(f'days_lookbacks: {days_lookbacks}')
print(f'days_eval: {days_eval}')
print(f'n_top_syms: {n_top_syms}')
print(f'syms_start: {syms_start}')
print(f'syms_end: {syms_end}')
# Out:
# verbose : True
# store_results: False
# run_type: train
# n_samples: 3
# days_lookbacks: [30, 60, 120]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10

# %% [markdown]
# #### Split dataframe into Train, Validate and Test

# %%
# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = _2_split_train_val_test(df_close_clean)

# %% [markdown]
# #### Create df_current, a df with the latest data

# %%
max_days_lookbacks = max(days_lookbacks)
print(f'max_days_lookbacks: {max_days_lookbacks}')
df_current = df_test.tail(max_days_lookbacks)  
df_current.tail(3)
# Out:
# max_days_lookbacks: 120
#                      A         AA    AAL         AAP        AAPL        AAWW         AB        ABB        ABBV         ABC        ABM    ABR        ABT       ACGL       ACHC  ...       XRAY    XRX         XYL       YELP       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION        ZTO         ZTS   ZUMZ        ZWS
# Date                                                                                                                                                                           ...
# 2023-03-09  138.929993  47.900002  15.88  129.830002  150.589996  100.279999  36.740002  33.930000  147.350006  150.000000  46.139999  13.71  97.849998  68.379997  69.989998  ...  37.090000  16.10  100.480003  29.450001  57.639999  28.690001  122.349998  296.910004  76.050003  38.779999  41.360001  24.980000  167.490005  22.52  22.299999
# 2023-03-10  135.720001  44.910000  15.46  128.039993  148.500000   99.930000  36.869999  33.139999  149.710007  149.600006  44.750000  13.15  96.959999  66.610001  68.980003  ...  36.930000  15.58   98.980003  28.570000  58.759998  28.440001  123.529999  288.190002  73.809998  38.650002  40.349998  25.740000  161.529999  21.65  21.309999
# 2023-03-13  136.690002  44.709999  14.85  124.360001  150.470001   99.519997  36.009998  32.919998  151.949997  148.369995  44.220001  12.99  98.190002  65.180000  68.349998  ...  37.549999  14.96   97.900002  28.360001  59.139999  27.620001  124.250000  284.920013  73.239998  39.459999  29.969999  25.709999  163.410004  20.66  21.070000
#
# [3 rows x 1292 columns]

# %% [markdown]
# #### Load previous data according to run_type

# %%
if run_type == 'train':
  df_eval_sym_freq_results_train = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_train)
  df = df_train.copy()    
elif run_type == 'validate':
  df_eval_sym_freq_results_validate = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_validate)
  df = df_val.copy()
elif run_type == 'test':
  df_eval_sym_freq_results_test = pickle_load(path_data_dump, fp_df_eval_sym_freq_results_test)
  df = df_test.copy()
elif run_type == 'current':  # get the current results
  df = df_current.copy()
else:
  msg_stop = f"ERROR run_type must be 'train', 'validate', 'test' or 'current', run_type is: {run_type}"
  raise SystemExit(msg_stop )

# %% [markdown]
# #### Print dataframe for the run, and lengths of other dataframes

# %%
print(f'df.tail(3):\n{df.tail(3)}\n')
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
len_df_current = len(df_current)
print(f'run_type: {run_type}, len(df): {len(df)}')
print(f'len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}, len_df_current: {len_df_current} ')
# Out:
# df.tail(3):
#                      A         AA        AAL         AAP        AAPL       AAWW         AB        ABB        ABBV         ABC        ABM        ABR         ABT       ACGL       ACHC  ...       XRAY        XRX         XYL       YELP       YUMC         YY         ZBH        ZBRA          ZD          ZG       ZION        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                                   ...
# 2021-05-25  131.847366  34.752930  23.209999  178.918228  125.603638  73.220001  38.166515  32.807087  106.727570  112.387894  47.737270  14.829548  115.037331  39.169998  62.090000  ...  65.783981  21.245119  114.152603  38.099998  64.132469  76.961487  160.729965  501.920013  108.686958  113.769997  53.410854  31.902248  174.493118  42.330002  48.712315
# 2021-05-26  131.906723  36.137112  23.900000  179.879425  125.554146  75.019997  38.699390  32.904530  106.857986  112.084908  48.202435  15.237702  113.434196  38.990002  63.529999  ...  65.587906  21.572107  114.515175  38.730000  64.791580  77.767075  157.300003  501.329987  109.773911  116.320000  54.078251  31.565599  173.208786  44.750000  49.433319
# 2021-05-27  136.112625  38.569321  24.430000  179.527313  124.000183  75.580002  39.363312  33.284531  104.640709  112.407448  48.464081  15.441776  112.404289  39.680000  63.740002  ...  65.176155  21.790096  115.240326  39.810001  65.981949  78.179024  160.605408  498.100006  109.243477  116.669998  55.174683  31.268560  172.566620  44.540001  49.304916
#
# [3 rows x 1292 columns]
#
# run_type: train, len(df): 1050
# len_df_train: 1050, len_df_val: 300, len_df_test: 150, len_df_current: 120

# %% [markdown]
# #### Create a sets of iloc lookback slices (iloc_start_train:iloc_end_train:iloc_end_eval), where:
# * iloc_end_train - iloc_start_train = days_lookback
# * iloc_end_eval - iloc_end_train = days_eval
# #### for example, if given:
# * n_samples = 2
# * days_lookbacks = [10, 20, 30]
# * days_eval = 5
# #### a possible result is:
#   - max_lookback_slices: [(417, 447, 452), (265, 295, 300)], where:
#     - len(max_lookback_slices) = n_samples = 2
#     - middle number in the tuples, 447 and 295, is the iloc of the "pivot day" for the days in "days_lookbacks" to lookback
#     - 447 - 417 = middle number - first number = max(days_lookbacks) = 30
#     - 295 - 265 = middle number - first number = max(days_lookbacks) = 30
#     - 452 - 447 = last number - middle number = days_eval = 5
#     - 300 - 295 = last number - middle number = days_eval = 5
#   - sets_lookback_slices: [[(437, 447, 452), (427, 447, 452), (417, 447, 452)], [(285, 295, 300), (275, 295, 300), (265, 295, 300)]], where:
#     - len(sets_lookback_slices) = n_samples = 2
#     - last tuple in each list, i.e. (417, 447, 452) and (265, 295, 300), is a tuple from max_lookback_slices
#     - where a set, e.g. [(437, 447, 452), (427, 447, 452), (417, 447, 452)]:
#       - middle number, 447, iloc of the "pivot day" is constant for that set
#       - middle number - first number, is the training period specified in days_lookbacks
#         - 447 - 437 = middle number - first number = days_lookbacks[0] = 10
#         - 447 - 427 = middle number - first number = days_lookbacks[1] = 20
#         - 447 - 417 = middle number - first number = days_lookbacks[2] = 30
#       - last number, 452, iloc of the end of the evaluation period is constant
#         - 452 - 447 = last number - middle number = days_eval = 5

# %%
# return n_samples slices
max_lookback_slices = _3_random_slices(len_df, n_samples=n_samples, days_lookback=max(days_lookbacks), days_eval=days_eval, verbose=True)
# return n_samples * len(days_lookbacks) slices
sets_lookback_slices = _4_lookback_slices(max_slices=max_lookback_slices, days_lookbacks=days_lookbacks, verbose=False)

if verbose:
  print(f'number of max_lookback_slices is equal to n_samples = {n_samples}')
  print(f'max_lookback_slices:\n{max_lookback_slices}\n')
  print(f'number of sets in sets_lookback_slices is equal to n_samples = {n_samples}')
  print(f'days_lookbacks: {days_lookbacks}')  
  print(f'sets_lookback_slices:\n{sets_lookback_slices}\n')
  print(f'number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): len({days_lookbacks})')
# Out:
# days_lookback: 120, days_eval: 4, days_total: 124, len_df: 1050
# number of max_lookback_slices is equal to n_samples = 3
# max_lookback_slices:
# [(256, 376, 380), (384, 504, 508), (912, 1032, 1036)]
#
# number of sets in sets_lookback_slices is equal to n_samples = 3
# days_lookbacks: [30, 60, 120]
# sets_lookback_slices:
# [[(346, 376, 380), (316, 376, 380), (256, 376, 380)], [(474, 504, 508), (444, 504, 508), (384, 504, 508)], [(1002, 1032, 1036), (972, 1032, 1036), (912, 1032, 1036)]]
#
# number of tuples in each "set of lookback slices" is equal to len(days_lookbacks): len([30, 60, 120])

# %% [markdown]
# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the max_lookback_slices. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks of a tuple in max_lookback_slices.

# %%
# grp_top_set_syms_n_freq is a list of lists of top_set_syms_n_freq, e.g.
#   [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)],
#    [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
#   where each list is the best performing symbols from a lb_slices, e.g.
#     [(483, 513, 523), (453, 513, 523), (393, 513, 523)]  
grp_top_set_syms_n_freq = []  # list of lists of top_set_symbols_n_freq, there are n_samples lists in list
grp_top_set_syms = []  # grp_top_set_syms_n_freq without the frequency count

# lb_slices, e.g  [(483, 513, 523), (453, 513, 523), (393, 513, 523)],
#  is one max_lookback_slice, e.g. (393, 513, 523), along with
#  the remaining slices of the days_lookbacks, e.g. (483, 513, 523), (453, 513, 523)  
for i, lb_slices in enumerate(sets_lookback_slices):
  print(f'\n########## {i + 1} of {len(sets_lookback_slices)} lb_slices in sets_lookcak_slices ##########')
  # unsorted list of the most frequent symbols in performance metrics of the lb_slices  
  grp_most_freq_syms = []
  for j, lb_slice in enumerate(lb_slices):  # lb_slice, e.g. (246, 276, 286)
    iloc_start_train = lb_slice[0]     # iloc of start of training period
    iloc_end_train   = lb_slice[1]     # iloc of end of training period
    iloc_start_eval  = iloc_end_train  # iloc of start of evaluation period
    iloc_end_eval    = lb_slice[2]     # iloc of end of evaluation period
    lookback         = iloc_end_train - iloc_start_train
    d_eval           = iloc_end_eval - iloc_start_eval

    _df = df.iloc[iloc_start_train:iloc_end_train]
    date_start_df_train = _df.index[0].strftime('%Y-%m-%d')
    date_end_df_train = _df.index[-1].strftime('%Y-%m-%d')

    if verbose:
      print(f'days lookback:       {lookback},  {j + 1} of {len(days_lookbacks)} days_lookbacks: {days_lookbacks}')
      print(f'lb_slices:           {lb_slices}')
      print(f'lb_slice:            {lb_slice}')
      print(f'days eval:           {d_eval}')    
      print(f'iloc_start_train:    {iloc_start_train}')
      print(f'iloc_end_train:      {iloc_end_train}')
      print(f'date_start_df_train: {date_start_df_train}')
      print(f'date_end_df_train:   {date_end_df_train}')


    perf_ranks, most_freq_syms = _5_perf_ranks(_df, n_top_syms=n_top_syms)
    # unsorted list of the most frequent symbols in performance metrics of the lb_slices  
    grp_most_freq_syms.append(most_freq_syms)  
    if verbose:    
      # 1 lookback of r_CAGR/UI, r_CAGR/retnStd, r_retnStd/UI
      print(f'perf_ranks: {perf_ranks}')  
      # most common symbols of perf_ranks 
      print(f'most_freq_syms: {most_freq_syms}')     
      # grp_perf_ranks[lookback] = perf_ranks
      print(f'+++ finish lookback slice {lookback} +++\n')

  if verbose:
    print(f'grp_most_freq_syms: {grp_most_freq_syms}')
    # grp_most_freq_syms a is list of lists of tuples of 
    #  the most-common-symbols symbol:frequency cumulated from
    #  each days_lookback  
    print(f'**** finish lookback slices {lb_slices} ****\n')

  # flatten list of lists of (symbol:frequency)
  flat_grp_most_freq_syms = [val for sublist in grp_most_freq_syms for val in sublist]
  # return "symbol, frequency" pairs of the most frequent symbols, i.e. best performing symbols,
  #  in flat_grp_most_freq_syms. The paris are sorted in descending frequency.   
  set_most_freq_syms = _6_grp_tuples_sort_sum(flat_grp_most_freq_syms, reverse=True)
  # get the top n_top_syms of the most frequent "symbol, frequency" pairs
  top_set_syms_n_freq = set_most_freq_syms[0:n_top_syms]
  # get symbols from top_set_syms_n_freq, i[0] = symbol, i[1]=symbol's frequency count
  top_set_syms = [i[0] for i in top_set_syms_n_freq[syms_start:syms_end]]  

  # grp_top_set_syms_n_freq is a list of lists of top_set_syms_n_freq, e.g.
  #   [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)],
  #    [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
  #   where each list is the best performing symbols from a lb_slices, e.g.
  #     [(483, 513, 523), (453, 513, 523), (393, 513, 523)]    
  grp_top_set_syms_n_freq.append(top_set_syms_n_freq)
  grp_top_set_syms.append(top_set_syms)

  if verbose:  
    print(f'top {n_top_syms} ranked symbols and frequency from set {lb_slices}:\n{top_set_syms_n_freq}')
    print(f'top {n_top_syms} ranked symbols from set {lb_slices}:\n{top_set_syms}')  
    print(f'===== finish top {n_top_syms} ranked symbols from days_lookback set {lb_slices} =====\n\n')
# Out:
# ########## 1 of 3 lb_slices in sets_lookcak_slices ##########
# days lookback:       30,  1 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(346, 376, 380), (316, 376, 380), (256, 376, 380)]
# lb_slice:            (346, 376, 380)
# days eval:           4
# iloc_start_train:    346
# iloc_end_train:      376
# date_start_df_train: 2018-08-10
# date_end_df_train:   2018-09-21
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['AMD', 'SWBI', 'EXAS', 'DCI', 'MCFT', 'ALSN', 'SBH', 'PLAY', 'LOW',
#        'TFX', 'BCPC', 'ROK', 'NVCR', 'TA', 'PH', 'HELE', 'ENS', 'SYF',
#        'EXLS', 'RGR'], dtype=object), 'r_CAGR/retnStd': array(['AMD', 'SWBI', 'EXAS', 'MCFT', 'SBH', 'DCI', 'ELF', 'NVCR', 'TNDM',
#        'ALSN', 'TFX', 'TA', 'UVV', 'PLAY', 'CLW', 'EVH', 'ROK', 'PH',
#        'ENS', 'HELE'], dtype=object), 'r_retnStd/UI': array(['DCI', 'SWBI', 'ALSN', 'EXAS', 'LOW', 'BCPC', 'MCFT', 'PLAY',
#        'GLW', 'RGR', 'SYF', 'HY', 'ROK', 'ASTE', 'FTV', 'FTSM', 'TFX',
#        'RAMP', 'CR', 'AMD'], dtype=object)}}
# most_freq_syms: [('AMD', 3), ('SWBI', 3), ('EXAS', 3), ('DCI', 3), ('MCFT', 3), ('ALSN', 3), ('PLAY', 3), ('TFX', 3), ('ROK', 3), ('SBH', 2), ('LOW', 2), ('BCPC', 2), ('NVCR', 2), ('TA', 2), ('PH', 2), ('HELE', 2), ('ENS', 2), ('SYF', 2), ('RGR', 2), ('EXLS', 1), ('ELF', 1), ('TNDM', 1), ('UVV', 1), ('CLW', 1), ('EVH', 1), ('GLW', 1), ('HY', 1), ('ASTE', 1), ('FTV', 1), ('FTSM', 1), ('RAMP', 1), ('CR', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  2 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(346, 376, 380), (316, 376, 380), (256, 376, 380)]
# lb_slice:            (316, 376, 380)
# days eval:           4
# iloc_start_train:    316
# iloc_end_train:      376
# date_start_df_train: 2018-06-28
# date_end_df_train:   2018-09-21
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['AMD', 'MOH', 'FLS', 'RAMP', 'DCI', 'PKI', 'FTSM', 'QCOM', 'ALSN',
#        'LLY', 'HCA', 'TNDM', 'PCRX', 'PAYC', 'AJG', 'UAL', 'TEAM', 'STEW',
#        'DOV', 'GLW'], dtype=object), 'r_CAGR/retnStd': array(['AMD', 'TNDM', 'RAMP', 'PCRX', 'MOH', 'FLS', 'NVCR', 'PKI', 'TEAM',
#        'DCI', 'BALL', 'TSLX', 'PAYC', 'ALRM', 'AJG', 'PFE', 'LLY', 'QCOM',
#        'ORLY', 'OLED'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'MOH', 'HCA', 'ALSN', 'QCOM', 'FLS', 'DCI', 'LLY', 'WST',
#        'PKI', 'AIN', 'AMD', 'UAL', 'SPSC', 'NUVA', 'DOV', 'NSC', 'J',
#        'AJG', 'PAYC'], dtype=object)}}
# most_freq_syms: [('AMD', 3), ('MOH', 3), ('FLS', 3), ('DCI', 3), ('PKI', 3), ('QCOM', 3), ('LLY', 3), ('PAYC', 3), ('AJG', 3), ('RAMP', 2), ('FTSM', 2), ('ALSN', 2), ('HCA', 2), ('TNDM', 2), ('PCRX', 2), ('UAL', 2), ('TEAM', 2), ('DOV', 2), ('STEW', 1), ('GLW', 1), ('NVCR', 1), ('BALL', 1), ('TSLX', 1), ('ALRM', 1), ('PFE', 1), ('ORLY', 1), ('OLED', 1), ('WST', 1), ('AIN', 1), ('SPSC', 1), ('NUVA', 1), ('NSC', 1), ('J', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  3 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(346, 376, 380), (316, 376, 380), (256, 376, 380)]
# lb_slice:            (256, 376, 380)
# days eval:           4
# iloc_start_train:    256
# iloc_end_train:      376
# date_start_df_train: 2018-04-04
# date_end_df_train:   2018-09-21
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['TNDM', 'STAA', 'AMD', 'FTSM', 'WWE', 'TTD', 'RAMP', 'MOH', 'NVCR',
#        'NTRA', 'DXCM', 'SEAS', 'XENE', 'TWLO', 'LULU', 'MED', 'AORT',
#        'HELE', 'TDOC', 'SPSC'], dtype=object), 'r_CAGR/retnStd': array(['TNDM', 'AMD', 'STAA', 'WWE', 'NTRA', 'NVCR', 'RAMP', 'XENE',
#        'TTD', 'FTSM', 'SEAS', 'MOH', 'MED', 'TWLO', 'ROCC', 'EVH', 'W',
#        'NSTG', 'BLFS', 'TDOC'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'TTD', 'MOH', 'DXCM', 'STAA', 'RAMP', 'TNDM', 'HELE',
#        'LULU', 'WWE', 'SPSC', 'HCA', 'NSC', 'SIG', 'AMD', 'AORT', 'TWLO',
#        'ETSY', 'PMT', 'MCS'], dtype=object)}}
# most_freq_syms: [('TNDM', 3), ('STAA', 3), ('AMD', 3), ('FTSM', 3), ('WWE', 3), ('TTD', 3), ('RAMP', 3), ('MOH', 3), ('TWLO', 3), ('NVCR', 2), ('NTRA', 2), ('DXCM', 2), ('SEAS', 2), ('XENE', 2), ('LULU', 2), ('MED', 2), ('AORT', 2), ('HELE', 2), ('TDOC', 2), ('SPSC', 2), ('ROCC', 1), ('EVH', 1), ('W', 1), ('NSTG', 1), ('BLFS', 1), ('HCA', 1), ('NSC', 1), ('SIG', 1), ('ETSY', 1), ('PMT', 1), ('MCS', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('AMD', 3), ('SWBI', 3), ('EXAS', 3), ('DCI', 3), ('MCFT', 3), ('ALSN', 3), ('PLAY', 3), ('TFX', 3), ('ROK', 3), ('SBH', 2), ('LOW', 2), ('BCPC', 2), ('NVCR', 2), ('TA', 2), ('PH', 2), ('HELE', 2), ('ENS', 2), ('SYF', 2), ('RGR', 2), ('EXLS', 1), ('ELF', 1), ('TNDM', 1), ('UVV', 1), ('CLW', 1), ('EVH', 1), ('GLW', 1), ('HY', 1), ('ASTE', 1), ('FTV', 1), ('FTSM', 1), ('RAMP', 1), ('CR', 1)], [('AMD', 3), ('MOH', 3), ('FLS', 3), ('DCI', 3), ('PKI', 3), ('QCOM', 3), ('LLY', 3), ('PAYC', 3), ('AJG', 3), ('RAMP', 2), ('FTSM', 2), ('ALSN', 2), ('HCA', 2), ('TNDM', 2), ('PCRX', 2), ('UAL', 2), ('TEAM', 2), ('DOV', 2), ('STEW', 1), ('GLW', 1), ('NVCR', 1), ('BALL', 1), ('TSLX', 1), ('ALRM', 1), ('PFE', 1), ('ORLY', 1), ('OLED', 1), ('WST', 1), ('AIN', 1), ('SPSC', 1), ('NUVA', 1), ('NSC', 1), ('J', 1)], [('TNDM', 3), ('STAA', 3), ('AMD', 3), ('FTSM', 3), ('WWE', 3), ('TTD', 3), ('RAMP', 3), ('MOH', 3), ('TWLO', 3), ('NVCR', 2), ('NTRA', 2), ('DXCM', 2), ('SEAS', 2), ('XENE', 2), ('LULU', 2), ('MED', 2), ('AORT', 2), ('HELE', 2), ('TDOC', 2), ('SPSC', 2), ('ROCC', 1), ('EVH', 1), ('W', 1), ('NSTG', 1), ('BLFS', 1), ('HCA', 1), ('NSC', 1), ('SIG', 1), ('ETSY', 1), ('PMT', 1), ('MCS', 1)]]
# **** finish lookback slices [(346, 376, 380), (316, 376, 380), (256, 376, 380)] ****
#
# top 20 ranked symbols and frequency from set [(346, 376, 380), (316, 376, 380), (256, 376, 380)]:
# [('AMD', 9), ('DCI', 6), ('FTSM', 6), ('MOH', 6), ('RAMP', 6), ('TNDM', 6), ('ALSN', 5), ('NVCR', 5), ('HELE', 4), ('AJG', 3), ('EXAS', 3), ('FLS', 3), ('HCA', 3), ('LLY', 3), ('MCFT', 3), ('PAYC', 3), ('PKI', 3), ('PLAY', 3), ('QCOM', 3), ('ROK', 3)]
# top 20 ranked symbols from set [(346, 376, 380), (316, 376, 380), (256, 376, 380)]:
# ['AMD', 'DCI', 'FTSM', 'MOH', 'RAMP', 'TNDM', 'ALSN', 'NVCR', 'HELE', 'AJG']
# ===== finish top 20 ranked symbols from days_lookback set [(346, 376, 380), (316, 376, 380), (256, 376, 380)] =====
#
#
#
# ########## 2 of 3 lb_slices in sets_lookcak_slices ##########
# days lookback:       30,  1 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(474, 504, 508), (444, 504, 508), (384, 504, 508)]
# lb_slice:            (474, 504, 508)
# days eval:           4
# iloc_start_train:    474
# iloc_end_train:      504
# date_start_df_train: 2019-02-14
# date_end_df_train:   2019-03-28
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['CPRX', 'JYNT', 'EVRI', 'QURE', 'IONS', 'NVS', 'FTSM', 'NXST',
#        'MELI', 'CDNS', 'AXSM', 'HAIN', 'BEP', 'PLUG', 'GRMN', 'MKC',
#        'ANET', 'CMG', 'MO', 'OLED'], dtype=object), 'r_CAGR/retnStd': array(['CPRX', 'QURE', 'JYNT', 'EVRI', 'AXSM', 'PLUG', 'HAIN', 'NXST',
#        'IONS', 'CDNS', 'MELI', 'ANET', 'CMG', 'LNTH', 'MKC', 'IRDM',
#        'PTCT', 'NVS', 'MO', 'BEP'], dtype=object), 'r_retnStd/UI': array(['FTSM', 'GRMN', 'NVS', 'BBY', 'IONS', 'BEP', 'COST', 'OLED', 'LYV',
#        'MELI', 'EVRI', 'CCEP', 'CDNS', 'CPRX', 'HIBB', 'TCOM', 'RIO',
#        'AGO', 'SR', 'SRE'], dtype=object)}}
# most_freq_syms: [('CPRX', 3), ('EVRI', 3), ('IONS', 3), ('NVS', 3), ('MELI', 3), ('CDNS', 3), ('BEP', 3), ('JYNT', 2), ('QURE', 2), ('FTSM', 2), ('NXST', 2), ('AXSM', 2), ('HAIN', 2), ('PLUG', 2), ('GRMN', 2), ('MKC', 2), ('ANET', 2), ('CMG', 2), ('MO', 2), ('OLED', 2), ('LNTH', 1), ('IRDM', 1), ('PTCT', 1), ('BBY', 1), ('COST', 1), ('LYV', 1), ('CCEP', 1), ('HIBB', 1), ('TCOM', 1), ('RIO', 1), ('AGO', 1), ('SR', 1), ('SRE', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  2 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(474, 504, 508), (444, 504, 508), (384, 504, 508)]
# lb_slice:            (444, 504, 508)
# days eval:           4
# iloc_start_train:    444
# iloc_end_train:      504
# date_start_df_train: 2019-01-02
# date_end_df_train:   2019-03-28
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['AXSM', 'EVRI', 'CPRX', 'CMG', 'QURE', 'CDNS', 'G', 'XRX', 'GRMN',
#        'ENPH', 'GIS', 'ARE', 'MELI', 'LSCC', 'PAYC', 'SSNC', 'JYNT',
#        'TNDM', 'FR', 'NXST'], dtype=object), 'r_CAGR/retnStd': array(['AXSM', 'EVRI', 'CPRX', 'ENPH', 'QURE', 'CMG', 'XRX', 'CDNS',
#        'TNDM', 'BOOT', 'PAYC', 'AVXL', 'APPS', 'GIS', 'JYNT', 'NYT',
#        'OFC', 'RARE', 'EDU', 'PLUG'], dtype=object), 'r_retnStd/UI': array(['GRMN', 'G', 'AXSM', 'BBY', 'WAT', 'LRN', 'CMG', 'LSCC', 'RACE',
#        'SYK', 'AGO', 'PAYX', 'CDNS', 'IBM', 'ARE', 'ULTA', 'FTSM', 'MELI',
#        'CSGS', 'SNPS'], dtype=object)}}
# most_freq_syms: [('AXSM', 3), ('CMG', 3), ('CDNS', 3), ('EVRI', 2), ('CPRX', 2), ('QURE', 2), ('G', 2), ('XRX', 2), ('GRMN', 2), ('ENPH', 2), ('GIS', 2), ('ARE', 2), ('MELI', 2), ('LSCC', 2), ('PAYC', 2), ('JYNT', 2), ('TNDM', 2), ('SSNC', 1), ('FR', 1), ('NXST', 1), ('BOOT', 1), ('AVXL', 1), ('APPS', 1), ('NYT', 1), ('OFC', 1), ('RARE', 1), ('EDU', 1), ('PLUG', 1), ('BBY', 1), ('WAT', 1), ('LRN', 1), ('RACE', 1), ('SYK', 1), ('AGO', 1), ('PAYX', 1), ('IBM', 1), ('ULTA', 1), ('FTSM', 1), ('CSGS', 1), ('SNPS', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  3 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(474, 504, 508), (444, 504, 508), (384, 504, 508)]
# lb_slice:            (384, 504, 508)
# days eval:           4
# iloc_start_train:    384
# iloc_end_train:      504
# date_start_df_train: 2018-10-04
# date_end_df_train:   2019-03-28
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['LRN', 'FTSM', 'AXSM', 'APPS', 'BNDX', 'MITK', 'ADC', 'ENPH',
#        'AMT', 'O', 'MYI', 'IONS', 'XRAY', 'MPW', 'NEA', 'WPC', 'WOLF',
#        'CMG', 'OR', 'PG'], dtype=object), 'r_CAGR/retnStd': array(['APPS', 'LRN', 'AXSM', 'FTSM', 'BNDX', 'ENPH', 'CMG', 'ADC',
#        'MITK', 'AMT', 'IONS', 'O', 'MYI', 'WPC', 'LNTH', 'NEA', 'MPW',
#        'OR', 'NAD', 'JYNT'], dtype=object), 'r_retnStd/UI': array(['LRN', 'FTSM', 'AXSM', 'BNDX', 'XRAY', 'DENN', 'TWLO', 'APPS',
#        'BKT', 'MITK', 'WOLF', 'DLTR', 'FIVN', 'MYI', 'HDB', 'ADC', 'USFD',
#        'O', 'MPW', 'NVO'], dtype=object)}}
# most_freq_syms: [('LRN', 3), ('FTSM', 3), ('AXSM', 3), ('APPS', 3), ('BNDX', 3), ('MITK', 3), ('ADC', 3), ('O', 3), ('MYI', 3), ('MPW', 3), ('ENPH', 2), ('AMT', 2), ('IONS', 2), ('XRAY', 2), ('NEA', 2), ('WPC', 2), ('WOLF', 2), ('CMG', 2), ('OR', 2), ('PG', 1), ('LNTH', 1), ('NAD', 1), ('JYNT', 1), ('DENN', 1), ('TWLO', 1), ('BKT', 1), ('DLTR', 1), ('FIVN', 1), ('HDB', 1), ('USFD', 1), ('NVO', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('CPRX', 3), ('EVRI', 3), ('IONS', 3), ('NVS', 3), ('MELI', 3), ('CDNS', 3), ('BEP', 3), ('JYNT', 2), ('QURE', 2), ('FTSM', 2), ('NXST', 2), ('AXSM', 2), ('HAIN', 2), ('PLUG', 2), ('GRMN', 2), ('MKC', 2), ('ANET', 2), ('CMG', 2), ('MO', 2), ('OLED', 2), ('LNTH', 1), ('IRDM', 1), ('PTCT', 1), ('BBY', 1), ('COST', 1), ('LYV', 1), ('CCEP', 1), ('HIBB', 1), ('TCOM', 1), ('RIO', 1), ('AGO', 1), ('SR', 1), ('SRE', 1)], [('AXSM', 3), ('CMG', 3), ('CDNS', 3), ('EVRI', 2), ('CPRX', 2), ('QURE', 2), ('G', 2), ('XRX', 2), ('GRMN', 2), ('ENPH', 2), ('GIS', 2), ('ARE', 2), ('MELI', 2), ('LSCC', 2), ('PAYC', 2), ('JYNT', 2), ('TNDM', 2), ('SSNC', 1), ('FR', 1), ('NXST', 1), ('BOOT', 1), ('AVXL', 1), ('APPS', 1), ('NYT', 1), ('OFC', 1), ('RARE', 1), ('EDU', 1), ('PLUG', 1), ('BBY', 1), ('WAT', 1), ('LRN', 1), ('RACE', 1), ('SYK', 1), ('AGO', 1), ('PAYX', 1), ('IBM', 1), ('ULTA', 1), ('FTSM', 1), ('CSGS', 1), ('SNPS', 1)], [('LRN', 3), ('FTSM', 3), ('AXSM', 3), ('APPS', 3), ('BNDX', 3), ('MITK', 3), ('ADC', 3), ('O', 3), ('MYI', 3), ('MPW', 3), ('ENPH', 2), ('AMT', 2), ('IONS', 2), ('XRAY', 2), ('NEA', 2), ('WPC', 2), ('WOLF', 2), ('CMG', 2), ('OR', 2), ('PG', 1), ('LNTH', 1), ('NAD', 1), ('JYNT', 1), ('DENN', 1), ('TWLO', 1), ('BKT', 1), ('DLTR', 1), ('FIVN', 1), ('HDB', 1), ('USFD', 1), ('NVO', 1)]]
# **** finish lookback slices [(474, 504, 508), (444, 504, 508), (384, 504, 508)] ****
#
# top 20 ranked symbols and frequency from set [(474, 504, 508), (444, 504, 508), (384, 504, 508)]:
# [('AXSM', 8), ('CMG', 7), ('CDNS', 6), ('FTSM', 6), ('CPRX', 5), ('EVRI', 5), ('IONS', 5), ('JYNT', 5), ('MELI', 5), ('APPS', 4), ('ENPH', 4), ('GRMN', 4), ('LRN', 4), ('QURE', 4), ('ADC', 3), ('BEP', 3), ('BNDX', 3), ('MITK', 3), ('MPW', 3), ('MYI', 3)]
# top 20 ranked symbols from set [(474, 504, 508), (444, 504, 508), (384, 504, 508)]:
# ['AXSM', 'CMG', 'CDNS', 'FTSM', 'CPRX', 'EVRI', 'IONS', 'JYNT', 'MELI', 'APPS']
# ===== finish top 20 ranked symbols from days_lookback set [(474, 504, 508), (444, 504, 508), (384, 504, 508)] =====
#
#
#
# ########## 3 of 3 lb_slices in sets_lookcak_slices ##########
# days lookback:       30,  1 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(1002, 1032, 1036), (972, 1032, 1036), (912, 1032, 1036)]
# lb_slice:            (1002, 1032, 1036)
# days eval:           4
# iloc_start_train:    1002
# iloc_end_train:      1032
# date_start_df_train: 2021-03-22
# date_end_df_train:   2021-05-03
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['STAA', 'UPS', 'MMC', 'BX', 'EFX', 'TBI', 'BRO', 'HOG', 'IQV',
#        'FNF', 'RQI', 'CSL', 'WCN', 'AJG', 'IMO', 'NCR', 'PSA', 'CAR',
#        'MOV', 'MAN'], dtype=object), 'r_CAGR/retnStd': array(['STAA', 'HOG', 'UPS', 'IQV', 'WCN', 'IMO', 'EFX', 'RQI', 'TBI',
#        'MAN', 'CAR', 'AJG', 'OI', 'BX', 'FNF', 'MOV', 'NCR', 'CRI', 'BRO',
#        'PSA'], dtype=object), 'r_retnStd/UI': array(['MMC', 'UPS', 'BX', 'TBI', 'CSL', 'BRO', 'EFX', 'FNF', 'PLD',
#        'AORT', 'KBR', 'SUI', 'STAA', 'PSA', 'O', 'GOOG', 'RQI', 'WSO',
#        'NCR', 'AJG'], dtype=object)}}
# most_freq_syms: [('STAA', 3), ('UPS', 3), ('BX', 3), ('EFX', 3), ('TBI', 3), ('BRO', 3), ('FNF', 3), ('RQI', 3), ('AJG', 3), ('NCR', 3), ('PSA', 3), ('MMC', 2), ('HOG', 2), ('IQV', 2), ('CSL', 2), ('WCN', 2), ('IMO', 2), ('CAR', 2), ('MOV', 2), ('MAN', 2), ('OI', 1), ('CRI', 1), ('PLD', 1), ('AORT', 1), ('KBR', 1), ('SUI', 1), ('O', 1), ('GOOG', 1), ('WSO', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  2 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(1002, 1032, 1036), (972, 1032, 1036), (912, 1032, 1036)]
# lb_slice:            (972, 1032, 1036)
# days eval:           4
# iloc_start_train:    972
# iloc_end_train:      1032
# date_start_df_train: 2021-02-05
# date_end_df_train:   2021-05-03
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['CAR', 'NUE', 'CHRD', 'CPE', 'SJR', 'LPX', 'AA', 'OLN', 'STLD',
#        'MHK', 'WCN', 'SNA', 'SFBS', 'GME', 'STEW', 'DOV', 'MAIN', 'GD',
#        'STWD', 'VVV'], dtype=object), 'r_CAGR/retnStd': array(['CAR', 'CPE', 'CHRD', 'NUE', 'GME', 'GDEN', 'LPX', 'SFBS', 'AA',
#        'SBLK', 'OLN', 'CTRN', 'HEP', 'GPS', 'IMO', 'CLMT', 'STLD', 'UFPI',
#        'SCHN', 'PBF'], dtype=object), 'r_retnStd/UI': array(['SJR', 'DOV', 'GD', 'NUE', 'WCN', 'SNA', 'MHK', 'STWD', 'STEW',
#        'HIG', 'TBI', 'HPQ', 'SLM', 'KT', 'CHRD', 'TT', 'CSL', 'AME',
#        'ITT', 'BWXT'], dtype=object)}}
# most_freq_syms: [('NUE', 3), ('CHRD', 3), ('CAR', 2), ('CPE', 2), ('SJR', 2), ('LPX', 2), ('AA', 2), ('OLN', 2), ('STLD', 2), ('MHK', 2), ('WCN', 2), ('SNA', 2), ('SFBS', 2), ('GME', 2), ('STEW', 2), ('DOV', 2), ('GD', 2), ('STWD', 2), ('MAIN', 1), ('VVV', 1), ('GDEN', 1), ('SBLK', 1), ('CTRN', 1), ('HEP', 1), ('GPS', 1), ('IMO', 1), ('CLMT', 1), ('UFPI', 1), ('SCHN', 1), ('PBF', 1), ('HIG', 1), ('TBI', 1), ('HPQ', 1), ('SLM', 1), ('KT', 1), ('TT', 1), ('CSL', 1), ('AME', 1), ('ITT', 1), ('BWXT', 1)]
# +++ finish lookback slice 60 +++
#
# days lookback:       120,  3 of 3 days_lookbacks: [30, 60, 120]
# lb_slices:           [(1002, 1032, 1036), (972, 1032, 1036), (912, 1032, 1036)]
# lb_slice:            (912, 1032, 1036)
# days eval:           4
# iloc_start_train:    912
# iloc_end_train:      1032
# date_start_df_train: 2020-11-09
# date_end_df_train:   2021-05-03
# perf_ranks: {'period-120': {'r_CAGR/UI': array(['CHRD', 'MARA', 'SM', 'GME', 'ACRS', 'CPE', 'ATKR', 'CTRN', 'LPX',
#        'NOG', 'IPI', 'SBLK', 'AEO', 'SLM', 'HPQ', 'KSS', 'LNTH', 'PTMN',
#        'MHK', 'MERC'], dtype=object), 'r_CAGR/retnStd': array(['CHRD', 'MARA', 'GME', 'SM', 'CPE', 'CTRN', 'ATKR', 'NOG', 'IPI',
#        'ACRS', 'SBLK', 'LPX', 'ERF', 'PDCE', 'MERC', 'AEO', 'JYNT',
#        'FANG', 'VCEL', 'EXTR'], dtype=object), 'r_retnStd/UI': array(['CHRD', 'ACRS', 'AJRD', 'SJR', 'SLM', 'MHK', 'TY', 'AN', 'STWD',
#        'HPQ', 'PTMN', 'ISD', 'CPF', 'ATI', 'ATKR', 'STEW', 'EXP', 'IVZ',
#        'LPX', 'TROW'], dtype=object)}}
# most_freq_syms: [('CHRD', 3), ('ACRS', 3), ('ATKR', 3), ('LPX', 3), ('MARA', 2), ('SM', 2), ('GME', 2), ('CPE', 2), ('CTRN', 2), ('NOG', 2), ('IPI', 2), ('SBLK', 2), ('AEO', 2), ('SLM', 2), ('HPQ', 2), ('PTMN', 2), ('MHK', 2), ('MERC', 2), ('KSS', 1), ('LNTH', 1), ('ERF', 1), ('PDCE', 1), ('JYNT', 1), ('FANG', 1), ('VCEL', 1), ('EXTR', 1), ('AJRD', 1), ('SJR', 1), ('TY', 1), ('AN', 1), ('STWD', 1), ('ISD', 1), ('CPF', 1), ('ATI', 1), ('STEW', 1), ('EXP', 1), ('IVZ', 1), ('TROW', 1)]
# +++ finish lookback slice 120 +++
#
# grp_most_freq_syms: [[('STAA', 3), ('UPS', 3), ('BX', 3), ('EFX', 3), ('TBI', 3), ('BRO', 3), ('FNF', 3), ('RQI', 3), ('AJG', 3), ('NCR', 3), ('PSA', 3), ('MMC', 2), ('HOG', 2), ('IQV', 2), ('CSL', 2), ('WCN', 2), ('IMO', 2), ('CAR', 2), ('MOV', 2), ('MAN', 2), ('OI', 1), ('CRI', 1), ('PLD', 1), ('AORT', 1), ('KBR', 1), ('SUI', 1), ('O', 1), ('GOOG', 1), ('WSO', 1)], [('NUE', 3), ('CHRD', 3), ('CAR', 2), ('CPE', 2), ('SJR', 2), ('LPX', 2), ('AA', 2), ('OLN', 2), ('STLD', 2), ('MHK', 2), ('WCN', 2), ('SNA', 2), ('SFBS', 2), ('GME', 2), ('STEW', 2), ('DOV', 2), ('GD', 2), ('STWD', 2), ('MAIN', 1), ('VVV', 1), ('GDEN', 1), ('SBLK', 1), ('CTRN', 1), ('HEP', 1), ('GPS', 1), ('IMO', 1), ('CLMT', 1), ('UFPI', 1), ('SCHN', 1), ('PBF', 1), ('HIG', 1), ('TBI', 1), ('HPQ', 1), ('SLM', 1), ('KT', 1), ('TT', 1), ('CSL', 1), ('AME', 1), ('ITT', 1), ('BWXT', 1)], [('CHRD', 3), ('ACRS', 3), ('ATKR', 3), ('LPX', 3), ('MARA', 2), ('SM', 2), ('GME', 2), ('CPE', 2), ('CTRN', 2), ('NOG', 2), ('IPI', 2), ('SBLK', 2), ('AEO', 2), ('SLM', 2), ('HPQ', 2), ('PTMN', 2), ('MHK', 2), ('MERC', 2), ('KSS', 1), ('LNTH', 1), ('ERF', 1), ('PDCE', 1), ('JYNT', 1), ('FANG', 1), ('VCEL', 1), ('EXTR', 1), ('AJRD', 1), ('SJR', 1), ('TY', 1), ('AN', 1), ('STWD', 1), ('ISD', 1), ('CPF', 1), ('ATI', 1), ('STEW', 1), ('EXP', 1), ('IVZ', 1), ('TROW', 1)]]
# **** finish lookback slices [(1002, 1032, 1036), (972, 1032, 1036), (912, 1032, 1036)] ****
#
# top 20 ranked symbols and frequency from set [(1002, 1032, 1036), (972, 1032, 1036), (912, 1032, 1036)]:
# [('CHRD', 6), ('LPX', 5), ('CAR', 4), ('CPE', 4), ('GME', 4), ('MHK', 4), ('TBI', 4), ('WCN', 4), ('ACRS', 3), ('AJG', 3), ('ATKR', 3), ('BRO', 3), ('BX', 3), ('CSL', 3), ('CTRN', 3), ('EFX', 3), ('FNF', 3), ('HPQ', 3), ('IMO', 3), ('NCR', 3)]
# top 20 ranked symbols from set [(1002, 1032, 1036), (972, 1032, 1036), (912, 1032, 1036)]:
# ['CHRD', 'LPX', 'CAR', 'CPE', 'GME', 'MHK', 'TBI', 'WCN', 'ACRS', 'AJG']
# ===== finish top 20 ranked symbols from days_lookback set [(1002, 1032, 1036), (972, 1032, 1036), (912, 1032, 1036)] =====

# %%
for top_set_syms_n_freq in grp_top_set_syms_n_freq:
  l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
  if verbose:
    print(f'days_lookbacks: {days_lookbacks}')
    print(f'sym_freq_15: {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14: {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13: {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12: {l_sym_freq_cnt[3]}')
    print(f'sym_freq_11: {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10: {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9: {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8: {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7: {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6: {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5: {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4: {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3: {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2: {l_sym_freq_cnt[13]}\n')
# Out:
# days_lookbacks: [30, 60, 120]
# sym_freq_15: []
# sym_freq_14: []
# sym_freq_13: []
# sym_freq_12: []
# sym_freq_11: []
# sym_freq_10: []
# sym_freq_9: ['AMD']
# sym_freq_8: []
# sym_freq_7: []
# sym_freq_6: ['DCI', 'FTSM', 'MOH', 'RAMP', 'TNDM']
# sym_freq_5: ['ALSN', 'NVCR']
# sym_freq_4: ['HELE']
# sym_freq_3: ['AJG', 'EXAS', 'FLS', 'HCA', 'LLY', 'MCFT', 'PAYC', 'PKI', 'PLAY', 'QCOM', 'ROK']
# sym_freq_2: []
#
# days_lookbacks: [30, 60, 120]
# sym_freq_15: []
# sym_freq_14: []
# sym_freq_13: []
# sym_freq_12: []
# sym_freq_11: []
# sym_freq_10: []
# sym_freq_9: []
# sym_freq_8: ['AXSM']
# sym_freq_7: ['CMG']
# sym_freq_6: ['CDNS', 'FTSM']
# sym_freq_5: ['CPRX', 'EVRI', 'IONS', 'JYNT', 'MELI']
# sym_freq_4: ['APPS', 'ENPH', 'GRMN', 'LRN', 'QURE']
# sym_freq_3: ['ADC', 'BEP', 'BNDX', 'MITK', 'MPW', 'MYI']
# sym_freq_2: []
#
# days_lookbacks: [30, 60, 120]
# sym_freq_15: []
# sym_freq_14: []
# sym_freq_13: []
# sym_freq_12: []
# sym_freq_11: []
# sym_freq_10: []
# sym_freq_9: []
# sym_freq_8: []
# sym_freq_7: []
# sym_freq_6: ['CHRD']
# sym_freq_5: ['LPX']
# sym_freq_4: ['CAR', 'CPE', 'GME', 'MHK', 'TBI', 'WCN']
# sym_freq_3: ['ACRS', 'AJG', 'ATKR', 'BRO', 'BX', 'CSL', 'CTRN', 'EFX', 'FNF', 'HPQ', 'IMO', 'NCR']
# sym_freq_2: []

# %%
print('z_grp_top_set_syms_n_freq:')
z_grp_top_set_syms_n_freq = zip(max_lookback_slices, grp_top_set_syms_n_freq)
print(f'max_lookback_slices: {max_lookback_slices}')
print(f'grp_top_set_syms_n_freq: {grp_top_set_syms_n_freq}')
# Out:
# z_grp_top_set_syms_n_freq:
# max_lookback_slices: [(256, 376, 380), (384, 504, 508), (912, 1032, 1036)]
# grp_top_set_syms_n_freq: [[('AMD', 9), ('DCI', 6), ('FTSM', 6), ('MOH', 6), ('RAMP', 6), ('TNDM', 6), ('ALSN', 5), ('NVCR', 5), ('HELE', 4), ('AJG', 3), ('EXAS', 3), ('FLS', 3), ('HCA', 3), ('LLY', 3), ('MCFT', 3), ('PAYC', 3), ('PKI', 3), ('PLAY', 3), ('QCOM', 3), ('ROK', 3)], [('AXSM', 8), ('CMG', 7), ('CDNS', 6), ('FTSM', 6), ('CPRX', 5), ('EVRI', 5), ('IONS', 5), ('JYNT', 5), ('MELI', 5), ('APPS', 4), ('ENPH', 4), ('GRMN', 4), ('LRN', 4), ('QURE', 4), ('ADC', 3), ('BEP', 3), ('BNDX', 3), ('MITK', 3), ('MPW', 3), ('MYI', 3)], [('CHRD', 6), ('LPX', 5), ('CAR', 4), ('CPE', 4), ('GME', 4), ('MHK', 4), ('TBI', 4), ('WCN', 4), ('ACRS', 3), ('AJG', 3), ('ATKR', 3), ('BRO', 3), ('BX', 3), ('CSL', 3), ('CTRN', 3), ('EFX', 3), ('FNF', 3), ('HPQ', 3), ('IMO', 3), ('NCR', 3)]]

# %%
from myUtils import symb_perf_stats_vectorized_v8

print('z_grp_top_set_syms_n_freq:')
z_grp_top_set_syms_n_freq = zip(max_lookback_slices, grp_top_set_syms_n_freq)

for i, (_lookback_slice, _top_set_syms_n_freq) in enumerate(z_grp_top_set_syms_n_freq):
  iloc_start_train = _lookback_slice[0]
  iloc_end_train = _lookback_slice[1]
  iloc_start_eval = iloc_end_train
  iloc_end_eval = _lookback_slice[2]

  print(f'{i + 1 } of {n_samples} max_lookback_slice')
  print(f'max_lookback_slice: {_lookback_slice}')
  # dates correspond to max_lookback_slice
  idx_train = df.index[iloc_start_train:iloc_end_train]
  date_start_df_train = idx_train[0].strftime('%Y-%m-%d')
  date_end_df_train = idx_train[-1].strftime('%Y-%m-%d')
  print(f'len(idx_train): {len(idx_train)}')
  print(f'idx_train: {idx_train}')
  print(f'df_train_dates (inclusive): {date_start_df_train} - {date_end_df_train}')     

  if run_type != 'current':
    idx_eval = df.index[iloc_start_eval:iloc_end_eval]
    date_start_eval = idx_eval[-1].strftime('%Y-%m-%d')
    date_end_df_eval = idx_eval[-1].strftime('%Y-%m-%d')
    print(f'len(idx_eval): {len(idx_eval)}')
    print(f'idx_eval: {idx_eval}')
    print(f'df_eval dates (inclusive): {date_start_eval} - {date_end_df_eval}')

  if idx_eval.empty:
    print(f'\n\n**** Warning: df_eval is empty ****\n\n')   
 
  print(f'top_set_syms_n_freq: {_top_set_syms_n_freq}\n')
# Out:
# z_grp_top_set_syms_n_freq:
# 1 of 3 max_lookback_slice
# max_lookback_slice: (256, 376, 380)
# len(idx_train): 120
# idx_train: DatetimeIndex(['2018-04-04', '2018-04-05', '2018-04-06', '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12', '2018-04-13', '2018-04-16', '2018-04-17',
#                ...
#                '2018-09-10', '2018-09-11', '2018-09-12', '2018-09-13', '2018-09-14', '2018-09-17', '2018-09-18', '2018-09-19', '2018-09-20', '2018-09-21'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2018-04-04 - 2018-09-21
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2018-09-24', '2018-09-25', '2018-09-26', '2018-09-27'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2018-09-27 - 2018-09-27
# top_set_syms_n_freq: [('AMD', 9), ('DCI', 6), ('FTSM', 6), ('MOH', 6), ('RAMP', 6), ('TNDM', 6), ('ALSN', 5), ('NVCR', 5), ('HELE', 4), ('AJG', 3), ('EXAS', 3), ('FLS', 3), ('HCA', 3), ('LLY', 3), ('MCFT', 3), ('PAYC', 3), ('PKI', 3), ('PLAY', 3), ('QCOM', 3), ('ROK', 3)]
#
# 2 of 3 max_lookback_slice
# max_lookback_slice: (384, 504, 508)
# len(idx_train): 120
# idx_train: DatetimeIndex(['2018-10-04', '2018-10-05', '2018-10-08', '2018-10-09', '2018-10-10', '2018-10-11', '2018-10-12', '2018-10-15', '2018-10-16', '2018-10-17',
#                ...
#                '2019-03-15', '2019-03-18', '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22', '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2018-10-04 - 2019-03-28
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2019-03-29', '2019-04-01', '2019-04-02', '2019-04-03'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2019-04-03 - 2019-04-03
# top_set_syms_n_freq: [('AXSM', 8), ('CMG', 7), ('CDNS', 6), ('FTSM', 6), ('CPRX', 5), ('EVRI', 5), ('IONS', 5), ('JYNT', 5), ('MELI', 5), ('APPS', 4), ('ENPH', 4), ('GRMN', 4), ('LRN', 4), ('QURE', 4), ('ADC', 3), ('BEP', 3), ('BNDX', 3), ('MITK', 3), ('MPW', 3), ('MYI', 3)]
#
# 3 of 3 max_lookback_slice
# max_lookback_slice: (912, 1032, 1036)
# len(idx_train): 120
# idx_train: DatetimeIndex(['2020-11-09', '2020-11-10', '2020-11-11', '2020-11-12', '2020-11-13', '2020-11-16', '2020-11-17', '2020-11-18', '2020-11-19', '2020-11-20',
#                ...
#                '2021-04-20', '2021-04-21', '2021-04-22', '2021-04-23', '2021-04-26', '2021-04-27', '2021-04-28', '2021-04-29', '2021-04-30', '2021-05-03'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2020-11-09 - 2021-05-03
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2021-05-04', '2021-05-05', '2021-05-06', '2021-05-07'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2021-05-07 - 2021-05-07
# top_set_syms_n_freq: [('CHRD', 6), ('LPX', 5), ('CAR', 4), ('CPE', 4), ('GME', 4), ('MHK', 4), ('TBI', 4), ('WCN', 4), ('ACRS', 3), ('AJG', 3), ('ATKR', 3), ('BRO', 3), ('BX', 3), ('CSL', 3), ('CTRN', 3), ('EFX', 3), ('FNF', 3), ('HPQ', 3), ('IMO', 3), ('NCR', 3)]

# %%
from myUtils import symb_perf_stats_vectorized_v8

print('z_grp_top_set_syms_n_freq:')
z_grp_top_set_syms_n_freq = zip(max_lookback_slices, grp_top_set_syms_n_freq)

idx_train = pd.Index([])
idx_eval = pd.Index([])
for i, (_lookback_slice, _top_set_syms_n_freq) in enumerate(z_grp_top_set_syms_n_freq):
  iloc_start_train = _lookback_slice[0]
  iloc_end_train = _lookback_slice[1]
  iloc_start_eval = iloc_end_train
  iloc_end_eval = _lookback_slice[2]

  print(f'{i + 1 } of {n_samples} max_lookback_slice')
  print(f'max_lookback_slice: {_lookback_slice}')
  # dates correspond to max_lookback_slice
  idx_train = df.index[iloc_start_train:iloc_end_train]
  date_start_df_train = idx_train[0].strftime('%Y-%m-%d')
  date_end_df_train = idx_train[-1].strftime('%Y-%m-%d')
  print(f'len(idx_train): {len(idx_train)}')
  print(f'idx_train: {idx_train}')
  print(f'df_train_dates (inclusive): {date_start_df_train} - {date_end_df_train}')     

  if run_type != 'current':
    idx_eval = df.index[iloc_start_eval:iloc_end_eval]
    date_start_df_eval = idx_eval[-1].strftime('%Y-%m-%d')
    date_end_df_eval = idx_eval[-1].strftime('%Y-%m-%d')
    print(f'len(idx_eval): {len(idx_eval)}')
    print(f'idx_eval: {idx_eval}')
    print(f'df_eval dates (inclusive): {date_start_df_eval} - {date_end_df_eval}')

  print(f'top_set_syms_n_freq: {_top_set_syms_n_freq}\n')   

  l_sym_freq_cnt = top_set_sym_freq_cnt(_top_set_syms_n_freq)
  if verbose:
    print(f'max_lookback_slice: {_lookback_slice}')    
    print(f'days_lookbacks:     {days_lookbacks}')
    print(f'sym_freq_15:        {l_sym_freq_cnt[0]}')
    print(f'sym_freq_14:        {l_sym_freq_cnt[1]}')
    print(f'sym_freq_13:        {l_sym_freq_cnt[2]}')
    print(f'sym_freq_12:        {l_sym_freq_cnt[4]}')
    print(f'sym_freq_10:        {l_sym_freq_cnt[5]}')
    print(f'sym_freq_9:         {l_sym_freq_cnt[6]}')
    print(f'sym_freq_8:         {l_sym_freq_cnt[7]}')
    print(f'sym_freq_7:         {l_sym_freq_cnt[8]}')
    print(f'sym_freq_6:         {l_sym_freq_cnt[9]}')
    print(f'sym_freq_5:         {l_sym_freq_cnt[10]}')
    print(f'sym_freq_4:         {l_sym_freq_cnt[11]}')
    print(f'sym_freq_3:         {l_sym_freq_cnt[12]}')
    print(f'sym_freq_2:         {l_sym_freq_cnt[13]}\n') 


  if idx_eval.empty:
    if run_type != 'current':
      msg_stop = f'\n\n**** STOPPED df_eval is empty which is normal for run_type "current", the run_type is "{run_type}" ****'
      raise SystemExit(msg_stop )
    else:
      msg_stop = f'\n\n**** STOPPED df_eval is empty which is normal for run_type "current", the run_type is "{run_type}" ****'
      raise SystemExit(msg_stop )           

  _sym_idx = ['SPY']
  df_SPY = df[iloc_start_eval:iloc_end_eval][_sym_idx]

  (
    _symbols,
    _period_yr,
    _retn,
    _DD,
    _UI,
    _MDD,
    _retnMean,
    _retnStd,
    _retnStd_div_UI,
    _CAGR,
    _CAGR_div_retnStd,
    _CAGR_div_UI,
    SPY_retnStd_d_UI,     
    SPY_CAGR,
    SPY_CAGR_d_retnStd,
    SPY_CAGR_d_UI,
  ) = symb_perf_stats_vectorized_v8(df_SPY)  

  print(f'\nSPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR: {SPY_retnStd_d_UI[0]:>17,.1f}, {SPY_CAGR_d_retnStd[0]:>17,.1f}, {SPY_CAGR_d_UI[0]:>17.1f}, {SPY_CAGR[0]:>17.1f}')

  # drop last list, with frequency count 2 or less, in l_sym_freq_cnt from zip
  # zip_cnt_n_syms = zip([6,5,4,3], l_sym_freq_cnt[:-1])  
  zip_cnt_n_syms = zip([15,14,13,12,11,10,9,8,7,6,5,4,3], l_sym_freq_cnt[:-1])
  for item in zip_cnt_n_syms:
    sym_freq_cnt = item[0]
    syms = item[1]
    if syms:  # iterate ONLY if there are symbols in syms
      df_eval = df[iloc_start_eval:iloc_end_eval][syms]      

      if verbose:
        print(f'iloc_start_eval: {iloc_start_eval},  df_eval first date: {date_start_df_eval}')
        print(f'iloc_end_eval:   {iloc_end_eval},     df_eval last date: {date_end_df_eval}')
        print(f'frequency count of symbol(s): {sym_freq_cnt}')      
        # print(f'\ndf_eval:\n{df_eval}\n')

        syms_n_SPY = syms + ['SPY']
        df_eval_n_SPY = df[iloc_start_eval:iloc_end_eval][syms_n_SPY]   
        print(f'\ndf_eval_n_SPY:\n{df_eval_n_SPY}\n')

      (
        _symbols,
        _period_yr,
        _retn,
        _DD,
        _UI,
        _MDD,
        _retnMean,
        _retnStd,
        _retnStd_div_UI,
        _CAGR,
        _CAGR_div_retnStd,
        _CAGR_div_UI,
        grp_retnStd_d_UI,     
        grp_CAGR,
        grp_CAGR_d_retnStd,
        grp_CAGR_d_UI,
      ) = symb_perf_stats_vectorized_v8(df_eval)  
      print(f'grp(retnStd/UI):   mean, std, mean/std: {grp_retnStd_d_UI[0]  :>17,.1f}, {grp_retnStd_d_UI[1]  :>17,.1f}, {grp_retnStd_d_UI[2]  :>17,.1f}')
      print(f'grp(CAGR/retnStd): mean, std, mean/std: {grp_CAGR_d_retnStd[0]:>17,.1f}, {grp_CAGR_d_retnStd[1]:>17,.1f}, {grp_CAGR_d_retnStd[2]:>17,.1f}')
      print(f'grp(CAGR/UI):      mean, std, mean/std: {grp_CAGR_d_UI[0]     :>17,.1f}, {grp_CAGR_d_UI[1]     :>17,.1f}, {grp_CAGR_d_UI[2]     :>17,.1f}')
      print(f'grp(CAGR):         mean, std, mean/std: {grp_CAGR[0]          :>17,.1f}, {grp_CAGR[1]          :>17,.1f}, {grp_CAGR[2]          :>17,.1f}')

      if store_results:  # record results to df
        row_add0      = [n_samples, str(days_lookbacks), days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt]
        row_add1      = [grp_CAGR[0],           grp_CAGR[1],           grp_CAGR[2]]
        row_add2      = [grp_CAGR_d_UI[0],      grp_CAGR_d_UI[1],      grp_CAGR_d_UI[2]]
        row_add3      = [grp_CAGR_d_retnStd[0], grp_CAGR_d_retnStd[1], grp_CAGR_d_retnStd[2]]
        row_add4      = [grp_retnStd_d_UI[0],   grp_retnStd_d_UI[1],   grp_retnStd_d_UI[2]]
        row_add5      = [SPY_CAGR[0], SPY_CAGR_d_UI[0], SPY_CAGR_d_retnStd[0], SPY_retnStd_d_UI[0]]
        row_add_total = row_add0 + row_add1 + row_add2 + row_add3 + row_add4 + row_add5
        print(f'row_add_total: {row_add_total}')

        if run_type == 'train':
          df_eval_sym_freq_results_train.loc[len(df_eval_sym_freq_results_train)] = row_add_total
          print(f'appended row_add to df_eval_sym_freq_results_train:\n{row_add_total}\n')
        elif run_type == 'validate':
          df_eval_sym_freq_results_validate.loc[len(df_eval_sym_freq_results_validate)] = row_add_total       
          print(f'appended row_add to df_eval_sym_freq_results_validate:\n{row_add_total}\n')
        elif run_type == 'test':
          df_eval_sym_freq_results_test.loc[len(df_eval_sym_freq_results_test)] = row_add_total       
          print(f'appended row_add to df_eval_sym_freq_results_test:\n{row_add_total}\n')
        else:
          msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
          raise SystemExit(msg_stop )                             
  
  print('='*50, '\n')
# Out:
# z_grp_top_set_syms_n_freq:
# 1 of 3 max_lookback_slice
# max_lookback_slice: (256, 376, 380)
# len(idx_train): 120
# idx_train: DatetimeIndex(['2018-04-04', '2018-04-05', '2018-04-06', '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12', '2018-04-13', '2018-04-16', '2018-04-17',
#                ...
#                '2018-09-10', '2018-09-11', '2018-09-12', '2018-09-13', '2018-09-14', '2018-09-17', '2018-09-18', '2018-09-19', '2018-09-20', '2018-09-21'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2018-04-04 - 2018-09-21
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2018-09-24', '2018-09-25', '2018-09-26', '2018-09-27'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2018-09-27 - 2018-09-27
# top_set_syms_n_freq: [('AMD', 9), ('DCI', 6), ('FTSM', 6), ('MOH', 6), ('RAMP', 6), ('TNDM', 6), ('ALSN', 5), ('NVCR', 5), ('HELE', 4), ('AJG', 3), ('EXAS', 3), ('FLS', 3), ('HCA', 3), ('LLY', 3), ('MCFT', 3), ('PAYC', 3), ('PKI', 3), ('PLAY', 3), ('QCOM', 3), ('ROK', 3)]
#
# max_lookback_slice: (256, 376, 380)
# days_lookbacks:     [30, 60, 120]
# sym_freq_15:        []
# sym_freq_14:        []
# sym_freq_13:        []
# sym_freq_12:        []
# sym_freq_10:        []
# sym_freq_9:         ['AMD']
# sym_freq_8:         []
# sym_freq_7:         []
# sym_freq_6:         ['DCI', 'FTSM', 'MOH', 'RAMP', 'TNDM']
# sym_freq_5:         ['ALSN', 'NVCR']
# sym_freq_4:         ['HELE']
# sym_freq_3:         ['AJG', 'EXAS', 'FLS', 'HCA', 'LLY', 'MCFT', 'PAYC', 'PKI', 'PLAY', 'QCOM', 'ROK']
# sym_freq_2:         []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:               1.1,             -38.0,             -43.5,              -0.1
# iloc_start_eval: 376,  df_eval first date: 2018-09-27
# iloc_end_eval:   380,     df_eval last date: 2018-09-27
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#                   AMD         SPY
# Date
# 2018-09-24  32.610001  270.689697
# 2018-09-25  32.570000  270.438477
# 2018-09-26  32.189999  269.629303
# 2018-09-27  32.590000  270.382690
#
# grp(retnStd/UI):   mean, std, mean/std:               1.5,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:              -5.1,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:              -7.8,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.1,               0.0,              -inf
# iloc_start_eval: 376,  df_eval first date: 2018-09-27
# iloc_end_eval:   380,     df_eval last date: 2018-09-27
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                   DCI       FTSM         MOH       RAMP       TNDM         SPY
# Date
# 2018-09-24  55.064953  56.003883  151.779999  51.049999  44.529999  270.689697
# 2018-09-25  55.018360  56.003883  149.830002  50.730000  47.840000  270.438477
# 2018-09-26  54.421959  56.013226  148.110001  49.080002  46.270000  269.629303
# 2018-09-27  54.328766  56.013226  148.020004  48.930000  42.790001  270.382690
#
# grp(retnStd/UI):   mean, std, mean/std:              31.9,              62.7,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:             -43.9,             123.6,              -0.4
# grp(CAGR/UI):      mean, std, mean/std:           5,608.8,          11,305.4,               0.5
# grp(CAGR):         mean, std, mean/std:              -0.7,               0.4,              -1.9
# iloc_start_eval: 376,  df_eval first date: 2018-09-27
# iloc_end_eval:   380,     df_eval last date: 2018-09-27
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  ALSN       NVCR         SPY
# Date
# 2018-09-24  49.234425  48.799999  270.689697
# 2018-09-25  48.357052  50.700001  270.438477
# 2018-09-26  47.941437  51.000000  269.629303
# 2018-09-27  48.606411  51.849998  270.382690
#
# grp(retnStd/UI):   mean, std, mean/std:          13,750.3,          13,749.6,               1.0
# grp(CAGR/retnStd): mean, std, mean/std:           5,858.5,           5,908.1,               1.0
# grp(CAGR/UI):      mean, std, mean/std:     161,790,965.1,     161,791,003.7,               1.0
# grp(CAGR):         mean, std, mean/std:              80.6,              81.2,               1.0
# iloc_start_eval: 376,  df_eval first date: 2018-09-27
# iloc_end_eval:   380,     df_eval last date: 2018-09-27
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   HELE         SPY
# Date
# 2018-09-24  130.399994  270.689697
# 2018-09-25  130.550003  270.438477
# 2018-09-26  130.600006  269.629303
# 2018-09-27  130.050003  270.382690
#
# grp(retnStd/UI):   mean, std, mean/std:               1.1,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -85.4,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -96.0,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.2,               0.0,              -inf
# iloc_start_eval: 376,  df_eval first date: 2018-09-27
# iloc_end_eval:   380,     df_eval last date: 2018-09-27
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   AJG       EXAS        FLS         HCA        LLY       MCFT        PAYC        PKI       PLAY       QCOM         ROK         SPY
# Date
# 2018-09-24  70.051445  78.739998  49.500450  129.143295  97.564674  37.200001  154.970001  95.238922  62.649559  65.384384  177.285843  270.689697
# 2018-09-25  69.492149  80.599998  49.554779  129.345245  97.666313  37.099998  159.020004  95.209274  63.435127  64.637947  175.845001  270.438477
# 2018-09-26  68.998108  79.190002  49.228764  131.374054  98.229958  37.070000  154.770004  95.753250  63.749363  63.767101  174.679504  269.629303
# 2018-09-27  69.398933  76.690002  49.663460  133.008636  98.581085  36.410000  154.979996  95.852196  64.505478  63.722679  173.881104  270.382690
#
# grp(retnStd/UI):   mean, std, mean/std:           2,074.6,           3,819.5,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:             455.1,           1,023.5,               0.4
# grp(CAGR/UI):      mean, std, mean/std:       4,166,152.0,       8,221,189.5,               0.5
# grp(CAGR):         mean, std, mean/std:               1.8,               4.3,               0.4
# ==================================================
#
# 2 of 3 max_lookback_slice
# max_lookback_slice: (384, 504, 508)
# len(idx_train): 120
# idx_train: DatetimeIndex(['2018-10-04', '2018-10-05', '2018-10-08', '2018-10-09', '2018-10-10', '2018-10-11', '2018-10-12', '2018-10-15', '2018-10-16', '2018-10-17',
#                ...
#                '2019-03-15', '2019-03-18', '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22', '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2018-10-04 - 2019-03-28
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2019-03-29', '2019-04-01', '2019-04-02', '2019-04-03'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2019-04-03 - 2019-04-03
# top_set_syms_n_freq: [('AXSM', 8), ('CMG', 7), ('CDNS', 6), ('FTSM', 6), ('CPRX', 5), ('EVRI', 5), ('IONS', 5), ('JYNT', 5), ('MELI', 5), ('APPS', 4), ('ENPH', 4), ('GRMN', 4), ('LRN', 4), ('QURE', 4), ('ADC', 3), ('BEP', 3), ('BNDX', 3), ('MITK', 3), ('MPW', 3), ('MYI', 3)]
#
# max_lookback_slice: (384, 504, 508)
# days_lookbacks:     [30, 60, 120]
# sym_freq_15:        []
# sym_freq_14:        []
# sym_freq_13:        []
# sym_freq_12:        []
# sym_freq_10:        []
# sym_freq_9:         []
# sym_freq_8:         ['AXSM']
# sym_freq_7:         ['CMG']
# sym_freq_6:         ['CDNS', 'FTSM']
# sym_freq_5:         ['CPRX', 'EVRI', 'IONS', 'JYNT', 'MELI']
# sym_freq_4:         ['APPS', 'ENPH', 'GRMN', 'LRN', 'QURE']
# sym_freq_3:         ['ADC', 'BEP', 'BNDX', 'MITK', 'MPW', 'MYI']
# sym_freq_2:         []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:          10,246.9,             429.6,         4402468.8,               2.2
# iloc_start_eval: 504,  df_eval first date: 2019-04-03
# iloc_end_eval:   508,     df_eval last date: 2019-04-03
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#              AXSM         SPY
# Date
# 2019-03-29  14.23  265.444672
# 2019-04-01  13.51  268.592712
# 2019-04-02  13.66  268.724243
# 2019-04-03  13.57  269.147095
#
# grp(retnStd/UI):   mean, std, mean/std:               0.7,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:             -37.8,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -24.7,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -1.0,               0.0,              -inf
# iloc_start_eval: 504,  df_eval first date: 2019-04-03
# iloc_end_eval:   508,     df_eval last date: 2019-04-03
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                    CMG         SPY
# Date
# 2019-03-29  710.309998  265.444672
# 2019-04-01  705.739990  268.592712
# 2019-04-02  704.799988  268.724243
# 2019-04-03  705.640015  269.147095
#
# grp(retnStd/UI):   mean, std, mean/std:               0.5,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:            -134.1,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:             -70.7,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.4,               0.0,              -inf
# iloc_start_eval: 504,  df_eval first date: 2019-04-03
# iloc_end_eval:   508,     df_eval last date: 2019-04-03
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  CDNS       FTSM         SPY
# Date
# 2019-03-29  63.509998  56.692661  265.444672
# 2019-04-01  64.800003  56.692661  268.592712
# 2019-04-02  64.610001  56.692661  268.724243
# 2019-04-03  65.169998  56.683197  269.147095
#
# grp(retnStd/UI):   mean, std, mean/std:               3.7,               2.8,               1.3
# grp(CAGR/retnStd): mean, std, mean/std:             319.1,             496.1,               0.6
# grp(CAGR/UI):      mean, std, mean/std:           2,554.6,           2,721.5,               0.9
# grp(CAGR):         mean, std, mean/std:               3.9,               3.9,               1.0
# iloc_start_eval: 504,  df_eval first date: 2019-04-03
# iloc_end_eval:   508,     df_eval last date: 2019-04-03
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#             CPRX   EVRI       IONS   JYNT        MELI         SPY
# Date
# 2019-03-29  5.10  10.52  81.169998  15.75  507.730011  265.444672
# 2019-04-01  4.97  10.33  81.309998  15.42  518.109985  268.592712
# 2019-04-02  5.10  10.40  81.739998  15.68  509.989990  268.724243
# 2019-04-03  5.24  10.38  84.889999  16.33  508.579987  269.147095
#
# grp(retnStd/UI):   mean, std, mean/std:           6,632.2,          13,261.3,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:             722.6,             956.5,               0.8
# grp(CAGR/UI):      mean, std, mean/std:      16,850,277.6,      33,699,306.3,               0.5
# grp(CAGR):         mean, std, mean/std:              14.0,              15.9,               0.9
# iloc_start_eval: 504,  df_eval first date: 2019-04-03
# iloc_end_eval:   508,     df_eval last date: 2019-04-03
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#             APPS  ENPH       GRMN        LRN       QURE         SPY
# Date
# 2019-03-29  3.50  9.23  78.659935  34.130001  59.650002  265.444672
# 2019-04-01  3.56  9.26  80.053680  34.180000  59.990002  268.592712
# 2019-04-02  3.72  9.35  80.390747  34.250000  59.590000  268.724243
# 2019-04-03  3.65  9.69  80.673134  35.099998  60.099998  269.147095
#
# grp(retnStd/UI):   mean, std, mean/std:          12,698.0,          11,482.2,               1.1
# grp(CAGR/retnStd): mean, std, mean/std:           1,495.3,           1,349.8,               1.1
# grp(CAGR/UI):      mean, std, mean/std:      30,139,455.2,      44,067,567.1,               0.7
# grp(CAGR):         mean, std, mean/std:              21.8,              21.3,               1.0
# iloc_start_eval: 504,  df_eval first date: 2019-04-03
# iloc_end_eval:   508,     df_eval last date: 2019-04-03
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                   ADC        BEP       BNDX   MITK        MPW        MYI         SPY
# Date
# 2019-03-29  59.780075  14.745638  50.632015  12.24  14.786627  10.865600  265.444672
# 2019-04-01  58.874828  14.764098  50.525715  12.20  14.970363  10.857192  268.592712
# 2019-04-02  58.529980  14.745638  50.552956  12.00  15.042254  10.865600  268.724243
# 2019-04-03  58.167885  14.597950  50.498428  12.04  15.050245  10.831985  269.147095
#
# grp(retnStd/UI):   mean, std, mean/std:           1,640.5,           3,666.8,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:              -8.7,             316.5,              -0.0
# grp(CAGR/UI):      mean, std, mean/std:       1,137,323.4,       2,543,337.3,               0.4
# grp(CAGR):         mean, std, mean/std:               0.1,               1.5,               0.1
# ==================================================
#
# 3 of 3 max_lookback_slice
# max_lookback_slice: (912, 1032, 1036)
# len(idx_train): 120
# idx_train: DatetimeIndex(['2020-11-09', '2020-11-10', '2020-11-11', '2020-11-12', '2020-11-13', '2020-11-16', '2020-11-17', '2020-11-18', '2020-11-19', '2020-11-20',
#                ...
#                '2021-04-20', '2021-04-21', '2021-04-22', '2021-04-23', '2021-04-26', '2021-04-27', '2021-04-28', '2021-04-29', '2021-04-30', '2021-05-03'], dtype='datetime64[ns]', name='Date', length=120, freq=None)
# df_train_dates (inclusive): 2020-11-09 - 2021-05-03
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2021-05-04', '2021-05-05', '2021-05-06', '2021-05-07'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2021-05-07 - 2021-05-07
# top_set_syms_n_freq: [('CHRD', 6), ('LPX', 5), ('CAR', 4), ('CPE', 4), ('GME', 4), ('MHK', 4), ('TBI', 4), ('WCN', 4), ('ACRS', 3), ('AJG', 3), ('ATKR', 3), ('BRO', 3), ('BX', 3), ('CSL', 3), ('CTRN', 3), ('EFX', 3), ('FNF', 3), ('HPQ', 3), ('IMO', 3), ('NCR', 3)]
#
# max_lookback_slice: (912, 1032, 1036)
# days_lookbacks:     [30, 60, 120]
# sym_freq_15:        []
# sym_freq_14:        []
# sym_freq_13:        []
# sym_freq_12:        []
# sym_freq_10:        []
# sym_freq_9:         []
# sym_freq_8:         []
# sym_freq_7:         []
# sym_freq_6:         ['CHRD']
# sym_freq_5:         ['LPX']
# sym_freq_4:         ['CAR', 'CPE', 'GME', 'MHK', 'TBI', 'WCN']
# sym_freq_3:         ['ACRS', 'AJG', 'ATKR', 'BRO', 'BX', 'CSL', 'CTRN', 'EFX', 'FNF', 'HPQ', 'IMO', 'NCR']
# sym_freq_2:         []
#
#
# SPY: retnStd/UI, CAGR/retnStd, CAGR/UI, CAGR:           6,924.6,             774.7,         5364563.4,               2.7
# iloc_start_eval: 1032,  df_eval first date: 2021-05-07
# iloc_end_eval:   1036,     df_eval last date: 2021-05-07
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  CHRD         SPY
# Date
# 2021-05-04  56.899517  404.926849
# 2021-05-05  59.117939  405.053497
# 2021-05-06  57.804691  408.288086
# 2021-05-07  56.751137  411.259613
#
# grp(retnStd/UI):   mean, std, mean/std:               1.2,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:              -7.0,               0.0,              -inf
# grp(CAGR/UI):      mean, std, mean/std:              -8.6,               0.0,              -inf
# grp(CAGR):         mean, std, mean/std:              -0.2,               0.0,              -inf
# iloc_start_eval: 1032,  df_eval first date: 2021-05-07
# iloc_end_eval:   1036,     df_eval last date: 2021-05-07
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                   LPX         SPY
# Date
# 2021-05-04  70.221924  404.926849
# 2021-05-05  67.942863  405.053497
# 2021-05-06  67.436409  408.288086
# 2021-05-07  70.835518  411.259613
#
# grp(retnStd/UI):   mean, std, mean/std:               1.4,               0.0,               inf
# grp(CAGR/retnStd): mean, std, mean/std:              31.0,               0.0,               inf
# grp(CAGR/UI):      mean, std, mean/std:              42.0,               0.0,               inf
# grp(CAGR):         mean, std, mean/std:               1.1,               0.0,               inf
# iloc_start_eval: 1032,  df_eval first date: 2021-05-07
# iloc_end_eval:   1036,     df_eval last date: 2021-05-07
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   CAR        CPE        GME         MHK        TBI         WCN         SPY
# Date
# 2021-05-04  83.349998  37.320000  40.182499  219.839996  28.540001  120.053413  404.926849
# 2021-05-05  83.959999  40.000000  39.869999  224.300003  28.200001  121.591660  405.053497
# 2021-05-06  83.910004  39.590000  40.252499  224.880005  27.809999  121.562080  408.288086
# 2021-05-07  82.230003  41.119999  40.277500  229.740005  28.219999  121.621246  411.259613
#
# grp(retnStd/UI):   mean, std, mean/std:           2,901.1,           6,460.5,               0.4
# grp(CAGR/retnStd): mean, std, mean/std:          17,836.9,          37,772.4,               0.5
# grp(CAGR/UI):      mean, std, mean/std:      13,264,575.8,      29,353,624.5,               0.5
# grp(CAGR):         mean, std, mean/std:             581.0,           1,281.1,               0.5
# iloc_start_eval: 1032,  df_eval first date: 2021-05-07
# iloc_end_eval:   1036,     df_eval last date: 2021-05-07
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ACRS         AJG       ATKR        BRO         BX         CSL        CTRN         EFX        FNF        HPQ        IMO        NCR         SPY
# Date
# 2021-05-04  23.670000  142.009979  84.209999  52.644527  82.499184  188.477249  104.839996  233.681015  41.250931  31.975220  28.324106  46.779999  404.926849
# 2021-05-05  24.139999  143.922958  86.370003  52.427559  82.256332  188.712418  104.010002  236.481125  41.098389  32.436581  29.009365  46.570000  405.053497
# 2021-05-06  23.830000  145.269867  86.690002  52.812180  82.499184  188.624222  107.199997  233.828918  41.475266  32.935604  29.561382  47.340000  408.288086
# 2021-05-07  22.950001  147.534241  89.110001  53.042374  84.096306  189.300278  105.910004  236.195221  41.448349  33.491127  29.846907  47.830002  411.259613
#
# grp(retnStd/UI):   mean, std, mean/std:           3,422.9,           6,530.6,               0.5
# grp(CAGR/retnStd): mean, std, mean/std:           6,880.6,          13,197.9,               0.5
# grp(CAGR/UI):      mean, std, mean/std:      44,445,637.8,      74,260,703.8,               0.6
# grp(CAGR):         mean, std, mean/std:              23.3,              36.5,               0.6
# ==================================================

# %%
if store_results:  # record results to df
  if run_type == 'train':
    pickle_dump(df_eval_sym_freq_results_train, path_data_dump, fp_df_eval_sym_freq_results_train)
    print(f'Save results to: {fp_df_eval_sym_freq_results_train}')
  elif run_type == 'validate':
    pickle_dump(df_eval_sym_freq_results_validate, path_data_dump, fp_df_eval_sym_freq_results_validate)   
    print(f'Save results to: {fp_df_eval_sym_freq_results_validate}')
  elif run_type == 'test':
    pickle_dump(df_eval_sym_freq_results_test, path_data_dump, fp_df_eval_sym_freq_results_test)   
    print(f'Save results to: {fp_df_eval_sym_freq_results_test}')
  else:
    msg_stop = f"ERROR: Result was not saved. run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop )
