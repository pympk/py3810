# %%
# # create empty DataFrame df and append row
# my_cols = ['date', 'days_lookback', 'syms_freq', 'symbols']
# # Creating Empty DataFrame and Storing it in variable df
# df_model_top_picks = pd.DataFrame(columns=my_cols)
# df_model_top_picks

# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.width', 900)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_picks  = f'df_picks'
fp_df_model_top_picks = f'df_model_top_picks'

verbose = True
# verbose = False

# %%
df = pickle_load(path_data_dump, fp_df_picks)
df = df.drop_duplicates(subset=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], keep='last')
df = df.sort_values(by=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], ascending=False)
df = df.reset_index(drop=True)
pickle_dump(df, path_data_dump, fp_df_picks)
print(f'len(df): {len(df)}')
print(df.head())
# Out:
# len(df): 272
#   date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12 sym_freq_11 sym_freq_10       sym_freq_9       sym_freq_8                     sym_freq_7                     sym_freq_6                     sym_freq_5 sym_freq_4                     sym_freq_3 sym_freq_2
# 0        2023-11-02                 120      [30, 60, 120]          []          []          []          []          []          []  ['FTSM', 'SHV']          ['ANF']                        ['NRG']                ['GPS', 'ICPT']  ['GBTC', 'LRN', 'SPLK', 'U...         []  ['AGYS', 'BTC-USD', 'CBOE'...         []
# 1        2023-11-02                 120  [15, 30, 60, 120]          []          []          []          []     ['SHV']          []         ['FTSM']          ['ANF']  ['GBTC', 'GPS', 'ICPT', 'L...  ['AGYS', 'BTC-USD', 'SPR',...   ['SPLK', 'TNK', 'USAC', 'X']         []  ['AES', 'CBOE', 'CLS', 'EDU']         []
# 2        2023-11-01                 120      [30, 60, 120]          []          []          []          []          []          []         ['FTSM']          ['ANF']                             []  ['EDU', 'ICPT', 'LRN', 'NR...  ['CBOE', 'GBTC', 'GPS', 'S...         []  ['AGYS', 'BTC-USD', 'CLS',...         []
# 3        2023-11-01                 120  [15, 30, 60, 120]          []          []          []          []          []    ['FTSM']          ['LRN']          ['ANF']                       ['GBTC']  ['AGYS', 'BTC-USD', 'EDU',...  ['CBOE', 'GPS', 'QNST', 'S...         []                        ['AES']         []
# 4        2023-10-31                 120      [30, 60, 120]          []          []          []          []          []          []          ['SHV']  ['ANF', 'SPLK']                             []  ['EDU', 'FTSM', 'ICPT', 'L...  ['CBOE', 'GBTC', 'USAC', 'X']    ['PGR']  ['AGYS', 'BTC-USD', 'CLS',...         []

# %%
df.head(50)
# df.head()
# Out:
#    date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13      sym_freq_12      sym_freq_11 sym_freq_10       sym_freq_9        sym_freq_8                     sym_freq_7                     sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0         2023-11-02                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']           ['ANF']                        ['NRG']                ['GPS', 'ICPT']  ['GBTC', 'LRN', 'SPLK', 'U...                             []  ['AGYS', 'BTC-USD', 'CBOE'...         []
# 1         2023-11-02                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']          []         ['FTSM']           ['ANF']  ['GBTC', 'GPS', 'ICPT', 'L...  ['AGYS', 'BTC-USD', 'SPR',...   ['SPLK', 'TNK', 'USAC', 'X']                             []  ['AES', 'CBOE', 'CLS', 'EDU']         []
# 2         2023-11-01                 120      [30, 60, 120]          []          []          []               []               []          []         ['FTSM']           ['ANF']                             []  ['EDU', 'ICPT', 'LRN', 'NR...  ['CBOE', 'GBTC', 'GPS', 'S...                             []  ['AGYS', 'BTC-USD', 'CLS',...         []
# 3         2023-11-01                 120  [15, 30, 60, 120]          []          []          []               []               []    ['FTSM']          ['LRN']           ['ANF']                       ['GBTC']  ['AGYS', 'BTC-USD', 'EDU',...  ['CBOE', 'GPS', 'QNST', 'S...                             []                        ['AES']         []
# 4         2023-10-31                 120      [30, 60, 120]          []          []          []               []               []          []          ['SHV']   ['ANF', 'SPLK']                             []  ['EDU', 'FTSM', 'ICPT', 'L...  ['CBOE', 'GBTC', 'USAC', 'X']                        ['PGR']  ['AGYS', 'BTC-USD', 'CLS',...         []
# 5         2023-10-31                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []          []          ['LRN']   ['ANF', 'SPLK']                       ['GBTC']  ['BTC-USD', 'EDU', 'FTSM',...  ['AGYS', 'CBOE', 'TNK', 'U...                ['PGR', 'QNST']                        ['AES']         []
# 6         2023-10-30                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']          ['SPLK']                        ['ANF']        ['ICPT', 'LRN', 'USAC']                  ['CBOE', 'X']  ['EDU', 'GBTC', 'NGS', 'PG...  ['AGYS', 'BTC-USD', 'CLS',...         []
# 7         2023-10-30                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []          []          ['LRN']          ['SPLK']                        ['ANF']  ['BTC-USD', 'GBTC', 'ICPT'...  ['AGYS', 'CBOE', 'GPS', 'P...          ['EDU', 'FCN', 'FTI']                             []         []
# 8         2023-10-27                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']          ['SPLK']                        ['ANF']   ['ICPT', 'LRN', 'USAC', 'X']                       ['CBOE']                 ['NGS', 'PGR']  ['AEO', 'BTC-USD', 'CHE', ...         []
# 9         2023-10-27                 120  [15, 30, 60, 120]          []          []          []          ['SHV']         ['FTSM']          []          ['LRN']          ['SPLK']                        ['ANF']  ['BTC-USD', 'ICPT', 'SPR',...  ['CBOE', 'GBTC', 'GPS', 'T...  ['CHE', 'FCN', 'FTI', 'GEL...                             []         []
# 10        2023-10-26                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']          ['SPLK']                             []  ['ANF', 'CBOE', 'ICPT', 'L...                        ['PGR']                          ['X']  ['BTC-USD', 'CLS', 'CNX', ...         []
# 11        2023-10-26                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']    ['FTSM']               []   ['LRN', 'SPLK']                             []  ['ANF', 'CBOE', 'GBTC', 'I...  ['BTC-USD', 'GEL', 'PGR', ...           ['FTI', 'SWBI', 'X']                        ['AES']         []
# 12        2023-10-25                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']   ['ANF', 'SPLK']                             []        ['CBOE', 'ICPT', 'TDS']         ['LRN', 'PGR', 'USAC']           ['GBTC', 'NGS', 'X']  ['AEO', 'AKAM', 'BTC-USD',...         []
# 13        2023-10-25                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']    ['FTSM']               []   ['ANF', 'SPLK']                             []  ['CBOE', 'GBTC', 'ICPT', '...  ['BTC-USD', 'PGR', 'SPR', ...           ['NGS', 'SGEN', 'X']                 ['AEO', 'AES']         []
# 14        2023-10-24                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']           ['ANF']                       ['SPLK']                ['ICPT', 'PGR']        ['CBOE', 'CLS', 'USAC']   ['ARLP', 'GBTC', 'NGS', 'X']  ['AEO', 'AKAM', 'BTC-USD',...         []
# 15        2023-10-24                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']    ['FTSM']               []           ['ANF']                       ['SPLK']        ['GBTC', 'ICPT', 'PGR']  ['BTC-USD', 'CBOE', 'CLS',...  ['ARLP', 'NGS', 'SGEN', 'T...                 ['AEM', 'AEO']         []
# 16        2023-10-23                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']          ['SPLK']                        ['ANF']                ['ICPT', 'PGR']                       ['USAC']  ['ARLP', 'CBOE', 'JBL', 'M...  ['AKAM', 'BTC-USD', 'CLS',...         []
# 17        2023-10-23                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']    ['FTSM']               []          ['SPLK']                        ['ANF']         ['ICPT', 'PGR', 'TGH']        ['GBTC', 'SPR', 'USAC']  ['ARLP', 'BTC-USD', 'CBOE'...                             []         []
# 18        2023-10-20                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                             []  ['ANF', 'ICPT', 'MMYT', 'P...        ['ARLP', 'CLS', 'USAC']                 ['JBL', 'NGS']  ['AKAM', 'CBOE', 'CNX', 'C...         []
# 19        2023-10-20                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']    ['FTSM']               []   ['PGR', 'USAC']                             []  ['ANF', 'ICPT', 'MMYT', 'S...          ['ARLP', 'CLS', 'FL']  ['GBTC', 'JBL', 'NGS', 'SG...  ['AEM', 'AKAM', 'AR', 'CBOE']         []
# 20        2023-10-19                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                             []  ['ANF', 'CLS', 'ICPT', 'MM...                 ['CNX', 'JBL']        ['ARLP', 'NGS', 'TWNK']  ['AKAM', 'CBOE', 'CPRI', '...         []
# 21        2023-10-19                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []    ['FTSM']  ['PGR', 'USAC']                []                             []  ['ANF', 'CLS', 'ICPT', 'MM...    ['ALL', 'CNX', 'FL', 'JBL']  ['ARLP', 'CI', 'HUM', 'NGS...                             []         []
# 22        2023-10-17                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                             []  ['ANF', 'CLS', 'ICPT', 'MM...                        ['CNX']  ['ARLP', 'JBL', 'LRN', 'NG...  ['AIZ', 'CPRI', 'DELL', 'H...         []
# 23        2023-10-17                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']    ['FTSM']               []    ['CLS', 'PGR']                        ['JBL']  ['ANF', 'ICPT', 'MMYT', 'S...                ['CNX', 'SWBI']  ['ARLP', 'LRN', 'NGS', 'TW...  ['AEO', 'AIZ', 'BAH', 'CPRI']         []
# 24        2023-10-12                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                             []  ['ANF', 'CLS', 'DELL', 'IC...        ['CNX', 'SPLK', 'USAC']  ['AKAM', 'LRN', 'MLKN', 'N...   ['HRB', 'JBL', 'LII', 'LLY']         []
# 25        2023-10-12                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']    ['FTSM']         ['ICPT']    ['ANF', 'CLS']                       ['MLKN']  ['DELL', 'JBL', 'MMYT', 'N...        ['CNX', 'SPLK', 'USAC']  ['AKAM', 'BAH', 'CME', 'LR...                             []         []
# 26        2023-10-06                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                        ['CLS']                ['ANF', 'USAC']        ['ICPT', 'LRN', 'MMYT']  ['CNX', 'DELL', 'MLKN', 'N...  ['ARCH', 'CCJ', 'CNK', 'HR...         []
# 27        2023-10-06                 120  [15, 30, 60, 120]          []          []          []          ['SHV']         ['FTSM']     ['CLS']               []          ['ICPT']       ['MLKN', 'SPLK', 'USAC']  ['ANF', 'CNK', 'JBL', 'SBL...         ['LRN', 'MMYT', 'NGS']  ['CNX', 'DELL', 'HOLI', 'H...                             []         []
# 28        2023-10-05                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                             []          ['ANF', 'CLS', 'LRN']  ['DELL', 'ICPT', 'MMYT', '...                 ['NGS', 'VST']  ['ARCH', 'CBOE', 'DBI', 'H...         []
# 29        2023-10-05                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []          []          ['CLS']  ['ICPT', 'SPLK']                             []  ['ANF', 'CBOE', 'JBL', 'LR...  ['CNK', 'DELL', 'MMYT', 'N...               ['HOLI', 'HZNP']                             []         []
# 30        2023-10-04                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                       ['SPLK']  ['ANF', 'BBW', 'ICPT', 'LRN']  ['CLS', 'DELL', 'MLKN', 'M...                             []  ['AKAM', 'ARLP', 'CBOE', '...         []
# 31        2023-10-04                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []    ['SPLK']         ['ICPT']          ['MLKN']                             []  ['ANF', 'BBW', 'CBOE', 'HZ...  ['CLS', 'DELL', 'MMYT', 'T...  ['HOLI', 'HRB', 'NGS', 'WSM']                       ['AKAM']         []
# 32        2023-10-02                 120      [30, 60, 120]          []          []          []               []               []          []         ['FTSM']           ['ANF']                             []                ['DELL', 'LRN']  ['ARCH', 'BBW', 'CLS', 'IC...  ['HRB', 'MMYT', 'SHV', 'SP...  ['CELH', 'DBI', 'HZNP', 'I...         []
# 33        2023-10-02                 120  [15, 30, 60, 120]          []          []          []         ['FTSM']               []          []          ['ANF']          ['ICPT']         ['HRB', 'NGS', 'SPLK']        ['DELL', 'LRN', 'MLKN']  ['ARCH', 'BBW', 'CLS', 'JB...  ['ARLP', 'HZNP', 'MMYT', '...                             []         []
# 34        2023-09-29                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                ['ANF', 'DELL']                ['ARCH', 'CCJ']  ['CLS', 'ICPT', 'LRN', 'NGS']                       ['MMYT']  ['BBW', 'CELH', 'HRB', 'HZ...         []
# 35        2023-09-29                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []    ['FTSM']         ['ARCH']   ['ICPT', 'NGS']                ['ANF', 'DELL']        ['CCJ', 'MLKN', 'SPLK']          ['CLS', 'HRB', 'LRN']       ['HZNP', 'MMYT', 'RCKT']  ['ARLP', 'BBW', 'CASY', 'C...         []
# 36        2023-09-28                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']           ['CCJ']                        ['ANF']               ['ARCH', 'DELL']                       ['USAC']  ['APO', 'CLS', 'ICPT', 'LR...  ['CELH', 'HRB', 'LII', 'SB...         []
# 37        2023-09-28                 120  [15, 30, 60, 120]          []          []          []          ['SHV']               []    ['FTSM']         ['ARCH']   ['CCJ', 'USAC']         ['ANF', 'ICPT', 'NGS']       ['DELL', 'SPLK', 'TWNK']                             []  ['APO', 'CLS', 'HRB', 'LRN...                       ['ARLP']         []
# 38        2023-09-25                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                        ['CCJ']                ['DELL', 'HRB']  ['ARCH', 'CLS', 'LRN', 'VST']         ['APO', 'MMYT', 'PBR']  ['BBW', 'CELH', 'CLMT', 'C...         []
# 39        2023-09-25                 120  [15, 30, 60, 120]          []          []          []               []  ['FTSM', 'SHV']          []               []   ['ARCH', 'CCJ']                        ['HRB']  ['DELL', 'NGS', 'TWNK', 'YY']          ['CLS', 'LRN', 'VST']  ['APO', 'CASY', 'CRS', 'MM...                       ['ARLP']         []
# 40        2023-09-22                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                       ['DELL']                 ['CCJ', 'HRB']          ['CLS', 'LRN', 'VST']  ['AKAM', 'APO', 'ARCH', 'M...  ['BBW', 'BX', 'CELH', 'CLM...         []
# 41        2023-09-22                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []          []               []                []               ['ARCH', 'DELL']  ['CCJ', 'HRB', 'SPLK', 'TW...   ['CLS', 'LRN', 'NGS', 'VST']  ['AKAM', 'APO', 'CASY', 'M...                       ['ARLP']         []
# 42        2023-09-21                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                       ['DELL']                        ['HRB']                        ['CCJ']  ['APO', 'ARCH', 'CLS', 'HE...  ['BBW', 'CELH', 'CLMT', 'C...         []
# 43        2023-09-21                 120  [15, 30, 60, 120]          []          []          []  ['FTSM', 'SHV']               []    ['DELL']               []                []                       ['ARCH']  ['HRB', 'SPLK', 'TWNK', 'YY']                 ['CCJ', 'NGS']  ['APO', 'CASY', 'CLS', 'HE...                             []         []
# 44        2023-09-20                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                        ['CCJ']                ['DELL', 'HRB']                       ['CPRI']  ['APO', 'CLS', 'LRN', 'MMY...  ['ARCH', 'BBW', 'CELH', 'C...         []
# 45        2023-09-20                 120  [15, 30, 60, 120]          []          []          []          ['SHV']         ['FTSM']          []         ['DELL']                []                        ['CCJ']  ['ARCH', 'HRB', 'TWNK', 'YY']  ['APO', 'CPRI', 'NGS', 'USO']  ['BX', 'CLS', 'GEL', 'HMC'...                             []         []
# 46        2023-09-18                 120      [30, 60, 120]          []          []          []               []               []          []          ['SHV']          ['FTSM']                             []        ['CELH', 'DELL', 'LLY']          ['CCJ', 'FTI', 'VST']  ['ANF', 'ARCH', 'CLS', 'CP...       ['CLMT', 'HZNP', 'SKYW']         []
# 47        2023-09-18                 120  [15, 30, 60, 120]          []          []          []               []          ['SHV']    ['FTSM']         ['DELL']                []                ['ARCH', 'CCJ']  ['CELH', 'FTI', 'LLY', 'TW...                       ['RCKT']  ['ANF', 'CLS', 'CPRI', 'HA...                             []         []
# 48        2023-09-15                 120      [30, 60, 120]          []          []          []               []               []          []  ['FTSM', 'SHV']                []                       ['DELL']         ['ANF', 'CELH', 'LLY']                ['CCJ', 'MMYT']  ['ARCH', 'CLS', 'CPRI', 'P...  ['CLMT', 'HRB', 'HZNP', 'O...         []
# 49        2023-09-15                 120  [15, 30, 60, 120]          []          []          []               []  ['FTSM', 'SHV']    ['DELL']               []                []                       ['ARCH']  ['ANF', 'CCJ', 'CELH', 'LL...               ['HZNP', 'MMYT']  ['CLS', 'CPRI', 'HMC', 'PB...                 ['BX', 'CLMT']         []

# %%
df_mp_res = pickle_load(path_data_dump, 'df_model_picks_results')
df_mp = pickle_load(path_data_dump, 'df_model_picks')
print(f'df_mp_res:\n{df_mp_res}\n') 
print(f'df_mp:\n{df_mp}')
# Out:
# df_mp_res:
#            date      days_lookback    syms_freq           symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 4    2023-09-01      [30, 60, 120]   sym_freq_9           ['SHV']  2023-09-05        [9.0]   990.629997      [2.0]  898.479980  2023-09-08         [9.0]    991.440033     0.081770       [2.0]  891.039978  -0.828065   0.909835    1
# 5    2023-09-01      [30, 60, 120]   sym_freq_8  ['FTSM', 'STRL']  2023-09-05   [8.0, 6.0]   959.080002      [2.0]  898.479980  2023-09-08    [8.0, 6.0]    947.040024    -1.255367       [2.0]  891.039978  -0.828065  -0.427302    0
# 6    2023-08-25      [30, 60, 120]   sym_freq_9           ['SHV']  2023-08-28        [9.0]   989.454735      [2.0]  885.520020  2023-08-31         [9.0]    990.350945     0.090576       [2.0]  900.700012   1.714246  -1.623670    0
# 7    2023-08-25      [30, 60, 120]   sym_freq_8          ['STRL']  2023-08-28       [12.0]   949.920044      [2.0]  885.520020  2023-08-31        [12.0]    993.120026     4.547749       [2.0]  900.700012   1.714246   2.833503    1
# 8    2023-08-25  [15, 30, 60, 120]  sym_freq_12           ['SHV']  2023-08-28        [9.0]   989.454735      [2.0]  885.520020  2023-08-31         [9.0]    990.350945     0.090576       [2.0]  900.700012   1.714246  -1.623670    0
# ..          ...                ...          ...               ...         ...          ...          ...        ...         ...         ...           ...           ...          ...         ...         ...        ...        ...  ...
# 124  2023-03-20      [30, 60, 120]   sym_freq_9   ['FTSM', 'SHV']  2023-03-21   [8.0, 4.0]   896.895111      [2.0]  794.867371  2023-03-24    [8.0, 4.0]    898.145630     0.139428       [2.0]  788.570801  -0.792154   0.931581    1
# 125  2023-03-17      [30, 60, 120]   sym_freq_9   ['FTSM', 'SHV']  2023-03-20   [8.0, 4.0]   897.481384      [2.0]  784.565613  2023-03-23    [8.0, 4.0]    897.872040     0.043528       [2.0]  783.429871  -0.144761   0.188289    1
# 126  2023-03-17      [30, 60, 120]   sym_freq_8            ['GE']  2023-03-20       [11.0]   988.389091      [2.0]  784.565613  2023-03-23        [11.0]   1006.745476     1.857202       [2.0]  783.429871  -0.144761   2.001963    1
# 127  2023-03-16      [30, 60, 120]   sym_freq_9   ['FTSM', 'SHV']  2023-03-17   [8.0, 4.0]   896.855835      [2.0]  777.093384  2023-03-22    [8.0, 4.0]    897.520447     0.074105       [2.0]  781.317688   0.543603  -0.469499    0
# 128  2023-03-15      [30, 60, 120]   sym_freq_9   ['FTSM', 'SHV']  2023-03-16   [8.0, 4.0]   896.621613      [2.0]  786.287231  2023-03-21    [8.0, 4.0]    896.895111     0.030503       [2.0]  794.867371   1.091222  -1.060719    0
#
# [125 rows x 18 columns]
#
# df_mp:
#          date  days_lookback   syms_freq           symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0  2023-09-08  [30, 60, 120]  sym_freq_9   ['FTSM', 'SHV']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 1  2023-09-08  [30, 60, 120]  sym_freq_8  ['DELL', 'STRL']        None         None          NaN       None         NaN      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 2  2023-09-05  [30, 60, 120]  sym_freq_9           ['SHV']  2023-09-06        [9.0]   990.809967      [2.0]  892.440002      None          None           NaN          NaN        None         NaN        NaN        NaN    0
# 3  2023-09-05  [30, 60, 120]  sym_freq_8          ['FTSM']  2023-09-06       [16.0]   951.840027      [2.0]  892.440002      None          None           NaN          NaN        None         NaN        NaN        NaN    0

# %%
from itertools import product
from ast import literal_eval

my_cols = ['sym_freq_12', 'sym_freq_9', 'sym_freq_8']
my_days_lookbacks = [[30, 60, 120], [15, 30, 60, 120]]

my_dates = []
for my_days_lookback in my_days_lookbacks:
  my_row = (df['days_lookbacks'] == str(my_days_lookback))
  l_dates = df.loc[my_row, 'date_end_df_train'].tolist()     
  my_dates.append(l_dates)

my_dates = [val for sublist in my_dates for val in sublist]
my_dates = sorted(list(set(my_dates)), reverse=True)


# d_lbk_freq, e.g.
# [('2023-11-02', [30, 60, 120], 'sym_freq_12'),
#  ('2023-11-02', [30, 60, 120], 'sym_freq_9'),
#  ('2023-11-02', [30, 60, 120], 'sym_freq_8'),
# ...
#  ('2023-03-15', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-15', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-15', [15, 30, 60, 120], 'sym_freq_8')] 

d_lbk_freq = list(product(my_dates, my_days_lookbacks, my_cols))

picks = []
prev_date = ''
# print(f'Model predicts the best performing symbols are:\n[30, 60, 120]        sym_freq_9\n[15, 30, 60, 120]    sym_freq_12\n[30, 60, 120]        sym_freq_8')
print(f'Model predicts the best performing symbols are:')
print(f'1st    {"[30, 60, 120]":<20}{"sym_freq_9":<14}{"days_eval = 4":<20}')
print(f'2nd    {"[15, 30, 60, 120]":<20}{"sym_freq_12":<14}{"days_eval = 5":<20}')
print(f'3rd    {"[30, 60, 120]":<20}{"sym_freq_8":<14}{"days_eval = 4":<20}')
for i, item in enumerate(d_lbk_freq):
  _date, my_days_lookback, my_col = item[0], item[1], item[2]
  my_row = (df['date_end_df_train'] == _date) & (df['days_lookbacks'] == str(my_days_lookback))  
  list_in_df = df.loc[my_row, my_col]
  my_str = list_in_df.tolist()[0]
  my_list = literal_eval(my_str)
  blank = ' '
  if _date != prev_date:
    if prev_date == '':
      print('\nModel Results:')  
      print(f'{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')
    else:
      print(f'\n{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}') 
  else:
    print(f'{i:<6}{blank:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')

  picks.append((i, my_list))
  prev_date = _date
# Out:
# Model predicts the best performing symbols are:
# 1st    [30, 60, 120]       sym_freq_9    days_eval = 4
# 2nd    [15, 30, 60, 120]   sym_freq_12   days_eval = 5
# 3rd    [30, 60, 120]       sym_freq_8    days_eval = 4
#
# Model Results:
# 0     2023-11-02    [30, 60, 120]        sym_freq_12: []
# 1                   [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 2                   [30, 60, 120]        sym_freq_8 : ['ANF']
# 3                   [15, 30, 60, 120]    sym_freq_12: []
# 4                   [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 5                   [15, 30, 60, 120]    sym_freq_8 : ['ANF']
#
# 6     2023-11-01    [30, 60, 120]        sym_freq_12: []
# 7                   [30, 60, 120]        sym_freq_9 : ['FTSM']
# 8                   [30, 60, 120]        sym_freq_8 : ['ANF']
# 9                   [15, 30, 60, 120]    sym_freq_12: []
# 10                  [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 11                  [15, 30, 60, 120]    sym_freq_8 : ['ANF']
#
# 12    2023-10-31    [30, 60, 120]        sym_freq_12: []
# 13                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 14                  [30, 60, 120]        sym_freq_8 : ['ANF', 'SPLK']
# 15                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 16                  [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 17                  [15, 30, 60, 120]    sym_freq_8 : ['ANF', 'SPLK']
#
# 18    2023-10-30    [30, 60, 120]        sym_freq_12: []
# 19                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 20                  [30, 60, 120]        sym_freq_8 : ['SPLK']
# 21                  [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 22                  [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 23                  [15, 30, 60, 120]    sym_freq_8 : ['SPLK']
#
# 24    2023-10-27    [30, 60, 120]        sym_freq_12: []
# 25                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 26                  [30, 60, 120]        sym_freq_8 : ['SPLK']
# 27                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 28                  [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 29                  [15, 30, 60, 120]    sym_freq_8 : ['SPLK']
#
# 30    2023-10-26    [30, 60, 120]        sym_freq_12: []
# 31                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 32                  [30, 60, 120]        sym_freq_8 : ['SPLK']
# 33                  [15, 30, 60, 120]    sym_freq_12: []
# 34                  [15, 30, 60, 120]    sym_freq_9 : []
# 35                  [15, 30, 60, 120]    sym_freq_8 : ['LRN', 'SPLK']
#
# 36    2023-10-25    [30, 60, 120]        sym_freq_12: []
# 37                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 38                  [30, 60, 120]        sym_freq_8 : ['ANF', 'SPLK']
# 39                  [15, 30, 60, 120]    sym_freq_12: []
# 40                  [15, 30, 60, 120]    sym_freq_9 : []
# 41                  [15, 30, 60, 120]    sym_freq_8 : ['ANF', 'SPLK']
#
# 42    2023-10-24    [30, 60, 120]        sym_freq_12: []
# 43                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 44                  [30, 60, 120]        sym_freq_8 : ['ANF']
# 45                  [15, 30, 60, 120]    sym_freq_12: []
# 46                  [15, 30, 60, 120]    sym_freq_9 : []
# 47                  [15, 30, 60, 120]    sym_freq_8 : ['ANF']
#
# 48    2023-10-23    [30, 60, 120]        sym_freq_12: []
# 49                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 50                  [30, 60, 120]        sym_freq_8 : ['SPLK']
# 51                  [15, 30, 60, 120]    sym_freq_12: []
# 52                  [15, 30, 60, 120]    sym_freq_9 : []
# 53                  [15, 30, 60, 120]    sym_freq_8 : ['SPLK']
#
# 54    2023-10-20    [30, 60, 120]        sym_freq_12: []
# 55                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 56                  [30, 60, 120]        sym_freq_8 : []
# 57                  [15, 30, 60, 120]    sym_freq_12: []
# 58                  [15, 30, 60, 120]    sym_freq_9 : []
# 59                  [15, 30, 60, 120]    sym_freq_8 : ['PGR', 'USAC']
#
# 60    2023-10-19    [30, 60, 120]        sym_freq_12: []
# 61                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 62                  [30, 60, 120]        sym_freq_8 : []
# 63                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 64                  [15, 30, 60, 120]    sym_freq_9 : ['PGR', 'USAC']
# 65                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 66    2023-10-17    [30, 60, 120]        sym_freq_12: []
# 67                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 68                  [30, 60, 120]        sym_freq_8 : []
# 69                  [15, 30, 60, 120]    sym_freq_12: []
# 70                  [15, 30, 60, 120]    sym_freq_9 : []
# 71                  [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'PGR']
#
# 72    2023-10-12    [30, 60, 120]        sym_freq_12: []
# 73                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 74                  [30, 60, 120]        sym_freq_8 : []
# 75                  [15, 30, 60, 120]    sym_freq_12: []
# 76                  [15, 30, 60, 120]    sym_freq_9 : ['ICPT']
# 77                  [15, 30, 60, 120]    sym_freq_8 : ['ANF', 'CLS']
#
# 78    2023-10-06    [30, 60, 120]        sym_freq_12: []
# 79                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 80                  [30, 60, 120]        sym_freq_8 : []
# 81                  [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 82                  [15, 30, 60, 120]    sym_freq_9 : []
# 83                  [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 84    2023-10-05    [30, 60, 120]        sym_freq_12: []
# 85                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 86                  [30, 60, 120]        sym_freq_8 : []
# 87                  [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 88                  [15, 30, 60, 120]    sym_freq_9 : ['CLS']
# 89                  [15, 30, 60, 120]    sym_freq_8 : ['ICPT', 'SPLK']
#
# 90    2023-10-04    [30, 60, 120]        sym_freq_12: []
# 91                  [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 92                  [30, 60, 120]        sym_freq_8 : []
# 93                  [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 94                  [15, 30, 60, 120]    sym_freq_9 : ['ICPT']
# 95                  [15, 30, 60, 120]    sym_freq_8 : ['MLKN']
#
# 96    2023-10-02    [30, 60, 120]        sym_freq_12: []
# 97                  [30, 60, 120]        sym_freq_9 : ['FTSM']
# 98                  [30, 60, 120]        sym_freq_8 : ['ANF']
# 99                  [15, 30, 60, 120]    sym_freq_12: ['FTSM']
# 100                 [15, 30, 60, 120]    sym_freq_9 : ['ANF']
# 101                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 102   2023-09-29    [30, 60, 120]        sym_freq_12: []
# 103                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 104                 [30, 60, 120]        sym_freq_8 : []
# 105                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 106                 [15, 30, 60, 120]    sym_freq_9 : ['ARCH']
# 107                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT', 'NGS']
#
# 108   2023-09-28    [30, 60, 120]        sym_freq_12: []
# 109                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 110                 [30, 60, 120]        sym_freq_8 : ['CCJ']
# 111                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 112                 [15, 30, 60, 120]    sym_freq_9 : ['ARCH']
# 113                 [15, 30, 60, 120]    sym_freq_8 : ['CCJ', 'USAC']
#
# 114   2023-09-25    [30, 60, 120]        sym_freq_12: []
# 115                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 116                 [30, 60, 120]        sym_freq_8 : []
# 117                 [15, 30, 60, 120]    sym_freq_12: []
# 118                 [15, 30, 60, 120]    sym_freq_9 : []
# 119                 [15, 30, 60, 120]    sym_freq_8 : ['ARCH', 'CCJ']
#
# 120   2023-09-22    [30, 60, 120]        sym_freq_12: []
# 121                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 122                 [30, 60, 120]        sym_freq_8 : []
# 123                 [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 124                 [15, 30, 60, 120]    sym_freq_9 : []
# 125                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 126   2023-09-21    [30, 60, 120]        sym_freq_12: []
# 127                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 128                 [30, 60, 120]        sym_freq_8 : []
# 129                 [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 130                 [15, 30, 60, 120]    sym_freq_9 : []
# 131                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 132   2023-09-20    [30, 60, 120]        sym_freq_12: []
# 133                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 134                 [30, 60, 120]        sym_freq_8 : []
# 135                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 136                 [15, 30, 60, 120]    sym_freq_9 : ['DELL']
# 137                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 138   2023-09-18    [30, 60, 120]        sym_freq_12: []
# 139                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 140                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 141                 [15, 30, 60, 120]    sym_freq_12: []
# 142                 [15, 30, 60, 120]    sym_freq_9 : ['DELL']
# 143                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 144   2023-09-15    [30, 60, 120]        sym_freq_12: []
# 145                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 146                 [30, 60, 120]        sym_freq_8 : []
# 147                 [15, 30, 60, 120]    sym_freq_12: []
# 148                 [15, 30, 60, 120]    sym_freq_9 : []
# 149                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 150   2023-09-14    [30, 60, 120]        sym_freq_12: []
# 151                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 152                 [30, 60, 120]        sym_freq_8 : ['DELL', 'FTSM']
# 153                 [15, 30, 60, 120]    sym_freq_12: []
# 154                 [15, 30, 60, 120]    sym_freq_9 : []
# 155                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 156   2023-09-13    [30, 60, 120]        sym_freq_12: []
# 157                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 158                 [30, 60, 120]        sym_freq_8 : ['DELL']
# 159                 [15, 30, 60, 120]    sym_freq_12: []
# 160                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 161                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 162   2023-09-12    [30, 60, 120]        sym_freq_12: []
# 163                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 164                 [30, 60, 120]        sym_freq_8 : ['DELL', 'MMYT']
# 165                 [15, 30, 60, 120]    sym_freq_12: []
# 166                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 167                 [15, 30, 60, 120]    sym_freq_8 : ['FTI', 'MMYT']
#
# 168   2023-09-11    [30, 60, 120]        sym_freq_12: []
# 169                 [30, 60, 120]        sym_freq_9 : ['DELL', 'FTSM', 'SHV']
# 170                 [30, 60, 120]        sym_freq_8 : []
# 171                 [15, 30, 60, 120]    sym_freq_12: ['DELL']
# 172                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 173                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 174   2023-09-08    [30, 60, 120]        sym_freq_12: []
# 175                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 176                 [30, 60, 120]        sym_freq_8 : ['DELL', 'STRL']
# 177                 [15, 30, 60, 120]    sym_freq_12: []
# 178                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 179                 [15, 30, 60, 120]    sym_freq_8 : ['CELH', 'STRL']
#
# 180   2023-09-05    [30, 60, 120]        sym_freq_12: []
# 181                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 182                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 183                 [15, 30, 60, 120]    sym_freq_12: []
# 184                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 185                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 186   2023-09-01    [30, 60, 120]        sym_freq_12: []
# 187                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 188                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 189                 [15, 30, 60, 120]    sym_freq_12: []
# 190                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'DELL', 'FTSM']
# 191                 [15, 30, 60, 120]    sym_freq_8 : ['STRL', 'TDS']
#
# 192   2023-08-25    [30, 60, 120]        sym_freq_12: []
# 193                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 194                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 195                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 196                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'TDS']
# 197                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'LLY']
#
# 198   2023-08-18    [30, 60, 120]        sym_freq_12: []
# 199                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 200                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 201                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 202                 [15, 30, 60, 120]    sym_freq_9 : ['CNX', 'STRL', 'TDS']
# 203                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 204   2023-08-17    [30, 60, 120]        sym_freq_12: []
# 205                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 206                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 207                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 208                 [15, 30, 60, 120]    sym_freq_9 : ['CNX', 'TDS']
# 209                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 210   2023-08-15    [30, 60, 120]        sym_freq_12: []
# 211                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 212                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 213                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 214                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 215                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 216   2023-08-14    [30, 60, 120]        sym_freq_12: []
# 217                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 218                 [30, 60, 120]        sym_freq_8 : []
# 219                 [15, 30, 60, 120]    sym_freq_12: []
# 220                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 221                 [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'EME']
#
# 222   2023-08-11    [30, 60, 120]        sym_freq_12: []
# 223                 [30, 60, 120]        sym_freq_9 : []
# 224                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 225                 [15, 30, 60, 120]    sym_freq_12: []
# 226                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 227                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 228   2023-08-10    [30, 60, 120]        sym_freq_12: []
# 229                 [30, 60, 120]        sym_freq_9 : []
# 230                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 231                 [15, 30, 60, 120]    sym_freq_12: []
# 232                 [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'TDS']
# 233                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 234   2023-08-09    [30, 60, 120]        sym_freq_12: []
# 235                 [30, 60, 120]        sym_freq_9 : []
# 236                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 237                 [15, 30, 60, 120]    sym_freq_12: []
# 238                 [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'TDS']
# 239                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 240   2023-08-08    [30, 60, 120]        sym_freq_12: []
# 241                 [30, 60, 120]        sym_freq_9 : []
# 242                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 243                 [15, 30, 60, 120]    sym_freq_12: []
# 244                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 245                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 246   2023-08-07    [30, 60, 120]        sym_freq_12: []
# 247                 [30, 60, 120]        sym_freq_9 : []
# 248                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 249                 [15, 30, 60, 120]    sym_freq_12: []
# 250                 [15, 30, 60, 120]    sym_freq_9 : []
# 251                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 252   2023-08-04    [30, 60, 120]        sym_freq_12: []
# 253                 [30, 60, 120]        sym_freq_9 : []
# 254                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 255                 [15, 30, 60, 120]    sym_freq_12: []
# 256                 [15, 30, 60, 120]    sym_freq_9 : []
# 257                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 258   2023-08-03    [30, 60, 120]        sym_freq_12: []
# 259                 [30, 60, 120]        sym_freq_9 : []
# 260                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 261                 [15, 30, 60, 120]    sym_freq_12: []
# 262                 [15, 30, 60, 120]    sym_freq_9 : []
# 263                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 264   2023-08-02    [30, 60, 120]        sym_freq_12: []
# 265                 [30, 60, 120]        sym_freq_9 : []
# 266                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 267                 [15, 30, 60, 120]    sym_freq_12: []
# 268                 [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 269                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 270   2023-08-01    [30, 60, 120]        sym_freq_12: []
# 271                 [30, 60, 120]        sym_freq_9 : []
# 272                 [30, 60, 120]        sym_freq_8 : []
# 273                 [15, 30, 60, 120]    sym_freq_12: []
# 274                 [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 275                 [15, 30, 60, 120]    sym_freq_8 : ['SMCI']
#
# 276   2023-07-27    [30, 60, 120]        sym_freq_12: []
# 277                 [30, 60, 120]        sym_freq_9 : []
# 278                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 279                 [15, 30, 60, 120]    sym_freq_12: []
# 280                 [15, 30, 60, 120]    sym_freq_9 : ['JOE']
# 281                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 282   2023-07-26    [30, 60, 120]        sym_freq_12: []
# 283                 [30, 60, 120]        sym_freq_9 : []
# 284                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 285                 [15, 30, 60, 120]    sym_freq_12: []
# 286                 [15, 30, 60, 120]    sym_freq_9 : []
# 287                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 288   2023-07-25    [30, 60, 120]        sym_freq_12: []
# 289                 [30, 60, 120]        sym_freq_9 : []
# 290                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 291                 [15, 30, 60, 120]    sym_freq_12: []
# 292                 [15, 30, 60, 120]    sym_freq_9 : []
# 293                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 294   2023-07-21    [30, 60, 120]        sym_freq_12: []
# 295                 [30, 60, 120]        sym_freq_9 : []
# 296                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 297                 [15, 30, 60, 120]    sym_freq_12: []
# 298                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 299                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 300   2023-07-20    [30, 60, 120]        sym_freq_12: []
# 301                 [30, 60, 120]        sym_freq_9 : []
# 302                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 303                 [15, 30, 60, 120]    sym_freq_12: []
# 304                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 305                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 306   2023-07-18    [30, 60, 120]        sym_freq_12: []
# 307                 [30, 60, 120]        sym_freq_9 : []
# 308                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 309                 [15, 30, 60, 120]    sym_freq_12: []
# 310                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 311                 [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 312   2023-07-14    [30, 60, 120]        sym_freq_12: []
# 313                 [30, 60, 120]        sym_freq_9 : []
# 314                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 315                 [15, 30, 60, 120]    sym_freq_12: []
# 316                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 317                 [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 318   2023-07-13    [30, 60, 120]        sym_freq_12: []
# 319                 [30, 60, 120]        sym_freq_9 : []
# 320                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 321                 [15, 30, 60, 120]    sym_freq_12: []
# 322                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 323                 [15, 30, 60, 120]    sym_freq_8 : ['BCC', 'SKYW']
#
# 324   2023-07-12    [30, 60, 120]        sym_freq_12: []
# 325                 [30, 60, 120]        sym_freq_9 : []
# 326                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 327                 [15, 30, 60, 120]    sym_freq_12: []
# 328                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 329                 [15, 30, 60, 120]    sym_freq_8 : ['BZH', 'SKYW']
#
# 330   2023-07-11    [30, 60, 120]        sym_freq_12: []
# 331                 [30, 60, 120]        sym_freq_9 : []
# 332                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 333                 [15, 30, 60, 120]    sym_freq_12: []
# 334                 [15, 30, 60, 120]    sym_freq_9 : []
# 335                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 336   2023-07-10    [30, 60, 120]        sym_freq_12: []
# 337                 [30, 60, 120]        sym_freq_9 : []
# 338                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 339                 [15, 30, 60, 120]    sym_freq_12: []
# 340                 [15, 30, 60, 120]    sym_freq_9 : []
# 341                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 342   2023-07-07    [30, 60, 120]        sym_freq_12: []
# 343                 [30, 60, 120]        sym_freq_9 : []
# 344                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 345                 [15, 30, 60, 120]    sym_freq_12: []
# 346                 [15, 30, 60, 120]    sym_freq_9 : []
# 347                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 348   2023-07-06    [30, 60, 120]        sym_freq_12: []
# 349                 [30, 60, 120]        sym_freq_9 : []
# 350                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 351                 [15, 30, 60, 120]    sym_freq_12: []
# 352                 [15, 30, 60, 120]    sym_freq_9 : []
# 353                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW']
#
# 354   2023-07-05    [30, 60, 120]        sym_freq_12: []
# 355                 [30, 60, 120]        sym_freq_9 : []
# 356                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 357                 [15, 30, 60, 120]    sym_freq_12: []
# 358                 [15, 30, 60, 120]    sym_freq_9 : []
# 359                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 360   2023-07-03    [30, 60, 120]        sym_freq_12: []
# 361                 [30, 60, 120]        sym_freq_9 : []
# 362                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 363                 [15, 30, 60, 120]    sym_freq_12: []
# 364                 [15, 30, 60, 120]    sym_freq_9 : []
# 365                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW', 'W']
#
# 366   2023-06-30    [30, 60, 120]        sym_freq_12: []
# 367                 [30, 60, 120]        sym_freq_9 : []
# 368                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 369                 [15, 30, 60, 120]    sym_freq_12: []
# 370                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 371                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 372   2023-06-29    [30, 60, 120]        sym_freq_12: []
# 373                 [30, 60, 120]        sym_freq_9 : []
# 374                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 375                 [15, 30, 60, 120]    sym_freq_12: []
# 376                 [15, 30, 60, 120]    sym_freq_9 : []
# 377                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 378   2023-06-28    [30, 60, 120]        sym_freq_12: []
# 379                 [30, 60, 120]        sym_freq_9 : []
# 380                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 381                 [15, 30, 60, 120]    sym_freq_12: []
# 382                 [15, 30, 60, 120]    sym_freq_9 : []
# 383                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 384   2023-06-27    [30, 60, 120]        sym_freq_12: []
# 385                 [30, 60, 120]        sym_freq_9 : []
# 386                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 387                 [15, 30, 60, 120]    sym_freq_12: []
# 388                 [15, 30, 60, 120]    sym_freq_9 : []
# 389                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 390   2023-06-26    [30, 60, 120]        sym_freq_12: []
# 391                 [30, 60, 120]        sym_freq_9 : []
# 392                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 393                 [15, 30, 60, 120]    sym_freq_12: []
# 394                 [15, 30, 60, 120]    sym_freq_9 : []
# 395                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 396   2023-06-23    [30, 60, 120]        sym_freq_12: []
# 397                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 398                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 399                 [15, 30, 60, 120]    sym_freq_12: []
# 400                 [15, 30, 60, 120]    sym_freq_9 : ['CCL', 'NVDA']
# 401                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH']
#
# 402   2023-06-22    [30, 60, 120]        sym_freq_12: []
# 403                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 404                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 405                 [15, 30, 60, 120]    sym_freq_12: []
# 406                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 407                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'PBR']
#
# 408   2023-06-21    [30, 60, 120]        sym_freq_12: []
# 409                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 410                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 411                 [15, 30, 60, 120]    sym_freq_12: []
# 412                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 413                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 414   2023-06-20    [30, 60, 120]        sym_freq_12: []
# 415                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 416                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 417                 [15, 30, 60, 120]    sym_freq_12: []
# 418                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 419                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 420   2023-06-16    [30, 60, 120]        sym_freq_12: []
# 421                 [30, 60, 120]        sym_freq_9 : []
# 422                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 423                 [15, 30, 60, 120]    sym_freq_12: []
# 424                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 425                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 426   2023-06-15    [30, 60, 120]        sym_freq_12: []
# 427                 [30, 60, 120]        sym_freq_9 : []
# 428                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 429                 [15, 30, 60, 120]    sym_freq_12: []
# 430                 [15, 30, 60, 120]    sym_freq_9 : []
# 431                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'NVDA', 'SKYW']
#
# 432   2023-06-14    [30, 60, 120]        sym_freq_12: []
# 433                 [30, 60, 120]        sym_freq_9 : []
# 434                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA', 'SHV']
# 435                 [15, 30, 60, 120]    sym_freq_12: []
# 436                 [15, 30, 60, 120]    sym_freq_9 : ['AVGO']
# 437                 [15, 30, 60, 120]    sym_freq_8 : ['ORCL', 'SKYW']
#
# 438   2023-06-13    [30, 60, 120]        sym_freq_12: []
# 439                 [30, 60, 120]        sym_freq_9 : []
# 440                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 441                 [15, 30, 60, 120]    sym_freq_12: []
# 442                 [15, 30, 60, 120]    sym_freq_9 : []
# 443                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 444   2023-06-12    [30, 60, 120]        sym_freq_12: []
# 445                 [30, 60, 120]        sym_freq_9 : []
# 446                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 447                 [15, 30, 60, 120]    sym_freq_12: []
# 448                 [15, 30, 60, 120]    sym_freq_9 : []
# 449                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 450   2023-06-09    [30, 60, 120]        sym_freq_12: []
# 451                 [30, 60, 120]        sym_freq_9 : []
# 452                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 453                 [15, 30, 60, 120]    sym_freq_12: []
# 454                 [15, 30, 60, 120]    sym_freq_9 : []
# 455                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 456   2023-06-08    [30, 60, 120]        sym_freq_12: []
# 457                 [30, 60, 120]        sym_freq_9 : []
# 458                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 459                 [15, 30, 60, 120]    sym_freq_12: []
# 460                 [15, 30, 60, 120]    sym_freq_9 : []
# 461                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA']
#
# 462   2023-06-07    [30, 60, 120]        sym_freq_12: []
# 463                 [30, 60, 120]        sym_freq_9 : []
# 464                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 465                 [15, 30, 60, 120]    sym_freq_12: []
# 466                 [15, 30, 60, 120]    sym_freq_9 : []
# 467                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 468   2023-06-06    [30, 60, 120]        sym_freq_12: []
# 469                 [30, 60, 120]        sym_freq_9 : []
# 470                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 471                 [15, 30, 60, 120]    sym_freq_12: []
# 472                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 473                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 474   2023-06-05    [30, 60, 120]        sym_freq_12: []
# 475                 [30, 60, 120]        sym_freq_9 : []
# 476                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 477                 [15, 30, 60, 120]    sym_freq_12: []
# 478                 [15, 30, 60, 120]    sym_freq_9 : []
# 479                 [15, 30, 60, 120]    sym_freq_8 : ['META', 'SKYW']
#
# 480   2023-06-02    [30, 60, 120]        sym_freq_12: []
# 481                 [30, 60, 120]        sym_freq_9 : []
# 482                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 483                 [15, 30, 60, 120]    sym_freq_12: []
# 484                 [15, 30, 60, 120]    sym_freq_9 : ['META']
# 485                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 486   2023-06-01    [30, 60, 120]        sym_freq_12: []
# 487                 [30, 60, 120]        sym_freq_9 : []
# 488                 [30, 60, 120]        sym_freq_8 : ['META', 'NVDA']
# 489                 [15, 30, 60, 120]    sym_freq_12: []
# 490                 [15, 30, 60, 120]    sym_freq_9 : ['AVGO', 'RMBS']
# 491                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 492   2023-05-31    [30, 60, 120]        sym_freq_12: []
# 493                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 494                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA']
# 495                 [15, 30, 60, 120]    sym_freq_12: []
# 496                 [15, 30, 60, 120]    sym_freq_9 : []
# 497                 [15, 30, 60, 120]    sym_freq_8 : ['RMBS']
#
# 498   2023-05-30    [30, 60, 120]        sym_freq_12: []
# 499                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 500                 [30, 60, 120]        sym_freq_8 : ['AVGO', 'NVDA']
# 501                 [15, 30, 60, 120]    sym_freq_12: []
# 502                 [15, 30, 60, 120]    sym_freq_9 : []
# 503                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 504   2023-05-26    [30, 60, 120]        sym_freq_12: []
# 505                 [30, 60, 120]        sym_freq_9 : ['AVGO', 'SHV']
# 506                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 507                 [15, 30, 60, 120]    sym_freq_12: ['AVGO']
# 508                 [15, 30, 60, 120]    sym_freq_9 : ['RMBS']
# 509                 [15, 30, 60, 120]    sym_freq_8 : ['AMD']
#
# 510   2023-05-25    [30, 60, 120]        sym_freq_12: []
# 511                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 512                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'NVDA']
# 513                 [15, 30, 60, 120]    sym_freq_12: []
# 514                 [15, 30, 60, 120]    sym_freq_9 : []
# 515                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 516   2023-05-24    [30, 60, 120]        sym_freq_12: []
# 517                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 518                 [30, 60, 120]        sym_freq_8 : []
# 519                 [15, 30, 60, 120]    sym_freq_12: []
# 520                 [15, 30, 60, 120]    sym_freq_9 : []
# 521                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 522   2023-05-23    [30, 60, 120]        sym_freq_12: []
# 523                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 524                 [30, 60, 120]        sym_freq_8 : []
# 525                 [15, 30, 60, 120]    sym_freq_12: []
# 526                 [15, 30, 60, 120]    sym_freq_9 : []
# 527                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 528   2023-05-22    [30, 60, 120]        sym_freq_12: []
# 529                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 530                 [30, 60, 120]        sym_freq_8 : []
# 531                 [15, 30, 60, 120]    sym_freq_12: []
# 532                 [15, 30, 60, 120]    sym_freq_9 : []
# 533                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 534   2023-05-19    [30, 60, 120]        sym_freq_12: []
# 535                 [30, 60, 120]        sym_freq_9 : []
# 536                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 537                 [15, 30, 60, 120]    sym_freq_12: []
# 538                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 539                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 540   2023-05-18    [30, 60, 120]        sym_freq_12: []
# 541                 [30, 60, 120]        sym_freq_9 : []
# 542                 [30, 60, 120]        sym_freq_8 : ['SHV', 'TMHC']
# 543                 [15, 30, 60, 120]    sym_freq_12: []
# 544                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 545                 [15, 30, 60, 120]    sym_freq_8 : ['TMHC']
#
# 546   2023-05-17    [30, 60, 120]        sym_freq_12: []
# 547                 [30, 60, 120]        sym_freq_9 : []
# 548                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 549                 [15, 30, 60, 120]    sym_freq_12: []
# 550                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 551                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 552   2023-05-16    [30, 60, 120]        sym_freq_12: []
# 553                 [30, 60, 120]        sym_freq_9 : []
# 554                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 555                 [15, 30, 60, 120]    sym_freq_12: []
# 556                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 557                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 558   2023-05-15    [30, 60, 120]        sym_freq_12: []
# 559                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 560                 [30, 60, 120]        sym_freq_8 : []
# 561                 [15, 30, 60, 120]    sym_freq_12: []
# 562                 [15, 30, 60, 120]    sym_freq_9 : []
# 563                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 564   2023-05-12    [30, 60, 120]        sym_freq_12: []
# 565                 [30, 60, 120]        sym_freq_9 : []
# 566                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 567                 [15, 30, 60, 120]    sym_freq_12: []
# 568                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE', 'SHV']
# 569                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 570   2023-05-11    [30, 60, 120]        sym_freq_12: []
# 571                 [30, 60, 120]        sym_freq_9 : []
# 572                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 573                 [15, 30, 60, 120]    sym_freq_12: []
# 574                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 575                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 576   2023-05-10    [30, 60, 120]        sym_freq_12: []
# 577                 [30, 60, 120]        sym_freq_9 : []
# 578                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 579                 [15, 30, 60, 120]    sym_freq_12: []
# 580                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 581                 [15, 30, 60, 120]    sym_freq_8 : ['BLDR']
#
# 582   2023-05-09    [30, 60, 120]        sym_freq_12: []
# 583                 [30, 60, 120]        sym_freq_9 : []
# 584                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 585                 [15, 30, 60, 120]    sym_freq_12: []
# 586                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 587                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 588   2023-05-08    [30, 60, 120]        sym_freq_12: []
# 589                 [30, 60, 120]        sym_freq_9 : []
# 590                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 591                 [15, 30, 60, 120]    sym_freq_12: []
# 592                 [15, 30, 60, 120]    sym_freq_9 : []
# 593                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 594   2023-05-05    [30, 60, 120]        sym_freq_12: []
# 595                 [30, 60, 120]        sym_freq_9 : []
# 596                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 597                 [15, 30, 60, 120]    sym_freq_12: []
# 598                 [15, 30, 60, 120]    sym_freq_9 : []
# 599                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 600   2023-05-04    [30, 60, 120]        sym_freq_12: []
# 601                 [30, 60, 120]        sym_freq_9 : []
# 602                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 603                 [15, 30, 60, 120]    sym_freq_12: []
# 604                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP']
# 605                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 606   2023-05-03    [30, 60, 120]        sym_freq_12: []
# 607                 [30, 60, 120]        sym_freq_9 : []
# 608                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 609                 [15, 30, 60, 120]    sym_freq_12: []
# 610                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE']
# 611                 [15, 30, 60, 120]    sym_freq_8 : ['CCEP', 'SHV', 'SKYW']
#
# 612   2023-05-02    [30, 60, 120]        sym_freq_12: []
# 613                 [30, 60, 120]        sym_freq_9 : []
# 614                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 615                 [15, 30, 60, 120]    sym_freq_12: []
# 616                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP', 'ISEE', 'SHV']
# 617                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 618   2023-05-01    [30, 60, 120]        sym_freq_12: []
# 619                 [30, 60, 120]        sym_freq_9 : []
# 620                 [30, 60, 120]        sym_freq_8 : []
# 621                 [15, 30, 60, 120]    sym_freq_12: []
# 622                 [15, 30, 60, 120]    sym_freq_9 : []
# 623                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 624   2023-04-28    [30, 60, 120]        sym_freq_12: []
# 625                 [30, 60, 120]        sym_freq_9 : []
# 626                 [30, 60, 120]        sym_freq_8 : []
# 627                 [15, 30, 60, 120]    sym_freq_12: []
# 628                 [15, 30, 60, 120]    sym_freq_9 : []
# 629                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 630   2023-04-27    [30, 60, 120]        sym_freq_12: []
# 631                 [30, 60, 120]        sym_freq_9 : []
# 632                 [30, 60, 120]        sym_freq_8 : []
# 633                 [15, 30, 60, 120]    sym_freq_12: []
# 634                 [15, 30, 60, 120]    sym_freq_9 : []
# 635                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 636   2023-04-26    [30, 60, 120]        sym_freq_12: []
# 637                 [30, 60, 120]        sym_freq_9 : []
# 638                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 639                 [15, 30, 60, 120]    sym_freq_12: []
# 640                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 641                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 642   2023-04-25    [30, 60, 120]        sym_freq_12: []
# 643                 [30, 60, 120]        sym_freq_9 : []
# 644                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 645                 [15, 30, 60, 120]    sym_freq_12: []
# 646                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 647                 [15, 30, 60, 120]    sym_freq_8 : ['ELF']
#
# 648   2023-04-24    [30, 60, 120]        sym_freq_12: []
# 649                 [30, 60, 120]        sym_freq_9 : []
# 650                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 651                 [15, 30, 60, 120]    sym_freq_12: []
# 652                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 653                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 654   2023-04-21    [30, 60, 120]        sym_freq_12: []
# 655                 [30, 60, 120]        sym_freq_9 : []
# 656                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 657                 [15, 30, 60, 120]    sym_freq_12: []
# 658                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 659                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 660   2023-04-20    [30, 60, 120]        sym_freq_12: []
# 661                 [30, 60, 120]        sym_freq_9 : []
# 662                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 663                 [15, 30, 60, 120]    sym_freq_12: []
# 664                 [15, 30, 60, 120]    sym_freq_9 : []
# 665                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 666   2023-04-19    [30, 60, 120]        sym_freq_12: []
# 667                 [30, 60, 120]        sym_freq_9 : []
# 668                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 669                 [15, 30, 60, 120]    sym_freq_12: []
# 670                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 671                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 672   2023-04-18    [30, 60, 120]        sym_freq_12: []
# 673                 [30, 60, 120]        sym_freq_9 : []
# 674                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 675                 [15, 30, 60, 120]    sym_freq_12: []
# 676                 [15, 30, 60, 120]    sym_freq_9 : []
# 677                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 678   2023-04-17    [30, 60, 120]        sym_freq_12: []
# 679                 [30, 60, 120]        sym_freq_9 : []
# 680                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 681                 [15, 30, 60, 120]    sym_freq_12: []
# 682                 [15, 30, 60, 120]    sym_freq_9 : []
# 683                 [15, 30, 60, 120]    sym_freq_8 : ['ELF', 'SHV']
#
# 684   2023-04-14    [30, 60, 120]        sym_freq_12: []
# 685                 [30, 60, 120]        sym_freq_9 : []
# 686                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 687                 [15, 30, 60, 120]    sym_freq_12: []
# 688                 [15, 30, 60, 120]    sym_freq_9 : []
# 689                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 690   2023-04-13    [30, 60, 120]        sym_freq_12: []
# 691                 [30, 60, 120]        sym_freq_9 : []
# 692                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 693                 [15, 30, 60, 120]    sym_freq_12: []
# 694                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 695                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 696   2023-04-12    [30, 60, 120]        sym_freq_12: []
# 697                 [30, 60, 120]        sym_freq_9 : []
# 698                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 699                 [15, 30, 60, 120]    sym_freq_12: []
# 700                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 701                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 702   2023-04-11    [30, 60, 120]        sym_freq_12: []
# 703                 [30, 60, 120]        sym_freq_9 : []
# 704                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 705                 [15, 30, 60, 120]    sym_freq_12: []
# 706                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 707                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 708   2023-04-10    [30, 60, 120]        sym_freq_12: []
# 709                 [30, 60, 120]        sym_freq_9 : []
# 710                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 711                 [15, 30, 60, 120]    sym_freq_12: []
# 712                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 713                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 714   2023-04-06    [30, 60, 120]        sym_freq_12: []
# 715                 [30, 60, 120]        sym_freq_9 : []
# 716                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 717                 [15, 30, 60, 120]    sym_freq_12: []
# 718                 [15, 30, 60, 120]    sym_freq_9 : []
# 719                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 720   2023-04-05    [30, 60, 120]        sym_freq_12: []
# 721                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 722                 [30, 60, 120]        sym_freq_8 : []
# 723                 [15, 30, 60, 120]    sym_freq_12: []
# 724                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 725                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 726   2023-04-04    [30, 60, 120]        sym_freq_12: []
# 727                 [30, 60, 120]        sym_freq_9 : []
# 728                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 729                 [15, 30, 60, 120]    sym_freq_12: []
# 730                 [15, 30, 60, 120]    sym_freq_9 : []
# 731                 [15, 30, 60, 120]    sym_freq_8 : ['NVDA', 'SHV']
#
# 732   2023-04-03    [30, 60, 120]        sym_freq_12: []
# 733                 [30, 60, 120]        sym_freq_9 : []
# 734                 [30, 60, 120]        sym_freq_8 : ['GE', 'NVDA']
# 735                 [15, 30, 60, 120]    sym_freq_12: []
# 736                 [15, 30, 60, 120]    sym_freq_9 : []
# 737                 [15, 30, 60, 120]    sym_freq_8 : ['GE', 'PERI']
#
# 738   2023-03-31    [30, 60, 120]        sym_freq_12: []
# 739                 [30, 60, 120]        sym_freq_9 : []
# 740                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 741                 [15, 30, 60, 120]    sym_freq_12: []
# 742                 [15, 30, 60, 120]    sym_freq_9 : []
# 743                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 744   2023-03-30    [30, 60, 120]        sym_freq_12: []
# 745                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 746                 [30, 60, 120]        sym_freq_8 : ['NVDA']
# 747                 [15, 30, 60, 120]    sym_freq_12: []
# 748                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 749                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 750   2023-03-29    [30, 60, 120]        sym_freq_12: []
# 751                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 752                 [30, 60, 120]        sym_freq_8 : []
# 753                 [15, 30, 60, 120]    sym_freq_12: []
# 754                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 755                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 756   2023-03-28    [30, 60, 120]        sym_freq_12: []
# 757                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 758                 [30, 60, 120]        sym_freq_8 : []
# 759                 [15, 30, 60, 120]    sym_freq_12: []
# 760                 [15, 30, 60, 120]    sym_freq_9 : []
# 761                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 762   2023-03-27    [30, 60, 120]        sym_freq_12: []
# 763                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 764                 [30, 60, 120]        sym_freq_8 : ['GE']
# 765                 [15, 30, 60, 120]    sym_freq_12: []
# 766                 [15, 30, 60, 120]    sym_freq_9 : []
# 767                 [15, 30, 60, 120]    sym_freq_8 : ['GE', 'NVDA', 'SGEN']
#
# 768   2023-03-24    [30, 60, 120]        sym_freq_12: []
# 769                 [30, 60, 120]        sym_freq_9 : []
# 770                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 771                 [15, 30, 60, 120]    sym_freq_12: []
# 772                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 773                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 774   2023-03-23    [30, 60, 120]        sym_freq_12: []
# 775                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 776                 [30, 60, 120]        sym_freq_8 : []
# 777                 [15, 30, 60, 120]    sym_freq_12: []
# 778                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 779                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'GE']
#
# 780   2023-03-22    [30, 60, 120]        sym_freq_12: []
# 781                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 782                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 783                 [15, 30, 60, 120]    sym_freq_12: []
# 784                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'NVDA']
# 785                 [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 786   2023-03-21    [30, 60, 120]        sym_freq_12: []
# 787                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 788                 [30, 60, 120]        sym_freq_8 : ['GE']
# 789                 [15, 30, 60, 120]    sym_freq_12: []
# 790                 [15, 30, 60, 120]    sym_freq_9 : ['GE']
# 791                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 792   2023-03-20    [30, 60, 120]        sym_freq_12: []
# 793                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 794                 [30, 60, 120]        sym_freq_8 : []
# 795                 [15, 30, 60, 120]    sym_freq_12: []
# 796                 [15, 30, 60, 120]    sym_freq_9 : []
# 797                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 798   2023-03-17    [30, 60, 120]        sym_freq_12: []
# 799                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 800                 [30, 60, 120]        sym_freq_8 : ['GE']
# 801                 [15, 30, 60, 120]    sym_freq_12: []
# 802                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'GE']
# 803                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 804   2023-03-16    [30, 60, 120]        sym_freq_12: []
# 805                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 806                 [30, 60, 120]        sym_freq_8 : []
# 807                 [15, 30, 60, 120]    sym_freq_12: []
# 808                 [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 809                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 810   2023-03-15    [30, 60, 120]        sym_freq_12: []
# 811                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 812                 [30, 60, 120]        sym_freq_8 : []
# 813                 [15, 30, 60, 120]    sym_freq_12: []
# 814                 [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 815                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'FCN']

# %%
model_top_picks = [([30, 60, 120], 'sym_freq_9'), ([15, 30, 60, 120], 'sym_freq_12'), ([30, 60, 120], 'sym_freq_8')]

# %%
######################

# %%
dates_in_df = df.date_end_df_train.copy()
dates_in_df_deduped = dates_in_df.drop_duplicates()
print(f'type(dates_in_df_deduped): {type(dates_in_df_deduped)}')
dates_in_df_deduped
# Out:
# type(dates_in_df_deduped): <class 'pandas.core.series.Series'>
# 0      2023-11-02
# 2      2023-11-01
# 4      2023-10-31
# 6      2023-10-30
# 8      2023-10-27
#           ...
# 262    2023-03-21
# 264    2023-03-20
# 266    2023-03-17
# 268    2023-03-16
# 270    2023-03-15
# Name: date_end_df_train, Length: 136, dtype: object

# %%
dates_in_df = dates_in_df_deduped.tolist()
dates_in_df
# Out:
# ['2023-11-02',
#  '2023-11-01',
#  '2023-10-31',
#  '2023-10-30',
#  '2023-10-27',
#  '2023-10-26',
#  '2023-10-25',
#  '2023-10-24',
#  '2023-10-23',
#  '2023-10-20',
#  '2023-10-19',
#  '2023-10-17',
#  '2023-10-12',
#  '2023-10-06',
#  '2023-10-05',
#  '2023-10-04',
#  '2023-10-02',
#  '2023-09-29',
#  '2023-09-28',
#  '2023-09-25',
#  '2023-09-22',
#  '2023-09-21',
#  '2023-09-20',
#  '2023-09-18',
#  '2023-09-15',
#  '2023-09-14',
#  '2023-09-13',
#  '2023-09-12',
#  '2023-09-11',
#  '2023-09-08',
#  '2023-09-05',
#  '2023-09-01',
#  '2023-08-25',
#  '2023-08-18',
#  '2023-08-17',
#  '2023-08-15',
#  '2023-08-14',
#  '2023-08-11',
#  '2023-08-10',
#  '2023-08-09',
#  '2023-08-08',
#  '2023-08-07',
#  '2023-08-04',
#  '2023-08-03',
#  '2023-08-02',
#  '2023-08-01',
#  '2023-07-27',
#  '2023-07-26',
#  '2023-07-25',
#  '2023-07-21',
#  '2023-07-20',
#  '2023-07-18',
#  '2023-07-14',
#  '2023-07-13',
#  '2023-07-12',
#  '2023-07-11',
#  '2023-07-10',
#  '2023-07-07',
#  '2023-07-06',
#  '2023-07-05',
#  '2023-07-03',
#  '2023-06-30',
#  '2023-06-29',
#  '2023-06-28',
#  '2023-06-27',
#  '2023-06-26',
#  '2023-06-23',
#  '2023-06-22',
#  '2023-06-21',
#  '2023-06-20',
#  '2023-06-16',
#  '2023-06-15',
#  '2023-06-14',
#  '2023-06-13',
#  '2023-06-12',
#  '2023-06-09',
#  '2023-06-08',
#  '2023-06-07',
#  '2023-06-06',
#  '2023-06-05',
#  '2023-06-02',
#  '2023-06-01',
#  '2023-05-31',
#  '2023-05-30',
#  '2023-05-26',
#  '2023-05-25',
#  '2023-05-24',
#  '2023-05-23',
#  '2023-05-22',
#  '2023-05-19',
#  '2023-05-18',
#  '2023-05-17',
#  '2023-05-16',
#  '2023-05-15',
#  '2023-05-12',
#  '2023-05-11',
#  '2023-05-10',
#  '2023-05-09',
#  '2023-05-08',
#  '2023-05-05',
#  '2023-05-04',
#  '2023-05-03',
#  '2023-05-02',
#  '2023-05-01',
#  '2023-04-28',
#  '2023-04-27',
#  '2023-04-26',
#  '2023-04-25',
#  '2023-04-24',
#  '2023-04-21',
#  '2023-04-20',
#  '2023-04-19',
#  '2023-04-18',
#  '2023-04-17',
#  '2023-04-14',
#  '2023-04-13',
#  '2023-04-12',
#  '2023-04-11',
#  '2023-04-10',
#  '2023-04-06',
#  '2023-04-05',
#  '2023-04-04',
#  '2023-04-03',
#  '2023-03-31',
#  '2023-03-30',
#  '2023-03-29',
#  '2023-03-28',
#  '2023-03-27',
#  '2023-03-24',
#  '2023-03-23',
#  '2023-03-22',
#  '2023-03-21',
#  '2023-03-20',
#  '2023-03-17',
#  '2023-03-16',
#  '2023-03-15']

# %% [markdown]
# ### TODO: dates_NYSE_2013_2023 are not wrong, e.g. '2023-10-29' is Sunday

# %%
import pandas_market_calendars as mcal
nyse = mcal.get_calendar('NYSE')
dates_NYSE_2013_2023 = nyse.valid_days(start_date='2013-01-01', end_date='2023-11-01').strftime('%Y-%m-%d')
print(f'len(dates_NYSE_2013_2023): {len(dates_NYSE_2013_2023)}')
print(f'dates_NYSE_2013_2023[0]:  {dates_NYSE_2013_2023[0]}, dates_NYSE_2013_2023[-1]: {dates_NYSE_2013_2023[-1]}')
print(f'{dates_NYSE_2013_2023}') 

# this gives valid trading dates, what is going on ???
dates_NYSE_2013_2023.sort_values(ascending=False)
# Out:
# len(dates_NYSE_2013_2023): 2728
# dates_NYSE_2013_2023[0]:  2013-01-02, dates_NYSE_2013_2023[-1]: 2023-11-01
# Index(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-07', '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-14', '2013-01-15',
#        ...
#        '2023-10-19', '2023-10-20', '2023-10-23', '2023-10-24', '2023-10-25', '2023-10-26', '2023-10-27', '2023-10-30', '2023-10-31', '2023-11-01'], dtype='object', length=2728)
# Index(['2023-11-01', '2023-10-31', '2023-10-30', '2023-10-27', '2023-10-26', '2023-10-25', '2023-10-24', '2023-10-23', '2023-10-20', '2023-10-19',
#        ...
#        '2013-01-15', '2013-01-14', '2013-01-11', '2013-01-10', '2013-01-09', '2013-01-08', '2013-01-07', '2013-01-04', '2013-01-03', '2013-01-02'], dtype='object', length=2728)

# %%
# new_index = dates_NYSE_2013_2023.date_range(start='2023-03-15', end='2023-11-02', freq='D')
new_index = pd.Index(dates_NYSE_2013_2023)
new_index = pd.date_range(start='2023-03-15', end='2023-11-02', freq='D').sort_values(ascending=False)
print(f'new_index (len={len(new_index)}):\n{new_index}')
print(f'type(new_index): {type(new_index)}')
dates_in_NYSE = new_index.tolist()

dates_in_NYSE = [date.strftime('%Y-%m-%d') for date in dates_in_NYSE]


print(f'dates_in_NYSE (len={len(dates_in_NYSE)}):\n{dates_in_NYSE}')
# Out:
# new_index (len=233):
# DatetimeIndex(['2023-11-02', '2023-11-01', '2023-10-31', '2023-10-30', '2023-10-29', '2023-10-28', '2023-10-27', '2023-10-26', '2023-10-25', '2023-10-24',
#                ...
#                '2023-03-24', '2023-03-23', '2023-03-22', '2023-03-21', '2023-03-20', '2023-03-19', '2023-03-18', '2023-03-17', '2023-03-16', '2023-03-15'], dtype='datetime64[ns]', length=233, freq='-1D')
# type(new_index): <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# dates_in_NYSE (len=233):
# ['2023-11-02', '2023-11-01', '2023-10-31', '2023-10-30', '2023-10-29', '2023-10-28', '2023-10-27', '2023-10-26', '2023-10-25', '2023-10-24', '2023-10-23', '2023-10-22', '2023-10-21', '2023-10-20', '2023-10-19', '2023-10-18', '2023-10-17', '2023-10-16', '2023-10-15', '2023-10-14', '2023-10-13', '2023-10-12', '2023-10-11', '2023-10-10', '2023-10-09', '2023-10-08', '2023-10-07', '2023-10-06', '2023-10-05', '2023-10-04', '2023-10-03', '2023-10-02', '2023-10-01', '2023-09-30', '2023-09-29', '2023-09-28', '2023-09-27', '2023-09-26', '2023-09-25', '2023-09-24', '2023-09-23', '2023-09-22', '2023-09-21', '2023-09-20', '2023-09-19', '2023-09-18', '2023-09-17', '2023-09-16', '2023-09-15', '2023-09-14', '2023-09-13', '2023-09-12', '2023-09-11', '2023-09-10', '2023-09-09', '2023-09-08', '2023-09-07', '2023-09-06', '2023-09-05', '2023-09-04', '2023-09-03', '2023-09-02', '2023-09-01', '2023-08-31', '2023-08-30', '2023-08-29', '2023-08-28', '2023-08-27', '2023-08-26', '2023-08-25', '2023-08-24', '2023-08-23', '2023-08-22', '2023-08-21', '2023-08-20', '2023-08-19', '2023-08-18', '2023-08-17', '2023-08-16', '2023-08-15', '2023-08-14', '2023-08-13', '2023-08-12', '2023-08-11', '2023-08-10', '2023-08-09', '2023-08-08', '2023-08-07', '2023-08-06', '2023-08-05', '2023-08-04', '2023-08-03', '2023-08-02', '2023-08-01', '2023-07-31', '2023-07-30', '2023-07-29', '2023-07-28', '2023-07-27', '2023-07-26', '2023-07-25', '2023-07-24', '2023-07-23', '2023-07-22', '2023-07-21', '2023-07-20', '2023-07-19', '2023-07-18', '2023-07-17', '2023-07-16', '2023-07-15', '2023-07-14', '2023-07-13', '2023-07-12', '2023-07-11', '2023-07-10', '2023-07-09', '2023-07-08', '2023-07-07', '2023-07-06', '2023-07-05', '2023-07-04', '2023-07-03', '2023-07-02', '2023-07-01', '2023-06-30', '2023-06-29', '2023-06-28', '2023-06-27', '2023-06-26', '2023-06-25', '2023-06-24', '2023-06-23', '2023-06-22', '2023-06-21', '2023-06-20', '2023-06-19', '2023-06-18', '2023-06-17', '2023-06-16', '2023-06-15', '2023-06-14', '2023-06-13', '2023-06-12', '2023-06-11', '2023-06-10', '2023-06-09', '2023-06-08', '2023-06-07', '2023-06-06', '2023-06-05', '2023-06-04', '2023-06-03', '2023-06-02', '2023-06-01', '2023-05-31', '2023-05-30', '2023-05-29', '2023-05-28', '2023-05-27', '2023-05-26', '2023-05-25', '2023-05-24', '2023-05-23', '2023-05-22', '2023-05-21', '2023-05-20', '2023-05-19', '2023-05-18', '2023-05-17', '2023-05-16', '2023-05-15', '2023-05-14', '2023-05-13', '2023-05-12', '2023-05-11', '2023-05-10', '2023-05-09', '2023-05-08', '2023-05-07', '2023-05-06', '2023-05-05', '2023-05-04', '2023-05-03', '2023-05-02', '2023-05-01', '2023-04-30', '2023-04-29', '2023-04-28', '2023-04-27', '2023-04-26', '2023-04-25', '2023-04-24', '2023-04-23', '2023-04-22', '2023-04-21', '2023-04-20', '2023-04-19', '2023-04-18', '2023-04-17', '2023-04-16', '2023-04-15', '2023-04-14', '2023-04-13', '2023-04-12', '2023-04-11', '2023-04-10', '2023-04-09', '2023-04-08', '2023-04-07', '2023-04-06', '2023-04-05', '2023-04-04', '2023-04-03', '2023-04-02', '2023-04-01', '2023-03-31', '2023-03-30', '2023-03-29', '2023-03-28', '2023-03-27', '2023-03-26', '2023-03-25', '2023-03-24', '2023-03-23', '2023-03-22', '2023-03-21', '2023-03-20', '2023-03-19', '2023-03-18', '2023-03-17', '2023-03-16', '2023-03-15']

# %%
def compare_lists(list_a, list_b):
  """Compares two lists and returns a list of values that are in list A but not in list B.

  Args:
    list_a: A list of objects.
    list_b: A list of objects.

  Returns:
    A list of values that are in list A but not in list B.
  """

  list_difference = []

  for item in list_a:
    if item not in list_b:
      list_difference.append(item)

  return list_difference

# %%
dates_missing_in_df = compare_lists(dates_in_NYSE, dates_in_df)
len(dates_missing_in_df)
print(f'dates_missing_in_df (len={len(dates_missing_in_df)}):\n{dates_missing_in_df}')
# Out:
# dates_missing_in_df (len=97):
# ['2023-10-29', '2023-10-28', '2023-10-22', '2023-10-21', '2023-10-18', '2023-10-16', '2023-10-15', '2023-10-14', '2023-10-13', '2023-10-11', '2023-10-10', '2023-10-09', '2023-10-08', '2023-10-07', '2023-10-03', '2023-10-01', '2023-09-30', '2023-09-27', '2023-09-26', '2023-09-24', '2023-09-23', '2023-09-19', '2023-09-17', '2023-09-16', '2023-09-10', '2023-09-09', '2023-09-07', '2023-09-06', '2023-09-04', '2023-09-03', '2023-09-02', '2023-08-31', '2023-08-30', '2023-08-29', '2023-08-28', '2023-08-27', '2023-08-26', '2023-08-24', '2023-08-23', '2023-08-22', '2023-08-21', '2023-08-20', '2023-08-19', '2023-08-16', '2023-08-13', '2023-08-12', '2023-08-06', '2023-08-05', '2023-07-31', '2023-07-30', '2023-07-29', '2023-07-28', '2023-07-24', '2023-07-23', '2023-07-22', '2023-07-19', '2023-07-17', '2023-07-16', '2023-07-15', '2023-07-09', '2023-07-08', '2023-07-04', '2023-07-02', '2023-07-01', '2023-06-25', '2023-06-24', '2023-06-19', '2023-06-18', '2023-06-17', '2023-06-11', '2023-06-10', '2023-06-04', '2023-06-03', '2023-05-29', '2023-05-28', '2023-05-27', '2023-05-21', '2023-05-20', '2023-05-14', '2023-05-13', '2023-05-07', '2023-05-06', '2023-04-30', '2023-04-29', '2023-04-23', '2023-04-22', '2023-04-16', '2023-04-15', '2023-04-09', '2023-04-08', '2023-04-07', '2023-04-02', '2023-04-01', '2023-03-26', '2023-03-25', '2023-03-19', '2023-03-18']

# %% [markdown]
# TODO: In above code, dates in dates_in_df_deduped should be the same as dates in new_index, so there are missing dates

# %%
# print(df.date_end_df_train)
print(type(df.date_end_df_train))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(len(picks))
picks
# Out:
# 816
# [(0, []),
#  (1, ['FTSM', 'SHV']),
#  (2, ['ANF']),
#  (3, []),
#  (4, ['FTSM']),
#  (5, ['ANF']),
#  (6, []),
#  (7, ['FTSM']),
#  (8, ['ANF']),
#  (9, []),
#  (10, ['LRN']),
#  (11, ['ANF']),
#  (12, []),
#  (13, ['SHV']),
#  (14, ['ANF', 'SPLK']),
#  (15, ['SHV']),
#  (16, ['LRN']),
#  (17, ['ANF', 'SPLK']),
#  (18, []),
#  (19, ['FTSM', 'SHV']),
#  (20, ['SPLK']),
#  (21, ['FTSM', 'SHV']),
#  (22, ['LRN']),
#  (23, ['SPLK']),
#  (24, []),
#  (25, ['FTSM', 'SHV']),
#  (26, ['SPLK']),
#  (27, ['SHV']),
#  (28, ['LRN']),
#  (29, ['SPLK']),
#  (30, []),
#  (31, ['FTSM', 'SHV']),
#  (32, ['SPLK']),
#  (33, []),
#  (34, []),
#  (35, ['LRN', 'SPLK']),
#  (36, []),
#  (37, ['FTSM', 'SHV']),
#  (38, ['ANF', 'SPLK']),
#  (39, []),
#  (40, []),
#  (41, ['ANF', 'SPLK']),
#  (42, []),
#  (43, ['FTSM', 'SHV']),
#  (44, ['ANF']),
#  (45, []),
#  (46, []),
#  (47, ['ANF']),
#  (48, []),
#  (49, ['FTSM', 'SHV']),
#  (50, ['SPLK']),
#  (51, []),
#  (52, []),
#  (53, ['SPLK']),
#  (54, []),
#  (55, ['FTSM', 'SHV']),
#  (56, []),
#  (57, []),
#  (58, []),
#  (59, ['PGR', 'USAC']),
#  (60, []),
#  (61, ['FTSM', 'SHV']),
#  (62, []),
#  (63, ['SHV']),
#  (64, ['PGR', 'USAC']),
#  (65, []),
#  (66, []),
#  (67, ['FTSM', 'SHV']),
#  (68, []),
#  (69, []),
#  (70, []),
#  (71, ['CLS', 'PGR']),
#  (72, []),
#  (73, ['FTSM', 'SHV']),
#  (74, []),
#  (75, []),
#  (76, ['ICPT']),
#  (77, ['ANF', 'CLS']),
#  (78, []),
#  (79, ['FTSM', 'SHV']),
#  (80, []),
#  (81, ['SHV']),
#  (82, []),
#  (83, ['ICPT']),
#  (84, []),
#  (85, ['FTSM', 'SHV']),
#  (86, []),
#  (87, ['FTSM', 'SHV']),
#  (88, ['CLS']),
#  (89, ['ICPT', 'SPLK']),
#  (90, []),
#  (91, ['FTSM', 'SHV']),
#  (92, []),
#  (93, ['FTSM', 'SHV']),
#  (94, ['ICPT']),
#  (95, ['MLKN']),
#  (96, []),
#  (97, ['FTSM']),
#  (98, ['ANF']),
#  (99, ['FTSM']),
#  (100, ['ANF']),
#  (101, ['ICPT']),
#  (102, []),
#  (103, ['FTSM', 'SHV']),
#  (104, []),
#  (105, ['SHV']),
#  (106, ['ARCH']),
#  (107, ['ICPT', 'NGS']),
#  (108, []),
#  (109, ['FTSM', 'SHV']),
#  (110, ['CCJ']),
#  (111, ['SHV']),
#  (112, ['ARCH']),
#  (113, ['CCJ', 'USAC']),
#  (114, []),
#  (115, ['FTSM', 'SHV']),
#  (116, []),
#  (117, []),
#  (118, []),
#  (119, ['ARCH', 'CCJ']),
#  (120, []),
#  (121, ['FTSM', 'SHV']),
#  (122, []),
#  (123, ['FTSM', 'SHV']),
#  (124, []),
#  (125, []),
#  (126, []),
#  (127, ['FTSM', 'SHV']),
#  (128, []),
#  (129, ['FTSM', 'SHV']),
#  (130, []),
#  (131, []),
#  (132, []),
#  (133, ['FTSM', 'SHV']),
#  (134, []),
#  (135, ['SHV']),
#  (136, ['DELL']),
#  (137, []),
#  (138, []),
#  (139, ['SHV']),
#  (140, ['FTSM']),
#  (141, []),
#  (142, ['DELL']),
#  (143, []),
#  (144, []),
#  (145, ['FTSM', 'SHV']),
#  (146, []),
#  (147, []),
#  (148, []),
#  (149, []),
#  (150, []),
#  (151, ['SHV']),
#  (152, ['DELL', 'FTSM']),
#  (153, []),
#  (154, []),
#  (155, ['FTSM']),
#  (156, []),
#  (157, ['FTSM', 'SHV']),
#  (158, ['DELL']),
#  (159, []),
#  (160, ['FTSM']),
#  (161, []),
#  (162, []),
#  (163, ['FTSM', 'SHV']),
#  (164, ['DELL', 'MMYT']),
#  (165, []),
#  (166, ['ANF', 'FTSM']),
#  (167, ['FTI', 'MMYT']),
#  (168, []),
#  (169, ['DELL', 'FTSM', 'SHV']),
#  (170, []),
#  (171, ['DELL']),
#  (172, ['ANF', 'FTSM']),
#  (173, []),
#  (174, []),
#  (175, ['FTSM', 'SHV']),
#  (176, ['DELL', 'STRL']),
#  (177, []),
#  (178, ['ANF', 'FTSM']),
#  (179, ['CELH', 'STRL']),
#  (180, []),
#  (181, ['SHV']),
#  (182, ['FTSM']),
#  (183, []),
#  (184, ['FTSM']),
#  (185, []),
#  (186, []),
#  (187, ['SHV']),
#  (188, ['FTSM', 'STRL']),
#  (189, []),
#  (190, ['ANF', 'DELL', 'FTSM']),
#  (191, ['STRL', 'TDS']),
#  (192, []),
#  (193, ['SHV']),
#  (194, ['STRL']),
#  (195, ['SHV']),
#  (196, ['ANF', 'TDS']),
#  (197, ['FTSM', 'LLY']),
#  (198, []),
#  (199, ['SHV']),
#  (200, ['FTSM']),
#  (201, ['SHV']),
#  (202, ['CNX', 'STRL', 'TDS']),
#  (203, []),
#  (204, []),
#  (205, ['SHV']),
#  (206, ['FTSM']),
#  (207, ['SHV']),
#  (208, ['CNX', 'TDS']),
#  (209, []),
#  (210, []),
#  (211, ['SHV']),
#  (212, ['STRL']),
#  (213, ['SHV']),
#  (214, ['TDS']),
#  (215, []),
#  (216, []),
#  (217, ['SHV']),
#  (218, []),
#  (219, []),
#  (220, ['TDS']),
#  (221, ['CLS', 'EME']),
#  (222, []),
#  (223, []),
#  (224, ['SHV', 'STRL']),
#  (225, []),
#  (226, ['TDS']),
#  (227, []),
#  (228, []),
#  (229, []),
#  (230, ['SHV', 'STRL']),
#  (231, []),
#  (232, ['LOB', 'TDS']),
#  (233, []),
#  (234, []),
#  (235, []),
#  (236, ['SHV', 'STRL']),
#  (237, []),
#  (238, ['LOB', 'TDS']),
#  (239, []),
#  (240, []),
#  (241, []),
#  (242, ['SHV', 'STRL']),
#  (243, []),
#  (244, ['TDS']),
#  (245, []),
#  (246, []),
#  (247, []),
#  (248, ['SHV']),
#  (249, []),
#  (250, []),
#  (251, ['LOB']),
#  (252, []),
#  (253, []),
#  (254, ['SHV']),
#  (255, []),
#  (256, []),
#  (257, ['LOB']),
#  (258, []),
#  (259, []),
#  (260, ['SHV']),
#  (261, []),
#  (262, []),
#  (263, ['LOB']),
#  (264, []),
#  (265, []),
#  (266, ['SHV']),
#  (267, []),
#  (268, ['LOB']),
#  (269, []),
#  (270, []),
#  (271, []),
#  (272, []),
#  (273, []),
#  (274, ['LOB']),
#  (275, ['SMCI']),
#  (276, []),
#  (277, []),
#  (278, ['SHV']),
#  (279, []),
#  (280, ['JOE']),
#  (281, []),
#  (282, []),
#  (283, []),
#  (284, ['SHV']),
#  (285, []),
#  (286, []),
#  (287, []),
#  (288, []),
#  (289, []),
#  (290, ['SHV']),
#  (291, []),
#  (292, []),
#  (293, []),
#  (294, []),
#  (295, []),
#  (296, ['SHV']),
#  (297, []),
#  (298, ['SHV', 'SIRI']),
#  (299, []),
#  (300, []),
#  (301, []),
#  (302, ['SHV']),
#  (303, []),
#  (304, ['SHV', 'SIRI']),
#  (305, []),
#  (306, []),
#  (307, []),
#  (308, ['SHV']),
#  (309, []),
#  (310, ['SHV']),
#  (311, ['BCC']),
#  (312, []),
#  (313, []),
#  (314, ['SHV']),
#  (315, []),
#  (316, ['SHV']),
#  (317, ['BCC']),
#  (318, []),
#  (319, []),
#  (320, ['SHV', 'SKYW']),
#  (321, []),
#  (322, ['SHV']),
#  (323, ['BCC', 'SKYW']),
#  (324, []),
#  (325, []),
#  (326, ['SHV', 'SKYW']),
#  (327, []),
#  (328, ['SHV']),
#  (329, ['BZH', 'SKYW']),
#  (330, []),
#  (331, []),
#  (332, ['SHV', 'SKYW']),
#  (333, []),
#  (334, []),
#  (335, ['SKYW']),
#  (336, []),
#  (337, []),
#  (338, ['SHV', 'SKYW']),
#  (339, []),
#  (340, []),
#  (341, ['SKYW']),
#  (342, []),
#  (343, []),
#  (344, ['SHV', 'SKYW']),
#  (345, []),
#  (346, []),
#  (347, ['SKYW']),
#  (348, []),
#  (349, []),
#  (350, ['SHV', 'SKYW']),
#  (351, []),
#  (352, []),
#  (353, ['CCL', 'SKYW']),
#  (354, []),
#  (355, []),
#  (356, ['SHV']),
#  (357, []),
#  (358, []),
#  (359, ['CCL']),
#  (360, []),
#  (361, []),
#  (362, ['SHV']),
#  (363, []),
#  (364, []),
#  (365, ['CCL', 'SKYW', 'W']),
#  (366, []),
#  (367, []),
#  (368, ['SHV']),
#  (369, []),
#  (370, ['SKYW']),
#  (371, ['CCL']),
#  (372, []),
#  (373, []),
#  (374, ['SHV', 'SKYW']),
#  (375, []),
#  (376, []),
#  (377, []),
#  (378, []),
#  (379, []),
#  (380, ['SHV', 'SKYW']),
#  (381, []),
#  (382, []),
#  (383, []),
#  (384, []),
#  (385, []),
#  (386, ['SHV', 'SKYW']),
#  (387, []),
#  (388, []),
#  (389, []),
#  (390, []),
#  (391, []),
#  (392, ['SHV', 'SKYW']),
#  (393, []),
#  (394, []),
#  (395, []),
#  (396, []),
#  (397, ['NVDA']),
#  (398, ['SHV', 'SKYW']),
#  (399, []),
#  (400, ['CCL', 'NVDA']),
#  (401, ['AMPH']),
#  (402, []),
#  (403, ['NVDA']),
#  (404, ['SHV', 'SKYW']),
#  (405, []),
#  (406, ['NVDA']),
#  (407, ['AMPH', 'PBR']),
#  (408, []),
#  (409, ['NVDA']),
#  (410, ['SHV']),
#  (411, []),
#  (412, ['NVDA']),
#  (413, []),
#  (414, []),
#  (415, ['NVDA']),
#  (416, ['SHV']),
#  (417, []),
#  (418, ['NVDA']),
#  (419, []),
#  (420, []),
#  (421, []),
#  (422, ['NVDA', 'SHV']),
#  (423, []),
#  (424, ['SKYW']),
#  (425, ['NVDA']),
#  (426, []),
#  (427, []),
#  (428, ['NVDA', 'SHV']),
#  (429, []),
#  (430, []),
#  (431, ['CCL', 'NVDA', 'SKYW']),
#  (432, []),
#  (433, []),
#  (434, ['AVGO', 'NVDA', 'SHV']),
#  (435, []),
#  (436, ['AVGO']),
#  (437, ['ORCL', 'SKYW']),
#  (438, []),
#  (439, []),
#  (440, ['SHV']),
#  (441, []),
#  (442, []),
#  (443, ['SKYW']),
#  (444, []),
#  (445, []),
#  (446, ['SHV']),
#  (447, []),
#  (448, []),
#  (449, ['SKYW']),
#  (450, []),
#  (451, []),
#  (452, ['NVDA', 'SHV']),
#  (453, []),
#  (454, []),
#  (455, ['NVDA']),
#  (456, []),
#  (457, []),
#  (458, ['NVDA', 'SHV']),
#  (459, []),
#  (460, []),
#  (461, ['NVDA']),
#  (462, []),
#  (463, []),
#  (464, ['SHV']),
#  (465, []),
#  (466, []),
#  (467, []),
#  (468, []),
#  (469, []),
#  (470, ['NVDA', 'SHV']),
#  (471, []),
#  (472, ['NVDA']),
#  (473, []),
#  (474, []),
#  (475, []),
#  (476, ['NVDA', 'SHV']),
#  (477, []),
#  (478, []),
#  (479, ['META', 'SKYW']),
#  (480, []),
#  (481, []),
#  (482, ['NVDA', 'SHV']),
#  (483, []),
#  (484, ['META']),
#  (485, []),
#  (486, []),
#  (487, []),
#  (488, ['META', 'NVDA']),
#  (489, []),
#  (490, ['AVGO', 'RMBS']),
#  (491, []),
#  (492, []),
#  (493, ['SHV']),
#  (494, ['AVGO', 'NVDA']),
#  (495, []),
#  (496, []),
#  (497, ['RMBS']),
#  (498, []),
#  (499, ['SHV']),
#  (500, ['AVGO', 'NVDA']),
#  (501, []),
#  (502, []),
#  (503, []),
#  (504, []),
#  (505, ['AVGO', 'SHV']),
#  (506, ['NVDA']),
#  (507, ['AVGO']),
#  (508, ['RMBS']),
#  (509, ['AMD']),
#  (510, []),
#  (511, ['SHV']),
#  (512, ['FTSM', 'NVDA']),
#  (513, []),
#  (514, []),
#  (515, ['FTSM']),
#  (516, []),
#  (517, ['SHV']),
#  (518, []),
#  (519, []),
#  (520, []),
#  (521, []),
#  (522, []),
#  (523, ['SHV']),
#  (524, []),
#  (525, []),
#  (526, []),
#  (527, []),
#  (528, []),
#  (529, ['SHV']),
#  (530, []),
#  (531, []),
#  (532, []),
#  (533, []),
#  (534, []),
#  (535, []),
#  (536, ['SHV']),
#  (537, []),
#  (538, ['SHV']),
#  (539, []),
#  (540, []),
#  (541, []),
#  (542, ['SHV', 'TMHC']),
#  (543, []),
#  (544, ['SHV']),
#  (545, ['TMHC']),
#  (546, []),
#  (547, []),
#  (548, ['SHV']),
#  (549, []),
#  (550, ['SHV']),
#  (551, []),
#  (552, []),
#  (553, []),
#  (554, ['SHV']),
#  (555, []),
#  (556, ['SHV']),
#  (557, []),
#  (558, []),
#  (559, ['SHV']),
#  (560, []),
#  (561, []),
#  (562, []),
#  (563, ['ISEE']),
#  (564, []),
#  (565, []),
#  (566, ['SHV']),
#  (567, []),
#  (568, ['ISEE', 'SHV']),
#  (569, []),
#  (570, []),
#  (571, []),
#  (572, ['ISEE', 'SHV']),
#  (573, []),
#  (574, ['BLDR']),
#  (575, []),
#  (576, []),
#  (577, []),
#  (578, ['ISEE', 'SHV']),
#  (579, []),
#  (580, ['SHV']),
#  (581, ['BLDR']),
#  (582, []),
#  (583, []),
#  (584, ['ISEE', 'SHV']),
#  (585, []),
#  (586, ['BLDR']),
#  (587, []),
#  (588, []),
#  (589, []),
#  (590, ['ISEE', 'SHV']),
#  (591, []),
#  (592, []),
#  (593, []),
#  (594, []),
#  (595, []),
#  (596, ['ISEE', 'SHV']),
#  (597, []),
#  (598, []),
#  (599, []),
#  (600, []),
#  (601, []),
#  (602, ['SHV']),
#  (603, []),
#  (604, ['CCEP']),
#  (605, []),
#  (606, []),
#  (607, []),
#  (608, ['SHV']),
#  (609, []),
#  (610, ['ISEE']),
#  (611, ['CCEP', 'SHV', 'SKYW']),
#  (612, []),
#  (613, []),
#  (614, ['SHV']),
#  (615, []),
#  (616, ['CCEP', 'ISEE', 'SHV']),
#  (617, []),
#  (618, []),
#  (619, []),
#  (620, []),
#  (621, []),
#  (622, []),
#  (623, ['ISEE']),
#  (624, []),
#  (625, []),
#  (626, []),
#  (627, []),
#  (628, []),
#  (629, ['PHM', 'SHV']),
#  (630, []),
#  (631, []),
#  (632, []),
#  (633, []),
#  (634, []),
#  (635, ['PHM', 'SHV']),
#  (636, []),
#  (637, []),
#  (638, ['ELF']),
#  (639, []),
#  (640, ['ELF']),
#  (641, ['SHV']),
#  (642, []),
#  (643, []),
#  (644, ['ELF', 'SHV']),
#  (645, []),
#  (646, ['SHV']),
#  (647, ['ELF']),
#  (648, []),
#  (649, []),
#  (650, ['ELF']),
#  (651, []),
#  (652, ['ELF']),
#  (653, ['SHV']),
#  (654, []),
#  (655, []),
#  (656, ['ELF']),
#  (657, []),
#  (658, ['ELF']),
#  (659, ['SHV']),
#  (660, []),
#  (661, []),
#  (662, ['ELF']),
#  (663, []),
#  (664, []),
#  (665, ['SHV']),
#  (666, []),
#  (667, []),
#  (668, ['SHV']),
#  (669, []),
#  (670, ['SHV']),
#  (671, []),
#  (672, []),
#  (673, []),
#  (674, ['SHV']),
#  (675, []),
#  (676, []),
#  (677, ['SHV']),
#  (678, []),
#  (679, []),
#  (680, ['ELF', 'SHV']),
#  (681, []),
#  (682, []),
#  (683, ['ELF', 'SHV']),
#  (684, []),
#  (685, []),
#  (686, ['SHV']),
#  (687, []),
#  (688, []),
#  (689, ['SHV']),
#  (690, []),
#  (691, []),
#  (692, ['SHV']),
#  (693, []),
#  (694, ['SHV']),
#  (695, []),
#  (696, []),
#  (697, []),
#  (698, ['SHV']),
#  (699, []),
#  (700, ['SHV']),
#  (701, []),
#  (702, []),
#  (703, []),
#  (704, ['SHV']),
#  (705, []),
#  (706, ['SHV']),
#  (707, []),
#  (708, []),
#  (709, []),
#  (710, ['SHV']),
#  (711, []),
#  (712, ['SHV']),
#  (713, []),
#  (714, []),
#  (715, []),
#  (716, ['SHV']),
#  (717, []),
#  (718, []),
#  (719, ['SHV']),
#  (720, []),
#  (721, ['SHV']),
#  (722, []),
#  (723, []),
#  (724, ['SHV']),
#  (725, []),
#  (726, []),
#  (727, []),
#  (728, ['NVDA', 'SHV']),
#  (729, []),
#  (730, []),
#  (731, ['NVDA', 'SHV']),
#  (732, []),
#  (733, []),
#  (734, ['GE', 'NVDA']),
#  (735, []),
#  (736, []),
#  (737, ['GE', 'PERI']),
#  (738, []),
#  (739, []),
#  (740, ['NVDA']),
#  (741, []),
#  (742, []),
#  (743, []),
#  (744, []),
#  (745, ['SHV']),
#  (746, ['NVDA']),
#  (747, []),
#  (748, ['SHV']),
#  (749, []),
#  (750, []),
#  (751, ['SHV']),
#  (752, []),
#  (753, []),
#  (754, ['SHV']),
#  (755, ['SGEN']),
#  (756, []),
#  (757, ['SHV']),
#  (758, []),
#  (759, []),
#  (760, []),
#  (761, ['SGEN']),
#  (762, []),
#  (763, ['SHV']),
#  (764, ['GE']),
#  (765, []),
#  (766, []),
#  (767, ['GE', 'NVDA', 'SGEN']),
#  (768, []),
#  (769, []),
#  (770, ['NVDA', 'SHV']),
#  (771, []),
#  (772, ['SHV']),
#  (773, ['SGEN']),
#  (774, []),
#  (775, ['SHV']),
#  (776, []),
#  (777, []),
#  (778, ['NVDA']),
#  (779, ['FTSM', 'GE']),
#  (780, []),
#  (781, ['SHV']),
#  (782, ['FTSM']),
#  (783, []),
#  (784, ['FTSM', 'NVDA']),
#  (785, ['SGEN']),
#  (786, []),
#  (787, ['SHV']),
#  (788, ['GE']),
#  (789, []),
#  (790, ['GE']),
#  (791, []),
#  (792, []),
#  (793, ['FTSM', 'SHV']),
#  (794, []),
#  (795, []),
#  (796, []),
#  (797, []),
#  (798, []),
#  (799, ['FTSM', 'SHV']),
#  (800, ['GE']),
#  (801, []),
#  (802, ['FTSM', 'GE']),
#  (803, []),
#  (804, []),
#  (805, ['FTSM', 'SHV']),
#  (806, []),
#  (807, []),
#  (808, ['SGEN']),
#  (809, []),
#  (810, []),
#  (811, ['FTSM', 'SHV']),
#  (812, []),
#  (813, []),
#  (814, ['SGEN']),
#  (815, ['AMPH', 'FCN'])]

# %%
print(len(d_lbk_freq))
d_lbk_freq
# Out:
# 816
# [('2023-11-02', [30, 60, 120], 'sym_freq_12'),
#  ('2023-11-02', [30, 60, 120], 'sym_freq_9'),
#  ('2023-11-02', [30, 60, 120], 'sym_freq_8'),
#  ('2023-11-02', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-11-02', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-11-02', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-11-01', [30, 60, 120], 'sym_freq_12'),
#  ('2023-11-01', [30, 60, 120], 'sym_freq_9'),
#  ('2023-11-01', [30, 60, 120], 'sym_freq_8'),
#  ('2023-11-01', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-11-01', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-11-01', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-31', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-31', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-31', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-31', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-31', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-31', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-30', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-30', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-30', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-30', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-30', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-30', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-27', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-27', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-27', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-27', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-27', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-27', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-26', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-26', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-26', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-26', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-26', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-26', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-25', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-25', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-25', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-25', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-25', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-25', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-24', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-24', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-24', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-24', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-24', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-24', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-23', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-23', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-23', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-23', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-23', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-23', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-20', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-20', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-20', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-20', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-20', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-20', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-19', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-19', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-19', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-19', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-19', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-19', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-17', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-17', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-17', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-17', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-17', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-17', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-12', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-12', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-12', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-12', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-12', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-12', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-06', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-06', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-06', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-06', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-06', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-06', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-05', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-05', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-05', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-05', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-05', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-05', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-04', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-04', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-04', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-04', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-04', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-04', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-10-02', [30, 60, 120], 'sym_freq_12'),
#  ('2023-10-02', [30, 60, 120], 'sym_freq_9'),
#  ('2023-10-02', [30, 60, 120], 'sym_freq_8'),
#  ('2023-10-02', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-10-02', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-10-02', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-29', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-29', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-29', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-29', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-29', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-29', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-28', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-28', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-28', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-28', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-28', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-28', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-25', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-25', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-25', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-25', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-25', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-25', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-22', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-22', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-22', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-22', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-22', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-22', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-21', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-21', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-21', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-21', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-21', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-21', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-20', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-20', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-20', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-20', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-20', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-20', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-18', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-18', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-18', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-18', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-18', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-18', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-15', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-15', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-15', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-15', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-15', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-15', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-14', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-14', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-14', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-14', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-14', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-14', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-13', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-13', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-13', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-13', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-13', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-13', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-12', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-12', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-12', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-12', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-12', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-12', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-11', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-11', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-11', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-11', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-11', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-11', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-08', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-08', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-08', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-08', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-08', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-08', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-05', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-05', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-05', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-05', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-05', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-05', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-09-01', [30, 60, 120], 'sym_freq_12'),
#  ('2023-09-01', [30, 60, 120], 'sym_freq_9'),
#  ('2023-09-01', [30, 60, 120], 'sym_freq_8'),
#  ('2023-09-01', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-09-01', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-09-01', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-25', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-25', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-25', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-25', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-25', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-25', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-18', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-18', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-18', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-18', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-18', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-18', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-17', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-17', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-17', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-17', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-17', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-17', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-15', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-15', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-15', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-15', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-15', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-15', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-14', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-14', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-14', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-14', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-14', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-14', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-11', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-11', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-11', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-11', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-11', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-11', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-10', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-10', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-10', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-10', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-10', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-10', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-09', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-09', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-09', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-09', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-09', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-09', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-08', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-08', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-08', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-08', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-08', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-08', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-07', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-07', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-07', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-07', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-07', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-07', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-04', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-04', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-04', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-04', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-04', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-04', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-03', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-03', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-03', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-03', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-03', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-03', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-02', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-02', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-02', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-02', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-02', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-02', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-08-01', [30, 60, 120], 'sym_freq_12'),
#  ('2023-08-01', [30, 60, 120], 'sym_freq_9'),
#  ('2023-08-01', [30, 60, 120], 'sym_freq_8'),
#  ('2023-08-01', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-08-01', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-08-01', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-27', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-27', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-27', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-27', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-27', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-27', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-26', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-26', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-26', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-26', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-26', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-26', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-25', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-25', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-25', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-25', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-25', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-25', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-21', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-21', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-21', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-21', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-21', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-21', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-20', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-20', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-20', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-20', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-20', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-20', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-18', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-18', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-18', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-18', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-18', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-18', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-14', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-14', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-14', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-14', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-14', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-14', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-13', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-13', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-13', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-13', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-13', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-13', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-12', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-12', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-12', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-12', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-12', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-12', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-11', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-11', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-11', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-11', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-11', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-11', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-10', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-10', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-10', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-10', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-10', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-10', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-07', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-07', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-07', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-07', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-07', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-07', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-06', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-06', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-06', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-06', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-06', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-06', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-05', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-05', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-05', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-05', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-05', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-05', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-07-03', [30, 60, 120], 'sym_freq_12'),
#  ('2023-07-03', [30, 60, 120], 'sym_freq_9'),
#  ('2023-07-03', [30, 60, 120], 'sym_freq_8'),
#  ('2023-07-03', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-07-03', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-07-03', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-30', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-30', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-30', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-30', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-30', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-30', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-29', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-29', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-29', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-29', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-29', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-29', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-28', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-28', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-28', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-28', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-28', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-28', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-27', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-27', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-27', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-27', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-27', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-27', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-26', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-26', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-26', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-26', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-26', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-26', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-23', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-23', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-23', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-23', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-23', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-23', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-22', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-22', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-22', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-22', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-22', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-22', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-21', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-21', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-21', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-21', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-21', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-21', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-20', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-20', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-20', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-20', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-20', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-20', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-16', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-16', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-16', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-16', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-16', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-16', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-15', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-15', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-15', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-15', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-15', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-15', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-14', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-14', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-14', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-14', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-14', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-14', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-13', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-13', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-13', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-13', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-13', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-13', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-12', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-12', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-12', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-12', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-12', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-12', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-09', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-09', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-09', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-09', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-09', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-09', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-08', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-08', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-08', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-08', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-08', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-08', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-07', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-07', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-07', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-07', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-07', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-07', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-06', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-06', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-06', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-06', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-06', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-06', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-05', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-05', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-05', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-05', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-05', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-05', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-02', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-02', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-02', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-02', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-02', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-02', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-06-01', [30, 60, 120], 'sym_freq_12'),
#  ('2023-06-01', [30, 60, 120], 'sym_freq_9'),
#  ('2023-06-01', [30, 60, 120], 'sym_freq_8'),
#  ('2023-06-01', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-06-01', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-06-01', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-31', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-31', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-31', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-31', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-31', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-31', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-30', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-30', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-30', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-30', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-30', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-30', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-26', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-26', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-26', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-26', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-26', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-26', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-25', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-25', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-25', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-25', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-25', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-25', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-24', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-24', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-24', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-24', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-24', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-24', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-23', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-23', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-23', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-23', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-23', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-23', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-22', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-22', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-22', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-22', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-22', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-22', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-19', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-19', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-19', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-19', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-19', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-19', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-18', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-18', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-18', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-18', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-18', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-18', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-17', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-17', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-17', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-17', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-17', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-17', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-16', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-16', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-16', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-16', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-16', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-16', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-15', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-15', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-15', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-15', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-15', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-15', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-12', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-12', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-12', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-12', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-12', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-12', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-11', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-11', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-11', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-11', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-11', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-11', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-10', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-10', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-10', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-10', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-10', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-10', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-09', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-09', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-09', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-09', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-09', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-09', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-08', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-08', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-08', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-08', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-08', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-08', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-05', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-05', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-05', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-05', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-05', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-05', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-04', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-04', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-04', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-04', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-04', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-04', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-03', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-03', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-03', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-03', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-03', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-03', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-02', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-02', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-02', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-02', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-02', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-02', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-05-01', [30, 60, 120], 'sym_freq_12'),
#  ('2023-05-01', [30, 60, 120], 'sym_freq_9'),
#  ('2023-05-01', [30, 60, 120], 'sym_freq_8'),
#  ('2023-05-01', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-05-01', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-05-01', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-28', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-28', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-28', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-28', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-28', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-28', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-27', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-27', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-27', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-27', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-27', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-27', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-26', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-26', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-26', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-26', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-26', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-26', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-25', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-25', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-25', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-25', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-25', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-25', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-24', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-24', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-24', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-24', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-24', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-24', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-21', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-21', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-21', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-21', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-21', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-21', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-20', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-20', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-20', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-20', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-20', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-20', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-19', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-19', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-19', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-19', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-19', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-19', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-18', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-18', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-18', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-18', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-18', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-18', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-17', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-17', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-17', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-17', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-17', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-17', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-14', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-14', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-14', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-14', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-14', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-14', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-13', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-13', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-13', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-13', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-13', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-13', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-12', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-12', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-12', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-12', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-12', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-12', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-11', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-11', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-11', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-11', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-11', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-11', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-10', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-10', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-10', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-10', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-10', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-10', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-06', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-06', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-06', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-06', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-06', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-06', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-05', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-05', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-05', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-05', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-05', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-05', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-04', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-04', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-04', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-04', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-04', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-04', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-04-03', [30, 60, 120], 'sym_freq_12'),
#  ('2023-04-03', [30, 60, 120], 'sym_freq_9'),
#  ('2023-04-03', [30, 60, 120], 'sym_freq_8'),
#  ('2023-04-03', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-04-03', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-04-03', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-31', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-31', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-31', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-31', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-31', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-31', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-30', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-30', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-30', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-30', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-30', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-30', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-29', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-29', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-29', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-29', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-29', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-29', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-28', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-28', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-28', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-28', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-28', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-28', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-27', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-27', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-27', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-27', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-27', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-27', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-24', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-24', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-24', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-24', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-24', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-24', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-23', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-23', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-23', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-23', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-23', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-23', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-22', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-22', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-22', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-22', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-22', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-22', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-21', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-21', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-21', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-21', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-21', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-21', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-20', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-20', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-20', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-20', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-20', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-20', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-17', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-17', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-17', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-17', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-17', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-17', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-16', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-16', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-16', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-16', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-16', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-16', [15, 30, 60, 120], 'sym_freq_8'),
#  ('2023-03-15', [30, 60, 120], 'sym_freq_12'),
#  ('2023-03-15', [30, 60, 120], 'sym_freq_9'),
#  ('2023-03-15', [30, 60, 120], 'sym_freq_8'),
#  ('2023-03-15', [15, 30, 60, 120], 'sym_freq_12'),
#  ('2023-03-15', [15, 30, 60, 120], 'sym_freq_9'),
#  ('2023-03-15', [15, 30, 60, 120], 'sym_freq_8')]

# %%
model_top_picks
# Out:
# [([30, 60, 120], 'sym_freq_9'),
#  ([15, 30, 60, 120], 'sym_freq_12'),
#  ([30, 60, 120], 'sym_freq_8')]

# %%
######################

# %%
df_model_top_picks = pickle_load(path_data_dump, fp_df_model_top_picks)

z_items   = zip(d_lbk_freq, picks)
for i, item in enumerate(z_items):
  _date, _days_lookback, _sym_freq, _syms = item[0][0], item[0][1], item[0][2], item[1][1]
  print(i, _date, _days_lookback, _sym_freq, _syms)
  dlb_sym_freq = (_days_lookback, _sym_freq)
  if dlb_sym_freq in model_top_picks and _syms:
    row_add = [_date, _days_lookback, _sym_freq, _syms]
    df_model_top_picks.loc[len(df_model_top_picks)] = row_add
    print(f'added row to df_model_top_picks:\n{row_add}\n')
# Out:
# 0 2023-11-02 [30, 60, 120] sym_freq_12 []
# 1 2023-11-02 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-11-02', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 2 2023-11-02 [30, 60, 120] sym_freq_8 ['ANF']
# added row to df_model_top_picks:
# ['2023-11-02', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 3 2023-11-02 [15, 30, 60, 120] sym_freq_12 []
# 4 2023-11-02 [15, 30, 60, 120] sym_freq_9 ['FTSM']
# 5 2023-11-02 [15, 30, 60, 120] sym_freq_8 ['ANF']
# 6 2023-11-01 [30, 60, 120] sym_freq_12 []
# 7 2023-11-01 [30, 60, 120] sym_freq_9 ['FTSM']
# added row to df_model_top_picks:
# ['2023-11-01', [30, 60, 120], 'sym_freq_9', ['FTSM']]
#
# 8 2023-11-01 [30, 60, 120] sym_freq_8 ['ANF']
# added row to df_model_top_picks:
# ['2023-11-01', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 9 2023-11-01 [15, 30, 60, 120] sym_freq_12 []
# 10 2023-11-01 [15, 30, 60, 120] sym_freq_9 ['LRN']
# 11 2023-11-01 [15, 30, 60, 120] sym_freq_8 ['ANF']
# 12 2023-10-31 [30, 60, 120] sym_freq_12 []
# 13 2023-10-31 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-10-31', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 14 2023-10-31 [30, 60, 120] sym_freq_8 ['ANF', 'SPLK']
# added row to df_model_top_picks:
# ['2023-10-31', [30, 60, 120], 'sym_freq_8', ['ANF', 'SPLK']]
#
# 15 2023-10-31 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-10-31', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 16 2023-10-31 [15, 30, 60, 120] sym_freq_9 ['LRN']
# 17 2023-10-31 [15, 30, 60, 120] sym_freq_8 ['ANF', 'SPLK']
# 18 2023-10-30 [30, 60, 120] sym_freq_12 []
# 19 2023-10-30 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-30', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 20 2023-10-30 [30, 60, 120] sym_freq_8 ['SPLK']
# added row to df_model_top_picks:
# ['2023-10-30', [30, 60, 120], 'sym_freq_8', ['SPLK']]
#
# 21 2023-10-30 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-30', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 22 2023-10-30 [15, 30, 60, 120] sym_freq_9 ['LRN']
# 23 2023-10-30 [15, 30, 60, 120] sym_freq_8 ['SPLK']
# 24 2023-10-27 [30, 60, 120] sym_freq_12 []
# 25 2023-10-27 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-27', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 26 2023-10-27 [30, 60, 120] sym_freq_8 ['SPLK']
# added row to df_model_top_picks:
# ['2023-10-27', [30, 60, 120], 'sym_freq_8', ['SPLK']]
#
# 27 2023-10-27 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-10-27', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 28 2023-10-27 [15, 30, 60, 120] sym_freq_9 ['LRN']
# 29 2023-10-27 [15, 30, 60, 120] sym_freq_8 ['SPLK']
# 30 2023-10-26 [30, 60, 120] sym_freq_12 []
# 31 2023-10-26 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-26', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 32 2023-10-26 [30, 60, 120] sym_freq_8 ['SPLK']
# added row to df_model_top_picks:
# ['2023-10-26', [30, 60, 120], 'sym_freq_8', ['SPLK']]
#
# 33 2023-10-26 [15, 30, 60, 120] sym_freq_12 []
# 34 2023-10-26 [15, 30, 60, 120] sym_freq_9 []
# 35 2023-10-26 [15, 30, 60, 120] sym_freq_8 ['LRN', 'SPLK']
# 36 2023-10-25 [30, 60, 120] sym_freq_12 []
# 37 2023-10-25 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-25', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 38 2023-10-25 [30, 60, 120] sym_freq_8 ['ANF', 'SPLK']
# added row to df_model_top_picks:
# ['2023-10-25', [30, 60, 120], 'sym_freq_8', ['ANF', 'SPLK']]
#
# 39 2023-10-25 [15, 30, 60, 120] sym_freq_12 []
# 40 2023-10-25 [15, 30, 60, 120] sym_freq_9 []
# 41 2023-10-25 [15, 30, 60, 120] sym_freq_8 ['ANF', 'SPLK']
# 42 2023-10-24 [30, 60, 120] sym_freq_12 []
# 43 2023-10-24 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-24', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 44 2023-10-24 [30, 60, 120] sym_freq_8 ['ANF']
# added row to df_model_top_picks:
# ['2023-10-24', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 45 2023-10-24 [15, 30, 60, 120] sym_freq_12 []
# 46 2023-10-24 [15, 30, 60, 120] sym_freq_9 []
# 47 2023-10-24 [15, 30, 60, 120] sym_freq_8 ['ANF']
# 48 2023-10-23 [30, 60, 120] sym_freq_12 []
# 49 2023-10-23 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-23', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 50 2023-10-23 [30, 60, 120] sym_freq_8 ['SPLK']
# added row to df_model_top_picks:
# ['2023-10-23', [30, 60, 120], 'sym_freq_8', ['SPLK']]
#
# 51 2023-10-23 [15, 30, 60, 120] sym_freq_12 []
# 52 2023-10-23 [15, 30, 60, 120] sym_freq_9 []
# 53 2023-10-23 [15, 30, 60, 120] sym_freq_8 ['SPLK']
# 54 2023-10-20 [30, 60, 120] sym_freq_12 []
# 55 2023-10-20 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 56 2023-10-20 [30, 60, 120] sym_freq_8 []
# 57 2023-10-20 [15, 30, 60, 120] sym_freq_12 []
# 58 2023-10-20 [15, 30, 60, 120] sym_freq_9 []
# 59 2023-10-20 [15, 30, 60, 120] sym_freq_8 ['PGR', 'USAC']
# 60 2023-10-19 [30, 60, 120] sym_freq_12 []
# 61 2023-10-19 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-19', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 62 2023-10-19 [30, 60, 120] sym_freq_8 []
# 63 2023-10-19 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-10-19', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 64 2023-10-19 [15, 30, 60, 120] sym_freq_9 ['PGR', 'USAC']
# 65 2023-10-19 [15, 30, 60, 120] sym_freq_8 []
# 66 2023-10-17 [30, 60, 120] sym_freq_12 []
# 67 2023-10-17 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-17', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 68 2023-10-17 [30, 60, 120] sym_freq_8 []
# 69 2023-10-17 [15, 30, 60, 120] sym_freq_12 []
# 70 2023-10-17 [15, 30, 60, 120] sym_freq_9 []
# 71 2023-10-17 [15, 30, 60, 120] sym_freq_8 ['CLS', 'PGR']
# 72 2023-10-12 [30, 60, 120] sym_freq_12 []
# 73 2023-10-12 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-12', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 74 2023-10-12 [30, 60, 120] sym_freq_8 []
# 75 2023-10-12 [15, 30, 60, 120] sym_freq_12 []
# 76 2023-10-12 [15, 30, 60, 120] sym_freq_9 ['ICPT']
# 77 2023-10-12 [15, 30, 60, 120] sym_freq_8 ['ANF', 'CLS']
# 78 2023-10-06 [30, 60, 120] sym_freq_12 []
# 79 2023-10-06 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-06', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 80 2023-10-06 [30, 60, 120] sym_freq_8 []
# 81 2023-10-06 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-10-06', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 82 2023-10-06 [15, 30, 60, 120] sym_freq_9 []
# 83 2023-10-06 [15, 30, 60, 120] sym_freq_8 ['ICPT']
# 84 2023-10-05 [30, 60, 120] sym_freq_12 []
# 85 2023-10-05 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-05', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 86 2023-10-05 [30, 60, 120] sym_freq_8 []
# 87 2023-10-05 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-05', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 88 2023-10-05 [15, 30, 60, 120] sym_freq_9 ['CLS']
# 89 2023-10-05 [15, 30, 60, 120] sym_freq_8 ['ICPT', 'SPLK']
# 90 2023-10-04 [30, 60, 120] sym_freq_12 []
# 91 2023-10-04 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-04', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 92 2023-10-04 [30, 60, 120] sym_freq_8 []
# 93 2023-10-04 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-10-04', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 94 2023-10-04 [15, 30, 60, 120] sym_freq_9 ['ICPT']
# 95 2023-10-04 [15, 30, 60, 120] sym_freq_8 ['MLKN']
# 96 2023-10-02 [30, 60, 120] sym_freq_12 []
# 97 2023-10-02 [30, 60, 120] sym_freq_9 ['FTSM']
# added row to df_model_top_picks:
# ['2023-10-02', [30, 60, 120], 'sym_freq_9', ['FTSM']]
#
# 98 2023-10-02 [30, 60, 120] sym_freq_8 ['ANF']
# added row to df_model_top_picks:
# ['2023-10-02', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 99 2023-10-02 [15, 30, 60, 120] sym_freq_12 ['FTSM']
# added row to df_model_top_picks:
# ['2023-10-02', [15, 30, 60, 120], 'sym_freq_12', ['FTSM']]
#
# 100 2023-10-02 [15, 30, 60, 120] sym_freq_9 ['ANF']
# 101 2023-10-02 [15, 30, 60, 120] sym_freq_8 ['ICPT']
# 102 2023-09-29 [30, 60, 120] sym_freq_12 []
# 103 2023-09-29 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-29', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 104 2023-09-29 [30, 60, 120] sym_freq_8 []
# 105 2023-09-29 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-29', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 106 2023-09-29 [15, 30, 60, 120] sym_freq_9 ['ARCH']
# 107 2023-09-29 [15, 30, 60, 120] sym_freq_8 ['ICPT', 'NGS']
# 108 2023-09-28 [30, 60, 120] sym_freq_12 []
# 109 2023-09-28 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-28', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 110 2023-09-28 [30, 60, 120] sym_freq_8 ['CCJ']
# added row to df_model_top_picks:
# ['2023-09-28', [30, 60, 120], 'sym_freq_8', ['CCJ']]
#
# 111 2023-09-28 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-28', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 112 2023-09-28 [15, 30, 60, 120] sym_freq_9 ['ARCH']
# 113 2023-09-28 [15, 30, 60, 120] sym_freq_8 ['CCJ', 'USAC']
# 114 2023-09-25 [30, 60, 120] sym_freq_12 []
# 115 2023-09-25 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-25', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 116 2023-09-25 [30, 60, 120] sym_freq_8 []
# 117 2023-09-25 [15, 30, 60, 120] sym_freq_12 []
# 118 2023-09-25 [15, 30, 60, 120] sym_freq_9 []
# 119 2023-09-25 [15, 30, 60, 120] sym_freq_8 ['ARCH', 'CCJ']
# 120 2023-09-22 [30, 60, 120] sym_freq_12 []
# 121 2023-09-22 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-22', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 122 2023-09-22 [30, 60, 120] sym_freq_8 []
# 123 2023-09-22 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-22', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 124 2023-09-22 [15, 30, 60, 120] sym_freq_9 []
# 125 2023-09-22 [15, 30, 60, 120] sym_freq_8 []
# 126 2023-09-21 [30, 60, 120] sym_freq_12 []
# 127 2023-09-21 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-21', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 128 2023-09-21 [30, 60, 120] sym_freq_8 []
# 129 2023-09-21 [15, 30, 60, 120] sym_freq_12 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-21', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 130 2023-09-21 [15, 30, 60, 120] sym_freq_9 []
# 131 2023-09-21 [15, 30, 60, 120] sym_freq_8 []
# 132 2023-09-20 [30, 60, 120] sym_freq_12 []
# 133 2023-09-20 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 134 2023-09-20 [30, 60, 120] sym_freq_8 []
# 135 2023-09-20 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-20', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 136 2023-09-20 [15, 30, 60, 120] sym_freq_9 ['DELL']
# 137 2023-09-20 [15, 30, 60, 120] sym_freq_8 []
# 138 2023-09-18 [30, 60, 120] sym_freq_12 []
# 139 2023-09-18 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 140 2023-09-18 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-09-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 141 2023-09-18 [15, 30, 60, 120] sym_freq_12 []
# 142 2023-09-18 [15, 30, 60, 120] sym_freq_9 ['DELL']
# 143 2023-09-18 [15, 30, 60, 120] sym_freq_8 []
# 144 2023-09-15 [30, 60, 120] sym_freq_12 []
# 145 2023-09-15 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 146 2023-09-15 [30, 60, 120] sym_freq_8 []
# 147 2023-09-15 [15, 30, 60, 120] sym_freq_12 []
# 148 2023-09-15 [15, 30, 60, 120] sym_freq_9 []
# 149 2023-09-15 [15, 30, 60, 120] sym_freq_8 []
# 150 2023-09-14 [30, 60, 120] sym_freq_12 []
# 151 2023-09-14 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 152 2023-09-14 [30, 60, 120] sym_freq_8 ['DELL', 'FTSM']
# added row to df_model_top_picks:
# ['2023-09-14', [30, 60, 120], 'sym_freq_8', ['DELL', 'FTSM']]
#
# 153 2023-09-14 [15, 30, 60, 120] sym_freq_12 []
# 154 2023-09-14 [15, 30, 60, 120] sym_freq_9 []
# 155 2023-09-14 [15, 30, 60, 120] sym_freq_8 ['FTSM']
# 156 2023-09-13 [30, 60, 120] sym_freq_12 []
# 157 2023-09-13 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-13', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 158 2023-09-13 [30, 60, 120] sym_freq_8 ['DELL']
# added row to df_model_top_picks:
# ['2023-09-13', [30, 60, 120], 'sym_freq_8', ['DELL']]
#
# 159 2023-09-13 [15, 30, 60, 120] sym_freq_12 []
# 160 2023-09-13 [15, 30, 60, 120] sym_freq_9 ['FTSM']
# 161 2023-09-13 [15, 30, 60, 120] sym_freq_8 []
# 162 2023-09-12 [30, 60, 120] sym_freq_12 []
# 163 2023-09-12 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-12', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 164 2023-09-12 [30, 60, 120] sym_freq_8 ['DELL', 'MMYT']
# added row to df_model_top_picks:
# ['2023-09-12', [30, 60, 120], 'sym_freq_8', ['DELL', 'MMYT']]
#
# 165 2023-09-12 [15, 30, 60, 120] sym_freq_12 []
# 166 2023-09-12 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 167 2023-09-12 [15, 30, 60, 120] sym_freq_8 ['FTI', 'MMYT']
# 168 2023-09-11 [30, 60, 120] sym_freq_12 []
# 169 2023-09-11 [30, 60, 120] sym_freq_9 ['DELL', 'FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-11', [30, 60, 120], 'sym_freq_9', ['DELL', 'FTSM', 'SHV']]
#
# 170 2023-09-11 [30, 60, 120] sym_freq_8 []
# 171 2023-09-11 [15, 30, 60, 120] sym_freq_12 ['DELL']
# added row to df_model_top_picks:
# ['2023-09-11', [15, 30, 60, 120], 'sym_freq_12', ['DELL']]
#
# 172 2023-09-11 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 173 2023-09-11 [15, 30, 60, 120] sym_freq_8 []
# 174 2023-09-08 [30, 60, 120] sym_freq_12 []
# 175 2023-09-08 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-09-08', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 176 2023-09-08 [30, 60, 120] sym_freq_8 ['DELL', 'STRL']
# added row to df_model_top_picks:
# ['2023-09-08', [30, 60, 120], 'sym_freq_8', ['DELL', 'STRL']]
#
# 177 2023-09-08 [15, 30, 60, 120] sym_freq_12 []
# 178 2023-09-08 [15, 30, 60, 120] sym_freq_9 ['ANF', 'FTSM']
# 179 2023-09-08 [15, 30, 60, 120] sym_freq_8 ['CELH', 'STRL']
# 180 2023-09-05 [30, 60, 120] sym_freq_12 []
# 181 2023-09-05 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 182 2023-09-05 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-09-05', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 183 2023-09-05 [15, 30, 60, 120] sym_freq_12 []
# 184 2023-09-05 [15, 30, 60, 120] sym_freq_9 ['FTSM']
# 185 2023-09-05 [15, 30, 60, 120] sym_freq_8 []
# 186 2023-09-01 [30, 60, 120] sym_freq_12 []
# 187 2023-09-01 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-09-01', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 188 2023-09-01 [30, 60, 120] sym_freq_8 ['FTSM', 'STRL']
# added row to df_model_top_picks:
# ['2023-09-01', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 189 2023-09-01 [15, 30, 60, 120] sym_freq_12 []
# 190 2023-09-01 [15, 30, 60, 120] sym_freq_9 ['ANF', 'DELL', 'FTSM']
# 191 2023-09-01 [15, 30, 60, 120] sym_freq_8 ['STRL', 'TDS']
# 192 2023-08-25 [30, 60, 120] sym_freq_12 []
# 193 2023-08-25 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-25', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 194 2023-08-25 [30, 60, 120] sym_freq_8 ['STRL']
# added row to df_model_top_picks:
# ['2023-08-25', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 195 2023-08-25 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-25', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 196 2023-08-25 [15, 30, 60, 120] sym_freq_9 ['ANF', 'TDS']
# 197 2023-08-25 [15, 30, 60, 120] sym_freq_8 ['FTSM', 'LLY']
# 198 2023-08-18 [30, 60, 120] sym_freq_12 []
# 199 2023-08-18 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 200 2023-08-18 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-08-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 201 2023-08-18 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-18', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 202 2023-08-18 [15, 30, 60, 120] sym_freq_9 ['CNX', 'STRL', 'TDS']
# 203 2023-08-18 [15, 30, 60, 120] sym_freq_8 []
# 204 2023-08-17 [30, 60, 120] sym_freq_12 []
# 205 2023-08-17 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-17', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 206 2023-08-17 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-08-17', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 207 2023-08-17 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-17', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 208 2023-08-17 [15, 30, 60, 120] sym_freq_9 ['CNX', 'TDS']
# 209 2023-08-17 [15, 30, 60, 120] sym_freq_8 []
# 210 2023-08-15 [30, 60, 120] sym_freq_12 []
# 211 2023-08-15 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 212 2023-08-15 [30, 60, 120] sym_freq_8 ['STRL']
# added row to df_model_top_picks:
# ['2023-08-15', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 213 2023-08-15 [15, 30, 60, 120] sym_freq_12 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-15', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 214 2023-08-15 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 215 2023-08-15 [15, 30, 60, 120] sym_freq_8 []
# 216 2023-08-14 [30, 60, 120] sym_freq_12 []
# 217 2023-08-14 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 218 2023-08-14 [30, 60, 120] sym_freq_8 []
# 219 2023-08-14 [15, 30, 60, 120] sym_freq_12 []
# 220 2023-08-14 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 221 2023-08-14 [15, 30, 60, 120] sym_freq_8 ['CLS', 'EME']
# 222 2023-08-11 [30, 60, 120] sym_freq_12 []
# 223 2023-08-11 [30, 60, 120] sym_freq_9 []
# 224 2023-08-11 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-11', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 225 2023-08-11 [15, 30, 60, 120] sym_freq_12 []
# 226 2023-08-11 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 227 2023-08-11 [15, 30, 60, 120] sym_freq_8 []
# 228 2023-08-10 [30, 60, 120] sym_freq_12 []
# 229 2023-08-10 [30, 60, 120] sym_freq_9 []
# 230 2023-08-10 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-10', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 231 2023-08-10 [15, 30, 60, 120] sym_freq_12 []
# 232 2023-08-10 [15, 30, 60, 120] sym_freq_9 ['LOB', 'TDS']
# 233 2023-08-10 [15, 30, 60, 120] sym_freq_8 []
# 234 2023-08-09 [30, 60, 120] sym_freq_12 []
# 235 2023-08-09 [30, 60, 120] sym_freq_9 []
# 236 2023-08-09 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-09', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 237 2023-08-09 [15, 30, 60, 120] sym_freq_12 []
# 238 2023-08-09 [15, 30, 60, 120] sym_freq_9 ['LOB', 'TDS']
# 239 2023-08-09 [15, 30, 60, 120] sym_freq_8 []
# 240 2023-08-08 [30, 60, 120] sym_freq_12 []
# 241 2023-08-08 [30, 60, 120] sym_freq_9 []
# 242 2023-08-08 [30, 60, 120] sym_freq_8 ['SHV', 'STRL']
# added row to df_model_top_picks:
# ['2023-08-08', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 243 2023-08-08 [15, 30, 60, 120] sym_freq_12 []
# 244 2023-08-08 [15, 30, 60, 120] sym_freq_9 ['TDS']
# 245 2023-08-08 [15, 30, 60, 120] sym_freq_8 []
# 246 2023-08-07 [30, 60, 120] sym_freq_12 []
# 247 2023-08-07 [30, 60, 120] sym_freq_9 []
# 248 2023-08-07 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-07', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 249 2023-08-07 [15, 30, 60, 120] sym_freq_12 []
# 250 2023-08-07 [15, 30, 60, 120] sym_freq_9 []
# 251 2023-08-07 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 252 2023-08-04 [30, 60, 120] sym_freq_12 []
# 253 2023-08-04 [30, 60, 120] sym_freq_9 []
# 254 2023-08-04 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 255 2023-08-04 [15, 30, 60, 120] sym_freq_12 []
# 256 2023-08-04 [15, 30, 60, 120] sym_freq_9 []
# 257 2023-08-04 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 258 2023-08-03 [30, 60, 120] sym_freq_12 []
# 259 2023-08-03 [30, 60, 120] sym_freq_9 []
# 260 2023-08-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 261 2023-08-03 [15, 30, 60, 120] sym_freq_12 []
# 262 2023-08-03 [15, 30, 60, 120] sym_freq_9 []
# 263 2023-08-03 [15, 30, 60, 120] sym_freq_8 ['LOB']
# 264 2023-08-02 [30, 60, 120] sym_freq_12 []
# 265 2023-08-02 [30, 60, 120] sym_freq_9 []
# 266 2023-08-02 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-08-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 267 2023-08-02 [15, 30, 60, 120] sym_freq_12 []
# 268 2023-08-02 [15, 30, 60, 120] sym_freq_9 ['LOB']
# 269 2023-08-02 [15, 30, 60, 120] sym_freq_8 []
# 270 2023-08-01 [30, 60, 120] sym_freq_12 []
# 271 2023-08-01 [30, 60, 120] sym_freq_9 []
# 272 2023-08-01 [30, 60, 120] sym_freq_8 []
# 273 2023-08-01 [15, 30, 60, 120] sym_freq_12 []
# 274 2023-08-01 [15, 30, 60, 120] sym_freq_9 ['LOB']
# 275 2023-08-01 [15, 30, 60, 120] sym_freq_8 ['SMCI']
# 276 2023-07-27 [30, 60, 120] sym_freq_12 []
# 277 2023-07-27 [30, 60, 120] sym_freq_9 []
# 278 2023-07-27 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-27', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 279 2023-07-27 [15, 30, 60, 120] sym_freq_12 []
# 280 2023-07-27 [15, 30, 60, 120] sym_freq_9 ['JOE']
# 281 2023-07-27 [15, 30, 60, 120] sym_freq_8 []
# 282 2023-07-26 [30, 60, 120] sym_freq_12 []
# 283 2023-07-26 [30, 60, 120] sym_freq_9 []
# 284 2023-07-26 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-26', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 285 2023-07-26 [15, 30, 60, 120] sym_freq_12 []
# 286 2023-07-26 [15, 30, 60, 120] sym_freq_9 []
# 287 2023-07-26 [15, 30, 60, 120] sym_freq_8 []
# 288 2023-07-25 [30, 60, 120] sym_freq_12 []
# 289 2023-07-25 [30, 60, 120] sym_freq_9 []
# 290 2023-07-25 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-25', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 291 2023-07-25 [15, 30, 60, 120] sym_freq_12 []
# 292 2023-07-25 [15, 30, 60, 120] sym_freq_9 []
# 293 2023-07-25 [15, 30, 60, 120] sym_freq_8 []
# 294 2023-07-21 [30, 60, 120] sym_freq_12 []
# 295 2023-07-21 [30, 60, 120] sym_freq_9 []
# 296 2023-07-21 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-21', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 297 2023-07-21 [15, 30, 60, 120] sym_freq_12 []
# 298 2023-07-21 [15, 30, 60, 120] sym_freq_9 ['SHV', 'SIRI']
# 299 2023-07-21 [15, 30, 60, 120] sym_freq_8 []
# 300 2023-07-20 [30, 60, 120] sym_freq_12 []
# 301 2023-07-20 [30, 60, 120] sym_freq_9 []
# 302 2023-07-20 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-20', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 303 2023-07-20 [15, 30, 60, 120] sym_freq_12 []
# 304 2023-07-20 [15, 30, 60, 120] sym_freq_9 ['SHV', 'SIRI']
# 305 2023-07-20 [15, 30, 60, 120] sym_freq_8 []
# 306 2023-07-18 [30, 60, 120] sym_freq_12 []
# 307 2023-07-18 [30, 60, 120] sym_freq_9 []
# 308 2023-07-18 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 309 2023-07-18 [15, 30, 60, 120] sym_freq_12 []
# 310 2023-07-18 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 311 2023-07-18 [15, 30, 60, 120] sym_freq_8 ['BCC']
# 312 2023-07-14 [30, 60, 120] sym_freq_12 []
# 313 2023-07-14 [30, 60, 120] sym_freq_9 []
# 314 2023-07-14 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 315 2023-07-14 [15, 30, 60, 120] sym_freq_12 []
# 316 2023-07-14 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 317 2023-07-14 [15, 30, 60, 120] sym_freq_8 ['BCC']
# 318 2023-07-13 [30, 60, 120] sym_freq_12 []
# 319 2023-07-13 [30, 60, 120] sym_freq_9 []
# 320 2023-07-13 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-13', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 321 2023-07-13 [15, 30, 60, 120] sym_freq_12 []
# 322 2023-07-13 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 323 2023-07-13 [15, 30, 60, 120] sym_freq_8 ['BCC', 'SKYW']
# 324 2023-07-12 [30, 60, 120] sym_freq_12 []
# 325 2023-07-12 [30, 60, 120] sym_freq_9 []
# 326 2023-07-12 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-12', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 327 2023-07-12 [15, 30, 60, 120] sym_freq_12 []
# 328 2023-07-12 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 329 2023-07-12 [15, 30, 60, 120] sym_freq_8 ['BZH', 'SKYW']
# 330 2023-07-11 [30, 60, 120] sym_freq_12 []
# 331 2023-07-11 [30, 60, 120] sym_freq_9 []
# 332 2023-07-11 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-11', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 333 2023-07-11 [15, 30, 60, 120] sym_freq_12 []
# 334 2023-07-11 [15, 30, 60, 120] sym_freq_9 []
# 335 2023-07-11 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 336 2023-07-10 [30, 60, 120] sym_freq_12 []
# 337 2023-07-10 [30, 60, 120] sym_freq_9 []
# 338 2023-07-10 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-10', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 339 2023-07-10 [15, 30, 60, 120] sym_freq_12 []
# 340 2023-07-10 [15, 30, 60, 120] sym_freq_9 []
# 341 2023-07-10 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 342 2023-07-07 [30, 60, 120] sym_freq_12 []
# 343 2023-07-07 [30, 60, 120] sym_freq_9 []
# 344 2023-07-07 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-07', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 345 2023-07-07 [15, 30, 60, 120] sym_freq_12 []
# 346 2023-07-07 [15, 30, 60, 120] sym_freq_9 []
# 347 2023-07-07 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 348 2023-07-06 [30, 60, 120] sym_freq_12 []
# 349 2023-07-06 [30, 60, 120] sym_freq_9 []
# 350 2023-07-06 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-07-06', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 351 2023-07-06 [15, 30, 60, 120] sym_freq_12 []
# 352 2023-07-06 [15, 30, 60, 120] sym_freq_9 []
# 353 2023-07-06 [15, 30, 60, 120] sym_freq_8 ['CCL', 'SKYW']
# 354 2023-07-05 [30, 60, 120] sym_freq_12 []
# 355 2023-07-05 [30, 60, 120] sym_freq_9 []
# 356 2023-07-05 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-05', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 357 2023-07-05 [15, 30, 60, 120] sym_freq_12 []
# 358 2023-07-05 [15, 30, 60, 120] sym_freq_9 []
# 359 2023-07-05 [15, 30, 60, 120] sym_freq_8 ['CCL']
# 360 2023-07-03 [30, 60, 120] sym_freq_12 []
# 361 2023-07-03 [30, 60, 120] sym_freq_9 []
# 362 2023-07-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-07-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 363 2023-07-03 [15, 30, 60, 120] sym_freq_12 []
# 364 2023-07-03 [15, 30, 60, 120] sym_freq_9 []
# 365 2023-07-03 [15, 30, 60, 120] sym_freq_8 ['CCL', 'SKYW', 'W']
# 366 2023-06-30 [30, 60, 120] sym_freq_12 []
# 367 2023-06-30 [30, 60, 120] sym_freq_9 []
# 368 2023-06-30 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-30', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 369 2023-06-30 [15, 30, 60, 120] sym_freq_12 []
# 370 2023-06-30 [15, 30, 60, 120] sym_freq_9 ['SKYW']
# 371 2023-06-30 [15, 30, 60, 120] sym_freq_8 ['CCL']
# 372 2023-06-29 [30, 60, 120] sym_freq_12 []
# 373 2023-06-29 [30, 60, 120] sym_freq_9 []
# 374 2023-06-29 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-29', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 375 2023-06-29 [15, 30, 60, 120] sym_freq_12 []
# 376 2023-06-29 [15, 30, 60, 120] sym_freq_9 []
# 377 2023-06-29 [15, 30, 60, 120] sym_freq_8 []
# 378 2023-06-28 [30, 60, 120] sym_freq_12 []
# 379 2023-06-28 [30, 60, 120] sym_freq_9 []
# 380 2023-06-28 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-28', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 381 2023-06-28 [15, 30, 60, 120] sym_freq_12 []
# 382 2023-06-28 [15, 30, 60, 120] sym_freq_9 []
# 383 2023-06-28 [15, 30, 60, 120] sym_freq_8 []
# 384 2023-06-27 [30, 60, 120] sym_freq_12 []
# 385 2023-06-27 [30, 60, 120] sym_freq_9 []
# 386 2023-06-27 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-27', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 387 2023-06-27 [15, 30, 60, 120] sym_freq_12 []
# 388 2023-06-27 [15, 30, 60, 120] sym_freq_9 []
# 389 2023-06-27 [15, 30, 60, 120] sym_freq_8 []
# 390 2023-06-26 [30, 60, 120] sym_freq_12 []
# 391 2023-06-26 [30, 60, 120] sym_freq_9 []
# 392 2023-06-26 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-26', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 393 2023-06-26 [15, 30, 60, 120] sym_freq_12 []
# 394 2023-06-26 [15, 30, 60, 120] sym_freq_9 []
# 395 2023-06-26 [15, 30, 60, 120] sym_freq_8 []
# 396 2023-06-23 [30, 60, 120] sym_freq_12 []
# 397 2023-06-23 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-23', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 398 2023-06-23 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-23', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 399 2023-06-23 [15, 30, 60, 120] sym_freq_12 []
# 400 2023-06-23 [15, 30, 60, 120] sym_freq_9 ['CCL', 'NVDA']
# 401 2023-06-23 [15, 30, 60, 120] sym_freq_8 ['AMPH']
# 402 2023-06-22 [30, 60, 120] sym_freq_12 []
# 403 2023-06-22 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-22', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 404 2023-06-22 [30, 60, 120] sym_freq_8 ['SHV', 'SKYW']
# added row to df_model_top_picks:
# ['2023-06-22', [30, 60, 120], 'sym_freq_8', ['SHV', 'SKYW']]
#
# 405 2023-06-22 [15, 30, 60, 120] sym_freq_12 []
# 406 2023-06-22 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 407 2023-06-22 [15, 30, 60, 120] sym_freq_8 ['AMPH', 'PBR']
# 408 2023-06-21 [30, 60, 120] sym_freq_12 []
# 409 2023-06-21 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-21', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 410 2023-06-21 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-21', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 411 2023-06-21 [15, 30, 60, 120] sym_freq_12 []
# 412 2023-06-21 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 413 2023-06-21 [15, 30, 60, 120] sym_freq_8 []
# 414 2023-06-20 [30, 60, 120] sym_freq_12 []
# 415 2023-06-20 [30, 60, 120] sym_freq_9 ['NVDA']
# added row to df_model_top_picks:
# ['2023-06-20', [30, 60, 120], 'sym_freq_9', ['NVDA']]
#
# 416 2023-06-20 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-20', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 417 2023-06-20 [15, 30, 60, 120] sym_freq_12 []
# 418 2023-06-20 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 419 2023-06-20 [15, 30, 60, 120] sym_freq_8 []
# 420 2023-06-16 [30, 60, 120] sym_freq_12 []
# 421 2023-06-16 [30, 60, 120] sym_freq_9 []
# 422 2023-06-16 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-16', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 423 2023-06-16 [15, 30, 60, 120] sym_freq_12 []
# 424 2023-06-16 [15, 30, 60, 120] sym_freq_9 ['SKYW']
# 425 2023-06-16 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 426 2023-06-15 [30, 60, 120] sym_freq_12 []
# 427 2023-06-15 [30, 60, 120] sym_freq_9 []
# 428 2023-06-15 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-15', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 429 2023-06-15 [15, 30, 60, 120] sym_freq_12 []
# 430 2023-06-15 [15, 30, 60, 120] sym_freq_9 []
# 431 2023-06-15 [15, 30, 60, 120] sym_freq_8 ['CCL', 'NVDA', 'SKYW']
# 432 2023-06-14 [30, 60, 120] sym_freq_12 []
# 433 2023-06-14 [30, 60, 120] sym_freq_9 []
# 434 2023-06-14 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-14', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA', 'SHV']]
#
# 435 2023-06-14 [15, 30, 60, 120] sym_freq_12 []
# 436 2023-06-14 [15, 30, 60, 120] sym_freq_9 ['AVGO']
# 437 2023-06-14 [15, 30, 60, 120] sym_freq_8 ['ORCL', 'SKYW']
# 438 2023-06-13 [30, 60, 120] sym_freq_12 []
# 439 2023-06-13 [30, 60, 120] sym_freq_9 []
# 440 2023-06-13 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 441 2023-06-13 [15, 30, 60, 120] sym_freq_12 []
# 442 2023-06-13 [15, 30, 60, 120] sym_freq_9 []
# 443 2023-06-13 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 444 2023-06-12 [30, 60, 120] sym_freq_12 []
# 445 2023-06-12 [30, 60, 120] sym_freq_9 []
# 446 2023-06-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 447 2023-06-12 [15, 30, 60, 120] sym_freq_12 []
# 448 2023-06-12 [15, 30, 60, 120] sym_freq_9 []
# 449 2023-06-12 [15, 30, 60, 120] sym_freq_8 ['SKYW']
# 450 2023-06-09 [30, 60, 120] sym_freq_12 []
# 451 2023-06-09 [30, 60, 120] sym_freq_9 []
# 452 2023-06-09 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-09', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 453 2023-06-09 [15, 30, 60, 120] sym_freq_12 []
# 454 2023-06-09 [15, 30, 60, 120] sym_freq_9 []
# 455 2023-06-09 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 456 2023-06-08 [30, 60, 120] sym_freq_12 []
# 457 2023-06-08 [30, 60, 120] sym_freq_9 []
# 458 2023-06-08 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-08', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 459 2023-06-08 [15, 30, 60, 120] sym_freq_12 []
# 460 2023-06-08 [15, 30, 60, 120] sym_freq_9 []
# 461 2023-06-08 [15, 30, 60, 120] sym_freq_8 ['NVDA']
# 462 2023-06-07 [30, 60, 120] sym_freq_12 []
# 463 2023-06-07 [30, 60, 120] sym_freq_9 []
# 464 2023-06-07 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-06-07', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 465 2023-06-07 [15, 30, 60, 120] sym_freq_12 []
# 466 2023-06-07 [15, 30, 60, 120] sym_freq_9 []
# 467 2023-06-07 [15, 30, 60, 120] sym_freq_8 []
# 468 2023-06-06 [30, 60, 120] sym_freq_12 []
# 469 2023-06-06 [30, 60, 120] sym_freq_9 []
# 470 2023-06-06 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-06', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 471 2023-06-06 [15, 30, 60, 120] sym_freq_12 []
# 472 2023-06-06 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 473 2023-06-06 [15, 30, 60, 120] sym_freq_8 []
# 474 2023-06-05 [30, 60, 120] sym_freq_12 []
# 475 2023-06-05 [30, 60, 120] sym_freq_9 []
# 476 2023-06-05 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-05', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 477 2023-06-05 [15, 30, 60, 120] sym_freq_12 []
# 478 2023-06-05 [15, 30, 60, 120] sym_freq_9 []
# 479 2023-06-05 [15, 30, 60, 120] sym_freq_8 ['META', 'SKYW']
# 480 2023-06-02 [30, 60, 120] sym_freq_12 []
# 481 2023-06-02 [30, 60, 120] sym_freq_9 []
# 482 2023-06-02 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-06-02', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 483 2023-06-02 [15, 30, 60, 120] sym_freq_12 []
# 484 2023-06-02 [15, 30, 60, 120] sym_freq_9 ['META']
# 485 2023-06-02 [15, 30, 60, 120] sym_freq_8 []
# 486 2023-06-01 [30, 60, 120] sym_freq_12 []
# 487 2023-06-01 [30, 60, 120] sym_freq_9 []
# 488 2023-06-01 [30, 60, 120] sym_freq_8 ['META', 'NVDA']
# added row to df_model_top_picks:
# ['2023-06-01', [30, 60, 120], 'sym_freq_8', ['META', 'NVDA']]
#
# 489 2023-06-01 [15, 30, 60, 120] sym_freq_12 []
# 490 2023-06-01 [15, 30, 60, 120] sym_freq_9 ['AVGO', 'RMBS']
# 491 2023-06-01 [15, 30, 60, 120] sym_freq_8 []
# 492 2023-05-31 [30, 60, 120] sym_freq_12 []
# 493 2023-05-31 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-31', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 494 2023-05-31 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-31', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA']]
#
# 495 2023-05-31 [15, 30, 60, 120] sym_freq_12 []
# 496 2023-05-31 [15, 30, 60, 120] sym_freq_9 []
# 497 2023-05-31 [15, 30, 60, 120] sym_freq_8 ['RMBS']
# 498 2023-05-30 [30, 60, 120] sym_freq_12 []
# 499 2023-05-30 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 500 2023-05-30 [30, 60, 120] sym_freq_8 ['AVGO', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-30', [30, 60, 120], 'sym_freq_8', ['AVGO', 'NVDA']]
#
# 501 2023-05-30 [15, 30, 60, 120] sym_freq_12 []
# 502 2023-05-30 [15, 30, 60, 120] sym_freq_9 []
# 503 2023-05-30 [15, 30, 60, 120] sym_freq_8 []
# 504 2023-05-26 [30, 60, 120] sym_freq_12 []
# 505 2023-05-26 [30, 60, 120] sym_freq_9 ['AVGO', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-26', [30, 60, 120], 'sym_freq_9', ['AVGO', 'SHV']]
#
# 506 2023-05-26 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-05-26', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 507 2023-05-26 [15, 30, 60, 120] sym_freq_12 ['AVGO']
# added row to df_model_top_picks:
# ['2023-05-26', [15, 30, 60, 120], 'sym_freq_12', ['AVGO']]
#
# 508 2023-05-26 [15, 30, 60, 120] sym_freq_9 ['RMBS']
# 509 2023-05-26 [15, 30, 60, 120] sym_freq_8 ['AMD']
# 510 2023-05-25 [30, 60, 120] sym_freq_12 []
# 511 2023-05-25 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-25', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 512 2023-05-25 [30, 60, 120] sym_freq_8 ['FTSM', 'NVDA']
# added row to df_model_top_picks:
# ['2023-05-25', [30, 60, 120], 'sym_freq_8', ['FTSM', 'NVDA']]
#
# 513 2023-05-25 [15, 30, 60, 120] sym_freq_12 []
# 514 2023-05-25 [15, 30, 60, 120] sym_freq_9 []
# 515 2023-05-25 [15, 30, 60, 120] sym_freq_8 ['FTSM']
# 516 2023-05-24 [30, 60, 120] sym_freq_12 []
# 517 2023-05-24 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-24', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 518 2023-05-24 [30, 60, 120] sym_freq_8 []
# 519 2023-05-24 [15, 30, 60, 120] sym_freq_12 []
# 520 2023-05-24 [15, 30, 60, 120] sym_freq_9 []
# 521 2023-05-24 [15, 30, 60, 120] sym_freq_8 []
# 522 2023-05-23 [30, 60, 120] sym_freq_12 []
# 523 2023-05-23 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 524 2023-05-23 [30, 60, 120] sym_freq_8 []
# 525 2023-05-23 [15, 30, 60, 120] sym_freq_12 []
# 526 2023-05-23 [15, 30, 60, 120] sym_freq_9 []
# 527 2023-05-23 [15, 30, 60, 120] sym_freq_8 []
# 528 2023-05-22 [30, 60, 120] sym_freq_12 []
# 529 2023-05-22 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 530 2023-05-22 [30, 60, 120] sym_freq_8 []
# 531 2023-05-22 [15, 30, 60, 120] sym_freq_12 []
# 532 2023-05-22 [15, 30, 60, 120] sym_freq_9 []
# 533 2023-05-22 [15, 30, 60, 120] sym_freq_8 []
# 534 2023-05-19 [30, 60, 120] sym_freq_12 []
# 535 2023-05-19 [30, 60, 120] sym_freq_9 []
# 536 2023-05-19 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 537 2023-05-19 [15, 30, 60, 120] sym_freq_12 []
# 538 2023-05-19 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 539 2023-05-19 [15, 30, 60, 120] sym_freq_8 []
# 540 2023-05-18 [30, 60, 120] sym_freq_12 []
# 541 2023-05-18 [30, 60, 120] sym_freq_9 []
# 542 2023-05-18 [30, 60, 120] sym_freq_8 ['SHV', 'TMHC']
# added row to df_model_top_picks:
# ['2023-05-18', [30, 60, 120], 'sym_freq_8', ['SHV', 'TMHC']]
#
# 543 2023-05-18 [15, 30, 60, 120] sym_freq_12 []
# 544 2023-05-18 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 545 2023-05-18 [15, 30, 60, 120] sym_freq_8 ['TMHC']
# 546 2023-05-17 [30, 60, 120] sym_freq_12 []
# 547 2023-05-17 [30, 60, 120] sym_freq_9 []
# 548 2023-05-17 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-17', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 549 2023-05-17 [15, 30, 60, 120] sym_freq_12 []
# 550 2023-05-17 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 551 2023-05-17 [15, 30, 60, 120] sym_freq_8 []
# 552 2023-05-16 [30, 60, 120] sym_freq_12 []
# 553 2023-05-16 [30, 60, 120] sym_freq_9 []
# 554 2023-05-16 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-16', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 555 2023-05-16 [15, 30, 60, 120] sym_freq_12 []
# 556 2023-05-16 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 557 2023-05-16 [15, 30, 60, 120] sym_freq_8 []
# 558 2023-05-15 [30, 60, 120] sym_freq_12 []
# 559 2023-05-15 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 560 2023-05-15 [30, 60, 120] sym_freq_8 []
# 561 2023-05-15 [15, 30, 60, 120] sym_freq_12 []
# 562 2023-05-15 [15, 30, 60, 120] sym_freq_9 []
# 563 2023-05-15 [15, 30, 60, 120] sym_freq_8 ['ISEE']
# 564 2023-05-12 [30, 60, 120] sym_freq_12 []
# 565 2023-05-12 [30, 60, 120] sym_freq_9 []
# 566 2023-05-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 567 2023-05-12 [15, 30, 60, 120] sym_freq_12 []
# 568 2023-05-12 [15, 30, 60, 120] sym_freq_9 ['ISEE', 'SHV']
# 569 2023-05-12 [15, 30, 60, 120] sym_freq_8 []
# 570 2023-05-11 [30, 60, 120] sym_freq_12 []
# 571 2023-05-11 [30, 60, 120] sym_freq_9 []
# 572 2023-05-11 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-11', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 573 2023-05-11 [15, 30, 60, 120] sym_freq_12 []
# 574 2023-05-11 [15, 30, 60, 120] sym_freq_9 ['BLDR']
# 575 2023-05-11 [15, 30, 60, 120] sym_freq_8 []
# 576 2023-05-10 [30, 60, 120] sym_freq_12 []
# 577 2023-05-10 [30, 60, 120] sym_freq_9 []
# 578 2023-05-10 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-10', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 579 2023-05-10 [15, 30, 60, 120] sym_freq_12 []
# 580 2023-05-10 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 581 2023-05-10 [15, 30, 60, 120] sym_freq_8 ['BLDR']
# 582 2023-05-09 [30, 60, 120] sym_freq_12 []
# 583 2023-05-09 [30, 60, 120] sym_freq_9 []
# 584 2023-05-09 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-09', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 585 2023-05-09 [15, 30, 60, 120] sym_freq_12 []
# 586 2023-05-09 [15, 30, 60, 120] sym_freq_9 ['BLDR']
# 587 2023-05-09 [15, 30, 60, 120] sym_freq_8 []
# 588 2023-05-08 [30, 60, 120] sym_freq_12 []
# 589 2023-05-08 [30, 60, 120] sym_freq_9 []
# 590 2023-05-08 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-08', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 591 2023-05-08 [15, 30, 60, 120] sym_freq_12 []
# 592 2023-05-08 [15, 30, 60, 120] sym_freq_9 []
# 593 2023-05-08 [15, 30, 60, 120] sym_freq_8 []
# 594 2023-05-05 [30, 60, 120] sym_freq_12 []
# 595 2023-05-05 [30, 60, 120] sym_freq_9 []
# 596 2023-05-05 [30, 60, 120] sym_freq_8 ['ISEE', 'SHV']
# added row to df_model_top_picks:
# ['2023-05-05', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 597 2023-05-05 [15, 30, 60, 120] sym_freq_12 []
# 598 2023-05-05 [15, 30, 60, 120] sym_freq_9 []
# 599 2023-05-05 [15, 30, 60, 120] sym_freq_8 []
# 600 2023-05-04 [30, 60, 120] sym_freq_12 []
# 601 2023-05-04 [30, 60, 120] sym_freq_9 []
# 602 2023-05-04 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 603 2023-05-04 [15, 30, 60, 120] sym_freq_12 []
# 604 2023-05-04 [15, 30, 60, 120] sym_freq_9 ['CCEP']
# 605 2023-05-04 [15, 30, 60, 120] sym_freq_8 []
# 606 2023-05-03 [30, 60, 120] sym_freq_12 []
# 607 2023-05-03 [30, 60, 120] sym_freq_9 []
# 608 2023-05-03 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 609 2023-05-03 [15, 30, 60, 120] sym_freq_12 []
# 610 2023-05-03 [15, 30, 60, 120] sym_freq_9 ['ISEE']
# 611 2023-05-03 [15, 30, 60, 120] sym_freq_8 ['CCEP', 'SHV', 'SKYW']
# 612 2023-05-02 [30, 60, 120] sym_freq_12 []
# 613 2023-05-02 [30, 60, 120] sym_freq_9 []
# 614 2023-05-02 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-05-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 615 2023-05-02 [15, 30, 60, 120] sym_freq_12 []
# 616 2023-05-02 [15, 30, 60, 120] sym_freq_9 ['CCEP', 'ISEE', 'SHV']
# 617 2023-05-02 [15, 30, 60, 120] sym_freq_8 []
# 618 2023-05-01 [30, 60, 120] sym_freq_12 []
# 619 2023-05-01 [30, 60, 120] sym_freq_9 []
# 620 2023-05-01 [30, 60, 120] sym_freq_8 []
# 621 2023-05-01 [15, 30, 60, 120] sym_freq_12 []
# 622 2023-05-01 [15, 30, 60, 120] sym_freq_9 []
# 623 2023-05-01 [15, 30, 60, 120] sym_freq_8 ['ISEE']
# 624 2023-04-28 [30, 60, 120] sym_freq_12 []
# 625 2023-04-28 [30, 60, 120] sym_freq_9 []
# 626 2023-04-28 [30, 60, 120] sym_freq_8 []
# 627 2023-04-28 [15, 30, 60, 120] sym_freq_12 []
# 628 2023-04-28 [15, 30, 60, 120] sym_freq_9 []
# 629 2023-04-28 [15, 30, 60, 120] sym_freq_8 ['PHM', 'SHV']
# 630 2023-04-27 [30, 60, 120] sym_freq_12 []
# 631 2023-04-27 [30, 60, 120] sym_freq_9 []
# 632 2023-04-27 [30, 60, 120] sym_freq_8 []
# 633 2023-04-27 [15, 30, 60, 120] sym_freq_12 []
# 634 2023-04-27 [15, 30, 60, 120] sym_freq_9 []
# 635 2023-04-27 [15, 30, 60, 120] sym_freq_8 ['PHM', 'SHV']
# 636 2023-04-26 [30, 60, 120] sym_freq_12 []
# 637 2023-04-26 [30, 60, 120] sym_freq_9 []
# 638 2023-04-26 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-26', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 639 2023-04-26 [15, 30, 60, 120] sym_freq_12 []
# 640 2023-04-26 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 641 2023-04-26 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 642 2023-04-25 [30, 60, 120] sym_freq_12 []
# 643 2023-04-25 [30, 60, 120] sym_freq_9 []
# 644 2023-04-25 [30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-25', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 645 2023-04-25 [15, 30, 60, 120] sym_freq_12 []
# 646 2023-04-25 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 647 2023-04-25 [15, 30, 60, 120] sym_freq_8 ['ELF']
# 648 2023-04-24 [30, 60, 120] sym_freq_12 []
# 649 2023-04-24 [30, 60, 120] sym_freq_9 []
# 650 2023-04-24 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-24', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 651 2023-04-24 [15, 30, 60, 120] sym_freq_12 []
# 652 2023-04-24 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 653 2023-04-24 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 654 2023-04-21 [30, 60, 120] sym_freq_12 []
# 655 2023-04-21 [30, 60, 120] sym_freq_9 []
# 656 2023-04-21 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-21', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 657 2023-04-21 [15, 30, 60, 120] sym_freq_12 []
# 658 2023-04-21 [15, 30, 60, 120] sym_freq_9 ['ELF']
# 659 2023-04-21 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 660 2023-04-20 [30, 60, 120] sym_freq_12 []
# 661 2023-04-20 [30, 60, 120] sym_freq_9 []
# 662 2023-04-20 [30, 60, 120] sym_freq_8 ['ELF']
# added row to df_model_top_picks:
# ['2023-04-20', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 663 2023-04-20 [15, 30, 60, 120] sym_freq_12 []
# 664 2023-04-20 [15, 30, 60, 120] sym_freq_9 []
# 665 2023-04-20 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 666 2023-04-19 [30, 60, 120] sym_freq_12 []
# 667 2023-04-19 [30, 60, 120] sym_freq_9 []
# 668 2023-04-19 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 669 2023-04-19 [15, 30, 60, 120] sym_freq_12 []
# 670 2023-04-19 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 671 2023-04-19 [15, 30, 60, 120] sym_freq_8 []
# 672 2023-04-18 [30, 60, 120] sym_freq_12 []
# 673 2023-04-18 [30, 60, 120] sym_freq_9 []
# 674 2023-04-18 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 675 2023-04-18 [15, 30, 60, 120] sym_freq_12 []
# 676 2023-04-18 [15, 30, 60, 120] sym_freq_9 []
# 677 2023-04-18 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 678 2023-04-17 [30, 60, 120] sym_freq_12 []
# 679 2023-04-17 [30, 60, 120] sym_freq_9 []
# 680 2023-04-17 [30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-17', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 681 2023-04-17 [15, 30, 60, 120] sym_freq_12 []
# 682 2023-04-17 [15, 30, 60, 120] sym_freq_9 []
# 683 2023-04-17 [15, 30, 60, 120] sym_freq_8 ['ELF', 'SHV']
# 684 2023-04-14 [30, 60, 120] sym_freq_12 []
# 685 2023-04-14 [30, 60, 120] sym_freq_9 []
# 686 2023-04-14 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 687 2023-04-14 [15, 30, 60, 120] sym_freq_12 []
# 688 2023-04-14 [15, 30, 60, 120] sym_freq_9 []
# 689 2023-04-14 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 690 2023-04-13 [30, 60, 120] sym_freq_12 []
# 691 2023-04-13 [30, 60, 120] sym_freq_9 []
# 692 2023-04-13 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 693 2023-04-13 [15, 30, 60, 120] sym_freq_12 []
# 694 2023-04-13 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 695 2023-04-13 [15, 30, 60, 120] sym_freq_8 []
# 696 2023-04-12 [30, 60, 120] sym_freq_12 []
# 697 2023-04-12 [30, 60, 120] sym_freq_9 []
# 698 2023-04-12 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 699 2023-04-12 [15, 30, 60, 120] sym_freq_12 []
# 700 2023-04-12 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 701 2023-04-12 [15, 30, 60, 120] sym_freq_8 []
# 702 2023-04-11 [30, 60, 120] sym_freq_12 []
# 703 2023-04-11 [30, 60, 120] sym_freq_9 []
# 704 2023-04-11 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-11', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 705 2023-04-11 [15, 30, 60, 120] sym_freq_12 []
# 706 2023-04-11 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 707 2023-04-11 [15, 30, 60, 120] sym_freq_8 []
# 708 2023-04-10 [30, 60, 120] sym_freq_12 []
# 709 2023-04-10 [30, 60, 120] sym_freq_9 []
# 710 2023-04-10 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-10', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 711 2023-04-10 [15, 30, 60, 120] sym_freq_12 []
# 712 2023-04-10 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 713 2023-04-10 [15, 30, 60, 120] sym_freq_8 []
# 714 2023-04-06 [30, 60, 120] sym_freq_12 []
# 715 2023-04-06 [30, 60, 120] sym_freq_9 []
# 716 2023-04-06 [30, 60, 120] sym_freq_8 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-06', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 717 2023-04-06 [15, 30, 60, 120] sym_freq_12 []
# 718 2023-04-06 [15, 30, 60, 120] sym_freq_9 []
# 719 2023-04-06 [15, 30, 60, 120] sym_freq_8 ['SHV']
# 720 2023-04-05 [30, 60, 120] sym_freq_12 []
# 721 2023-04-05 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-04-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 722 2023-04-05 [30, 60, 120] sym_freq_8 []
# 723 2023-04-05 [15, 30, 60, 120] sym_freq_12 []
# 724 2023-04-05 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 725 2023-04-05 [15, 30, 60, 120] sym_freq_8 []
# 726 2023-04-04 [30, 60, 120] sym_freq_12 []
# 727 2023-04-04 [30, 60, 120] sym_freq_9 []
# 728 2023-04-04 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-04-04', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 729 2023-04-04 [15, 30, 60, 120] sym_freq_12 []
# 730 2023-04-04 [15, 30, 60, 120] sym_freq_9 []
# 731 2023-04-04 [15, 30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# 732 2023-04-03 [30, 60, 120] sym_freq_12 []
# 733 2023-04-03 [30, 60, 120] sym_freq_9 []
# 734 2023-04-03 [30, 60, 120] sym_freq_8 ['GE', 'NVDA']
# added row to df_model_top_picks:
# ['2023-04-03', [30, 60, 120], 'sym_freq_8', ['GE', 'NVDA']]
#
# 735 2023-04-03 [15, 30, 60, 120] sym_freq_12 []
# 736 2023-04-03 [15, 30, 60, 120] sym_freq_9 []
# 737 2023-04-03 [15, 30, 60, 120] sym_freq_8 ['GE', 'PERI']
# 738 2023-03-31 [30, 60, 120] sym_freq_12 []
# 739 2023-03-31 [30, 60, 120] sym_freq_9 []
# 740 2023-03-31 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-03-31', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 741 2023-03-31 [15, 30, 60, 120] sym_freq_12 []
# 742 2023-03-31 [15, 30, 60, 120] sym_freq_9 []
# 743 2023-03-31 [15, 30, 60, 120] sym_freq_8 []
# 744 2023-03-30 [30, 60, 120] sym_freq_12 []
# 745 2023-03-30 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 746 2023-03-30 [30, 60, 120] sym_freq_8 ['NVDA']
# added row to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 747 2023-03-30 [15, 30, 60, 120] sym_freq_12 []
# 748 2023-03-30 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 749 2023-03-30 [15, 30, 60, 120] sym_freq_8 []
# 750 2023-03-29 [30, 60, 120] sym_freq_12 []
# 751 2023-03-29 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-29', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 752 2023-03-29 [30, 60, 120] sym_freq_8 []
# 753 2023-03-29 [15, 30, 60, 120] sym_freq_12 []
# 754 2023-03-29 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 755 2023-03-29 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 756 2023-03-28 [30, 60, 120] sym_freq_12 []
# 757 2023-03-28 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-28', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 758 2023-03-28 [30, 60, 120] sym_freq_8 []
# 759 2023-03-28 [15, 30, 60, 120] sym_freq_12 []
# 760 2023-03-28 [15, 30, 60, 120] sym_freq_9 []
# 761 2023-03-28 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 762 2023-03-27 [30, 60, 120] sym_freq_12 []
# 763 2023-03-27 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 764 2023-03-27 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 765 2023-03-27 [15, 30, 60, 120] sym_freq_12 []
# 766 2023-03-27 [15, 30, 60, 120] sym_freq_9 []
# 767 2023-03-27 [15, 30, 60, 120] sym_freq_8 ['GE', 'NVDA', 'SGEN']
# 768 2023-03-24 [30, 60, 120] sym_freq_12 []
# 769 2023-03-24 [30, 60, 120] sym_freq_9 []
# 770 2023-03-24 [30, 60, 120] sym_freq_8 ['NVDA', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-24', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 771 2023-03-24 [15, 30, 60, 120] sym_freq_12 []
# 772 2023-03-24 [15, 30, 60, 120] sym_freq_9 ['SHV']
# 773 2023-03-24 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 774 2023-03-23 [30, 60, 120] sym_freq_12 []
# 775 2023-03-23 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 776 2023-03-23 [30, 60, 120] sym_freq_8 []
# 777 2023-03-23 [15, 30, 60, 120] sym_freq_12 []
# 778 2023-03-23 [15, 30, 60, 120] sym_freq_9 ['NVDA']
# 779 2023-03-23 [15, 30, 60, 120] sym_freq_8 ['FTSM', 'GE']
# 780 2023-03-22 [30, 60, 120] sym_freq_12 []
# 781 2023-03-22 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 782 2023-03-22 [30, 60, 120] sym_freq_8 ['FTSM']
# added row to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 783 2023-03-22 [15, 30, 60, 120] sym_freq_12 []
# 784 2023-03-22 [15, 30, 60, 120] sym_freq_9 ['FTSM', 'NVDA']
# 785 2023-03-22 [15, 30, 60, 120] sym_freq_8 ['SGEN']
# 786 2023-03-21 [30, 60, 120] sym_freq_12 []
# 787 2023-03-21 [30, 60, 120] sym_freq_9 ['SHV']
# added row to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 788 2023-03-21 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 789 2023-03-21 [15, 30, 60, 120] sym_freq_12 []
# 790 2023-03-21 [15, 30, 60, 120] sym_freq_9 ['GE']
# 791 2023-03-21 [15, 30, 60, 120] sym_freq_8 []
# 792 2023-03-20 [30, 60, 120] sym_freq_12 []
# 793 2023-03-20 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 794 2023-03-20 [30, 60, 120] sym_freq_8 []
# 795 2023-03-20 [15, 30, 60, 120] sym_freq_12 []
# 796 2023-03-20 [15, 30, 60, 120] sym_freq_9 []
# 797 2023-03-20 [15, 30, 60, 120] sym_freq_8 []
# 798 2023-03-17 [30, 60, 120] sym_freq_12 []
# 799 2023-03-17 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 800 2023-03-17 [30, 60, 120] sym_freq_8 ['GE']
# added row to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 801 2023-03-17 [15, 30, 60, 120] sym_freq_12 []
# 802 2023-03-17 [15, 30, 60, 120] sym_freq_9 ['FTSM', 'GE']
# 803 2023-03-17 [15, 30, 60, 120] sym_freq_8 []
# 804 2023-03-16 [30, 60, 120] sym_freq_12 []
# 805 2023-03-16 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-16', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 806 2023-03-16 [30, 60, 120] sym_freq_8 []
# 807 2023-03-16 [15, 30, 60, 120] sym_freq_12 []
# 808 2023-03-16 [15, 30, 60, 120] sym_freq_9 ['SGEN']
# 809 2023-03-16 [15, 30, 60, 120] sym_freq_8 []
# 810 2023-03-15 [30, 60, 120] sym_freq_12 []
# 811 2023-03-15 [30, 60, 120] sym_freq_9 ['FTSM', 'SHV']
# added row to df_model_top_picks:
# ['2023-03-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 812 2023-03-15 [30, 60, 120] sym_freq_8 []
# 813 2023-03-15 [15, 30, 60, 120] sym_freq_12 []
# 814 2023-03-15 [15, 30, 60, 120] sym_freq_9 ['SGEN']
# 815 2023-03-15 [15, 30, 60, 120] sym_freq_8 ['AMPH', 'FCN']

# %%
df_model_top_picks = df_model_top_picks.astype(str)
df_model_top_picks = df_model_top_picks.drop_duplicates(keep='last')
df_model_top_picks = df_model_top_picks.sort_values(by=['date', 'days_lookback', 'syms_freq'], ascending=False)
df_model_top_picks = df_model_top_picks.reset_index(drop=True)
pickle_dump(df_model_top_picks, path_data_dump, fp_df_model_top_picks)
print(f'len(df_model_top_picks): {len(df_model_top_picks)}')
print(f'{fp_df_model_top_picks}:\n{df_model_top_picks}')
# Out:
# len(df_model_top_picks): 187
# df_model_top_picks:
#            date  days_lookback   syms_freq          symbols
# 0    2023-11-02  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 1    2023-11-02  [30, 60, 120]  sym_freq_8          ['ANF']
# 2    2023-11-01  [30, 60, 120]  sym_freq_9         ['FTSM']
# 3    2023-11-01  [30, 60, 120]  sym_freq_8          ['ANF']
# 4    2023-10-31  [30, 60, 120]  sym_freq_9          ['SHV']
# ..          ...            ...         ...              ...
# 182  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 183  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 184  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']
# 185  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 186  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
#
# [187 rows x 4 columns]

# %%
df_mp = df_model_top_picks.copy()
df_close = pickle_load(path_data_dump, 'df_close_clean')

# %%
def get_NYSE_date_n(date, dates_NYSE, n, verbose=False):

  if date in dates_NYSE:
    idx_last = len(dates_NYSE) - 1  # last index of dates_NYSE
    idx_date = dates_NYSE.get_loc(date)  # index of date
    idx_date_n = idx_date + n  # index of date_n
    if verbose:
      print(f"date: {date} is in dates_NYSE,  date's position in dates_NYSE is: {idx_date} of {idx_last},  n: {n},  idx_date_n: {idx_date_n},")
    if 0 <= idx_date_n <= idx_last:  # idx_date_n is within bounds of dates_NYSE
      date_n = dates_NYSE[idx_date_n]
      if verbose:      
        print(f'idx_date_n: {idx_date_n} is wiithin bounds of dates_NYSE ("0 to {idx_last}), date_n: {date_n}"\n')
    else:  # idx_date_n is out-of-bounds of dates_NYSE
      date_n = None   
      if verbose:  
        print(f'idx_date_n: {idx_date_n} is out-of-bounds of dates_NYSE ("0 to {idx_last})"\n')
  else:  # date not in dates_NYSE
      date_n = None  
      if verbose:  
        print(f'date: {date} is not in dates_NYSE\n')

  return date_n

# %%
def get_portf_buy(df_close, date, str_symbols, portf_target, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    sym_cnt = len(l_syms)  # number of symbols
    amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
    ar_sym_share = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
    ar_sym_amt = ar_price * ar_sym_share  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_sym_amt)  # total actual portfolio value
    if verbose:
        # print(date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value)    
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_sym_share = }, {ar_sym_amt = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_sym_share, ar_sym_amt, portf_value

# %%
def get_SPY_buy(df_close, date, portf_target, symbol="SPY", verbose=False):   
    import numpy as np
    price = df_close.loc[date][symbol]    
    share = np.floor(portf_target / price)  # array of shares for each symbol
    value = price * share  # array of actual dollar amount invested in each symbol
    if verbose:
        # print(date, symbol, price, share, value)
        print(f'{date = }, {symbol = }, {price = }, {share = }, {value = }')                        
        print(f'{date} {symbol} {value = }')
    return date, price, share, value

# %%
import pandas_market_calendars as mcal
nyse = mcal.get_calendar('NYSE')
dates_NYSE_2013_2023 = nyse.valid_days(start_date='2013-01-01', end_date='2023-12-31').strftime('%Y-%m-%d')
print(f'len(dates_NYSE_2013_2023): {len(dates_NYSE_2013_2023)}')
print(f'dates_NYSE_2013_2023[0]:  {dates_NYSE_2013_2023[0]}, dates_NYSE_2013_2023[-1]: {dates_NYSE_2013_2023[-1]}')
print(f'{dates_NYSE_2013_2023}')
# Out:
# len(dates_NYSE_2013_2023): 2768
# dates_NYSE_2013_2023[0]:  2013-01-02, dates_NYSE_2013_2023[-1]: 2023-12-29
# Index(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-07', '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-14', '2013-01-15',
#        ...
#        '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20', '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29'], dtype='object', length=2768)

# %% [markdown]
# #### TODO: 2023-07-15 only evaluate performance of df_model_picks, after evaluation, append results to df_model_picks_results
#
#
# #### 2023-07-11 got KeyError: "['ISEE'] not in index". ISEE was in past model picks, but since then ISEE was acquired. The symbol was dropped from df_close_clean. Current program recalculate the performance of all the past picks. Rewrite program such that performance of past picks with win records are not recalculated.

# %%
#####################################

# %%
# for items in z_date_syms:
#   print(items)

# %%
# idx_close = df_close.index.strftime('%Y-%m-%d')
# idx_close

# %%
# df_mp
# # df_mp.date
# # df_mp.symbols

# %%
# _df = pickle_load(path_data_dump, 'df_model_picks_results')
# # _df
# len(_df.columns)

# %%
# _df = pickle_load(path_data_dump, 'df_model_picks')
# len(_df.columns)

# %%
#####################################

# %%
import numpy as np
# from ast import literal_eval
z_date_syms = zip(df_mp.date, df_mp.symbols)  # e.g. ('2023-10-31', "['ANF', 'SPLK']")

idx_close = df_close.index.strftime('%Y-%m-%d')

n = 1  # n=1 is the buy date
# n = 4  # n=4 is the sell date

date_buy = []  # buy date of portfolio
shares_syms = []  # lists of shares of each symbol brought on date_buy
value_portf = [] # list of porfolio value on date_buy
shares_SPY = []  # list of shares of SPY brought on date_buy
value_SPY = []  # list of value of SPY shares on date_buy 
for date, syms in z_date_syms:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=verbose)

    if next_date_n in idx_close:
        close_date_n = next_date_n
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is in df_close')
        print(f'picks for {date}: {syms}')      
    else:
        close_date_n = None
        print(f'date: {date},  n: {n},  next_date_n: {next_date_n} is not in df_close')
        print(f'picks for {date}: {syms}')        

    if close_date_n is None:
        p_date = None
        p_l_syms = None
        p_ar_price = None
        p_ar_sym_share = None
        p_ar_sym_amt = None
        p_portf_value = None  # data not available in df_close
        
        s_date = None
        s_price = None
        s_share = None
        s_value = None  # data not available in df_close

        date_buy.append(p_date)
        shares_syms.append(p_l_syms)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)    
        
        print(f"No data for next_date_n {next_date_n}, pick's portf value = None")
        print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else:    
        p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
            get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
        s_date, s_price, s_share, s_value = \
            get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
                
        date_buy.append(p_date)
        shares_syms.append(p_ar_sym_share)
        value_portf.append(p_portf_value)
        shares_SPY.append(s_share)
        value_SPY.append(s_value)

        print(f"next_date_n pick's portf value = {p_portf_value}")
        print(f'next_date_n SPY portf value =    {s_value}')

    print('='*20, '\n')
# Out:
# date: 2023-11-02 is in dates_NYSE,  date's position in dates_NYSE is: 2728 of 2767,  n: 1,  idx_date_n: 2729,
# idx_date_n: 2729 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-11-03"
#
# date: 2023-11-02,  n: 1,  next_date_n: 2023-11-03 is not in df_close
# picks for 2023-11-02: ['FTSM', 'SHV']
# No data for next_date_n 2023-11-03, pick's portf value = None
# No data for next_date_n 2023-11-03, SPY portf value =    None
# ====================
#
# date: 2023-11-02 is in dates_NYSE,  date's position in dates_NYSE is: 2728 of 2767,  n: 1,  idx_date_n: 2729,
# idx_date_n: 2729 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-11-03"
#
# date: 2023-11-02,  n: 1,  next_date_n: 2023-11-03 is not in df_close
# picks for 2023-11-02: ['ANF']
# No data for next_date_n 2023-11-03, pick's portf value = None
# No data for next_date_n 2023-11-03, SPY portf value =    None
# ====================
#
# date: 2023-11-01 is in dates_NYSE,  date's position in dates_NYSE is: 2727 of 2767,  n: 1,  idx_date_n: 2728,
# idx_date_n: 2728 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-11-02"
#
# date: 2023-11-01,  n: 1,  next_date_n: 2023-11-02 is in df_close
# picks for 2023-11-01: ['FTSM']
# date = '2023-11-02', l_syms = ['FTSM'], ar_price = array([59.5]), ar_sym_share = array([16.]), ar_sym_amt = array([952.]), portf_value = 952.0
# 2023-11-02 portf_value = 952.0
# date = '2023-11-02', symbol = 'SPY', price = 430.760009765625, share = 2.0, value = 861.52001953125
# 2023-11-02 SPY value = 861.52001953125
# next_date_n pick's portf value = 952.0
# next_date_n SPY portf value =    861.52001953125
# ====================
#
# date: 2023-11-01 is in dates_NYSE,  date's position in dates_NYSE is: 2727 of 2767,  n: 1,  idx_date_n: 2728,
# idx_date_n: 2728 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-11-02"
#
# date: 2023-11-01,  n: 1,  next_date_n: 2023-11-02 is in df_close
# picks for 2023-11-01: ['ANF']
# date = '2023-11-02', l_syms = ['ANF'], ar_price = array([63.31000137]), ar_sym_share = array([15.]), ar_sym_amt = array([949.6500206]), portf_value = 949.6500205993652
# 2023-11-02 portf_value = 949.6500205993652
# date = '2023-11-02', symbol = 'SPY', price = 430.760009765625, share = 2.0, value = 861.52001953125
# 2023-11-02 SPY value = 861.52001953125
# next_date_n pick's portf value = 949.6500205993652
# next_date_n SPY portf value =    861.52001953125
# ====================
#
# date: 2023-10-31 is in dates_NYSE,  date's position in dates_NYSE is: 2726 of 2767,  n: 1,  idx_date_n: 2727,
# idx_date_n: 2727 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-11-01"
#
# date: 2023-10-31,  n: 1,  next_date_n: 2023-11-01 is in df_close
# picks for 2023-10-31: ['SHV']
# date = '2023-11-01', l_syms = ['SHV'], ar_price = array([110.06999969]), ar_sym_share = array([9.]), ar_sym_amt = array([990.62999725]), portf_value = 990.629997253418
# 2023-11-01 portf_value = 990.629997253418
# date = '2023-11-01', symbol = 'SPY', price = 422.6600036621094, share = 2.0, value = 845.3200073242188
# 2023-11-01 SPY value = 845.3200073242188
# next_date_n pick's portf value = 990.629997253418
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date: 2023-10-31 is in dates_NYSE,  date's position in dates_NYSE is: 2726 of 2767,  n: 1,  idx_date_n: 2727,
# idx_date_n: 2727 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-11-01"
#
# date: 2023-10-31,  n: 1,  next_date_n: 2023-11-01 is in df_close
# picks for 2023-10-31: ['ANF', 'SPLK']
# date = '2023-11-01', l_syms = ['ANF', 'SPLK'], ar_price = array([ 62.13000107, 146.88000488]), ar_sym_share = array([8., 3.]), ar_sym_amt = array([497.04000854, 440.64001465]), portf_value = 937.6800231933594
# 2023-11-01 portf_value = 937.6800231933594
# date = '2023-11-01', symbol = 'SPY', price = 422.6600036621094, share = 2.0, value = 845.3200073242188
# 2023-11-01 SPY value = 845.3200073242188
# next_date_n pick's portf value = 937.6800231933594
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date: 2023-10-31 is in dates_NYSE,  date's position in dates_NYSE is: 2726 of 2767,  n: 1,  idx_date_n: 2727,
# idx_date_n: 2727 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-11-01"
#
# date: 2023-10-31,  n: 1,  next_date_n: 2023-11-01 is in df_close
# picks for 2023-10-31: ['SHV']
# date = '2023-11-01', l_syms = ['SHV'], ar_price = array([110.06999969]), ar_sym_share = array([9.]), ar_sym_amt = array([990.62999725]), portf_value = 990.629997253418
# 2023-11-01 portf_value = 990.629997253418
# date = '2023-11-01', symbol = 'SPY', price = 422.6600036621094, share = 2.0, value = 845.3200073242188
# 2023-11-01 SPY value = 845.3200073242188
# next_date_n pick's portf value = 990.629997253418
# next_date_n SPY portf value =    845.3200073242188
# ====================
#
# date: 2023-10-30 is in dates_NYSE,  date's position in dates_NYSE is: 2725 of 2767,  n: 1,  idx_date_n: 2726,
# idx_date_n: 2726 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-31"
#
# date: 2023-10-30,  n: 1,  next_date_n: 2023-10-31 is in df_close
# picks for 2023-10-30: ['FTSM', 'SHV']
# date = '2023-10-31', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.43000031, 110.03200531]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.44000244, 440.12802124]), portf_value = 915.5680236816406
# 2023-10-31 portf_value = 915.5680236816406
# date = '2023-10-31', symbol = 'SPY', price = 418.20001220703125, share = 2.0, value = 836.4000244140625
# 2023-10-31 SPY value = 836.4000244140625
# next_date_n pick's portf value = 915.5680236816406
# next_date_n SPY portf value =    836.4000244140625
# ====================
#
# date: 2023-10-30 is in dates_NYSE,  date's position in dates_NYSE is: 2725 of 2767,  n: 1,  idx_date_n: 2726,
# idx_date_n: 2726 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-31"
#
# date: 2023-10-30,  n: 1,  next_date_n: 2023-10-31 is in df_close
# picks for 2023-10-30: ['SPLK']
# date = '2023-10-31', l_syms = ['SPLK'], ar_price = array([147.16000366]), ar_sym_share = array([6.]), ar_sym_amt = array([882.96002197]), portf_value = 882.9600219726562
# 2023-10-31 portf_value = 882.9600219726562
# date = '2023-10-31', symbol = 'SPY', price = 418.20001220703125, share = 2.0, value = 836.4000244140625
# 2023-10-31 SPY value = 836.4000244140625
# next_date_n pick's portf value = 882.9600219726562
# next_date_n SPY portf value =    836.4000244140625
# ====================
#
# date: 2023-10-30 is in dates_NYSE,  date's position in dates_NYSE is: 2725 of 2767,  n: 1,  idx_date_n: 2726,
# idx_date_n: 2726 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-31"
#
# date: 2023-10-30,  n: 1,  next_date_n: 2023-10-31 is in df_close
# picks for 2023-10-30: ['FTSM', 'SHV']
# date = '2023-10-31', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.43000031, 110.03200531]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.44000244, 440.12802124]), portf_value = 915.5680236816406
# 2023-10-31 portf_value = 915.5680236816406
# date = '2023-10-31', symbol = 'SPY', price = 418.20001220703125, share = 2.0, value = 836.4000244140625
# 2023-10-31 SPY value = 836.4000244140625
# next_date_n pick's portf value = 915.5680236816406
# next_date_n SPY portf value =    836.4000244140625
# ====================
#
# date: 2023-10-27 is in dates_NYSE,  date's position in dates_NYSE is: 2724 of 2767,  n: 1,  idx_date_n: 2725,
# idx_date_n: 2725 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-30"
#
# date: 2023-10-27,  n: 1,  next_date_n: 2023-10-30 is in df_close
# picks for 2023-10-27: ['FTSM', 'SHV']
# date = '2023-10-30', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.44100189, 110.03200531]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.52801514, 440.12802124]), portf_value = 915.6560363769531
# 2023-10-30 portf_value = 915.6560363769531
# date = '2023-10-30', symbol = 'SPY', price = 415.5899963378906, share = 2.0, value = 831.1799926757812
# 2023-10-30 SPY value = 831.1799926757812
# next_date_n pick's portf value = 915.6560363769531
# next_date_n SPY portf value =    831.1799926757812
# ====================
#
# date: 2023-10-27 is in dates_NYSE,  date's position in dates_NYSE is: 2724 of 2767,  n: 1,  idx_date_n: 2725,
# idx_date_n: 2725 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-30"
#
# date: 2023-10-27,  n: 1,  next_date_n: 2023-10-30 is in df_close
# picks for 2023-10-27: ['SPLK']
# date = '2023-10-30', l_syms = ['SPLK'], ar_price = array([147.19999695]), ar_sym_share = array([6.]), ar_sym_amt = array([883.19998169]), portf_value = 883.1999816894531
# 2023-10-30 portf_value = 883.1999816894531
# date = '2023-10-30', symbol = 'SPY', price = 415.5899963378906, share = 2.0, value = 831.1799926757812
# 2023-10-30 SPY value = 831.1799926757812
# next_date_n pick's portf value = 883.1999816894531
# next_date_n SPY portf value =    831.1799926757812
# ====================
#
# date: 2023-10-27 is in dates_NYSE,  date's position in dates_NYSE is: 2724 of 2767,  n: 1,  idx_date_n: 2725,
# idx_date_n: 2725 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-30"
#
# date: 2023-10-27,  n: 1,  next_date_n: 2023-10-30 is in df_close
# picks for 2023-10-27: ['SHV']
# date = '2023-10-30', l_syms = ['SHV'], ar_price = array([110.03200531]), ar_sym_share = array([9.]), ar_sym_amt = array([990.28804779]), portf_value = 990.2880477905273
# 2023-10-30 portf_value = 990.2880477905273
# date = '2023-10-30', symbol = 'SPY', price = 415.5899963378906, share = 2.0, value = 831.1799926757812
# 2023-10-30 SPY value = 831.1799926757812
# next_date_n pick's portf value = 990.2880477905273
# next_date_n SPY portf value =    831.1799926757812
# ====================
#
# date: 2023-10-26 is in dates_NYSE,  date's position in dates_NYSE is: 2723 of 2767,  n: 1,  idx_date_n: 2724,
# idx_date_n: 2724 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-27"
#
# date: 2023-10-26,  n: 1,  next_date_n: 2023-10-27 is in df_close
# picks for 2023-10-26: ['FTSM', 'SHV']
# date = '2023-10-27', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.42605972, 110.02204132]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.40847778, 440.08816528]), portf_value = 915.4966430664062
# 2023-10-27 portf_value = 915.4966430664062
# date = '2023-10-27', symbol = 'SPY', price = 410.67999267578125, share = 2.0, value = 821.3599853515625
# 2023-10-27 SPY value = 821.3599853515625
# next_date_n pick's portf value = 915.4966430664062
# next_date_n SPY portf value =    821.3599853515625
# ====================
#
# date: 2023-10-26 is in dates_NYSE,  date's position in dates_NYSE is: 2723 of 2767,  n: 1,  idx_date_n: 2724,
# idx_date_n: 2724 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-27"
#
# date: 2023-10-26,  n: 1,  next_date_n: 2023-10-27 is in df_close
# picks for 2023-10-26: ['SPLK']
# date = '2023-10-27', l_syms = ['SPLK'], ar_price = array([147.13999939]), ar_sym_share = array([6.]), ar_sym_amt = array([882.83999634]), portf_value = 882.8399963378906
# 2023-10-27 portf_value = 882.8399963378906
# date = '2023-10-27', symbol = 'SPY', price = 410.67999267578125, share = 2.0, value = 821.3599853515625
# 2023-10-27 SPY value = 821.3599853515625
# next_date_n pick's portf value = 882.8399963378906
# next_date_n SPY portf value =    821.3599853515625
# ====================
#
# date: 2023-10-25 is in dates_NYSE,  date's position in dates_NYSE is: 2722 of 2767,  n: 1,  idx_date_n: 2723,
# idx_date_n: 2723 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-26"
#
# date: 2023-10-25,  n: 1,  next_date_n: 2023-10-26 is in df_close
# picks for 2023-10-25: ['FTSM', 'SHV']
# date = '2023-10-26', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.42108536, 110.0021286 ]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.36868286, 440.0085144 ]), portf_value = 915.377197265625
# 2023-10-26 portf_value = 915.377197265625
# date = '2023-10-26', symbol = 'SPY', price = 412.54998779296875, share = 2.0, value = 825.0999755859375
# 2023-10-26 SPY value = 825.0999755859375
# next_date_n pick's portf value = 915.377197265625
# next_date_n SPY portf value =    825.0999755859375
# ====================
#
# date: 2023-10-25 is in dates_NYSE,  date's position in dates_NYSE is: 2722 of 2767,  n: 1,  idx_date_n: 2723,
# idx_date_n: 2723 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-26"
#
# date: 2023-10-25,  n: 1,  next_date_n: 2023-10-26 is in df_close
# picks for 2023-10-25: ['ANF', 'SPLK']
# date = '2023-10-26', l_syms = ['ANF', 'SPLK'], ar_price = array([ 59.84999847, 147.13000488]), ar_sym_share = array([8., 3.]), ar_sym_amt = array([478.79998779, 441.39001465]), portf_value = 920.1900024414062
# 2023-10-26 portf_value = 920.1900024414062
# date = '2023-10-26', symbol = 'SPY', price = 412.54998779296875, share = 2.0, value = 825.0999755859375
# 2023-10-26 SPY value = 825.0999755859375
# next_date_n pick's portf value = 920.1900024414062
# next_date_n SPY portf value =    825.0999755859375
# ====================
#
# date: 2023-10-24 is in dates_NYSE,  date's position in dates_NYSE is: 2721 of 2767,  n: 1,  idx_date_n: 2722,
# idx_date_n: 2722 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-25"
#
# date: 2023-10-24,  n: 1,  next_date_n: 2023-10-25 is in df_close
# picks for 2023-10-24: ['FTSM', 'SHV']
# date = '2023-10-25', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.37626648, 109.93242645]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.01013184, 439.72970581]), portf_value = 914.7398376464844
# 2023-10-25 portf_value = 914.7398376464844
# date = '2023-10-25', symbol = 'SPY', price = 417.54998779296875, share = 2.0, value = 835.0999755859375
# 2023-10-25 SPY value = 835.0999755859375
# next_date_n pick's portf value = 914.7398376464844
# next_date_n SPY portf value =    835.0999755859375
# ====================
#
# date: 2023-10-24 is in dates_NYSE,  date's position in dates_NYSE is: 2721 of 2767,  n: 1,  idx_date_n: 2722,
# idx_date_n: 2722 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-25"
#
# date: 2023-10-24,  n: 1,  next_date_n: 2023-10-25 is in df_close
# picks for 2023-10-24: ['ANF']
# date = '2023-10-25', l_syms = ['ANF'], ar_price = array([61.58000183]), ar_sym_share = array([16.]), ar_sym_amt = array([985.2800293]), portf_value = 985.280029296875
# 2023-10-25 portf_value = 985.280029296875
# date = '2023-10-25', symbol = 'SPY', price = 417.54998779296875, share = 2.0, value = 835.0999755859375
# 2023-10-25 SPY value = 835.0999755859375
# next_date_n pick's portf value = 985.280029296875
# next_date_n SPY portf value =    835.0999755859375
# ====================
#
# date: 2023-10-23 is in dates_NYSE,  date's position in dates_NYSE is: 2720 of 2767,  n: 1,  idx_date_n: 2721,
# idx_date_n: 2721 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-24"
#
# date: 2023-10-23,  n: 1,  next_date_n: 2023-10-24 is in df_close
# picks for 2023-10-23: ['FTSM', 'SHV']
# date = '2023-10-24', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.38622665, 109.93242645]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.08981323, 439.72970581]), portf_value = 914.8195190429688
# 2023-10-24 portf_value = 914.8195190429688
# date = '2023-10-24', symbol = 'SPY', price = 423.6300048828125, share = 2.0, value = 847.260009765625
# 2023-10-24 SPY value = 847.260009765625
# next_date_n pick's portf value = 914.8195190429688
# next_date_n SPY portf value =    847.260009765625
# ====================
#
# date: 2023-10-23 is in dates_NYSE,  date's position in dates_NYSE is: 2720 of 2767,  n: 1,  idx_date_n: 2721,
# idx_date_n: 2721 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-24"
#
# date: 2023-10-23,  n: 1,  next_date_n: 2023-10-24 is in df_close
# picks for 2023-10-23: ['SPLK']
# date = '2023-10-24', l_syms = ['SPLK'], ar_price = array([147.66999817]), ar_sym_share = array([6.]), ar_sym_amt = array([886.01998901]), portf_value = 886.0199890136719
# 2023-10-24 portf_value = 886.0199890136719
# date = '2023-10-24', symbol = 'SPY', price = 423.6300048828125, share = 2.0, value = 847.260009765625
# 2023-10-24 SPY value = 847.260009765625
# next_date_n pick's portf value = 886.0199890136719
# next_date_n SPY portf value =    847.260009765625
# ====================
#
# date: 2023-10-20 is in dates_NYSE,  date's position in dates_NYSE is: 2719 of 2767,  n: 1,  idx_date_n: 2720,
# idx_date_n: 2720 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-23"
#
# date: 2023-10-20,  n: 1,  next_date_n: 2023-10-23 is in df_close
# picks for 2023-10-20: ['FTSM', 'SHV']
# date = '2023-10-23', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.38622665, 109.92247009]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([475.08981323, 439.68988037]), portf_value = 914.7796936035156
# 2023-10-23 portf_value = 914.7796936035156
# date = '2023-10-23', symbol = 'SPY', price = 420.4599914550781, share = 2.0, value = 840.9199829101562
# 2023-10-23 SPY value = 840.9199829101562
# next_date_n pick's portf value = 914.7796936035156
# next_date_n SPY portf value =    840.9199829101562
# ====================
#
# date: 2023-10-19 is in dates_NYSE,  date's position in dates_NYSE is: 2718 of 2767,  n: 1,  idx_date_n: 2719,
# idx_date_n: 2719 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-20"
#
# date: 2023-10-19,  n: 1,  next_date_n: 2023-10-20 is in df_close
# picks for 2023-10-19: ['FTSM', 'SHV']
# date = '2023-10-20', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.35634613, 109.90255737]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.85076904, 439.61022949]), portf_value = 914.4609985351562
# 2023-10-20 portf_value = 914.4609985351562
# date = '2023-10-20', symbol = 'SPY', price = 421.19000244140625, share = 2.0, value = 842.3800048828125
# 2023-10-20 SPY value = 842.3800048828125
# next_date_n pick's portf value = 914.4609985351562
# next_date_n SPY portf value =    842.3800048828125
# ====================
#
# date: 2023-10-19 is in dates_NYSE,  date's position in dates_NYSE is: 2718 of 2767,  n: 1,  idx_date_n: 2719,
# idx_date_n: 2719 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-20"
#
# date: 2023-10-19,  n: 1,  next_date_n: 2023-10-20 is in df_close
# picks for 2023-10-19: ['SHV']
# date = '2023-10-20', l_syms = ['SHV'], ar_price = array([109.90255737]), ar_sym_share = array([9.]), ar_sym_amt = array([989.12301636]), portf_value = 989.1230163574219
# 2023-10-20 portf_value = 989.1230163574219
# date = '2023-10-20', symbol = 'SPY', price = 421.19000244140625, share = 2.0, value = 842.3800048828125
# 2023-10-20 SPY value = 842.3800048828125
# next_date_n pick's portf value = 989.1230163574219
# next_date_n SPY portf value =    842.3800048828125
# ====================
#
# date: 2023-10-17 is in dates_NYSE,  date's position in dates_NYSE is: 2716 of 2767,  n: 1,  idx_date_n: 2717,
# idx_date_n: 2717 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-18"
#
# date: 2023-10-17,  n: 1,  next_date_n: 2023-10-18 is in df_close
# picks for 2023-10-17: ['FTSM', 'SHV']
# date = '2023-10-18', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.30655289, 109.82289124]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.4524231 , 439.29156494]), portf_value = 913.7439880371094
# 2023-10-18 portf_value = 913.7439880371094
# date = '2023-10-18', symbol = 'SPY', price = 430.2099914550781, share = 2.0, value = 860.4199829101562
# 2023-10-18 SPY value = 860.4199829101562
# next_date_n pick's portf value = 913.7439880371094
# next_date_n SPY portf value =    860.4199829101562
# ====================
#
# date: 2023-10-12 is in dates_NYSE,  date's position in dates_NYSE is: 2713 of 2767,  n: 1,  idx_date_n: 2714,
# idx_date_n: 2714 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-13"
#
# date: 2023-10-12,  n: 1,  next_date_n: 2023-10-13 is in df_close
# picks for 2023-10-12: ['FTSM', 'SHV']
# date = '2023-10-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.32647324, 109.79302216]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.61178589, 439.17208862]), portf_value = 913.7838745117188
# 2023-10-13 portf_value = 913.7838745117188
# date = '2023-10-13', symbol = 'SPY', price = 431.5, share = 2.0, value = 863.0
# 2023-10-13 SPY value = 863.0
# next_date_n pick's portf value = 913.7838745117188
# next_date_n SPY portf value =    863.0
# ====================
#
# date: 2023-10-06 is in dates_NYSE,  date's position in dates_NYSE is: 2709 of 2767,  n: 1,  idx_date_n: 2710,
# idx_date_n: 2710 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-09"
#
# date: 2023-10-06,  n: 1,  next_date_n: 2023-10-09 is in df_close
# picks for 2023-10-06: ['FTSM', 'SHV']
# date = '2023-10-09', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.266716 , 109.6934433]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([474.13372803, 438.77377319]), portf_value = 912.9075012207031
# 2023-10-09 portf_value = 912.9075012207031
# date = '2023-10-09', symbol = 'SPY', price = 432.2900085449219, share = 2.0, value = 864.5800170898438
# 2023-10-09 SPY value = 864.5800170898438
# next_date_n pick's portf value = 912.9075012207031
# next_date_n SPY portf value =    864.5800170898438
# ====================
#
# date: 2023-10-06 is in dates_NYSE,  date's position in dates_NYSE is: 2709 of 2767,  n: 1,  idx_date_n: 2710,
# idx_date_n: 2710 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-09"
#
# date: 2023-10-06,  n: 1,  next_date_n: 2023-10-09 is in df_close
# picks for 2023-10-06: ['SHV']
# date = '2023-10-09', l_syms = ['SHV'], ar_price = array([109.6934433]), ar_sym_share = array([9.]), ar_sym_amt = array([987.24098969]), portf_value = 987.2409896850586
# 2023-10-09 portf_value = 987.2409896850586
# date = '2023-10-09', symbol = 'SPY', price = 432.2900085449219, share = 2.0, value = 864.5800170898438
# 2023-10-09 SPY value = 864.5800170898438
# next_date_n pick's portf value = 987.2409896850586
# next_date_n SPY portf value =    864.5800170898438
# ====================
#
# date: 2023-10-05 is in dates_NYSE,  date's position in dates_NYSE is: 2708 of 2767,  n: 1,  idx_date_n: 2709,
# idx_date_n: 2709 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-06"
#
# date: 2023-10-05,  n: 1,  next_date_n: 2023-10-06 is in df_close
# picks for 2023-10-05: ['FTSM', 'SHV']
# date = '2023-10-06', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.23683929, 109.68348694]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.89471436, 438.73394775]), portf_value = 912.628662109375
# 2023-10-06 portf_value = 912.628662109375
# date = '2023-10-06', symbol = 'SPY', price = 429.5400085449219, share = 2.0, value = 859.0800170898438
# 2023-10-06 SPY value = 859.0800170898438
# next_date_n pick's portf value = 912.628662109375
# next_date_n SPY portf value =    859.0800170898438
# ====================
#
# date: 2023-10-05 is in dates_NYSE,  date's position in dates_NYSE is: 2708 of 2767,  n: 1,  idx_date_n: 2709,
# idx_date_n: 2709 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-06"
#
# date: 2023-10-05,  n: 1,  next_date_n: 2023-10-06 is in df_close
# picks for 2023-10-05: ['FTSM', 'SHV']
# date = '2023-10-06', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.23683929, 109.68348694]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.89471436, 438.73394775]), portf_value = 912.628662109375
# 2023-10-06 portf_value = 912.628662109375
# date = '2023-10-06', symbol = 'SPY', price = 429.5400085449219, share = 2.0, value = 859.0800170898438
# 2023-10-06 SPY value = 859.0800170898438
# next_date_n pick's portf value = 912.628662109375
# next_date_n SPY portf value =    859.0800170898438
# ====================
#
# date: 2023-10-04 is in dates_NYSE,  date's position in dates_NYSE is: 2707 of 2767,  n: 1,  idx_date_n: 2708,
# idx_date_n: 2708 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-05"
#
# date: 2023-10-04,  n: 1,  next_date_n: 2023-10-05 is in df_close
# picks for 2023-10-04: ['FTSM', 'SHV']
# date = '2023-10-05', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.24679947, 109.67353058]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.97439575, 438.69412231]), portf_value = 912.6685180664062
# 2023-10-05 portf_value = 912.6685180664062
# date = '2023-10-05', symbol = 'SPY', price = 424.5, share = 2.0, value = 849.0
# 2023-10-05 SPY value = 849.0
# next_date_n pick's portf value = 912.6685180664062
# next_date_n SPY portf value =    849.0
# ====================
#
# date: 2023-10-04 is in dates_NYSE,  date's position in dates_NYSE is: 2707 of 2767,  n: 1,  idx_date_n: 2708,
# idx_date_n: 2708 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-05"
#
# date: 2023-10-04,  n: 1,  next_date_n: 2023-10-05 is in df_close
# picks for 2023-10-04: ['FTSM', 'SHV']
# date = '2023-10-05', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.24679947, 109.67353058]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.97439575, 438.69412231]), portf_value = 912.6685180664062
# 2023-10-05 portf_value = 912.6685180664062
# date = '2023-10-05', symbol = 'SPY', price = 424.5, share = 2.0, value = 849.0
# 2023-10-05 SPY value = 849.0
# next_date_n pick's portf value = 912.6685180664062
# next_date_n SPY portf value =    849.0
# ====================
#
# date: 2023-10-02 is in dates_NYSE,  date's position in dates_NYSE is: 2705 of 2767,  n: 1,  idx_date_n: 2706,
# idx_date_n: 2706 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-03"
#
# date: 2023-10-02,  n: 1,  next_date_n: 2023-10-03 is in df_close
# picks for 2023-10-02: ['FTSM']
# date = '2023-10-03', l_syms = ['FTSM'], ar_price = array([59.18704605]), ar_sym_share = array([16.]), ar_sym_amt = array([946.99273682]), portf_value = 946.9927368164062
# 2023-10-03 portf_value = 946.9927368164062
# date = '2023-10-03', symbol = 'SPY', price = 421.5899963378906, share = 2.0, value = 843.1799926757812
# 2023-10-03 SPY value = 843.1799926757812
# next_date_n pick's portf value = 946.9927368164062
# next_date_n SPY portf value =    843.1799926757812
# ====================
#
# date: 2023-10-02 is in dates_NYSE,  date's position in dates_NYSE is: 2705 of 2767,  n: 1,  idx_date_n: 2706,
# idx_date_n: 2706 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-03"
#
# date: 2023-10-02,  n: 1,  next_date_n: 2023-10-03 is in df_close
# picks for 2023-10-02: ['ANF']
# date = '2023-10-03', l_syms = ['ANF'], ar_price = array([55.49000168]), ar_sym_share = array([18.]), ar_sym_amt = array([998.82003021]), portf_value = 998.8200302124023
# 2023-10-03 portf_value = 998.8200302124023
# date = '2023-10-03', symbol = 'SPY', price = 421.5899963378906, share = 2.0, value = 843.1799926757812
# 2023-10-03 SPY value = 843.1799926757812
# next_date_n pick's portf value = 998.8200302124023
# next_date_n SPY portf value =    843.1799926757812
# ====================
#
# date: 2023-10-02 is in dates_NYSE,  date's position in dates_NYSE is: 2705 of 2767,  n: 1,  idx_date_n: 2706,
# idx_date_n: 2706 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-03"
#
# date: 2023-10-02,  n: 1,  next_date_n: 2023-10-03 is in df_close
# picks for 2023-10-02: ['FTSM']
# date = '2023-10-03', l_syms = ['FTSM'], ar_price = array([59.18704605]), ar_sym_share = array([16.]), ar_sym_amt = array([946.99273682]), portf_value = 946.9927368164062
# 2023-10-03 portf_value = 946.9927368164062
# date = '2023-10-03', symbol = 'SPY', price = 421.5899963378906, share = 2.0, value = 843.1799926757812
# 2023-10-03 SPY value = 843.1799926757812
# next_date_n pick's portf value = 946.9927368164062
# next_date_n SPY portf value =    843.1799926757812
# ====================
#
# date: 2023-09-29 is in dates_NYSE,  date's position in dates_NYSE is: 2704 of 2767,  n: 1,  idx_date_n: 2705,
# idx_date_n: 2705 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-02"
#
# date: 2023-09-29,  n: 1,  next_date_n: 2023-10-02 is in df_close
# picks for 2023-09-29: ['FTSM', 'SHV']
# date = '2023-10-02', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.19700241, 109.56399536]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.57601929, 438.25598145]), portf_value = 911.8320007324219
# 2023-10-02 portf_value = 911.8320007324219
# date = '2023-10-02', symbol = 'SPY', price = 427.30999755859375, share = 2.0, value = 854.6199951171875
# 2023-10-02 SPY value = 854.6199951171875
# next_date_n pick's portf value = 911.8320007324219
# next_date_n SPY portf value =    854.6199951171875
# ====================
#
# date: 2023-09-29 is in dates_NYSE,  date's position in dates_NYSE is: 2704 of 2767,  n: 1,  idx_date_n: 2705,
# idx_date_n: 2705 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-10-02"
#
# date: 2023-09-29,  n: 1,  next_date_n: 2023-10-02 is in df_close
# picks for 2023-09-29: ['SHV']
# date = '2023-10-02', l_syms = ['SHV'], ar_price = array([109.56399536]), ar_sym_share = array([9.]), ar_sym_amt = array([986.07595825]), portf_value = 986.0759582519531
# 2023-10-02 portf_value = 986.0759582519531
# date = '2023-10-02', symbol = 'SPY', price = 427.30999755859375, share = 2.0, value = 854.6199951171875
# 2023-10-02 SPY value = 854.6199951171875
# next_date_n pick's portf value = 986.0759582519531
# next_date_n SPY portf value =    854.6199951171875
# ====================
#
# date: 2023-09-28 is in dates_NYSE,  date's position in dates_NYSE is: 2703 of 2767,  n: 1,  idx_date_n: 2704,
# idx_date_n: 2704 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-29"
#
# date: 2023-09-28,  n: 1,  next_date_n: 2023-09-29 is in df_close
# picks for 2023-09-28: ['FTSM', 'SHV']
# date = '2023-09-29', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.17708206, 109.53910065]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.41665649, 438.15640259]), portf_value = 911.5730590820312
# 2023-09-29 portf_value = 911.5730590820312
# date = '2023-09-29', symbol = 'SPY', price = 427.4800109863281, share = 2.0, value = 854.9600219726562
# 2023-09-29 SPY value = 854.9600219726562
# next_date_n pick's portf value = 911.5730590820312
# next_date_n SPY portf value =    854.9600219726562
# ====================
#
# date: 2023-09-28 is in dates_NYSE,  date's position in dates_NYSE is: 2703 of 2767,  n: 1,  idx_date_n: 2704,
# idx_date_n: 2704 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-29"
#
# date: 2023-09-28,  n: 1,  next_date_n: 2023-09-29 is in df_close
# picks for 2023-09-28: ['CCJ']
# date = '2023-09-29', l_syms = ['CCJ'], ar_price = array([39.63999939]), ar_sym_share = array([25.]), ar_sym_amt = array([990.99998474]), portf_value = 990.9999847412109
# 2023-09-29 portf_value = 990.9999847412109
# date = '2023-09-29', symbol = 'SPY', price = 427.4800109863281, share = 2.0, value = 854.9600219726562
# 2023-09-29 SPY value = 854.9600219726562
# next_date_n pick's portf value = 990.9999847412109
# next_date_n SPY portf value =    854.9600219726562
# ====================
#
# date: 2023-09-28 is in dates_NYSE,  date's position in dates_NYSE is: 2703 of 2767,  n: 1,  idx_date_n: 2704,
# idx_date_n: 2704 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-29"
#
# date: 2023-09-28,  n: 1,  next_date_n: 2023-09-29 is in df_close
# picks for 2023-09-28: ['SHV']
# date = '2023-09-29', l_syms = ['SHV'], ar_price = array([109.53910065]), ar_sym_share = array([9.]), ar_sym_amt = array([985.85190582]), portf_value = 985.8519058227539
# 2023-09-29 portf_value = 985.8519058227539
# date = '2023-09-29', symbol = 'SPY', price = 427.4800109863281, share = 2.0, value = 854.9600219726562
# 2023-09-29 SPY value = 854.9600219726562
# next_date_n pick's portf value = 985.8519058227539
# next_date_n SPY portf value =    854.9600219726562
# ====================
#
# date: 2023-09-25 is in dates_NYSE,  date's position in dates_NYSE is: 2700 of 2767,  n: 1,  idx_date_n: 2701,
# idx_date_n: 2701 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-26"
#
# date: 2023-09-25,  n: 1,  next_date_n: 2023-09-26 is in df_close
# picks for 2023-09-25: ['FTSM', 'SHV']
# date = '2023-09-26', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.14531708, 109.46968842]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.16253662, 437.87875366]), portf_value = 911.0412902832031
# 2023-09-26 portf_value = 911.0412902832031
# date = '2023-09-26', symbol = 'SPY', price = 425.8800048828125, share = 2.0, value = 851.760009765625
# 2023-09-26 SPY value = 851.760009765625
# next_date_n pick's portf value = 911.0412902832031
# next_date_n SPY portf value =    851.760009765625
# ====================
#
# date: 2023-09-22 is in dates_NYSE,  date's position in dates_NYSE is: 2699 of 2767,  n: 1,  idx_date_n: 2700,
# idx_date_n: 2700 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-25"
#
# date: 2023-09-22,  n: 1,  next_date_n: 2023-09-25 is in df_close
# picks for 2023-09-22: ['FTSM', 'SHV']
# date = '2023-09-25', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.16019821, 109.45977783]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.28158569, 437.83911133]), portf_value = 911.1206970214844
# 2023-09-25 portf_value = 911.1206970214844
# date = '2023-09-25', symbol = 'SPY', price = 432.2300109863281, share = 2.0, value = 864.4600219726562
# 2023-09-25 SPY value = 864.4600219726562
# next_date_n pick's portf value = 911.1206970214844
# next_date_n SPY portf value =    864.4600219726562
# ====================
#
# date: 2023-09-22 is in dates_NYSE,  date's position in dates_NYSE is: 2699 of 2767,  n: 1,  idx_date_n: 2700,
# idx_date_n: 2700 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-25"
#
# date: 2023-09-22,  n: 1,  next_date_n: 2023-09-25 is in df_close
# picks for 2023-09-22: ['FTSM', 'SHV']
# date = '2023-09-25', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.16019821, 109.45977783]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.28158569, 437.83911133]), portf_value = 911.1206970214844
# 2023-09-25 portf_value = 911.1206970214844
# date = '2023-09-25', symbol = 'SPY', price = 432.2300109863281, share = 2.0, value = 864.4600219726562
# 2023-09-25 SPY value = 864.4600219726562
# next_date_n pick's portf value = 911.1206970214844
# next_date_n SPY portf value =    864.4600219726562
# ====================
#
# date: 2023-09-21 is in dates_NYSE,  date's position in dates_NYSE is: 2698 of 2767,  n: 1,  idx_date_n: 2699,
# idx_date_n: 2699 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-22"
#
# date: 2023-09-21,  n: 1,  next_date_n: 2023-09-22 is in df_close
# picks for 2023-09-21: ['FTSM', 'SHV']
# date = '2023-09-22', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.13540268, 109.44985199]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.08322144, 437.79940796]), portf_value = 910.8826293945312
# 2023-09-22 portf_value = 910.8826293945312
# date = '2023-09-22', symbol = 'SPY', price = 430.4200134277344, share = 2.0, value = 860.8400268554688
# 2023-09-22 SPY value = 860.8400268554688
# next_date_n pick's portf value = 910.8826293945312
# next_date_n SPY portf value =    860.8400268554688
# ====================
#
# date: 2023-09-21 is in dates_NYSE,  date's position in dates_NYSE is: 2698 of 2767,  n: 1,  idx_date_n: 2699,
# idx_date_n: 2699 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-22"
#
# date: 2023-09-21,  n: 1,  next_date_n: 2023-09-22 is in df_close
# picks for 2023-09-21: ['FTSM', 'SHV']
# date = '2023-09-22', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.13540268, 109.44985199]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([473.08322144, 437.79940796]), portf_value = 910.8826293945312
# 2023-09-22 portf_value = 910.8826293945312
# date = '2023-09-22', symbol = 'SPY', price = 430.4200134277344, share = 2.0, value = 860.8400268554688
# 2023-09-22 SPY value = 860.8400268554688
# next_date_n pick's portf value = 910.8826293945312
# next_date_n SPY portf value =    860.8400268554688
# ====================
#
# date: 2023-09-20 is in dates_NYSE,  date's position in dates_NYSE is: 2697 of 2767,  n: 1,  idx_date_n: 2698,
# idx_date_n: 2698 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-21"
#
# date: 2023-09-20,  n: 1,  next_date_n: 2023-09-21 is in df_close
# picks for 2023-09-20: ['FTSM', 'SHV']
# date = '2023-09-21', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.10068893, 109.43002319]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([472.80551147, 437.72009277]), portf_value = 910.5256042480469
# 2023-09-21 portf_value = 910.5256042480469
# date = '2023-09-21', symbol = 'SPY', price = 431.3900146484375, share = 2.0, value = 862.780029296875
# 2023-09-21 SPY value = 862.780029296875
# next_date_n pick's portf value = 910.5256042480469
# next_date_n SPY portf value =    862.780029296875
# ====================
#
# date: 2023-09-20 is in dates_NYSE,  date's position in dates_NYSE is: 2697 of 2767,  n: 1,  idx_date_n: 2698,
# idx_date_n: 2698 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-21"
#
# date: 2023-09-20,  n: 1,  next_date_n: 2023-09-21 is in df_close
# picks for 2023-09-20: ['SHV']
# date = '2023-09-21', l_syms = ['SHV'], ar_price = array([109.43002319]), ar_sym_share = array([9.]), ar_sym_amt = array([984.87020874]), portf_value = 984.8702087402344
# 2023-09-21 portf_value = 984.8702087402344
# date = '2023-09-21', symbol = 'SPY', price = 431.3900146484375, share = 2.0, value = 862.780029296875
# 2023-09-21 SPY value = 862.780029296875
# next_date_n pick's portf value = 984.8702087402344
# next_date_n SPY portf value =    862.780029296875
# ====================
#
# date: 2023-09-18 is in dates_NYSE,  date's position in dates_NYSE is: 2695 of 2767,  n: 1,  idx_date_n: 2696,
# idx_date_n: 2696 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-19"
#
# date: 2023-09-18,  n: 1,  next_date_n: 2023-09-19 is in df_close
# picks for 2023-09-18: ['SHV']
# date = '2023-09-19', l_syms = ['SHV'], ar_price = array([109.36061859]), ar_sym_share = array([9.]), ar_sym_amt = array([984.24556732]), portf_value = 984.2455673217773
# 2023-09-19 portf_value = 984.2455673217773
# date = '2023-09-19', symbol = 'SPY', price = 442.7099914550781, share = 2.0, value = 885.4199829101562
# 2023-09-19 SPY value = 885.4199829101562
# next_date_n pick's portf value = 984.2455673217773
# next_date_n SPY portf value =    885.4199829101562
# ====================
#
# date: 2023-09-18 is in dates_NYSE,  date's position in dates_NYSE is: 2695 of 2767,  n: 1,  idx_date_n: 2696,
# idx_date_n: 2696 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-19"
#
# date: 2023-09-18,  n: 1,  next_date_n: 2023-09-19 is in df_close
# picks for 2023-09-18: ['FTSM']
# date = '2023-09-19', l_syms = ['FTSM'], ar_price = array([59.08085251]), ar_sym_share = array([16.]), ar_sym_amt = array([945.29364014]), portf_value = 945.2936401367188
# 2023-09-19 portf_value = 945.2936401367188
# date = '2023-09-19', symbol = 'SPY', price = 442.7099914550781, share = 2.0, value = 885.4199829101562
# 2023-09-19 SPY value = 885.4199829101562
# next_date_n pick's portf value = 945.2936401367188
# next_date_n SPY portf value =    885.4199829101562
# ====================
#
# date: 2023-09-15 is in dates_NYSE,  date's position in dates_NYSE is: 2694 of 2767,  n: 1,  idx_date_n: 2695,
# idx_date_n: 2695 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-18"
#
# date: 2023-09-15,  n: 1,  next_date_n: 2023-09-18 is in df_close
# picks for 2023-09-15: ['FTSM', 'SHV']
# date = '2023-09-18', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.08085251, 109.36061859]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([472.64682007, 437.44247437]), portf_value = 910.0892944335938
# 2023-09-18 portf_value = 910.0892944335938
# date = '2023-09-18', symbol = 'SPY', price = 443.6300048828125, share = 2.0, value = 887.260009765625
# 2023-09-18 SPY value = 887.260009765625
# next_date_n pick's portf value = 910.0892944335938
# next_date_n SPY portf value =    887.260009765625
# ====================
#
# date: 2023-09-14 is in dates_NYSE,  date's position in dates_NYSE is: 2693 of 2767,  n: 1,  idx_date_n: 2694,
# idx_date_n: 2694 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-15"
#
# date: 2023-09-14,  n: 1,  next_date_n: 2023-09-15 is in df_close
# picks for 2023-09-14: ['SHV']
# date = '2023-09-15', l_syms = ['SHV'], ar_price = array([109.34078217]), ar_sym_share = array([9.]), ar_sym_amt = array([984.06703949]), portf_value = 984.0670394897461
# 2023-09-15 portf_value = 984.0670394897461
# date = '2023-09-15', symbol = 'SPY', price = 443.3699951171875, share = 2.0, value = 886.739990234375
# 2023-09-15 SPY value = 886.739990234375
# next_date_n pick's portf value = 984.0670394897461
# next_date_n SPY portf value =    886.739990234375
# ====================
#
# date: 2023-09-14 is in dates_NYSE,  date's position in dates_NYSE is: 2693 of 2767,  n: 1,  idx_date_n: 2694,
# idx_date_n: 2694 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-15"
#
# date: 2023-09-14,  n: 1,  next_date_n: 2023-09-15 is in df_close
# picks for 2023-09-14: ['DELL', 'FTSM']
# date = '2023-09-15', l_syms = ['DELL', 'FTSM'], ar_price = array([68.90102386, 59.0709343 ]), ar_sym_share = array([7., 8.]), ar_sym_amt = array([482.30716705, 472.56747437]), portf_value = 954.874641418457
# 2023-09-15 portf_value = 954.874641418457
# date = '2023-09-15', symbol = 'SPY', price = 443.3699951171875, share = 2.0, value = 886.739990234375
# 2023-09-15 SPY value = 886.739990234375
# next_date_n pick's portf value = 954.874641418457
# next_date_n SPY portf value =    886.739990234375
# ====================
#
# date: 2023-09-13 is in dates_NYSE,  date's position in dates_NYSE is: 2692 of 2767,  n: 1,  idx_date_n: 2693,
# idx_date_n: 2693 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-14"
#
# date: 2023-09-13,  n: 1,  next_date_n: 2023-09-14 is in df_close
# picks for 2023-09-13: ['FTSM', 'SHV']
# date = '2023-09-14', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.06101608, 109.33087158]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([472.48812866, 437.32348633]), portf_value = 909.8116149902344
# 2023-09-14 portf_value = 909.8116149902344
# date = '2023-09-14', symbol = 'SPY', price = 448.7770080566406, share = 2.0, value = 897.5540161132812
# 2023-09-14 SPY value = 897.5540161132812
# next_date_n pick's portf value = 909.8116149902344
# next_date_n SPY portf value =    897.5540161132812
# ====================
#
# date: 2023-09-13 is in dates_NYSE,  date's position in dates_NYSE is: 2692 of 2767,  n: 1,  idx_date_n: 2693,
# idx_date_n: 2693 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-14"
#
# date: 2023-09-13,  n: 1,  next_date_n: 2023-09-14 is in df_close
# picks for 2023-09-13: ['DELL']
# date = '2023-09-14', l_syms = ['DELL'], ar_price = array([70.76052856]), ar_sym_share = array([14.]), ar_sym_amt = array([990.6473999]), portf_value = 990.6473999023438
# 2023-09-14 portf_value = 990.6473999023438
# date = '2023-09-14', symbol = 'SPY', price = 448.7770080566406, share = 2.0, value = 897.5540161132812
# 2023-09-14 SPY value = 897.5540161132812
# next_date_n pick's portf value = 990.6473999023438
# next_date_n SPY portf value =    897.5540161132812
# ====================
#
# date: 2023-09-12 is in dates_NYSE,  date's position in dates_NYSE is: 2691 of 2767,  n: 1,  idx_date_n: 2692,
# idx_date_n: 2692 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-13"
#
# date: 2023-09-12,  n: 1,  next_date_n: 2023-09-13 is in df_close
# picks for 2023-09-12: ['FTSM', 'SHV']
# date = '2023-09-13', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.06597519, 109.28128815]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([472.52780151, 437.12515259]), portf_value = 909.6529541015625
# 2023-09-13 portf_value = 909.6529541015625
# date = '2023-09-13', symbol = 'SPY', price = 444.9405517578125, share = 2.0, value = 889.881103515625
# 2023-09-13 SPY value = 889.881103515625
# next_date_n pick's portf value = 909.6529541015625
# next_date_n SPY portf value =    889.881103515625
# ====================
#
# date: 2023-09-12 is in dates_NYSE,  date's position in dates_NYSE is: 2691 of 2767,  n: 1,  idx_date_n: 2692,
# idx_date_n: 2692 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-13"
#
# date: 2023-09-12,  n: 1,  next_date_n: 2023-09-13 is in df_close
# picks for 2023-09-12: ['DELL', 'MMYT']
# date = '2023-09-13', l_syms = ['DELL', 'MMYT'], ar_price = array([70.05451202, 39.54999924]), ar_sym_share = array([ 7., 12.]), ar_sym_amt = array([490.38158417, 474.59999084]), portf_value = 964.981575012207
# 2023-09-13 portf_value = 964.981575012207
# date = '2023-09-13', symbol = 'SPY', price = 444.9405517578125, share = 2.0, value = 889.881103515625
# 2023-09-13 SPY value = 889.881103515625
# next_date_n pick's portf value = 964.981575012207
# next_date_n SPY portf value =    889.881103515625
# ====================
#
# date: 2023-09-11 is in dates_NYSE,  date's position in dates_NYSE is: 2690 of 2767,  n: 1,  idx_date_n: 2691,
# idx_date_n: 2691 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-12"
#
# date: 2023-09-11,  n: 1,  next_date_n: 2023-09-12 is in df_close
# picks for 2023-09-11: ['DELL', 'FTSM', 'SHV']
# date = '2023-09-12', l_syms = ['DELL', 'FTSM', 'SHV'], ar_price = array([ 70.33294678,  59.04117584, 109.26145935]), ar_sym_share = array([4., 5., 3.]), ar_sym_amt = array([281.33178711, 295.20587921, 327.78437805]), portf_value = 904.3220443725586
# 2023-09-12 portf_value = 904.3220443725586
# date = '2023-09-12', symbol = 'SPY', price = 444.42236328125, share = 2.0, value = 888.8447265625
# 2023-09-12 SPY value = 888.8447265625
# next_date_n pick's portf value = 904.3220443725586
# next_date_n SPY portf value =    888.8447265625
# ====================
#
# date: 2023-09-11 is in dates_NYSE,  date's position in dates_NYSE is: 2690 of 2767,  n: 1,  idx_date_n: 2691,
# idx_date_n: 2691 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-12"
#
# date: 2023-09-11,  n: 1,  next_date_n: 2023-09-12 is in df_close
# picks for 2023-09-11: ['DELL']
# date = '2023-09-12', l_syms = ['DELL'], ar_price = array([70.33294678]), ar_sym_share = array([14.]), ar_sym_amt = array([984.66125488]), portf_value = 984.6612548828125
# 2023-09-12 portf_value = 984.6612548828125
# date = '2023-09-12', symbol = 'SPY', price = 444.42236328125, share = 2.0, value = 888.8447265625
# 2023-09-12 SPY value = 888.8447265625
# next_date_n pick's portf value = 984.6612548828125
# next_date_n SPY portf value =    888.8447265625
# ====================
#
# date: 2023-09-08 is in dates_NYSE,  date's position in dates_NYSE is: 2689 of 2767,  n: 1,  idx_date_n: 2690,
# idx_date_n: 2690 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-11"
#
# date: 2023-09-08,  n: 1,  next_date_n: 2023-09-11 is in df_close
# picks for 2023-09-08: ['FTSM', 'SHV']
# date = '2023-09-11', l_syms = ['FTSM', 'SHV'], ar_price = array([ 59.04117584, 109.25154877]), ar_sym_share = array([8., 4.]), ar_sym_amt = array([472.32940674, 437.00619507]), portf_value = 909.3356018066406
# 2023-09-11 portf_value = 909.3356018066406
# date = '2023-09-11', symbol = 'SPY', price = 446.8737487792969, share = 2.0, value = 893.7474975585938
# 2023-09-11 SPY value = 893.7474975585938
# next_date_n pick's portf value = 909.3356018066406
# next_date_n SPY portf value =    893.7474975585938
# ====================
#
# date: 2023-09-08 is in dates_NYSE,  date's position in dates_NYSE is: 2689 of 2767,  n: 1,  idx_date_n: 2690,
# idx_date_n: 2690 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-11"
#
# date: 2023-09-08,  n: 1,  next_date_n: 2023-09-11 is in df_close
# picks for 2023-09-08: ['DELL', 'STRL']
# date = '2023-09-11', l_syms = ['DELL', 'STRL'], ar_price = array([71.75491333, 77.43000031]), ar_sym_share = array([6., 6.]), ar_sym_amt = array([430.52947998, 464.58000183]), portf_value = 895.1094818115234
# 2023-09-11 portf_value = 895.1094818115234
# date = '2023-09-11', symbol = 'SPY', price = 446.8737487792969, share = 2.0, value = 893.7474975585938
# 2023-09-11 SPY value = 893.7474975585938
# next_date_n pick's portf value = 895.1094818115234
# next_date_n SPY portf value =    893.7474975585938
# ====================
#
# date: 2023-09-05 is in dates_NYSE,  date's position in dates_NYSE is: 2686 of 2767,  n: 1,  idx_date_n: 2687,
# idx_date_n: 2687 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-06"
#
# date: 2023-09-05,  n: 1,  next_date_n: 2023-09-06 is in df_close
# picks for 2023-09-05: ['SHV']
# date = '2023-09-06', l_syms = ['SHV'], ar_price = array([109.16230011]), ar_sym_share = array([9.]), ar_sym_amt = array([982.46070099]), portf_value = 982.4607009887695
# 2023-09-06 portf_value = 982.4607009887695
# date = '2023-09-06', symbol = 'SPY', price = 444.65155029296875, share = 2.0, value = 889.3031005859375
# 2023-09-06 SPY value = 889.3031005859375
# next_date_n pick's portf value = 982.4607009887695
# next_date_n SPY portf value =    889.3031005859375
# ====================
#
# date: 2023-09-05 is in dates_NYSE,  date's position in dates_NYSE is: 2686 of 2767,  n: 1,  idx_date_n: 2687,
# idx_date_n: 2687 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-09-06"
#
# ...
# next_date_n SPY portf value =    829.6806640625
# ====================
#
# date: 2023-05-30 is in dates_NYSE,  date's position in dates_NYSE is: 2619 of 2767,  n: 1,  idx_date_n: 2620,
# idx_date_n: 2620 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-31"
#
# date: 2023-05-30,  n: 1,  next_date_n: 2023-05-31 is in df_close
# picks for 2023-05-30: ['AVGO', 'NVDA']
# date = '2023-05-31', l_syms = ['AVGO', 'NVDA'], ar_price = array([799.32501221, 378.26968384]), ar_sym_share = array([0., 1.]), ar_sym_amt = array([  0.        , 378.26968384]), portf_value = 378.2696838378906
# 2023-05-31 portf_value = 378.2696838378906
# date = '2023-05-31', symbol = 'SPY', price = 414.84033203125, share = 2.0, value = 829.6806640625
# 2023-05-31 SPY value = 829.6806640625
# next_date_n pick's portf value = 378.2696838378906
# next_date_n SPY portf value =    829.6806640625
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['AVGO', 'SHV']
# date = '2023-05-30', l_syms = ['AVGO', 'SHV'], ar_price = array([794.7543335 , 107.64565277]), ar_sym_share = array([0., 4.]), ar_sym_amt = array([  0.        , 430.58261108]), portf_value = 430.5826110839844
# 2023-05-30 portf_value = 430.5826110839844
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 430.5826110839844
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['NVDA']
# date = '2023-05-30', l_syms = ['NVDA'], ar_price = array([401.03543091]), ar_sym_share = array([2.]), ar_sym_amt = array([802.07086182]), portf_value = 802.0708618164062
# 2023-05-30 portf_value = 802.0708618164062
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 802.0708618164062
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-26 is in dates_NYSE,  date's position in dates_NYSE is: 2618 of 2767,  n: 1,  idx_date_n: 2619,
# idx_date_n: 2619 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-30"
#
# date: 2023-05-26,  n: 1,  next_date_n: 2023-05-30 is in df_close
# picks for 2023-05-26: ['AVGO']
# date = '2023-05-30', l_syms = ['AVGO'], ar_price = array([794.7543335]), ar_sym_share = array([1.]), ar_sym_amt = array([794.7543335]), portf_value = 794.7543334960938
# 2023-05-30 portf_value = 794.7543334960938
# date = '2023-05-30', symbol = 'SPY', price = 417.1535339355469, share = 2.0, value = 834.3070678710938
# 2023-05-30 SPY value = 834.3070678710938
# next_date_n pick's portf value = 794.7543334960938
# next_date_n SPY portf value =    834.3070678710938
# ====================
#
# date: 2023-05-25 is in dates_NYSE,  date's position in dates_NYSE is: 2617 of 2767,  n: 1,  idx_date_n: 2618,
# idx_date_n: 2618 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-26"
#
# date: 2023-05-25,  n: 1,  next_date_n: 2023-05-26 is in df_close
# picks for 2023-05-25: ['SHV']
# date = '2023-05-26', l_syms = ['SHV'], ar_price = array([107.6359024]), ar_sym_share = array([9.]), ar_sym_amt = array([968.72312164]), portf_value = 968.7231216430664
# 2023-05-26 portf_value = 968.7231216430664
# date = '2023-05-26', symbol = 'SPY', price = 416.9946594238281, share = 2.0, value = 833.9893188476562
# 2023-05-26 SPY value = 833.9893188476562
# next_date_n pick's portf value = 968.7231216430664
# next_date_n SPY portf value =    833.9893188476562
# ====================
#
# date: 2023-05-25 is in dates_NYSE,  date's position in dates_NYSE is: 2617 of 2767,  n: 1,  idx_date_n: 2618,
# idx_date_n: 2618 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-26"
#
# date: 2023-05-25,  n: 1,  next_date_n: 2023-05-26 is in df_close
# picks for 2023-05-25: ['FTSM', 'NVDA']
# date = '2023-05-26', l_syms = ['FTSM', 'NVDA'], ar_price = array([ 58.22890472, 389.38763428]), ar_sym_share = array([8., 1.]), ar_sym_amt = array([465.83123779, 389.38763428]), portf_value = 855.2188720703125
# 2023-05-26 portf_value = 855.2188720703125
# date = '2023-05-26', symbol = 'SPY', price = 416.9946594238281, share = 2.0, value = 833.9893188476562
# 2023-05-26 SPY value = 833.9893188476562
# next_date_n pick's portf value = 855.2188720703125
# next_date_n SPY portf value =    833.9893188476562
# ====================
#
# date: 2023-05-24 is in dates_NYSE,  date's position in dates_NYSE is: 2616 of 2767,  n: 1,  idx_date_n: 2617,
# idx_date_n: 2617 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-25"
#
# date: 2023-05-24,  n: 1,  next_date_n: 2023-05-25 is in df_close
# picks for 2023-05-24: ['SHV']
# date = '2023-05-25', l_syms = ['SHV'], ar_price = array([107.61639404]), ar_sym_share = array([9.]), ar_sym_amt = array([968.54754639]), portf_value = 968.5475463867188
# 2023-05-25 portf_value = 968.5475463867188
# date = '2023-05-25', symbol = 'SPY', price = 411.6633605957031, share = 2.0, value = 823.3267211914062
# 2023-05-25 SPY value = 823.3267211914062
# next_date_n pick's portf value = 968.5475463867188
# next_date_n SPY portf value =    823.3267211914062
# ====================
#
# date: 2023-05-23 is in dates_NYSE,  date's position in dates_NYSE is: 2615 of 2767,  n: 1,  idx_date_n: 2616,
# idx_date_n: 2616 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-24"
#
# date: 2023-05-23,  n: 1,  next_date_n: 2023-05-24 is in df_close
# picks for 2023-05-23: ['SHV']
# date = '2023-05-24', l_syms = ['SHV'], ar_price = array([107.56764984]), ar_sym_share = array([9.]), ar_sym_amt = array([968.10884857]), portf_value = 968.1088485717773
# 2023-05-24 portf_value = 968.1088485717773
# date = '2023-05-24', symbol = 'SPY', price = 408.1289978027344, share = 2.0, value = 816.2579956054688
# 2023-05-24 SPY value = 816.2579956054688
# next_date_n pick's portf value = 968.1088485717773
# next_date_n SPY portf value =    816.2579956054688
# ====================
#
# date: 2023-05-22 is in dates_NYSE,  date's position in dates_NYSE is: 2614 of 2767,  n: 1,  idx_date_n: 2615,
# idx_date_n: 2615 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-23"
#
# date: 2023-05-22,  n: 1,  next_date_n: 2023-05-23 is in df_close
# picks for 2023-05-22: ['SHV']
# date = '2023-05-23', l_syms = ['SHV'], ar_price = array([107.56764984]), ar_sym_share = array([9.]), ar_sym_amt = array([968.10884857]), portf_value = 968.1088485717773
# 2023-05-23 portf_value = 968.1088485717773
# date = '2023-05-23', symbol = 'SPY', price = 411.107421875, share = 2.0, value = 822.21484375
# 2023-05-23 SPY value = 822.21484375
# next_date_n pick's portf value = 968.1088485717773
# next_date_n SPY portf value =    822.21484375
# ====================
#
# date: 2023-05-19 is in dates_NYSE,  date's position in dates_NYSE is: 2613 of 2767,  n: 1,  idx_date_n: 2614,
# idx_date_n: 2614 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-22"
#
# date: 2023-05-19,  n: 1,  next_date_n: 2023-05-22 is in df_close
# picks for 2023-05-19: ['SHV']
# date = '2023-05-22', l_syms = ['SHV'], ar_price = array([107.54814148]), ar_sym_share = array([9.]), ar_sym_amt = array([967.93327332]), portf_value = 967.9332733154297
# 2023-05-22 portf_value = 967.9332733154297
# date = '2023-05-22', symbol = 'SPY', price = 415.7735595703125, share = 2.0, value = 831.547119140625
# 2023-05-22 SPY value = 831.547119140625
# next_date_n pick's portf value = 967.9332733154297
# next_date_n SPY portf value =    831.547119140625
# ====================
#
# date: 2023-05-18 is in dates_NYSE,  date's position in dates_NYSE is: 2612 of 2767,  n: 1,  idx_date_n: 2613,
# idx_date_n: 2613 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-19"
#
# date: 2023-05-18,  n: 1,  next_date_n: 2023-05-19 is in df_close
# picks for 2023-05-18: ['SHV', 'TMHC']
# date = '2023-05-19', l_syms = ['SHV', 'TMHC'], ar_price = array([107.54814148,  44.25      ]), ar_sym_share = array([ 4., 11.]), ar_sym_amt = array([430.19256592, 486.75      ]), portf_value = 916.9425659179688
# 2023-05-19 portf_value = 916.9425659179688
# date = '2023-05-19', symbol = 'SPY', price = 415.6047668457031, share = 2.0, value = 831.2095336914062
# 2023-05-19 SPY value = 831.2095336914062
# next_date_n pick's portf value = 916.9425659179688
# next_date_n SPY portf value =    831.2095336914062
# ====================
#
# date: 2023-05-17 is in dates_NYSE,  date's position in dates_NYSE is: 2611 of 2767,  n: 1,  idx_date_n: 2612,
# idx_date_n: 2612 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-18"
#
# date: 2023-05-17,  n: 1,  next_date_n: 2023-05-18 is in df_close
# picks for 2023-05-17: ['SHV']
# date = '2023-05-18', l_syms = ['SHV'], ar_price = array([107.54814148]), ar_sym_share = array([9.]), ar_sym_amt = array([967.93327332]), portf_value = 967.9332733154297
# 2023-05-18 portf_value = 967.9332733154297
# date = '2023-05-18', symbol = 'SPY', price = 416.21038818359375, share = 2.0, value = 832.4207763671875
# 2023-05-18 SPY value = 832.4207763671875
# next_date_n pick's portf value = 967.9332733154297
# next_date_n SPY portf value =    832.4207763671875
# ====================
#
# date: 2023-05-16 is in dates_NYSE,  date's position in dates_NYSE is: 2610 of 2767,  n: 1,  idx_date_n: 2611,
# idx_date_n: 2611 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-17"
#
# date: 2023-05-16,  n: 1,  next_date_n: 2023-05-17 is in df_close
# picks for 2023-05-16: ['SHV']
# date = '2023-05-17', l_syms = ['SHV'], ar_price = array([107.51889801]), ar_sym_share = array([9.]), ar_sym_amt = array([967.67008209]), portf_value = 967.6700820922852
# 2023-05-17 portf_value = 967.6700820922852
# date = '2023-05-17', symbol = 'SPY', price = 412.23919677734375, share = 2.0, value = 824.4783935546875
# 2023-05-17 SPY value = 824.4783935546875
# next_date_n pick's portf value = 967.6700820922852
# next_date_n SPY portf value =    824.4783935546875
# ====================
#
# date: 2023-05-15 is in dates_NYSE,  date's position in dates_NYSE is: 2609 of 2767,  n: 1,  idx_date_n: 2610,
# idx_date_n: 2610 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-16"
#
# date: 2023-05-15,  n: 1,  next_date_n: 2023-05-16 is in df_close
# picks for 2023-05-15: ['SHV']
# date = '2023-05-16', l_syms = ['SHV'], ar_price = array([107.49938965]), ar_sym_share = array([9.]), ar_sym_amt = array([967.49450684]), portf_value = 967.4945068359375
# 2023-05-16 portf_value = 967.4945068359375
# date = '2023-05-16', symbol = 'SPY', price = 407.2950439453125, share = 2.0, value = 814.590087890625
# 2023-05-16 SPY value = 814.590087890625
# next_date_n pick's portf value = 967.4945068359375
# next_date_n SPY portf value =    814.590087890625
# ====================
#
# date: 2023-05-12 is in dates_NYSE,  date's position in dates_NYSE is: 2608 of 2767,  n: 1,  idx_date_n: 2609,
# idx_date_n: 2609 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-15"
#
# date: 2023-05-12,  n: 1,  next_date_n: 2023-05-15 is in df_close
# picks for 2023-05-12: ['SHV']
# date = '2023-05-15', l_syms = ['SHV'], ar_price = array([107.49938965]), ar_sym_share = array([9.]), ar_sym_amt = array([967.49450684]), portf_value = 967.4945068359375
# 2023-05-15 portf_value = 967.4945068359375
# date = '2023-05-15', symbol = 'SPY', price = 410.03515625, share = 2.0, value = 820.0703125
# 2023-05-15 SPY value = 820.0703125
# next_date_n pick's portf value = 967.4945068359375
# next_date_n SPY portf value =    820.0703125
# ====================
#
# date: 2023-05-11 is in dates_NYSE,  date's position in dates_NYSE is: 2607 of 2767,  n: 1,  idx_date_n: 2608,
# idx_date_n: 2608 is wiithin bounds of dates_NYSE ("0 to 2767), date_n: 2023-05-12"
#
# date: 2023-05-11,  n: 1,  next_date_n: 2023-05-12 is in df_close
# picks for 2023-05-11: ['ISEE', 'SHV']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 51
#      47     print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')
#      49 else:
#      50     p_date, p_l_syms, p_ar_price, p_ar_sym_share, p_ar_sym_amt, p_portf_value = \
# ---> 51         get_portf_buy(df_close, next_date_n, syms, portf_target=1000, verbose=verbose)
#      52     s_date, s_price, s_share, s_value = \
#      53         get_SPY_buy(df_close, next_date_n, portf_target=1000, verbose=verbose)
#      55     date_buy.append(p_date)
#
# Cell In[17], line 6, in get_portf_buy(df_close, date, str_symbols, portf_target, verbose)
#       4 l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
#       5 # array of closing prices corresponding to symbols in l_syms
# ----> 6 ar_price = df_close.loc[date][l_syms].values
#       7 sym_cnt = len(l_syms)  # number of symbols
#       8 amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     key = np.asarray(key, dtype=bool)
#    1005     return self._get_values(key)
# -> 1007 return self._get_with(key)
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\series.py:1047, in Series._get_with(self, key)
#    1044         return self.iloc[key]
#    1046 # handle the dup indexing case GH#4246
# -> 1047 return self.loc[key]
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1239, in _LocIndexer._getitem_iterable(self, key, axis)
#    1236 self._validate_key(key, axis)
#    1238 # A collection of keys
# -> 1239 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240 return self.obj._reindex_with_indexers(
#    1241     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1242 )
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1429 ax = self.obj._get_axis(axis)
#    1430 axis_name = self.obj._get_axis_name(axis)
# -> 1432 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434 return keyarr, indexer
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\ping\MyDrive\py_files\python\py3810\.venv\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['ISEE'] not in index"

# %% [markdown]
# #### Below cells calculate past performance of model picks

# %%
def calc_portf_shares(df_close, date, str_symbols, portf_target):
  # calculate number of shares to buy for symbols in str_symbols to meet port_target
  import numpy as np
  from ast import literal_eval    
  l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
  # array of closing prices corresponding to symbols in l_syms    
  ar_price = df_close.loc[date][l_syms].values  
  sym_cnt = len(l_syms)  # number of symbols
  amt_per_sym = portf_target / sym_cnt  # target dollar investment in each symbol
  ar_shares = np.floor(amt_per_sym / ar_price)  # array of shares for each symbol
  return ar_shares

# %%
def calc_portf_value(df_close, date, str_symbols, ar_shares, verbose=False):
    import numpy as np
    from ast import literal_eval    
    l_syms = literal_eval(str_symbols)  # convert list stored as str back to list
    # array of closing prices corresponding to symbols in l_syms    
    ar_price = df_close.loc[date][l_syms].values  
    ar_value = ar_price * ar_shares  # array of actual dollar amount invested in each symbol
    portf_value = sum(ar_value)  # total actual portfolio value
    if verbose:
        print(f'{date = }, {l_syms = }, {ar_price = }, {ar_shares = }, {ar_value = }, {portf_value = }')            
        print(f'{date} {portf_value = }')
    return date, l_syms, ar_price, ar_shares, ar_value, portf_value

# %%
def get_next_date_n(df_close, date, n=1):

    """Get the next n(default=1) date from df_close. date has to in df_close.index.

    Edge case: The function won't return the first date in df_close as the
    next trading date, if date is a trading date just before the first date in df_close.
    """

    len_df_close = len(df_close)
    idx_dates = df_close.index.strftime('%Y-%m-%d')  # date index of df_close    

    if date in idx_dates:
        idx_next_date = idx_dates.get_loc(date) + n  # get index position of next date
        print(f'n: {n},  idx_next_date: {idx_next_date}')

        if idx_next_date >= 0:  # if idx_nex_date is negative, stop index loop back from index[0] to index[-1]    
            if idx_next_date >= (len_df_close - n):  # next date's index is within bound of df_close
                next_date = idx_dates[idx_dates.get_loc(date) + n]  # get the next date
                return next_date
        
              
            else:  # idx_next_date is out-of_bounds df_close
                print(f"{date} is the last date in df_close. No data for next {n} day")
                return None    
        
        
        else:  # idx_next_date is negative, no data in df_close
            # no data from df_close
            print(f'idx_next_date: {idx_next_date} is negative, no data for {n} days from {date} in df_close')

    else:     
        # no data from df_close
        print(f'no data for {date} in df_close')
        return None

# %%
def is_date_in_close(date, df_close):
  idx_close = df_close.index.strftime('%Y-%m-%d')
  if date in idx_close:
    return date
  else:
    return None

# %%
def calc_portf_value_date_buy(my_dates, my_symbols, df_close, portf_target, n, verbose=False):
  
  z_date_syms = zip(my_dates, my_symbols)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, syms in z_date_syms:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date = None
      p_ar_shares = None
      p_portf_value = None  # set to None when data are not available in df_close
      SPY_shares = None
      SPY_value = None  # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        print(f'No data for close_date_n {close_date_n}, SPY portf value =    None')

    else:    
      p_ar_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      p_date, l_syms, ar_price, ar_shares, ar_value, p_portf_value = \
        calc_portf_value(df_close, close_date_n, syms, p_ar_shares, verbose)

      syms = str(['SPY'])
      SPY_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      date, l_syms, ar_price, ar_shares, ar_value, SPY_value = \
        calc_portf_value(df_close, close_date_n, syms, SPY_shares, verbose)

      if verbose:
        print(f"close_date_n pick's portf value = {p_portf_value}")
        print(f'close_date_n SPY portf value =    {SPY_value}')

    date_exec.append(p_date)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_portf_value)
    shares_SPY.append(SPY_shares)
    value_SPY.append(SPY_value)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
def calc_portf_value_date_n(my_dates, my_symbols, df_close, my_portf_shares, my_SPY_shares, n, verbose=False):
  
  z_date_syms_shares = zip(my_dates, my_symbols, my_portf_shares, my_SPY_shares)

  date_exec = []  # buy date of portfolio
  shares_syms = []  # lists of shares of each symbol brought on date
  value_portf = [] # list of porfolio value on date
  shares_SPY = []  # list of shares of SPY brought on date
  value_SPY = []  # list of value of SPY shares on date 

  for date, symbols, portf_shares, SPY_shares in z_date_syms_shares:
    next_date_n = get_NYSE_date_n(date, dates_NYSE_2013_2023, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    if close_date_n is None:
      p_date_exec = None
      p_ar_shares = None
      p_value_portf = None  # set to None when data are not available in df_close
      SPY_ar_shares = None
      SPY_value_portf = None # set to None when data are not available in df_close

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        # print(f'No data for next_date_n {next_date_n}, SPY portf value =    None')

    else: 
      if portf_shares is None:
        p_date_exec = None
        p_ar_shares = None
        p_value_portf = None
        SPY_ar_shares = None
        SPY_value_portf = None

      else:  
        p_date_exec, p_ar_syms, p_ar_price, p_ar_shares, p_ar_value, p_value_portf = \
          calc_portf_value(df_close, close_date_n, symbols, portf_shares, verbose)
        
        SPY = str(['SPY'])
        SPY_date_exec, SPY_ar_syms, SPY_ar_price, SPY_ar_shares, SPY_ar_value, SPY_value_portf = \
          calc_portf_value(df_close, close_date_n, SPY, SPY_shares, verbose) 

        if verbose:
          print(f"next_date_n pick's portf value = {p_value_portf}")
          print(f'next_date_n SPY portf value =    {SPY_value_portf}')

    date_exec.append(p_date_exec)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_value_portf)
    shares_SPY.append(SPY_ar_shares)
    value_SPY.append(SPY_value_portf)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
# total target investment for each day's picks, if day's pick has 2 symbols, the function will try to invest $500 for each symbol
portf_target = 1000  
date_buy, shares_syms, value_portf, shares_SPY, value_SPY = calc_portf_value_date_buy(df_mp.date, df_mp.symbols, df_close, portf_target, n=1, verbose=verbose)

# %%
df_mp['date_buy'] = date_buy
df_mp['sh_portf_buy'] = shares_syms
df_mp['$_portf_buy'] = value_portf
df_mp['sh_SPY_buy'] = shares_SPY
df_mp['$_SPY_buy'] = value_SPY
# df_mp.tail()
# df_mp.head()
df_mp

# %%
date_exec, shares_syms, value_portf, shares_SPY, value_SPY  = \
  calc_portf_value_date_n(df_mp.date, df_mp.symbols, df_close, df_mp.sh_portf_buy, df_mp.sh_SPY_buy, n=4, verbose=verbose)

# %%
df_mp['date_sell'] = date_exec
df_mp['sh_portf_sell'] = shares_syms
df_mp['$_portf_sell'] = value_portf
df_mp['%_portf_chg'] = (df_mp['$_portf_sell'] / df_mp['$_portf_buy'] - 1) * 100

df_mp['sh_SPY_sell'] = shares_SPY
df_mp['$_SPY_sell'] = value_SPY
df_mp['%_SPY_chg'] = (df_mp['$_SPY_sell'] / df_mp['$_SPY_buy'] - 1) * 100

df_mp['dif_%_chg'] = df_mp['%_portf_chg'] - df_mp['%_SPY_chg']

# %%
# get symbol's close price for that date
date = '2023-03-16'
# _date = '2023-03-21'
# _sym = 'GE'
# _sym = 'NVDA'
_sym = 'FTSM'
# _sym = 'SHV'
_sym = 'SPY'
# _c = df_close.loc['2023-04-11']['NVDA']
_c = df_close.loc[_date][_sym]
_c

# %% [markdown]
# #### dif_%_chg is the percentage change of model icks - percentage change of SPY

# %%
df_mp.head(20)

# %%
df_mp['win'] = np.where(df_mp['dif_%_chg']>0,1,0)
df_mp.head(20)

# %% [markdown]
# ### Model Performance Not Good

# %%
wins = df_mp['win'].sum()
attempts = len(df_mp['dif_%_chg'].dropna())

win_rate = wins / attempts
print(f'win_rate: {win_rate:0.6f}, wins: {wins}, attempts: {attempts}')
print(f'sum(dff_%_chg): {df_mp["dif_%_chg"].sum():0.6f}')

# %%
df = df_mp.copy()

# %%
df_model_picks = df[df['dif_%_chg'].isnull()].copy()
pickle_dump(df_model_picks, path_data_dump, 'df_model_picks')
_df = pickle_load(path_data_dump, 'df_model_picks')
_df

# %%
idx_last_row = df_model_picks.index[-1]
df_model_picks_results = df.iloc[(idx_last_row + 1)::].copy()
pickle_dump(df_model_picks_results, path_data_dump, 'df_model_picks_results')
_df = pickle_load(path_data_dump, 'df_model_picks_results')
_df
