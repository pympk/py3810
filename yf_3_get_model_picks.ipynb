# %%
# # create empty DataFrame df_picks and append row
# my_cols = ['date', 'days_lookback', 'syms_freq', 'symbols']
# # Creating Empty DataFrame and Storing it in variable df_picks
# df_model_top_picks = pd.DataFrame(columns=my_cols)
# df_model_top_picks

# %%
import pandas as pd
from itertools import product
from ast import literal_eval
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.width', 900)

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
path_data_dump = path_dir + "VSCode_dump/"

fp_df_picks  = f'df_picks'  # stock picks by criteria: CAGR/UI, CAGR/rtn_std, rtd/UI
fp_df_model_top_picks = f'df_model_top_picks'  # top stock picks from model developed by back test

verbose = True
# verbose = False

# %% [markdown]
# #### Clean df_picks_pick data:<br>- drop duplicates<br>- sort on date<br>- re-index<br>- save

# %%
df_picks = pickle_load(path_data_dump, fp_df_picks)
df_picks = df_picks.drop_duplicates(subset=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], keep='last')
df_picks = df_picks.sort_values(by=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], ascending=False)
df_picks = df_picks.reset_index(drop=True)
pickle_dump(df_picks, path_data_dump, fp_df_picks)
print(f'len(df_picks): {len(df_picks)}')
print(df_picks.head())
# Out:
# len(df_picks): 390
#   date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12 sym_freq_11 sym_freq_10 sym_freq_9      sym_freq_8       sym_freq_7                   sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0        2023-12-20                 120      [30, 60, 120]          []          []          []          []          []          []         []  ['GPS', 'SHV']         ['FTSM']                           []     ['ANF', 'HIBB', 'SQ', 'X']  ['LRN', 'M', 'MARA', 'MBI'...  ['BA', 'BPMC', 'FFWM', 'GB...         []
# 1        2023-12-20                 120  [15, 30, 60, 120]          []          []          []          []          []     ['SHV']         []         ['GPS']  ['FTSM', 'MBI']  ['FFWM', 'HA', 'MARA', 'X']          ['ANF', 'HIBB', 'SQ']  ['HPP', 'LC', 'LRN', 'M', ...                             []         []
# 2        2023-12-19                 120      [30, 60, 120]          []          []          []          []          []          []         []  ['GPS', 'SHV']         ['FTSM']                           []     ['ANF', 'HIBB', 'SQ', 'X']  ['AMKR', 'LRN', 'MARA', 'M...  ['BA', 'BPMC', 'BTC-USD', ...         []
# 3        2023-12-19                 120  [15, 30, 60, 120]          []          []          []          []          []     ['SHV']         []         ['GPS']  ['FTSM', 'MBI']   ['HA', 'MARA', 'WOR', 'X']  ['ANF', 'FFWM', 'HIBB', 'H...  ['AMKR', 'LOB', 'LRN', 'RU...                         ['BA']         []
# 4        2023-12-18                 120      [30, 60, 120]          []          []          []          []          []          []         []         ['SHV']  ['FTSM', 'GPS']                        ['X']         ['ANF', 'HIBB', 'LRN']  ['AMKR', 'KKR', 'MARA', 'M...  ['BPMC', 'BTC-USD', 'CG', ...         []

# %% [markdown]
# #### Get dates in df_picks where values in column "days_lookbacks" matched items in my_days_lookbacks.

# %%
my_days_lookbacks = [[30, 60, 120], [15, 30, 60, 120]]

# get list of dates correspond to dates in my_days_lookbacks
# e.g. ['2023-12-15', ... ,  '2023-03-15']
dates_in_days_lookbacks = []
for my_days_lookback in my_days_lookbacks:
  mask_days_lookback = (df_picks['days_lookbacks'] == str(my_days_lookback))
  l_dates = df_picks.loc[mask_days_lookback, 'date_end_df_train'].tolist()     
  dates_in_days_lookbacks.append(l_dates)
# get dates in sublists into one list
dates_in_days_lookbacks = [val for sublist in dates_in_days_lookbacks for val in sublist]
# get unique dates and sort newest to oldest
dates_in_days_lookbacks = sorted(list(set(dates_in_days_lookbacks)), reverse=True)

# %% [markdown]
# #### Create list of tuples of all combination of dates_in_days_lookbacks, my_days_lookbacks, my_cols<br> e.g. [('2023-12-15', [30, 60, 120], 'sym_freq_12'), ... , [15, 30, 60, 120], 'sym_freq_8')]

# %%
my_cols = ['sym_freq_12', 'sym_freq_9', 'sym_freq_8']

# list of tuples of all combination of dates_in_days_lookbacks, my_days_lookbacks, my_cols
# e.g. [('2023-12-15', [30, 60, 120], 'sym_freq_12'), ... , [15, 30, 60, 120], 'sym_freq_8')]
d_lbk_freq = list(product(dates_in_days_lookbacks, my_days_lookbacks, my_cols))

# %%
print(f'Model predicts the best performing symbols are from:')
print(f'1st    {"[30, 60, 120]":<20}{"sym_freq_9":<14}{"days_eval = 4":<20}')
print(f'2nd    {"[15, 30, 60, 120]":<20}{"sym_freq_12":<14}{"days_eval = 5":<20}')
print(f'3rd    {"[30, 60, 120]":<20}{"sym_freq_8":<14}{"days_eval = 4":<20}')
# Out:
# Model predicts the best performing symbols are from:
# 1st    [30, 60, 120]       sym_freq_9    days_eval = 4
# 2nd    [15, 30, 60, 120]   sym_freq_12   days_eval = 5
# 3rd    [30, 60, 120]       sym_freq_8    days_eval = 4

# %% [markdown]
# #### Get symbols in df_picks column in my_cols where values in columns "date_end_df_picks_train", "days_lookbacks" matched dates_in_days_lookbacks and my_days_lookbacks.

# %%
# picks, e.g.: [(0, []), (1, []), (2, ['SHV']), (3, []), ... , (998, ['ELF']), (999, []), ...]
picks = []
prev_date = ''

for i, item in enumerate(d_lbk_freq):
  _date, my_days_lookback, my_col = item[0], item[1], item[2]
  mask_date_n_days_lookback = (df_picks['date_end_df_train'] == _date) & (df_picks['days_lookbacks'] == str(my_days_lookback))  
  list_in_df_picks = df_picks.loc[mask_date_n_days_lookback, my_col]  # pandas series, e.g. 0 ['AMPH', 'FCN']
  my_str = list_in_df_picks.tolist()[0]  # e.g. string: "['AMPH', 'FCN']"
  my_list = literal_eval(my_str)  # e.g. list: ['AMPH', 'FCN']

  # print symbols picked by the model
  if _date != prev_date:
    if prev_date == '':
      print('\nModel Results:')  
      print(f'{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')
    else:
      print(f'\n{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}') 
  else:
    print(f'{i:<6}{" ":<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}')

  picks.append((i, my_list))
  prev_date = _date
# Out:
# Model Results:
# 0     2023-12-20    [30, 60, 120]        sym_freq_12: []
# 1                   [30, 60, 120]        sym_freq_9 : []
# 2                   [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 3                   [15, 30, 60, 120]    sym_freq_12: []
# 4                   [15, 30, 60, 120]    sym_freq_9 : []
# 5                   [15, 30, 60, 120]    sym_freq_8 : ['GPS']
#
# 6     2023-12-19    [30, 60, 120]        sym_freq_12: []
# 7                   [30, 60, 120]        sym_freq_9 : []
# 8                   [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 9                   [15, 30, 60, 120]    sym_freq_12: []
# 10                  [15, 30, 60, 120]    sym_freq_9 : []
# 11                  [15, 30, 60, 120]    sym_freq_8 : ['GPS']
#
# 12    2023-12-18    [30, 60, 120]        sym_freq_12: []
# 13                  [30, 60, 120]        sym_freq_9 : []
# 14                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 15                  [15, 30, 60, 120]    sym_freq_12: []
# 16                  [15, 30, 60, 120]    sym_freq_9 : ['X']
# 17                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 18    2023-12-15    [30, 60, 120]        sym_freq_12: []
# 19                  [30, 60, 120]        sym_freq_9 : []
# 20                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 21                  [15, 30, 60, 120]    sym_freq_12: []
# 22                  [15, 30, 60, 120]    sym_freq_9 : []
# 23                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 24    2023-12-14    [30, 60, 120]        sym_freq_12: []
# 25                  [30, 60, 120]        sym_freq_9 : []
# 26                  [30, 60, 120]        sym_freq_8 : []
# 27                  [15, 30, 60, 120]    sym_freq_12: []
# 28                  [15, 30, 60, 120]    sym_freq_9 : []
# 29                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 30    2023-12-13    [30, 60, 120]        sym_freq_12: []
# 31                  [30, 60, 120]        sym_freq_9 : []
# 32                  [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 33                  [15, 30, 60, 120]    sym_freq_12: []
# 34                  [15, 30, 60, 120]    sym_freq_9 : []
# 35                  [15, 30, 60, 120]    sym_freq_8 : ['GPS']
#
# 36    2023-12-12    [30, 60, 120]        sym_freq_12: []
# 37                  [30, 60, 120]        sym_freq_9 : []
# 38                  [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 39                  [15, 30, 60, 120]    sym_freq_12: []
# 40                  [15, 30, 60, 120]    sym_freq_9 : []
# 41                  [15, 30, 60, 120]    sym_freq_8 : ['GPS']
#
# 42    2023-12-11    [30, 60, 120]        sym_freq_12: []
# 43                  [30, 60, 120]        sym_freq_9 : []
# 44                  [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 45                  [15, 30, 60, 120]    sym_freq_12: []
# 46                  [15, 30, 60, 120]    sym_freq_9 : ['GPS']
# 47                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 48    2023-12-08    [30, 60, 120]        sym_freq_12: []
# 49                  [30, 60, 120]        sym_freq_9 : []
# 50                  [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 51                  [15, 30, 60, 120]    sym_freq_12: []
# 52                  [15, 30, 60, 120]    sym_freq_9 : ['GPS']
# 53                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 54    2023-12-07    [30, 60, 120]        sym_freq_12: []
# 55                  [30, 60, 120]        sym_freq_9 : []
# 56                  [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 57                  [15, 30, 60, 120]    sym_freq_12: []
# 58                  [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 59                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 60    2023-12-06    [30, 60, 120]        sym_freq_12: []
# 61                  [30, 60, 120]        sym_freq_9 : []
# 62                  [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 63                  [15, 30, 60, 120]    sym_freq_12: []
# 64                  [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 65                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 66    2023-12-05    [30, 60, 120]        sym_freq_12: []
# 67                  [30, 60, 120]        sym_freq_9 : ['GPS']
# 68                  [30, 60, 120]        sym_freq_8 : ['LRN', 'SHV']
# 69                  [15, 30, 60, 120]    sym_freq_12: ['GPS']
# 70                  [15, 30, 60, 120]    sym_freq_9 : []
# 71                  [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'LRN', 'VRNS']
#
# 72    2023-12-04    [30, 60, 120]        sym_freq_12: []
# 73                  [30, 60, 120]        sym_freq_9 : ['GPS']
# 74                  [30, 60, 120]        sym_freq_8 : ['SHV']
# 75                  [15, 30, 60, 120]    sym_freq_12: ['GPS']
# 76                  [15, 30, 60, 120]    sym_freq_9 : []
# 77                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 78    2023-12-01    [30, 60, 120]        sym_freq_12: []
# 79                  [30, 60, 120]        sym_freq_9 : ['GPS']
# 80                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
# 81                  [15, 30, 60, 120]    sym_freq_12: ['GPS']
# 82                  [15, 30, 60, 120]    sym_freq_9 : []
# 83                  [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 84    2023-11-30    [30, 60, 120]        sym_freq_12: []
# 85                  [30, 60, 120]        sym_freq_9 : []
# 86                  [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 87                  [15, 30, 60, 120]    sym_freq_12: []
# 88                  [15, 30, 60, 120]    sym_freq_9 : []
# 89                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 90    2023-11-29    [30, 60, 120]        sym_freq_12: []
# 91                  [30, 60, 120]        sym_freq_9 : []
# 92                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'GPS', 'SHV']
# 93                  [15, 30, 60, 120]    sym_freq_12: []
# 94                  [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 95                  [15, 30, 60, 120]    sym_freq_8 : []
#
# 96    2023-11-28    [30, 60, 120]        sym_freq_12: []
# 97                  [30, 60, 120]        sym_freq_9 : ['SHV']
# 98                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'GPS']
# 99                  [15, 30, 60, 120]    sym_freq_12: []
# 100                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 101                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 102   2023-11-27    [30, 60, 120]        sym_freq_12: []
# 103                 [30, 60, 120]        sym_freq_9 : []
# 104                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'GPS', 'SHV']
# 105                 [15, 30, 60, 120]    sym_freq_12: []
# 106                 [15, 30, 60, 120]    sym_freq_9 : []
# 107                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'WING']
#
# 108   2023-11-24    [30, 60, 120]        sym_freq_12: []
# 109                 [30, 60, 120]        sym_freq_9 : []
# 110                 [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 111                 [15, 30, 60, 120]    sym_freq_12: []
# 112                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 113                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 114   2023-11-22    [30, 60, 120]        sym_freq_12: []
# 115                 [30, 60, 120]        sym_freq_9 : []
# 116                 [30, 60, 120]        sym_freq_8 : ['GPS', 'SHV']
# 117                 [15, 30, 60, 120]    sym_freq_12: []
# 118                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 119                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 120   2023-11-21    [30, 60, 120]        sym_freq_12: []
# 121                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 122                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'GPS']
# 123                 [15, 30, 60, 120]    sym_freq_12: []
# 124                 [15, 30, 60, 120]    sym_freq_9 : []
# 125                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 126   2023-11-20    [30, 60, 120]        sym_freq_12: []
# 127                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 128                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'GPS', 'NRG']
# 129                 [15, 30, 60, 120]    sym_freq_12: []
# 130                 [15, 30, 60, 120]    sym_freq_9 : []
# 131                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'NRG', 'WING']
#
# 132   2023-11-17    [30, 60, 120]        sym_freq_12: []
# 133                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 134                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'GPS', 'NRG']
# 135                 [15, 30, 60, 120]    sym_freq_12: []
# 136                 [15, 30, 60, 120]    sym_freq_9 : []
# 137                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'NRG']
#
# 138   2023-11-16    [30, 60, 120]        sym_freq_12: []
# 139                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 140                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'NRG']
# 141                 [15, 30, 60, 120]    sym_freq_12: []
# 142                 [15, 30, 60, 120]    sym_freq_9 : []
# 143                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'NRG', 'WING']
#
# 144   2023-11-15    [30, 60, 120]        sym_freq_12: []
# 145                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 146                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'NRG']
# 147                 [15, 30, 60, 120]    sym_freq_12: []
# 148                 [15, 30, 60, 120]    sym_freq_9 : []
# 149                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'NRG']
#
# 150   2023-11-14    [30, 60, 120]        sym_freq_12: []
# 151                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 152                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'NRG']
# 153                 [15, 30, 60, 120]    sym_freq_12: []
# 154                 [15, 30, 60, 120]    sym_freq_9 : []
# 155                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'NRG']
#
# 156   2023-11-13    [30, 60, 120]        sym_freq_12: []
# 157                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 158                 [30, 60, 120]        sym_freq_8 : ['CBOE']
# 159                 [15, 30, 60, 120]    sym_freq_12: []
# 160                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'LRN']
# 161                 [15, 30, 60, 120]    sym_freq_8 : ['CBOE']
#
# 162   2023-11-10    [30, 60, 120]        sym_freq_12: []
# 163                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 164                 [30, 60, 120]        sym_freq_8 : ['CBOE']
# 165                 [15, 30, 60, 120]    sym_freq_12: []
# 166                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'LRN']
# 167                 [15, 30, 60, 120]    sym_freq_8 : ['CBOE', 'GBTC']
#
# 168   2023-11-09    [30, 60, 120]        sym_freq_12: []
# 169                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 170                 [30, 60, 120]        sym_freq_8 : ['CBOE']
# 171                 [15, 30, 60, 120]    sym_freq_12: []
# 172                 [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 173                 [15, 30, 60, 120]    sym_freq_8 : ['CBOE', 'GBTC']
#
# 174   2023-11-08    [30, 60, 120]        sym_freq_12: []
# 175                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 176                 [30, 60, 120]        sym_freq_8 : ['NRG']
# 177                 [15, 30, 60, 120]    sym_freq_12: []
# 178                 [15, 30, 60, 120]    sym_freq_9 : ['GBTC', 'LRN', 'NRG']
# 179                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 180   2023-11-07    [30, 60, 120]        sym_freq_12: []
# 181                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 182                 [30, 60, 120]        sym_freq_8 : ['NRG']
# 183                 [15, 30, 60, 120]    sym_freq_12: []
# 184                 [15, 30, 60, 120]    sym_freq_9 : ['GBTC']
# 185                 [15, 30, 60, 120]    sym_freq_8 : ['LRN', 'NRG']
#
# 186   2023-11-06    [30, 60, 120]        sym_freq_12: []
# 187                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 188                 [30, 60, 120]        sym_freq_8 : ['NRG']
# 189                 [15, 30, 60, 120]    sym_freq_12: []
# 190                 [15, 30, 60, 120]    sym_freq_9 : []
# 191                 [15, 30, 60, 120]    sym_freq_8 : ['LRN', 'NRG']
#
# 192   2023-11-03    [30, 60, 120]        sym_freq_12: []
# 193                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 194                 [30, 60, 120]        sym_freq_8 : ['ANF']
# 195                 [15, 30, 60, 120]    sym_freq_12: []
# 196                 [15, 30, 60, 120]    sym_freq_9 : []
# 197                 [15, 30, 60, 120]    sym_freq_8 : ['ANF', 'LRN']
#
# 198   2023-11-02    [30, 60, 120]        sym_freq_12: []
# 199                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 200                 [30, 60, 120]        sym_freq_8 : ['ANF']
# 201                 [15, 30, 60, 120]    sym_freq_12: []
# 202                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 203                 [15, 30, 60, 120]    sym_freq_8 : ['ANF']
#
# 204   2023-11-01    [30, 60, 120]        sym_freq_12: []
# 205                 [30, 60, 120]        sym_freq_9 : ['FTSM']
# 206                 [30, 60, 120]        sym_freq_8 : ['ANF']
# 207                 [15, 30, 60, 120]    sym_freq_12: []
# 208                 [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 209                 [15, 30, 60, 120]    sym_freq_8 : ['ANF']
#
# 210   2023-10-31    [30, 60, 120]        sym_freq_12: []
# 211                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 212                 [30, 60, 120]        sym_freq_8 : ['ANF', 'SPLK']
# 213                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 214                 [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 215                 [15, 30, 60, 120]    sym_freq_8 : ['ANF', 'SPLK']
#
# 216   2023-10-30    [30, 60, 120]        sym_freq_12: []
# 217                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 218                 [30, 60, 120]        sym_freq_8 : ['SPLK']
# 219                 [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 220                 [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 221                 [15, 30, 60, 120]    sym_freq_8 : ['SPLK']
#
# 222   2023-10-27    [30, 60, 120]        sym_freq_12: []
# 223                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 224                 [30, 60, 120]        sym_freq_8 : ['SPLK']
# 225                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 226                 [15, 30, 60, 120]    sym_freq_9 : ['LRN']
# 227                 [15, 30, 60, 120]    sym_freq_8 : ['SPLK']
#
# 228   2023-10-26    [30, 60, 120]        sym_freq_12: []
# 229                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 230                 [30, 60, 120]        sym_freq_8 : ['SPLK']
# 231                 [15, 30, 60, 120]    sym_freq_12: []
# 232                 [15, 30, 60, 120]    sym_freq_9 : []
# 233                 [15, 30, 60, 120]    sym_freq_8 : ['LRN', 'SPLK']
#
# 234   2023-10-25    [30, 60, 120]        sym_freq_12: []
# 235                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 236                 [30, 60, 120]        sym_freq_8 : ['ANF', 'SPLK']
# 237                 [15, 30, 60, 120]    sym_freq_12: []
# 238                 [15, 30, 60, 120]    sym_freq_9 : []
# 239                 [15, 30, 60, 120]    sym_freq_8 : ['ANF', 'SPLK']
#
# 240   2023-10-24    [30, 60, 120]        sym_freq_12: []
# 241                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 242                 [30, 60, 120]        sym_freq_8 : ['ANF']
# 243                 [15, 30, 60, 120]    sym_freq_12: []
# 244                 [15, 30, 60, 120]    sym_freq_9 : []
# 245                 [15, 30, 60, 120]    sym_freq_8 : ['ANF']
#
# 246   2023-10-23    [30, 60, 120]        sym_freq_12: []
# 247                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 248                 [30, 60, 120]        sym_freq_8 : ['SPLK']
# 249                 [15, 30, 60, 120]    sym_freq_12: []
# 250                 [15, 30, 60, 120]    sym_freq_9 : []
# 251                 [15, 30, 60, 120]    sym_freq_8 : ['SPLK']
#
# 252   2023-10-20    [30, 60, 120]        sym_freq_12: []
# 253                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 254                 [30, 60, 120]        sym_freq_8 : []
# 255                 [15, 30, 60, 120]    sym_freq_12: []
# 256                 [15, 30, 60, 120]    sym_freq_9 : []
# 257                 [15, 30, 60, 120]    sym_freq_8 : ['PGR', 'USAC']
#
# 258   2023-10-19    [30, 60, 120]        sym_freq_12: []
# 259                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 260                 [30, 60, 120]        sym_freq_8 : []
# 261                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 262                 [15, 30, 60, 120]    sym_freq_9 : ['PGR', 'USAC']
# 263                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 264   2023-10-18    [30, 60, 120]        sym_freq_12: []
# 265                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 266                 [30, 60, 120]        sym_freq_8 : []
# 267                 [15, 30, 60, 120]    sym_freq_12: []
# 268                 [15, 30, 60, 120]    sym_freq_9 : ['PGR']
# 269                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 270   2023-10-17    [30, 60, 120]        sym_freq_12: []
# 271                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 272                 [30, 60, 120]        sym_freq_8 : []
# 273                 [15, 30, 60, 120]    sym_freq_12: []
# 274                 [15, 30, 60, 120]    sym_freq_9 : []
# 275                 [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'PGR']
#
# 276   2023-10-16    [30, 60, 120]        sym_freq_12: []
# 277                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 278                 [30, 60, 120]        sym_freq_8 : []
# 279                 [15, 30, 60, 120]    sym_freq_12: []
# 280                 [15, 30, 60, 120]    sym_freq_9 : []
# 281                 [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'PGR']
#
# 282   2023-10-13    [30, 60, 120]        sym_freq_12: []
# 283                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 284                 [30, 60, 120]        sym_freq_8 : []
# 285                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 286                 [15, 30, 60, 120]    sym_freq_9 : ['ICPT']
# 287                 [15, 30, 60, 120]    sym_freq_8 : ['ANF']
#
# 288   2023-10-12    [30, 60, 120]        sym_freq_12: []
# 289                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 290                 [30, 60, 120]        sym_freq_8 : []
# 291                 [15, 30, 60, 120]    sym_freq_12: []
# 292                 [15, 30, 60, 120]    sym_freq_9 : ['ICPT']
# 293                 [15, 30, 60, 120]    sym_freq_8 : ['ANF', 'CLS']
#
# 294   2023-10-11    [30, 60, 120]        sym_freq_12: []
# 295                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 296                 [30, 60, 120]        sym_freq_8 : []
# 297                 [15, 30, 60, 120]    sym_freq_12: []
# 298                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'CLS']
# 299                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 300   2023-10-10    [30, 60, 120]        sym_freq_12: []
# 301                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 302                 [30, 60, 120]        sym_freq_8 : []
# 303                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 304                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'CLS']
# 305                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT', 'MLKN']
#
# 306   2023-10-09    [30, 60, 120]        sym_freq_12: []
# 307                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 308                 [30, 60, 120]        sym_freq_8 : []
# 309                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 310                 [15, 30, 60, 120]    sym_freq_9 : ['CLS']
# 311                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT', 'MLKN']
#
# 312   2023-10-06    [30, 60, 120]        sym_freq_12: []
# 313                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 314                 [30, 60, 120]        sym_freq_8 : []
# 315                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 316                 [15, 30, 60, 120]    sym_freq_9 : []
# 317                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 318   2023-10-05    [30, 60, 120]        sym_freq_12: []
# 319                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 320                 [30, 60, 120]        sym_freq_8 : []
# 321                 [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 322                 [15, 30, 60, 120]    sym_freq_9 : ['CLS']
# 323                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT', 'SPLK']
#
# 324   2023-10-04    [30, 60, 120]        sym_freq_12: []
# 325                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 326                 [30, 60, 120]        sym_freq_8 : []
# 327                 [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 328                 [15, 30, 60, 120]    sym_freq_9 : ['ICPT']
# 329                 [15, 30, 60, 120]    sym_freq_8 : ['MLKN']
#
# 330   2023-10-03    [30, 60, 120]        sym_freq_12: []
# 331                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 332                 [30, 60, 120]        sym_freq_8 : ['ANF']
# 333                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 334                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'SPLK']
# 335                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 336   2023-10-02    [30, 60, 120]        sym_freq_12: []
# 337                 [30, 60, 120]        sym_freq_9 : ['FTSM']
# 338                 [30, 60, 120]        sym_freq_8 : ['ANF']
# 339                 [15, 30, 60, 120]    sym_freq_12: ['FTSM']
# 340                 [15, 30, 60, 120]    sym_freq_9 : ['ANF']
# 341                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 342   2023-09-29    [30, 60, 120]        sym_freq_12: []
# 343                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 344                 [30, 60, 120]        sym_freq_8 : []
# 345                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 346                 [15, 30, 60, 120]    sym_freq_9 : ['ARCH']
# 347                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT', 'NGS']
#
# 348   2023-09-28    [30, 60, 120]        sym_freq_12: []
# 349                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 350                 [30, 60, 120]        sym_freq_8 : ['CCJ']
# 351                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 352                 [15, 30, 60, 120]    sym_freq_9 : ['ARCH']
# 353                 [15, 30, 60, 120]    sym_freq_8 : ['CCJ', 'USAC']
#
# 354   2023-09-27    [30, 60, 120]        sym_freq_12: []
# 355                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 356                 [30, 60, 120]        sym_freq_8 : ['CCJ']
# 357                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 358                 [15, 30, 60, 120]    sym_freq_9 : ['ARCH']
# 359                 [15, 30, 60, 120]    sym_freq_8 : ['CCJ', 'ICPT', 'NGS']
#
# 360   2023-09-26    [30, 60, 120]        sym_freq_12: []
# 361                 [30, 60, 120]        sym_freq_9 : ['CCJ', 'FTSM', 'SHV']
# 362                 [30, 60, 120]        sym_freq_8 : []
# 363                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 364                 [15, 30, 60, 120]    sym_freq_9 : ['ARCH', 'CCJ']
# 365                 [15, 30, 60, 120]    sym_freq_8 : ['ICPT']
#
# 366   2023-09-25    [30, 60, 120]        sym_freq_12: []
# 367                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 368                 [30, 60, 120]        sym_freq_8 : []
# 369                 [15, 30, 60, 120]    sym_freq_12: []
# 370                 [15, 30, 60, 120]    sym_freq_9 : []
# 371                 [15, 30, 60, 120]    sym_freq_8 : ['ARCH', 'CCJ']
#
# 372   2023-09-22    [30, 60, 120]        sym_freq_12: []
# 373                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 374                 [30, 60, 120]        sym_freq_8 : []
# 375                 [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 376                 [15, 30, 60, 120]    sym_freq_9 : []
# 377                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 378   2023-09-21    [30, 60, 120]        sym_freq_12: []
# 379                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 380                 [30, 60, 120]        sym_freq_8 : []
# 381                 [15, 30, 60, 120]    sym_freq_12: ['FTSM', 'SHV']
# 382                 [15, 30, 60, 120]    sym_freq_9 : []
# 383                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 384   2023-09-20    [30, 60, 120]        sym_freq_12: []
# 385                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 386                 [30, 60, 120]        sym_freq_8 : []
# 387                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 388                 [15, 30, 60, 120]    sym_freq_9 : ['DELL']
# 389                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 390   2023-09-19    [30, 60, 120]        sym_freq_12: []
# 391                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 392                 [30, 60, 120]        sym_freq_8 : []
# 393                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 394                 [15, 30, 60, 120]    sym_freq_9 : []
# 395                 [15, 30, 60, 120]    sym_freq_8 : ['DELL']
#
# 396   2023-09-18    [30, 60, 120]        sym_freq_12: []
# 397                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 398                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 399                 [15, 30, 60, 120]    sym_freq_12: []
# 400                 [15, 30, 60, 120]    sym_freq_9 : ['DELL']
# 401                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 402   2023-09-15    [30, 60, 120]        sym_freq_12: []
# 403                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 404                 [30, 60, 120]        sym_freq_8 : []
# 405                 [15, 30, 60, 120]    sym_freq_12: []
# 406                 [15, 30, 60, 120]    sym_freq_9 : []
# 407                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 408   2023-09-14    [30, 60, 120]        sym_freq_12: []
# 409                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 410                 [30, 60, 120]        sym_freq_8 : ['DELL', 'FTSM']
# 411                 [15, 30, 60, 120]    sym_freq_12: []
# 412                 [15, 30, 60, 120]    sym_freq_9 : []
# 413                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM']
#
# 414   2023-09-13    [30, 60, 120]        sym_freq_12: []
# 415                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 416                 [30, 60, 120]        sym_freq_8 : ['DELL']
# 417                 [15, 30, 60, 120]    sym_freq_12: []
# 418                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 419                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 420   2023-09-12    [30, 60, 120]        sym_freq_12: []
# 421                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 422                 [30, 60, 120]        sym_freq_8 : ['DELL', 'MMYT']
# 423                 [15, 30, 60, 120]    sym_freq_12: []
# 424                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 425                 [15, 30, 60, 120]    sym_freq_8 : ['FTI', 'MMYT']
#
# 426   2023-09-11    [30, 60, 120]        sym_freq_12: []
# 427                 [30, 60, 120]        sym_freq_9 : ['DELL', 'FTSM', 'SHV']
# 428                 [30, 60, 120]        sym_freq_8 : []
# 429                 [15, 30, 60, 120]    sym_freq_12: ['DELL']
# 430                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 431                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 432   2023-09-08    [30, 60, 120]        sym_freq_12: []
# 433                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 434                 [30, 60, 120]        sym_freq_8 : ['DELL', 'STRL']
# 435                 [15, 30, 60, 120]    sym_freq_12: []
# 436                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 437                 [15, 30, 60, 120]    sym_freq_8 : ['CELH', 'STRL']
#
# 438   2023-09-07    [30, 60, 120]        sym_freq_12: []
# 439                 [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 440                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 441                 [15, 30, 60, 120]    sym_freq_12: []
# 442                 [15, 30, 60, 120]    sym_freq_9 : ['CELH', 'FTSM']
# 443                 [15, 30, 60, 120]    sym_freq_8 : ['STRL']
#
# 444   2023-09-06    [30, 60, 120]        sym_freq_12: []
# 445                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 446                 [30, 60, 120]        sym_freq_8 : ['DELL', 'FTSM', 'STRL']
# 447                 [15, 30, 60, 120]    sym_freq_12: []
# 448                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 449                 [15, 30, 60, 120]    sym_freq_8 : ['STRL']
#
# 450   2023-09-05    [30, 60, 120]        sym_freq_12: []
# 451                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 452                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 453                 [15, 30, 60, 120]    sym_freq_12: []
# 454                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 455                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 456   2023-09-01    [30, 60, 120]        sym_freq_12: []
# 457                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 458                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 459                 [15, 30, 60, 120]    sym_freq_12: []
# 460                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'DELL', 'FTSM']
# 461                 [15, 30, 60, 120]    sym_freq_8 : ['STRL', 'TDS']
#
# 462   2023-08-31    [30, 60, 120]        sym_freq_12: []
# 463                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 464                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 465                 [15, 30, 60, 120]    sym_freq_12: []
# 466                 [15, 30, 60, 120]    sym_freq_9 : ['FTSM']
# 467                 [15, 30, 60, 120]    sym_freq_8 : ['STRL', 'TDS', 'UBS']
#
# 468   2023-08-30    [30, 60, 120]        sym_freq_12: []
# 469                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 470                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 471                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 472                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 473                 [15, 30, 60, 120]    sym_freq_8 : ['STRL', 'TDS']
#
# 474   2023-08-29    [30, 60, 120]        sym_freq_12: []
# 475                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 476                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 477                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 478                 [15, 30, 60, 120]    sym_freq_9 : ['ANF']
# 479                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'STRL', 'TDS']
#
# 480   2023-08-28    [30, 60, 120]        sym_freq_12: []
# 481                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 482                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 483                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 484                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM']
# 485                 [15, 30, 60, 120]    sym_freq_8 : ['STRL']
#
# 486   2023-08-25    [30, 60, 120]        sym_freq_12: []
# 487                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 488                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 489                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 490                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'TDS']
# 491                 [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'LLY']
#
# 492   2023-08-24    [30, 60, 120]        sym_freq_12: []
# 493                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 494                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 495                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 496                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM', 'TDS']
# 497                 [15, 30, 60, 120]    sym_freq_8 : ['LLY']
#
# 498   2023-08-23    [30, 60, 120]        sym_freq_12: []
# 499                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 500                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 501                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 502                 [15, 30, 60, 120]    sym_freq_9 : ['ANF', 'FTSM', 'LLY', 'TDS']
# 503                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 504   2023-08-22    [30, 60, 120]        sym_freq_12: []
# 505                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 506                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 507                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 508                 [15, 30, 60, 120]    sym_freq_9 : ['LLY', 'TDS']
# 509                 [15, 30, 60, 120]    sym_freq_8 : ['CNX', 'SM']
#
# 510   2023-08-21    [30, 60, 120]        sym_freq_12: []
# 511                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 512                 [30, 60, 120]        sym_freq_8 : ['FTSM', 'STRL']
# 513                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 514                 [15, 30, 60, 120]    sym_freq_9 : ['LLY', 'SM', 'TDS']
# 515                 [15, 30, 60, 120]    sym_freq_8 : ['CNX']
#
# 516   2023-08-18    [30, 60, 120]        sym_freq_12: []
# 517                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 518                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 519                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 520                 [15, 30, 60, 120]    sym_freq_9 : ['CNX', 'STRL', 'TDS']
# 521                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 522   2023-08-17    [30, 60, 120]        sym_freq_12: []
# 523                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 524                 [30, 60, 120]        sym_freq_8 : ['FTSM']
# 525                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 526                 [15, 30, 60, 120]    sym_freq_9 : ['CNX', 'TDS']
# 527                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 528   2023-08-16    [30, 60, 120]        sym_freq_12: []
# 529                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 530                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 531                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 532                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 533                 [15, 30, 60, 120]    sym_freq_8 : ['CNX']
#
# 534   2023-08-15    [30, 60, 120]        sym_freq_12: []
# 535                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 536                 [30, 60, 120]        sym_freq_8 : ['STRL']
# 537                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 538                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 539                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 540   2023-08-14    [30, 60, 120]        sym_freq_12: []
# 541                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 542                 [30, 60, 120]        sym_freq_8 : []
# 543                 [15, 30, 60, 120]    sym_freq_12: []
# 544                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 545                 [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'EME']
#
# 546   2023-08-11    [30, 60, 120]        sym_freq_12: []
# 547                 [30, 60, 120]        sym_freq_9 : []
# 548                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 549                 [15, 30, 60, 120]    sym_freq_12: []
# 550                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 551                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 552   2023-08-10    [30, 60, 120]        sym_freq_12: []
# 553                 [30, 60, 120]        sym_freq_9 : []
# 554                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 555                 [15, 30, 60, 120]    sym_freq_12: []
# 556                 [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'TDS']
# 557                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 558   2023-08-09    [30, 60, 120]        sym_freq_12: []
# 559                 [30, 60, 120]        sym_freq_9 : []
# 560                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 561                 [15, 30, 60, 120]    sym_freq_12: []
# 562                 [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'TDS']
# 563                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 564   2023-08-08    [30, 60, 120]        sym_freq_12: []
# 565                 [30, 60, 120]        sym_freq_9 : []
# 566                 [30, 60, 120]        sym_freq_8 : ['SHV', 'STRL']
# 567                 [15, 30, 60, 120]    sym_freq_12: []
# 568                 [15, 30, 60, 120]    sym_freq_9 : ['TDS']
# 569                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 570   2023-08-07    [30, 60, 120]        sym_freq_12: []
# 571                 [30, 60, 120]        sym_freq_9 : []
# 572                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 573                 [15, 30, 60, 120]    sym_freq_12: []
# 574                 [15, 30, 60, 120]    sym_freq_9 : []
# 575                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 576   2023-08-04    [30, 60, 120]        sym_freq_12: []
# 577                 [30, 60, 120]        sym_freq_9 : []
# 578                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 579                 [15, 30, 60, 120]    sym_freq_12: []
# 580                 [15, 30, 60, 120]    sym_freq_9 : []
# 581                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 582   2023-08-03    [30, 60, 120]        sym_freq_12: []
# 583                 [30, 60, 120]        sym_freq_9 : []
# 584                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 585                 [15, 30, 60, 120]    sym_freq_12: []
# 586                 [15, 30, 60, 120]    sym_freq_9 : []
# 587                 [15, 30, 60, 120]    sym_freq_8 : ['LOB']
#
# 588   2023-08-02    [30, 60, 120]        sym_freq_12: []
# 589                 [30, 60, 120]        sym_freq_9 : []
# 590                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 591                 [15, 30, 60, 120]    sym_freq_12: []
# 592                 [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 593                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 594   2023-08-01    [30, 60, 120]        sym_freq_12: []
# 595                 [30, 60, 120]        sym_freq_9 : []
# 596                 [30, 60, 120]        sym_freq_8 : []
# 597                 [15, 30, 60, 120]    sym_freq_12: []
# 598                 [15, 30, 60, 120]    sym_freq_9 : ['LOB']
# 599                 [15, 30, 60, 120]    sym_freq_8 : ['SMCI']
#
# 600   2023-07-31    [30, 60, 120]        sym_freq_12: []
# 601                 [30, 60, 120]        sym_freq_9 : []
# 602                 [30, 60, 120]        sym_freq_8 : []
# 603                 [15, 30, 60, 120]    sym_freq_12: []
# 604                 [15, 30, 60, 120]    sym_freq_9 : ['LOB', 'SHV']
# 605                 [15, 30, 60, 120]    sym_freq_8 : ['CLS', 'PKX']
#
# 606   2023-07-28    [30, 60, 120]        sym_freq_12: []
# 607                 [30, 60, 120]        sym_freq_9 : []
# 608                 [30, 60, 120]        sym_freq_8 : ['BZH', 'SHV']
# 609                 [15, 30, 60, 120]    sym_freq_12: []
# 610                 [15, 30, 60, 120]    sym_freq_9 : []
# 611                 [15, 30, 60, 120]    sym_freq_8 : ['BZH', 'CLS', 'LOB']
#
# 612   2023-07-27    [30, 60, 120]        sym_freq_12: []
# 613                 [30, 60, 120]        sym_freq_9 : []
# 614                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 615                 [15, 30, 60, 120]    sym_freq_12: []
# 616                 [15, 30, 60, 120]    sym_freq_9 : ['JOE']
# 617                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 618   2023-07-26    [30, 60, 120]        sym_freq_12: []
# 619                 [30, 60, 120]        sym_freq_9 : []
# 620                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 621                 [15, 30, 60, 120]    sym_freq_12: []
# 622                 [15, 30, 60, 120]    sym_freq_9 : []
# 623                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 624   2023-07-25    [30, 60, 120]        sym_freq_12: []
# 625                 [30, 60, 120]        sym_freq_9 : []
# 626                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 627                 [15, 30, 60, 120]    sym_freq_12: []
# 628                 [15, 30, 60, 120]    sym_freq_9 : []
# 629                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 630   2023-07-24    [30, 60, 120]        sym_freq_12: []
# 631                 [30, 60, 120]        sym_freq_9 : []
# 632                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 633                 [15, 30, 60, 120]    sym_freq_12: []
# 634                 [15, 30, 60, 120]    sym_freq_9 : []
# 635                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 636   2023-07-21    [30, 60, 120]        sym_freq_12: []
# 637                 [30, 60, 120]        sym_freq_9 : []
# 638                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 639                 [15, 30, 60, 120]    sym_freq_12: []
# 640                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 641                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 642   2023-07-20    [30, 60, 120]        sym_freq_12: []
# 643                 [30, 60, 120]        sym_freq_9 : []
# 644                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 645                 [15, 30, 60, 120]    sym_freq_12: []
# 646                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SIRI']
# 647                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 648   2023-07-19    [30, 60, 120]        sym_freq_12: []
# 649                 [30, 60, 120]        sym_freq_9 : []
# 650                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 651                 [15, 30, 60, 120]    sym_freq_12: []
# 652                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 653                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 654   2023-07-18    [30, 60, 120]        sym_freq_12: []
# 655                 [30, 60, 120]        sym_freq_9 : []
# 656                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 657                 [15, 30, 60, 120]    sym_freq_12: []
# 658                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 659                 [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 660   2023-07-17    [30, 60, 120]        sym_freq_12: []
# 661                 [30, 60, 120]        sym_freq_9 : []
# 662                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 663                 [15, 30, 60, 120]    sym_freq_12: []
# 664                 [15, 30, 60, 120]    sym_freq_9 : ['SHV', 'SMCI']
# 665                 [15, 30, 60, 120]    sym_freq_8 : ['BCC', 'BZH']
#
# 666   2023-07-14    [30, 60, 120]        sym_freq_12: []
# 667                 [30, 60, 120]        sym_freq_9 : []
# 668                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 669                 [15, 30, 60, 120]    sym_freq_12: []
# 670                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 671                 [15, 30, 60, 120]    sym_freq_8 : ['BCC']
#
# 672   2023-07-13    [30, 60, 120]        sym_freq_12: []
# 673                 [30, 60, 120]        sym_freq_9 : []
# 674                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 675                 [15, 30, 60, 120]    sym_freq_12: []
# 676                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 677                 [15, 30, 60, 120]    sym_freq_8 : ['BCC', 'SKYW']
#
# 678   2023-07-12    [30, 60, 120]        sym_freq_12: []
# 679                 [30, 60, 120]        sym_freq_9 : []
# 680                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 681                 [15, 30, 60, 120]    sym_freq_12: []
# 682                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 683                 [15, 30, 60, 120]    sym_freq_8 : ['BZH', 'SKYW']
#
# 684   2023-07-11    [30, 60, 120]        sym_freq_12: []
# 685                 [30, 60, 120]        sym_freq_9 : []
# 686                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 687                 [15, 30, 60, 120]    sym_freq_12: []
# 688                 [15, 30, 60, 120]    sym_freq_9 : []
# 689                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 690   2023-07-10    [30, 60, 120]        sym_freq_12: []
# 691                 [30, 60, 120]        sym_freq_9 : []
# 692                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 693                 [15, 30, 60, 120]    sym_freq_12: []
# 694                 [15, 30, 60, 120]    sym_freq_9 : []
# 695                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 696   2023-07-07    [30, 60, 120]        sym_freq_12: []
# 697                 [30, 60, 120]        sym_freq_9 : []
# 698                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 699                 [15, 30, 60, 120]    sym_freq_12: []
# 700                 [15, 30, 60, 120]    sym_freq_9 : []
# 701                 [15, 30, 60, 120]    sym_freq_8 : ['SKYW']
#
# 702   2023-07-06    [30, 60, 120]        sym_freq_12: []
# 703                 [30, 60, 120]        sym_freq_9 : []
# 704                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 705                 [15, 30, 60, 120]    sym_freq_12: []
# 706                 [15, 30, 60, 120]    sym_freq_9 : []
# 707                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW']
#
# 708   2023-07-05    [30, 60, 120]        sym_freq_12: []
# 709                 [30, 60, 120]        sym_freq_9 : []
# 710                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 711                 [15, 30, 60, 120]    sym_freq_12: []
# 712                 [15, 30, 60, 120]    sym_freq_9 : []
# 713                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 714   2023-07-03    [30, 60, 120]        sym_freq_12: []
# 715                 [30, 60, 120]        sym_freq_9 : []
# 716                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 717                 [15, 30, 60, 120]    sym_freq_12: []
# 718                 [15, 30, 60, 120]    sym_freq_9 : []
# 719                 [15, 30, 60, 120]    sym_freq_8 : ['CCL', 'SKYW', 'W']
#
# 720   2023-06-30    [30, 60, 120]        sym_freq_12: []
# 721                 [30, 60, 120]        sym_freq_9 : []
# 722                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 723                 [15, 30, 60, 120]    sym_freq_12: []
# 724                 [15, 30, 60, 120]    sym_freq_9 : ['SKYW']
# 725                 [15, 30, 60, 120]    sym_freq_8 : ['CCL']
#
# 726   2023-06-29    [30, 60, 120]        sym_freq_12: []
# 727                 [30, 60, 120]        sym_freq_9 : []
# 728                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 729                 [15, 30, 60, 120]    sym_freq_12: []
# 730                 [15, 30, 60, 120]    sym_freq_9 : []
# 731                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 732   2023-06-28    [30, 60, 120]        sym_freq_12: []
# 733                 [30, 60, 120]        sym_freq_9 : []
# 734                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 735                 [15, 30, 60, 120]    sym_freq_12: []
# 736                 [15, 30, 60, 120]    sym_freq_9 : []
# 737                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 738   2023-06-27    [30, 60, 120]        sym_freq_12: []
# 739                 [30, 60, 120]        sym_freq_9 : []
# 740                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 741                 [15, 30, 60, 120]    sym_freq_12: []
# 742                 [15, 30, 60, 120]    sym_freq_9 : []
# 743                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 744   2023-06-26    [30, 60, 120]        sym_freq_12: []
# 745                 [30, 60, 120]        sym_freq_9 : []
# 746                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 747                 [15, 30, 60, 120]    sym_freq_12: []
# 748                 [15, 30, 60, 120]    sym_freq_9 : []
# 749                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 750   2023-06-23    [30, 60, 120]        sym_freq_12: []
# 751                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 752                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 753                 [15, 30, 60, 120]    sym_freq_12: []
# 754                 [15, 30, 60, 120]    sym_freq_9 : ['CCL', 'NVDA']
# 755                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH']
#
# 756   2023-06-22    [30, 60, 120]        sym_freq_12: []
# 757                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 758                 [30, 60, 120]        sym_freq_8 : ['SHV', 'SKYW']
# 759                 [15, 30, 60, 120]    sym_freq_12: []
# 760                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 761                 [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'PBR']
#
# 762   2023-06-21    [30, 60, 120]        sym_freq_12: []
# 763                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 764                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 765                 [15, 30, 60, 120]    sym_freq_12: []
# 766                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 767                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 768   2023-06-20    [30, 60, 120]        sym_freq_12: []
# 769                 [30, 60, 120]        sym_freq_9 : ['NVDA']
# 770                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 771                 [15, 30, 60, 120]    sym_freq_12: []
# 772                 [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 773                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 774   2023-06-16    [30, 60, 120]        sym_freq_12: []
# 775                 [30, 60, 120]        sym_freq_9 : []
# 776                 [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 777                 [15, 30, 60, 120]    sym_freq_12: []
# ...
# 903                 [15, 30, 60, 120]    sym_freq_12: []
# 904                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 905                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 906   2023-05-16    [30, 60, 120]        sym_freq_12: []
# 907                 [30, 60, 120]        sym_freq_9 : []
# 908                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 909                 [15, 30, 60, 120]    sym_freq_12: []
# 910                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 911                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 912   2023-05-15    [30, 60, 120]        sym_freq_12: []
# 913                 [30, 60, 120]        sym_freq_9 : ['SHV']
# 914                 [30, 60, 120]        sym_freq_8 : []
# 915                 [15, 30, 60, 120]    sym_freq_12: []
# 916                 [15, 30, 60, 120]    sym_freq_9 : []
# 917                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 918   2023-05-12    [30, 60, 120]        sym_freq_12: []
# 919                 [30, 60, 120]        sym_freq_9 : []
# 920                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 921                 [15, 30, 60, 120]    sym_freq_12: []
# 922                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE', 'SHV']
# 923                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 924   2023-05-11    [30, 60, 120]        sym_freq_12: []
# 925                 [30, 60, 120]        sym_freq_9 : []
# 926                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 927                 [15, 30, 60, 120]    sym_freq_12: []
# 928                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 929                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 930   2023-05-10    [30, 60, 120]        sym_freq_12: []
# 931                 [30, 60, 120]        sym_freq_9 : []
# 932                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 933                 [15, 30, 60, 120]    sym_freq_12: []
# 934                 [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 935                 [15, 30, 60, 120]    sym_freq_8 : ['BLDR']
#
# 936   2023-05-09    [30, 60, 120]        sym_freq_12: []
# 937                 [30, 60, 120]        sym_freq_9 : []
# 938                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 939                 [15, 30, 60, 120]    sym_freq_12: []
# 940                 [15, 30, 60, 120]    sym_freq_9 : ['BLDR']
# 941                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 942   2023-05-08    [30, 60, 120]        sym_freq_12: []
# 943                 [30, 60, 120]        sym_freq_9 : []
# 944                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 945                 [15, 30, 60, 120]    sym_freq_12: []
# 946                 [15, 30, 60, 120]    sym_freq_9 : []
# 947                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 948   2023-05-05    [30, 60, 120]        sym_freq_12: []
# 949                 [30, 60, 120]        sym_freq_9 : []
# 950                 [30, 60, 120]        sym_freq_8 : ['ISEE', 'SHV']
# 951                 [15, 30, 60, 120]    sym_freq_12: []
# 952                 [15, 30, 60, 120]    sym_freq_9 : []
# 953                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 954   2023-05-04    [30, 60, 120]        sym_freq_12: []
# 955                 [30, 60, 120]        sym_freq_9 : []
# 956                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 957                 [15, 30, 60, 120]    sym_freq_12: []
# 958                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP']
# 959                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 960   2023-05-03    [30, 60, 120]        sym_freq_12: []
# 961                 [30, 60, 120]        sym_freq_9 : []
# 962                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 963                 [15, 30, 60, 120]    sym_freq_12: []
# 964                 [15, 30, 60, 120]    sym_freq_9 : ['ISEE']
# 965                 [15, 30, 60, 120]    sym_freq_8 : ['CCEP', 'SHV', 'SKYW']
#
# 966   2023-05-02    [30, 60, 120]        sym_freq_12: []
# 967                 [30, 60, 120]        sym_freq_9 : []
# 968                 [30, 60, 120]        sym_freq_8 : ['SHV']
# 969                 [15, 30, 60, 120]    sym_freq_12: []
# 970                 [15, 30, 60, 120]    sym_freq_9 : ['CCEP', 'ISEE', 'SHV']
# 971                 [15, 30, 60, 120]    sym_freq_8 : []
#
# 972   2023-05-01    [30, 60, 120]        sym_freq_12: []
# 973                 [30, 60, 120]        sym_freq_9 : []
# 974                 [30, 60, 120]        sym_freq_8 : []
# 975                 [15, 30, 60, 120]    sym_freq_12: []
# 976                 [15, 30, 60, 120]    sym_freq_9 : []
# 977                 [15, 30, 60, 120]    sym_freq_8 : ['ISEE']
#
# 978   2023-04-28    [30, 60, 120]        sym_freq_12: []
# 979                 [30, 60, 120]        sym_freq_9 : []
# 980                 [30, 60, 120]        sym_freq_8 : []
# 981                 [15, 30, 60, 120]    sym_freq_12: []
# 982                 [15, 30, 60, 120]    sym_freq_9 : []
# 983                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 984   2023-04-27    [30, 60, 120]        sym_freq_12: []
# 985                 [30, 60, 120]        sym_freq_9 : []
# 986                 [30, 60, 120]        sym_freq_8 : []
# 987                 [15, 30, 60, 120]    sym_freq_12: []
# 988                 [15, 30, 60, 120]    sym_freq_9 : []
# 989                 [15, 30, 60, 120]    sym_freq_8 : ['PHM', 'SHV']
#
# 990   2023-04-26    [30, 60, 120]        sym_freq_12: []
# 991                 [30, 60, 120]        sym_freq_9 : []
# 992                 [30, 60, 120]        sym_freq_8 : ['ELF']
# 993                 [15, 30, 60, 120]    sym_freq_12: []
# 994                 [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 995                 [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 996   2023-04-25    [30, 60, 120]        sym_freq_12: []
# 997                 [30, 60, 120]        sym_freq_9 : []
# 998                 [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 999                 [15, 30, 60, 120]    sym_freq_12: []
# 1000                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1001                [15, 30, 60, 120]    sym_freq_8 : ['ELF']
#
# 1002  2023-04-24    [30, 60, 120]        sym_freq_12: []
# 1003                [30, 60, 120]        sym_freq_9 : []
# 1004                [30, 60, 120]        sym_freq_8 : ['ELF']
# 1005                [15, 30, 60, 120]    sym_freq_12: []
# 1006                [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 1007                [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 1008  2023-04-21    [30, 60, 120]        sym_freq_12: []
# 1009                [30, 60, 120]        sym_freq_9 : []
# 1010                [30, 60, 120]        sym_freq_8 : ['ELF']
# 1011                [15, 30, 60, 120]    sym_freq_12: []
# 1012                [15, 30, 60, 120]    sym_freq_9 : ['ELF']
# 1013                [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 1014  2023-04-20    [30, 60, 120]        sym_freq_12: []
# 1015                [30, 60, 120]        sym_freq_9 : []
# 1016                [30, 60, 120]        sym_freq_8 : ['ELF']
# 1017                [15, 30, 60, 120]    sym_freq_12: []
# 1018                [15, 30, 60, 120]    sym_freq_9 : []
# 1019                [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 1020  2023-04-19    [30, 60, 120]        sym_freq_12: []
# 1021                [30, 60, 120]        sym_freq_9 : []
# 1022                [30, 60, 120]        sym_freq_8 : ['SHV']
# 1023                [15, 30, 60, 120]    sym_freq_12: []
# 1024                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1025                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1026  2023-04-18    [30, 60, 120]        sym_freq_12: []
# 1027                [30, 60, 120]        sym_freq_9 : []
# 1028                [30, 60, 120]        sym_freq_8 : ['SHV']
# 1029                [15, 30, 60, 120]    sym_freq_12: []
# 1030                [15, 30, 60, 120]    sym_freq_9 : []
# 1031                [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 1032  2023-04-17    [30, 60, 120]        sym_freq_12: []
# 1033                [30, 60, 120]        sym_freq_9 : []
# 1034                [30, 60, 120]        sym_freq_8 : ['ELF', 'SHV']
# 1035                [15, 30, 60, 120]    sym_freq_12: []
# 1036                [15, 30, 60, 120]    sym_freq_9 : []
# 1037                [15, 30, 60, 120]    sym_freq_8 : ['ELF', 'SHV']
#
# 1038  2023-04-14    [30, 60, 120]        sym_freq_12: []
# 1039                [30, 60, 120]        sym_freq_9 : []
# 1040                [30, 60, 120]        sym_freq_8 : ['SHV']
# 1041                [15, 30, 60, 120]    sym_freq_12: []
# 1042                [15, 30, 60, 120]    sym_freq_9 : []
# 1043                [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 1044  2023-04-13    [30, 60, 120]        sym_freq_12: []
# 1045                [30, 60, 120]        sym_freq_9 : []
# 1046                [30, 60, 120]        sym_freq_8 : ['SHV']
# 1047                [15, 30, 60, 120]    sym_freq_12: []
# 1048                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1049                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1050  2023-04-12    [30, 60, 120]        sym_freq_12: []
# 1051                [30, 60, 120]        sym_freq_9 : []
# 1052                [30, 60, 120]        sym_freq_8 : ['SHV']
# 1053                [15, 30, 60, 120]    sym_freq_12: []
# 1054                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1055                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1056  2023-04-11    [30, 60, 120]        sym_freq_12: []
# 1057                [30, 60, 120]        sym_freq_9 : []
# 1058                [30, 60, 120]        sym_freq_8 : ['SHV']
# 1059                [15, 30, 60, 120]    sym_freq_12: []
# 1060                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1061                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1062  2023-04-10    [30, 60, 120]        sym_freq_12: []
# 1063                [30, 60, 120]        sym_freq_9 : []
# 1064                [30, 60, 120]        sym_freq_8 : ['SHV']
# 1065                [15, 30, 60, 120]    sym_freq_12: []
# 1066                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1067                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1068  2023-04-06    [30, 60, 120]        sym_freq_12: []
# 1069                [30, 60, 120]        sym_freq_9 : []
# 1070                [30, 60, 120]        sym_freq_8 : ['SHV']
# 1071                [15, 30, 60, 120]    sym_freq_12: []
# 1072                [15, 30, 60, 120]    sym_freq_9 : []
# 1073                [15, 30, 60, 120]    sym_freq_8 : ['SHV']
#
# 1074  2023-04-05    [30, 60, 120]        sym_freq_12: []
# 1075                [30, 60, 120]        sym_freq_9 : ['SHV']
# 1076                [30, 60, 120]        sym_freq_8 : []
# 1077                [15, 30, 60, 120]    sym_freq_12: []
# 1078                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1079                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1080  2023-04-04    [30, 60, 120]        sym_freq_12: []
# 1081                [30, 60, 120]        sym_freq_9 : []
# 1082                [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 1083                [15, 30, 60, 120]    sym_freq_12: []
# 1084                [15, 30, 60, 120]    sym_freq_9 : []
# 1085                [15, 30, 60, 120]    sym_freq_8 : ['NVDA', 'SHV']
#
# 1086  2023-04-03    [30, 60, 120]        sym_freq_12: []
# 1087                [30, 60, 120]        sym_freq_9 : []
# 1088                [30, 60, 120]        sym_freq_8 : ['GE', 'NVDA']
# 1089                [15, 30, 60, 120]    sym_freq_12: []
# 1090                [15, 30, 60, 120]    sym_freq_9 : []
# 1091                [15, 30, 60, 120]    sym_freq_8 : ['GE', 'PERI']
#
# 1092  2023-03-31    [30, 60, 120]        sym_freq_12: []
# 1093                [30, 60, 120]        sym_freq_9 : []
# 1094                [30, 60, 120]        sym_freq_8 : ['NVDA']
# 1095                [15, 30, 60, 120]    sym_freq_12: []
# 1096                [15, 30, 60, 120]    sym_freq_9 : []
# 1097                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1098  2023-03-30    [30, 60, 120]        sym_freq_12: []
# 1099                [30, 60, 120]        sym_freq_9 : ['SHV']
# 1100                [30, 60, 120]        sym_freq_8 : ['NVDA']
# 1101                [15, 30, 60, 120]    sym_freq_12: []
# 1102                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1103                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1104  2023-03-29    [30, 60, 120]        sym_freq_12: []
# 1105                [30, 60, 120]        sym_freq_9 : ['SHV']
# 1106                [30, 60, 120]        sym_freq_8 : []
# 1107                [15, 30, 60, 120]    sym_freq_12: []
# 1108                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1109                [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 1110  2023-03-28    [30, 60, 120]        sym_freq_12: []
# 1111                [30, 60, 120]        sym_freq_9 : ['SHV']
# 1112                [30, 60, 120]        sym_freq_8 : []
# 1113                [15, 30, 60, 120]    sym_freq_12: []
# 1114                [15, 30, 60, 120]    sym_freq_9 : []
# 1115                [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 1116  2023-03-27    [30, 60, 120]        sym_freq_12: []
# 1117                [30, 60, 120]        sym_freq_9 : ['SHV']
# 1118                [30, 60, 120]        sym_freq_8 : ['GE']
# 1119                [15, 30, 60, 120]    sym_freq_12: []
# 1120                [15, 30, 60, 120]    sym_freq_9 : []
# 1121                [15, 30, 60, 120]    sym_freq_8 : ['GE', 'NVDA', 'SGEN']
#
# 1122  2023-03-24    [30, 60, 120]        sym_freq_12: []
# 1123                [30, 60, 120]        sym_freq_9 : []
# 1124                [30, 60, 120]        sym_freq_8 : ['NVDA', 'SHV']
# 1125                [15, 30, 60, 120]    sym_freq_12: []
# 1126                [15, 30, 60, 120]    sym_freq_9 : ['SHV']
# 1127                [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 1128  2023-03-23    [30, 60, 120]        sym_freq_12: []
# 1129                [30, 60, 120]        sym_freq_9 : ['SHV']
# 1130                [30, 60, 120]        sym_freq_8 : []
# 1131                [15, 30, 60, 120]    sym_freq_12: []
# 1132                [15, 30, 60, 120]    sym_freq_9 : ['NVDA']
# 1133                [15, 30, 60, 120]    sym_freq_8 : ['FTSM', 'GE']
#
# 1134  2023-03-22    [30, 60, 120]        sym_freq_12: []
# 1135                [30, 60, 120]        sym_freq_9 : ['SHV']
# 1136                [30, 60, 120]        sym_freq_8 : ['FTSM']
# 1137                [15, 30, 60, 120]    sym_freq_12: []
# 1138                [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'NVDA']
# 1139                [15, 30, 60, 120]    sym_freq_8 : ['SGEN']
#
# 1140  2023-03-21    [30, 60, 120]        sym_freq_12: []
# 1141                [30, 60, 120]        sym_freq_9 : ['SHV']
# 1142                [30, 60, 120]        sym_freq_8 : ['GE']
# 1143                [15, 30, 60, 120]    sym_freq_12: []
# 1144                [15, 30, 60, 120]    sym_freq_9 : ['GE']
# 1145                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1146  2023-03-20    [30, 60, 120]        sym_freq_12: []
# 1147                [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 1148                [30, 60, 120]        sym_freq_8 : []
# 1149                [15, 30, 60, 120]    sym_freq_12: []
# 1150                [15, 30, 60, 120]    sym_freq_9 : []
# 1151                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1152  2023-03-17    [30, 60, 120]        sym_freq_12: []
# 1153                [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 1154                [30, 60, 120]        sym_freq_8 : ['GE']
# 1155                [15, 30, 60, 120]    sym_freq_12: []
# 1156                [15, 30, 60, 120]    sym_freq_9 : ['FTSM', 'GE']
# 1157                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1158  2023-03-16    [30, 60, 120]        sym_freq_12: []
# 1159                [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 1160                [30, 60, 120]        sym_freq_8 : []
# 1161                [15, 30, 60, 120]    sym_freq_12: []
# 1162                [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 1163                [15, 30, 60, 120]    sym_freq_8 : []
#
# 1164  2023-03-15    [30, 60, 120]        sym_freq_12: []
# 1165                [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 1166                [30, 60, 120]        sym_freq_8 : []
# 1167                [15, 30, 60, 120]    sym_freq_12: []
# 1168                [15, 30, 60, 120]    sym_freq_9 : ['SGEN']
# 1169                [15, 30, 60, 120]    sym_freq_8 : ['AMPH', 'FCN']

# %% [markdown]
# #### Create iterable z_items of dates_in_days_lookbacks, my_days_lookbacks, my_cols, and picks, e.g.:<br>(('2023-12-15', [30, 60, 120], 'sym_freq_12'), (0, []))<br>(('2023-12-15', [30, 60, 120], 'sym_freq_9'), (1, []))<br>….<br>(('2023-03-15', [15, 30, 60, 120], 'sym_freq_9'), (1150, [SGEN']))<br>(('2023-03-15', [15, 30, 60, 120], 'sym_freq_8'), (1151, ['AMPH', 'FCN']))

# %%
# z_items, e.g.:
# (('2023-12-14', [30, 60, 120], 'sym_freq_12'), (0, []))
# ...
# (('2023-03-15', [15, 30, 60, 120], 'sym_freq_8'), (1145, ['AMPH', 'FCN']))
z_items = zip(d_lbk_freq, picks)

# %% [markdown]
# #### Criteria of the best stocks from the model

# %%
criteria_model_top_picks = [([30, 60, 120], 'sym_freq_9'), ([15, 30, 60, 120], 'sym_freq_12'), ([30, 60, 120], 'sym_freq_8')]

# %%
df_model_top_picks = pickle_load(path_data_dump, fp_df_model_top_picks)
print(f'len(df_model_top_picks): {len(df_model_top_picks)}')
print(df_model_top_picks.head(), '\n')
print(df_model_top_picks.tail())
# Out:
# len(df_model_top_picks): 293
#          date  days_lookback   syms_freq         symbols
# 0  2023-12-20  [30, 60, 120]  sym_freq_8  ['GPS', 'SHV']
# 1  2023-12-19  [30, 60, 120]  sym_freq_8  ['GPS', 'SHV']
# 2  2023-12-18  [30, 60, 120]  sym_freq_8         ['SHV']
# 3  2023-12-15  [30, 60, 120]  sym_freq_8         ['SHV']
# 4  2023-12-13  [30, 60, 120]  sym_freq_8  ['GPS', 'SHV']
#
#            date  days_lookback   syms_freq          symbols
# 288  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 289  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 290  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']
# 291  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 292  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']

# %% [markdown]
# #### Add picks to df_model_top_picks if dlb_sym_freq match criteria_model_top_picks and _syms has symbol(s)

# %%
for i, item in enumerate(z_items):
  _date, _days_lookback, _sym_freq, _syms = item[0][0], item[0][1], item[0][2], item[1][1]
  len_df_model_top_picks = len(df_model_top_picks)
  print(f'{i}, {_date}, {_days_lookback}, {_sym_freq}, {_syms}')  
  dlb_sym_freq = (_days_lookback, _sym_freq)
  # add data if dlb_sym_freq in criteria_model_top_picks and _syms has symbol(s)  
  if dlb_sym_freq in criteria_model_top_picks and _syms:
    row_add = [_date, _days_lookback, _sym_freq, _syms]
    df_model_top_picks.loc[len_df_model_top_picks] = row_add    
    print(f'\nadded row {len_df_model_top_picks} to df_model_top_picks:\n{row_add}\n')
# Out:
# 0, 2023-12-20, [30, 60, 120], sym_freq_12, []
# 1, 2023-12-20, [30, 60, 120], sym_freq_9, []
# 2, 2023-12-20, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 293 to df_model_top_picks:
# ['2023-12-20', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 3, 2023-12-20, [15, 30, 60, 120], sym_freq_12, []
# 4, 2023-12-20, [15, 30, 60, 120], sym_freq_9, []
# 5, 2023-12-20, [15, 30, 60, 120], sym_freq_8, ['GPS']
# 6, 2023-12-19, [30, 60, 120], sym_freq_12, []
# 7, 2023-12-19, [30, 60, 120], sym_freq_9, []
# 8, 2023-12-19, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 294 to df_model_top_picks:
# ['2023-12-19', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 9, 2023-12-19, [15, 30, 60, 120], sym_freq_12, []
# 10, 2023-12-19, [15, 30, 60, 120], sym_freq_9, []
# 11, 2023-12-19, [15, 30, 60, 120], sym_freq_8, ['GPS']
# 12, 2023-12-18, [30, 60, 120], sym_freq_12, []
# 13, 2023-12-18, [30, 60, 120], sym_freq_9, []
# 14, 2023-12-18, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 295 to df_model_top_picks:
# ['2023-12-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 15, 2023-12-18, [15, 30, 60, 120], sym_freq_12, []
# 16, 2023-12-18, [15, 30, 60, 120], sym_freq_9, ['X']
# 17, 2023-12-18, [15, 30, 60, 120], sym_freq_8, []
# 18, 2023-12-15, [30, 60, 120], sym_freq_12, []
# 19, 2023-12-15, [30, 60, 120], sym_freq_9, []
# 20, 2023-12-15, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 296 to df_model_top_picks:
# ['2023-12-15', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 21, 2023-12-15, [15, 30, 60, 120], sym_freq_12, []
# 22, 2023-12-15, [15, 30, 60, 120], sym_freq_9, []
# 23, 2023-12-15, [15, 30, 60, 120], sym_freq_8, []
# 24, 2023-12-14, [30, 60, 120], sym_freq_12, []
# 25, 2023-12-14, [30, 60, 120], sym_freq_9, []
# 26, 2023-12-14, [30, 60, 120], sym_freq_8, []
# 27, 2023-12-14, [15, 30, 60, 120], sym_freq_12, []
# 28, 2023-12-14, [15, 30, 60, 120], sym_freq_9, []
# 29, 2023-12-14, [15, 30, 60, 120], sym_freq_8, []
# 30, 2023-12-13, [30, 60, 120], sym_freq_12, []
# 31, 2023-12-13, [30, 60, 120], sym_freq_9, []
# 32, 2023-12-13, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 297 to df_model_top_picks:
# ['2023-12-13', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 33, 2023-12-13, [15, 30, 60, 120], sym_freq_12, []
# 34, 2023-12-13, [15, 30, 60, 120], sym_freq_9, []
# 35, 2023-12-13, [15, 30, 60, 120], sym_freq_8, ['GPS']
# 36, 2023-12-12, [30, 60, 120], sym_freq_12, []
# 37, 2023-12-12, [30, 60, 120], sym_freq_9, []
# 38, 2023-12-12, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 298 to df_model_top_picks:
# ['2023-12-12', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 39, 2023-12-12, [15, 30, 60, 120], sym_freq_12, []
# 40, 2023-12-12, [15, 30, 60, 120], sym_freq_9, []
# 41, 2023-12-12, [15, 30, 60, 120], sym_freq_8, ['GPS']
# 42, 2023-12-11, [30, 60, 120], sym_freq_12, []
# 43, 2023-12-11, [30, 60, 120], sym_freq_9, []
# 44, 2023-12-11, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 299 to df_model_top_picks:
# ['2023-12-11', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 45, 2023-12-11, [15, 30, 60, 120], sym_freq_12, []
# 46, 2023-12-11, [15, 30, 60, 120], sym_freq_9, ['GPS']
# 47, 2023-12-11, [15, 30, 60, 120], sym_freq_8, []
# 48, 2023-12-08, [30, 60, 120], sym_freq_12, []
# 49, 2023-12-08, [30, 60, 120], sym_freq_9, []
# 50, 2023-12-08, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 300 to df_model_top_picks:
# ['2023-12-08', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 51, 2023-12-08, [15, 30, 60, 120], sym_freq_12, []
# 52, 2023-12-08, [15, 30, 60, 120], sym_freq_9, ['GPS']
# 53, 2023-12-08, [15, 30, 60, 120], sym_freq_8, []
# 54, 2023-12-07, [30, 60, 120], sym_freq_12, []
# 55, 2023-12-07, [30, 60, 120], sym_freq_9, []
# 56, 2023-12-07, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 301 to df_model_top_picks:
# ['2023-12-07', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 57, 2023-12-07, [15, 30, 60, 120], sym_freq_12, []
# 58, 2023-12-07, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 59, 2023-12-07, [15, 30, 60, 120], sym_freq_8, []
# 60, 2023-12-06, [30, 60, 120], sym_freq_12, []
# 61, 2023-12-06, [30, 60, 120], sym_freq_9, []
# 62, 2023-12-06, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 302 to df_model_top_picks:
# ['2023-12-06', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 63, 2023-12-06, [15, 30, 60, 120], sym_freq_12, []
# 64, 2023-12-06, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 65, 2023-12-06, [15, 30, 60, 120], sym_freq_8, []
# 66, 2023-12-05, [30, 60, 120], sym_freq_12, []
# 67, 2023-12-05, [30, 60, 120], sym_freq_9, ['GPS']
#
# added row 303 to df_model_top_picks:
# ['2023-12-05', [30, 60, 120], 'sym_freq_9', ['GPS']]
#
# 68, 2023-12-05, [30, 60, 120], sym_freq_8, ['LRN', 'SHV']
#
# added row 304 to df_model_top_picks:
# ['2023-12-05', [30, 60, 120], 'sym_freq_8', ['LRN', 'SHV']]
#
# 69, 2023-12-05, [15, 30, 60, 120], sym_freq_12, ['GPS']
#
# added row 305 to df_model_top_picks:
# ['2023-12-05', [15, 30, 60, 120], 'sym_freq_12', ['GPS']]
#
# 70, 2023-12-05, [15, 30, 60, 120], sym_freq_9, []
# 71, 2023-12-05, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'LRN', 'VRNS']
# 72, 2023-12-04, [30, 60, 120], sym_freq_12, []
# 73, 2023-12-04, [30, 60, 120], sym_freq_9, ['GPS']
#
# added row 306 to df_model_top_picks:
# ['2023-12-04', [30, 60, 120], 'sym_freq_9', ['GPS']]
#
# 74, 2023-12-04, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 307 to df_model_top_picks:
# ['2023-12-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 75, 2023-12-04, [15, 30, 60, 120], sym_freq_12, ['GPS']
#
# added row 308 to df_model_top_picks:
# ['2023-12-04', [15, 30, 60, 120], 'sym_freq_12', ['GPS']]
#
# 76, 2023-12-04, [15, 30, 60, 120], sym_freq_9, []
# 77, 2023-12-04, [15, 30, 60, 120], sym_freq_8, []
# 78, 2023-12-01, [30, 60, 120], sym_freq_12, []
# 79, 2023-12-01, [30, 60, 120], sym_freq_9, ['GPS']
#
# added row 309 to df_model_top_picks:
# ['2023-12-01', [30, 60, 120], 'sym_freq_9', ['GPS']]
#
# 80, 2023-12-01, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# added row 310 to df_model_top_picks:
# ['2023-12-01', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 81, 2023-12-01, [15, 30, 60, 120], sym_freq_12, ['GPS']
#
# added row 311 to df_model_top_picks:
# ['2023-12-01', [15, 30, 60, 120], 'sym_freq_12', ['GPS']]
#
# 82, 2023-12-01, [15, 30, 60, 120], sym_freq_9, []
# 83, 2023-12-01, [15, 30, 60, 120], sym_freq_8, ['FTSM']
# 84, 2023-11-30, [30, 60, 120], sym_freq_12, []
# 85, 2023-11-30, [30, 60, 120], sym_freq_9, []
# 86, 2023-11-30, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 312 to df_model_top_picks:
# ['2023-11-30', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 87, 2023-11-30, [15, 30, 60, 120], sym_freq_12, []
# 88, 2023-11-30, [15, 30, 60, 120], sym_freq_9, []
# 89, 2023-11-30, [15, 30, 60, 120], sym_freq_8, []
# 90, 2023-11-29, [30, 60, 120], sym_freq_12, []
# 91, 2023-11-29, [30, 60, 120], sym_freq_9, []
# 92, 2023-11-29, [30, 60, 120], sym_freq_8, ['FTSM', 'GPS', 'SHV']
#
# added row 313 to df_model_top_picks:
# ['2023-11-29', [30, 60, 120], 'sym_freq_8', ['FTSM', 'GPS', 'SHV']]
#
# 93, 2023-11-29, [15, 30, 60, 120], sym_freq_12, []
# 94, 2023-11-29, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 95, 2023-11-29, [15, 30, 60, 120], sym_freq_8, []
# 96, 2023-11-28, [30, 60, 120], sym_freq_12, []
# 97, 2023-11-28, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 314 to df_model_top_picks:
# ['2023-11-28', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 98, 2023-11-28, [30, 60, 120], sym_freq_8, ['FTSM', 'GPS']
#
# added row 315 to df_model_top_picks:
# ['2023-11-28', [30, 60, 120], 'sym_freq_8', ['FTSM', 'GPS']]
#
# 99, 2023-11-28, [15, 30, 60, 120], sym_freq_12, []
# 100, 2023-11-28, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 101, 2023-11-28, [15, 30, 60, 120], sym_freq_8, []
# 102, 2023-11-27, [30, 60, 120], sym_freq_12, []
# 103, 2023-11-27, [30, 60, 120], sym_freq_9, []
# 104, 2023-11-27, [30, 60, 120], sym_freq_8, ['FTSM', 'GPS', 'SHV']
#
# added row 316 to df_model_top_picks:
# ['2023-11-27', [30, 60, 120], 'sym_freq_8', ['FTSM', 'GPS', 'SHV']]
#
# 105, 2023-11-27, [15, 30, 60, 120], sym_freq_12, []
# 106, 2023-11-27, [15, 30, 60, 120], sym_freq_9, []
# 107, 2023-11-27, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'WING']
# 108, 2023-11-24, [30, 60, 120], sym_freq_12, []
# 109, 2023-11-24, [30, 60, 120], sym_freq_9, []
# 110, 2023-11-24, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 317 to df_model_top_picks:
# ['2023-11-24', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 111, 2023-11-24, [15, 30, 60, 120], sym_freq_12, []
# 112, 2023-11-24, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 113, 2023-11-24, [15, 30, 60, 120], sym_freq_8, []
# 114, 2023-11-22, [30, 60, 120], sym_freq_12, []
# 115, 2023-11-22, [30, 60, 120], sym_freq_9, []
# 116, 2023-11-22, [30, 60, 120], sym_freq_8, ['GPS', 'SHV']
#
# added row 318 to df_model_top_picks:
# ['2023-11-22', [30, 60, 120], 'sym_freq_8', ['GPS', 'SHV']]
#
# 117, 2023-11-22, [15, 30, 60, 120], sym_freq_12, []
# 118, 2023-11-22, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 119, 2023-11-22, [15, 30, 60, 120], sym_freq_8, []
# 120, 2023-11-21, [30, 60, 120], sym_freq_12, []
# 121, 2023-11-21, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 319 to df_model_top_picks:
# ['2023-11-21', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 122, 2023-11-21, [30, 60, 120], sym_freq_8, ['FTSM', 'GPS']
#
# added row 320 to df_model_top_picks:
# ['2023-11-21', [30, 60, 120], 'sym_freq_8', ['FTSM', 'GPS']]
#
# 123, 2023-11-21, [15, 30, 60, 120], sym_freq_12, []
# 124, 2023-11-21, [15, 30, 60, 120], sym_freq_9, []
# 125, 2023-11-21, [15, 30, 60, 120], sym_freq_8, ['FTSM']
# 126, 2023-11-20, [30, 60, 120], sym_freq_12, []
# 127, 2023-11-20, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 321 to df_model_top_picks:
# ['2023-11-20', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 128, 2023-11-20, [30, 60, 120], sym_freq_8, ['FTSM', 'GPS', 'NRG']
#
# added row 322 to df_model_top_picks:
# ['2023-11-20', [30, 60, 120], 'sym_freq_8', ['FTSM', 'GPS', 'NRG']]
#
# 129, 2023-11-20, [15, 30, 60, 120], sym_freq_12, []
# 130, 2023-11-20, [15, 30, 60, 120], sym_freq_9, []
# 131, 2023-11-20, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'NRG', 'WING']
# 132, 2023-11-17, [30, 60, 120], sym_freq_12, []
# 133, 2023-11-17, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 323 to df_model_top_picks:
# ['2023-11-17', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 134, 2023-11-17, [30, 60, 120], sym_freq_8, ['FTSM', 'GPS', 'NRG']
#
# added row 324 to df_model_top_picks:
# ['2023-11-17', [30, 60, 120], 'sym_freq_8', ['FTSM', 'GPS', 'NRG']]
#
# 135, 2023-11-17, [15, 30, 60, 120], sym_freq_12, []
# 136, 2023-11-17, [15, 30, 60, 120], sym_freq_9, []
# 137, 2023-11-17, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'NRG']
# 138, 2023-11-16, [30, 60, 120], sym_freq_12, []
# 139, 2023-11-16, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 325 to df_model_top_picks:
# ['2023-11-16', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 140, 2023-11-16, [30, 60, 120], sym_freq_8, ['FTSM', 'NRG']
#
# added row 326 to df_model_top_picks:
# ['2023-11-16', [30, 60, 120], 'sym_freq_8', ['FTSM', 'NRG']]
#
# 141, 2023-11-16, [15, 30, 60, 120], sym_freq_12, []
# 142, 2023-11-16, [15, 30, 60, 120], sym_freq_9, []
# 143, 2023-11-16, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'NRG', 'WING']
# 144, 2023-11-15, [30, 60, 120], sym_freq_12, []
# 145, 2023-11-15, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 327 to df_model_top_picks:
# ['2023-11-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 146, 2023-11-15, [30, 60, 120], sym_freq_8, ['FTSM', 'NRG']
#
# added row 328 to df_model_top_picks:
# ['2023-11-15', [30, 60, 120], 'sym_freq_8', ['FTSM', 'NRG']]
#
# 147, 2023-11-15, [15, 30, 60, 120], sym_freq_12, []
# 148, 2023-11-15, [15, 30, 60, 120], sym_freq_9, []
# 149, 2023-11-15, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'NRG']
# 150, 2023-11-14, [30, 60, 120], sym_freq_12, []
# 151, 2023-11-14, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 329 to df_model_top_picks:
# ['2023-11-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 152, 2023-11-14, [30, 60, 120], sym_freq_8, ['FTSM', 'NRG']
#
# added row 330 to df_model_top_picks:
# ['2023-11-14', [30, 60, 120], 'sym_freq_8', ['FTSM', 'NRG']]
#
# 153, 2023-11-14, [15, 30, 60, 120], sym_freq_12, []
# 154, 2023-11-14, [15, 30, 60, 120], sym_freq_9, []
# 155, 2023-11-14, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'NRG']
# 156, 2023-11-13, [30, 60, 120], sym_freq_12, []
# 157, 2023-11-13, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 331 to df_model_top_picks:
# ['2023-11-13', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 158, 2023-11-13, [30, 60, 120], sym_freq_8, ['CBOE']
#
# added row 332 to df_model_top_picks:
# ['2023-11-13', [30, 60, 120], 'sym_freq_8', ['CBOE']]
#
# 159, 2023-11-13, [15, 30, 60, 120], sym_freq_12, []
# 160, 2023-11-13, [15, 30, 60, 120], sym_freq_9, ['FTSM', 'LRN']
# 161, 2023-11-13, [15, 30, 60, 120], sym_freq_8, ['CBOE']
# 162, 2023-11-10, [30, 60, 120], sym_freq_12, []
# 163, 2023-11-10, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 333 to df_model_top_picks:
# ['2023-11-10', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 164, 2023-11-10, [30, 60, 120], sym_freq_8, ['CBOE']
#
# added row 334 to df_model_top_picks:
# ['2023-11-10', [30, 60, 120], 'sym_freq_8', ['CBOE']]
#
# 165, 2023-11-10, [15, 30, 60, 120], sym_freq_12, []
# 166, 2023-11-10, [15, 30, 60, 120], sym_freq_9, ['FTSM', 'LRN']
# 167, 2023-11-10, [15, 30, 60, 120], sym_freq_8, ['CBOE', 'GBTC']
# 168, 2023-11-09, [30, 60, 120], sym_freq_12, []
# 169, 2023-11-09, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 335 to df_model_top_picks:
# ['2023-11-09', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 170, 2023-11-09, [30, 60, 120], sym_freq_8, ['CBOE']
#
# added row 336 to df_model_top_picks:
# ['2023-11-09', [30, 60, 120], 'sym_freq_8', ['CBOE']]
#
# 171, 2023-11-09, [15, 30, 60, 120], sym_freq_12, []
# 172, 2023-11-09, [15, 30, 60, 120], sym_freq_9, ['LRN']
# 173, 2023-11-09, [15, 30, 60, 120], sym_freq_8, ['CBOE', 'GBTC']
# 174, 2023-11-08, [30, 60, 120], sym_freq_12, []
# 175, 2023-11-08, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 337 to df_model_top_picks:
# ['2023-11-08', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 176, 2023-11-08, [30, 60, 120], sym_freq_8, ['NRG']
#
# added row 338 to df_model_top_picks:
# ['2023-11-08', [30, 60, 120], 'sym_freq_8', ['NRG']]
#
# 177, 2023-11-08, [15, 30, 60, 120], sym_freq_12, []
# 178, 2023-11-08, [15, 30, 60, 120], sym_freq_9, ['GBTC', 'LRN', 'NRG']
# 179, 2023-11-08, [15, 30, 60, 120], sym_freq_8, []
# 180, 2023-11-07, [30, 60, 120], sym_freq_12, []
# 181, 2023-11-07, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 339 to df_model_top_picks:
# ['2023-11-07', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 182, 2023-11-07, [30, 60, 120], sym_freq_8, ['NRG']
#
# added row 340 to df_model_top_picks:
# ['2023-11-07', [30, 60, 120], 'sym_freq_8', ['NRG']]
#
# 183, 2023-11-07, [15, 30, 60, 120], sym_freq_12, []
# 184, 2023-11-07, [15, 30, 60, 120], sym_freq_9, ['GBTC']
# 185, 2023-11-07, [15, 30, 60, 120], sym_freq_8, ['LRN', 'NRG']
# 186, 2023-11-06, [30, 60, 120], sym_freq_12, []
# 187, 2023-11-06, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 341 to df_model_top_picks:
# ['2023-11-06', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 188, 2023-11-06, [30, 60, 120], sym_freq_8, ['NRG']
#
# added row 342 to df_model_top_picks:
# ['2023-11-06', [30, 60, 120], 'sym_freq_8', ['NRG']]
#
# 189, 2023-11-06, [15, 30, 60, 120], sym_freq_12, []
# 190, 2023-11-06, [15, 30, 60, 120], sym_freq_9, []
# 191, 2023-11-06, [15, 30, 60, 120], sym_freq_8, ['LRN', 'NRG']
# 192, 2023-11-03, [30, 60, 120], sym_freq_12, []
# 193, 2023-11-03, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 343 to df_model_top_picks:
# ['2023-11-03', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 194, 2023-11-03, [30, 60, 120], sym_freq_8, ['ANF']
#
# added row 344 to df_model_top_picks:
# ['2023-11-03', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 195, 2023-11-03, [15, 30, 60, 120], sym_freq_12, []
# 196, 2023-11-03, [15, 30, 60, 120], sym_freq_9, []
# 197, 2023-11-03, [15, 30, 60, 120], sym_freq_8, ['ANF', 'LRN']
# 198, 2023-11-02, [30, 60, 120], sym_freq_12, []
# 199, 2023-11-02, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 345 to df_model_top_picks:
# ['2023-11-02', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 200, 2023-11-02, [30, 60, 120], sym_freq_8, ['ANF']
#
# added row 346 to df_model_top_picks:
# ['2023-11-02', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 201, 2023-11-02, [15, 30, 60, 120], sym_freq_12, []
# 202, 2023-11-02, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 203, 2023-11-02, [15, 30, 60, 120], sym_freq_8, ['ANF']
# 204, 2023-11-01, [30, 60, 120], sym_freq_12, []
# 205, 2023-11-01, [30, 60, 120], sym_freq_9, ['FTSM']
#
# added row 347 to df_model_top_picks:
# ['2023-11-01', [30, 60, 120], 'sym_freq_9', ['FTSM']]
#
# 206, 2023-11-01, [30, 60, 120], sym_freq_8, ['ANF']
#
# added row 348 to df_model_top_picks:
# ['2023-11-01', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 207, 2023-11-01, [15, 30, 60, 120], sym_freq_12, []
# 208, 2023-11-01, [15, 30, 60, 120], sym_freq_9, ['LRN']
# 209, 2023-11-01, [15, 30, 60, 120], sym_freq_8, ['ANF']
# 210, 2023-10-31, [30, 60, 120], sym_freq_12, []
# 211, 2023-10-31, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 349 to df_model_top_picks:
# ['2023-10-31', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 212, 2023-10-31, [30, 60, 120], sym_freq_8, ['ANF', 'SPLK']
#
# added row 350 to df_model_top_picks:
# ['2023-10-31', [30, 60, 120], 'sym_freq_8', ['ANF', 'SPLK']]
#
# 213, 2023-10-31, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 351 to df_model_top_picks:
# ['2023-10-31', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 214, 2023-10-31, [15, 30, 60, 120], sym_freq_9, ['LRN']
# 215, 2023-10-31, [15, 30, 60, 120], sym_freq_8, ['ANF', 'SPLK']
# 216, 2023-10-30, [30, 60, 120], sym_freq_12, []
# 217, 2023-10-30, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 352 to df_model_top_picks:
# ['2023-10-30', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 218, 2023-10-30, [30, 60, 120], sym_freq_8, ['SPLK']
#
# added row 353 to df_model_top_picks:
# ['2023-10-30', [30, 60, 120], 'sym_freq_8', ['SPLK']]
#
# 219, 2023-10-30, [15, 30, 60, 120], sym_freq_12, ['FTSM', 'SHV']
#
# added row 354 to df_model_top_picks:
# ['2023-10-30', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 220, 2023-10-30, [15, 30, 60, 120], sym_freq_9, ['LRN']
# 221, 2023-10-30, [15, 30, 60, 120], sym_freq_8, ['SPLK']
# 222, 2023-10-27, [30, 60, 120], sym_freq_12, []
# 223, 2023-10-27, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 355 to df_model_top_picks:
# ['2023-10-27', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 224, 2023-10-27, [30, 60, 120], sym_freq_8, ['SPLK']
#
# added row 356 to df_model_top_picks:
# ['2023-10-27', [30, 60, 120], 'sym_freq_8', ['SPLK']]
#
# 225, 2023-10-27, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 357 to df_model_top_picks:
# ['2023-10-27', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 226, 2023-10-27, [15, 30, 60, 120], sym_freq_9, ['LRN']
# 227, 2023-10-27, [15, 30, 60, 120], sym_freq_8, ['SPLK']
# 228, 2023-10-26, [30, 60, 120], sym_freq_12, []
# 229, 2023-10-26, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 358 to df_model_top_picks:
# ['2023-10-26', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 230, 2023-10-26, [30, 60, 120], sym_freq_8, ['SPLK']
#
# added row 359 to df_model_top_picks:
# ['2023-10-26', [30, 60, 120], 'sym_freq_8', ['SPLK']]
#
# 231, 2023-10-26, [15, 30, 60, 120], sym_freq_12, []
# 232, 2023-10-26, [15, 30, 60, 120], sym_freq_9, []
# 233, 2023-10-26, [15, 30, 60, 120], sym_freq_8, ['LRN', 'SPLK']
# 234, 2023-10-25, [30, 60, 120], sym_freq_12, []
# 235, 2023-10-25, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 360 to df_model_top_picks:
# ['2023-10-25', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 236, 2023-10-25, [30, 60, 120], sym_freq_8, ['ANF', 'SPLK']
#
# added row 361 to df_model_top_picks:
# ['2023-10-25', [30, 60, 120], 'sym_freq_8', ['ANF', 'SPLK']]
#
# 237, 2023-10-25, [15, 30, 60, 120], sym_freq_12, []
# 238, 2023-10-25, [15, 30, 60, 120], sym_freq_9, []
# 239, 2023-10-25, [15, 30, 60, 120], sym_freq_8, ['ANF', 'SPLK']
# 240, 2023-10-24, [30, 60, 120], sym_freq_12, []
# 241, 2023-10-24, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 362 to df_model_top_picks:
# ['2023-10-24', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 242, 2023-10-24, [30, 60, 120], sym_freq_8, ['ANF']
#
# added row 363 to df_model_top_picks:
# ['2023-10-24', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 243, 2023-10-24, [15, 30, 60, 120], sym_freq_12, []
# 244, 2023-10-24, [15, 30, 60, 120], sym_freq_9, []
# 245, 2023-10-24, [15, 30, 60, 120], sym_freq_8, ['ANF']
# 246, 2023-10-23, [30, 60, 120], sym_freq_12, []
# 247, 2023-10-23, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 364 to df_model_top_picks:
# ['2023-10-23', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 248, 2023-10-23, [30, 60, 120], sym_freq_8, ['SPLK']
#
# added row 365 to df_model_top_picks:
# ['2023-10-23', [30, 60, 120], 'sym_freq_8', ['SPLK']]
#
# 249, 2023-10-23, [15, 30, 60, 120], sym_freq_12, []
# 250, 2023-10-23, [15, 30, 60, 120], sym_freq_9, []
# 251, 2023-10-23, [15, 30, 60, 120], sym_freq_8, ['SPLK']
# 252, 2023-10-20, [30, 60, 120], sym_freq_12, []
# 253, 2023-10-20, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 366 to df_model_top_picks:
# ['2023-10-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 254, 2023-10-20, [30, 60, 120], sym_freq_8, []
# 255, 2023-10-20, [15, 30, 60, 120], sym_freq_12, []
# 256, 2023-10-20, [15, 30, 60, 120], sym_freq_9, []
# 257, 2023-10-20, [15, 30, 60, 120], sym_freq_8, ['PGR', 'USAC']
# 258, 2023-10-19, [30, 60, 120], sym_freq_12, []
# 259, 2023-10-19, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 367 to df_model_top_picks:
# ['2023-10-19', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 260, 2023-10-19, [30, 60, 120], sym_freq_8, []
# 261, 2023-10-19, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 368 to df_model_top_picks:
# ['2023-10-19', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 262, 2023-10-19, [15, 30, 60, 120], sym_freq_9, ['PGR', 'USAC']
# 263, 2023-10-19, [15, 30, 60, 120], sym_freq_8, []
# 264, 2023-10-18, [30, 60, 120], sym_freq_12, []
# 265, 2023-10-18, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 369 to df_model_top_picks:
# ['2023-10-18', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 266, 2023-10-18, [30, 60, 120], sym_freq_8, []
# 267, 2023-10-18, [15, 30, 60, 120], sym_freq_12, []
# 268, 2023-10-18, [15, 30, 60, 120], sym_freq_9, ['PGR']
# 269, 2023-10-18, [15, 30, 60, 120], sym_freq_8, []
# 270, 2023-10-17, [30, 60, 120], sym_freq_12, []
# 271, 2023-10-17, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 370 to df_model_top_picks:
# ['2023-10-17', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 272, 2023-10-17, [30, 60, 120], sym_freq_8, []
# 273, 2023-10-17, [15, 30, 60, 120], sym_freq_12, []
# 274, 2023-10-17, [15, 30, 60, 120], sym_freq_9, []
# 275, 2023-10-17, [15, 30, 60, 120], sym_freq_8, ['CLS', 'PGR']
# 276, 2023-10-16, [30, 60, 120], sym_freq_12, []
# 277, 2023-10-16, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 371 to df_model_top_picks:
# ['2023-10-16', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 278, 2023-10-16, [30, 60, 120], sym_freq_8, []
# 279, 2023-10-16, [15, 30, 60, 120], sym_freq_12, []
# 280, 2023-10-16, [15, 30, 60, 120], sym_freq_9, []
# 281, 2023-10-16, [15, 30, 60, 120], sym_freq_8, ['CLS', 'PGR']
# 282, 2023-10-13, [30, 60, 120], sym_freq_12, []
# 283, 2023-10-13, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 372 to df_model_top_picks:
# ['2023-10-13', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 284, 2023-10-13, [30, 60, 120], sym_freq_8, []
# 285, 2023-10-13, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 373 to df_model_top_picks:
# ['2023-10-13', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 286, 2023-10-13, [15, 30, 60, 120], sym_freq_9, ['ICPT']
# 287, 2023-10-13, [15, 30, 60, 120], sym_freq_8, ['ANF']
# 288, 2023-10-12, [30, 60, 120], sym_freq_12, []
# 289, 2023-10-12, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 374 to df_model_top_picks:
# ['2023-10-12', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 290, 2023-10-12, [30, 60, 120], sym_freq_8, []
# 291, 2023-10-12, [15, 30, 60, 120], sym_freq_12, []
# 292, 2023-10-12, [15, 30, 60, 120], sym_freq_9, ['ICPT']
# 293, 2023-10-12, [15, 30, 60, 120], sym_freq_8, ['ANF', 'CLS']
# 294, 2023-10-11, [30, 60, 120], sym_freq_12, []
# 295, 2023-10-11, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 375 to df_model_top_picks:
# ['2023-10-11', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 296, 2023-10-11, [30, 60, 120], sym_freq_8, []
# 297, 2023-10-11, [15, 30, 60, 120], sym_freq_12, []
# 298, 2023-10-11, [15, 30, 60, 120], sym_freq_9, ['ANF', 'CLS']
# 299, 2023-10-11, [15, 30, 60, 120], sym_freq_8, ['ICPT']
# 300, 2023-10-10, [30, 60, 120], sym_freq_12, []
# 301, 2023-10-10, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 376 to df_model_top_picks:
# ['2023-10-10', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 302, 2023-10-10, [30, 60, 120], sym_freq_8, []
# 303, 2023-10-10, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 377 to df_model_top_picks:
# ['2023-10-10', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 304, 2023-10-10, [15, 30, 60, 120], sym_freq_9, ['ANF', 'CLS']
# 305, 2023-10-10, [15, 30, 60, 120], sym_freq_8, ['ICPT', 'MLKN']
# 306, 2023-10-09, [30, 60, 120], sym_freq_12, []
# 307, 2023-10-09, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 378 to df_model_top_picks:
# ['2023-10-09', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 308, 2023-10-09, [30, 60, 120], sym_freq_8, []
# 309, 2023-10-09, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 379 to df_model_top_picks:
# ['2023-10-09', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 310, 2023-10-09, [15, 30, 60, 120], sym_freq_9, ['CLS']
# 311, 2023-10-09, [15, 30, 60, 120], sym_freq_8, ['ICPT', 'MLKN']
# 312, 2023-10-06, [30, 60, 120], sym_freq_12, []
# 313, 2023-10-06, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 380 to df_model_top_picks:
# ['2023-10-06', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 314, 2023-10-06, [30, 60, 120], sym_freq_8, []
# 315, 2023-10-06, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 381 to df_model_top_picks:
# ['2023-10-06', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 316, 2023-10-06, [15, 30, 60, 120], sym_freq_9, []
# 317, 2023-10-06, [15, 30, 60, 120], sym_freq_8, ['ICPT']
# 318, 2023-10-05, [30, 60, 120], sym_freq_12, []
# 319, 2023-10-05, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 382 to df_model_top_picks:
# ['2023-10-05', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 320, 2023-10-05, [30, 60, 120], sym_freq_8, []
# 321, 2023-10-05, [15, 30, 60, 120], sym_freq_12, ['FTSM', 'SHV']
#
# added row 383 to df_model_top_picks:
# ['2023-10-05', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 322, 2023-10-05, [15, 30, 60, 120], sym_freq_9, ['CLS']
# 323, 2023-10-05, [15, 30, 60, 120], sym_freq_8, ['ICPT', 'SPLK']
# 324, 2023-10-04, [30, 60, 120], sym_freq_12, []
# 325, 2023-10-04, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 384 to df_model_top_picks:
# ['2023-10-04', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 326, 2023-10-04, [30, 60, 120], sym_freq_8, []
# 327, 2023-10-04, [15, 30, 60, 120], sym_freq_12, ['FTSM', 'SHV']
#
# added row 385 to df_model_top_picks:
# ['2023-10-04', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 328, 2023-10-04, [15, 30, 60, 120], sym_freq_9, ['ICPT']
# 329, 2023-10-04, [15, 30, 60, 120], sym_freq_8, ['MLKN']
# 330, 2023-10-03, [30, 60, 120], sym_freq_12, []
# 331, 2023-10-03, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 386 to df_model_top_picks:
# ['2023-10-03', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 332, 2023-10-03, [30, 60, 120], sym_freq_8, ['ANF']
#
# added row 387 to df_model_top_picks:
# ['2023-10-03', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 333, 2023-10-03, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 388 to df_model_top_picks:
# ['2023-10-03', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 334, 2023-10-03, [15, 30, 60, 120], sym_freq_9, ['ANF', 'SPLK']
# 335, 2023-10-03, [15, 30, 60, 120], sym_freq_8, ['ICPT']
# 336, 2023-10-02, [30, 60, 120], sym_freq_12, []
# 337, 2023-10-02, [30, 60, 120], sym_freq_9, ['FTSM']
#
# added row 389 to df_model_top_picks:
# ['2023-10-02', [30, 60, 120], 'sym_freq_9', ['FTSM']]
#
# 338, 2023-10-02, [30, 60, 120], sym_freq_8, ['ANF']
#
# added row 390 to df_model_top_picks:
# ['2023-10-02', [30, 60, 120], 'sym_freq_8', ['ANF']]
#
# 339, 2023-10-02, [15, 30, 60, 120], sym_freq_12, ['FTSM']
#
# added row 391 to df_model_top_picks:
# ['2023-10-02', [15, 30, 60, 120], 'sym_freq_12', ['FTSM']]
#
# 340, 2023-10-02, [15, 30, 60, 120], sym_freq_9, ['ANF']
# 341, 2023-10-02, [15, 30, 60, 120], sym_freq_8, ['ICPT']
# 342, 2023-09-29, [30, 60, 120], sym_freq_12, []
# 343, 2023-09-29, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 392 to df_model_top_picks:
# ['2023-09-29', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 344, 2023-09-29, [30, 60, 120], sym_freq_8, []
# 345, 2023-09-29, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 393 to df_model_top_picks:
# ['2023-09-29', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 346, 2023-09-29, [15, 30, 60, 120], sym_freq_9, ['ARCH']
# 347, 2023-09-29, [15, 30, 60, 120], sym_freq_8, ['ICPT', 'NGS']
# 348, 2023-09-28, [30, 60, 120], sym_freq_12, []
# 349, 2023-09-28, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 394 to df_model_top_picks:
# ['2023-09-28', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 350, 2023-09-28, [30, 60, 120], sym_freq_8, ['CCJ']
#
# added row 395 to df_model_top_picks:
# ['2023-09-28', [30, 60, 120], 'sym_freq_8', ['CCJ']]
#
# 351, 2023-09-28, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 396 to df_model_top_picks:
# ['2023-09-28', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 352, 2023-09-28, [15, 30, 60, 120], sym_freq_9, ['ARCH']
# 353, 2023-09-28, [15, 30, 60, 120], sym_freq_8, ['CCJ', 'USAC']
# 354, 2023-09-27, [30, 60, 120], sym_freq_12, []
# 355, 2023-09-27, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 397 to df_model_top_picks:
# ['2023-09-27', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 356, 2023-09-27, [30, 60, 120], sym_freq_8, ['CCJ']
#
# added row 398 to df_model_top_picks:
# ['2023-09-27', [30, 60, 120], 'sym_freq_8', ['CCJ']]
#
# 357, 2023-09-27, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 399 to df_model_top_picks:
# ['2023-09-27', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 358, 2023-09-27, [15, 30, 60, 120], sym_freq_9, ['ARCH']
# 359, 2023-09-27, [15, 30, 60, 120], sym_freq_8, ['CCJ', 'ICPT', 'NGS']
# 360, 2023-09-26, [30, 60, 120], sym_freq_12, []
# 361, 2023-09-26, [30, 60, 120], sym_freq_9, ['CCJ', 'FTSM', 'SHV']
#
# added row 400 to df_model_top_picks:
# ['2023-09-26', [30, 60, 120], 'sym_freq_9', ['CCJ', 'FTSM', 'SHV']]
#
# 362, 2023-09-26, [30, 60, 120], sym_freq_8, []
# 363, 2023-09-26, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 401 to df_model_top_picks:
# ['2023-09-26', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 364, 2023-09-26, [15, 30, 60, 120], sym_freq_9, ['ARCH', 'CCJ']
# 365, 2023-09-26, [15, 30, 60, 120], sym_freq_8, ['ICPT']
# 366, 2023-09-25, [30, 60, 120], sym_freq_12, []
# 367, 2023-09-25, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 402 to df_model_top_picks:
# ['2023-09-25', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 368, 2023-09-25, [30, 60, 120], sym_freq_8, []
# 369, 2023-09-25, [15, 30, 60, 120], sym_freq_12, []
# 370, 2023-09-25, [15, 30, 60, 120], sym_freq_9, []
# 371, 2023-09-25, [15, 30, 60, 120], sym_freq_8, ['ARCH', 'CCJ']
# 372, 2023-09-22, [30, 60, 120], sym_freq_12, []
# 373, 2023-09-22, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 403 to df_model_top_picks:
# ['2023-09-22', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 374, 2023-09-22, [30, 60, 120], sym_freq_8, []
# 375, 2023-09-22, [15, 30, 60, 120], sym_freq_12, ['FTSM', 'SHV']
#
# added row 404 to df_model_top_picks:
# ['2023-09-22', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 376, 2023-09-22, [15, 30, 60, 120], sym_freq_9, []
# 377, 2023-09-22, [15, 30, 60, 120], sym_freq_8, []
# 378, 2023-09-21, [30, 60, 120], sym_freq_12, []
# 379, 2023-09-21, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 405 to df_model_top_picks:
# ['2023-09-21', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 380, 2023-09-21, [30, 60, 120], sym_freq_8, []
# 381, 2023-09-21, [15, 30, 60, 120], sym_freq_12, ['FTSM', 'SHV']
#
# added row 406 to df_model_top_picks:
# ['2023-09-21', [15, 30, 60, 120], 'sym_freq_12', ['FTSM', 'SHV']]
#
# 382, 2023-09-21, [15, 30, 60, 120], sym_freq_9, []
# 383, 2023-09-21, [15, 30, 60, 120], sym_freq_8, []
# 384, 2023-09-20, [30, 60, 120], sym_freq_12, []
# 385, 2023-09-20, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 407 to df_model_top_picks:
# ['2023-09-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 386, 2023-09-20, [30, 60, 120], sym_freq_8, []
# 387, 2023-09-20, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 408 to df_model_top_picks:
# ['2023-09-20', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 388, 2023-09-20, [15, 30, 60, 120], sym_freq_9, ['DELL']
# 389, 2023-09-20, [15, 30, 60, 120], sym_freq_8, []
# 390, 2023-09-19, [30, 60, 120], sym_freq_12, []
# 391, 2023-09-19, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 409 to df_model_top_picks:
# ['2023-09-19', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 392, 2023-09-19, [30, 60, 120], sym_freq_8, []
# 393, 2023-09-19, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 410 to df_model_top_picks:
# ['2023-09-19', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 394, 2023-09-19, [15, 30, 60, 120], sym_freq_9, []
# 395, 2023-09-19, [15, 30, 60, 120], sym_freq_8, ['DELL']
# 396, 2023-09-18, [30, 60, 120], sym_freq_12, []
# 397, 2023-09-18, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 411 to df_model_top_picks:
# ['2023-09-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 398, 2023-09-18, [30, 60, 120], sym_freq_8, ['FTSM']
#
# added row 412 to df_model_top_picks:
# ['2023-09-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 399, 2023-09-18, [15, 30, 60, 120], sym_freq_12, []
# 400, 2023-09-18, [15, 30, 60, 120], sym_freq_9, ['DELL']
# 401, 2023-09-18, [15, 30, 60, 120], sym_freq_8, []
# 402, 2023-09-15, [30, 60, 120], sym_freq_12, []
# 403, 2023-09-15, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 413 to df_model_top_picks:
# ['2023-09-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 404, 2023-09-15, [30, 60, 120], sym_freq_8, []
# 405, 2023-09-15, [15, 30, 60, 120], sym_freq_12, []
# 406, 2023-09-15, [15, 30, 60, 120], sym_freq_9, []
# 407, 2023-09-15, [15, 30, 60, 120], sym_freq_8, []
# 408, 2023-09-14, [30, 60, 120], sym_freq_12, []
# 409, 2023-09-14, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 414 to df_model_top_picks:
# ['2023-09-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 410, 2023-09-14, [30, 60, 120], sym_freq_8, ['DELL', 'FTSM']
#
# added row 415 to df_model_top_picks:
# ['2023-09-14', [30, 60, 120], 'sym_freq_8', ['DELL', 'FTSM']]
#
# 411, 2023-09-14, [15, 30, 60, 120], sym_freq_12, []
# 412, 2023-09-14, [15, 30, 60, 120], sym_freq_9, []
# 413, 2023-09-14, [15, 30, 60, 120], sym_freq_8, ['FTSM']
# 414, 2023-09-13, [30, 60, 120], sym_freq_12, []
# 415, 2023-09-13, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 416 to df_model_top_picks:
# ['2023-09-13', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 416, 2023-09-13, [30, 60, 120], sym_freq_8, ['DELL']
#
# added row 417 to df_model_top_picks:
# ['2023-09-13', [30, 60, 120], 'sym_freq_8', ['DELL']]
#
# 417, 2023-09-13, [15, 30, 60, 120], sym_freq_12, []
# 418, 2023-09-13, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 419, 2023-09-13, [15, 30, 60, 120], sym_freq_8, []
# 420, 2023-09-12, [30, 60, 120], sym_freq_12, []
# 421, 2023-09-12, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 418 to df_model_top_picks:
# ['2023-09-12', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 422, 2023-09-12, [30, 60, 120], sym_freq_8, ['DELL', 'MMYT']
#
# added row 419 to df_model_top_picks:
# ['2023-09-12', [30, 60, 120], 'sym_freq_8', ['DELL', 'MMYT']]
#
# 423, 2023-09-12, [15, 30, 60, 120], sym_freq_12, []
# 424, 2023-09-12, [15, 30, 60, 120], sym_freq_9, ['ANF', 'FTSM']
# 425, 2023-09-12, [15, 30, 60, 120], sym_freq_8, ['FTI', 'MMYT']
# 426, 2023-09-11, [30, 60, 120], sym_freq_12, []
# 427, 2023-09-11, [30, 60, 120], sym_freq_9, ['DELL', 'FTSM', 'SHV']
#
# added row 420 to df_model_top_picks:
# ['2023-09-11', [30, 60, 120], 'sym_freq_9', ['DELL', 'FTSM', 'SHV']]
#
# 428, 2023-09-11, [30, 60, 120], sym_freq_8, []
# 429, 2023-09-11, [15, 30, 60, 120], sym_freq_12, ['DELL']
#
# added row 421 to df_model_top_picks:
# ['2023-09-11', [15, 30, 60, 120], 'sym_freq_12', ['DELL']]
#
# 430, 2023-09-11, [15, 30, 60, 120], sym_freq_9, ['ANF', 'FTSM']
# 431, 2023-09-11, [15, 30, 60, 120], sym_freq_8, []
# 432, 2023-09-08, [30, 60, 120], sym_freq_12, []
# 433, 2023-09-08, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 422 to df_model_top_picks:
# ['2023-09-08', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 434, 2023-09-08, [30, 60, 120], sym_freq_8, ['DELL', 'STRL']
#
# added row 423 to df_model_top_picks:
# ['2023-09-08', [30, 60, 120], 'sym_freq_8', ['DELL', 'STRL']]
#
# 435, 2023-09-08, [15, 30, 60, 120], sym_freq_12, []
# 436, 2023-09-08, [15, 30, 60, 120], sym_freq_9, ['ANF', 'FTSM']
# 437, 2023-09-08, [15, 30, 60, 120], sym_freq_8, ['CELH', 'STRL']
# 438, 2023-09-07, [30, 60, 120], sym_freq_12, []
# 439, 2023-09-07, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 424 to df_model_top_picks:
# ['2023-09-07', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 440, 2023-09-07, [30, 60, 120], sym_freq_8, ['STRL']
#
# added row 425 to df_model_top_picks:
# ['2023-09-07', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 441, 2023-09-07, [15, 30, 60, 120], sym_freq_12, []
# 442, 2023-09-07, [15, 30, 60, 120], sym_freq_9, ['CELH', 'FTSM']
# 443, 2023-09-07, [15, 30, 60, 120], sym_freq_8, ['STRL']
# 444, 2023-09-06, [30, 60, 120], sym_freq_12, []
# 445, 2023-09-06, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 426 to df_model_top_picks:
# ['2023-09-06', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 446, 2023-09-06, [30, 60, 120], sym_freq_8, ['DELL', 'FTSM', 'STRL']
#
# added row 427 to df_model_top_picks:
# ['2023-09-06', [30, 60, 120], 'sym_freq_8', ['DELL', 'FTSM', 'STRL']]
#
# 447, 2023-09-06, [15, 30, 60, 120], sym_freq_12, []
# 448, 2023-09-06, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 449, 2023-09-06, [15, 30, 60, 120], sym_freq_8, ['STRL']
# 450, 2023-09-05, [30, 60, 120], sym_freq_12, []
# 451, 2023-09-05, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 428 to df_model_top_picks:
# ['2023-09-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 452, 2023-09-05, [30, 60, 120], sym_freq_8, ['FTSM']
#
# added row 429 to df_model_top_picks:
# ['2023-09-05', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 453, 2023-09-05, [15, 30, 60, 120], sym_freq_12, []
# 454, 2023-09-05, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 455, 2023-09-05, [15, 30, 60, 120], sym_freq_8, []
# 456, 2023-09-01, [30, 60, 120], sym_freq_12, []
# 457, 2023-09-01, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 430 to df_model_top_picks:
# ['2023-09-01', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 458, 2023-09-01, [30, 60, 120], sym_freq_8, ['FTSM', 'STRL']
#
# added row 431 to df_model_top_picks:
# ['2023-09-01', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 459, 2023-09-01, [15, 30, 60, 120], sym_freq_12, []
# 460, 2023-09-01, [15, 30, 60, 120], sym_freq_9, ['ANF', 'DELL', 'FTSM']
# 461, 2023-09-01, [15, 30, 60, 120], sym_freq_8, ['STRL', 'TDS']
# 462, 2023-08-31, [30, 60, 120], sym_freq_12, []
# 463, 2023-08-31, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 432 to df_model_top_picks:
# ['2023-08-31', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 464, 2023-08-31, [30, 60, 120], sym_freq_8, ['FTSM', 'STRL']
#
# added row 433 to df_model_top_picks:
# ['2023-08-31', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 465, 2023-08-31, [15, 30, 60, 120], sym_freq_12, []
# 466, 2023-08-31, [15, 30, 60, 120], sym_freq_9, ['FTSM']
# 467, 2023-08-31, [15, 30, 60, 120], sym_freq_8, ['STRL', 'TDS', 'UBS']
# 468, 2023-08-30, [30, 60, 120], sym_freq_12, []
# 469, 2023-08-30, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 434 to df_model_top_picks:
# ['2023-08-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 470, 2023-08-30, [30, 60, 120], sym_freq_8, ['FTSM', 'STRL']
#
# added row 435 to df_model_top_picks:
# ['2023-08-30', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 471, 2023-08-30, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 436 to df_model_top_picks:
# ['2023-08-30', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 472, 2023-08-30, [15, 30, 60, 120], sym_freq_9, ['ANF', 'FTSM']
# 473, 2023-08-30, [15, 30, 60, 120], sym_freq_8, ['STRL', 'TDS']
# 474, 2023-08-29, [30, 60, 120], sym_freq_12, []
# 475, 2023-08-29, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 437 to df_model_top_picks:
# ['2023-08-29', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 476, 2023-08-29, [30, 60, 120], sym_freq_8, ['STRL']
#
# added row 438 to df_model_top_picks:
# ['2023-08-29', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 477, 2023-08-29, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 439 to df_model_top_picks:
# ['2023-08-29', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 478, 2023-08-29, [15, 30, 60, 120], sym_freq_9, ['ANF']
# 479, 2023-08-29, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'STRL', 'TDS']
# 480, 2023-08-28, [30, 60, 120], sym_freq_12, []
# 481, 2023-08-28, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 440 to df_model_top_picks:
# ['2023-08-28', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 482, 2023-08-28, [30, 60, 120], sym_freq_8, ['FTSM', 'STRL']
#
# added row 441 to df_model_top_picks:
# ['2023-08-28', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 483, 2023-08-28, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 442 to df_model_top_picks:
# ['2023-08-28', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 484, 2023-08-28, [15, 30, 60, 120], sym_freq_9, ['ANF', 'FTSM']
# 485, 2023-08-28, [15, 30, 60, 120], sym_freq_8, ['STRL']
# 486, 2023-08-25, [30, 60, 120], sym_freq_12, []
# 487, 2023-08-25, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 443 to df_model_top_picks:
# ['2023-08-25', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 488, 2023-08-25, [30, 60, 120], sym_freq_8, ['STRL']
#
# added row 444 to df_model_top_picks:
# ['2023-08-25', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 489, 2023-08-25, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 445 to df_model_top_picks:
# ['2023-08-25', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 490, 2023-08-25, [15, 30, 60, 120], sym_freq_9, ['ANF', 'TDS']
# 491, 2023-08-25, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'LLY']
# 492, 2023-08-24, [30, 60, 120], sym_freq_12, []
# 493, 2023-08-24, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 446 to df_model_top_picks:
# ['2023-08-24', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 494, 2023-08-24, [30, 60, 120], sym_freq_8, ['STRL']
#
# added row 447 to df_model_top_picks:
# ['2023-08-24', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 495, 2023-08-24, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 448 to df_model_top_picks:
# ['2023-08-24', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 496, 2023-08-24, [15, 30, 60, 120], sym_freq_9, ['ANF', 'FTSM', 'TDS']
# 497, 2023-08-24, [15, 30, 60, 120], sym_freq_8, ['LLY']
# 498, 2023-08-23, [30, 60, 120], sym_freq_12, []
# 499, 2023-08-23, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 449 to df_model_top_picks:
# ['2023-08-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 500, 2023-08-23, [30, 60, 120], sym_freq_8, ['STRL']
#
# added row 450 to df_model_top_picks:
# ['2023-08-23', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 501, 2023-08-23, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 451 to df_model_top_picks:
# ['2023-08-23', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 502, 2023-08-23, [15, 30, 60, 120], sym_freq_9, ['ANF', 'FTSM', 'LLY', 'TDS']
# 503, 2023-08-23, [15, 30, 60, 120], sym_freq_8, []
# 504, 2023-08-22, [30, 60, 120], sym_freq_12, []
# 505, 2023-08-22, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 452 to df_model_top_picks:
# ['2023-08-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 506, 2023-08-22, [30, 60, 120], sym_freq_8, ['FTSM', 'STRL']
#
# added row 453 to df_model_top_picks:
# ['2023-08-22', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 507, 2023-08-22, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 454 to df_model_top_picks:
# ['2023-08-22', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 508, 2023-08-22, [15, 30, 60, 120], sym_freq_9, ['LLY', 'TDS']
# 509, 2023-08-22, [15, 30, 60, 120], sym_freq_8, ['CNX', 'SM']
# 510, 2023-08-21, [30, 60, 120], sym_freq_12, []
# 511, 2023-08-21, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 455 to df_model_top_picks:
# ['2023-08-21', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 512, 2023-08-21, [30, 60, 120], sym_freq_8, ['FTSM', 'STRL']
#
# added row 456 to df_model_top_picks:
# ['2023-08-21', [30, 60, 120], 'sym_freq_8', ['FTSM', 'STRL']]
#
# 513, 2023-08-21, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 457 to df_model_top_picks:
# ['2023-08-21', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 514, 2023-08-21, [15, 30, 60, 120], sym_freq_9, ['LLY', 'SM', 'TDS']
# 515, 2023-08-21, [15, 30, 60, 120], sym_freq_8, ['CNX']
# 516, 2023-08-18, [30, 60, 120], sym_freq_12, []
# 517, 2023-08-18, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 458 to df_model_top_picks:
# ['2023-08-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 518, 2023-08-18, [30, 60, 120], sym_freq_8, ['FTSM']
#
# added row 459 to df_model_top_picks:
# ['2023-08-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 519, 2023-08-18, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 460 to df_model_top_picks:
# ['2023-08-18', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 520, 2023-08-18, [15, 30, 60, 120], sym_freq_9, ['CNX', 'STRL', 'TDS']
# 521, 2023-08-18, [15, 30, 60, 120], sym_freq_8, []
# 522, 2023-08-17, [30, 60, 120], sym_freq_12, []
# 523, 2023-08-17, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 461 to df_model_top_picks:
# ['2023-08-17', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 524, 2023-08-17, [30, 60, 120], sym_freq_8, ['FTSM']
#
# added row 462 to df_model_top_picks:
# ['2023-08-17', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 525, 2023-08-17, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 463 to df_model_top_picks:
# ['2023-08-17', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 526, 2023-08-17, [15, 30, 60, 120], sym_freq_9, ['CNX', 'TDS']
# 527, 2023-08-17, [15, 30, 60, 120], sym_freq_8, []
# 528, 2023-08-16, [30, 60, 120], sym_freq_12, []
# 529, 2023-08-16, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 464 to df_model_top_picks:
# ['2023-08-16', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 530, 2023-08-16, [30, 60, 120], sym_freq_8, ['STRL']
#
# added row 465 to df_model_top_picks:
# ['2023-08-16', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 531, 2023-08-16, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 466 to df_model_top_picks:
# ['2023-08-16', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 532, 2023-08-16, [15, 30, 60, 120], sym_freq_9, ['TDS']
# 533, 2023-08-16, [15, 30, 60, 120], sym_freq_8, ['CNX']
# 534, 2023-08-15, [30, 60, 120], sym_freq_12, []
# 535, 2023-08-15, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 467 to df_model_top_picks:
# ['2023-08-15', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 536, 2023-08-15, [30, 60, 120], sym_freq_8, ['STRL']
#
# added row 468 to df_model_top_picks:
# ['2023-08-15', [30, 60, 120], 'sym_freq_8', ['STRL']]
#
# 537, 2023-08-15, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# added row 469 to df_model_top_picks:
# ['2023-08-15', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 538, 2023-08-15, [15, 30, 60, 120], sym_freq_9, ['TDS']
# 539, 2023-08-15, [15, 30, 60, 120], sym_freq_8, []
# 540, 2023-08-14, [30, 60, 120], sym_freq_12, []
# 541, 2023-08-14, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 470 to df_model_top_picks:
# ['2023-08-14', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 542, 2023-08-14, [30, 60, 120], sym_freq_8, []
# 543, 2023-08-14, [15, 30, 60, 120], sym_freq_12, []
# 544, 2023-08-14, [15, 30, 60, 120], sym_freq_9, ['TDS']
# 545, 2023-08-14, [15, 30, 60, 120], sym_freq_8, ['CLS', 'EME']
# 546, 2023-08-11, [30, 60, 120], sym_freq_12, []
# 547, 2023-08-11, [30, 60, 120], sym_freq_9, []
# 548, 2023-08-11, [30, 60, 120], sym_freq_8, ['SHV', 'STRL']
#
# added row 471 to df_model_top_picks:
# ['2023-08-11', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 549, 2023-08-11, [15, 30, 60, 120], sym_freq_12, []
# 550, 2023-08-11, [15, 30, 60, 120], sym_freq_9, ['TDS']
# 551, 2023-08-11, [15, 30, 60, 120], sym_freq_8, []
# 552, 2023-08-10, [30, 60, 120], sym_freq_12, []
# 553, 2023-08-10, [30, 60, 120], sym_freq_9, []
# 554, 2023-08-10, [30, 60, 120], sym_freq_8, ['SHV', 'STRL']
#
# added row 472 to df_model_top_picks:
# ['2023-08-10', [30, 60, 120], 'sym_freq_8', ['SHV', 'STRL']]
#
# 555, 2023-08-10, [15, 30, 60, 120], sym_freq_12, []
# 556, 2023-08-10, [15, 30, 60, 120], sym_freq_9, ['LOB', 'TDS']
# 557, 2023-08-10, [15, 30, 60, 120], sym_freq_8, []
# 558, 2023-08-09, [30, 60, 120], sym_freq_12, []
# 559, 2023-08-09, [30, 60, 120], sym_freq_9, []
# 560, 2023-08-09, [30, 60, 120], sym_freq_8, ['SHV', 'STRL']
#
# added row 473 to df_model_top_picks:
# ...
#
# 939, 2023-05-09, [15, 30, 60, 120], sym_freq_12, []
# 940, 2023-05-09, [15, 30, 60, 120], sym_freq_9, ['BLDR']
# 941, 2023-05-09, [15, 30, 60, 120], sym_freq_8, []
# 942, 2023-05-08, [30, 60, 120], sym_freq_12, []
# 943, 2023-05-08, [30, 60, 120], sym_freq_9, []
# 944, 2023-05-08, [30, 60, 120], sym_freq_8, ['ISEE', 'SHV']
#
# added row 544 to df_model_top_picks:
# ['2023-05-08', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 945, 2023-05-08, [15, 30, 60, 120], sym_freq_12, []
# 946, 2023-05-08, [15, 30, 60, 120], sym_freq_9, []
# 947, 2023-05-08, [15, 30, 60, 120], sym_freq_8, []
# 948, 2023-05-05, [30, 60, 120], sym_freq_12, []
# 949, 2023-05-05, [30, 60, 120], sym_freq_9, []
# 950, 2023-05-05, [30, 60, 120], sym_freq_8, ['ISEE', 'SHV']
#
# added row 545 to df_model_top_picks:
# ['2023-05-05', [30, 60, 120], 'sym_freq_8', ['ISEE', 'SHV']]
#
# 951, 2023-05-05, [15, 30, 60, 120], sym_freq_12, []
# 952, 2023-05-05, [15, 30, 60, 120], sym_freq_9, []
# 953, 2023-05-05, [15, 30, 60, 120], sym_freq_8, []
# 954, 2023-05-04, [30, 60, 120], sym_freq_12, []
# 955, 2023-05-04, [30, 60, 120], sym_freq_9, []
# 956, 2023-05-04, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 546 to df_model_top_picks:
# ['2023-05-04', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 957, 2023-05-04, [15, 30, 60, 120], sym_freq_12, []
# 958, 2023-05-04, [15, 30, 60, 120], sym_freq_9, ['CCEP']
# 959, 2023-05-04, [15, 30, 60, 120], sym_freq_8, []
# 960, 2023-05-03, [30, 60, 120], sym_freq_12, []
# 961, 2023-05-03, [30, 60, 120], sym_freq_9, []
# 962, 2023-05-03, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 547 to df_model_top_picks:
# ['2023-05-03', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 963, 2023-05-03, [15, 30, 60, 120], sym_freq_12, []
# 964, 2023-05-03, [15, 30, 60, 120], sym_freq_9, ['ISEE']
# 965, 2023-05-03, [15, 30, 60, 120], sym_freq_8, ['CCEP', 'SHV', 'SKYW']
# 966, 2023-05-02, [30, 60, 120], sym_freq_12, []
# 967, 2023-05-02, [30, 60, 120], sym_freq_9, []
# 968, 2023-05-02, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 548 to df_model_top_picks:
# ['2023-05-02', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 969, 2023-05-02, [15, 30, 60, 120], sym_freq_12, []
# 970, 2023-05-02, [15, 30, 60, 120], sym_freq_9, ['CCEP', 'ISEE', 'SHV']
# 971, 2023-05-02, [15, 30, 60, 120], sym_freq_8, []
# 972, 2023-05-01, [30, 60, 120], sym_freq_12, []
# 973, 2023-05-01, [30, 60, 120], sym_freq_9, []
# 974, 2023-05-01, [30, 60, 120], sym_freq_8, []
# 975, 2023-05-01, [15, 30, 60, 120], sym_freq_12, []
# 976, 2023-05-01, [15, 30, 60, 120], sym_freq_9, []
# 977, 2023-05-01, [15, 30, 60, 120], sym_freq_8, ['ISEE']
# 978, 2023-04-28, [30, 60, 120], sym_freq_12, []
# 979, 2023-04-28, [30, 60, 120], sym_freq_9, []
# 980, 2023-04-28, [30, 60, 120], sym_freq_8, []
# 981, 2023-04-28, [15, 30, 60, 120], sym_freq_12, []
# 982, 2023-04-28, [15, 30, 60, 120], sym_freq_9, []
# 983, 2023-04-28, [15, 30, 60, 120], sym_freq_8, ['PHM', 'SHV']
# 984, 2023-04-27, [30, 60, 120], sym_freq_12, []
# 985, 2023-04-27, [30, 60, 120], sym_freq_9, []
# 986, 2023-04-27, [30, 60, 120], sym_freq_8, []
# 987, 2023-04-27, [15, 30, 60, 120], sym_freq_12, []
# 988, 2023-04-27, [15, 30, 60, 120], sym_freq_9, []
# 989, 2023-04-27, [15, 30, 60, 120], sym_freq_8, ['PHM', 'SHV']
# 990, 2023-04-26, [30, 60, 120], sym_freq_12, []
# 991, 2023-04-26, [30, 60, 120], sym_freq_9, []
# 992, 2023-04-26, [30, 60, 120], sym_freq_8, ['ELF']
#
# added row 549 to df_model_top_picks:
# ['2023-04-26', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 993, 2023-04-26, [15, 30, 60, 120], sym_freq_12, []
# 994, 2023-04-26, [15, 30, 60, 120], sym_freq_9, ['ELF']
# 995, 2023-04-26, [15, 30, 60, 120], sym_freq_8, ['SHV']
# 996, 2023-04-25, [30, 60, 120], sym_freq_12, []
# 997, 2023-04-25, [30, 60, 120], sym_freq_9, []
# 998, 2023-04-25, [30, 60, 120], sym_freq_8, ['ELF', 'SHV']
#
# added row 550 to df_model_top_picks:
# ['2023-04-25', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 999, 2023-04-25, [15, 30, 60, 120], sym_freq_12, []
# 1000, 2023-04-25, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1001, 2023-04-25, [15, 30, 60, 120], sym_freq_8, ['ELF']
# 1002, 2023-04-24, [30, 60, 120], sym_freq_12, []
# 1003, 2023-04-24, [30, 60, 120], sym_freq_9, []
# 1004, 2023-04-24, [30, 60, 120], sym_freq_8, ['ELF']
#
# added row 551 to df_model_top_picks:
# ['2023-04-24', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 1005, 2023-04-24, [15, 30, 60, 120], sym_freq_12, []
# 1006, 2023-04-24, [15, 30, 60, 120], sym_freq_9, ['ELF']
# 1007, 2023-04-24, [15, 30, 60, 120], sym_freq_8, ['SHV']
# 1008, 2023-04-21, [30, 60, 120], sym_freq_12, []
# 1009, 2023-04-21, [30, 60, 120], sym_freq_9, []
# 1010, 2023-04-21, [30, 60, 120], sym_freq_8, ['ELF']
#
# added row 552 to df_model_top_picks:
# ['2023-04-21', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 1011, 2023-04-21, [15, 30, 60, 120], sym_freq_12, []
# 1012, 2023-04-21, [15, 30, 60, 120], sym_freq_9, ['ELF']
# 1013, 2023-04-21, [15, 30, 60, 120], sym_freq_8, ['SHV']
# 1014, 2023-04-20, [30, 60, 120], sym_freq_12, []
# 1015, 2023-04-20, [30, 60, 120], sym_freq_9, []
# 1016, 2023-04-20, [30, 60, 120], sym_freq_8, ['ELF']
#
# added row 553 to df_model_top_picks:
# ['2023-04-20', [30, 60, 120], 'sym_freq_8', ['ELF']]
#
# 1017, 2023-04-20, [15, 30, 60, 120], sym_freq_12, []
# 1018, 2023-04-20, [15, 30, 60, 120], sym_freq_9, []
# 1019, 2023-04-20, [15, 30, 60, 120], sym_freq_8, ['SHV']
# 1020, 2023-04-19, [30, 60, 120], sym_freq_12, []
# 1021, 2023-04-19, [30, 60, 120], sym_freq_9, []
# 1022, 2023-04-19, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 554 to df_model_top_picks:
# ['2023-04-19', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 1023, 2023-04-19, [15, 30, 60, 120], sym_freq_12, []
# 1024, 2023-04-19, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1025, 2023-04-19, [15, 30, 60, 120], sym_freq_8, []
# 1026, 2023-04-18, [30, 60, 120], sym_freq_12, []
# 1027, 2023-04-18, [30, 60, 120], sym_freq_9, []
# 1028, 2023-04-18, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 555 to df_model_top_picks:
# ['2023-04-18', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 1029, 2023-04-18, [15, 30, 60, 120], sym_freq_12, []
# 1030, 2023-04-18, [15, 30, 60, 120], sym_freq_9, []
# 1031, 2023-04-18, [15, 30, 60, 120], sym_freq_8, ['SHV']
# 1032, 2023-04-17, [30, 60, 120], sym_freq_12, []
# 1033, 2023-04-17, [30, 60, 120], sym_freq_9, []
# 1034, 2023-04-17, [30, 60, 120], sym_freq_8, ['ELF', 'SHV']
#
# added row 556 to df_model_top_picks:
# ['2023-04-17', [30, 60, 120], 'sym_freq_8', ['ELF', 'SHV']]
#
# 1035, 2023-04-17, [15, 30, 60, 120], sym_freq_12, []
# 1036, 2023-04-17, [15, 30, 60, 120], sym_freq_9, []
# 1037, 2023-04-17, [15, 30, 60, 120], sym_freq_8, ['ELF', 'SHV']
# 1038, 2023-04-14, [30, 60, 120], sym_freq_12, []
# 1039, 2023-04-14, [30, 60, 120], sym_freq_9, []
# 1040, 2023-04-14, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 557 to df_model_top_picks:
# ['2023-04-14', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 1041, 2023-04-14, [15, 30, 60, 120], sym_freq_12, []
# 1042, 2023-04-14, [15, 30, 60, 120], sym_freq_9, []
# 1043, 2023-04-14, [15, 30, 60, 120], sym_freq_8, ['SHV']
# 1044, 2023-04-13, [30, 60, 120], sym_freq_12, []
# 1045, 2023-04-13, [30, 60, 120], sym_freq_9, []
# 1046, 2023-04-13, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 558 to df_model_top_picks:
# ['2023-04-13', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 1047, 2023-04-13, [15, 30, 60, 120], sym_freq_12, []
# 1048, 2023-04-13, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1049, 2023-04-13, [15, 30, 60, 120], sym_freq_8, []
# 1050, 2023-04-12, [30, 60, 120], sym_freq_12, []
# 1051, 2023-04-12, [30, 60, 120], sym_freq_9, []
# 1052, 2023-04-12, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 559 to df_model_top_picks:
# ['2023-04-12', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 1053, 2023-04-12, [15, 30, 60, 120], sym_freq_12, []
# 1054, 2023-04-12, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1055, 2023-04-12, [15, 30, 60, 120], sym_freq_8, []
# 1056, 2023-04-11, [30, 60, 120], sym_freq_12, []
# 1057, 2023-04-11, [30, 60, 120], sym_freq_9, []
# 1058, 2023-04-11, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 560 to df_model_top_picks:
# ['2023-04-11', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 1059, 2023-04-11, [15, 30, 60, 120], sym_freq_12, []
# 1060, 2023-04-11, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1061, 2023-04-11, [15, 30, 60, 120], sym_freq_8, []
# 1062, 2023-04-10, [30, 60, 120], sym_freq_12, []
# 1063, 2023-04-10, [30, 60, 120], sym_freq_9, []
# 1064, 2023-04-10, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 561 to df_model_top_picks:
# ['2023-04-10', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 1065, 2023-04-10, [15, 30, 60, 120], sym_freq_12, []
# 1066, 2023-04-10, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1067, 2023-04-10, [15, 30, 60, 120], sym_freq_8, []
# 1068, 2023-04-06, [30, 60, 120], sym_freq_12, []
# 1069, 2023-04-06, [30, 60, 120], sym_freq_9, []
# 1070, 2023-04-06, [30, 60, 120], sym_freq_8, ['SHV']
#
# added row 562 to df_model_top_picks:
# ['2023-04-06', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 1071, 2023-04-06, [15, 30, 60, 120], sym_freq_12, []
# 1072, 2023-04-06, [15, 30, 60, 120], sym_freq_9, []
# 1073, 2023-04-06, [15, 30, 60, 120], sym_freq_8, ['SHV']
# 1074, 2023-04-05, [30, 60, 120], sym_freq_12, []
# 1075, 2023-04-05, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 563 to df_model_top_picks:
# ['2023-04-05', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1076, 2023-04-05, [30, 60, 120], sym_freq_8, []
# 1077, 2023-04-05, [15, 30, 60, 120], sym_freq_12, []
# 1078, 2023-04-05, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1079, 2023-04-05, [15, 30, 60, 120], sym_freq_8, []
# 1080, 2023-04-04, [30, 60, 120], sym_freq_12, []
# 1081, 2023-04-04, [30, 60, 120], sym_freq_9, []
# 1082, 2023-04-04, [30, 60, 120], sym_freq_8, ['NVDA', 'SHV']
#
# added row 564 to df_model_top_picks:
# ['2023-04-04', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 1083, 2023-04-04, [15, 30, 60, 120], sym_freq_12, []
# 1084, 2023-04-04, [15, 30, 60, 120], sym_freq_9, []
# 1085, 2023-04-04, [15, 30, 60, 120], sym_freq_8, ['NVDA', 'SHV']
# 1086, 2023-04-03, [30, 60, 120], sym_freq_12, []
# 1087, 2023-04-03, [30, 60, 120], sym_freq_9, []
# 1088, 2023-04-03, [30, 60, 120], sym_freq_8, ['GE', 'NVDA']
#
# added row 565 to df_model_top_picks:
# ['2023-04-03', [30, 60, 120], 'sym_freq_8', ['GE', 'NVDA']]
#
# 1089, 2023-04-03, [15, 30, 60, 120], sym_freq_12, []
# 1090, 2023-04-03, [15, 30, 60, 120], sym_freq_9, []
# 1091, 2023-04-03, [15, 30, 60, 120], sym_freq_8, ['GE', 'PERI']
# 1092, 2023-03-31, [30, 60, 120], sym_freq_12, []
# 1093, 2023-03-31, [30, 60, 120], sym_freq_9, []
# 1094, 2023-03-31, [30, 60, 120], sym_freq_8, ['NVDA']
#
# added row 566 to df_model_top_picks:
# ['2023-03-31', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 1095, 2023-03-31, [15, 30, 60, 120], sym_freq_12, []
# 1096, 2023-03-31, [15, 30, 60, 120], sym_freq_9, []
# 1097, 2023-03-31, [15, 30, 60, 120], sym_freq_8, []
# 1098, 2023-03-30, [30, 60, 120], sym_freq_12, []
# 1099, 2023-03-30, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 567 to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1100, 2023-03-30, [30, 60, 120], sym_freq_8, ['NVDA']
#
# added row 568 to df_model_top_picks:
# ['2023-03-30', [30, 60, 120], 'sym_freq_8', ['NVDA']]
#
# 1101, 2023-03-30, [15, 30, 60, 120], sym_freq_12, []
# 1102, 2023-03-30, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1103, 2023-03-30, [15, 30, 60, 120], sym_freq_8, []
# 1104, 2023-03-29, [30, 60, 120], sym_freq_12, []
# 1105, 2023-03-29, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 569 to df_model_top_picks:
# ['2023-03-29', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1106, 2023-03-29, [30, 60, 120], sym_freq_8, []
# 1107, 2023-03-29, [15, 30, 60, 120], sym_freq_12, []
# 1108, 2023-03-29, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1109, 2023-03-29, [15, 30, 60, 120], sym_freq_8, ['SGEN']
# 1110, 2023-03-28, [30, 60, 120], sym_freq_12, []
# 1111, 2023-03-28, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 570 to df_model_top_picks:
# ['2023-03-28', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1112, 2023-03-28, [30, 60, 120], sym_freq_8, []
# 1113, 2023-03-28, [15, 30, 60, 120], sym_freq_12, []
# 1114, 2023-03-28, [15, 30, 60, 120], sym_freq_9, []
# 1115, 2023-03-28, [15, 30, 60, 120], sym_freq_8, ['SGEN']
# 1116, 2023-03-27, [30, 60, 120], sym_freq_12, []
# 1117, 2023-03-27, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 571 to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1118, 2023-03-27, [30, 60, 120], sym_freq_8, ['GE']
#
# added row 572 to df_model_top_picks:
# ['2023-03-27', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 1119, 2023-03-27, [15, 30, 60, 120], sym_freq_12, []
# 1120, 2023-03-27, [15, 30, 60, 120], sym_freq_9, []
# 1121, 2023-03-27, [15, 30, 60, 120], sym_freq_8, ['GE', 'NVDA', 'SGEN']
# 1122, 2023-03-24, [30, 60, 120], sym_freq_12, []
# 1123, 2023-03-24, [30, 60, 120], sym_freq_9, []
# 1124, 2023-03-24, [30, 60, 120], sym_freq_8, ['NVDA', 'SHV']
#
# added row 573 to df_model_top_picks:
# ['2023-03-24', [30, 60, 120], 'sym_freq_8', ['NVDA', 'SHV']]
#
# 1125, 2023-03-24, [15, 30, 60, 120], sym_freq_12, []
# 1126, 2023-03-24, [15, 30, 60, 120], sym_freq_9, ['SHV']
# 1127, 2023-03-24, [15, 30, 60, 120], sym_freq_8, ['SGEN']
# 1128, 2023-03-23, [30, 60, 120], sym_freq_12, []
# 1129, 2023-03-23, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 574 to df_model_top_picks:
# ['2023-03-23', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1130, 2023-03-23, [30, 60, 120], sym_freq_8, []
# 1131, 2023-03-23, [15, 30, 60, 120], sym_freq_12, []
# 1132, 2023-03-23, [15, 30, 60, 120], sym_freq_9, ['NVDA']
# 1133, 2023-03-23, [15, 30, 60, 120], sym_freq_8, ['FTSM', 'GE']
# 1134, 2023-03-22, [30, 60, 120], sym_freq_12, []
# 1135, 2023-03-22, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 575 to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1136, 2023-03-22, [30, 60, 120], sym_freq_8, ['FTSM']
#
# added row 576 to df_model_top_picks:
# ['2023-03-22', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 1137, 2023-03-22, [15, 30, 60, 120], sym_freq_12, []
# 1138, 2023-03-22, [15, 30, 60, 120], sym_freq_9, ['FTSM', 'NVDA']
# 1139, 2023-03-22, [15, 30, 60, 120], sym_freq_8, ['SGEN']
# 1140, 2023-03-21, [30, 60, 120], sym_freq_12, []
# 1141, 2023-03-21, [30, 60, 120], sym_freq_9, ['SHV']
#
# added row 577 to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1142, 2023-03-21, [30, 60, 120], sym_freq_8, ['GE']
#
# added row 578 to df_model_top_picks:
# ['2023-03-21', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 1143, 2023-03-21, [15, 30, 60, 120], sym_freq_12, []
# 1144, 2023-03-21, [15, 30, 60, 120], sym_freq_9, ['GE']
# 1145, 2023-03-21, [15, 30, 60, 120], sym_freq_8, []
# 1146, 2023-03-20, [30, 60, 120], sym_freq_12, []
# 1147, 2023-03-20, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 579 to df_model_top_picks:
# ['2023-03-20', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 1148, 2023-03-20, [30, 60, 120], sym_freq_8, []
# 1149, 2023-03-20, [15, 30, 60, 120], sym_freq_12, []
# 1150, 2023-03-20, [15, 30, 60, 120], sym_freq_9, []
# 1151, 2023-03-20, [15, 30, 60, 120], sym_freq_8, []
# 1152, 2023-03-17, [30, 60, 120], sym_freq_12, []
# 1153, 2023-03-17, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 580 to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 1154, 2023-03-17, [30, 60, 120], sym_freq_8, ['GE']
#
# added row 581 to df_model_top_picks:
# ['2023-03-17', [30, 60, 120], 'sym_freq_8', ['GE']]
#
# 1155, 2023-03-17, [15, 30, 60, 120], sym_freq_12, []
# 1156, 2023-03-17, [15, 30, 60, 120], sym_freq_9, ['FTSM', 'GE']
# 1157, 2023-03-17, [15, 30, 60, 120], sym_freq_8, []
# 1158, 2023-03-16, [30, 60, 120], sym_freq_12, []
# 1159, 2023-03-16, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 582 to df_model_top_picks:
# ['2023-03-16', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 1160, 2023-03-16, [30, 60, 120], sym_freq_8, []
# 1161, 2023-03-16, [15, 30, 60, 120], sym_freq_12, []
# 1162, 2023-03-16, [15, 30, 60, 120], sym_freq_9, ['SGEN']
# 1163, 2023-03-16, [15, 30, 60, 120], sym_freq_8, []
# 1164, 2023-03-15, [30, 60, 120], sym_freq_12, []
# 1165, 2023-03-15, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# added row 583 to df_model_top_picks:
# ['2023-03-15', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 1166, 2023-03-15, [30, 60, 120], sym_freq_8, []
# 1167, 2023-03-15, [15, 30, 60, 120], sym_freq_12, []
# 1168, 2023-03-15, [15, 30, 60, 120], sym_freq_9, ['SGEN']
# 1169, 2023-03-15, [15, 30, 60, 120], sym_freq_8, ['AMPH', 'FCN']

# %% [markdown]
# #### Cleanup df_model_top_picks<br>- convert data to str<br>- drop duplicates, keep last value<br>- sort date, newest first<br>- re-index

# %%
df_model_top_picks = df_model_top_picks.astype(str)
df_model_top_picks = df_model_top_picks.drop_duplicates(keep='last')
df_model_top_picks = df_model_top_picks.sort_values(by=['date', 'days_lookback', 'syms_freq'], ascending=False)
df_model_top_picks = df_model_top_picks.reset_index(drop=True)
pickle_dump(df_model_top_picks, path_data_dump, fp_df_model_top_picks)
print(f'len(df_model_top_picks): {len(df_model_top_picks)}')
print(f'{fp_df_model_top_picks}:\n{df_model_top_picks}')
# Out:
# len(df_model_top_picks): 293
# df_model_top_picks:
#            date  days_lookback   syms_freq          symbols
# 0    2023-12-20  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']
# 1    2023-12-19  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']
# 2    2023-12-18  [30, 60, 120]  sym_freq_8          ['SHV']
# 3    2023-12-15  [30, 60, 120]  sym_freq_8          ['SHV']
# 4    2023-12-13  [30, 60, 120]  sym_freq_8   ['GPS', 'SHV']
# ..          ...            ...         ...              ...
# 288  2023-03-20  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 289  2023-03-17  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 290  2023-03-17  [30, 60, 120]  sym_freq_8           ['GE']
# 291  2023-03-16  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
# 292  2023-03-15  [30, 60, 120]  sym_freq_9  ['FTSM', 'SHV']
#
# [293 rows x 4 columns]
